# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
print('Importing Librairies...')
import talib
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import xgboost as xgb
from xgboost import XGBRegressor, plot_importance
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')
import time
import datetime as dt
import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
print('Librairies imported')
print('')

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print('BOOST SKAN 55 Version v1.40',Style.RESET_ALL)



print('')
print('Sraping tickers')
constituents = pd.read_csv('New.csv')
print('Scrap -----> ok')
# PARAMETRES TEMPORELS INITIAUX
start = pd.to_datetime('2015-06-01')
end = pd.to_datetime('2019-12-31')

error = []


try :
    amorce = pd.read_csv('compteur.csv').index[-1] + 1
except:
    amorce = 0
    compteur = pd.DataFrame(columns = ['Symb.','Name','Sector'])
    
    
    
# SCRAPING DES DONNES BRUTES
def scrap_data(ticker,start,end):
    df = web.DataReader(ticker,'yahoo',start,end)
    df = df.drop(['Close'],axis=1)
    df['Close'] = df['Adj Close']
    df = df.drop(['Adj Close'],axis = 1)    
    return(df)

def prepa_data(df):
    tmps1=time.time()
    print('Preparing data...')
    rsi = talib.RSI(df['Close'],timeperiod=14)
    stoc_slowk, stoc_slowd = talib.STOCH(df['High'],df['Low'],df['Close'])
    upper, middle, lower =  talib.BBANDS(df['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(df['Close'],timeperiod=5)
    sma8 = talib.SMA(df['Close'],timeperiod=8)
    sma10 = talib.SMA(df['Close'],timeperiod=10)
    sma12 = talib.SMA(df['Close'],timeperiod=12)
    sma15 = talib.SMA(df['Close'],timeperiod=15)
    sma30 = talib.SMA(df['Close'],timeperiod=30)
    sma35 = talib.SMA(df['Close'],timeperiod=35)
    sma40 = talib.SMA(df['Close'],timeperiod=40)
    sma45 = talib.SMA(df['Close'],timeperiod=45)
    sma50 = talib.SMA(df['Close'],timeperiod=50)
    atr = talib.ATR(df['High'],df['Low'],df['Close'],timeperiod=10)
    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50
    bbdelta = upper - middle
    price_bolup = df['Close'] - lower
    price_bolow = df['Close'] - upper
    Ema = talib.EMA(df['Close'],timeperiod=20)
    KC_High = Ema + 2*atr
    KC_Low = Ema - 2*atr
    aroondown, aroonup = talib.AROON(df['High'], df['Low'], timeperiod=9)
    aroon = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
    rsi30_list = []
    rsi70_list = []
    for i in range(0,df.shape[0]):
        rsi70_list.append(70 - rsi[i])
        rsi30_list.append(rsi[i] - 30)
        #except:
         #   rsi70_list.append(0)
          #  rs30_list.append(0)
    varop_spy = df['Open'] - df['Close']
    varhl_spy = df['High'] - df['Low']
    df['Varop_Spy'] = varop_spy
    df['Varhl_spy'] = varhl_spy
    df['RSI'] = rsi
    df['70 - RSI'] = np.array(rsi70_list)
    df['RSI - 30'] = np.array(rsi30_list)
    df['BBD_Delta_Up'] = bbdelta
    df['delta5_8'] = delta5_8
    df['delta8_10'] = delta8_10
    df['delta10_12'] = delta10_12
    df['delta12_15'] = delta12_15
    df['delta15_30'] = delta15_30
    df['delta30_35'] = delta30_35
    df['delta35_40'] = delta35_40
    df['delta40_45'] = delta40_45
    df['delta45_50'] = delta45_50
    df['Stoc_Slowk'] = stoc_slowk
    df['Stoc_Slowd'] = stoc_slowd
    df['KC_High'] = KC_High
    df['KC_Low'] = KC_Low
    df['upper'] = upper
    df['lower'] = lower
    df['var_bollup_kchigh'] = upper-KC_High
    df['var_bolllow_kclow'] = lower-KC_Low
    df['Aroon Up'] = aroonup
    df['Aroon Down'] = aroondown
    df['Delta Aroon'] = aroon
    up = []
    down = []
    df = df.dropna()
    df = boost(df)
    df['%Futur'] = ((df['Close.S']-df['Close']) *100) / (df['Close'])
    df['%Futur2'] = ((df['Close.S2']-df['Close']) *100) / (df['Close'])
    for i in range(0,df.shape[0]-5):
        if df.iloc[i]['%Futur'] > 0.1 :#or df.iloc[i]['%Futur2'] > 0.1:
            up.append(1)
            down.append(0)
        elif df.iloc[i]['%Futur'] < -0.1: #or df.iloc[i]['%Futur2'] < -0.1:
            up.append(0)
            down.append(1)
        else:
            up.append(0)
            down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    
    
    df['target_up'] = up  # target_up # abs(np.array(valley))#target_up
    df['target_down'] = down # target_down # abs(np.array(peak))#target_down
    #df = df.dropna()
    tmps2=round(time.time()-tmps1,2)
    print ("Data prepared in = %f" %tmps2,'seconds')
    return(df)

def boost(df):
    print('Boosting')
    X = df.copy()
    X = X.drop(['Close'],axis=1)
    X['Close'] = df['Close']
    y = X.iloc[:,-1]
    Xtrain = X.iloc[:-2,:-1]
    Xtest = X.iloc[-2:-1,:-1]
    yshift = y.shift(-1)
    ytrain = yshift.iloc[:-2]
    ytest = yshift.iloc[-2:-1]

    model = xgb.XGBRegressor(n_estimators=20000, learning_rate=1, gamma=1, subsample=1, colsample_bytree=1, max_depth=100)

    model.fit( Xtrain, ytrain, early_stopping_rounds=150, eval_set=[(Xtest, ytest)], verbose=0)

    ytrain_pred = model.predict(Xtrain)

    y_pred = model.predict(Xtest)

    pred = model.predict(X.iloc[:,:-1])

    df['Close.S'] = pred
    df['Close.S2'] = df['Close.S']
    df = df.dropna()
    print('Boost ok')
    return(df)

    
def deep_learning(df):
    tmps1=time.time()
    X = df.iloc[:,1:-4]
    y_up = df.iloc[:,-2].values
    y_down = df.iloc[:,-1].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:bloc1,:]
    Xtest = X[bloc1:,:]
    ytrain_up = y_up[:bloc1,:]
    ytest_up = y_up[bloc1:,:]
    ytrain_down = y_down[:bloc1,:]
    ytest_down = y_down[bloc1:,:]

    seed = 770
    np.random.seed(seed)

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    model_up = Sequential()
    # Add an input layer 
    model_up.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_up.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_up.add(Dense(1, activation='sigmoid'))

    model_down = Sequential()
    # Add an input layer 
    model_down.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_down.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_down.add(Dense(1, activation='sigmoid'))

    print('Processing move_up')
    model_up.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])
    
              

    history_up = model_up.fit(Xtrain, ytrain_up,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Processing move_down')
    model_down.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])

    history_down = model_down.fit(Xtrain, ytrain_down,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Computing done')
    print('\n')

    train_acc_up = model_up.evaluate(Xtrain, ytrain_up,verbose=1)
    train_acc_down = model_down.evaluate(Xtrain, ytrain_down,verbose=1)

    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    score_up = model_up.evaluate(Xtest, ytest_up,verbose=1)
    score_down = model_down.evaluate(Xtest, ytest_down,verbose=1)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)

    accuracy_up = accuracy_score(ytest_up, yhat_up)
    accuracy_down = accuracy_score(ytest_down, yhat_down)

    # La précision permet de mesurer la capacité du modèle à refuser résultats non-pertinents : vrais_positifs/(vrais_positifs+faux_positifs)
    precision_up = precision_score(ytest_up, yhat_up)  
    precision_down = precision_score(ytest_down, yhat_down) 


    # Recall : (vrai_positifs/(vrais_positifs+faux_négatifs))
    recall_up = recall_score(ytest_up, yhat_up) 
    recall_down = recall_score(ytest_down, yhat_down) 


    #roc_up=roc_auc_score(ytest_up,yhat_up)
    #roc_down=roc_auc_score(ytest_down,yhat_down)
    print('\n')
    print(Fore.GREEN,'RESULTATS UP\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_up * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_up *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_up * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_up *100))
    # get probabilities for positive class

    print(classification_report(ytest_up, yhat_up))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_up, yhat_up))

    print('\n')
    print('_______________________________________________________________________________________________________________________________________________________________\n')
    print(Fore.RED,'RESULTATS DOWN\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_down * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_down *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_down * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_down *100))
    # get probabilities for positive class

    print(classification_report(ytest_down, yhat_down))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_down, yhat_down))
    print('\n')

    resultats = pd.DataFrame()
    resultats['Date'] = df.index[bloc1:]
    resultats.index= df.index[bloc1:]
    resultats['Move Up'] = yhat_up
    resultats['Confiance up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confiance Down'] = (predict_down)*100
    resultats['Actual'] = df.iloc[bloc1:]['Close']
    resultats['Actual.S'] = df.iloc[bloc1:]['Close.S']
    open_S = df['Open'].shift(-1)
    resultats['Open.S'] = open_S.iloc[bloc1:]
    dmp_cp=[]
    dmp_cp = ((resultats['Confiance up']-resultats['Confiance Down'])/(resultats['Confiance up']+resultats['Confiance Down'])*100)
    resultats['DMP_CP'] = dmp_cp
    tmps2=round(time.time()-tmps1,2)
    print ("Deep Learning executed in = %f" %tmps2,'seconds')
    #resultats.set_index('Date',inplace=True)
    #parse_dates=resultats['Date']
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def learn(df):
    resultats,precision_up,precision_down,model_up,model_down,scaler = deep_learning(df)
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def grobeta(df,dfb):
    # create a time-series of monthly data points
    rts = df.resample('M').last()
    rbts = dfb.resample('M').last()
    dfsm = pd.DataFrame({'s_adjclose' : rts['Close'],
                            'b_adjclose' : rbts['Adj Close']},
                            index=rts.index)

    # compute returns
    dfsm[['s_returns','b_returns']] = dfsm[['s_adjclose','b_adjclose']]/\
        dfsm[['s_adjclose','b_adjclose']].shift(1) -1
    dfsm = dfsm.dropna()
    covmat = np.cov(dfsm["s_returns"],dfsm["b_returns"])

    # calculate measures now
    beta = covmat[0,1]/covmat[1,1]
    alpha= np.mean(dfsm["s_returns"])-beta*np.mean(dfsm["b_returns"])

    # r_squared     = 1. - SS_res/SS_tot
    ypred = alpha + beta * dfsm["b_returns"]
    SS_res = np.sum(np.power(ypred-dfsm["s_returns"],2))
    SS_tot = covmat[0,0]*(len(dfsm)-1) # SS_tot is sample_variance*(n-1)
    r_squared = 1. - SS_res/SS_tot
    # 5- year volatiity and 1-year momentum
    volatility = np.sqrt(covmat[0,0])
    momentum = np.prod(1+dfsm["s_returns"].tail(12).values) -1

    # annualize the numbers
    prd = 12. # used monthly returns; 12 periods to annualize
    alpha = alpha*prd
    volatility = volatility*np.sqrt(prd)

    print ('Beta : ',beta,'\n Alpha : ',alpha,'\n R_Squared : ', r_squared, '\n Volatility : ', volatility, '\n Momentum : ',momentum)
    return(beta,alpha,r_squared,volatility,momentum)


def save_model(model_up,model_down):
    savename = 'Save_'+ticker
    # serialize model to YAML
    model_up_yaml = model_up.to_yaml()
    model_down_yaml = model_down.to_yaml()
    with open(savename+"_up.yaml", "w") as yaml_file:
        yaml_file.write(model_up_yaml)
        print("Yaml Model ",savename,"_up.yaml saved to disk")
    with open(savename+"_down.yaml", "w") as yaml_file:
        yaml_file.write(model_up_yaml)
        print("Yaml Model ",savename,"_down.yaml saved to disk")
    # serialize weights to HDF5
    model_up.save_weights(savename+"_up.h5")
    print("Weights ",savename,"_up.h5 saved to disk")
    model_down.save_weights(savename+"_down.h5")
    print("Weights ",savename,"_down.h5 saved to disk")
    
########################
#### MAIN SKAN55 #######
########################
compteur = pd.read_csv('compteur.csv')
ticker_list = compteur['Symb.'].tolist()
name_list = compteur['Name'].tolist()
sector_list = compteur['Sector'].tolist()

for loop in range(amorce,amorce+10):
#for loop in range(amorce,len(constituents)):
    print('Loop :',loop)
    print('amorce : ',amorce)
    
    try:

        ticker = (constituents.iloc[loop]['Symbol'])
        name = constituents.iloc[loop]['Name']
        sector = constituents.iloc[loop]['Sector']
        ticker_list.append(ticker)
        name_list.append(name)
        sector_list.append(sector)
        
        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        global delta,bloc1,bloc2
        tmps1=time.time()
        print('Scraping data...')

        df = scrap_data(ticker,start,end)

        dfb = web.DataReader('^GSPC','yahoo',start,end)

        beta,alpha, r_squared, volatility, momentum = grobeta(df,dfb)

        tmps2=round(time.time()-tmps1,2)
        print ("executed in = %f" %tmps2,'seconds')

        print('\n')
        print('GOLEM begins Computing...')
        print('\n')
        delta = round(df.shape[0])
        bloc1 = round(delta*0.80)
        bloc2 = delta - bloc1
        print("# of periods : ",delta)
        print('On 80% - 20% slash : ')
        print('Bloc 1 : ',bloc1,'\nBloc 2 :',bloc2,' periods ')
        print('First period :',df.index[0])
        print('Split period :',df.index[bloc1-1])
        print('Last period :',df.index[df.shape[0]-1])
        print('\n')

        print('Data prep')
        df = prepa_data(df)

        print(Fore.BLUE,'Deeping in blue',Style.RESET_ALL)
        print('')
        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        resultats,precision_up,precision_down,model_up,model_down,scaler = learn(df)

        save_model(model_up, model_down)

        print('Le ',Fore.BLUE,'Deep Learning',Style.RESET_ALL ,'de ',Fore.YELLOW,ticker,Style.RESET_ALL,' a été effecué avec succès. Les modèles ont été sauvegardés')

    except:
        print(Fore.RED,'Problème loop : ',loop,Style.RESET_ALL)
        error.append((loop,ticker))
         
        continue

print(Fore.YELLOW,Back.BLUE,'Longueur des listes pour vérification : ',len(ticker_list),len(name_list),len(sector_list),Style.RESET_ALL)

compteur = pd.DataFrame(columns = ['Symb.','Name','Sector'])

compteur['Symb.'] = ticker_list

compteur['Name'] = name_list

compteur['Sector'] = sector_list

compteur.to_csv('compteur.csv')

print(Fore.YELLOW,Back.MAGENTA,Style.DIM,'PASSAGE FINI!!!!!!',Style.RESET_ALL)
# Out:
# Importing Librairies...
# Using TensorFlow backend.
# Librairies imported
#
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
# BOOST SKAN 55 Version v1.35
#
# Sraping tickers
# Scrap -----> ok
# Loop : 479
# amorce :  479
#  --- Loop : 479  ---  --- Symbol :   VMC   ---  --- Name :  Vulcan Materials  ---  --- Sector :  Materials  ---
# Scraping data...
# Beta :  0.8825357423623177
#  Alpha :  0.03187331316333744
#  R_Squared :  0.29351721675125597
#  Volatility :  0.2583638283732032
#  Momentum :  0.2563831995463506
# executed in = 7.950000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  405
# On 80% - 20% slash :
# Bloc 1 :  324
# Bloc 2 : 81  periods
# First period : 2017-11-01 00:00:00
# Split period : 2019-04-10 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:24:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 1.000000 seconds
#  Deeping in blue
#
#  --- Loop : 479  ---  --- Symbol :   VMC   ---  --- Name :  Vulcan Materials  ---  --- Sector :  Materials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 324/324 [==============================] - 0s 164us/step
# 324/324 [==============================] - 0s 167us/step
# 32/32 [==============================] - 0s 17us/step
# 32/32 [==============================] - 0s 14us/step
#
#
#  RESULTATS UP
#
# Accuracy: 37.50%
#  Precision: 31.03%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.13      0.23        23
#            1       0.31      1.00      0.47         9
#
#    micro avg       0.38      0.38      0.38        32
#    macro avg       0.66      0.57      0.35        32
# weighted avg       0.81      0.38      0.30        32
#
# [[ 3 20]
#  [ 0  9]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 78.12%
#  Precision: 66.67%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 92.31%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.93      0.68      0.79        19
#            1       0.67      0.92      0.77        13
#
#    micro avg       0.78      0.78      0.78        32
#    macro avg       0.80      0.80      0.78        32
# weighted avg       0.82      0.78      0.78        32
#
# [[13  6]
#  [ 1 12]]
#
#
# Deep Learning executed in = 20.690000 seconds
# Yaml Model  Save_VMC _up.yaml saved to disk
# Yaml Model  Save_VMC _down.yaml saved to disk
# Weights  Save_VMC _up.h5 saved to disk
# Weights  Save_VMC _down.h5 saved to disk
# Le   Deep Learning  de   VMC   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 480
# amorce :  479
#  --- Loop : 480  ---  --- Symbol :   WMT   ---  --- Name :  Wal-Mart Stores  ---  --- Sector :  Consumer Staples  ---
# Scraping data...
# Beta :  0.3949227554635219
#  Alpha :  0.10720614813553714
#  R_Squared :  0.07103864793990056
#  Volatility :  0.1867545250123353
#  Momentum :  0.1371974334772208
# executed in = 3.540000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:24:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.740000 seconds
#  Deeping in blue
#
#  --- Loop : 480  ---  --- Symbol :   WMT   ---  --- Name :  Wal-Mart Stores  ---  --- Sector :  Consumer Staples  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 0s 108us/step
# 843/843 [==============================] - 0s 113us/step
# 162/162 [==============================] - 0s 22us/step
# 162/162 [==============================] - 0s 22us/step
#
#
#  RESULTATS UP
#
# Accuracy: 74.07%
#  Precision: 90.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 48.65%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.69      0.95      0.80        88
#            1       0.90      0.49      0.63        74
#
#    micro avg       0.74      0.74      0.74       162
#    macro avg       0.79      0.72      0.72       162
# weighted avg       0.79      0.74      0.72       162
#
# [[84  4]
#  [38 36]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 82.72%
#  Precision: 78.67%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 83.10%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84        91
#            1       0.79      0.83      0.81        71
#
#    micro avg       0.83      0.83      0.83       162
#    macro avg       0.82      0.83      0.83       162
# weighted avg       0.83      0.83      0.83       162
#
# [[75 16]
#  [12 59]]
#
#
# Deep Learning executed in = 54.310000 seconds
# Yaml Model  Save_WMT _up.yaml saved to disk
# Yaml Model  Save_WMT _down.yaml saved to disk
# Weights  Save_WMT _up.h5 saved to disk
# Weights  Save_WMT _down.h5 saved to disk
# Le   Deep Learning  de   WMT   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 481
# amorce :  479
#  --- Loop : 481  ---  --- Symbol :   WBA   ---  --- Name :  Walgreens Boots Alliance  ---  --- Sector :  Consumer Staples  ---
# Scraping data...
# Beta :  0.8212820147516766
#  Alpha :  -0.1404834781007511
#  R_Squared :  0.17781177954966587
#  Volatility :  0.24548127289099034
#  Momentum :  -0.2344822023885741
# executed in = 7.160000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:25:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.040000 seconds
#  Deeping in blue
#
#  --- Loop : 481  ---  --- Symbol :   WBA   ---  --- Name :  Walgreens Boots Alliance  ---  --- Sector :  Consumer Staples  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 0s 141us/step
# 843/843 [==============================] - 0s 158us/step
# 162/162 [==============================] - 0s 23us/step
# 162/162 [==============================] - 0s 23us/step
#
#
#  RESULTATS UP
#
# Accuracy: 71.60%
#  Precision: 63.95%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 78.57%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.66      0.73        92
#            1       0.64      0.79      0.71        70
#
#    micro avg       0.72      0.72      0.72       162
#    macro avg       0.72      0.72      0.72       162
# weighted avg       0.73      0.72      0.72       162
#
# [[61 31]
#  [15 55]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 69.14%
#  Precision: 76.19%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 44.44%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.67      0.89      0.76        90
#            1       0.76      0.44      0.56        72
#
#    micro avg       0.69      0.69      0.69       162
#    macro avg       0.71      0.67      0.66       162
# weighted avg       0.71      0.69      0.67       162
#
# [[80 10]
#  [40 32]]
#
#
# Deep Learning executed in = 55.010000 seconds
# Yaml Model  Save_WBA _up.yaml saved to disk
# Yaml Model  Save_WBA _down.yaml saved to disk
# Weights  Save_WBA _up.h5 saved to disk
# Weights  Save_WBA _down.h5 saved to disk
# Le   Deep Learning  de   WBA   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 482
# amorce :  479
#  --- Loop : 482  ---  --- Symbol :   WM   ---  --- Name :  Waste Management Inc.  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  0.6144304084432853
#  Alpha :  0.19876904438511234
#  R_Squared :  0.37761327945947454
#  Volatility :  0.1260246181203662
#  Momentum :  0.30277027879658736
# executed in = 5.640000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:26:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.830000 seconds
#  Deeping in blue
#
#  --- Loop : 482  ---  --- Symbol :   WM   ---  --- Name :  Waste Management Inc.  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 0s 192us/step
# 843/843 [==============================] - 0s 187us/step
# 162/162 [==============================] - 0s 24us/step
# 162/162 [==============================] - 0s 23us/step
#
#
#  RESULTATS UP
#
# Accuracy: 61.73%
#  Precision: 65.62%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 29.17%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.61      0.88      0.72        90
#            1       0.66      0.29      0.40        72
#
#    micro avg       0.62      0.62      0.62       162
#    macro avg       0.63      0.58      0.56       162
# weighted avg       0.63      0.62      0.58       162
#
# [[79 11]
#  [51 21]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 73.46%
#  Precision: 68.35%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 75.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.78      0.72      0.75        90
#            1       0.68      0.75      0.72        72
#
#    micro avg       0.73      0.73      0.73       162
#    macro avg       0.73      0.74      0.73       162
# weighted avg       0.74      0.73      0.74       162
#
# [[65 25]
#  [18 54]]
#
#
# Deep Learning executed in = 58.130000 seconds
# Yaml Model  Save_WM _up.yaml saved to disk
# Yaml Model  Save_WM _down.yaml saved to disk
# Weights  Save_WM _up.h5 saved to disk
# Weights  Save_WM _down.h5 saved to disk
# Le   Deep Learning  de   WM   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 483
# amorce :  479
#  --- Loop : 483  ---  --- Symbol :   WAT   ---  --- Name :  Waters Corporation  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.1274801417311586
#  Alpha :  0.04486481300628631
#  R_Squared :  0.37128363650951257
#  Volatility :  0.23321813352098245
#  Momentum :  0.10623815356085498
# executed in = 8.350000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:27:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.030000 seconds
#  Deeping in blue
#
#  --- Loop : 483  ---  --- Symbol :   WAT   ---  --- Name :  Waters Corporation  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 0s 238us/step
# 843/843 [==============================] - 0s 234us/step
# 162/162 [==============================] - 0s 37us/step
# 162/162 [==============================] - 0s 36us/step
#
#
#  RESULTATS UP
#
# Accuracy: 77.78%
#  Precision: 72.94%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 82.67%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.83      0.74      0.78        87
#            1       0.73      0.83      0.77        75
#
#    micro avg       0.78      0.78      0.78       162
#    macro avg       0.78      0.78      0.78       162
# weighted avg       0.78      0.78      0.78       162
#
# [[64 23]
#  [13 62]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 76.54%
#  Precision: 78.72%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 56.92%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.76      0.90      0.82        97
#            1       0.79      0.57      0.66        65
#
#    micro avg       0.77      0.77      0.77       162
#    macro avg       0.77      0.73      0.74       162
# weighted avg       0.77      0.77      0.76       162
#
# [[87 10]
#  [28 37]]
#
#
# Deep Learning executed in = 62.090000 seconds
# Yaml Model  Save_WAT _up.yaml saved to disk
# Yaml Model  Save_WAT _down.yaml saved to disk
# Weights  Save_WAT _up.h5 saved to disk
# Weights  Save_WAT _down.h5 saved to disk
# Le   Deep Learning  de   WAT   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 484
# amorce :  479
#  --- Loop : 484  ---  --- Symbol :   WEC   ---  --- Name :  Wec Energy Group Inc  ---  --- Sector :  Utilities  ---
# Scraping data...
# Beta :  0.10431213644499741
#  Alpha :  0.19827767747796676
#  R_Squared :  0.00883380524419175
#  Volatility :  0.13988374431621214
#  Momentum :  0.33105611735561635
# executed in = 3.360000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:29:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.550000 seconds
#  Deeping in blue
#
#  --- Loop : 484  ---  --- Symbol :   WEC   ---  --- Name :  Wec Energy Group Inc  ---  --- Sector :  Utilities  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 0s 273us/step
# 843/843 [==============================] - 0s 269us/step
# 162/162 [==============================] - 0s 26us/step
# 162/162 [==============================] - 0s 26us/step
#
#
#  RESULTATS UP
#
# Accuracy: 64.81%
#  Precision: 86.21%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 32.05%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.60      0.95      0.74        84
#            1       0.86      0.32      0.47        78
#
#    micro avg       0.65      0.65      0.65       162
#    macro avg       0.73      0.64      0.60       162
# weighted avg       0.73      0.65      0.61       162
#
# [[80  4]
#  [53 25]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 80.86%
#  Precision: 68.92%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 86.44%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.91      0.78      0.84       103
#            1       0.69      0.86      0.77        59
#
#    micro avg       0.81      0.81      0.81       162
#    macro avg       0.80      0.82      0.80       162
# weighted avg       0.83      0.81      0.81       162
#
# [[80 23]
#  [ 8 51]]
#
#
# Deep Learning executed in = 61.160000 seconds
# Yaml Model  Save_WEC _up.yaml saved to disk
# Yaml Model  Save_WEC _down.yaml saved to disk
# Weights  Save_WEC _up.h5 saved to disk
# Weights  Save_WEC _down.h5 saved to disk
# Le   Deep Learning  de   WEC   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 485
# amorce :  479
#  --- Loop : 485  ---  --- Symbol :   WFC   ---  --- Name :  Wells Fargo  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  1.0982793807307305
#  Alpha :  -0.08813631036457846
#  R_Squared :  0.4083713341654057
#  Volatility :  0.21661649487807247
#  Momentum :  -0.17578580913785424
# executed in = 10.560000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:30:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.550000 seconds
#  Deeping in blue
#
#  --- Loop : 485  ---  --- Symbol :   WFC   ---  --- Name :  Wells Fargo  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 0s 304us/step
# 843/843 [==============================] - 0s 375us/step
# 162/162 [==============================] - 0s 44us/step
# 162/162 [==============================] - 0s 31us/step
#
#
#  RESULTATS UP
#
# Accuracy: 87.04%
#  Precision: 87.32%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 83.78%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88        88
#            1       0.87      0.84      0.86        74
#
#    micro avg       0.87      0.87      0.87       162
#    macro avg       0.87      0.87      0.87       162
# weighted avg       0.87      0.87      0.87       162
#
# [[79  9]
#  [12 62]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 84.57%
#  Precision: 73.63%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 98.53%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.99      0.74      0.85        94
#            1       0.74      0.99      0.84        68
#
#    micro avg       0.85      0.85      0.85       162
#    macro avg       0.86      0.86      0.85       162
# weighted avg       0.88      0.85      0.85       162
#
# [[70 24]
#  [ 1 67]]
#
#
# Deep Learning executed in = 67.010000 seconds
# Yaml Model  Save_WFC _up.yaml saved to disk
# Yaml Model  Save_WFC _down.yaml saved to disk
# Weights  Save_WFC _up.h5 saved to disk
# Weights  Save_WFC _down.h5 saved to disk
# Le   Deep Learning  de   WFC   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 486
# amorce :  479
#  --- Loop : 486  ---  --- Symbol :   WELL   ---  --- Name :  Welltower Inc.  ---  --- Sector :  Real Estate  ---
# Scraping data...
# Beta :  0.2615496530861911
#  Alpha :  0.10944652440541484
#  R_Squared :  0.027131916519030574
#  Volatility :  0.20013370284873924
#  Momentum :  0.32659477171738027
# executed in = 2.600000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:31:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.370000 seconds
#  Deeping in blue
#
#  --- Loop : 486  ---  --- Symbol :   WELL   ---  --- Name :  Welltower Inc.  ---  --- Sector :  Real Estate  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 0s 376us/step
# 843/843 [==============================] - 0s 359us/step
# 162/162 [==============================] - 0s 29us/step
# 162/162 [==============================] - 0s 28us/step
#
#
#  RESULTATS UP
#
# Accuracy: 79.01%
#  Precision: 96.36%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 62.35%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.70      0.97      0.82        77
#            1       0.96      0.62      0.76        85
#
#    micro avg       0.79      0.79      0.79       162
#    macro avg       0.83      0.80      0.79       162
# weighted avg       0.84      0.79      0.78       162
#
# [[75  2]
#  [32 53]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 88.89%
#  Precision: 86.67%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 83.87%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91       100
#            1       0.87      0.84      0.85        62
#
#    micro avg       0.89      0.89      0.89       162
#    macro avg       0.88      0.88      0.88       162
# weighted avg       0.89      0.89      0.89       162
#
# [[92  8]
#  [10 52]]
#
#
# Deep Learning executed in = 65.640000 seconds
# Yaml Model  Save_WELL _up.yaml saved to disk
# Yaml Model  Save_WELL _down.yaml saved to disk
# Weights  Save_WELL _up.h5 saved to disk
# Weights  Save_WELL _down.h5 saved to disk
# Le   Deep Learning  de   WELL   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 487
# amorce :  479
#  --- Loop : 487  ---  --- Symbol :   WDC   ---  --- Name :  Western Digital  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.7188261552799298
#  Alpha :  -0.12176829761900979
#  R_Squared :  0.2724214785535396
#  Volatility :  0.41506642008917216
#  Momentum :  -0.1140796092828128
# executed in = 2.710000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:32:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.300000 seconds
#  Deeping in blue
#
#  --- Loop : 487  ---  --- Symbol :   WDC   ---  --- Name :  Western Digital  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 0s 406us/step
# 843/843 [==============================] - 0s 402us/step
# 162/162 [==============================] - 0s 29us/step
# 162/162 [==============================] - 0s 29us/step
#
#
#  RESULTATS UP
#
# Accuracy: 79.01%
#  Precision: 59.74%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 93.88%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.96      0.73      0.83       113
#            1       0.60      0.94      0.73        49
#
#    micro avg       0.79      0.79      0.79       162
#    macro avg       0.78      0.83      0.78       162
# weighted avg       0.85      0.79      0.80       162
#
# [[82 31]
#  [ 3 46]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 89.51%
#  Precision: 97.87%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.98%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.78      0.96      0.86        55
#            1       0.98      0.86      0.92       107
#
#    micro avg       0.90      0.90      0.90       162
#    macro avg       0.88      0.91      0.89       162
# weighted avg       0.91      0.90      0.90       162
#
# [[53  2]
#  [15 92]]
#
#
# Deep Learning executed in = 68.840000 seconds
# Yaml Model  Save_WDC _up.yaml saved to disk
# Yaml Model  Save_WDC _down.yaml saved to disk
# Weights  Save_WDC _up.h5 saved to disk
# Weights  Save_WDC _down.h5 saved to disk
# Le   Deep Learning  de   WDC   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 488
# amorce :  479
#  --- Loop : 488  ---  --- Symbol :   WU   ---  --- Name :  Western Union Co  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  0.6806983112696132
#  Alpha :  -0.0018062576609192624
#  R_Squared :  0.3184703734305252
#  Volatility :  0.15202901197295568
#  Momentum :  0.1773324002293477
# executed in = 3.800000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:34:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.720000 seconds
#  Deeping in blue
#
#  --- Loop : 488  ---  --- Symbol :   WU   ---  --- Name :  Western Union Co  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 0s 444us/step
# 843/843 [==============================] - 0s 464us/step
# 162/162 [==============================] - 0s 31us/step
# 162/162 [==============================] - 0s 36us/step
#
#
#  RESULTATS UP
#
# Accuracy: 81.48%
#  Precision: 83.87%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 83.87%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78        69
#            1       0.84      0.84      0.84        93
#
#    micro avg       0.81      0.81      0.81       162
#    macro avg       0.81      0.81      0.81       162
# weighted avg       0.81      0.81      0.81       162
#
# [[54 15]
#  [15 78]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 85.80%
#  Precision: 78.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 76.47%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90       111
#            1       0.78      0.76      0.77        51
#
#    micro avg       0.86      0.86      0.86       162
#    macro avg       0.84      0.83      0.83       162
# weighted avg       0.86      0.86      0.86       162
#
# [[100  11]
#  [ 12  39]]
#
#
# Deep Learning executed in = 72.870000 seconds
# Yaml Model  Save_WU _up.yaml saved to disk
# Yaml Model  Save_WU _down.yaml saved to disk
# Weights  Save_WU _up.h5 saved to disk
# Weights  Save_WU _down.h5 saved to disk
# Le   Deep Learning  de   WU   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 489
# amorce :  479
#  --- Loop : 489  ---  --- Symbol :   WRK   ---  --- Name :  WestRock Company  ---  --- Sector :  Materials  ---
# Scraping data...
# Beta :  1.69305499995333
#  Alpha :  -0.1833726722002731
#  R_Squared :  0.5655358472182608
#  Volatility :  0.2837574782386779
#  Momentum :  -0.3463113985120757
# executed in = 5.170000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1037
# On 80% - 20% slash :
# Bloc 1 :  830
# Bloc 2 : 207  periods
# First period : 2015-06-24 00:00:00
# Split period : 2018-10-08 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:35:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.800000 seconds
#  Deeping in blue
#
#  --- Loop : 489  ---  --- Symbol :   WRK   ---  --- Name :  WestRock Company  ---  --- Sector :  Materials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 830/830 [==============================] - 0s 494us/step
# 830/830 [==============================] - 0s 513us/step
# 158/158 [==============================] - 0s 32us/step
# 158/158 [==============================] - 0s 31us/step
#
#
#  RESULTATS UP
#
# Accuracy: 74.05%
#  Precision: 86.79%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 57.50%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.68      0.91      0.78        78
#            1       0.87      0.57      0.69        80
#
#    micro avg       0.74      0.74      0.74       158
#    macro avg       0.77      0.74      0.73       158
# weighted avg       0.77      0.74      0.73       158
#
# [[71  7]
#  [34 46]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 79.11%
#  Precision: 78.46%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 72.86%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82        88
#            1       0.78      0.73      0.76        70
#
#    micro avg       0.79      0.79      0.79       158
#    macro avg       0.79      0.78      0.79       158
# weighted avg       0.79      0.79      0.79       158
#
# [[74 14]
#  [19 51]]
#
#
# Deep Learning executed in = 72.470000 seconds
# Yaml Model  Save_WRK _up.yaml saved to disk
# Yaml Model  Save_WRK _down.yaml saved to disk
# Weights  Save_WRK _up.h5 saved to disk
# Weights  Save_WRK _down.h5 saved to disk
# Le   Deep Learning  de   WRK   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 490
# amorce :  479
#  --- Loop : 490  ---  --- Symbol :   WY   ---  --- Name :  Weyerhaeuser Corp.  ---  --- Sector :  Real Estate  ---
# Scraping data...
# Beta :  1.7800418320196663
#  Alpha :  -0.1415990385922184
#  R_Squared :  0.6666587011098772
#  Volatility :  0.2747797671318782
#  Momentum :  -0.26182021127353217
# executed in = 3.700000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1053
# On 80% - 20% slash :
# Bloc 1 :  842
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-01 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:36:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.270000 seconds
#  Deeping in blue
#
#  --- Loop : 490  ---  --- Symbol :   WY   ---  --- Name :  Weyerhaeuser Corp.  ---  --- Sector :  Real Estate  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 842/842 [==============================] - 0s 525us/step
# 842/842 [==============================] - 0s 519us/step
# 162/162 [==============================] - 0s 31us/step
# 162/162 [==============================] - 0s 30us/step
#
#
#  RESULTATS UP
#
# Accuracy: 69.14%
#  Precision: 80.77%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 31.82%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.67      0.95      0.78        96
#            1       0.81      0.32      0.46        66
#
#    micro avg       0.69      0.69      0.69       162
#    macro avg       0.74      0.63      0.62       162
# weighted avg       0.73      0.69      0.65       162
#
# [[91  5]
#  [45 21]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 53.09%
#  Precision: 52.50%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.03      0.05        78
#            1       0.53      1.00      0.69        84
#
#    micro avg       0.53      0.53      0.53       162
#    macro avg       0.76      0.51      0.37       162
# weighted avg       0.75      0.53      0.38       162
#
# [[ 2 76]
#  [ 0 84]]
#
#
# Deep Learning executed in = 74.190000 seconds
# Yaml Model  Save_WY _up.yaml saved to disk
# Yaml Model  Save_WY _down.yaml saved to disk
# Weights  Save_WY _up.h5 saved to disk
# Weights  Save_WY _down.h5 saved to disk
# Le   Deep Learning  de   WY   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 491
# amorce :  479
#  --- Loop : 491  ---  --- Symbol :   WHR   ---  --- Name :  Whirlpool Corp.  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  1.8326154729169468
#  Alpha :  -0.14028814597540942
#  R_Squared :  0.48171846016661335
#  Volatility :  0.33279824145095255
#  Momentum :  0.12100464127322397
# executed in = 2.860000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:38:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.550000 seconds
#  Deeping in blue
#
#  --- Loop : 491  ---  --- Symbol :   WHR   ---  --- Name :  Whirlpool Corp.  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 0s 578us/step
# 843/843 [==============================] - 0s 574us/step
# 162/162 [==============================] - 0s 37us/step
# 162/162 [==============================] - 0s 39us/step
#
#
#  RESULTATS UP
#
# Accuracy: 80.86%
#  Precision: 83.12%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 78.05%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.81        80
#            1       0.83      0.78      0.81        82
#
#    micro avg       0.81      0.81      0.81       162
#    macro avg       0.81      0.81      0.81       162
# weighted avg       0.81      0.81      0.81       162
#
# [[67 13]
#  [18 64]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 79.01%
#  Precision: 75.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 72.73%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82        96
#            1       0.75      0.73      0.74        66
#
#    micro avg       0.79      0.79      0.79       162
#    macro avg       0.78      0.78      0.78       162
# weighted avg       0.79      0.79      0.79       162
#
# [[80 16]
#  [18 48]]
#
#
# Deep Learning executed in = 79.790000 seconds
# Yaml Model  Save_WHR _up.yaml saved to disk
# Yaml Model  Save_WHR _down.yaml saved to disk
# Weights  Save_WHR _up.h5 saved to disk
# Weights  Save_WHR _down.h5 saved to disk
# Le   Deep Learning  de   WHR   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 492
# amorce :  479
#  --- Loop : 492  ---  --- Symbol :   WMB   ---  --- Name :  Williams Cos.  ---  --- Sector :  Energy  ---
# Scraping data...
# Beta :  1.6508515074018026
#  Alpha :  -0.23285235362885423
#  R_Squared :  0.32231717501502855
#  Volatility :  0.3664988405800867
#  Momentum :  -0.16110620446314872
# executed in = 3.160000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:39:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.010000 seconds
#  Deeping in blue
#
#  --- Loop : 492  ---  --- Symbol :   WMB   ---  --- Name :  Williams Cos.  ---  --- Sector :  Energy  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 1s 649us/step
# 843/843 [==============================] - 1s 638us/step
# 162/162 [==============================] - 0s 34us/step
# 162/162 [==============================] - 0s 34us/step
#
#
#  RESULTATS UP
#
# Accuracy: 71.60%
#  Precision: 68.06%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 68.06%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.74      0.74      0.74        90
#            1       0.68      0.68      0.68        72
#
#    micro avg       0.72      0.72      0.72       162
#    macro avg       0.71      0.71      0.71       162
# weighted avg       0.72      0.72      0.72       162
#
# [[67 23]
#  [23 49]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 74.69%
#  Precision: 69.77%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.70      0.75        87
#            1       0.70      0.80      0.75        75
#
#    micro avg       0.75      0.75      0.75       162
#    macro avg       0.75      0.75      0.75       162
# weighted avg       0.75      0.75      0.75       162
#
# [[61 26]
#  [15 60]]
#
#
# Deep Learning executed in = 79.910000 seconds
# Yaml Model  Save_WMB _up.yaml saved to disk
# Yaml Model  Save_WMB _down.yaml saved to disk
# Weights  Save_WMB _up.h5 saved to disk
# Weights  Save_WMB _down.h5 saved to disk
# Le   Deep Learning  de   WMB   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 493
# amorce :  479
#  --- Loop : 493  ---  --- Symbol :   WLTW   ---  --- Name :  Willis Towers Watson  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  0.7940224825970049
#  Alpha :  0.06582170288662914
#  R_Squared :  0.35045935351998125
#  Volatility :  0.1690519911013026
#  Momentum :  0.3388113445822909
# executed in = 3.270000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:41:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.640000 seconds
#  Deeping in blue
#
#  --- Loop : 493  ---  --- Symbol :   WLTW   ---  --- Name :  Willis Towers Watson  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 1s 797us/step
# 843/843 [==============================] - 1s 807us/step
# 162/162 [==============================] - 0s 39us/step
# 162/162 [==============================] - 0s 41us/step
#
#
#  RESULTATS UP
#
# Accuracy: 80.25%
#  Precision: 96.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 61.54%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.73      0.98      0.84        84
#            1       0.96      0.62      0.75        78
#
#    micro avg       0.80      0.80      0.80       162
#    macro avg       0.85      0.80      0.79       162
# weighted avg       0.84      0.80      0.79       162
#
# [[82  2]
#  [30 48]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 76.54%
#  Precision: 62.75%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.61      0.76        98
#            1       0.63      1.00      0.77        64
#
#    micro avg       0.77      0.77      0.77       162
#    macro avg       0.81      0.81      0.77       162
# weighted avg       0.85      0.77      0.76       162
#
# [[60 38]
#  [ 0 64]]
#
#
# Deep Learning executed in = 82.500000 seconds
# Yaml Model  Save_WLTW _up.yaml saved to disk
# Yaml Model  Save_WLTW _down.yaml saved to disk
# Weights  Save_WLTW _up.h5 saved to disk
# Weights  Save_WLTW _down.h5 saved to disk
# Le   Deep Learning  de   WLTW   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 494
# amorce :  479
#  --- Loop : 494  ---  --- Symbol :   WYN   ---  --- Name :  Wyndham Worldwide  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
#  Problème loop :  494
# Loop : 495
# amorce :  479
#  --- Loop : 495  ---  --- Symbol :   WYNN   ---  --- Name :  Wynn Resorts Ltd  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  2.199997564354307
#  Alpha :  -0.0379210602346865
#  R_Squared :  0.3659895295815563
#  Volatility :  0.4583467834457214
#  Momentum :  -0.2294833138204071
# executed in = 2.330000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:42:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.980000 seconds
#  Deeping in blue
#
#  --- Loop : 495  ---  --- Symbol :   WYNN   ---  --- Name :  Wynn Resorts Ltd  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 1s 688us/step
# 843/843 [==============================] - 1s 702us/step
# 162/162 [==============================] - 0s 34us/step
# 162/162 [==============================] - 0s 35us/step
#
#
#  RESULTATS UP
#
# Accuracy: 71.60%
#  Precision: 60.61%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 89.55%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.89      0.59      0.71        95
#            1       0.61      0.90      0.72        67
#
#    micro avg       0.72      0.72      0.72       162
#    macro avg       0.75      0.74      0.72       162
# weighted avg       0.77      0.72      0.71       162
#
# [[56 39]
#  [ 7 60]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 69.75%
#  Precision: 83.33%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 49.38%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.64      0.90      0.75        81
#            1       0.83      0.49      0.62        81
#
#    micro avg       0.70      0.70      0.70       162
#    macro avg       0.74      0.70      0.68       162
# weighted avg       0.74      0.70      0.68       162
#
# [[73  8]
#  [41 40]]
#
#
# Deep Learning executed in = 91.270000 seconds
# Yaml Model  Save_WYNN _up.yaml saved to disk
# Yaml Model  Save_WYNN _down.yaml saved to disk
# Weights  Save_WYNN _up.h5 saved to disk
# Weights  Save_WYNN _down.h5 saved to disk
# Le   Deep Learning  de   WYNN   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 496
# amorce :  479
#  --- Loop : 496  ---  --- Symbol :   XEL   ---  --- Name :  Xcel Energy Inc  ---  --- Sector :  Utilities  ---
# Scraping data...
# Beta :  0.17178456509360016
#  Alpha :  0.17842535376844537
#  R_Squared :  0.023372705481251588
#  Volatility :  0.14162370929514623
#  Momentum :  0.2953673420341718
# executed in = 5.030000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:44:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.620000 seconds
#  Deeping in blue
#
#  --- Loop : 496  ---  --- Symbol :   XEL   ---  --- Name :  Xcel Energy Inc  ---  --- Sector :  Utilities  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 1s 736us/step
# 843/843 [==============================] - 1s 747us/step
# 162/162 [==============================] - 0s 38us/step
# 162/162 [==============================] - 0s 38us/step
#
#
#  RESULTATS UP
#
# Accuracy: 91.36%
#  Precision: 98.18%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.60%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93        95
#            1       0.98      0.81      0.89        67
#
#    micro avg       0.91      0.91      0.91       162
#    macro avg       0.93      0.90      0.91       162
# weighted avg       0.92      0.91      0.91       162
#
# [[94  1]
#  [13 54]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 75.31%
#  Precision: 92.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 56.10%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.68      0.95      0.79        80
#            1       0.92      0.56      0.70        82
#
#    micro avg       0.75      0.75      0.75       162
#    macro avg       0.80      0.76      0.74       162
# weighted avg       0.80      0.75      0.74       162
#
# [[76  4]
#  [36 46]]
#
#
# Deep Learning executed in = 87.620000 seconds
# Yaml Model  Save_XEL _up.yaml saved to disk
# Yaml Model  Save_XEL _down.yaml saved to disk
# Weights  Save_XEL _up.h5 saved to disk
# Weights  Save_XEL _down.h5 saved to disk
# Le   Deep Learning  de   XEL   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 497
# amorce :  479
#  --- Loop : 497  ---  --- Symbol :   XRX   ---  --- Name :  Xerox Corp.  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.8118821096146924
#  Alpha :  -0.05209135292450774
#  R_Squared :  0.3724370868616268
#  Volatility :  0.37420517979780366
#  Momentum :  0.09102398016825863
# executed in = 2.750000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:45:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.420000 seconds
#  Deeping in blue
#
# ...
# weighted avg       0.91      0.91      0.91       162
#
# [[100   4]
#  [ 10  48]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 93.21%
#  Precision: 89.81%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91        65
#            1       0.90      1.00      0.95        97
#
#    micro avg       0.93      0.93      0.93       162
#    macro avg       0.95      0.92      0.93       162
# weighted avg       0.94      0.93      0.93       162
#
# [[54 11]
#  [ 0 97]]
#
#
# Deep Learning executed in = 98.870000 seconds
# Yaml Model  Save_XLNX _up.yaml saved to disk
# Yaml Model  Save_XLNX _down.yaml saved to disk
# Weights  Save_XLNX _up.h5 saved to disk
# Weights  Save_XLNX _down.h5 saved to disk
# Le   Deep Learning  de   XLNX   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 499
# amorce :  479
#  --- Loop : 499  ---  --- Symbol :   XL   ---  --- Name :  XL Capital  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  0.16155634146334186
#  Alpha :  0.05090583634731422
#  R_Squared :  0.1097420724718694
#  Volatility :  0.024728769694341513
#  Momentum :  0.042164348567248267
# executed in = 3.010000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  130
# On 80% - 20% slash :
# Bloc 1 :  104
# Bloc 2 : 26  periods
# First period : 2018-01-04 00:00:00
# Split period : 2018-08-06 00:00:00
# Last period : 2018-09-12 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:49:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 0.730000 seconds
#  Deeping in blue
#
#  --- Loop : 499  ---  --- Symbol :   XL   ---  --- Name :  XL Capital  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 81/81 [==============================] - 1s 9ms/step
# 81/81 [==============================] - 1s 9ms/step
#  Problème loop :  499
# Loop : 500
# amorce :  479
#  --- Loop : 500  ---  --- Symbol :   XYL   ---  --- Name :  Xylem Inc.  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.1698947520861438
#  Alpha :  0.10685607621892619
#  R_Squared :  0.4458126390865724
#  Volatility :  0.22083958525178982
#  Momentum :  0.00861565967443978
# executed in = 2.450000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:49:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.370000 seconds
#  Deeping in blue
#
#  --- Loop : 500  ---  --- Symbol :   XYL   ---  --- Name :  Xylem Inc.  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 1s 923us/step
# 843/843 [==============================] - 1s 898us/step
# 162/162 [==============================] - 0s 40us/step
# 162/162 [==============================] - 0s 44us/step
#
#
#  RESULTATS UP
#
# Accuracy: 70.37%
#  Precision: 73.21%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 55.41%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.69      0.83      0.75        88
#            1       0.73      0.55      0.63        74
#
#    micro avg       0.70      0.70      0.70       162
#    macro avg       0.71      0.69      0.69       162
# weighted avg       0.71      0.70      0.70       162
#
# [[73 15]
#  [33 41]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 82.72%
#  Precision: 76.62%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.51%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84        93
#            1       0.77      0.86      0.81        69
#
#    micro avg       0.83      0.83      0.83       162
#    macro avg       0.82      0.83      0.83       162
# weighted avg       0.83      0.83      0.83       162
#
# [[75 18]
#  [10 59]]
#
#
# Deep Learning executed in = 94.380000 seconds
# Yaml Model  Save_XYL _up.yaml saved to disk
# Yaml Model  Save_XYL _down.yaml saved to disk
# Weights  Save_XYL _up.h5 saved to disk
# Weights  Save_XYL _down.h5 saved to disk
# Le   Deep Learning  de   XYL   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 501
# amorce :  479
#  --- Loop : 501  ---  --- Symbol :   YUM   ---  --- Name :  Yum! Brands Inc  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  0.4052284023073164
#  Alpha :  0.14001897807912006
#  R_Squared :  0.09789165878311745
#  Volatility :  0.16324254309966899
#  Momentum :  0.3528038324490832
# executed in = 5.520000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:51:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.220000 seconds
#  Deeping in blue
#
#  --- Loop : 501  ---  --- Symbol :   YUM   ---  --- Name :  Yum! Brands Inc  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 1s 967us/step
# 843/843 [==============================] - 1s 957us/step
# 162/162 [==============================] - 0s 41us/step
# 162/162 [==============================] - 0s 45us/step
#
#
#  RESULTATS UP
#
# Accuracy: 67.90%
#  Precision: 62.10%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 93.90%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.87      0.41      0.56        80
#            1       0.62      0.94      0.75        82
#
#    micro avg       0.68      0.68      0.68       162
#    macro avg       0.74      0.68      0.65       162
# weighted avg       0.74      0.68      0.65       162
#
# [[33 47]
#  [ 5 77]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 64.81%
#  Precision: 52.14%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 98.39%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.98      0.44      0.61       100
#            1       0.52      0.98      0.68        62
#
#    micro avg       0.65      0.65      0.65       162
#    macro avg       0.75      0.71      0.64       162
# weighted avg       0.80      0.65      0.64       162
#
# [[44 56]
#  [ 1 61]]
#
#
# Deep Learning executed in = 97.690000 seconds
# Yaml Model  Save_YUM _up.yaml saved to disk
# Yaml Model  Save_YUM _down.yaml saved to disk
# Weights  Save_YUM _up.h5 saved to disk
# Weights  Save_YUM _down.h5 saved to disk
# Le   Deep Learning  de   YUM   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 502
# amorce :  479
#  --- Loop : 502  ---  --- Symbol :   ZBH   ---  --- Name :  Zimmer Biomet Holdings  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.2081490941055881
#  Alpha :  0.05377782104414558
#  R_Squared :  0.4659103196414004
#  Volatility :  0.2807278929089516
#  Momentum :  0.10217429298628633
# executed in = 2.120000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  405
# On 80% - 20% slash :
# Bloc 1 :  324
# Bloc 2 : 81  periods
# First period : 2017-11-01 00:00:00
# Split period : 2019-04-10 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:53:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 1.420000 seconds
#  Deeping in blue
#
#  --- Loop : 502  ---  --- Symbol :   ZBH   ---  --- Name :  Zimmer Biomet Holdings  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 324/324 [==============================] - 1s 2ms/step
# 324/324 [==============================] - 1s 3ms/step
# 32/32 [==============================] - 0s 47us/step
# 32/32 [==============================] - 0s 33us/step
#
#
#  RESULTATS UP
#
# Accuracy: 59.38%
#  Precision: 44.44%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 33.33%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.65      0.75      0.70        20
#            1       0.44      0.33      0.38        12
#
#    micro avg       0.59      0.59      0.59        32
#    macro avg       0.55      0.54      0.54        32
# weighted avg       0.57      0.59      0.58        32
#
# [[15  5]
#  [ 8  4]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 65.62%
#  Precision: 57.14%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.71%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.82      0.50      0.62        18
#            1       0.57      0.86      0.69        14
#
#    micro avg       0.66      0.66      0.66        32
#    macro avg       0.69      0.68      0.65        32
# weighted avg       0.71      0.66      0.65        32
#
# [[ 9  9]
#  [ 2 12]]
#
#
# Deep Learning executed in = 45.070000 seconds
# Yaml Model  Save_ZBH _up.yaml saved to disk
# Yaml Model  Save_ZBH _down.yaml saved to disk
# Weights  Save_ZBH _up.h5 saved to disk
# Weights  Save_ZBH _down.h5 saved to disk
# Le   Deep Learning  de   ZBH   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 503
# amorce :  479
#  --- Loop : 503  ---  --- Symbol :   ZION   ---  --- Name :  Zions Bancorp  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  1.5361494784096221
#  Alpha :  -0.013967531243284204
#  R_Squared :  0.44883147681120783
#  Volatility :  0.2890001997058034
#  Momentum :  -0.19668169387679058
# executed in = 2.360000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:54:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.000000 seconds
#  Deeping in blue
#
#  --- Loop : 503  ---  --- Symbol :   ZION   ---  --- Name :  Zions Bancorp  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 1s 1ms/step
# 843/843 [==============================] - 1s 1ms/step
# 162/162 [==============================] - 0s 46us/step
# 162/162 [==============================] - 0s 42us/step
#
#
#  RESULTATS UP
#
# Accuracy: 74.69%
#  Precision: 74.03%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 73.08%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.75      0.76      0.76        84
#            1       0.74      0.73      0.74        78
#
#    micro avg       0.75      0.75      0.75       162
#    macro avg       0.75      0.75      0.75       162
# weighted avg       0.75      0.75      0.75       162
#
# [[64 20]
#  [21 57]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 83.33%
#  Precision: 80.52%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 83.78%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84        88
#            1       0.81      0.84      0.82        74
#
#    micro avg       0.83      0.83      0.83       162
#    macro avg       0.83      0.83      0.83       162
# weighted avg       0.83      0.83      0.83       162
#
# [[73 15]
#  [12 62]]
#
#
# Deep Learning executed in = 106.990000 seconds
# Yaml Model  Save_ZION _up.yaml saved to disk
# Yaml Model  Save_ZION _down.yaml saved to disk
# Weights  Save_ZION _up.h5 saved to disk
# Weights  Save_ZION _down.h5 saved to disk
# Le   Deep Learning  de   ZION   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 504
# amorce :  479
#  --- Loop : 504  ---  --- Symbol :   ZTS   ---  --- Name :  Zoetis  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  0.8006594331030832
#  Alpha :  0.1756114532306003
#  R_Squared :  0.3146442630411732
#  Volatility :  0.17990541456271314
#  Momentum :  0.34605557765740147
# executed in = 2.310000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1054
# On 80% - 20% slash :
# Bloc 1 :  843
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-02 00:00:00
# Last period : 2019-08-06 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [00:55:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.180000 seconds
#  Deeping in blue
#
#  --- Loop : 504  ---  --- Symbol :   ZTS   ---  --- Name :  Zoetis  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 843/843 [==============================] - 1s 1ms/step
# 843/843 [==============================] - 1s 1ms/step
# 162/162 [==============================] - 0s 53us/step
# 162/162 [==============================] - 0s 47us/step
#
#
#  RESULTATS UP
#
# Accuracy: 56.17%
#  Precision: 60.78%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 37.80%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.54      0.75      0.63        80
#            1       0.61      0.38      0.47        82
#
#    micro avg       0.56      0.56      0.56       162
#    macro avg       0.57      0.56      0.55       162
# weighted avg       0.57      0.56      0.55       162
#
# [[60 20]
#  [51 31]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 67.90%
#  Precision: 53.47%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 91.53%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.92      0.54      0.68       103
#            1       0.53      0.92      0.68        59
#
#    micro avg       0.68      0.68      0.68       162
#    macro avg       0.73      0.73      0.68       162
# weighted avg       0.78      0.68      0.68       162
#
# [[56 47]
#  [ 5 54]]
#
#
# Deep Learning executed in = 108.800000 seconds
# Yaml Model  Save_ZTS _up.yaml saved to disk
# Yaml Model  Save_ZTS _down.yaml saved to disk
# Weights  Save_ZTS _up.h5 saved to disk
# Weights  Save_ZTS _down.h5 saved to disk
# Le   Deep Learning  de   ZTS   a été effecué avec succès. Les modèles ont été sauvegardés
#   Longueur des listes pour vérification :  505 505 505
#    PASSAGE FINI!!!!!!

# %%
#import sys
#orig_stdout = sys.stdout
#f = open('backtestv2_4.txt', 'w')
#sys.stdout = f

# %%
#f.close()
#sys.stdout = orig_stdout

# %% [markdown]
# import pandas as pd
#
# backtest = pd.DataFrame(columns = ['Symb.','Name','Sector','period','Begin.','End',\
#                           'Pnl','%Pnl','Total Winners','Total Loosers','Nb Win','Nb Los',\
#                           '% Winners','MaxDD','%MaxDD','Aver. Win',\
#                           'Aver. Los','Aver. Duration',\
#                           'Total Trades','% Long','% Short','Profit Factor'])
# backtest.to_csv('BackTest.csv')
#
# signals = pd.DataFrame(columns = ['Date','Ticker','Open Long','Close Long','Open Short','Close Short','Buy/Sell Price','Quantity','tPNL'])
# signals.to_csv('SIGNALS.csv')

# %%
2+2

# %%
print(Fore.YELLOW,Back.BLUE,'Longueur des listes pour vérification : ',len(ticker_list),len(name_list),len(sector_list),Style.RESET_ALL)

compteur = pd.DataFrame(columns = ['Symb.','Name','Sector'])

compteur['Symb.'] = ticker_list

compteur['Name'] = name_list

compteur['Sector'] = sector_list

compteur.to_csv('compteur.csv')

print(Fore.YELLOW,Back.MAGENTA,Style.DIM,'PASSAGE FINI!!!!!!',Style.RESET_ALL)

# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
import warnings
warnings.filterwarnings("ignore")

print('Importing Librairies...')
import warnings
warnings.filterwarnings("ignore")
import ib_insync
from ib_insync import *
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import time
import datetime as dt
import os
import sys
print('Librairies imported')
print('')

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print(Fore.YELLOW,Back.BLUE,'PlaySignal IB Version v1.55',Style.RESET_ALL)

print('')
ib = IB()
compte = 'DU1507426'
# Out:
# Importing Librairies...
# Librairies imported
#
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
#   PlaySignal IB Version v1.55

# %%
def conX():
    util.startLoop()  # uncomment this line when in a notebook
    ib.connect('127.0.0.1', 7497, clientId=1)
    if ib.isConnected() == True:
        print('Golem est maintenant connecté à IB')
    return

def disconX():
    ib.disconnect()
    if ib.isConnected() == False:
        print('Golem est maintenant déconnecté de IB')
    return



def relevpoz():
    CPT = []
    QT = []
    TYPE = []
    STOCK = []
    TICK = []
    AVGCOST = []
    CONID = []
    DAILYPNL = []
    
    globalpoz = ib.positions(account=compte)
    
    if globalpoz == []:
        print("Il n'y a aucune position en cours actuellement.")
        poz = pd.DataFrame({'ALERTE': [101]}) 
    else:
        print('Il y a actuellement ',len(globalpoz),'positions en cours')
        for i in range(0,len(globalpoz)):
            ib.reqPnLSingle(account=compte,modelCode='',conId=ib.positions(account=compte)[i][1].conId)
            CPT.append(globalpoz[i][0])
            TYPE.append(str(globalpoz[i][1]).split("(")[0])
            if str(globalpoz[i][1]).split("(")[0] == 'Future':
                TICK.append(str(globalpoz[i][1]).split("'")[1])
            elif str(globalpoz[i][1]).split("(")[0] == 'Forex':
                TICK.append(str(globalpoz[i][1]).split("'")[1])
            elif str(globalpoz[i][1]).split("(")[0] == 'Stock':
                TICK.append(str(globalpoz[i][1]).split("'")[1])
            else:
                TICK.append('NA')
            
            QT.append(globalpoz[i][2])
            AVGCOST.append(globalpoz[i][3])
            CONID.append(ib.positions(account=compte)[i][1].conId)
            poz = pd.DataFrame()
            
            poz['Compte'] = CPT
            poz['Type'] = TYPE
            poz['conId'] = CONID
            poz['Ticker'] = TICK
            poz['Quantité'] = QT
            poz['Average Cost'] = AVGCOST
        return(poz)

# %%
try:
    disconX()
except:
    pass

try:
    conX()
except:
    pass
poz = relevpoz()
poz
# Out:
# Golem est maintenant déconnecté de IB
# Golem est maintenant connecté à IB
# Il y a actuellement  28 positions en cours
#        Compte   Type      conId Ticker  Quantité  Average Cost
# 0   DU1507426  Stock       5407    CAH     266.0     55.475000
# 1   DU1507426  Stock     275850   VRTX     -71.0    212.481397
# 2   DU1507426  Stock    3691937   AMZN       8.0   1756.165000
# 3   DU1507426  Stock       9657    MCK      99.0    149.900101
# 4   DU1507426  Stock      13535    VNO     234.0     63.325000
# 5   DU1507426  Stock  105669270    PSX    -125.0    118.489428
# 6   DU1507426  Stock   13878278    CNC    -252.0     59.553648
# 7   DU1507426  Stock  375796353    XRX    -380.0     39.384066
# 8   DU1507426  Stock       9358    MAR     110.0    135.959091
# 9   DU1507426  Stock       9360    MAS     326.0     45.696595
# 10  DU1507426  Stock  346403540     CI      75.0    198.633333
# 11  DU1507426  Stock    2586156    KMX    -150.0     99.721150
# 12  DU1507426  Stock       5800    CMA     200.0     69.205000
# 13  DU1507426  Stock   29380756   NDAQ    -143.0    104.596736
# 14  DU1507426  Stock       8251    HUM     -45.0    334.440736
# 15  DU1507426  Stock   94078796   FBHS     234.0     63.495000
# 16  DU1507426  Stock       8894     KO    -282.0     53.133781
# 17  DU1507426  Stock    4726021   SWKS     153.0     97.646536
# 18  DU1507426  Stock     273733   REGN     -86.0    346.182947
# 19  DU1507426  Stock      11656    RJF     166.0     89.156024
# 20  DU1507426  Stock     269315   FISV    -128.0    116.039666
# 21  DU1507426  Stock      12120    SHW     -25.0    585.577760
# 22  DU1507426  Stock   40369429    HBI     -22.0     14.824573
# 23  DU1507426  Stock     274385   SIVB      65.0    229.655385
# 24  DU1507426  Stock     268627    DHI    -273.0     54.713748
# 25  DU1507426  Stock       6442    DHR     106.0    140.205094
# 26  DU1507426  Stock  120643512   NCLH     278.0     53.605000
# 27  DU1507426  Stock   49588376     PM    -178.0     83.562533

# %%
ib.reqPnL(account=compte, modelCode='')
# Out:
# PnL(account='DU1507426')

# %%
ib.pnl()
# Out:
# [PnL(account='DU1507426', dailyPnL=678.2753099487254, unrealizedPnL=766.4470096987308, realizedPnL=-263.99873935)]

# %%
ib.cancelPnL(account=compte, modelCode='')

# %%
ib.pnlSingle()[0]
# Out:
# PnLSingle(account='DU1507426', conId=5407, dailyPnL=138.31963470458868, unrealizedPnL=57.18963470458948, realizedPnL=1.7976931348623157e+308, position=266, value=14813.53963470459)

# %%
ib.positions(account=compte)[0]
# Out:
# Position(account='DU1507426', contract=Stock(conId=5407, symbol='CAH', exchange='NYSE', currency='USD', localSymbol='CAH', tradingClass='CAH'), position=266.0, avgCost=55.475)

# %%
TICKER = []
CONID = []
DAILYPNL = []
UNRLZPNL = []
RLZPNL = []
VALUE = []
singlepnl = pd.DataFrame()
if len(ib.pnlSingle()) >= 1:
    for i in range(0,len(ib.pnlSingle())):
        TICKER.append(poz[poz['conId']==ib.pnlSingle()[i].conId].iloc[-1]['Ticker'])
        CONID.append(ib.pnlSingle()[i].conId)
        DAILYPNL.append(ib.pnlSingle()[i].dailyPnL)
        UNRLZPNL.append(ib.pnlSingle()[i].unrealizedPnL)
        RLZPNL.append(ib.pnlSingle()[i].realizedPnL)
        VALUE.append(ib.pnlSingle()[i].value)

singlepnl['Ticker'] = TICKER
singlepnl['conId'] = CONID
singlepnl['Daily P&L'] = DAILYPNL
singlepnl['Unrealized P&L'] = UNRLZPNL
singlepnl['Realized P&L'] = RLZPNL
singlepnl['Value'] = VALUE
singlepnl
# Out:
#    Ticker      conId   Daily P&L  Unrealized P&L   Realized P&L         Value
# 0     CAH       5407  138.319635       57.189635  1.797693e+308  14813.539635
# 1    VRTX     275850 -177.500000     -391.820799  1.797693e+308 -15478.000000
# 2    AMZN    3691937   92.720391      -78.919609  1.797693e+308  13970.400391
# 3     MCK       9657   34.650060      268.280061  1.797693e+308  15108.390060
# 4     VNO      13535  -54.989964      -54.989964  1.797693e+308  14763.060036
# 5     PSX  105669270  232.428843      232.428843  1.797693e+308 -14578.749657
# 6     CNC   13878278  -12.600423      -46.961127  1.797693e+308 -15054.480423
# 7     XRX  375796353 -140.600522      123.144387  1.797693e+308 -14842.800522
# 8     MAR       9358  359.700000       32.000001  1.797693e+308  14987.500000
# 9     MAS       9360  -19.559552      118.470445  1.797693e+308  15015.560448
# 10     CI  346403540   11.999634      205.249633  1.797693e+308  15102.749634
# 11    KMX    2586156   89.999725      321.172225  1.797693e+308 -14637.000275
# 12    CMA       5800  141.000732      141.000732  1.797693e+308  13982.000732
# 13   NDAQ   29380756   52.909607       32.422905  1.797693e+308 -14924.910393
# 14    HUM       8251   10.350439     -170.966461  1.797693e+308 -15220.799561
# 15   FBHS   94078796   91.260179     -127.529821  1.797693e+308  14730.300179
# 16     KO       8894  -19.739656       29.266544  1.797693e+308 -14954.459656
# 17   SWKS    4726021  218.789440       29.599439  1.797693e+308  14969.519440
# 18   REGN     273733 -818.230915    -1245.026916  1.797693e+308 -31016.760315
# 19    RJF      11656   43.160608     -123.839393  1.797693e+308  14676.060608
# 20   FISV     269315   20.480234      271.317534  1.797693e+308 -14581.759766
# 21    SHW      12120 -156.750427      268.693573  1.797693e+308 -14370.750427
# 22    HBI   40369429   47.806897       -5.839403  -2.639987e+02   -331.980003
# 23   SIVB     274385  200.850278       88.700279  1.797693e+308  15016.300278
# 24    DHI     268627  -43.679917      175.743383  1.797693e+308 -14761.109917
# 25    DHR       6442   14.840776      330.180775  1.797693e+308  15191.920776
# 26   NCLH  120643512  164.019527      112.589527  1.797693e+308  15014.779527
# 27     PM   49588376  156.639674      174.890575  1.797693e+308 -14699.240326

# %%
ib.trades()[0].order.account
# Out:
# 'DU1507425'

# %%
[ib.trades()[x] for x in range(len(ib.trades())) if ib.trades()[x].order.account == 'DU1507426']
# Out:
# []

# %%
ib.orders()
# Out:
# [Order(orderId=14446, clientId=1, permId=1195129012, action='BUY', totalQuantity=143.0, orderType='LMT', lmtPrice=100.21, auxPrice=0.0, tif='GTC', ocaGroup='1195129011', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14447, clientId=1, permId=1195129013, action='BUY', totalQuantity=143.0, orderType='STP', lmtPrice=0.0, auxPrice=108.57, tif='GTC', ocaGroup='1195129011', ocaType=3, rule80A='0', trailStopPrice=108.57, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14442, clientId=1, permId=1195129009, action='SELL', totalQuantity=234.0, orderType='LMT', lmtPrice=66.25, auxPrice=0.0, tif='GTC', ocaGroup='1195129008', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14443, clientId=1, permId=1195129010, action='SELL', totalQuantity=234.0, orderType='STP', lmtPrice=0.0, auxPrice=61.15, tif='GTC', ocaGroup='1195129008', ocaType=3, rule80A='0', trailStopPrice=61.15, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14438, clientId=1, permId=1195129006, action='SELL', totalQuantity=106.0, orderType='LMT', lmtPrice=146.13, auxPrice=0.0, tif='GTC', ocaGroup='1195129005', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14439, clientId=1, permId=1195129007, action='SELL', totalQuantity=106.0, orderType='STP', lmtPrice=0.0, auxPrice=134.89, tif='GTC', ocaGroup='1195129005', ocaType=3, rule80A='0', trailStopPrice=134.89, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14430, clientId=1, permId=1195129000, action='BUY', totalQuantity=25.0, orderType='LMT', lmtPrice=561.51, auxPrice=0.0, tif='GTC', ocaGroup='1195128999', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14431, clientId=1, permId=1195129001, action='BUY', totalQuantity=25.0, orderType='STP', lmtPrice=0.0, auxPrice=608.31, tif='GTC', ocaGroup='1195128999', ocaType=3, rule80A='0', trailStopPrice=608.31, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14419, clientId=1, permId=1195128992, action='SELL', totalQuantity=75.0, orderType='STP', lmtPrice=0.0, auxPrice=190.83, tif='GTC', ocaGroup='1195128990', ocaType=3, rule80A='0', trailStopPrice=190.83, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14422, clientId=1, permId=1195128994, action='SELL', totalQuantity=153.0, orderType='LMT', lmtPrice=101.55, auxPrice=0.0, tif='GTC', ocaGroup='1195128993', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14423, clientId=1, permId=1195128995, action='SELL', totalQuantity=153.0, orderType='STP', lmtPrice=0.0, auxPrice=93.73, tif='GTC', ocaGroup='1195128993', ocaType=3, rule80A='0', trailStopPrice=93.73, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14414, clientId=1, permId=1195128988, action='SELL', totalQuantity=110.0, orderType='LMT', lmtPrice=141.39, auxPrice=0.0, tif='GTC', ocaGroup='1195128987', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14415, clientId=1, permId=1195128989, action='SELL', totalQuantity=110.0, orderType='STP', lmtPrice=0.0, auxPrice=130.51, tif='GTC', ocaGroup='1195128987', ocaType=3, rule80A='0', trailStopPrice=130.51, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14418, clientId=1, permId=1195128991, action='SELL', totalQuantity=75.0, orderType='LMT', lmtPrice=206.73, auxPrice=0.0, tif='GTC', ocaGroup='1195128990', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15704, clientId=1, permId=285724323, action='BUY', totalQuantity=1005.0, orderType='STP', lmtPrice=0.0, auxPrice=15.33, tif='GTC', ocaGroup='285724321', ocaType=3, rule80A='0', trailStopPrice=15.33, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14410, clientId=1, permId=1195128985, action='SELL', totalQuantity=65.0, orderType='LMT', lmtPrice=238.83, auxPrice=0.0, tif='GTC', ocaGroup='1195128984', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15703, clientId=1, permId=285724322, action='BUY', totalQuantity=1005.0, orderType='LMT', lmtPrice=14.15, auxPrice=0.0, tif='GTC', ocaGroup='285724321', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14411, clientId=1, permId=1195128986, action='SELL', totalQuantity=65.0, orderType='STP', lmtPrice=0.0, auxPrice=220.45, tif='GTC', ocaGroup='1195128984', ocaType=3, rule80A='0', trailStopPrice=220.45, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14403, clientId=1, permId=1195128980, action='BUY', totalQuantity=380.0, orderType='STP', lmtPrice=0.0, auxPrice=40.79, tif='GTC', ocaGroup='1195128978', ocaType=3, rule80A='0', trailStopPrice=40.79, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15049, clientId=1, permId=1667654350, action='SELL', totalQuantity=166.0, orderType='STP', lmtPrice=0.0, auxPrice=85.58, tif='GTC', ocaGroup='1667654348', ocaType=3, rule80A='0', trailStopPrice=85.58, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14406, clientId=1, permId=1195128982, action='SELL', totalQuantity=278.0, orderType='LMT', lmtPrice=55.74, auxPrice=0.0, tif='GTC', ocaGroup='1195128981', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14407, clientId=1, permId=1195128983, action='SELL', totalQuantity=278.0, orderType='STP', lmtPrice=0.0, auxPrice=51.46, tif='GTC', ocaGroup='1195128981', ocaType=3, rule80A='0', trailStopPrice=51.46, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15048, clientId=1, permId=1667654349, action='SELL', totalQuantity=166.0, orderType='LMT', lmtPrice=92.72, auxPrice=0.0, tif='GTC', ocaGroup='1667654348', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15716, clientId=1, permId=285724332, action='SELL', totalQuantity=234.0, orderType='STP', lmtPrice=0.0, auxPrice=60.82, tif='GTC', ocaGroup='285724330', ocaType=3, rule80A='0', trailStopPrice=60.82, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15044, clientId=1, permId=1667654346, action='SELL', totalQuantity=983.0, orderType='LMT', lmtPrice=15.69, auxPrice=0.0, tif='GTC', ocaGroup='1667654345', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15715, clientId=1, permId=285724331, action='SELL', totalQuantity=234.0, orderType='LMT', lmtPrice=65.88, auxPrice=0.0, tif='GTC', ocaGroup='285724330', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15045, clientId=1, permId=1667654347, action='SELL', totalQuantity=983.0, orderType='STP', lmtPrice=0.0, auxPrice=14.49, tif='GTC', ocaGroup='1667654345', ocaType=3, rule80A='0', trailStopPrice=14.49, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15712, clientId=1, permId=285724329, action='BUY', totalQuantity=125.0, orderType='STP', lmtPrice=0.0, auxPrice=122.86, tif='GTC', ocaGroup='285724327', ocaType=3, rule80A='0', trailStopPrice=122.86, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14402, clientId=1, permId=1195128979, action='BUY', totalQuantity=380.0, orderType='LMT', lmtPrice=37.65, auxPrice=0.0, tif='GTC', ocaGroup='1195128978', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15711, clientId=1, permId=285724328, action='BUY', totalQuantity=125.0, orderType='LMT', lmtPrice=113.4, auxPrice=0.0, tif='GTC', ocaGroup='285724327', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14394, clientId=1, permId=1195128973, action='BUY', totalQuantity=45.0, orderType='LMT', lmtPrice=320.52, auxPrice=0.0, tif='GTC', ocaGroup='1195128972', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14275, clientId=1, permId=1250058672, action='BUY', totalQuantity=77.0, orderType='LMT', lmtPrice=186.92, auxPrice=0.0, tif='GTC', ocaGroup='1250058671', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14395, clientId=1, permId=1195128974, action='BUY', totalQuantity=45.0, orderType='STP', lmtPrice=0.0, auxPrice=347.22, tif='GTC', ocaGroup='1195128972', ocaType=3, rule80A='0', trailStopPrice=347.22, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14276, clientId=1, permId=1250058673, action='BUY', totalQuantity=77.0, orderType='STP', lmtPrice=0.0, auxPrice=202.5, tif='GTC', ocaGroup='1250058671', ocaType=3, rule80A='0', trailStopPrice=202.5, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14390, clientId=1, permId=1195128970, action='BUY', totalQuantity=273.0, orderType='LMT', lmtPrice=52.34, auxPrice=0.0, tif='GTC', ocaGroup='1195128969', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15052, clientId=1, permId=1667654352, action='BUY', totalQuantity=178.0, orderType='LMT', lmtPrice=79.98, auxPrice=0.0, tif='GTC', ocaGroup='1667654351', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14391, clientId=1, permId=1195128971, action='BUY', totalQuantity=273.0, orderType='STP', lmtPrice=0.0, auxPrice=56.7, tif='GTC', ocaGroup='1195128969', ocaType=3, rule80A='0', trailStopPrice=56.7, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15053, clientId=1, permId=1667654353, action='BUY', totalQuantity=178.0, orderType='STP', lmtPrice=0.0, auxPrice=86.64, tif='GTC', ocaGroup='1667654351', ocaType=3, rule80A='0', trailStopPrice=86.64, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14382, clientId=1, permId=1195128964, action='BUY', totalQuantity=150.0, orderType='LMT', lmtPrice=95.55, auxPrice=0.0, tif='GTC', ocaGroup='1195128963', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14383, clientId=1, permId=1195128965, action='BUY', totalQuantity=150.0, orderType='STP', lmtPrice=0.0, auxPrice=103.51, tif='GTC', ocaGroup='1195128963', ocaType=3, rule80A='0', trailStopPrice=103.51, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14378, clientId=1, permId=1195128961, action='BUY', totalQuantity=282.0, orderType='LMT', lmtPrice=50.8, auxPrice=0.0, tif='GTC', ocaGroup='1195128960', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14379, clientId=1, permId=1195128962, action='BUY', totalQuantity=282.0, orderType='STP', lmtPrice=0.0, auxPrice=55.04, tif='GTC', ocaGroup='1195128960', ocaType=3, rule80A='0', trailStopPrice=55.04, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14299, clientId=1, permId=1250058690, action='SELL', totalQuantity=9.0, orderType='LMT', lmtPrice=1777.83, auxPrice=0.0, tif='GTC', ocaGroup='1250058689', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14371, clientId=1, permId=1195128956, action='SELL', totalQuantity=8.0, orderType='STP', lmtPrice=0.0, auxPrice=1685.8, tif='GTC', ocaGroup='1195128954', ocaType=3, rule80A='0', trailStopPrice=1685.8, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14300, clientId=1, permId=1250058691, action='SELL', totalQuantity=9.0, orderType='STP', lmtPrice=0.0, auxPrice=1708.11, tif='GTC', ocaGroup='1250058689', ocaType=3, rule80A='0', trailStopPrice=1708.11, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14374, clientId=1, permId=1195128958, action='BUY', totalQuantity=252.0, orderType='LMT', lmtPrice=56.87, auxPrice=0.0, tif='GTC', ocaGroup='1195128957', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14375, clientId=1, permId=1195128959, action='BUY', totalQuantity=252.0, orderType='STP', lmtPrice=0.0, auxPrice=61.61, tif='GTC', ocaGroup='1195128957', ocaType=3, rule80A='0', trailStopPrice=61.61, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14366, clientId=1, permId=1195128952, action='SELL', totalQuantity=326.0, orderType='LMT', lmtPrice=47.63, auxPrice=0.0, tif='GTC', ocaGroup='1195128951', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14367, clientId=1, permId=1195128953, action='SELL', totalQuantity=326.0, orderType='STP', lmtPrice=0.0, auxPrice=43.97, tif='GTC', ocaGroup='1195128951', ocaType=3, rule80A='0', trailStopPrice=43.97, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14370, clientId=1, permId=1195128955, action='SELL', totalQuantity=8.0, orderType='LMT', lmtPrice=1826.28, auxPrice=0.0, tif='GTC', ocaGroup='1195128954', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14362, clientId=1, permId=1195128949, action='SELL', totalQuantity=99.0, orderType='LMT', lmtPrice=155.89, auxPrice=0.0, tif='GTC', ocaGroup='1195128948', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14307, clientId=1, permId=1250058696, action='BUY', totalQuantity=87.0, orderType='LMT', lmtPrice=164.36, auxPrice=0.0, tif='GTC', ocaGroup='1250058695', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14363, clientId=1, permId=1195128950, action='SELL', totalQuantity=99.0, orderType='STP', lmtPrice=0.0, auxPrice=143.89, tif='GTC', ocaGroup='1195128948', ocaType=3, rule80A='0', trailStopPrice=143.89, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14308, clientId=1, permId=1250058697, action='BUY', totalQuantity=87.0, orderType='STP', lmtPrice=0.0, auxPrice=178.06, tif='GTC', ocaGroup='1250058695', ocaType=3, rule80A='0', trailStopPrice=178.06, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14320, clientId=1, permId=1250058706, action='BUY', totalQuantity=56.0, orderType='STP', lmtPrice=0.0, auxPrice=275.84, tif='GTC', ocaGroup='1250058704', ocaType=3, rule80A='0', trailStopPrice=275.84, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14319, clientId=1, permId=1250058705, action='BUY', totalQuantity=56.0, orderType='LMT', lmtPrice=254.62, auxPrice=0.0, tif='GTC', ocaGroup='1250058704', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14331, clientId=1, permId=1250058714, action='BUY', totalQuantity=142.0, orderType='LMT', lmtPrice=101.08, auxPrice=0.0, tif='GTC', ocaGroup='1250058713', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14332, clientId=1, permId=1250058715, action='BUY', totalQuantity=142.0, orderType='STP', lmtPrice=0.0, auxPrice=109.5, tif='GTC', ocaGroup='1250058713', ocaType=3, rule80A='0', trailStopPrice=109.5, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15029, clientId=1, permId=1736090659, action='SELL', totalQuantity=266.0, orderType='LMT', lmtPrice=58.02, auxPrice=0.0, tif='GTC', ocaGroup='1736090658', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15025, clientId=1, permId=1736090656, action='BUY', totalQuantity=128.0, orderType='LMT', lmtPrice=111.18, auxPrice=0.0, tif='GTC', ocaGroup='1736090655', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15026, clientId=1, permId=1736090657, action='BUY', totalQuantity=128.0, orderType='STP', lmtPrice=0.0, auxPrice=120.44, tif='GTC', ocaGroup='1736090655', ocaType=3, rule80A='0', trailStopPrice=120.44, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15030, clientId=1, permId=1736090660, action='SELL', totalQuantity=266.0, orderType='STP', lmtPrice=0.0, auxPrice=53.56, tif='GTC', ocaGroup='1736090658', ocaType=3, rule80A='0', trailStopPrice=53.56, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14343, clientId=1, permId=1250058723, action='BUY', totalQuantity=49.0, orderType='LMT', lmtPrice=293.95, auxPrice=0.0, tif='GTC', ocaGroup='1250058722', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14344, clientId=1, permId=1250058724, action='BUY', totalQuantity=49.0, orderType='STP', lmtPrice=0.0, auxPrice=318.45, tif='GTC', ocaGroup='1250058722', ocaType=3, rule80A='0', trailStopPrice=318.45, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True)]
# Peer closed connection

# %%
ib.openOrders()
# Out:
# [Order(orderId=14446, clientId=1, permId=1195129012, action='BUY', totalQuantity=143.0, orderType='LMT', lmtPrice=100.21, auxPrice=0.0, tif='GTC', ocaGroup='1195129011', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14447, clientId=1, permId=1195129013, action='BUY', totalQuantity=143.0, orderType='STP', lmtPrice=0.0, auxPrice=108.57, tif='GTC', ocaGroup='1195129011', ocaType=3, rule80A='0', trailStopPrice=108.57, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14442, clientId=1, permId=1195129009, action='SELL', totalQuantity=234.0, orderType='LMT', lmtPrice=66.25, auxPrice=0.0, tif='GTC', ocaGroup='1195129008', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14443, clientId=1, permId=1195129010, action='SELL', totalQuantity=234.0, orderType='STP', lmtPrice=0.0, auxPrice=61.15, tif='GTC', ocaGroup='1195129008', ocaType=3, rule80A='0', trailStopPrice=61.15, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14438, clientId=1, permId=1195129006, action='SELL', totalQuantity=106.0, orderType='LMT', lmtPrice=146.13, auxPrice=0.0, tif='GTC', ocaGroup='1195129005', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14439, clientId=1, permId=1195129007, action='SELL', totalQuantity=106.0, orderType='STP', lmtPrice=0.0, auxPrice=134.89, tif='GTC', ocaGroup='1195129005', ocaType=3, rule80A='0', trailStopPrice=134.89, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14430, clientId=1, permId=1195129000, action='BUY', totalQuantity=25.0, orderType='LMT', lmtPrice=561.51, auxPrice=0.0, tif='GTC', ocaGroup='1195128999', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14431, clientId=1, permId=1195129001, action='BUY', totalQuantity=25.0, orderType='STP', lmtPrice=0.0, auxPrice=608.31, tif='GTC', ocaGroup='1195128999', ocaType=3, rule80A='0', trailStopPrice=608.31, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14419, clientId=1, permId=1195128992, action='SELL', totalQuantity=75.0, orderType='STP', lmtPrice=0.0, auxPrice=190.83, tif='GTC', ocaGroup='1195128990', ocaType=3, rule80A='0', trailStopPrice=190.83, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14422, clientId=1, permId=1195128994, action='SELL', totalQuantity=153.0, orderType='LMT', lmtPrice=101.55, auxPrice=0.0, tif='GTC', ocaGroup='1195128993', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14423, clientId=1, permId=1195128995, action='SELL', totalQuantity=153.0, orderType='STP', lmtPrice=0.0, auxPrice=93.73, tif='GTC', ocaGroup='1195128993', ocaType=3, rule80A='0', trailStopPrice=93.73, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14414, clientId=1, permId=1195128988, action='SELL', totalQuantity=110.0, orderType='LMT', lmtPrice=141.39, auxPrice=0.0, tif='GTC', ocaGroup='1195128987', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14415, clientId=1, permId=1195128989, action='SELL', totalQuantity=110.0, orderType='STP', lmtPrice=0.0, auxPrice=130.51, tif='GTC', ocaGroup='1195128987', ocaType=3, rule80A='0', trailStopPrice=130.51, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14418, clientId=1, permId=1195128991, action='SELL', totalQuantity=75.0, orderType='LMT', lmtPrice=206.73, auxPrice=0.0, tif='GTC', ocaGroup='1195128990', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15704, clientId=1, permId=285724323, action='BUY', totalQuantity=1005.0, orderType='STP', lmtPrice=0.0, auxPrice=15.33, tif='GTC', ocaGroup='285724321', ocaType=3, rule80A='0', trailStopPrice=15.33, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14410, clientId=1, permId=1195128985, action='SELL', totalQuantity=65.0, orderType='LMT', lmtPrice=238.83, auxPrice=0.0, tif='GTC', ocaGroup='1195128984', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15703, clientId=1, permId=285724322, action='BUY', totalQuantity=1005.0, orderType='LMT', lmtPrice=14.15, auxPrice=0.0, tif='GTC', ocaGroup='285724321', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14411, clientId=1, permId=1195128986, action='SELL', totalQuantity=65.0, orderType='STP', lmtPrice=0.0, auxPrice=220.45, tif='GTC', ocaGroup='1195128984', ocaType=3, rule80A='0', trailStopPrice=220.45, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14403, clientId=1, permId=1195128980, action='BUY', totalQuantity=380.0, orderType='STP', lmtPrice=0.0, auxPrice=40.79, tif='GTC', ocaGroup='1195128978', ocaType=3, rule80A='0', trailStopPrice=40.79, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15049, clientId=1, permId=1667654350, action='SELL', totalQuantity=166.0, orderType='STP', lmtPrice=0.0, auxPrice=85.58, tif='GTC', ocaGroup='1667654348', ocaType=3, rule80A='0', trailStopPrice=85.58, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14406, clientId=1, permId=1195128982, action='SELL', totalQuantity=278.0, orderType='LMT', lmtPrice=55.74, auxPrice=0.0, tif='GTC', ocaGroup='1195128981', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14407, clientId=1, permId=1195128983, action='SELL', totalQuantity=278.0, orderType='STP', lmtPrice=0.0, auxPrice=51.46, tif='GTC', ocaGroup='1195128981', ocaType=3, rule80A='0', trailStopPrice=51.46, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15048, clientId=1, permId=1667654349, action='SELL', totalQuantity=166.0, orderType='LMT', lmtPrice=92.72, auxPrice=0.0, tif='GTC', ocaGroup='1667654348', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15716, clientId=1, permId=285724332, action='SELL', totalQuantity=234.0, orderType='STP', lmtPrice=0.0, auxPrice=60.82, tif='GTC', ocaGroup='285724330', ocaType=3, rule80A='0', trailStopPrice=60.82, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15044, clientId=1, permId=1667654346, action='SELL', totalQuantity=983.0, orderType='LMT', lmtPrice=15.69, auxPrice=0.0, tif='GTC', ocaGroup='1667654345', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15715, clientId=1, permId=285724331, action='SELL', totalQuantity=234.0, orderType='LMT', lmtPrice=65.88, auxPrice=0.0, tif='GTC', ocaGroup='285724330', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15045, clientId=1, permId=1667654347, action='SELL', totalQuantity=983.0, orderType='STP', lmtPrice=0.0, auxPrice=14.49, tif='GTC', ocaGroup='1667654345', ocaType=3, rule80A='0', trailStopPrice=14.49, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15712, clientId=1, permId=285724329, action='BUY', totalQuantity=125.0, orderType='STP', lmtPrice=0.0, auxPrice=122.86, tif='GTC', ocaGroup='285724327', ocaType=3, rule80A='0', trailStopPrice=122.86, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14402, clientId=1, permId=1195128979, action='BUY', totalQuantity=380.0, orderType='LMT', lmtPrice=37.65, auxPrice=0.0, tif='GTC', ocaGroup='1195128978', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15711, clientId=1, permId=285724328, action='BUY', totalQuantity=125.0, orderType='LMT', lmtPrice=113.4, auxPrice=0.0, tif='GTC', ocaGroup='285724327', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14394, clientId=1, permId=1195128973, action='BUY', totalQuantity=45.0, orderType='LMT', lmtPrice=320.52, auxPrice=0.0, tif='GTC', ocaGroup='1195128972', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14275, clientId=1, permId=1250058672, action='BUY', totalQuantity=77.0, orderType='LMT', lmtPrice=186.92, auxPrice=0.0, tif='GTC', ocaGroup='1250058671', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14395, clientId=1, permId=1195128974, action='BUY', totalQuantity=45.0, orderType='STP', lmtPrice=0.0, auxPrice=347.22, tif='GTC', ocaGroup='1195128972', ocaType=3, rule80A='0', trailStopPrice=347.22, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14276, clientId=1, permId=1250058673, action='BUY', totalQuantity=77.0, orderType='STP', lmtPrice=0.0, auxPrice=202.5, tif='GTC', ocaGroup='1250058671', ocaType=3, rule80A='0', trailStopPrice=202.5, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14390, clientId=1, permId=1195128970, action='BUY', totalQuantity=273.0, orderType='LMT', lmtPrice=52.34, auxPrice=0.0, tif='GTC', ocaGroup='1195128969', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15052, clientId=1, permId=1667654352, action='BUY', totalQuantity=178.0, orderType='LMT', lmtPrice=79.98, auxPrice=0.0, tif='GTC', ocaGroup='1667654351', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14391, clientId=1, permId=1195128971, action='BUY', totalQuantity=273.0, orderType='STP', lmtPrice=0.0, auxPrice=56.7, tif='GTC', ocaGroup='1195128969', ocaType=3, rule80A='0', trailStopPrice=56.7, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15053, clientId=1, permId=1667654353, action='BUY', totalQuantity=178.0, orderType='STP', lmtPrice=0.0, auxPrice=86.64, tif='GTC', ocaGroup='1667654351', ocaType=3, rule80A='0', trailStopPrice=86.64, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14382, clientId=1, permId=1195128964, action='BUY', totalQuantity=150.0, orderType='LMT', lmtPrice=95.55, auxPrice=0.0, tif='GTC', ocaGroup='1195128963', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14383, clientId=1, permId=1195128965, action='BUY', totalQuantity=150.0, orderType='STP', lmtPrice=0.0, auxPrice=103.51, tif='GTC', ocaGroup='1195128963', ocaType=3, rule80A='0', trailStopPrice=103.51, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14378, clientId=1, permId=1195128961, action='BUY', totalQuantity=282.0, orderType='LMT', lmtPrice=50.8, auxPrice=0.0, tif='GTC', ocaGroup='1195128960', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14379, clientId=1, permId=1195128962, action='BUY', totalQuantity=282.0, orderType='STP', lmtPrice=0.0, auxPrice=55.04, tif='GTC', ocaGroup='1195128960', ocaType=3, rule80A='0', trailStopPrice=55.04, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14299, clientId=1, permId=1250058690, action='SELL', totalQuantity=9.0, orderType='LMT', lmtPrice=1777.83, auxPrice=0.0, tif='GTC', ocaGroup='1250058689', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14371, clientId=1, permId=1195128956, action='SELL', totalQuantity=8.0, orderType='STP', lmtPrice=0.0, auxPrice=1685.8, tif='GTC', ocaGroup='1195128954', ocaType=3, rule80A='0', trailStopPrice=1685.8, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14300, clientId=1, permId=1250058691, action='SELL', totalQuantity=9.0, orderType='STP', lmtPrice=0.0, auxPrice=1708.11, tif='GTC', ocaGroup='1250058689', ocaType=3, rule80A='0', trailStopPrice=1708.11, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14374, clientId=1, permId=1195128958, action='BUY', totalQuantity=252.0, orderType='LMT', lmtPrice=56.87, auxPrice=0.0, tif='GTC', ocaGroup='1195128957', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14375, clientId=1, permId=1195128959, action='BUY', totalQuantity=252.0, orderType='STP', lmtPrice=0.0, auxPrice=61.61, tif='GTC', ocaGroup='1195128957', ocaType=3, rule80A='0', trailStopPrice=61.61, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14366, clientId=1, permId=1195128952, action='SELL', totalQuantity=326.0, orderType='LMT', lmtPrice=47.63, auxPrice=0.0, tif='GTC', ocaGroup='1195128951', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14367, clientId=1, permId=1195128953, action='SELL', totalQuantity=326.0, orderType='STP', lmtPrice=0.0, auxPrice=43.97, tif='GTC', ocaGroup='1195128951', ocaType=3, rule80A='0', trailStopPrice=43.97, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14370, clientId=1, permId=1195128955, action='SELL', totalQuantity=8.0, orderType='LMT', lmtPrice=1826.28, auxPrice=0.0, tif='GTC', ocaGroup='1195128954', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14362, clientId=1, permId=1195128949, action='SELL', totalQuantity=99.0, orderType='LMT', lmtPrice=155.89, auxPrice=0.0, tif='GTC', ocaGroup='1195128948', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14307, clientId=1, permId=1250058696, action='BUY', totalQuantity=87.0, orderType='LMT', lmtPrice=164.36, auxPrice=0.0, tif='GTC', ocaGroup='1250058695', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14363, clientId=1, permId=1195128950, action='SELL', totalQuantity=99.0, orderType='STP', lmtPrice=0.0, auxPrice=143.89, tif='GTC', ocaGroup='1195128948', ocaType=3, rule80A='0', trailStopPrice=143.89, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14308, clientId=1, permId=1250058697, action='BUY', totalQuantity=87.0, orderType='STP', lmtPrice=0.0, auxPrice=178.06, tif='GTC', ocaGroup='1250058695', ocaType=3, rule80A='0', trailStopPrice=178.06, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14320, clientId=1, permId=1250058706, action='BUY', totalQuantity=56.0, orderType='STP', lmtPrice=0.0, auxPrice=275.84, tif='GTC', ocaGroup='1250058704', ocaType=3, rule80A='0', trailStopPrice=275.84, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14319, clientId=1, permId=1250058705, action='BUY', totalQuantity=56.0, orderType='LMT', lmtPrice=254.62, auxPrice=0.0, tif='GTC', ocaGroup='1250058704', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14331, clientId=1, permId=1250058714, action='BUY', totalQuantity=142.0, orderType='LMT', lmtPrice=101.08, auxPrice=0.0, tif='GTC', ocaGroup='1250058713', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14332, clientId=1, permId=1250058715, action='BUY', totalQuantity=142.0, orderType='STP', lmtPrice=0.0, auxPrice=109.5, tif='GTC', ocaGroup='1250058713', ocaType=3, rule80A='0', trailStopPrice=109.5, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15029, clientId=1, permId=1736090659, action='SELL', totalQuantity=266.0, orderType='LMT', lmtPrice=58.02, auxPrice=0.0, tif='GTC', ocaGroup='1736090658', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15025, clientId=1, permId=1736090656, action='BUY', totalQuantity=128.0, orderType='LMT', lmtPrice=111.18, auxPrice=0.0, tif='GTC', ocaGroup='1736090655', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15026, clientId=1, permId=1736090657, action='BUY', totalQuantity=128.0, orderType='STP', lmtPrice=0.0, auxPrice=120.44, tif='GTC', ocaGroup='1736090655', ocaType=3, rule80A='0', trailStopPrice=120.44, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=15030, clientId=1, permId=1736090660, action='SELL', totalQuantity=266.0, orderType='STP', lmtPrice=0.0, auxPrice=53.56, tif='GTC', ocaGroup='1736090658', ocaType=3, rule80A='0', trailStopPrice=53.56, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14343, clientId=1, permId=1250058723, action='BUY', totalQuantity=49.0, orderType='LMT', lmtPrice=293.95, auxPrice=0.0, tif='GTC', ocaGroup='1250058722', ocaType=3, rule80A='0', openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True),
#  Order(orderId=14344, clientId=1, permId=1250058724, action='BUY', totalQuantity=49.0, orderType='STP', lmtPrice=0.0, auxPrice=318.45, tif='GTC', ocaGroup='1250058722', ocaType=3, rule80A='0', trailStopPrice=318.45, openClose='', eTradeOnly=False, firmQuoteOnly=False, volatilityType=0, deltaNeutralOrderType='None', referencePriceType=0, account='DU1507425', clearingIntent='IB', orderComboLegs=[], adjustedOrderType='None', conditions=[], softDollarTier=SoftDollarTier(), cashQty=0.0, dontUseAutoPriceForHedge=True)]

# %%
ib.openTrades()
# Out:
# []

# %%
ib.

# %%
ticker = 'EOG'
contract = Stock(ticker,'SMART','USD')
bars = ib.reqHistoricalData(contract, endDateTime='', durationStr='60 S',barSizeSetting='1 min', whatToShow='MIDPOINT', useRTH=True)

# convert to pandas dataframe:
df = util.df(bars)
df

# %%
sub = ScannerSubscription(contract)
scanData = ib.reqScannerSubscription(sub)

# %%
bars = ib.reqHistoricalData(contract, endDateTime='', durationStr='3 D',barSizeSetting='1 day', whatToShow='MIDPOINT', useRTH=True)
util.df(bars)

# %%
ib.reqMktData(contract).dividends

# %%
ib.reqMktData(contract).fundamentalRatios

# %%
ib_insync.objects.PnL(compte,ib.reqMktData(contract))

# %%
ib_insync.objects.PnLSingle(compte,ib.reqMktData(contract))

# %%
ib_insync.objects.PnLSingle(ib.reqMktData(contract))

# %%
(ib.reqMktData(contract).marketPrice)

# %%
(ib.reqMktData(contract)).update

# %%
(ib.reqMktData(contract,snapshot=True)).ask

# %%
(ib.reqMktData(contract)).bid

# %%
ib.accountSummary(compte)
# Out:
# [AccountValue(account='DU1507426', tag='AccountType', value='CORPORATION', currency='', modelCode=''),
#  AccountValue(account='DU1507426', tag='Cushion', value='0.652593', currency='', modelCode=''),
#  AccountValue(account='DU1507426', tag='DayTradesRemaining', value='-1', currency='', modelCode=''),
#  AccountValue(account='DU1507426', tag='LookAheadNextChange', value='1573655400', currency='', modelCode=''),
#  AccountValue(account='DU1507426', tag='AccruedCash', value='62.35', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='AvailableFunds', value='315507.20', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='BuyingPower', value='2103381.34', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='EquityWithLoanValue', value='510651.30', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='ExcessLiquidity', value='333247.57', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='FullAvailableFunds', value='315507.20', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='FullExcessLiquidity', value='333247.57', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='FullInitMarginReq', value='195144.10', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='FullMaintMarginReq', value='177403.73', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='GrossPositionValue', value='1155485.69', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='InitMarginReq', value='195144.10', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='LookAheadAvailableFunds', value='315507.20', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='LookAheadExcessLiquidity', value='333247.57', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='LookAheadInitMarginReq', value='195144.10', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='LookAheadMaintMarginReq', value='177403.73', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='MaintMarginReq', value='177403.73', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='NetLiquidation', value='510651.30', currency='USD', modelCode=''),
#  AccountValue(account='DU1507426', tag='TotalCashValue', value='664412.10', currency='USD', modelCode='')]

# %%
poz[poz['Ticker'] == ticker].iloc[-1]['Average Cost']

# %%
try:
    LaBase = pd.read_csv('LaBase.csv')
    print('LaBase est chargée :\n',LaBase.tail(2))
    try:
        LaBase = LaBase.drop(['Unnamed: 0'],axis=1)
    except:
        pass
    try:
        LaBase = LaBase.drop(['Date.1'],axis=1)
    except:
        pass
except:
    print("Il n'y a pas de fichier LaBase")
    kill()
stamp = input("Enter the date (YYYY-MM-DD): ")
compte = 'DU1507425'

def conX():
    util.startLoop()  # uncomment this line when in a notebook
    ib.connect('127.0.0.1', 7497, clientId=1)
    if ib.isConnected() == True:
        print('Golem est maintenant connecté à IB')
    return

def disconX():
    ib.disconnect()
    if ib.isConnected() == False:
        print('Golem est maintenant déconnecté de IB')
    return



def relevpoz():
    CPT = []
    QT = []
    TYPE = []
    STOCK = []
    TICK = []
    AVGCOST = []
    globalpoz = ib.positions(account=compte)
    
    if globalpoz == []:
        print("Il n'y a aucune position en cours actuellement.")
        poz = pd.DataFrame({'ALERTE': [101]}) 
    else:
        print('Il y a actuellement ',len(globalpoz),'positions en cours')
        for i in range(0,len(globalpoz)):
            CPT.append(globalpoz[i][0])
            TYPE.append(str(globalpoz[i][1]).split("(")[0])
            if str(globalpoz[i][1]).split("(")[0] == 'Future':
                TICK.append(str(globalpoz[i][1]).split("'")[1])
            elif str(globalpoz[i][1]).split("(")[0] == 'Forex':
                TICK.append(str(globalpoz[i][1]).split("'")[1])
            elif str(globalpoz[i][1]).split("(")[0] == 'Stock':
                TICK.append(str(globalpoz[i][1]).split("'")[1])
            else:
                TICK.append('NA')

            QT.append(globalpoz[i][2])
            AVGCOST.append(globalpoz[i][3])
            poz = pd.DataFrame()
            
            poz['Compte'] = CPT
            poz['Type'] = TYPE
            poz['Ticker'] = TICK
            poz['Quantité'] = QT
            poz['Average Cost'] = AVGCOST
            poz.to_csv('RelevPoz_'+time.strftime("%d_%m_%Y_%H_%M_%S", time.localtime())+'.csv')
    return(poz)

def price_close(LaBase,ticker):
    
    #today = str(dt.date.today())[:5]+str(dt.date.today())[5:7]+str(dt.date.today())[7:10]
    #yesterday = str(dt.date.today()-dt.timedelta(1))[:5]+str(dt.date.today()-dt.timedelta(1))[5:7]+str(dt.date.today()-dt.timedelta(1))[7:10]
    
    #if str(web.DataReader(ticker,'yahoo',yesterday,today).index[-1])[:10] == today:
    #    price = web.DataReader(ticker,'yahoo',yesterday,today).iloc[-2,3]

    #elif str(web.DataReader(ticker,'yahoo',yesterday,today).index[-1])[:10] == yesterday:
    #    price = web.DataReader(ticker,'yahoo',yesterday,today).iloc[-1,3]
    #else:
    #    price = web.DataReader(ticker,'yahoo',yesterday,today).iloc[-1,3]
    
    price = round(LaBase[LaBase['Symbol']==ticker].iloc[-1]['Close'],2)
    
    return(price)

def BUY(contract,quantity,pot,price):
    #Contract(conId=270639)
    ib.qualifyContracts(contract)
    order = StopLimitOrder('BUY', quantity,lmtPrice=pot,stopPrice=round(price*1.05,2),account=compte,outsideRth=True)
    trade = ib.placeOrder(contract, order)
    print(trade)
    return()

def SELL(contract,quantity,pot,price):
    #Contract(conId=270639)
    ib.qualifyContracts(contract)
    order = StopLimitOrder('SELL', quantity,lmtPrice=pot,stopPrice=round(price*0.95,2),account=compte,outsideRth=True)
    trade = ib.placeOrder(contract, order)
    print(trade)
    return()

try:
    disconX()
except:
    pass

try:
    conX()
except:
    pass

today = str(dt.date.today())[:5]+str(dt.date.today())[5:7]+str(dt.date.today())[7:10]
yesterday = str(dt.date.today()-dt.timedelta(1))[:5]+str(dt.date.today()-dt.timedelta(1))[5:7]+str(dt.date.today()-dt.timedelta(1))[7:10]

# %%
try:
    
    signals = pd.read_csv('SIGNALS_'+stamp+'.csv')
    try:
        signals = signals.drop('Unnamed: 0',axis=1)
    except:
        pass
    print('Le fichier SIGNALS_'+stamp+'.csv a bien été chargé')
    
    
except:
    sys.exit("\n Golem n'a pas trouvé le fichier SIGNALS_"+stamp+".csv => Arrêt du programme")

poz = relevpoz()


foo = 0
ACTION = []
ASKED_PRICE = []
WHEN = []
OL = []
CL = []
OS = []
CS = []

try:
    signals['Tradé']
except:
    signals['Tradé'] = 'NA'
if (signals[signals['Tradé']=='NA'].shape[0] == signals.shape[0]):
    print('1er passagd')
else:
    
    foo = signals[signals['Tradé']=='NA'].index[0]
    print('On reprend le passage en ligne ',foo)
    
try:
    pactol = float(str(str([v for v in ib.accountValues() if v.tag == 'NetLiquidationByCurrency' and v.currency == 'BASE']).split()[2]).split("'")[1])
except:
    print('Montant du pactol non récupéré')
    ib.isConnected()
try:
    print(Back.BLUE,Fore.YELLOW,'Les fonds disponibles sur le compte sont de : $',pactol,Style.RESET_ALL)
except:
    pass
mise = pactol * 0.02
tmps55=time.time()
for i in range (foo,signals.shape[0]):
    #try:
    #Contract(conId=270639)
    horo = signals.iloc[i,0]
    ticker = signals.iloc[i,1]
    openlong = signals.iloc[i,2]
    closelong = signals.iloc[i,3]
    openshort = signals.iloc[i,4]
    closeshort = signals.iloc[i,5]
    contract = Stock(ticker,'SMART','USD')
    price = price_close(LaBase,ticker)

    en_poz = 0
    if poz.iloc[0,0] != 101:
        if len(poz[ticker == poz.iloc[:,2]]) > 1:
            exit("Il y a plus d'une position pour le ticker ",ticker)
        elif len(poz[ticker == poz.iloc[:,2]]) == 1:
            indeX = int(str(str(poz[ticker == poz.iloc[:,2]].index).split('[')[1]).split(']')[0])
            quantity = abs(poz.iloc[indeX,3])
            if poz.iloc[indeX,3] < 0:
                en_poz = -1
            if poz.iloc[indeX,3] > 0:
                en_poz = 1

    if openlong == 1 and en_poz == 0:
        print('')
        pot = round(price * 1.002,2)
        quantity = round(mise/pot)
        print(Fore.GREEN,'Open Long',Style.RESET_ALL,' sur le ticker ',ticker,' basé sur un close limité à ', price,'\n')
        WHEN.append(time.strftime("%d-%m-%Y %H:%M:%S", time.localtime()))
        ASKED_PRICE.append(pot)
        ACTION.append('Open Long')
        OL.append(1)
        BUY(contract,quantity,pot,price)


    elif openshort == 1 and en_poz == 0:
        print('')
        pot = round(price * 0.998,2)
        quantity = round(mise/pot)
        print(Fore.GREEN,'Open Short',Style.RESET_ALL,' sur le ticker ',ticker,' basé sur un close limité à ', price,'\n')
        WHEN.append(time.strftime("%d-%m-%Y %H:%M:%S", time.localtime()))
        ASKED_PRICE.append(pot)
        ACTION.append('Open Short')
        OS.append(1)
        SELL(contract,quantity,pot,price)


    elif closelong == 1 and en_poz == 1:
        print('')
        pot = float(round(poz[poz['Ticker']==ticker]['Average Cost'],2))
        print(Fore.RED,'Close Long',Style.RESET_ALL,' sur le ticker ',ticker,' basé sur un close limité à ', price,'\n')
        WHEN.append(time.strftime("%d-%m-%Y %H:%M:%S", time.localtime()))
        ASKED_PRICE.append(pot)
        ACTION.append('Close Long')
        CL.append(1)
        SELL(contract,quantity,pot,price)


    elif closeshort == 1 and en_poz == -1:
        print('')
        pot = pot = float(round(poz[poz['Ticker']==ticker]['Average Cost'],2))
        print(Fore.RED,'Close Short',Style.RESET_ALL,' sur le ticker ',ticker,' basé sur un close limité à ', price,'\n')
        WHEN.append(time.strftime("%d-%m-%Y %H:%M:%S", time.localtime()))
        ASKED_PRICE.append(pot)
        ACTION.append('Close Short')
        CS.append(1)
        BUY(contract,quantity,pot,price)


    else:
        WHEN.append('NA')
        ASKED_PRICE.append('NA')
        ACTION.append('NA')
        
    signals.iloc[foo,7]='Traité'
    #except:
     #   print('souci boucle ',i,' pour le ticker ',ticker)
      #  continue

traded = signals
traded['Action'] = ACTION
traded['Quand'] = WHEN
traded['Prix limite'] = ASKED_PRICE

traded.to_csv('OrdresPasses_'+time.strftime("%d_%m_%Y_%H_%M_%S", time.localtime())+'.csv')

tmps22=round(time.time()-tmps55,2)
print("\n Ensemble des opérations du jour effectué en %f" %tmps22,'seconds \n')

print('Il y a eu ',sum(OL),' Open Long, ',sum(OS),' Open Short, ',sum(CL),' Close Long, et ',sum(CS),' Close Short.')
disconX()

# %%
disconX()

# %%
ib.trades()

# %%
disconX()

# %%
conX()

# %%
# MANOUAL

#ticker = 'TROW'
#contract = Stock(ticker,'SMART','USD')
#indeX = int(str(str(poz[ticker == poz.iloc[:,2]].index).split('[')[1]).split(']')[0])
#quantity = abs(poz.iloc[indeX,3])
#price = 117.34
#indeX, quantity, price

# %%
#BUY(contract,quantity,price)
#SELL(contract,quantity,price)

# %%
len(ib.positions(compte))

# %%
ib.positions(compte)

# %%
relevpoz()

# %%
signals.iloc[foo,7]='Traité'

# %%
signals.head()

# %%
util.df(ib.accountSummary(account=compte))

# %%
ib_insync.objects.PnLSingle(compte).dailyPnL

# %%
ib_insync.objects.PnLSingle(compte).unrealizedPnL

# %%
ib_insync.objects.PnLSingle(compte).realizedPnL

# %%
ib_insync.objects.PnLSingle(compte).value

# %%
ib_insync.objects.PnL(compte,'dailyPnL')

# %%
ib_insync.client.Client()#.reqCompletedOrders()

# %%
ib.qualifyContracts(contract)
order = LimitOrder('SELL', quantity, pot,account=compte,conditionsIgnoreRth=True)
trade = ib.placeOrder(contract, order)
print(trade)

# %%
disconX()

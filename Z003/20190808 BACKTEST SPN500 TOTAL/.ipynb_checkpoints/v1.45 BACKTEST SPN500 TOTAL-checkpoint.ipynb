# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
print('Importing Librairies...')
import talib
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)


from keras.models import model_from_yaml

import xgboost as xgb
from xgboost import XGBRegressor, plot_importance
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')
import time
import datetime as dt
import os
print('Librairies imported')
print('')

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print(Fore.YELLOW,Back.BLUE,'BOOST BACKTEST SPN500 55 Version v1.45',Style.RESET_ALL)

print('')
print('Sraping tickers')
constituents_csv = os.path.abspath('constituents_csv.csv')
constituents = pd.read_csv(constituents_csv)
print('Scrap -----> ok')

start = pd.to_datetime('2015-06-01')
end = pd.to_datetime('2019-12-31')

try :
    amorce = pd.read_csv('backTest.csv').index[-1] + 1
    backtest = pd.read_csv('backTest.csv')
    
    try:
        backtest = backtest.drop(['Unnamed: 0'],axis=1)
    except:
        pass
    
except:
    amorce = 0
    backtest = pd.DataFrame(columns = ['Symb.','Name','Sector','Period','Begin.','End',\
                          'Pnl $','Pnl %','Gross Profit','Gross Loss','# Winners','# Loosers',\
                          '% Winners','MaxDD $','MaxDD %','Aver. Win $',\
                          'Aver. Loos $','Aver. Duration',\
                          'Total Trades','% Long','% Short','Profit Factor'])
    
    
try:
    amorce2 = pd.read_csv('SIGNALS.csv').index[-1] + 1
    signals = pd.read_csv('SIGNALS.csv')

    try:
        signals = signals.drop(['Unnamed: 0'],axis=1)
    except:
        pass
except:
    amorce2 = 0
    signals = pd.DataFrame(columns = ['Date','Ticker','Open Long','Close Long','Open Short','Close Short','Buy/Sell Price','Quantity','PNL','Cumulative PNL','Latent PNL'])

    
# SCRAPING DES DONNES BRUTES
def scrap_data(ticker,start,end):
    df = web.DataReader(ticker,'yahoo',start,end)
    df = df.drop(['Close'],axis=1)
    df['Close'] = df['Adj Close']
    df = df.drop(['Adj Close'],axis = 1)    
    return(df)

def prepa_data(df):
    tmps1=time.time()
    print('Preparing data...')
    rsi = talib.RSI(df['Close'],timeperiod=14)
    stoc_slowk, stoc_slowd = talib.STOCH(df['High'],df['Low'],df['Close'])
    upper, middle, lower =  talib.BBANDS(df['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(df['Close'],timeperiod=5)
    sma8 = talib.SMA(df['Close'],timeperiod=8)
    sma10 = talib.SMA(df['Close'],timeperiod=10)
    sma12 = talib.SMA(df['Close'],timeperiod=12)
    sma15 = talib.SMA(df['Close'],timeperiod=15)
    sma30 = talib.SMA(df['Close'],timeperiod=30)
    sma35 = talib.SMA(df['Close'],timeperiod=35)
    sma40 = talib.SMA(df['Close'],timeperiod=40)
    sma45 = talib.SMA(df['Close'],timeperiod=45)
    sma50 = talib.SMA(df['Close'],timeperiod=50)
    atr = talib.ATR(df['High'],df['Low'],df['Close'],timeperiod=10)
    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50
    bbdelta = upper - middle
    price_bolup = df['Close'] - lower
    price_bolow = df['Close'] - upper
    Ema = talib.EMA(df['Close'],timeperiod=20)
    KC_High = Ema + 2*atr
    KC_Low = Ema - 2*atr
    aroondown, aroonup = talib.AROON(df['High'], df['Low'], timeperiod=9)
    aroon = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
    rsi30_list = []
    rsi70_list = []
    for i in range(0,df.shape[0]):
        rsi70_list.append(70 - rsi[i])
        rsi30_list.append(rsi[i] - 30)
        #except:
         #   rsi70_list.append(0)
          #  rs30_list.append(0)
    varop_spy = df['Open'] - df['Close']
    varhl_spy = df['High'] - df['Low']
    df['Varop_Spy'] = varop_spy
    df['Varhl_spy'] = varhl_spy
    df['RSI'] = rsi
    df['70 - RSI'] = np.array(rsi70_list)
    df['RSI - 30'] = np.array(rsi30_list)
    df['BBD_Delta_Up'] = bbdelta
    df['delta5_8'] = delta5_8
    df['delta8_10'] = delta8_10
    df['delta10_12'] = delta10_12
    df['delta12_15'] = delta12_15
    df['delta15_30'] = delta15_30
    df['delta30_35'] = delta30_35
    df['delta35_40'] = delta35_40
    df['delta40_45'] = delta40_45
    df['delta45_50'] = delta45_50
    df['Stoc_Slowk'] = stoc_slowk
    df['Stoc_Slowd'] = stoc_slowd
    df['KC_High'] = KC_High
    df['KC_Low'] = KC_Low
    df['upper'] = upper
    df['lower'] = lower
    df['var_bollup_kchigh'] = upper-KC_High
    df['var_bolllow_kclow'] = lower-KC_Low
    df['Aroon Up'] = aroonup
    df['Aroon Down'] = aroondown
    df['Delta Aroon'] = aroon
    up = []
    down = []
    df = df.dropna()
    df = boost(df)
    df['%Futur'] = ((df['Close.S']-df['Close']) *100) / (df['Close'])
    df['%Futur2'] = ((df['Close.S2']-df['Close']) *100) / (df['Close'])
    for i in range(0,df.shape[0]-5):
        if df.iloc[i]['%Futur'] > 0.1 :#or df.iloc[i]['%Futur2'] > 0.1:
            up.append(1)
            down.append(0)
        elif df.iloc[i]['%Futur'] < -0.1: #or df.iloc[i]['%Futur2'] < -0.1:
            up.append(0)
            down.append(1)
        else:
            up.append(0)
            down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    
    
    df['target_up'] = up  # target_up # abs(np.array(valley))#target_up
    df['target_down'] = down # target_down # abs(np.array(peak))#target_down
    #df = df.dropna()
    tmps2=round(time.time()-tmps1,2)
    print ("Data prepared in = %f" %tmps2,'seconds')
    return(df)

def boost(df):
    print('Boosting')
    X = df.copy()
    X = X.drop(['Close'],axis=1)
    X['Close'] = df['Close']
    y = X.iloc[:,-1]
    Xtrain = X.iloc[:-2,:-1]
    Xtest = X.iloc[-2:-1,:-1]
    yshift = y.shift(-1)
    ytrain = yshift.iloc[:-2]
    ytest = yshift.iloc[-2:-1]

    model = xgb.XGBRegressor(n_estimators=20000, learning_rate=1, gamma=1, subsample=1, colsample_bytree=1, max_depth=100)

    model.fit( Xtrain, ytrain, early_stopping_rounds=150, eval_set=[(Xtest, ytest)], verbose=0)

    ytrain_pred = model.predict(Xtrain)

    y_pred = model.predict(Xtest)

    pred = model.predict(X.iloc[:,:-1])

    df['Close.S'] = pred
    df['Close.S2'] = df['Close.S']
    df = df.dropna()
    print('Boost ok')
    return(df)

    
def deep_learning(df):
    tmps1=time.time()
    X = df.iloc[:,1:-4]
    y_up = df.iloc[:,-2].values
    y_down = df.iloc[:,-1].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:bloc1,:]
    Xtest = X[bloc1:,:]
    ytrain_up = y_up[:bloc1,:]
    ytest_up = y_up[bloc1:,:]
    ytrain_down = y_down[:bloc1,:]
    ytest_down = y_down[bloc1:,:]

    seed = 770
    np.random.seed(seed)

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)

    accuracy_up = accuracy_score(ytest_up, yhat_up)
    accuracy_down = accuracy_score(ytest_down, yhat_down)

    # La précision permet de mesurer la capacité du modèle à refuser résultats non-pertinents : vrais_positifs/(vrais_positifs+faux_positifs)
    precision_up = precision_score(ytest_up, yhat_up)  
    precision_down = precision_score(ytest_down, yhat_down) 


    # Recall : (vrai_positifs/(vrais_positifs+faux_négatifs))
    recall_up = recall_score(ytest_up, yhat_up) 
    recall_down = recall_score(ytest_down, yhat_down) 


    #roc_up=roc_auc_score(ytest_up,yhat_up)
    #roc_down=roc_auc_score(ytest_down,yhat_down)
    print('\n')
    print(Fore.GREEN,'RESULTATS UP\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_up * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_up *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_up * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_up *100))
    # get probabilities for positive class

    print(classification_report(ytest_up, yhat_up))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_up, yhat_up))

    print('\n')
    print('_______________________________________________________________________________________________________________________________________________________________\n')
    print(Fore.RED,'RESULTATS DOWN\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_down * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_down *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_down * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_down *100))
    # get probabilities for positive class

    print(classification_report(ytest_down, yhat_down))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_down, yhat_down))
    print('\n')

    resultats = pd.DataFrame()
    resultats['Date'] = df.index[bloc1:]
    resultats.index= df.index[bloc1:]
    resultats['Move Up'] = yhat_up
    resultats['Confiance up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confiance Down'] = (predict_down)*100
    resultats['Actual'] = df.iloc[bloc1:]['Close']
    resultats['Actual.S'] = df.iloc[bloc1:]['Close.S']
    open_S = df['Open'].shift(-1)
    resultats['Open.S'] = open_S.iloc[bloc1:]
    dmp_cp=[]
    dmp_cp = ((resultats['Confiance up']-resultats['Confiance Down'])/(resultats['Confiance up']+resultats['Confiance Down'])*100)
    resultats['DMP_CP'] = dmp_cp
    tmps2=round(time.time()-tmps1,2)
    print ("Deep Learning executed in = %f" %tmps2,'seconds')
    #resultats.set_index('Date',inplace=True)
    #parse_dates=resultats['Date']
    return(resultats,precision_up,precision_down,scaler)

def learn(df):
    resultats,precision_up,precision_down,scaler = deep_learning(df)
    return(resultats,precision_up,precision_down,scaler)

def grobeta(df,dfb):
    # create a time-series of monthly data points
    rts = df.resample('M').last()
    rbts = dfb.resample('M').last()
    dfsm = pd.DataFrame({'s_adjclose' : rts['Close'],
                            'b_adjclose' : rbts['Adj Close']},
                            index=rts.index)

    # compute returns
    dfsm[['s_returns','b_returns']] = dfsm[['s_adjclose','b_adjclose']]/\
        dfsm[['s_adjclose','b_adjclose']].shift(1) -1
    dfsm = dfsm.dropna()
    covmat = np.cov(dfsm["s_returns"],dfsm["b_returns"])

    # calculate measures now
    beta = covmat[0,1]/covmat[1,1]
    alpha= np.mean(dfsm["s_returns"])-beta*np.mean(dfsm["b_returns"])

    # r_squared     = 1. - SS_res/SS_tot
    ypred = alpha + beta * dfsm["b_returns"]
    SS_res = np.sum(np.power(ypred-dfsm["s_returns"],2))
    SS_tot = covmat[0,0]*(len(dfsm)-1) # SS_tot is sample_variance*(n-1)
    r_squared = 1. - SS_res/SS_tot
    # 5- year volatiity and 1-year momentum
    volatility = np.sqrt(covmat[0,0])
    momentum = np.prod(1+dfsm["s_returns"].tail(12).values) -1

    # annualize the numbers
    prd = 12. # used monthly returns; 12 periods to annualize
    alpha = alpha*prd
    volatility = volatility*np.sqrt(prd)

    print ('Beta : ',beta,'\n Alpha : ',alpha,'\n R_Squared : ', r_squared, '\n Volatility : ', volatility, '\n Momentum : ',momentum)
    return(beta,alpha,r_squared,volatility,momentum)



for loop in range(amorce,len(constituents)):
    try:
        tmps1=time.time()
        global delta,bloc1,bloc2,model_up,model_down
        ticker = (constituents.iloc[loop]['Symbol'])
        name = constituents.iloc[loop]['Name']
        sector = constituents.iloc[loop]['Sector']
        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        yamlup = os.path.join(os.path.dirname(constituents_csv), 'DONNEES_DL/Save_'+ticker+'_up.yaml')
        yamldown = os.path.join(os.path.dirname(constituents_csv), 'DONNEES_DL/Save_'+ticker+'_down.yaml')
        modelup = os.path.join(os.path.dirname(constituents_csv), 'DONNEES_DL/Save_'+ticker+'_up.h5')
        modeldown = os.path.join(os.path.dirname(constituents_csv), 'DONNEES_DL/Save_'+ticker+'_down.h5')

        yaml_file_up = open(yamlup, 'r')
        yaml_file_down = open(yamldown, 'r')
        model_yaml_up = yaml_file_up.read()
        model_yaml_down = yaml_file_down.read()
        yaml_file_up.close()
        yaml_file_down.close()
        model_up = model_from_yaml(model_yaml_up)
        model_down = model_from_yaml(model_yaml_down)
        # load weights into new model
        model_up.load_weights(modelup)
        model_down.load_weights(modeldown)
        tmps2=round(time.time()-tmps1,2)
        print("Models loaded from disk in = %f" %tmps2,'seconds')

        tmps1=time.time()
        print('Scraping data...')

        df = scrap_data(ticker,start,end)

        dfb = web.DataReader('^GSPC','yahoo',start,end)

        beta,alpha, r_squared, volatility, momentum = grobeta(df,dfb)

        tmps2=round(time.time()-tmps1,2)
        print ("executed in = %f" %tmps2,'seconds')

        print('\n')
        print('GOLEM begins Computing...')
        print('\n')
        delta = round(df.shape[0])
        bloc1 = round(delta*0.80)
        bloc2 = delta - bloc1
        print("# of periods : ",delta)
        print('On 80% - 20% slash : ')
        print('Bloc 1 : ',bloc1,'\nBloc 2 :',bloc2,' periods ')
        print('First period :',df.index[0])
        print('Split period :',df.index[bloc1-1])
        print('Last period :',df.index[df.shape[0]-1])
        print('\n')

        print('Data prep')
        df = prepa_data(df)

        print(Fore.BLUE,'Deeping in blue',Style.RESET_ALL)
        print('')
        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        resultats,precision_up,precision_down,scaler = learn(df)

        import sys
        orig_stdout = sys.stdout
        f = open('backtest de '+str(ticker)+'.txt', 'w')
        sys.stdout = f

        ####################
        #### TEST PLOT ####
        ###################

        filtre_up = 93
        filtre_down = 97
        filtre_up_close = 80
        filtre_down_close = 80


        plt.figure(figsize=(26,8),dpi=300)
        #plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
        plt.title('Deep Learning '+name+' Trade Signals')
        plt.plot(resultats['Actual'],color='purple',lw=0.9,label=ticker)

        green=[]
        red=[]
        green_close=[]
        red_close=[]

        for i in range(0,len(resultats)-1):


            if resultats.iloc[i]['Confiance Down'] > filtre_down:
                doob = -1
            elif resultats.iloc[i]['Confiance Down'] > filtre_down_close and resultats.iloc[i]['Confiance Down'] < filtre_down :
                waab = -1
                doob = 0
            elif resultats.iloc[i]['Confiance up'] > filtre_up:
                doob = 1
            elif resultats.iloc[i]['Confiance up'] > filtre_up_close and resultats.iloc[i]['Confiance up'] < filtre_up:
                waab = 1
                doob = 0
            else :
                doob = 0
                waab = 0

            if doob == 1 :#and resultats.iloc[i]['Confiance up'] > filtre_up:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='g',marker='o')
                #doob = -1
                green.append(1)
                red.append(0)
                green_close.append(0)
                red_close.append(1)

            elif doob == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(1)
                green_close.append(1)
                red_close.append(0)

            elif doob == 0 and waab == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(0)
                green_close.append(0)
                red_close.append(1)

            elif waab == 1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(0)
                green_close.append(1)
                red_close.append(0)  

            else:
                green.append(0)
                red.append(0)
                green_close.append(0)
                red_close.append(0)  

                #doob = 0


        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='g',marker='o',label='Buy Signal')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o',label='Sell Signal')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_01.pdf')
        plt.close()


        green.append(0)
        red.append(0)
        green_close.append(0)
        red_close.append(0)
        resultats['Green'] = green
        resultats['Red'] = red
        resultats['Green_Close'] = green_close
        resultats['Red_Close'] = red_close
        #resultats['Actual'] = df['Close'][bloc1:]

        ########################
        ####### BACKTEST########
        ########################
        pos_long = 0
        pos_short = 0
        pactol = 10000/beta
        price_buy = 0
        price_sell = 0
        x = 0
        winners = []
        loosers = []
        nb_win = 0
        nb_los = 0
        mini_pnl = 0
        pos_duration = []
        average_duration = resultats.iloc[0,0] - resultats.iloc[0,0]
        trades = []
        eq_curx = []
        eq_cury = []
        maxdd = []
        nbS = 0
        nbL = 0

        for i in range(0,len(resultats)-1):
            if pos_long == 0 and pos_short == 0 and resultats.iloc[i]['Green'] == 1 :
                pos_long = 1
                nbL+=1
                x = round((10000/beta)/resultats.iloc[i]['Open.S'])
                price_buy = round(resultats.iloc[i]['Open.S'],2)
                time_enter = resultats.iloc[i]['Date']

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 1,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':0}],ignore_index=True)

                print('\n Le ',str(resultats.iloc[i]['Date']),', achat de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',round(pactol,2))
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],1))

            elif pos_long == 1 and resultats.iloc[i]['Green_Close'] == 0 :

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':round((resultats.iloc[i]['Open.S'] - price_buy)*x,2)}],ignore_index=True)
                try:
                    maxdd.append(round((resultats.iloc[i]['Open.S'] - price_buy)*x,2))
                except:
                    print('Null val of maxdd')
                    maxdd.append('Null')


            elif pos_long == 1 and resultats.iloc[i]['Green_Close'] == 1 :
                old_pactol = round(pactol,2)
                eq_curx.append(resultats.iloc[i]['Date'])
                eq_cury.append(old_pactol)
                pos_long = 0
                price_sell = round(resultats.iloc[i]['Open.S'],2)
                mini_pnl = round(x*(price_sell-price_buy),2)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],2))

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 1, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : mini_pnl,\
                                           'Cumulative PNL':round(signals.iloc[:i]['PNL'].sum(),2),'Latent PNL':0}],ignore_index=True)

                pactol = round((pactol + mini_pnl),2)
                print('\n Le ',str(resultats.iloc[i]['Date']),', vente pour close de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)
                print('pnl:', mini_pnl)
                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                pos_duration.append(resultats.iloc[i]['Date'] - time_enter)

                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1


            elif pos_short == 0 and pos_long == 0 and resultats.iloc[i]['Red']:
                pos_short = 1
                nbS+=1
                x = round((10000/beta)/resultats.iloc[i]['Open.S'])
                price_sell = round(resultats.iloc[i]['Open.S'],2)
                time_enter = resultats.iloc[i]['Date']

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 1, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

                print('\n Le ',str(resultats.iloc[i]['Date']),', vente de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],-1))


            elif pos_short == 1 and resultats.iloc[i]['Red_Close'] == 0 :

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':-round((resultats.iloc[i]['Open.S'] - price_sell)*x,2)}],ignore_index=True)
                try:
                    maxdd.append(round((resultats.iloc[i]['Open.S'] - price_sell)*x,2))
                except:
                    print('Null val of maxdd')
                    maxdd.append(0)

            elif pos_short == 1 and resultats.iloc[i]['Red_Close'] == 1 :
                old_pactol = round(pactol,2)
                eq_curx.append(resultats.iloc[i]['Date'])
                eq_cury.append(old_pactol)
                pos_short = 0
                price_buy = round(resultats.iloc[i]['Open.S'],2)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],-2))
                mini_pnl = round(x*(price_sell-price_buy),2)

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 1,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : mini_pnl,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

                pactol = round((pactol + mini_pnl),2)
                print('\n Le ',str(resultats.iloc[i]['Date']),', achat pour close de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)

                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                print('pnl:', mini_pnl)
                pos_duration.append(resultats.iloc[i]['Date'] - time_enter)
                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1
            else:

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                               'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                               'Buy/Sell Price' : 0, 'Quantity' : 0, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

        if pos_long == 1:
            pos_long = 0
            print('Cutting non resolved position')
            print(' Le price buy était de : ',price_buy)
            x = round((10000/beta)/resultats.iloc[i]['Open.S'])
            print('x = ',x)
            price_sell = round(resultats.iloc[i]['Open.S'],2)
            print('Et le price sell : ',price_sell)
            mini_pnl = round(x*(price_sell-price_buy),2)

            signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 1, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : mini_pnl,\
                                       'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

            pactol = round((pactol + mini_pnl),2)
            print('pnl : ',mini_pnl)
            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1


        if pos_short == 1:
            pos_short = 0
            print('Cutting non resolved position')
            print(' Le price sell était de : ',price_sell)
            x = round((10000/beta)/resultats.iloc[i]['Open.S'])
            print('x = ',x)
            price_buy = round(resultats.iloc[i]['Open.S'],2)
            print('Et le price_buy : ',price_buy)
            mini_pnl = round(x*(price_sell-price_buy),2)

            signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 1,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : 0,\
                                       'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':mini_pnl}],ignore_index=True)

            pactol = round((pactol + mini_pnl),2)
            print('pnl : ',mini_pnl)

            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1


        pnl = round(pactol - (10000/beta),2)
        print('\n Begining of BackTest :',resultats.iloc[0]['Date'])
        print('Instrument :',ticker)
        print('Face value per trade : $',10000/beta)
        print('End of BackTest :',resultats.iloc[-1]['Date'])
        duration = pd.to_timedelta((resultats.iloc[-1]['Date'] - resultats.iloc[0]['Date']),unit='d')
        print("BackTest's period :",duration)
        print('Pnl :',round(pnl,2),'$')
        print('% Pnl : ',round(pnl/(10000/beta)*100,2))
        print('Total winners :',round(sum(winners),2),'$')
        print('Total loosers :',round(sum(loosers),2),'$')
        print('Number of winners :',round(nb_win))
        print('Number of loosers :',round(nb_los))
        print('Maximum Drawdown : ',round(min(maxdd),2))
        print('% Max Drawdown : ',round(min(maxdd)/(10000/beta)*100,2),'%')
        print('Nombre toatl de trades : ',round(nbL+nbS,2))
        print('% de trades Long : ',round((nbL*100)/(nbL+nbS),2))
        print('% de trades Short : ',round((nbS*100)/(nbL+nbS),2))
        try:
            print('% winners :', round((nb_win/(nb_win+nb_los) * 100),2),'%')
            print('Average winners :',(round(sum(winners)/(nb_win))))
        except:
            print('% winners : null')
        try:
            print('Average losers :',(round(sum(loosers)/(nb_los))))
        except:
            print('Average losers : Inf')
        try:
            for t in range(0,len(pos_duration)):
                average_duration = pd.to_timedelta((average_duration + pos_duration[t]),unit='d')
            average_duration = average_duration/(nb_los+nb_win)
            print('Average Duration :', average_duration)
        except:
            print('No Average Duration available')
        try:
            print('Profit Factor : ',abs(round((sum(winners)/sum(loosers)),2)))
        except:
            print('Profit Factor : null')

        ########################
        ##### PLOT TRADES ######
        ########################

        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Trades')
        plt.plot(resultats['Open.S'],color='blue',lw=0.9)
        for i in range(0,len(trades)):
            if trades[i][2] == 1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='green',marker='^',lw=2.5)
            elif trades[i][2] == -1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='red',marker='^',lw=2.5)
            elif trades[i][2] == 2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='g',marker='x',lw=2.5)
            elif trades[i][2] == -2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='r',marker='x',lw=2.5)

        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='g',marker='^',label='Open Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='r',marker='^',label='Open Short')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='g',marker='x',label='Close Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='r',marker='x',label='Close Short')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_02.pdf')
        plt.close()

        #########################
        ##### PLOT E-CURVE ######
        #########################
        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Equity Curve')
        plt.plot(eq_curx,eq_cury)
        plt.scatter(x=eq_curx,y=eq_cury,c='orange',marker='o',lw=2.5)
        plt.savefig('backtest de '+str(ticker)+'_03.pdf')
        plt.close()


        f.close()
        sys.stdout = orig_stdout

        print('\r Boucle ', loop, 'terminée...',end='')
        print('Opération restantes :', len(constituents)-loop,'/',len(constituents),'\n')

        if nb_los == 0:
            nb_los = 0.0001
        if nb_win == 0:
            nb_win = 0.0001

        backtest = backtest.append([{'Symb.':ticker,'Name':name,'Sector':sector,'Period':duration,'Begin.':resultats.iloc[0,0],'End':resultats.iloc[-1,0],\
                          'Pnl $':pnl,'Pnl %':round(pnl/(10000/beta)*100,2),'Gross Profit':round(sum(winners),2),'Gross Loss':round(sum(loosers),2),'# Winners':nb_win,'# Loosers':nb_los,\
                          '% Winners':round((nb_win/(nb_win+nb_los) * 100),2),'MaxDD $':round(min(maxdd),2),'MaxDD %':round(min(maxdd)/(10000/beta)*100,2),'Aver. Win $':(round(sum(winners)/(nb_win))),\
                          'Aver. Loos $':(round(sum(loosers)/(nb_los))),'Aver. Duration':average_duration,\
                          'Total Trades':nbL+nbS,'% Long':round((nbL*100)/(nbL+nbS),2),'% Short':round((nbS*100)/(nbL+nbS),2), 'Profit Factor':abs(round((sum(winners)/sum(loosers)),2))}], ignore_index=True)


    # symbol / name / sector / period of backtest / debut / fin / pnl / total winners / total loosers / Nb winners / nb loosers / 
    # / % winners / Max DD / Aver Win / Aver Loos / Average duration / Profit Factor
        print(Fore.YELLOW,'Writing BACKTEST CSV AND SIGNALS.CSV',Style.RESET_ALL)
        backtest.to_csv('BackTest.csv')
        signals.to_csv('SIGNALS.csv')

        print(Fore.CYAN,'BACKTEST CSV WRITED AND SIGNALS.CSV',Style.RESET_ALL)

        
    except:
        print(Fore.RED,Back.GREEN,'Il y a un problème en loop ',loop,', avec le ticker ',ticker,'absent de la base.',Style.RESET_ALL)
        continue
# Out:
# Importing Librairies...
# Using TensorFlow backend.
# Librairies imported
#
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
#   BOOST BACKTEST SPN500 55 Version v1.45
#
# Sraping tickers
# Scrap -----> ok
#  --- Loop : 310  ---  --- Symbol :   MCHP   ---  --- Name :  Microchip Technology  ---  --- Sector :  Information Technology  ---
# Models loaded from disk in = 0.250000 seconds
# Scraping data...
# Beta :  1.3711785098833336
#  Alpha :  0.0915374559753084
#  R_Squared :  0.35277501068768446
#  Volatility :  0.2883165801591984
#  Momentum :  0.06967434864155897
# executed in = 5.380000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:29:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.110000 seconds
#  Deeping in blue
#
#  --- Loop : 310  ---  --- Symbol :   MCHP   ---  --- Name :  Microchip Technology  ---  --- Sector :  Information Technology  ---
#
#
#  RESULTATS UP
#
# Accuracy: 48.77%
#  Precision: 46.10%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.09      0.16        91
#            1       0.46      1.00      0.63        71
#
#    micro avg       0.49      0.49      0.49       162
#    macro avg       0.73      0.54      0.40       162
# weighted avg       0.76      0.49      0.37       162
#
# [[ 8 83]
#  [ 0 71]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 51.85%
#  Precision: 100.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 7.14%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67        78
#            1       1.00      0.07      0.13        84
#
#    micro avg       0.52      0.52      0.52       162
#    macro avg       0.75      0.54      0.40       162
# weighted avg       0.76      0.52      0.39       162
#
# [[78  0]
#  [78  6]]
#
#
# Deep Learning executed in = 0.100000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Boucle  310 terminée...Opération restantes : 195 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 311  ---  --- Symbol :   MU   ---  --- Name :  Micron Technology  ---  --- Sector :  Information Technology  ---
# Models loaded from disk in = 0.210000 seconds
# Scraping data...
# Beta :  1.8244994277274933
#  Alpha :  0.11294088497363858
#  R_Squared :  0.29770203637651105
#  Volatility :  0.41761621757551
#  Momentum :  -0.18830920227432058
# executed in = 1.870000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:29:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.090000 seconds
#  Deeping in blue
#
#  --- Loop : 311  ---  --- Symbol :   MU   ---  --- Name :  Micron Technology  ---  --- Sector :  Information Technology  ---
#
#
#  RESULTATS UP
#
# Accuracy: 70.37%
#  Precision: 60.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 88.24%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.87      0.57      0.69        94
#            1       0.60      0.88      0.71        68
#
#    micro avg       0.70      0.70      0.70       162
#    macro avg       0.74      0.73      0.70       162
# weighted avg       0.76      0.70      0.70       162
#
# [[54 40]
#  [ 8 60]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 84.57%
#  Precision: 83.52%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 88.37%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83        76
#            1       0.84      0.88      0.86        86
#
#    micro avg       0.85      0.85      0.85       162
#    macro avg       0.85      0.84      0.84       162
# weighted avg       0.85      0.85      0.85       162
#
# [[61 15]
#  [10 76]]
#
#
# Deep Learning executed in = 0.060000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64, float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Boucle  311 terminée...Opération restantes : 194 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 312  ---  --- Symbol :   MSFT   ---  --- Name :  Microsoft Corp.  ---  --- Sector :  Information Technology  ---
# Models loaded from disk in = 0.210000 seconds
# Scraping data...
# Beta :  1.118249158024655
#  Alpha :  0.21324351360872032
#  R_Squared :  0.53818133408871
#  Volatility :  0.19037012329002306
#  Momentum :  0.25170725576135244
# executed in = 1.870000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:29:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.970000 seconds
#  Deeping in blue
#
#  --- Loop : 312  ---  --- Symbol :   MSFT   ---  --- Name :  Microsoft Corp.  ---  --- Sector :  Information Technology  ---
#
#
#  RESULTATS UP
#
# Accuracy: 50.62%
#  Precision: 100.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 4.76%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.49      1.00      0.66        78
#            1       1.00      0.05      0.09        84
#
#    micro avg       0.51      0.51      0.51       162
#    macro avg       0.75      0.52      0.38       162
# weighted avg       0.76      0.51      0.37       162
#
# [[78  0]
#  [80  4]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 42.59%
#  Precision: 40.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.07      0.13       100
#            1       0.40      1.00      0.57        62
#
#    micro avg       0.43      0.43      0.43       162
#    macro avg       0.70      0.54      0.35       162
# weighted avg       0.77      0.43      0.30       162
#
# [[ 7 93]
#  [ 0 62]]
#
#
# Deep Learning executed in = 0.070000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Boucle  312 terminée...Opération restantes : 193 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 313  ---  --- Symbol :   MAA   ---  --- Name :  Mid-America Apartments  ---  --- Sector :  Real Estate  ---
# Models loaded from disk in = 0.270000 seconds
# Scraping data...
# Beta :  0.4534629807075696
#  Alpha :  0.1359082213362997
#  R_Squared :  0.11098320701935616
#  Volatility :  0.1699956193388927
#  Momentum :  0.2323337601187765
# executed in = 1.860000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:29:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.190000 seconds
#  Deeping in blue
#
#  --- Loop : 313  ---  --- Symbol :   MAA   ---  --- Name :  Mid-America Apartments  ---  --- Sector :  Real Estate  ---
#
#
#  RESULTATS UP
#
# Accuracy: 57.41%
#  Precision: 90.91%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 22.99%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.52      0.97      0.68        75
#            1       0.91      0.23      0.37        87
#
#    micro avg       0.57      0.57      0.57       162
#    macro avg       0.72      0.60      0.52       162
# weighted avg       0.73      0.57      0.51       162
#
# [[73  2]
#  [67 20]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 51.23%
#  Precision: 42.65%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 98.31%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.96      0.24      0.39       103
#            1       0.43      0.98      0.59        59
#
#    micro avg       0.51      0.51      0.51       162
#    macro avg       0.69      0.61      0.49       162
# weighted avg       0.77      0.51      0.46       162
#
# [[25 78]
#  [ 1 58]]
#
#
# Deep Learning executed in = 0.080000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Boucle  313 terminée...Opération restantes : 192 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 314  ---  --- Symbol :   MHK   ---  --- Name :  Mohawk Industries  ---  --- Sector :  Consumer Discretionary  ---
# Models loaded from disk in = 0.250000 seconds
# Scraping data...
# Beta :  1.359187794334062
#  Alpha :  -0.20259654380075998
#  R_Squared :  0.39601911772012344
#  Volatility :  0.2697403500098566
#  Momentum :  -0.3843102388475602
# executed in = 1.910000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:29:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.050000 seconds
#  Deeping in blue
#
#  --- Loop : 314  ---  --- Symbol :   MHK   ---  --- Name :  Mohawk Industries  ---  --- Sector :  Consumer Discretionary  ---
#
#
#  RESULTATS UP
#
# Accuracy: 61.73%
#  Precision: 56.57%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 74.67%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.70      0.51      0.59        87
#            1       0.57      0.75      0.64        75
#
#    micro avg       0.62      0.62      0.62       162
#    macro avg       0.63      0.63      0.62       162
# weighted avg       0.64      0.62      0.61       162
#
# [[44 43]
#  [19 56]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 58.02%
#  Precision: 51.79%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.56%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.72      0.40      0.51        90
#            1       0.52      0.81      0.63        72
#
#    micro avg       0.58      0.58      0.58       162
#    macro avg       0.62      0.60      0.57       162
# weighted avg       0.63      0.58      0.57       162
#
# [[36 54]
#  [14 58]]
#
#
# Deep Learning executed in = 0.080000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64, float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Boucle  314 terminée...Opération restantes : 191 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 315  ---  --- Symbol :   TAP   ---  --- Name :  Molson Coors Brewing Company  ---  --- Sector :  Consumer Staples  ---
# Models loaded from disk in = 0.270000 seconds
# Scraping data...
# Beta :  0.8006439133065144
#  Alpha :  -0.09101371088086298
#  R_Squared :  0.15802065936375853
#  Volatility :  0.25153996627530884
#  Momentum :  -0.1937659435650303
# executed in = 2.170000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:30:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.930000 seconds
#  Deeping in blue
#
#  --- Loop : 315  ---  --- Symbol :   TAP   ---  --- Name :  Molson Coors Brewing Company  ---  --- Sector :  Consumer Staples  ---
#
#
#  RESULTATS UP
#
# Accuracy: 76.54%
#  Precision: 76.32%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 74.36%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.77      0.79      0.78        84
#            1       0.76      0.74      0.75        78
#
#    micro avg       0.77      0.77      0.77       162
#    macro avg       0.77      0.76      0.76       162
# weighted avg       0.77      0.77      0.77       162
#
# [[66 18]
#  [20 58]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 81.48%
#  Precision: 75.34%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 82.09%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84        95
#            1       0.75      0.82      0.79        67
#
#    micro avg       0.81      0.81      0.81       162
#    macro avg       0.81      0.82      0.81       162
# weighted avg       0.82      0.81      0.82       162
#
# [[77 18]
#  [12 55]]
#
#
# Deep Learning executed in = 0.090000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Boucle  315 terminée...Opération restantes : 190 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 316  ---  --- Symbol :   MDLZ   ---  --- Name :  Mondelez International  ---  --- Sector :  Consumer Staples  ---
# Models loaded from disk in = 0.250000 seconds
# Scraping data...
# Beta :  0.7642959827417406
#  Alpha :  0.03295077320453478
#  R_Squared :  0.28371657143923745
#  Volatility :  0.17920237129070266
#  Momentum :  0.31562205710796265
# executed in = 1.890000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:30:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.260000 seconds
#  Deeping in blue
#
#  --- Loop : 316  ---  --- Symbol :   MDLZ   ---  --- Name :  Mondelez International  ---  --- Sector :  Consumer Staples  ---
#
#
#  RESULTATS UP
#
# Accuracy: 52.47%
#  Precision: 75.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 10.84%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.51      0.96      0.66        79
#            1       0.75      0.11      0.19        83
#
#    micro avg       0.52      0.52      0.52       162
#    macro avg       0.63      0.54      0.43       162
# weighted avg       0.63      0.52      0.42       162
#
# [[76  3]
#  [74  9]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 46.91%
#  Precision: 44.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 97.06%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.83      0.11      0.19        94
#            1       0.44      0.97      0.61        68
#
#    micro avg       0.47      0.47      0.47       162
#    macro avg       0.64      0.54      0.40       162
# weighted avg       0.67      0.47      0.36       162
#
# [[10 84]
#  [ 2 66]]
#
#
# Deep Learning executed in = 0.100000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Boucle  316 terminée...Opération restantes : 189 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 317  ---  --- Symbol :   MON   ---  --- Name :  Monsanto Co.  ---  --- Sector :  Materials  ---
#   Il y a un problème en loop  317 , avec le ticker  MON absent de la base.
#  --- Loop : 318  ---  --- Symbol :   MNST   ---  --- Name :  Monster Beverage  ---  --- Sector :  Consumer Staples  ---
# Models loaded from disk in = 0.290000 seconds
# Scraping data...
# Beta :  1.1347480179459244
#  Alpha :  0.010979274431237064
#  R_Squared :  0.26752380064492254
#  Volatility :  0.2739950688260739
#  Momentum :  0.02118576003380035
# executed in = 2.160000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:30:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.410000 seconds
#  Deeping in blue
#
#  --- Loop : 318  ---  --- Symbol :   MNST   ---  --- Name :  Monster Beverage  ---  --- Sector :  Consumer Staples  ---
#
#
#  RESULTATS UP
#
# Accuracy: 48.15%
#  Precision: 43.24%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.14      0.25        98
#            1       0.43      1.00      0.60        64
#
#    micro avg       0.48      0.48      0.48       162
#    macro avg       0.72      0.57      0.43       162
# weighted avg       0.78      0.48      0.39       162
#
# [[14 84]
#  [ 0 64]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 51.85%
#  Precision: 88.24%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 16.48%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.48      0.97      0.64        71
#            1       0.88      0.16      0.28        91
#
#    micro avg       0.52      0.52      0.52       162
#    macro avg       0.68      0.57      0.46       162
# weighted avg       0.70      0.52      0.44       162
#
# [[69  2]
#  [76 15]]
#
#
# Deep Learning executed in = 0.110000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Boucle  318 terminée...Opération restantes : 187 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 319  ---  --- Symbol :   MCO   ---  --- Name :  Moody's Corp  ---  --- Sector :  Financials  ---
# Models loaded from disk in = 0.280000 seconds
# Scraping data...
# Beta :  1.2864234885084178
#  Alpha :  0.08401398960661438
#  R_Squared :  0.5241600253956857
#  Volatility :  0.22190982940098244
#  Momentum :  0.21612162096273058
# executed in = 2.080000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:30:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.400000 seconds
#  Deeping in blue
#
#  --- Loop : 319  ---  --- Symbol :   MCO   ---  --- Name :  Moody's Corp  ---  --- Sector :  Financials  ---
#
#
#  RESULTATS UP
#
# Accuracy: 43.83%
#  Precision: 100.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 5.21%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.42      1.00      0.59        66
#            1       1.00      0.05      0.10        96
#
#    micro avg       0.44      0.44      0.44       162
#    macro avg       0.71      0.53      0.35       162
# weighted avg       0.76      0.44      0.30       162
#
# [[66  0]
#  [91  5]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 35.19%
#  Precision: 33.12%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.05      0.09       110
#            1       0.33      1.00      0.50        52
#
#    micro avg       0.35      0.35      0.35       162
#    macro avg       0.67      0.52      0.29       162
# weighted avg       0.79      0.35      0.22       162
#
# [[  5 105]
#  [  0  52]]
#
#
# Deep Learning executed in = 0.110000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Boucle  319 terminée...Opération restantes : 186 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 320  ---  --- Symbol :   MS   ---  --- Name :  Morgan Stanley  ---  --- Sector :  Financials  ---
# Models loaded from disk in = 0.330000 seconds
# Scraping data...
# Beta :  1.3657256383071046
#  Alpha :  -0.05523053883477623
#  R_Squared :  0.4196748321042352
#  Volatility :  0.2632882794396283
#  Momentum :  -0.13083463128159867
# executed in = 2.170000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:30:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.860000 seconds
#  Deeping in blue
#
#  --- Loop : 320  ---  --- Symbol :   MS   ---  --- Name :  Morgan Stanley  ---  --- Sector :  Financials  ---
#
#
#  RESULTATS UP
#
# Accuracy: 56.17%
#  Precision: 0.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 0.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.56      1.00      0.72        91
#            1       0.00      0.00      0.00        71
#
#    micro avg       0.56      0.56      0.56       162
#    macro avg       0.28      0.50      0.36       162
# weighted avg       0.32      0.56      0.40       162
#
# [[91  0]
#  [71  0]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 45.68%
#  Precision: 45.34%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.01      0.02        89
#            1       0.45      1.00      0.62        73
#
#    micro avg       0.46      0.46      0.46       162
#    macro avg       0.73      0.51      0.32       162
# weighted avg       0.75      0.46      0.29       162
#
# [[ 1 88]
#  [ 0 73]]
#
#
# Deep Learning executed in = 0.120000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#  Boucle  320 terminée...Opération restantes : 185 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 321  ---  --- Symbol :   MSI   ---  --- Name :  Motorola Solutions Inc.  ---  --- Sector :  Information Technology  ---
# Models loaded from disk in = 0.310000 seconds
# Scraping data...
# Beta :  0.5218090451557108
#  Alpha :  0.26887295045579596
#  R_Squared :  0.09624097762139017
#  Volatility :  0.21006616975565776
#  Momentum :  0.41764069839988593
# executed in = 1.980000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:30:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.320000 seconds
#  Deeping in blue
#
#  --- Loop : 321  ---  --- Symbol :   MSI   ---  --- Name :  Motorola Solutions Inc.  ---  --- Sector :  Information Technology  ---
#
#
#  RESULTATS UP
#
# Accuracy: 64.20%
#  Precision: 83.33%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 40.70%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.57      0.91      0.70        76
#            1       0.83      0.41      0.55        86
#
#    micro avg       0.64      0.64      0.64       162
#    macro avg       0.70      0.66      0.63       162
# weighted avg       0.71      0.64      0.62       162
#
# [[69  7]
#  [51 35]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 66.67%
#  Precision: 53.68%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 83.61%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.85      0.56      0.68       101
#            1       0.54      0.84      0.65        61
#
#    micro avg       0.67      0.67      0.67       162
#    macro avg       0.69      0.70      0.67       162
# weighted avg       0.73      0.67      0.67       162
#
# [[57 44]
#  [10 51]]
#
#
# Deep Learning executed in = 0.130000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Boucle  321 terminée...Opération restantes : 184 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 322  ---  --- Symbol :   MYL   ---  --- Name :  Mylan N.V.  ---  --- Sector :  Health Care  ---
# Models loaded from disk in = 0.340000 seconds
# Scraping data...
# Beta :  1.7912321218872285
#  Alpha :  -0.3936033611449598
#  R_Squared :  0.3683985377256994
#  Volatility :  0.36856784785882246
#  Momentum :  -0.5121390331843557
# executed in = 1.840000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:30:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.090000 seconds
#  Deeping in blue
#
#  --- Loop : 322  ---  --- Symbol :   MYL   ---  --- Name :  Mylan N.V.  ---  --- Sector :  Health Care  ---
#
#
#  RESULTATS UP
#
# Accuracy: 76.54%
#  Precision: 85.87%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 75.96%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.64      0.78      0.70        58
#            1       0.86      0.76      0.81       104
#
#    micro avg       0.77      0.77      0.77       162
#    macro avg       0.75      0.77      0.75       162
# weighted avg       0.78      0.77      0.77       162
#
# [[45 13]
#  [25 79]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 72.84%
#  Precision: 59.18%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 54.72%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.80       109
#            1       0.59      0.55      0.57        53
#
#    micro avg       0.73      0.73      0.73       162
#    macro avg       0.69      0.68      0.69       162
# weighted avg       0.72      0.73      0.73       162
#
# [[89 20]
#  [24 29]]
#
#
# Deep Learning executed in = 0.140000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64, float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Boucle  322 terminée...Opération restantes : 183 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 323  ---  --- Symbol :   NDAQ   ---  --- Name :  Nasdaq, Inc.  ---  --- Sector :  Financials  ---
# Models loaded from disk in = 0.350000 seconds
# Scraping data...
# Beta :  0.5801927268412466
#  Alpha :  0.14674840701686484
#  R_Squared :  0.1996370443081139
#  Volatility :  0.16217213766592706
#  Momentum :  0.05032906540531723
# executed in = 2.180000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:31:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.940000 seconds
#  Deeping in blue
#
#  --- Loop : 323  ---  --- Symbol :   NDAQ   ---  --- Name :  Nasdaq, Inc.  ---  --- Sector :  Financials  ---
#
#
#  RESULTATS UP
#
# Accuracy: 69.75%
#  Precision: 96.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 33.33%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.65      0.99      0.78        90
#            1       0.96      0.33      0.49        72
#
#    micro avg       0.70      0.70      0.70       162
#    macro avg       0.80      0.66      0.64       162
# weighted avg       0.79      0.70      0.66       162
#
# [[89  1]
#  [48 24]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 78.40%
#  Precision: 71.91%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 86.49%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.72      0.78        88
#            1       0.72      0.86      0.79        74
#
#    micro avg       0.78      0.78      0.78       162
#    macro avg       0.79      0.79      0.78       162
# weighted avg       0.80      0.78      0.78       162
#
# [[63 25]
#  [10 64]]
#
#
# Deep Learning executed in = 0.140000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Boucle  323 terminée...Opération restantes : 182 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 324  ---  --- Symbol :   NOV   ---  --- Name :  National Oilwell Varco Inc.  ---  --- Sector :  Energy  ---
# Models loaded from disk in = 0.340000 seconds
# Scraping data...
# Beta :  1.3099558622370862
#  Alpha :  -0.2581986867651797
#  R_Squared :  0.2687576978548809
#  Volatility :  0.31557365025806006
#  Momentum :  -0.554153399805358
# executed in = 1.810000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:31:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.700000 seconds
#  Deeping in blue
#
#  --- Loop : 324  ---  --- Symbol :   NOV   ---  --- Name :  National Oilwell Varco Inc.  ---  --- Sector :  Energy  ---
#
#
#  RESULTATS UP
#
# Accuracy: 74.69%
#  Precision: 62.03%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 81.67%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.87      0.71      0.78       102
#            1       0.62      0.82      0.71        60
#
#    micro avg       0.75      0.75      0.75       162
#    macro avg       0.74      0.76      0.74       162
# weighted avg       0.78      0.75      0.75       162
#
# [[72 30]
#  [11 49]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 71.60%
#  Precision: 86.96%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 61.86%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.60      0.86      0.71        65
#            1       0.87      0.62      0.72        97
#
#    micro avg       0.72      0.72      0.72       162
#    macro avg       0.74      0.74      0.72       162
# weighted avg       0.76      0.72      0.72       162
#
# [[56  9]
#  [37 60]]
#
#
# Deep Learning executed in = 0.150000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Boucle  324 terminée...Opération restantes : 181 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 325  ---  --- Symbol :   NAVI   ---  --- Name :  Navient  ---  --- Sector :  Financials  ---
# Models loaded from disk in = 0.370000 seconds
# Scraping data...
# Beta :  2.151330524595276
#  Alpha :  -0.13978440294149874
#  R_Squared :  0.4142723460187262
#  Volatility :  0.4174348408325002
#  Momentum :  0.05364752746148538
# executed in = 2.050000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:31:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.110000 seconds
#  Deeping in blue
#
#  --- Loop : 325  ---  --- Symbol :   NAVI   ---  --- Name :  Navient  ---  --- Sector :  Financials  ---
#
#
#  RESULTATS UP
#
# Accuracy: 61.73%
#  Precision: 83.87%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 31.33%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.56      0.94      0.70        79
#            1       0.84      0.31      0.46        83
#
#    micro avg       0.62      0.62      0.62       162
#    macro avg       0.70      0.62      0.58       162
# weighted avg       0.71      0.62      0.58       162
#
# [[74  5]
#  [57 26]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 54.32%
#  Precision: 47.37%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 94.03%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.26      0.40        95
#            1       0.47      0.94      0.63        67
#
#    micro avg       0.54      0.54      0.54       162
#    macro avg       0.67      0.60      0.52       162
# weighted avg       0.70      0.54      0.50       162
#
# [[25 70]
#  [ 4 63]]
#
#
# Deep Learning executed in = 0.160000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Boucle  325 terminée...Opération restantes : 180 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 326  ---  --- Symbol :   NKTR   ---  --- Name :  Nektar Therapeutics  ---  --- Sector :  Health Care  ---
# Models loaded from disk in = 0.390000 seconds
# Scraping data...
# Beta :  2.6185199319429646
#  Alpha :  0.2858728776895517
#  R_Squared :  0.12790356905795364
#  Volatility :  0.9144060254757
#  Momentum :  -0.5552714596951891
# executed in = 1.950000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:31:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.220000 seconds
#  Deeping in blue
#
#  --- Loop : 326  ---  --- Symbol :   NKTR   ---  --- Name :  Nektar Therapeutics  ---  --- Sector :  Health Care  ---
#
#
#  RESULTATS UP
#
# Accuracy: 74.69%
#  Precision: 68.82%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 84.21%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.83      0.66      0.74        86
#            1       0.69      0.84      0.76        76
#
#    micro avg       0.75      0.75      0.75       162
#    macro avg       0.76      0.75      0.75       162
# weighted avg       0.76      0.75      0.75       162
#
# [[57 29]
#  [12 64]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 70.99%
#  Precision: 96.55%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 37.84%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.65      0.99      0.79        88
#            1       0.97      0.38      0.54        74
#
#    micro avg       0.71      0.71      0.71       162
#    macro avg       0.81      0.68      0.67       162
# weighted avg       0.80      0.71      0.68       162
#
# [[87  1]
#  [46 28]]
#
#
# Deep Learning executed in = 0.180000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64, float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Boucle  326 terminée...Opération restantes : 179 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 327  ---  --- Symbol :   NTAP   ---  --- Name :  NetApp  ---  --- Sector :  Information Technology  ---
# Models loaded from disk in = 0.400000 seconds
# Scraping data...
# Beta :  1.5451634265122587
#  Alpha :  0.04466341763503306
#  R_Squared :  0.2733383288878476
#  Volatility :  0.3691039384760738
#  Momentum :  -0.4362231064385287
# executed in = 4.870000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:31:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.700000 seconds
#  Deeping in blue
#
#  --- Loop : 327  ---  --- Symbol :   NTAP   ---  --- Name :  NetApp  ---  --- Sector :  Information Technology  ---
#
#
#  RESULTATS UP
#
# Accuracy: 70.99%
#  Precision: 93.55%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 39.19%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.66      0.98      0.79        88
#            1       0.94      0.39      0.55        74
#
#    micro avg       0.71      0.71      0.71       162
#    macro avg       0.80      0.68      0.67       162
# weighted avg       0.78      0.71      0.68       162
#
# [[86  2]
#  [45 29]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 75.93%
#  Precision: 95.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 50.67%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.70      0.98      0.81        87
#            1       0.95      0.51      0.66        75
#
#    micro avg       0.76      0.76      0.76       162
#    macro avg       0.82      0.74      0.74       162
# weighted avg       0.81      0.76      0.74       162
#
# [[85  2]
#  [37 38]]
#
#
# Deep Learning executed in = 0.170000 seconds
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  Boucle  327 terminée...Opération restantes : 178 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 328  ---  --- Symbol :   NFLX   ---  --- Name :  Netflix Inc.  ---  --- Sector :  Information Technology  ---
# Models loaded from disk in = 0.400000 seconds
# Scraping data...
# Beta :  1.4516049754772742
#  Alpha :  0.23740361533972618
#  R_Squared :  0.19617093421120146
#  Volatility :  0.4093131003244825
#  Momentum :  -0.1408289812085486
# executed in = 1.790000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [05:31:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.470000 seconds
#  Deeping in blue
#
#  --- Loop : 328  ---  --- Symbol :   NFLX   ---  --- Name :  Netflix Inc.  ---  --- Sector :  Information Technology  ---
#
#
#  RESULTATS UP
#
# Accuracy: 50.00%
#  Precision: 46.71%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.11      0.20        91
#            1       0.47      1.00      0.64        71
#
#    micro avg       0.50      0.50      0.50       162
#    macro avg       0.73      0.55      0.42       162
# weighted avg       0.77      0.50      0.39       162
#
# [[10 81]
#  [ 0 71]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 53.09%
#  Precision: 100.00%    => Discrimnination des vrais positifs parmi les faux positifs
# ...
#  Boucle  497 terminée...Opération restantes : 8 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 498  ---  --- Symbol :   XLNX   ---  --- Name :  Xilinx Inc  ---  --- Sector :  Information Technology  ---
# Models loaded from disk in = 2.550000 seconds
# Scraping data...
# Beta :  1.1455729381858688
#  Alpha :  0.1732989217836204
#  R_Squared :  0.2616512037161616
#  Volatility :  0.27969577366719317
#  Momentum :  0.43142417426352253
# executed in = 2.000000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [06:03:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.720000 seconds
#  Deeping in blue
#
#  --- Loop : 498  ---  --- Symbol :   XLNX   ---  --- Name :  Xilinx Inc  ---  --- Sector :  Information Technology  ---
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  RESULTATS UP
#
# Accuracy: 52.47%
#  Precision: 100.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 1.28%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.52      1.00      0.69        84
#            1       1.00      0.01      0.03        78
#
#    micro avg       0.52      0.52      0.52       162
#    macro avg       0.76      0.51      0.36       162
# weighted avg       0.75      0.52      0.37       162
#
# [[84  0]
#  [77  1]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 46.30%
#  Precision: 45.96%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.01      0.02        88
#            1       0.46      1.00      0.63        74
#
#    micro avg       0.46      0.46      0.46       162
#    macro avg       0.73      0.51      0.33       162
# weighted avg       0.75      0.46      0.30       162
#
# [[ 1 87]
#  [ 0 74]]
#
#
# Deep Learning executed in = 1.470000 seconds
#  Boucle  498 terminée...Opération restantes : 7 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 499  ---  --- Symbol :   XL   ---  --- Name :  XL Capital  ---  --- Sector :  Financials  ---
#   Il y a un problème en loop  499 , avec le ticker  XL absent de la base.
#  --- Loop : 500  ---  --- Symbol :   XYL   ---  --- Name :  Xylem Inc.  ---  --- Sector :  Industrials  ---
# Models loaded from disk in = 2.580000 seconds
# Scraping data...
# Beta :  1.1638696829285098
#  Alpha :  0.1062646000552397
#  R_Squared :  0.438144470037203
#  Volatility :  0.21959387126511465
#  Momentum :  0.02710649529802578
# executed in = 1.940000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [06:03:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.100000 seconds
#  Deeping in blue
#
#  --- Loop : 500  ---  --- Symbol :   XYL   ---  --- Name :  Xylem Inc.  ---  --- Sector :  Industrials  ---
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  RESULTATS UP
#
# Accuracy: 69.14%
#  Precision: 50.50%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.55      0.71       111
#            1       0.50      1.00      0.67        51
#
#    micro avg       0.69      0.69      0.69       162
#    macro avg       0.75      0.77      0.69       162
# weighted avg       0.84      0.69      0.70       162
#
# [[61 50]
#  [ 0 51]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 59.26%
#  Precision: 100.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 36.54%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.47      1.00      0.64        58
#            1       1.00      0.37      0.54       104
#
#    micro avg       0.59      0.59      0.59       162
#    macro avg       0.73      0.68      0.59       162
# weighted avg       0.81      0.59      0.57       162
#
# [[58  0]
#  [66 38]]
#
#
# Deep Learning executed in = 1.450000 seconds
#  Boucle  500 terminée...Opération restantes : 5 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 501  ---  --- Symbol :   YUM   ---  --- Name :  Yum! Brands Inc  ---  --- Sector :  Consumer Discretionary  ---
# Models loaded from disk in = 2.600000 seconds
# Scraping data...
# Beta :  0.41380337672167783
#  Alpha :  0.14009389749111334
#  R_Squared :  0.09976315032223415
#  Volatility :  0.16361890415779917
#  Momentum :  0.3676082812276966
# executed in = 1.650000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [06:03:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.300000 seconds
#  Deeping in blue
#
#  --- Loop : 501  ---  --- Symbol :   YUM   ---  --- Name :  Yum! Brands Inc  ---  --- Sector :  Consumer Discretionary  ---
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  RESULTATS UP
#
# Accuracy: 75.31%
#  Precision: 73.26%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 78.75%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.78      0.72      0.75        82
#            1       0.73      0.79      0.76        80
#
#    micro avg       0.75      0.75      0.75       162
#    macro avg       0.75      0.75      0.75       162
# weighted avg       0.75      0.75      0.75       162
#
# [[59 23]
#  [17 63]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 47.53%
#  Precision: 40.14%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.19      0.32       105
#            1       0.40      1.00      0.57        57
#
#    micro avg       0.48      0.48      0.48       162
#    macro avg       0.70      0.60      0.45       162
# weighted avg       0.79      0.48      0.41       162
#
# [[20 85]
#  [ 0 57]]
#
#
# Deep Learning executed in = 1.510000 seconds
#  Boucle  501 terminée...Opération restantes : 4 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 502  ---  --- Symbol :   ZBH   ---  --- Name :  Zimmer Biomet Holdings  ---  --- Sector :  Health Care  ---
# Models loaded from disk in = 2.620000 seconds
# Scraping data...
# Beta :  1.2240630054184904
#  Alpha :  0.05643951044899839
#  R_Squared :  0.46430097328272124
#  Volatility :  0.28115331243854985
#  Momentum :  0.13300091281766857
# executed in = 1.790000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  407
# On 80% - 20% slash :
# Bloc 1 :  326
# Bloc 2 : 81  periods
# First period : 2017-11-01 00:00:00
# Split period : 2019-04-12 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [06:03:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.230000 seconds
#  Deeping in blue
#
#  --- Loop : 502  ---  --- Symbol :   ZBH   ---  --- Name :  Zimmer Biomet Holdings  ---  --- Sector :  Health Care  ---
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  RESULTATS UP
#
# Accuracy: 75.00%
#  Precision: 69.23%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 69.23%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.79      0.79      0.79        19
#            1       0.69      0.69      0.69        13
#
#    micro avg       0.75      0.75      0.75        32
#    macro avg       0.74      0.74      0.74        32
# weighted avg       0.75      0.75      0.75        32
#
# [[15  4]
#  [ 4  9]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 65.62%
#  Precision: 52.94%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 75.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.60      0.69        20
#            1       0.53      0.75      0.62        12
#
#    micro avg       0.66      0.66      0.66        32
#    macro avg       0.66      0.68      0.65        32
# weighted avg       0.70      0.66      0.66        32
#
# [[12  8]
#  [ 3  9]]
#
#
# Deep Learning executed in = 1.460000 seconds
#  Boucle  502 terminée...Opération restantes : 3 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 503  ---  --- Symbol :   ZION   ---  --- Name :  Zions Bancorp  ---  --- Sector :  Financials  ---
# Models loaded from disk in = 2.590000 seconds
# Scraping data...
# Beta :  1.5406496124839235
#  Alpha :  -0.02076641500015413
#  R_Squared :  0.44374864196785546
#  Volatility :  0.28884169662904263
#  Momentum :  -0.19457875472834962
# executed in = 2.070000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [06:04:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.410000 seconds
#  Deeping in blue
#
#  --- Loop : 503  ---  --- Symbol :   ZION   ---  --- Name :  Zions Bancorp  ---  --- Sector :  Financials  ---
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  RESULTATS UP
#
# Accuracy: 54.32%
#  Precision: 48.25%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.20      0.34        93
#            1       0.48      1.00      0.65        69
#
#    micro avg       0.54      0.54      0.54       162
#    macro avg       0.74      0.60      0.50       162
# weighted avg       0.78      0.54      0.47       162
#
# [[19 74]
#  [ 0 69]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 60.49%
#  Precision: 100.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 25.58%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.54      1.00      0.70        76
#            1       1.00      0.26      0.41        86
#
#    micro avg       0.60      0.60      0.60       162
#    macro avg       0.77      0.63      0.56       162
# weighted avg       0.79      0.60      0.55       162
#
# [[76  0]
#  [64 22]]
#
#
# Deep Learning executed in = 1.510000 seconds
#  Boucle  503 terminée...Opération restantes : 2 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
#  --- Loop : 504  ---  --- Symbol :   ZTS   ---  --- Name :  Zoetis  ---  --- Sector :  Health Care  ---
# Models loaded from disk in = 2.600000 seconds
# Scraping data...
# Beta :  0.8167947058660328
#  Alpha :  0.1766237714208584
#  R_Squared :  0.315796183462996
#  Volatility :  0.18152397887982757
#  Momentum :  0.3787155326329188
# executed in = 2.060000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1056
# On 80% - 20% slash :
# Bloc 1 :  845
# Bloc 2 : 211  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-10-04 00:00:00
# Last period : 2019-08-08 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [06:04:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.840000 seconds
#  Deeping in blue
#
#  --- Loop : 504  ---  --- Symbol :   ZTS   ---  --- Name :  Zoetis  ---  --- Sector :  Health Care  ---
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype float32, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
#  RESULTATS UP
#
# Accuracy: 60.49%
#  Precision: 55.70%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 60.27%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.65      0.61      0.63        89
#            1       0.56      0.60      0.58        73
#
#    micro avg       0.60      0.60      0.60       162
#    macro avg       0.60      0.60      0.60       162
# weighted avg       0.61      0.60      0.61       162
#
# [[54 35]
#  [29 44]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 53.70%
#  Precision: 62.50%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 6.49%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.53      0.96      0.69        85
#            1       0.62      0.06      0.12        77
#
#    micro avg       0.54      0.54      0.54       162
#    macro avg       0.58      0.51      0.40       162
# weighted avg       0.58      0.54      0.42       162
#
# [[82  3]
#  [72  5]]
#
#
# Deep Learning executed in = 1.540000 seconds
#  Boucle  504 terminée...Opération restantes : 1 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV

# %%
2+2

# %%
signals.head()

# %%
import pandas as pd
import os
import shutil
from bs4 import BeautifulSoup
import time
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

os.system('say "Okay pticrapaud. On commence! Youpihihihi! Espèssdecafard"')
___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print(Fore.YELLOW,Back.BLUE,'Reporting v0.55',Style.RESET_ALL)
compte = 'xxx'
list_dir = os.listdir('.')
try:
    if str(list_dir).split(',')[0].split('.')[1].split("'")[0]=='xls':
        compte = str(list_dir).split(',')[0].split('_')[0][-2:]
    else:
        try:
            if str(list_dir).split(',')[1].split('.')[1].split("'")[0]=='xls':
                compte = str(list_dir).split(',')[1].split('_')[0][-2:]
            else:
                try:
                    if str(list_dir).split(',')[2].split('.')[1].split("'")[0]=='xls':
                        compte = str(list_dir).split(',')[2].split('_')[0][-2:]
                    else:
                        try:
                            if str(list_dir).split(',')[3].split('.')[1].split("'")[0]=='xls':
                                compte = str(list_dir).split(',')[3].split('_')[0][-2:]
                            else:
                                try:
                                    if str(list_dir).split(',')[4].split('.')[1].split("'")[0]=='xls':
                                        compte = str(list_dir).split(',')[4].split('_')[0][-2:]
                                    else:
                                        pass
                                except:
                                    pass
                        except:
                            pass
                except:
                    pass
        except:
            pass
except:
    pass
    
try:
    os.mkdir('DONE/')
except:
    pass

try:
    report = pd.read_csv('report_'+compte+'.csv')
    DATE = report['Date'].tolist()  
    NAV_DEB = report['Starting NAV'].tolist()  
    NAV_FIN = report['Ending NAV'].tolist()  
    DIFF = report['Daily PNL in $'].tolist()
    PER = report['Daily PNL in %'].tolist()
    CUMUL = report['Cumulative Daily P&L'].tolist()
except:
    
    DATE = []
    NAV_DEB = []
    NAV_FIN = []
    DIFF = []
    PER = []
    CUMUL = []


long = len(list_dir)
tmps55=time.time()
for i,j in enumerate(sorted(list_dir)):
    if i == 1:
        print('\r',Fore.GREEN,' |==',Fore.BLUE,'O',Fore.RED,'==================|',end='',flush=True)
    if i == round(long/9):
        print('\r',Fore.GREEN,' |====',Fore.BLUE,'O',Fore.RED,'================|',end='',flush=True)
    if i == round(long/9)*2:
        print('\r',Fore.GREEN,' |======',Fore.BLUE,'O',Fore.RED,'==============|',end='',flush=True)
    if i == round(long/9)*3:
        print('\r',Fore.GREEN,' |========',Fore.BLUE,'O',Fore.RED,'============|',end='',flush=True)
    if i == round(long/9)*4:
        print('\r',Fore.GREEN,' |==========',Fore.BLUE,'O',Fore.RED,'==========|',end='',flush=True)
    if i == round(long/9)*5:
        print('\r',Fore.GREEN,' |============',Fore.BLUE,'O',Fore.RED,'========|',end='',flush=True)
    if i == round(long/9)*6:
        print('\r',Fore.GREEN,' |==============',Fore.BLUE,'O',Fore.RED,'======|',end='',flush=True)
    if i == round(long/9)*7:
        print('\r',Fore.GREEN,' |================',Fore.BLUE,'O',Fore.RED,'====|',end='',flush=True)
    if i == round(long/9)*8:
        print('\r',Fore.GREEN,' |==================',Fore.BLUE,'O',Fore.RED,'==|',end='',flush=True)
    
    if j != 'DONE' and j.split('.')[1] == 'xls' and j.split('.')[0].split('_')[1] == j.split('.')[0].split('_')[2]:
    
        try:
            table = BeautifulSoup(open(j,'r').read())
            df = pd.read_html(str(table))
        except:
            continue
        DATE.append(j.split('.')[0].split('_')[1][:4]+'-'+j.split('.')[0].split('_')[1][4:6]+'-'+j.split('.')[0].split('_')[1][6:])
        NAV_DEB.append(df[2].iloc[0,1]) 
        NAV_FIN.append(df[2][df[2]['Change in NAV'] == 'Ending Value'].iloc[0,1])
        DIFF.append(round((df[2][df[2]['Change in NAV'] == 'Ending Value'].iloc[0,1] - (df[2].iloc[0,1])),2))
        PER.append(round(((df[2][df[2]['Change in NAV'] == 'Ending Value'].iloc[0,1] - (df[2].iloc[0,1]))/(df[2].iloc[0,1]))*100,2))
        CUMUL.append(round(sum(DIFF),2))
        shutil.move(j, 'DONE/'+j)
tmps22=round(time.time()-tmps55,2)
print(Fore.BLUE,"\n Time for complete Generation = %f" %tmps22,'seconds \n',Style.RESET_ALL)
try:
    name = df[df=='Account Information'].iloc[0,1]
    account = df[df=='Account Information'].iloc[1,1]
except:
    pass
report = pd.DataFrame()
report['Date'] = DATE
report['Starting NAV'] = NAV_DEB
report['Ending NAV'] = NAV_FIN
report['Daily PNL in $'] = DIFF
report['Daily PNL in %'] = PER
report['Cumulative Daily P&L'] = CUMUL
report.to_csv('report_'+compte+'.csv')
if compte !='xxx':
    debut = report.iloc[0]['Date']
    fin = t = report.iloc[1]['Date']
    mean = round((report.iloc[:]['Daily PNL in %'].sum())/len(report),5)
    plt.figure(figsize=(20,10))
    plt.plot(report.iloc[:]['Daily PNL in %'],label='Daily P&L in %',c='blue')
    plt.axhline(y=mean,label='Mean of % daily p&l',c='orange')
    plt.suptitle(name+' Account '+account+'   from '+debut+' to '+fin,c='purple')
    plt.title('Mean daily p&l = '+str(mean)+'%',c='red')
    plt.title('CUMUL = '+str(sum(CUMUL))+" - CUMUL'S MEAN = " +str(round(sum(CUMUL)/len(CUMUL),2)))
    plt.legend()
    plt.savefig('Report_'+compte+'.jpg')

os.system('say "Okay pticrapaud. Programme terminé. Espèssdecafard kanmèm"')
report
# Out:
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
#   Reporting v0.55
#    |==================  O  ==|
#  Time for complete Generation = 62.320000 seconds
#           Date  Starting NAV  Ending NAV  Daily PNL in $  Daily PNL in %  \
# 0   2019-10-03     489309.09   489535.25          226.16            0.05
# 1   2019-10-04     489535.25   489392.36         -142.89           -0.03
# 2   2019-10-07     489392.36   488290.87        -1101.49           -0.23
# 3   2019-10-08     488290.87   484041.33        -4249.54           -0.87
# 4   2019-10-09     484041.33   485499.10         1457.77            0.30
# 5   2019-10-10     485499.10   485268.15         -230.95           -0.05
# 6   2019-10-11     485268.15   490643.57         5375.42            1.11
# 7   2019-10-14     490643.57   488257.66        -2385.91           -0.49
# 8   2019-10-15     488257.66   490306.57         2048.91            0.42
# 9   2019-10-16     490306.57   489268.62        -1037.95           -0.21
# 10  2019-10-17     489268.62   487416.43        -1852.19           -0.38
# 11  2019-10-18     487416.43   484552.72        -2863.71           -0.59
# 12  2019-10-21     484552.72   482871.61        -1681.11           -0.35
# 13  2019-10-22     482871.61   477144.02        -5727.59           -1.19
# 14  2019-10-23     477144.02   475206.43        -1937.59           -0.41
# 15  2019-10-24     475206.43   479540.26         4333.83            0.91
# 16  2019-10-25     479540.26   477494.71        -2045.55           -0.43
# 17  2019-10-28     477494.71   479160.61         1665.90            0.35
#
#     Cumulative Daily P&L
# 0                 226.16
# 1                  83.27
# 2               -1018.22
# 3               -5267.76
# 4               -3809.99
# 5               -4040.94
# 6                1334.48
# 7               -1051.43
# 8                 997.48
# 9                 -40.47
# 10              -1892.66
# 11              -4756.37
# 12              -6437.48
# 13             -12165.07
# 14             -14102.66
# 15              -9768.83
# 16             -11814.38
# 17             -10148.48

# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
import pandas as pd
import os
import shutil
import smtplib
import mimetypes
from email.message import EmailMessage
from bs4 import BeautifulSoup
import time
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

os.system('say "Okay pticrapaud. On commence! Youpihihihi! Espèssdecafard"')
___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print(Fore.YELLOW,Back.BLUE,'Reporting v0.55',Style.RESET_ALL)
compte = 'xxx'
list_dir = os.listdir('.')

for foo,bar in enumerate(list_dir):
    try:
        if str(list_dir).split(',')[foo].split('.')[1].split("'")[0] == 'xls':
            compte = str(list_dir).split(',')[foo].split('_')[0][-2:]
    except:
        pass
    
try:
    os.mkdir('DONE/')
except:
    pass
try:
    os.mkdir('Reports/')
except:
    pass

try:
    report = pd.read_csv('report_#'+compte+'.csv')
    DATE = report['Date'].tolist()  
    NAV_DEB = report['Starting NAV'].tolist()  
    NAV_FIN = report['Ending NAV'].tolist()  
    DIFF = report['Daily PNL ($)'].tolist()
    PER = report['Daily PNL (%)'].tolist()
    CUMUL = report['Cumulative Daily P&L ($)'].tolist()
    CUM_PER = report['Cumulative Daily P&L (%)'].tolist()
    
except:
    
    DATE = []
    NAV_DEB = []
    NAV_FIN = []
    DIFF = []
    PER = []
    CUMUL = []
    CUM_PER = []
    


long = len(list_dir)
tmps55=time.time()
for i,j in enumerate(sorted(list_dir)):
    if i == 1:
        print('\r',Fore.GREEN,' |==',Fore.BLUE,'O',Fore.RED,'==================|',end='',flush=True)
    if i == round(long/9):
        print('\r',Fore.GREEN,' |====',Fore.BLUE,'O',Fore.RED,'================|',end='',flush=True)
    if i == round(long/9)*2:
        print('\r',Fore.GREEN,' |======',Fore.BLUE,'O',Fore.RED,'==============|',end='',flush=True)
    if i == round(long/9)*3:
        print('\r',Fore.GREEN,' |========',Fore.BLUE,'O',Fore.RED,'============|',end='',flush=True)
    if i == round(long/9)*4:
        print('\r',Fore.GREEN,' |==========',Fore.BLUE,'O',Fore.RED,'==========|',end='',flush=True)
    if i == round(long/9)*5:
        print('\r',Fore.GREEN,' |============',Fore.BLUE,'O',Fore.RED,'========|',end='',flush=True)
    if i == round(long/9)*6:
        print('\r',Fore.GREEN,' |==============',Fore.BLUE,'O',Fore.RED,'======|',end='',flush=True)
    if i == round(long/9)*7:
        print('\r',Fore.GREEN,' |================',Fore.BLUE,'O',Fore.RED,'====|',end='',flush=True)
    if i == round(long/9)*8:
        print('\r',Fore.GREEN,' |==================',Fore.BLUE,'O',Fore.RED,'==|',end='',flush=True)
    
    try:
        j.split('.')[1]
        if j.split('.')[1] == 'xls' and j.split('.')[0].split('_')[1] == j.split('.')[0].split('_')[2]:
    
            try:
                table = BeautifulSoup(open(j,'r').read())
                df = pd.read_html(str(table))
            except:
                continue
            DATE.append(j.split('.')[0].split('_')[1][:4]+'-'+j.split('.')[0].split('_')[1][4:6]+'-'+j.split('.')[0].split('_')[1][6:])
            NAV_DEB.append(df[1].iloc[-1,1]) 
            NAV_FIN.append(df[1].iloc[-1,4])
            DIFF.append(round((df[1].iloc[-1,4] - df[1].iloc[-1,1]),2))
            PER.append(round(((df[1].iloc[-1,4] - df[1].iloc[-1,1])/df[1].iloc[-1,1])*100,2))
            CUMUL.append(round(sum(DIFF),2))
            CUM_PER.append(round((sum(DIFF)/498825.00)*100,2))
            shutil.move(j, 'DONE/'+j)
    except:
        pass
    
tmps22=round(time.time()-tmps55,2)
print(Fore.BLUE,"\n Time for complete Generation = %f" %tmps22,'seconds \n',Style.RESET_ALL)
try:
    name = df[df=='Account Information'].iloc[0,1]
    account = df[df=='Account Information'].iloc[1,1]
except:
    pass
report = pd.DataFrame()
report['Date'] = DATE
report['Starting NAV'] = NAV_DEB
report['Ending NAV'] = NAV_FIN
report['Daily PNL ($)'] = DIFF
report['Daily PNL (%)'] = PER
report['Cumulative Daily P&L ($)'] = CUMUL
report['Cumulative Daily P&L (%)'] = CUM_PER

debut = report.iloc[0]['Date']
fin  = report.iloc[-1]['Date']
report.to_csv('report_#'+compte+'.csv')
if compte !='xxx':
    debut = report.iloc[0]['Date']
    fin  = report.iloc[-1]['Date']
    mean_0 = round((report.iloc[:]['Daily PNL (%)'].sum())/len(report),5)
    mean_1 = round((report.iloc[:]['Cumulative Daily P&L ($)'].sum())/len(report),5)
    mean_2 = round((report.iloc[:]['Cumulative Daily P&L (%)'].sum())/len(report),5)
    
    plt.figure(figsize=(20,10))
    plt.plot(report.iloc[:]['Daily PNL (%)'],label='Daily P&L in %',c='blue')
    plt.axhline(y=mean_0,label='Mean of % daily p&l',c='orange')
    plt.suptitle(name+' Account '+account+'   from '+debut+' to '+fin,c='purple')
    plt.title('Mean daily p&l = '+str(mean_0)+'% - Daily p&l = '+str(report.iloc[-1,4])+'%',c='red')
    #plt.title('CUMUL = '+str(sum(CUMUL))+" - CUMUL'S MEAN = " +str(round(sum(CUMUL)/len(CUMUL),2)))
    plt.legend()
    plt.savefig('DPNL_#'+compte+'.jpg')
    
    plt.figure(figsize=(20,10))
    plt.plot(report.iloc[:]['Cumulative Daily P&L ($)'],label='Daily P&L in %',c='blue')
    plt.axhline(y=mean_1,label='Mean of cumulative p&l ($)',c='orange')
    plt.suptitle(name+' Account '+account+'   from '+debut+' to '+fin,c='purple')
    plt.title('Mean Cumulative p&l = $'+str(mean_1)+' - Daily p&l = '+str(report.iloc[-1,4])+'%',c='red')
    #plt.title('CUMUL = '+str(sum(CUMUL))+" - CUMUL'S MEAN = " +str(round(sum(CUMUL)/len(CUMUL),2)))
    plt.legend()
    plt.savefig('CUMUL_#'+compte+'.jpg')
    
    plt.figure(figsize=(20,10))
    plt.plot(report.iloc[:]['Cumulative Daily P&L (%)'],label='Daily P&L in %',c='blue')
    plt.axhline(y=mean_2,label='Mean of of cumulative p&l (%)',c='orange')
    plt.suptitle(name+' Account '+account+'   from '+debut+' to '+fin,c='purple')
    plt.title('Mean Cumulative p&l = '+str(mean_2)+'% - Daily p&l = '+str(report.iloc[-1,4])+'%',c='red')
    #plt.title('CUMUL = '+str(sum(CUMUL))+" - CUMUL'S MEAN = " +str(round(sum(CUMUL)/len(CUMUL),2)))
    plt.legend()
    plt.savefig('PERCUMUL_#'+compte+'.jpg')

os.system('say "Okay pticrapaud. Programme terminé. Espèssdecafard kanmèm"')
time.sleep(5)
os.system('say "Envoi du mail"')
msg = EmailMessage()
msg.set_content('Hi. Here are the reports of the day for the account '+account)
filename1 = ('report_#'+compte+'.csv')
filename2 = ('DPNL_#'+compte+'.jpg')
filename3 = ('CUMUL_#'+compte+'.jpg')
filename4 = ('PERCUMUL_#'+compte+'.jpg')

ctype, encoding = mimetypes.guess_type(filename1)
ctype, encoding = mimetypes.guess_type(filename2)
if ctype is None or encoding is not None:
    # No guess could be made, or the file is encoded (compressed), so
    # use a generic bag-of-bits type.
    ctype = 'application/octet-stream'
maintype, subtype = ctype.split('/', 1)
with open(filename1, 'rb') as fp:
    msg.add_attachment(fp.read(),
                       maintype=maintype,
                       subtype=subtype,
                       filename=filename1)
with open(filename2, 'rb') as fp:
    msg.add_attachment(fp.read(),
                       maintype=maintype,
                       subtype=subtype,
                       filename=filename2)
with open(filename3, 'rb') as fp:
    msg.add_attachment(fp.read(),
                       maintype=maintype,
                       subtype=subtype,
                       filename=filename3)
with open(filename4, 'rb') as fp:
    msg.add_attachment(fp.read(),
                       maintype=maintype,
                       subtype=subtype,
                       filename=filename4)

msg['Subject'] = fin+' Automatic Reporting #'+account
msg['From'] = 'jyss@dag26.com'
msg['To'] = 'GM@css-europe.co.uk'
msg['Cc'] = 'jyss@dag26.com' ,'billy@dag26.com','stephane@dag26.com'

# Send the message via our own SMTP server.
s = smtplib.SMTP('smtp.free.fr')
s.send_message(msg)
s.quit()    
print('Mail envoyé')
os.system('say "Mail envoyé"')
shutil.move(filename2,'Reports/'+DATE[-1]+'_'+filename2)
shutil.move(filename3,'Reports/'+DATE[-1]+'_'+filename3)
shutil.move(filename4,'Reports/'+DATE[-1]+'_'+filename4)
report
# Out:
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
#   Reporting v0.55
#    |==================  O  ==|
#  Time for complete Generation = 1.010000 seconds
#
# Mail envoyé
#           Date  Starting NAV  Ending NAV  Daily PNL ($)  Daily PNL (%)  \
# 0   2019-10-03     498825.00   500580.60        1755.60           0.35
# 1   2019-10-04     500580.60   501319.30         738.70           0.15
# 2   2019-10-07     501319.30   499958.94       -1360.36          -0.27
# 3   2019-10-08     499958.94   497927.11       -2031.83          -0.41
# 4   2019-10-09     497927.11   501212.99        3285.88           0.66
# 5   2019-10-10     501212.99   503663.29        2450.30           0.49
# 6   2019-10-11     503663.29   510512.26        6848.97           1.36
# 7   2019-10-14     510512.26   509605.55        -906.71          -0.18
# 8   2019-10-15     509605.55   512376.79        2771.24           0.54
# 9   2019-10-16     512376.79   511186.54       -1190.25          -0.23
# 10  2019-10-17     511186.54   510352.06        -834.48          -0.16
# 11  2019-10-18     510352.06   508501.05       -1851.01          -0.36
# 12  2019-10-21     508501.05   507814.06        -686.99          -0.14
# 13  2019-10-22     507814.06   503218.76       -4595.30          -0.90
# 14  2019-10-23     503218.76   502944.44        -274.32          -0.05
# 15  2019-10-24     502944.44   504793.89        1849.45           0.37
# 16  2019-10-25     504793.89   502206.16       -2587.73          -0.51
# 17  2019-10-28     502206.16   502812.67         606.51           0.12
# 18  2019-10-29     502812.67   503854.60        1041.93           0.21

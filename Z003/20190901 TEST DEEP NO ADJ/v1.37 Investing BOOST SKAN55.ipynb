# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
print('Importing Librairies...')
import talib
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import xgboost as xgb
from xgboost import XGBRegressor, plot_importance
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')
import time
import datetime as dt
import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
print('Librairies imported')
print('')

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print('BOOST SKAN 55 Version v1.35',Style.RESET_ALL)



print('')
print('Sraping tickers')
constituents = pd.read_csv('constituents_csv.csv')
print('Scrap -----> ok')
# PARAMETRES TEMPORELS INITIAUX
start = pd.to_datetime('2013-01-06')
end = pd.to_datetime('2017-12-31')

error = []


try :
    amorce = pd.read_csv('backTest.csv').index[-1] + 1
except:
    amorce = 0
    backtest = pd.DataFrame(columns = ['Symb.','Name','Sector','Period','Begin.','End',\
                          'Pnl $','Pnl %','Gross Profit','Gross Loss','# Winners','# Loosers',\
                          '% Winners','MaxDD $','MaxDD %','Aver. Win $',\
                          'Aver. Loos $','Aver. Duration',\
                          'Total Trades','% Long','% Short','Profit Factor'])
    
    
try:
    amorce2 = pd.read_csv('SIGNALS.csv').index[-1] + 1
except:
    amorce2 = 0
    signals = pd.DataFrame(columns = ['Date','Ticker','Open Long','Close Long','Open Short','Close Short','Buy/Sell Price','Quantity','PNL','Cumulative PNL','Latent PNL'])

    
# SCRAPING DES DONNES BRUTES
def scrap_data(ticker,start,end):
    df = web.DataReader(ticker,'yahoo',start,end)
    df['toto'] = df['Close']
    df = df.drop(['Adj Close'],axis = 1)
    df = df.drop(['Close'],axis = 1)
    df['Close'] = df['toto']
    df = df.drop(['toto'],axis = 1)    
    return(df)

def prepa_data(df):
    tmps1=time.time()
    print('Preparing data...')
    rsi = talib.RSI(df['Close'],timeperiod=14)
    stoc_slowk, stoc_slowd = talib.STOCH(df['High'],df['Low'],df['Close'])
    upper, middle, lower =  talib.BBANDS(df['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(df['Close'],timeperiod=5)
    sma8 = talib.SMA(df['Close'],timeperiod=8)
    sma10 = talib.SMA(df['Close'],timeperiod=10)
    sma12 = talib.SMA(df['Close'],timeperiod=12)
    sma15 = talib.SMA(df['Close'],timeperiod=15)
    sma30 = talib.SMA(df['Close'],timeperiod=30)
    sma35 = talib.SMA(df['Close'],timeperiod=35)
    sma40 = talib.SMA(df['Close'],timeperiod=40)
    sma45 = talib.SMA(df['Close'],timeperiod=45)
    sma50 = talib.SMA(df['Close'],timeperiod=50)
    atr = talib.ATR(df['High'],df['Low'],df['Close'],timeperiod=10)
    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50
    bbdelta = upper - middle
    price_bolup = df['Close'] - lower
    price_bolow = df['Close'] - upper
    Ema = talib.EMA(df['Close'],timeperiod=20)
    KC_High = Ema + 2*atr
    KC_Low = Ema - 2*atr
    aroondown, aroonup = talib.AROON(df['High'], df['Low'], timeperiod=9)
    aroon = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
    rsi30_list = []
    rsi70_list = []
    for i in range(0,df.shape[0]):
        rsi70_list.append(70 - rsi[i])
        rsi30_list.append(rsi[i] - 30)
        #except:
         #   rsi70_list.append(0)
          #  rs30_list.append(0)
    varop_spy = df['Open'] - df['Close']
    varhl_spy = df['High'] - df['Low']
    df['Varop_Spy'] = varop_spy
    df['Varhl_spy'] = varhl_spy
    df['RSI'] = rsi
    df['70 - RSI'] = np.array(rsi70_list)
    df['RSI - 30'] = np.array(rsi30_list)
    df['BBD_Delta_Up'] = bbdelta
    df['delta5_8'] = delta5_8
    df['delta8_10'] = delta8_10
    df['delta10_12'] = delta10_12
    df['delta12_15'] = delta12_15
    df['delta15_30'] = delta15_30
    df['delta30_35'] = delta30_35
    df['delta35_40'] = delta35_40
    df['delta40_45'] = delta40_45
    df['delta45_50'] = delta45_50
    df['Stoc_Slowk'] = stoc_slowk
    df['Stoc_Slowd'] = stoc_slowd
    df['KC_High'] = KC_High
    df['KC_Low'] = KC_Low
    df['upper'] = upper
    df['lower'] = lower
    df['var_bollup_kchigh'] = upper-KC_High
    df['var_bolllow_kclow'] = lower-KC_Low
    df['Aroon Up'] = aroonup
    df['Aroon Down'] = aroondown
    df['Delta Aroon'] = aroon
    up = []
    down = []
    df = df.dropna()
    df = boost(df)
    df['%Futur'] = ((df['Close.S']-df['Close']) *100) / (df['Close'])
    df['%Futur2'] = ((df['Close.S2']-df['Close']) *100) / (df['Close'])
    for i in range(0,df.shape[0]-5):
        if df.iloc[i]['%Futur'] > 0.1 :#or df.iloc[i]['%Futur2'] > 0.1:
            up.append(1)
            down.append(0)
        elif df.iloc[i]['%Futur'] < -0.1: #or df.iloc[i]['%Futur2'] < -0.1:
            up.append(0)
            down.append(1)
        else:
            up.append(0)
            down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    
    
    df['target_up'] = up  # target_up # abs(np.array(valley))#target_up
    df['target_down'] = down # target_down # abs(np.array(peak))#target_down
    #df = df.dropna()
    tmps2=round(time.time()-tmps1,2)
    print ("Data prepared in = %f" %tmps2,'seconds')
    return(df)

def boost(df):
    print('Boosting')
    X = df.copy()
    X = X.drop(['Close'],axis=1)
    X['Close'] = df['Close']
    y = X.iloc[:,-1]
    Xtrain = X.iloc[:-2,:-1]
    Xtest = X.iloc[-2:-1,:-1]
    yshift = y.shift(-1)
    ytrain = yshift.iloc[:-2]
    ytest = yshift.iloc[-2:-1]

    model = xgb.XGBRegressor(n_estimators=20000, learning_rate=1, gamma=1, subsample=1, colsample_bytree=1, max_depth=100)

    model.fit( Xtrain, ytrain, early_stopping_rounds=150, eval_set=[(Xtest, ytest)], verbose=0)

    ytrain_pred = model.predict(Xtrain)

    y_pred = model.predict(Xtest)

    pred = model.predict(X.iloc[:,:-1])

    df['Close.S'] = pred
    df['Close.S2'] = df['Close.S']
    df = df.dropna()
    print('Boost ok')
    return(df)

    
def deep_learning(df):
    tmps1=time.time()
    X = df.iloc[:,1:-4]
    y_up = df.iloc[:,-2].values
    y_down = df.iloc[:,-1].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:bloc1,:]
    Xtest = X[bloc1:,:]
    ytrain_up = y_up[:bloc1,:]
    ytest_up = y_up[bloc1:,:]
    ytrain_down = y_down[:bloc1,:]
    ytest_down = y_down[bloc1:,:]

    seed = 770
    np.random.seed(seed)

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    model_up = Sequential()
    # Add an input layer 
    model_up.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_up.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_up.add(Dense(1, activation='sigmoid'))

    model_down = Sequential()
    # Add an input layer 
    model_down.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_down.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_down.add(Dense(1, activation='sigmoid'))

    print('Processing move_up')
    model_up.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])
    
              

    history_up = model_up.fit(Xtrain, ytrain_up,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Processing move_down')
    model_down.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])

    history_down = model_down.fit(Xtrain, ytrain_down,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Computing done')
    print('\n')

    train_acc_up = model_up.evaluate(Xtrain, ytrain_up,verbose=1)
    train_acc_down = model_down.evaluate(Xtrain, ytrain_down,verbose=1)

    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    score_up = model_up.evaluate(Xtest, ytest_up,verbose=1)
    score_down = model_down.evaluate(Xtest, ytest_down,verbose=1)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)

    accuracy_up = accuracy_score(ytest_up, yhat_up)
    accuracy_down = accuracy_score(ytest_down, yhat_down)

    # La précision permet de mesurer la capacité du modèle à refuser résultats non-pertinents : vrais_positifs/(vrais_positifs+faux_positifs)
    precision_up = precision_score(ytest_up, yhat_up)  
    precision_down = precision_score(ytest_down, yhat_down) 


    # Recall : (vrai_positifs/(vrais_positifs+faux_négatifs))
    recall_up = recall_score(ytest_up, yhat_up) 
    recall_down = recall_score(ytest_down, yhat_down) 


    #roc_up=roc_auc_score(ytest_up,yhat_up)
    #roc_down=roc_auc_score(ytest_down,yhat_down)
    print('\n')
    print(Fore.GREEN,'RESULTATS UP\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_up * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_up *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_up * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_up *100))
    # get probabilities for positive class

    print(classification_report(ytest_up, yhat_up))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_up, yhat_up))

    print('\n')
    print('_______________________________________________________________________________________________________________________________________________________________\n')
    print(Fore.RED,'RESULTATS DOWN\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_down * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_down *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_down * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_down *100))
    # get probabilities for positive class

    print(classification_report(ytest_down, yhat_down))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_down, yhat_down))
    print('\n')

    resultats = pd.DataFrame()
    resultats['Date'] = df.index[bloc1:]
    resultats.index= df.index[bloc1:]
    resultats['Move Up'] = yhat_up
    resultats['Confiance up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confiance Down'] = (predict_down)*100
    resultats['Actual'] = df.iloc[bloc1:]['Close']
    resultats['Actual.S'] = df.iloc[bloc1:]['Close.S']
    open_S = df['Open'].shift(-1)
    resultats['Open.S'] = open_S.iloc[bloc1:]
    dmp_cp=[]
    dmp_cp = ((resultats['Confiance up']-resultats['Confiance Down'])/(resultats['Confiance up']+resultats['Confiance Down'])*100)
    resultats['DMP_CP'] = dmp_cp
    tmps2=round(time.time()-tmps1,2)
    print ("Deep Learning executed in = %f" %tmps2,'seconds')
    #resultats.set_index('Date',inplace=True)
    #parse_dates=resultats['Date']
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def learn(df):
    resultats,precision_up,precision_down,model_up,model_down,scaler = deep_learning(df)
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def grobeta(df,dfb):
    # create a time-series of monthly data points
    rts = df.resample('M').last()
    rbts = dfb.resample('M').last()
    dfsm = pd.DataFrame({'s_adjclose' : rts['Close'],
                            'b_adjclose' : rbts['Adj Close']},
                            index=rts.index)

    # compute returns
    dfsm[['s_returns','b_returns']] = dfsm[['s_adjclose','b_adjclose']]/\
        dfsm[['s_adjclose','b_adjclose']].shift(1) -1
    dfsm = dfsm.dropna()
    covmat = np.cov(dfsm["s_returns"],dfsm["b_returns"])

    # calculate measures now
    beta = covmat[0,1]/covmat[1,1]
    alpha= np.mean(dfsm["s_returns"])-beta*np.mean(dfsm["b_returns"])

    # r_squared     = 1. - SS_res/SS_tot
    ypred = alpha + beta * dfsm["b_returns"]
    SS_res = np.sum(np.power(ypred-dfsm["s_returns"],2))
    SS_tot = covmat[0,0]*(len(dfsm)-1) # SS_tot is sample_variance*(n-1)
    r_squared = 1. - SS_res/SS_tot
    # 5- year volatiity and 1-year momentum
    volatility = np.sqrt(covmat[0,0])
    momentum = np.prod(1+dfsm["s_returns"].tail(12).values) -1

    # annualize the numbers
    prd = 12. # used monthly returns; 12 periods to annualize
    alpha = alpha*prd
    volatility = volatility*np.sqrt(prd)

    print ('Beta : ',beta,'\n Alpha : ',alpha,'\n R_Squared : ', r_squared, '\n Volatility : ', volatility, '\n Momentum : ',momentum)
    return(beta,alpha,r_squared,volatility,momentum)

########################
#### MAIN SKAN55 #######
########################

for loop in range(0,49):    
#for loop in range(amorce,len(constituents)):
    print('Loop :',loop)
    print('amorce : ',amorce)
    print('amorce2 : ',amorce2)

    try:

        ticker = (constituents.iloc[loop]['Symbol'])
        name = constituents.iloc[loop]['Name']
        sector = constituents.iloc[loop]['Sector']

        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        global delta,bloc1,bloc2
        tmps1=time.time()
        print('Scraping data...')

        df = scrap_data(ticker,start,end)

        dfb = web.DataReader('^GSPC','yahoo',start,end)

        beta,alpha, r_squared, volatility, momentum = grobeta(df,dfb)

        tmps2=round(time.time()-tmps1,2)
        print ("executed in = %f" %tmps2,'seconds')

        print('\n')
        print('GOLEM begins Computing...')
        print('\n')
        delta = round(df.shape[0])
        bloc1 = round(delta*0.80)
        bloc2 = delta - bloc1
        print("# of periods : ",delta)
        print('On 80% - 20% slash : ')
        print('Bloc 1 : ',bloc1,'\nBloc 2 :',bloc2,' periods ')
        print('First period :',df.index[0])
        print('Split period :',df.index[bloc1-1])
        print('Last period :',df.index[df.shape[0]-1])
        print('\n')

        print('Data prep')
        df = prepa_data(df)

        print(Fore.BLUE,'Deeping in blue',Style.RESET_ALL)
        print('')
        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        resultats,precision_up,precision_down,model_up,model_down,scaler = learn(df)

        import sys
        orig_stdout = sys.stdout
        f = open('backtest de '+str(ticker)+'.txt', 'w')
        sys.stdout = f

        ####################
        #### TEST PLOT ####
        ###################

        filtre_up = 93
        filtre_down = 97
        filtre_up_close = 80
        filtre_down_close = 80


        plt.figure(figsize=(26,8),dpi=300)
        #plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
        plt.title('Deep Learning '+name+' Trade Signals')
        plt.plot(resultats['Actual'],color='purple',lw=0.9,label=ticker)

        green=[]
        red=[]
        green_close=[]
        red_close=[]

        for i in range(0,len(resultats)-1):


            if resultats.iloc[i]['Confiance Down'] > filtre_down:
                doob = -1
            elif resultats.iloc[i]['Confiance Down'] > filtre_down_close and resultats.iloc[i]['Confiance Down'] < filtre_down :
                waab = -1
                doob = 0
            elif resultats.iloc[i]['Confiance up'] > filtre_up:
                doob = 1
            elif resultats.iloc[i]['Confiance up'] > filtre_up_close and resultats.iloc[i]['Confiance up'] < filtre_up:
                waab = 1
                doob = 0
            else :
                doob = 0
                waab = 0

            if doob == 1 :#and resultats.iloc[i]['Confiance up'] > filtre_up:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='g',marker='o')
                #doob = -1
                green.append(1)
                red.append(0)
                green_close.append(0)
                red_close.append(1)

            elif doob == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(1)
                green_close.append(1)
                red_close.append(0)

            elif doob == 0 and waab == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(0)
                green_close.append(0)
                red_close.append(1)

            elif waab == 1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(0)
                green_close.append(1)
                red_close.append(0)  

            else:
                green.append(0)
                red.append(0)
                green_close.append(0)
                red_close.append(0)  

                #doob = 0


        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='g',marker='o',label='Buy Signal')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o',label='Sell Signal')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_01.pdf')
        plt.close()


        green.append(0)
        red.append(0)
        green_close.append(0)
        red_close.append(0)
        resultats['Green'] = green
        resultats['Red'] = red
        resultats['Green_Close'] = green_close
        resultats['Red_Close'] = red_close
        #resultats['Actual'] = df['Close'][bloc1:]

        ########################
        ####### BACKTEST########
        ########################
        pos_long = 0
        pos_short = 0
        pactol = 10000/beta
        price_buy = 0
        price_sell = 0
        x = 0
        winners = []
        loosers = []
        nb_win = 0
        nb_los = 0
        mini_pnl = 0
        pos_duration = []
        average_duration = resultats.iloc[0,0] - resultats.iloc[0,0]
        trades = []
        eq_curx = []
        eq_cury = []
        maxdd = []
        nbS = 0
        nbL = 0

        for i in range(0,len(resultats)-1):
            if pos_long == 0 and pos_short == 0 and resultats.iloc[i]['Green'] == 1 :
                pos_long = 1
                nbL+=1
                x = round((10000/beta)/resultats.iloc[i]['Open.S'])
                price_buy = round(resultats.iloc[i]['Open.S'],2)
                time_enter = resultats.iloc[i]['Date']

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 1,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':0}],ignore_index=True)

                print('\n Le ',str(resultats.iloc[i]['Date']),', achat de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',round(pactol,2))
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],1))

            elif pos_long == 1 and resultats.iloc[i]['Green_Close'] == 0 :

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':round((resultats.iloc[i]['Open.S'] - price_buy)*x,2)}],ignore_index=True)
                try:
                    maxdd.append(round((resultats.iloc[i]['Open.S'] - price_buy)*x,2))
                except:
                    print('Null val of maxdd')
                    maxdd.append('Null')


            elif pos_long == 1 and resultats.iloc[i]['Green_Close'] == 1 :
                old_pactol = round(pactol,2)
                eq_curx.append(resultats.iloc[i]['Date'])
                eq_cury.append(old_pactol)
                pos_long = 0
                price_sell = round(resultats.iloc[i]['Open.S'],2)
                mini_pnl = round(x*(price_sell-price_buy),2)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],2))

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 1, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : mini_pnl,\
                                           'Cumulative PNL':round(signals.iloc[:i]['PNL'].sum(),2),'Latent PNL':0}],ignore_index=True)

                pactol = round((pactol + mini_pnl),2)
                print('\n Le ',str(resultats.iloc[i]['Date']),', vente pour close de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)
                print('pnl:', mini_pnl)
                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                pos_duration.append(resultats.iloc[i]['Date'] - time_enter)

                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1


            elif pos_short == 0 and pos_long == 0 and resultats.iloc[i]['Red']:
                pos_short = 1
                nbS+=1
                x = round((10000/beta)/resultats.iloc[i]['Open.S'])
                price_sell = round(resultats.iloc[i]['Open.S'],2)
                time_enter = resultats.iloc[i]['Date']

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 1, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

                print('\n Le ',str(resultats.iloc[i]['Date']),', vente de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],-1))


            elif pos_short == 1 and resultats.iloc[i]['Red_Close'] == 0 :

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':-round((resultats.iloc[i]['Open.S'] - price_sell)*x,2)}],ignore_index=True)
                try:
                    maxdd.append(round((resultats.iloc[i]['Open.S'] - price_sell)*x,2))
                except:
                    print('Null val of maxdd')
                    maxdd.append(0)

            elif pos_short == 1 and resultats.iloc[i]['Red_Close'] == 1 :
                old_pactol = round(pactol,2)
                eq_curx.append(resultats.iloc[i]['Date'])
                eq_cury.append(old_pactol)
                pos_short = 0
                price_buy = round(resultats.iloc[i]['Open.S'],2)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],-2))
                mini_pnl = round(x*(price_sell-price_buy),2)

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 1,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : mini_pnl,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

                pactol = round((pactol + mini_pnl),2)
                print('\n Le ',str(resultats.iloc[i]['Date']),', achat pour close de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)

                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                print('pnl:', mini_pnl)
                pos_duration.append(resultats.iloc[i]['Date'] - time_enter)
                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1
            else:

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                               'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                               'Buy/Sell Price' : 0, 'Quantity' : 0, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

        if pos_long == 1:
            pos_long = 0
            print('Cutting non resolved position')
            print(' Le price buy était de : ',price_buy)
            x = round((10000/beta)/resultats.iloc[i]['Open.S'])
            print('x = ',x)
            price_sell = round(resultats.iloc[i]['Open.S'],2)
            print('Et le price sell : ',price_sell)
            mini_pnl = round(x*(price_sell-price_buy),2)

            signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 1, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : mini_pnl,\
                                       'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

            pactol = round((pactol + mini_pnl),2)
            print('pnl : ',mini_pnl)
            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1


        if pos_short == 1:
            pos_short = 0
            print('Cutting non resolved position')
            print(' Le price sell était de : ',price_sell)
            x = round((10000/beta)/resultats.iloc[i]['Open.S'])
            print('x = ',x)
            price_buy = round(resultats.iloc[i]['Open.S'],2)
            print('Et le price_buy : ',price_buy)
            mini_pnl = round(x*(price_sell-price_buy),2)

            signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 1,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : mini_pnl,\
                                       'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

            pactol = round((pactol + mini_pnl),2)
            print('pnl : ',mini_pnl)

            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1


        pnl = round(pactol - (10000/beta),2)
        print('\n Begining of BackTest :',resultats.iloc[0]['Date'])
        print('Instrument :',ticker)
        print('Face value per trade : $',10000/beta)
        print('End of BackTest :',resultats.iloc[-1]['Date'])
        duration = pd.to_timedelta((resultats.iloc[-1]['Date'] - resultats.iloc[0]['Date']),unit='d')
        print("BackTest's period :",duration)
        print('Pnl :',round(pnl,2),'$')
        print('% Pnl : ',round(pnl/(10000/beta)*100,2))
        print('Total winners :',round(sum(winners),2),'$')
        print('Total loosers :',round(sum(loosers),2),'$')
        print('Number of winners :',round(nb_win))
        print('Number of loosers :',round(nb_los))
        print('Maximum Drawdown : ',round(min(maxdd),2))
        print('% Max Drawdown : ',round(min(maxdd)/(10000/beta)*100,2),'%')
        print('Nombre toatl de trades : ',round(nbL+nbS,2))
        print('% de trades Long : ',round((nbL*100)/(nbL+nbS),2))
        print('% de trades Short : ',round((nbS*100)/(nbL+nbS),2))
        try:
            print('% winners :', round((nb_win/(nb_win+nb_los) * 100),2),'%')
            print('Average winners :',(round(sum(winners)/(nb_win))))
        except:
            print('% winners : null')
        try:
            print('Average losers :',(round(sum(loosers)/(nb_los))))
        except:
            print('Average losers : Inf')
        try:
            for t in range(0,len(pos_duration)):
                average_duration = pd.to_timedelta((average_duration + pos_duration[t]),unit='d')
            average_duration = average_duration/(nb_los+nb_win)
            print('Average Duration :', average_duration)
        except:
            print('No Average Duration available')
        try:
            print('Profit Factor : ',abs(round((sum(winners)/sum(loosers)),2)))
        except:
            print('Profit Factor : null')

        ########################
        ##### PLOT TRADES ######
        ########################

        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Trades')
        plt.plot(resultats['Open.S'],color='blue',lw=0.9)
        for i in range(0,len(trades)):
            if trades[i][2] == 1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='green',marker='^',lw=2.5)
            elif trades[i][2] == -1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='red',marker='^',lw=2.5)
            elif trades[i][2] == 2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='g',marker='x',lw=2.5)
            elif trades[i][2] == -2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='r',marker='x',lw=2.5)

        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='g',marker='^',label='Open Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='r',marker='^',label='Open Short')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='g',marker='x',label='Close Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='r',marker='x',label='Close Short')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_02.pdf')
        plt.close()

        #########################
        ##### PLOT E-CURVE ######
        #########################
        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Equity Curve')
        plt.plot(eq_curx,eq_cury)
        plt.scatter(x=eq_curx,y=eq_cury,c='orange',marker='o',lw=2.5)
        plt.savefig('backtest de '+str(ticker)+'_03.pdf')
        plt.close()


        f.close()
        sys.stdout = orig_stdout

        print('\r Boucle ', loop, 'terminée...',end='')
        print('Opération restantes :', len(constituents)-loop,'/',len(constituents),'\n')


        backtest = backtest.append([{'Symb.':ticker,'Name':name,'Sector':sector,'Period':duration,'Begin.':resultats.iloc[0,0],'End':resultats.iloc[-1,0],\
                          'Pnl $':pnl,'Pnl %':round(pnl/(10000/beta)*100,2),'Gross Profit':round(sum(winners),2),'Gross Loss':round(sum(loosers),2),'# Winners':nb_win,'# Loosers':nb_los,\
                          '% Winners':round((nb_win/(nb_win+nb_los) * 100),2),'MaxDD $':round(min(maxdd),2),'MaxDD %':round(min(maxdd)/(10000/beta)*100,2),'Aver. Win $':(round(sum(winners)/(nb_win))),\
                          'Aver. Loos $':(round(sum(loosers)/(nb_los))),'Aver. Duration':average_duration,\
                          'Total Trades':nbL+nbS,'% Long':round((nbL*100)/(nbL+nbS),2),'% Short':round((nbS*100)/(nbL+nbS),2), 'Profit Factor':abs(round((sum(winners)/sum(loosers)),2))}], ignore_index=True)


        #signals = signals.append([{ 'Date': list_signals[0], 'Ticker' : list_signals[8], 'Open Long' : list_signals[1],\
                                   #'Close Long' : list_signals[2], 'Open Short' : list_signals[3], 'Close Short' : list_signals[4],\
                                   #'Buy/Sell Price' : list_signals[5], 'Quantity' : list_signals[6], ' tPNL' : list_signals[7]}])

        #signals['Date'] = list_signals[0]
        #signals['Ticker'] = list_signals[8]
        #signals['Open Long'] = list_signals[1]
        #signals['Close Long'] = list_signals[2]
        #signals['Open Short'] = list_signals[3]
        #signals['Close Short'] = list_signals[4]
        #signals['Buy/Sell Price'] = list_signals[5]
        #signals['Quantity'] = list_signals[6]
        #signals['tPNL'] = list_signals[7]

    # symbol / name / sector / period of backtest / debut / fin / pnl / total winners / total loosers / Nb winners / nb loosers / 
    # / % winners / Max DD / Aver Win / Aver Loos / Average duration / Profit Factor
        print(Fore.YELLOW,'Writing BACKTEST CSV AND SIGNALS.CSV',Style.RESET_ALL)
        backtest.to_csv('BackTest.csv')
        signals.sort_values(by=['Date'])
        signals.to_csv('SIGNALS.csv')

        print(Fore.CYAN,'BACKTEST CSV WRITED AND SIGNALS.CSV',Style.RESET_ALL)
    except:
        print(Fore.RED,'Problème loop : ',loop,Style.RESET_ALL)
        error.append((loop,ticker))
         
        continue
# Out:
# Importing Librairies...
# Using TensorFlow backend.
# Librairies imported
#
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
# BOOST SKAN 55 Version v1.35
#
# Sraping tickers
# Scrap -----> ok
# Loop : 0
# amorce :  0
# amorce2 :  0
#  --- Loop : 0  ---  --- Symbol :   MMM   ---  --- Name :  3M Company  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.0658741671497383
#  Alpha :  0.05288355651620968
#  R_Squared :  0.5162105965962622
#  Volatility :  0.13902140071962835
#  Momentum :  0.3180824632539796
# executed in = 2.440000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:50:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.230000 seconds
#  Deeping in blue
#
#  --- Loop : 0  ---  --- Symbol :   MMM   ---  --- Name :  3M Company  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 63us/step
# 1005/1005 [==============================] - 0s 66us/step
# 202/202 [==============================] - 0s 19us/step
# 202/202 [==============================] - 0s 21us/step
#
#
#  RESULTATS UP
#
# Accuracy: 62.87%
#  Precision: 54.96%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 81.82%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.77      0.48      0.59       114
#            1       0.55      0.82      0.66        88
#
#    micro avg       0.63      0.63      0.63       202
#    macro avg       0.66      0.65      0.63       202
# weighted avg       0.68      0.63      0.62       202
#
# [[55 59]
#  [16 72]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 68.81%
#  Precision: 52.05%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 57.58%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.78      0.74      0.76       136
#            1       0.52      0.58      0.55        66
#
#    micro avg       0.69      0.69      0.69       202
#    macro avg       0.65      0.66      0.65       202
# weighted avg       0.70      0.69      0.69       202
#
# [[101  35]
#  [ 28  38]]
#
#
# Deep Learning executed in = 61.950000 seconds
#  Boucle  0 terminée...Opération restantes : 505 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 1
# amorce :  0
# amorce2 :  0
#  --- Loop : 1  ---  --- Symbol :   AOS   ---  --- Name :  A.O. Smith Corp  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.5180597845675035
#  Alpha :  0.0946833073124018
#  R_Squared :  0.4642855973814496
#  Volatility :  0.2087783449908988
#  Momentum :  0.29419220177565863
# executed in = 2.330000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:51:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.380000 seconds
#  Deeping in blue
#
#  --- Loop : 1  ---  --- Symbol :   AOS   ---  --- Name :  A.O. Smith Corp  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 95us/step
# 1005/1005 [==============================] - 0s 99us/step
# 202/202 [==============================] - 0s 21us/step
# 202/202 [==============================] - 0s 21us/step
#
#
#  RESULTATS UP
#
# Accuracy: 66.83%
#  Precision: 68.92%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 53.68%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.66      0.79      0.71       107
#            1       0.69      0.54      0.60        95
#
#    micro avg       0.67      0.67      0.67       202
#    macro avg       0.67      0.66      0.66       202
# weighted avg       0.67      0.67      0.66       202
#
# [[84 23]
#  [44 51]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 76.24%
#  Precision: 85.25%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 57.14%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.72      0.92      0.81       111
#            1       0.85      0.57      0.68        91
#
#    micro avg       0.76      0.76      0.76       202
#    macro avg       0.79      0.75      0.75       202
# weighted avg       0.78      0.76      0.75       202
#
# [[102   9]
#  [ 39  52]]
#
#
# Deep Learning executed in = 64.800000 seconds
#  Boucle  1 terminée...Opération restantes : 504 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 2
# amorce :  0
# amorce2 :  0
#  --- Loop : 2  ---  --- Symbol :   ABT   ---  --- Name :  Abbott Laboratories  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.5535942995933947
#  Alpha :  -0.06597156365741844
#  R_Squared :  0.5837359095015333
#  Volatility :  0.19055423041684716
#  Momentum :  0.48581098467953576
# executed in = 5.140000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:53:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.120000 seconds
#  Deeping in blue
#
#  --- Loop : 2  ---  --- Symbol :   ABT   ---  --- Name :  Abbott Laboratories  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 137us/step
# 1005/1005 [==============================] - 0s 132us/step
# 202/202 [==============================] - 0s 21us/step
# 202/202 [==============================] - 0s 22us/step
#
#
#  RESULTATS UP
#
# Accuracy: 81.68%
#  Precision: 74.29%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 88.64%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.76      0.82       114
#            1       0.74      0.89      0.81        88
#
#    micro avg       0.82      0.82      0.82       202
#    macro avg       0.82      0.82      0.82       202
# weighted avg       0.83      0.82      0.82       202
#
# [[87 27]
#  [10 78]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 78.71%
#  Precision: 66.94%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 96.43%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.96      0.66      0.78       118
#            1       0.67      0.96      0.79        84
#
#    micro avg       0.79      0.79      0.79       202
#    macro avg       0.82      0.81      0.79       202
# weighted avg       0.84      0.79      0.79       202
#
# [[78 40]
#  [ 3 81]]
#
#
# Deep Learning executed in = 67.430000 seconds
#  Boucle  2 terminée...Opération restantes : 503 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 3
# amorce :  0
# amorce2 :  0
#  --- Loop : 3  ---  --- Symbol :   ABBV   ---  --- Name :  AbbVie Inc.  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.5397139899244308
#  Alpha :  0.034609235198254235
#  R_Squared :  0.4102954604711334
#  Volatility :  0.22525834077834286
#  Momentum :  0.5443947737793715
# executed in = 2.150000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:54:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.680000 seconds
#  Deeping in blue
#
#  --- Loop : 3  ---  --- Symbol :   ABBV   ---  --- Name :  AbbVie Inc.  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 164us/step
# 1005/1005 [==============================] - 0s 165us/step
# 202/202 [==============================] - 0s 22us/step
# 202/202 [==============================] - 0s 24us/step
#
#
#  RESULTATS UP
#
# Accuracy: 82.67%
#  Precision: 83.16%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.61%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.83       104
#            1       0.83      0.81      0.82        98
#
#    micro avg       0.83      0.83      0.83       202
#    macro avg       0.83      0.83      0.83       202
# weighted avg       0.83      0.83      0.83       202
#
# [[88 16]
#  [19 79]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 75.25%
#  Precision: 88.89%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 41.03%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.72      0.97      0.83       124
#            1       0.89      0.41      0.56        78
#
#    micro avg       0.75      0.75      0.75       202
#    macro avg       0.81      0.69      0.69       202
# weighted avg       0.79      0.75      0.72       202
#
# [[120   4]
#  [ 46  32]]
#
#
# Deep Learning executed in = 71.250000 seconds
#  Boucle  3 terminée...Opération restantes : 502 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 4
# amorce :  0
# amorce2 :  0
#  --- Loop : 4  ---  --- Symbol :   ACN   ---  --- Name :  Accenture plc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.0348650333214666
#  Alpha :  0.03986496426437658
#  R_Squared :  0.3803683501397872
#  Volatility :  0.1572427778888457
#  Momentum :  0.3070093052821552
# executed in = 4.990000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:55:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.980000 seconds
#  Deeping in blue
#
#  --- Loop : 4  ---  --- Symbol :   ACN   ---  --- Name :  Accenture plc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 207us/step
# 1005/1005 [==============================] - 0s 204us/step
# 202/202 [==============================] - 0s 26us/step
# 202/202 [==============================] - 0s 24us/step
#
#
#  RESULTATS UP
#
# Accuracy: 83.17%
#  Precision: 76.72%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 92.71%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.92      0.75      0.82       106
#            1       0.77      0.93      0.84        96
#
#    micro avg       0.83      0.83      0.83       202
#    macro avg       0.84      0.84      0.83       202
# weighted avg       0.85      0.83      0.83       202
#
# [[79 27]
#  [ 7 89]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 85.64%
#  Precision: 79.52%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 84.62%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88       124
#            1       0.80      0.85      0.82        78
#
#    micro avg       0.86      0.86      0.86       202
#    macro avg       0.85      0.85      0.85       202
# weighted avg       0.86      0.86      0.86       202
#
# [[107  17]
#  [ 12  66]]
#
#
# Deep Learning executed in = 71.940000 seconds
#  Boucle  4 terminée...Opération restantes : 501 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 5
# amorce :  0
# amorce2 :  0
#  --- Loop : 5  ---  --- Symbol :   ATVI   ---  --- Name :  Activision Blizzard  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.0077345926175068
#  Alpha :  0.2652398086090076
#  R_Squared :  0.12007568287751502
#  Volatility :  0.27252592054852687
#  Momentum :  0.7535308397827178
# executed in = 2.180000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:57:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.960000 seconds
#  Deeping in blue
#
#  --- Loop : 5  ---  --- Symbol :   ATVI   ---  --- Name :  Activision Blizzard  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 258us/step
# 1005/1005 [==============================] - 0s 251us/step
# 202/202 [==============================] - 0s 25us/step
# 202/202 [==============================] - 0s 26us/step
#
#
#  RESULTATS UP
#
# Accuracy: 69.80%
#  Precision: 70.25%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 77.27%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.69      0.61      0.65        92
#            1       0.70      0.77      0.74       110
#
#    micro avg       0.70      0.70      0.70       202
#    macro avg       0.70      0.69      0.69       202
# weighted avg       0.70      0.70      0.70       202
#
# [[56 36]
#  [25 85]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 63.86%
#  Precision: 52.54%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 78.48%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.54      0.65       123
#            1       0.53      0.78      0.63        79
#
#    micro avg       0.64      0.64      0.64       202
#    macro avg       0.66      0.66      0.64       202
# weighted avg       0.69      0.64      0.64       202
#
# [[67 56]
#  [17 62]]
#
#
# Deep Learning executed in = 75.920000 seconds
#  Boucle  5 terminée...Opération restantes : 500 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 6
# amorce :  0
# amorce2 :  0
#  --- Loop : 6  ---  --- Symbol :   AYI   ---  --- Name :  Acuity Brands Inc  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.4933333626254386
#  Alpha :  0.05988839910688112
#  R_Squared :  0.1886208665849617
#  Volatility :  0.3222189520630367
#  Momentum :  -0.2376331996244987
# executed in = 2.480000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:58:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.550000 seconds
#  Deeping in blue
#
#  --- Loop : 6  ---  --- Symbol :   AYI   ---  --- Name :  Acuity Brands Inc  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 277us/step
# 1005/1005 [==============================] - 0s 277us/step
# 202/202 [==============================] - 0s 24us/step
# 202/202 [==============================] - 0s 29us/step
#
#
#  RESULTATS UP
#
# Accuracy: 77.72%
#  Precision: 68.87%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.88%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.88      0.72      0.79       117
#            1       0.69      0.86      0.76        85
#
#    micro avg       0.78      0.78      0.78       202
#    macro avg       0.78      0.79      0.78       202
# weighted avg       0.80      0.78      0.78       202
#
# [[84 33]
#  [12 73]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 80.69%
#  Precision: 93.94%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 63.92%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.74      0.96      0.84       105
#            1       0.94      0.64      0.76        97
#
#    micro avg       0.81      0.81      0.81       202
#    macro avg       0.84      0.80      0.80       202
# weighted avg       0.84      0.81      0.80       202
#
# [[101   4]
#  [ 35  62]]
#
#
# Deep Learning executed in = 77.730000 seconds
#  Boucle  6 terminée...Opération restantes : 499 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 7
# amorce :  0
# amorce2 :  0
#  --- Loop : 7  ---  --- Symbol :   ADBE   ---  --- Name :  Adobe Systems Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.1181148719992475
#  Alpha :  0.19712782996643455
#  R_Squared :  0.28187736351830517
#  Volatility :  0.19735380527455068
#  Momentum :  0.7021856307704932
# executed in = 2.340000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:59:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.750000 seconds
#  Deeping in blue
#
#  --- Loop : 7  ---  --- Symbol :   ADBE   ---  --- Name :  Adobe Systems Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 314us/step
# 1005/1005 [==============================] - 0s 304us/step
# 202/202 [==============================] - 0s 27us/step
# 202/202 [==============================] - 0s 28us/step
#
#
#  RESULTATS UP
#
# Accuracy: 50.00%
#  Precision: 46.70%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 95.51%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.14      0.24       113
#            1       0.47      0.96      0.63        89
#
#    micro avg       0.50      0.50      0.50       202
#    macro avg       0.63      0.55      0.43       202
# weighted avg       0.65      0.50      0.41       202
#
# [[16 97]
#  [ 4 85]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 67.33%
#  Precision: 68.06%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 53.26%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.67      0.79      0.72       110
#            1       0.68      0.53      0.60        92
#
#    micro avg       0.67      0.67      0.67       202
#    macro avg       0.67      0.66      0.66       202
# weighted avg       0.67      0.67      0.67       202
#
# [[87 23]
#  [43 49]]
#
#
# Deep Learning executed in = 81.620000 seconds
#  Boucle  7 terminée...Opération restantes : 498 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 8
# amorce :  0
# amorce2 :  0
#  --- Loop : 8  ---  --- Symbol :   AAP   ---  --- Name :  Advance Auto Parts  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  1.0253490444880045
#  Alpha :  -0.02388827380356936
#  R_Squared :  0.111842883112106
#  Volatility :  0.28731396469551196
#  Momentum :  -0.41053686542310663
# executed in = 2.650000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:01:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.270000 seconds
#  Deeping in blue
#
#  --- Loop : 8  ---  --- Symbol :   AAP   ---  --- Name :  Advance Auto Parts  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 349us/step
# 1005/1005 [==============================] - 0s 344us/step
# 202/202 [==============================] - 0s 29us/step
# 202/202 [==============================] - 0s 27us/step
#
#
#  RESULTATS UP
#
# Accuracy: 83.17%
#  Precision: 88.89%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 71.11%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86       112
#            1       0.89      0.71      0.79        90
#
#    micro avg       0.83      0.83      0.83       202
#    macro avg       0.84      0.82      0.82       202
# weighted avg       0.84      0.83      0.83       202
#
# [[104   8]
#  [ 26  64]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 84.16%
#  Precision: 85.56%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.21%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85       106
#            1       0.86      0.80      0.83        96
#
#    micro avg       0.84      0.84      0.84       202
#    macro avg       0.84      0.84      0.84       202
# weighted avg       0.84      0.84      0.84       202
#
# [[93 13]
#  [19 77]]
#
#
# Deep Learning executed in = 80.990000 seconds
#  Boucle  8 terminée...Opération restantes : 497 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 9
# amorce :  0
# amorce2 :  0
#  --- Loop : 9  ---  --- Symbol :   AMD   ---  --- Name :  Advanced Micro Devices Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  2.4953641848261214
#  Alpha :  0.10639148082561213
#  R_Squared :  0.19273511500474083
#  Volatility :  0.5326509363848048
#  Momentum :  -0.09347446255322989
# executed in = 2.290000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:02:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.990000 seconds
#  Deeping in blue
#
#  --- Loop : 9  ---  --- Symbol :   AMD   ---  --- Name :  Advanced Micro Devices Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 397us/step
# 1005/1005 [==============================] - 0s 384us/step
# 202/202 [==============================] - 0s 28us/step
# 202/202 [==============================] - 0s 33us/step
#
#
#  RESULTATS UP
#
# Accuracy: 80.20%
#  Precision: 74.02%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 93.07%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.91      0.67      0.77       101
#            1       0.74      0.93      0.82       101
#
#    micro avg       0.80      0.80      0.80       202
#    macro avg       0.82      0.80      0.80       202
# weighted avg       0.82      0.80      0.80       202
#
# [[68 33]
#  [ 7 94]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 77.72%
#  Precision: 75.56%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 74.73%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.80       111
#            1       0.76      0.75      0.75        91
#
#    micro avg       0.78      0.78      0.78       202
#    macro avg       0.78      0.77      0.77       202
# weighted avg       0.78      0.78      0.78       202
#
# [[89 22]
#  [23 68]]
#
#
# Deep Learning executed in = 84.630000 seconds
#  Boucle  9 terminée...Opération restantes : 496 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 10
# amorce :  0
# amorce2 :  0
#  --- Loop : 10  ---  --- Symbol :   AES   ---  --- Name :  AES Corp  ---  --- Sector :  Utilities  ---
# Scraping data...
# Beta :  1.2567543944408321
#  Alpha :  -0.13073386634698997
#  R_Squared :  0.2877490745998236
#  Volatility :  0.21954958759970436
#  Momentum :  -0.06798622802353116
# executed in = 2.180000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:04:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.750000 seconds
#  Deeping in blue
#
#  --- Loop : 10  ---  --- Symbol :   AES   ---  --- Name :  AES Corp  ---  --- Sector :  Utilities  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 421us/step
# 1005/1005 [==============================] - 0s 423us/step
# 202/202 [==============================] - 0s 41us/step
# 202/202 [==============================] - 0s 36us/step
#
#
#  RESULTATS UP
#
# Accuracy: 91.58%
#  Precision: 87.23%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 94.25%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92       115
#            1       0.87      0.94      0.91        87
#
#    micro avg       0.92      0.92      0.92       202
#    macro avg       0.91      0.92      0.91       202
# weighted avg       0.92      0.92      0.92       202
#
# [[103  12]
#  [  5  82]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 80.69%
#  Precision: 87.93%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 61.45%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85       119
#            1       0.88      0.61      0.72        83
#
#    micro avg       0.81      0.81      0.81       202
#    macro avg       0.83      0.78      0.79       202
# weighted avg       0.82      0.81      0.80       202
#
# [[112   7]
#  [ 32  51]]
#
#
# Deep Learning executed in = 88.340000 seconds
#  Boucle  10 terminée...Opération restantes : 495 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 11
# amorce :  0
# amorce2 :  0
#  --- Loop : 11  ---  --- Symbol :   AET   ---  --- Name :  Aetna Inc  ---  --- Sector :  Health Care  ---
# Scraping data...
#  Problème loop :  11
# Loop : 12
# amorce :  0
# amorce2 :  0
#  --- Loop : 12  ---  --- Symbol :   AMG   ---  --- Name :  Affiliated Managers Group Inc  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  1.6915408586619545
#  Alpha :  -0.1068424470458216
#  R_Squared :  0.4441863799381972
#  Volatility :  0.2378422773797866
#  Momentum :  0.41259460212734567
# executed in = 2.060000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:06:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.230000 seconds
#  Deeping in blue
#
#  --- Loop : 12  ---  --- Symbol :   AMG   ---  --- Name :  Affiliated Managers Group Inc  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 459us/step
# 1005/1005 [==============================] - 0s 453us/step
# 202/202 [==============================] - 0s 37us/step
# 202/202 [==============================] - 0s 29us/step
#
#
#  RESULTATS UP
#
# Accuracy: 85.15%
#  Precision: 82.08%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 88.78%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.89      0.82      0.85       104
#            1       0.82      0.89      0.85        98
#
#    micro avg       0.85      0.85      0.85       202
#    macro avg       0.85      0.85      0.85       202
# weighted avg       0.85      0.85      0.85       202
#
# [[85 19]
#  [11 87]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 82.67%
#  Precision: 79.22%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 76.25%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.85      0.87      0.86       122
#            1       0.79      0.76      0.78        80
#
#    micro avg       0.83      0.83      0.83       202
#    macro avg       0.82      0.82      0.82       202
# weighted avg       0.83      0.83      0.83       202
#
# [[106  16]
#  [ 19  61]]
#
#
# Deep Learning executed in = 90.220000 seconds
#  Boucle  12 terminée...Opération restantes : 493 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 13
# amorce :  0
# amorce2 :  0
#  --- Loop : 13  ---  --- Symbol :   AFL   ---  --- Name :  AFLAC Inc  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  1.0596588275911443
#  Alpha :  -0.017086514988497836
#  R_Squared :  0.4807400186117685
#  Volatility :  0.14321882403588085
#  Momentum :  0.2612069066630158
# executed in = 2.380000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:07:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.760000 seconds
#  Deeping in blue
#
#  --- Loop : 13  ---  --- Symbol :   AFL   ---  --- Name :  AFLAC Inc  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 498us/step
# 1005/1005 [==============================] - 1s 512us/step
# 202/202 [==============================] - 0s 34us/step
# 202/202 [==============================] - 0s 42us/step
#
#
#  RESULTATS UP
#
# Accuracy: 79.21%
#  Precision: 77.63%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 70.24%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83       118
#            1       0.78      0.70      0.74        84
#
#    micro avg       0.79      0.79      0.79       202
#    macro avg       0.79      0.78      0.78       202
# weighted avg       0.79      0.79      0.79       202
#
# [[101  17]
#  [ 25  59]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 75.74%
#  Precision: 63.78%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 96.43%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.96      0.61      0.75       118
#            1       0.64      0.96      0.77        84
#
#    micro avg       0.76      0.76      0.76       202
#    macro avg       0.80      0.79      0.76       202
# weighted avg       0.83      0.76      0.76       202
#
# [[72 46]
#  [ 3 81]]
#
#
# Deep Learning executed in = 92.930000 seconds
#  Boucle  13 terminée...Opération restantes : 492 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 14
# amorce :  0
# amorce2 :  0
#  --- Loop : 14  ---  --- Symbol :   A   ---  --- Name :  Agilent Technologies Inc  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.267263845742091
#  Alpha :  0.0142431409084076
#  R_Squared :  0.36581797452192066
#  Volatility :  0.19634674476248898
#  Momentum :  0.46992974543594834
# executed in = 2.190000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:09:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.050000 seconds
#  Deeping in blue
#
#  --- Loop : 14  ---  --- Symbol :   A   ---  --- Name :  Agilent Technologies Inc  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 558us/step
# 1005/1005 [==============================] - 1s 525us/step
# 202/202 [==============================] - 0s 30us/step
# 202/202 [==============================] - 0s 33us/step
#
#
#  RESULTATS UP
#
# Accuracy: 72.77%
#  Precision: 64.89%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 90.43%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.87      0.57      0.69       108
#            1       0.65      0.90      0.76        94
#
#    micro avg       0.73      0.73      0.73       202
#    macro avg       0.76      0.74      0.72       202
# weighted avg       0.77      0.73      0.72       202
#
# [[62 46]
#  [ 9 85]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 79.21%
#  Precision: 77.63%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 70.24%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83       118
#            1       0.78      0.70      0.74        84
#
#    micro avg       0.79      0.79      0.79       202
#    macro avg       0.79      0.78      0.78       202
# weighted avg       0.79      0.79      0.79       202
#
# [[101  17]
#  [ 25  59]]
#
#
# Deep Learning executed in = 93.890000 seconds
#  Boucle  14 terminée...Opération restantes : 491 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 15
# amorce :  0
# amorce2 :  0
#  --- Loop : 15  ---  --- Symbol :   APD   ---  --- Name :  Air Products & Chemicals Inc  ---  --- Sector :  Materials  ---
# Scraping data...
# Beta :  1.2830710382629025
#  Alpha :  0.00197232747988018
#  R_Squared :  0.46749537966569543
#  Volatility :  0.17585358305302876
#  Momentum :  0.1408704872414801
# executed in = 3.480000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:11:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.190000 seconds
#  Deeping in blue
#
#  --- Loop : 15  ---  --- Symbol :   APD   ---  --- Name :  Air Products & Chemicals Inc  ---  --- Sector :  Materials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 603us/step
# 1005/1005 [==============================] - 1s 621us/step
# 202/202 [==============================] - 0s 38us/step
# 202/202 [==============================] - 0s 44us/step
#
#
#  RESULTATS UP
#
# Accuracy: 80.20%
#  Precision: 71.82%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 89.77%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.73      0.81       114
#            1       0.72      0.90      0.80        88
#
#    micro avg       0.80      0.80      0.80       202
#    macro avg       0.81      0.81      0.80       202
# weighted avg       0.82      0.80      0.80       202
#
# [[83 31]
#  [ 9 79]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 75.25%
#  Precision: 61.06%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 92.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.93      0.65      0.77       127
#            1       0.61      0.92      0.73        75
#
#    micro avg       0.75      0.75      0.75       202
#    macro avg       0.77      0.79      0.75       202
# weighted avg       0.81      0.75      0.76       202
#
# [[83 44]
#  [ 6 69]]
#
#
# Deep Learning executed in = 98.380000 seconds
#  Boucle  15 terminée...Opération restantes : 490 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 16
# amorce :  0
# amorce2 :  0
#  --- Loop : 16  ---  --- Symbol :   AKAM   ---  --- Name :  Akamai Technologies Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  0.7183115784185561
#  Alpha :  0.06702328879113895
#  R_Squared :  0.03575225534338278
#  Volatility :  0.3560002690081513
#  Momentum :  -0.024595071717795514
# executed in = 2.060000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:13:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.380000 seconds
#  Deeping in blue
#
#  --- Loop : 16  ---  --- Symbol :   AKAM   ---  --- Name :  Akamai Technologies Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 624us/step
# 1005/1005 [==============================] - 1s 609us/step
# 202/202 [==============================] - 0s 34us/step
# 202/202 [==============================] - 0s 33us/step
#
#
#  RESULTATS UP
#
# Accuracy: 83.17%
#  Precision: 81.82%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 89.19%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.85      0.76      0.80        91
#            1       0.82      0.89      0.85       111
#
#    micro avg       0.83      0.83      0.83       202
#    macro avg       0.84      0.83      0.83       202
# weighted avg       0.83      0.83      0.83       202
#
# [[69 22]
#  [12 99]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 89.60%
#  Precision: 85.92%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 84.72%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92       130
#            1       0.86      0.85      0.85        72
#
#    micro avg       0.90      0.90      0.90       202
#    macro avg       0.89      0.89      0.89       202
# weighted avg       0.90      0.90      0.90       202
#
# [[120  10]
#  [ 11  61]]
#
#
# Deep Learning executed in = 102.030000 seconds
#  Boucle  16 terminée...Opération restantes : 489 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 17
# amorce :  0
# amorce2 :  0
#  --- Loop : 17  ---  --- Symbol :   ALK   ---  --- Name :  Alaska Air Group Inc  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.021731817888853
#  Alpha :  0.16006426889196074
#  R_Squared :  0.09264258874659403
#  Volatility :  0.31457250295427475
#  Momentum :  -0.1715316200257283
# executed in = 2.360000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:14:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.910000 seconds
#  Deeping in blue
#
#  --- Loop : 17  ---  --- Symbol :   ALK   ---  --- Name :  Alaska Air Group Inc  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 654us/step
# 1005/1005 [==============================] - 1s 651us/step
# 202/202 [==============================] - 0s 34us/step
# 202/202 [==============================] - 0s 35us/step
#
#
#  RESULTATS UP
#
# Accuracy: 79.70%
#  Precision: 85.07%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 64.77%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.84       114
#            1       0.85      0.65      0.74        88
#
#    micro avg       0.80      0.80      0.80       202
#    macro avg       0.81      0.78      0.79       202
# weighted avg       0.81      0.80      0.79       202
#
# [[104  10]
#  [ 31  57]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 78.22%
#  Precision: 81.82%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 67.74%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81       109
#            1       0.82      0.68      0.74        93
#
#    micro avg       0.78      0.78      0.78       202
#    macro avg       0.79      0.77      0.78       202
# weighted avg       0.79      0.78      0.78       202
#
# [[95 14]
#  [30 63]]
#
#
# Deep Learning executed in = 104.680000 seconds
#  Boucle  17 terminée...Opération restantes : 488 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 18
# amorce :  0
# amorce2 :  0
#  --- Loop : 18  ---  --- Symbol :   ALB   ---  --- Name :  Albemarle Corp  ---  --- Sector :  Materials  ---
# Scraping data...
# Beta :  1.7945037131130688
#  Alpha :  -0.032779836082420806
#  R_Squared :  0.37421292824088237
#  Volatility :  0.2748996257606911
#  Momentum :  0.4857109278488674
# executed in = 2.420000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:16:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.100000 seconds
#  Deeping in blue
#
#  --- Loop : 18  ---  --- Symbol :   ALB   ---  --- Name :  Albemarle Corp  ---  --- Sector :  Materials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 693us/step
# 1005/1005 [==============================] - 1s 683us/step
# 202/202 [==============================] - 0s 40us/step
# 202/202 [==============================] - 0s 41us/step
#
#
#  RESULTATS UP
#
# Accuracy: 67.33%
#  Precision: 75.61%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 57.41%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.62      0.79      0.69        94
#            1       0.76      0.57      0.65       108
#
#    micro avg       0.67      0.67      0.67       202
#    macro avg       0.69      0.68      0.67       202
# weighted avg       0.69      0.67      0.67       202
#
# [[74 20]
#  [46 62]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 82.18%
#  Precision: 75.31%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 79.22%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.85       125
#            1       0.75      0.79      0.77        77
#
#    micro avg       0.82      0.82      0.82       202
#    macro avg       0.81      0.82      0.81       202
# weighted avg       0.82      0.82      0.82       202
#
# [[105  20]
#  [ 16  61]]
#
#
# Deep Learning executed in = 104.920000 seconds
#  Boucle  18 terminée...Opération restantes : 487 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 19
# ...
#  Alpha :  -0.0047443698068423065
#  R_Squared :  0.34098319563963075
#  Volatility :  0.2300749626297304
#  Momentum :  0.18938503461535583
# executed in = 1.970000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [13:10:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.560000 seconds
#  Deeping in blue
#
#  --- Loop : 41  ---  --- Symbol :   AMGN   ---  --- Name :  Amgen Inc.  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 59us/step
# 202/202 [==============================] - 0s 64us/step
#
#
#  RESULTATS UP
#
# Accuracy: 78.22%
#  Precision: 69.17%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 92.22%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.91      0.67      0.77       112
#            1       0.69      0.92      0.79        90
#
#    micro avg       0.78      0.78      0.78       202
#    macro avg       0.80      0.80      0.78       202
# weighted avg       0.82      0.78      0.78       202
#
# [[75 37]
#  [ 7 83]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 73.27%
#  Precision: 97.06%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 38.37%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.68      0.99      0.81       116
#            1       0.97      0.38      0.55        86
#
#    micro avg       0.73      0.73      0.73       202
#    macro avg       0.83      0.69      0.68       202
# weighted avg       0.81      0.73      0.70       202
#
# [[115   1]
#  [ 53  33]]
#
#
# Deep Learning executed in = 156.940000 seconds
#  Boucle  41 terminée...Opération restantes : 464 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 42
# amorce :  0
# amorce2 :  0
#  --- Loop : 42  ---  --- Symbol :   APH   ---  --- Name :  Amphenol Corp  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  0.8172888999613701
#  Alpha :  0.10321317136962332
#  R_Squared :  0.3753713479328228
#  Volatility :  0.1250069679930921
#  Momentum :  0.30654772379501605
# executed in = 2.120000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [13:12:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.120000 seconds
#  Deeping in blue
#
#  --- Loop : 42  ---  --- Symbol :   APH   ---  --- Name :  Amphenol Corp  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 72us/step
# 202/202 [==============================] - 0s 67us/step
#
#
#  RESULTATS UP
#
# Accuracy: 69.31%
#  Precision: 64.80%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 81.82%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.77      0.57      0.66       103
#            1       0.65      0.82      0.72        99
#
#    micro avg       0.69      0.69      0.69       202
#    macro avg       0.71      0.70      0.69       202
# weighted avg       0.71      0.69      0.69       202
#
# [[59 44]
#  [18 81]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 69.80%
#  Precision: 70.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 49.41%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.70      0.85      0.76       117
#            1       0.70      0.49      0.58        85
#
#    micro avg       0.70      0.70      0.70       202
#    macro avg       0.70      0.67      0.67       202
# weighted avg       0.70      0.70      0.69       202
#
# [[99 18]
#  [43 42]]
#
#
# Deep Learning executed in = 159.590000 seconds
#  Boucle  42 terminée...Opération restantes : 463 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 43
# amorce :  0
# amorce2 :  0
#  --- Loop : 43  ---  --- Symbol :   APC   ---  --- Name :  Anadarko Petroleum Corp  ---  --- Sector :  Energy  ---
# Scraping data...
#  Problème loop :  43
# Loop : 44
# amorce :  0
# amorce2 :  0
#  --- Loop : 44  ---  --- Symbol :   ADI   ---  --- Name :  Analog Devices, Inc.  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.311927882703417
#  Alpha :  0.007133872355749117
#  R_Squared :  0.32877775258747566
#  Volatility :  0.21441142939121408
#  Momentum :  0.22597074376298032
# executed in = 64.330000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [13:18:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.710000 seconds
#  Deeping in blue
#
#  --- Loop : 44  ---  --- Symbol :   ADI   ---  --- Name :  Analog Devices, Inc.  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 74us/step
# 202/202 [==============================] - 0s 68us/step
#
#
#  RESULTATS UP
#
# Accuracy: 73.27%
#  Precision: 67.20%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 86.60%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.83      0.61      0.70       105
#            1       0.67      0.87      0.76        97
#
#    micro avg       0.73      0.73      0.73       202
#    macro avg       0.75      0.74      0.73       202
# weighted avg       0.75      0.73      0.73       202
#
# [[64 41]
#  [13 84]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 79.21%
#  Precision: 78.87%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 67.47%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83       119
#            1       0.79      0.67      0.73        83
#
#    micro avg       0.79      0.79      0.79       202
#    macro avg       0.79      0.77      0.78       202
# weighted avg       0.79      0.79      0.79       202
#
# [[104  15]
#  [ 27  56]]
#
#
# Deep Learning executed in = 160.330000 seconds
#  Boucle  44 terminée...Opération restantes : 461 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 45
# amorce :  0
# amorce2 :  0
#  --- Loop : 45  ---  --- Symbol :   ANDV   ---  --- Name :  Andeavor  ---  --- Sector :  Energy  ---
# Scraping data...
#  Problème loop :  45
# Loop : 46
# amorce :  0
# amorce2 :  0
#  --- Loop : 46  ---  --- Symbol :   ANSS   ---  --- Name :  ANSYS  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.0305599873484095
#  Alpha :  0.03205713917091176
#  R_Squared :  0.2782540132536011
#  Volatility :  0.18308035211791435
#  Momentum :  0.5957400772706152
# executed in = 5.170000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [13:25:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.540000 seconds
#  Deeping in blue
#
#  --- Loop : 46  ---  --- Symbol :   ANSS   ---  --- Name :  ANSYS  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 57us/step
# 202/202 [==============================] - 0s 74us/step
#
#
#  RESULTATS UP
#
# Accuracy: 73.27%
#  Precision: 87.30%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 54.46%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.67      0.92      0.78       101
#            1       0.87      0.54      0.67       101
#
#    micro avg       0.73      0.73      0.73       202
#    macro avg       0.77      0.73      0.72       202
# weighted avg       0.77      0.73      0.72       202
#
# [[93  8]
#  [46 55]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 67.82%
#  Precision: 55.56%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 14.93%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.69      0.94      0.80       135
#            1       0.56      0.15      0.24        67
#
#    micro avg       0.68      0.68      0.68       202
#    macro avg       0.62      0.54      0.52       202
# weighted avg       0.65      0.68      0.61       202
#
# [[127   8]
#  [ 57  10]]
#
#
# Deep Learning executed in = 174.140000 seconds
#  Boucle  46 terminée...Opération restantes : 459 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 47
# amorce :  0
# amorce2 :  0
#  --- Loop : 47  ---  --- Symbol :   ANTM   ---  --- Name :  Anthem Inc.  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  0.7910632500951553
#  Alpha :  0.17639852099060216
#  R_Squared :  0.14917578981385782
#  Volatility :  0.1919336919552332
#  Momentum :  0.5650691230447187
# executed in = 3.500000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [13:28:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.880000 seconds
#  Deeping in blue
#
#  --- Loop : 47  ---  --- Symbol :   ANTM   ---  --- Name :  Anthem Inc.  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 64us/step
# 202/202 [==============================] - 0s 67us/step
#
#
#  RESULTATS UP
#
# Accuracy: 75.74%
#  Precision: 79.59%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 72.90%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.72      0.79      0.75        95
#            1       0.80      0.73      0.76       107
#
#    micro avg       0.76      0.76      0.76       202
#    macro avg       0.76      0.76      0.76       202
# weighted avg       0.76      0.76      0.76       202
#
# [[75 20]
#  [29 78]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 73.27%
#  Precision: 60.34%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 89.74%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.91      0.63      0.74       124
#            1       0.60      0.90      0.72        78
#
#    micro avg       0.73      0.73      0.73       202
#    macro avg       0.76      0.76      0.73       202
# weighted avg       0.79      0.73      0.73       202
#
# [[78 46]
#  [ 8 70]]
#
#
# Deep Learning executed in = 162.480000 seconds
#  Boucle  47 terminée...Opération restantes : 458 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 48
# amorce :  0
# amorce2 :  0
#  --- Loop : 48  ---  --- Symbol :   AON   ---  --- Name :  Aon plc  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  1.043767356316547
#  Alpha :  0.055478603803250454
#  R_Squared :  0.416093422440989
#  Volatility :  0.15163430530582817
#  Momentum :  0.20147046952962255
# executed in = 2.400000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [13:31:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.520000 seconds
#  Deeping in blue
#
#  --- Loop : 48  ---  --- Symbol :   AON   ---  --- Name :  Aon plc  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 60us/step
# 202/202 [==============================] - 0s 77us/step
#
#
#  RESULTATS UP
#
# Accuracy: 57.43%
#  Precision: 72.41%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 21.21%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.55      0.92      0.69       103
#            1       0.72      0.21      0.33        99
#
#    micro avg       0.57      0.57      0.57       202
#    macro avg       0.64      0.57      0.51       202
# weighted avg       0.63      0.57      0.51       202
#
# [[95  8]
#  [78 21]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 62.38%
#  Precision: 48.65%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.42      0.59       130
#            1       0.49      1.00      0.65        72
#
#    micro avg       0.62      0.62      0.62       202
#    macro avg       0.74      0.71      0.62       202
# weighted avg       0.82      0.62      0.61       202
#
# [[54 76]
#  [ 0 72]]
#
#
# Deep Learning executed in = 163.540000 seconds
#  Boucle  48 terminée...Opération restantes : 457 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV

# %%
#import sys
#orig_stdout = sys.stdout
#f = open('backtestv2_4.txt', 'w')
#sys.stdout = f

# %%
#f.close()
#sys.stdout = orig_stdout

# %% [markdown]
# import pandas as pd
#
# backtest = pd.DataFrame(columns = ['Symb.','Name','Sector','period','Begin.','End',\
#                           'Pnl','%Pnl','Total Winners','Total Loosers','Nb Win','Nb Los',\
#                           '% Winners','MaxDD','%MaxDD','Aver. Win',\
#                           'Aver. Los','Aver. Duration',\
#                           'Total Trades','% Long','% Short','Profit Factor'])
# backtest.to_csv('BackTest.csv')
#
# signals = pd.DataFrame(columns = ['Date','Ticker','Open Long','Close Long','Open Short','Close Short','Buy/Sell Price','Quantity','tPNL'])
# signals.to_csv('SIGNALS.csv')

# %%
signals.tail()
# Out:
#            Date Ticker Open Long Close Long Open Short Close Short  \
# 9231 2017-12-22    AON         0          0          0           0
# 9232 2017-12-26    AON         0          0          0           0
# 9233 2017-12-27    AON         0          0          0           0
# 9234 2017-12-28    AON         0          0          0           0
# 9235 2017-12-28    AON         0          0          0           1
#
#      Buy/Sell Price Quantity     PNL Cumulative PNL Latent PNL
# 9231         138.57       69       0          756.4     338.79
# 9232         138.57       69       0          756.4     342.24
# 9233         138.57       69       0          756.4     280.83
# 9234         138.57       69       0          756.4     256.68
# 9235         134.85       71  264.12          756.4          0

# %%
signals.to_csv('SIGNALS.csv')
print(Fore.CYAN,'BACKTEST CSV WRITED AND SIGNALS.CSV',Style.RESET_ALL)
# Out:
#  BACKTEST CSV WRITED AND SIGNALS.CSV

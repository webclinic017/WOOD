# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
import talib
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from sklearn.preprocessing import MinMaxScaler
import yaml
from keras.models import model_from_yaml
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report


import xgboost as xgb
from xgboost import XGBRegressor, plot_importance
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')
import time
import datetime as dt
import os


import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

import warnings
#warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore')

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print(Fore.YELLOW,Back.BLUE,'BOOST LIVE SPN500 55 Version v1.50',Style.RESET_ALL)


constituents_csv = os.path.abspath('constituents_csv.csv')
constituents = pd.read_csv(constituents_csv)

yaml.warnings({'YAMLLoadWarning': False})

def scrap_data(ticker,start,end):
    df = web.DataReader(ticker,'yahoo',start,end)
    df = df.drop(['Close'],axis=1)
    df['Close'] = df['Adj Close']
    df = df.drop(['Adj Close'],axis = 1)    
    return(df)

def boost(df):
    X = df
    X = X.drop(['Close'],axis=1)
    X['Close'] = df['Close']
    y = X.iloc[:,-1]
    Xtrain = X.iloc[:-2,:-1]
    Xtest = X.iloc[-2:-1,:-1]
    yshift = y.shift(-1)
    ytrain = yshift.iloc[:-2]
    ytest = yshift.iloc[-2:-1]

    model = xgb.XGBRegressor(n_estimators=20000, objective='reg:squarederror',learning_rate=1, gamma=1, subsample=1, colsample_bytree=1, max_depth=100)

    model.fit( Xtrain, ytrain, early_stopping_rounds=150, eval_set=[(Xtest, ytest)], verbose=0)

    ytrain_pred = model.predict(Xtrain)

    y_pred = model.predict(Xtest)

    pred = model.predict(X.iloc[:,:-1])

    df['Close.S'] = pred
    df['Close.S2'] = df['Close.S']
    df = df.dropna()
    return(df)

def prepa_data(df):
    rsi = talib.RSI(df['Close'],timeperiod=14)
    stoc_slowk, stoc_slowd = talib.STOCH(df['High'],df['Low'],df['Close'])
    upper, middle, lower =  talib.BBANDS(df['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(df['Close'],timeperiod=5)
    sma8 = talib.SMA(df['Close'],timeperiod=8)
    sma10 = talib.SMA(df['Close'],timeperiod=10)
    sma12 = talib.SMA(df['Close'],timeperiod=12)
    sma15 = talib.SMA(df['Close'],timeperiod=15)
    sma30 = talib.SMA(df['Close'],timeperiod=30)
    sma35 = talib.SMA(df['Close'],timeperiod=35)
    sma40 = talib.SMA(df['Close'],timeperiod=40)
    sma45 = talib.SMA(df['Close'],timeperiod=45)
    sma50 = talib.SMA(df['Close'],timeperiod=50)
    atr = talib.ATR(df['High'],df['Low'],df['Close'],timeperiod=10)
    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50
    bbdelta = upper - middle
    price_bolup = df['Close'] - lower
    price_bolow = df['Close'] - upper
    Ema = talib.EMA(df['Close'],timeperiod=20)
    KC_High = Ema + 2*atr
    KC_Low = Ema - 2*atr
    aroondown, aroonup = talib.AROON(df['High'], df['Low'], timeperiod=9)
    aroon = aroonup - aroondown 
    rsi30_list = []
    rsi70_list = []
    for i in range(0,df.shape[0]):
        rsi70_list.append(70 - rsi[i])
        rsi30_list.append(rsi[i] - 30)
        
    varop_spy = df['Open'] - df['Close']
    varhl_spy = df['High'] - df['Low']
    df['Varop_Spy'] = varop_spy
    df['Varhl_spy'] = varhl_spy
    df['RSI'] = rsi
    df['70 - RSI'] = np.array(rsi70_list)
    df['RSI - 30'] = np.array(rsi30_list)
    df['BBD_Delta_Up'] = bbdelta
    df['delta5_8'] = delta5_8
    df['delta8_10'] = delta8_10
    df['delta10_12'] = delta10_12
    df['delta12_15'] = delta12_15
    df['delta15_30'] = delta15_30
    df['delta30_35'] = delta30_35
    df['delta35_40'] = delta35_40
    df['delta40_45'] = delta40_45
    df['delta45_50'] = delta45_50
    df['Stoc_Slowk'] = stoc_slowk
    df['Stoc_Slowd'] = stoc_slowd
    df['KC_High'] = KC_High
    df['KC_Low'] = KC_Low
    df['upper'] = upper
    df['lower'] = lower
    df['var_bollup_kchigh'] = upper-KC_High
    df['var_bolllow_kclow'] = lower-KC_Low
    df['Aroon Up'] = aroonup
    df['Aroon Down'] = aroondown
    df['Delta Aroon'] = aroon
    up = []
    down = []
    df = df.dropna()
    df = boost(df)
    df['%Futur'] = ((df['Close.S']-df['Close']) *100) / (df['Close'])
    df['%Futur2'] = ((df['Close.S2']-df['Close']) *100) / (df['Close'])
    for i in range(0,df.shape[0]-5):
        if df.iloc[i]['%Futur'] > 0.1 :
            up.append(1)
            down.append(0)
        elif df.iloc[i]['%Futur'] < -0.1: 
            up.append(0)
            down.append(1)
        else:
            up.append(0)
            down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    
    
    df['target_up'] = up  
    df['target_down'] = down 
    return(df)

def deep_learning(df):
    tmps1=time.time()
    X = df.iloc[:,1:-4]
    X.astype(np.float64)
    y_up = df.iloc[:,-2].values
    y_down = df.iloc[:,-1].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:bloc1,:]
    Xtest = X[bloc1:,:]
    ytrain_up = y_up[:bloc1,:]
    ytest_up = y_up[bloc1:,:]
    ytrain_down = y_down[:bloc1,:]
    ytest_down = y_down[bloc1:,:]

    seed = 770
    np.random.seed(seed)

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)

    accuracy_up = accuracy_score(ytest_up, yhat_up)
    accuracy_down = accuracy_score(ytest_down, yhat_down)

    precision_up = precision_score(ytest_up, yhat_up)  
    precision_down = precision_score(ytest_down, yhat_down) 


    recall_up = recall_score(ytest_up, yhat_up) 
    recall_down = recall_score(ytest_down, yhat_down) 

    resultats = pd.DataFrame()
    resultats['Date'] = df.index[bloc1:]
    resultats.index= df.index[bloc1:]
    resultats['Move Up'] = yhat_up
    resultats['Confiance up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confiance Down'] = (predict_down)*100
    resultats['Actual'] = df.iloc[bloc1:]['Close']
    resultats['Actual.S'] = df.iloc[bloc1:]['Close.S']
    open_S = df['Open'].shift(-1)
    resultats['Open.S'] = open_S.iloc[bloc1:]
    dmp_cp=[]
    dmp_cp = ((resultats['Confiance up']-resultats['Confiance Down'])/(resultats['Confiance up']+resultats['Confiance Down'])*100)
    resultats['DMP_CP'] = dmp_cp    
    return(resultats,precision_up,precision_down,scaler)

def grobeta(df,dfb):
    rts = df.resample('M').last()
    rbts = dfb.resample('M').last()
    dfsm = pd.DataFrame({'s_adjclose' : rts['Close'],
                            'b_adjclose' : rbts['Adj Close']},
                            index=rts.index)

    dfsm[['s_returns','b_returns']] = dfsm[['s_adjclose','b_adjclose']]/\
        dfsm[['s_adjclose','b_adjclose']].shift(1) -1
    dfsm = dfsm.dropna()
    covmat = np.cov(dfsm["s_returns"],dfsm["b_returns"])

    beta = covmat[0,1]/covmat[1,1]
    alpha= np.mean(dfsm["s_returns"])-beta*np.mean(dfsm["b_returns"])

    ypred = alpha + beta * dfsm["b_returns"]
    SS_res = np.sum(np.power(ypred-dfsm["s_returns"],2))
    SS_tot = covmat[0,0]*(len(dfsm)-1) # SS_tot is sample_variance*(n-1)
    r_squared = 1. - SS_res/SS_tot

    volatility = np.sqrt(covmat[0,0])
    momentum = np.prod(1+dfsm["s_returns"].tail(12).values) -1

    prd = 12. 
    alpha = alpha*prd
    volatility = volatility*np.sqrt(prd)
    return(beta,alpha,r_squared,volatility,momentum)

start =str(dt.date.today()-dt.timedelta(1110))
end = str(dt.date.today())
signals = pd.DataFrame(columns = ['Date','Ticker','Open Long','Close Long','Open Short','Close Short'])
global delta,bloc1,bloc2,model_up,model_down


GREEN = []
RED = []
GREEN_CLOSE = []
RED_CLOSE=[]
TICKER = []
DATE = []
i = -1

tmps55=time.time()
for loop in range(0,len(constituents)):
    print('- Loop : ',loop,' -',end='')
    try:
        tmps1=time.time()
        ticker = (constituents.iloc[loop]['Symbol'])
        name = constituents.iloc[loop]['Name']
        sector = constituents.iloc[loop]['Sector']

        yamlup = os.path.join(os.path.dirname(constituents_csv), 'DONNEES_DL/Save_'+ticker+'_up.yaml')
        yamldown = os.path.join(os.path.dirname(constituents_csv), 'DONNEES_DL/Save_'+ticker+'_down.yaml')
        modelup = os.path.join(os.path.dirname(constituents_csv), 'DONNEES_DL/Save_'+ticker+'_up.h5')
        modeldown = os.path.join(os.path.dirname(constituents_csv), 'DONNEES_DL/Save_'+ticker+'_down.h5')

        yaml_file_up = open(yamlup, 'r')
        yaml_file_down = open(yamldown, 'r')
        model_yaml_up = yaml_file_up.read()
        model_yaml_down = yaml_file_down.read()
        yaml_file_up.close()
        yaml_file_down.close()
        model_up = model_from_yaml(model_yaml_up)
        model_down = model_from_yaml(model_yaml_down)
        # load weights into new model
        model_up.load_weights(modelup)
        model_down.load_weights(modeldown)

        
        df = scrap_data(ticker,start,end)
        dfb = web.DataReader('^GSPC','yahoo',start,end)
        
        
        delta = round(df.shape[0])
        bloc1 = round(delta*0.80)
        bloc2 = delta - bloc1
       

        beta,alpha, r_squared, volatility, momentum = grobeta(df,dfb)

        
        df = prepa_data(df)

        
        resultats,precision_up,precision_down,scaler = deep_learning(df)

      
        if (precision_up * 100) > 59 and (precision_down * 100) > 59:
            
            ####################
            ##### SIGNALS #####
            ###################

            filtre_up = 93
            filtre_down = 97
            filtre_up_close = 80
            filtre_down_close = 80


            if resultats.iloc[i]['Confiance Down'] > filtre_down:
                doob = -1
            elif resultats.iloc[i]['Confiance Down'] > filtre_down_close and resultats.iloc[i]['Confiance Down'] < filtre_down :
                waab = -1
                doob = 0
            elif resultats.iloc[i]['Confiance up'] > filtre_up:
                doob = 1
            elif resultats.iloc[i]['Confiance up'] > filtre_up_close and resultats.iloc[i]['Confiance up'] < filtre_up:
                waab = 1
                doob = 0
            else :
                doob = 0
                waab = 0

            if doob == 1 :
                DATE.append(df.index[i])
                TICKER.append(ticker)
                GREEN.append(1)
                RED.append(0)
                GREEN_CLOSE.append(0)
                RED_CLOSE.append(1)

            elif doob == -1 :
                DATE.append(df.index[i])
                TICKER.append(ticker)
                GREEN.append(0)
                RED.append(1)
                GREEN_CLOSE.append(1)
                RED_CLOSE.append(0)

            elif doob == 0 and waab == -1 :
                DATE.append(df.index[i])
                TICKER.append(ticker)
                GREEN.append(0)
                RED.append(0)
                GREEN_CLOSE.append(0)
                RED_CLOSE.append(1)

            elif waab == 1 :
                DATE.append(df.index[i])
                TICKER.append(ticker)
                GREEN.append(0)
                RED.append(0)
                GREEN_CLOSE.append(1)
                RED_CLOSE.append(0)  

            else:
                DATE.append(df.index[i])
                TICKER.append(ticker)
                GREEN.append(0)
                RED.append(0)
                GREEN_CLOSE.append(0)
                RED_CLOSE.append(0)  

    
        else:
            print('\n',Fore.BLACK,Back.YELLOW,' Test de precision pour ',ticker,' non passé.',Style.RESET_ALL)
            DATE.append(df.index[i])
            TICKER.append(ticker)
            GREEN.append(0)
            RED.append(0)
            GREEN_CLOSE.append(0)
            RED_CLOSE.append(0)  
            

    except:
        print(Fore.RED,Back.GREEN,'Il y a un problème en loop ',loop,', avec le ticker ',ticker,'absent de la base.',Style.RESET_ALL)
        continue


signals['Date'] = DATE
signals['Ticker'] = TICKER
signals['Open Long'] = GREEN
signals['Close Long'] = GREEN_CLOSE
signals['Open Short'] = RED
signals['Close Short'] = RED_CLOSE        

try:
    print('Le fichier SIGNALS.csv existe déjà')
    signals_csv = pd.read_csv('SIGNALS.csv')
    signals_csv = signals_csv.drop('Unnamed: 0',axis=1)
    final_csv = pd.concat([signals_csv,signals],ignore_index=True)
    final_csv.to_csv('SIGNALS.csv')
    
except:
    print('Création du fichier SIGNALS.csv')
    signals.to_csv('SIGNALS.csv')        
        

tmps22=round(time.time()-tmps55,2)
print("Time for complete Signals Generation = %f" %tmps22,'seconds \n')
# Out:
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0813 02:04:00.895357 4519560640 deprecation.py:323] From /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/tensorflow/python/compat/v2_compat.py:61: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# W0813 02:04:00.924903 4519560640 deprecation_wrapper.py:119] From /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0813 02:04:00.938694 4519560640 deprecation_wrapper.py:119] From /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0813 02:04:01.024759 4519560640 deprecation_wrapper.py:119] From /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0813 02:04:01.025718 4519560640 deprecation_wrapper.py:119] From /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0813 02:04:01.026384 4519560640 deprecation_wrapper.py:119] From /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
#   BOOST LIVE SPN500 55 Version v1.50
# - Loop :  0  -- Loop :  1  -- Loop :  2  -
#     Test de precision pour  ABT  non passé.
# - Loop :  3  -- Loop :  4  -- Loop :  5  -- Loop :  6  -- Loop :  7  -
#     Test de precision pour  ADBE  non passé.
# - Loop :  8  -
#     Test de precision pour  AAP  non passé.
# - Loop :  9  -
#     Test de precision pour  AMD  non passé.
# - Loop :  10  -
#     Test de precision pour  AES  non passé.
# - Loop :  11  -  Il y a un problème en loop  11 , avec le ticker  AET absent de la base.
# - Loop :  12  -
#     Test de precision pour  AMG  non passé.
# - Loop :  13  -
#     Test de precision pour  AFL  non passé.
# - Loop :  14  -
#     Test de precision pour  A  non passé.
# - Loop :  15  -
#     Test de precision pour  APD  non passé.
# - Loop :  16  -- Loop :  17  -
#     Test de precision pour  ALK  non passé.
# - Loop :  18  -
#     Test de precision pour  ALB  non passé.
# - Loop :  19  -
#     Test de precision pour  ARE  non passé.
# - Loop :  20  -- Loop :  21  -
#     Test de precision pour  ALGN  non passé.
# - Loop :  22  -- Loop :  23  -- Loop :  24  -- Loop :  25  -
#     Test de precision pour  LNT  non passé.
# - Loop :  26  -- Loop :  27  -- Loop :  28  -- Loop :  29  -
#     Test de precision pour  MO  non passé.
# - Loop :  30  -
#     Test de precision pour  AMZN  non passé.
# - Loop :  31  -
#     Test de precision pour  AEE  non passé.
# - Loop :  32  -
#     Test de precision pour  AAL  non passé.
# - Loop :  33  -
#     Test de precision pour  AEP  non passé.
# - Loop :  34  -- Loop :  35  -
#     Test de precision pour  AIG  non passé.
# - Loop :  36  -
#     Test de precision pour  AMT  non passé.
# - Loop :  37  -
#     Test de precision pour  AWK  non passé.
# - Loop :  38  -
#     Test de precision pour  AMP  non passé.
# - Loop :  39  -
#     Test de precision pour  ABC  non passé.
# - Loop :  40  -- Loop :  41  -
#     Test de precision pour  AMGN  non passé.
# - Loop :  42  -
#     Test de precision pour  APH  non passé.
# - Loop :  43  -
#     Test de precision pour  APC  non passé.
# - Loop :  44  -
#     Test de precision pour  ADI  non passé.
# - Loop :  45  -  Il y a un problème en loop  45 , avec le ticker  ANDV absent de la base.
# - Loop :  46  -- Loop :  47  -
#     Test de precision pour  ANTM  non passé.
# - Loop :  48  -- Loop :  49  -- Loop :  50  -
#     Test de precision pour  AIV  non passé.
# - Loop :  51  -- Loop :  52  -- Loop :  53  -- Loop :  54  -
#     Test de precision pour  ADM  non passé.
# - Loop :  55  -
#     Test de precision pour  ARNC  non passé.
# - Loop :  56  -- Loop :  57  -
#     Test de precision pour  AIZ  non passé.
# - Loop :  58  -- Loop :  59  -
#     Test de precision pour  ADSK  non passé.
# - Loop :  60  -
#     Test de precision pour  ADP  non passé.
# - Loop :  61  -
#     Test de precision pour  AZO  non passé.
# - Loop :  62  -
#     Test de precision pour  AVB  non passé.
# - Loop :  63  -
#     Test de precision pour  AVY  non passé.
# - Loop :  64  -
#     Test de precision pour  BHGE  non passé.
# - Loop :  65  -
#     Test de precision pour  BLL  non passé.
# - Loop :  66  -- Loop :  67  -
#     Test de precision pour  BAX  non passé.
# - Loop :  68  -
#     Test de precision pour  BBT  non passé.
# - Loop :  69  -
#     Test de precision pour  BDX  non passé.
# - Loop :  70  -  Il y a un problème en loop  70 , avec le ticker  BRK.B absent de la base.
# - Loop :  71  -
#     Test de precision pour  BBY  non passé.
# - Loop :  72  -- Loop :  73  -- Loop :  74  -
#     Test de precision pour  HRB  non passé.
# - Loop :  75  -- Loop :  76  -
#     Test de precision pour  BKNG  non passé.
# - Loop :  77  -- Loop :  78  -
#     Test de precision pour  BXP  non passé.
# - Loop :  79  -
#     Test de precision pour  BSX  non passé.
# - Loop :  80  -
#     Test de precision pour  BHF  non passé.
# - Loop :  81  -
#     Test de precision pour  BMY  non passé.
# - Loop :  82  -
#     Test de precision pour  AVGO  non passé.
# - Loop :  83  -  Il y a un problème en loop  83 , avec le ticker  BF.B absent de la base.
# - Loop :  84  -
#     Test de precision pour  CHRW  non passé.
# - Loop :  85  -
#     Test de precision pour  CA  non passé.
# - Loop :  86  -
#     Test de precision pour  COG  non passé.
# - Loop :  87  -  Il y a un problème en loop  87 , avec le ticker  CDNS absent de la base.
# - Loop :  88  -  Il y a un problème en loop  88 , avec le ticker  CPB absent de la base.
# - Loop :  89  -  Il y a un problème en loop  89 , avec le ticker  COF absent de la base.
# - Loop :  90  -- Loop :  91  -
#     Test de precision pour  KMX  non passé.
# - Loop :  92  -
#     Test de precision pour  CCL  non passé.
# - Loop :  93  -
#     Test de precision pour  CAT  non passé.
# - Loop :  94  -- Loop :  95  -
#     Test de precision pour  CBRE  non passé.
# - Loop :  96  -
#     Test de precision pour  CBS  non passé.
# - Loop :  97  -- Loop :  98  -
#     Test de precision pour  CNC  non passé.
# - Loop :  99  -- Loop :  100  -
#     Test de precision pour  CTL  non passé.
# - Loop :  101  -- Loop :  102  -
#     Test de precision pour  CF  non passé.
# - Loop :  103  -- Loop :  104  -- Loop :  105  -
#     Test de precision pour  CVX  non passé.
# - Loop :  106  -- Loop :  107  -
#     Test de precision pour  CB  non passé.
# - Loop :  108  -
#     Test de precision pour  CHD  non passé.
# - Loop :  109  -- Loop :  110  -- Loop :  111  -
#     Test de precision pour  CINF  non passé.
# - Loop :  112  -
#     Test de precision pour  CTAS  non passé.
# - Loop :  113  -
#     Test de precision pour  CSCO  non passé.
# - Loop :  114  -
#     Test de precision pour  C  non passé.
# - Loop :  115  -
#     Test de precision pour  CFG  non passé.
# - Loop :  116  -
#     Test de precision pour  CTXS  non passé.
# - Loop :  117  -
#     Test de precision pour  CME  non passé.
# - Loop :  118  -
#     Test de precision pour  CMS  non passé.
# - Loop :  119  -
#     Test de precision pour  KO  non passé.
# - Loop :  120  -- Loop :  121  -
#     Test de precision pour  CL  non passé.
# - Loop :  122  -- Loop :  123  -- Loop :  124  -- Loop :  125  -
#     Test de precision pour  CXO  non passé.
# - Loop :  126  -
#     Test de precision pour  COP  non passé.
# - Loop :  127  -- Loop :  128  -- Loop :  129  -
#     Test de precision pour  GLW  non passé.
# - Loop :  130  -
#     Test de precision pour  COST  non passé.
# - Loop :  131  -
#     Test de precision pour  COTY  non passé.
# - Loop :  132  -
#     Test de precision pour  CCI  non passé.
# - Loop :  133  -  Il y a un problème en loop  133 , avec le ticker  CSRA absent de la base.
# - Loop :  134  -
#     Test de precision pour  CSX  non passé.
# - Loop :  135  -- Loop :  136  -- Loop :  137  -
#     Test de precision pour  DHI  non passé.
# - Loop :  138  -
#     Test de precision pour  DHR  non passé.
# - Loop :  139  -
#     Test de precision pour  DRI  non passé.
# - Loop :  140  -
#     Test de precision pour  DVA  non passé.
# - Loop :  141  -
#     Test de precision pour  DE  non passé.
# - Loop :  142  -
#     Test de precision pour  DAL  non passé.
# - Loop :  143  -- Loop :  144  -
#     Test de precision pour  DVN  non passé.
# - Loop :  145  -
#     Test de precision pour  DLR  non passé.
# - Loop :  146  -
#     Test de precision pour  DFS  non passé.
# - Loop :  147  -- Loop :  148  -
#     Test de precision pour  DISCK  non passé.
# - Loop :  149  -
#     Test de precision pour  DISH  non passé.
# - Loop :  150  -
#     Test de precision pour  DG  non passé.
# - Loop :  151  -
#     Test de precision pour  DLTR  non passé.
# - Loop :  152  -
#     Test de precision pour  D  non passé.
# - Loop :  153  -
#     Test de precision pour  DOV  non passé.
# - Loop :  154  -
#     Test de precision pour  DWDP  non passé.
# - Loop :  155  -  Il y a un problème en loop  155 , avec le ticker  DPS absent de la base.
# - Loop :  156  -
#     Test de precision pour  DTE  non passé.
# - Loop :  157  -
#     Test de precision pour  DUK  non passé.
# - Loop :  158  -- Loop :  159  -- Loop :  160  -- Loop :  161  -- Loop :  162  -
#     Test de precision pour  ETN  non passé.
# - Loop :  163  -
#     Test de precision pour  EBAY  non passé.
# - Loop :  164  -
#     Test de precision pour  ECL  non passé.
# - Loop :  165  -
#     Test de precision pour  EIX  non passé.
# - Loop :  166  -
#     Test de precision pour  EW  non passé.
# - Loop :  167  -- Loop :  168  -
#     Test de precision pour  EMR  non passé.
# - Loop :  169  -- Loop :  170  -  Il y a un problème en loop  170 , avec le ticker  EVHC absent de la base.
# - Loop :  171  -- Loop :  172  -
#     Test de precision pour  EQT  non passé.
# - Loop :  173  -
#     Test de precision pour  EFX  non passé.
# - Loop :  174  -
#     Test de precision pour  EQIX  non passé.
# - Loop :  175  -
#     Test de precision pour  EQR  non passé.
# - Loop :  176  -- Loop :  177  -
#     Test de precision pour  EL  non passé.
# - Loop :  178  -
#     Test de precision pour  RE  non passé.
# - Loop :  179  -- Loop :  180  -
#     Test de precision pour  EXC  non passé.
# - Loop :  181  -- Loop :  182  -- Loop :  183  -  Il y a un problème en loop  183 , avec le ticker  ESRX absent de la base.
# - Loop :  184  -- Loop :  185  -- Loop :  186  -- Loop :  187  -
#     Test de precision pour  FB  non passé.
# - Loop :  188  -
#     Test de precision pour  FAST  non passé.
# - Loop :  189  -
#     Test de precision pour  FRT  non passé.
# - Loop :  190  -
#     Test de precision pour  FDX  non passé.
# - Loop :  191  -- Loop :  192  -
#     Test de precision pour  FITB  non passé.
# - Loop :  193  -
#     Test de precision pour  FE  non passé.
# - Loop :  194  -
#     Test de precision pour  FISV  non passé.
# - Loop :  195  -- Loop :  196  -
#     Test de precision pour  FLS  non passé.
# - Loop :  197  -
#     Test de precision pour  FLR  non passé.
# - Loop :  198  -
#     Test de precision pour  FMC  non passé.
# - Loop :  199  -- Loop :  200  -
#     Test de precision pour  F  non passé.
# - Loop :  201  -
#     Test de precision pour  FTV  non passé.
# - Loop :  202  -
#     Test de precision pour  FBHS  non passé.
# - Loop :  203  -
#     Test de precision pour  BEN  non passé.
# - Loop :  204  -
#     Test de precision pour  FCX  non passé.
# - Loop :  205  -
#     Test de precision pour  GPS  non passé.
# - Loop :  206  -
#     Test de precision pour  GRMN  non passé.
# - Loop :  207  -
#     Test de precision pour  IT  non passé.
# - Loop :  208  -- Loop :  209  -
#     Test de precision pour  GE  non passé.
# - Loop :  210  -  Il y a un problème en loop  210 , avec le ticker  GGP absent de la base.
# - Loop :  211  -
#     Test de precision pour  GIS  non passé.
# - Loop :  212  -
#     Test de precision pour  GM  non passé.
# - Loop :  213  -
#     Test de precision pour  GPC  non passé.
# - Loop :  214  -- Loop :  215  -
#     Test de precision pour  GPN  non passé.
# - Loop :  216  -- Loop :  217  -- Loop :  218  -- Loop :  219  -
#     Test de precision pour  HAL  non passé.
# - Loop :  220  -
#     Test de precision pour  HBI  non passé.
# - Loop :  221  -
#     Test de precision pour  HOG  non passé.
# - Loop :  222  -
#     Test de precision pour  HRS  non passé.
# - Loop :  223  -- Loop :  224  -- Loop :  225  -
#     Test de precision pour  HCA  non passé.
# - Loop :  226  -
#     Test de precision pour  HCP  non passé.
# - Loop :  227  -- Loop :  228  -- Loop :  229  -
#     Test de precision pour  HES  non passé.
# - Loop :  230  -
#     Test de precision pour  HPE  non passé.
# - Loop :  231  -- Loop :  232  -- Loop :  233  -
#     Test de precision pour  HD  non passé.
# - Loop :  234  -- Loop :  235  -- Loop :  236  -
#     Test de precision pour  HST  non passé.
# - Loop :  237  -- Loop :  238  -- Loop :  239  -
#     Test de precision pour  HBAN  non passé.
# - Loop :  240  -- Loop :  241  -- Loop :  242  -
#     Test de precision pour  INFO  non passé.
# - Loop :  243  -
#     Test de precision pour  ITW  non passé.
# - Loop :  244  -
#     Test de precision pour  ILMN  non passé.
# - Loop :  245  -- Loop :  246  -
#     Test de precision pour  IR  non passé.
# - Loop :  247  -  Il y a un problème en loop  247 , avec le ticker  INTC absent de la base.
# - Loop :  248  -
#     Test de precision pour  ICE  non passé.
# - Loop :  249  -- Loop :  250  -
#     Test de precision pour  IP  non passé.
# - Loop :  251  -- Loop :  252  -
#     Test de precision pour  IFF  non passé.
# - Loop :  253  -
#     Test de precision pour  INTU  non passé.
# - Loop :  254  -
#     Test de precision pour  ISRG  non passé.
# - Loop :  255  -
#     Test de precision pour  IVZ  non passé.
# - Loop :  256  -- Loop :  257  -- Loop :  258  -
#     Test de precision pour  IRM  non passé.
# - Loop :  259  -- Loop :  260  -- Loop :  261  -
#     Test de precision pour  SJM  non passé.
# - Loop :  262  -- Loop :  263  -
#     Test de precision pour  JCI  non passé.
# - Loop :  264  -
#     Test de precision pour  JPM  non passé.
# - Loop :  265  -- Loop :  266  -
#     Test de precision pour  KSU  non passé.
# - Loop :  267  -
#     Test de precision pour  K  non passé.
# - Loop :  268  -- Loop :  269  -- Loop :  270  -
#     Test de precision pour  KIM  non passé.
# - Loop :  271  -
#     Test de precision pour  KMI  non passé.
# - Loop :  272  -
#     Test de precision pour  KLAC  non passé.
# - Loop :  273  -- Loop :  274  -
#     Test de precision pour  KHC  non passé.
# - Loop :  275  -- Loop :  276  -
#     Test de precision pour  LB  non passé.
# - Loop :  277  -
#     Test de precision pour  LLL  non passé.
# - Loop :  278  -- Loop :  279  -
#     Test de precision pour  LRCX  non passé.
# - Loop :  280  -- Loop :  281  -- Loop :  282  -  Il y a un problème en loop  282 , avec le ticker  LUK absent de la base.
# - Loop :  283  -
#     Test de precision pour  LLY  non passé.
# - Loop :  284  -- Loop :  285  -- Loop :  286  -
#     Test de precision pour  LMT  non passé.
# - Loop :  287  -
#     Test de precision pour  L  non passé.
# - Loop :  288  -
#     Test de precision pour  LOW  non passé.
# - Loop :  289  -- Loop :  290  -- Loop :  291  -
#     Test de precision pour  MAC  non passé.
# - Loop :  292  -- Loop :  293  -
#     Test de precision pour  MRO  non passé.
# - Loop :  294  -
#     Test de precision pour  MPC  non passé.
# - Loop :  295  -
#     Test de precision pour  MAR  non passé.
# - Loop :  296  -
#     Test de precision pour  MMC  non passé.
# - Loop :  297  -
#     Test de precision pour  MLM  non passé.
# - Loop :  298  -
#     Test de precision pour  MAS  non passé.
# - Loop :  299  -
#     Test de precision pour  MA  non passé.
# - Loop :  300  -- Loop :  301  -
#     Test de precision pour  MKC  non passé.
# - Loop :  302  -
#     Test de precision pour  MCD  non passé.
# - Loop :  303  -
#     Test de precision pour  MCK  non passé.
# - Loop :  304  -- Loop :  305  -
#     Test de precision pour  MRK  non passé.
# - Loop :  306  -- Loop :  307  -
#     Test de precision pour  MTD  non passé.
# - Loop :  308  -
#     Test de precision pour  MGM  non passé.
# - Loop :  309  -  Il y a un problème en loop  309 , avec le ticker  KORS absent de la base.
# - Loop :  310  -- Loop :  311  -
#     Test de precision pour  MU  non passé.
# - Loop :  312  -- Loop :  313  -
#     Test de precision pour  MAA  non passé.
# - Loop :  314  -
#     Test de precision pour  MHK  non passé.
# - Loop :  315  -
#     Test de precision pour  TAP  non passé.
# - Loop :  316  -
#     Test de precision pour  MDLZ  non passé.
# - Loop :  317  -  Il y a un problème en loop  317 , avec le ticker  MON absent de la base.
# - Loop :  318  -- Loop :  319  -- Loop :  320  -
#     Test de precision pour  MS  non passé.
# - Loop :  321  -
#     Test de precision pour  MSI  non passé.
# - Loop :  322  -
#     Test de precision pour  MYL  non passé.
# - Loop :  323  -- Loop :  324  -- Loop :  325  -
#     Test de precision pour  NAVI  non passé.
# - Loop :  326  -- Loop :  327  -- Loop :  328  -
#     Test de precision pour  NFLX  non passé.
# - Loop :  329  -
#     Test de precision pour  NWL  non passé.
# - Loop :  330  -  Il y a un problème en loop  330 , avec le ticker  NFX absent de la base.
# - Loop :  331  -- Loop :  332  -
#     Test de precision pour  NWSA  non passé.
# - Loop :  333  -
#     Test de precision pour  NWS  non passé.
# - Loop :  334  -
#     Test de precision pour  NEE  non passé.
# - Loop :  335  -- Loop :  336  -
#     Test de precision pour  NKE  non passé.
# - Loop :  337  -
#     Test de precision pour  NI  non passé.
# - Loop :  338  -- Loop :  339  -
#     Test de precision pour  JWN  non passé.
# - Loop :  340  -
#     Test de precision pour  NSC  non passé.
# - Loop :  341  -- Loop :  342  -
#     Test de precision pour  NOC  non passé.
# - Loop :  343  -
#     Test de precision pour  NCLH  non passé.
# - Loop :  344  -
#     Test de precision pour  NRG  non passé.
# - Loop :  345  -- Loop :  346  -
#     Test de precision pour  NVDA  non passé.
# - Loop :  347  -
#     Test de precision pour  ORLY  non passé.
# - Loop :  348  -
#     Test de precision pour  OXY  non passé.
# - Loop :  349  -
#     Test de precision pour  OMC  non passé.
# - Loop :  350  -
#     Test de precision pour  OKE  non passé.
# - Loop :  351  -  Il y a un problème en loop  351 , avec le ticker  ORCL absent de la base.
# - Loop :  352  -  Il y a un problème en loop  352 , avec le ticker  PCAR absent de la base.
# - Loop :  353  -  Il y a un problème en loop  353 , avec le ticker  PKG absent de la base.
# - Loop :  354  -  Il y a un problème en loop  354 , avec le ticker  PH absent de la base.
# - Loop :  355  -
#     Test de precision pour  PAYX  non passé.
# - Loop :  356  -
#     Test de precision pour  PYPL  non passé.
# - Loop :  357  -
#     Test de precision pour  PNR  non passé.
# - Loop :  358  -
#     Test de precision pour  PBCT  non passé.
# - Loop :  359  -
#     Test de precision pour  PEP  non passé.
# - Loop :  360  -- Loop :  361  -
#     Test de precision pour  PRGO  non passé.
# - Loop :  362  -
#     Test de precision pour  PFE  non passé.
# - Loop :  363  -
#     Test de precision pour  PCG  non passé.
# - Loop :  364  -
#     Test de precision pour  PM  non passé.
# - Loop :  365  -- Loop :  366  -
#     Test de precision pour  PNW  non passé.
# - Loop :  367  -- Loop :  368  -
#     Test de precision pour  PNC  non passé.
# - Loop :  369  -- Loop :  370  -
#     Test de precision pour  PPG  non passé.
# - Loop :  371  -- Loop :  372  -  Il y a un problème en loop  372 , avec le ticker  PX absent de la base.
# - Loop :  373  -- Loop :  374  -
#     Test de precision pour  PG  non passé.
# - Loop :  375  -- Loop :  376  -- Loop :  377  -
#     Test de precision pour  PRU  non passé.
# - Loop :  378  -  Il y a un problème en loop  378 , avec le ticker  PEG absent de la base.
# - Loop :  379  -  Il y a un problème en loop  379 , avec le ticker  PSA absent de la base.
# - Loop :  380  -  Il y a un problème en loop  380 , avec le ticker  PHM absent de la base.
# - Loop :  381  -- Loop :  382  -- Loop :  383  -  Il y a un problème en loop  383 , avec le ticker  QCOM absent de la base.
# - Loop :  384  -  Il y a un problème en loop  384 , avec le ticker  PWR absent de la base.
# - Loop :  385  -
#     Test de precision pour  DGX  non passé.
# - Loop :  386  -- Loop :  387  -
#     Test de precision pour  RJF  non passé.
# - Loop :  388  -- Loop :  389  -
#     Test de precision pour  O  non passé.
# - Loop :  390  -
#     Test de precision pour  RHT  non passé.
# - Loop :  391  -
#     Test de precision pour  REG  non passé.
# - Loop :  392  -
#     Test de precision pour  REGN  non passé.
# - Loop :  393  -
#     Test de precision pour  RF  non passé.
# - Loop :  394  -
#     Test de precision pour  RSG  non passé.
# - Loop :  395  -
#     Test de precision pour  RMD  non passé.
# - Loop :  396  -
#     Test de precision pour  RHI  non passé.
# - Loop :  397  -
#     Test de precision pour  ROK  non passé.
# - Loop :  398  -  Il y a un problème en loop  398 , avec le ticker  COL absent de la base.
# - Loop :  399  -- Loop :  400  -- Loop :  401  -- Loop :  402  -
#     Test de precision pour  SPGI  non passé.
# - Loop :  403  -- Loop :  404  -
#     Test de precision pour  SBAC  non passé.
# - Loop :  405  -
#     Test de precision pour  SCG  non passé.
# - Loop :  406  -- Loop :  407  -
#     Test de precision pour  STX  non passé.
# - Loop :  408  -
#     Test de precision pour  SEE  non passé.
# - Loop :  409  -- Loop :  410  -- Loop :  411  -
#     Test de precision pour  SPG  non passé.
# - Loop :  412  -- Loop :  413  -
#     Test de precision pour  SLG  non passé.
# - Loop :  414  -- Loop :  415  -
#     Test de precision pour  SO  non passé.
# - Loop :  416  -- Loop :  417  -
#     Test de precision pour  SWK  non passé.
# - Loop :  418  -
#     Test de precision pour  SBUX  non passé.
# - Loop :  419  -
#     Test de precision pour  STT  non passé.
# - Loop :  420  -- Loop :  421  -
#     Test de precision pour  SYK  non passé.
# - Loop :  422  -
#     Test de precision pour  STI  non passé.
# - Loop :  423  -- Loop :  424  -
#     Test de precision pour  SYMC  non passé.
# - Loop :  425  -
#     Test de precision pour  SYF  non passé.
# - Loop :  426  -
#     Test de precision pour  SNPS  non passé.
# - Loop :  427  -
#     Test de precision pour  SYY  non passé.
# - Loop :  428  -- Loop :  429  -
#     Test de precision pour  TTWO  non passé.
# - Loop :  430  -- Loop :  431  -
#     Test de precision pour  TGT  non passé.
# - Loop :  432  -- Loop :  433  -- Loop :  434  -
#     Test de precision pour  TXN  non passé.
# - Loop :  435  -- Loop :  436  -
#     Test de precision pour  BK  non passé.
# - Loop :  437  -- Loop :  438  -- Loop :  439  -
#     Test de precision pour  HSY  non passé.
# - Loop :  440  -
#     Test de precision pour  MOS  non passé.
# - Loop :  441  -
#     Test de precision pour  TRV  non passé.
# - Loop :  442  -
#     Test de precision pour  DIS  non passé.
# - Loop :  443  -- Loop :  444  -- Loop :  445  -
#     Test de precision pour  TWX  non passé.
# - Loop :  446  -
#     Test de precision pour  TJX  non passé.
# - Loop :  447  -
#     Test de precision pour  TMK  non passé.
# - Loop :  448  -
#     Test de precision pour  TSS  non passé.
# - Loop :  449  -
#     Test de precision pour  TSCO  non passé.
# - Loop :  450  -
#     Test de precision pour  TDG  non passé.
# - Loop :  451  -- Loop :  452  -  Il y a un problème en loop  452 , avec le ticker  FOXA absent de la base.
# - Loop :  453  -  Il y a un problème en loop  453 , avec le ticker  FOX absent de la base.
# - Loop :  454  -
#     Test de precision pour  TSN  non passé.
# - Loop :  455  -
#     Test de precision pour  USB  non passé.
# - Loop :  456  -
#     Test de precision pour  UDR  non passé.
# - Loop :  457  -
#     Test de precision pour  ULTA  non passé.
# - Loop :  458  -- Loop :  459  -  Il y a un problème en loop  459 , avec le ticker  UA absent de la base.
# - Loop :  460  -
#     Test de precision pour  UNP  non passé.
# - Loop :  461  -
#     Test de precision pour  UAL  non passé.
# - Loop :  462  -
#     Test de precision pour  UNH  non passé.
# - Loop :  463  -
#     Test de precision pour  UPS  non passé.
# - Loop :  464  -- Loop :  465  -
#     Test de precision pour  UTX  non passé.
# - Loop :  466  -
#     Test de precision pour  UHS  non passé.
# - Loop :  467  -
#     Test de precision pour  UNM  non passé.
# - Loop :  468  -
#     Test de precision pour  VFC  non passé.
# - Loop :  469  -- Loop :  470  -
#     Test de precision pour  VAR  non passé.
# - Loop :  471  -
#     Test de precision pour  VTR  non passé.
# - Loop :  472  -
#     Test de precision pour  VRSN  non passé.
# - Loop :  473  -
#     Test de precision pour  VRSK  non passé.
# - Loop :  474  -- Loop :  475  -- Loop :  476  -
#     Test de precision pour  VIAB  non passé.
# - Loop :  477  -- Loop :  478  -- Loop :  479  -
#     Test de precision pour  VMC  non passé.
# - Loop :  480  -
#     Test de precision pour  WMT  non passé.
# - Loop :  481  -
#     Test de precision pour  WBA  non passé.
# - Loop :  482  -
#     Test de precision pour  WM  non passé.
# - Loop :  483  -
#     Test de precision pour  WAT  non passé.
# - Loop :  484  -
#     Test de precision pour  WEC  non passé.
# - Loop :  485  -
#     Test de precision pour  WFC  non passé.
# - Loop :  486  -- Loop :  487  -- Loop :  488  -
#     Test de precision pour  WU  non passé.
# - Loop :  489  -- Loop :  490  -
#     Test de precision pour  WY  non passé.
# - Loop :  491  -- Loop :  492  -
#     Test de precision pour  WMB  non passé.
# - Loop :  493  -
#     Test de precision pour  WLTW  non passé.
# - Loop :  494  -  Il y a un problème en loop  494 , avec le ticker  WYN absent de la base.
# - Loop :  495  -- Loop :  496  -- Loop :  497  -
#     Test de precision pour  XRX  non passé.
# - Loop :  498  -
#     Test de precision pour  XLNX  non passé.
# - Loop :  499  -  Il y a un problème en loop  499 , avec le ticker  XL absent de la base.
# - Loop :  500  -
#     Test de precision pour  XYL  non passé.
# - Loop :  501  -
#     Test de precision pour  YUM  non passé.
# - Loop :  502  -
#     Test de precision pour  ZBH  non passé.
# - Loop :  503  -- Loop :  504  -
#     Test de precision pour  ZTS  non passé.
# Le fichier SIGNALS.csv existe déjà
# Time for complete Signals Generation = 4782.830000 seconds

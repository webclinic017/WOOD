# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
print('Importing Librairies...')
import talib
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import xgboost as xgb
from xgboost import XGBRegressor, plot_importance
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')
import time
import datetime as dt
import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
print('Librairies imported')
print('')

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print('BOOST SKAN 55 Version v1.35',Style.RESET_ALL)



print('')
print('Sraping tickers')
constituents = pd.read_csv('constituents_csv.csv')
print('Scrap -----> ok')
# PARAMETRES TEMPORELS INITIAUX
start = pd.to_datetime('2015-01-01')
end = pd.to_datetime('2019-12-31')

error = []


try :
    amorce = pd.read_csv('backTest.csv').index[-1] + 1
except:
    amorce = 0
    backtest = pd.DataFrame(columns = ['Symb.','Name','Sector','Period','Begin.','End',\
                          'Pnl $','Pnl %','Gross Profit','Gross Loss','# Winners','# Loosers',\
                          '% Winners','MaxDD $','MaxDD %','Aver. Win $',\
                          'Aver. Loos $','Aver. Duration',\
                          'Total Trades','% Long','% Short','Profit Factor'])
    
    
try:
    amorce2 = pd.read_csv('SIGNALS.csv').index[-1] + 1
except:
    amorce2 = 0
    signals = pd.DataFrame(columns = ['Date','Ticker','Open Long','Close Long','Open Short','Close Short','Buy/Sell Price','Quantity','PNL','Cumulative PNL','Latent PNL'])

    
# SCRAPING DES DONNES BRUTES
def scrap_data(ticker,start,end):
    df = web.DataReader(ticker,'yahoo',start,end)
    df = df.drop(['Close'],axis=1)
    df['Close'] = df['Adj Close']
    df = df.drop(['Adj Close'],axis = 1)    
    return(df)

def prepa_data(df):
    tmps1=time.time()
    print('Preparing data...')
    rsi = talib.RSI(df['Close'],timeperiod=14)
    stoc_slowk, stoc_slowd = talib.STOCH(df['High'],df['Low'],df['Close'])
    upper, middle, lower =  talib.BBANDS(df['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(df['Close'],timeperiod=5)
    sma8 = talib.SMA(df['Close'],timeperiod=8)
    sma10 = talib.SMA(df['Close'],timeperiod=10)
    sma12 = talib.SMA(df['Close'],timeperiod=12)
    sma15 = talib.SMA(df['Close'],timeperiod=15)
    sma30 = talib.SMA(df['Close'],timeperiod=30)
    sma35 = talib.SMA(df['Close'],timeperiod=35)
    sma40 = talib.SMA(df['Close'],timeperiod=40)
    sma45 = talib.SMA(df['Close'],timeperiod=45)
    sma50 = talib.SMA(df['Close'],timeperiod=50)
    atr = talib.ATR(df['High'],df['Low'],df['Close'],timeperiod=10)
    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50
    bbdelta = upper - middle
    price_bolup = df['Close'] - lower
    price_bolow = df['Close'] - upper
    Ema = talib.EMA(df['Close'],timeperiod=20)
    KC_High = Ema + 2*atr
    KC_Low = Ema - 2*atr
    aroondown, aroonup = talib.AROON(df['High'], df['Low'], timeperiod=9)
    aroon = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
    rsi30_list = []
    rsi70_list = []
    for i in range(0,df.shape[0]):
        rsi70_list.append(70 - rsi[i])
        rsi30_list.append(rsi[i] - 30)
        #except:
         #   rsi70_list.append(0)
          #  rs30_list.append(0)
    varop_spy = df['Open'] - df['Close']
    varhl_spy = df['High'] - df['Low']
    df['Varop_Spy'] = varop_spy
    df['Varhl_spy'] = varhl_spy
    df['RSI'] = rsi
    df['70 - RSI'] = np.array(rsi70_list)
    df['RSI - 30'] = np.array(rsi30_list)
    df['BBD_Delta_Up'] = bbdelta
    df['delta5_8'] = delta5_8
    df['delta8_10'] = delta8_10
    df['delta10_12'] = delta10_12
    df['delta12_15'] = delta12_15
    df['delta15_30'] = delta15_30
    df['delta30_35'] = delta30_35
    df['delta35_40'] = delta35_40
    df['delta40_45'] = delta40_45
    df['delta45_50'] = delta45_50
    df['Stoc_Slowk'] = stoc_slowk
    df['Stoc_Slowd'] = stoc_slowd
    df['KC_High'] = KC_High
    df['KC_Low'] = KC_Low
    df['upper'] = upper
    df['lower'] = lower
    df['var_bollup_kchigh'] = upper-KC_High
    df['var_bolllow_kclow'] = lower-KC_Low
    df['Aroon Up'] = aroonup
    df['Aroon Down'] = aroondown
    df['Delta Aroon'] = aroon
    up = []
    down = []
    df = df.dropna()
    df = boost(df)
    df['%Futur'] = ((df['Close.S']-df['Close']) *100) / (df['Close'])
    df['%Futur2'] = ((df['Close.S2']-df['Close']) *100) / (df['Close'])
    for i in range(0,df.shape[0]-5):
        if df.iloc[i]['%Futur'] > 0.1 :#or df.iloc[i]['%Futur2'] > 0.1:
            up.append(1)
            down.append(0)
        elif df.iloc[i]['%Futur'] < -0.1: #or df.iloc[i]['%Futur2'] < -0.1:
            up.append(0)
            down.append(1)
        else:
            up.append(0)
            down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    
    
    df['target_up'] = up  # target_up # abs(np.array(valley))#target_up
    df['target_down'] = down # target_down # abs(np.array(peak))#target_down
    #df = df.dropna()
    tmps2=round(time.time()-tmps1,2)
    print ("Data prepared in = %f" %tmps2,'seconds')
    return(df)

def boost(df):
    print('Boosting')
    X = df.copy()
    X = X.drop(['Close'],axis=1)
    X['Close'] = df['Close']
    y = X.iloc[:,-1]
    Xtrain = X.iloc[:-2,:-1]
    Xtest = X.iloc[-2:-1,:-1]
    yshift = y.shift(-1)
    ytrain = yshift.iloc[:-2]
    ytest = yshift.iloc[-2:-1]

    model = xgb.XGBRegressor(n_estimators=20000, learning_rate=1, gamma=1, subsample=1, colsample_bytree=1, max_depth=100)

    model.fit( Xtrain, ytrain, early_stopping_rounds=150, eval_set=[(Xtest, ytest)], verbose=0)

    ytrain_pred = model.predict(Xtrain)

    y_pred = model.predict(Xtest)

    pred = model.predict(X.iloc[:,:-1])

    df['Close.S'] = pred
    df['Close.S2'] = df['Close.S']
    df = df.dropna()
    print('Boost ok')
    return(df)

    
def deep_learning(df):
    tmps1=time.time()
    X = df.iloc[:,1:-4]
    y_up = df.iloc[:,-2].values
    y_down = df.iloc[:,-1].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:bloc1,:]
    Xtest = X[bloc1:,:]
    ytrain_up = y_up[:bloc1,:]
    ytest_up = y_up[bloc1:,:]
    ytrain_down = y_down[:bloc1,:]
    ytest_down = y_down[bloc1:,:]

    seed = 770
    np.random.seed(seed)

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    model_up = Sequential()
    # Add an input layer 
    model_up.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_up.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_up.add(Dense(1, activation='sigmoid'))

    model_down = Sequential()
    # Add an input layer 
    model_down.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_down.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_down.add(Dense(1, activation='sigmoid'))

    print('Processing move_up')
    model_up.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])
    
              

    history_up = model_up.fit(Xtrain, ytrain_up,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Processing move_down')
    model_down.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])

    history_down = model_down.fit(Xtrain, ytrain_down,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Computing done')
    print('\n')

    train_acc_up = model_up.evaluate(Xtrain, ytrain_up,verbose=1)
    train_acc_down = model_down.evaluate(Xtrain, ytrain_down,verbose=1)

    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    score_up = model_up.evaluate(Xtest, ytest_up,verbose=1)
    score_down = model_down.evaluate(Xtest, ytest_down,verbose=1)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)

    accuracy_up = accuracy_score(ytest_up, yhat_up)
    accuracy_down = accuracy_score(ytest_down, yhat_down)

    # La précision permet de mesurer la capacité du modèle à refuser résultats non-pertinents : vrais_positifs/(vrais_positifs+faux_positifs)
    precision_up = precision_score(ytest_up, yhat_up)  
    precision_down = precision_score(ytest_down, yhat_down) 


    # Recall : (vrai_positifs/(vrais_positifs+faux_négatifs))
    recall_up = recall_score(ytest_up, yhat_up) 
    recall_down = recall_score(ytest_down, yhat_down) 


    #roc_up=roc_auc_score(ytest_up,yhat_up)
    #roc_down=roc_auc_score(ytest_down,yhat_down)
    print('\n')
    print(Fore.GREEN,'RESULTATS UP\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_up * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_up *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_up * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_up *100))
    # get probabilities for positive class

    print(classification_report(ytest_up, yhat_up))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_up, yhat_up))

    print('\n')
    print('_______________________________________________________________________________________________________________________________________________________________\n')
    print(Fore.RED,'RESULTATS DOWN\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_down * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_down *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_down * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_down *100))
    # get probabilities for positive class

    print(classification_report(ytest_down, yhat_down))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_down, yhat_down))
    print('\n')

    resultats = pd.DataFrame()
    resultats['Date'] = df.index[bloc1:]
    resultats.index= df.index[bloc1:]
    resultats['Move Up'] = yhat_up
    resultats['Confiance up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confiance Down'] = (predict_down)*100
    resultats['Actual'] = df.iloc[bloc1:]['Close']
    resultats['Actual.S'] = df.iloc[bloc1:]['Close.S']
    open_S = df['Open'].shift(-1)
    resultats['Open.S'] = open_S.iloc[bloc1:]
    dmp_cp=[]
    dmp_cp = ((resultats['Confiance up']-resultats['Confiance Down'])/(resultats['Confiance up']+resultats['Confiance Down'])*100)
    resultats['DMP_CP'] = dmp_cp
    tmps2=round(time.time()-tmps1,2)
    print ("Deep Learning executed in = %f" %tmps2,'seconds')
    #resultats.set_index('Date',inplace=True)
    #parse_dates=resultats['Date']
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def learn(df):
    resultats,precision_up,precision_down,model_up,model_down,scaler = deep_learning(df)
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def grobeta(df,dfb):
    # create a time-series of monthly data points
    rts = df.resample('M').last()
    rbts = dfb.resample('M').last()
    dfsm = pd.DataFrame({'s_adjclose' : rts['Close'],
                            'b_adjclose' : rbts['Adj Close']},
                            index=rts.index)

    # compute returns
    dfsm[['s_returns','b_returns']] = dfsm[['s_adjclose','b_adjclose']]/\
        dfsm[['s_adjclose','b_adjclose']].shift(1) -1
    dfsm = dfsm.dropna()
    covmat = np.cov(dfsm["s_returns"],dfsm["b_returns"])

    # calculate measures now
    beta = covmat[0,1]/covmat[1,1]
    alpha= np.mean(dfsm["s_returns"])-beta*np.mean(dfsm["b_returns"])

    # r_squared     = 1. - SS_res/SS_tot
    ypred = alpha + beta * dfsm["b_returns"]
    SS_res = np.sum(np.power(ypred-dfsm["s_returns"],2))
    SS_tot = covmat[0,0]*(len(dfsm)-1) # SS_tot is sample_variance*(n-1)
    r_squared = 1. - SS_res/SS_tot
    # 5- year volatiity and 1-year momentum
    volatility = np.sqrt(covmat[0,0])
    momentum = np.prod(1+dfsm["s_returns"].tail(12).values) -1

    # annualize the numbers
    prd = 12. # used monthly returns; 12 periods to annualize
    alpha = alpha*prd
    volatility = volatility*np.sqrt(prd)

    print ('Beta : ',beta,'\n Alpha : ',alpha,'\n R_Squared : ', r_squared, '\n Volatility : ', volatility, '\n Momentum : ',momentum)
    return(beta,alpha,r_squared,volatility,momentum)

########################
#### MAIN SKAN55 #######
########################

    
for loop in range(amorce,len(constituents)):
    print('Loop :',loop)
    print('amorce : ',amorce)
    print('amorce2 : ',amorce2)
    
    try:

        ticker = (constituents.iloc[loop]['Symbol'])
        name = constituents.iloc[loop]['Name']
        sector = constituents.iloc[loop]['Sector']

        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        global delta,bloc1,bloc2
        tmps1=time.time()
        print('Scraping data...')

        df = scrap_data(ticker,start,end)

        dfb = web.DataReader('^GSPC','yahoo',start,end)

        beta,alpha, r_squared, volatility, momentum = grobeta(df,dfb)

        tmps2=round(time.time()-tmps1,2)
        print ("executed in = %f" %tmps2,'seconds')

        print('\n')
        print('GOLEM begins Computing...')
        print('\n')
        delta = round(df.shape[0])
        bloc1 = round(delta*0.80)
        bloc2 = delta - bloc1
        print("# of periods : ",delta)
        print('On 80% - 20% slash : ')
        print('Bloc 1 : ',bloc1,'\nBloc 2 :',bloc2,' periods ')
        print('First period :',df.index[0])
        print('Split period :',df.index[bloc1-1])
        print('Last period :',df.index[df.shape[0]-1])
        print('\n')

        print('Data prep')
        df = prepa_data(df)

        print(Fore.BLUE,'Deeping in blue',Style.RESET_ALL)
        print('')
        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        resultats,precision_up,precision_down,model_up,model_down,scaler = learn(df)

        import sys
        orig_stdout = sys.stdout
        f = open('backtest de '+str(ticker)+'.txt', 'w')
        sys.stdout = f

        ####################
        #### TEST PLOT ####
        ###################

        filtre_up = 93
        filtre_down = 97
        filtre_up_close = 80
        filtre_down_close = 80


        plt.figure(figsize=(26,8),dpi=300)
        #plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
        plt.title('Deep Learning '+name+' Trade Signals')
        plt.plot(resultats['Actual'],color='purple',lw=0.9,label=ticker)

        green=[]
        red=[]
        green_close=[]
        red_close=[]

        for i in range(0,len(resultats)-1):


            if resultats.iloc[i]['Confiance Down'] > filtre_down:
                doob = -1
            elif resultats.iloc[i]['Confiance Down'] > filtre_down_close and resultats.iloc[i]['Confiance Down'] < filtre_down :
                waab = -1
                doob = 0
            elif resultats.iloc[i]['Confiance up'] > filtre_up:
                doob = 1
            elif resultats.iloc[i]['Confiance up'] > filtre_up_close and resultats.iloc[i]['Confiance up'] < filtre_up:
                waab = 1
                doob = 0
            else :
                doob = 0
                waab = 0

            if doob == 1 :#and resultats.iloc[i]['Confiance up'] > filtre_up:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='g',marker='o')
                #doob = -1
                green.append(1)
                red.append(0)
                green_close.append(0)
                red_close.append(1)

            elif doob == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(1)
                green_close.append(1)
                red_close.append(0)

            elif doob == 0 and waab == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(0)
                green_close.append(0)
                red_close.append(1)

            elif waab == 1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(0)
                green_close.append(1)
                red_close.append(0)  

            else:
                green.append(0)
                red.append(0)
                green_close.append(0)
                red_close.append(0)  

                #doob = 0


        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='g',marker='o',label='Buy Signal')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o',label='Sell Signal')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_01.pdf')
        plt.close()


        green.append(0)
        red.append(0)
        green_close.append(0)
        red_close.append(0)
        resultats['Green'] = green
        resultats['Red'] = red
        resultats['Green_Close'] = green_close
        resultats['Red_Close'] = red_close
        #resultats['Actual'] = df['Close'][bloc1:]

        ########################
        ####### BACKTEST########
        ########################
        pos_long = 0
        pos_short = 0
        pactol = 10000/beta
        price_buy = 0
        price_sell = 0
        x = 0
        winners = []
        loosers = []
        nb_win = 0
        nb_los = 0
        mini_pnl = 0
        pos_duration = []
        average_duration = resultats.iloc[0,0] - resultats.iloc[0,0]
        trades = []
        eq_curx = []
        eq_cury = []
        maxdd = []
        nbS = 0
        nbL = 0

        for i in range(0,len(resultats)-1):
            if pos_long == 0 and pos_short == 0 and resultats.iloc[i]['Green'] == 1 :
                pos_long = 1
                nbL+=1
                x = round((10000/beta)/resultats.iloc[i]['Open.S'])
                price_buy = round(resultats.iloc[i]['Open.S'],2)
                time_enter = resultats.iloc[i]['Date']

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 1,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':0}],ignore_index=True)

                print('\n Le ',str(resultats.iloc[i]['Date']),', achat de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',round(pactol,2))
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],1))

            elif pos_long == 1 and resultats.iloc[i]['Green_Close'] == 0 :

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':round((resultats.iloc[i]['Open.S'] - price_buy)*x,2)}],ignore_index=True)
                try:
                    maxdd.append(round((resultats.iloc[i]['Open.S'] - price_buy)*x,2))
                except:
                    print('Null val of maxdd')
                    maxdd.append('Null')


            elif pos_long == 1 and resultats.iloc[i]['Green_Close'] == 1 :
                old_pactol = round(pactol,2)
                eq_curx.append(resultats.iloc[i]['Date'])
                eq_cury.append(old_pactol)
                pos_long = 0
                price_sell = round(resultats.iloc[i]['Open.S'],2)
                mini_pnl = round(x*(price_sell-price_buy),2)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],2))

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 1, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : mini_pnl,\
                                           'Cumulative PNL':round(signals.iloc[:i]['PNL'].sum(),2),'Latent PNL':mini_pnl}],ignore_index=True)

                pactol = round((pactol + mini_pnl),2)
                print('\n Le ',str(resultats.iloc[i]['Date']),', vente pour close de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)
                print('pnl:', mini_pnl)
                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                pos_duration.append(resultats.iloc[i]['Date'] - time_enter)

                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1


            elif pos_short == 0 and pos_long == 0 and resultats.iloc[i]['Red']:
                pos_short = 1
                nbS+=1
                x = round((10000/beta)/resultats.iloc[i]['Open.S'])
                price_sell = round(resultats.iloc[i]['Open.S'],2)
                time_enter = resultats.iloc[i]['Date']

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 1, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

                print('\n Le ',str(resultats.iloc[i]['Date']),', vente de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],-1))


            elif pos_short == 1 and resultats.iloc[i]['Red_Close'] == 0 :

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':-round((resultats.iloc[i]['Open.S'] - price_sell)*x,2)}],ignore_index=True)
                try:
                    maxdd.append(round((resultats.iloc[i]['Open.S'] - price_sell)*x,2))
                except:
                    print('Null val of maxdd')
                    maxdd.append(0)

            elif pos_short == 1 and resultats.iloc[i]['Red_Close'] == 1 :
                old_pactol = round(pactol,2)
                eq_curx.append(resultats.iloc[i]['Date'])
                eq_cury.append(old_pactol)
                pos_short = 0
                price_buy = round(resultats.iloc[i]['Open.S'],2)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],-2))
                mini_pnl = round(x*(price_sell-price_buy),2)

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 1,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : mini_pnl,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':mini_pnl}],ignore_index=True)

                pactol = round((pactol + mini_pnl),2)
                print('\n Le ',str(resultats.iloc[i]['Date']),', achat pour close de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)

                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                print('pnl:', mini_pnl)
                pos_duration.append(resultats.iloc[i]['Date'] - time_enter)
                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1
            else:

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                               'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                               'Buy/Sell Price' : 0, 'Quantity' : 0, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

        if pos_long == 1:
            pos_long = 0
            print('Cutting non resolved position')
            print(' Le price buy était de : ',price_buy)
            x = round((10000/beta)/resultats.iloc[i]['Open.S'])
            print('x = ',x)
            price_sell = round(resultats.iloc[i]['Open.S'],2)
            print('Et le price sell : ',price_sell)
            mini_pnl = round(x*(price_sell-price_buy),2)

            signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 1, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : mini_pnl,\
                                       'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':mini_pnl}],ignore_index=True)

            pactol = round((pactol + mini_pnl),2)
            print('pnl : ',mini_pnl)
            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1


        if pos_short == 1:
            pos_short = 0
            print('Cutting non resolved position')
            print(' Le price sell était de : ',price_sell)
            x = round((10000/beta)/resultats.iloc[i]['Open.S'])
            print('x = ',x)
            price_buy = round(resultats.iloc[i]['Open.S'],2)
            print('Et le price_buy : ',price_buy)
            mini_pnl = round(x*(price_sell-price_buy),2)

            signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 1,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : mini_pnl,\
                                       'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':mini_pnl}],ignore_index=True)

            pactol = round((pactol + mini_pnl),2)
            print('pnl : ',mini_pnl)

            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1


        pnl = round(pactol - (10000/beta),2)
        print('\n Begining of BackTest :',resultats.iloc[0]['Date'])
        print('Instrument :',ticker)
        print('Face value per trade : $',10000/beta)
        print('End of BackTest :',resultats.iloc[-1]['Date'])
        duration = pd.to_timedelta((resultats.iloc[-1]['Date'] - resultats.iloc[0]['Date']),unit='d')
        print("BackTest's period :",duration)
        print('Pnl :',round(pnl,2),'$')
        print('% Pnl : ',round(pnl/(10000/beta)*100,2))
        print('Total winners :',round(sum(winners),2),'$')
        print('Total loosers :',round(sum(loosers),2),'$')
        print('Number of winners :',round(nb_win))
        print('Number of loosers :',round(nb_los))
        print('Maximum Drawdown : ',round(min(maxdd),2))
        print('% Max Drawdown : ',round(min(maxdd)/(10000/beta)*100,2),'%')
        print('Nombre toatl de trades : ',round(nbL+nbS,2))
        print('% de trades Long : ',round((nbL*100)/(nbL+nbS),2))
        print('% de trades Short : ',round((nbS*100)/(nbL+nbS),2))
        try:
            print('% winners :', round((nb_win/(nb_win+nb_los) * 100),2),'%')
            print('Average winners :',(round(sum(winners)/(nb_win))))
        except:
            print('% winners : null')
        try:
            print('Average losers :',(round(sum(loosers)/(nb_los))))
        except:
            print('Average losers : Inf')
        try:
            for t in range(0,len(pos_duration)):
                average_duration = pd.to_timedelta((average_duration + pos_duration[t]),unit='d')
            average_duration = average_duration/(nb_los+nb_win)
            print('Average Duration :', average_duration)
        except:
            print('No Average Duration available')
        try:
            print('Profit Factor : ',abs(round((sum(winners)/sum(loosers)),2)))
        except:
            print('Profit Factor : null')

        ########################
        ##### PLOT TRADES ######
        ########################

        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Trades')
        plt.plot(resultats['Open.S'],color='blue',lw=0.9)
        for i in range(0,len(trades)):
            if trades[i][2] == 1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='green',marker='^',lw=2.5)
            elif trades[i][2] == -1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='red',marker='^',lw=2.5)
            elif trades[i][2] == 2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='g',marker='x',lw=2.5)
            elif trades[i][2] == -2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='r',marker='x',lw=2.5)

        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='g',marker='^',label='Open Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='r',marker='^',label='Open Short')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='g',marker='x',label='Close Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='r',marker='x',label='Close Short')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_02.pdf')
        plt.close()

        #########################
        ##### PLOT E-CURVE ######
        #########################
        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Equity Curve')
        plt.plot(eq_curx,eq_cury)
        plt.scatter(x=eq_curx,y=eq_cury,c='orange',marker='o',lw=2.5)
        plt.savefig('backtest de '+str(ticker)+'_03.pdf')
        plt.close()


        f.close()
        sys.stdout = orig_stdout

        print('\r Boucle ', loop, 'terminée...',end='')
        print('Opération restantes :', len(constituents)-loop,'/',len(constituents),'\n')


        backtest = backtest.append([{'Symb.':ticker,'Name':name,'Sector':sector,'Period':duration,'Begin.':resultats.iloc[0,0],'End':resultats.iloc[-1,0],\
                          'Pnl $':pnl,'Pnl %':round(pnl/(10000/beta)*100,2),'Gross Profit':round(sum(winners),2),'Gross Loss':round(sum(loosers),2),'# Winners':nb_win,'# Loosers':nb_los,\
                          '% Winners':round((nb_win/(nb_win+nb_los) * 100),2),'MaxDD $':round(min(maxdd),2),'MaxDD %':round(min(maxdd)/(10000/beta)*100,2),'Aver. Win $':(round(sum(winners)/(nb_win))),\
                          'Aver. Loos $':(round(sum(loosers)/(nb_los))),'Aver. Duration':average_duration,\
                          'Total Trades':nbL+nbS,'% Long':round((nbL*100)/(nbL+nbS),2),'% Short':round((nbS*100)/(nbL+nbS),2), 'Profit Factor':abs(round((sum(winners)/sum(loosers)),2))}], ignore_index=True)


        #signals = signals.append([{ 'Date': list_signals[0], 'Ticker' : list_signals[8], 'Open Long' : list_signals[1],\
                                   #'Close Long' : list_signals[2], 'Open Short' : list_signals[3], 'Close Short' : list_signals[4],\
                                   #'Buy/Sell Price' : list_signals[5], 'Quantity' : list_signals[6], ' tPNL' : list_signals[7]}])

        #signals['Date'] = list_signals[0]
        #signals['Ticker'] = list_signals[8]
        #signals['Open Long'] = list_signals[1]
        #signals['Close Long'] = list_signals[2]
        #signals['Open Short'] = list_signals[3]
        #signals['Close Short'] = list_signals[4]
        #signals['Buy/Sell Price'] = list_signals[5]
        #signals['Quantity'] = list_signals[6]
        #signals['tPNL'] = list_signals[7]

    # symbol / name / sector / period of backtest / debut / fin / pnl / total winners / total loosers / Nb winners / nb loosers / 
    # / % winners / Max DD / Aver Win / Aver Loos / Average duration / Profit Factor
        print(Fore.YELLOW,'Writing BACKTEST CSV AND SIGNALS.CSV',Style.RESET_ALL)
        backtest.to_csv('BackTest.csv')
        signals.sort_values(by=['Date'])
        signals.to_csv('SIGNALS.csv')

        print(Fore.CYAN,'BACKTEST CSV WRITED AND SIGNALS.CSV',Style.RESET_ALL)
    except:
        print(Fore.RED,'Problème loop : ',loop,Style.RESET_ALL)
        error.append((loop,ticker))
         
        continue
# Out:
# Importing Librairies...
# Using TensorFlow backend.
# Librairies imported
#
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
# BOOST SKAN 55 Version v1.35
#
# Sraping tickers
# Scrap -----> ok
# Loop : 0
# amorce :  0
# amorce2 :  0
#  --- Loop : 0  ---  --- Symbol :   MMM   ---  --- Name :  3M Company  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.0945285903339417
#  Alpha :  -0.04407200024459089
#  R_Squared :  0.48816612063317844
#  Volatility :  0.1931265162312109
#  Momentum :  -0.13885796574283382
# executed in = 13.700000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:45:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.140000 seconds
#  Deeping in blue
#
#  --- Loop : 0  ---  --- Symbol :   MMM   ---  --- Name :  3M Company  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 0s 66us/step
# 921/921 [==============================] - 0s 69us/step
# 181/181 [==============================] - 0s 19us/step
# 181/181 [==============================] - 0s 20us/step
#
#
#  RESULTATS UP
#
# Accuracy: 75.69%
#  Precision: 70.10%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 81.93%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.82      0.70      0.76        98
#            1       0.70      0.82      0.76        83
#
#    micro avg       0.76      0.76      0.76       181
#    macro avg       0.76      0.76      0.76       181
# weighted avg       0.77      0.76      0.76       181
#
# [[69 29]
#  [15 68]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 77.90%
#  Precision: 69.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 88.46%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.89      0.70      0.78       103
#            1       0.69      0.88      0.78        78
#
#    micro avg       0.78      0.78      0.78       181
#    macro avg       0.79      0.79      0.78       181
# weighted avg       0.80      0.78      0.78       181
#
# [[72 31]
#  [ 9 69]]
#
#
# Deep Learning executed in = 56.370000 seconds
#  Boucle  0 terminée...Opération restantes : 505 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 1
# amorce :  0
# amorce2 :  0
#  --- Loop : 1  ---  --- Symbol :   AOS   ---  --- Name :  A.O. Smith Corp  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.5860916527080855
#  Alpha :  -0.013071321355266854
#  R_Squared :  0.5927091562768683
#  Volatility :  0.2539838342517698
#  Momentum :  -0.2247686647400754
# executed in = 9.720000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:46:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.970000 seconds
#  Deeping in blue
#
#  --- Loop : 1  ---  --- Symbol :   AOS   ---  --- Name :  A.O. Smith Corp  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 0s 99us/step
# 921/921 [==============================] - 0s 109us/step
# 181/181 [==============================] - 0s 21us/step
# 181/181 [==============================] - 0s 20us/step
#
#
#  RESULTATS UP
#
# Accuracy: 84.53%
#  Precision: 70.93%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 95.31%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.97      0.79      0.87       117
#            1       0.71      0.95      0.81        64
#
#    micro avg       0.85      0.85      0.85       181
#    macro avg       0.84      0.87      0.84       181
# weighted avg       0.88      0.85      0.85       181
#
# [[92 25]
#  [ 3 61]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 86.19%
#  Precision: 95.60%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.56%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.77      0.95      0.85        73
#            1       0.96      0.81      0.87       108
#
#    micro avg       0.86      0.86      0.86       181
#    macro avg       0.86      0.88      0.86       181
# weighted avg       0.88      0.86      0.86       181
#
# [[69  4]
#  [21 87]]
#
#
# Deep Learning executed in = 56.520000 seconds
#  Boucle  1 terminée...Opération restantes : 504 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 2
# amorce :  0
# amorce2 :  0
#  --- Loop : 2  ---  --- Symbol :   ABT   ---  --- Name :  Abbott Laboratories  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.161244235314478
#  Alpha :  0.07826488763930645
#  R_Squared :  0.48962039910582167
#  Volatility :  0.20459378323115163
#  Momentum :  0.36990883660510643
# executed in = 8.480000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:48:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.180000 seconds
#  Deeping in blue
#
#  --- Loop : 2  ---  --- Symbol :   ABT   ---  --- Name :  Abbott Laboratories  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 0s 137us/step
# 921/921 [==============================] - 0s 145us/step
# 181/181 [==============================] - 0s 21us/step
# 181/181 [==============================] - 0s 23us/step
#
#
#  RESULTATS UP
#
# Accuracy: 83.43%
#  Precision: 82.56%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 82.56%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84        95
#            1       0.83      0.83      0.83        86
#
#    micro avg       0.83      0.83      0.83       181
#    macro avg       0.83      0.83      0.83       181
# weighted avg       0.83      0.83      0.83       181
#
# [[80 15]
#  [15 71]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 74.59%
#  Precision: 63.64%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 86.30%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.88      0.67      0.76       108
#            1       0.64      0.86      0.73        73
#
#    micro avg       0.75      0.75      0.75       181
#    macro avg       0.76      0.76      0.75       181
# weighted avg       0.78      0.75      0.75       181
#
# [[72 36]
#  [10 63]]
#
#
# Deep Learning executed in = 57.600000 seconds
#  Boucle  2 terminée...Opération restantes : 503 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 3
# amorce :  0
# amorce2 :  0
#  --- Loop : 3  ---  --- Symbol :   ABBV   ---  --- Name :  AbbVie Inc.  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  0.8862338823067936
#  Alpha :  0.010764879814861093
#  R_Squared :  0.16487508111007365
#  Volatility :  0.2690725859734696
#  Momentum :  -0.23338709671802504
# executed in = 10.470000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:49:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.340000 seconds
#  Deeping in blue
#
#  --- Loop : 3  ---  --- Symbol :   ABBV   ---  --- Name :  AbbVie Inc.  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 0s 168us/step
# 921/921 [==============================] - 0s 185us/step
# 181/181 [==============================] - 0s 21us/step
# 181/181 [==============================] - 0s 22us/step
#
#
#  RESULTATS UP
#
# Accuracy: 78.45%
#  Precision: 69.37%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 93.90%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.93      0.66      0.77        99
#            1       0.69      0.94      0.80        82
#
#    micro avg       0.78      0.78      0.78       181
#    macro avg       0.81      0.80      0.78       181
# weighted avg       0.82      0.78      0.78       181
#
# [[65 34]
#  [ 5 77]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 70.17%
#  Precision: 61.70%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.43      0.60        94
#            1       0.62      1.00      0.76        87
#
#    micro avg       0.70      0.70      0.70       181
#    macro avg       0.81      0.71      0.68       181
# weighted avg       0.82      0.70      0.68       181
#
# [[40 54]
#  [ 0 87]]
#
#
# Deep Learning executed in = 60.210000 seconds
#  Boucle  3 terminée...Opération restantes : 502 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 4
# amorce :  0
# amorce2 :  0
#  --- Loop : 4  ---  --- Symbol :   ACN   ---  --- Name :  Accenture plc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.0439292716985364
#  Alpha :  0.12267022422252435
#  R_Squared :  0.5420520585571769
#  Volatility :  0.1748031241131563
#  Momentum :  0.24944157140923595
# executed in = 15.250000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:50:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.190000 seconds
#  Deeping in blue
#
#  --- Loop : 4  ---  --- Symbol :   ACN   ---  --- Name :  Accenture plc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 0s 215us/step
# 921/921 [==============================] - 0s 225us/step
# 181/181 [==============================] - 0s 25us/step
# 181/181 [==============================] - 0s 25us/step
#
#
#  RESULTATS UP
#
# Accuracy: 70.17%
#  Precision: 88.24%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 37.50%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.66      0.96      0.78       101
#            1       0.88      0.38      0.53        80
#
#    micro avg       0.70      0.70      0.70       181
#    macro avg       0.77      0.67      0.65       181
# weighted avg       0.76      0.70      0.67       181
#
# [[97  4]
#  [50 30]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 73.48%
#  Precision: 57.89%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 87.30%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.91      0.66      0.76       118
#            1       0.58      0.87      0.70        63
#
#    micro avg       0.73      0.73      0.73       181
#    macro avg       0.74      0.77      0.73       181
# weighted avg       0.79      0.73      0.74       181
#
# [[78 40]
#  [ 8 55]]
#
#
# Deep Learning executed in = 62.670000 seconds
#  Boucle  4 terminée...Opération restantes : 501 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 5
# amorce :  0
# amorce2 :  0
#  --- Loop : 5  ---  --- Symbol :   ATVI   ---  --- Name :  Activision Blizzard  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  0.8817623321160434
#  Alpha :  0.1566906932533232
#  R_Squared :  0.12515515788244813
#  Volatility :  0.30727397594622813
#  Momentum :  -0.3369937919376266
# executed in = 23.740000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:52:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.130000 seconds
#  Deeping in blue
#
#  --- Loop : 5  ---  --- Symbol :   ATVI   ---  --- Name :  Activision Blizzard  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 0s 268us/step
# 921/921 [==============================] - 0s 254us/step
# 181/181 [==============================] - 0s 23us/step
# 181/181 [==============================] - 0s 25us/step
#
#
#  RESULTATS UP
#
# Accuracy: 69.61%
#  Precision: 72.22%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 59.77%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.68      0.79      0.73        94
#            1       0.72      0.60      0.65        87
#
#    micro avg       0.70      0.70      0.70       181
#    macro avg       0.70      0.69      0.69       181
# weighted avg       0.70      0.70      0.69       181
#
# [[74 20]
#  [35 52]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 85.08%
#  Precision: 79.76%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 87.01%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87       104
#            1       0.80      0.87      0.83        77
#
#    micro avg       0.85      0.85      0.85       181
#    macro avg       0.85      0.85      0.85       181
# weighted avg       0.85      0.85      0.85       181
#
# [[87 17]
#  [10 67]]
#
#
# Deep Learning executed in = 64.090000 seconds
#  Boucle  5 terminée...Opération restantes : 500 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 6
# amorce :  0
# amorce2 :  0
#  --- Loop : 6  ---  --- Symbol :   AYI   ---  --- Name :  Acuity Brands Inc  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.5955917851903305
#  Alpha :  -0.11567957753300379
#  R_Squared :  0.307068704607237
#  Volatility :  0.3549789717868761
#  Momentum :  -0.014684527615114518
# executed in = 15.230000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:53:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.950000 seconds
#  Deeping in blue
#
#  --- Loop : 6  ---  --- Symbol :   AYI   ---  --- Name :  Acuity Brands Inc  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 0s 314us/step
# 921/921 [==============================] - 0s 290us/step
# 181/181 [==============================] - 0s 23us/step
# 181/181 [==============================] - 0s 26us/step
#
#
#  RESULTATS UP
#
# Accuracy: 80.11%
#  Precision: 79.76%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 77.91%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81        95
#            1       0.80      0.78      0.79        86
#
#    micro avg       0.80      0.80      0.80       181
#    macro avg       0.80      0.80      0.80       181
# weighted avg       0.80      0.80      0.80       181
#
# [[78 17]
#  [19 67]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 82.87%
#  Precision: 74.51%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 93.83%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83       100
#            1       0.75      0.94      0.83        81
#
#    micro avg       0.83      0.83      0.83       181
#    macro avg       0.84      0.84      0.83       181
# weighted avg       0.85      0.83      0.83       181
#
# [[74 26]
#  [ 5 76]]
#
#
# Deep Learning executed in = 66.730000 seconds
#  Boucle  6 terminée...Opération restantes : 499 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 7
# amorce :  0
# amorce2 :  0
#  --- Loop : 7  ---  --- Symbol :   ADBE   ---  --- Name :  Adobe Systems Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.0619504657999443
#  Alpha :  0.24397259302123764
#  R_Squared :  0.42045593141636883
#  Volatility :  0.20190293484442234
#  Momentum :  0.2409678916852942
# executed in = 15.660000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:55:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.070000 seconds
#  Deeping in blue
#
#  --- Loop : 7  ---  --- Symbol :   ADBE   ---  --- Name :  Adobe Systems Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 0s 329us/step
# 921/921 [==============================] - 0s 316us/step
# 181/181 [==============================] - 0s 25us/step
# 181/181 [==============================] - 0s 26us/step
#
#
#  RESULTATS UP
#
# Accuracy: 67.96%
#  Precision: 58.77%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.90%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.84      0.54      0.66       103
#            1       0.59      0.86      0.70        78
#
#    micro avg       0.68      0.68      0.68       181
#    macro avg       0.71      0.70      0.68       181
# weighted avg       0.73      0.68      0.68       181
#
# [[56 47]
#  [11 67]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 66.30%
#  Precision: 60.68%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 82.56%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.77      0.52      0.62        95
#            1       0.61      0.83      0.70        86
#
#    micro avg       0.66      0.66      0.66       181
#    macro avg       0.69      0.67      0.66       181
# weighted avg       0.69      0.66      0.66       181
#
# [[49 46]
#  [15 71]]
#
#
# Deep Learning executed in = 68.410000 seconds
#  Boucle  7 terminée...Opération restantes : 498 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 8
# amorce :  0
# amorce2 :  0
#  --- Loop : 8  ---  --- Symbol :   AAP   ---  --- Name :  Advance Auto Parts  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  0.8195672506491788
#  Alpha :  -0.04829622679819945
#  R_Squared :  0.11735895559769083
#  Volatility :  0.29493417040086234
#  Momentum :  0.0764495693548175
# executed in = 16.290000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:56:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.360000 seconds
#  Deeping in blue
#
#  --- Loop : 8  ---  --- Symbol :   AAP   ---  --- Name :  Advance Auto Parts  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 0s 390us/step
# 921/921 [==============================] - 0s 374us/step
# 181/181 [==============================] - 0s 29us/step
# 181/181 [==============================] - 0s 31us/step
#
#
#  RESULTATS UP
#
# Accuracy: 88.40%
#  Precision: 87.50%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 84.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90       106
#            1       0.88      0.84      0.86        75
#
#    micro avg       0.88      0.88      0.88       181
#    macro avg       0.88      0.88      0.88       181
# weighted avg       0.88      0.88      0.88       181
#
# [[97  9]
#  [12 63]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 86.19%
#  Precision: 79.25%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 96.55%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.96      0.77      0.85        94
#            1       0.79      0.97      0.87        87
#
#    micro avg       0.86      0.86      0.86       181
#    macro avg       0.88      0.87      0.86       181
# weighted avg       0.88      0.86      0.86       181
#
# [[72 22]
#  [ 3 84]]
#
#
# Deep Learning executed in = 70.420000 seconds
#  Boucle  8 terminée...Opération restantes : 497 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 9
# amorce :  0
# amorce2 :  0
#  --- Loop : 9  ---  --- Symbol :   AMD   ---  --- Name :  Advanced Micro Devices Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  3.121630483777047
#  Alpha :  0.4603829550056101
#  R_Squared :  0.3883213380045024
#  Volatility :  0.6175675660370035
#  Momentum :  0.8477904567845054
# executed in = 15.040000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:58:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.700000 seconds
#  Deeping in blue
#
#  --- Loop : 9  ---  --- Symbol :   AMD   ---  --- Name :  Advanced Micro Devices Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 0s 409us/step
# 921/921 [==============================] - 0s 389us/step
# 181/181 [==============================] - 0s 34us/step
# 181/181 [==============================] - 0s 28us/step
#
#
#  RESULTATS UP
#
# Accuracy: 77.35%
#  Precision: 77.65%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 75.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.77      0.80      0.78        93
#            1       0.78      0.75      0.76        88
#
#    micro avg       0.77      0.77      0.77       181
#    macro avg       0.77      0.77      0.77       181
# weighted avg       0.77      0.77      0.77       181
#
# [[74 19]
#  [22 66]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 79.01%
#  Precision: 93.62%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 55.70%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.74      0.97      0.84       102
#            1       0.94      0.56      0.70        79
#
#    micro avg       0.79      0.79      0.79       181
#    macro avg       0.84      0.76      0.77       181
# weighted avg       0.82      0.79      0.78       181
#
# [[99  3]
#  [35 44]]
#
#
# Deep Learning executed in = 72.850000 seconds
#  Boucle  9 terminée...Opération restantes : 496 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 10
# amorce :  0
# amorce2 :  0
#  --- Loop : 10  ---  --- Symbol :   AES   ---  --- Name :  AES Corp  ---  --- Sector :  Utilities  ---
# Scraping data...
# Beta :  0.9862914562007221
#  Alpha :  0.04064696336366944
#  R_Squared :  0.30143283047067215
#  Volatility :  0.221466789071325
#  Momentum :  0.3292498024560635
# executed in = 18.190000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:59:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.500000 seconds
#  Deeping in blue
#
#  --- Loop : 10  ---  --- Symbol :   AES   ---  --- Name :  AES Corp  ---  --- Sector :  Utilities  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 0s 429us/step
# 921/921 [==============================] - 0s 440us/step
# 181/181 [==============================] - 0s 27us/step
# 181/181 [==============================] - 0s 29us/step
#
#
#  RESULTATS UP
#
# Accuracy: 69.06%
#  Precision: 59.26%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 98.77%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.98      0.45      0.62       100
#            1       0.59      0.99      0.74        81
#
#    micro avg       0.69      0.69      0.69       181
#    macro avg       0.79      0.72      0.68       181
# weighted avg       0.81      0.69      0.67       181
#
# [[45 55]
#  [ 1 80]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 79.56%
#  Precision: 88.14%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 63.41%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.75      0.93      0.83        99
#            1       0.88      0.63      0.74        82
#
#    micro avg       0.80      0.80      0.80       181
#    macro avg       0.82      0.78      0.79       181
# weighted avg       0.81      0.80      0.79       181
#
# [[92  7]
#  [30 52]]
#
#
# Deep Learning executed in = 74.850000 seconds
#  Boucle  10 terminée...Opération restantes : 495 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 11
# amorce :  0
# amorce2 :  0
#  --- Loop : 11  ---  --- Symbol :   AET   ---  --- Name :  Aetna Inc  ---  --- Sector :  Health Care  ---
# Scraping data...
#  Problème loop :  11
# Loop : 12
# amorce :  0
# amorce2 :  0
#  --- Loop : 12  ---  --- Symbol :   AMG   ---  --- Name :  Affiliated Managers Group Inc  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  1.6484490126749425
#  Alpha :  -0.3067513384177257
#  R_Squared :  0.49132532070967116
#  Volatility :  0.2899275993028444
#  Momentum :  -0.45162940066033397
# executed in = 22.320000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [10:01:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.820000 seconds
#  Deeping in blue
#
#  --- Loop : 12  ---  --- Symbol :   AMG   ---  --- Name :  Affiliated Managers Group Inc  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 0s 464us/step
# 921/921 [==============================] - 0s 485us/step
# 181/181 [==============================] - 0s 29us/step
# 181/181 [==============================] - 0s 30us/step
#
#
#  RESULTATS UP
#
# Accuracy: 64.09%
#  Precision: 75.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 35.29%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.61      0.90      0.73        96
#            1       0.75      0.35      0.48        85
#
#    micro avg       0.64      0.64      0.64       181
#    macro avg       0.68      0.62      0.60       181
# weighted avg       0.68      0.64      0.61       181
#
# [[86 10]
#  [55 30]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 54.70%
#  Precision: 50.37%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 81.93%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.67      0.32      0.43        98
#            1       0.50      0.82      0.62        83
#
#    micro avg       0.55      0.55      0.55       181
#    macro avg       0.59      0.57      0.53       181
# weighted avg       0.60      0.55      0.52       181
#
# [[31 67]
#  [15 68]]
#
#
# Deep Learning executed in = 76.170000 seconds
#  Boucle  12 terminée...Opération restantes : 493 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 13
# amorce :  0
# amorce2 :  0
#  --- Loop : 13  ---  --- Symbol :   AFL   ---  --- Name :  AFLAC Inc  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  0.6551880476043012
#  Alpha :  0.12439233465744884
#  R_Squared :  0.3139497780840921
#  Volatility :  0.1441565864093086
#  Momentum :  0.1615059402209882
# executed in = 19.280000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [10:03:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.730000 seconds
#  Deeping in blue
#
#  --- Loop : 13  ---  --- Symbol :   AFL   ---  --- Name :  AFLAC Inc  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 0s 538us/step
# 921/921 [==============================] - 0s 506us/step
# 181/181 [==============================] - 0s 30us/step
# 181/181 [==============================] - 0s 34us/step
#
#
#  RESULTATS UP
#
# Accuracy: 72.93%
#  Precision: 71.95%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 69.41%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.74      0.76      0.75        96
#            1       0.72      0.69      0.71        85
#
#    micro avg       0.73      0.73      0.73       181
#    macro avg       0.73      0.73      0.73       181
# weighted avg       0.73      0.73      0.73       181
#
# [[73 23]
#  [26 59]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 79.01%
#  Precision: 73.08%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 77.03%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.82       107
#            1       0.73      0.77      0.75        74
#
#    micro avg       0.79      0.79      0.79       181
#    macro avg       0.78      0.79      0.78       181
# weighted avg       0.79      0.79      0.79       181
#
# [[86 21]
#  [17 57]]
#
#
# Deep Learning executed in = 81.480000 seconds
#  Boucle  13 terminée...Opération restantes : 492 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 14
# amorce :  0
# amorce2 :  0
#  --- Loop : 14  ---  --- Symbol :   A   ---  --- Name :  Agilent Technologies Inc  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.3930626573732603
#  Alpha :  0.035269969553318486
#  R_Squared :  0.5632471629350662
#  Volatility :  0.22883358160996972
#  Momentum :  0.07165121706007715
# executed in = 16.570000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [10:04:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.730000 seconds
#  Deeping in blue
#
#  --- Loop : 14  ---  --- Symbol :   A   ---  --- Name :  Agilent Technologies Inc  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 1s 570us/step
# 921/921 [==============================] - 0s 543us/step
# 181/181 [==============================] - 0s 30us/step
# 181/181 [==============================] - 0s 32us/step
#
#
#  RESULTATS UP
#
# Accuracy: 74.59%
#  Precision: 67.44%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 76.32%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.81      0.73      0.77       105
#            1       0.67      0.76      0.72        76
#
#    micro avg       0.75      0.75      0.75       181
#    macro avg       0.74      0.75      0.74       181
# weighted avg       0.75      0.75      0.75       181
#
# [[77 28]
#  [18 58]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 84.53%
#  Precision: 78.50%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 94.38%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.93      0.75      0.83        92
#            1       0.79      0.94      0.86        89
#
#    micro avg       0.85      0.85      0.85       181
#    macro avg       0.86      0.85      0.84       181
# weighted avg       0.86      0.85      0.84       181
#
# [[69 23]
#  [ 5 84]]
#
#
# Deep Learning executed in = 81.010000 seconds
#  Boucle  14 terminée...Opération restantes : 491 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 15
# amorce :  0
# amorce2 :  0
#  --- Loop : 15  ---  --- Symbol :   APD   ---  --- Name :  Air Products & Chemicals Inc  ---  --- Sector :  Materials  ---
# Scraping data...
# Beta :  0.8587834820836446
#  Alpha :  0.07641249623929627
#  R_Squared :  0.4557373137140349
#  Volatility :  0.15682850496951528
#  Momentum :  0.4473801170849807
# executed in = 25.620000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [10:06:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.880000 seconds
#  Deeping in blue
#
#  --- Loop : 15  ---  --- Symbol :   APD   ---  --- Name :  Air Products & Chemicals Inc  ---  --- Sector :  Materials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 1s 601us/step
# 921/921 [==============================] - 1s 584us/step
# 181/181 [==============================] - 0s 34us/step
# 181/181 [==============================] - 0s 33us/step
#
#
#  RESULTATS UP
#
# Accuracy: 69.61%
#  Precision: 80.30%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 55.79%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.63      0.85      0.73        86
#            1       0.80      0.56      0.66        95
#
#    micro avg       0.70      0.70      0.70       181
#    macro avg       0.72      0.70      0.69       181
# weighted avg       0.72      0.70      0.69       181
#
# [[73 13]
#  [42 53]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 88.95%
#  Precision: 82.89%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 90.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.91       111
#            1       0.83      0.90      0.86        70
#
#    micro avg       0.89      0.89      0.89       181
#    macro avg       0.88      0.89      0.89       181
# weighted avg       0.89      0.89      0.89       181
#
# [[98 13]
#  [ 7 63]]
#
#
# Deep Learning executed in = 83.490000 seconds
#  Boucle  15 terminée...Opération restantes : 490 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 16
# amorce :  0
# amorce2 :  0
#  --- Loop : 16  ---  --- Symbol :   AKAM   ---  --- Name :  Akamai Technologies Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  0.5724794285643713
#  Alpha :  0.07139990484846079
#  R_Squared :  0.05150743501834609
#  Volatility :  0.31097361166214876
#  Momentum :  0.1165293169563244
# executed in = 20.030000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [10:08:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.930000 seconds
#  Deeping in blue
#
#  --- Loop : 16  ---  --- Symbol :   AKAM   ---  --- Name :  Akamai Technologies Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 1s 619us/step
# 921/921 [==============================] - 1s 639us/step
# 181/181 [==============================] - 0s 31us/step
# 181/181 [==============================] - 0s 32us/step
#
#
#  RESULTATS UP
#
# Accuracy: 88.40%
#  Precision: 96.20%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.85%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89        87
#            1       0.96      0.81      0.88        94
#
#    micro avg       0.88      0.88      0.88       181
#    macro avg       0.89      0.89      0.88       181
# weighted avg       0.90      0.88      0.88       181
#
# [[84  3]
#  [18 76]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 92.82%
#  Precision: 88.31%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 94.44%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       109
#            1       0.88      0.94      0.91        72
#
#    micro avg       0.93      0.93      0.93       181
#    macro avg       0.92      0.93      0.93       181
# weighted avg       0.93      0.93      0.93       181
#
# [[100   9]
#  [  4  68]]
#
#
# Deep Learning executed in = 84.650000 seconds
#  Boucle  16 terminée...Opération restantes : 489 / 505
#
#  Problème loop :  16
# Loop : 17
# amorce :  0
# amorce2 :  0
#  --- Loop : 17  ---  --- Symbol :   ALK   ---  --- Name :  Alaska Air Group Inc  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  0.8538370433659751
#  Alpha :  -0.03950398356939486
#  R_Squared :  0.1310114083110403
#  Volatility :  0.29081650367576417
#  Momentum :  0.039933458490140517
# executed in = 13.860000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [10:10:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.990000 seconds
#  Deeping in blue
#
#  --- Loop : 17  ---  --- Symbol :   ALK   ---  --- Name :  Alaska Air Group Inc  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 1s 675us/step
# 921/921 [==============================] - 1s 685us/step
# 181/181 [==============================] - 0s 35us/step
# 181/181 [==============================] - 0s 33us/step
#
#
#  RESULTATS UP
#
# Accuracy: 81.77%
#  Precision: 76.34%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 86.59%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.82        99
#            1       0.76      0.87      0.81        82
#
#    micro avg       0.82      0.82      0.82       181
#    macro avg       0.82      0.82      0.82       181
# weighted avg       0.82      0.82      0.82       181
#
# [[77 22]
#  [11 71]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 75.69%
#  Precision: 66.67%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 87.18%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.87      0.67      0.76       103
#            1       0.67      0.87      0.76        78
#
#    micro avg       0.76      0.76      0.76       181
#    macro avg       0.77      0.77      0.76       181
# weighted avg       0.78      0.76      0.76       181
#
# [[69 34]
#  [10 68]]
#
#
# Deep Learning executed in = 87.480000 seconds
#  Boucle  17 terminée...Opération restantes : 488 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 18
# amorce :  0
# amorce2 :  0
#  --- Loop : 18  ---  --- Symbol :   ALB   ---  --- Name :  Albemarle Corp  ---  --- Sector :  Materials  ---
# Scraping data...
# Beta :  1.5230182465518274
#  Alpha :  0.006370287943417582
#  R_Squared :  0.36454553572768245
#  Volatility :  0.3109766839455265
#  Momentum :  -0.20566049605444547
# executed in = 13.980000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [10:12:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.380000 seconds
#  Deeping in blue
#
#  --- Loop : 18  ---  --- Symbol :   ALB   ---  --- Name :  Albemarle Corp  ---  --- Sector :  Materials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 1s 763us/step
# 921/921 [==============================] - 1s 718us/step
# 181/181 [==============================] - 0s 33us/step
# 181/181 [==============================] - 0s 35us/step
#
#
#  RESULTATS UP
#
# Accuracy: 80.66%
#  Precision: 80.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 75.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83       101
#            1       0.80      0.75      0.77        80
#
#    micro avg       0.81      0.81      0.81       181
#    macro avg       0.81      0.80      0.80       181
# weighted avg       0.81      0.81      0.81       181
#
# [[86 15]
#  [20 60]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 73.48%
#  Precision: 85.71%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 58.06%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.67      0.90      0.77        88
#            1       0.86      0.58      0.69        93
#
#    micro avg       0.73      0.73      0.73       181
#    macro avg       0.76      0.74      0.73       181
# weighted avg       0.77      0.73      0.73       181
#
# [[79  9]
#  [39 54]]
#
#
# Deep Learning executed in = 88.780000 seconds
#  Boucle  18 terminée...Opération restantes : 487 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 19
# amorce :  0
# amorce2 :  0
#  --- Loop : 19  ---  --- Symbol :   ARE   ---  --- Name :  Alexandria Real Estate Equities Inc  ---  --- Sector :  Real Estate  ---
# Scraping data...
# ...
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 2s 2ms/step
# 921/921 [==============================] - 2s 2ms/step
# 181/181 [==============================] - 0s 76us/step
# 181/181 [==============================] - 0s 62us/step
#
#
#  RESULTATS UP
#
# Accuracy: 79.01%
#  Precision: 81.43%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 69.51%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.77      0.87      0.82        99
#            1       0.81      0.70      0.75        82
#
#    micro avg       0.79      0.79      0.79       181
#    macro avg       0.79      0.78      0.78       181
# weighted avg       0.79      0.79      0.79       181
#
# [[86 13]
#  [25 57]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 69.61%
#  Precision: 59.69%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 96.25%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.94      0.49      0.64       101
#            1       0.60      0.96      0.74        80
#
#    micro avg       0.70      0.70      0.70       181
#    macro avg       0.77      0.72      0.69       181
# weighted avg       0.79      0.70      0.68       181
#
# [[49 52]
#  [ 3 77]]
#
#
# Deep Learning executed in = 158.240000 seconds
#  Boucle  48 terminée...Opération restantes : 457 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 49
# amorce :  0
# amorce2 :  0
#  --- Loop : 49  ---  --- Symbol :   APA   ---  --- Name :  Apache Corporation  ---  --- Sector :  Energy  ---
# Scraping data...
# Beta :  1.9355480883790237
#  Alpha :  -0.2845847699841966
#  R_Squared :  0.292369849327904
#  Volatility :  0.44130239829082
#  Momentum :  -0.45941540744731335
# executed in = 15.550000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:26:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.500000 seconds
#  Deeping in blue
#
#  --- Loop : 49  ---  --- Symbol :   APA   ---  --- Name :  Apache Corporation  ---  --- Sector :  Energy  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 2s 2ms/step
# 921/921 [==============================] - 2s 2ms/step
# 181/181 [==============================] - 0s 70us/step
# 181/181 [==============================] - 0s 66us/step
#
#
#  RESULTATS UP
#
# Accuracy: 74.03%
#  Precision: 66.06%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 87.80%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.63      0.73        99
#            1       0.66      0.88      0.75        82
#
#    micro avg       0.74      0.74      0.74       181
#    macro avg       0.76      0.75      0.74       181
# weighted avg       0.77      0.74      0.74       181
#
# [[62 37]
#  [10 72]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 76.80%
#  Precision: 74.44%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 77.91%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.79      0.76      0.77        95
#            1       0.74      0.78      0.76        86
#
#    micro avg       0.77      0.77      0.77       181
#    macro avg       0.77      0.77      0.77       181
# weighted avg       0.77      0.77      0.77       181
#
# [[72 23]
#  [19 67]]
#
#
# Deep Learning executed in = 155.630000 seconds
#  Boucle  49 terminée...Opération restantes : 456 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 50
# amorce :  0
# amorce2 :  0
#  --- Loop : 50  ---  --- Symbol :   AIV   ---  --- Name :  Apartment Investment & Management  ---  --- Sector :  Real Estate  ---
# Scraping data...
# Beta :  0.5650753031122835
#  Alpha :  0.04066842644704899
#  R_Squared :  0.17700792404705412
#  Volatility :  0.16558026990274402
#  Momentum :  0.21227390139080327
# executed in = 7.110000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:29:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.970000 seconds
#  Deeping in blue
#
#  --- Loop : 50  ---  --- Symbol :   AIV   ---  --- Name :  Apartment Investment & Management  ---  --- Sector :  Real Estate  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 2s 2ms/step
# 921/921 [==============================] - 2s 2ms/step
# 181/181 [==============================] - 0s 83us/step
# 181/181 [==============================] - 0s 62us/step
#
#
#  RESULTATS UP
#
# Accuracy: 80.66%
#  Precision: 72.90%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 92.86%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.92      0.70      0.80        97
#            1       0.73      0.93      0.82        84
#
#    micro avg       0.81      0.81      0.81       181
#    macro avg       0.82      0.81      0.81       181
# weighted avg       0.83      0.81      0.81       181
#
# [[68 29]
#  [ 6 78]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 80.66%
#  Precision: 81.67%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 67.12%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.90      0.85       108
#            1       0.82      0.67      0.74        73
#
#    micro avg       0.81      0.81      0.81       181
#    macro avg       0.81      0.78      0.79       181
# weighted avg       0.81      0.81      0.80       181
#
# [[97 11]
#  [24 49]]
#
#
# Deep Learning executed in = 160.570000 seconds
#  Boucle  50 terminée...Opération restantes : 455 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 51
# amorce :  0
# amorce2 :  0
#  --- Loop : 51  ---  --- Symbol :   AAPL   ---  --- Name :  Apple Inc.  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.2496506649015744
#  Alpha :  0.05746784366863656
#  R_Squared :  0.3314601566483416
#  Volatility :  0.2675910433102783
#  Momentum :  0.1138686048196571
# executed in = 10.830000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:32:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.830000 seconds
#  Deeping in blue
#
#  --- Loop : 51  ---  --- Symbol :   AAPL   ---  --- Name :  Apple Inc.  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 2s 2ms/step
# 921/921 [==============================] - 2s 2ms/step
# 181/181 [==============================] - 0s 80us/step
# 181/181 [==============================] - 0s 68us/step
#
#
#  RESULTATS UP
#
# Accuracy: 79.56%
#  Precision: 85.51%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 68.60%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.76      0.89      0.82        95
#            1       0.86      0.69      0.76        86
#
#    micro avg       0.80      0.80      0.80       181
#    macro avg       0.81      0.79      0.79       181
# weighted avg       0.80      0.80      0.79       181
#
# [[85 10]
#  [27 59]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 81.22%
#  Precision: 97.87%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 58.23%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.75      0.99      0.86       102
#            1       0.98      0.58      0.73        79
#
#    micro avg       0.81      0.81      0.81       181
#    macro avg       0.87      0.79      0.79       181
# weighted avg       0.85      0.81      0.80       181
#
# [[101   1]
#  [ 33  46]]
#
#
# Deep Learning executed in = 161.120000 seconds
#  Boucle  51 terminée...Opération restantes : 454 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 52
# amorce :  0
# amorce2 :  0
#  --- Loop : 52  ---  --- Symbol :   AMAT   ---  --- Name :  Applied Materials Inc.  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.6309130475077578
#  Alpha :  0.086223327965706
#  R_Squared :  0.37016457949268855
#  Volatility :  0.33046996261040346
#  Momentum :  0.06467339901075597
# executed in = 33.070000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:36:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.180000 seconds
#  Deeping in blue
#
#  --- Loop : 52  ---  --- Symbol :   AMAT   ---  --- Name :  Applied Materials Inc.  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 2s 2ms/step
# 921/921 [==============================] - 2s 2ms/step
# 181/181 [==============================] - 0s 68us/step
# 181/181 [==============================] - 0s 80us/step
#
#
#  RESULTATS UP
#
# Accuracy: 66.30%
#  Precision: 62.90%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 83.87%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.74      0.48      0.58        88
#            1       0.63      0.84      0.72        93
#
#    micro avg       0.66      0.66      0.66       181
#    macro avg       0.68      0.66      0.65       181
# weighted avg       0.68      0.66      0.65       181
#
# [[42 46]
#  [15 78]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 81.77%
#  Precision: 76.83%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 81.82%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84       104
#            1       0.77      0.82      0.79        77
#
#    micro avg       0.82      0.82      0.82       181
#    macro avg       0.81      0.82      0.81       181
# weighted avg       0.82      0.82      0.82       181
#
# [[85 19]
#  [14 63]]
#
#
# Deep Learning executed in = 163.310000 seconds
#  Boucle  52 terminée...Opération restantes : 453 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 53
# amorce :  0
# amorce2 :  0
#  --- Loop : 53  ---  --- Symbol :   APTV   ---  --- Name :  Aptiv Plc  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  2.0206286347300555
#  Alpha :  -0.052355686675386
#  R_Squared :  0.546035614201833
#  Volatility :  0.33711232603370866
#  Momentum :  -0.15929163597029972
# executed in = 10.810000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:39:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.780000 seconds
#  Deeping in blue
#
#  --- Loop : 53  ---  --- Symbol :   APTV   ---  --- Name :  Aptiv Plc  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 921/921 [==============================] - 2s 2ms/step
# 921/921 [==============================] - 2s 2ms/step
# 181/181 [==============================] - 0s 91us/step
# 181/181 [==============================] - 0s 75us/step
#
#
#  RESULTATS UP
#
# Accuracy: 79.01%
#  Precision: 73.79%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 87.36%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.71      0.78        94
#            1       0.74      0.87      0.80        87
#
#    micro avg       0.79      0.79      0.79       181
#    macro avg       0.80      0.79      0.79       181
# weighted avg       0.80      0.79      0.79       181
#
# [[67 27]
#  [11 76]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 80.11%
#  Precision: 75.58%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 81.25%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.84      0.79      0.82       101
#            1       0.76      0.81      0.78        80
#
#    micro avg       0.80      0.80      0.80       181
#    macro avg       0.80      0.80      0.80       181
# weighted avg       0.80      0.80      0.80       181
#
# [[80 21]
#  [15 65]]
#
#
# Deep Learning executed in = 166.080000 seconds
#  Boucle  53 terminée...Opération restantes : 452 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 54
# amorce :  0
# amorce2 :  0
#  --- Loop : 54  ---  --- Symbol :   ADM   ---  --- Name :  Archer-Daniels-Midland Co  ---  --- Sector :  Consumer Staples  ---
# Scraping data...
# Beta :  1.0102513180538522
#  Alpha :  -0.07830756717024087
#  R_Squared :  0.3654667985920367
#  Volatility :  0.20601748215368962
#  Momentum :  -0.12470766640123399
# executed in = 8.530000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1151
# On 80% - 20% slash :
# Bloc 1 :  921
# Bloc 2 : 230  periods
# First period : 2015-01-02 00:00:00
# Split period : 2018-08-28 00:00:00
# Last period : 2019-07-30 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:42:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.110000 seconds
#  Deeping in blue
#
#  --- Loop : 54  ---  --- Symbol :   ADM   ---  --- Name :  Archer-Daniels-Midland Co  ---  --- Sector :  Consumer Staples  ---
# Processing move_up
#
#
# Processing move_down

# %%
#import sys
#orig_stdout = sys.stdout
#f = open('backtestv2_4.txt', 'w')
#sys.stdout = f

# %%
#f.close()
#sys.stdout = orig_stdout

# %% [markdown]
# import pandas as pd
#
# backtest = pd.DataFrame(columns = ['Symb.','Name','Sector','period','Begin.','End',\
#                           'Pnl','%Pnl','Total Winners','Total Loosers','Nb Win','Nb Los',\
#                           '% Winners','MaxDD','%MaxDD','Aver. Win',\
#                           'Aver. Los','Aver. Duration',\
#                           'Total Trades','% Long','% Short','Profit Factor'])
# backtest.to_csv('BackTest.csv')
#
# signals = pd.DataFrame(columns = ['Date','Ticker','Open Long','Close Long','Open Short','Close Short','Buy/Sell Price','Quantity','tPNL'])
# signals.to_csv('SIGNALS.csv')

# %%
2+2

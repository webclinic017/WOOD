# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\n°OoO_FXCM_Oo0°\nLumberJack Jyss 5779(c)')
print('°0Oo_INVESTING.COM_oO0°')
print('SKAN55 Version v1.0')
print('Importing librairies...')

print('Importing Librairies...')
import talib
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')
import time
import datetime as dt
import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
print('Librairies imported')

constituents = pd.read_csv('constituents_csv.csv')

# PARAMETRES TEMPORELS INITIAUX
start = pd.to_datetime('2017-03-03')
end = pd.to_datetime('2019-07-21')

error = []

# SCRAPING DES DONNES BRUTES
def scrap_data(ticker,start,end):
    df = web.DataReader(ticker,'yahoo',start,end)
    df = df.drop(['Close'],axis=1)
    df['Close'] = df['Adj Close']
    df = df.drop(['Adj Close'],axis = 1)
    df.tail()
    return(df)

def prepa_data(df):
    tmps1=time.time()
    print('Preparing data...')
    rsi = talib.RSI(df['Close'],timeperiod=14)
    stoc_slowk, stoc_slowd = talib.STOCH(df['High'],df['Low'],df['Close'])
    upper, middle, lower =  talib.BBANDS(df['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(df['Close'],timeperiod=5)
    sma8 = talib.SMA(df['Close'],timeperiod=8)
    sma10 = talib.SMA(df['Close'],timeperiod=10)
    sma12 = talib.SMA(df['Close'],timeperiod=12)
    sma15 = talib.SMA(df['Close'],timeperiod=15)
    sma30 = talib.SMA(df['Close'],timeperiod=30)
    sma35 = talib.SMA(df['Close'],timeperiod=35)
    sma40 = talib.SMA(df['Close'],timeperiod=40)
    sma45 = talib.SMA(df['Close'],timeperiod=45)
    sma50 = talib.SMA(df['Close'],timeperiod=50)
    atr = talib.ATR(df['High'],df['Low'],df['Close'],timeperiod=10)
    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50
    bbdelta = upper - middle
    price_bolup = df['Close'] - lower
    price_bolow = df['Close'] - upper
    Ema = talib.EMA(df['Close'],timeperiod=20)
    KC_High = Ema + 2*atr
    KC_Low = Ema - 2*atr
    aroondown, aroonup = talib.AROON(df['High'], df['Low'], timeperiod=9)
    aroon = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
    rsi30_list = []
    rsi70_list = []
    for i in range(0,df.shape[0]):
        rsi70_list.append(70 - rsi[i])
        rsi30_list.append(rsi[i] - 30)
        #except:
         #   rsi70_list.append(0)
          #  rs30_list.append(0)
    varop_spy = df['Open'] - df['Close']
    varhl_spy = df['High'] - df['Low']
    df['Varop_Spy'] = varop_spy
    df['Varhl_spy'] = varhl_spy
    df['RSI'] = rsi
    df['70 - RSI'] = np.array(rsi70_list)
    df['RSI - 30'] = np.array(rsi30_list)
    df['BBD_Delta_Up'] = bbdelta
    df['delta5_8'] = delta5_8
    df['delta8_10'] = delta8_10
    df['delta10_12'] = delta10_12
    df['delta12_15'] = delta12_15
    df['delta15_30'] = delta15_30
    df['delta30_35'] = delta30_35
    df['delta35_40'] = delta35_40
    df['delta40_45'] = delta40_45
    df['delta45_50'] = delta45_50
    df['Stoc_Slowk'] = stoc_slowk
    df['Stoc_Slowd'] = stoc_slowd
    df['KC_High'] = KC_High
    df['KC_Low'] = KC_Low
    df['upper'] = upper
    df['lower'] = lower
    df['var_bollup_kchigh'] = upper-KC_High
    df['var_bolllow_kclow'] = lower-KC_Low
    df['Aroon Up'] = aroonup
    df['Aroon Down'] = aroondown
    df['Delta Aroon'] = aroon
    up = []
    down = []
    df['Close.S'] = df['Close'].shift(-1)
    df['Close.S2'] = df['Close'].shift(-2)
    df['%Futur'] = ((df['Close.S']-df['Close']) *100) / (df['Close'])
    df['%Futur2'] = ((df['Close.S2']-df['Close']) *100) / (df['Close'])
    for i in range(0,df.shape[0]-5):
        if df.iloc[i]['%Futur'] > 0.4 or df.iloc[i]['%Futur2'] > 0.4:
            up.append(1)
            down.append(0)
        elif df.iloc[i]['%Futur'] < -0.1 or df.iloc[i]['%Futur2'] < -0.1:
            up.append(0)
            down.append(1)
        else:
            up.append(0)
            down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    
    
    df['target_up'] = up  # target_up # abs(np.array(valley))#target_up
    df['target_down'] = down # target_down # abs(np.array(peak))#target_down
    df = df.dropna()
    tmps2=round(time.time()-tmps1,2)
    print ("Data prepared in = %f" %tmps2,'seconds')
    return(df)

def deep_learning(df):
    tmps1=time.time()
    X = df.iloc[:,1:-6]
    y_up = df.iloc[:,-2].values
    y_down = df.iloc[:,-1].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:bloc1,:]
    Xtest = X[bloc1:,:]
    ytrain_up = y_up[:bloc1,:]
    ytest_up = y_up[bloc1:,:]
    ytrain_down = y_down[:bloc1,:]
    ytest_down = y_down[bloc1:,:]

    seed = 770
    np.random.seed(seed)

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    model_up = Sequential()
    # Add an input layer 
    model_up.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_up.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_up.add(Dense(1, activation='sigmoid'))

    model_down = Sequential()
    # Add an input layer 
    model_down.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_down.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_down.add(Dense(1, activation='sigmoid'))

    print('Processing move_up')
    model_up.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])
    
              

    history_up = model_up.fit(Xtrain, ytrain_up,epochs=280, batch_size=1, verbose=0)
    print('\n')
    print('Processing move_down')
    model_down.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])

    history_down = model_down.fit(Xtrain, ytrain_down,epochs=280, batch_size=1, verbose=0)
    print('\n')
    print('Computing done')
    print('\n')

    train_acc_up = model_up.evaluate(Xtrain, ytrain_up,verbose=1)
    train_acc_down = model_down.evaluate(Xtrain, ytrain_down,verbose=1)

    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    score_up = model_up.evaluate(Xtest, ytest_up,verbose=1)
    score_down = model_down.evaluate(Xtest, ytest_down,verbose=1)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)

    accuracy_up = accuracy_score(ytest_up, yhat_up)
    accuracy_down = accuracy_score(ytest_down, yhat_down)

    # La précision permet de mesurer la capacité du modèle à refuser résultats non-pertinents : vrais_positifs/(vrais_positifs+faux_positifs)
    precision_up = precision_score(ytest_up, yhat_up)  
    precision_down = precision_score(ytest_down, yhat_down) 


    # Recall : (vrai_positifs/(vrais_positifs+faux_négatifs))
    recall_up = recall_score(ytest_up, yhat_up) 
    recall_down = recall_score(ytest_down, yhat_down) 


    #roc_up=roc_auc_score(ytest_up,yhat_up)
    #roc_down=roc_auc_score(ytest_down,yhat_down)
    print('\n')
    print('RESULTATS UP\n')
    print('Accuracy: %.2f%%' % (accuracy_up * 100.0))
    print("Precision: %.2f%% " % (precision_up *100),' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_up * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_up *100))
    # get probabilities for positive class

    print(classification_report(ytest_up, yhat_up))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_up, yhat_up))

    print('\n')
    print('_______________________________________________________________________________________________________________________________________________________________\n')
    print('RESULTATS DOWN\n')
    print('Accuracy: %.2f%%' % (accuracy_down * 100.0))
    print("Precision: %.2f%% " % (precision_down *100),' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_down * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_down *100))
    # get probabilities for positive class

    print(classification_report(ytest_down, yhat_down))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_down, yhat_down))
    print('\n')

    resultats = pd.DataFrame()
    resultats['Date'] = df.index[bloc1:]
    resultats.index= df.index[bloc1:]
    resultats['Move Up'] = yhat_up
    resultats['Confiance up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confiance Down'] = (predict_down)*100
    resultats['Actual'] = df['Close']
    resultats['Actual.S'] = df['Close.S']
    dmp_cp=[]
    dmp_cp = ((resultats['Confiance up']-resultats['Confiance Down'])/(resultats['Confiance up']+resultats['Confiance Down'])*100)
    resultats['DMP_CP'] = dmp_cp
    tmps2=round(time.time()-tmps1,2)
    print ("Deep Learning executed in = %f" %tmps2,'seconds')
    #resultats.set_index('Date',inplace=True)
    #parse_dates=resultats['Date']
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def learn(df):
    resultats,precision_up,precision_down,model_up,model_down,scaler = deep_learning(df)
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

########################
#### MAIN SKAN55 #######
########################
try:
    
    for loop in range(0,len(constituents)):

        ticker = (constituents.iloc[loop]['Symbol'])
        global delta,bloc1,bloc2
        tmps1=time.time()
        print('Scraping data...')

        df = scrap_data(ticker,start,end)
        tmps2=round(time.time()-tmps1,2)
        print ("executed in = %f" %tmps2,'seconds')

        print('\n')
        print('GOLEM begins Computing...')
        print('\n')
        delta = round(df.shape[0])
        bloc1 = round(delta*0.80)
        bloc2 = delta - bloc1
        print("# of periods : ",delta)
        print('On 80% - 20% slash : ')
        print('Bloc 1 : ',bloc1,'\nBloc 2 :',bloc2,' periods ')
        print('First period :',df.index[0])
        print('Split period :',df.index[bloc1-1])
        print('Last period :',df.index[df.shape[0]-1])
        print('\n')

        df = prepa_data(df)

        resultats,precision_up,precision_down,model_up,model_down,scaler = learn(df)

        import sys
        orig_stdout = sys.stdout
        f = open('backtest de '+str(ticker)+'.txt', 'w')
        sys.stdout = f

        ####################
        #### TEST PLOT ####
        ###################

        filtre_up = 93
        filtre_down = 97


        plt.figure(figsize=(26,8),dpi=300)
        #plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
        plt.title('Deep Learning '+ticker+' Trade Signals')
        plt.plot(resultats['Actual'],color='purple',lw=0.9)

        green=[]
        red=[]

        for i in range(0,len(resultats)):


            if resultats.iloc[i]['Confiance Down'] > filtre_down:
                doob = -1

            elif resultats.iloc[i]['Confiance up'] > filtre_up:
                doob = 1

            else :
                doob = 0

            if doob == 1 :#and resultats.iloc[i]['Confiance up'] > filtre_up:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i,5],c='g',marker='o')
                #doob = -1
                green.append(1)
                red.append(0)

            elif doob == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i,5],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(1)

            else:
                green.append(0)
                red.append(0)
                #doob = 0


        plt.scatter(x=resultats.index[i],y=resultats.iloc[i,5],c='g',marker='o',label='Buy Signal')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i,5],c='r',marker='o',label='Sell Signal')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_01.pdf')
        plt.close()

        resultats['Green'] = green
        resultats['Red'] = red
        resultats['Actual'] = df['Close'][bloc1:]


        ########################
        ####### BACKTEST########
        ########################
        pos_long = 0
        pos_short = 0
        pactol = 100000
        price_buy = 0
        price_sell = 0
        x = 0
        winners = []
        loosers = []
        nb_win = 0
        nb_los = 0
        mini_pnl = 0
        pos_duration = []
        average_duration = resultats.iloc[0,0] - resultats.iloc[0,0]
        trades = []
        eq_curx = []
        eq_cury = []

        for i in range(0,len(resultats)):
            if pos_long == 0 and pos_short == 0 and resultats.iloc[i,-2] == 1 :
                pos_long = 1
                x = 100000/resultats.iloc[i,5]
                price_buy = resultats.iloc[i,5]
                time_enter = resultats.iloc[i,0]
                print('\n Le ',str(resultats.iloc[i,0]),', achat de ',x,' actions à',resultats.iloc[i,5],'$')
                print('Nouveau pactol : ',pactol)
                trades.append((resultats.iloc[i,5],resultats.iloc[i,0],1))

            elif pos_long == 1 and resultats.iloc[i,-1] == 1 :
                old_pactol = pactol
                eq_curx.append(resultats.iloc[i,0])
                eq_cury.append(old_pactol)
                pos_long = 0
                price_sell = resultats.iloc[i,5]
                trades.append((resultats.iloc[i,5],resultats.iloc[i,0],2))
                mini_pnl = x*(price_sell-price_buy)
                pactol = pactol + mini_pnl
                print('\n Le ',str(resultats.iloc[i,0]),', vente pour close de ',x,' actions à',resultats.iloc[i,5],'$')
                print('Nouveau pactol : ',pactol)
                print('pnl:', mini_pnl)
                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                pos_duration.append(resultats.iloc[i,0] - time_enter)
                price_buy=0
                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1


            elif pos_short == 0 and pos_long == 0 and resultats.iloc[i,-1]:
                pos_short = 1
                x = 100000/resultats.iloc[i,5]
                price_sell = resultats.iloc[i,5]
                time_enter = resultats.iloc[i,0]
                print('\n Le ',str(resultats.iloc[i,0]),', vente de ',x,' actions à',resultats.iloc[i,5],'$')
                print('Nouveau pactol : ',pactol)
                trades.append((resultats.iloc[i,5],resultats.iloc[i,0],-1))

            elif pos_short == 1 and resultats.iloc[i,-2] == 1 :
                old_pactol = pactol
                eq_curx.append(resultats.iloc[i,0])
                eq_cury.append(old_pactol)
                pos_short = 0
                price_buy=resultats.iloc[i,5]
                trades.append((resultats.iloc[i,5],resultats.iloc[i,0],-2))
                mini_pnl = x*(price_sell-price_buy)
                pactol = pactol + mini_pnl
                print('\n Le ',str(resultats.iloc[i,0]),', achat pour close de ',x,' actions à',resultats.iloc[i,5],'$')
                print('Nouveau pactol : ',pactol)

                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                print('pnl:', mini_pnl)
                pos_duration.append(resultats.iloc[i,0] - time_enter)
                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1



        if pos_long == 1:
            pos_long = 0
            print('Cutting non resolved position')
            x = round(100000/resultats.iloc[i,5])
            price_sell = resultats.iloc[i,5]
            mini_pnl = x*(price_sell-price_buy)
            pactol = pactol + mini_pnl
            print('pnl',mini_pnl)
            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1
            x = 0

        if pos_short == 1:
            pos_short = 0
            print('Cutting non resolved position')
            x = round(100000/resultats.iloc[i,5])
            price_buy=resultats.iloc[i,5]
            mini_pnl = x*(price_sell-price_buy)
            pactol = pactol + mini_pnl
            print('pnl',mini_pnl)

            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1
            x = 0    

        pnl = round(pactol - 100000,2)
        print('\n Begining of BackTest :',resultats.iloc[0,0])
        print('Instrument :',ticker)
        print('Face value per trade : $100,000')
        print('End of BackTest :',resultats.iloc[-1,0])
        duration = resultats.iloc[-1,0] - resultats.iloc[0,0]
        print("BackTest's period :",duration)
        print( 'pnl :',pnl,'$')
        print('Total winners :',round(sum(winners),2),'$')
        print('Total loosers :',round(sum(loosers),2),'$')
        print('Number of winners :',nb_win)
        print('Number of loosers :',nb_los)
        try:
            print('% winners :', round((nb_win/(nb_win+nb_los) * 100),2),'%')
            print('Average winners :',(round(sum(winners)/(nb_win))))
        except:
            print('% winners : null')
        try:
            print('Average losers :',(round(sum(loosers)/(nb_los))))
        except:
            print('Average losers : Inf')
        try:
            for t in range(0,len(pos_duration)):
                average_duration = average_duration + pos_duration[t]
            average_duration = average_duration/(nb_los+nb_win)
            print('Average Duration :', average_duration)
        except:
            print('No Average Duration available')
        try:
            print('Profit Factor : ',abs(round((sum(winners)/sum(loosers)),2)))
        except:
            print('Profit Factor : null')

        ########################
        ##### PLOT TRADES ######
        ########################

        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Trades')
        plt.plot(resultats['Actual'],color='blue',lw=0.9)
        for i in range(0,len(trades)):
            if trades[i][2] == 1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='green',marker='^',lw=2.5)
            elif trades[i][2] == -1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='red',marker='^',lw=2.5)
            elif trades[i][2] == 2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='g',marker='x',lw=2.5)
            elif trades[i][2] == -2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='r',marker='x',lw=2.5)

        plt.scatter(x=resultats.index[i],y=resultats.iloc[i,5],c='g',marker='^',label='Open Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i,5],c='r',marker='^',label='Open Short')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i,5],c='g',marker='x',label='Close Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i,5],c='r',marker='x',label='Close Short')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_02.pdf')
        plt.close()

        #########################
        ##### PLOT E-CURVE ######
        #########################
        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Equity Curve')
        plt.plot(eq_curx,eq_cury)
        plt.scatter(x=eq_curx,y=eq_cury,c='orange',marker='o',lw=2.5)
        plt.savefig('backtest de '+str(ticker)+'_03.pdf')
        plt.close()


        f.close()
        sys.stdout = orig_stdout

        print('\r Boucle ', loop, 'terminée...',end='')
        print('Ticker en cours : ',ticker,'. Opération restantes :', len(constituents)-loop,'/',len(constituents),'\n')
except:
    print('Problème loop : ',loop)
    error.append((loop,ticker))
    pass
# Out:
# Global Optimized LumberJack Environment Motor 55
# °OoO_FXCM_Oo0°
# LumberJack Jyss 5779(c)
# °0Oo_INVESTING.COM_oO0°
# SKAN55 Version v1.0
# Importing librairies...
# Importing Librairies...
# Librairies imported
# Scraping data...
# executed in = 1.500000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  599
# On 80% - 20% slash :
# Bloc 1 :  479
# Bloc 2 : 120  periods
# First period : 2017-03-03 00:00:00
# Split period : 2019-01-28 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Preparing data...
# Data prepared in = 0.290000 seconds
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 479/479 [==============================] - 3s 6ms/step
# 479/479 [==============================] - 3s 6ms/step
# 69/69 [==============================] - 0s 178us/step
# 69/69 [==============================] - 0s 156us/step
#
#
# RESULTATS UP
#
# Accuracy: 44.93%
# Precision: 42.37%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 86.21%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.60      0.15      0.24        40
#            1       0.42      0.86      0.57        29
#
#    micro avg       0.45      0.45      0.45        69
#    macro avg       0.51      0.51      0.40        69
# weighted avg       0.53      0.45      0.38        69
#
# [[ 6 34]
#  [ 4 25]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
# RESULTATS DOWN
#
# Accuracy: 56.52%
# Precision: 66.67%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 33.33%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.53      0.82      0.64        33
#            1       0.67      0.33      0.44        36
#
#    micro avg       0.57      0.57      0.57        69
#    macro avg       0.60      0.58      0.54        69
# weighted avg       0.60      0.57      0.54        69
#
# [[27  6]
#  [24 12]]
#
#
# Deep Learning executed in = 845.010000 seconds
#  Boucle  0 terminée...Ticker en cours :  MMM . Opération restantes : 505 / 505
#
# Scraping data...
# executed in = 4.410000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  599
# On 80% - 20% slash :
# Bloc 1 :  479
# Bloc 2 : 120  periods
# First period : 2017-03-03 00:00:00
# Split period : 2019-01-28 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Preparing data...
# Data prepared in = 0.310000 seconds
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 479/479 [==============================] - 3s 6ms/step
# 479/479 [==============================] - 3s 6ms/step
# 69/69 [==============================] - 0s 206us/step
# 69/69 [==============================] - 0s 145us/step
#
#
# RESULTATS UP
#
# Accuracy: 53.62%
# Precision: 50.00%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 71.88%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.61      0.38      0.47        37
#            1       0.50      0.72      0.59        32
#
#    micro avg       0.54      0.54      0.54        69
#    macro avg       0.55      0.55      0.53        69
# weighted avg       0.56      0.54      0.52        69
#
# [[14 23]
#  [ 9 23]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
# RESULTATS DOWN
#
# Accuracy: 59.42%
# Precision: 53.49%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 74.19%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.69      0.47      0.56        38
#            1       0.53      0.74      0.62        31
#
#    micro avg       0.59      0.59      0.59        69
#    macro avg       0.61      0.61      0.59        69
# weighted avg       0.62      0.59      0.59        69
#
# [[18 20]
#  [ 8 23]]
#
#
# Deep Learning executed in = 882.830000 seconds
#  Boucle  1 terminée...Ticker en cours :  AOS . Opération restantes : 504 / 505
#
# Scraping data...
# executed in = 4.710000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  599
# On 80% - 20% slash :
# Bloc 1 :  479
# Bloc 2 : 120  periods
# First period : 2017-03-03 00:00:00
# Split period : 2019-01-28 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Preparing data...
# Data prepared in = 0.290000 seconds
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 479/479 [==============================] - 3s 6ms/step
# 479/479 [==============================] - 3s 6ms/step
# 69/69 [==============================] - 0s 194us/step
# 69/69 [==============================] - 0s 199us/step
#
#
# RESULTATS UP
#
# Accuracy: 56.52%
# Precision: 61.54%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 44.44%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.53      0.70      0.61        33
#            1       0.62      0.44      0.52        36
#
#    micro avg       0.57      0.57      0.57        69
#    macro avg       0.58      0.57      0.56        69
# weighted avg       0.58      0.57      0.56        69
#
# [[23 10]
#  [20 16]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
# RESULTATS DOWN
#
# Accuracy: 46.38%
# Precision: 22.22%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 14.81%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.55      0.67      0.60        42
#            1       0.22      0.15      0.18        27
#
#    micro avg       0.46      0.46      0.46        69
#    macro avg       0.39      0.41      0.39        69
# weighted avg       0.42      0.46      0.44        69
#
# [[28 14]
#  [23  4]]
#
#
# Deep Learning executed in = 853.120000 seconds
#  Boucle  2 terminée...Ticker en cours :  ABT . Opération restantes : 503 / 505
#
# Scraping data...
# executed in = 1.190000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  599
# On 80% - 20% slash :
# Bloc 1 :  479
# Bloc 2 : 120  periods
# First period : 2017-03-03 00:00:00
# Split period : 2019-01-28 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Preparing data...
# Data prepared in = 0.280000 seconds
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 479/479 [==============================] - 3s 6ms/step
# 479/479 [==============================] - 3s 6ms/step
# 69/69 [==============================] - 0s 156us/step
# 69/69 [==============================] - 0s 209us/step
#
#
# RESULTATS UP
#
# Accuracy: 56.52%
# Precision: 55.32%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 74.29%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.59      0.38      0.46        34
#            1       0.55      0.74      0.63        35
#
#    micro avg       0.57      0.57      0.57        69
#    macro avg       0.57      0.56      0.55        69
# weighted avg       0.57      0.57      0.55        69
#
# [[13 21]
#  [ 9 26]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
# RESULTATS DOWN
#
# Accuracy: 53.62%
# Precision: 44.83%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 44.83%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.60      0.60      0.60        40
#            1       0.45      0.45      0.45        29
#
#    micro avg       0.54      0.54      0.54        69
#    macro avg       0.52      0.52      0.52        69
# weighted avg       0.54      0.54      0.54        69
#
# [[24 16]
#  [16 13]]
#
#
# Deep Learning executed in = 833.230000 seconds
#  Boucle  3 terminée...Ticker en cours :  ABBV . Opération restantes : 502 / 505
#
# Scraping data...
# executed in = 1.450000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  599
# On 80% - 20% slash :
# Bloc 1 :  479
# Bloc 2 : 120  periods
# First period : 2017-03-03 00:00:00
# Split period : 2019-01-28 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Preparing data...
# Data prepared in = 0.310000 seconds
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 479/479 [==============================] - 3s 6ms/step
# 479/479 [==============================] - 3s 6ms/step
# 69/69 [==============================] - 0s 136us/step
# 69/69 [==============================] - 0s 183us/step
#
#
# RESULTATS UP
#
# Accuracy: 60.87%
# Precision: 63.16%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 37.50%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.60      0.81      0.69        37
#            1       0.63      0.38      0.47        32
#
#    micro avg       0.61      0.61      0.61        69
#    macro avg       0.62      0.59      0.58        69
# weighted avg       0.61      0.61      0.59        69
#
# [[30  7]
#  [20 12]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
# RESULTATS DOWN
#
# Accuracy: 56.52%
# Precision: 46.51%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 74.07%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.73      0.45      0.56        42
#            1       0.47      0.74      0.57        27
#
#    micro avg       0.57      0.57      0.57        69
#    macro avg       0.60      0.60      0.57        69
# weighted avg       0.63      0.57      0.56        69
#
# [[19 23]
#  [ 7 20]]
#
#
# Deep Learning executed in = 911.330000 seconds
#  Boucle  4 terminée...Ticker en cours :  ACN . Opération restantes : 501 / 505
#
# Scraping data...
# executed in = 1.330000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  599
# On 80% - 20% slash :
# Bloc 1 :  479
# Bloc 2 : 120  periods
# First period : 2017-03-03 00:00:00
# Split period : 2019-01-28 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Preparing data...
# Data prepared in = 0.270000 seconds
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 479/479 [==============================] - 3s 6ms/step
# 479/479 [==============================] - 3s 6ms/step
# 69/69 [==============================] - 0s 149us/step
# 69/69 [==============================] - 0s 191us/step
#
#
# RESULTATS UP
#
# Accuracy: 53.62%
# Precision: 60.47%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 63.41%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.42      0.39      0.41        28
#            1       0.60      0.63      0.62        41
#
#    micro avg       0.54      0.54      0.54        69
#    macro avg       0.51      0.51      0.51        69
# weighted avg       0.53      0.54      0.53        69
#
# [[11 17]
#  [15 26]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
# RESULTATS DOWN
#
# Accuracy: 59.42%
# Precision: 42.86%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 50.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.71      0.64      0.67        45
#            1       0.43      0.50      0.46        24
#
#    micro avg       0.59      0.59      0.59        69
#    macro avg       0.57      0.57      0.57        69
# weighted avg       0.61      0.59      0.60        69
#
# [[29 16]
#  [12 12]]
#
#
# Deep Learning executed in = 915.350000 seconds
#  Boucle  5 terminée...Ticker en cours :  ATVI . Opération restantes : 500 / 505
#
# Scraping data...
# executed in = 1.950000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  599
# On 80% - 20% slash :
# Bloc 1 :  479
# Bloc 2 : 120  periods
# First period : 2017-03-03 00:00:00
# Split period : 2019-01-28 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Preparing data...
# Data prepared in = 0.270000 seconds
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 479/479 [==============================] - 3s 7ms/step
# 479/479 [==============================] - 3s 6ms/step
# 69/69 [==============================] - 0s 133us/step
# 69/69 [==============================] - 0s 179us/step
#
#
# RESULTATS UP
#
# Accuracy: 55.07%
# Precision: 61.29%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 50.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.50      0.61      0.55        31
#            1       0.61      0.50      0.55        38
#
#    micro avg       0.55      0.55      0.55        69
#    macro avg       0.56      0.56      0.55        69
# weighted avg       0.56      0.55      0.55        69
#
# [[19 12]
#  [19 19]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
# RESULTATS DOWN
#
# Accuracy: 43.48%
# Precision: 33.33%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 50.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.57      0.40      0.47        43
#            1       0.33      0.50      0.40        26
#
#    micro avg       0.43      0.43      0.43        69
#    macro avg       0.45      0.45      0.43        69
# weighted avg       0.48      0.43      0.44        69
#
# [[17 26]
#  [13 13]]
#
#
# Deep Learning executed in = 1351.080000 seconds
#  Boucle  6 terminée...Ticker en cours :  AYI . Opération restantes : 499 / 505
#
# Scraping data...
# executed in = 1.070000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  599
# On 80% - 20% slash :
# Bloc 1 :  479
# Bloc 2 : 120  periods
# First period : 2017-03-03 00:00:00
# Split period : 2019-01-28 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Preparing data...
# Data prepared in = 0.380000 seconds
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 479/479 [==============================] - 4s 8ms/step
# 479/479 [==============================] - 4s 8ms/step
# 69/69 [==============================] - 0s 270us/step
# 69/69 [==============================] - 0s 211us/step
#
#
# RESULTATS UP
#
# Accuracy: 50.72%
# Precision: 59.26%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 41.03%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.45      0.63      0.53        30
#            1       0.59      0.41      0.48        39
#
#    micro avg       0.51      0.51      0.51        69
#    macro avg       0.52      0.52      0.51        69
# weighted avg       0.53      0.51      0.50        69
#
# [[19 11]
#  [23 16]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
# RESULTATS DOWN
#
# Accuracy: 47.83%
# Precision: 33.33%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 50.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.64      0.47      0.54        45
#            1       0.33      0.50      0.40        24
#
#    micro avg       0.48      0.48      0.48        69
#    macro avg       0.48      0.48      0.47        69
# weighted avg       0.53      0.48      0.49        69
#
# [[21 24]
#  [12 12]]
#
#
# Deep Learning executed in = 1255.490000 seconds
#  Boucle  7 terminée...Ticker en cours :  ADBE . Opération restantes : 498 / 505
#
# Scraping data...
# executed in = 4.350000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  599
# On 80% - 20% slash :
# Bloc 1 :  479
# Bloc 2 : 120  periods
# First period : 2017-03-03 00:00:00
# Split period : 2019-01-28 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Preparing data...
# Data prepared in = 0.370000 seconds
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 479/479 [==============================] - 4s 8ms/step
# 479/479 [==============================] - 3s 7ms/step
# 69/69 [==============================] - 0s 222us/step
# 69/69 [==============================] - 0s 236us/step
#
#
# RESULTATS UP
#
# Accuracy: 62.32%
# Precision: 54.90%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 90.32%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.83      0.39      0.54        38
#            1       0.55      0.90      0.68        31
#
#    micro avg       0.62      0.62      0.62        69
#    macro avg       0.69      0.65      0.61        69
# weighted avg       0.71      0.62      0.60        69
#
# [[15 23]
#  [ 3 28]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
# RESULTATS DOWN
#
# Accuracy: 68.12%
# Precision: 78.95%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 45.45%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.64      0.89      0.74        36
#            1       0.79      0.45      0.58        33
#
#    micro avg       0.68      0.68      0.68        69
#    macro avg       0.71      0.67      0.66        69
# weighted avg       0.71      0.68      0.66        69
#
# [[32  4]
#  [18 15]]
#
#
# Deep Learning executed in = 3214.810000 seconds
#  Boucle  8 terminée...Ticker en cours :  AAP . Opération restantes : 497 / 505
#
# Scraping data...
# executed in = 1.580000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  599
# On 80% - 20% slash :
# Bloc 1 :  479
# Bloc 2 : 120  periods
# First period : 2017-03-03 00:00:00
# Split period : 2019-01-28 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Preparing data...
# Data prepared in = 0.430000 seconds
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 479/479 [==============================] - 3s 6ms/step
# 479/479 [==============================] - 3s 7ms/step
# 69/69 [==============================] - 0s 159us/step
# 69/69 [==============================] - 0s 218us/step
#
#
# RESULTATS UP
#
# Accuracy: 55.07%
# Precision: 66.67%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 36.84%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.50      0.77      0.61        31
#            1       0.67      0.37      0.47        38
#
#    micro avg       0.55      0.55      0.55        69
#    macro avg       0.58      0.57      0.54        69
# weighted avg       0.59      0.55      0.53        69
#
# [[24  7]
#  [24 14]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
# RESULTATS DOWN
#
# Accuracy: 44.93%
# Precision: 37.78%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 62.96%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.58      0.33      0.42        42
#            1       0.38      0.63      0.47        27
#
#    micro avg       0.45      0.45      0.45        69
#    macro avg       0.48      0.48      0.45        69
# weighted avg       0.50      0.45      0.44        69
#
# [[14 28]
#  [10 17]]
#
#
# Deep Learning executed in = 1044.140000 seconds
#  Boucle  9 terminée...Ticker en cours :  AMD . Opération restantes : 496 / 505
#
# Scraping data...
# executed in = 1.160000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  599
# On 80% - 20% slash :
# Bloc 1 :  479
# Bloc 2 : 120  periods
# First period : 2017-03-03 00:00:00
# Split period : 2019-01-28 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Preparing data...
# Data prepared in = 0.300000 seconds
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 479/479 [==============================] - 3s 6ms/step
# 479/479 [==============================] - 3s 6ms/step
# 69/69 [==============================] - 0s 158us/step
# 69/69 [==============================] - 0s 229us/step
#
#
# RESULTATS UP
#
# Accuracy: 47.83%
# Precision: 41.51%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 81.48%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.69      0.26      0.38        42
#            1       0.42      0.81      0.55        27
#
#    micro avg       0.48      0.48      0.48        69
#    macro avg       0.55      0.54      0.46        69
# weighted avg       0.58      0.48      0.45        69
#
# [[11 31]
#  [ 5 22]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
# RESULTATS DOWN
#
# Accuracy: 47.83%
# Precision: 100.00%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 2.70%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.47      1.00      0.64        32
#            1       1.00      0.03      0.05        37
#
#    micro avg       0.48      0.48      0.48        69
#    macro avg       0.74      0.51      0.35        69
# weighted avg       0.75      0.48      0.33        69
#
# [[32  0]
#  [36  1]]
#
#
# Deep Learning executed in = 1009.870000 seconds
#  Boucle  10 terminée...Ticker en cours :  AES . Opération restantes : 495 / 505
#
# Scraping data...
# executed in = 1.080000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  185
# On 80% - 20% slash :
# Bloc 1 :  148
# Bloc 2 : 37  periods
# First period : 2018-01-04 00:00:00
# Split period : 2018-10-08 00:00:00
# Last period : 2018-11-29 00:00:00
#
#
# Preparing data...
# Data prepared in = 0.120000 seconds
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 134/134 [==============================] - 4s 26ms/step
# 134/134 [==============================] - 3s 26ms/step
# Problème loop :  11

# %%
# for loop in range(0,len(constituents)):
#    ticker = (constituents.iloc[loop]['Symbol'])

# %%
#import sys
#orig_stdout = sys.stdout
#f = open('backtestv2_4.txt', 'w')
#sys.stdout = f

# %%
#f.close()
#sys.stdout = orig_stdout

# %%
loop
# Out:
# 70

# %%
# 10 40 65 70

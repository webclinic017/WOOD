# %%
___Author___='LumberJack Jyss'

# %%
import pandas as pd
import pandas_datareader as web
import quandl
import numpy as np
from scipy.optimize import minimize
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(palette='bright',style='whitegrid') #["deep", "muted", "pastel", "bright", "dark", "colorblind"]

# %%
# help(stats.linregress)

# %%
spy_etf=web.DataReader('SPY','yahoo') # will give an index

# %%
spy_etf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2315 entries, 2010-01-04 to 2019-03-15
# Data columns (total 6 columns):
# High         2315 non-null float64
# Low          2315 non-null float64
# Open         2315 non-null float64
# Close        2315 non-null float64
# Volume       2315 non-null float64
# Adj Close    2315 non-null float64
# dtypes: float64(6)
# memory usage: 126.6 KB

# %%
spy_etf.head()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2010-01-04  113.389999  111.510002  112.370003  113.330002  118944600.0
# 2010-01-05  113.680000  112.849998  113.260002  113.629997  111579900.0
# 2010-01-06  113.989998  113.430000  113.519997  113.709999  116074400.0
# 2010-01-07  114.330002  113.180000  113.500000  114.190002  131091100.0
# 2010-01-08  114.620003  113.660004  113.889999  114.570000  126402800.0
#
#             Adj Close  Cumulative  Daily Return
# Date
# 2010-01-04  94.545494    1.000000           NaN
# 2010-01-05  94.795784    1.002647      0.002647
# 2010-01-06  94.862526    1.003353      0.000704
# 2010-01-07  95.262955    1.007588      0.004221
# 2010-01-08  95.579971    1.010941      0.003328

# %%
# Ce n'est pas le S&P mais juste un indicateur d'un exchange trade fund (etf).
start = pd.to_datetime('2010-01-04') # On récupère la date de début par .head()
end = pd.to_datetime('2019-03-15') # On récupère la date de fin par .tail()

# %%
aapl=web.DataReader('AAPL','yahoo',start,end)

# %%
aapl['Close'].plot(label='AAPL',figsize=(16,6))
spy_etf['Close'].plot(label='SPY Index',figsize=(16,6))
plt.legend()

# %%
aapl['Cumulative']=aapl['Close']/aapl['Close'].iloc[0]
spy_etf['Cumulative']=spy_etf['Close']/spy_etf['Close'].iloc[0]

# %%
aapl['Cumulative'].plot(label='AAPL Cumulative Return', figsize=(16,6))
spy_etf['Cumulative'].plot(label='SPY')
plt.legend()

# %%
aapl['Daily Return'] = aapl['Close'].pct_change(1)
spy_etf['Daily Return'] = spy_etf['Close'].pct_change(1)

# %%
plt.scatter(aapl['Daily Return'],spy_etf['Daily Return'],alpha=0.25)
# S'il y a une parfaite corrélation, on observe une droite bien claire

# %%
# On passe par une RL
beta,alpha,r_value,p_value,std_err = stats.linregress(aapl['Daily Return'].iloc[1:],\
spy_etf['Daily Return'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-129e9092ef4f> in <module>
#       1 # On passe par une RL
#       2 beta,alpha,r_value,p_value,std_err = stats.linregress(aapl['Daily Return'].iloc[1:],\
# ----> 3 spy_etf['Daily Return'])
#
# ~/Applications/anaconda3/lib/python3.6/site-packages/scipy/stats/_stats_mstats_common.py in linregress(x, y)
#     100
#     101     # average sum of squares:
# --> 102     ssxm, ssxym, ssyxm, ssym = np.cov(x, y, bias=1).flat
#     103     r_num = ssxym
#     104     r_den = np.sqrt(ssxm * ssym)
#
# ~/Applications/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights)
#    2259         if not rowvar and y.shape[0] != 1:
#    2260             y = y.T
# -> 2261         X = np.concatenate((X, y), axis=0)
#    2262
#    2263     if ddof is None:
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly

# %%
beta

# %%
alpha # Close to zéro, but not

# %%
r_value # valeur bof

# On va créer du bruit artificilement pour mieux comprendre

# %%
noise = np.random.normal(0,0.001,len(spy_etf['Daily Return'].iloc[1:]))
noise

# %%
fake_stock = spy_etf[et_return].iloc[1:]+noise

# %%
# Scfake r splot one other the other
plt.scatter(fake_stock,etf_spy,alpha=0.25)
# Forcéement, on s'attend à une droite très marquée, car on veut prouver que le

# %%
beta,alpha,r_value,p_value,std_err = stats.linregress(aapl['Daily Value'].ilc[1:],\
etf_spy['Daily Value'])

# %%
beta #  almost 1 because

# %%
alpha # very small

# %%
# => LE MODELE FONCTIONNE. Le but sera donc d'augmenter vraiment le alpha

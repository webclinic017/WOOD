# %%
___Author___='LumberJack Jyss'

# %%
import random

# %%
print("Modèle Bollinger Stochastic Descent #1 de Cliff Benson")

print('Mise de départ de 400 000, valeur à 100')

pool_long = 100000
pool_short = 100000
stock_long = 1000
stock_short = 1000
value = 100
gain = 0
cumul = 0
ratio = 0
p = -1
boucle = 0

print('________________')
print("Initialization")
print('________________')

while boucle < 5:
    n = random.randint(-20,20)
    value = 100 + n
    p = p + 1
    boucle = boucle + 1
    
    if n == 0:
            boucle = boucle + 1
            print ('Phase',p)
            print("Valeur d'achat : ", value)
            print ('Pool_long : ',pool_long)
            print ('stock_long : ',stock_long)
            print ('pool_short : ',pool_short)
            print ('stock_short : ',stock_short)
            print('___________________________')
    
    elif n < 0 and pool_long > 0:
        print ('Phase',p)
        print("Valeur d'achat : ", value)
        print('Long on de ',((pool_long/2) / value),' actions')
        print('Dépense du pool long de ',(pool_long/2))
        stock_long = stock_long + ((pool_long/2) / value)
        pool_long = pool_long - (pool_long/2)
        boucle = 0
        print ('Pool_long : ',pool_long)
        print ('stock_long : ',stock_long)
        print ('pool_short : ',pool_short)
        print ('stock_short : ',stock_short)
        print('___________________________')
    
    elif n > 0 and stock_short > 1 :
            print ('Phase',p)
            print("Valeur d'achat : ", value)
            print('Short de ',(stock_short/2),' actions')
            print('Gain du pool short de ',((stock_short/2) * value))
            pool_short = pool_short + ((stock_short/2) * value)
            stock_short = stock_short - (stock_short/2)
            boucle = 0
            print ('Pool_long : ',pool_long)
            print ('stock_long : ',stock_long)
            print ('pool_short : ',pool_short)
            print ('stock_short : ',stock_short)
            print('___________________________')
            
    else :
        boucle = boucle + 1
        print ('Phase',p)
        print("Valeur d'achat : ", value)
        print ('Pool_long : ',pool_long)
        print ('stock_long : ',stock_long)
        print ('pool_short : ',pool_short)
        print ('stock_short : ',stock_short)
        print('___________________________')
        if boucle == 5:
            exit
print('___________________________________________________________________')
print("Il n'y a plus de fond à dépenser. Termination")
print('___________________________________________________________________')

    
print ('Phase',p)
print("Valeur d'achat : ", value)
print ('Pool_long : ',pool_long)
print ('stock_long : ',stock_long)
print ('pool_short : ',pool_short)
print ('stock_short : ',stock_short)
print('___________________________')
    
    

pool_short = pool_short + (stock_short * value)
stock_short = 0
pool_long = pool_long + (stock_long * value)
stock_long = 0

print('___________________________________________________________________')
print("Il n'y a plus de stock à vendre. Finalization")
print('___________________________________________________________________')

print ('Phase finale')
print("Valeur d'achat : ", value)
print ('Pool_long : ',pool_long)
print ('stock_long : ',stock_long)
print ('pool_short : ',pool_short)
print ('stock_short : ',stock_short)
print('___________________________')

cumul = pool_short + pool_long
print('le cumul est de : ',cumul)
gain = cumul - 400000
print ("Le gain total est de : ",gain)
ratio = gain/4000
print('Le ratio est de ',ratio,'%')
# Out:
# Modèle Bollinger Stochastic Descent #1 de Cliff Benson
# Mise de départ de 400 000, valeur à 100
# ________________
# Initialization
# ________________
# Phase 0
# Valeur d'achat :  100
# Pool_long :  100000
# stock_long :  1000
# pool_short :  100000
# stock_short :  1000
# ___________________________
# Phase 1
# Valeur d'achat :  85
# Long on de  588.2352941176471  actions
# Dépense du pool long de  50000.0
# Pool_long :  50000.0
# stock_long :  1588.235294117647
# pool_short :  100000
# stock_short :  1000
# ___________________________
# Phase 2
# Valeur d'achat :  106
# Short de  500.0  actions
# Gain du pool short de  53000.0
# Pool_long :  50000.0
# stock_long :  1588.235294117647
# pool_short :  153000.0
# stock_short :  500.0
# ___________________________
# Phase 3
# Valeur d'achat :  108
# Short de  250.0  actions
# Gain du pool short de  27000.0
# Pool_long :  50000.0
# stock_long :  1588.235294117647
# pool_short :  180000.0
# stock_short :  250.0
# ___________________________
# Phase 4
# Valeur d'achat :  104
# Short de  125.0  actions
# Gain du pool short de  13000.0
# Pool_long :  50000.0
# stock_long :  1588.235294117647
# pool_short :  193000.0
# stock_short :  125.0
# ___________________________
# Phase 5
# Valeur d'achat :  88
# Long on de  284.09090909090907  actions
# Dépense du pool long de  25000.0
# Pool_long :  25000.0
# stock_long :  1872.326203208556
# pool_short :  193000.0
# stock_short :  125.0
# ___________________________
# Phase 6
# Valeur d'achat :  81
# Long on de  154.320987654321  actions
# Dépense du pool long de  12500.0
# Pool_long :  12500.0
# stock_long :  2026.647190862877
# pool_short :  193000.0
# stock_short :  125.0
# ___________________________
# Phase 7
# Valeur d'achat :  115
# Short de  62.5  actions
# Gain du pool short de  7187.5
# Pool_long :  12500.0
# stock_long :  2026.647190862877
# pool_short :  200187.5
# stock_short :  62.5
# ___________________________
# Phase 8
# Valeur d'achat :  102
# Short de  31.25  actions
# Gain du pool short de  3187.5
# Pool_long :  12500.0
# stock_long :  2026.647190862877
# pool_short :  203375.0
# stock_short :  31.25
# ___________________________
# Phase 9
# Valeur d'achat :  96
# Long on de  65.10416666666667  actions
# Dépense du pool long de  6250.0
# Pool_long :  6250.0
# stock_long :  2091.751357529544
# pool_short :  203375.0
# stock_short :  31.25
# ___________________________
# Phase 10
# Valeur d'achat :  91
# Long on de  34.34065934065934  actions
# Dépense du pool long de  3125.0
# Pool_long :  3125.0
# stock_long :  2126.092016870203
# pool_short :  203375.0
# stock_short :  31.25
# ___________________________
# Phase 11
# Valeur d'achat :  92
# Long on de  16.983695652173914  actions
# Dépense du pool long de  1562.5
# Pool_long :  1562.5
# stock_long :  2143.075712522377
# pool_short :  203375.0
# stock_short :  31.25
# ___________________________
# Phase 12
# Valeur d'achat :  83
# Long on de  9.412650602409638  actions
# Dépense du pool long de  781.25
# Pool_long :  781.25
# stock_long :  2152.4883631247867
# pool_short :  203375.0
# stock_short :  31.25
# ___________________________
# Phase 13
# Valeur d'achat :  80
# Long on de  4.8828125  actions
# Dépense du pool long de  390.625
# Pool_long :  390.625
# stock_long :  2157.3711756247867
# pool_short :  203375.0
# stock_short :  31.25
# ___________________________
# Phase 14
# Valeur d'achat :  111
# Short de  15.625  actions
# Gain du pool short de  1734.375
# Pool_long :  390.625
# stock_long :  2157.3711756247867
# pool_short :  205109.375
# stock_short :  15.625
# ___________________________
# Phase 15
# Valeur d'achat :  81
# Long on de  2.4112654320987654  actions
# Dépense du pool long de  195.3125
# Pool_long :  195.3125
# stock_long :  2159.7824410568855
# pool_short :  205109.375
# stock_short :  15.625
# ___________________________
# Phase 16
# Valeur d'achat :  98
# Long on de  0.9964923469387755  actions
# Dépense du pool long de  97.65625
# Pool_long :  97.65625
# stock_long :  2160.7789334038243
# pool_short :  205109.375
# stock_short :  15.625
# ___________________________
# Phase 17
# Valeur d'achat :  118
# Short de  7.8125  actions
# Gain du pool short de  921.875
# Pool_long :  97.65625
# stock_long :  2160.7789334038243
# pool_short :  206031.25
# stock_short :  7.8125
# ___________________________
# Phase 18
# Valeur d'achat :  94
# Long on de  0.5194481382978723  actions
# Dépense du pool long de  48.828125
# Pool_long :  48.828125
# stock_long :  2161.298381542122
# pool_short :  206031.25
# stock_short :  7.8125
# ___________________________
# Phase 19
# Valeur d'achat :  94
# Long on de  0.25972406914893614  actions
# Dépense du pool long de  24.4140625
# Pool_long :  24.4140625
# stock_long :  2161.558105611271
# pool_short :  206031.25
# stock_short :  7.8125
# ___________________________
# Phase 20
# Valeur d'achat :  107
# Short de  3.90625  actions
# Gain du pool short de  417.96875
# Pool_long :  24.4140625
# stock_long :  2161.558105611271
# pool_short :  206449.21875
# stock_short :  3.90625
# ___________________________
# Phase 21
# Valeur d'achat :  112
# Short de  1.953125  actions
# Gain du pool short de  218.75
# Pool_long :  24.4140625
# stock_long :  2161.558105611271
# pool_short :  206667.96875
# stock_short :  1.953125
# ___________________________
# Phase 22
# Valeur d'achat :  98
# Long on de  0.12456154336734694  actions
# Dépense du pool long de  12.20703125
# Pool_long :  12.20703125
# stock_long :  2161.6826671546382
# pool_short :  206667.96875
# stock_short :  1.953125
# ___________________________
# Phase 23
# Valeur d'achat :  103
# Short de  0.9765625  actions
# Gain du pool short de  100.5859375
# Pool_long :  12.20703125
# stock_long :  2161.6826671546382
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 24
# Valeur d'achat :  111
# Pool_long :  12.20703125
# stock_long :  2161.6826671546382
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 25
# Valeur d'achat :  81
# Long on de  0.07535204475308642  actions
# Dépense du pool long de  6.103515625
# Pool_long :  6.103515625
# stock_long :  2161.758019199391
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 26
# Valeur d'achat :  91
# Long on de  0.03353580013736264  actions
# Dépense du pool long de  3.0517578125
# Pool_long :  3.0517578125
# stock_long :  2161.7915549995287
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 27
# Valeur d'achat :  99
# Long on de  0.015412918244949494  actions
# Dépense du pool long de  1.52587890625
# Pool_long :  1.52587890625
# stock_long :  2161.806967917774
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 28
# Valeur d'achat :  82
# Long on de  0.009304139672256097  actions
# Dépense du pool long de  0.762939453125
# Pool_long :  0.762939453125
# stock_long :  2161.816272057446
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 29
# Valeur d'achat :  106
# Pool_long :  0.762939453125
# stock_long :  2161.816272057446
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 30
# Valeur d'achat :  93
# Long on de  0.004101825016801075  actions
# Dépense du pool long de  0.3814697265625
# Pool_long :  0.3814697265625
# stock_long :  2161.8203738824627
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 31
# Valeur d'achat :  101
# Pool_long :  0.3814697265625
# stock_long :  2161.8203738824627
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 32
# Valeur d'achat :  119
# Pool_long :  0.3814697265625
# stock_long :  2161.8203738824627
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 33
# Valeur d'achat :  97
# Long on de  0.0019663387967139177  actions
# Dépense du pool long de  0.19073486328125
# Pool_long :  0.19073486328125
# stock_long :  2161.8223402212593
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 34
# Valeur d'achat :  105
# Pool_long :  0.19073486328125
# stock_long :  2161.8223402212593
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 35
# Valeur d'achat :  97
# Long on de  0.0009831693983569588  actions
# Dépense du pool long de  0.095367431640625
# Pool_long :  0.095367431640625
# stock_long :  2161.8233233906576
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 36
# Valeur d'achat :  120
# Pool_long :  0.095367431640625
# stock_long :  2161.8233233906576
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 37
# Valeur d'achat :  99
# Long on de  0.0004816536951546717  actions
# Dépense du pool long de  0.0476837158203125
# Pool_long :  0.0476837158203125
# stock_long :  2161.823805044353
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 38
# Valeur d'achat :  113
# Pool_long :  0.0476837158203125
# stock_long :  2161.823805044353
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 39
# Valeur d'achat :  119
# Pool_long :  0.0476837158203125
# stock_long :  2161.823805044353
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# Phase 40
# Valeur d'achat :  116
# Pool_long :  0.0476837158203125
# stock_long :  2161.823805044353
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# ___________________________________________________________________
# Il n'y a plus de fond à dépenser. On amorce la phase de termination
# ___________________________________________________________________
# Phase 40
# Valeur d'achat :  116
# Pool_long :  0.0476837158203125
# stock_long :  2161.823805044353
# pool_short :  206768.5546875
# stock_short :  0.9765625
# ___________________________
# ___________________________________________________________________
# Il n'y a plus de stock à vendre. On amorce la phase de termination
# ___________________________________________________________________
# Phase finale
# Valeur d'achat :  116
# Pool_long :  250771.60906886077
# stock_long :  0
# pool_short :  206881.8359375
# stock_short :  0
# ___________________________
# le cumul est de :  457653.44500636077
# Le gain total est de :  57653.445006360766
# Le ratio est de  14.41336125159019 %

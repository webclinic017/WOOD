# %%
___Author___='LumberJack Jyss'

# %%
print('LumberJack Trading Predictor Model\nLumberJack Jyss (c)')
# Out:
# LumberJack Trading Predictor Model
# LumberJack Jyss (c)

# %% [markdown]
# ## IMPORT DES LIBRAIRIES

# %%
print('Importation des librairies...')
from yahoofinancials import YahooFinancials
from python_utils import *
import time
import numpy as np
import pandas as pd
from mxnet import nd, autograd, gluon
from mxnet.gluon import nn, rnn
import mxnet as mx
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.decomposition import PCA
import math
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score
import warnings
import pandas_datareader as web
import bert
from collections import deque
from statsmodels.tsa.arima_model import ARIMA
from pandas.plotting import autocorrelation_plot
print('Librairies importées')
# Out:
# Importation des librairies...
# Librairies importées

# %%
warnings.filterwarnings("ignore")
context = mx.cpu(); model_ctx=mx.cpu()
mx.random.seed(1719)

# %%
def parser(x):
    return datetime.datetime.strptime(x,'%Y-%m-%d')

# %%
# PARAMETRES TEMPORELS INITIAUX
print('PARAMETRES TEMPORELS INITIAUX')
start = pd.to_datetime('2018-03-03')
end = pd.to_datetime('2019-03-03')
delta = round((end-start).days)
bloc1 = round(delta*0.8)
bloc2 = delta - bloc1
print("Période d'étude : ",delta)
print('Sur un découpage 80% - 20% de la période : ')
print('Bloc 1 : ',bloc1,' jours \nBloc 2 :',bloc2,' jours')
print('Note : On change de règles de calculs, car tous les jours ne sont pas ouvrés')
# Out:
# PARAMETRES TEMPORELS INITIAUX
# Période d'étude :  365
# Sur un découpage 80% - 20% de la période :
# Bloc 1 :  292  jours
# Bloc 2 : 73  jours
# Note : On change de règles de calculs, car tous les jours ne sont pas ouvrés

# %% [markdown]
# ## PREPARATION DU DATASET

# %% [markdown]
# Il nous faut récupérer sur une période donnée :
#
# EURUSD (OUTPUT) | USDJPY | USDCAD | USDGBP
#
#
# NIKKEI225 | EUROSTOXX50 | FTSE100 | VIX | GLD | SLV | USO
#
#
# Sur ces indices
#
# MM8 => Moving Mean 8D | MM34 => Moving Mean 34D | RSI | MACD | BOLLINGER (modifié) [On currencies & stocks]

# %%
# SCRAPING DES DONNES BRUTES

spy = web.DataReader('SPY','yahoo',start,end)
vix = web.DataReader('^VIX','yahoo',start,end)
gld = web.DataReader('GLD','yahoo',start,end)
slv = web.DataReader('SLV','yahoo',start,end)
uso = web.DataReader('USO','yahoo',start,end)
eurostoxx = web.DataReader('^STOXX50E','yahoo',start,end)
nikkei = web.DataReader('^N225','yahoo',start,end)
print('Scraping des données brutes effectué\n')
# Out:
# Scraping des données brutes effectué

# %%
# CHARGEMENT DES CSV
path = '/Users/YTsBaCh/Documents/DATA SCIENCES/20190402 MODELES STOCK/'
eurusd = pd.read_csv(path+'EURUSD.csv',sep=',',index_col='Date',parse_dates=True)
usdcad = pd.read_csv(path+'USDCAD.csv',sep=',',index_col='Date',parse_dates=True)
usdgbp = pd.read_csv(path+'USDGBP.csv',sep=',',index_col='Date',parse_dates=True)
usdjpy = pd.read_csv(path+'USDJPY.csv',sep=',',index_col='Date',parse_dates=True)
ftse = pd.read_csv(path+'FTSE.csv',sep=',',index_col='Date',parse_dates=True)
print('CSV chargés')
# Out:
# CSV chargés

# %%
print('TOUTES LES DONNEES SONT COLLECTEES')
print('\n\nPREPARATION DES DONNEES')
# Out:
# TOUTES LES DONNEES SONT COLLECTEES
#
#
# PREPARATION DES DONNEES

# %%
# TRAITEMENT DES DONNEES BRUTES
spy = spy.drop(['Open','Adj Close','High','Low','Volume'],axis = 1)
vix = vix.drop(['Open','Adj Close','High','Low','Volume'],axis = 1)
gld = gld.drop(['Open','Adj Close','High','Low','Volume'],axis = 1)
slv = slv.drop(['Open','Adj Close','High','Low','Volume'],axis = 1)
uso = uso.drop(['Open','Adj Close','High','Low','Volume'],axis = 1)
eurostoxx = eurostoxx.drop(['Open','Adj Close','High','Low','Volume'],axis = 1)
nikkei = nikkei.drop(['Open','Adj Close','High','Low','Volume'],axis = 1)
eurusd = eurusd.drop(['Open','High','Low','Change %'],axis = 1)
usdcad = usdcad.drop(['Open','High','Low','Change %'],axis = 1)
usdgbp = usdgbp.drop(['Open','High','Low','Change %'],axis = 1)
usdjpy = usdjpy.drop(['Open','High','Low','Change %'],axis = 1)
ftse = ftse.drop(['Open','High','Low','Change %','Vol.'],axis = 1)
print('DONNEES BRUTES TRAITEES')
# Out:
# DONNEES BRUTES TRAITEES

# %%
print('\nCONCATENATION EN UN DATASET BRUT => raw_dataset\n\n')
raw_dataset = pd.concat((vix,gld,slv,uso,eurostoxx,nikkei,eurusd,usdcad,usdgbp,usdjpy,ftse,spy),axis = 1)
raw_dataset.columns = (['VIX','GLD','SLV','USO','EURSTXX','NIKKEI','EURUSD','USDCAD','USDGBP','USDJPY','FTSE','SPY'])
raw_dataset.head()
raw_dataset.to_csv(path+'raw_data.csv')
# Out:
# CONCATENATION EN UN DATASET BRUT => raw_dataset

# %%
raw_dataset.head()
# Out:
#                   VIX         GLD    SLV    USO      EURSTXX        NIKKEI  \
# Date
# 2018-03-05  18.730000  125.180000  15.49  12.59  3355.320068  21042.089844
# 2018-03-06  18.360001  126.529999  15.78  12.57  3357.860107  21417.759766
# 2018-03-07  17.760000  125.720001  15.53  12.35  3377.360107  21252.720703
# 2018-03-08  16.540001  125.419998  15.55  12.15  3413.280029  21368.070312
# 2018-03-09  14.640000  125.540001  15.63  12.47  3420.540039  21469.199219
#
#             EURUSD  USDCAD  USDGBP  USDJPY   FTSE         SPY
# Date
# 2018-03-05  1.2336  1.2964  0.7220  106.20  593.7  272.190002
# 2018-03-06  1.2404  1.2876  0.7200  106.12  596.5  272.880005
# 2018-03-07  1.2413  1.2912  0.7194  106.08  597.3  272.779999
# 2018-03-08  1.2312  1.2896  0.7240  106.20  601.8  274.100006
# 2018-03-09  1.2307  1.2812  0.7221  106.80  603.8  278.869995

# %%
print('Le fichier contient',raw_dataset.isnull().sum().sum(),' valeurs NaN, réparties ainsi :\n')
print(raw_dataset.isnull().sum())
# Out:
# Le fichier contient 485  valeurs NaN, réparties ainsi :
#
# VIX        52
# GLD        52
# SLV        52
# USO        52
# EURSTXX    70
# NIKKEI     56
# EURUSD     42
# USDCAD      4
# USDGBP      1
# USDJPY      2
# FTSE       50
# SPY        52
# dtype: int64

# %%
print('\nRepérage et nettoyage des lignes incirminées\n')
# Out:
# Repérage et nettoyage des lignes incirminées

# %%
dataset = raw_dataset.dropna()
print('------------------------NETTOYAGE EFFECTUE---------------------')
print('-----------------VERIFICATION DES RESIDUS----------------------')
print('Le fichier contient',dataset.isnull().sum().sum(),' valeurs NaN')
# Out:
# ------------------------NETTOYAGE EFFECTUE---------------------
# -----------------VERIFICATION DES RESIDUS----------------------
# Le fichier contient 0  valeurs NaN

# %%
print('Il y a {} jours dans le dataset.'.format(dataset.shape[0]))
# Out:
# Il y a 215 jours dans le dataset.

# %%
# AJUSTEMENT DES PARAMETRES TEMPORELS
print('AJUSTEMENT DES PARAMETRES TEMPORELS')

delta = int(format(dataset.shape[0]))
bloc1 = round(delta*0.8)
bloc2 = delta - bloc1
print("Période d'étude : ",delta)
print('Sur un découpage 80% - 20% de la période : ')
print('Bloc 1 : ',bloc1,' jours \nBloc 2 :',bloc2,' jours')
print('Note : On change de règles de calculs, car tous les jours ne sont pas ouvrés')
# Out:
# AJUSTEMENT DES PARAMETRES TEMPORELS
# Période d'étude :  215
# Sur un découpage 80% - 20% de la période :
# Bloc 1 :  172  jours
# Bloc 2 : 43  jours
# Note : On change de règles de calculs, car tous les jours ne sont pas ouvrés

# %%
plt.figure(figsize=(16, 6), dpi=100,)
plt.plot(dataset['SPY'], label='Evolution du SPY')
axes = plt.gca()
axes.set_ylim([200,320])
plt.vlines(datetime.date(2018,12, 16), 0, 270, linestyles='--', colors='gray', label='Train/Test data cut-off')
plt.xlabel('Date')
plt.ylabel('SPY')
plt.title('Figure 1: Evolution du SPY')
plt.legend()
plt.show()

# %%
num_training_days = int(dataset.shape[0]*.8)
print('Number of training days: {}. Number of test days: {}.'.format(num_training_days, \
                                                                    dataset.shape[0]-num_training_days))
print('\n*******************PARAMETRES CORRIGES*****************')
# Out:
# Number of training days: 172. Number of test days: 43.
#
# *******************PARAMETRES CORRIGES*****************

# %%
def get_technical_indicators(dataset):
    # Create 7 and 21 days Moving Average
    dataset['ma7'] = dataset['SPY'].rolling(window=7).mean()
    dataset['ma21'] = dataset['SPY'].rolling(window=21).mean()
    temp = dataset['SPY'].to_frame()
    # Create MACD
    dataset['26ema'] = temp.ewm(span=26).mean()
    dataset['12ema'] = temp.ewm(span=12).mean()
    dataset['MACD'] = (dataset['12ema']-dataset['26ema'])

    # Create Bollinger Bands
    dataset['20sd'] = temp.rolling(window=20).std()
    dataset['upper_band'] = dataset['ma21'] + (dataset['20sd']*2)
    dataset['lower_band'] = dataset['ma21'] - (dataset['20sd']*2)
    
    # Create Exponential moving average
    dataset['ema'] = temp.ewm(com=0.5).mean()
    
    # Create Momentum
    dataset['momentum'] = dataset['SPY']-1
    
    return dataset

# %% [markdown]
# ## INITIATION DU PROGRAMME

# %%
print('INITIATION DU PROGRAMME')
# Out:
# INITIATION DU PROGRAMME

# %%
dataset_TI_df = get_technical_indicators(dataset[['SPY']])

# %%
dataset_TI_df.tail()
# Out:
#                    SPY         ma7        ma21       26ema       12ema  \
# Date
# 2019-02-25  279.519989  277.727147  270.981905  271.108560  275.201830
# 2019-02-26  279.320007  278.432861  271.760953  271.716816  275.835395
# 2019-02-27  279.200012  278.694292  272.367621  272.271126  276.353029
# 2019-02-28  278.679993  278.812862  273.094763  272.745857  276.711023
# 2019-03-01  280.420013  279.100006  273.898097  273.314313  277.281637
#
#                 MACD      20sd  upper_band  lower_band         ema    momentum
# Date
# 2019-02-25  4.093270  5.762441  282.506786  259.457023  279.225315  278.519989
# 2019-02-26  4.118580  5.900044  283.561040  259.960866  279.288443  278.320007
# 2019-02-27  4.081902  5.740734  283.849089  260.886152  279.229489  278.200012
# 2019-02-28  3.965166  5.444753  283.984268  262.205258  278.863158  277.679993
# 2019-03-01  3.967324  5.324841  284.547780  263.248415  279.901062  279.420013

# %%
def plot_technical_indicators(dataset, last_days):
    plt.figure(figsize=(16, 10), dpi=100)
    shape_0 = dataset.shape[0]
    xmacd_ = shape_0-last_days
    
    dataset = dataset.iloc[-last_days:, :]
    x_ = range(3, dataset.shape[0])
    x_ =list(dataset.index)
    
    # Plot first subplot
    plt.subplot(2, 1, 1)
    dataset['ma7'].plot(label='MA 7', color='g',linestyle='--')
    dataset['SPY'].plot(label='Prix de clôture', color='b')
    dataset['ma21'].plot(label='MA 21', color='r',linestyle='--')
    dataset['upper_band'].plot(label='Upper Band', color='c')
    dataset['lower_band'].plot(label='Lower Band', color='c')
    plt.fill_between(x_, dataset['lower_band'], dataset['upper_band'], alpha=0.35)
    plt.title('Indicateurs Techniques pour le SPY - deniers {} jours.'.format(last_days))
    plt.ylabel('SPY')
    plt.legend()

    # Plot second subplot
    plt.subplot(2, 1, 2)
    plt.title('MACD')
    dataset['MACD'].plot(label='MACD', linestyle='-.')
    plt.hlines(15, xmacd_, shape_0, colors='g', linestyles='--')
    plt.hlines(-15, xmacd_, shape_0, colors='g', linestyles='--')
    #dataset['momentum'].plot(label='Momentum', color='b',linestyle='-')

    plt.legend()
    plt.show()

# %%
plot_technical_indicators(dataset_TI_df, 400)

# %%
temp = dataset.rename_axis('Date').reset_index()
data_FT = temp[['Date', 'SPY']]

# %%
close_fft = np.fft.fft(np.asarray(data_FT['SPY'].tolist()))
fft_df = pd.DataFrame({'fft':close_fft})
fft_df['absolute'] = fft_df['fft'].apply(lambda x: np.abs(x))
fft_df['angle'] = fft_df['fft'].apply(lambda x: np.angle(x))

# %%
fft_df.head()
# Out:
#                                fft      absolute     angle
# 0                (59011.760025+0j)  59011.760025  0.000000
# 1  (-1022.81145868+11.9396841187j)   1022.881145  3.129920
# 2   (518.835205799-323.901645501j)    611.638984 -0.558086
# 3   (341.926803254+325.326372956j)    471.965240  0.760525
# 4   (299.199629972+75.9268548002j)    308.683180  0.248520

# %%
plt.figure(figsize=(14, 7), dpi=100)
fft_list = np.asarray(fft_df['fft'].tolist())
for num_ in [3, 6, 9, 100]:
    fft_list_m10= np.copy(fft_list); fft_list_m10[num_:-num_]=0
    plt.plot(np.fft.ifft(fft_list_m10), label='Transformation de Fourier comprenant {} composants'.format(num_))
data_FT['SPY'].plot(label='Real')
plt.xlabel('Days')
plt.ylabel('SPY')
plt.title('Figure 3: SPY (close) stock prices & Fourier transforms, et toc!')
plt.legend()
plt.show()

# %%
items = deque(np.asarray(fft_df['absolute'].tolist()))
items.rotate(int(np.floor(len(fft_df)/2)))
plt.figure(figsize=(10, 7), dpi=80)
plt.stem(items)
plt.title('Figure 4: Composants de la transformation de Fourier')
plt.show()

# %%
series = data_FT['SPY']
model = ARIMA(series, order=(5, 1, 0))
model_fit = model.fit(disp=0)
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                  D.SPY   No. Observations:                  214
# Model:                 ARIMA(5, 1, 0)   Log Likelihood                -514.138
# Method:                       css-mle   S.D. of innovations              2.673
# Date:                Thu, 04 Apr 2019   AIC                           1042.277
# Time:                        14:37:06   BIC                           1065.838
# Sample:                             1   HQIC                          1051.798
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const           0.0323      0.158      0.205      0.838      -0.277       0.342
# ar.L1.D.SPY    -0.0399      0.068     -0.588      0.557      -0.173       0.093
# ar.L2.D.SPY    -0.0173      0.067     -0.257      0.797      -0.149       0.114
# ar.L3.D.SPY     0.1437      0.066      2.170      0.031       0.014       0.274
# ar.L4.D.SPY    -0.1294      0.067     -1.924      0.056      -0.261       0.002
# ar.L5.D.SPY    -0.1171      0.068     -1.731      0.085      -0.250       0.015
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1707           -0.8461j            1.4444           -0.0996
# AR.2            1.1707           +0.8461j            1.4444            0.0996
# AR.3           -0.6672           -1.2217j            1.3920           -0.3296
# AR.4           -0.6672           +1.2217j            1.3920            0.3296
# AR.5           -2.1120           -0.0000j            2.1120           -0.5000
# -----------------------------------------------------------------------------
# """

# %%
autocorrelation_plot(series)
plt.figure(figsize=(16, 10), dpi=120)
plt.show()

# %%
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit(disp=0)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)

# %%
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# Out:
# Test MSE: 14.849

# %%
# Plot les predictions (selon ARIMA) et les vrais indices

plt.figure(figsize=(16, 6), dpi=100)
plt.plot(test, label='Real')
plt.plot(predictions, color='red', label='Predicted')
plt.xlabel('Days')
plt.ylabel('SPY')
plt.title('Figure 5: ARIMA model sur le SPY')
plt.legend()
plt.show()

# %%
data_FT.columns = (['Date','FT'])

# %%
data_FT.head()
# Out:
#         Date          FT
# 0 2018-03-05  272.190002
# 1 2018-03-06  272.880005
# 2 2018-03-07  272.779999
# 3 2018-03-08  274.100006
# 4 2018-03-09  278.869995

# %%
SYMBOLS = '[]' 

Rresults = []
for element in range(len(predictions)):
    Rresults.append(int(predictions[element]))

predictionss = pd.DataFrame({'predictions':Rresults})
#for col in predictionss.columns:
#    predictionss[col] = predictionss[col].apply(lambda i: ''.join(i))
predictionss.head()
# Out:
#    predictions
# 0          287
# 1          278
# 2          271
# 3          273
# 4          273

# %%
data_ARIMA = pd.DataFrame()
data_ARIMA['ARIMA'] = model_fit.fittedvalues
data_ARIMA.head()
# Out:
#       ARIMA
# 0  0.024290
# 1 -0.007526
# 2  0.005079
# 3  0.073637
# 4 -0.238280

# %%
dataset_total_df = pd.concat((dataset,dataset_TI_df.iloc[:,1:10],fft_df,data_FT.iloc[:,1:1],data_ARIMA,predictionss),axis=1)

print('Total dataset has {} samples, and {} features.'.format(dataset_total_df.shape[0], \
                                                              dataset_total_df.shape[1]))
dataset_total_df.tail()
# Out:
# Total dataset has 430 samples, and 26 features.
#               VIX         GLD    SLV    USO      EURSTXX        NIKKEI  \
# 2019-02-25  14.85  125.370003  14.90  11.57  3280.010010  21528.230469
# 2019-02-26  15.17  125.580002  14.94  11.63  3289.320068  21449.390625
# 2019-02-27  14.70  124.690002  14.75  11.89  3282.770020  21556.509766
# 2019-02-28  14.78  123.989998  14.63  11.95  3298.260010  21385.160156
# 2019-03-01  13.57  121.879997  14.20  11.66  3312.100098  21602.689453
#
#             EURUSD  USDCAD  USDGBP  USDJPY  ...      MACD      20sd  \
# 2019-02-25  1.1359  1.3191  0.7635  111.06  ...  4.093270  5.762441
# 2019-02-26  1.1387  1.3169  0.7547  110.58  ...  4.118580  5.900044
# 2019-02-27  1.1369  1.3156  0.7513  111.00  ...  4.081902  5.740734
# 2019-02-28  1.1371  1.3168  0.7540  111.39  ...  3.965166  5.444753
# 2019-03-01  1.1377  1.3296  0.7573  111.92  ...  3.967324  5.324841
#
#             upper_band  lower_band         ema  fft  absolute  angle  ARIMA  \
# 2019-02-25  282.506786  259.457023  279.225315  NaN       NaN    NaN    NaN
# 2019-02-26  283.561040  259.960866  279.288443  NaN       NaN    NaN    NaN
# 2019-02-27  283.849089  260.886152  279.229489  NaN       NaN    NaN    NaN
# 2019-02-28  283.984268  262.205258  278.863158  NaN       NaN    NaN    NaN
# 2019-03-01  284.547780  263.248415  279.901062  NaN       NaN    NaN    NaN
#
#             predictions
# 2019-02-25          NaN
# 2019-02-26          NaN
# 2019-02-27          NaN
# 2019-02-28          NaN
# 2019-03-01          NaN
#
# [5 rows x 26 columns]

# %%
def get_feature_importance_data(data_income):
    data = data_income.copy()
    y = data['SPY']
    X = data.iloc[:, 1:]
    
    train_samples = int(X.shape[0] * 0.65)
 
    X_train = X.iloc[:train_samples]
    X_test = X.iloc[train_samples:]

    y_train = y.iloc[:train_samples]
    y_test = y.iloc[train_samples:]
    
    return (X_train, y_train), (X_test, y_test)

# %%
# Séparation du training & test data
(X_train_FI, y_train_FI), (X_test_FI, y_test_FI) = get_feature_importance_data(dataset_TI_df)

# %%
regressor = xgb.XGBRegressor(gamma=0.0,n_estimators=150,base_score=0.7,colsample_bytree=1,learning_rate=0.05)

# %%
xgbModel = regressor.fit(X_train_FI,y_train_FI, \
                         eval_set = [(X_train_FI, y_train_FI), (X_test_FI, y_test_FI)], \
                         verbose=False)

# %%
eval_result = regressor.evals_result()

# %%
training_rounds = range(len(eval_result['validation_0']['rmse']))

# %%
plt.figure(figsize=(16, 6), dpi=100)
plt.scatter(x=training_rounds,y=eval_result['validation_0']['rmse'],label='Training Error')
plt.scatter(x=training_rounds,y=eval_result['validation_1']['rmse'],label='Validation Error')
plt.xlabel('Iterations')
plt.ylabel('RMSE')
plt.title('Training Vs Validation Error')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(16,6))
plt.xticks(rotation='vertical')
plt.bar([i for i in range(len(xgbModel.feature_importances_))], xgbModel.feature_importances_.tolist(), tick_label=X_test_FI.columns)
plt.title('Figure 6: Importance des technical indicators.')
plt.show()

# %%
def gelu(x):
    return 0.5 * x * (1 + math.tanh(math.sqrt(2 / math.pi) * (x + 0.044715 * math.pow(x, 3))))
def relu(x):
    return max(x, 0)
def lrelu(x):
    return max(0.01*x, x)

# %%
plt.figure(figsize=(16, 6))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=.5, hspace=None)

ranges_ = (-10, 3, .25)

plt.subplot(1, 2, 1)
plt.plot([i for i in np.arange(*ranges_)], [relu(i) for i in np.arange(*ranges_)], label='ReLU', marker='.')
plt.plot([i for i in np.arange(*ranges_)], [gelu(i) for i in np.arange(*ranges_)], label='GELU')
plt.hlines(0, -10, 3, colors='gray', linestyles='--', label='0')
plt.title("Figure 7: GELU en tant que fonction d'activation pour les autoencoders")
plt.ylabel('f(x) pour GELU & ReLU')
plt.xlabel('x')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot([i for i in np.arange(*ranges_)], [lrelu(i) for i in np.arange(*ranges_)], label='Leaky ReLU')
plt.hlines(0, -10, 3, colors='gray', linestyles='--', label='0')
plt.ylabel('f(x) pour Leaky ReLU')
plt.xlabel('x')
plt.title('Figure 8: LeakyReLU')
plt.legend()

plt.show()

# %%
VAE_data = dataset
batch_size = 8
n_batches = VAE_data.shape[0]/batch_size
VAE_data = VAE_data.values

train_iter = mx.io.NDArrayIter(data={'data': VAE_data[:num_training_days,:-1]}, \
                               label={'label': VAE_data[:num_training_days, -1]}, batch_size = batch_size)
test_iter = mx.io.NDArrayIter(data={'data': VAE_data[num_training_days:,:-1]}, \
                              label={'label': VAE_data[num_training_days:,-1]}, batch_size = batch_size)

# %%
model_ctx =  mx.cpu()
class VAE(gluon.HybridBlock):
    def __init__(self, n_hidden=400, n_latent=2, n_layers=1, n_output=784, \
                 batch_size=100, act_type='relu', **kwargs):
        self.soft_zero = 1e-10
        self.n_latent = n_latent
        self.batch_size = batch_size
        self.output = None
        self.mu = None
        super(VAE, self).__init__(**kwargs)
        
        with self.name_scope():
            self.encoder = nn.HybridSequential(prefix='encoder')
            
            for i in range(n_layers):
                self.encoder.add(nn.Dense(n_hidden, activation=act_type))
            self.encoder.add(nn.Dense(n_latent*2, activation=None))

            self.decoder = nn.HybridSequential(prefix='decoder')
            for i in range(n_layers):
                self.decoder.add(nn.Dense(n_hidden, activation=act_type))
            self.decoder.add(nn.Dense(n_output, activation='sigmoid'))

    def hybrid_forward(self, F, x):
        h = self.encoder(x)
        #print(h)
        mu_lv = F.split(h, axis=1, num_outputs=2)
        mu = mu_lv[0]
        lv = mu_lv[1]
        self.mu = mu

        eps = F.random_normal(loc=0, scale=1, shape=(self.batch_size, self.n_latent), ctx=model_ctx)
        z = mu + F.exp(0.5*lv)*eps
        y = self.decoder(z)
        self.output = y

        KL = 0.5*F.sum(1+lv-mu*mu-F.exp(lv),axis=1)
        logloss = F.sum(x*F.log(y+self.soft_zero)+ (1-x)*F.log(1-y+self.soft_zero), axis=1)
        loss = -logloss-KL

        return loss

# %%
n_hidden=400 # neurons in each layer
n_latent=2 
n_layers=3 # num of dense layers in encoder and decoder respectively
n_output=VAE_data.shape[1]-1 

net = VAE(n_hidden=n_hidden, n_latent=n_latent, n_layers=n_layers, n_output=n_output, batch_size=batch_size, act_type='gelu')

# %%
net.collect_params().initialize(mx.init.Xavier(), ctx=mx.cpu())
net.hybridize()
trainer = gluon.Trainer(net.collect_params(), 'adam', {'learning_rate': .01})

# %%
print(net)
# Out:
# VAE(
#   (encoder): HybridSequential(
#     (0): Dense(None -> 400, Activation(gelu))
#     (1): Dense(None -> 400, Activation(gelu))
#     (2): Dense(None -> 400, Activation(gelu))
#     (3): Dense(None -> 4, linear)
#   )
#   (decoder): HybridSequential(
#     (0): Dense(None -> 400, Activation(gelu))
#     (1): Dense(None -> 400, Activation(gelu))
#     (2): Dense(None -> 400, Activation(gelu))
#     (3): Dense(None -> 11, Activation(sigmoid))
#   )
# )

# %%
n_epoch = 150
print_period = n_epoch // 10
start = time.time()

training_loss = []
validation_loss = []
for epoch in range(n_epoch):
    epoch_loss = 0
    epoch_val_loss = 0

    train_iter.reset()
    test_iter.reset()

    n_batch_train = 0
    for batch in train_iter:
        n_batch_train +=1
        data = batch.data[0].as_in_context(mx.cpu())

        with autograd.record():
            loss = net(data)
        loss.backward()
        trainer.step(data.shape[0])
        epoch_loss += nd.mean(loss).asscalar()

    n_batch_val = 0
    for batch in test_iter:
        n_batch_val +=1
        data = batch.data[0].as_in_context(mx.cpu())
        loss = net(data)
        epoch_val_loss += nd.mean(loss).asscalar()

    epoch_loss /= n_batch_train
    epoch_val_loss /= n_batch_val

    training_loss.append(epoch_loss)
    validation_loss.append(epoch_val_loss)

    """if epoch % max(print_period, 1) == 0:
        print('Epoch {}, Training loss {:.2f}, Validation loss {:.2f}'.\
              format(epoch, epoch_loss, epoch_val_loss))"""

end = time.time()
print('Training completed in {} seconds.'.format(int(end-start)))
# Out:
# ---------------------------------------------------------------------------
# MXNetError                                Traceback (most recent call last)
# <ipython-input-104-e4800f3c9354> in <module>
#      18
#      19         with autograd.record():
# ---> 20             loss = net(data)
#      21         loss.backward()
#      22         trainer.step(data.shape[0])
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/gluon/block.py in __call__(self, *args)
#     358     def __call__(self, *args):
#     359         """Calls forward. Only accepts positional arguments."""
# --> 360         return self.forward(*args)
#     361
#     362     def forward(self, *args):
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/gluon/block.py in forward(self, x, *args)
#     565                 try:
#     566                     if self._active:
# --> 567                         return self._call_cached_op(x, *args)
#     568                     params = {i: j.data(ctx) for i, j in self._reg_params.items()}
#     569                 except DeferredInitializationError:
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/gluon/block.py in _call_cached_op(self, *args)
#     469     def _call_cached_op(self, *args):
#     470         if self._cached_op is None:
# --> 471             self._build_cache(*args)
#     472
#     473         args, fmt = _flatten(args)
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/gluon/block.py in _build_cache(self, *args)
#     434
#     435     def _build_cache(self, *args):
# --> 436         inputs, out = self._get_graph(*args)
#     437         input_idx = {var.name: i for i, var in enumerate(inputs)}
#     438         self._cached_op = ndarray.CachedOp(out, self._flags)
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/gluon/block.py in _get_graph(self, *args)
#     426             params = {i: j.var() for i, j in self._reg_params.items()}
#     427             with self.name_scope():
# --> 428                 out = self.hybrid_forward(symbol, *grouped_inputs, **params)  # pylint: disable=no-value-for-parameter
#     429             out, self._out_format = _flatten(out)
#     430
#
# <ipython-input-100-3f909dd1390a> in hybrid_forward(self, F, x)
#      23
#      24     def hybrid_forward(self, F, x):
# ---> 25         h = self.encoder(x)
#      26         #print(h)
#      27         mu_lv = F.split(h, axis=1, num_outputs=2)
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/gluon/block.py in __call__(self, *args)
#     358     def __call__(self, *args):
#     359         """Calls forward. Only accepts positional arguments."""
# --> 360         return self.forward(*args)
#     361
#     362     def forward(self, *args):
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/gluon/block.py in forward(self, x, *args)
#     580         params = {i: j.var() for i, j in self._reg_params.items()}
#     581         with self.name_scope():
# --> 582             return self.hybrid_forward(symbol, x, *args, **params)
#     583
#     584     def hybrid_forward(self, F, x, *args, **kwargs):
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/gluon/nn/basic_layers.py in hybrid_forward(self, F, x)
#     108     def hybrid_forward(self, F, x):
#     109         for block in self._children:
# --> 110             x = block(x)
#     111         return x
#     112
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/gluon/block.py in __call__(self, *args)
#     358     def __call__(self, *args):
#     359         """Calls forward. Only accepts positional arguments."""
# --> 360         return self.forward(*args)
#     361
#     362     def forward(self, *args):
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/gluon/block.py in forward(self, x, *args)
#     580         params = {i: j.var() for i, j in self._reg_params.items()}
#     581         with self.name_scope():
# --> 582             return self.hybrid_forward(symbol, x, *args, **params)
#     583
#     584     def hybrid_forward(self, F, x, *args, **kwargs):
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/gluon/nn/basic_layers.py in hybrid_forward(self, F, x, weight, bias)
#     206                                flatten=self._flatten, name='fwd')
#     207         if self.act is not None:
# --> 208             act = self.act(act)
#     209         return act
#     210
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/gluon/block.py in __call__(self, *args)
#     358     def __call__(self, *args):
#     359         """Calls forward. Only accepts positional arguments."""
# --> 360         return self.forward(*args)
#     361
#     362     def forward(self, *args):
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/gluon/block.py in forward(self, x, *args)
#     580         params = {i: j.var() for i, j in self._reg_params.items()}
#     581         with self.name_scope():
# --> 582             return self.hybrid_forward(symbol, x, *args, **params)
#     583
#     584     def hybrid_forward(self, F, x, *args, **kwargs):
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/gluon/nn/basic_layers.py in hybrid_forward(self, F, x)
#     241
#     242     def hybrid_forward(self, F, x):
# --> 243         return F.Activation(x, act_type=self._act_type, name='fwd')
#     244
#     245     def __repr__(self):
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/symbol/register.py in Activation(data, act_type, name, attr, out, **kwargs)
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/_ctypes/symbol.py in _symbol_creator(handle, args, kwargs, keys, vals, name)
#     123         c_str_array(keys),
#     124         c_str_array([str(v) for v in vals]),
# --> 125         ctypes.byref(sym_handle)))
#     126
#     127     if args and kwargs:
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/mxnet/base.py in check_call(ret)
#     144     """
#     145     if ret != 0:
# --> 146         raise MXNetError(py_str(_LIB.MXGetLastError()))
#     147
#     148
#
# MXNetError: Invalid Input: 'gelu', valid values are: {'relu', 'sigmoid', 'softrelu', 'tanh'}, in operator Activation(name="", act_type="gelu")

# %%
vae_added_df = pd.DataFrame( {'VAE':mx.nd.array(dataset_total_df.iloc[:, :-1].values)},index = dataset.index)
vae_added_df.head()

# %%
vvaaee = dataset_total_df.iloc[:, :-1].values

# %%
# We want the PCA to create the new components to explain 80% of the variance
pca = PCA(n_components=.8)

# %%
x_pca = StandardScaler().fit_transform(vvaaee)

# %%
principalComponents = pca.fit_transform(x_pca)

# %%
principalComponents.n_components_

# %%
gan_num_features = dataset_total_df.shape[1]
sequence_length = 17

class RNNModel(gluon.Block):
    def __init__(self, num_embed, num_hidden, num_layers, bidirectional=False, \
                 sequence_length=sequence_length, **kwargs):
        super(RNNModel, self).__init__(**kwargs)
        self.num_hidden = num_hidden
        with self.name_scope():
            self.rnn = rnn.LSTM(num_hidden, num_layers, input_size=num_embed, \
                                bidirectional=bidirectional, layout='TNC')
            
            self.decoder = nn.Dense(1, in_units=num_hidden)
    
    def forward(self, inputs, hidden):
        output, hidden = self.rnn(inputs, hidden)
        decoded = self.decoder(output.reshape((-1, self.num_hidden)))
        return decoded, hidden
    
    def begin_state(self, *args, **kwargs):
        return self.rnn.begin_state(*args, **kwargs)
    
lstm_model = RNNModel(num_embed=gan_num_features, num_hidden=500, num_layers=1)
lstm_model.collect_params().initialize(mx.init.Xavier(), ctx=mx.cpu())
trainer = gluon.Trainer(lstm_model.collect_params(), 'adam', {'learning_rate': .01})
loss = gluon.loss.L1Loss()

# %%
print(lstm_model)

# %%
class TriangularSchedule():
    def __init__(self, min_lr, max_lr, cycle_length, inc_fraction=0.5):     
        self.min_lr = min_lr
        self.max_lr = max_lr
        self.cycle_length = cycle_length
        self.inc_fraction = inc_fraction
        
    def __call__(self, iteration):
        if iteration <= self.cycle_length*self.inc_fraction:
            unit_cycle = iteration * 1 / (self.cycle_length * self.inc_fraction)
        elif iteration <= self.cycle_length:
            unit_cycle = (self.cycle_length - iteration) * 1 / (self.cycle_length * (1 - self.inc_fraction))
        else:
            unit_cycle = 0
        adjusted_cycle = (unit_cycle * (self.max_lr - self.min_lr)) + self.min_lr
        return adjusted_cycle

class CyclicalSchedule():
    def __init__(self, schedule_class, cycle_length, cycle_length_decay=1, cycle_magnitude_decay=1, **kwargs):
        self.schedule_class = schedule_class
        self.length = cycle_length
        self.length_decay = cycle_length_decay
        self.magnitude_decay = cycle_magnitude_decay
        self.kwargs = kwargs
    
    def __call__(self, iteration):
        cycle_idx = 0
        cycle_length = self.length
        idx = self.length
        while idx <= iteration:
            cycle_length = math.ceil(cycle_length * self.length_decay)
            cycle_idx += 1
            idx += cycle_length
        cycle_offset = iteration - idx + cycle_length
        
        schedule = self.schedule_class(cycle_length=cycle_length, **self.kwargs)
        return schedule(cycle_offset) * self.magnitude_decay**cycle_idx

# %%
schedule = CyclicalSchedule(TriangularSchedule, min_lr=0.5, max_lr=2, cycle_length=500)
iterations=1500

plt.plot([i+1 for i in range(iterations)],[schedule(i) for i in range(iterations)])
plt.title('Learning rate for each epoch')
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.show()

# %%
num_fc = 512

# ... other parts of the GAN

cnn_net = gluon.nn.Sequential()
with net.name_scope():
    
    # Add the 1D Convolutional layers
    cnn_net.add(gluon.nn.Conv1D(32, kernel_size=5, strides=2))
    cnn_net.add(nn.LeakyReLU(0.01))
    cnn_net.add(gluon.nn.Conv1D(64, kernel_size=5, strides=2))
    cnn_net.add(nn.LeakyReLU(0.01))
    cnn_net.add(nn.BatchNorm())
    cnn_net.add(gluon.nn.Conv1D(128, kernel_size=5, strides=2))
    cnn_net.add(nn.LeakyReLU(0.01))
    cnn_net.add(nn.BatchNorm())
    
    # Add the two Fully Connected layers
    cnn_net.add(nn.Dense(220, use_bias=False), nn.BatchNorm(), nn.LeakyReLU(0.01))
    cnn_net.add(nn.Dense(220, use_bias=False), nn.Activation(activation='relu'))
    cnn_net.add(nn.Dense(1))
    
# ... other parts of the GAN

# %%
print(cnn_net)

# %%
# Initialize the optimizer
from bayes_opt import BayesianOptimization
from bayes_opt import UtilityFunction

utility = UtilityFunction(kind="ucb", kappa=2.5, xi=0.0)

# %%
from python_utils import plot_prediction

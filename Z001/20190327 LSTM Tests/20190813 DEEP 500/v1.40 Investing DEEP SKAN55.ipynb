# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
print('Importing Librairies...')
import talib
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import xgboost as xgb
from xgboost import XGBRegressor, plot_importance
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')
import time
import datetime as dt
import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
print('Librairies imported')
print('')

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print('BOOST SKAN 55 Version v1.40',Style.RESET_ALL)



print('')
print('Sraping tickers')
constituents = pd.read_csv('constituents_csv.csv')
print('Scrap -----> ok')
# PARAMETRES TEMPORELS INITIAUX
start =str(dt.date.today()-dt.timedelta(1110))
end = str(dt.date.today())

error = []



try :
    amorce = pd.read_csv('compteur.csv').index[-1] + 1
except:
    amorce = 0
    compteur = pd.DataFrame(columns = ['Symb.','Name','Sector'])
    compteur.to_csv('compteur.csv')
    
    
# SCRAPING DES DONNES BRUTES
def scrap_data(ticker,start,end):
    df = web.DataReader(ticker,'yahoo',start,end)
    df = df.drop(['Close'],axis=1)
    df['Close'] = df['Adj Close']
    df = df.drop(['Adj Close'],axis = 1)    
    return(df)

def prepa_data(df):
    tmps1=time.time()
    print('Preparing data...')
    rsi = talib.RSI(df['Close'],timeperiod=14)
    stoc_slowk, stoc_slowd = talib.STOCH(df['High'],df['Low'],df['Close'])
    upper, middle, lower =  talib.BBANDS(df['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(df['Close'],timeperiod=5)
    sma8 = talib.SMA(df['Close'],timeperiod=8)
    sma10 = talib.SMA(df['Close'],timeperiod=10)
    sma12 = talib.SMA(df['Close'],timeperiod=12)
    sma15 = talib.SMA(df['Close'],timeperiod=15)
    sma30 = talib.SMA(df['Close'],timeperiod=30)
    sma35 = talib.SMA(df['Close'],timeperiod=35)
    sma40 = talib.SMA(df['Close'],timeperiod=40)
    sma45 = talib.SMA(df['Close'],timeperiod=45)
    sma50 = talib.SMA(df['Close'],timeperiod=50)
    atr = talib.ATR(df['High'],df['Low'],df['Close'],timeperiod=10)
    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50
    bbdelta = upper - middle
    price_bolup = df['Close'] - lower
    price_bolow = df['Close'] - upper
    Ema = talib.EMA(df['Close'],timeperiod=20)
    KC_High = Ema + 2*atr
    KC_Low = Ema - 2*atr
    aroondown, aroonup = talib.AROON(df['High'], df['Low'], timeperiod=9)
    aroon = aroonup - aroondown 
    rsi30_list = []
    rsi70_list = []
    for i in range(0,df.shape[0]):
        rsi70_list.append(70 - rsi[i])
        rsi30_list.append(rsi[i] - 30)
        
    varop_spy = df['Open'] - df['Close']
    varhl_spy = df['High'] - df['Low']
    df['Varop_Spy'] = varop_spy
    df['Varhl_spy'] = varhl_spy
    df['RSI'] = rsi
    df['70 - RSI'] = np.array(rsi70_list)
    df['RSI - 30'] = np.array(rsi30_list)
    df['BBD_Delta_Up'] = bbdelta
    df['delta5_8'] = delta5_8
    df['delta8_10'] = delta8_10
    df['delta10_12'] = delta10_12
    df['delta12_15'] = delta12_15
    df['delta15_30'] = delta15_30
    df['delta30_35'] = delta30_35
    df['delta35_40'] = delta35_40
    df['delta40_45'] = delta40_45
    df['delta45_50'] = delta45_50
    df['Stoc_Slowk'] = stoc_slowk
    df['Stoc_Slowd'] = stoc_slowd
    df['KC_High'] = KC_High
    df['KC_Low'] = KC_Low
    df['upper'] = upper
    df['lower'] = lower
    df['var_bollup_kchigh'] = upper-KC_High
    df['var_bolllow_kclow'] = lower-KC_Low
    df['Aroon Up'] = aroonup
    df['Aroon Down'] = aroondown
    df['Delta Aroon'] = aroon
    up = []
    down = []
    df = df.dropna()
    df = boost(df)
    df['%Futur'] = ((df['Close.S']-df['Close']) *100) / (df['Close'])
    df['%Futur2'] = ((df['Close.S2']-df['Close']) *100) / (df['Close'])
    for i in range(0,df.shape[0]-5):
        if df.iloc[i]['%Futur'] > 0.1 :
            up.append(1)
            down.append(0)
        elif df.iloc[i]['%Futur'] < -0.1:
            up.append(0)
            down.append(1)
        else:
            up.append(0)
            down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    
    
    df['target_up'] = up  
    df['target_down'] = down 
    #df = df.dropna()
    tmps2=round(time.time()-tmps1,2)
    print ("Data prepared in = %f" %tmps2,'seconds')
    return(df)

def boost(df):
    print('Boosting')
    X = df.copy()
    X = X.drop(['Close'],axis=1)
    X['Close'] = df['Close']
    y = X.iloc[:,-1]
    Xtrain = X.iloc[:-2,:-1]
    Xtest = X.iloc[-2:-1,:-1]
    yshift = y.shift(-1)
    ytrain = yshift.iloc[:-2]
    ytest = yshift.iloc[-2:-1]

    model = xgb.XGBRegressor(n_estimators=20000, learning_rate=1, gamma=1, subsample=1, colsample_bytree=1, max_depth=100)

    model.fit( Xtrain, ytrain, early_stopping_rounds=150, eval_set=[(Xtest, ytest)], verbose=0)

    ytrain_pred = model.predict(Xtrain)

    y_pred = model.predict(Xtest)

    pred = model.predict(X.iloc[:,:-1])

    df['Close.S'] = pred
    df['Close.S2'] = df['Close.S']
    df = df.dropna()
    print('Boost ok')
    return(df)

    
def deep_learning(df):
    tmps1=time.time()
    X = df.iloc[:,1:-4]
    y_up = df.iloc[:,-2].values
    y_down = df.iloc[:,-1].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:bloc1,:]
    Xtest = X[bloc1:,:]
    ytrain_up = y_up[:bloc1,:]
    ytest_up = y_up[bloc1:,:]
    ytrain_down = y_down[:bloc1,:]
    ytest_down = y_down[bloc1:,:]

    seed = 770
    np.random.seed(seed)

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    model_up = Sequential()
    # Add an input layer 
    model_up.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_up.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_up.add(Dense(1, activation='sigmoid'))

    model_down = Sequential()
    # Add an input layer 
    model_down.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_down.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_down.add(Dense(1, activation='sigmoid'))

    print('Processing move_up')
    model_up.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])
    
              

    history_up = model_up.fit(Xtrain, ytrain_up,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Processing move_down')
    model_down.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])

    history_down = model_down.fit(Xtrain, ytrain_down,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Computing done')
    print('\n')

    train_acc_up = model_up.evaluate(Xtrain, ytrain_up,verbose=1)
    train_acc_down = model_down.evaluate(Xtrain, ytrain_down,verbose=1)

    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    score_up = model_up.evaluate(Xtest, ytest_up,verbose=1)
    score_down = model_down.evaluate(Xtest, ytest_down,verbose=1)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)

    accuracy_up = accuracy_score(ytest_up, yhat_up)
    accuracy_down = accuracy_score(ytest_down, yhat_down)

    # La précision permet de mesurer la capacité du modèle à refuser résultats non-pertinents : vrais_positifs/(vrais_positifs+faux_positifs)
    precision_up = precision_score(ytest_up, yhat_up)  
    precision_down = precision_score(ytest_down, yhat_down) 


    # Recall : (vrai_positifs/(vrais_positifs+faux_négatifs))
    recall_up = recall_score(ytest_up, yhat_up) 
    recall_down = recall_score(ytest_down, yhat_down) 


    
    print('\n')
    print(Fore.GREEN,'RESULTATS UP\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_up * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_up *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_up * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    

    print(classification_report(ytest_up, yhat_up))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_up, yhat_up))

    print('\n')
    print('_______________________________________________________________________________________________________________________________________________________________\n')
    print(Fore.RED,'RESULTATS DOWN\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_down * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_down *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_down * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    

    print(classification_report(ytest_down, yhat_down))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_down, yhat_down))
    print('\n')

    resultats = pd.DataFrame()
    resultats['Date'] = df.index[bloc1:]
    resultats.index= df.index[bloc1:]
    resultats['Move Up'] = yhat_up
    resultats['Confiance up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confiance Down'] = (predict_down)*100
    resultats['Actual'] = df.iloc[bloc1:]['Close']
    resultats['Actual.S'] = df.iloc[bloc1:]['Close.S']
    open_S = df['Open'].shift(-1)
    resultats['Open.S'] = open_S.iloc[bloc1:]
    dmp_cp=[]
    dmp_cp = ((resultats['Confiance up']-resultats['Confiance Down'])/(resultats['Confiance up']+resultats['Confiance Down'])*100)
    resultats['DMP_CP'] = dmp_cp
    tmps2=round(time.time()-tmps1,2)
    print (Fore.MAGENTA,"Deep Learning executed in = %f" %tmps2,'seconds',Style.RESET_ALL)
    
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)



def grobeta(df,dfb):
    # create a time-series of monthly data points
    rts = df.resample('M').last()
    rbts = dfb.resample('M').last()
    dfsm = pd.DataFrame({'s_adjclose' : rts['Close'],
                            'b_adjclose' : rbts['Adj Close']},
                            index=rts.index)

    # compute returns
    dfsm[['s_returns','b_returns']] = dfsm[['s_adjclose','b_adjclose']]/\
        dfsm[['s_adjclose','b_adjclose']].shift(1) -1
    dfsm = dfsm.dropna()
    covmat = np.cov(dfsm["s_returns"],dfsm["b_returns"])

    # calculate measures now
    beta = covmat[0,1]/covmat[1,1]
    alpha= np.mean(dfsm["s_returns"])-beta*np.mean(dfsm["b_returns"])

    # r_squared     = 1. - SS_res/SS_tot
    ypred = alpha + beta * dfsm["b_returns"]
    SS_res = np.sum(np.power(ypred-dfsm["s_returns"],2))
    SS_tot = covmat[0,0]*(len(dfsm)-1) # SS_tot is sample_variance*(n-1)
    r_squared = 1. - SS_res/SS_tot
    # 5- year volatiity and 1-year momentum
    volatility = np.sqrt(covmat[0,0])
    momentum = np.prod(1+dfsm["s_returns"].tail(12).values) -1

    # annualize the numbers
    prd = 12. # used monthly returns; 12 periods to annualize
    alpha = alpha*prd
    volatility = volatility*np.sqrt(prd)

    print ('Beta : ',beta,'\n Alpha : ',alpha,'\n R_Squared : ', r_squared, '\n Volatility : ', volatility, '\n Momentum : ',momentum)
    return(beta,alpha,r_squared,volatility,momentum)


def save_model(model_up,model_down):
    savename = 'Save_'+ticker
    # serialize model to YAML
    model_up_yaml = model_up.to_yaml()
    model_down_yaml = model_down.to_yaml()
    with open(savename+"_up.yaml", "w") as yaml_file:
        yaml_file.write(model_up_yaml)
        print("Yaml Model ",savename,"_up.yaml saved to disk")
    with open(savename+"_down.yaml", "w") as yaml_file:
        yaml_file.write(model_up_yaml)
        print("Yaml Model ",savename,"_down.yaml saved to disk")
    # serialize weights to HDF5
    model_up.save_weights(savename+"_up.h5")
    print("Weights ",savename,"_up.h5 saved to disk")
    model_down.save_weights(savename+"_down.h5")
    print("Weights ",savename,"_down.h5 saved to disk")
    
########################
#### MAIN SKAN55 #######
########################
compteur = pd.read_csv('compteur.csv')
ticker_list = compteur['Symb.'].tolist()
name_list = compteur['Name'].tolist()
sector_list = compteur['Sector'].tolist()

#for loop in range(amorce,amorce+10):

for loop in range(amorce,len(constituents)):
    print('Loop :',loop)
    print('amorce : ',amorce)
    
    try:

        ticker = (constituents.iloc[loop]['Symbol'])
        name = constituents.iloc[loop]['Name']
        sector = constituents.iloc[loop]['Sector']
        ticker_list.append(ticker)
        name_list.append(name)
        sector_list.append(sector)

        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        global delta,bloc1,bloc2
        tmps1=time.time()
        print('Scraping data...')

        df = scrap_data(ticker,start,end)

        dfb = web.DataReader('^GSPC','yahoo',start,end)

        beta,alpha, r_squared, volatility, momentum = grobeta(df,dfb)

        tmps2=round(time.time()-tmps1,2)
        print ("executed in = %f" %tmps2,'seconds')

        print('\n')
        print('GOLEM begins Computing...')
        print('\n')
        delta = round(df.shape[0])
        bloc1 = round(delta*0.80)
        bloc2 = delta - bloc1
        print("# of periods : ",delta)
        print('On 80% - 20% slash : ')
        print('Bloc 1 : ',bloc1,'\nBloc 2 :',bloc2,' periods ')
        print('First period :',df.index[0])
        print('Split period :',df.index[bloc1-1])
        print('Last period :',df.index[df.shape[0]-1])
        print('\n')

        print('Data prep')
        df = prepa_data(df)

        print(Fore.BLUE,'Deeping in blue',Style.RESET_ALL)
        print('')
        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        resultats,precision_up,precision_down,model_up,model_down,scaler = deep_learning(df)

        
        if (precision_up*100) < 65 or (precision_down*100) < 65:
            print(Fore.BLACK,Back.YELLOW,'Invalid precision test ==> Doing it again #1',Style.RESET_ALL)
            resultats,precision_up,precision_down,model_up,model_down,scaler = deep_learning(df)
            
        if (precision_up*100) < 65 or (precision_down*100) < 65:
            print(Fore.BLACK,Back.YELLOW,'Invalid precision test ==> Doing it again #2',Style.RESET_ALL)
            resultats,precision_up,precision_down,model_up,model_down,scaler = deep_learning(df)
            
        if (precision_up*100) < 65 or (precision_down*100) < 65:
            print(Fore.BLACK,Back.YELLOW,'Invalid precision test ==> Last test (#3)',Style.RESET_ALL)
            resultats,precision_up,precision_down,model_up,model_down,scaler = deep_learning(df)
            
        save_model(model_up, model_down)

        print('Le ',Fore.BLUE,'Deep Learning',Style.RESET_ALL ,'de ',Fore.YELLOW,ticker,Style.RESET_ALL,' a été effecué avec succès. Les modèles ont été sauvegardés')

    except:
        print(Fore.RED,'Problème loop : ',loop,Style.RESET_ALL)
        error.append((loop,ticker))
         
        continue

print(Fore.YELLOW,Back.BLUE,'Longueur des listes pour vérification : ',len(ticker_list),len(name_list),len(sector_list),Style.RESET_ALL)

compteur = pd.DataFrame(columns = ['Symb.','Name','Sector'])

compteur['Symb.'] = ticker_list

compteur['Name'] = name_list

compteur['Sector'] = sector_list

compteur.to_csv('compteur.csv')

print(Fore.YELLOW,Back.MAGENTA,Style.DIM,'PASSAGE FINI!!!!!!',Style.RESET_ALL)
# Out:
# Importing Librairies...
# Using TensorFlow backend.
# Librairies imported
#
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
# BOOST SKAN 55 Version v1.40
#
# Sraping tickers
# Scrap -----> ok
# Loop : 480
# amorce :  480
#  --- Loop : 480  ---  --- Symbol :   WMT   ---  --- Name :  Wal-Mart Stores  ---  --- Sector :  Consumer Staples  ---
# Scraping data...
# Beta :  0.6316725963506614
#  Alpha :  0.12775910900331294
#  R_Squared :  0.1836922455064528
#  Volatility :  0.18424894847487908
#  Momentum :  0.18567535987244987
# executed in = 5.300000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  766
# On 80% - 20% slash :
# Bloc 1 :  613
# Bloc 2 : 153  periods
# First period : 2016-08-01 00:00:00
# Split period : 2019-01-07 00:00:00
# Last period : 2019-08-15 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [20:28:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.140000 seconds
#  Deeping in blue
#
#  --- Loop : 480  ---  --- Symbol :   WMT   ---  --- Name :  Wal-Mart Stores  ---  --- Sector :  Consumer Staples  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 0s 95us/step
# 613/613 [==============================] - 0s 95us/step
# 104/104 [==============================] - 0s 25us/step
# 104/104 [==============================] - 0s 31us/step
#
#
#  RESULTATS UP
#
# Accuracy: 67.31%
#  Precision: 79.17%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 39.58%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.64      0.91      0.75        56
#            1       0.79      0.40      0.53        48
#
#    micro avg       0.67      0.67      0.67       104
#    macro avg       0.71      0.65      0.64       104
# weighted avg       0.71      0.67      0.65       104
#
# [[51  5]
#  [29 19]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 64.42%
#  Precision: 50.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 97.30%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.97      0.46      0.63        67
#            1       0.50      0.97      0.66        37
#
#    micro avg       0.64      0.64      0.64       104
#    macro avg       0.73      0.72      0.64       104
# weighted avg       0.80      0.64      0.64       104
#
# [[31 36]
#  [ 1 36]]
#
#
#  Deep Learning executed in = 36.270000 seconds
#   Invalid precision test ==> Doing it again #1
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 0s 144us/step
# 613/613 [==============================] - 0s 152us/step
# 104/104 [==============================] - 0s 27us/step
# 104/104 [==============================] - 0s 33us/step
#
#
#  RESULTATS UP
#
# Accuracy: 71.15%
#  Precision: 87.50%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 43.75%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.66      0.95      0.78        56
#            1       0.88      0.44      0.58        48
#
#    micro avg       0.71      0.71      0.71       104
#    macro avg       0.77      0.69      0.68       104
# weighted avg       0.76      0.71      0.69       104
#
# [[53  3]
#  [27 21]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 65.38%
#  Precision: 50.70%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 97.30%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.97      0.48      0.64        67
#            1       0.51      0.97      0.67        37
#
#    micro avg       0.65      0.65      0.65       104
#    macro avg       0.74      0.73      0.65       104
# weighted avg       0.81      0.65      0.65       104
#
# [[32 35]
#  [ 1 36]]
#
#
#  Deep Learning executed in = 38.530000 seconds
#   Invalid precision test ==> Doing it again #2
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 0s 202us/step
# 613/613 [==============================] - 0s 208us/step
# 104/104 [==============================] - 0s 27us/step
# 104/104 [==============================] - 0s 27us/step
#
#
#  RESULTATS UP
#
# Accuracy: 73.08%
#  Precision: 85.71%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 50.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.68      0.93      0.79        56
#            1       0.86      0.50      0.63        48
#
#    micro avg       0.73      0.73      0.73       104
#    macro avg       0.77      0.71      0.71       104
# weighted avg       0.76      0.73      0.72       104
#
# [[52  4]
#  [24 24]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 74.04%
#  Precision: 58.06%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 97.30%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.98      0.61      0.75        67
#            1       0.58      0.97      0.73        37
#
#    micro avg       0.74      0.74      0.74       104
#    macro avg       0.78      0.79      0.74       104
# weighted avg       0.84      0.74      0.74       104
#
# [[41 26]
#  [ 1 36]]
#
#
#  Deep Learning executed in = 41.040000 seconds
#   Invalid precision test ==> Last test (#3)
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 0s 250us/step
# 613/613 [==============================] - 0s 262us/step
# 104/104 [==============================] - 0s 29us/step
# 104/104 [==============================] - 0s 34us/step
#
#
#  RESULTATS UP
#
# Accuracy: 75.96%
#  Precision: 82.86%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 60.42%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.72      0.89      0.80        56
#            1       0.83      0.60      0.70        48
#
#    micro avg       0.76      0.76      0.76       104
#    macro avg       0.78      0.75      0.75       104
# weighted avg       0.77      0.76      0.75       104
#
# [[50  6]
#  [19 29]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 77.88%
#  Precision: 62.50%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 94.59%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.96      0.69      0.80        67
#            1       0.62      0.95      0.75        37
#
#    micro avg       0.78      0.78      0.78       104
#    macro avg       0.79      0.82      0.78       104
# weighted avg       0.84      0.78      0.78       104
#
# [[46 21]
#  [ 2 35]]
#
#
#  Deep Learning executed in = 41.640000 seconds
# Yaml Model  Save_WMT _up.yaml saved to disk
# Yaml Model  Save_WMT _down.yaml saved to disk
# Weights  Save_WMT _up.h5 saved to disk
# Weights  Save_WMT _down.h5 saved to disk
# Le   Deep Learning  de   WMT   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 481
# amorce :  480
#  --- Loop : 481  ---  --- Symbol :   WBA   ---  --- Name :  Walgreens Boots Alliance  ---  --- Sector :  Consumer Staples  ---
# Scraping data...
# Beta :  0.8630558381622566
#  Alpha :  -0.1932190204734154
#  R_Squared :  0.17292549487781506
#  Volatility :  0.25961117510124043
#  Momentum :  -0.26699255057625637
# executed in = 1.780000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  766
# On 80% - 20% slash :
# Bloc 1 :  613
# Bloc 2 : 153  periods
# First period : 2016-08-01 00:00:00
# Split period : 2019-01-07 00:00:00
# Last period : 2019-08-15 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [20:31:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.050000 seconds
#  Deeping in blue
#
#  --- Loop : 481  ---  --- Symbol :   WBA   ---  --- Name :  Walgreens Boots Alliance  ---  --- Sector :  Consumer Staples  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 0s 308us/step
# 613/613 [==============================] - 0s 309us/step
# 104/104 [==============================] - 0s 29us/step
# 104/104 [==============================] - 0s 28us/step
#
#
#  RESULTATS UP
#
# Accuracy: 82.69%
#  Precision: 78.26%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 58.06%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.84      0.93      0.88        73
#            1       0.78      0.58      0.67        31
#
#    micro avg       0.83      0.83      0.83       104
#    macro avg       0.81      0.76      0.77       104
# weighted avg       0.82      0.83      0.82       104
#
# [[68  5]
#  [13 18]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 62.50%
#  Precision: 85.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 32.08%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.57      0.94      0.71        51
#            1       0.85      0.32      0.47        53
#
#    micro avg       0.62      0.62      0.62       104
#    macro avg       0.71      0.63      0.59       104
# weighted avg       0.71      0.62      0.59       104
#
# [[48  3]
#  [36 17]]
#
#
#  Deep Learning executed in = 44.310000 seconds
# Yaml Model  Save_WBA _up.yaml saved to disk
# Yaml Model  Save_WBA _down.yaml saved to disk
# Weights  Save_WBA _up.h5 saved to disk
# Weights  Save_WBA _down.h5 saved to disk
# Le   Deep Learning  de   WBA   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 482
# amorce :  480
#  --- Loop : 482  ---  --- Symbol :   WM   ---  --- Name :  Waste Management Inc.  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  0.5775141632380093
#  Alpha :  0.17803370863431667
#  R_Squared :  0.4067907027139053
#  Volatility :  0.11326516606154292
#  Momentum :  0.3246514850037405
# executed in = 3.180000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  766
# On 80% - 20% slash :
# Bloc 1 :  613
# Bloc 2 : 153  periods
# First period : 2016-08-01 00:00:00
# Split period : 2019-01-07 00:00:00
# Last period : 2019-08-15 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [20:32:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.160000 seconds
#  Deeping in blue
#
#  --- Loop : 482  ---  --- Symbol :   WM   ---  --- Name :  Waste Management Inc.  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 0s 368us/step
# 613/613 [==============================] - 0s 365us/step
# 104/104 [==============================] - 0s 30us/step
# 104/104 [==============================] - 0s 35us/step
#
#
#  RESULTATS UP
#
# Accuracy: 71.15%
#  Precision: 61.43%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 93.48%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.91      0.53      0.67        58
#            1       0.61      0.93      0.74        46
#
#    micro avg       0.71      0.71      0.71       104
#    macro avg       0.76      0.73      0.71       104
# weighted avg       0.78      0.71      0.70       104
#
# [[31 27]
#  [ 3 43]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 66.35%
#  Precision: 69.57%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 36.36%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.65      0.88      0.75        60
#            1       0.70      0.36      0.48        44
#
#    micro avg       0.66      0.66      0.66       104
#    macro avg       0.67      0.62      0.61       104
# weighted avg       0.67      0.66      0.64       104
#
# [[53  7]
#  [28 16]]
#
#
#  Deep Learning executed in = 46.670000 seconds
#   Invalid precision test ==> Doing it again #1
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 0s 436us/step
# 613/613 [==============================] - 0s 436us/step
# 104/104 [==============================] - 0s 34us/step
# 104/104 [==============================] - 0s 37us/step
#
#
#  RESULTATS UP
#
# Accuracy: 73.08%
#  Precision: 65.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 84.78%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.84      0.64      0.73        58
#            1       0.65      0.85      0.74        46
#
#    micro avg       0.73      0.73      0.73       104
#    macro avg       0.75      0.74      0.73       104
# weighted avg       0.76      0.73      0.73       104
#
# [[37 21]
#  [ 7 39]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 75.00%
#  Precision: 76.47%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 59.09%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.74      0.87      0.80        60
#            1       0.76      0.59      0.67        44
#
#    micro avg       0.75      0.75      0.75       104
#    macro avg       0.75      0.73      0.73       104
# weighted avg       0.75      0.75      0.74       104
#
# [[52  8]
#  [18 26]]
#
#
#  Deep Learning executed in = 45.140000 seconds
# Yaml Model  Save_WM _up.yaml saved to disk
# Yaml Model  Save_WM _down.yaml saved to disk
# Weights  Save_WM _up.h5 saved to disk
# Weights  Save_WM _down.h5 saved to disk
# Le   Deep Learning  de   WM   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 483
# amorce :  480
#  --- Loop : 483  ---  --- Symbol :   WAT   ---  --- Name :  Waters Corporation  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.0072482366034312
#  Alpha :  0.012984578918049786
#  R_Squared :  0.2743297050711988
#  Volatility :  0.24065828707035367
#  Momentum :  0.06628666794279559
# executed in = 1.880000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  766
# On 80% - 20% slash :
# Bloc 1 :  613
# Bloc 2 : 153  periods
# First period : 2016-08-01 00:00:00
# Split period : 2019-01-07 00:00:00
# Last period : 2019-08-15 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [20:34:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.370000 seconds
#  Deeping in blue
#
#  --- Loop : 483  ---  --- Symbol :   WAT   ---  --- Name :  Waters Corporation  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 0s 510us/step
# 613/613 [==============================] - 0s 503us/step
# 104/104 [==============================] - 0s 37us/step
# 104/104 [==============================] - 0s 43us/step
#
#
#  RESULTATS UP
#
# Accuracy: 78.85%
#  Precision: 66.67%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 70.59%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84        70
#            1       0.67      0.71      0.69        34
#
#    micro avg       0.79      0.79      0.79       104
#    macro avg       0.76      0.77      0.76       104
# weighted avg       0.79      0.79      0.79       104
#
# [[58 12]
#  [10 24]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 69.23%
#  Precision: 96.43%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 46.55%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.59      0.98      0.74        46
#            1       0.96      0.47      0.63        58
#
#    micro avg       0.69      0.69      0.69       104
#    macro avg       0.78      0.72      0.68       104
# weighted avg       0.80      0.69      0.68       104
#
# [[45  1]
#  [31 27]]
#
#
#  Deep Learning executed in = 50.010000 seconds
# Yaml Model  Save_WAT _up.yaml saved to disk
# Yaml Model  Save_WAT _down.yaml saved to disk
# Weights  Save_WAT _up.h5 saved to disk
# Weights  Save_WAT _down.h5 saved to disk
# Le   Deep Learning  de   WAT   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 484
# amorce :  480
#  --- Loop : 484  ---  --- Symbol :   WEC   ---  --- Name :  Wec Energy Group Inc  ---  --- Sector :  Utilities  ---
# Scraping data...
# Beta :  0.15112699869300333
#  Alpha :  0.1662467928194656
#  R_Squared :  0.023870252312931384
#  Volatility :  0.12233834018168353
#  Momentum :  0.37673222433602693
# executed in = 1.880000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  766
# On 80% - 20% slash :
# Bloc 1 :  613
# Bloc 2 : 153  periods
# First period : 2016-08-01 00:00:00
# Split period : 2019-01-07 00:00:00
# Last period : 2019-08-15 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [20:34:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.110000 seconds
#  Deeping in blue
#
#  --- Loop : 484  ---  --- Symbol :   WEC   ---  --- Name :  Wec Energy Group Inc  ---  --- Sector :  Utilities  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 0s 544us/step
# 613/613 [==============================] - 0s 557us/step
# 104/104 [==============================] - 0s 36us/step
# 104/104 [==============================] - 0s 41us/step
#
#
#  RESULTATS UP
#
# Accuracy: 83.65%
#  Precision: 88.46%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.70%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83        47
#            1       0.88      0.81      0.84        57
#
#    micro avg       0.84      0.84      0.84       104
#    macro avg       0.84      0.84      0.84       104
# weighted avg       0.84      0.84      0.84       104
#
# [[41  6]
#  [11 46]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 68.27%
#  Precision: 100.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 8.33%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80        68
#            1       1.00      0.08      0.15        36
#
#    micro avg       0.68      0.68      0.68       104
#    macro avg       0.84      0.54      0.48       104
# weighted avg       0.79      0.68      0.58       104
#
# [[68  0]
#  [33  3]]
#
#
#  Deep Learning executed in = 53.540000 seconds
# Yaml Model  Save_WEC _up.yaml saved to disk
# Yaml Model  Save_WEC _down.yaml saved to disk
# Weights  Save_WEC _up.h5 saved to disk
# Weights  Save_WEC _down.h5 saved to disk
# Le   Deep Learning  de   WEC   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 485
# amorce :  480
#  --- Loop : 485  ---  --- Symbol :   WFC   ---  --- Name :  Wells Fargo  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  1.2484549121358504
#  Alpha :  -0.11445233948078443
#  R_Squared :  0.4254165247927906
#  Volatility :  0.2394975793696479
#  Momentum :  -0.22964468928223658
# executed in = 1.940000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  766
# On 80% - 20% slash :
# Bloc 1 :  613
# Bloc 2 : 153  periods
# First period : 2016-08-01 00:00:00
# Split period : 2019-01-07 00:00:00
# Last period : 2019-08-15 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [20:35:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.360000 seconds
#  Deeping in blue
#
#  --- Loop : 485  ---  --- Symbol :   WFC   ---  --- Name :  Wells Fargo  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 0s 628us/step
# 613/613 [==============================] - 0s 614us/step
# 104/104 [==============================] - 0s 39us/step
# 104/104 [==============================] - 0s 46us/step
#
#
#  RESULTATS UP
#
# Accuracy: 82.69%
#  Precision: 72.31%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.68      0.81        57
#            1       0.72      1.00      0.84        47
#
#    micro avg       0.83      0.83      0.83       104
#    macro avg       0.86      0.84      0.83       104
# weighted avg       0.87      0.83      0.82       104
#
# [[39 18]
#  [ 0 47]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 83.65%
#  Precision: 93.55%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 65.91%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.79      0.97      0.87        60
#            1       0.94      0.66      0.77        44
#
#    micro avg       0.84      0.84      0.84       104
#    macro avg       0.87      0.81      0.82       104
# weighted avg       0.85      0.84      0.83       104
#
# [[58  2]
#  [15 29]]
#
#
#  Deep Learning executed in = 52.980000 seconds
# Yaml Model  Save_WFC _up.yaml saved to disk
# Yaml Model  Save_WFC _down.yaml saved to disk
# Weights  Save_WFC _up.h5 saved to disk
# Weights  Save_WFC _down.h5 saved to disk
# Le   Deep Learning  de   WFC   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 486
# amorce :  480
#  --- Loop : 486  ---  --- Symbol :   WELL   ---  --- Name :  Welltower Inc.  ---  --- Sector :  Real Estate  ---
# Scraping data...
# Beta :  0.10959888820519331
#  Alpha :  0.10640262733743135
#  R_Squared :  0.004610372148727393
#  Volatility :  0.20201309980411786
#  Momentum :  0.3808503233067897
# executed in = 1.960000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  766
# On 80% - 20% slash :
# Bloc 1 :  613
# Bloc 2 : 153  periods
# First period : 2016-08-01 00:00:00
# Split period : 2019-01-07 00:00:00
# Last period : 2019-08-15 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [20:36:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.320000 seconds
#  Deeping in blue
#
#  --- Loop : 486  ---  --- Symbol :   WELL   ---  --- Name :  Welltower Inc.  ---  --- Sector :  Real Estate  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 0s 648us/step
# 613/613 [==============================] - 0s 643us/step
# 104/104 [==============================] - 0s 43us/step
# 104/104 [==============================] - 0s 42us/step
#
#
#  RESULTATS UP
#
# Accuracy: 67.31%
#  Precision: 64.44%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 96.67%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.27      0.41        44
#            1       0.64      0.97      0.77        60
#
#    micro avg       0.67      0.67      0.67       104
#    macro avg       0.75      0.62      0.59       104
# weighted avg       0.73      0.67      0.62       104
#
# [[12 32]
#  [ 2 58]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 68.27%
#  Precision: 56.25%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 48.65%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.76        67
#            1       0.56      0.49      0.52        37
#
#    micro avg       0.68      0.68      0.68       104
#    macro avg       0.65      0.64      0.64       104
# weighted avg       0.67      0.68      0.68       104
#
# [[53 14]
#  [19 18]]
#
#
#  Deep Learning executed in = 52.180000 seconds
#   Invalid precision test ==> Doing it again #1
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 0s 720us/step
# 613/613 [==============================] - 0s 713us/step
# 104/104 [==============================] - 0s 41us/step
# 104/104 [==============================] - 0s 48us/step
#
#
#  RESULTATS UP
#
# Accuracy: 64.42%
#  Precision: 61.86%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.16      0.27        44
#            1       0.62      1.00      0.76        60
#
#    micro avg       0.64      0.64      0.64       104
#    macro avg       0.81      0.58      0.52       104
# weighted avg       0.78      0.64      0.56       104
#
# [[ 7 37]
#  [ 0 60]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 70.19%
#  Precision: 61.54%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 43.24%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.73      0.85      0.79        67
#            1       0.62      0.43      0.51        37
#
#    micro avg       0.70      0.70      0.70       104
#    macro avg       0.67      0.64      0.65       104
# weighted avg       0.69      0.70      0.69       104
#
# [[57 10]
#  [21 16]]
#
#
#  Deep Learning executed in = 53.590000 seconds
#   Invalid precision test ==> Doing it again #2
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 0s 774us/step
# 613/613 [==============================] - 0s 780us/step
# 104/104 [==============================] - 0s 44us/step
# 104/104 [==============================] - 0s 46us/step
#
#
#  RESULTATS UP
#
# Accuracy: 74.04%
#  Precision: 68.97%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.39      0.56        44
#            1       0.69      1.00      0.82        60
#
#    micro avg       0.74      0.74      0.74       104
#    macro avg       0.84      0.69      0.69       104
# weighted avg       0.82      0.74      0.71       104
#
# [[17 27]
#  [ 0 60]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 69.23%
#  Precision: 64.71%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 29.73%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.70      0.91      0.79        67
#            1       0.65      0.30      0.41        37
#
#    micro avg       0.69      0.69      0.69       104
#    macro avg       0.67      0.60      0.60       104
# weighted avg       0.68      0.69      0.66       104
#
# [[61  6]
#  [26 11]]
#
#
#  Deep Learning executed in = 55.400000 seconds
#   Invalid precision test ==> Last test (#3)
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 1s 844us/step
# 613/613 [==============================] - 1s 817us/step
# 104/104 [==============================] - 0s 44us/step
# 104/104 [==============================] - 0s 46us/step
#
#
#  RESULTATS UP
#
# Accuracy: 69.23%
#  Precision: 65.56%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 98.33%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.93      0.30      0.45        44
#            1       0.66      0.98      0.79        60
#
#    micro avg       0.69      0.69      0.69       104
#    macro avg       0.79      0.64      0.62       104
# weighted avg       0.77      0.69      0.64       104
#
# [[13 31]
#  [ 1 59]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 75.96%
#  Precision: 68.75%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 59.46%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82        67
#            1       0.69      0.59      0.64        37
#
#    micro avg       0.76      0.76      0.76       104
#    macro avg       0.74      0.72      0.73       104
# weighted avg       0.75      0.76      0.76       104
#
# [[57 10]
#  [15 22]]
#
#
#  Deep Learning executed in = 57.240000 seconds
# Yaml Model  Save_WELL _up.yaml saved to disk
# Yaml Model  Save_WELL _down.yaml saved to disk
# Weights  Save_WELL _up.h5 saved to disk
# Weights  Save_WELL _down.h5 saved to disk
# Le   Deep Learning  de   WELL   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 487
# amorce :  480
#  --- Loop : 487  ---  --- Symbol :   WDC   ---  --- Name :  Western Digital  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  2.1114441945390303
#  Alpha :  -0.0333290879953179
#  R_Squared :  0.3666281495223169
#  Volatility :  0.4364928656685818
#  Momentum :  -0.11374897409742635
# executed in = 2.480000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  766
# On 80% - 20% slash :
# Bloc 1 :  613
# Bloc 2 : 153  periods
# First period : 2016-08-01 00:00:00
# Split period : 2019-01-07 00:00:00
# Last period : 2019-08-15 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [20:40:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.360000 seconds
#  Deeping in blue
#
#  --- Loop : 487  ---  --- Symbol :   WDC   ---  --- Name :  Western Digital  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 1s 905us/step
# 613/613 [==============================] - 1s 874us/step
# 104/104 [==============================] - 0s 45us/step
# 104/104 [==============================] - 0s 49us/step
#
#
#  RESULTATS UP
#
# Accuracy: 84.62%
#  Precision: 93.33%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 76.36%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85        49
#            1       0.93      0.76      0.84        55
#
#    micro avg       0.85      0.85      0.85       104
#    macro avg       0.86      0.85      0.85       104
# weighted avg       0.86      0.85      0.85       104
#
# [[46  3]
#  [13 42]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 82.69%
#  Precision: 70.97%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.70      0.82        60
#            1       0.71      1.00      0.83        44
#
#    micro avg       0.83      0.83      0.83       104
#    macro avg       0.85      0.85      0.83       104
# weighted avg       0.88      0.83      0.83       104
#
# [[42 18]
#  [ 0 44]]
#
#
#  Deep Learning executed in = 59.100000 seconds
# Yaml Model  Save_WDC _up.yaml saved to disk
# Yaml Model  Save_WDC _down.yaml saved to disk
# Weights  Save_WDC _up.h5 saved to disk
# Weights  Save_WDC _down.h5 saved to disk
# Le   Deep Learning  de   WDC   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 488
# amorce :  480
#  --- Loop : 488  ---  --- Symbol :   WU   ---  --- Name :  Western Union Co  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  0.6570513682730188
#  Alpha :  -0.024455434087937024
#  R_Squared :  0.2910449280329229
#  Volatility :  0.15243340879565437
#  Momentum :  0.15447965010911235
# executed in = 6.790000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  766
# On 80% - 20% slash :
# Bloc 1 :  613
# Bloc 2 : 153  periods
# First period : 2016-08-01 00:00:00
# Split period : 2019-01-07 00:00:00
# Last period : 2019-08-15 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [20:41:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.110000 seconds
#  Deeping in blue
#
#  --- Loop : 488  ---  --- Symbol :   WU   ---  --- Name :  Western Union Co  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 1s 971us/step
# 613/613 [==============================] - 1s 999us/step
# 104/104 [==============================] - 0s 44us/step
# 104/104 [==============================] - 0s 54us/step
#
#
#  RESULTATS UP
#
# Accuracy: 89.42%
#  Precision: 91.43%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92        64
#            1       0.91      0.80      0.85        40
#
#    micro avg       0.89      0.89      0.89       104
#    macro avg       0.90      0.88      0.89       104
# weighted avg       0.90      0.89      0.89       104
#
# [[61  3]
#  [ 8 32]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 75.00%
#  Precision: 87.88%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 56.86%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.69      0.92      0.79        53
#            1       0.88      0.57      0.69        51
#
#    micro avg       0.75      0.75      0.75       104
#    macro avg       0.78      0.75      0.74       104
# weighted avg       0.78      0.75      0.74       104
#
# [[49  4]
#  [22 29]]
#
#
#  Deep Learning executed in = 61.770000 seconds
# Yaml Model  Save_WU _up.yaml saved to disk
# Yaml Model  Save_WU _down.yaml saved to disk
# Weights  Save_WU _up.h5 saved to disk
# Weights  Save_WU _down.h5 saved to disk
# Le   Deep Learning  de   WU   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 489
# amorce :  480
#  --- Loop : 489  ---  --- Symbol :   WRK   ---  --- Name :  WestRock Company  ---  --- Sector :  Materials  ---
# Scraping data...
# Beta :  1.6141739623524234
#  Alpha :  -0.2186555034293024
#  R_Squared :  0.6398264909465026
#  Volatility :  0.25250325830862486
#  Momentum :  -0.3820655397083622
# executed in = 2.240000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  766
# On 80% - 20% slash :
# Bloc 1 :  613
# Bloc 2 : 153  periods
# First period : 2016-08-01 00:00:00
# Split period : 2019-01-07 00:00:00
# Last period : 2019-08-15 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [20:42:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.310000 seconds
#  Deeping in blue
#
#  --- Loop : 489  ---  --- Symbol :   WRK   ---  --- Name :  WestRock Company  ---  --- Sector :  Materials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 1s 1ms/step
# 613/613 [==============================] - 1s 1ms/step
# 104/104 [==============================] - 0s 52us/step
# 104/104 [==============================] - 0s 49us/step
#
#
#  RESULTATS UP
#
# Accuracy: 74.04%
#  Precision: 91.18%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 56.36%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.66      0.94      0.77        49
#            1       0.91      0.56      0.70        55
#
#    micro avg       0.74      0.74      0.74       104
#    macro avg       0.78      0.75      0.73       104
# weighted avg       0.79      0.74      0.73       104
#
# [[46  3]
#  [24 31]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 63.46%
#  Precision: 52.50%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.39      0.56        62
#            1       0.53      1.00      0.69        42
#
#    micro avg       0.63      0.63      0.63       104
#    macro avg       0.76      0.69      0.62       104
# weighted avg       0.81      0.63      0.61       104
#
# [[24 38]
#  [ 0 42]]
#
#
#  Deep Learning executed in = 60.870000 seconds
#   Invalid precision test ==> Doing it again #1
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 1s 1ms/step
# 613/613 [==============================] - 1s 1ms/step
# 104/104 [==============================] - 0s 46us/step
# 104/104 [==============================] - 0s 44us/step
#
#
#  RESULTATS UP
#
# Accuracy: 65.38%
#  Precision: 88.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 40.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.58      0.94      0.72        49
#            1       0.88      0.40      0.55        55
#
#    micro avg       0.65      0.65      0.65       104
#    macro avg       0.73      0.67      0.63       104
# weighted avg       0.74      0.65      0.63       104
#
# [[46  3]
#  [33 22]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 70.19%
#  Precision: 57.75%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 97.62%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.97      0.52      0.67        62
#            1       0.58      0.98      0.73        42
#
#    micro avg       0.70      0.70      0.70       104
#    macro avg       0.77      0.75      0.70       104
# weighted avg       0.81      0.70      0.69       104
#
# [[32 30]
#  [ 1 41]]
#
#
#  Deep Learning executed in = 62.830000 seconds
#   Invalid precision test ==> Doing it again #2
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 1s 1ms/step
# 613/613 [==============================] - 1s 1ms/step
# 104/104 [==============================] - 0s 52us/step
# 104/104 [==============================] - 0s 53us/step
#
#
#  RESULTATS UP
#
# Accuracy: 60.58%
#  Precision: 85.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 30.91%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.55      0.94      0.69        49
#            1       0.85      0.31      0.45        55
#
#    micro avg       0.61      0.61      0.61       104
#    macro avg       0.70      0.62      0.57       104
# weighted avg       0.71      0.61      0.57       104
#
# [[46  3]
#  [38 17]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 66.35%
#  Precision: 54.55%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.44      0.61        62
#            1       0.55      1.00      0.71        42
#
#    micro avg       0.66      0.66      0.66       104
#    macro avg       0.77      0.72      0.66       104
# weighted avg       0.82      0.66      0.65       104
#
# [[27 35]
#  [ 0 42]]
#
#
#  Deep Learning executed in = 63.090000 seconds
#   Invalid precision test ==> Last test (#3)
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 1s 1ms/step
# 613/613 [==============================] - 1s 1ms/step
# 104/104 [==============================] - 0s 51us/step
# 104/104 [==============================] - 0s 55us/step
#
#
#  RESULTATS UP
#
# Accuracy: 64.42%
#  Precision: 87.50%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 38.18%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.57      0.94      0.71        49
#            1       0.88      0.38      0.53        55
#
#    micro avg       0.64      0.64      0.64       104
#    macro avg       0.72      0.66      0.62       104
# weighted avg       0.73      0.64      0.62       104
#
# [[46  3]
#  [34 21]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 65.38%
#  Precision: 53.85%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.42      0.59        62
#            1       0.54      1.00      0.70        42
#
#    micro avg       0.65      0.65      0.65       104
#    macro avg       0.77      0.71      0.65       104
# weighted avg       0.81      0.65      0.63       104
#
# [[26 36]
#  [ 0 42]]
#
#
#  Deep Learning executed in = 66.160000 seconds
# Yaml Model  Save_WRK _up.yaml saved to disk
# Yaml Model  Save_WRK _down.yaml saved to disk
# Weights  Save_WRK _up.h5 saved to disk
# Weights  Save_WRK _down.h5 saved to disk
# Le   Deep Learning  de   WRK   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 490
# amorce :  480
#  --- Loop : 490  ---  --- Symbol :   WY   ---  --- Name :  Weyerhaeuser Corp.  ---  --- Sector :  Real Estate  ---
# Scraping data...
# Beta :  1.7176001267817238
#  Alpha :  -0.17778785769147307
#  R_Squared :  0.6742646529645899
#  Volatility :  0.26136118000763636
#  Momentum :  -0.2515172049305173
# executed in = 2.310000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  765
# On 80% - 20% slash :
# Bloc 1 :  612
# Bloc 2 : 153  periods
# First period : 2016-08-01 00:00:00
# Split period : 2019-01-04 00:00:00
# Last period : 2019-08-15 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [20:47:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.270000 seconds
#  Deeping in blue
#
#  --- Loop : 490  ---  --- Symbol :   WY   ---  --- Name :  Weyerhaeuser Corp.  ---  --- Sector :  Real Estate  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 612/612 [==============================] - 1s 1ms/step
# 612/612 [==============================] - 1s 1ms/step
# 104/104 [==============================] - 0s 54us/step
# 104/104 [==============================] - 0s 55us/step
#
#
#  RESULTATS UP
#
# Accuracy: 75.96%
#  Precision: 71.11%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 72.73%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79        60
#            1       0.71      0.73      0.72        44
#
#    micro avg       0.76      0.76      0.76       104
#    macro avg       0.75      0.76      0.75       104
# weighted avg       0.76      0.76      0.76       104
#
# [[47 13]
#  [12 32]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 78.85%
#  Precision: 80.43%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 74.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.78      0.83      0.80        54
#            1       0.80      0.74      0.77        50
#
#    micro avg       0.79      0.79      0.79       104
#    macro avg       0.79      0.79      0.79       104
# weighted avg       0.79      0.79      0.79       104
#
# [[45  9]
#  [13 37]]
#
#
#  Deep Learning executed in = 68.920000 seconds
# Yaml Model  Save_WY _up.yaml saved to disk
# Yaml Model  Save_WY _down.yaml saved to disk
# Weights  Save_WY _up.h5 saved to disk
# Weights  Save_WY _down.h5 saved to disk
# Le   Deep Learning  de   WY   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 491
# amorce :  480
#  --- Loop : 491  ---  --- Symbol :   WHR   ---  --- Name :  Whirlpool Corp.  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  1.9254731083992052
#  Alpha :  -0.2161454611590207
#  R_Squared :  0.5052761803218764
#  Volatility :  0.3384963773752503
#  Momentum :  0.059942772772368036
# executed in = 2.140000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  766
# On 80% - 20% slash :
# Bloc 1 :  613
# Bloc 2 : 153  periods
# First period : 2016-08-01 00:00:00
# Split period : 2019-01-07 00:00:00
# Last period : 2019-08-15 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [20:48:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.330000 seconds
#  Deeping in blue
#
#  --- Loop : 491  ---  --- Symbol :   WHR   ---  --- Name :  Whirlpool Corp.  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 1s 1ms/step
# 613/613 [==============================] - 1s 1ms/step
# 104/104 [==============================] - 0s 49us/step
# ...
#    macro avg       0.61      0.61      0.60       104
# weighted avg       0.62      0.60      0.59       104
#
# [[30 29]
#  [13 32]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 60.58%
#  Precision: 66.67%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 4.76%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.60      0.98      0.75        62
#            1       0.67      0.05      0.09        42
#
#    micro avg       0.61      0.61      0.61       104
#    macro avg       0.64      0.52      0.42       104
# weighted avg       0.63      0.61      0.48       104
#
# [[61  1]
#  [40  2]]
#
#
#  Deep Learning executed in = 96.380000 seconds
#   Invalid precision test ==> Last test (#3)
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 1s 2ms/step
# 613/613 [==============================] - 1s 2ms/step
# 104/104 [==============================] - 0s 66us/step
# 104/104 [==============================] - 0s 67us/step
#
#
#  RESULTATS UP
#
# Accuracy: 60.58%
#  Precision: 52.70%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 86.67%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.41      0.54        59
#            1       0.53      0.87      0.66        45
#
#    micro avg       0.61      0.61      0.61       104
#    macro avg       0.66      0.64      0.60       104
# weighted avg       0.68      0.61      0.59       104
#
# [[24 35]
#  [ 6 39]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 59.62%
#  Precision: 50.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 2.38%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.60      0.98      0.74        62
#            1       0.50      0.02      0.05        42
#
#    micro avg       0.60      0.60      0.60       104
#    macro avg       0.55      0.50      0.39       104
# weighted avg       0.56      0.60      0.46       104
#
# [[61  1]
#  [41  1]]
#
#
#  Deep Learning executed in = 102.000000 seconds
# Yaml Model  Save_YUM _up.yaml saved to disk
# Yaml Model  Save_YUM _down.yaml saved to disk
# Weights  Save_YUM _up.h5 saved to disk
# Weights  Save_YUM _down.h5 saved to disk
# Le   Deep Learning  de   YUM   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 502
# amorce :  480
#  --- Loop : 502  ---  --- Symbol :   ZBH   ---  --- Name :  Zimmer Biomet Holdings  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.1787312228022653
#  Alpha :  0.06448144689252418
#  R_Squared :  0.45425944255331907
#  Volatility :  0.2806933636029387
#  Momentum :  0.10502778926585887
# executed in = 2.120000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  412
# On 80% - 20% slash :
# Bloc 1 :  330
# Bloc 2 : 82  periods
# First period : 2017-11-01 00:00:00
# Split period : 2019-04-18 00:00:00
# Last period : 2019-08-15 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [21:16:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 1.740000 seconds
#  Deeping in blue
#
#  --- Loop : 502  ---  --- Symbol :   ZBH   ---  --- Name :  Zimmer Biomet Holdings  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 330/330 [==============================] - 1s 5ms/step
# 330/330 [==============================] - 1s 5ms/step
# 33/33 [==============================] - 0s 190us/step
# 33/33 [==============================] - 0s 219us/step
#
#
#  RESULTATS UP
#
# Accuracy: 84.85%
#  Precision: 78.95%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 93.75%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.93      0.76      0.84        17
#            1       0.79      0.94      0.86        16
#
#    micro avg       0.85      0.85      0.85        33
#    macro avg       0.86      0.85      0.85        33
# weighted avg       0.86      0.85      0.85        33
#
# [[13  4]
#  [ 1 15]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 84.85%
#  Precision: 75.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 81.82%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88        22
#            1       0.75      0.82      0.78        11
#
#    micro avg       0.85      0.85      0.85        33
#    macro avg       0.83      0.84      0.83        33
# weighted avg       0.85      0.85      0.85        33
#
# [[19  3]
#  [ 2  9]]
#
#
#  Deep Learning executed in = 67.250000 seconds
# Yaml Model  Save_ZBH _up.yaml saved to disk
# Yaml Model  Save_ZBH _down.yaml saved to disk
# Weights  Save_ZBH _up.h5 saved to disk
# Weights  Save_ZBH _down.h5 saved to disk
# Le   Deep Learning  de   ZBH   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 503
# amorce :  480
#  --- Loop : 503  ---  --- Symbol :   ZION   ---  --- Name :  Zions Bancorp  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  1.5541536940227672
#  Alpha :  -0.014667716300414642
#  R_Squared :  0.47504162249113846
#  Volatility :  0.2811742390394542
#  Momentum :  -0.2443633399288252
# executed in = 3.020000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  766
# On 80% - 20% slash :
# Bloc 1 :  613
# Bloc 2 : 153  periods
# First period : 2016-08-01 00:00:00
# Split period : 2019-01-07 00:00:00
# Last period : 2019-08-15 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [21:17:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.900000 seconds
#  Deeping in blue
#
#  --- Loop : 503  ---  --- Symbol :   ZION   ---  --- Name :  Zions Bancorp  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 2s 3ms/step
# 613/613 [==============================] - 2s 3ms/step
# 104/104 [==============================] - 0s 97us/step
# 104/104 [==============================] - 0s 98us/step
#
#
#  RESULTATS UP
#
# Accuracy: 80.77%
#  Precision: 82.35%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 66.67%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.90      0.85        62
#            1       0.82      0.67      0.74        42
#
#    micro avg       0.81      0.81      0.81       104
#    macro avg       0.81      0.78      0.79       104
# weighted avg       0.81      0.81      0.80       104
#
# [[56  6]
#  [14 28]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 77.88%
#  Precision: 69.86%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 98.08%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.97      0.58      0.72        52
#            1       0.70      0.98      0.82        52
#
#    micro avg       0.78      0.78      0.78       104
#    macro avg       0.83      0.78      0.77       104
# weighted avg       0.83      0.78      0.77       104
#
# [[30 22]
#  [ 1 51]]
#
#
#  Deep Learning executed in = 109.900000 seconds
# Yaml Model  Save_ZION _up.yaml saved to disk
# Yaml Model  Save_ZION _down.yaml saved to disk
# Weights  Save_ZION _up.h5 saved to disk
# Weights  Save_ZION _down.h5 saved to disk
# Le   Deep Learning  de   ZION   a été effecué avec succès. Les modèles ont été sauvegardés
# Loop : 504
# amorce :  480
#  --- Loop : 504  ---  --- Symbol :   ZTS   ---  --- Name :  Zoetis  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  0.5794180709291925
#  Alpha :  0.2598973018305889
#  R_Squared :  0.1913971888936079
#  Volatility :  0.16521033613472982
#  Momentum :  0.3691619415142784
# executed in = 2.490000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  766
# On 80% - 20% slash :
# Bloc 1 :  613
# Bloc 2 : 153  periods
# First period : 2016-08-01 00:00:00
# Split period : 2019-01-07 00:00:00
# Last period : 2019-08-15 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [21:19:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.070000 seconds
#  Deeping in blue
#
#  --- Loop : 504  ---  --- Symbol :   ZTS   ---  --- Name :  Zoetis  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 2s 3ms/step
# 613/613 [==============================] - 2s 3ms/step
# 104/104 [==============================] - 0s 96us/step
# 104/104 [==============================] - 0s 83us/step
#
#
#  RESULTATS UP
#
# Accuracy: 63.46%
#  Precision: 62.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 62.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.65      0.65      0.65        54
#            1       0.62      0.62      0.62        50
#
#    micro avg       0.63      0.63      0.63       104
#    macro avg       0.63      0.63      0.63       104
# weighted avg       0.63      0.63      0.63       104
#
# [[35 19]
#  [19 31]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 55.77%
#  Precision: 42.67%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 91.43%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.38      0.53        69
#            1       0.43      0.91      0.58        35
#
#    micro avg       0.56      0.56      0.56       104
#    macro avg       0.66      0.65      0.56       104
# weighted avg       0.74      0.56      0.55       104
#
# [[26 43]
#  [ 3 32]]
#
#
#  Deep Learning executed in = 109.570000 seconds
#   Invalid precision test ==> Doing it again #1
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 2s 3ms/step
# 613/613 [==============================] - 2s 3ms/step
# 104/104 [==============================] - 0s 78us/step
# 104/104 [==============================] - 0s 97us/step
#
#
#  RESULTATS UP
#
# Accuracy: 64.42%
#  Precision: 74.07%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 40.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.61      0.87      0.72        54
#            1       0.74      0.40      0.52        50
#
#    micro avg       0.64      0.64      0.64       104
#    macro avg       0.68      0.64      0.62       104
# weighted avg       0.67      0.64      0.62       104
#
# [[47  7]
#  [30 20]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 53.85%
#  Precision: 41.77%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 94.29%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.92      0.33      0.49        69
#            1       0.42      0.94      0.58        35
#
#    micro avg       0.54      0.54      0.54       104
#    macro avg       0.67      0.64      0.53       104
# weighted avg       0.75      0.54      0.52       104
#
# [[23 46]
#  [ 2 33]]
#
#
#  Deep Learning executed in = 108.790000 seconds
#   Invalid precision test ==> Doing it again #2
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 2s 3ms/step
# 613/613 [==============================] - 2s 3ms/step
# 104/104 [==============================] - 0s 90us/step
# 104/104 [==============================] - 0s 86us/step
#
#
#  RESULTATS UP
#
# Accuracy: 60.58%
#  Precision: 64.52%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 40.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.59      0.80      0.68        54
#            1       0.65      0.40      0.49        50
#
#    micro avg       0.61      0.61      0.61       104
#    macro avg       0.62      0.60      0.59       104
# weighted avg       0.62      0.61      0.59       104
#
# [[43 11]
#  [30 20]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 57.69%
#  Precision: 43.28%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 82.86%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.84      0.45      0.58        69
#            1       0.43      0.83      0.57        35
#
#    micro avg       0.58      0.58      0.58       104
#    macro avg       0.64      0.64      0.58       104
# weighted avg       0.70      0.58      0.58       104
#
# [[31 38]
#  [ 6 29]]
#
#
#  Deep Learning executed in = 108.670000 seconds
#   Invalid precision test ==> Last test (#3)
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 613/613 [==============================] - 2s 3ms/step
# 613/613 [==============================] - 2s 3ms/step
# 104/104 [==============================] - 0s 119us/step
# 104/104 [==============================] - 0s 120us/step
#
#
#  RESULTATS UP
#
# Accuracy: 62.50%
#  Precision: 64.86%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 48.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.61      0.76      0.68        54
#            1       0.65      0.48      0.55        50
#
#    micro avg       0.62      0.62      0.62       104
#    macro avg       0.63      0.62      0.61       104
# weighted avg       0.63      0.62      0.62       104
#
# [[41 13]
#  [26 24]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 50.00%
#  Precision: 39.24%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 88.57%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.84      0.30      0.45        69
#            1       0.39      0.89      0.54        35
#
#    micro avg       0.50      0.50      0.50       104
#    macro avg       0.62      0.60      0.50       104
# weighted avg       0.69      0.50      0.48       104
#
# [[21 48]
#  [ 4 31]]
#
#
#  Deep Learning executed in = 112.550000 seconds
# Yaml Model  Save_ZTS _up.yaml saved to disk
# Yaml Model  Save_ZTS _down.yaml saved to disk
# Weights  Save_ZTS _up.h5 saved to disk
# Weights  Save_ZTS _down.h5 saved to disk
# Le   Deep Learning  de   ZTS   a été effecué avec succès. Les modèles ont été sauvegardés
#   Longueur des listes pour vérification :  505 505 505
#    PASSAGE FINI!!!!!!

# %%
#import sys
#orig_stdout = sys.stdout
#f = open('backtestv2_4.txt', 'w')
#sys.stdout = f

# %%
#f.close()
#sys.stdout = orig_stdout

# %% [markdown]
# import pandas as pd
#
# backtest = pd.DataFrame(columns = ['Symb.','Name','Sector','period','Begin.','End',\
#                           'Pnl','%Pnl','Total Winners','Total Loosers','Nb Win','Nb Los',\
#                           '% Winners','MaxDD','%MaxDD','Aver. Win',\
#                           'Aver. Los','Aver. Duration',\
#                           'Total Trades','% Long','% Short','Profit Factor'])
# backtest.to_csv('BackTest.csv')
#
# signals = pd.DataFrame(columns = ['Date','Ticker','Open Long','Close Long','Open Short','Close Short','Buy/Sell Price','Quantity','tPNL'])
# signals.to_csv('SIGNALS.csv')

# %%
2+2

# %% [markdown]
# print(Fore.YELLOW,Back.BLUE,'Longueur des listes pour vérification : ',len(ticker_list),len(name_list),len(sector_list),Style.RESET_ALL)
#
# compteur = pd.DataFrame(columns = ['Symb.','Name','Sector'])
#
# compteur['Symb.'] = ticker_list
#
# compteur['Name'] = name_list
#
# compteur['Sector'] = sector_list
#
# compteur.to_csv('compteur.csv')
#
# print(Fore.YELLOW,Back.MAGENTA,Style.DIM,'PASSAGE FINI!!!!!!',Style.RESET_ALL)

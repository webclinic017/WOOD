# %%
___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor\n°OoO_FXCM_Oo0°\nLumberJack Jyss 5779(c)')
print('Version v2.00')
print('Importing librairies...')
import forexconnect
from forexconnect import fxcorepy
from forexconnect import ForexConnect, ResponseListener, Common
import time
import sys
import numpy as np
import pandas as pd
from colorama import Fore, Back, Style 
import datetime as dt
import talib
print('Librairies imported')
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)


def session_status_changed(session: fxcorepy.O2GSession,
                           status: fxcorepy.AO2GSessionStatus.O2GSessionStatus):
    print("Trading session status: " + str(status))
    return



pos_long_EURUSD = 0
pos_short_EURUSD = 0

# TOKEN = 'e053ac1597cef331df9429ac8151100ea9f1c411'
# server = 'demo'
user_id = 'D261151986'
password = '2786'
url = 'fxcorporate.com/Hosts.jsp'
accountid='01147539'
# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'
ticker = 'EUR/USD'
period = 'm15'
number = 30
jet_lag = -2
amount_EURUSD = 9000
buysell_EURUSD = None
side_EURUSD = None
trade_id_EURUSD = None
open_rate_EURUSD = None
open_time_EURUSD = None
offerid_EURUSD = None
pnl_EURUSD = None

# Time Windows
# start = dt.datetime(2017, 7, 15)
# stop = dt.datetime(2017, 8, 1)
# con.get_candles('EUR/USD', period='D1',start=start, stop=stop)

# CONNEXION

fx = ForexConnect()
fx.login(user_id, password, url,"Demo", session_status_callback=session_status_changed)
table_manager = fx.table_manager
trades_table = table_manager.get_table(fx.TRADES)

# RECOVERING TEST
for row in trades_table:
    if row['trade_id'] == trade_id_EURUSD and row['buy_sell'] == 'B':
        pos_long_EURUSD = 1
    elif row['trade_id'] == trade_id_EURUSD and row['buy_sell'] == 'S':
        pos_short_EURUSD = 1

# RECCUPERATION DES 30 DERNIERES DONNEES
tmps1=time.time()
history = fx.get_history(ticker, period,quotes_count=number)
data = pd.DataFrame({'Date':history['Date'],'Open':history['BidOpen'],'High':history['BidHigh'],'Low':history['BidLow'],'Close':history['BidClose']})
df = data.copy()
tmps2=round(time.time()-tmps1,2)
print('Data scraped in ',tmps2,' seconds')

print('\033[33m' + 'Initializing GOLEM...')
print('\033[35m' +'Long Pos =',pos_long_EURUSD)
print('Short Pos =',pos_short_EURUSD,Style.RESET_ALL)

# DATA PREPARATION

tmps1=time.time()
print('df.shape control : ',df.shape)
df.reset_index(inplace=True,drop=True)
dataset_1D = df.copy()
dataset_1D = dataset_1D.dropna()
rsi = talib.RSI(dataset_1D['Close'],timeperiod=2)
aroondown, aroonup = talib.AROON(dataset_1D['High'], dataset_1D['Low'], timeperiod=12)
aroondelta = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
dataset_1D['RSI'] = rsi
dataset_1D['Aroon Up'] = aroonup
dataset_1D['Aroon Down'] = aroondown
dataset_1D['Delta Aroon'] = aroondelta

dataset_1D['target_value'] = dataset_1D['Close']
dataset_1D = dataset_1D.drop(['Open','High','Low','Close'],axis=1)
df_1D = dataset_1D.copy()
df_1D = df_1D.iloc[:,1:]
df_1D['Date'] = df['Date']
df_1D = df_1D.dropna()
df_1D = df_1D[['Date'] + df_1D.columns[:-1].tolist()]
df_1D.reset_index(inplace=True,drop=True)
tmps2=round(time.time()-tmps1,2)
print('Data prepared in ',tmps2,' seconds')

print('\033[36m'+'GOLEM begins Computing...'+Style.RESET_ALL)


print('Computing done')
print('Instrument :', ticker)
print(df_1D.tail())

print('\n Initializing GOLEM on STREAMING LIVE...\n')

# UPDATING DATA
for loop in range(0,200000):
    #print(' \n INFRA LOOP ',loop,'\n')
    tmps1=time.time()

    history = fx.get_history(ticker, period,quotes_count=1)
    last = pd.DataFrame({'Date':history['Date'],'Open':history['BidOpen'],'High':history['BidHigh'],'Low':history['BidLow'],'Close':history['BidClose']})
    
    if last.iloc[-1,0].minute < df.iloc[-1,0].minute + 15 :
    
        print('\r \033[43m '+period+' \033[0m'+'\033[46m'+'...'+'\033[0m',end='')
        print ('\033[36m', dt.datetime.now().hour,'H',dt.datetime.now().minute,'min',dt.datetime.now().second,'sec',Style.RESET_ALL,end='')
        if pos_long_EURUSD == 1:
            try:
                if pnl_EURUSD > 0 :
                    print('\033[42m  - pnl : ',round(pnl_EURUSD,2),'\033[0m',end='', flush=True)
                elif pnl_EURUSD < 0:
                    print('\033[41m  - pnl : ',round(pnl_EURUSD,2),'\033[0m',end='', flush=True)
            except:
                pass
        elif pos_short_EURUSD == 1:
            try:
                if pnl_EURUSD > 0 :
                    print('\033[42m  - pnl : ',round(pnl_EURUSD,2),'\033[0m',end='', flush=True)
                elif pnl_EURUSD < 0:
                    print('\033[41m  - pnl : ',round(pnl_EURUSD,2),'\033[0m',end='', flush=True)
            except:
                pass
        else:
            print(' - No position',end='',flush=True)
        time.sleep(0.1)
    else :
        tmps1=time.time()
        df = df.iloc[1:,:]
        df = df.append({'Date':last.iloc[-1,0],'Open':last.iloc[-1,1], 'High':last.iloc[-1,2],'Low':last.iloc[-1,3], 'Close':last.iloc[-1,4]}, ignore_index=True)

        print('df.shape control : ',df.shape)
        df.reset_index(inplace=True,drop=True)
        dataset_1D = df.copy()
        dataset_1D = dataset_1D.dropna()
        rsi = talib.RSI(dataset_1D['Close'],timeperiod=2)
        aroondown, aroonup = talib.AROON(dataset_1D['High'], dataset_1D['Low'], timeperiod=12)
        atr = talib.ATR(dataset_1D['High'],dataset_1D['Low'],dataset_1D['Close'],timeperiod=14)
        aroondelta = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
        dataset_1D['RSI'] = rsi
        dataset_1D['Aroon Up'] = aroonup
        dataset_1D['Aroon Down'] = aroondown
        dataset_1D['Delta Aroon'] = aroondelta
        dataset_1D['target_value'] = dataset_1D['Close']
        dataset_1D = dataset_1D.drop(['Open','High','Low','Close'],axis=1)
        df_1D = dataset_1D.copy()
        df_1D = df_1D.iloc[:,1:]
        df_1D['Date'] = df['Date']
        df_1D = df_1D.dropna()
        df_1D = df_1D[['Date'] + df_1D.columns[:-1].tolist()]
        df_1D.reset_index(inplace=True,drop=True)
        
        
        print()
        print('\r GOLEM begins testing...',end='')
        print('   Aroon up :',aroonup.iloc[-1],end='')
        print('   Aroon down : ',aroondown.iloc[-1],end='')
        print('   RSI : ',rsi.iloc[-1],end='')
        print ('\033[36m    ', dt.datetime.now().hour,'H',dt.datetime.now().minute,'min',dt.datetime.now().second,'sec',Style.RESET_ALL,end='')
        
        if (aroonup.iloc[-1] < 10 and aroondown.iloc[-1] > 90  and rsi.iloc[-1] < 15) or (aroonup.iloc[-1] < 10 and aroondown.iloc[-1] > 90  and rsi.iloc[-1] > 80):

            if  pos_long_EURUSD == 0 and pos_short_EURUSD == 1 :
                
                try:
                   
                    buysell_EURUSD = 'B'
                    trade_rate_EURUSD = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) + (4*float(atr.iloc[-1]))
                    request_close_EURUSD = fx.create_order_request(order_type='CM',
                                                                            ACCOUNT_ID=accountid,
                                                                            OFFER_ID = offerid_EURUSD,
                                                                            BUY_SELL=buysell_EURUSD,
                                                                            AMOUNT=amount_EURUSD,
                                                                            TIME_IN_FORCE='IOC',
                                                                            TRADE_ID =trade_id_EURUSD)
                    resp_close_EURUSD = fx.send_request(request_close_EURUSD)

                    closed_table = table_manager.get_table(fx.CLOSED_TRADES)
                    for row in closed_table:
                        if row['trade_id'] == trade_id_EURUSD:
                            trade =None
                            side_EURUSD = row['buy_sell']
                            pnl_EURUSD = row['pl']
                            trade_id_EURUSD = row['trade_id']
                            open_rate_EURUSD = row['open_rate']
                            amount_EURUSD = row['amount']
                            open_time_EURUSD = row['open_time']
                            close_rate_EURUSD = row['close_rate']
                            close_time_EURUSD = row['close_time']

                    print('\033[47m \033[31m Close Short avec un pnl de', pnl_EURUSD,'\033[0m')
                    print('Résumé : ')
                    print(' Open date : ', open_time_EURUSD)
                    print('Open Rate : ',open_rate_EURUSD)
                    print('Amount : ',amount_EURUSD)
                    print('')
                    pos_short_EURUSD = 0
                    continue
                except:
                    print("WARNING! It wasn't possible to close the position" )
                    pass

            if pos_long_EURUSD == 0 and pos_short_EURUSD == 0:
                
                try:
                    buysell_EURUSD = 'B'
                    trade_rate_EURUSD = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) + (4*float(atr.iloc[-1]))
                    print('Trying Long at :',trade_rate_EURUSD)

                    request_open_EURUSD = fx.create_order_request(\
                        SYMBOL=ticker,\
                        order_type='OM',\
                        ACCOUNT_ID=accountid,\
                        BUY_SELL=buysell_EURUSD,\
                        AMOUNT=amount_EURUSD,\
                        TIME_IN_FORCE='IOC'\
                        )
                    resp_open_EURUSD = fx.send_request(request_open_EURUSD)
                    order_id_EURUSD = resp_open_EURUSD.order_id
                    offer_EURUSD = Common.get_offer(fx,ticker)
                    offerid_EURUSD = offer_EURUSD.offer_id
                    table_manager = fx.table_manager
                    trades_table = table_manager.get_table(fx.TRADES)
                    print('Actualisation des tables')
                    time.sleep(0.5)
                    for row in trades_table:
                        side_EURUSD = row['buy_sell']
                        pnl_EURUSD = row['pl']
                        trade_id_EURUSD = row['trade_id']
                        open_rate_EURUSD = row['open_rate']
                        amount_EURUSD = row['amount']
                        print('Side',side_EURUSD,'pnl : ',pnl_EURUSD,'Trade_ID : ',trade_id_EURUSD,'Open_Rate',open_rate_EURUSD,'Amount',amount_EURUSD)

                    print('Résumé : ')
                    print(' Open date : ', open_time_EURUSD)
                    print('Open Rate : ',open_rate_EURUSD)
                    print('Amount : ',amount_EURUSD)
                    print('pnl : ',pnl_EURUSD)
                    print('Order : ',trade_id_EURUSD)
                    print('')
                    print(                                                    'Go Long!')
                    pos_long_EURUSD = 1
                    
                except:
                    print("It wasn't possible to long... What a good opportunity missed... Meoow yells the black cat")
                    pass

        elif (aroondown.iloc[-1] < 10 and aroonup.iloc[-1] > 90  and rsi.iloc[-1] > 80) or (aroondown.iloc[-1] < 10 and aroonup.iloc[-1] > 90  and rsi.iloc[-1] < 20):
            
            if  pos_long_EURUSD == 1 and pos_short_EURUSD == 0 :
                
                try:
                    buysell_EURUSD = 'S'

                    trade_rate_EURUSD = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) + (4*float(atr.iloc[-1]))
                    request_close_EURUSD = fx.create_order_request(order_type='CM',
                                                                            ACCOUNT_ID=accountid,
                                                                            OFFER_ID = offerid_EURUSD,
                                                                            BUY_SELL=buysell_EURUSD,
                                                                            AMOUNT=amount_EURUSD,
                                                                            TIME_IN_FORCE='IOC',
                                                                            TRADE_ID =trade_id_EURUSD)
                    resp_close_EURUSD = fx.send_request(request_close_EURUSD)

                    closed_table = table_manager.get_table(fx.CLOSED_TRADES)
                    for row in closed_table:
                        if row['trade_id'] == trade_id_EURUSD:
                            trade =None
                            side_EURUSD = row['buy_sell']
                            pnl_EURUSD = row['pl']
                            trade_id_EURUSD = row['trade_id']
                            open_rate_EURUSD = row['open_rate']
                            amount_EURUSD = row['amount']
                            open_time_EURUSD = row['open_time']
                            close_rate_EURUSD = row['close_rate']
                            close_time_EURUSD = row['close_time']

                    print('\033[47m \033[31m Close Short avec un pnl de', pnl_EURUSD,'\033[0m')
                    print('Résumé : ')
                    print(' Open date : ', open_time_EURUSD)
                    print('Open Rate : ',open_rate_EURUSD)
                    print('Amount : ',amount_EURUSD)
                    print('')
                    pos_long_EURUSD = 0
                    continue
                except:
                    print("WARNING! It wasn't possible to close the position" )
                    continue

            if pos_long_EURUSD == 0 and pos_short_EURUSD == 0:
                
                try:
                    buysell_EURUSD = 'S'
                    trade_rate_EURUSD = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) - (4*float(atr.iloc[-1]))
                    print('Trying short at : ',trade_rate_EURUSD)

                    request_open_EURUSD = fx.create_order_request(\
                        SYMBOL=ticker,\
                        order_type='OM',\
                        ACCOUNT_ID=accountid,\
                        BUY_SELL=buysell_EURUSD,\
                        AMOUNT=amount_EURUSD,\
                        TIME_IN_FORCE='IOC'\
                        )
                    resp_open_EURUSD = fx.send_request(request_open_EURUSD)
                    order_id_EURUSD = resp_open_EURUSD.order_id
                    offer_EURUSD = Common.get_offer(fx,ticker)
                    offerid_EURUSD = offer_EURUSD.offer_id
                    table_manager = fx.table_manager
                    trades_table = table_manager.get_table(fx.TRADES)
                    print('Actualisation des tables')
                    time.sleep(0.5)
                    for row in trades_table:
                        side_EURUSD = row['buy_sell']
                        pnl_EURUSD = row['pl']
                        trade_id_EURUSD = row['trade_id']
                        open_rate_EURUSD = row['open_rate']
                        amount_EURUSD = row['amount']
                        print('Side',side_EURUSD,'pnl : ',pnl_EURUSD,'Trade_ID : ',trade_id_EURUSD,'Open_Rate',open_rate_EURUSD,'Amount',amount_EURUSD)

                    print('Résumé : ')
                    print(' Open date : ', open_time_EURUSD)
                    print('Open Rate : ',open_rate_EURUSD)
                    print('Amount : ',amount_EURUSD)
                    print('pnl : ',pnl_EURUSD)
                    print('Order : ',trade_id_EURUSD)
                    print('')
                    print(                                                    'Go Short!')
                    pos_short_EURUSD = 1
                except:
                    print("It wasn't possible to short. You missed a great opportunity!")
                    pass
        else:
            print('No signal at the moment')
# Out:
# Global Optimized LumberJack Environment Motor
# °OoO_FXCM_Oo0°
# LumberJack Jyss 5779(c)
# Version v2.00
# Importing librairies...
# Librairies imported
# Trading session status: CONNECTING
# Trading session status: CONNECTED
# Data scraped in  0.25  seconds
# Initializing GOLEM...
# Long Pos = 0
# Short Pos = 0
# df.shape control :  (30, 5)
# Data prepared in  0.02  seconds
# GOLEM begins Computing...
# Computing done
# Instrument : EUR/USD
#                   Date        RSI  Aroon Up  Aroon Down  Delta Aroon  \
# 13 2019-07-05 09:30:00   5.755933  0.000000  100.000000  -100.000000
# 14 2019-07-05 09:45:00  71.113484  8.333333   91.666667   -83.333333
# 15 2019-07-05 10:00:00  68.365041  0.000000   83.333333   -83.333333
# 16 2019-07-05 10:15:00  70.634887  0.000000   75.000000   -75.000000
# 17 2019-07-05 10:30:00  42.919291  0.000000   66.666667   -66.666667
#
#     target_value
# 13       1.12563
# 14       1.12632
# 15       1.12630
# 16       1.12632
# 17       1.12623
#
# ...

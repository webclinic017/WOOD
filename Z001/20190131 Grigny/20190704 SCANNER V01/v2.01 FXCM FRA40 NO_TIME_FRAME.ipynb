# %%
___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor\n°OoO_FXCM_Oo0°\nLumberJack Jyss 5779(c)')
print('Version v2.00')
print('Importing librairies...')
import forexconnect
from forexconnect import fxcorepy
from forexconnect import ForexConnect, ResponseListener, Common
import time
import sys
import numpy as np
import pandas as pd
from colorama import Fore, Back, Style 
import datetime as dt
import talib
print('Librairies imported')
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)


def session_status_changed(session: fxcorepy.O2GSession,
                           status: fxcorepy.AO2GSessionStatus.O2GSessionStatus):
    print("Trading session status: " + str(status))
    return



pos_long_FRA40 = 0
pos_short_FRA40 = 0

# TOKEN = 'e053ac1597cef331df9429ac8151100ea9f1c411'
# server = 'demo'
user_id = 'D261151986'
password = '2786'
url = 'fxcorporate.com/Hosts.jsp'
accountid='01147539'
# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'
ticker = 'FRA40'
period = 'm1'
number = 30
jet_lag = -2
amount_FRA40 = 30
buysell_FRA40 = None
side_FRA40 = None
trade_id_FRA40 = None
open_rate_FRA40 = None
open_time_FRA40 = None
offerid_FRA40 = None
pnl_FRA40 = None

# Time Windows
# start = dt.datetime(2017, 7, 15)
# stop = dt.datetime(2017, 8, 1)
# con.get_candles('EUR/USD', period='D1',start=start, stop=stop)

# CONNEXION

fx = ForexConnect()
fx.login(user_id, password, url,"Demo", session_status_callback=session_status_changed)
table_manager = fx.table_manager
trades_table = table_manager.get_table(fx.TRADES)

# RECOVERING TEST
for row in trades_table:
    if row['trade_id'] == trade_id_FRA40 and row['buy_sell'] == 'B':
        pos_long_FRA40 = 1
    elif row['trade_id'] == trade_id_FRA40 and row['buy_sell'] == 'S':
        pos_short_FRA40 = 1

# RECCUPERATION DES 30 DERNIERES DONNEES
tmps1=time.time()
history = fx.get_history(ticker, period,quotes_count=number)
data = pd.DataFrame({'Date':history['Date'],'Open':history['BidOpen'],'High':history['BidHigh'],'Low':history['BidLow'],'Close':history['BidClose']})
df = data.copy()
tmps2=round(time.time()-tmps1,2)
print('Data scraped in ',tmps2,' seconds')

print('\033[33m' + 'Initializing GOLEM...')
print('\033[35m' +'Long Pos =',pos_long_FRA40)
print('Short Pos =',pos_short_FRA40,Style.RESET_ALL)

# DATA PREPARATION

tmps1=time.time()
print('df.shape control : ',df.shape)
df.reset_index(inplace=True,drop=True)
dataset_1D = df.copy()
dataset_1D = dataset_1D.dropna()
rsi = talib.RSI(dataset_1D['Close'],timeperiod=2)
aroondown, aroonup = talib.AROON(dataset_1D['High'], dataset_1D['Low'], timeperiod=25)
aroondelta = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
dataset_1D['RSI'] = rsi
dataset_1D['Aroon Up'] = aroonup
dataset_1D['Aroon Down'] = aroondown
dataset_1D['Delta Aroon'] = aroondelta

dataset_1D['target_value'] = dataset_1D['Close']
dataset_1D = dataset_1D.drop(['Open','High','Low','Close'],axis=1)
df_1D = dataset_1D.copy()
df_1D = df_1D.iloc[:,1:]
df_1D['Date'] = df['Date']
df_1D = df_1D.dropna()
df_1D = df_1D[['Date'] + df_1D.columns[:-1].tolist()]
df_1D.reset_index(inplace=True,drop=True)
tmps2=round(time.time()-tmps1,2)
print('Data prepared in ',tmps2,' seconds')

print('\033[36m'+'GOLEM begins Computing...'+Style.RESET_ALL)


print('Computing done')
print('Instrument :', ticker)
print(df_1D.tail())

print('\n Initializing GOLEM on STREAMING LIVE...\n')

# UPDATING DATA
for loop in range(0,200000):
    #print(' \n INFRA LOOP ',loop,'\n')
    tmps1=time.time()

    history = fx.get_history(ticker, period,quotes_count=1)
    last = pd.DataFrame({'Date':history['Date'],'Open':history['BidOpen'],'High':history['BidHigh'],'Low':history['BidLow'],'Close':history['BidClose']})
    
    if last.iloc[-1,0].minute == df.iloc[-1,0].minute :
    
        print('\r \033[43m '+period+' \033[0m'+'\033[46m'+'...'+'\033[0m',end='')
        print ('\033[36m', dt.datetime.now().hour,'H',dt.datetime.now().minute,'min',dt.datetime.now().second,'sec',Style.RESET_ALL,end='')
        if pos_long_FRA40 == 1:
            try:
                if pnl_FRA40 > 0 :
                    print('\033[42m  - pnl : ',round(pnl_FRA40,2),'\033[0m',end='', flush=True)
                elif pnl_FRA40 < 0:
                    print('\033[41m  - pnl : ',round(pnl_FRA40,2),'\033[0m',end='', flush=True)
            except:
                pass
        elif pos_short_FRA40 == 1:
            try:
                if pnl_FRA40 > 0 :
                    print('\033[42m  - pnl : ',round(pnl_FRA40,2),'\033[0m',end='', flush=True)
                elif pnl_FRA40 < 0:
                    print('\033[41m  - pnl : ',round(pnl_FRA40,2),'\033[0m',end='', flush=True)
            except:
                pass
        else:
            print(' - No position',end='',flush=True)
        time.sleep(0.1)
    else :
        tmps1=time.time()
        df = df.iloc[1:,:]
        df = df.append({'Date':last.iloc[-1,0],'Open':last.iloc[-1,1], 'High':last.iloc[-1,2],'Low':last.iloc[-1,3], 'Close':last.iloc[-1,4]}, ignore_index=True)

        print('df.shape control : ',df.shape)
        df.reset_index(inplace=True,drop=True)
        dataset_1D = df.copy()
        dataset_1D = dataset_1D.dropna()
        rsi = talib.RSI(dataset_1D['Close'],timeperiod=2)
        aroondown, aroonup = talib.AROON(dataset_1D['High'], dataset_1D['Low'], timeperiod=25)
        atr = talib.ATR(dataset_1D['High'],dataset_1D['Low'],dataset_1D['Close'],timeperiod=14)
        aroondelta = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
        dataset_1D['RSI'] = rsi
        dataset_1D['Aroon Up'] = aroonup
        dataset_1D['Aroon Down'] = aroondown
        dataset_1D['Delta Aroon'] = aroondelta
        dataset_1D['target_value'] = dataset_1D['Close']
        dataset_1D = dataset_1D.drop(['Open','High','Low','Close'],axis=1)
        df_1D = dataset_1D.copy()
        df_1D = df_1D.iloc[:,1:]
        df_1D['Date'] = df['Date']
        df_1D = df_1D.dropna()
        df_1D = df_1D[['Date'] + df_1D.columns[:-1].tolist()]
        df_1D.reset_index(inplace=True,drop=True)
        
        
        print()
        print('\r GOLEM begins testing...',end='')
        print('   Aroon up :',aroonup.iloc[-1],end='')
        print('   Aroon down : ',aroondown.iloc[-1],end='')
        print('   RSI : ',rsi.iloc[-1],end='')
        print ('\033[36m    ', dt.datetime.now().hour,'H',dt.datetime.now().minute,'min',dt.datetime.now().second,'sec',Style.RESET_ALL,end='')
        
        if aroonup.iloc[-1] < 4 and aroondown.iloc[-1] > 97  and rsi.iloc[-1] < 10:

            if  pos_long_FRA40 == 0 and pos_short_FRA40 == 1 :
                
                try:
                   
                    buysell_FRA40 = 'B'
                    trade_rate_FRA40 = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) + (4*float(atr.iloc[-1]))
                    request_close_FRA40 = fx.create_order_request(order_type='CM',
                                                                            ACCOUNT_ID=accountid,
                                                                            OFFER_ID = offerid_FRA40,
                                                                            BUY_SELL=buysell_FRA40,
                                                                            AMOUNT=amount_FRA40,
                                                                            TIME_IN_FORCE='IOC',
                                                                            TRADE_ID =trade_id_FRA40)
                    resp_close_FRA40 = fx.send_request(request_close_FRA40)

                    closed_table = table_manager.get_table(fx.CLOSED_TRADES)
                    for row in closed_table:
                        if row['trade_id'] == trade_id_FRA40:
                            trade =None
                            side_FRA40 = row['buy_sell']
                            pnl_FRA40 = row['pl']
                            trade_id_FRA40 = row['trade_id']
                            open_rate_FRA40 = row['open_rate']
                            amount_FRA40 = row['amount']
                            open_time_FRA40 = row['open_time']
                            close_rate_FRA40 = row['close_rate']
                            close_time_FRA40 = row['close_time']

                    print('\033[47m \033[31m Close Short avec un pnl de', pnl_FRA40,'\033[0m')
                    print('Résumé : ')
                    print(' Open date : ', open_time_FRA40)
                    print('Open Rate : ',open_rate_FRA40)
                    print('Amount : ',amount_FRA40)
                    print('')
                    pos_short_FRA40 = 0
                    continue
                except:
                    print("WARNING! It wasn't possible to close the position" )
                    pass

            if pos_long_FRA40 == 0 and pos_short_FRA40 == 0:
                
                try:
                    buysell_FRA40 = 'B'
                    trade_rate_FRA40 = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) + (4*float(atr.iloc[-1]))
                    print('Trying Long at :',trade_rate_FRA40)

                    request_open_FRA40 = fx.create_order_request(\
                        SYMBOL=ticker,\
                        order_type='OM',\
                        ACCOUNT_ID=accountid,\
                        BUY_SELL=buysell_FRA40,\
                        AMOUNT=amount_FRA40,\
                        TIME_IN_FORCE='IOC'\
                        )
                    resp_open_FRA40 = fx.send_request(request_open_FRA40)
                    order_id_FRA40 = resp_open_FRA40.order_id
                    offer_FRA40 = Common.get_offer(fx,ticker)
                    offerid_FRA40 = offer_FRA40.offer_id
                    table_manager = fx.table_manager
                    trades_table = table_manager.get_table(fx.TRADES)
                    print('Actualisation des tables')
                    time.sleep(0.5)
                    for row in trades_table:
                        side_FRA40 = row['buy_sell']
                        pnl_FRA40 = row['pl']
                        trade_id_FRA40 = row['trade_id']
                        open_rate_FRA40 = row['open_rate']
                        amount_FRA40 = row['amount']
                        print('Side',side_FRA40,'pnl : ',pnl_FRA40,'Trade_ID : ',trade_id_FRA40,'Open_Rate',open_rate_FRA40,'Amount',amount_FRA40)

                    print('Résumé : ')
                    print(' Open date : ', open_time_FRA40)
                    print('Open Rate : ',open_rate_FRA40)
                    print('Amount : ',amount_FRA40)
                    print('pnl : ',pnl_FRA40)
                    print('Order : ',trade_id_FRA40)
                    print('')
                    print(                                                    'Go Long!')
                    pos_long_FRA40 = 1
                    
                except:
                    print("It wasn't possible to long... What a good opportunity missed... Meoow yells the black cat")
                    pass

        elif aroondown.iloc[-1] < 4 and aroonup.iloc[-1] > 97  and rsi.iloc[-1] > 90:
            
            if  pos_long_FRA40 == 1 and pos_short_FRA40 == 0 :
                
                try:
                    buysell_FRA40 = 'S'

                    trade_rate_FRA40 = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) + (4*float(atr.iloc[-1]))
                    request_close_FRA40 = fx.create_order_request(order_type='CM',
                                                                            ACCOUNT_ID=accountid,
                                                                            OFFER_ID = offerid_FRA40,
                                                                            BUY_SELL=buysell_FRA40,
                                                                            AMOUNT=amount_FRA40,
                                                                            TIME_IN_FORCE='IOC',
                                                                            TRADE_ID =trade_id_FRA40)
                    resp_close_FRA40 = fx.send_request(request_close_FRA40)

                    closed_table = table_manager.get_table(fx.CLOSED_TRADES)
                    for row in closed_table:
                        if row['trade_id'] == trade_id_FRA40:
                            trade =None
                            side_FRA40 = row['buy_sell']
                            pnl_FRA40 = row['pl']
                            trade_id_FRA40 = row['trade_id']
                            open_rate_FRA40 = row['open_rate']
                            amount_FRA40 = row['amount']
                            open_time_FRA40 = row['open_time']
                            close_rate_FRA40 = row['close_rate']
                            close_time_FRA40 = row['close_time']

                    print('\033[47m \033[31m Close Short avec un pnl de', pnl_FRA40,'\033[0m')
                    print('Résumé : ')
                    print(' Open date : ', open_time_FRA40)
                    print('Open Rate : ',open_rate_FRA40)
                    print('Amount : ',amount_FRA40)
                    print('')
                    pos_long_FRA40 = 0
                    continue
                except:
                    print("WARNING! It wasn't possible to close the position" )
                    continue

            if pos_long_FRA40 == 0 and pos_short_FRA40 == 0:
                
                try:
                    buysell_FRA40 = 'S'
                    trade_rate_FRA40 = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) - (4*float(atr.iloc[-1]))
                    print('Trying short at : ',trade_rate_FRA40)

                    request_open_FRA40 = fx.create_order_request(\
                        SYMBOL=ticker,\
                        order_type='OM',\
                        ACCOUNT_ID=accountid,\
                        BUY_SELL=buysell_FRA40,\
                        AMOUNT=amount_FRA40,\
                        TIME_IN_FORCE='IOC'\
                        )
                    resp_open_FRA40 = fx.send_request(request_open_FRA40)
                    order_id_FRA40 = resp_open_FRA40.order_id
                    offer_FRA40 = Common.get_offer(fx,ticker)
                    offerid_FRA40 = offer_FRA40.offer_id
                    table_manager = fx.table_manager
                    trades_table = table_manager.get_table(fx.TRADES)
                    print('Actualisation des tables')
                    time.sleep(0.5)
                    for row in trades_table:
                        side_FRA40 = row['buy_sell']
                        pnl_FRA40 = row['pl']
                        trade_id_FRA40 = row['trade_id']
                        open_rate_FRA40 = row['open_rate']
                        amount_FRA40 = row['amount']
                        print('Side',side_FRA40,'pnl : ',pnl_FRA40,'Trade_ID : ',trade_id_FRA40,'Open_Rate',open_rate_FRA40,'Amount',amount_FRA40)

                    print('Résumé : ')
                    print(' Open date : ', open_time_FRA40)
                    print('Open Rate : ',open_rate_FRA40)
                    print('Amount : ',amount_FRA40)
                    print('pnl : ',pnl_FRA40)
                    print('Order : ',trade_id_FRA40)
                    print('')
                    print(                                                    'Go Short!')
                    pos_short_FRA40 = 1
                except:
                    print("It wasn't possible to short. You missed a great opportunity!")
                    pass
        else:
            print('No signal at the moment')
# Out:
# Global Optimized LumberJack Environment Motor
# °OoO_FXCM_Oo0°
# LumberJack Jyss 5779(c)
# Version v2.00
# Importing librairies...
# Librairies imported
# Trading session status: CONNECTING
# Trading session status: CONNECTED
# Data scraped in  0.25  seconds
# Initializing GOLEM...
# Long Pos = 0
# Short Pos = 0
# df.shape control :  (30, 5)
# Data prepared in  0.04  seconds
# GOLEM begins Computing...
# Computing done
# Instrument : FRA40
#                  Date        RSI  Aroon Up  Aroon Down  Delta Aroon  \
# 0 2019-07-05 08:06:00  79.301301      16.0        52.0        -36.0
# 1 2019-07-05 08:07:00  46.254370      12.0        48.0        -36.0
# 2 2019-07-05 08:08:00  46.254370       8.0        44.0        -36.0
# 3 2019-07-05 08:09:00  17.343840       4.0        40.0        -36.0
# 4 2019-07-05 08:10:00  86.224588       0.0        36.0        -36.0
#
#    target_value
# 0        5605.9
# 1        5605.4
# 2        5605.4
# 3        5604.9
# 4        5606.9
#
#  Initializing GOLEM on STREAMING LIVE...
#
#   m1 ... 8 H 10 min 43 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  32.0   RSI :  86.22458838743032     8 H 10 min 43 sec No signal at the moment
#   m1 ... 8 H 11 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  28.0   RSI :  92.4861696416992     8 H 11 min 26 sec No signal at the moment
#   m1 ... 8 H 12 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  24.0   RSI :  97.3338105058719     8 H 12 min 26 sec No signal at the moment
#   m1 ... 8 H 13 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  20.0   RSI :  98.37937576760308     8 H 13 min 26 sec No signal at the moment
#   m1 ... 8 H 14 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  16.0   RSI :  99.09173845340763     8 H 14 min 26 sec No signal at the moment
#   m1 ... 8 H 15 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 96.0   Aroon down :  12.0   RSI :  18.3652625795534     8 H 15 min 26 sec No signal at the moment
#   m1 ... 8 H 16 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 92.0   Aroon down :  8.0   RSI :  50.57625830084469     8 H 16 min 26 sec No signal at the moment
#   m1 ... 8 H 17 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 88.0   Aroon down :  4.0   RSI :  36.266441235361036     8 H 17 min 26 sec No signal at the moment
#   m1 ... 8 H 18 min 27 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  0.0   RSI :  83.8343456997702     8 H 18 min 27 sec No signal at the moment
#   m1 ... 8 H 19 min 27 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 96.0   Aroon down :  40.0   RSI :  62.35485327350324     8 H 19 min 27 sec No signal at the moment
#   m1 ... 8 H 20 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 92.0   Aroon down :  36.0   RSI :  43.69577408912814     8 H 20 min 26 sec No signal at the moment
#   m1 ... 8 H 21 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 88.0   Aroon down :  32.0   RSI :  39.02467321448902     8 H 21 min 26 sec No signal at the moment
#   m1 ... 8 H 22 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 84.0   Aroon down :  28.0   RSI :  67.1328202556453     8 H 22 min 27 sec No signal at the moment
#   m1 ... 8 H 23 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 80.0   Aroon down :  24.0   RSI :  16.79856570862456     8 H 23 min 27 sec No signal at the moment
#   m1 ... 8 H 24 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 76.0   Aroon down :  20.0   RSI :  16.79856628100451     8 H 24 min 26 sec No signal at the moment
#   m1 ... 8 H 25 min 30 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 72.0   Aroon down :  16.0   RSI :  7.80060890049854     8 H 25 min 31 sec No signal at the moment
#   m1 ... 8 H 26 min 31 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 68.0   Aroon down :  12.0   RSI :  50.350927853245764     8 H 26 min 32 sec No signal at the moment
#   m1 ... 8 H 27 min 29 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 64.0   Aroon down :  8.0   RSI :  26.183440665005463     8 H 27 min 30 sec No signal at the moment
#   m1 ... 8 H 28 min 44 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 60.0   Aroon down :  4.0   RSI :  11.90182218509754     8 H 28 min 44 sec No signal at the moment
#   m1 ... 8 H 29 min 37 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 56.0   Aroon down :  0.0   RSI :  61.8468555927751     8 H 29 min 38 sec No signal at the moment
#   m1 ... 8 H 30 min 25 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 52.0   Aroon down :  16.0   RSI :  28.983701864349182     8 H 30 min 26 sec No signal at the moment
#   m1 ... 8 H 31 min 33 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 48.0   Aroon down :  12.0   RSI :  28.983701959970414     8 H 31 min 34 sec No signal at the moment
#   m1 ... 8 H 32 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 44.0   Aroon down :  8.0   RSI :  93.89226248410888     8 H 32 min 26 sec No signal at the moment
#   m1 ... 8 H 33 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  4.0   RSI :  96.80890667977174     8 H 33 min 26 sec No signal at the moment
#   m1 ... 8 H 34 min 27 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 96.0   Aroon down :  0.0   RSI :  37.352349450839014     8 H 34 min 27 sec No signal at the moment
#   m1 ... 8 H 35 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 92.0   Aroon down :  20.0   RSI :  68.40226338412542     8 H 35 min 26 sec No signal at the moment
#   m1 ... 8 H 36 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 88.0   Aroon down :  16.0   RSI :  22.934454762976834     8 H 36 min 27 sec No signal at the moment
#   m1 ... 8 H 37 min 28 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 84.0   Aroon down :  12.0   RSI :  53.706381130902955     8 H 37 min 28 sec No signal at the moment
#   m1 ... 8 H 38 min 28 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 80.0   Aroon down :  100.0   RSI :  26.35031669219036     8 H 38 min 28 sec No signal at the moment
#   m1 ... 8 H 39 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 76.0   Aroon down :  96.0   RSI :  34.096920440173164     8 H 39 min 26 sec No signal at the moment
#   m1 ... 8 H 40 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 72.0   Aroon down :  100.0   RSI :  15.554738673132496     8 H 40 min 27 sec No signal at the moment
#   m1 ... 8 H 41 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 68.0   Aroon down :  100.0   RSI :  15.554738572501408     8 H 41 min 26 sec No signal at the moment
#   m1 ... 8 H 42 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 64.0   Aroon down :  100.0   RSI :  15.554738572501408     8 H 42 min 26 sec No signal at the moment
#   m1 ... 8 H 43 min 28 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 60.0   Aroon down :  100.0   RSI :  82.54774731786489     8 H 43 min 28 sec No signal at the moment
#   m1 ... 8 H 44 min 27 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 56.0   Aroon down :  96.0   RSI :  44.71177841588235     8 H 44 min 27 sec No signal at the moment
#   m1 ... 8 H 45 min 27 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 52.0   Aroon down :  92.0   RSI :  36.37539970336235     8 H 45 min 27 sec No signal at the moment
#   m1 ... 8 H 46 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 48.0   Aroon down :  88.0   RSI :  18.82555594559958     8 H 46 min 26 sec No signal at the moment
#   m1 ... 8 H 47 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 44.0   Aroon down :  100.0   RSI :  9.580779446028567     8 H 47 min 26 sec No signal at the moment
#   m1 ... 8 H 48 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 40.0   Aroon down :  96.0   RSI :  54.38329897176632     8 H 48 min 26 sec No signal at the moment
#   m1 ... 8 H 49 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 36.0   Aroon down :  100.0   RSI :  27.314627053293833     8 H 49 min 26 sec No signal at the moment
#   m1 ... 8 H 50 min 25 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 32.0   Aroon down :  100.0   RSI :  13.688267072185639     8 H 50 min 26 sec No signal at the moment
#   m1 ... 8 H 51 min 36 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 28.0   Aroon down :  100.0   RSI :  13.688266683258915     8 H 51 min 36 sec No signal at the moment
#   m1 ... 8 H 52 min 31 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 24.0   Aroon down :  100.0   RSI :  7.612260573495304     8 H 52 min 31 sec No signal at the moment
#   m1 ... 8 H 53 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 20.0   Aroon down :  100.0   RSI :  3.264748730653249     8 H 53 min 26 sec No signal at the moment
#   m1 ... 8 H 54 min 27 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 16.0   Aroon down :  96.0   RSI :  66.68589187113598     8 H 54 min 29 sec No signal at the moment
#   m1 ... 8 H 55 min 36 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 12.0   Aroon down :  100.0   RSI :  28.85297221948488     8 H 55 min 36 sec No signal at the moment
#   m1 ... 8 H 56 min 29 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 8.0   Aroon down :  100.0   RSI :  13.516422831839902     8 H 56 min 29 sec No signal at the moment
#   m1 ... 8 H 57 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  100.0   RSI :  4.3236427483623014     8 H 57 min 26 sec No signal at the moment
#   m1 ... 8 H 58 min 27 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  100.0   RSI :  1.4220833613337227     8 H 58 min 27 sec Trying Long at : 5604.844574815071
# Actualisation des tables
# Side B pnl :  -24.30000000000291 Trade_ID :  154418166 Open_Rate 2992.65 Amount 30
# Side B pnl :  -0.3600000000005821 Trade_ID :  154419021 Open_Rate 12583.51 Amount 30
# Side B pnl :  -4.400000000000546 Trade_ID :  154419023 Open_Rate 5604.8 Amount 30
# Résumé :
#  Open date :  None
# Open Rate :  5604.8
# Amount :  30
# pnl :  -4.400000000000546
# Order :  154419023
#
# Go Long!
#   m1 ... 8 H 59 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  100.0   RSI :  0.8744007570388082     8 H 59 min 26 sec No signal at the moment
#   m1 ... 9 H 0 min 31 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#   m1 ... 9 H 1 min 35 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#   m1 ... 9 H 2 min 28 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  96.0   RSI :  51.37000939917071     9 H 2 min 29 sec No signal at the moment
#   m1 ... 9 H 3 min 28 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  92.0   RSI :  75.96542003116438     9 H 3 min 29 sec No signal at the moment
#   m1 ... 9 H 4 min 36 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  88.0   RSI :  75.9654173788359     9 H 4 min 36 sec No signal at the moment
#   m1 ... 9 H 5 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 12.0   Aroon down :  84.0   RSI :  25.12860894530384     9 H 5 min 26 sec No signal at the moment
#   m1 ... 9 H 6 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 8.0   Aroon down :  80.0   RSI :  85.07128213739463     9 H 6 min 26 sec No signal at the moment
#   m1 ... 9 H 7 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  76.0   RSI :  85.07128303478468     9 H 7 min 26 sec No signal at the moment
#   m1 ... 9 H 8 min 25 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  72.0   RSI :  96.44760206050982     9 H 8 min 27 sec No signal at the moment
#   m1 ... 9 H 9 min 29 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  68.0   RSI :  96.44760268111945     9 H 9 min 30 sec No signal at the moment
#   m1 ... 9 H 10 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 8.0   Aroon down :  64.0   RSI :  98.82840897164553     9 H 10 min 26 sec No signal at the moment
#   m1 ... 9 H 11 min 32 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  60.0   RSI :  99.610843539199     9 H 11 min 32 sec No signal at the moment
#   m1 ... 9 H 12 min 27 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  56.0   RSI :  35.81957947111129     9 H 12 min 27 sec No signal at the moment
#   m1 ... 9 H 13 min 29 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 92.0   Aroon down :  52.0   RSI :  27.131884691998447     9 H 13 min 30 sec No signal at the moment
#   m1 ... 9 H 14 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 88.0   Aroon down :  48.0   RSI :  27.13188466258097     9 H 14 min 26 sec No signal at the moment
#   m1 ... 9 H 15 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 84.0   Aroon down :  44.0   RSI :  63.014142252825856     9 H 15 min 26 sec No signal at the moment
#   m1 ... 9 H 16 min 25 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 80.0   Aroon down :  40.0   RSI :  28.881381278280156     9 H 16 min 26 sec No signal at the moment
#   m1 ... 9 H 17 min 31 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 76.0   Aroon down :  36.0   RSI :  76.18357898235702     9 H 17 min 31 sec No signal at the moment
#   m1 ... 9 H 18 min 34 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 72.0   Aroon down :  32.0   RSI :  89.2199415829366     9 H 18 min 34 sec No signal at the moment
#   m1 ... 9 H 19 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 68.0   Aroon down :  28.0   RSI :  80.41645248340477     9 H 19 min 26 sec No signal at the moment
#   m1 ... 9 H 20 min 27 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 64.0   Aroon down :  24.0   RSI :  83.64416970374604     9 H 20 min 27 sec No signal at the moment
#   m1 ... 9 H 21 min 28 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  20.0   RSI :  97.24859341556328     9 H 21 min 28 sec No signal at the moment
#   m1 ... 9 H 22 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  16.0   RSI :  98.6954208920996     9 H 22 min 26 sec No signal at the moment
#   m1 ... 9 H 23 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  12.0   RSI :  99.00830913741032     9 H 23 min 27 sec No signal at the moment
#   m1 ... 9 H 24 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 96.0   Aroon down :  8.0   RSI :  66.91210250596804     9 H 24 min 26 sec No signal at the moment
#   m1 ... 9 H 25 min 27 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 92.0   Aroon down :  4.0   RSI :  21.16681640180247     9 H 25 min 28 sec No signal at the moment
#   m1 ... 9 H 26 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 88.0   Aroon down :  0.0   RSI :  53.17755772681076     9 H 26 min 26 sec No signal at the moment
#   m1 ... 9 H 27 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 84.0   Aroon down :  0.0   RSI :  29.345602009362683     9 H 27 min 26 sec No signal at the moment
#   m1 ... 9 H 28 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 80.0   Aroon down :  8.0   RSI :  58.85135965748102     9 H 28 min 26 sec No signal at the moment
#   m1 ... 9 H 29 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 76.0   Aroon down :  4.0   RSI :  58.8513598405919     9 H 29 min 27 sec No signal at the moment
#   m1 ... 9 H 30 min 45 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  0.0   RSI :  88.26216333458362     9 H 30 min 45 sec No signal at the moment
#   m1 ... 9 H 31 min 28 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 96.0   Aroon down :  4.0   RSI :  40.279506560281376     9 H 31 min 28 sec No signal at the moment
#   m1 ... 9 H 32 min 43 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 92.0   Aroon down :  0.0   RSI :  40.279506318388414     9 H 32 min 44 sec No signal at the moment
#   m1 ... 9 H 33 min 33 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 88.0   Aroon down :  32.0   RSI :  17.47687992658815     9 H 33 min 33 sec No signal at the moment
#   m1 ... 9 H 34 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 84.0   Aroon down :  28.0   RSI :  61.29708539802189     9 H 34 min 26 sec No signal at the moment
#   m1 ... 9 H 35 min 29 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 80.0   Aroon down :  24.0   RSI :  13.501457496516691     9 H 35 min 30 sec No signal at the moment
#   m1 ... 9 H 36 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 76.0   Aroon down :  20.0   RSI :  4.043306616008983     9 H 36 min 26 sec No signal at the moment
#   m1 ... 9 H 37 min 35 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 72.0   Aroon down :  16.0   RSI :  4.04330611517823     9 H 37 min 35 sec No signal at the moment
#   m1 ... 9 H 38 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 68.0   Aroon down :  12.0   RSI :  4.043306782952565     9 H 38 min 26 sec No signal at the moment
#   m1 ... 9 H 39 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 64.0   Aroon down :  8.0   RSI :  1.4097634691765841     9 H 39 min 26 sec No signal at the moment
#   m1 ... 9 H 40 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 60.0   Aroon down :  4.0   RSI :  65.08517178151939     9 H 40 min 26 sec No signal at the moment
#   m1 ... 9 H 41 min 26 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 56.0   Aroon down :  0.0   RSI :  37.44562717064957     9 H 41 min 26 sec No signal at the moment
#   m1 ... 9 H 42 min 39 sec   - pnl :  -4.4 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 52.0   Aroon down :  96.0   RSI :  56.09194367697388     9 H 42 min 39 sec No signal at the moment
#   m1 ... 9 H 42 min 52 sec   - pnl :  -4.4

# %%
___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor\n°OoO_FXCM_Oo0°\nLumberJack Jyss 5779(c)')
print('Version v2.00')
print('Importing librairies...')
import forexconnect
from forexconnect import fxcorepy
from forexconnect import ForexConnect, ResponseListener, Common
import time
import sys
import numpy as np
import pandas as pd
from colorama import Fore, Back, Style 
import datetime as dt
import talib
print('Librairies imported')
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)


def session_status_changed(session: fxcorepy.O2GSession,
                           status: fxcorepy.AO2GSessionStatus.O2GSessionStatus):
    print("Trading session status: " + str(status))
    return



pos_long_GER30 = 0
pos_short_GER30 = 0

# TOKEN = 'e053ac1597cef331df9429ac8151100ea9f1c411'
# server = 'demo'
user_id = 'D261151986'
password = '2786'
url = 'fxcorporate.com/Hosts.jsp'
accountid='01147539'
# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'
ticker = 'GER30'
period = 'm15'
number = 30
jet_lag = -2
amount_GER30 = 30
buysell_GER30 = None
side_GER30 = None
trade_id_GER30 = None
open_rate_GER30 = None
open_time_GER30 = None
offerid_GER30 = None
pnl_GER30 = None

# Time Windows
# start = dt.datetime(2017, 7, 15)
# stop = dt.datetime(2017, 8, 1)
# con.get_candles('EUR/USD', period='D1',start=start, stop=stop)

# CONNEXION

fx = ForexConnect()
fx.login(user_id, password, url,"Demo", session_status_callback=session_status_changed)
table_manager = fx.table_manager
trades_table = table_manager.get_table(fx.TRADES)

# RECOVERING TEST
for row in trades_table:
    if row['trade_id'] == trade_id_GER30 and row['buy_sell'] == 'B':
        pos_long_GER30 = 1
    elif row['trade_id'] == trade_id_GER30 and row['buy_sell'] == 'S':
        pos_short_GER30 = 1

# RECCUPERATION DES 30 DERNIERES DONNEES
tmps1=time.time()
history = fx.get_history(ticker, period,quotes_count=number)
data = pd.DataFrame({'Date':history['Date'],'Open':history['BidOpen'],'High':history['BidHigh'],'Low':history['BidLow'],'Close':history['BidClose']})
df = data.copy()
tmps2=round(time.time()-tmps1,2)
print('Data scraped in ',tmps2,' seconds')

print('\033[33m' + 'Initializing GOLEM...')
print('\033[35m' +'Long Pos =',pos_long_GER30)
print('Short Pos =',pos_short_GER30,Style.RESET_ALL)

# DATA PREPARATION

tmps1=time.time()
print('df.shape control : ',df.shape)
df.reset_index(inplace=True,drop=True)
dataset_1D = df.copy()
dataset_1D = dataset_1D.dropna()
rsi = talib.RSI(dataset_1D['Close'],timeperiod=2)
aroondown, aroonup = talib.AROON(dataset_1D['High'], dataset_1D['Low'], timeperiod=10)
aroondelta = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
dataset_1D['RSI'] = rsi
dataset_1D['Aroon Up'] = aroonup
dataset_1D['Aroon Down'] = aroondown
dataset_1D['Delta Aroon'] = aroondelta

dataset_1D['target_value'] = dataset_1D['Close']
dataset_1D = dataset_1D.drop(['Open','High','Low','Close'],axis=1)
df_1D = dataset_1D.copy()
df_1D = df_1D.iloc[:,1:]
df_1D['Date'] = df['Date']
df_1D = df_1D.dropna()
df_1D = df_1D[['Date'] + df_1D.columns[:-1].tolist()]
df_1D.reset_index(inplace=True,drop=True)
tmps2=round(time.time()-tmps1,2)
print('Data prepared in ',tmps2,' seconds')

print('\033[36m'+'GOLEM begins Computing...'+Style.RESET_ALL)


print('Computing done')
print('Instrument :', ticker)
print(df_1D.tail())

print('\n Initializing GOLEM on STREAMING LIVE...\n')

# UPDATING DATA
for loop in range(0,200000):
    #print(' \n INFRA LOOP ',loop,'\n')
    tmps1=time.time()

    history = fx.get_history(ticker, period,quotes_count=1)
    last = pd.DataFrame({'Date':history['Date'],'Open':history['BidOpen'],'High':history['BidHigh'],'Low':history['BidLow'],'Close':history['BidClose']})
    
    if last.iloc[-1,0].minute < df.iloc[-1,0].minute + 15 :
    
        print('\r \033[43m '+period+' \033[0m'+'\033[46m'+'...'+'\033[0m',end='')
        print ('\033[36m', dt.datetime.now().hour,'H',dt.datetime.now().minute,'min',dt.datetime.now().second,'sec',Style.RESET_ALL,end='')
        if pos_long_GER30 == 1:
            try:
                if pnl_GER30 > 0 :
                    print('\033[42m  - pnl : ',round(pnl_GER30,2),'\033[0m',end='', flush=True)
                elif pnl_GER30 < 0:
                    print('\033[41m  - pnl : ',round(pnl_GER30,2),'\033[0m',end='', flush=True)
            except:
                pass
        elif pos_short_GER30 == 1:
            try:
                if pnl_GER30 > 0 :
                    print('\033[42m  - pnl : ',round(pnl_GER30,2),'\033[0m',end='', flush=True)
                elif pnl_GER30 < 0:
                    print('\033[41m  - pnl : ',round(pnl_GER30,2),'\033[0m',end='', flush=True)
            except:
                pass
        else:
            print(' - No position',end='',flush=True)
        time.sleep(0.1)
    else :
        tmps1=time.time()
        df = df.iloc[1:,:]
        df = df.append({'Date':last.iloc[-1,0],'Open':last.iloc[-1,1], 'High':last.iloc[-1,2],'Low':last.iloc[-1,3], 'Close':last.iloc[-1,4]}, ignore_index=True)

        print('df.shape control : ',df.shape)
        df.reset_index(inplace=True,drop=True)
        dataset_1D = df.copy()
        dataset_1D = dataset_1D.dropna()
        rsi = talib.RSI(dataset_1D['Close'],timeperiod=2)
        aroondown, aroonup = talib.AROON(dataset_1D['High'], dataset_1D['Low'], timeperiod=10)
        atr = talib.ATR(dataset_1D['High'],dataset_1D['Low'],dataset_1D['Close'],timeperiod=14)
        aroondelta = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
        dataset_1D['RSI'] = rsi
        dataset_1D['Aroon Up'] = aroonup
        dataset_1D['Aroon Down'] = aroondown
        dataset_1D['Delta Aroon'] = aroondelta
        dataset_1D['target_value'] = dataset_1D['Close']
        dataset_1D = dataset_1D.drop(['Open','High','Low','Close'],axis=1)
        df_1D = dataset_1D.copy()
        df_1D = df_1D.iloc[:,1:]
        df_1D['Date'] = df['Date']
        df_1D = df_1D.dropna()
        df_1D = df_1D[['Date'] + df_1D.columns[:-1].tolist()]
        df_1D.reset_index(inplace=True,drop=True)
        
        
        print()
        print('\r GOLEM begins testing...',end='')
        print('   Aroon up :',aroonup.iloc[-1],end='')
        print('   Aroon down : ',aroondown.iloc[-1],end='')
        print('   RSI : ',rsi.iloc[-1],end='')
        print ('\033[36m    ', dt.datetime.now().hour,'H',dt.datetime.now().minute,'min',dt.datetime.now().second,'sec',Style.RESET_ALL,end='')
        
        if (aroonup.iloc[-1] < 10 and aroondown.iloc[-1] > 90  and rsi.iloc[-1] < 20) or (aroonup.iloc[-1] < 10 and aroondown.iloc[-1] > 90  and rsi.iloc[-1] > 80):

            if  pos_long_GER30 == 0 and pos_short_GER30 == 1 :
                
                try:
                   
                    buysell_GER30 = 'B'
                    trade_rate_GER30 = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) + (4*float(atr.iloc[-1]))
                    request_close_GER30 = fx.create_order_request(order_type='CM',
                                                                            ACCOUNT_ID=accountid,
                                                                            OFFER_ID = offerid_GER30,
                                                                            BUY_SELL=buysell_GER30,
                                                                            AMOUNT=amount_GER30,
                                                                            TIME_IN_FORCE='IOC',
                                                                            TRADE_ID =trade_id_GER30)
                    resp_close_GER30 = fx.send_request(request_close_GER30)

                    closed_table = table_manager.get_table(fx.CLOSED_TRADES)
                    for row in closed_table:
                        if row['trade_id'] == trade_id_GER30:
                            trade =None
                            side_GER30 = row['buy_sell']
                            pnl_GER30 = row['pl']
                            trade_id_GER30 = row['trade_id']
                            open_rate_GER30 = row['open_rate']
                            amount_GER30 = row['amount']
                            open_time_GER30 = row['open_time']
                            close_rate_GER30 = row['close_rate']
                            close_time_GER30 = row['close_time']

                    print('\033[47m \033[31m Close Short avec un pnl de', pnl_GER30,'\033[0m')
                    print('Résumé : ')
                    print(' Open date : ', open_time_GER30)
                    print('Open Rate : ',open_rate_GER30)
                    print('Amount : ',amount_GER30)
                    print('')
                    pos_short_GER30 = 0
                    continue
                except:
                    print("WARNING! It wasn't possible to close the position" )
                    pass

            if pos_long_GER30 == 0 and pos_short_GER30 == 0:
                
                try:
                    buysell_GER30 = 'B'
                    trade_rate_GER30 = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) + (4*float(atr.iloc[-1]))
                    print('Trying Long at :',trade_rate_GER30)

                    request_open_GER30 = fx.create_order_request(\
                        SYMBOL=ticker,\
                        order_type='OM',\
                        ACCOUNT_ID=accountid,\
                        BUY_SELL=buysell_GER30,\
                        AMOUNT=amount_GER30,\
                        TIME_IN_FORCE='IOC'\
                        )
                    resp_open_GER30 = fx.send_request(request_open_GER30)
                    order_id_GER30 = resp_open_GER30.order_id
                    offer_GER30 = Common.get_offer(fx,ticker)
                    offerid_GER30 = offer_GER30.offer_id
                    table_manager = fx.table_manager
                    trades_table = table_manager.get_table(fx.TRADES)
                    print('Actualisation des tables')
                    time.sleep(0.5)
                    for row in trades_table:
                        side_GER30 = row['buy_sell']
                        pnl_GER30 = row['pl']
                        trade_id_GER30 = row['trade_id']
                        open_rate_GER30 = row['open_rate']
                        amount_GER30 = row['amount']
                        print('Side',side_GER30,'pnl : ',pnl_GER30,'Trade_ID : ',trade_id_GER30,'Open_Rate',open_rate_GER30,'Amount',amount_GER30)

                    print('Résumé : ')
                    print(' Open date : ', open_time_GER30)
                    print('Open Rate : ',open_rate_GER30)
                    print('Amount : ',amount_GER30)
                    print('pnl : ',pnl_GER30)
                    print('Order : ',trade_id_GER30)
                    print('')
                    print(                                                    'Go Long!')
                    pos_long_GER30 = 1
                    
                except:
                    print("It wasn't possible to long... What a good opportunity missed... Meoow yells the black cat")
                    pass

        elif (aroondown.iloc[-1] < 10 and aroonup.iloc[-1] > 90  and rsi.iloc[-1] > 80) or (aroondown.iloc[-1] < 10 and aroonup.iloc[-1] > 90  and rsi.iloc[-1] < 80):
            
            if  pos_long_GER30 == 1 and pos_short_GER30 == 0 :
                
                try:
                    buysell_GER30 = 'S'

                    trade_rate_GER30 = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) + (4*float(atr.iloc[-1]))
                    request_close_GER30 = fx.create_order_request(order_type='CM',
                                                                            ACCOUNT_ID=accountid,
                                                                            OFFER_ID = offerid_GER30,
                                                                            BUY_SELL=buysell_GER30,
                                                                            AMOUNT=amount_GER30,
                                                                            TIME_IN_FORCE='IOC',
                                                                            TRADE_ID =trade_id_GER30)
                    resp_close_GER30 = fx.send_request(request_close_GER30)

                    closed_table = table_manager.get_table(fx.CLOSED_TRADES)
                    for row in closed_table:
                        if row['trade_id'] == trade_id_GER30:
                            trade =None
                            side_GER30 = row['buy_sell']
                            pnl_GER30 = row['pl']
                            trade_id_GER30 = row['trade_id']
                            open_rate_GER30 = row['open_rate']
                            amount_GER30 = row['amount']
                            open_time_GER30 = row['open_time']
                            close_rate_GER30 = row['close_rate']
                            close_time_GER30 = row['close_time']

                    print('\033[47m \033[31m Close Short avec un pnl de', pnl_GER30,'\033[0m')
                    print('Résumé : ')
                    print(' Open date : ', open_time_GER30)
                    print('Open Rate : ',open_rate_GER30)
                    print('Amount : ',amount_GER30)
                    print('')
                    pos_long_GER30 = 0
                    continue
                except:
                    print("WARNING! It wasn't possible to close the position" )
                    continue

            if pos_long_GER30 == 0 and pos_short_GER30 == 0:
                
                try:
                    buysell_GER30 = 'S'
                    trade_rate_GER30 = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) - (4*float(atr.iloc[-1]))
                    print('Trying short at : ',trade_rate_GER30)

                    request_open_GER30 = fx.create_order_request(\
                        SYMBOL=ticker,\
                        order_type='OM',\
                        ACCOUNT_ID=accountid,\
                        BUY_SELL=buysell_GER30,\
                        AMOUNT=amount_GER30,\
                        TIME_IN_FORCE='IOC'\
                        )
                    resp_open_GER30 = fx.send_request(request_open_GER30)
                    order_id_GER30 = resp_open_GER30.order_id
                    offer_GER30 = Common.get_offer(fx,ticker)
                    offerid_GER30 = offer_GER30.offer_id
                    table_manager = fx.table_manager
                    trades_table = table_manager.get_table(fx.TRADES)
                    print('Actualisation des tables')
                    time.sleep(0.5)
                    for row in trades_table:
                        side_GER30 = row['buy_sell']
                        pnl_GER30 = row['pl']
                        trade_id_GER30 = row['trade_id']
                        open_rate_GER30 = row['open_rate']
                        amount_GER30 = row['amount']
                        print('Side',side_GER30,'pnl : ',pnl_GER30,'Trade_ID : ',trade_id_GER30,'Open_Rate',open_rate_GER30,'Amount',amount_GER30)

                    print('Résumé : ')
                    print(' Open date : ', open_time_GER30)
                    print('Open Rate : ',open_rate_GER30)
                    print('Amount : ',amount_GER30)
                    print('pnl : ',pnl_GER30)
                    print('Order : ',trade_id_GER30)
                    print('')
                    print(                                                    'Go Short!')
                    pos_short_GER30 = 1
                except:
                    print("It wasn't possible to short. You missed a great opportunity!")
                    pass
        else:
            print('No signal at the moment')
# Out:
# Global Optimized LumberJack Environment Motor
# °OoO_FXCM_Oo0°
# LumberJack Jyss 5779(c)
# Version v2.00
# Importing librairies...
# Librairies imported
# Trading session status: CONNECTING
# Trading session status: CONNECTED
# Data scraped in  0.25  seconds
# Initializing GOLEM...
# Long Pos = 0
# Short Pos = 0
# df.shape control :  (30, 5)
# Data prepared in  0.02  seconds
# GOLEM begins Computing...
# Computing done
# Instrument : GER30
#                  Date        RSI  Aroon Up  Aroon Down  Delta Aroon  \
# 0 2019-07-05 08:07:00  35.933938      12.0        36.0        -24.0
# 1 2019-07-05 08:08:00  22.743456       8.0        32.0        -24.0
# 2 2019-07-05 08:09:00   7.517886       4.0       100.0        -96.0
# 3 2019-07-05 08:10:00  67.826215       0.0       100.0       -100.0
# 4 2019-07-05 08:11:00  59.510386      48.0        96.0        -48.0
#
#    target_value
# 0      12598.57
# 1      12597.41
# 2      12594.21
# 3      12598.69
# 4      12598.21
#
#  Initializing GOLEM on STREAMING LIVE...
#
#   m1 ... 8 H 11 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 44.0   Aroon down :  92.0   RSI :  69.9493874999265     8 H 11 min 26 sec No signal at the moment
#   m1 ... 8 H 12 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 40.0   Aroon down :  88.0   RSI :  90.08957430593769     8 H 12 min 26 sec No signal at the moment
#   m1 ... 8 H 13 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 36.0   Aroon down :  84.0   RSI :  93.72829636583042     8 H 13 min 26 sec No signal at the moment
#   m1 ... 8 H 14 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 32.0   Aroon down :  80.0   RSI :  89.2104217572378     8 H 14 min 26 sec No signal at the moment
#   m1 ... 8 H 15 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 28.0   Aroon down :  76.0   RSI :  14.047996014100017     8 H 15 min 26 sec No signal at the moment
#   m1 ... 8 H 16 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 24.0   Aroon down :  72.0   RSI :  51.13686244661106     8 H 16 min 26 sec No signal at the moment
#   m1 ... 8 H 17 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 20.0   Aroon down :  68.0   RSI :  67.80677462534489     8 H 17 min 26 sec No signal at the moment
#   m1 ... 8 H 18 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 16.0   Aroon down :  64.0   RSI :  90.92456263128231     8 H 18 min 27 sec No signal at the moment
#   m1 ... 8 H 19 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 12.0   Aroon down :  60.0   RSI :  87.55632630743581     8 H 19 min 26 sec No signal at the moment
#   m1 ... 8 H 20 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 8.0   Aroon down :  56.0   RSI :  91.93705574810326     8 H 20 min 26 sec No signal at the moment
#   m1 ... 8 H 21 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  52.0   RSI :  75.11022807347578     8 H 21 min 26 sec No signal at the moment
#   m1 ... 8 H 22 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  48.0   RSI :  92.57727519984562     8 H 22 min 26 sec No signal at the moment
#   m1 ... 8 H 23 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 96.0   Aroon down :  44.0   RSI :  40.07705388572748     8 H 23 min 26 sec No signal at the moment
#   m1 ... 8 H 24 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 92.0   Aroon down :  40.0   RSI :  32.24113051724336     8 H 24 min 27 sec No signal at the moment
#   m1 ... 8 H 25 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 88.0   Aroon down :  36.0   RSI :  46.252777038378184     8 H 25 min 26 sec No signal at the moment
#   m1 ... 8 H 26 min 28 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 84.0   Aroon down :  32.0   RSI :  11.668367995024283     8 H 26 min 29 sec No signal at the moment
#   m1 ... 8 H 27 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 80.0   Aroon down :  28.0   RSI :  9.128580503003125     8 H 27 min 26 sec No signal at the moment
#   m1 ... 8 H 28 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 76.0   Aroon down :  24.0   RSI :  21.88131845560937     8 H 28 min 27 sec No signal at the moment
#   m1 ... 8 H 29 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 72.0   Aroon down :  20.0   RSI :  12.85856998969722     8 H 29 min 26 sec No signal at the moment
#   m1 ... 8 H 30 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 68.0   Aroon down :  16.0   RSI :  74.91680415946261     8 H 30 min 26 sec No signal at the moment
#   m1 ... 8 H 31 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 64.0   Aroon down :  12.0   RSI :  84.02063704684288     8 H 31 min 26 sec No signal at the moment
#   m1 ... 8 H 32 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  8.0   RSI :  98.1379348133003     8 H 32 min 26 sec No signal at the moment
#   m1 ... 8 H 33 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  4.0   RSI :  99.20240660117429     8 H 33 min 27 sec No signal at the moment
#   m1 ... 8 H 34 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 96.0   Aroon down :  0.0   RSI :  47.35165822011765     8 H 34 min 27 sec No signal at the moment
#   m1 ... 8 H 35 min 31 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 92.0   Aroon down :  0.0   RSI :  61.96810670083318     8 H 35 min 32 sec No signal at the moment
#   m1 ... 8 H 36 min 25 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 88.0   Aroon down :  16.0   RSI :  21.793480779791622     8 H 36 min 27 sec No signal at the moment
#   m1 ... 8 H 37 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 84.0   Aroon down :  12.0   RSI :  11.821245884925778     8 H 37 min 26 sec No signal at the moment
#   m1 ... 8 H 38 min 25 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 80.0   Aroon down :  100.0   RSI :  3.072722240489222     8 H 38 min 26 sec No signal at the moment
#   m1 ... 8 H 39 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 76.0   Aroon down :  96.0   RSI :  38.36775398049774     8 H 39 min 26 sec No signal at the moment
#   m1 ... 8 H 40 min 25 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 72.0   Aroon down :  100.0   RSI :  22.64030771408226     8 H 40 min 27 sec No signal at the moment
#   m1 ... 8 H 41 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 68.0   Aroon down :  100.0   RSI :  13.208722090997988     8 H 41 min 26 sec No signal at the moment
#   m1 ... 8 H 42 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 64.0   Aroon down :  100.0   RSI :  12.262713111813714     8 H 42 min 27 sec No signal at the moment
#   m1 ... 8 H 43 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 60.0   Aroon down :  96.0   RSI :  74.45844732753814     8 H 43 min 27 sec No signal at the moment
#   m1 ... 8 H 44 min 27 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 56.0   Aroon down :  92.0   RSI :  50.75452339603304     8 H 44 min 27 sec No signal at the moment
#   m1 ... 8 H 45 min 27 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 52.0   Aroon down :  88.0   RSI :  73.2558680077361     8 H 45 min 27 sec No signal at the moment
#   m1 ... 8 H 46 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 48.0   Aroon down :  84.0   RSI :  36.85014817126869     8 H 46 min 26 sec No signal at the moment
#   m1 ... 8 H 47 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 44.0   Aroon down :  80.0   RSI :  73.31686798908191     8 H 47 min 27 sec No signal at the moment
#   m1 ... 8 H 48 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 40.0   Aroon down :  76.0   RSI :  75.85222334520635     8 H 48 min 27 sec No signal at the moment
#   m1 ... 8 H 49 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 36.0   Aroon down :  72.0   RSI :  20.508986172436163     8 H 49 min 26 sec No signal at the moment
#   m1 ... 8 H 50 min 25 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 32.0   Aroon down :  68.0   RSI :  17.01247210728599     8 H 50 min 26 sec No signal at the moment
#   m1 ... 8 H 51 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 28.0   Aroon down :  64.0   RSI :  11.787481318020358     8 H 51 min 26 sec No signal at the moment
#   m1 ... 8 H 52 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 24.0   Aroon down :  100.0   RSI :  5.403983362331795     8 H 52 min 27 sec No signal at the moment
#   m1 ... 8 H 53 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 20.0   Aroon down :  100.0   RSI :  1.1648502191830965     8 H 53 min 26 sec No signal at the moment
#   m1 ... 8 H 54 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 16.0   Aroon down :  100.0   RSI :  0.9372753095628575     8 H 54 min 27 sec No signal at the moment
#   m1 ... 8 H 55 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 12.0   Aroon down :  100.0   RSI :  0.7124345144032327     8 H 55 min 27 sec No signal at the moment
#   m1 ... 8 H 56 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 8.0   Aroon down :  96.0   RSI :  68.68307490738651     8 H 56 min 26 sec No signal at the moment
#   m1 ... 8 H 57 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  100.0   RSI :  10.51113127343291     8 H 57 min 26 sec No signal at the moment
#   m1 ... 8 H 58 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  100.0   RSI :  6.5697391593477015     8 H 58 min 26 sec Trying Long at : 12592.645835316944
# Actualisation des tables
# Side B pnl :  -24.30000000000291 Trade_ID :  154418166 Open_Rate 2992.65 Amount 30
# Side B pnl :  -0.6599999999998545 Trade_ID :  154419021 Open_Rate 12583.51 Amount 30
# Résumé :
#  Open date :  None
# Open Rate :  12583.51
# Amount :  30
# pnl :  -0.6599999999998545
# Order :  154419021
#
# Go Long!
#   m1 ... 8 H 59 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  100.0   RSI :  3.574054701618178     8 H 59 min 26 sec No signal at the moment
#   m1 ... 9 H 0 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  96.0   RSI :  3.574055068002844     9 H 0 min 26 sec No signal at the moment
#   m1 ... 9 H 1 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  92.0   RSI :  63.363118189544764     9 H 1 min 27 sec No signal at the moment
#   m1 ... 9 H 2 min 27 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  88.0   RSI :  83.77707453976487     9 H 2 min 28 sec No signal at the moment
#   m1 ... 9 H 3 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  84.0   RSI :  79.90550127065465     9 H 3 min 26 sec No signal at the moment
#   m1 ... 9 H 4 min 25 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  80.0   RSI :  85.32929563143392     9 H 4 min 27 sec No signal at the moment
#   m1 ... 9 H 5 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 32.0   Aroon down :  76.0   RSI :  40.1617020766171     9 H 5 min 27 sec No signal at the moment
#   m1 ... 9 H 6 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 28.0   Aroon down :  72.0   RSI :  70.93345318633986     9 H 6 min 26 sec No signal at the moment
#   m1 ... 9 H 7 min 27 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 24.0   Aroon down :  68.0   RSI :  38.05570694952821     9 H 7 min 27 sec No signal at the moment
#   m1 ... 9 H 8 min 25 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 20.0   Aroon down :  64.0   RSI :  85.01644353685718     9 H 8 min 27 sec No signal at the moment
#   m1 ... 9 H 9 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 16.0   Aroon down :  60.0   RSI :  87.65314822980623     9 H 9 min 26 sec No signal at the moment
#   m1 ... 9 H 10 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 12.0   Aroon down :  56.0   RSI :  92.75373975893547     9 H 10 min 26 sec No signal at the moment
#   m1 ... 9 H 11 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 8.0   Aroon down :  52.0   RSI :  36.09357804210588     9 H 11 min 27 sec No signal at the moment
#   m1 ... 9 H 12 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  48.0   RSI :  13.84198365804932     9 H 12 min 27 sec No signal at the moment
#   m1 ... 9 H 13 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  44.0   RSI :  11.561200310532033     9 H 13 min 26 sec No signal at the moment
#   m1 ... 9 H 14 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  40.0   RSI :  61.15977457382687     9 H 14 min 26 sec No signal at the moment
#   m1 ... 9 H 15 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  36.0   RSI :  86.17347028900161     9 H 15 min 26 sec No signal at the moment
#   m1 ... 9 H 16 min 27 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  32.0   RSI :  53.25087322928874     9 H 16 min 27 sec No signal at the moment
#   m1 ... 9 H 17 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  28.0   RSI :  86.82010026245837     9 H 17 min 27 sec No signal at the moment
#   m1 ... 9 H 18 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 12.0   Aroon down :  24.0   RSI :  88.47522385344871     9 H 18 min 26 sec No signal at the moment
#   m1 ... 9 H 19 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  20.0   RSI :  96.56449890551903     9 H 19 min 26 sec No signal at the moment
#   m1 ... 9 H 20 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  16.0   RSI :  97.25749015350449     9 H 20 min 26 sec No signal at the moment
#   m1 ... 9 H 21 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  12.0   RSI :  99.20171873882907     9 H 21 min 26 sec No signal at the moment
#   m1 ... 9 H 22 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  8.0   RSI :  99.56906697400308     9 H 22 min 26 sec No signal at the moment
#   m1 ... 9 H 23 min 27 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  4.0   RSI :  99.83403444584458     9 H 23 min 29 sec No signal at the moment
#   m1 ... 9 H 24 min 26 sec   - pnl :  -0.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  0.0   RSI :  99.84093818860003     9 H 24 min 26 sec   Close Short avec un pnl de -0.6599999999998545
# Résumé :
#  Open date :  None
# Open Rate :  12583.51
# Amount :  30
#
#   m1 ... 9 H 25 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 96.0   Aroon down :  0.0   RSI :  35.625139609465414     9 H 25 min 27 sec No signal at the moment
#   m1 ... 9 H 26 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 92.0   Aroon down :  0.0   RSI :  22.079475379504622     9 H 26 min 26 sec No signal at the moment
#   m1 ... 9 H 27 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 88.0   Aroon down :  20.0   RSI :  41.99888344320992     9 H 27 min 26 sec No signal at the moment
#   m1 ... 9 H 28 min 29 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 84.0   Aroon down :  16.0   RSI :  41.99888387745808     9 H 28 min 29 sec No signal at the moment
#   m1 ... 9 H 29 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 80.0   Aroon down :  12.0   RSI :  80.95264016303027     9 H 29 min 26 sec No signal at the moment
#   m1 ... 9 H 30 min 28 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  8.0   RSI :  96.02331887698485     9 H 30 min 28 sec No signal at the moment
#   m1 ... 9 H 31 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 96.0   Aroon down :  4.0   RSI :  44.01056286983561     9 H 31 min 27 sec No signal at the moment
#   m1 ... 9 H 32 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 92.0   Aroon down :  0.0   RSI :  57.329925936674286     9 H 32 min 26 sec No signal at the moment
#   m1 ... 9 H 33 min 29 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 88.0   Aroon down :  20.0   RSI :  41.19062149148375     9 H 33 min 30 sec No signal at the moment
#   m1 ... 9 H 34 min 27 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 84.0   Aroon down :  16.0   RSI :  75.57325168125757     9 H 34 min 27 sec No signal at the moment
#   m1 ... 9 H 35 min 27 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 80.0   Aroon down :  12.0   RSI :  13.233921675783389     9 H 35 min 27 sec No signal at the moment
#   m1 ... 9 H 36 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 76.0   Aroon down :  8.0   RSI :  6.825246452467798     9 H 36 min 26 sec No signal at the moment
#   m1 ... 9 H 37 min 28 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 72.0   Aroon down :  4.0   RSI :  6.825246196931335     9 H 37 min 29 sec No signal at the moment
#   m1 ... 9 H 38 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 68.0   Aroon down :  0.0   RSI :  7.384128241039411     9 H 38 min 26 sec No signal at the moment
#   m1 ... 9 H 39 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 64.0   Aroon down :  0.0   RSI :  2.7435033086335703     9 H 39 min 27 sec No signal at the moment
#   m1 ... 9 H 40 min 32 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 60.0   Aroon down :  4.0   RSI :  28.3071993503128     9 H 40 min 32 sec No signal at the moment
#   m1 ... 9 H 41 min 27 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 56.0   Aroon down :  0.0   RSI :  59.012013572473954     9 H 41 min 27 sec No signal at the moment
#   m1 ... 9 H 42 min 26 sec  - No positiondf.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 52.0   Aroon down :  0.0   RSI :  34.58495645631708     9 H 42 min 27 sec No signal at the moment
#   m1 ... 9 H 42 min 48 sec  - No position
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-88b4794862a2> in <module>
#     125     tmps1=time.time()
#     126
# --> 127     history = fx.get_history(ticker, period,quotes_count=1)
#     128     last = pd.DataFrame({'Date':history['Date'],'Open':history['BidOpen'],'High':history['BidHigh'],'Low':history['BidLow'],'Close':history['BidClose']})
#     129
#
# ~\Anaconda3\envs\golem\lib\site-packages\forexconnect\ForexConnect.py in get_history(self, instrument, timeframe, date_from, date_to, quotes_count, candle_open_price_mode)
#     456         com.candle_open_price_mode = candle_open_price_mode
#     457
# --> 458         reader = com.get_history(instrument, timeframe, date_from, date_to, quotes_count)
#     459         if timeframe.unit == fxcorepy.O2GTimeFrameUnit.TICK:
#     460             result = np.zeros(len(reader), np.dtype([('Date', "M8[ns]"), ('Bid', "f8"), ("Ask", "f8")]))
#
# KeyboardInterrupt:

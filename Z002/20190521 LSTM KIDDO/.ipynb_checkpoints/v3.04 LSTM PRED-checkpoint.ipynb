# %%
___Author___='LumberJack Jyss'

# %%
print('Global Optimized LumberJack Equities Method\n°OoO_FOREX_Oo0°\nLumberJack Jyss 5779(c)')
# Out:
# Global Optimized LumberJack Equities Method
# °OoO_FOREX_Oo0°
# LumberJack Jyss 5779(c)

# %%
print('Importation des librairies...')
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
import os
from sklearn.preprocessing import MinMaxScaler
import math
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Input, Dense, GRU, Embedding
from tensorflow.python.keras.optimizers import RMSprop
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, ReduceLROnPlateau
print('Librairies importées')
# Out:
# Importation des librairies...
# Librairies importées

# %%
df = pd.read_csv('1_MIN_ALL.txt', index_col=0, sep = ' ')
df = df.tail(1088480)
df = df.drop('Per',axis = 1)
df['Vol'] = df['Vol'].str.replace("'", '')
df['DateTime'] = df['Date']*1000000 + df['Time']
df['DateTime'] = pd.to_datetime(df['DateTime'], format="%Y%m%d%H%M%S")
df = df.reset_index(drop = True)
df = df.set_index('DateTime')
df = df.drop(['Date','Time'],axis = 1)
df = df
df = df.head(300000)
df.head()
# Out:
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                         Open     High     Low    Close   Vol
# DateTime
# 2014-10-31 15:21:00  1.25678  1.25680  1.2563  1.25664  1085
# 2014-10-31 15:22:00  1.25664  1.25691  1.2563  1.25652  1733
# 2014-10-31 15:23:00  1.25647  1.25656  1.2559  1.25647  1260
# 2014-10-31 15:24:00  1.25646  1.25649  1.2558  1.25615  1419
# 2014-10-31 15:25:00  1.25615  1.25633  1.2558  1.25633  1642

# %%
#df['DayOfYear'] = df.index.dayofyear
df['HourOfDay'] = df.index.hour
#df['MonthOfYear'] = df.index.month

# %%
df = df.fillna(method='ffill')

# %%
df[['Open','High','Low','Close']] = np.exp(10*df[['Open','High','Low','Close']]) #See if we can help the model out

# %%
df.describe()
# Out:
#                 Open           High            Low          Close  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean   105822.631311  106100.451747  105511.650284  105821.610468
# std     72894.261827   73356.436313   72707.156821   72895.699135
# min     34703.644873   34787.033648   34596.230153   34630.843687
# 25%     57837.926078   57930.540832   57641.611054   57837.926078
# 50%     73894.967069   74028.097791   73644.150810   73894.967069
# 75%    113348.792262  113641.041405  112983.831117  113345.958472
# max    442413.392009  442413.392009  290105.520624  442413.392009
#
#            HourOfDay
# count  300000.000000
# mean       11.676247
# std         7.036441
# min         0.000000
# 25%         6.000000
# 50%        12.000000
# 75%        18.000000
# max        23.000000

# %%
df.values.shape
# Out:
# (300000, 6)

# %%
target_names = ['Close']

# %%
shift_mn = 1
shift_steps = shift_mn * 1  # Number of mn.

# %%
df_targets = df[target_names].shift(-shift_steps)

# %%
x_data = df.values[0:-shift_steps]
x_data = x_data.astype('float32')

# %%
print(type(x_data))
print("Shape:", x_data.shape)
# Out:
# <class 'numpy.ndarray'>
# Shape: (299999, 6)

# %%
y_data = df_targets.values[:-shift_steps]
y_data = y_data.astype('float32')

# %%
#nb of data rows in the dataset
num_data = len(x_data)
num_data
# Out:
# 299999

# %%
train_split = 0.9

# %%
num_train = int(train_split * num_data)
num_train
# Out:
# 269999

# %%
#These are the input-signals for the training- and test-sets
x_train = x_data[0:num_train]
x_test = x_data[num_train:]
len(x_train) + len(x_test)
# Out:
# 299999

# %%
#These are the output-signals for the training- and test-sets
y_train = y_data[0:num_train]
y_test = y_data[num_train:]
len(y_train) + len(y_test)
# Out:
# 299999

# %%
#number of input-signals
num_x_signals = x_data.shape[1]
num_x_signals
# Out:
# 6

# %%
#number of output-signals
num_y_signals = y_data.shape[1]
num_y_signals
# Out:
# 1

# %%
# Scaling data (0-1)
print("Min:", np.min(x_train))
print("Max:", np.max(x_train))
# Out:
# Min: 0.0
# Max: 442413.4

# %%
x_scaler = MinMaxScaler()

# %%
x_train_scaled = x_scaler.fit_transform(x_train)

# %%
print("Min:", np.min(x_train_scaled))
print("Max:", np.max(x_train_scaled))
# Out:
# Min: 0.0
# Max: 1.0

# %%
x_test_scaled = x_scaler.transform(x_test)

# %%
y_scaler = MinMaxScaler()
y_train_scaled = y_scaler.fit_transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
print(x_train_scaled.shape)
print(y_train_scaled.shape)
# Out:
# (269999, 6)
# (269999, 1)

# %%
def batch_generator(batch_size, sequence_length):
    """
    Generator function for creating random batches of training-data.
    """

    # Infinite loop.
    while True:
        # Allocate a new array for the batch of input-signals.
        x_shape = (batch_size, sequence_length, num_x_signals)
        x_batch = np.zeros(shape=x_shape, dtype=np.float16)

        # Allocate a new array for the batch of output-signals.
        y_shape = (batch_size, sequence_length, num_y_signals)
        y_batch = np.zeros(shape=y_shape, dtype=np.float16)

        # Fill the batch with random sequences of data.
        for i in range(batch_size):
            # Get a random start-index.
            # This points somewhere into the training-data.
            idx = np.random.randint(num_train - sequence_length)
            
            # Copy the sequences of data starting at this index.
            x_batch[i] = x_train_scaled[idx:idx+sequence_length]
            y_batch[i] = y_train_scaled[idx:idx+sequence_length]
        
        yield (x_batch, y_batch)

# %%
batch_size = 64

# %%
# We adjust the length to be  interesting for the model to work on it but not to heavy to crush our computer
sequence_length = 60 * 24 * 7
sequence_length
# Out:
# 10080

# %%
generator = batch_generator(batch_size=batch_size,
                            sequence_length=sequence_length)

# %%
x_batch, y_batch = next(generator)

# %%
print(x_batch.shape)
print(y_batch.shape)
# Out:
# (64, 10080, 6)
# (64, 10080, 1)

# %%
#Lets plot it 

batch = 0   # First sequence in the batch.
signal = 0  # First signal from the input-signals.
seq = x_batch[batch, :, signal]
plt.figure(figsize=(16,6),dpi=200)
plt.plot(seq,color='purple')

# %%
#plot of the batch we want to predict
seq = y_batch[batch, :, signal]
plt.figure(figsize=(16,6),dpi=200)
plt.plot(seq,color='purple')

# %%
validation_data = (np.expand_dims(x_test_scaled, axis=0),
                   np.expand_dims(y_test_scaled, axis=0))

# %%
model = Sequential()

# %%
# The GRU outputs a batch of sequences of 512 values. We want to predict 1 output-signals, 
# so we add a fully-connected (or dense) layer which maps 512 values down to only 1 values.
model.add(Dense(num_y_signals, activation='sigmoid'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0521 00:38:11.686821 4497700288 deprecation.py:506] From /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
if False:
    from tensorflow.python.keras.initializers import RandomUniform

    # Maybe use lower init-ranges.
    init = RandomUniform(minval=-0.05, maxval=0.05)

    model.add(Dense(num_y_signals,
                    activation='linear',
                    kernel_initializer=init))

# %%
warmup_steps = 50

# %%
def loss_mse_warmup(y_true, y_pred):
    """
    Calculate the Mean Squared Error between y_true and y_pred,
    but ignore the beginning "warmup" part of the sequences.
    
    y_true is the desired output.
    y_pred is the model's output.
    """

    # The shape of both input tensors are:
    # [batch_size, sequence_length, num_y_signals].

    # Ignore the "warmup" parts of the sequences
    # by taking slices of the tensors.
    y_true_slice = y_true[:, warmup_steps:, :]
    y_pred_slice = y_pred[:, warmup_steps:, :]

    # These sliced tensors both have this shape:
    # [batch_size, sequence_length - warmup_steps, num_y_signals]

    # Calculate the MSE loss for each value in these tensors.
    # This outputs a 3-rank tensor of the same shape.
    loss = tf.losses.mean_squared_error(labels=y_true_slice,
                                        predictions=y_pred_slice)

    # Keras may reduce this across the first axis (the batch)
    # but the semantics are unclear, so to be sure we use
    # the loss across the entire tensor, we reduce it to a
    # single scalar with the mean function.
    loss_mean = tf.reduce_mean(loss)

    return loss_mean

# %%
optimizer = RMSprop(lr=1e-3)

# %%
len(x_train_scaled),len(y_train_scaled)
# Out:
# (269999, 269999)

# %%
epochs_custom = 1

# %%
model.build(x_train_scaled.shape)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                multiple                  7
# =================================================================
# Total params: 7
# Trainable params: 7
# Non-trainable params: 0
# _________________________________________________________________

# %%
#This is the callback for writing checkpoints during training.
path_checkpoint = '23_checkpoint.keras'
callback_checkpoint = ModelCheckpoint(filepath=path_checkpoint,
                                      monitor='val_loss',
                                      verbose=1,
                                      save_weights_only=True,
                                      save_best_only=True)

# %%
#stopping the model when performance worsens on the valid set
callback_early_stopping = EarlyStopping(monitor='val_loss',
                                        patience=3, verbose=1)

# %%
#This is the callback for writing the TensorBoard log during training.
callback_tensorboard = TensorBoard(log_dir='./23_logs/',
                                   histogram_freq=0,
                                   write_graph=False)

# %%
#This callback reduces the learning-rate for the optimizer if the validation-loss has not improved since 
# the last epoch (as indicated by patience=0). The learning-rate will be reduced by multiplying it with 
# the given factor. We set a start learning-rate of 1e-3 above, so multiplying it by 0.1 gives a learning-rate of 1e-4. 
# We don't want the learning-rate to go any lower than this.

callback_reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                                       factor=0.1,
                                       min_lr=1e-4,
                                       patience=0,
                                       verbose=1)

# %%
callbacks = [callback_early_stopping,
             callback_checkpoint,
             callback_tensorboard,
             callback_reduce_lr]

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
epochs = 3000
steps_per_epoch = 100

# %%
# %%time
model.fit_generator(generator=generator,
                    epochs=epochs,
                    steps_per_epoch=steps_per_epoch, #should be 100 ##################
                    validation_data=validation_data,
                    callbacks=callbacks,shuffle=False)
# Out:
# Epoch 1/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0095
# Epoch 00001: val_loss improved from 0.01057 to 0.00958, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0095 - val_loss: 0.0096
# Epoch 2/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0089
# Epoch 00002: val_loss improved from 0.00958 to 0.00884, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0089 - val_loss: 0.0088
# Epoch 3/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0083
# Epoch 00003: val_loss improved from 0.00884 to 0.00811, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0083 - val_loss: 0.0081
# Epoch 4/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0078
# Epoch 00004: val_loss improved from 0.00811 to 0.00744, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0078 - val_loss: 0.0074
# Epoch 5/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0072
# Epoch 00005: val_loss improved from 0.00744 to 0.00684, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0072 - val_loss: 0.0068
# Epoch 6/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 00006: val_loss improved from 0.00684 to 0.00634, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0068 - val_loss: 0.0063
# Epoch 7/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0064
# Epoch 00007: val_loss improved from 0.00634 to 0.00585, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 8/3000
#  98/100 [============================>.] - ETA: 0s - loss: 0.0059
# Epoch 00008: val_loss improved from 0.00585 to 0.00538, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0059 - val_loss: 0.0054
# Epoch 9/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0056
# Epoch 00009: val_loss improved from 0.00538 to 0.00497, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0056 - val_loss: 0.0050
# Epoch 10/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0052
# Epoch 00010: val_loss improved from 0.00497 to 0.00461, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0052 - val_loss: 0.0046
# Epoch 11/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0049
# Epoch 00011: val_loss improved from 0.00461 to 0.00427, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 3s 31ms/step - loss: 0.0049 - val_loss: 0.0043
# Epoch 12/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0046
# Epoch 00012: val_loss improved from 0.00427 to 0.00397, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0046 - val_loss: 0.0040
# Epoch 13/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0043
# Epoch 00013: val_loss improved from 0.00397 to 0.00370, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0043 - val_loss: 0.0037
# Epoch 14/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0040
# Epoch 00014: val_loss improved from 0.00370 to 0.00345, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 3s 34ms/step - loss: 0.0040 - val_loss: 0.0034
# Epoch 15/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0037
# Epoch 00015: val_loss improved from 0.00345 to 0.00320, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 3s 33ms/step - loss: 0.0037 - val_loss: 0.0032
# Epoch 16/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0035
# Epoch 00016: val_loss improved from 0.00320 to 0.00299, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 17/3000
#  98/100 [============================>.] - ETA: 0s - loss: 0.0033
# Epoch 00017: val_loss improved from 0.00299 to 0.00279, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 18/3000
#  98/100 [============================>.] - ETA: 0s - loss: 0.0031
# Epoch 00018: val_loss improved from 0.00279 to 0.00261, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 4s 40ms/step - loss: 0.0031 - val_loss: 0.0026
# Epoch 19/3000
#  98/100 [============================>.] - ETA: 0s - loss: 0.0029
# Epoch 00019: val_loss improved from 0.00261 to 0.00244, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0029 - val_loss: 0.0024
# Epoch 20/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0027
# Epoch 00020: val_loss improved from 0.00244 to 0.00228, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 3s 35ms/step - loss: 0.0027 - val_loss: 0.0023
# Epoch 21/3000
#  98/100 [============================>.] - ETA: 0s - loss: 0.0025
# Epoch 00021: val_loss improved from 0.00228 to 0.00214, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 4s 38ms/step - loss: 0.0025 - val_loss: 0.0021
# Epoch 22/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0023
# Epoch 00022: val_loss improved from 0.00214 to 0.00201, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 4s 35ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 23/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0022
# Epoch 00023: val_loss improved from 0.00201 to 0.00189, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 24/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 00024: val_loss improved from 0.00189 to 0.00176, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 4s 41ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 25/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 00025: val_loss improved from 0.00176 to 0.00165, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 5s 49ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 26/3000
#  98/100 [============================>.] - ETA: 0s - loss: 0.0018
# Epoch 00026: val_loss improved from 0.00165 to 0.00156, saving model to 23_checkpoint.keras
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 100/100 [==============================] - 4s 39ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 27/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 00027: val_loss improved from 0.00156 to 0.00155, saving model to 23_checkpoint.keras
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001.
# 100/100 [==============================] - 4s 37ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 28/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 00028: val_loss improved from 0.00155 to 0.00154, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 4s 36ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 29/3000
#  98/100 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 00029: val_loss improved from 0.00154 to 0.00153, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 5s 45ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 30/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 00030: val_loss improved from 0.00153 to 0.00152, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 5s 51ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 31/3000
#  98/100 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 00031: val_loss improved from 0.00152 to 0.00150, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 6s 56ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 32/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 00032: val_loss improved from 0.00150 to 0.00149, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 5s 50ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 33/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 00033: val_loss improved from 0.00149 to 0.00148, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 5s 52ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 34/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 00034: val_loss improved from 0.00148 to 0.00147, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 35/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 00035: val_loss improved from 0.00147 to 0.00146, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 5s 54ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 36/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 00036: val_loss improved from 0.00146 to 0.00144, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 6s 63ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 37/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 00037: val_loss improved from 0.00144 to 0.00143, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 6s 60ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 38/3000
#  98/100 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 00038: val_loss improved from 0.00143 to 0.00141, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 6s 57ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 39/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 00039: val_loss improved from 0.00141 to 0.00140, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 5s 52ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 40/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 00040: val_loss improved from 0.00140 to 0.00139, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 5s 55ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 41/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0016
# Epoch 00041: val_loss improved from 0.00139 to 0.00138, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 6s 59ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 42/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 00042: val_loss improved from 0.00138 to 0.00136, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 6s 61ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 43/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 00043: val_loss improved from 0.00136 to 0.00134, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 6s 58ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 44/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 00044: val_loss improved from 0.00134 to 0.00133, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 45/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 00045: val_loss improved from 0.00133 to 0.00131, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 46/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 00046: val_loss improved from 0.00131 to 0.00130, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 97ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 47/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 00047: val_loss improved from 0.00130 to 0.00128, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 48/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 00048: val_loss improved from 0.00128 to 0.00127, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 11s 109ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 49/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 00049: val_loss improved from 0.00127 to 0.00125, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 11s 110ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 50/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 00050: val_loss improved from 0.00125 to 0.00123, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 100ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 51/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 00051: val_loss improved from 0.00123 to 0.00122, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 98ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 52/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 00052: val_loss improved from 0.00122 to 0.00120, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 95ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 53/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 00053: val_loss improved from 0.00120 to 0.00119, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 9s 94ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 54/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 00054: val_loss improved from 0.00119 to 0.00117, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 96ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 55/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 00055: val_loss improved from 0.00117 to 0.00116, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 11s 106ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 56/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 00056: val_loss improved from 0.00116 to 0.00114, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 97ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 57/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 00057: val_loss improved from 0.00114 to 0.00112, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 96ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 58/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0013
# Epoch 00058: val_loss improved from 0.00112 to 0.00110, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 96ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 59/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 00059: val_loss improved from 0.00110 to 0.00109, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 9s 95ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 60/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 00060: val_loss improved from 0.00109 to 0.00107, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 97ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 61/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 00061: val_loss improved from 0.00107 to 0.00106, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 62/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 00062: val_loss improved from 0.00106 to 0.00104, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 104ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 63/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 00063: val_loss improved from 0.00104 to 0.00103, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 64/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0012
# Epoch 00064: val_loss improved from 0.00103 to 0.00101, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 100ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 65/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 00065: val_loss improved from 0.00101 to 0.00100, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 9s 95ms/step - loss: 0.0011 - val_loss: 9.9769e-04
# Epoch 66/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 00066: val_loss improved from 0.00100 to 0.00098, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 97ms/step - loss: 0.0011 - val_loss: 9.7899e-04
# Epoch 67/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 00067: val_loss improved from 0.00098 to 0.00096, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 12s 119ms/step - loss: 0.0011 - val_loss: 9.6283e-04
# Epoch 68/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 00068: val_loss improved from 0.00096 to 0.00095, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 99ms/step - loss: 0.0011 - val_loss: 9.4675e-04
# Epoch 69/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 00069: val_loss improved from 0.00095 to 0.00093, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0011 - val_loss: 9.3300e-04
# Epoch 70/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 00070: val_loss improved from 0.00093 to 0.00092, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 101ms/step - loss: 0.0011 - val_loss: 9.1653e-04
# Epoch 71/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 00071: val_loss improved from 0.00092 to 0.00090, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 100ms/step - loss: 0.0011 - val_loss: 9.0279e-04
# Epoch 72/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 00072: val_loss improved from 0.00090 to 0.00089, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 100ms/step - loss: 0.0011 - val_loss: 8.8715e-04
# Epoch 73/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0011
# Epoch 00073: val_loss improved from 0.00089 to 0.00087, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 102ms/step - loss: 0.0011 - val_loss: 8.7261e-04
# Epoch 74/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 00074: val_loss improved from 0.00087 to 0.00086, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 11s 108ms/step - loss: 0.0010 - val_loss: 8.5561e-04
# Epoch 75/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 00075: val_loss improved from 0.00086 to 0.00084, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 11s 107ms/step - loss: 0.0010 - val_loss: 8.4236e-04
# Epoch 76/3000
#  99/100 [============================>.] - ETA: 0s - loss: 0.0010
# Epoch 00076: val_loss improved from 0.00084 to 0.00083, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 100ms/step - loss: 0.0010 - val_loss: 8.3424e-04
# Epoch 77/3000
#  99/100 [============================>.] - ETA: 0s - loss: 9.9537e-04
# Epoch 00077: val_loss improved from 0.00083 to 0.00082, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 98ms/step - loss: 9.9412e-04 - val_loss: 8.1524e-04
# Epoch 78/3000
#  99/100 [============================>.] - ETA: 0s - loss: 9.7924e-04
# Epoch 00078: val_loss improved from 0.00082 to 0.00081, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 11s 112ms/step - loss: 9.7973e-04 - val_loss: 8.0517e-04
# Epoch 79/3000
#  99/100 [============================>.] - ETA: 0s - loss: 9.9226e-04
# Epoch 00079: val_loss improved from 0.00081 to 0.00080, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 12s 123ms/step - loss: 9.9160e-04 - val_loss: 7.9626e-04
# Epoch 80/3000
#  99/100 [============================>.] - ETA: 0s - loss: 9.6318e-04
# Epoch 00080: val_loss improved from 0.00080 to 0.00078, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 11s 109ms/step - loss: 9.6336e-04 - val_loss: 7.8130e-04
# Epoch 81/3000
#  99/100 [============================>.] - ETA: 0s - loss: 9.4184e-04
# Epoch 00081: val_loss improved from 0.00078 to 0.00077, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 98ms/step - loss: 9.4208e-04 - val_loss: 7.7115e-04
# Epoch 82/3000
#  99/100 [============================>.] - ETA: 0s - loss: 9.5042e-04
# Epoch 00082: val_loss improved from 0.00077 to 0.00076, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 9s 92ms/step - loss: 9.5068e-04 - val_loss: 7.5671e-04
# Epoch 83/3000
#  99/100 [============================>.] - ETA: 0s - loss: 9.4662e-04
# Epoch 00083: val_loss improved from 0.00076 to 0.00075, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 101ms/step - loss: 9.4704e-04 - val_loss: 7.4635e-04
# Epoch 84/3000
#  99/100 [============================>.] - ETA: 0s - loss: 9.1338e-04
# Epoch 00084: val_loss improved from 0.00075 to 0.00073, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 101ms/step - loss: 9.1390e-04 - val_loss: 7.3448e-04
# Epoch 85/3000
#  99/100 [============================>.] - ETA: 0s - loss: 9.1486e-04
# Epoch 00085: val_loss improved from 0.00073 to 0.00072, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 103ms/step - loss: 9.1617e-04 - val_loss: 7.2062e-04
# Epoch 86/3000
#  99/100 [============================>.] - ETA: 0s - loss: 9.1779e-04
# Epoch 00086: val_loss improved from 0.00072 to 0.00071, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 11s 112ms/step - loss: 9.1936e-04 - val_loss: 7.0650e-04
# Epoch 87/3000
#  99/100 [============================>.] - ETA: 0s - loss: 9.0506e-04
# Epoch 00087: val_loss improved from 0.00071 to 0.00070, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 11s 109ms/step - loss: 9.0596e-04 - val_loss: 6.9857e-04
# Epoch 88/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.8408e-04
# Epoch 00088: val_loss improved from 0.00070 to 0.00069, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 11s 108ms/step - loss: 8.8394e-04 - val_loss: 6.9332e-04
# Epoch 89/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.8347e-04
# Epoch 00089: val_loss improved from 0.00069 to 0.00068, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 11s 108ms/step - loss: 8.8357e-04 - val_loss: 6.8026e-04
# Epoch 90/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.8222e-04
# Epoch 00090: val_loss improved from 0.00068 to 0.00067, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 100ms/step - loss: 8.8303e-04 - val_loss: 6.7144e-04
# Epoch 91/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.6509e-04
# Epoch 00091: val_loss improved from 0.00067 to 0.00066, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 99ms/step - loss: 8.6495e-04 - val_loss: 6.6120e-04
# Epoch 92/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.5941e-04
# Epoch 00092: val_loss improved from 0.00066 to 0.00066, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 11s 112ms/step - loss: 8.5949e-04 - val_loss: 6.5522e-04
# Epoch 93/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.4450e-04
# Epoch 00093: val_loss improved from 0.00066 to 0.00065, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 103ms/step - loss: 8.4426e-04 - val_loss: 6.4805e-04
# Epoch 94/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.5188e-04
# Epoch 00094: val_loss improved from 0.00065 to 0.00063, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 97ms/step - loss: 8.5214e-04 - val_loss: 6.3337e-04
# Epoch 95/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.4959e-04
# Epoch 00095: val_loss improved from 0.00063 to 0.00063, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 103ms/step - loss: 8.4896e-04 - val_loss: 6.2871e-04
# Epoch 96/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.4718e-04
# Epoch 00096: val_loss improved from 0.00063 to 0.00061, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 11s 110ms/step - loss: 8.4767e-04 - val_loss: 6.1080e-04
# Epoch 97/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.2481e-04
# Epoch 00097: val_loss improved from 0.00061 to 0.00061, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 11s 112ms/step - loss: 8.2645e-04 - val_loss: 6.0918e-04
# Epoch 98/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.2524e-04
# Epoch 00098: val_loss improved from 0.00061 to 0.00060, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 12s 122ms/step - loss: 8.2538e-04 - val_loss: 5.9729e-04
# Epoch 99/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.1952e-04
# Epoch 00099: val_loss improved from 0.00060 to 0.00059, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 104ms/step - loss: 8.1857e-04 - val_loss: 5.9317e-04
# Epoch 100/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.1985e-04
# Epoch 00100: val_loss improved from 0.00059 to 0.00058, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 102ms/step - loss: 8.2033e-04 - val_loss: 5.8500e-04
# Epoch 101/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.0129e-04
# Epoch 00101: val_loss improved from 0.00058 to 0.00058, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 105ms/step - loss: 8.0146e-04 - val_loss: 5.7933e-04
# Epoch 102/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.1455e-04
# Epoch 00102: val_loss improved from 0.00058 to 0.00057, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 103ms/step - loss: 8.1405e-04 - val_loss: 5.7068e-04
# Epoch 103/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.1021e-04
# Epoch 00103: val_loss improved from 0.00057 to 0.00056, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 103ms/step - loss: 8.0954e-04 - val_loss: 5.6307e-04
# Epoch 104/3000
#  99/100 [============================>.] - ETA: 0s - loss: 8.0096e-04
# Epoch 00104: val_loss improved from 0.00056 to 0.00055, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 12s 117ms/step - loss: 8.0133e-04 - val_loss: 5.5479e-04
# Epoch 105/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.9135e-04
# Epoch 00105: val_loss improved from 0.00055 to 0.00055, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 102ms/step - loss: 7.9048e-04 - val_loss: 5.5273e-04
# Epoch 106/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.8361e-04
# Epoch 00106: val_loss improved from 0.00055 to 0.00055, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 102ms/step - loss: 7.8417e-04 - val_loss: 5.4968e-04
# Epoch 107/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.9770e-04
# Epoch 00107: val_loss improved from 0.00055 to 0.00054, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 101ms/step - loss: 7.9843e-04 - val_loss: 5.4416e-04
# Epoch 108/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.8488e-04
# Epoch 00108: val_loss improved from 0.00054 to 0.00054, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 99ms/step - loss: 7.8451e-04 - val_loss: 5.3716e-04
# Epoch 109/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.8426e-04
# Epoch 00109: val_loss improved from 0.00054 to 0.00053, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 96ms/step - loss: 7.8538e-04 - val_loss: 5.2759e-04
# Epoch 110/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.7460e-04
# Epoch 00110: val_loss improved from 0.00053 to 0.00053, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 98ms/step - loss: 7.7528e-04 - val_loss: 5.2654e-04
# Epoch 111/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.8899e-04
# Epoch 00111: val_loss improved from 0.00053 to 0.00052, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 98ms/step - loss: 7.8949e-04 - val_loss: 5.2383e-04
# Epoch 112/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.7373e-04
# Epoch 00112: val_loss improved from 0.00052 to 0.00052, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 11s 114ms/step - loss: 7.7278e-04 - val_loss: 5.1686e-04
# Epoch 113/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.7754e-04
# Epoch 00113: val_loss improved from 0.00052 to 0.00051, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 99ms/step - loss: 7.7802e-04 - val_loss: 5.0603e-04
# Epoch 114/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.7466e-04
# Epoch 00114: val_loss improved from 0.00051 to 0.00050, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 95ms/step - loss: 7.7463e-04 - val_loss: 5.0254e-04
# Epoch 115/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.6548e-04
# Epoch 00115: val_loss improved from 0.00050 to 0.00050, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 98ms/step - loss: 7.6629e-04 - val_loss: 4.9793e-04
# Epoch 116/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.3876e-04
# Epoch 00116: val_loss improved from 0.00050 to 0.00050, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 96ms/step - loss: 7.3812e-04 - val_loss: 4.9642e-04
# Epoch 117/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.6646e-04
# Epoch 00117: val_loss improved from 0.00050 to 0.00049, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 97ms/step - loss: 7.6601e-04 - val_loss: 4.9133e-04
# Epoch 118/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.6781e-04
# Epoch 00118: val_loss improved from 0.00049 to 0.00048, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 96ms/step - loss: 7.6946e-04 - val_loss: 4.8260e-04
# Epoch 119/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.5962e-04
# Epoch 00119: val_loss did not improve from 0.00048
# 100/100 [==============================] - 10s 97ms/step - loss: 7.5799e-04 - val_loss: 4.8683e-04
# Epoch 120/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.5954e-04
# Epoch 00120: val_loss improved from 0.00048 to 0.00048, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 9s 91ms/step - loss: 7.5823e-04 - val_loss: 4.7675e-04
# Epoch 121/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.5602e-04
# Epoch 00121: val_loss improved from 0.00048 to 0.00048, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 95ms/step - loss: 7.5739e-04 - val_loss: 4.7604e-04
# Epoch 122/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.5197e-04
# Epoch 00122: val_loss improved from 0.00048 to 0.00047, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 101ms/step - loss: 7.5185e-04 - val_loss: 4.7069e-04
# Epoch 123/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.5041e-04
# Epoch 00123: val_loss did not improve from 0.00047
# 100/100 [==============================] - 10s 97ms/step - loss: 7.5007e-04 - val_loss: 4.7452e-04
# Epoch 124/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.6027e-04
# Epoch 00124: val_loss did not improve from 0.00047
# 100/100 [==============================] - 9s 92ms/step - loss: 7.5890e-04 - val_loss: 4.7294e-04
# Epoch 125/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.2573e-04
# Epoch 00125: val_loss improved from 0.00047 to 0.00046, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 9s 93ms/step - loss: 7.2496e-04 - val_loss: 4.6222e-04
# Epoch 126/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.4746e-04
# Epoch 00126: val_loss did not improve from 0.00046
# 100/100 [==============================] - 11s 109ms/step - loss: 7.4752e-04 - val_loss: 4.6364e-04
# Epoch 127/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.4644e-04
# Epoch 00127: val_loss did not improve from 0.00046
# 100/100 [==============================] - 10s 97ms/step - loss: 7.4502e-04 - val_loss: 4.6237e-04
# Epoch 128/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.3426e-04
# Epoch 00128: val_loss improved from 0.00046 to 0.00046, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 9s 94ms/step - loss: 7.3349e-04 - val_loss: 4.5954e-04
# Epoch 129/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.4954e-04
# Epoch 00129: val_loss improved from 0.00046 to 0.00045, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 96ms/step - loss: 7.4854e-04 - val_loss: 4.5265e-04
# Epoch 130/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.2923e-04
# Epoch 00130: val_loss improved from 0.00045 to 0.00045, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 98ms/step - loss: 7.2828e-04 - val_loss: 4.5153e-04
# Epoch 131/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.3316e-04
# Epoch 00131: val_loss improved from 0.00045 to 0.00045, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 12s 117ms/step - loss: 7.3401e-04 - val_loss: 4.4799e-04
# Epoch 132/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.3212e-04
# Epoch 00132: val_loss improved from 0.00045 to 0.00044, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 10s 104ms/step - loss: 7.3301e-04 - val_loss: 4.4397e-04
# Epoch 133/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.2951e-04
# Epoch 00133: val_loss improved from 0.00044 to 0.00044, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 9s 93ms/step - loss: 7.2842e-04 - val_loss: 4.4264e-04
# Epoch 134/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.2760e-04
# Epoch 00134: val_loss did not improve from 0.00044
# 100/100 [==============================] - 10s 99ms/step - loss: 7.2747e-04 - val_loss: 4.4517e-04
# Epoch 135/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.3278e-04
# Epoch 00135: val_loss improved from 0.00044 to 0.00044, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 9s 91ms/step - loss: 7.3254e-04 - val_loss: 4.4012e-04
# Epoch 136/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.2869e-04
# Epoch 00136: val_loss improved from 0.00044 to 0.00044, saving model to 23_checkpoint.keras
# 100/100 [==============================] - 8s 81ms/step - loss: 7.3043e-04 - val_loss: 4.3686e-04
# Epoch 137/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.4201e-04
# Epoch 00137: val_loss did not improve from 0.00044
# 100/100 [==============================] - 10s 96ms/step - loss: 7.4028e-04 - val_loss: 4.4170e-04
# Epoch 138/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.1718e-04
# Epoch 00138: val_loss did not improve from 0.00044
# 100/100 [==============================] - 9s 93ms/step - loss: 7.1741e-04 - val_loss: 4.3884e-04
# Epoch 139/3000
#  99/100 [============================>.] - ETA: 0s - loss: 7.3751e-04
# Epoch 00139: val_loss did not improve from 0.00044
# 100/100 [==============================] - 9s 92ms/step - loss: 7.3629e-04 - val_loss: 4.3828e-04
# Epoch 00139: early stopping
# CPU times: user 27min 30s, sys: 1min 6s, total: 28min 37s
# Wall time: 19min 15s

# %%
try:
    model.load_weights(path_checkpoint)
except Exception as error:
    print("Error trying to load checkpoint.")
    print(error)

# %%
loss_test_set = model.evaluate(x=np.expand_dims(x_test_scaled, axis=0),
                        y=np.expand_dims(y_test_scaled, axis=0))
# Out:
# 1/1 [==============================] - 0s 2ms/sample - loss: 4.3686e-04

# %%
print("loss (test-set):", loss_test_set)
# Out:
# loss (test-set): 0.0004368628724478185

# %%
# If you have several metrics you can use this instead.
if False:
    for res, metric in zip(result, model.metrics_names):
        print("{0}: {1:.3e}".format(metric, res))

# %%
def plot_comparison(start_idx, length=100, train=True):
    """
    Plot the predicted and true output-signals.
    
    :param start_idx: Start-index for the time-series.
    :param length: Sequence-length to process and plot.
    :param train: Boolean whether to use training- or test-set.
    """
    
    if train:
        # Use training-data.
        x = x_train_scaled
        y_true = y_train
    else:
        # Use test-data.
        x = x_test_scaled
        y_true = y_test
    
    # End-index for the sequences.
    end_idx = start_idx + length
    
    # Select the sequences from the given start-index and
    # of the given length.
    x = x[start_idx:end_idx]
    y_true = y_true[start_idx:end_idx]
    
    # Input-signals for the model.
    x = np.expand_dims(x, axis=0)

    # Use the model to predict the output-signals.
    y_pred = model.predict(x)
    
    # The output of the model is between 0 and 1.
    # Do an inverse map to get it back to the scale
    # of the original data-set.
    y_pred_rescaled = y_scaler.inverse_transform(y_pred[0])
    
    # For each output-signal.
    for signal in range(len(target_names)):
        # Get the output-signal predicted by the model.
        signal_pred = y_pred_rescaled[:, signal]
        
        # Get the true output-signal from the data-set.
        signal_true = y_true[:, signal]

        # Make the plotting-canvas bigger.
        plt.figure(figsize=(16,6),dpi=250)
        
        # Plot and compare the two signals.
        plt.plot(signal_true, label='true')
        plt.plot(signal_pred, label='pred')
        
        # Plot grey box for warmup-period.
        p = plt.axvspan(0, warmup_steps, facecolor='black', alpha=0.15)
        
        # Plot labels etc.
        plt.ylabel(target_names[signal])
        plt.legend()
        plt.show()

# %%
plot_comparison(start_idx=200000, length=10000, train=True)

# %%
plot_comparison(start_idx=200000, length=1000, train=True)

# %%
def return_pred(start_idx, length=100, train=True):
    """
    Plot the predicted and true output-signals.
    
    :param start_idx: Start-index for the time-series.
    :param length: Sequence-length to process and plot.
    :param train: Boolean whether to use training- or test-set.
    """
    
    if train:
        # Use training-data.
        x = x_train_scaled
        y_true = y_train
    else:
        # Use test-data.
        x = x_test_scaled
        y_true = y_test
    
    # End-index for the sequences.
    end_idx = start_idx + length
    
    # Select the sequences from the given start-index and
    # of the given length.
    x = x[start_idx:end_idx]
    y_true = y_true[start_idx:end_idx]
    
    # Input-signals for the model.
    x = np.expand_dims(x, axis=0)

    # Use the model to predict the output-signals.
    y_pred = model.predict(x)
    
    # The output of the model is between 0 and 1.
    # Do an inverse map to get it back to the scale
    # of the original data-set.
    y_pred_rescaled = y_scaler.inverse_transform(y_pred[0])
    y_pred_rescaled[:,0] = np.log(y_pred_rescaled[:,0])/10
    y_tc = y_true[:,0]
    y_tc = np.log(y_true[:,0])/10
    
    result = pd.DataFrame({'Close_pred':y_pred_rescaled[:,0],'Close_true':y_tc})
    result['rmse'] = np.sqrt((result['Close_pred'] - result['Close_true'])*
                              (result['Close_pred'] - result['Close_true']))
    
    result = result.tail(len(result)-200) #giving at least 50 learning steps to the model
    return(result)

# %%
result = return_pred(start_idx = 0, length=10000, train=False)
result.head()
# Out:
#      Close_pred  Close_true      rmse
# 200    1.111981     1.09347  0.018511
# 201    1.111789     1.09356  0.018229
# 202    1.111818     1.09363  0.018188
# 203    1.110670     1.09391  0.016760
# 204    1.111378     1.09406  0.017318

# %%
result.describe()
# Out:
#         Close_pred   Close_true         rmse
# count  9800.000000  9800.000000  9800.000000
# mean      1.112832     1.099787     0.013048
# std       0.002912     0.005822     0.004161
# min       1.102072     1.087000     0.000183
# 25%       1.110959     1.095070     0.009486
# 50%       1.112857     1.098420     0.013799
# 75%       1.114621     1.105410     0.016267
# max       1.119927     1.112470     0.023668

# %%
rmse = result.describe()['rmse'][1]
data_history.append([rmse,loss_test_set,shift_mn,epochs,steps_per_epoch,batch_size,sequence_length])
df = pd.DataFrame(data_history,columns=['rmse','trainScore','shift_mn',
                                        'epochs','steps_per_epoch','batch_size','sequence_length'])
df.head()
# Out:
#        rmse  trainScore  shift_mn  epochs  steps_per_epoch  batch_size  \
# 0  0.045098     0.01057         1      20              100          64
#
#    sequence_length
# 0            10080

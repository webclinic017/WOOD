# %%
___Author___='LumberJack Jyss'

# %%
print('Global Optimized LumberJack Equities Method\n°OoO_FOREX_Oo0°\nLumberJack Jyss 5779(c)')
# Out:
# Global Optimized LumberJack Equities Method
# °OoO_FOREX_Oo0°
# LumberJack Jyss 5779(c)

# %%
print('Importation des librairies...')
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import pandas as pd
import os
from sklearn.preprocessing import MinMaxScaler
import pandas_datareader as web
import math
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Input, Dense, GRU, Embedding
from tensorflow.python.keras.optimizers import RMSprop
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, ReduceLROnPlateau
print('Librairies importées')
# Out:
# Importation des librairies...
# Librairies importées

# %%
# Setting the data
start = pd.to_datetime('2015-01-28')
end = pd.to_datetime('2019-03-28')
delta = round((end-start).days)
bloc1 = round(delta*0.8)
bloc2 = delta - bloc1
print("Période d'étude : ",delta)
print('Sur un découpage 80% - 20% de la période : ')
print('Bloc 1 : ',bloc1,' jours \nBloc 2 :',bloc2,' jours')
print('Note : On change de règles de calculs, car tous les jours ne sont pas ouvrés')
# Out:
# Période d'étude :  1520
# Sur un découpage 80% - 20% de la période :
# Bloc 1 :  1216  jours
# Bloc 2 : 304  jours
# Note : On change de règles de calculs, car tous les jours ne sont pas ouvrés

# %%
# fix random seed for reproducibility
np.random.seed(7)
# load the dataset
df = web.DataReader('GOOG','yahoo',start,end)
#dataframe = dataframe.iloc[:,1:]
df.reset_index(inplace=True)
df.head()
# Out:
#         Date        High         Low        Open       Close     Volume  \
# 0 2015-01-28  520.127686  507.208801  519.918884  507.208801  1683800.0
# 1 2015-01-29  508.292847  498.456970  508.203339  507.865204  4186400.0
# 2 2015-01-30  536.915344  512.698608  513.036743  531.594604  5606400.0
# 3 2015-02-02  530.082947  515.712036  528.819885  525.587646  2849800.0
# 4 2015-02-03  530.480713  520.396240  525.110291  526.343506  2034800.0
#
#     Adj Close
# 0  507.208801
# 1  507.865204
# 2  531.594604
# 3  525.587646
# 4  526.343506

# %%
#df['DayOfYear'] = df.index.dayofyear
#df['HourOfDay'] = df.index.hour
#df['MonthOfYear'] = df.index.month
df = df.iloc[:,1:]
df = df.drop(columns='Close',axis=1)

# %%
df.head()
# Out:
#          High         Low        Open     Volume   Adj Close
# 0  520.127686  507.208801  519.918884  1683800.0  507.208801
# 1  508.292847  498.456970  508.203339  4186400.0  507.865204
# 2  536.915344  512.698608  513.036743  5606400.0  531.594604
# 3  530.082947  515.712036  528.819885  2849800.0  525.587646
# 4  530.480713  520.396240  525.110291  2034800.0  526.343506

# %%
df = df.fillna(method='ffill')

# %%
df[['Open','High','Low','Adj Close']] = np.exp(10*df[['Open','High','Low','Adj Close']]) #See if we can help the model out
# Out:
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: overflow encountered in exp
#   """Entry point for launching an IPython kernel.

# %%
df.describe()
# Out:
#               High          Low         Open        Volume    Adj Close
# count  1049.000000  1049.000000  1049.000000  1.049000e+03  1049.000000
# mean    873.300222   858.029534   865.777153  1.755486e+06   865.937344
# std     207.077123   202.690041   204.834931  8.678156e+05   204.948153
# min     508.292847   498.456970   508.203339  5.272000e+05   507.208801
# 25%     722.469971   710.010010   717.059998  1.252000e+06   716.549988
# 50%     828.484985   821.020020   824.710022  1.532600e+06   824.320007
# 75%    1062.375000  1039.839966  1050.170044  1.984900e+06  1050.709961
# max    1273.890015  1249.020020  1271.000000  1.116490e+07  1268.329956

# %%
df.values.shape
# Out:
# (1049, 5)

# %%
target_names = ['Adj Close']

# %%
shift_mn = 1
shift_steps = shift_mn * 1  # Number of mn.

# %%
df_targets = df[target_names].shift(-shift_steps)

# %%
x_data = df.values[0:-shift_steps]
x_data = x_data.astype('float32')

# %%
print(type(x_data))
print("Shape:", x_data.shape)
# Out:
# <class 'numpy.ndarray'>
# Shape: (1048, 5)

# %%
y_data = df_targets.values[:-shift_steps]
y_data = y_data.astype('float32')

# %%
#nb of data rows in the dataset
num_data = len(x_data)
num_data
# Out:
# 1048

# %%
train_split = 0.8

# %%
num_train = int(train_split * num_data)
num_train
# Out:
# 838

# %%
#These are the input-signals for the training- and test-sets
x_train = x_data[0:num_train]
x_test = x_data[num_train:]
len(x_train) + len(x_test)
# Out:
# 1048

# %%
#These are the output-signals for the training- and test-sets
y_train = y_data[0:num_train]
y_test = y_data[num_train:]
len(y_train) + len(y_test)
# Out:
# 1048

# %%
#number of input-signals
num_x_signals = x_data.shape[1]
num_x_signals
# Out:
# 5

# %%
#number of output-signals
num_y_signals = y_data.shape[1]
num_y_signals
# Out:
# 1

# %%
# Scaling data (0-1)
print("Min:", np.min(x_train))
print("Max:", np.max(x_train))
# Out:
# Min: 498.45697
# Max: 11164900.0

# %%
x_scaler = MinMaxScaler()

# %%
x_train_scaled = x_scaler.fit_transform(x_train)

# %%
print("Min:", np.min(x_train_scaled))
print("Max:", np.max(x_train_scaled))
# Out:
# Min: 0.0
# Max: 1.0000001

# %%
x_test_scaled = x_scaler.transform(x_test)

# %%
y_scaler = MinMaxScaler()
y_train_scaled = y_scaler.fit_transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
print(x_train_scaled.shape)
print(y_train_scaled.shape)
# Out:
# (838, 5)
# (838, 1)

# %%
def batch_generator(batch_size, sequence_length):
    """
    Generator function for creating random batches of training-data.
    """

    # Infinite loop.
    while True:
        # Allocate a new array for the batch of input-signals.
        x_shape = (batch_size, sequence_length, num_x_signals)
        x_batch = np.zeros(shape=x_shape, dtype=np.float16)

        # Allocate a new array for the batch of output-signals.
        y_shape = (batch_size, sequence_length, num_y_signals)
        y_batch = np.zeros(shape=y_shape, dtype=np.float16)

        # Fill the batch with random sequences of data.
        for i in range(batch_size):
            # Get a random start-index.
            # This points somewhere into the training-data.
            idx = np.random.randint(num_train - sequence_length)
            
            # Copy the sequences of data starting at this index.
            x_batch[i] = x_train_scaled[idx:idx+sequence_length]
            y_batch[i] = y_train_scaled[idx:idx+sequence_length]
        
        yield (x_batch, y_batch)

# %%
batch_size = 6

# %%
# We adjust the length to be  interesting for the model to work on it but not to heavy to crush our computer
sequence_length = 6 * 4 * 7
sequence_length
# Out:
# 168

# %%
generator = batch_generator(batch_size=batch_size,
                            sequence_length=sequence_length)

# %%
x_batch, y_batch = next(generator)

# %%
print(x_batch.shape)
print(y_batch.shape)
# Out:
# (6, 168, 5)
# (6, 168, 1)

# %%
#Lets plot it 

batch = 0   # First sequence in the batch.
signal = 0  # First signal from the input-signals.
seq = x_batch[batch, :, signal]
plt.figure(figsize=(16,6),dpi=200)
plt.plot(seq,color='purple')

# %%
#plot of the batch we want to predict
seq = y_batch[batch, :, signal]
plt.figure(figsize=(16,6),dpi=200)
plt.plot(seq,color='purple')

# %%
validation_data = (np.expand_dims(x_test_scaled, axis=0),
                   np.expand_dims(y_test_scaled, axis=0))

# %%
model = Sequential()

# %%
# The GRU outputs a batch of sequences of 512 values. We want to predict 1 output-signals, 
# so we add a fully-connected (or dense) layer which maps 512 values down to only 1 values.
model.add(Dense(num_y_signals, activation='sigmoid'))

# %%
if False:
    from tensorflow.python.keras.initializers import RandomUniform

    # Maybe use lower init-ranges.
    init = RandomUniform(minval=-0.05, maxval=0.05)

    model.add(Dense(num_y_signals,
                    activation='linear',
                    kernel_initializer=init))

# %%
warmup_steps = 5

# %%
def loss_mse_warmup(y_true, y_pred):
    """
    Calculate the Mean Squared Error between y_true and y_pred,
    but ignore the beginning "warmup" part of the sequences.
    
    y_true is the desired output.
    y_pred is the model's output.
    """

    # The shape of both input tensors are:
    # [batch_size, sequence_length, num_y_signals].

    # Ignore the "warmup" parts of the sequences
    # by taking slices of the tensors.
    y_true_slice = y_true[:, warmup_steps:, :]
    y_pred_slice = y_pred[:, warmup_steps:, :]

    # These sliced tensors both have this shape:
    # [batch_size, sequence_length - warmup_steps, num_y_signals]

    # Calculate the MSE loss for each value in these tensors.
    # This outputs a 3-rank tensor of the same shape.
    loss = tf.losses.mean_squared_error(labels=y_true_slice,
                                        predictions=y_pred_slice)

    # Keras may reduce this across the first axis (the batch)
    # but the semantics are unclear, so to be sure we use
    # the loss across the entire tensor, we reduce it to a
    # single scalar with the mean function.
    loss_mean = tf.reduce_mean(loss)

    return loss_mean

# %%
optimizer = RMSprop(lr=1e-4)

# %%
len(x_train_scaled),len(y_train_scaled)
# Out:
# (838, 838)

# %%
epochs_custom = 10

# %%
model.build(x_train_scaled.shape)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                multiple                  6
# _________________________________________________________________
# dense_1 (Dense)              multiple                  2
# =================================================================
# Total params: 8
# Trainable params: 8
# Non-trainable params: 0
# _________________________________________________________________

# %%
#This is the callback for writing checkpoints during training.
path_checkpoint = '23_checkpoint.keras'
callback_checkpoint = ModelCheckpoint(filepath=path_checkpoint,
                                      monitor='val_loss',
                                      verbose=1,
                                      save_weights_only=True,
                                      save_best_only=True)

# %%
#stopping the model when performance worsens on the valid set
callback_early_stopping = EarlyStopping(monitor='val_loss',
                                        patience=10, verbose=1)

# %%
#This is the callback for writing the TensorBoard log during training.
callback_tensorboard = TensorBoard(log_dir='./23_logs/',
                                   histogram_freq=0,
                                   write_graph=False)

# %%
#This callback reduces the learning-rate for the optimizer if the validation-loss has not improved since 
# the last epoch (as indicated by patience=0). The learning-rate will be reduced by multiplying it with 
# the given factor. We set a start learning-rate of 1e-3 above, so multiplying it by 0.1 gives a learning-rate of 1e-4. 
# We don't want the learning-rate to go any lower than this.

callback_reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                                       factor=0.1,
                                       min_lr=1e-6,
                                       patience=0,
                                       verbose=1)

# %%
callbacks = [callback_early_stopping,
             callback_checkpoint,
             callback_tensorboard,
             callback_reduce_lr]

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
epochs = 100
steps_per_epoch = 400

# %%
# %%time
model.fit_generator(generator=generator,
                    epochs=epochs,
                    steps_per_epoch=steps_per_epoch, #should be 100 ##################
                    validation_data=validation_data,
                    callbacks=callbacks,shuffle=False)
# Out:
# Epoch 1/100
# 383/400 [===========================>..] - ETA: 0s - loss: 0.0203
# Epoch 00001: val_loss improved from 0.15691 to 0.15689, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0205 - val_loss: 0.1569
# Epoch 2/100
# 373/400 [==========================>...] - ETA: 0s - loss: 0.0202
# Epoch 00002: val_loss improved from 0.15689 to 0.15686, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0201 - val_loss: 0.1569
# Epoch 3/100
# 369/400 [==========================>...] - ETA: 0s - loss: 0.0203
# Epoch 00003: val_loss improved from 0.15686 to 0.15683, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0202 - val_loss: 0.1568
# Epoch 4/100
# 373/400 [==========================>...] - ETA: 0s - loss: 0.0200
# Epoch 00004: val_loss improved from 0.15683 to 0.15681, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0199 - val_loss: 0.1568
# Epoch 5/100
# 374/400 [===========================>..] - ETA: 0s - loss: 0.0193
# Epoch 00005: val_loss improved from 0.15681 to 0.15679, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0192 - val_loss: 0.1568
# Epoch 6/100
# 372/400 [==========================>...] - ETA: 0s - loss: 0.0196
# Epoch 00006: val_loss improved from 0.15679 to 0.15677, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0198 - val_loss: 0.1568
# Epoch 7/100
# 374/400 [===========================>..] - ETA: 0s - loss: 0.0196
# Epoch 00007: val_loss improved from 0.15677 to 0.15674, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0195 - val_loss: 0.1567
# Epoch 8/100
# 375/400 [===========================>..] - ETA: 0s - loss: 0.0193
# Epoch 00008: val_loss improved from 0.15674 to 0.15672, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0193 - val_loss: 0.1567
# Epoch 9/100
# 376/400 [===========================>..] - ETA: 0s - loss: 0.0202
# Epoch 00009: val_loss improved from 0.15672 to 0.15670, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0201 - val_loss: 0.1567
# Epoch 10/100
# 368/400 [==========================>...] - ETA: 0s - loss: 0.0193
# Epoch 00010: val_loss improved from 0.15670 to 0.15668, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0192 - val_loss: 0.1567
# Epoch 11/100
# 374/400 [===========================>..] - ETA: 0s - loss: 0.0194
# Epoch 00011: val_loss improved from 0.15668 to 0.15666, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0195 - val_loss: 0.1567
# Epoch 12/100
# 380/400 [===========================>..] - ETA: 0s - loss: 0.0195
# Epoch 00012: val_loss improved from 0.15666 to 0.15663, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0196 - val_loss: 0.1566
# Epoch 13/100
# 375/400 [===========================>..] - ETA: 0s - loss: 0.0198
# Epoch 00013: val_loss improved from 0.15663 to 0.15660, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0200 - val_loss: 0.1566
# Epoch 14/100
# 399/400 [============================>.] - ETA: 0s - loss: 0.0197
# Epoch 00014: val_loss improved from 0.15660 to 0.15657, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0198 - val_loss: 0.1566
# Epoch 15/100
# 372/400 [==========================>...] - ETA: 0s - loss: 0.0191
# Epoch 00015: val_loss improved from 0.15657 to 0.15655, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0191 - val_loss: 0.1566
# Epoch 16/100
# 374/400 [===========================>..] - ETA: 0s - loss: 0.0193
# Epoch 00016: val_loss improved from 0.15655 to 0.15653, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0193 - val_loss: 0.1565
# Epoch 17/100
# 370/400 [==========================>...] - ETA: 0s - loss: 0.0204
# Epoch 00017: val_loss improved from 0.15653 to 0.15649, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0203 - val_loss: 0.1565
# Epoch 18/100
# 366/400 [==========================>...] - ETA: 0s - loss: 0.0201
# Epoch 00018: val_loss improved from 0.15649 to 0.15647, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0201 - val_loss: 0.1565
# Epoch 19/100
# 368/400 [==========================>...] - ETA: 0s - loss: 0.0202
# Epoch 00019: val_loss improved from 0.15647 to 0.15644, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0203 - val_loss: 0.1564
# Epoch 20/100
# 372/400 [==========================>...] - ETA: 0s - loss: 0.0197
# Epoch 00020: val_loss improved from 0.15644 to 0.15642, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0198 - val_loss: 0.1564
# Epoch 21/100
# 371/400 [==========================>...] - ETA: 0s - loss: 0.0201
# Epoch 00021: val_loss improved from 0.15642 to 0.15639, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0202 - val_loss: 0.1564
# Epoch 22/100
# 371/400 [==========================>...] - ETA: 0s - loss: 0.0187
# Epoch 00022: val_loss improved from 0.15639 to 0.15637, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0186 - val_loss: 0.1564
# Epoch 23/100
# 377/400 [===========================>..] - ETA: 0s - loss: 0.0201
# Epoch 00023: val_loss improved from 0.15637 to 0.15634, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0201 - val_loss: 0.1563
# Epoch 24/100
# 373/400 [==========================>...] - ETA: 0s - loss: 0.0197
# Epoch 00024: val_loss improved from 0.15634 to 0.15632, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0198 - val_loss: 0.1563
# Epoch 25/100
# 368/400 [==========================>...] - ETA: 0s - loss: 0.0201
# Epoch 00025: val_loss improved from 0.15632 to 0.15630, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0202 - val_loss: 0.1563
# Epoch 26/100
# 366/400 [==========================>...] - ETA: 0s - loss: 0.0193
# Epoch 00026: val_loss improved from 0.15630 to 0.15628, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0195 - val_loss: 0.1563
# Epoch 27/100
# 370/400 [==========================>...] - ETA: 0s - loss: 0.0202
# Epoch 00027: val_loss improved from 0.15628 to 0.15625, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0202 - val_loss: 0.1563
# Epoch 28/100
# 382/400 [===========================>..] - ETA: 0s - loss: 0.0200
# Epoch 00028: val_loss improved from 0.15625 to 0.15622, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0201 - val_loss: 0.1562
# Epoch 29/100
# 377/400 [===========================>..] - ETA: 0s - loss: 0.0204
# Epoch 00029: val_loss improved from 0.15622 to 0.15619, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0204 - val_loss: 0.1562
# Epoch 30/100
# 375/400 [===========================>..] - ETA: 0s - loss: 0.0192
# Epoch 00030: val_loss improved from 0.15619 to 0.15617, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0195 - val_loss: 0.1562
# Epoch 31/100
# 377/400 [===========================>..] - ETA: 0s - loss: 0.0194
# Epoch 00031: val_loss improved from 0.15617 to 0.15615, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0195 - val_loss: 0.1562
# Epoch 32/100
# 373/400 [==========================>...] - ETA: 0s - loss: 0.0204
# Epoch 00032: val_loss improved from 0.15615 to 0.15612, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0206 - val_loss: 0.1561
# Epoch 33/100
# 377/400 [===========================>..] - ETA: 0s - loss: 0.0201
# Epoch 00033: val_loss improved from 0.15612 to 0.15610, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0201 - val_loss: 0.1561
# Epoch 34/100
# 375/400 [===========================>..] - ETA: 0s - loss: 0.0193
# Epoch 00034: val_loss improved from 0.15610 to 0.15608, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0192 - val_loss: 0.1561
# Epoch 35/100
# 374/400 [===========================>..] - ETA: 0s - loss: 0.0192
# Epoch 00035: val_loss improved from 0.15608 to 0.15606, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0192 - val_loss: 0.1561
# Epoch 36/100
# 370/400 [==========================>...] - ETA: 0s - loss: 0.0200
# Epoch 00036: val_loss improved from 0.15606 to 0.15603, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0200 - val_loss: 0.1560
# Epoch 37/100
# 374/400 [===========================>..] - ETA: 0s - loss: 0.0207
# Epoch 00037: val_loss improved from 0.15603 to 0.15600, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0205 - val_loss: 0.1560
# Epoch 38/100
# 367/400 [==========================>...] - ETA: 0s - loss: 0.0195
# Epoch 00038: val_loss improved from 0.15600 to 0.15599, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0196 - val_loss: 0.1560
# Epoch 39/100
# 368/400 [==========================>...] - ETA: 0s - loss: 0.0198
# Epoch 00039: val_loss improved from 0.15599 to 0.15597, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0197 - val_loss: 0.1560
# Epoch 40/100
# 374/400 [===========================>..] - ETA: 0s - loss: 0.0200
# Epoch 00040: val_loss improved from 0.15597 to 0.15594, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0199 - val_loss: 0.1559
# Epoch 41/100
# 380/400 [===========================>..] - ETA: 0s - loss: 0.0195
# Epoch 00041: val_loss improved from 0.15594 to 0.15592, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0196 - val_loss: 0.1559
# Epoch 42/100
# 372/400 [==========================>...] - ETA: 0s - loss: 0.0193
# Epoch 00042: val_loss improved from 0.15592 to 0.15589, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0194 - val_loss: 0.1559
# Epoch 43/100
# 374/400 [===========================>..] - ETA: 0s - loss: 0.0196
# Epoch 00043: val_loss improved from 0.15589 to 0.15587, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0194 - val_loss: 0.1559
# Epoch 44/100
# 378/400 [===========================>..] - ETA: 0s - loss: 0.0183
# Epoch 00044: val_loss improved from 0.15587 to 0.15585, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0184 - val_loss: 0.1559
# Epoch 45/100
# 374/400 [===========================>..] - ETA: 0s - loss: 0.0202
# Epoch 00045: val_loss improved from 0.15585 to 0.15582, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0204 - val_loss: 0.1558
# Epoch 46/100
# 379/400 [===========================>..] - ETA: 0s - loss: 0.0196
# Epoch 00046: val_loss improved from 0.15582 to 0.15580, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0197 - val_loss: 0.1558
# Epoch 47/100
# 376/400 [===========================>..] - ETA: 0s - loss: 0.0197
# Epoch 00047: val_loss improved from 0.15580 to 0.15577, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0196 - val_loss: 0.1558
# Epoch 48/100
# 375/400 [===========================>..] - ETA: 0s - loss: 0.0187
# Epoch 00048: val_loss improved from 0.15577 to 0.15575, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0190 - val_loss: 0.1557
# Epoch 49/100
# 373/400 [==========================>...] - ETA: 0s - loss: 0.0192
# Epoch 00049: val_loss improved from 0.15575 to 0.15574, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0191 - val_loss: 0.1557
# Epoch 50/100
# 369/400 [==========================>...] - ETA: 0s - loss: 0.0199
# Epoch 00050: val_loss improved from 0.15574 to 0.15571, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0199 - val_loss: 0.1557
# Epoch 51/100
# 374/400 [===========================>..] - ETA: 0s - loss: 0.0203
# Epoch 00051: val_loss improved from 0.15571 to 0.15568, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0202 - val_loss: 0.1557
# Epoch 52/100
# 371/400 [==========================>...] - ETA: 0s - loss: 0.0192
# Epoch 00052: val_loss improved from 0.15568 to 0.15566, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0192 - val_loss: 0.1557
# Epoch 53/100
# 378/400 [===========================>..] - ETA: 0s - loss: 0.0199
# Epoch 00053: val_loss improved from 0.15566 to 0.15564, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0199 - val_loss: 0.1556
# Epoch 54/100
# 375/400 [===========================>..] - ETA: 0s - loss: 0.0193
# Epoch 00054: val_loss improved from 0.15564 to 0.15562, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0192 - val_loss: 0.1556
# Epoch 55/100
# 376/400 [===========================>..] - ETA: 0s - loss: 0.0194
# Epoch 00055: val_loss improved from 0.15562 to 0.15560, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0196 - val_loss: 0.1556
# Epoch 56/100
# 375/400 [===========================>..] - ETA: 0s - loss: 0.0200
# Epoch 00056: val_loss improved from 0.15560 to 0.15557, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0200 - val_loss: 0.1556
# Epoch 57/100
# 370/400 [==========================>...] - ETA: 0s - loss: 0.0195
# Epoch 00057: val_loss improved from 0.15557 to 0.15554, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0195 - val_loss: 0.1555
# Epoch 58/100
# 369/400 [==========================>...] - ETA: 0s - loss: 0.0188
# Epoch 00058: val_loss improved from 0.15554 to 0.15552, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0188 - val_loss: 0.1555
# Epoch 59/100
# 367/400 [==========================>...] - ETA: 0s - loss: 0.0196
# Epoch 00059: val_loss improved from 0.15552 to 0.15548, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0197 - val_loss: 0.1555
# Epoch 60/100
# 371/400 [==========================>...] - ETA: 0s - loss: 0.0195
# Epoch 00060: val_loss improved from 0.15548 to 0.15547, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0193 - val_loss: 0.1555
# Epoch 61/100
# 388/400 [============================>.] - ETA: 0s - loss: 0.0193
# Epoch 00061: val_loss improved from 0.15547 to 0.15545, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0193 - val_loss: 0.1555
# Epoch 62/100
# 388/400 [============================>.] - ETA: 0s - loss: 0.0190
# Epoch 00062: val_loss improved from 0.15545 to 0.15543, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0190 - val_loss: 0.1554
# Epoch 63/100
# 395/400 [============================>.] - ETA: 0s - loss: 0.0192
# Epoch 00063: val_loss improved from 0.15543 to 0.15541, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0192 - val_loss: 0.1554
# Epoch 64/100
# 396/400 [============================>.] - ETA: 0s - loss: 0.0201
# Epoch 00064: val_loss improved from 0.15541 to 0.15537, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0201 - val_loss: 0.1554
# Epoch 65/100
# 377/400 [===========================>..] - ETA: 0s - loss: 0.0196
# Epoch 00065: val_loss improved from 0.15537 to 0.15535, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0196 - val_loss: 0.1553
# Epoch 66/100
# 397/400 [============================>.] - ETA: 0s - loss: 0.0194
# Epoch 00066: val_loss improved from 0.15535 to 0.15532, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0193 - val_loss: 0.1553
# Epoch 67/100
# 394/400 [============================>.] - ETA: 0s - loss: 0.0196
# Epoch 00067: val_loss improved from 0.15532 to 0.15530, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0195 - val_loss: 0.1553
# Epoch 68/100
# 395/400 [============================>.] - ETA: 0s - loss: 0.0191
# Epoch 00068: val_loss improved from 0.15530 to 0.15528, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0191 - val_loss: 0.1553
# Epoch 69/100
# 366/400 [==========================>...] - ETA: 0s - loss: 0.0194
# Epoch 00069: val_loss improved from 0.15528 to 0.15526, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0194 - val_loss: 0.1553
# Epoch 70/100
# 371/400 [==========================>...] - ETA: 0s - loss: 0.0191
# Epoch 00070: val_loss improved from 0.15526 to 0.15523, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0194 - val_loss: 0.1552
# Epoch 71/100
# 375/400 [===========================>..] - ETA: 0s - loss: 0.0193
# Epoch 00071: val_loss improved from 0.15523 to 0.15521, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0192 - val_loss: 0.1552
# Epoch 72/100
# 377/400 [===========================>..] - ETA: 0s - loss: 0.0202
# Epoch 00072: val_loss improved from 0.15521 to 0.15518, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0203 - val_loss: 0.1552
# Epoch 73/100
# 366/400 [==========================>...] - ETA: 0s - loss: 0.0193
# Epoch 00073: val_loss improved from 0.15518 to 0.15515, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0193 - val_loss: 0.1552
# Epoch 74/100
# 369/400 [==========================>...] - ETA: 0s - loss: 0.0195
# Epoch 00074: val_loss improved from 0.15515 to 0.15513, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0194 - val_loss: 0.1551
# Epoch 75/100
# 369/400 [==========================>...] - ETA: 0s - loss: 0.0198
# Epoch 00075: val_loss improved from 0.15513 to 0.15510, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0197 - val_loss: 0.1551
# Epoch 76/100
# 374/400 [===========================>..] - ETA: 0s - loss: 0.0191
# Epoch 00076: val_loss improved from 0.15510 to 0.15508, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0192 - val_loss: 0.1551
# Epoch 77/100
# 372/400 [==========================>...] - ETA: 0s - loss: 0.0195
# Epoch 00077: val_loss improved from 0.15508 to 0.15506, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0195 - val_loss: 0.1551
# Epoch 78/100
# 375/400 [===========================>..] - ETA: 0s - loss: 0.0202
# Epoch 00078: val_loss improved from 0.15506 to 0.15502, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0202 - val_loss: 0.1550
# Epoch 79/100
# 372/400 [==========================>...] - ETA: 0s - loss: 0.0202
# Epoch 00079: val_loss improved from 0.15502 to 0.15499, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0202 - val_loss: 0.1550
# Epoch 80/100
# 365/400 [==========================>...] - ETA: 0s - loss: 0.0199
# Epoch 00080: val_loss improved from 0.15499 to 0.15497, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0199 - val_loss: 0.1550
# Epoch 81/100
# 368/400 [==========================>...] - ETA: 0s - loss: 0.0197
# Epoch 00081: val_loss improved from 0.15497 to 0.15495, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0200 - val_loss: 0.1549
# Epoch 82/100
# 376/400 [===========================>..] - ETA: 0s - loss: 0.0191
# Epoch 00082: val_loss improved from 0.15495 to 0.15492, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0191 - val_loss: 0.1549
# Epoch 83/100
# 374/400 [===========================>..] - ETA: 0s - loss: 0.0200
# Epoch 00083: val_loss improved from 0.15492 to 0.15489, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0202 - val_loss: 0.1549
# Epoch 84/100
# 370/400 [==========================>...] - ETA: 0s - loss: 0.0196
# Epoch 00084: val_loss improved from 0.15489 to 0.15487, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0196 - val_loss: 0.1549
# Epoch 85/100
# 375/400 [===========================>..] - ETA: 0s - loss: 0.0194
# Epoch 00085: val_loss improved from 0.15487 to 0.15485, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0195 - val_loss: 0.1548
# Epoch 86/100
# 370/400 [==========================>...] - ETA: 0s - loss: 0.0197
# Epoch 00086: val_loss improved from 0.15485 to 0.15482, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0196 - val_loss: 0.1548
# Epoch 87/100
# 366/400 [==========================>...] - ETA: 0s - loss: 0.0189
# Epoch 00087: val_loss improved from 0.15482 to 0.15480, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0191 - val_loss: 0.1548
# Epoch 88/100
# 377/400 [===========================>..] - ETA: 0s - loss: 0.0187
# Epoch 00088: val_loss improved from 0.15480 to 0.15477, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0187 - val_loss: 0.1548
# Epoch 89/100
# 373/400 [==========================>...] - ETA: 0s - loss: 0.0193
# Epoch 00089: val_loss improved from 0.15477 to 0.15476, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0193 - val_loss: 0.1548
# Epoch 90/100
# 359/400 [=========================>....] - ETA: 0s - loss: 0.0195
# Epoch 00090: val_loss improved from 0.15476 to 0.15473, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0194 - val_loss: 0.1547
# Epoch 91/100
# 372/400 [==========================>...] - ETA: 0s - loss: 0.0197
# Epoch 00091: val_loss improved from 0.15473 to 0.15471, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0196 - val_loss: 0.1547
# Epoch 92/100
# 369/400 [==========================>...] - ETA: 0s - loss: 0.0191
# Epoch 00092: val_loss improved from 0.15471 to 0.15469, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0193 - val_loss: 0.1547
# Epoch 93/100
# 378/400 [===========================>..] - ETA: 0s - loss: 0.0192
# Epoch 00093: val_loss improved from 0.15469 to 0.15467, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0193 - val_loss: 0.1547
# Epoch 94/100
# 378/400 [===========================>..] - ETA: 0s - loss: 0.0186
# Epoch 00094: val_loss improved from 0.15467 to 0.15465, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0188 - val_loss: 0.1546
# Epoch 95/100
# 377/400 [===========================>..] - ETA: 0s - loss: 0.0193
# Epoch 00095: val_loss improved from 0.15465 to 0.15462, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 0s 1ms/step - loss: 0.0194 - val_loss: 0.1546
# Epoch 96/100
# 376/400 [===========================>..] - ETA: 0s - loss: 0.0197
# Epoch 00096: val_loss improved from 0.15462 to 0.15460, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0195 - val_loss: 0.1546
# Epoch 97/100
# 369/400 [==========================>...] - ETA: 0s - loss: 0.0204
# Epoch 00097: val_loss improved from 0.15460 to 0.15457, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0202 - val_loss: 0.1546
# Epoch 98/100
# 371/400 [==========================>...] - ETA: 0s - loss: 0.0194
# Epoch 00098: val_loss improved from 0.15457 to 0.15455, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0194 - val_loss: 0.1545
# Epoch 99/100
# 373/400 [==========================>...] - ETA: 0s - loss: 0.0184
# Epoch 00099: val_loss improved from 0.15455 to 0.15453, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0182 - val_loss: 0.1545
# Epoch 100/100
# 361/400 [==========================>...] - ETA: 0s - loss: 0.0193
# Epoch 00100: val_loss improved from 0.15453 to 0.15450, saving model to 23_checkpoint.keras
# 400/400 [==============================] - 1s 1ms/step - loss: 0.0195 - val_loss: 0.1545
# CPU times: user 1min 12s, sys: 9.89 s, total: 1min 22s
# Wall time: 50.7 s

# %%
try:
    model.load_weights(path_checkpoint)
except Exception as error:
    print("Error trying to load checkpoint.")
    print(error)

# %%
loss_test_set = model.evaluate(x=np.expand_dims(x_test_scaled, axis=0),
                        y=np.expand_dims(y_test_scaled, axis=0))
# Out:
# 1/1 [==============================] - 0s 900us/sample - loss: 0.1545

# %%
print("loss (test-set):", loss_test_set)
# Out:
# loss (test-set): 0.15450416505336761

# %%
# If you have several metrics you can use this instead.
if False:
    for res, metric in zip(result, model.metrics_names):
        print("{0}: {1:.3e}".format(metric, res))

# %%
def plot_comparison(start_idx, length=100, train=True):
    """
    Plot the predicted and true output-signals.
    
    :param start_idx: Start-index for the time-series.
    :param length: Sequence-length to process and plot.
    :param train: Boolean whether to use training- or test-set.
    """
    
    if train:
        # Use training-data.
        x = x_train_scaled
        y_true = y_train
    else:
        # Use test-data.
        x = x_test_scaled
        y_true = y_test
    
    # End-index for the sequences.
    end_idx = start_idx + length
    
    # Select the sequences from the given start-index and
    # of the given length.
    x = x[start_idx:end_idx]
    y_true = y_true[start_idx:end_idx]
    
    # Input-signals for the model.
    x = np.expand_dims(x, axis=0)

    # Use the model to predict the output-signals.
    y_pred = model.predict(x)
    
    # The output of the model is between 0 and 1.
    # Do an inverse map to get it back to the scale
    # of the original data-set.
    y_pred_rescaled = y_scaler.inverse_transform(y_pred[0])
    
    # For each output-signal.
    for signal in range(len(target_names)):
        # Get the output-signal predicted by the model.
        signal_pred = y_pred_rescaled[:, signal]
        
        # Get the true output-signal from the data-set.
        signal_true = y_true[:, signal]

        # Make the plotting-canvas bigger.
        plt.figure(figsize=(16,6),dpi=250)
        
        # Plot and compare the two signals.
        plt.plot(signal_true, label='true')
        plt.plot(signal_pred, label='pred')
        
        # Plot grey box for warmup-period.
        p = plt.axvspan(0, warmup_steps, facecolor='black', alpha=0.15)
        
        # Plot labels etc.
        plt.ylabel(target_names[signal])
        plt.legend()
        plt.show()

# %%
plot_comparison(start_idx=200, length=100, train=True)

# %%
plot_comparison(start_idx=1, length=900, train=True)

# %%
def return_pred(start_idx, length=900, train=True):
    """
    Plot the predicted and true output-signals.
    
    :param start_idx: Start-index for the time-series.
    :param length: Sequence-length to process and plot.
    :param train: Boolean whether to use training- or test-set.
    """
    
    if train:
        # Use training-data.
        x = x_train_scaled
        y_true = y_train
    else:
        # Use test-data.
        x = x_test_scaled
        y_true = y_test
    
    # End-index for the sequences.
    end_idx = start_idx + length
    
    # Select the sequences from the given start-index and
    # of the given length.
    x = x[start_idx:end_idx]
    y_true = y_true[start_idx:end_idx]
    
    # Input-signals for the model.
    x = np.expand_dims(x, axis=0)

    # Use the model to predict the output-signals.
    y_pred = model.predict(x)
    
    # The output of the model is between 0 and 1.
    # Do an inverse map to get it back to the scale
    # of the original data-set.
    y_pred_rescaled = y_scaler.inverse_transform(y_pred[0])
    y_pred_rescaled[:,0] = np.log(y_pred_rescaled[:,0])/10
    y_tc = y_true[:,0]
    y_tc = np.log(y_true[:,0])/10
    
    result = pd.DataFrame({'Close_pred':y_pred_rescaled[:,0],'Close_true':y_tc})
    result['rmse'] = np.sqrt((result['Close_pred'] - result['Close_true'])*
                              (result['Close_pred'] - result['Close_true']))
    result['Delta'] = result['Close_true'] - result['Close_pred']
    
    result = result.tail(len(result)-200) #giving at least 50 learning steps to the model
    return(result)

# %%
result = return_pred(start_idx = 0, length=900, train=False)
result
# Out:
#      Close_pred  Close_true      rmse     Delta
# 200    0.678092    0.707704  0.029613  0.029613
# 201    0.678035    0.707687  0.029653  0.029653
# 202    0.678015    0.708912  0.030896  0.030896
# 203    0.678075    0.710985  0.032911  0.032911
# 204    0.678161    0.711602  0.033441  0.033441
# 205    0.678304    0.709465  0.031160  0.031160
# 206    0.678283    0.708423  0.030140  0.030140
# 207    0.678113    0.707718  0.029605  0.029605
# 208    0.678071    0.706734  0.028663  0.028663
# 209    0.677966    0.706347  0.028381  0.028381

# %%
result.describe()
# Out:
#        Close_pred  Close_true       rmse      Delta
# count   10.000000   10.000000  10.000000  10.000000
# mean     0.678111    0.708558   0.030446   0.030446
# std      0.000110    0.001717   0.001678   0.001678
# min      0.677966    0.706347   0.028381   0.028381
# 25%      0.678044    0.707692   0.029607   0.029607
# 50%      0.678083    0.708070   0.029896   0.029896
# 75%      0.678149    0.709327   0.031094   0.031094
# max      0.678304    0.711602   0.033441   0.033441

# %%
rmse = result.describe()['rmse'][1]
data_history.append([rmse,loss_test_set,shift_mn,epochs,steps_per_epoch,batch_size,sequence_length])
df = pd.DataFrame(data_history,columns=['rmse','trainScore','shift_mn',
                                        'epochs','steps_per_epoch','batch_size','sequence_length'])
df.head()
# Out:
#        rmse  trainScore  shift_mn  epochs  steps_per_epoch  batch_size  \
# 0  0.030446    0.154504         1     100              400           6
# 1  0.030446    0.154504         1     100              400           6
#
#    sequence_length
# 0              168
# 1              168

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                multiple                  6
# _________________________________________________________________
# dense_1 (Dense)              multiple                  2
# =================================================================
# Total params: 8
# Trainable params: 8
# Non-trainable params: 0
# _________________________________________________________________

# %%
error = pd.DataFrame()
error = ((result.iloc[:,1] - result.iloc[:,0])/result.iloc[:,1])*100
error.head()
# Out:
# 200    4.184319
# 201    4.190095
# 202    4.358272
# 203    4.628911
# 204    4.699430
# dtype: float32

# %%
plt.figure(figsize=(16,6),dpi=250)
plt.title="% d'erreur dans la prédiction à 15 minutes"
plt.plot(error,color='orange')

# %%
plt.figure(figsize=(16,6),dpi=250)
plt.plot(result.iloc[:,1],label='Actual',color='orange')
plt.plot(result.iloc[:,0],label='Predicted',color='purple')
plt.legend()

# %%
data_history = []

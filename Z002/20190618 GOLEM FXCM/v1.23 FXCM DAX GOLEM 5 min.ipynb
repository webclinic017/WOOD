# %%
TOKEN = 'e053ac1597cef331df9429ac8151100ea9f1c411'
server = 'demo'

# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'
ticker = 'GER30'
period = 'm5'
number = 8000
long_open = 90
long_close = 85
short_open = 90
short_close = 85
jet_lag = -2
pik_long = 0.08
pik_short = 0.08
targetup = 0.5
targetdown = 0.5
# Time Windows
# start = dt.datetime(2017, 7, 15)
# stop = dt.datetime(2017, 8, 1)
# con.get_candles('EUR/USD', period='D1',start=start, stop=stop)

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return True;
# }

# %%
pos_long = 0
pos_short = 0

# %%
___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor\n°OoO_FXCM_Oo0°\nLumberJack Jyss 5779(c)')
print('Version v1.22')
print('Importing librairies...')
import fxcmpy
print('version fxcmpy :',fxcmpy.__version__)
import time
import numpy as np
import pandas as pd
from colorama import Fore, Back, Style 
import datetime as dt
import talib
from zigzag import *
#import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
#from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report
print('Librairies imported')
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
buy_price = 0
sell_price = 0
pnl = 0
#try :

def connexion():
    tmps1=time.time()
    print('Connecting server...')
    con = fxcmpy.fxcmpy(access_token=TOKEN, log_level='error',server= server)
    if con.is_connected():
        print('Connection established for', Fore.BLUE + str(con.get_account_ids()[-1]),Style.RESET_ALL,' - Mode :',Fore.RED + server,Style.RESET_ALL)
    else:
        print('Not connected. Will try again in 10 seconds')
        dt.time(10)
        con = connexion()
    tmps2=round(time.time()-tmps1,2)
    print ("Connexion executed in = %f" %tmps2,'secondes')
    return(con)

def scrap_data(ticker,period,number):
    tmps1=time.time()
    data = con.get_candles(ticker, period=period,number=number) #start=start,stop=stop)
    df = pd.DataFrame()
    df['Open'] = data['askopen']
    df['High'] = data['askhigh']
    df['Low'] = data['asklow']
    df['Close'] = data['askclose']
    df['Date'] = data.index
    df = df[['Date'] + df.columns[:-1].tolist()]
    tmps2=round(time.time()-tmps1,2)
    print (Fore.GREEN + "Scrap (historical) executed in = %f"  %tmps2,'secondes',Style.RESET_ALL)
    return(df)

def prepa_data(df,pik_long, pik_short,targetup,targetdown):
    tmps1=time.time()
    df.reset_index(inplace=True,drop=True)
    dataset_1D = df.copy()
    dataset_1D = dataset_1D.dropna()
    rsi = talib.RSI(dataset_1D['Close'],timeperiod=2)
    upper, middle, lower =  talib.BBANDS(dataset_1D['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(dataset_1D['Close'],timeperiod=5)
    sma8 = talib.SMA(dataset_1D['Close'],timeperiod=8)
    sma10 = talib.SMA(dataset_1D['Close'],timeperiod=10)
    sma12 = talib.SMA(dataset_1D['Close'],timeperiod=12)
    sma15 = talib.SMA(dataset_1D['Close'],timeperiod=15)
    sma30 = talib.SMA(dataset_1D['Close'],timeperiod=30)
    sma35 = talib.SMA(dataset_1D['Close'],timeperiod=35)
    sma40 = talib.SMA(dataset_1D['Close'],timeperiod=40)
    sma45 = talib.SMA(dataset_1D['Close'],timeperiod=45)
    sma50 = talib.SMA(dataset_1D['Close'],timeperiod=50)
    aroondown, aroonup = talib.AROON(dataset_1D['High'], dataset_1D['Low'], timeperiod=25)
    aroon = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))

    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50

    X = dataset_1D['Close']
    pivots = peak_valley_pivots(X.values, pik_long, -pik_short)
    ts_pivots = pd.Series(X, index=X.index)
    ts_pivots = ts_pivots[pivots != 0]

    peak = []
    valley = []

    for i in range(0,dataset_1D.shape[0]):
        if pivots[i] == 1:
            peak.append(pivots[i])
            valley.append(0)
        elif pivots[i] == -1:
            peak.append(0)
            valley.append(pivots[i])
        else:
            peak.append(0)
            valley.append(0)

    bbdelta = upper - middle
    price_bolup = dataset_1D['Close'] - lower
    price_bolow = dataset_1D['Close'] - upper

    rsi5_list = []
    rsi95_list = []
    for i in range(0,dataset_1D.shape[0]):
        try:
            rsi95_list.append(95 - rsi[i])
            rsi5_list.append(rsi[i] - 5)
        except:
            rsi95_list.append(0)
            rsi5_list.append(0)
    varop_spy = dataset_1D['Open'] - dataset_1D['Close']
    varhl_spy = dataset_1D['High'] - dataset_1D['Low']
    dataset_1D['Varop_Spy'] = varop_spy
    dataset_1D['Varhl_spy'] = varhl_spy
    dataset_1D['RSI'] = rsi
    dataset_1D['Aroon'] = aroon
    dataset_1D['95 - RSI'] = np.array(rsi95_list)
    dataset_1D['RSI - 5'] = np.array(rsi5_list)
    dataset_1D['BBD_Delta_Up'] = bbdelta
    dataset_1D['delta5_8'] = delta5_8
    dataset_1D['delta8_10'] = delta8_10
    dataset_1D['delta10_12'] = delta10_12
    dataset_1D['delta12_15'] = delta12_15
    dataset_1D['delta15_30'] = delta15_30
    dataset_1D['delta30_35'] = delta30_35
    dataset_1D['delta35_40'] = delta35_40
    dataset_1D['delta40_45'] = delta40_45
    dataset_1D['delta45_50'] = delta45_50
    dataset_1D['Peaks'] = abs(np.array(peak))
    dataset_1D['Valley'] = abs(np.array(valley))
    tsf = talib.TSF(dataset_1D['Close'],timeperiod=14)
    delta_tsf = dataset_1D['Close'] - tsf
    dataset_1D['delta_tsf'] = tsf
    forosc = []
    forosc.append(0)
    for i in range(1,dataset_1D.shape[0]):
        try:
            forosc.append((dataset_1D.iloc[i,4] - tsf[i-1])*100/dataset_1D.iloc[i,4])
        except:
            forosc.append(0)
    dataset_1D['Forcast Oscillator'] = (forosc)
    target_up = []
    target_down = []

    for i in range(0,dataset_1D.shape[0]-5):

        if (dataset_1D.iloc[i+1,5] * dataset_1D.iloc[i,5]) < 0 :
            if (dataset_1D.iloc[i+1,4] - dataset_1D.iloc[i,4]) > targetup : 
                target_up.append(1)
                target_down.append(0)
            elif (dataset_1D.iloc[i+1,4] - dataset_1D.iloc[i,4]) < -targetdown: 
                target_up.append(0)
                target_down.append(1)
            else:
                target_up.append(0)
                target_down.append(0)
        else :
            target_up.append(0)
            target_down.append(0) 

    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    dataset_1D['target_up'] = target_up  # target_up # abs(np.array(valley))#target_up
    dataset_1D['target_down'] = target_down # target_down # abs(np.array(peak))#target_down
    dataset_1D['target_value'] = dataset_1D['Close']
    dataset_1D = dataset_1D.drop(['Open','High','Low','Close'],axis=1)
    df_1D = dataset_1D.copy()
    df_1D = df_1D.iloc[:,1:]
    df_1D['Date'] = df['Date']
    df_1D = df_1D.dropna()
    df_1D = df_1D[['Date'] + df_1D.columns[:-1].tolist()]
    df_1D.reset_index(inplace=True,drop=True)
    return(df_1D,aroon)
    
def deep_learning(df_1D):
    tmps1=time.time()
    X = df_1D.iloc[:,1:-3]
    y_up = df_1D.iloc[:,-3].values
    y_down = df_1D.iloc[:,-2].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:-1,:]
    Xtest = X[-1:,:]
    ytrain_up = y_up[:-1,:]
    ytest_up = y_up[-1:,:]
    ytrain_down = y_down[:-1,:]
    ytest_down = y_down[-1:,:]

    seed = 770
    np.random.seed(seed)

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    model_up = Sequential()
        # Add an input layer 
    model_up.add(Dense(30, activation='relu'))
        # Add one hidden layer 
    model_up.add(Dense(30, activation='relu'))
        # Add an output layer 
    model_up.add(Dense(1, activation='sigmoid'))

    model_down = Sequential()
        # Add an input layer 
    model_down.add(Dense(30, activation='relu'))
        # Add one hidden layer 
    model_down.add(Dense(30, activation='relu'))
        # Add an output layer 
    model_down.add(Dense(1, activation='sigmoid'))

    print('Processing move_up')
    model_up.compile(loss='binary_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy','mse'])

    history_up = model_up.fit(Xtrain, ytrain_up,epochs=50, batch_size=32, verbose=0)

    print('Processing move_down')
    model_down.compile(loss='binary_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy','mse'])

    history_down = model_down.fit(Xtrain, ytrain_down,epochs=50, batch_size=32, verbose=0)

    print('Computing done')


    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)
    resultats = pd.DataFrame()
    resultats['Date'] = df_1D.iloc[-1:,0]
    resultats['Move Up'] = yhat_up
    resultats['Confidence up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confidence Down'] = (predict_down)*100
    resultats['Actual'] = df_1D['target_value']
    tmps2=round(time.time()-tmps1,2)
    print ("DL executed in = %f" %tmps2,'seconds')
    print('Results :\n \033[31m', resultats,'\n',Style.RESET_ALL)
    return(resultats,scaler,model_up,model_down)

def main(con,ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik_long, pik_short,targetup,targetdown,pos_long,pos_short):
    
    for ukulele in range (0,500):

        # CONNEXION TESTING
        if con.is_connected() == False:
            con = connexion()
            time.sleep(3)
        print(' \n MEGA LOOP ',ukulele,'\n')
        df = scrap_data(ticker,period,number)

        print('\033[33m' + 'Initializing GOLEM...')
        print('\033[35m' +'Long Pos =',pos_long)
        print('Short Pos =',pos_short,Style.RESET_ALL)


        # DATA PREPARATION
        df_1D,aroon = prepa_data(df,pik_long, pik_short,targetup,targetdown)

        print('\033[36m'+'GOLEM begins Computing...'+Style.RESET_ALL)

        # DEEP LEARNING

        resultats,scaler,model_up,model_down = deep_learning (df_1D)

        # TESTING POSITIONS

        # TEST POS
        print('Aroon :',aroon.iloc[-1])
        print('Long Pos =',pos_long)
        print('Short Pos =',pos_short)
        print('Initializing GOLEM on STREAMING LIVE...')
        print('Long Pos =',pos_long)
        print('Short Pos =',pos_short)
        # SCRAP DATA
        print('Instrument :', ticker)

        for loop in range(0,2000):

            #print(' \n INFRA LOOP ',loop,'\n')
            if con.is_connected() == False:
                con = connexion()

            tmps1=time.time()
            con.subscribe_market_data(ticker)

            last = con.get_candles(ticker, period=period,number=1)
            try:
                pnl = con.get_open_positions().iloc[0,-1]
            except :
                pass
            if last.index[-1].minute < df.iloc[-1,0].minute+5 :
                if  pos_long == 0 and pos_short == 1 and pnl > 7:
                    tradeId_short = con.get_open_trade_ids()[-1]
                    order = con.close_trade(trade_id=tradeId_short, amount=30)
                    pos_short = 0
                    print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')
                
                if  pos_long == 0 and pos_short == 1 and pnl < -21:
                    tradeId_short = con.get_open_trade_ids()[-1]
                    order = con.close_trade(trade_id=tradeId_short, amount=30)
                    pos_short = 0
                    print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')
                    
                if  pos_long == 1 and pos_short == 0 and pnl > 7:
                    tradeId_long = con.get_open_trade_ids()[-1]
                    order = con.close_trade(trade_id=tradeId_long, amount=30)
                    print('\033[47m \033[31m Close Long avec un pnl de', pnl,'\033[0m')
                    pos_long = 0
                
                if  pos_long == 1 and pos_short == 0 and pnl < -21:
                    tradeId_long = con.get_open_trade_ids()[-1]
                    order = con.close_trade(trade_id=tradeId_long, amount=30)
                    print('\033[47m \033[31m Close Long avec un pnl de', pnl,'\033[0m')
                    pos_long = 0
                print('\033[43m'+' Tempo '+'\033[0m'+'\033[46m'+'...'+'\033[0m',end='')                
                continue

            else :
                df = df.iloc[1:,:]
                df = df.append({'Date':last.index[-1],'Open':last.iloc[-1,4], 'High':last.iloc[-1,6],'Low':last.iloc[-1,7], 'Close':last.iloc[-1,5]}, ignore_index=True)

                df_1D,aroon = prepa_data(df,pik_long, pik_short,targetup,targetdown)

                # TESTING ONLY
                print()
                print('GOLEM begins testing...')

                X = df_1D.iloc[:,1:-3]
                X = scaler.fit_transform(X)
                Xtest = X[-1:,:]

                seed = 770
                np.random.seed(seed)

                yhat_up = model_up.predict_classes(Xtest)
                yhat_down = model_down.predict_classes(Xtest)

                predict_up = model_up.predict(Xtest)
                predict_down = model_down.predict(Xtest)
                resultats = pd.DataFrame()
                resultats['Date'] = df_1D.iloc[-1:,0]
                resultats['Move Up'] = yhat_up
                resultats['Confidence up'] = (predict_up)*100
                resultats['Move Down'] = yhat_down
                resultats['Confidence Down'] = (predict_down)*100
                resultats['Actual'] = df_1D['target_value']
                #resultats,scaler,model_up,model_down = deep_learning (df_1D)
                tmps2=round(time.time()-tmps1,2)
                print ("Testing executed in = %f" %tmps2,'secondes')
                print('Time of request', Fore.BLUE)
                print(dt.datetime.now().hour+jet_lag,'H',dt.datetime.now().minute,'min',dt.datetime.now().second,'seconds',Style.RESET_ALL)
                print('Results :\n')
                print('\033[45m')
                print(resultats)
                print(Style.RESET_ALL)
                
                # TEST POSITION EN L'AIR
                if pos_long == 0 and pos_short == 0:
                    try:
                        if con.get_open_positions().iloc[0,8] == True:
                            pos_long = 1
                        if con.get_open_positions().iloc[0,8] == False:
                            pos_short
                    except:
                        print("Pas de position en l'air")
                    
                
                # TEST OUVERTURE
                try : 
                    
                    if con.get_open_positions().iloc[0,2] != 0.03:
                        pos_long = 0
                        pos_short = 0
                except:
                    pass

                if pos_long == 1:

                    pnl = con.get_open_positions().iloc[0,-1]
                    if pnl > 0 :
                        print('\033[42m pnl : ',round(pnl,2),'\033[0m')
                    elif pnl < 0:
                        print('\033[41m pnl : ',round(pnl,2),'\033[0m')
                elif pos_short == 1:

                    pnl = con.get_open_positions().iloc[0,-1]
                    if pnl > 0 :
                        print('\033[42m pnl : ',round(pnl,2),'\033[0m')
                    elif pnl < 0:
                        print('\033[41m pnl : ',round(pnl,2),'\033[0m')

                print('Aroon :',aroon.iloc[-1])
                print('Long Pos =',pos_long)
                print('Short Pos =',pos_short)

                # ACTIONS
                if con.is_connected() == False:
                    con = connexion()
                
                if  pos_long == 0 and pos_short == 1 and pnl > 7:
                    tradeId_short = con.get_open_trade_ids()[-1]
                    order = con.close_trade(trade_id=tradeId_short, amount=30)
                    time.sleep(10)
                    pos_short = 0
                    print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')
                
                if  pos_long == 0 and pos_short == 1 and pnl < -21:
                    tradeId_short = con.get_open_trade_ids()[-1]
                    order = con.close_trade(trade_id=tradeId_short, amount=30)
                    time.sleep(10)
                    pos_short = 0
                    print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')
                    
                if  pos_long == 1 and pos_short == 0 and pnl > 7:
                    tradeId_long = con.get_open_trade_ids()[-1]
                    order = con.close_trade(trade_id=tradeId_long, amount=30)
                    time.sleep(10)
                    print('\033[47m \033[31m Close Long avec un pnl de', pnl,'\033[0m')
                    pos_long = 0
                
                if  pos_long == 1 and pos_short == 0 and pnl < -21:
                    tradeId_long = con.get_open_trade_ids()[-1]
                    order = con.close_trade(trade_id=tradeId_long, amount=30)
                    time.sleep(10)
                    print('\033[47m \033[31m Close Long avec un pnl de', pnl,'\033[0m')
                    pos_long = 0
                    
                if resultats.iloc[0,1] == 1 and resultats.iloc[0,2] > short_close:

                    if  pos_long == 0 and pos_short == 1 :
                        #order = con.close_all_for_symbol(ticker)
                        tradeId_short = con.get_open_trade_ids()[-1]
                        pnl = con.get_open_positions().iloc[0,-1]
                        order = con.close_trade(trade_id=tradeId_short, amount=30)
                        time.sleep(10)
                        pos_short = 0
                        print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')


                    if pos_long == 0 and pos_short == 0 and resultats.iloc[0,2] > long_open:
                        #order = con.create_market_buy_order(ticker, 30)
                        order = con.open_trade(symbol=ticker,is_buy=True,amount=30,order_type='MarketRange',time_in_force='IOC')#,\
                                               #stop=(last.iloc[-1,5]-2.0))
                        time.sleep(10)
                        print('Go Long')
                        print('Buy Price :',con.get_open_positions().iloc[0,11])
                        buy_price = con.get_open_positions().iloc[0,11]
                        pos_long = 1



                elif resultats.iloc[0,3] == 1 and resultats.iloc[0,4] > long_close:

                    if  pos_long == 1 and pos_short == 0:
                        #order = con.close_all_for_symbol(ticker)
                        tradeId_long = con.get_open_trade_ids()[-1]
                        pnl = con.get_open_positions().iloc[0,-1]
                        order = con.close_trade(trade_id=tradeId_long, amount=30)
                        time.sleep(10)
                        print('\033[47m \033[31m Close Long avec un pnl de', pnl,'\033[0m')
                        pos_long = 0

                    if pos_long == 0 and pos_short == 0 and resultats.iloc[0,4] > short_open:
                        #order = con.create_market_sell_order(ticker, 30)
                        order = con.open_trade(symbol=ticker,is_buy=False,amount=30,order_type='MarketRange',time_in_force='IOC')#,\
                                               #stop=(last.iloc[-1,5]+2.0))
                        time.sleep(10)
                        print('Go Short')
                        print('Sell Price :',con.get_open_positions().iloc[0,11])
                        sell_price = con.get_open_positions().iloc[0,11]
                        pos_short = 1
    return(con)

try:
    con = connexion()
except:
    con = fxcmpy.fxcmpy
    main(con,ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik_long, pik_short,targetup,targetdown,pos_long,pos_short) 
main(con,ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik_long, pik_short,targetup,targetdown,pos_long,pos_short)
# Out:
# Global Optimized LumberJack Environment Motor
# °OoO_FXCM_Oo0°
# LumberJack Jyss 5779(c)
# Version v1.22
# Importing librairies...
# version fxcmpy : 1.2.4
# Librairies imported
# Connecting server...
# W0625 13:23:37.715523 4576486848 fxcmpy.py:222] Default account set to 1147539, to change use set_default_account().
# Connection established for 1147539   - Mode : demo
# Connexion executed in = 11.670000 secondes
#
#  MEGA LOOP  0
#
# Scrap (historical) executed in = 2.380000 secondes
# Initializing GOLEM...
# Long Pos = 0
# Short Pos = 0
# GOLEM begins Computing...
# Processing move_up
# Processing move_down
# Computing done
# DL executed in = 25.820000 seconds
# Results :
#                       Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-25 11:15:00        0       2.431104          0        44.102295
#
#        Actual
# 7950  12261.8
#
# Aroon : 24.0
# Long Pos = 0
# Short Pos = 0
# Initializing GOLEM on STREAMING LIVE...
# Long Pos = 0
# Short Pos = 0
# Instrument : GER30
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 3.230000 secondes
# Time of request
# 11 H 25 min 2 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-25 11:20:00        0       2.117368          0        43.780117
#
#        Actual
# 7950  12262.3
#
# Pas de position en l'air
# Aroon : 24.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 2.740000 secondes
# Time of request
# 11 H 30 min 0 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-25 11:25:00        0      20.793303          0        24.584745
#
#        Actual
# 7950  12260.1
#
# Pas de position en l'air
# Aroon : -20.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 2.370000 secondes
# Time of request
# 11 H 35 min 2 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-25 11:30:00        0        21.8741          0         7.635467
#
#        Actual
# 7950  12258.1
#
# Pas de position en l'air
# Aroon : -20.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 3.720000 secondes
# Time of request
# 11 H 40 min 2 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-25 11:35:00        0      22.689386          0         3.583468
#
#        Actual
# 7950  12255.7
#
# Pas de position en l'air
# Aroon : -20.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 5.790000 secondes
# Time of request
# 11 H 45 min 6 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-25 11:40:00        0      29.052956          0         1.434425
#
#        Actual
# 7950  12247.2
#
# Pas de position en l'air
# Aroon : -20.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 4.150000 secondes
# Time of request
# 11 H 50 min 4 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-25 11:45:00        0      18.004995          0        12.337132
#
#        Actual
# 7950  12248.0
#
# Pas de position en l'air
# Aroon : -20.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 2.830000 secondes
# Time of request
# 11 H 55 min 2 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-25 11:50:00        0        6.85557          0        44.272091
#
#        Actual
# 7950  12252.2
#
# Pas de position en l'air
# Aroon : -20.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 13.620000 secondes
# Time of request
# 12 H 0 min 14 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-25 11:55:00        0       16.71846          0        28.577591
#
#        Actual
# 7950  12251.1
#
# Pas de position en l'air
# Aroon : 56.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... ...
#  MEGA LOOP  1
#
# Scrap (historical) executed in = 2.190000 secondes
# Initializing GOLEM...
# Long Pos = 0
# Short Pos = 0
# GOLEM begins Computing...
# Processing move_up
# Processing move_down
# Computing done
# DL executed in = 27.590000 seconds
# Results :
#                       Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-25 12:50:00        0       1.152271          1         54.23407
#
#        Actual
# 7950  12257.1
#
# Aroon : -20.0
# Long Pos = 0
# Short Pos = 0
# Initializing GOLEM on STREAMING LIVE...
# Long Pos = 0
# Short Pos = 0
# Instrument : GER30
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 5.850000 secondes
# Time of request
# 13 H 0 min 4 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-25 12:55:00        0        1.19978          1        54.813927
#
#        Actual
# 7950  12258.1
#
# Pas de position en l'air
# Aroon : -20.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ...
# W0625 15:00:13.203066 123145571500032 fxcmpy.py:2681] Got a insert event for open positions: {'t': 1, 'ratePrecision': 2, 'tradeId': '152716175', 'accountName': '01147539', 'accountId': '1147539', 'roll': 0, 'com': 0, 'open': 2946.88, 'valueDate': '', 'grossPL': -10.00544, 'close': 2946.5, 'visiblePL': -3.8, 'isDisabled': False, 'currency': 'SPX500', 'isBuy': True, 'amountK': 0.03, 'currencyPoint': 0.00263, 'time': '06252019130012', 'usedMargin': 2100, 'stop': 0, 'stopMove': 0, 'limit': 0, 'action': 'I'}.
# W0625 15:00:13.477108 123145571500032 fxcmpy.py:2603] Got a delete event for orders: {'t': 3, 'orderId': '319150592', 'action': 'D'}.
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# W0625 15:07:12.930510 123145571500032 fxcmpy.py:2733] Got a insert event for closed positions: {'t': 2, 'ratePrecision': 2, 'tradeId': '152716175', 'accountName': '01147539', 'roll': 0, 'com': 0, 'open': 2946.88, 'valueDate': '', 'grossPL': 21.59, 'close': 2947.7, 'visiblePL': 8.2, 'currency': 'SPX500', 'isBuy': True, 'amountK': 0.03, 'currencyPoint': 0.00263, 'openTime': '06252019130012', 'closeTime': '06252019130712', 'action': 'I'}.
# W0625 15:07:12.932013 123145571500032 fxcmpy.py:2684] Got a delete event for open posi: {'t': 1, 'tradeId': '152716175', 'action': 'D'}
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... ...
# E0625 15:30:19.955379 4576486848 fxcmpy.py:2506] Server reports an error: {'executed': False, 'error': 'Unauthorized'}.
# E0625 15:30:19.956345 4576486848 fxcmpy.py:2507] URL: https://api-demo.fxcm.com:443/trading/get_model?models=OpenPosition
# E0625 15:30:19.957503 4576486848 fxcmpy.py:2508] Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer Eqv-RrW9mPIUoL5CAC0Ae053ac1597cef331df9429ac8151100ea9f1c411', 'Content-Type': 'application/x-www-form-urlencoded'}
# E0625 15:30:19.958343 4576486848 fxcmpy.py:2509] Params: {'models': ['OpenPosition']}
# E0625 15:30:19.959115 4576486848 fxcmpy.py:2510] Bearer token: Bearer Eqv-RrW9mPIUoL5CAC0Ae053ac1597cef331df9429ac8151100ea9f1c411
# E0625 15:30:19.959803 4576486848 fxcmpy.py:2512] Connection status: established
# E0625 15:30:19.960471 4576486848 fxcmpy.py:2514] Socket session id: Eqv-RrW9mPIUoL5CAC0A
# E0625 15:30:19.961143 4576486848 fxcmpy.py:2525] Can not parse server answer to json object: {"response":{"executed":false,"error":"Unauthorized"}}.
#  Tempo ...
# E0625 15:30:20.624150 4576486848 fxcmpy.py:2506] Server reports an error: {'executed': False, 'error': 'Unauthorized'}.
# E0625 15:30:20.625350 4576486848 fxcmpy.py:2507] URL: https://api-demo.fxcm.com:443/subscribe
# E0625 15:30:20.626466 4576486848 fxcmpy.py:2508] Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer Eqv-RrW9mPIUoL5CAC0Ae053ac1597cef331df9429ac8151100ea9f1c411', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '11'}
# E0625 15:30:20.627198 4576486848 fxcmpy.py:2509] Params: {'pairs': 'GER30'}
# E0625 15:30:20.627916 4576486848 fxcmpy.py:2510] Bearer token: Bearer Eqv-RrW9mPIUoL5CAC0Ae053ac1597cef331df9429ac8151100ea9f1c411
# E0625 15:30:20.629034 4576486848 fxcmpy.py:2512] Connection status: established
# E0625 15:30:20.629786 4576486848 fxcmpy.py:2514] Socket session id: Eqv-RrW9mPIUoL5CAC0A
# E0625 15:30:20.630849 4576486848 fxcmpy.py:2525] Can not parse server answer to json object: {"response":{"executed":false,"error":"Unauthorized"},"pairs":[]}.
# E0625 15:30:21.493622 4576486848 fxcmpy.py:2506] Server reports an error: {'executed': False, 'error': 'Unauthorized'}.
# E0625 15:30:21.494621 4576486848 fxcmpy.py:2507] URL: https://api-demo.fxcm.com:443/candles/1004/m5?num=1
# E0625 15:30:21.495937 4576486848 fxcmpy.py:2508] Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer Eqv-RrW9mPIUoL5CAC0Ae053ac1597cef331df9429ac8151100ea9f1c411', 'Content-Type': 'application/x-www-form-urlencoded'}
# E0625 15:30:21.496685 4576486848 fxcmpy.py:2509] Params: {'num': 1}
# E0625 15:30:21.497487 4576486848 fxcmpy.py:2510] Bearer token: Bearer Eqv-RrW9mPIUoL5CAC0Ae053ac1597cef331df9429ac8151100ea9f1c411
# E0625 15:30:21.498234 4576486848 fxcmpy.py:2512] Connection status: established
# E0625 15:30:21.498863 4576486848 fxcmpy.py:2514] Socket session id: Eqv-RrW9mPIUoL5CAC0A
# E0625 15:30:21.499524 4576486848 fxcmpy.py:2525] Can not parse server answer to json object: {"response":{"executed":false,"error":"Unauthorized"},"instrument_id":0,"period_id":0,"candles":[]}.
# E0625 15:30:22.520533 4576486848 fxcmpy.py:2506] Server reports an error: {'executed': False, 'error': 'Unauthorized'}.
# E0625 15:30:22.521510 4576486848 fxcmpy.py:2507] URL: https://api-demo.fxcm.com:443/trading/get_model?models=OpenPosition
# E0625 15:30:22.522253 4576486848 fxcmpy.py:2508] Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer Eqv-RrW9mPIUoL5CAC0Ae053ac1597cef331df9429ac8151100ea9f1c411', 'Content-Type': 'application/x-www-form-urlencoded'}
# E0625 15:30:22.523589 4576486848 fxcmpy.py:2509] Params: {'models': ['OpenPosition']}
# E0625 15:30:22.524327 4576486848 fxcmpy.py:2510] Bearer token: Bearer Eqv-RrW9mPIUoL5CAC0Ae053ac1597cef331df9429ac8151100ea9f1c411
# E0625 15:30:22.524998 4576486848 fxcmpy.py:2512] Connection status: established
# E0625 15:30:22.525692 4576486848 fxcmpy.py:2514] Socket session id: Eqv-RrW9mPIUoL5CAC0A
# E0625 15:30:22.527137 4576486848 fxcmpy.py:2525] Can not parse server answer to json object: {"response":{"executed":false,"error":"Unauthorized"}}.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-7b5148e4bfca> in <module>
#     504     con = fxcmpy.fxcmpy
#     505     main(con,ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik_long, pik_short,targetup,targetdown,pos_long,pos_short)
# --> 506 main(con,ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik_long, pik_short,targetup,targetdown,pos_long,pos_short)
#
# <ipython-input-12-7b5148e4bfca> in main(con, ticker, period, number, long_open, long_close, short_open, short_close, jet_lag, pik_long, pik_short, targetup, targetdown, pos_long, pos_short)
#     316             except :
#     317                 pass
# --> 318             if last.index[-1].minute < df.iloc[-1,0].minute+5 :
#     319                 if  pos_long == 0 and pos_short == 1 and pnl > 7:
#     320                     tradeId_short = con.get_open_trade_ids()[-1]
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/pandas/core/indexes/datetimelike.py in __getitem__(self, key)
#     401         getitem = self._data.__getitem__
#     402         if is_int:
# --> 403             val = getitem(key)
#     404             return self._box_func(val)
#     405         else:
#
# IndexError: index -1 is out of bounds for axis 0 with size 0
# W0625 16:31:32.154160 123145547038720 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 54] Connection reset by peer)
# W0625 16:31:32.266672 123145571500032 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 54] Connection reset by peer)
# W0625 17:44:31.456073 123145547038720 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 60] Operation timed out)
# W0625 17:44:38.276516 123145571500032 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 60] Operation timed out)
# W0626 01:34:21.869407 123145547038720 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 54] Connection reset by peer)
# W0626 01:34:28.586418 123145571500032 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 54] Connection reset by peer)
# W0626 06:14:00.883673 123145571500032 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] ('Connection aborted.', OSError("(54, 'ECONNRESET')",))
# W0626 06:14:00.888378 123145547038720 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] ('Connection aborted.', OSError("(54, 'ECONNRESET')",))
# W0626 09:05:16.359354 123145547038720 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 54] Connection reset by peer)
# W0626 09:05:16.664572 123145571500032 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 54] Connection reset by peer)
# W0626 09:20:46.643748 123145547038720 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561533586631-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x109965f28>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0626 09:20:46.656553 123145571500032 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561533586648-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1099650f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0626 10:00:24.523162 123145571500032 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected (Connection is already closed.)
# W0626 10:00:24.524341 123145547038720 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected (Connection is already closed.)
# W0626 10:00:26.185018 123145571500032 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] ('Connection aborted.', OSError("(54, 'ECONNRESET')",))
# W0626 10:00:26.192709 123145547038720 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] ('Connection aborted.', OSError("(54, 'ECONNRESET')",))
# W0626 10:17:17.154577 123145547038720 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 60] Operation timed out)
# W0626 10:19:24.530725 123145571500032 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 60] Operation timed out)
# W0626 13:33:04.617873 123145547038720 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 50] Network is down)
# W0626 14:59:12.400132 123145547038720 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 54] Connection reset by peer)
# W0626 14:59:12.474519 123145571500032 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 54] Connection reset by peer)
# W0626 14:59:14.123213 123145571500032 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] ('Connection aborted.', OSError("(54, 'ECONNRESET')",))
# W0626 14:59:14.145231 123145547038720 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] ('Connection aborted.', OSError("(54, 'ECONNRESET')",))
# W0626 15:02:51.702970 123145571500032 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 54] Connection reset by peer)
# W0626 15:02:51.718847 123145547038720 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 54] Connection reset by peer)
# Exception in thread Thread-11:
# Traceback (most recent call last):
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/fxcmpy/fxcmpy.py", line 2370, in __connect__
#     self.socket.wait()
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/__init__.py", line 251, in wait
#     self._process_packets()
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/__init__.py", line 276, in _process_packets
#     for engineIO_packet in self._transport.recv_packet():
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/transports.py", line 158, in recv_packet
#     packet_text)
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/parsers.py", line 96, in parse_packet_text
#     packet_type = int(get_character(packet_text, 0))
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/symmetries.py", line 33, in get_character
#     return chr(get_byte(x, index))
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/symmetries.py", line 29, in get_byte
#     return indexbytes(x, index)
# IndexError: index out of range
#
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/fxcmpy/fxcmpy.py", line 2370, in __connect__
#     self.socket.wait()
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/__init__.py", line 251, in wait
#     self._process_packets()
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/__init__.py", line 276, in _process_packets
#     for engineIO_packet in self._transport.recv_packet():
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/transports.py", line 158, in recv_packet
#     packet_text)
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/parsers.py", line 96, in parse_packet_text
#     packet_type = int(get_character(packet_text, 0))
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/symmetries.py", line 33, in get_character
#     return chr(get_byte(x, index))
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/symmetries.py", line 29, in get_byte
#     return indexbytes(x, index)
# IndexError: index out of range

# %%
# PNL con.get_open_positions().iloc[0,-1]

# %%
# BUY/SELL PRICE con.get_open_positions().iloc[0,11]

# %%
# IS BUY OR IS SELL = con.get_open_positions().iloc[0,8]

# %%
# AMOUNTK = con.get_open_positions().iloc[0,2] == 0.03

# %%
# Short =>

# %%
# Long =>

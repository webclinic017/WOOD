# %%
# TOKEN = 'e053ac1597cef331df9429ac8151100ea9f1c411'
# server = 'demo'
user_id = ' D261151986'
password = '2786'
# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'
ticker = 'SPX500'
period = 'm5'
number = 8000
long_open = 95
long_close = 85
short_open = 95
short_close = 85
jet_lag = -2
pik_long = 0.008
pik_short = 0.008
targetup = 1
targetdown = 1
# Time Windows
# start = dt.datetime(2017, 7, 15)
# stop = dt.datetime(2017, 8, 1)
# con.get_candles('EUR/USD', period='D1',start=start, stop=stop)

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return True;
# }

# %%
pos_long = 0
pos_short = 0

# %%
___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor\n°OoO_FXCM_Oo0°\nLumberJack Jyss 5779(c)')
print('Version v1.30')
print('Importing librairies...')
import fxcmpy
print('version fxcmpy :',fxcmpy.__version__)
import forexconnect
from forexconnect import fxcorepy
from forexconnect import ForexConnect, ResponseListener, Common
import time
import numpy as np
import pandas as pd
from colorama import Fore, Back, Style 
import datetime as dt
import talib
from zigzag import *
#import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
#from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report
print('Librairies imported')
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
buy_price = 0
sell_price = 0
pnl = 0
#try :

def session_status_changed(session: fxcorepy.O2GSession,
                           status: fxcorepy.AO2GSessionStatus.O2GSessionStatus):
    print("Trading session status: " + str(status))



def scrap_data(ticker,period,number):
    tmps1=time.time()
    data = fx.get_history(ticker, period,
                                    datetime.datetime.strptime("MM.DD.YYYY HH:MM:SS", '%m.%d.%Y %H:%M:%S').replace(tzinfo=datetime.timezone.utc),
                                    datetime.datetime.strptime("MM.DD.YYYY HH:MM:SS", '%m.%d.%Y %H:%M:%S').replace(tzinfo=datetime.timezone.utc))
    df = pd.DataFrame()
    df['Open'] = data['askopen']
    df['High'] = data['askhigh']
    df['Low'] = data['asklow']
    df['Close'] = data['askclose']
    df['Date'] = data.index
    df = df[['Date'] + df.columns[:-1].tolist()]
    tmps2=round(time.time()-tmps1,2)
    print (Fore.GREEN + "Scrap (historical) executed in = %f"  %tmps2,'secondes',Style.RESET_ALL)
    return(df)

def log_out():
    try:
        fx.logout()
    except Exception as e:
        print("Exception: " + str(e))
    return

def prepa_data(df,pik_long, pik_short,targetup,targetdown):
    tmps1=time.time()
    df.reset_index(inplace=True,drop=True)
    dataset_1D = df.copy()
    dataset_1D = dataset_1D.dropna()
    rsi = talib.RSI(dataset_1D['Close'],timeperiod=2)
    upper, middle, lower =  talib.BBANDS(dataset_1D['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(dataset_1D['Close'],timeperiod=5)
    sma8 = talib.SMA(dataset_1D['Close'],timeperiod=8)
    sma10 = talib.SMA(dataset_1D['Close'],timeperiod=10)
    sma12 = talib.SMA(dataset_1D['Close'],timeperiod=12)
    sma15 = talib.SMA(dataset_1D['Close'],timeperiod=15)
    sma30 = talib.SMA(dataset_1D['Close'],timeperiod=30)
    sma35 = talib.SMA(dataset_1D['Close'],timeperiod=35)
    sma40 = talib.SMA(dataset_1D['Close'],timeperiod=40)
    sma45 = talib.SMA(dataset_1D['Close'],timeperiod=45)
    sma50 = talib.SMA(dataset_1D['Close'],timeperiod=50)
    aroondown, aroonup = talib.AROON(dataset_1D['High'], dataset_1D['Low'], timeperiod=25)
    aroon = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))

    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50

    X = dataset_1D['Close']
    pivots = peak_valley_pivots(X.values, pik_long, -pik_short)
    ts_pivots = pd.Series(X, index=X.index)
    ts_pivots = ts_pivots[pivots != 0]

    peak = []
    valley = []

    for i in range(0,dataset_1D.shape[0]):
        if pivots[i] == 1:
            peak.append(pivots[i])
            valley.append(0)
        elif pivots[i] == -1:
            peak.append(0)
            valley.append(pivots[i])
        else:
            peak.append(0)
            valley.append(0)

    bbdelta = upper - middle
    price_bolup = dataset_1D['Close'] - lower
    price_bolow = dataset_1D['Close'] - upper

    rsi5_list = []
    rsi95_list = []
    for i in range(0,dataset_1D.shape[0]):
        try:
            rsi95_list.append(95 - rsi[i])
            rsi5_list.append(rsi[i] - 5)
        except:
            rsi95_list.append(0)
            rsi5_list.append(0)
    varop_spy = dataset_1D['Open'] - dataset_1D['Close']
    varhl_spy = dataset_1D['High'] - dataset_1D['Low']
    dataset_1D['Varop_Spy'] = varop_spy
    dataset_1D['Varhl_spy'] = varhl_spy
    dataset_1D['RSI'] = rsi
    dataset_1D['Aroon'] = aroon
    dataset_1D['95 - RSI'] = np.array(rsi95_list)
    dataset_1D['RSI - 5'] = np.array(rsi5_list)
    dataset_1D['BBD_Delta_Up'] = bbdelta
    dataset_1D['delta5_8'] = delta5_8
    dataset_1D['delta8_10'] = delta8_10
    dataset_1D['delta10_12'] = delta10_12
    dataset_1D['delta12_15'] = delta12_15
    dataset_1D['delta15_30'] = delta15_30
    dataset_1D['delta30_35'] = delta30_35
    dataset_1D['delta35_40'] = delta35_40
    dataset_1D['delta40_45'] = delta40_45
    dataset_1D['delta45_50'] = delta45_50
    dataset_1D['Peaks'] = abs(np.array(peak))
    dataset_1D['Valley'] = abs(np.array(valley))
    tsf = talib.TSF(dataset_1D['Close'],timeperiod=14)
    delta_tsf = dataset_1D['Close'] - tsf
    dataset_1D['delta_tsf'] = tsf
    forosc = []
    forosc.append(0)
    for i in range(1,dataset_1D.shape[0]):
        try:
            forosc.append((dataset_1D.iloc[i,4] - tsf[i-1])*100/dataset_1D.iloc[i,4])
        except:
            forosc.append(0)
    dataset_1D['Forcast Oscillator'] = (forosc)
    target_up = []
    target_down = []

    for i in range(0,dataset_1D.shape[0]-5):

        if (dataset_1D.iloc[i+1,5] * dataset_1D.iloc[i,5]) < 0 :
            if (dataset_1D.iloc[i+1,4] - dataset_1D.iloc[i,4]) > targetup : 
                target_up.append(1)
                target_down.append(0)
            elif (dataset_1D.iloc[i+1,4] - dataset_1D.iloc[i,4]) < -targetdown: 
                target_up.append(0)
                target_down.append(1)
            else:
                target_up.append(0)
                target_down.append(0)
        else :
            target_up.append(0)
            target_down.append(0) 

    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    dataset_1D['target_up'] = target_up  # target_up # abs(np.array(valley))#target_up
    dataset_1D['target_down'] = target_down # target_down # abs(np.array(peak))#target_down
    dataset_1D['target_value'] = dataset_1D['Close']
    dataset_1D = dataset_1D.drop(['Open','High','Low','Close'],axis=1)
    df_1D = dataset_1D.copy()
    df_1D = df_1D.iloc[:,1:]
    df_1D['Date'] = df['Date']
    df_1D = df_1D.dropna()
    df_1D = df_1D[['Date'] + df_1D.columns[:-1].tolist()]
    df_1D.reset_index(inplace=True,drop=True)
    return(df_1D,aroon)
    
def deep_learning(df_1D):
    tmps1=time.time()
    X = df_1D.iloc[:,1:-3]
    y_up = df_1D.iloc[:,-3].values
    y_down = df_1D.iloc[:,-2].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:-1,:]
    Xtest = X[-1:,:]
    ytrain_up = y_up[:-1,:]
    ytest_up = y_up[-1:,:]
    ytrain_down = y_down[:-1,:]
    ytest_down = y_down[-1:,:]

    seed = 770
    np.random.seed(seed)

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    model_up = Sequential()
        # Add an input layer 
    model_up.add(Dense(23, activation='relu'))
        # Add one hidden layer 
    model_up.add(Dense(50, activation='relu'))
        # Add an output layer 
    model_up.add(Dense(1, activation='sigmoid'))

    model_down = Sequential()
        # Add an input layer 
    model_down.add(Dense(23, activation='relu'))
        # Add one hidden layer 
    model_down.add(Dense(50, activation='relu'))
        # Add an output layer 
    model_down.add(Dense(1, activation='sigmoid'))

    print('Processing move_up')
    model_up.compile(loss='binary_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy','mse'])

    history_up = model_up.fit(Xtrain, ytrain_up,epochs=50, batch_size=32, verbose=0)

    print('Processing move_down')
    model_down.compile(loss='binary_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy','mse'])

    history_down = model_down.fit(Xtrain, ytrain_down,epochs=50, batch_size=32, verbose=0)

    print('Computing done')


    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)
    resultats = pd.DataFrame()
    resultats['Date'] = df_1D.iloc[-1:,0]
    resultats['Move Up'] = yhat_up
    resultats['Confidence up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confidence Down'] = (predict_down)*100
    resultats['Actual'] = df_1D['target_value']
    tmps2=round(time.time()-tmps1,2)
    print ("DL executed in = %f" %tmps2,'seconds')
    print('Results :\n \033[31m', resultats,'\n',Style.RESET_ALL)
    return(resultats,scaler,model_up,model_down)

def main(ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik_long, pik_short,targetup,targetdown,pos_long,pos_short):
    with ForexConnect() as fx:
        try:
            fx.login("user_id", "password", "url",
                     "connection", session_status_callback=session_status_changed)

            for ukulele in range (0,500):
                
                print(' \n MEGA LOOP ',ukulele,'\n')
                df = scrap_data(ticker,period,number)

                print('\033[33m' + 'Initializing GOLEM...')
                print('\033[35m' +'Long Pos =',pos_long)
                print('Short Pos =',pos_short,Style.RESET_ALL)


                # DATA PREPARATION
                df_1D,aroon = prepa_data(df,pik_long, pik_short,targetup,targetdown)

                print('\033[36m'+'GOLEM begins Computing...'+Style.RESET_ALL)

                # DEEP LEARNING

                resultats,scaler,model_up,model_down = deep_learning (df_1D)

                # TESTING POSITIONS

                # TEST POS
                print('Aroon :',aroon.iloc[-1])
                print('Long Pos =',pos_long)
                print('Short Pos =',pos_short)
                print('Initializing GOLEM on STREAMING LIVE...')
                print('Long Pos =',pos_long)
                print('Short Pos =',pos_short)
                # SCRAP DATA
                print('Instrument :', ticker)

                for loop in range(0,2000):

                    #print(' \n INFRA LOOP ',loop,'\n')
                    
                    tmps1=time.time()
                    con.subscribe_market_data(ticker)

                    last = con.get_candles(ticker, period=period,number=1)
                    try:
                        pnl = con.get_open_positions().iloc[0,-1]
                    except :
                        pass
                    if last.index[-1].minute == df.iloc[-1,0].minute :
                        if  pos_long == 0 and pos_short == 1 and pnl > 21:
                            tradeId_short = con.get_open_trade_ids()[-1]
                            order = con.close_trade(trade_id=tradeId_short, amount=30)
                            pos_short = 0
                            print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')

                        if  pos_long == 0 and pos_short == 1 and pnl < -25:
                            tradeId_short = con.get_open_trade_ids()[-1]
                            order = con.close_trade(trade_id=tradeId_short, amount=30)
                            pos_short = 0
                            print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')

                        if  pos_long == 1 and pos_short == 0 and pnl > 21:
                            tradeId_long = con.get_open_trade_ids()[-1]
                            order = con.close_trade(trade_id=tradeId_long, amount=30)
                            print('\033[47m \033[31m Close Long avec un pnl de', pnl,'\033[0m')
                            pos_long = 0

                        if  pos_long == 1 and pos_short == 0 and pnl < -25:
                            tradeId_long = con.get_open_trade_ids()[-1]
                            order = con.close_trade(trade_id=tradeId_long, amount=30)
                            print('\033[47m \033[31m Close Long avec un pnl de', pnl,'\033[0m')
                            pos_long = 0
                        print('\033[43m'+' Tempo '+'\033[0m'+'\033[46m'+'...'+'\033[0m',end='')                
                        continue

                    else :
                        df = df.iloc[1:,:]
                        df = df.append({'Date':last.index[-1],'Open':last.iloc[-1,4], 'High':last.iloc[-1,6],'Low':last.iloc[-1,7], 'Close':last.iloc[-1,5]}, ignore_index=True)

                        df_1D,aroon = prepa_data(df,pik_long, pik_short,targetup,targetdown)

                        # TESTING ONLY
                        print()
                        print('GOLEM begins testing...')

                        X = df_1D.iloc[:,1:-3]
                        X = scaler.fit_transform(X)
                        Xtest = X[-1:,:]

                        seed = 770
                        np.random.seed(seed)

                        yhat_up = model_up.predict_classes(Xtest)
                        yhat_down = model_down.predict_classes(Xtest)

                        predict_up = model_up.predict(Xtest)
                        predict_down = model_down.predict(Xtest)
                        resultats = pd.DataFrame()
                        resultats['Date'] = df_1D.iloc[-1:,0]
                        resultats['Move Up'] = yhat_up
                        resultats['Confidence up'] = (predict_up)*100
                        resultats['Move Down'] = yhat_down
                        resultats['Confidence Down'] = (predict_down)*100
                        resultats['Actual'] = df_1D['target_value']
                        #resultats,scaler,model_up,model_down = deep_learning (df_1D)
                        tmps2=round(time.time()-tmps1,2)
                        print ("Testing executed in = %f" %tmps2,'secondes')
                        print('Time of request', Fore.BLUE)
                        print(dt.datetime.now().hour+jet_lag,'H',dt.datetime.now().minute,'min',dt.datetime.now().second,'seconds',Style.RESET_ALL)
                        print('Results :\n')
                        print('\033[45m')
                        print(resultats)
                        print(Style.RESET_ALL)

                        # TEST POSITION EN L'AIR
                        if pos_long == 0 and pos_short == 0:
                            try:
                                if con.get_open_positions().iloc[0,8] == True:
                                    pos_long = 1
                                if con.get_open_positions().iloc[0,8] == False:
                                    pos_short
                            except:
                                print("Pas de position en l'air")


                        # TEST OUVERTURE
                        try : 

                            if con.get_open_positions().iloc[0,2] != 0.03:
                                pos_long = 0
                                pos_short = 0
                        except:
                            pass

                        if pos_long == 1:

                            pnl = con.get_open_positions().iloc[0,-1]
                            if pnl > 0 :
                                print('\033[42m pnl : ',round(pnl,2),'\033[0m')
                            elif pnl < 0:
                                print('\033[41m pnl : ',round(pnl,2),'\033[0m')
                        elif pos_short == 1:

                            pnl = con.get_open_positions().iloc[0,-1]
                            if pnl > 0 :
                                print('\033[42m pnl : ',round(pnl,2),'\033[0m')
                            elif pnl < 0:
                                print('\033[41m pnl : ',round(pnl,2),'\033[0m')

                        print('Aroon :',aroon.iloc[-1])
                        print('Long Pos =',pos_long)
                        print('Short Pos =',pos_short)

                        # ACTIONS

                        if  pos_long == 0 and pos_short == 1 and pnl > 3:
                            tradeId_short = con.get_open_trade_ids()[-1]
                            order = con.close_trade(trade_id=tradeId_short, amount=30)
                            time.sleep(10)
                            pos_short = 0
                            print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')

                        if  pos_long == 0 and pos_short == 1 and pnl < -15:
                            tradeId_short = con.get_open_trade_ids()[-1]
                            order = con.close_trade(trade_id=tradeId_short, amount=30)
                            time.sleep(10)
                            pos_short = 0
                            print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')

                        if  pos_long == 1 and pos_short == 0 and pnl > 21:
                            tradeId_long = con.get_open_trade_ids()[-1]
                            order = con.close_trade(trade_id=tradeId_long, amount=30)
                            time.sleep(10)
                            print('\033[47m \033[31m Close Long avec un pnl de', pnl,'\033[0m')
                            pos_long = 0

                        if  pos_long == 1 and pos_short == 0 and pnl < -15:
                            tradeId_long = con.get_open_trade_ids()[-1]
                            order = con.close_trade(trade_id=tradeId_long, amount=30)
                            time.sleep(10)
                            print('\033[47m \033[31m Close Long avec un pnl de', pnl,'\033[0m')
                            pos_long = 0

                        if resultats.iloc[0,1] == 1 and resultats.iloc[0,2] > short_close:

                            if  pos_long == 0 and pos_short == 1 :
                                #order = con.close_all_for_symbol(ticker)
                                tradeId_short = con.get_open_trade_ids()[-1]
                                pnl = con.get_open_positions().iloc[0,-1]
                                order = con.close_trade(trade_id=tradeId_short, amount=30)
                                time.sleep(10)
                                pos_short = 0
                                print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')


                            if pos_long == 0 and pos_short == 0 and resultats.iloc[0,2] > long_open:
                                #order = con.create_market_buy_order(ticker, 30)
                                order = con.open_trade(symbol=ticker,is_buy=True,amount=30,order_type='AtMarket',time_in_force='GTC')#,\
                                                       #stop=(last.iloc[-1,5]-2.0))
                                time.sleep(10)
                                print('Go Long')
                                print('Buy Price :',con.get_open_positions().iloc[0,11])
                                buy_price = con.get_open_positions().iloc[0,11]
                                pos_long = 1



                        elif resultats.iloc[0,3] == 1 and resultats.iloc[0,4] > long_close:

                            if  pos_long == 1 and pos_short == 0:
                                #order = con.close_all_for_symbol(ticker)
                                tradeId_long = con.get_open_trade_ids()[-1]
                                pnl = con.get_open_positions().iloc[0,-1]
                                order = con.close_trade(trade_id=tradeId_long, amount=30)
                                time.sleep(10)
                                print('\033[47m \033[31m Close Long avec un pnl de', pnl,'\033[0m')
                                pos_long = 0

                            if pos_long == 0 and pos_short == 0 and resultats.iloc[0,4] > short_open:
                                #order = con.create_market_sell_order(ticker, 30)
                                order = con.open_trade(symbol=ticker,is_buy=False,amount=30,order_type='AtMarket',time_in_force='GTC')#,\
                                                       #stop=(last.iloc[-1,5]+2.0))
                                time.sleep(10)
                                print('Go Short')
                                print('Sell Price :',con.get_open_positions().iloc[0,11])
                                sell_price = con.get_open_positions().iloc[0,11]
                                pos_short = 1

        except Exception as e:
            print("Exception: " + str(e))
    return(con)

main(con,ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik_long, pik_short,targetup,targetdown,pos_long,pos_short)
# Out:
# Global Optimized LumberJack Environment Motor
# °OoO_FXCM_Oo0°
# LumberJack Jyss 5779(c)
# Version v1.30
# Importing librairies...
# version fxcmpy : 1.2.6
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-181f0e603615> in <module>
#       6 print('version fxcmpy :',fxcmpy.__version__)
#       7 import forexconnect
# ----> 8 from forexconnect import fxcorepy
#       9 from forexconnect import ForexConnect, ResponseListener, Common
#      10 import time
#
# ImportError: dlopen(/Users/dag26/.local/lib/python3.7/site-packages/forexconnect/fxcorepy.so, 2): Library not loaded: /Library/Frameworks/Python.framework/Versions/3.7/Python
#   Referenced from: /Users/dag26/.local/lib/python3.7/site-packages/forexconnect/fxcorepy.so
#   Reason: image not found

# %%
# PNL con.get_open_positions().iloc[0,-1]

# %%
# BUY/SELL PRICE con.get_open_positions().iloc[0,11]

# %%
# IS BUY OR IS SELL = con.get_open_positions().iloc[0,8]

# %%
# AMOUNTK = con.get_open_positions().iloc[0,2] == 0.03

# %%
# Short =>

# %%
# Long =>

# %%
connexion()
# Out:
# Connecting server...
# W0623 20:48:48.838388 4427298240 fxcmpy.py:222] Default account set to 1147539, to change use set_default_account().
# Connection established for 1147539   - Mode : demo
# Connexion executed in = 7.400000 secondes

# %%
main(con,ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik,targetup,targetdown,pos_long,pos_short)
# Out:
#
#  MEGA LOOP  0
#
# Scrap (historical) executed in = 2.300000 secondes
# Initializing GOLEM...
# Long Pos = 0
# Short Pos = 0
# GOLEM begins Computing...
# Processing move_up
# Processing move_down
# Computing done
# DL executed in = 28.770000 seconds
# Results :
#                       Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-24 09:16:00        1      94.649818          0          0.00004
#
#        Actual
# 7950  12273.1
#
# Aroon : -76.0
# Long Pos = 0
# Short Pos = 0
# Initializing GOLEM on STREAMING LIVE...
# Long Pos = 0
# Short Pos = 0
# Instrument : GER30
#
# GOLEM begins testing...
# Testing executed in = 3.960000 secondes
# Time of request
# 9 H 18 min 19 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-24 09:17:00        1      95.414146          0              0.0
#
#        Actual
# 7950  12271.1
#
# Aroon : -76.0
# Long Pos = 0
# Short Pos = 0
# E0624 11:18:23.040513 4593132992 fxcmpy.py:2506] Server reports an error: {'executed': False, 'error': '{"type":5,"sessionId":"EUDEMO_7F5BED13C4617FE6E053E12B3C0A17EF_06242019090842312568_79U","requestId":"Request-818202","text":" limit price peg too big: 12271.1 (max: 6150) pips.\\n","code":20143,"stack":""}'}.
# E0624 11:18:23.041507 4593132992 fxcmpy.py:2507] URL: https://api-demo.fxcm.com:443/trading/open_trade
# E0624 11:18:23.042291 4593132992 fxcmpy.py:2508] Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer BqzlAbHKfYaWK-QMAeMGe053ac1597cef331df9429ac8151100ea9f1c411', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '145'}
# E0624 11:18:23.043147 4593132992 fxcmpy.py:2509] Params: {'account_id': 1147539, 'symbol': 'GER30', 'is_buy': 'true', 'rate': 0.0, 'amount': 30, 'at_market': 0.0, 'order_type': 'AtMarket', 'time_in_force': 'GTC', 'limit': 12271.15, 'is_in_pips': 'true'}
# E0624 11:18:23.044709 4593132992 fxcmpy.py:2510] Bearer token: Bearer BqzlAbHKfYaWK-QMAeMGe053ac1597cef331df9429ac8151100ea9f1c411
# E0624 11:18:23.045400 4593132992 fxcmpy.py:2512] Connection status: established
# E0624 11:18:23.046750 4593132992 fxcmpy.py:2514] Socket session id: BqzlAbHKfYaWK-QMAeMG
# E0624 11:18:23.047632 4593132992 fxcmpy.py:2525] Can not parse server answer to json object: {"response":{"executed":false,"error":"{\"type\":5,\"sessionId\":\"EUDEMO_7F5BED13C4617FE6E053E12B3C0A17EF_06242019090842312568_79U\",\"requestId\":\"Request-818202\",\"text\":\" limit price peg too big: 12271.1 (max: 6150) pips.\\n\",\"code\":20143,\"stack\":\"\"}"}}.
# W0624 11:18:23.048403 4593132992 fxcmpy.py:1125] Missing orderId in servers answer.
# Go Long
# Buy Price : 12271.61
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 4.330000 secondes
# Time of request
# 9 H 19 min 4 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-24 09:18:00        1       94.84166          0         0.000002
#
#        Actual
# 7950  12269.8
#
#  pnl :  -4.9
# Aroon : -88.0
# Long Pos = 1
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 3.670000 secondes
# Time of request
# 9 H 20 min 3 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-24 09:19:00        1      94.789192          0              0.0
#
#        Actual
# 7950  12267.5
#
#  pnl :  -4.9
# Aroon : -92.0
# Long Pos = 1
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 3.580000 secondes
# Time of request
# 9 H 21 min 4 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-24 09:20:00        1       94.89019          0         0.000004
#
#        Actual
# 7950  12267.6
#
#  pnl :  -4.9
# Aroon : -96.0
# Long Pos = 1
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 3.450000 secondes
# Time of request
# 9 H 22 min 2 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-24 09:21:00        1       80.03418          0         0.028881
#
#        Actual
# 7950  12271.9
#
#  pnl :  -4.9
# Aroon : -96.0
# Long Pos = 1
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 4.150000 secondes
# Time of request
# 9 H 23 min 3 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-24 09:22:00        1      95.035095          0         0.000023
#
#        Actual
# 7950  12268.5
#
#  pnl :  -4.9
# Aroon : -92.0
# Long Pos = 1
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 3.950000 secondes
# Time of request
# 9 H 24 min 4 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-24 09:23:00        1      95.347107          0         0.000003
#
#        Actual
# 7950  12265.1
#
#  pnl :  -4.9
# Aroon : -100.0
# Long Pos = 1
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 3.430000 secondes
# Time of request
# 9 H 25 min 1 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-24 09:24:00        1      93.715912          0         0.000252
#
#        Actual
# 7950  12266.9
#
#  pnl :  -4.9
# Aroon : -60.0
# Long Pos = 1
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 3.340000 secondes
# Time of request
# 9 H 26 min 3 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-24 09:25:00        1      95.103027          0         0.000018
#
#        Actual
# 7950  12265.5
#
#  pnl :  -4.9
# Aroon : -60.0
# Long Pos = 1
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# W0624 11:26:41.375727 123145408946176 fxcmpy.py:2733] Got a insert event for closed positions: {'t': 2, 'ratePrecision': 2, 'tradeId': '152157262', 'accountName': '01147539', 'roll': 0, 'com': 0, 'open': 12271.61, 'valueDate': '', 'grossPL': 26.88, 'close': 12262.65, 'visiblePL': 9, 'currency': 'GER30', 'isBuy': False, 'amountK': 0.03, 'currencyPoint': 0.003, 'openTime': '06242019091557', 'closeTime': '06242019092641', 'action': 'I'}.
# W0624 11:26:41.379713 123145429966848 fxcmpy.py:2733] Got a insert event for closed positions: {'t': 2, 'ratePrecision': 2, 'tradeId': '152157262', 'accountName': '01147539', 'roll': 0, 'com': 0, 'open': 12271.61, 'valueDate': '', 'grossPL': 26.88, 'close': 12262.65, 'visiblePL': 9, 'currency': 'GER30', 'isBuy': False, 'amountK': 0.03, 'currencyPoint': 0.003, 'openTime': '06242019091557', 'closeTime': '06242019092641', 'action': 'I'}.
# W0624 11:26:41.381443 123145429966848 fxcmpy.py:2684] Got a delete event for open posi: {'t': 1, 'tradeId': '152157262', 'action': 'D'}
# W0624 11:26:41.382688 123145379766272 fxcmpy.py:2733] Got a insert event for closed positions: {'t': 2, 'ratePrecision': 2, 'tradeId': '152157262', 'accountName': '01147539', 'roll': 0, 'com': 0, 'open': 12271.61, 'valueDate': '', 'grossPL': 26.88, 'close': 12262.65, 'visiblePL': 9, 'currency': 'GER30', 'isBuy': False, 'amountK': 0.03, 'currencyPoint': 0.003, 'openTime': '06242019091557', 'closeTime': '06242019092641', 'action': 'I'}.
# W0624 11:26:41.382936 123145408946176 fxcmpy.py:2684] Got a delete event for open posi: {'t': 1, 'tradeId': '152157262', 'action': 'D'}
# W0624 11:26:41.387080 123145379766272 fxcmpy.py:2684] Got a delete event for open posi: {'t': 1, 'tradeId': '152157262', 'action': 'D'}
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# W0624 11:28:31.258753 123145373974528 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 60] Operation timed out)
# W0624 11:28:48.316080 123145408946176 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 60] Operation timed out)
# W0624 11:28:50.446623 123145429966848 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 60] Operation timed out)
# W0624 11:29:33.500154 123145379766272 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 60] Operation timed out)
# W0624 11:29:40.304894 123145403691008 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 60] Operation timed out)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-c50fa4302ff3> in <module>
# ----> 1 main(con,ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik,targetup,targetdown,pos_long,pos_short)
#
# <ipython-input-34-2ebb3b253f92> in main(con, ticker, period, number, long_open, long_close, short_open, short_close, jet_lag, pik, targetup, targetdown, pos_long, pos_short)
#     311             con.subscribe_market_data(ticker)
#     312
# --> 313             last = con.get_candles(ticker, period=period,number=1)
#     314             try:
#     315                 pnl = con.get_open_positions().iloc[0,-1]
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/fxcmpy/fxcmpy.py in get_candles(self, instrument, offer_id, period, number, start, end, with_index, columns, stop)
#    2182
#    2183         data = self.__handle_request__(method='candles/%s/%s'
# -> 2184                                        % (offer_id, period), params=params)
#    2185
#    2186         if len(columns) == 0:
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/fxcmpy/fxcmpy.py in __handle_request__(self, method, params, protocol)
#    2478             req = requests.get('%s:443/%s' % (self.trading_url, method),
#    2479                                headers=self.request_headers, params=params,
# -> 2480                                proxies=self.proxies)
#    2481             self.logger.info('Sending GET Request:')
#    2482             self.logger.info('URL: %s' % req.url)
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     342             ca_cert_dir=self.ca_cert_dir,
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#     346         if self.assert_fingerprint:
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     342             or IS_SECURETRANSPORT):
#     343         if HAS_SNI and server_hostname is not None:
# --> 344             return context.wrap_socket(sock, server_hostname=server_hostname)
#     345
#     346         warnings.warn(
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     451         while True:
#     452             try:
# --> 453                 cnx.do_handshake()
#     454             except OpenSSL.SSL.WantReadError:
#     455                 if not util.wait_for_read(sock, sock.gettimeout()):
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1912         :return: None.
#    1913         """
# -> 1914         result = _lib.SSL_do_handshake(self._ssl)
#    1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# KeyboardInterrupt:

# %%
con.get_open_positions().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 22 columns):
# accountId        1 non-null object
# accountName      1 non-null object
# amountK          1 non-null float64
# close            1 non-null float64
# com              1 non-null int64
# currency         1 non-null object
# currencyPoint    1 non-null float64
# grossPL          1 non-null float64
# isBuy            1 non-null bool
# isDisabled       1 non-null bool
# limit            1 non-null int64
# open             1 non-null float64
# ratePrecision    1 non-null int64
# roll             1 non-null int64
# stop             1 non-null int64
# stopMove         1 non-null int64
# t                1 non-null int64
# time             1 non-null object
# tradeId          1 non-null object
# usedMargin       1 non-null int64
# valueDate        1 non-null object
# visiblePL        1 non-null float64
# dtypes: bool(2), float64(6), int64(8), object(6)
# memory usage: 242.0+ bytes

# %%
con.open_trade(symbol=ticker,is_buy=False,amount=30,order_type='AtMarket',time_in_force='GTC')
# Out:
# W0624 11:15:57.585417 123145408946176 fxcmpy.py:2681] Got a insert event for open positions: {'t': 1, 'ratePrecision': 2, 'tradeId': '152157262', 'accountName': '01147539', 'accountId': '1147539', 'roll': 0, 'com': 0, 'open': 12271.61, 'valueDate': '', 'grossPL': -25.38, 'close': 12280.07, 'visiblePL': -8.5, 'isDisabled': False, 'currency': 'GER30', 'isBuy': False, 'amountK': 0.03, 'currencyPoint': 0.003, 'time': '06242019091557', 'usedMargin': 975, 'stop': 0, 'stopMove': 0, 'limit': 0, 'action': 'I'}.
# W0624 11:15:57.590970 123145429966848 fxcmpy.py:2681] Got a insert event for open positions: {'t': 1, 'ratePrecision': 2, 'tradeId': '152157262', 'accountName': '01147539', 'accountId': '1147539', 'roll': 0, 'com': 0, 'open': 12271.61, 'valueDate': '', 'grossPL': -20.58, 'close': 12278.47, 'visiblePL': -6.9, 'isDisabled': False, 'currency': 'GER30', 'isBuy': False, 'amountK': 0.03, 'currencyPoint': 0.003, 'time': '06242019091557', 'usedMargin': 975, 'stop': 0, 'stopMove': 0, 'limit': 0, 'action': 'I'}.
# W0624 11:15:57.596693 123145379766272 fxcmpy.py:2681] Got a insert event for open positions: {'t': 1, 'ratePrecision': 2, 'tradeId': '152157262', 'accountName': '01147539', 'accountId': '1147539', 'roll': 0, 'com': 0, 'open': 12271.61, 'valueDate': '', 'grossPL': -14.67, 'close': 12276.5, 'visiblePL': -4.9, 'isDisabled': False, 'currency': 'GER30', 'isBuy': False, 'amountK': 0.03, 'currencyPoint': 0.003, 'time': '06242019091557', 'usedMargin': 975, 'stop': 0, 'stopMove': 0, 'limit': 0, 'action': 'I'}.
# W0624 11:15:57.603301 123145408946176 fxcmpy.py:2603] Got a delete event for orders: {'t': 3, 'orderId': '317931306', 'action': 'D'}.
# W0624 11:15:57.603539 123145429966848 fxcmpy.py:2603] Got a delete event for orders: {'t': 3, 'orderId': '317931306', 'action': 'D'}.
# W0624 11:15:57.609719 123145379766272 fxcmpy.py:2603] Got a delete event for orders: {'t': 3, 'orderId': '317931306', 'action': 'D'}.

# %%
connexion()
# Out:
# Connecting server...
# W0624 11:14:07.862441 4593132992 fxcmpy.py:222] Default account set to 1147539, to change use set_default_account().
# Connection established for 1147539   - Mode : demo
# Connexion executed in = 12.650000 secondes

# %%
last
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-cfde3e342ac3> in <module>
# ----> 1 last
#
# NameError: name 'last' is not defined

# %%
TOKEN = 'e053ac1597cef331df9429ac8151100ea9f1c411'
server = 'demo'

# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'
ticker = 'SPX500'
period = 'm1'
number = 8000
long_open = 95
long_close = 85
short_open = 95
short_close = 85
jet_lag = -2
pik = 0.005
targetup = 0.06
targetdown = 0.03
# Time Windows
# start = dt.datetime(2017, 7, 15)
# stop = dt.datetime(2017, 8, 1)
# con.get_candles('EUR/USD', period='D1',start=start, stop=stop)

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return True;
# }

# %%
pos_long = 0
pos_short = 0

# %%
___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor\n°OoO_FXCM_Oo0°\nLumberJack Jyss 5779(c)')
print('Version v1.21')
print('Importing librairies...')
import fxcmpy
print('version fxcmpy :',fxcmpy.__version__)
import time
import numpy as np
import pandas as pd
from colorama import Fore, Back, Style 
import datetime as dt
import talib
from zigzag import *
#import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
#from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report
print('Librairies imported')
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
buy_price = 0
sell_price = 0
pnl = 0
#try :

def connexion():
    tmps1=time.time()
    print('Connecting server...')
    con = fxcmpy.fxcmpy(access_token=TOKEN, log_level='error',server= server)
    if con.is_connected():
        print('Connection established for', Fore.BLUE + str(con.get_account_ids()[-1]),Style.RESET_ALL,' - Mode :',Fore.RED + server,Style.RESET_ALL)
    else:
        print('Not connected. Will try again in 10 seconds')
        dt.time(10)
        con = connexion()
    tmps2=round(time.time()-tmps1,2)
    print ("Connexion executed in = %f" %tmps2,'secondes')
    return(con)

def scrap_data(ticker,period,number):
    tmps1=time.time()
    data = con.get_candles(ticker, period=period,number=number) #start=start,stop=stop)
    df = pd.DataFrame()
    df['Open'] = data['askopen']
    df['High'] = data['askhigh']
    df['Low'] = data['asklow']
    df['Close'] = data['askclose']
    df['Date'] = data.index
    df = df[['Date'] + df.columns[:-1].tolist()]
    tmps2=round(time.time()-tmps1,2)
    print (Fore.GREEN + "Scrap (historical) executed in = %f"  %tmps2,'secondes',Style.RESET_ALL)
    return(df)

def prepa_data(df,pik,targetup,targetdown):
    tmps1=time.time()
    df.reset_index(inplace=True,drop=True)
    dataset_1D = df.copy()
    dataset_1D = dataset_1D.dropna()
    rsi = talib.RSI(dataset_1D['Close'],timeperiod=2)
    upper, middle, lower =  talib.BBANDS(dataset_1D['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(dataset_1D['Close'],timeperiod=5)
    sma8 = talib.SMA(dataset_1D['Close'],timeperiod=8)
    sma10 = talib.SMA(dataset_1D['Close'],timeperiod=10)
    sma12 = talib.SMA(dataset_1D['Close'],timeperiod=12)
    sma15 = talib.SMA(dataset_1D['Close'],timeperiod=15)
    sma30 = talib.SMA(dataset_1D['Close'],timeperiod=30)
    sma35 = talib.SMA(dataset_1D['Close'],timeperiod=35)
    sma40 = talib.SMA(dataset_1D['Close'],timeperiod=40)
    sma45 = talib.SMA(dataset_1D['Close'],timeperiod=45)
    sma50 = talib.SMA(dataset_1D['Close'],timeperiod=50)
    aroondown, aroonup = talib.AROON(dataset_1D['High'], dataset_1D['Low'], timeperiod=25)
    aroon = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))

    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50

    X = dataset_1D['Close']
    pivots = peak_valley_pivots(X.values, pik, -pik)
    ts_pivots = pd.Series(X, index=X.index)
    ts_pivots = ts_pivots[pivots != 0]

    peak = []
    valley = []

    for i in range(0,dataset_1D.shape[0]):
        if pivots[i] == 1:
            peak.append(pivots[i])
            valley.append(0)
        elif pivots[i] == -1:
            peak.append(0)
            valley.append(pivots[i])
        else:
            peak.append(0)
            valley.append(0)

    bbdelta = upper - middle
    price_bolup = dataset_1D['Close'] - lower
    price_bolow = dataset_1D['Close'] - upper

    rsi5_list = []
    rsi95_list = []
    for i in range(0,dataset_1D.shape[0]):
        try:
            rsi95_list.append(95 - rsi[i])
            rsi5_list.append(rsi[i] - 5)
        except:
            rsi95_list.append(0)
            rsi5_list.append(0)
    varop_spy = dataset_1D['Open'] - dataset_1D['Close']
    varhl_spy = dataset_1D['High'] - dataset_1D['Low']
    dataset_1D['Varop_Spy'] = varop_spy
    dataset_1D['Varhl_spy'] = varhl_spy
    dataset_1D['RSI'] = rsi
    dataset_1D['Aroon'] = aroon
    dataset_1D['95 - RSI'] = np.array(rsi95_list)
    dataset_1D['RSI - 5'] = np.array(rsi5_list)
    dataset_1D['BBD_Delta_Up'] = bbdelta
    dataset_1D['delta5_8'] = delta5_8
    dataset_1D['delta8_10'] = delta8_10
    dataset_1D['delta10_12'] = delta10_12
    dataset_1D['delta12_15'] = delta12_15
    dataset_1D['delta15_30'] = delta15_30
    dataset_1D['delta30_35'] = delta30_35
    dataset_1D['delta35_40'] = delta35_40
    dataset_1D['delta40_45'] = delta40_45
    dataset_1D['delta45_50'] = delta45_50
    dataset_1D['Peaks'] = abs(np.array(peak))
    dataset_1D['Valley'] = abs(np.array(valley))
    tsf = talib.TSF(dataset_1D['Close'],timeperiod=14)
    delta_tsf = dataset_1D['Close'] - tsf
    dataset_1D['delta_tsf'] = tsf
    forosc = []
    forosc.append(0)
    for i in range(1,dataset_1D.shape[0]):
        try:
            forosc.append((dataset_1D.iloc[i,4] - tsf[i-1])*100/dataset_1D.iloc[i,4])
        except:
            forosc.append(0)
    dataset_1D['Forcast Oscillator'] = (forosc)
    target_up = []
    target_down = []

    for i in range(0,dataset_1D.shape[0]-5):

        if (dataset_1D.iloc[i+1,5] * dataset_1D.iloc[i,5]) < 0 :
            if (dataset_1D.iloc[i+1,4] - dataset_1D.iloc[i,4]) > targetup : 
                target_up.append(1)
                target_down.append(0)
            elif (dataset_1D.iloc[i+1,4] - dataset_1D.iloc[i,4]) < -targetdown: 
                target_up.append(0)
                target_down.append(1)
            else:
                target_up.append(0)
                target_down.append(0)
        else :
            target_up.append(0)
            target_down.append(0) 

    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    dataset_1D['target_up'] = target_up  # target_up # abs(np.array(valley))#target_up
    dataset_1D['target_down'] = target_down # target_down # abs(np.array(peak))#target_down
    dataset_1D['target_value'] = dataset_1D['Close']
    dataset_1D = dataset_1D.drop(['Open','High','Low','Close'],axis=1)
    df_1D = dataset_1D.copy()
    df_1D = df_1D.iloc[:,1:]
    df_1D['Date'] = df['Date']
    df_1D = df_1D.dropna()
    df_1D = df_1D[['Date'] + df_1D.columns[:-1].tolist()]
    df_1D.reset_index(inplace=True,drop=True)
    return(df_1D,aroon)
    
def deep_learning(df_1D):
    tmps1=time.time()
    X = df_1D.iloc[:,1:-3]
    y_up = df_1D.iloc[:,-3].values
    y_down = df_1D.iloc[:,-2].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:-1,:]
    Xtest = X[-1:,:]
    ytrain_up = y_up[:-1,:]
    ytest_up = y_up[-1:,:]
    ytrain_down = y_down[:-1,:]
    ytest_down = y_down[-1:,:]

    seed = 770
    np.random.seed(seed)

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    model_up = Sequential()
        # Add an input layer 
    model_up.add(Dense(23, activation='relu'))
        # Add one hidden layer 
    model_up.add(Dense(50, activation='relu'))
        # Add an output layer 
    model_up.add(Dense(1, activation='sigmoid'))

    model_down = Sequential()
        # Add an input layer 
    model_down.add(Dense(23, activation='relu'))
        # Add one hidden layer 
    model_down.add(Dense(50, activation='relu'))
        # Add an output layer 
    model_down.add(Dense(1, activation='sigmoid'))

    print('Processing move_up')
    model_up.compile(loss='binary_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy','mse'])

    history_up = model_up.fit(Xtrain, ytrain_up,epochs=50, batch_size=32, verbose=0)

    print('Processing move_down')
    model_down.compile(loss='binary_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy','mse'])

    history_down = model_down.fit(Xtrain, ytrain_down,epochs=50, batch_size=32, verbose=0)

    print('Computing done')


    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)
    resultats = pd.DataFrame()
    resultats['Date'] = df_1D.iloc[-1:,0]
    resultats['Move Up'] = yhat_up
    resultats['Confidence up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confidence Down'] = (predict_down)*100
    resultats['Actual'] = df_1D['target_value']
    tmps2=round(time.time()-tmps1,2)
    print ("DL executed in = %f" %tmps2,'seconds')
    print('Results :\n \033[31m', resultats,'\n',Style.RESET_ALL)
    return(resultats,scaler,model_up,model_down)

def main(con,ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik,targetup,targetdown,pos_long,pos_short):
    
    for ukulele in range (0,2000):

        # CONNEXION TESTING
        if con.is_connected() == False:
            con = connexion()
            time.sleep(3)
        print(' \n MEGA LOOP ',ukulele,'\n')
        df = scrap_data(ticker,period,number)

        print('\033[33m' + 'Initializing GOLEM...')
        print('\033[35m' +'Long Pos =',pos_long)
        print('Short Pos =',pos_short,Style.RESET_ALL)


        # DATA PREPARATION
        df_1D,aroon = prepa_data(df,pik,targetup,targetdown)

        print('\033[36m'+'GOLEM begins Computing...'+Style.RESET_ALL)

        # DEEP LEARNING

        resultats,scaler,model_up,model_down = deep_learning (df_1D)

        # TESTING POSITIONS

        # TEST POS
        print('Aroon :',aroon.iloc[-1])
        print('Long Pos =',pos_long)
        print('Short Pos =',pos_short)
        print('Initializing GOLEM on STREAMING LIVE...')
        print('Long Pos =',pos_long)
        print('Short Pos =',pos_short)
        # SCRAP DATA
        print('Instrument :', ticker)

        for loop in range(0,2000):

            #print(' \n INFRA LOOP ',loop,'\n')
            if con.is_connected() == False:
                con = connexion()

            tmps1=time.time()
            con.subscribe_market_data(ticker)

            last = con.get_candles(ticker, period=period,number=1)

            if last.index[-1].minute == df.iloc[-1,0].minute :
                print('\033[43m'+' Tempo '+'\033[0m'+'\033[46m'+'...'+'\033[0m',end='')
                continue

            else :
                df = df.iloc[1:,:]
                df = df.append({'Date':last.index[-1],'Open':last.iloc[-1,4], 'High':last.iloc[-1,6],'Low':last.iloc[-1,7], 'Close':last.iloc[-1,5]}, ignore_index=True)

                df_1D,aroon = prepa_data(df,pik,targetup,targetdown)

                # TESTING ONLY
                print()
                print('GOLEM begins testing...')

                X = df_1D.iloc[:,1:-3]
                X = scaler.fit_transform(X)
                Xtest = X[-1:,:]

                seed = 770
                np.random.seed(seed)

                yhat_up = model_up.predict_classes(Xtest)
                yhat_down = model_down.predict_classes(Xtest)

                predict_up = model_up.predict(Xtest)
                predict_down = model_down.predict(Xtest)
                resultats = pd.DataFrame()
                resultats['Date'] = df_1D.iloc[-1:,0]
                resultats['Move Up'] = yhat_up
                resultats['Confidence up'] = (predict_up)*100
                resultats['Move Down'] = yhat_down
                resultats['Confidence Down'] = (predict_down)*100
                resultats['Actual'] = df_1D['target_value']
                #resultats,scaler,model_up,model_down = deep_learning (df_1D)
                tmps2=round(time.time()-tmps1,2)
                print ("Testing executed in = %f" %tmps2,'secondes')
                print('Time of request', Fore.BLUE)
                print(dt.datetime.now().hour+jet_lag,'H',dt.datetime.now().minute,'min',dt.datetime.now().second,'seconds',Style.RESET_ALL)
                print('Results :\n')
                print('\033[45m')
                print(resultats)
                print(Style.RESET_ALL)


                if pos_long == 1:

                    pnl = last.iloc[-1,5] - buy_price
                    if pnl > 0 :
                        print('\033[42m pnl : ',round(pnl,2),'\033[0m')
                    elif pnl < 0:
                        print('\033[41m pnl : ',round(pnl,2),'\033[0m')
                elif pos_short == 1:

                    pnl = sell_price - last.iloc[-1,5]
                    if pnl > 0 :
                        print('\033[42m pnl : ',round(pnl,2),'\033[0m')
                    elif pnl < 0:
                        print('\033[41m pnl : ',round(pnl,2),'\033[0m')

                print('Aroon :',aroon.iloc[-1])
                print('Long Pos =',pos_long)
                print('Short Pos =',pos_short)

                # ACTIONS
                if con.is_connected() == False:
                    con = connexion()
                if resultats.iloc[0,1] == 1 and resultats.iloc[0,2] > short_close:

                    if  pos_long == 0 and pos_short == 1 :
                        #order = con.close_all_for_symbol(ticker)
                        tradeId_short = con.get_open_trade_ids()[-1]
                        order = con.close_trade(trade_id=tradeId_short, amount=30)
                        pos_short = 0
                        print('\033[47m \033[31m Close Short avec un pnl de', sell_price - last.iloc[-1,5],'\033[0m')


                    if pos_long == 0 and pos_short == 0 and resultats.iloc[0,2] > long_open:
                        #order = con.create_market_buy_order(ticker, 30)
                        order = con.open_trade(symbol=ticker,is_buy=True,amount=30,limit=(last.iloc[-1,5]+2.0),order_type='AtMarket',time_in_force='GTC')#,\
                                               #stop=(last.iloc[-1,5]-2.0))

                        print('Go Long')
                        print('Buy Price :',last.iloc[-1,5])
                        buy_price = last.iloc[-1,5]
                        pos_long = 1



                elif resultats.iloc[0,3] == 1 and resultats.iloc[0,4] > long_close:

                    if  pos_long == 1 and pos_short == 0:
                        #order = con.close_all_for_symbol(ticker)
                        tradeId_long = con.get_open_trade_ids()[-1]
                        order = con.close_trade(trade_id=tradeId_long, amount=30)
                        print('\033[47m \033[31m Close Long avec un pnl de', last.iloc[-1,5] - buy_price,'\033[0m')
                        pos_long = 0

                    if pos_long == 0 and pos_short == 0 and resultats.iloc[0,4] > short_open:
                        #order = con.create_market_sell_order(ticker, 30)
                        order = con.open_trade(symbol=ticker,is_buy=False,amount=30,limit=(last.iloc[-1,5]-2.0),order_type='AtMarket',time_in_force='GTC')#,\
                                               #stop=(last.iloc[-1,5]+2.0))

                        print('Go Short')
                        print('Sell Price :',last.iloc[-1,5])
                        sell_price = last.iloc[-1,5]
                        pos_short = 1
    return(con)

con = connexion()
main(con,ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik,targetup,targetdown,pos_long,pos_short)
# Out:
# Global Optimized LumberJack Environment Motor
# °OoO_FXCM_Oo0°
# LumberJack Jyss 5779(c)
# Version v1.2
# Importing librairies...
# version fxcmpy : 1.2.4
# Librairies imported
# Connecting server...
# W0621 11:48:32.025050 4392490432 fxcmpy.py:222] Default account set to 1147539, to change use set_default_account().
# Connection established for 1147539   - Mode : demo
# Connexion executed in = 10.650000 secondes
#
#  MEGA LOOP  0
#
# Scrap (historical) executed in = 1.640000 secondes
# Initializing GOLEM...
# Long Pos = 0
# Short Pos = 0
# GOLEM begins Computing...
# Processing move_up
# Processing move_down
# Computing done
# DL executed in = 23.110000 seconds
# Results :
#                       Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-21 09:47:00        1      90.675964          0              0.0
#
#        Actual
# 7950  2950.58
#
# Aroon : -60.0
# Long Pos = 0
# Short Pos = 0
# Initializing GOLEM on STREAMING LIVE...
# Long Pos = 0
# Short Pos = 0
# Instrument : SPX500
#
# GOLEM begins testing...
# Testing executed in = 1.740000 secondes
# Time of request
# 9 H 49 min 3 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-21 09:48:00        0       0.003494          1        95.095406
#
#        Actual
# 7950  2950.58
#
# Aroon : -76.0
# Long Pos = 0
# Short Pos = 0
# W0621 11:49:04.536417 123145554497536 fxcmpy.py:2681] Got a insert event for open positions: {'t': 1, 'ratePrecision': 2, 'tradeId': '151524939', 'accountName': '01147539', 'accountId': '1147539', 'roll': 0, 'com': 0, 'open': 2950.32, 'valueDate': '', 'grossPL': -9.02587, 'close': 2950.66, 'visiblePL': -3.4, 'isDisabled': False, 'currency': 'SPX500', 'isBuy': False, 'amountK': 0.03, 'currencyPoint': 0.00265, 'time': '06212019094904', 'usedMargin': 2100, 'stop': 0, 'stopMove': 0, 'limit': 2655.46, 'action': 'I'}.
# W0621 11:49:04.542485 123145554497536 fxcmpy.py:2603] Got a delete event for orders: {'t': 3, 'orderId': '317153433', 'action': 'D'}.
# Go Short
# Sell Price : 2950.58
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 2.770000 secondes
# Time of request
# 9 H 50 min 2 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-21 09:49:00        0            0.0          1        96.465988
#
#        Actual
# 7950  2951.12
#
#  pnl :  -0.54
# Aroon : -76.0
# Long Pos = 0
# Short Pos = 1
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 2.250000 secondes
# Time of request
# 9 H 51 min 2 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-21 09:50:00        1      91.315323          0              0.0
#
#        Actual
# 7950  2950.18
#
#  pnl :  0.4
# Aroon : -84.0
# Long Pos = 0
# Short Pos = 1
# W0621 11:51:03.261286 123145554497536 fxcmpy.py:2733] Got a insert event for closed positions: {'t': 2, 'ratePrecision': 2, 'tradeId': '151524939', 'accountName': '01147539', 'roll': 0, 'com': 0, 'open': 2950.32, 'valueDate': '', 'grossPL': 5.31, 'close': 2950.12, 'visiblePL': 2, 'currency': 'SPX500', 'isBuy': False, 'amountK': 0.03, 'currencyPoint': 0.00265, 'openTime': '06212019094904', 'closeTime': '06212019095102', 'action': 'I'}.
# W0621 11:51:03.263428 123145554497536 fxcmpy.py:2684] Got a delete event for open posi: {'t': 1, 'tradeId': '151524939', 'action': 'D'}
#   Close Short avec un pnl de 0.40000000000009095
# W0621 11:51:03.739013 123145554497536 fxcmpy.py:2681] Got a insert event for open positions: {'t': 1, 'ratePrecision': 2, 'tradeId': '151525270', 'accountName': '01147539', 'accountId': '1147539', 'roll': 0, 'com': 0, 'open': 2950.12, 'valueDate': '', 'grossPL': -7.96291, 'close': 2949.82, 'visiblePL': -3, 'isDisabled': False, 'currency': 'SPX500', 'isBuy': True, 'amountK': 0.03, 'currencyPoint': 0.00265, 'time': '06212019095103', 'usedMargin': 2100, 'stop': 0, 'stopMove': 0, 'limit': 3245.34, 'action': 'I'}.
# W0621 11:51:03.747925 123145554497536 fxcmpy.py:2603] Got a delete event for orders: {'t': 3, 'orderId': '317154006', 'action': 'D'}.
# Go Long
# Buy Price : 2950.18
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 1.790000 secondes
# Time of request
# 9 H 52 min 1 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-21 09:51:00        1      91.233047          0              0.0
#
#        Actual
# 7950  2949.84
#
#  pnl :  -0.34
# Aroon : -84.0
# Long Pos = 1
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 1.600000 secondes
# Time of request
# 9 H 53 min 1 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-21 09:52:00        0       0.000041          1        96.242798
#
#        Actual
# 7950  2950.26
#
#  pnl :  0.08
# Aroon : -84.0
# Long Pos = 1
# Short Pos = 0
#   Close Long avec un pnl de 0.08000000000038199
# W0621 11:53:02.597336 123145554497536 fxcmpy.py:2733] Got a insert event for closed positions: {'t': 2, 'ratePrecision': 2, 'tradeId': '151525270', 'accountName': '01147539', 'roll': 0, 'com': 0, 'open': 2950.12, 'valueDate': '', 'grossPL': -7.96, 'close': 2949.82, 'visiblePL': -3, 'currency': 'SPX500', 'isBuy': True, 'amountK': 0.03, 'currencyPoint': 0.00265, 'openTime': '06212019095103', 'closeTime': '06212019095302', 'action': 'I'}.
# W0621 11:53:02.599267 123145554497536 fxcmpy.py:2684] Got a delete event for open posi: {'t': 1, 'tradeId': '151525270', 'action': 'D'}
# W0621 11:53:03.088077 123145554497536 fxcmpy.py:2681] Got a insert event for open positions: {'t': 1, 'ratePrecision': 2, 'tradeId': '151525322', 'accountName': '01147539', 'accountId': '1147539', 'roll': 0, 'com': 0, 'open': 2949.82, 'valueDate': '', 'grossPL': -7.96316, 'close': 2950.12, 'visiblePL': -3, 'isDisabled': False, 'currency': 'SPX500', 'isBuy': False, 'amountK': 0.03, 'currencyPoint': 0.00265, 'time': '06212019095302', 'usedMargin': 2100, 'stop': 0, 'stopMove': 0, 'limit': 2654.99, 'action': 'I'}.
# W0621 11:53:03.091722 123145554497536 fxcmpy.py:2603] Got a delete event for orders: {'t': 3, 'orderId': '317154105', 'action': 'D'}.
# Go Short
# Sell Price : 2950.26
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 1.640000 secondes
# Time of request
# 9 H 54 min 0 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-21 09:53:00        0       0.001533          1        95.522156
#
#        Actual
# 7950  2949.94
#
#  pnl :  0.32
# Aroon : -84.0
# Long Pos = 0
# Short Pos = 1
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 2.220000 secondes
# Time of request
# 9 H 55 min 0 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-21 09:54:00        0       0.000102          1        95.900665
#
#        Actual
# 7950  2950.08
#
#  pnl :  0.18
# Aroon : -84.0
# Long Pos = 0
# Short Pos = 1
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 1.870000 secondes
# Time of request
# 9 H 56 min 1 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-21 09:55:00        0       0.000015          1        95.890846
#
#        Actual
# 7950  2950.18
#
#  pnl :  0.08
# Aroon : -80.0
# Long Pos = 0
# Short Pos = 1
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 2.660000 secondes
# Time of request
# 9 H 57 min 2 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-21 09:56:00        0            0.0          1        96.716156
#
#        Actual
# 7950  2950.84
#
#  pnl :  -0.58
# Aroon : -76.0
# Long Pos = 0
# Short Pos = 1
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 1.720000 secondes
# Time of request
# 9 H 58 min 0 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-21 09:57:00        0            0.0          1        96.219048
#
#        Actual
# 7950  2950.94
#
#  pnl :  -0.68
# Aroon : -68.0
# Long Pos = 0
# Short Pos = 1
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 1.740000 secondes
# Time of request
# 9 H 59 min 0 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-21 09:58:00        0            0.0          1        97.042427
#
#        Actual
# 7950  2951.84
#
#  pnl :  -1.58
# Aroon : -68.0
# Long Pos = 0
# Short Pos = 1
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-95424125c217> in <module>
#     422
#     423 con = connexion()
# --> 424 main(con,ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik,targetup,targetdown,pos_long,pos_short)
#
# <ipython-input-8-95424125c217> in main(con, ticker, period, number, long_open, long_close, short_open, short_close, jet_lag, pik, targetup, targetdown, pos_long, pos_short)
#     309
#     310             tmps1=time.time()
# --> 311             con.subscribe_market_data(ticker)
#     312
#     313             last = con.get_candles(ticker, period=period,number=1)
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/fxcmpy/fxcmpy.py in subscribe_market_data(self, symbol, add_callbacks)
#     744         params = {'pairs': symbol}
#     745         data = self.__handle_request__(method='subscribe', params=params,
# --> 746                                        protocol='post')
#     747         if symbol not in self.prices:
#     748             data = data['pairs'][0]
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/fxcmpy/fxcmpy.py in __handle_request__(self, method, params, protocol)
#    2467             req = requests.post('%s:443/%s' % (self.trading_url, method),
#    2468                                 headers=self.request_headers, data=params,
# -> 2469                                 proxies=self.proxies)
#    2470             self.logger.info('Sending POST Request:')
#    2471             self.logger.info('URL: %s' % req.url)
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     114     """
#     115
# --> 116     return request('post', url, data=data, json=json, **kwargs)
#     117
#     118
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     342             ca_cert_dir=self.ca_cert_dir,
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#     346         if self.assert_fingerprint:
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     342             or IS_SECURETRANSPORT):
#     343         if HAS_SNI and server_hostname is not None:
# --> 344             return context.wrap_socket(sock, server_hostname=server_hostname)
#     345
#     346         warnings.warn(
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     451         while True:
#     452             try:
# --> 453                 cnx.do_handshake()
#     454             except OpenSSL.SSL.WantReadError:
#     455                 if not util.wait_for_read(sock, sock.gettimeout()):
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1912         :return: None.
#    1913         """
# -> 1914         result = _lib.SSL_do_handshake(self._ssl)
#    1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# KeyboardInterrupt:

# %%
pnl_live = con.get_open_positions().iloc[0,-1]
pnl_live
# Out:
# -5.4

# %%
buy_price = con.get_open_positions().iloc[0,11]
buy_price
# Out:
# 2949.82

# %%
is_buy = con.get_open_positions().iloc[0,8]
is_buy
# Out:
# False

# %%
con.get_open_positions().iloc[0,2] == 0.03
# Out:
# True
# W0621 12:13:04.888087 123145554497536 fxcmpy.py:2733] Got a insert event for closed positions: {'t': 2, 'ratePrecision': 2, 'tradeId': '151525322', 'accountName': '01147539', 'roll': 0, 'com': 0, 'open': 2949.82, 'valueDate': '', 'grossPL': 13.81, 'close': 2949.3, 'visiblePL': 5.2, 'currency': 'SPX500', 'isBuy': False, 'amountK': 0.03, 'currencyPoint': 0.00266, 'openTime': '06212019095302', 'closeTime': '06212019101304', 'action': 'I'}.
# W0621 12:13:04.890198 123145554497536 fxcmpy.py:2684] Got a delete event for open posi: {'t': 1, 'tradeId': '151525322', 'action': 'D'}

# %%
con.get_open_positions().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 22 columns):
# accountId        1 non-null object
# accountName      1 non-null object
# amountK          1 non-null float64
# close            1 non-null float64
# com              1 non-null int64
# currency         1 non-null object
# currencyPoint    1 non-null float64
# grossPL          1 non-null float64
# isBuy            1 non-null bool
# isDisabled       1 non-null bool
# limit            1 non-null float64
# open             1 non-null float64
# ratePrecision    1 non-null int64
# roll             1 non-null int64
# stop             1 non-null int64
# stopMove         1 non-null int64
# t                1 non-null int64
# time             1 non-null object
# tradeId          1 non-null object
# usedMargin       1 non-null int64
# valueDate        1 non-null object
# visiblePL        1 non-null float64
# dtypes: bool(2), float64(7), int64(7), object(6)
# memory usage: 242.0+ bytes

# %%
con.get_open_trade_ids()[-1]

# %%
tradeId_short = con.get_open_trade_ids()[-1]
                  
order = con.close_trade(trade_id=tradeId_short, amount=30)
pos_short = 0
# Out:
# W0621 10:30:03.132570 123145530036224 fxcmpy.py:2733] Got a insert event for closed positions: {'t': 2, 'ratePrecision': 2, 'tradeId': '151486089', 'accountName': '01147539', 'roll': 0, 'com': 0, 'open': 2952.88, 'valueDate': '', 'grossPL': 10.61, 'close': 2952.48, 'visiblePL': 4, 'currency': 'SPX500', 'isBuy': False, 'amountK': 0.03, 'currencyPoint': 0.00265, 'openTime': '06212019081911', 'closeTime': '06212019082954', 'action': 'I'}.
# W0621 10:30:03.134351 123145530036224 fxcmpy.py:2684] Got a delete event for open posi: {'t': 1, 'tradeId': '151486089', 'action': 'D'}
# W0621 10:39:53.411023 123145530036224 fxcmpy.py:2733] Got a insert event for closed positions: {'t': 2, 'ratePrecision': 2, 'tradeId': '151487444', 'accountName': '01147539', 'roll': 0, 'com': 0, 'open': 2952.36, 'valueDate': '', 'grossPL': 5.84, 'close': 2952.14, 'visiblePL': 2.2, 'currency': 'SPX500', 'isBuy': False, 'amountK': 0.03, 'currencyPoint': 0.00265, 'openTime': '06212019082901', 'closeTime': '06212019083952', 'action': 'I'}.
# W0621 10:39:53.429666 123145530036224 fxcmpy.py:2684] Got a delete event for open posi: {'t': 1, 'tradeId': '151487444', 'action': 'D'}
# W0621 10:45:07.379721 123145530036224 fxcmpy.py:2733] Got a insert event for closed positions: {'t': 2, 'ratePrecision': 2, 'tradeId': '151486887', 'accountName': '01147539', 'roll': 0, 'com': 0, 'open': 2952.02, 'valueDate': '', 'grossPL': 24.94, 'close': 2951.08, 'visiblePL': 9.4, 'currency': 'SPX500', 'isBuy': False, 'amountK': 0.03, 'currencyPoint': 0.00265, 'openTime': '06212019082503', 'closeTime': '06212019084507', 'action': 'I'}.
# W0621 10:45:07.536461 123145530036224 fxcmpy.py:2684] Got a delete event for open posi: {'t': 1, 'tradeId': '151486887', 'action': 'D'}

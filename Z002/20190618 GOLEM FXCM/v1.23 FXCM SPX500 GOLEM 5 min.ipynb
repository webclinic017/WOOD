# %%
TOKEN = 'e053ac1597cef331df9429ac8151100ea9f1c411'
server = 'demo'

# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'
ticker = 'SPX500'
period = 'm5'
number = 8000
long_open = 90
long_close = 85
short_open = 90
short_close = 85
jet_lag = -2
pik_long = 0.08
pik_short = 0.08
targetup = 0.5
targetdown = 0.5
# Time Windows
# start = dt.datetime(2017, 7, 15)
# stop = dt.datetime(2017, 8, 1)
# con.get_candles('EUR/USD', period='D1',start=start, stop=stop)

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return True;
# }

# %%
pos_long = 0
pos_short = 0

# %%
___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor\n°OoO_FXCM_Oo0°\nLumberJack Jyss 5779(c)')
print('Version v1.22')
print('Importing librairies...')
import fxcmpy
print('version fxcmpy :',fxcmpy.__version__)
import time
import numpy as np
import pandas as pd
from colorama import Fore, Back, Style 
import datetime as dt
import talib
from zigzag import *
#import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
#from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report
print('Librairies imported')
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
buy_price = 0
sell_price = 0
pnl = 0
#try :

def connexion():
    tmps1=time.time()
    print('Connecting server...')
    con = fxcmpy.fxcmpy(access_token=TOKEN, log_level='error',server= server)
    if con.is_connected():
        print('Connection established for', Fore.BLUE + str(con.get_account_ids()[-1]),Style.RESET_ALL,' - Mode :',Fore.RED + server,Style.RESET_ALL)
    else:
        print('Not connected. Will try again in 10 seconds')
        dt.time(10)
        con = connexion()
    tmps2=round(time.time()-tmps1,2)
    print ("Connexion executed in = %f" %tmps2,'secondes')
    return(con)

def scrap_data(ticker,period,number):
    tmps1=time.time()
    data = con.get_candles(ticker, period=period,number=number) #start=start,stop=stop)
    df = pd.DataFrame()
    df['Open'] = data['askopen']
    df['High'] = data['askhigh']
    df['Low'] = data['asklow']
    df['Close'] = data['askclose']
    df['Date'] = data.index
    df = df[['Date'] + df.columns[:-1].tolist()]
    tmps2=round(time.time()-tmps1,2)
    print (Fore.GREEN + "Scrap (historical) executed in = %f"  %tmps2,'secondes',Style.RESET_ALL)
    return(df)

def prepa_data(df,pik_long, pik_short,targetup,targetdown):
    tmps1=time.time()
    df.reset_index(inplace=True,drop=True)
    dataset_1D = df.copy()
    dataset_1D = dataset_1D.dropna()
    rsi = talib.RSI(dataset_1D['Close'],timeperiod=2)
    upper, middle, lower =  talib.BBANDS(dataset_1D['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(dataset_1D['Close'],timeperiod=5)
    sma8 = talib.SMA(dataset_1D['Close'],timeperiod=8)
    sma10 = talib.SMA(dataset_1D['Close'],timeperiod=10)
    sma12 = talib.SMA(dataset_1D['Close'],timeperiod=12)
    sma15 = talib.SMA(dataset_1D['Close'],timeperiod=15)
    sma30 = talib.SMA(dataset_1D['Close'],timeperiod=30)
    sma35 = talib.SMA(dataset_1D['Close'],timeperiod=35)
    sma40 = talib.SMA(dataset_1D['Close'],timeperiod=40)
    sma45 = talib.SMA(dataset_1D['Close'],timeperiod=45)
    sma50 = talib.SMA(dataset_1D['Close'],timeperiod=50)
    aroondown, aroonup = talib.AROON(dataset_1D['High'], dataset_1D['Low'], timeperiod=25)
    aroon = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))

    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50

    X = dataset_1D['Close']
    pivots = peak_valley_pivots(X.values, pik_long, -pik_short)
    ts_pivots = pd.Series(X, index=X.index)
    ts_pivots = ts_pivots[pivots != 0]

    peak = []
    valley = []

    for i in range(0,dataset_1D.shape[0]):
        if pivots[i] == 1:
            peak.append(pivots[i])
            valley.append(0)
        elif pivots[i] == -1:
            peak.append(0)
            valley.append(pivots[i])
        else:
            peak.append(0)
            valley.append(0)

    bbdelta = upper - middle
    price_bolup = dataset_1D['Close'] - lower
    price_bolow = dataset_1D['Close'] - upper

    rsi5_list = []
    rsi95_list = []
    for i in range(0,dataset_1D.shape[0]):
        try:
            rsi95_list.append(95 - rsi[i])
            rsi5_list.append(rsi[i] - 5)
        except:
            rsi95_list.append(0)
            rsi5_list.append(0)
    varop_spy = dataset_1D['Open'] - dataset_1D['Close']
    varhl_spy = dataset_1D['High'] - dataset_1D['Low']
    dataset_1D['Varop_Spy'] = varop_spy
    dataset_1D['Varhl_spy'] = varhl_spy
    dataset_1D['RSI'] = rsi
    dataset_1D['Aroon'] = aroon
    dataset_1D['95 - RSI'] = np.array(rsi95_list)
    dataset_1D['RSI - 5'] = np.array(rsi5_list)
    dataset_1D['BBD_Delta_Up'] = bbdelta
    dataset_1D['delta5_8'] = delta5_8
    dataset_1D['delta8_10'] = delta8_10
    dataset_1D['delta10_12'] = delta10_12
    dataset_1D['delta12_15'] = delta12_15
    dataset_1D['delta15_30'] = delta15_30
    dataset_1D['delta30_35'] = delta30_35
    dataset_1D['delta35_40'] = delta35_40
    dataset_1D['delta40_45'] = delta40_45
    dataset_1D['delta45_50'] = delta45_50
    dataset_1D['Peaks'] = abs(np.array(peak))
    dataset_1D['Valley'] = abs(np.array(valley))
    tsf = talib.TSF(dataset_1D['Close'],timeperiod=14)
    delta_tsf = dataset_1D['Close'] - tsf
    dataset_1D['delta_tsf'] = tsf
    forosc = []
    forosc.append(0)
    for i in range(1,dataset_1D.shape[0]):
        try:
            forosc.append((dataset_1D.iloc[i,4] - tsf[i-1])*100/dataset_1D.iloc[i,4])
        except:
            forosc.append(0)
    dataset_1D['Forcast Oscillator'] = (forosc)
    target_up = []
    target_down = []

    for i in range(0,dataset_1D.shape[0]-5):

        if (dataset_1D.iloc[i+1,5] * dataset_1D.iloc[i,5]) < 0 :
            if (dataset_1D.iloc[i+1,4] - dataset_1D.iloc[i,4]) > targetup : 
                target_up.append(1)
                target_down.append(0)
            elif (dataset_1D.iloc[i+1,4] - dataset_1D.iloc[i,4]) < -targetdown: 
                target_up.append(0)
                target_down.append(1)
            else:
                target_up.append(0)
                target_down.append(0)
        else :
            target_up.append(0)
            target_down.append(0) 

    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    dataset_1D['target_up'] = target_up  # target_up # abs(np.array(valley))#target_up
    dataset_1D['target_down'] = target_down # target_down # abs(np.array(peak))#target_down
    dataset_1D['target_value'] = dataset_1D['Close']
    dataset_1D = dataset_1D.drop(['Open','High','Low','Close'],axis=1)
    df_1D = dataset_1D.copy()
    df_1D = df_1D.iloc[:,1:]
    df_1D['Date'] = df['Date']
    df_1D = df_1D.dropna()
    df_1D = df_1D[['Date'] + df_1D.columns[:-1].tolist()]
    df_1D.reset_index(inplace=True,drop=True)
    return(df_1D,aroon)
    
def deep_learning(df_1D):
    tmps1=time.time()
    X = df_1D.iloc[:,1:-3]
    y_up = df_1D.iloc[:,-3].values
    y_down = df_1D.iloc[:,-2].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:-1,:]
    Xtest = X[-1:,:]
    ytrain_up = y_up[:-1,:]
    ytest_up = y_up[-1:,:]
    ytrain_down = y_down[:-1,:]
    ytest_down = y_down[-1:,:]

    seed = 770
    np.random.seed(seed)

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    model_up = Sequential()
        # Add an input layer 
    model_up.add(Dense(30, activation='relu'))
        # Add one hidden layer 
    model_up.add(Dense(30, activation='relu'))
        # Add an output layer 
    model_up.add(Dense(1, activation='sigmoid'))

    model_down = Sequential()
        # Add an input layer 
    model_down.add(Dense(30, activation='relu'))
        # Add one hidden layer 
    model_down.add(Dense(30, activation='relu'))
        # Add an output layer 
    model_down.add(Dense(1, activation='sigmoid'))

    print('Processing move_up')
    model_up.compile(loss='binary_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy','mse'])

    history_up = model_up.fit(Xtrain, ytrain_up,epochs=50, batch_size=32, verbose=0)

    print('Processing move_down')
    model_down.compile(loss='binary_crossentropy',
                    optimizer='adam',
                    metrics=['accuracy','mse'])

    history_down = model_down.fit(Xtrain, ytrain_down,epochs=50, batch_size=32, verbose=0)

    print('Computing done')


    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)
    resultats = pd.DataFrame()
    resultats['Date'] = df_1D.iloc[-1:,0]
    resultats['Move Up'] = yhat_up
    resultats['Confidence up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confidence Down'] = (predict_down)*100
    resultats['Actual'] = df_1D['target_value']
    tmps2=round(time.time()-tmps1,2)
    print ("DL executed in = %f" %tmps2,'seconds')
    print('Results :\n \033[31m', resultats,'\n',Style.RESET_ALL)
    return(resultats,scaler,model_up,model_down)

def main(con,ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik_long, pik_short,targetup,targetdown,pos_long,pos_short):
    
    for ukulele in range (0,500):

        # CONNEXION TESTING
        if con.is_connected() == False:
            con = connexion()
            time.sleep(3)
        print(' \n MEGA LOOP ',ukulele,'\n')
        df = scrap_data(ticker,period,number)

        print('\033[33m' + 'Initializing GOLEM...')
        print('\033[35m' +'Long Pos =',pos_long)
        print('Short Pos =',pos_short,Style.RESET_ALL)


        # DATA PREPARATION
        df_1D,aroon = prepa_data(df,pik_long, pik_short,targetup,targetdown)

        print('\033[36m'+'GOLEM begins Computing...'+Style.RESET_ALL)

        # DEEP LEARNING

        resultats,scaler,model_up,model_down = deep_learning (df_1D)

        # TESTING POSITIONS

        # TEST POS
        print('Aroon :',aroon.iloc[-1])
        print('Long Pos =',pos_long)
        print('Short Pos =',pos_short)
        print('Initializing GOLEM on STREAMING LIVE...')
        print('Long Pos =',pos_long)
        print('Short Pos =',pos_short)
        # SCRAP DATA
        print('Instrument :', ticker)

        for loop in range(0,2000):

            #print(' \n INFRA LOOP ',loop,'\n')
            if con.is_connected() == False:
                con = connexion()

            tmps1=time.time()
            con.subscribe_market_data(ticker)

            last = con.get_candles(ticker, period=period,number=1)
            try:
                pnl = con.get_open_positions().iloc[0,-1]
            except :
                pass
            if last.index[-1].minute < df.iloc[-1,0].minute+5 :
                if  pos_long == 0 and pos_short == 1 and pnl > 7:
                    tradeId_short = con.get_open_trade_ids()[-1]
                    order = con.close_trade(trade_id=tradeId_short, amount=30)
                    pos_short = 0
                    print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')
                
                if  pos_long == 0 and pos_short == 1 and pnl < -21:
                    tradeId_short = con.get_open_trade_ids()[-1]
                    order = con.close_trade(trade_id=tradeId_short, amount=30)
                    pos_short = 0
                    print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')
                    
                if  pos_long == 1 and pos_short == 0 and pnl > 7:
                    tradeId_long = con.get_open_trade_ids()[-1]
                    order = con.close_trade(trade_id=tradeId_long, amount=30)
                    print('\033[47m \033[31m Close Long avec un pnl de', pnl,'\033[0m')
                    pos_long = 0
                
                if  pos_long == 1 and pos_short == 0 and pnl < -21:
                    tradeId_long = con.get_open_trade_ids()[-1]
                    order = con.close_trade(trade_id=tradeId_long, amount=30)
                    print('\033[47m \033[31m Close Long avec un pnl de', pnl,'\033[0m')
                    pos_long = 0
                print('\033[43m'+' Tempo '+'\033[0m'+'\033[46m'+'...'+'\033[0m',end='')                
                continue

            else :
                df = df.iloc[1:,:]
                df = df.append({'Date':last.index[-1],'Open':last.iloc[-1,4], 'High':last.iloc[-1,6],'Low':last.iloc[-1,7], 'Close':last.iloc[-1,5]}, ignore_index=True)

                df_1D,aroon = prepa_data(df,pik_long, pik_short,targetup,targetdown)

                # TESTING ONLY
                print()
                print('GOLEM begins testing...')

                X = df_1D.iloc[:,1:-3]
                X = scaler.fit_transform(X)
                Xtest = X[-1:,:]

                seed = 770
                np.random.seed(seed)

                yhat_up = model_up.predict_classes(Xtest)
                yhat_down = model_down.predict_classes(Xtest)

                predict_up = model_up.predict(Xtest)
                predict_down = model_down.predict(Xtest)
                resultats = pd.DataFrame()
                resultats['Date'] = df_1D.iloc[-1:,0]
                resultats['Move Up'] = yhat_up
                resultats['Confidence up'] = (predict_up)*100
                resultats['Move Down'] = yhat_down
                resultats['Confidence Down'] = (predict_down)*100
                resultats['Actual'] = df_1D['target_value']
                #resultats,scaler,model_up,model_down = deep_learning (df_1D)
                tmps2=round(time.time()-tmps1,2)
                print ("Testing executed in = %f" %tmps2,'secondes')
                print('Time of request', Fore.BLUE)
                print(dt.datetime.now().hour+jet_lag,'H',dt.datetime.now().minute,'min',dt.datetime.now().second,'seconds',Style.RESET_ALL)
                print('Results :\n')
                print('\033[45m')
                print(resultats)
                print(Style.RESET_ALL)
                
                # TEST POSITION EN L'AIR
                if pos_long == 0 and pos_short == 0:
                    try:
                        if con.get_open_positions().iloc[0,8] == True:
                            pos_long = 1
                        if con.get_open_positions().iloc[0,8] == False:
                            pos_short
                    except:
                        print("Pas de position en l'air")
                    
                
                # TEST OUVERTURE
                try : 
                    
                    if con.get_open_positions().iloc[0,2] != 0.03:
                        pos_long = 0
                        pos_short = 0
                except:
                    pass

                if pos_long == 1:

                    pnl = con.get_open_positions().iloc[0,-1]
                    if pnl > 0 :
                        print('\033[42m pnl : ',round(pnl,2),'\033[0m')
                    elif pnl < 0:
                        print('\033[41m pnl : ',round(pnl,2),'\033[0m')
                elif pos_short == 1:

                    pnl = con.get_open_positions().iloc[0,-1]
                    if pnl > 0 :
                        print('\033[42m pnl : ',round(pnl,2),'\033[0m')
                    elif pnl < 0:
                        print('\033[41m pnl : ',round(pnl,2),'\033[0m')

                print('Aroon :',aroon.iloc[-1])
                print('Long Pos =',pos_long)
                print('Short Pos =',pos_short)

                # ACTIONS
                if con.is_connected() == False:
                    con = connexion()
                
                if  pos_long == 0 and pos_short == 1 and pnl > 7:
                    tradeId_short = con.get_open_trade_ids()[-1]
                    order = con.close_trade(trade_id=tradeId_short, amount=30)
                    time.sleep(10)
                    pos_short = 0
                    print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')
                
                if  pos_long == 0 and pos_short == 1 and pnl < -21:
                    tradeId_short = con.get_open_trade_ids()[-1]
                    order = con.close_trade(trade_id=tradeId_short, amount=30)
                    time.sleep(10)
                    pos_short = 0
                    print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')
                    
                if  pos_long == 1 and pos_short == 0 and pnl > 7:
                    tradeId_long = con.get_open_trade_ids()[-1]
                    order = con.close_trade(trade_id=tradeId_long, amount=30)
                    time.sleep(10)
                    print('\033[47m \033[31m Close Long avec un pnl de', pnl,'\033[0m')
                    pos_long = 0
                
                if  pos_long == 1 and pos_short == 0 and pnl < -21:
                    tradeId_long = con.get_open_trade_ids()[-1]
                    order = con.close_trade(trade_id=tradeId_long, amount=30)
                    time.sleep(10)
                    print('\033[47m \033[31m Close Long avec un pnl de', pnl,'\033[0m')
                    pos_long = 0
                    
                if resultats.iloc[0,1] == 1 and resultats.iloc[0,2] > short_close:

                    if  pos_long == 0 and pos_short == 1 :
                        #order = con.close_all_for_symbol(ticker)
                        tradeId_short = con.get_open_trade_ids()[-1]
                        pnl = con.get_open_positions().iloc[0,-1]
                        order = con.close_trade(trade_id=tradeId_short, amount=30)
                        time.sleep(10)
                        pos_short = 0
                        print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')


                    if pos_long == 0 and pos_short == 0 and resultats.iloc[0,2] > long_open:
                        #order = con.create_market_buy_order(ticker, 30)
                        order = con.open_trade(symbol=ticker,is_buy=True,amount=30,order_type='MarketRange',time_in_force='IOC')#,\
                                               #stop=(last.iloc[-1,5]-2.0))
                        time.sleep(10)
                        print('Go Long')
                        print('Buy Price :',con.get_open_positions().iloc[0,11])
                        buy_price = con.get_open_positions().iloc[0,11]
                        pos_long = 1



                elif resultats.iloc[0,3] == 1 and resultats.iloc[0,4] > long_close:

                    if  pos_long == 1 and pos_short == 0:
                        #order = con.close_all_for_symbol(ticker)
                        tradeId_long = con.get_open_trade_ids()[-1]
                        pnl = con.get_open_positions().iloc[0,-1]
                        order = con.close_trade(trade_id=tradeId_long, amount=30)
                        time.sleep(10)
                        print('\033[47m \033[31m Close Long avec un pnl de', pnl,'\033[0m')
                        pos_long = 0

                    if pos_long == 0 and pos_short == 0 and resultats.iloc[0,4] > short_open:
                        #order = con.create_market_sell_order(ticker, 30)
                        order = con.open_trade(symbol=ticker,is_buy=False,amount=30,order_type='MarketRange',time_in_force='IOC')#,\
                                               #stop=(last.iloc[-1,5]+2.0))
                        time.sleep(10)
                        print('Go Short')
                        print('Sell Price :',con.get_open_positions().iloc[0,11])
                        sell_price = con.get_open_positions().iloc[0,11]
                        pos_short = 1
    return(con)

try:
    con = connexion()
except:
    con = fxcmpy.fxcmpy
    main(con,ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik_long, pik_short,targetup,targetdown,pos_long,pos_short) 
main(con,ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik_long, pik_short,targetup,targetdown,pos_long,pos_short)
# Out:
# Global Optimized LumberJack Environment Motor
# °OoO_FXCM_Oo0°
# LumberJack Jyss 5779(c)
# Version v1.22
# Importing librairies...
# version fxcmpy : 1.2.4
# Using TensorFlow backend.
# Librairies imported
# Connecting server...
# WARNING: Logging before flag parsing goes to stderr.
# W0626 17:02:00.259742 4693796288 fxcmpy.py:222] Default account set to 1147539, to change use set_default_account().
# Connection established for 1147539   - Mode : demo
# Connexion executed in = 7.190000 secondes
#
#  MEGA LOOP  0
#
# Scrap (historical) executed in = 2.070000 secondes
# Initializing GOLEM...
# Long Pos = 0
# Short Pos = 0
# GOLEM begins Computing...
# Processing move_up
# Processing move_down
# Computing done
# DL executed in = 22.630000 seconds
# Results :
#                       Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-26 14:55:00        1      91.838173          0         0.662403
#
#        Actual
# 7950  2925.96
#
# Aroon : -36.0
# Long Pos = 0
# Short Pos = 0
# Initializing GOLEM on STREAMING LIVE...
# Long Pos = 0
# Short Pos = 0
# Instrument : SPX500
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... ...
#  MEGA LOOP  1
#
# Scrap (historical) executed in = 2.830000 secondes
# Initializing GOLEM...
# Long Pos = 0
# Short Pos = 0
# GOLEM begins Computing...
# Processing move_up
# Processing move_down
# Computing done
# DL executed in = 23.510000 seconds
# Results :
#                       Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-26 16:05:00        1      82.564919          0        12.883179
#
#        Actual
# 7950  2924.86
#
# Aroon : 32.0
# Long Pos = 0
# Short Pos = 0
# Initializing GOLEM on STREAMING LIVE...
# Long Pos = 0
# Short Pos = 0
# Instrument : SPX500
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 3.300000 secondes
# Time of request
# 16 H 15 min 3 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-26 16:10:00        1      85.078743          0          0.48331
#
#       Actual
# 7950  2924.4
#
# Pas de position en l'air
# Aroon : 32.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 3.330000 secondes
# Time of request
# 16 H 20 min 2 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-26 16:15:00        1      74.164787          0         0.004922
#
#        Actual
# 7950  2923.62
#
# Pas de position en l'air
# Aroon : 32.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 2.300000 secondes
# Time of request
# 16 H 25 min 1 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-26 16:20:00        1      67.626373          0         0.000027
#
#        Actual
# 7950  2922.65
#
# Pas de position en l'air
# Aroon : 32.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 2.320000 secondes
# Time of request
# 16 H 30 min 1 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-26 16:25:00        1      81.596169          0         3.465117
#
#        Actual
# 7950  2923.65
#
# Pas de position en l'air
# Aroon : 32.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 2.220000 secondes
# Time of request
# 16 H 35 min 2 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-26 16:30:00        1       86.18438          0          4.26468
#
#       Actual
# 7950  2924.2
#
# Pas de position en l'air
# Aroon : 28.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 2.230000 secondes
# Time of request
# 16 H 40 min 2 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-26 16:35:00        1      80.499069          0        12.855837
#
#        Actual
# 7950  2924.84
#
# Pas de position en l'air
# Aroon : -40.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 2.600000 secondes
# Time of request
# 16 H 45 min 2 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-26 16:40:00        1      74.420845          0        25.240786
#
#        Actual
# 7950  2926.15
#
# Pas de position en l'air
# Aroon : -40.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# GOLEM begins testing...
# Testing executed in = 2.430000 secondes
# Time of request
# 16 H 50 min 2 seconds
# Results :
#
#
#                     Date  Move Up  Confidence up  Move Down  Confidence Down  \
# 7950 2019-06-26 16:45:00        1      80.056625          0         0.002858
#
#        Actual
# 7950  2924.36
#
# Pas de position en l'air
# Aroon : -40.0
# Long Pos = 0
# Short Pos = 0
#  Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ... Tempo ...
# W0626 20:30:32.169902 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 60] Operation timed out)
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     452             try:
# --> 453                 cnx.do_handshake()
#     454             except OpenSSL.SSL.WantReadError:
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1638                     if errno != 0:
# -> 1639                         raise SysCallError(errno, errorcode.get(errno))
#    1640                 raise SysCallError(-1, "Unexpected EOF")
#
# SysCallError: (50, 'ENETDOWN')
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     343         if HAS_SNI and server_hostname is not None:
# --> 344             return context.wrap_socket(sock, server_hostname=server_hostname)
#     345
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     458             except OpenSSL.SSL.Error as e:
# --> 459                 raise ssl.SSLError('bad handshake: %r' % e)
#     460             break
#
# SSLError: ("bad handshake: SysCallError(50, 'ENETDOWN')",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /subscribe (Caused by SSLError(SSLError("bad handshake: SysCallError(50, 'ENETDOWN')",),))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-4-7b5148e4bfca> in <module>
#     504     con = fxcmpy.fxcmpy
#     505     main(con,ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik_long, pik_short,targetup,targetdown,pos_long,pos_short)
# --> 506 main(con,ticker,period,number,long_open,long_close,short_open,short_close,jet_lag,pik_long, pik_short,targetup,targetdown,pos_long,pos_short)
#
# <ipython-input-4-7b5148e4bfca> in main(con, ticker, period, number, long_open, long_close, short_open, short_close, jet_lag, pik_long, pik_short, targetup, targetdown, pos_long, pos_short)
#     309
#     310             tmps1=time.time()
# --> 311             con.subscribe_market_data(ticker)
#     312
#     313             last = con.get_candles(ticker, period=period,number=1)
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/fxcmpy/fxcmpy.py in subscribe_market_data(self, symbol, add_callbacks)
#     744         params = {'pairs': symbol}
#     745         data = self.__handle_request__(method='subscribe', params=params,
# --> 746                                        protocol='post')
#     747         if symbol not in self.prices:
#     748             data = data['pairs'][0]
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/fxcmpy/fxcmpy.py in __handle_request__(self, method, params, protocol)
#    2467             req = requests.post('%s:443/%s' % (self.trading_url, method),
#    2468                                 headers=self.request_headers, data=params,
# -> 2469                                 proxies=self.proxies)
#    2470             self.logger.info('Sending POST Request:')
#    2471             self.logger.info('URL: %s' % req.url)
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     114     """
#     115
# --> 116     return request('post', url, data=data, json=json, **kwargs)
#     117
#     118
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /subscribe (Caused by SSLError(SSLError("bad handshake: SysCallError(50, 'ENETDOWN')",),))
# W0627 00:16:50.273402 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 50] Network is down)
# W0627 00:16:51.282672 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587411277-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1341ac240>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:16:52.293187 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587412288-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11096e6a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:16:53.300279 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587413295-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11096e518>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:16:54.307438 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587414303-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x11096e588>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:16:55.318024 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587415313-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1352116a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:16:56.325598 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587416322-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1352111d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:16:57.334915 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587417330-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1352116a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:16:58.341023 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587418337-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1352110f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:16:59.349410 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587419344-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x135211cc0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:17:00.358359 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587420353-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1352111d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:17:01.367912 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587421364-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1352116a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:17:02.373898 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587422369-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1352110f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:17:03.383372 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587423378-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x135211cc0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:17:04.392113 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587424387-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1352111d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:17:05.402691 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587425398-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1352116a0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:17:06.408455 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587426404-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1352110f0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:17:07.413926 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587427409-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x135211cc0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 00:17:08.424615 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] HTTPSConnectionPool(host='api-demo.fxcm.com', port=443): Max retries exceeded with url: /socket.io/?access_token=e053ac1597cef331df9429ac8151100ea9f1c411&agent=pythonquants&EIO=3&transport=polling&t=1561587428420-0 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1352111d0>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known',))
# W0627 09:37:09.584505 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected (Connection is already closed.)
# W0627 12:18:47.084419 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 54] Connection reset by peer)
# W0627 13:36:17.528418 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 60] Operation timed out)
# W0627 13:38:06.862969 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] ('Connection aborted.', OSError("(60, 'ETIMEDOUT')",))
# W0627 23:37:35.261870 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 60] Operation timed out)
# W0628 09:14:18.380896 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 54] Connection reset by peer)
# W0628 09:16:14.530203 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] unexpected status code (400 {"code":1,"message":"Session ID unknown"})
# W0628 11:43:06.582381 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] recv disconnected ([Errno 60] Operation timed out)
# W0628 11:50:04.012837 123145367080960 logs.py:14] api-demo.fxcm.com:443/socket.io [connection error] ('Connection aborted.', OSError("(60, 'ETIMEDOUT')",))
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/fxcmpy/fxcmpy.py", line 2370, in __connect__
#     self.socket.wait()
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/__init__.py", line 251, in wait
#     self._process_packets()
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/__init__.py", line 276, in _process_packets
#     for engineIO_packet in self._transport.recv_packet():
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/transports.py", line 158, in recv_packet
#     packet_text)
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/parsers.py", line 96, in parse_packet_text
#     packet_type = int(get_character(packet_text, 0))
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/symmetries.py", line 33, in get_character
#     return chr(get_byte(x, index))
#   File "/Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/socketIO_client/symmetries.py", line 29, in get_byte
#     return indexbytes(x, index)
# IndexError: index out of range

# %%
# PNL con.get_open_positions().iloc[0,-1]

# %%
# BUY/SELL PRICE con.get_open_positions().iloc[0,11]

# %%
# IS BUY OR IS SELL = con.get_open_positions().iloc[0,8]

# %%
# AMOUNTK = con.get_open_positions().iloc[0,2] == 0.03

# %%
# Short =>

# %%
# Long =>

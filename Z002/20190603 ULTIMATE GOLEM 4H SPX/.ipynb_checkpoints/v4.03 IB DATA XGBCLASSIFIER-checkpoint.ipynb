# %%
___Author___='LumberJack Jyss'

# %%
print('Global Optimized LumberJack Equities Method\n°OoO_FOREX_Oo0°\nLumberJack Jyss 5779(c)')
# Out:
# Global Optimized LumberJack Equities Method
# °OoO_FOREX_Oo0°
# LumberJack Jyss 5779(c)

# %%
print('Importing librairies...')
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import xgboost as xgb
from xgboost import XGBClassifier
from xgboost import plot_importance
from sklearn.preprocessing import MinMaxScaler
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve
from keras.models import Sequential
from keras.layers import Input
from keras.layers import Dense
from keras.utils import to_categorical
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
# %matplotlib inline
print('Librairies imported')
# Out:
# Importing librairies...
# Librairies imported
# Using TensorFlow backend.

# %%
import warnings
warnings.filterwarnings("ignore")
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
df_4H= pd.read_csv('20190603 data prepared.csv')
df_4H = df_4H.iloc[:,1:]
df_4H = df_4H.dropna()
df_4H.reset_index(inplace=True,drop=True)

# %%
df_4H.isnull().sum().sum()
# Out:
# 0

# %%
df_4H.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2303 entries, 0 to 2302
# Data columns (total 27 columns):
# Date                  2303 non-null object
# Vix                   2303 non-null float64
# Varop_Spy             2303 non-null float64
# Varhl_spy             2303 non-null float64
# Varop_vix             2303 non-null float64
# Varhl_vix             2303 non-null float64
# RSI                   2303 non-null float64
# 75 - RSI              2303 non-null float64
# RSI - 25              2303 non-null float64
# BBD_Delta_Up          2303 non-null float64
# delta5_8              2303 non-null float64
# delta8_10             2303 non-null float64
# delta10_12            2303 non-null float64
# delta12_15            2303 non-null float64
# delta15_30            2303 non-null float64
# delta30_35            2303 non-null float64
# delta35_40            2303 non-null float64
# delta40_45            2303 non-null float64
# delta45_50            2303 non-null float64
# Spread                2303 non-null float64
# Peaks                 2303 non-null int64
# Valley                2303 non-null int64
# delta_tsf             2303 non-null float64
# Forcast Oscillator    2303 non-null float64
# target_up             2303 non-null int64
# target_down           2303 non-null int64
# target_value          2303 non-null float64
# dtypes: float64(22), int64(4), object(1)
# memory usage: 485.9+ KB

# %%
plt.figure(figsize=(26,20))
sns.heatmap(df_4H.iloc[:,:-1].corr(),annot=True,cmap='rainbow')
plt.show()

# %%
df_4H.shape
# Out:
# (2303, 27)

# %%
df_4H['target_up'].sum(),df_4H['target_down'].sum()
# Out:
# (234, 205)

# %%
delta = round(df_4H.shape[0])
bloc1 = round(delta*0.8)
bloc2 = delta - bloc1
print("# of periods : ",delta)
print('On 80% - 20% slash : ')
print('Bloc 1 : ',bloc1,' periods (',df_4H.iloc[bloc1,0],')\nBloc 2 :',bloc2,' periods (',df_4H.iloc[bloc2,0],')')
print('First period :',df_4H.iloc[0,0])
print('Last period :',df_4H.iloc[df_4H.shape[0]-1,0])
# Out:
# # of periods :  2303
# On 80% - 20% slash :
# Bloc 1 :  1842  periods ( 20180828  18:00:00 )
# Bloc 2 : 461  periods ( 20160404  15:30:00 )
# First period : 20150707  18:00:00
# Last period : 20190531  18:00:00

# %%
X = df_4H.iloc[:,1:-4]
#X = X.drop(['Peaks','Valley'],axis=1)
#X = X.drop(['75 - RSI','RSI - 25'],axis=1)
y_up = df_4H.iloc[:,-3].values
y_down = df_4H.iloc[:,-2].values
X = X.drop(['Vix','Varop_vix','Varhl_vix'],axis=1)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2303 entries, 0 to 2302
# Data columns (total 19 columns):
# Varop_Spy       2303 non-null float64
# Varhl_spy       2303 non-null float64
# RSI             2303 non-null float64
# 75 - RSI        2303 non-null float64
# RSI - 25        2303 non-null float64
# BBD_Delta_Up    2303 non-null float64
# delta5_8        2303 non-null float64
# delta8_10       2303 non-null float64
# delta10_12      2303 non-null float64
# delta12_15      2303 non-null float64
# delta15_30      2303 non-null float64
# delta30_35      2303 non-null float64
# delta35_40      2303 non-null float64
# delta40_45      2303 non-null float64
# delta45_50      2303 non-null float64
# Spread          2303 non-null float64
# Peaks           2303 non-null int64
# Valley          2303 non-null int64
# delta_tsf       2303 non-null float64
# dtypes: float64(17), int64(2)
# memory usage: 341.9 KB

# %%
X.iloc[:5,[6,7]]
# Out:
#    delta5_8  delta8_10
# 0  -1.77525    2.15125
# 1  -3.70125    0.25625
# 2  -4.79225   -1.97475
# 3  -4.53575   -2.33525
# 4  -2.54425   -2.79475

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
X = scaler.fit_transform(X)
#y_up = scaler.fit_transform(np.array(y_up).reshape(-1,1))
#y_down = scaler.fit_transform(np.array(y_down).reshape(-1,1))
y_up = np.array(y_up).reshape(-1,1)
y_down = np.array(y_down).reshape(-1,1)

# %%
X[:5,[6,7]]
# Out:
# array([[0.54475885, 0.5695274 ],
#        [0.51839227, 0.53009177],
#        [0.50345668, 0.48366387],
#        [0.50696812, 0.47616174],
#        [0.53423139, 0.46659938]])

# %%
Xtrain = X[:bloc1,:]
Xtest = X[bloc1:,:]
ytrain_up = y_up[:bloc1,:]
ytest_up = y_up[bloc1:,:]
ytrain_down = y_down[:bloc1,:]
ytest_down = y_down[bloc1:,:]

# %%
Xtrain.shape,ytrain_up.shape,ytrain_down.shape,ytest_down.shape,ytest_up.shape
# Out:
# ((1842, 19), (1842, 1), (1842, 1), (461, 1), (461, 1))

# %%
model_up = XGBClassifier(learning_rate=0.5,silent=False,objective='binary:logistic',n_estimators=800,base_score=0.8,booster='gbtree')
eval_set_up = [(Xtrain, ytrain_up), (Xtest, ytest_up)]
history_up = model_up.fit( Xtrain, ytrain_up, eval_metric=['auc','error'], eval_set=eval_set_up, verbose=0)

# %%
model_down = XGBClassifier(learning_rate=0.005,silent=False,objective='binary:logistic',n_estimators=800,base_score=0.8,booster='gbtree')
eval_set_down = [(Xtrain, ytrain_down), (Xtest, ytest_down)]
history_down = model_down.fit( Xtrain, ytrain_down, eval_metric=['auc','error'], eval_set=eval_set_down, verbose=0)

# %%
plt.figure(figsize=(26,8))
plt.bar(range(len(model_up.feature_importances_)), model_up.feature_importances_)
plt.show()

# %%
plt.figure(figsize=(26,20))
plot_importance(model_up)
plt.show()

# %%
plt.figure(figsize=(26,8))
plt.bar(range(len(model_down.feature_importances_)), model_down.feature_importances_)
plt.show()

# %%
plt.figure(figsize=(26,20))
plot_importance(model_down)
plt.show()

# %%
from sklearn.feature_selection import SelectFromModel
print('Model up')
thresholds = np.sort(model_up.feature_importances_)
for thresh in range(0,len(thresholds)-1):
    selection = SelectFromModel(model_up, threshold=thresholds[thresh], prefit=True)
    select_Xtrain = selection.transform(Xtrain)
    # train model
    selection_model = XGBClassifier()
    selection_model.fit(select_Xtrain, ytrain_up)
	# eval model
    select_Xtest = selection.transform(Xtest)
    y_pred = selection_model.predict(select_Xtest)
    predictions = [round(value) for value in y_pred]
    accuracy = accuracy_score(ytest_up, predictions)
    print('If n=',thresh,' accuracy ',round(accuracy*100),'%')
# Out:
# Model up
# If n= 0  accuracy  85.0 %
# If n= 1  accuracy  85.0 %
# If n= 2  accuracy  85.0 %
# If n= 3  accuracy  85.0 %
# If n= 4  accuracy  85.0 %
# If n= 5  accuracy  85.0 %
# If n= 6  accuracy  85.0 %
# If n= 7  accuracy  86.0 %
# If n= 8  accuracy  85.0 %
# If n= 9  accuracy  85.0 %
# If n= 10  accuracy  86.0 %
# If n= 11  accuracy  85.0 %
# If n= 12  accuracy  85.0 %
# If n= 13  accuracy  86.0 %
# If n= 14  accuracy  86.0 %
# If n= 15  accuracy  86.0 %
# If n= 16  accuracy  87.0 %
# If n= 17  accuracy  88.0 %

# %%
print('Model Down')
for thresh in range(0,len(thresholds)-1):
    selection = SelectFromModel(model_down, threshold=thresholds[thresh], prefit=True)
    select_Xtrain = selection.transform(Xtrain)
    # train model
    selection_model = XGBClassifier()
    selection_model.fit(select_Xtrain, ytrain_down)
	# eval model
    select_Xtest = selection.transform(Xtest)
    y_pred = selection_model.predict(select_Xtest)
    predictions = [round(value) for value in y_pred]
    accuracy = accuracy_score(ytest_down, predictions)
    print('If n=',thresh,' accuracy ',round(accuracy*100),'%')
# Out:
# Model Down
# If n= 0  accuracy  87.0 %
# If n= 1  accuracy  87.0 %
# If n= 2  accuracy  87.0 %
# If n= 3  accuracy  87.0 %
# If n= 4  accuracy  87.0 %
# If n= 5  accuracy  87.0 %
# If n= 6  accuracy  87.0 %
# If n= 7  accuracy  87.0 %
# If n= 8  accuracy  87.0 %
# If n= 9  accuracy  87.0 %
# If n= 10  accuracy  87.0 %
# If n= 11  accuracy  87.0 %
# If n= 12  accuracy  87.0 %
# If n= 13  accuracy  87.0 %
# If n= 14  accuracy  87.0 %
# If n= 15  accuracy  87.0 %
# If n= 16  accuracy  87.0 %
# If n= 17  accuracy  88.0 %

# %%
yhat_up = model_up.predict(Xtest)
yhat_down = model_down.predict(Xtest)

accuracy_up = accuracy_score(ytest_up, yhat_up)
accuracy_down = accuracy_score(ytest_down, yhat_down)

# La précision permet de mesurer la capacité du modèle à refuser résultats non-pertinents : vrais_positifs/(vrais_positifs+faux_positifs)
precision_up = precision_score(ytest_up, yhat_up)  
precision_down = precision_score(ytest_down, yhat_down) 


# Recall : (vrai_positifs/(vrais_positifs+faux_négatifs))
recall_up = recall_score(ytest_up, yhat_up) 
recall_down = recall_score(ytest_down, yhat_down) 

f1_up = (2 * (precision_up * recall_up)) / (precision_up + recall_up)
f1_down = (2 * (precision_down * recall_down)) / (precision_down + recall_down)

roc_up=roc_auc_score(ytest_up,yhat_up)
roc_down=roc_auc_score(ytest_down,yhat_down)

# %%
print('RESULTATS UP\n')
print('Accuracy: %.2f%%' % (accuracy_up * 100.0))
print("Precision: %.2f%% " % (precision_up *100),' => Discrimnination des vrais positifs parmi les faux positifs')
print("Recall: %.2f%% " % (recall_up * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
print('F1 : %.2f%%' % (f1_up * 100))
print("AUC: %.2f%% " % (roc_up *100))
# get probabilities for positive class

print(classification_report(ytest_up, yhat_up))
conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
print(confusion_matrix(ytest_up, yhat_up))
print('Matrice de confusion :')
conf_matrix
# Out:
# RESULTATS UP
#
# Accuracy: 83.08%
# Precision: 41.18%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 19.44%   => Positifs trouvés par Golem sur tous les positifs existants
# F1 : 26.42%
# AUC: 57.15%
#               precision    recall  f1-score   support
#
#            0       0.86      0.95      0.90       389
#            1       0.41      0.19      0.26        72
#
#    micro avg       0.83      0.83      0.83       461
#    macro avg       0.64      0.57      0.58       461
# weighted avg       0.79      0.83      0.80       461
#
# [[369  20]
#  [ 58  14]]
# Matrice de confusion :
#               Vrais_estimés    Faux_estimés
# vrais_réels  Vrais_positifs    Faux_négatif
# Faux_réels    Faux_positifs  Vrais-négatifs

# %%
print('RESULTATS DOWN\n')
print('Accuracy: %.2f%%' % (accuracy_down * 100.0))
print("Precision: %.2f%% " % (precision_down *100),' => Discrimnination des vrais positifs parmi les faux positifs')
print("Recall: %.2f%% " % (recall_down * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
print('F1 : %.2f%%' % (f1_down * 100))
print("AUC: %.2f%% " % (roc_down *100))
# get probabilities for positive class

print(classification_report(ytest_down, yhat_down))
conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
print(confusion_matrix(ytest_down, yhat_down))
print('Matrice de confusion :')
conf_matrix
# Out:
# RESULTATS DOWN
#
# Accuracy: 87.42%
# Precision: 69.23%   => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 14.29%   => Positifs trouvés par Golem sur tous les positifs existants
# F1 : 23.68%
# AUC: 56.64%
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93       398
#            1       0.69      0.14      0.24        63
#
#    micro avg       0.87      0.87      0.87       461
#    macro avg       0.79      0.57      0.58       461
# weighted avg       0.85      0.87      0.84       461
#
# [[394   4]
#  [ 54   9]]
# Matrice de confusion :
#               Vrais_estimés    Faux_estimés
# vrais_réels  Vrais_positifs    Faux_négatif
# Faux_réels    Faux_positifs  Vrais-négatifs

# %%
len(df_4H)-(len(df_4H)-bloc2)
# Out:
# 461

# %%
plt.figure(figsize=(26,8),dpi=300)
plt.plot(df_4H['target_value'],color='orange',lw=0.8)
plt.xlim(1700,2400)
plt.ylim(2200,3050)
a = -1
for i in range(len(df_4H)-bloc2,len(df_4H)):
    a+=1
    if yhat_up[a] == 1:
        plt.scatter(x=df_4H.index[i],y=df_4H.iloc[i,-1],c='g',marker='o')
    elif yhat_down[a] == 1:
        plt.scatter(x=df_4H.index[i],y=df_4H.iloc[i,-1],c='r',marker='o')
plt.legend()

# %%
sum(yhat_up),sum(yhat_down)
# Out:
# (34, 13)

# %%
# save the model to disk
filename = 'finalized_model_up.sav'
pickle.dump(model_up, open(filename, 'wb'))
filename = 'finalized_model_down.sav'
pickle.dump(model_down, open(filename, 'wb'))

# %% [markdown]
# # load the model from disk
# loaded_model = pickle.load(open(filename, 'rb'))
# result = loaded_model.score(X_test, Y_test)
# print(result)

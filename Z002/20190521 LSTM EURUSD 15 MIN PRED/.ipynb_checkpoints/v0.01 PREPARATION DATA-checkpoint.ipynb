# %%
___Author___='LumberJack Jyss'

# %%
print('Global Optimized LumberJack Equities Method\n°OoO_FOREX_Oo0°\nLumberJack Jyss 5779(c)')
# Out:
# Global Optimized LumberJack Equities Method
# °OoO_FOREX_Oo0°
# LumberJack Jyss 5779(c)

# %%
print('Importation des librairies...')
import talib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
print('Librairies importées')
# Out:
# Importation des librairies...
# Librairies importées

# %%
# SCRAPING DES DONNES BRUTES
eurusd = pd.read_csv('eurusd_15mn_1Y.csv')
eurusd = eurusd.set_index('Date')
eurusd = eurusd.iloc[:-2,1:-1]

len_eurusd = len(eurusd)

eurusd_norm = []

# %%
eurusd.head()
# Out:
#                         Open      High       Low     Close
# Date
# 20180506  23:15:00  1.195975  1.196370  1.195975  1.196155
# 20180506  23:30:00  1.196155  1.196205  1.196020  1.196060
# 20180506  23:45:00  1.196060  1.196325  1.195575  1.195805
# 20180507  00:00:00  1.195805  1.196170  1.195780  1.195980
# 20180507  00:15:00  1.195980  1.196360  1.195960  1.196255

# %%
eurusd.head()
# Out:
#                         Open      High       Low     Close
# Date
# 20180506  23:15:00  1.195975  1.196370  1.195975  1.196155
# 20180506  23:30:00  1.196155  1.196205  1.196020  1.196060
# 20180506  23:45:00  1.196060  1.196325  1.195575  1.195805
# 20180507  00:00:00  1.195805  1.196170  1.195780  1.195980
# 20180507  00:15:00  1.195980  1.196360  1.195960  1.196255

# %%
eurusd.head()
# Out:
#                         Open      High       Low     Close
# Date
# 20180506  23:15:00  1.195975  1.196370  1.195975  1.196155
# 20180506  23:30:00  1.196155  1.196205  1.196020  1.196060
# 20180506  23:45:00  1.196060  1.196325  1.195575  1.195805
# 20180507  00:00:00  1.195805  1.196170  1.195780  1.195980
# 20180507  00:15:00  1.195980  1.196360  1.195960  1.196255

# %%
eurusd.shape,eurusd.shape,eurusd.shape
# Out:
# ((24481, 4), (24481, 4), (24481, 4))

# %%
eurusd_close = []
eurusd_oc = []
eurusd_hl = []
eurusd_Doc = []
eurusd_Dhl = []

# %%
rsi_eurusd = talib.RSI(eurusd['Close'], timeperiod=2)
ema5_eurusd = talib.EMA(eurusd['Close'],timeperiod=5)
ema21_eurusd = talib.EMA(eurusd['Close'],timeperiod=21)
len(rsi_eurusd)
# Out:
# 24480

# %%
for i in range (0,len_eurusd):
    eurusd_oc.append(float(eurusd.iloc[i,0]) - float(eurusd.iloc[i,3]))
    eurusd_hl.append(float(eurusd.iloc[i,1]) - float(eurusd.iloc[i,2]))

# %%
len(eurusd_oc),len(eurusd_hl),len(eurusd)
# Out:
# (24481, 24481, 24481)

# %%
eurusd['oc_eurusd'] = eurusd_oc
eurusd['hl_eurusd'] = eurusd_hl
eurusd.head()
# Out:
#                         Open      High       Low     Close  oc_eurusd  \
# Date
# 20180506  23:15:00  1.195975  1.196370  1.195975  1.196155  -0.000180
# 20180506  23:30:00  1.196155  1.196205  1.196020  1.196060   0.000095
# 20180506  23:45:00  1.196060  1.196325  1.195575  1.195805   0.000255
# 20180507  00:00:00  1.195805  1.196170  1.195780  1.195980  -0.000175
# 20180507  00:15:00  1.195980  1.196360  1.195960  1.196255  -0.000275
#
#                     hl_eurusd
# Date
# 20180506  23:15:00   0.000395
# 20180506  23:30:00   0.000185
# 20180506  23:45:00   0.000750
# 20180507  00:00:00   0.000390
# 20180507  00:15:00   0.000400

# %%
eurusd['oc_eurusd'] = eurusd_oc
eurusd['hl_eurusd'] = eurusd_hl
eurusd.head()
# Out:
#                         Open      High       Low     Close  oc_eurusd  \
# Date
# 20180506  23:15:00  1.195975  1.196370  1.195975  1.196155  -0.000180
# 20180506  23:30:00  1.196155  1.196205  1.196020  1.196060   0.000095
# 20180506  23:45:00  1.196060  1.196325  1.195575  1.195805   0.000255
# 20180507  00:00:00  1.195805  1.196170  1.195780  1.195980  -0.000175
# 20180507  00:15:00  1.195980  1.196360  1.195960  1.196255  -0.000275
#
#                     hl_eurusd
# Date
# 20180506  23:15:00   0.000395
# 20180506  23:30:00   0.000185
# 20180506  23:45:00   0.000750
# 20180507  00:00:00   0.000390
# 20180507  00:15:00   0.000400

# %%
eurusd['oc_eurusd'] = eurusd_oc
eurusd['hl_eurusd'] = eurusd_hl
eurusd.head()
# Out:
#                         Open      High       Low     Close  oc_eurusd  \
# Date
# 20180506  23:15:00  1.195975  1.196370  1.195975  1.196155  -0.000180
# 20180506  23:30:00  1.196155  1.196205  1.196020  1.196060   0.000095
# 20180506  23:45:00  1.196060  1.196325  1.195575  1.195805   0.000255
# 20180507  00:00:00  1.195805  1.196170  1.195780  1.195980  -0.000175
# 20180507  00:15:00  1.195980  1.196360  1.195960  1.196255  -0.000275
#
#                     hl_eurusd
# Date
# 20180506  23:15:00   0.000395
# 20180506  23:30:00   0.000185
# 20180506  23:45:00   0.000750
# 20180507  00:00:00   0.000390
# 20180507  00:15:00   0.000400

# %%
for i in range (1,len_eurusd):
    b = i - 1
    eurusd_close.append((eurusd.iloc[i,3] - eurusd.iloc[b,3]) / (eurusd.iloc[b,3]+0.0001))
    eurusd_Doc.append((eurusd.iloc[i,4] - eurusd.iloc[b,4]) / (eurusd.iloc[b,4]+0.0001))
    eurusd_Dhl.append((eurusd.iloc[i,5] - eurusd.iloc[b,5]) / (eurusd.iloc[b,5]+0.0001))

# %%
eurusd = eurusd.iloc[1:,:]

# %%
len(eurusd_close),len(eurusd_Doc)
# Out:
# (24480, 24480)

# %%
eurusd['eurusd_close'] = eurusd_close
eurusd['eurusd_Doc'] = eurusd_Doc
eurusd['eurusd_Dhl'] = eurusd_Dhl
eurusd['rsi_eurusd'] = rsi_eurusd
eurusd['ema5_eurusd'] = ema5_eurusd
eurusd['ema21_eurusd'] = ema21_eurusd

# %% [markdown]
# df = pd.concat((gbpjpy.iloc[:,4:],gbpusd.iloc[:,4:],eurusd.iloc[:,4:]),axis=1)
# df = df.dropna()
# df.shape

# %%
df = eurusd.iloc[:,4:]
df = df.dropna()
df.shape
# Out:
# (24460, 8)

# %%
df.head()
# Out:
#                     oc_eurusd  hl_eurusd  eurusd_close  eurusd_Doc  \
# Date
# 20180507  04:30:00  -0.000130   0.000425      0.000109   -7.000000
# 20180507  04:45:00   0.000155   0.000410     -0.000129   -9.500000
# 20180507  05:00:00  -0.000350   0.000560      0.000292   -1.980392
# 20180507  05:15:00   0.000055   0.000235     -0.000046   -1.620000
# 20180507  05:30:00   0.000155   0.000440     -0.000129    0.645161
#
#                     eurusd_Dhl  rsi_eurusd  ema5_eurusd  ema21_eurusd
# Date
# 20180507  04:30:00    0.071429   82.022425     1.197203      1.196460
# 20180507  04:45:00   -0.028571   44.483960     1.197220      1.196532
# 20180507  05:00:00    0.294118   81.898062     1.197348      1.196630
# 20180507  05:15:00   -0.492424   67.583388     1.197416      1.196714
# 20180507  05:30:00    0.611940   34.044301     1.197409      1.196776

# %%
df.tail()
# Out:
#                     oc_eurusd  hl_eurusd  eurusd_close  eurusd_Doc  \
# Date
# 20190505  23:15:00  -0.000345   0.001425     -0.002013   -1.960784
# 20190505  23:30:00  -0.000125   0.000690      0.000112   -0.897959
# 20190505  23:45:00   0.000050   0.001415     -0.000045   -7.000000
# 20190506  00:00:00  -0.000840   0.000890      0.000751   -5.933333
# 20190506  00:15:00  -0.000110   0.000555      0.000098   -0.986486
#
#                     eurusd_Dhl  rsi_eurusd  ema5_eurusd  ema21_eurusd
# Date
# 20190505  23:15:00    2.388889    1.873345     1.119404      1.119337
# 20190505  23:30:00   -0.481967   11.193971     1.118949      1.119219
# 20190505  23:45:00    0.917722   10.403430     1.118629      1.119107
# 20190506  00:00:00   -0.346535   73.436352     1.118696      1.119082
# 20190506  00:15:00   -0.338384   77.569319     1.118778      1.119069

# %%
plt.figure(figsize=(16,6))
sns.heatmap(df.corr())
plt.show()

# %%
df.head()
# Out:
#                     oc_eurusd  hl_eurusd  eurusd_close  eurusd_Doc  \
# Date
# 20180507  04:30:00  -0.000130   0.000425      0.000109   -7.000000
# 20180507  04:45:00   0.000155   0.000410     -0.000129   -9.500000
# 20180507  05:00:00  -0.000350   0.000560      0.000292   -1.980392
# 20180507  05:15:00   0.000055   0.000235     -0.000046   -1.620000
# 20180507  05:30:00   0.000155   0.000440     -0.000129    0.645161
#
#                     eurusd_Dhl  rsi_eurusd  ema5_eurusd  ema21_eurusd
# Date
# 20180507  04:30:00    0.071429   82.022425     1.197203      1.196460
# 20180507  04:45:00   -0.028571   44.483960     1.197220      1.196532
# 20180507  05:00:00    0.294118   81.898062     1.197348      1.196630
# 20180507  05:15:00   -0.492424   67.583388     1.197416      1.196714
# 20180507  05:30:00    0.611940   34.044301     1.197409      1.196776

# %%
df['EURUSD']=eurusd.iloc[:,3]
#df['GBPUSD']=gbpusd.iloc[:,3]
#df['EURUSD']=eurusd.iloc[:,3]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24460 entries, 20180507  04:30:00 to 20190506  00:15:00
# Data columns (total 9 columns):
# oc_eurusd       24460 non-null float64
# hl_eurusd       24460 non-null float64
# eurusd_close    24460 non-null float64
# eurusd_Doc      24460 non-null float64
# eurusd_Dhl      24460 non-null float64
# rsi_eurusd      24460 non-null float64
# ema5_eurusd     24460 non-null float64
# ema21_eurusd    24460 non-null float64
# EURUSD          24460 non-null float64
# dtypes: float64(9)
# memory usage: 1.9+ MB

# %%
df.head()
# Out:
#                     oc_eurusd  hl_eurusd  eurusd_close  eurusd_Doc  \
# Date
# 20180507  04:30:00  -0.000130   0.000425      0.000109   -7.000000
# 20180507  04:45:00   0.000155   0.000410     -0.000129   -9.500000
# 20180507  05:00:00  -0.000350   0.000560      0.000292   -1.980392
# 20180507  05:15:00   0.000055   0.000235     -0.000046   -1.620000
# 20180507  05:30:00   0.000155   0.000440     -0.000129    0.645161
#
#                     eurusd_Dhl  rsi_eurusd  ema5_eurusd  ema21_eurusd  \
# Date
# 20180507  04:30:00    0.071429   82.022425     1.197203      1.196460
# 20180507  04:45:00   -0.028571   44.483960     1.197220      1.196532
# 20180507  05:00:00    0.294118   81.898062     1.197348      1.196630
# 20180507  05:15:00   -0.492424   67.583388     1.197416      1.196714
# 20180507  05:30:00    0.611940   34.044301     1.197409      1.196776
#
#                       EURUSD
# Date
# 20180507  04:30:00  1.197410
# 20180507  04:45:00  1.197255
# 20180507  05:00:00  1.197605
# 20180507  05:15:00  1.197550
# 20180507  05:30:00  1.197395

# %% [markdown]
# plt.figure(figsize=(16,6))
# plt.plot(df['GBPJPY'],label='GBPJPY')
# plt.plot(df['rsi_gbpjpy'],label = 'RSI GBPJPY (14)')
# plt.legend()
# plt.show()

# %% [markdown]
# for row in range(1,len_df):
#     if df.iloc[row-1,5] < rsi_low_long and df.iloc[row,5] > rsi_low_long :
#         short_list_gbpjpy.append(0)
#         long_list_gbpjpy.append(1)
#     elif df.iloc[row-1,5] > rsi_high_short and df.iloc[row,5] < rsi_high_short :
#         short_list_gbpjpy.append(1)
#         long_list_gbpjpy.append(0)
#     else:
#         short_list_gbpjpy.append(0)
#         long_list_gbpjpy.append(0)

# %% [markdown]
# # TARGET = GBPJPY
# short_list_gbpjpy = []
# long_list_gbpjpy = []
# rsi_low_long = 5
# rsi_target_long = 80
# rsi_high_short = 95
# rsi_target_short = 20
# delta_pip = 0.05
# len_df = len(df)-4

# %%
short_list_eurusd = []
long_list_eurusd = []
delta_pip = 0.25
len_df = len(df)-4

for row in range(0,len_df):
    if (df.iloc[row+1,6] - df.iloc[row,6]) > delta_pip or (df.iloc[row+2,6] - df.iloc[row,6]) > delta_pip or\
    (df.iloc[row+3,6] - df.iloc[row,6]) > delta_pip:
        short_list_eurusd.append(0)
        long_list_eurusd.append(1)
        
    elif (df.iloc[row+1,6] - df.iloc[row,6]) < -delta_pip or (df.iloc[row+2,6] - df.iloc[row,6]) < -delta_pip or\
    (df.iloc[row+3,6] - df.iloc[row,6]) < -delta_pip:
        short_list_eurusd.append(1)
        long_list_eurusd.append(0)
   
    else:
        long_list_eurusd.append(0)
        short_list_eurusd.append(0)

# %%
len_df, len(short_list_eurusd),len(long_list_eurusd),sum(short_list_eurusd),sum(long_list_eurusd)
# Out:
# (24456, 24456, 24456, 0, 0)

# %% [markdown]
# long_list_gbpjpy = []
# flag_long = 0
# dube_long = 0
# for row in range(1,len_df):
#     if df.iloc[row-1,5] < rsi_low_long and df.iloc[row,5] > rsi_low_long :
#         if (df.iloc[row+1,5] > rsi_target_long) and ((df.iloc[row+1,18] - df.iloc[row,18]) > delta_pip) and flag_long == 0:
#             short_list_gbpjpy.append(0)
#             long_list_gbpjpy.append(1)
#             flag_long = 1
#             dube_long = 1
#         elif df.iloc[row+2,5] > rsi_target_long and (df.iloc[row+2,18] - df.iloc[row,18]) > delta_pip and flag_long == 0:
#             short_list_gbpjpy.append(0)
#             long_list_gbpjpy.append(1)
#             flag_long = 1
#             dube_long = 1
#         elif df.iloc[row+3,5] > rsi_target_long and (df.iloc[row+3,18] - df.iloc[row,18]) > delta_pip and flag_long == 0:
#             short_list_gbpjpy.append(0)
#             long_list_gbpjpy.append(1)
#             flag_long = 1
#             dube_long = 1
#         elif df.iloc[row+3,5] > rsi_target_long and (df.iloc[row+4,18] - df.iloc[row,18]) > delta_pip and flag_long == 0:
#             short_list_gbpjpy.append(0)
#             long_list_gbpjpy.append(1)
#             flag_long = 1
#             dube_long = 1
#         elif df.iloc[row+3,5] > rsi_target_long and (df.iloc[row+5,18] - df.iloc[row,18]) > delta_pip and flag_long == 0:
#             short_list_gbpjpy.append(0)
#             long_list_gbpjpy.append(1)
#             flag_long = 1
#             dube_long = 1
#         elif df.iloc[row+3,5] > rsi_target_long and (df.iloc[row+6,18] - df.iloc[row,18]) > delta_pip and flag_long == 0:
#             short_list_gbpjpy.append(0)
#             long_list_gbpjpy.append(1)
#             flag_long = 1
#             dube_long = 1
#         flag_long = 0
#
# if dube != 1:
#     long_list_gbpjpy.append(0)
#     short_list_gbpjpy.append(0)
#     dube_short = 0

# %% [markdown]
# short_list_gbpjpy = []
# flag_short = 0
# dube_short = 0
# for row in range(1,len_df):
#     if df.iloc[row-1,5] > rsi_high_short and df.iloc[row,5] < rsi_high_short :
#         if df.iloc[row+1,5] < rsi_target_short and (df.iloc[row+1,18] - df.iloc[row,18]) < -delta_pip and flag_short == 0:
#             short_list_gbpjpy.append(1)
#             long_list_gbpjpy.append(0)
#             flag_short = 1
#             dube_short = 1
#         elif df.iloc[row+2,5] < rsi_target_short and (df.iloc[row+2,18] - df.iloc[row,18]) < -delta_pip and flag_short == 0:
#             short_list_gbpjpy.append(1)
#             long_list_gbpjpy.append(0)
#             flag_short = 1
#             dube_short = 1
#         elif df.iloc[row+3,5] < rsi_target_short and (df.iloc[row+3,18] - df.iloc[row,18]) < -delta_pip and flag_short == 0:
#             short_list_gbpjpy.append(1)
#             long_list_gbpjpy.append(0)
#             flag_short = 1
#             dube_short = 1
#         elif df.iloc[row+3,5] < rsi_target_short and (df.iloc[row+4,18] - df.iloc[row,18]) < -delta_pip and flag_short == 0:
#             short_list_gbpjpy.append(1)
#             long_list_gbpjpy.append(0)
#             flag_short = 1
#             dube_short = 1
#         elif df.iloc[row+3,5] < rsi_target_short and (df.iloc[row+5,18] - df.iloc[row,18]) < -delta_pip and flag_short == 0:
#             short_list_gbpjpy.append(1)
#             long_list_gbpjpy.append(0)
#             flag_short = 1
#             dube_short = 1
#         elif df.iloc[row+3,5] < rsi_target_short and (df.iloc[row+6,18] - df.iloc[row,18]) < -delta_pip and flag_short == 0:
#             short_list_gbpjpy.append(1)
#             long_list_gbpjpy.append(0)
#             flag_short = 1
#             dube_short = 1
#         flag_short = 0
#
#     if dube != 1:
#         long_list_gbpjpy.append(0)
#         short_list_gbpjpy.append(0)
#         dube_short = 0

# %%
df = df.iloc[4:,:]

# %%
len(df),len_df, len(short_list_eurusd),len(long_list_eurusd),sum(short_list_eurusd),sum(long_list_eurusd)
# Out:
# (24456, 24456, 24456, 24456, 0, 0)

# %%
df['short_eurusd'] = short_list_eurusd
df['long_eurusd'] = long_list_eurusd

# %%
df.head()
# Out:
#                     oc_eurusd  hl_eurusd  eurusd_close  eurusd_Doc  \
# Date
# 20180507  05:30:00   0.000155   0.000440     -0.000129    0.645161
# 20180507  05:45:00   0.000695   0.000700     -0.000580    2.117647
# 20180507  06:00:00   0.000125   0.000425     -0.000104   -0.716981
# 20180507  06:15:00   0.000395   0.000560     -0.000330    1.200000
# 20180507  06:30:00   0.000025   0.000250     -0.000021   -0.747475
#
#                     eurusd_Dhl  rsi_eurusd  ema5_eurusd  ema21_eurusd  \
# Date
# 20180507  05:30:00    0.611940   34.044301     1.197409      1.196776
# 20180507  05:45:00    0.481481    6.246257     1.197172      1.196769
# 20180507  06:00:00   -0.343750    4.828158     1.196973      1.196751
# 20180507  06:15:00    0.257143    1.982946     1.196709      1.196699
# 20180507  06:30:00   -0.469697    1.845297     1.196524      1.196650
#
#                       EURUSD  short_eurusd  long_eurusd
# Date
# 20180507  05:30:00  1.197395             0            0
# 20180507  05:45:00  1.196700             0            0
# 20180507  06:00:00  1.196575             0            0
# 20180507  06:15:00  1.196180             0            0
# 20180507  06:30:00  1.196155             0            0

# %%
df.to_csv('eurusd.csv')

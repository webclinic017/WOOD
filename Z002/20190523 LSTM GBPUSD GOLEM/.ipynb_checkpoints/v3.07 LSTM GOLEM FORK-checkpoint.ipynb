# %%
___Author___='LumberJack Jyss'

# %%
print('Global Optimized LumberJack Equities Method\n°OoO_FOREX_Oo0°\nLumberJack Jyss 5779(c)')
# Out:
# Global Optimized LumberJack Equities Method
# °OoO_FOREX_Oo0°
# LumberJack Jyss 5779(c)

# %%
print('Importation des librairies...')
import numpy as np
import pandas as pd
import pandas_datareader as web
import matplotlib.pyplot as plt
import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
print('Librairies importées')
# Out:
# Importation des librairies...
# Librairies importées

# %%
df = web.DataReader('BIDU','yahoo',start,end)



start = pd.to_datetime('2014-01-28')
end = pd.to_datetime('2019-05-21')
delta = round(df.shape[0])
bloc1 = round(delta*0.8)
bloc2 = delta - bloc1
print("Période d'étude : ",delta)
print('Sur un découpage 80% - 20% de la période : ')
print('Bloc 1 : ',bloc1,' jours \nBloc 2 :',bloc2,' jours')
print('Note : On change de règles de calculs, car tous les jours ne sont pas ouvrés')

#dataframe = dataframe.iloc[:,1:]
df.reset_index(inplace=True)
df.head()
# Out:
# Période d'étude :  1338
# Sur un découpage 80% - 20% de la période :
# Bloc 1 :  1070  jours
# Bloc 2 : 268  jours
# Note : On change de règles de calculs, car tous les jours ne sont pas ouvrés
#         Date        High         Low        Open       Close   Volume  \
# 0 2014-01-28  166.550003  162.500000  163.289993  164.240005  4873500
# 1 2014-01-29  163.389999  157.399994  163.289993  158.100006  4315800
# 2 2014-01-30  162.600006  158.300003  161.479996  160.809998  3334800
# 3 2014-01-31  159.949997  155.369995  159.740005  156.500000  3945800
# 4 2014-02-03  157.929993  148.600006  156.259995  150.520004  5027500
#
#     Adj Close
# 0  164.240005
# 1  158.100006
# 2  160.809998
# 3  156.500000
# 4  150.520004

# %%
df.shape
# Out:
# (1338, 7)

# %%
data_train = df.iloc[:bloc1,:6]
data_train.head()
# Out:
#         Date        High         Low        Open       Close   Volume
# 0 2014-01-28  166.550003  162.500000  163.289993  164.240005  4873500
# 1 2014-01-29  163.389999  157.399994  163.289993  158.100006  4315800
# 2 2014-01-30  162.600006  158.300003  161.479996  160.809998  3334800
# 3 2014-01-31  159.949997  155.369995  159.740005  156.500000  3945800
# 4 2014-02-03  157.929993  148.600006  156.259995  150.520004  5027500

# %%
df.shape
# Out:
# (1338, 7)

# %%
trainset = data_train.iloc[:, 3:4].values
trainset
# Out:
# array([[163.28999329],
#        [163.28999329],
#        [161.47999573],
#        ...,
#        [130.52999878],
#        [123.23000336],
#        [119.22000122]])

# %%
sc = MinMaxScaler(feature_range = (0,1))
trainData_scaled = sc.fit_transform(trainset)

# %%
x_train = []
y_train = []

# %%
for i in range(60, len(data_train)): #60 is the memory size, nb of rows of training data
    x_train.append(trainData_scaled[i-60:i, 0]) # adds data for the last 60 rows
    y_train.append(trainData_scaled[i,0]) # adds the prices that the model is trying to predict

# Convert to tensors
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (1278, 60)

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1)) # adds a 3rd dimension to the tensor
#                     array , new size -->(x, y, z)

# %%
model = Sequential()

model.add(LSTM(units = 50, return_sequences = True, input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 50))
model.add(Dropout(0.2))

model.add(Dense(units = 1))

model.compile(optimizer = 'adam', loss='mean_squared_error')

# %%
model.fit(x_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 1278/1278 [==============================] - 7s 6ms/step - loss: 0.0446
# Epoch 2/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0088
# Epoch 3/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0077
# Epoch 4/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0071
# Epoch 5/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0072
# Epoch 6/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0065
# Epoch 7/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0064
# Epoch 8/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0055
# Epoch 9/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0055
# Epoch 10/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0057
# Epoch 11/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0051
# Epoch 12/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0060
# Epoch 13/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0050
# Epoch 14/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0047
# Epoch 15/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0042
# Epoch 16/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0046
# Epoch 17/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0046
# Epoch 18/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0044
# Epoch 19/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0040
# Epoch 20/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0041
# Epoch 21/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0040
# Epoch 22/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0039
# Epoch 23/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0036
# Epoch 24/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0036
# Epoch 25/100
# 1278/1278 [==============================] - 4s 4ms/step - loss: 0.0034
# Epoch 26/100
# 1278/1278 [==============================] - 4s 3ms/step - loss: 0.0039
# Epoch 27/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0035
# Epoch 28/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0039
# Epoch 29/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0034
# Epoch 30/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0036
# Epoch 31/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0032
# Epoch 32/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0030
# Epoch 33/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0031
# Epoch 34/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0031
# Epoch 35/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0029
# Epoch 36/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0028
# Epoch 37/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0027
# Epoch 38/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0030
# Epoch 39/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0031
# Epoch 40/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0034
# Epoch 41/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0026
# Epoch 42/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0026
# Epoch 43/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0027
# Epoch 44/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0026
# Epoch 45/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0027
# Epoch 46/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0025
# Epoch 47/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0025
# Epoch 48/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0025
# Epoch 49/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0025
# Epoch 50/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0023
# Epoch 51/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0026
# Epoch 52/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0023
# Epoch 53/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0022
# Epoch 54/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0023
# Epoch 55/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0023
# Epoch 56/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0022
# Epoch 57/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0022
# Epoch 58/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0023
# Epoch 59/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0020
# Epoch 60/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0021
# Epoch 61/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0023
# Epoch 62/100
# 1278/1278 [==============================] - 4s 4ms/step - loss: 0.0023
# Epoch 63/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0022
# Epoch 64/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0024
# Epoch 65/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0020
# Epoch 66/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0021
# Epoch 67/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0022
# Epoch 68/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0020
# Epoch 69/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0021
# Epoch 70/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0021
# Epoch 71/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0019
# Epoch 72/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0017
# Epoch 73/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0020
# Epoch 74/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0019
# Epoch 75/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0017
# Epoch 76/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0018
# Epoch 77/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0018
# Epoch 78/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0019
# Epoch 79/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0017
# Epoch 80/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0017
# Epoch 81/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0017
# Epoch 82/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0017
# Epoch 83/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0017
# Epoch 84/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0016
# Epoch 85/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0016
# Epoch 86/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0021
# Epoch 87/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0017
# Epoch 88/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0017
# Epoch 89/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0016
# Epoch 90/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0017
# Epoch 91/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0014
# Epoch 92/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0017
# Epoch 93/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0016
# Epoch 94/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0017
# Epoch 95/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0015
# Epoch 96/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0017
# Epoch 97/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0016
# Epoch 98/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0015
# Epoch 99/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0015
# Epoch 100/100
# 1278/1278 [==============================] - 5s 4ms/step - loss: 0.0016

# %%
model.save("BIDU_RNN.hd5f")

# %%
df.head()
# Out:
#         Date        High         Low        Open       Close   Volume  \
# 0 2014-01-28  166.550003  162.500000  163.289993  164.240005  4873500
# 1 2014-01-29  163.389999  157.399994  163.289993  158.100006  4315800
# 2 2014-01-30  162.600006  158.300003  161.479996  160.809998  3334800
# 3 2014-01-31  159.949997  155.369995  159.740005  156.500000  3945800
# 4 2014-02-03  157.929993  148.600006  156.259995  150.520004  5027500
#
#     Adj Close
# 0  164.240005
# 1  158.100006
# 2  160.809998
# 3  156.500000
# 4  150.520004

# %%
bloc1
# Out:
# 1070

# %%
data_test= df.iloc[bloc1:,:6] # Import Test Data

# %%
data_train.tail()
# Out:
#            Date        High         Low        Open       Close    Volume
# 1333 2019-05-15  153.539993  150.880005  151.729996  152.500000   3072600
# 1334 2019-05-16  155.449997  152.020004  153.309998  153.699997   4935400
# 1335 2019-05-17  134.130005  126.910004  130.529999  128.309998  29287200
# 1336 2019-05-20  123.269997  117.160004  123.230003  117.550003  18045200
# 1337 2019-05-21  121.120003  118.160004  119.220001  120.489998   9089900

# %%
data_test.head()
# Out:
#            Date        High         Low        Open       Close   Volume
# 1070 2018-04-27  257.299988  245.630005  253.949997  251.929993  8015600
# 1071 2018-04-30  255.000000  244.399994  253.690002  250.899994  4269500
# 1072 2018-05-01  254.080002  246.009995  247.240005  252.130005  2471100
# 1073 2018-05-02  252.740005  246.800003  250.919998  249.800003  3058000
# 1074 2018-05-03  254.539993  245.740005  249.000000  252.460007  2728200

# %%
actual_stock_price = data_test.iloc[:, 3:4].values # Get the Open Prices

# %%
data_total = pd.concat((data_train['Open'], data_test['Open']), axis=0) 
# combines the train and test data (axis=0 labels by index)

# %%
data_total[-5:]
# Out:
# 1333    151.729996
# 1334    153.309998
# 1335    130.529999
# 1336    123.230003
# 1337    119.220001
# Name: Open, dtype: float64

# %%
inputs = data_total[len(data_total) - len(data_test)-60:].values #removes the answers
print(len(data_total))
print(len(data_test))

inputs = inputs.reshape(-1, 1) #Converts the row of values into a column vector
inputs = sc.transform(inputs) # Feature Scaling (0-1)
inputs.shape
# Out:
# 1606
# 268
# (328, 1)

# %%
# Prepare Testing Inputs
x_test = []

for i in range(60, inputs.shape[0]):
    x_test.append(inputs[i-60:i, 0]) #Prepares the 60 data memory input

x_test = np.array(x_test) #Turn the inputs into an array
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1)) # Add a 3rd dimension

# %%
# Use the RNN to make the predeictions 
raw_prediction = model.predict(x_test)

# %%
price_prediction = sc.inverse_transform(raw_prediction) # Undoes the normalization into usable values
price_prediction [0:5]
# Out:
# array([[124.15059],
#        [203.06764],
#        [246.58183],
#        [246.6523 ],
#        [250.08498]], dtype=float32)

# %%
data_test.iloc[:,3].shape,raw_prediction.shape
# Out:
# ((268,), (268, 1))

# %%
(data_test.iloc[:,3].values.reshape(data_test.shape[0],1)).shape
# Out:
# (268, 1)

# %%
sc2 = MinMaxScaler(feature_range = (-1,1))

raw_prediction = sc2.fit_transform(raw_prediction)
raw_real = sc2.fit_transform((data_test.iloc[:,3].values.reshape(data_test.shape[0],1)))
Suggestion = []
percentChange = []

for d in range(1,len(raw_prediction)):
    percentChange.append(float((raw_prediction[d]-raw_real[d-1])))
    
for n in percentChange:
    #print(n)
    if n < -0.015:
        Suggestion.append(1) # Buy after a threshhold of increase
    elif n > 0.0:
        Suggestion.append(-1) # Sell when there is a drop
    else:
        Suggestion.append(0)
#print(Buy)

# %%
sc2.inverse_transform(raw_prediction[153].reshape(-1, 1)),sc2.inverse_transform(raw_real[152].reshape(-1, 1))
# Out:
# (array([[193.52742]], dtype=float32), array([[196.]]))

# %%
PurchaseHistory_short=[]
BuyPoints_short =  [[], []]
SellPoints_short = [[], []]
sold_short = False
for i in range(0, len(actual_stock_price)-1):
    if Suggestion[i] == -1 and not sold_short:
        PurchaseHistory_short.append(["Sell: ", actual_stock_price[i], i])
        SellPoints_short[0].append(actual_stock_price[i])
        SellPoints_short[1].append(i)
        sold_short = True
    if Suggestion[i] == 1 and sold_short:
        PurchaseHistory_short.append(["Buy:", actual_stock_price[i], i])
        BuyPoints_short[0].append(actual_stock_price[i])
        BuyPoints_short[1].append(i)        
        sold_short = False
if len(PurchaseHistory_short)%2 != 0:
    PurchaseHistory_short.pop()
    SellPoints_short[0].pop()
    SellPoints_short[1].pop() 
#PurchaseHistory

# %%
Profit_short = 0
for purchase in range(1, len(PurchaseHistory_short)+1, 2):
    MoneyMade_short = (float(-PurchaseHistory_short[purchase][1] + float(PurchaseHistory_short[purchase-1][1])))
    Profit_short += MoneyMade_short

print('$'+ str(round(Profit_short, 2)))
# Out:
# $71.36

# %%
plt.figure(figsize=(16,6),dpi=200)
plt.plot(actual_stock_price, color =  'purple', label = "Actual Price")
plt.plot(price_prediction, color = 'orange', label = "Predicted Price")
plt.plot(BuyPoints_short[1], BuyPoints_short[0], "go",label='Buy')
plt.plot(SellPoints_short[1], SellPoints_short[0], "ro",label='Sell')

plt.title("Go Short, BIDU January 2014 - May 2019 Stock Predictions")
plt.xlabel('Time')
plt.ylabel('BIDU Stock Price')
plt.legend()
plt.show()

# %%
sc2 = MinMaxScaler(feature_range = (-1,1))

raw_prediction = sc2.fit_transform(raw_prediction)
raw_real = sc2.fit_transform((data_test.iloc[:,3].values.reshape(data_test.shape[0],1)))

Suggestion_entry = []
Suggestion_exit = []
percentChange_entry = []
percentChange_exit = []

for d in range(1,len(raw_prediction)):
    percentChange_entry.append(float((raw_prediction[d]-raw_real[d-1])))
    percentChange_exit.append(float((raw_real[d]-raw_prediction[d-1])))
    
for n in percentChange_entry:
    #print(n)
    if n > 0.02:
        Suggestion_entry.append(1) # Sell after a threshhold of increase
    else:
        Suggestion_entry.append(0)    

for n in percentChange_exit:    
    if n < 0.00:
        Suggestion_exit.append(1) # Buy when there is a drop
    else:
        Suggestion_exit.append(0)
#print(Buy)

# %%
PurchaseHistory_long=[]
BuyPoints_long =  [[], []]
SellPoints_long = [[], []]
bought_long = False
for i in range(0, len(actual_stock_price)-1):
    if Suggestion_exit[i] == 1 and bought_long:
        PurchaseHistory_long.append(["Buy: ", actual_stock_price[i], i])
        BuyPoints_long[0].append(actual_stock_price[i])
        BuyPoints_long[1].append(i)
        bought_long = True
    if Suggestion_entry[i] == 1 and not bought_long:
        PurchaseHistory_long.append(["Sell:", actual_stock_price[i], i])
        SellPoints_long[0].append(actual_stock_price[i])
        SellPoints_long[1].append(i)        
        bought_long = False
if len(PurchaseHistory_long)%2 != 0:
    PurchaseHistory_long.pop()
    BuyPoints_long[0].pop()
    BuyPoints_long[1].pop() 
#PurchaseHistory

# %%
purchase = 0
Profit_long = 0
for purchase in range(1, len(PurchaseHistory_long)+1, 2):
    MoneyMade_long = float(PurchaseHistory_long[purchase][1] - float(PurchaseHistory_long[purchase-1][1]))
    Profit_long += MoneyMade_long

print('$'+ str(round(Profit_long, 2)))
# Out:
# $-35.79

# %%
plt.figure(figsize=(16,6))
plt.plot(actual_stock_price, color =  'purple', label = "Actual Price")
plt.plot(price_prediction, color = 'orange', label = "Predicted Price")
plt.plot(BuyPoints_long[1], BuyPoints_long[0], "go",label='Buy')
plt.plot(SellPoints_long[1], SellPoints_long[0], "ro",label='Sell')
plt.title("BIDU January 2014 - May 2019 Stock Predictions")
plt.xlabel('Time')
plt.ylabel('Go Long BIDU, Go Long... Stock Price')
plt.legend()
plt.show()

# %%
print('CumProfit :','$'+ str(round(Profit_long+Profit_short, 2)))
# Out:
# CumProfit : $166.56

# %%
MinimumRequiredCapital = max(BuyPoints[0])
ROI_long = Profit_long / MinimumRequiredCapital * 100
ROI_short = Profit_short / MinimumRequiredCapital * 100
print("Return on Investment:", round(float(ROI_long), 2),"%")
print("Return on Investment:", round(float(ROI_short), 2),"%")
# Out:
# Return on Investment: 8.93 %
# Return on Investment: 52.42 %

# %%
df.shape
# Out:
# (1338, 7)

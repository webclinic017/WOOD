# %%
___Author___='LumberJack Jyss'

# %%
print('Global Optimized LumberJack Equities Method\n°OoO_FOREX_Oo0°\nLumberJack Jyss 5779(c)')
# Out:
# Global Optimized LumberJack Equities Method
# °OoO_FOREX_Oo0°
# LumberJack Jyss 5779(c)

# %%
print('Importing librairies...')
import numpy as np
import pandas as pd
import pandas_datareader as web
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Input
from keras.layers import Dense
from yahoofinancials import YahooFinancials
print('Librairies imported')
# Out:
# Importing librairies...
# Using TensorFlow backend.
# Librairies imported

# %%
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
start = '2014-01-28'
end = '2019-05-26'

# %%
currencies = ['GBPUSD=X']
daily_currency_prices = YahooFinancials(currencies).get_historical_price_data(start,end,'daily')

# %%
vix = web.DataReader('^VIX','yahoo',start,end)

# %%
temp_df = pd.DataFrame.from_dict(daily_currency_prices.values()).T

# %%
gbpusd = pd.DataFrame.from_dict(temp_df.iloc[4,0])

# %%
df = pd.DataFrame()
df['Date'] = gbpusd['formatted_date']
df['High'] = gbpusd['high']
df['Low'] = gbpusd['low']
df['Open'] = gbpusd['open']
df['Close'] = gbpusd['close']
#df['Volume'] = gbpusd['volume']
df['Adj Close'] = gbpusd['adjclose']

# %%
delta = round(df.shape[0])
bloc1 = round(delta*0.8)
bloc2 = delta - bloc1
print("Période d'étude : ",delta)
print('Sur un découpage 80% - 20% de la période : ')
print('Bloc 1 : ',bloc1,' jours \nBloc 2 :',bloc2,' jours')
# Out:
# Période d'étude :  1389
# Sur un découpage 80% - 20% de la période :
# Bloc 1 :  1111  jours
# Bloc 2 : 278  jours

# %%
date = df['Date'].iloc[50:]

# %%
vix = vix.iloc[:-1,:]

# %%
temp = pd.DataFrame()
temp = vix.iloc[:,-1]
temp.reset_index(inplace=True,drop=True)

# %%
dataset = df.copy()
dataset = dataset.iloc[-vix.shape[0]:,:]
dataset['Vix'] = np.array(temp)
dataset = dataset.drop(dataset[['Close','Date']],axis=1)
dataset.rename(columns={'Adj Close':'Close'}, inplace=True)
dataset.fillna(dataset.mean(), inplace=True)

# %%
temp = dataset.copy()
dataset = pd.DataFrame()
dataset['Date'] = date
dataset['Open'] = temp['Open']
dataset['Vix'] = temp['Vix'].shift(1)
dataset['Close'] = temp['Close']
dataset = dataset.dropna()
dataset.reset_index(inplace=True,drop=True)

# %%
dataset.head()
# Out:
#          Date      Open        Vix     Close
# 0  2014-04-07  1.661074  15.800000  1.661047
# 1  2014-04-08  1.674677  17.350000  1.675014
# 2  2014-04-09  1.680023  17.290001  1.679995
# 3  2014-04-10  1.677627  18.410000  1.677740
# 4  2014-04-13  1.672996  21.440001  1.672968

# %%
# convert into input/output
X1 = dataset['Open'].values.reshape(len(dataset),1)
X2 = dataset['Vix'].values.reshape(len(dataset),1)
y = dataset['Close'].values.reshape(len(dataset),1)

#scaler = MinMaxScaler()
#X1 = scaler.fit_transform(X1)
#X2 = scaler.fit_transform(X2)

X1_train = X1[:bloc1]
X1_test = X1[bloc1:]

X2_train = X2[:bloc1]
X2_test = X2[bloc1:]

y_train = y[:bloc1]
y_test = y[bloc1:]

# %%
X_train = np.concatenate((X1_train,X2_train),axis=1)
X_test = np.concatenate((X1_test,X2_test),axis=1)

# %%
# first input model
model = Sequential()
model.add(Dense(50, activation='relu', input_dim=2))
#model.add(Dense(30, activation='relu', input_dim=2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
# fit model
history = model.fit(x=X_train, y=y_train, batch_size=32, epochs=100, verbose=1,shuffle=True,validation_split=.2)
# Out:
# Train on 888 samples, validate on 223 samples
# Epoch 1/100
# 888/888 [==============================] - 0s 29us/step - loss: 2.3403e-06 - val_loss: 3.6637e-06
# Epoch 2/100
# 888/888 [==============================] - 0s 27us/step - loss: 1.7901e-05 - val_loss: 2.2450e-05
# Epoch 3/100
# 888/888 [==============================] - 0s 29us/step - loss: 1.7031e-05 - val_loss: 9.6542e-06
# Epoch 4/100
# 888/888 [==============================] - 0s 29us/step - loss: 4.3050e-06 - val_loss: 3.3790e-07
# Epoch 5/100
# 888/888 [==============================] - 0s 28us/step - loss: 5.3129e-07 - val_loss: 4.2190e-06
# Epoch 6/100
# 888/888 [==============================] - 0s 27us/step - loss: 1.1481e-06 - val_loss: 9.6715e-08
# Epoch 7/100
# 888/888 [==============================] - 0s 26us/step - loss: 2.8748e-07 - val_loss: 7.0921e-07
# Epoch 8/100
# 888/888 [==============================] - 0s 26us/step - loss: 7.8178e-07 - val_loss: 2.2333e-06
# Epoch 9/100
# 888/888 [==============================] - 0s 27us/step - loss: 3.0744e-05 - val_loss: 6.2555e-06
# Epoch 10/100
# 888/888 [==============================] - 0s 26us/step - loss: 9.1730e-05 - val_loss: 2.0737e-05
# Epoch 11/100
# 888/888 [==============================] - 0s 27us/step - loss: 2.2558e-04 - val_loss: 5.5325e-04
# Epoch 12/100
# 888/888 [==============================] - 0s 27us/step - loss: 1.6517e-04 - val_loss: 1.4030e-05
# Epoch 13/100
# 888/888 [==============================] - 0s 27us/step - loss: 3.1266e-05 - val_loss: 4.0874e-06
# Epoch 14/100
# 888/888 [==============================] - 0s 26us/step - loss: 2.6971e-06 - val_loss: 1.0608e-06
# Epoch 15/100
# 888/888 [==============================] - 0s 27us/step - loss: 8.1638e-07 - val_loss: 3.7685e-07
# Epoch 16/100
# 888/888 [==============================] - 0s 26us/step - loss: 3.6818e-07 - val_loss: 2.4773e-07
# Epoch 17/100
# 888/888 [==============================] - 0s 26us/step - loss: 1.2366e-07 - val_loss: 9.9745e-08
# Epoch 18/100
# 888/888 [==============================] - 0s 26us/step - loss: 2.6232e-07 - val_loss: 1.7333e-07
# Epoch 19/100
# 888/888 [==============================] - 0s 26us/step - loss: 3.0292e-07 - val_loss: 6.7339e-07
# Epoch 20/100
# 888/888 [==============================] - 0s 26us/step - loss: 1.0141e-06 - val_loss: 8.5836e-07
# Epoch 21/100
# 888/888 [==============================] - 0s 26us/step - loss: 9.1416e-07 - val_loss: 2.0964e-06
# Epoch 22/100
# 888/888 [==============================] - 0s 26us/step - loss: 1.8843e-06 - val_loss: 2.1599e-06
# Epoch 23/100
# 888/888 [==============================] - 0s 26us/step - loss: 1.6626e-06 - val_loss: 9.5467e-07
# Epoch 24/100
# 888/888 [==============================] - 0s 27us/step - loss: 2.8819e-07 - val_loss: 6.4344e-08
# Epoch 25/100
# 888/888 [==============================] - 0s 26us/step - loss: 1.8581e-07 - val_loss: 3.8196e-07
# Epoch 26/100
# 888/888 [==============================] - 0s 26us/step - loss: 1.4780e-06 - val_loss: 1.1951e-07
# Epoch 27/100
# 888/888 [==============================] - 0s 26us/step - loss: 1.5434e-07 - val_loss: 3.4393e-08
# Epoch 28/100
# 888/888 [==============================] - 0s 26us/step - loss: 2.3270e-07 - val_loss: 1.1762e-07
# Epoch 29/100
# 888/888 [==============================] - 0s 26us/step - loss: 2.0540e-07 - val_loss: 9.0779e-08
# Epoch 30/100
# 888/888 [==============================] - 0s 26us/step - loss: 1.7001e-07 - val_loss: 4.7413e-07
# Epoch 31/100
# 888/888 [==============================] - 0s 27us/step - loss: 1.9089e-07 - val_loss: 4.9752e-08
# Epoch 32/100
# 888/888 [==============================] - 0s 25us/step - loss: 2.3155e-07 - val_loss: 6.1380e-07
# Epoch 33/100
# 888/888 [==============================] - 0s 27us/step - loss: 6.9721e-07 - val_loss: 8.0298e-07
# Epoch 34/100
# 888/888 [==============================] - 0s 26us/step - loss: 4.2414e-07 - val_loss: 6.0536e-08
# Epoch 35/100
# 888/888 [==============================] - 0s 25us/step - loss: 3.8226e-07 - val_loss: 2.3115e-07
# Epoch 36/100
# 888/888 [==============================] - 0s 26us/step - loss: 7.1243e-07 - val_loss: 9.1541e-08
# Epoch 37/100
100
# 888/888 [==============================] - 0s 26us/step - loss: 3.8405e-07 - val_loss: 1.5444e-06
# Epoch 75/100
# 888/888 [==============================] - 0s 26us/step - loss: 4.8252e-07 - val_loss: 4.8384e-07
# Epoch 76/100
# 888/888 [==============================] - 0s 26us/step - loss: 1.0374e-06 - val_loss: 1.8332e-06
# Epoch 77/100
# 888/888 [==============================] - 0s 26us/step - loss: 1.8736e-06 - val_loss: 4.3267e-07
# Epoch 78/100
# 888/888 [==============================] - 0s 26us/step - loss: 3.8328e-06 - val_loss: 4.9675e-06
# Epoch 79/100
# 888/888 [==============================] - 0s 26us/step - loss: 2.7958e-06 - val_loss: 1.3566e-06
# Epoch 80/100
# 888/888 [==============================] - 0s 25us/step - loss: 4.5449e-06 - val_loss: 1.0314e-05
# Epoch 81/100
# 888/888 [==============================] - 0s 26us/step - loss: 8.0461e-06 - val_loss: 1.2159e-05
# Epoch 82/100
# 888/888 [==============================] - 0s 25us/step - loss: 1.3779e-05 - val_loss: 4.1091e-06
# Epoch 83/100
# 888/888 [==============================] - 0s 27us/step - loss: 1.8798e-05 - val_loss: 8.5428e-06
# Epoch 84/100
# 888/888 [==============================] - 0s 28us/step - loss: 2.5161e-05 - val_loss: 1.5663e-05
# Epoch 85/100
# 888/888 [==============================] - 0s 27us/step - loss: 2.5151e-06 - val_loss: 2.4305e-07
# Epoch 86/100
# 888/888 [==============================] - 0s 28us/step - loss: 1.3698e-06 - val_loss: 2.5047e-07
# Epoch 87/100
# 888/888 [==============================] - 0s 28us/step - loss: 1.7223e-07 - val_loss: 9.7536e-07
# Epoch 88/100
# 888/888 [==============================] - 0s 29us/step - loss: 9.0424e-07 - val_loss: 1.5279e-06
# Epoch 89/100
# 888/888 [==============================] - 0s 28us/step - loss: 1.1487e-05 - val_loss: 1.0494e-06
# Epoch 90/100
# 888/888 [==============================] - 0s 28us/step - loss: 2.7692e-05 - val_loss: 1.9955e-06
# Epoch 91/100
# 888/888 [==============================] - 0s 27us/step - loss: 2.3989e-04 - val_loss: 2.6748e-04
# Epoch 92/100
# 888/888 [==============================] - 0s 28us/step - loss: 5.8523e-05 - val_loss: 3.5490e-06
# Epoch 93/100
# 888/888 [==============================] - 0s 28us/step - loss: 2.8108e-06 - val_loss: 2.9689e-07
# Epoch 94/100
# 888/888 [==============================] - 0s 27us/step - loss: 5.7071e-07 - val_loss: 1.2545e-06
# Epoch 95/100
# 888/888 [==============================] - 0s 28us/step - loss: 7.6833e-07 - val_loss: 3.6143e-07
# Epoch 96/100
# 888/888 [==============================] - 0s 28us/step - loss: 6.9443e-07 - val_loss: 4.0823e-08
# Epoch 97/100
# 888/888 [==============================] - 0s 29us/step - loss: 3.9450e-07 - val_loss: 4.8135e-07
# Epoch 98/100
# 888/888 [==============================] - 0s 28us/step - loss: 3.8805e-07 - val_loss: 1.0465e-06
# Epoch 99/100
# 888/888 [==============================] - 0s 28us/step - loss: 3.5770e-07 - val_loss: 6.4132e-08
# Epoch 100/100
# 888/888 [==============================] - 0s 27us/step - loss: 3.2802e-07 - val_loss: 6.8737e-08

# %%
model.test_on_batch(X_test, y_test)
model.metrics_names
# Out:
# ['loss']

# %%
plt.figure(figsize=(16,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
model.save('GBPUSD.h5')

# %%
# demonstrate prediction
x_input = np.array([[df.iloc[-1,5],vix.iloc[-2,5]]])
yhat = model.predict(x_input, verbose=1)
print(yhat,'versus', df.iloc[-1,-1])
error = ((df.iloc[-1,-1] - yhat)/df.iloc[-1,-1])*100
print('Error : ',abs(error[0][0]),'%')
# Out:
# 1/1 [==============================] - 0s 463us/step
# [[1.2666847]] versus 1.2664639949798584
# Error :  0.01742303 %

# %%
print('Initializing \b Processing')
yhat = model.predict(X_test, verbose=1)
print('All processed')
# Out:
# Initializing Processing
# 228/228 [==============================] - 0s 20us/step
# All processed

# %%
date.reset_index(inplace=True,drop=True)
resultats = date
resultats = resultats.iloc[-228:]
resultats.reset_index(inplace=True,drop=True)

# %%
pred = pd.DataFrame()
pred['Open'] = dataset.iloc[1111:,1]
pred['Vix'] = dataset.iloc[1111:,2]
pred['Close'] = dataset.iloc[1111:,3]
pred['Predictions'] = yhat.reshape(228,)
pred.reset_index(inplace=True,drop=True)
resultats = pd.concat((date,pred),axis=1)
resultats = resultats.iloc[:228,:]
resultats['% Error'] = ((resultats.iloc[:,3].values-resultats.iloc[:,4])/resultats.iloc[:,4])*100

# %%
resultats.tail()
# Out:
#            Date      Open        Vix     Close  Predictions   % Error
# 223  2015-02-13  1.273026  15.290000  1.273156     1.273260 -0.008183
# 224  2015-02-16  1.272783  15.960000  1.272912     1.273033 -0.009514
# 225  2015-02-17  1.410239  16.309999  1.410265     1.410493 -0.016157
# 226  2015-02-18  1.266336  14.950000  1.266416     1.266561 -0.011483
# 227  2015-02-19  1.266464  14.750000  1.266464     1.266685 -0.017411

# %%
plt.figure(figsize=(16,6),dpi=200)
plt.suptitle('Prediction of GBPUSD with DEEP LEARNING',fontsize=16)
plt.plot(resultats['Close'],color='purple',label='Actual')
plt.plot(resultats['Predictions'],color='orange',label='Predicted')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,6),dpi=200)
plt.suptitle('Prediction of GBPUSD with DEEP LEARNING',fontsize=16)
plt.plot(resultats['% Error'],color='g',label='% Error')
plt.axhline(y=0,linestyle='--',color='r')
plt.legend()
plt.show()

# %%
yhat = model.predict(np.array([[1.24927,21.76]]), verbose=1)
# Out:
# 1/1 [==============================] - 0s 531us/step

# %%
yhat
# Out:
# array([[1.2496666]], dtype=float32)

# %%
resultats
# Out:
#            Date      Open        Vix     Close  Predictions   % Error
# 0    2014-04-07  1.325996  15.920000  1.325732     1.326244 -0.038543
# 1    2014-04-08  1.320690  17.910000  1.321004     1.320987  0.001254
# 2    2014-04-09  1.317836  16.850000  1.318044     1.318107 -0.004757
# 3    2014-04-10  1.322926  16.090000  1.322769     1.323178 -0.030947
# 4    2014-04-13  1.323627  15.600000  1.323644     1.323866 -0.016785
# 5    2014-04-14  1.310942  16.139999  1.310616     1.311196 -0.044249
# 6    2014-04-15  1.307822  14.970000  1.307822     1.308047 -0.017161
# 7    2014-04-16  1.302253  13.370000  1.302304     1.302438 -0.010269
# 8    2014-04-17  1.314873  12.690000  1.314717     1.315040 -0.024566
# 9    2014-04-20  1.310444  12.640000  1.310273     1.310610 -0.025768
# 10   2014-04-21  1.315270  13.630000  1.315218     1.315461 -0.018460
# 11   2014-04-22  1.319975  12.580000  1.319958     1.320140 -0.013771
# 12   2014-04-23  1.310977  12.180000  1.310874     1.311132 -0.019675
# 13   2014-04-24  1.311131  12.830000  1.311183     1.311303 -0.009109
# 14   2014-04-27  1.313646  12.060000  1.313543     1.313798 -0.019418
# 15   2014-04-28  1.311837  12.100000  1.312164     1.311989  0.013302
# 16   2014-04-29  1.312525  12.870000  1.312612     1.312697 -0.006538
# 17   2014-04-30  1.301575  12.860000  1.301812     1.301747  0.005028

# %%
___Author___='LumberJack Jyss'

# %%
print('Global Optimized LumberJack Equities Method\n°OoO_FOREX_Oo0°\nLumberJack Jyss 5779(c)')
# Out:
# Global Optimized LumberJack Equities Method
# °OoO_FOREX_Oo0°
# LumberJack Jyss 5779(c)

# %%
print('Importing librairies...')
import numpy as np
import pandas as pd
import pandas_datareader as web
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Input
from keras.layers import Dense
from yahoofinancials import YahooFinancials
print('Librairies imported')
# Out:
# Importing librairies...
# Using TensorFlow backend.
# Librairies imported

# %%
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
start = '2014-01-28'
end = '2019-05-26'

# %%
currencies = ['GBPUSD=X']
daily_currency_prices = YahooFinancials(currencies).get_historical_price_data(start,end,'daily')

# %%
vix = web.DataReader('^VIX','yahoo',start,end)

# %%
temp_df = pd.DataFrame.from_dict(daily_currency_prices.values()).T

# %%
gbpusd = pd.DataFrame.from_dict(temp_df.iloc[4,0])

# %%
df = pd.DataFrame()
df['Date'] = gbpusd['formatted_date']
df['High'] = gbpusd['high']
df['Low'] = gbpusd['low']
df['Open'] = gbpusd['open']
df['Close'] = gbpusd['close']
#df['Volume'] = gbpusd['volume']
df['Adj Close'] = gbpusd['adjclose']

# %%
delta = round(df.shape[0])
bloc1 = round(delta*0.8)
bloc2 = delta - bloc1
print("Période d'étude : ",delta)
print('Sur un découpage 80% - 20% de la période : ')
print('Bloc 1 : ',bloc1,' jours \nBloc 2 :',bloc2,' jours')
# Out:
# Période d'étude :  1389
# Sur un découpage 80% - 20% de la période :
# Bloc 1 :  1111  jours
# Bloc 2 : 278  jours

# %%
date = df['Date'].iloc[50:]

# %%
vix = vix.iloc[:-1,:]

# %%
temp = pd.DataFrame()
temp = vix.iloc[:,-1]
temp.reset_index(inplace=True,drop=True)

# %%
dataset = df.copy()
dataset = dataset.iloc[-vix.shape[0]:,:]
dataset['Vix'] = np.array(temp)
dataset = dataset.drop(dataset[['Close','Date']],axis=1)
dataset.rename(columns={'Adj Close':'Close'}, inplace=True)
dataset.fillna(dataset.mean(), inplace=True)

# %%
temp = dataset.copy()
dataset = pd.DataFrame()
dataset['Date'] = date
dataset['Open'] = temp['Open']
dataset['Vix'] = temp['Vix'].shift(1)
dataset['Close'] = temp['Close']
dataset = dataset.dropna()
dataset.reset_index(inplace=True,drop=True)

# %%
# convert into input/output
X1 = dataset['Open'].values.reshape(len(dataset),1)
X2 = dataset['Vix'].values.reshape(len(dataset),1)
y = dataset['Close'].values.reshape(len(dataset),1)

#scaler = MinMaxScaler()
#X1 = scaler.fit_transform(X1)
#X2 = scaler.fit_transform(X2)

X1_train = X1[:bloc1]
X1_test = X1[bloc1:]

X2_train = X2[:bloc1]
X2_test = X2[bloc1:]

y_train = y[:bloc1]
y_test = y[bloc1:]

# %%
X_train = np.concatenate((X1_train,X2_train),axis=1)
X_test = np.concatenate((X1_test,X2_test),axis=1)

# %%
# first input model
model = Sequential()
model.add(Dense(50, activation='relu', input_dim=2))
#model.add(Dense(30, activation='relu', input_dim=2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
# fit model
model.fit(x=X_train, y=y_train, batch_size=32, epochs=100, verbose=1,shuffle=True,validation_split=.2)
# Out:
# Train on 888 samples, validate on 223 samples
# Epoch 1/100
# 888/888 [==============================] - 0s 225us/step - loss: 0.1750 - val_loss: 0.1429
# Epoch 2/100
# 888/888 [==============================] - 0s 32us/step - loss: 0.1106 - val_loss: 0.1138
# Epoch 3/100
# 888/888 [==============================] - 0s 31us/step - loss: 0.0837 - val_loss: 0.0780
# Epoch 4/100
# 888/888 [==============================] - 0s 29us/step - loss: 0.0582 - val_loss: 0.0645
# Epoch 5/100
# 888/888 [==============================] - 0s 29us/step - loss: 0.0411 - val_loss: 0.0343
# Epoch 6/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0265 - val_loss: 0.0213
# Epoch 7/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0171 - val_loss: 0.0165
# Epoch 8/100
# 888/888 [==============================] - 0s 25us/step - loss: 0.0117 - val_loss: 0.0060
# Epoch 9/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0079 - val_loss: 0.0026
# Epoch 10/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0058 - val_loss: 0.0014
# Epoch 11/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0038 - val_loss: 0.0010
# Epoch 12/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0030 - val_loss: 9.8098e-04
# Epoch 13/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 14/100
# 888/888 [==============================] - 0s 25us/step - loss: 0.0025 - val_loss: 0.0014
# Epoch 15/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 16/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0022 - val_loss: 0.0020
# Epoch 17/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0021 - val_loss: 7.7972e-04
# Epoch 18/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 19/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 20/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0019 - val_loss: 5.2757e-04
# Epoch 21/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0018 - val_loss: 6.4653e-04
# Epoch 22/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 23/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0018 - val_loss: 6.7370e-04
# Epoch 24/100
# 888/888 [==============================] - 0s 25us/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 25/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0015 - val_loss: 8.1135e-04
# Epoch 26/100
# 888/888 [==============================] - 0s 25us/step - loss: 0.0015 - val_loss: 4.9577e-04
# Epoch 27/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0013 - val_loss: 8.1067e-04
# Epoch 28/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0014 - val_loss: 6.0215e-04
# Epoch 29/100
# 888/888 [==============================] - 0s 36us/step - loss: 0.0012 - val_loss: 8.7716e-04
# Epoch 30/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 31/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0012 - val_loss: 6.6368e-04
# Epoch 32/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0011 - val_loss: 2.6733e-04
# Epoch 33/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0011 - val_loss: 4.3818e-04
# Epoch 34/100
# 888/888 [==============================] - 0s 26us/step - loss: 9.5859e-04 - val_loss: 7.0349e-04
# Epoch 35/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0010 - val_loss: 2.1338e-04
# Epoch 36/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0010 - val_loss: 5.0020e-04
# Epoch 37/100
# 888/888 [==============================] - 0s 32us/step - loss: 8.9019e-04 - val_loss: 8.0103e-04
# Epoch 38/100
# 888/888 [==============================] - 0s 28us/step - loss: 7.6424e-04 - val_loss: 2.0491e-04
# Epoch 39/100
# 888/888 [==============================] - 0s 27us/step - loss: 7.1583e-04 - val_loss: 4.2826e-04
# Epoch 40/100
# 888/888 [==============================] - 0s 26us/step - loss: 7.3836e-04 - val_loss: 5.1681e-04
# Epoch 41/100
# 888/888 [==============================] - 0s 27us/step - loss: 6.1955e-04 - val_loss: 1.9705e-04
# Epoch 42/100
# 888/888 [==============================] - 0s 26us/step - loss: 6.0549e-04 - val_loss: 1.4956e-04
# Epoch 43/100
# 888/888 [==============================] - 0s 27us/step - loss: 5.9729e-04 - val_loss: 6.6007e-04
# Epoch 44/100
# 888/888 [==============================] - 0s 28us/step - loss: 5.1247e-04 - val_loss: 1.3586e-04
x_input = np.array([[df.iloc[-1,5],vix.iloc[-2,5]]])
yhat = model.predict(x_input, verbose=1)
print(yhat,'versus', df.iloc[-1,-1])
error = ((df.iloc[-1,-1] - yhat)/df.iloc[-1,-1])*100
print('Error : ',abs(error[0][0]),'%')
# Out:
# 1/1 [==============================] - 0s 15ms/step
# [[1.2675799]] versus 1.2664639949798584
# Error :  0.0881129 %

# %%
print('Initializing \b Processing')
yhat = model.predict(X_test, verbose=1)
print('All processed')
# Out:
# Initializing Processing
# 228/228 [==============================] - 0s 20us/step
# All processed

# %%
date.reset_index(inplace=True,drop=True)
resultats = date
resultats = resultats.iloc[-228:]
resultats.reset_index(inplace=True,drop=True)

# %%
pred = pd.DataFrame()
pred['Open'] = dataset.iloc[1111:,1]
pred['Vix'] = dataset.iloc[1111:,2]
pred['Close'] = dataset.iloc[1111:,3]
pred['Predictions'] = yhat.reshape(228,)
pred.reset_index(inplace=True,drop=True)
resultats = pd.concat((date,pred),axis=1)
resultats = resultats.iloc[:228,:]
resultats['% Error'] = ((resultats.iloc[:,3].values-resultats.iloc[:,4])/resultats.iloc[:,4])*100

# %%
resultats.tail()
# Out:
#            Date      Open        Vix     Close  Predictions   % Error
# 223  2015-02-13  1.273026  15.290000  1.273156     1.274113 -0.075140
# 224  2015-02-16  1.272783  15.960000  1.272912     1.273868 -0.075042
# 225  2015-02-17  1.410239  16.309999  1.410265     1.410756 -0.034812
# 226  2015-02-18  1.266336  14.950000  1.266416     1.267451 -0.081658
# 227  2015-02-19  1.266464  14.750000  1.266464     1.267579 -0.087998

# %%
plt.figure(figsize=(16,6),dpi=200)
plt.suptitle('Prediction of GBPUSD with DEEP LEARNING',fontsize=16)
plt.plot(resultats['Close'],color='purple',label='Actual')
plt.plot(resultats['Predictions'],color='orange',label='Predicted')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,6),dpi=200)
plt.suptitle('Prediction of GBPUSD with DEEP LEARNING',fontsize=16)
plt.plot(resultats['% Error'],color='g',label='% Error')
plt.axhline(y=0,linestyle='--',color='r')
plt.legend()
plt.show()

# %%
gbpusd.tail()
# Out:
#       adjclose     close        date formatted_date      high       low  \
# 1384  1.273156  1.273156  1558306800     2019-05-19  1.275754  1.271682
# 1385  1.272912  1.272912  1558393200     2019-05-20  1.279427  1.268617
# 1386       NaN       NaN  1558479600     2019-05-21       NaN       NaN
# 1387  1.266416  1.266416  1558566000     2019-05-22  1.268343  1.260589
# 1388  1.266464  1.266464  1558652400     2019-05-23  1.271715  1.264942
#
#           open  volume
# 1384  1.273026     0.0
# 1385  1.272783     0.0
# 1386       NaN     NaN
# 1387  1.266336     0.0
# 1388  1.266464     0.0

# %%
vix.tail()
# Out:
#                  High    Low   Open      Close  Volume  Adj Close
# Date
# 2019-05-17  16.809999  14.86  15.89  15.960000       0  15.960000
# 2019-05-20  17.629999  15.46  15.88  16.309999       0  16.309999
# 2019-05-21  16.219999  14.79  15.86  14.950000       0  14.950000
# 2019-05-22  15.440000  14.42  15.06  14.750000       0  14.750000
# 2019-05-23  18.049999  15.28  15.93  16.920000       0  16.920000

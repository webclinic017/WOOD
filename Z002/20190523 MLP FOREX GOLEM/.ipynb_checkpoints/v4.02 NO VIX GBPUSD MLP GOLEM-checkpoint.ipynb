# %%
___Author___='LumberJack Jyss'

# %%
print('Global Optimized LumberJack Equities Method\n°OoO_FOREX_Oo0°\nLumberJack Jyss 5779(c)')
# Out:
# Global Optimized LumberJack Equities Method
# °OoO_FOREX_Oo0°
# LumberJack Jyss 5779(c)

# %%
print('Importing librairies...')
import numpy as np
import pandas as pd
import pandas_datareader as web
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Input
from keras.layers import Dense
from yahoofinancials import YahooFinancials
print('Librairies imported')
# Out:
# Importing librairies...
# Using TensorFlow backend.
# Librairies imported

# %%
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
start = '2014-01-28'
end = '2019-05-26'

# %%
currencies = ['GBPUSD=X']
daily_currency_prices = YahooFinancials(currencies).get_historical_price_data(start,end,'daily')

# %%
#vix = web.DataReader('^VIX','yahoo',start,end)

# %%
temp_df = pd.DataFrame.from_dict(daily_currency_prices.values()).T

# %%
gbpusd = pd.DataFrame.from_dict(temp_df.iloc[4,0])

# %%
df = pd.DataFrame()
df['Date'] = gbpusd['formatted_date']
df['High'] = gbpusd['high']
df['Low'] = gbpusd['low']
df['Open'] = gbpusd['open']
df['Close'] = gbpusd['close']
#df['Volume'] = gbpusd['volume']
df['Adj Close'] = gbpusd['adjclose']

# %%
delta = round(df.shape[0])
bloc1 = round(delta*0.8)
bloc2 = delta - bloc1
print("Période d'étude : ",delta)
print('Sur un découpage 80% - 20% de la période : ')
print('Bloc 1 : ',bloc1,' jours \nBloc 2 :',bloc2,' jours')
# Out:
# Période d'étude :  1389
# Sur un découpage 80% - 20% de la période :
# Bloc 1 :  1111  jours
# Bloc 2 : 278  jours

# %%
date = df['Date'].iloc[50:]

# %%
#vix = vix.iloc[:-1,:]

# %%
#temp = pd.DataFrame()
#temp = vix.iloc[:,-1]
#temp.reset_index(inplace=True,drop=True)

# %%
dataset = df.copy()
#dataset = dataset.iloc[-vix.shape[0]:,:]
#dataset['Vix'] = np.array(temp)
dataset = dataset.drop(dataset[['Close','Date']],axis=1)
dataset.rename(columns={'Adj Close':'Close'}, inplace=True)
dataset.fillna(dataset.mean(), inplace=True)

# %%
temp = dataset.copy()
dataset = pd.DataFrame()
dataset['Date'] = date
dataset['Open'] = temp['Open']
#dataset['Vix'] = temp['Vix'].shift(1)
dataset['Close'] = temp['Close']
dataset = dataset.dropna()
dataset.reset_index(inplace=True,drop=True)

# %%
# convert into input/output
X1 = dataset['Open'].values.reshape(len(dataset),1)
#X2 = dataset['Vix'].values.reshape(len(dataset),1)
y = dataset['Close'].values.reshape(len(dataset),1)

#scaler = MinMaxScaler()
#X1 = scaler.fit_transform(X1)
#X2 = scaler.fit_transform(X2)

X1_train = X1[:bloc1]
X1_test = X1[bloc1:]

#X2_train = X2[:bloc1]
#X2_test = X2[bloc1:]

y_train = y[:bloc1]
y_test = y[bloc1:]

# %%
#X_train = np.concatenate((X1_train,X2_train),axis=1)
#X_test = np.concatenate((X1_test,X2_test),axis=1)

# %%
# first input model
model = Sequential()
model.add(Dense(50, activation='relu', input_dim=1))
#model.add(Dense(30, activation='relu', input_dim=2))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
# fit model
model.fit(x=X1_train, y=y_train, batch_size=32, epochs=100, verbose=1,shuffle=True,validation_split=.2)
# Out:
# Train on 888 samples, validate on 223 samples
# Epoch 1/100
# 888/888 [==============================] - 0s 230us/step - loss: 1.3035 - val_loss: 0.6516
# Epoch 2/100
# 888/888 [==============================] - 0s 33us/step - loss: 0.4625 - val_loss: 0.1623
# Epoch 3/100
# 888/888 [==============================] - 0s 31us/step - loss: 0.1007 - val_loss: 0.0156
# Epoch 4/100
# 888/888 [==============================] - 0s 30us/step - loss: 0.0105 - val_loss: 1.5541e-04
# Epoch 5/100
# 888/888 [==============================] - 0s 31us/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 6/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 7/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0018 - val_loss: 9.9131e-04
# Epoch 8/100
# 888/888 [==============================] - 0s 29us/step - loss: 0.0018 - val_loss: 9.8772e-04
# Epoch 9/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 10/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0018 - val_loss: 9.8337e-04
# Epoch 11/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0017 - val_loss: 0.0010
# Epoch 12/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0017 - val_loss: 9.4723e-04
# Epoch 13/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0017 - val_loss: 9.9606e-04
# Epoch 14/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0017 - val_loss: 9.7793e-04
# Epoch 15/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0017 - val_loss: 9.0830e-04
# Epoch 16/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0017 - val_loss: 9.6775e-04
# Epoch 17/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0017 - val_loss: 9.6393e-04
# Epoch 18/100
# 888/888 [==============================] - 0s 29us/step - loss: 0.0017 - val_loss: 9.0577e-04
# Epoch 19/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0016 - val_loss: 8.8832e-04
# Epoch 20/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0016 - val_loss: 9.5639e-04
# Epoch 21/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0016 - val_loss: 8.7059e-04
# Epoch 22/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0016 - val_loss: 8.9997e-04
# Epoch 23/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0016 - val_loss: 9.1139e-04
# Epoch 24/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0016 - val_loss: 8.7601e-04
# Epoch 25/100
# 888/888 [==============================] - 0s 29us/step - loss: 0.0015 - val_loss: 8.3868e-04
# Epoch 26/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0015 - val_loss: 8.8311e-04
# Epoch 27/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0015 - val_loss: 8.2777e-04
# Epoch 28/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0015 - val_loss: 8.7736e-04
# Epoch 29/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0015 - val_loss: 8.7000e-04
# Epoch 30/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0014 - val_loss: 6.9073e-04
# Epoch 31/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0014 - val_loss: 8.4563e-04
# Epoch 32/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0014 - val_loss: 7.6528e-04
# Epoch 33/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0014 - val_loss: 7.0944e-04
# Epoch 34/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0014 - val_loss: 7.7122e-04
# Epoch 35/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0013 - val_loss: 7.0464e-04
# Epoch 36/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0013 - val_loss: 7.7674e-04
# Epoch 37/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0013 - val_loss: 7.4367e-04
# Epoch 38/100
# 888/888 [==============================] - 0s 30us/step - loss: 0.0013 - val_loss: 7.4103e-04
# Epoch 39/100
# 888/888 [==============================] - 0s 32us/step - loss: 0.0013 - val_loss: 6.9328e-04
# Epoch 40/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0012 - val_loss: 7.0264e-04
# Epoch 41/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0012 - val_loss: 6.6961e-04
# Epoch 42/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0012 - val_loss: 6.8440e-04
# Epoch 43/100
# 888/888 [==============================] - 0s 26us/step - loss: 0.0012 - val_loss: 6.2130e-04
# Epoch 44/100
# 888/888 [==============================] - 0s 30us/step - loss: 0.0011 - val_loss: 7.1519e-04
# Epoch 45/100
# 888/888 [==============================] - 0s 29us/step - loss: 0.0011 - val_loss: 5.4134e-04
# Epoch 46/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0011 - val_loss: 6.9068e-04
# Epoch 47/100
# 888/888 [==============================] - 0s 29us/step - loss: 0.0011 - val_loss: 5.4391e-04
# Epoch 48/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0011 - val_loss: 6.6243e-04
# Epoch 49/100
# 888/888 [==============================] - 0s 27us/step - loss: 0.0010 - val_loss: 5.3633e-04
# Epoch 50/100
# 888/888 [==============================] - 0s 28us/step - loss: 0.0010 - val_loss: 4.8677e-04
# Epoch 51/100
# 888/888 [==============================] - 0s 28us/step - loss: 9.9734e-04 - val_loss: 5.1382e-04
# Epoch 52/100
# 888/888 [==============================] - 0s 26us/step - loss: 9.7160e-04 - val_loss: 6.1825e-04
# Epoch 53/100
# 888/888 [==============================] - 0s 26us/step - loss: 9.5526e-04 - val_loss: 5.1402e-04
# Epoch 54/100
# 888/888 [==============================] - 0s 26us/step - loss: 9.2849e-04 - val_loss: 4.6265e-04
# Epoch 55/100
# 888/888 [==============================] - 0s 28us/step - loss: 9.0938e-04 - val_loss: 5.1821e-04
100
# 888/888 [==============================] - 0s 27us/step - loss: 2.9960e-04 - val_loss: 1.6360e-04
# Epoch 89/100
# 888/888 [==============================] - 0s 28us/step - loss: 2.8712e-04 - val_loss: 1.9186e-04
# Epoch 90/100
# 888/888 [==============================] - 0s 27us/step - loss: 2.7442e-04 - val_loss: 1.2583e-04
# Epoch 91/100
# 888/888 [==============================] - 0s 27us/step - loss: 2.6151e-04 - val_loss: 1.2708e-04
# Epoch 92/100
# 888/888 [==============================] - 0s 27us/step - loss: 2.4759e-04 - val_loss: 1.5978e-04
# Epoch 93/100
# 888/888 [==============================] - 0s 28us/step - loss: 2.3681e-04 - val_loss: 1.2745e-04
# Epoch 94/100
# 888/888 [==============================] - 0s 27us/step - loss: 2.2560e-04 - val_loss: 1.5129e-04
# Epoch 95/100
# 888/888 [==============================] - 0s 27us/step - loss: 2.1307e-04 - val_loss: 9.7797e-05
# Epoch 96/100
# 888/888 [==============================] - 0s 27us/step - loss: 2.0264e-04 - val_loss: 1.5649e-04
# Epoch 97/100
# 888/888 [==============================] - 0s 28us/step - loss: 1.9212e-04 - val_loss: 1.0723e-04
# Epoch 98/100
# 888/888 [==============================] - 0s 29us/step - loss: 1.8235e-04 - val_loss: 1.0923e-04
# Epoch 99/100
# 888/888 [==============================] - 0s 28us/step - loss: 1.7217e-04 - val_loss: 1.2454e-04
# Epoch 100/100
# 888/888 [==============================] - 0s 30us/step - loss: 1.6366e-04 - val_loss: 1.0644e-04

# %%
model.save('GBPUSDnoVix.h5')

# %%
# demonstrate prediction
x_input = np.array([df.iloc[-1,5]])
yhat = model.predict(x_input, verbose=1)
print(yhat,'versus', df.iloc[-1,-1])
error = ((df.iloc[-1,-1] - yhat)/df.iloc[-1,-1])*100
print('Error : ',abs(error[0][0]),'%')
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [[1.2838979]] versus 1.2664639949798584
# Error :  1.3765793 %

# %%
print('Initializing \b Processing')
yhat = model.predict(X1_test, verbose=1)
print('All processed')
# Out:
# Initializing Processing
# 228/228 [==============================] - 0s 18us/step
# All processed

# %%
date.reset_index(inplace=True,drop=True)
resultats = date
resultats = resultats.iloc[-228:]
resultats.reset_index(inplace=True,drop=True)

# %%
dataset.head()
# Out:
#          Date      Open     Close
# 0  2014-04-07  1.661074  1.661047
# 1  2014-04-08  1.674677  1.675014
# 2  2014-04-09  1.680023  1.679995
# 3  2014-04-10  1.677627  1.677740
# 4  2014-04-13  1.672996  1.672968

# %%
pred = pd.DataFrame()
pred['Open'] = dataset.iloc[1111:,1]
#pred['Vix'] = dataset.iloc[1111:,2]
pred['Close'] = dataset.iloc[1111:,2]
pred['Predictions'] = yhat.reshape(228,)
pred.reset_index(inplace=True,drop=True)
resultats = pd.concat((date,pred),axis=1)
resultats = resultats.iloc[:228,:]
resultats['% Error'] = ((resultats.iloc[:,2].values-resultats.iloc[:,3])/resultats.iloc[:,3])*100

# %%
resultats.tail()
# Out:
#            Date      Open     Close  Predictions   % Error
# 223  2015-02-13  1.273026  1.273156     1.289911 -1.298944
# 224  2015-02-16  1.272783  1.272912     1.289688 -1.300768
# 225  2015-02-17  1.419030  1.419055     1.423704 -0.326514
# 226  2015-02-18  1.266336  1.266416     1.283780 -1.352588
# 227  2015-02-19  1.266464  1.266464     1.283898 -1.357887

# %%
plt.figure(figsize=(16,6),dpi=200)
plt.suptitle('Prediction of GBPUSD with DEEP LEARNING WITHOUT VIX',fontsize=16)
plt.plot(resultats['Close'],color='purple',label='Actual')
plt.plot(resultats['Predictions'],color='orange',label='Predicted')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,6),dpi=200)
plt.suptitle('Prediction of GBPUSD with DEEP LEARNING WITHOUT VIX',fontsize=16)
plt.plot(resultats['% Error'],color='g',label='% Error')
plt.axhline(y=0,linestyle='--',color='r')
plt.legend()
plt.show()

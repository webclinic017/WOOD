# %%
___Author___='LumberJack Jyss'

# %%
print('Global Optimized LumberJack Equities Method\n°OoO_FOREX_Oo0°\nLumberJack Jyss 5779(c)')
# Out:
# Global Optimized LumberJack Equities Method
# °OoO_FOREX_Oo0°
# LumberJack Jyss 5779(c)

# %%
print('Importing librairies...')
import numpy as np
import pandas as pd
import pandas_datareader as web
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from keras.models import Sequential
from keras.layers import Input
from keras.layers import Dense
import seaborn as sns
import talib
from yahoofinancials import YahooFinancials
print('Librairies imported')
# Out:
# Importing librairies...
# Librairies imported

# %%
tf.logging.set_verbosity(tf.logging.ERROR)

# %%
start = '2017-01-01'
end = '2019-05-26'

# %%
currencies = ['GBPJPY=X', 'EURAUD=X', 'AUDNZD=X','AUDJPY=X','USDCAD=X',\
             'AUDHKD=X','GBPSGD=X','GBPUSD=X']
print('Strating Global Optimized LumberJack Equities Method')
# Out:
# Strating Global Optimized LumberJack Equities Method

# %%
print('Scrapping Data')
df = pd.DataFrame()
# Out:
# Scrapping Data

# %%
pd.DataFrame.from_dict(temp_df.iloc[4,1])['formatted_date'].isnull().sum()
# Out:
# 0

# %%
daily_currency_prices = YahooFinancials(currencies).get_historical_price_data(start,end,'daily')
temp_df = pd.DataFrame.from_dict(daily_currency_prices.values()).T
print('Data scrapped')
# Out:
# Data scrapped

# %%
print('\nSetting TimeFrame')
for i in range(0,len(currencies)-1):
    df['Date'] = pd.DataFrame.from_dict(temp_df.iloc[4,1])['formatted_date']
print('TimeFrame : Daily => OK')
df.shape
# Out:
# Setting TimeFrame
# TimeFrame : Daily => OK
# (625, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 1 columns):
# Date    625 non-null object
# dtypes: object(1)
# memory usage: 5.0+ KB

# %%
len(currencies)
# Out:
# 8

# %%
temp_df.iloc[4,1][:2]
# Out:
# [{'date': 1483315200,
#   'high': 1.463670015335083,
#   'low': 1.4550000429153442,
#   'open': 1.4595999717712402,
#   'close': 1.4580299854278564,
#   'volume': 0,
#   'adjclose': 1.4580299854278564,
#   'formatted_date': '2017-01-02'},
#  {'date': 1483401600,
#   'high': 1.4553899765014648,
#   'low': 1.4359099864959717,
#   'open': 1.4533300399780273,
#   'close': 1.4536199569702148,
#   'volume': 0,
#   'adjclose': 1.4536199569702148,
#   'formatted_date': '2017-01-03'}]

# %%
len(temp_df.iloc[4,1])
# Out:
# 625

# %%
currencies
# Out:
# ['GBPJPY=X',
#  'EURAUD=X',
#  'AUDNZD=X',
#  'AUDJPY=X',
#  'USDCAD=X',
#  'AUDHKD=X',
#  'GBPSGD=X',
#  'GBPUSD=X']

# %%
for i in range(0,len(currencies)):
    print('Collecting ==> '+str(currencies[i]),' rang i=',i)
    
    if i == len(currencies)-1:
        print('Extra features for GBPUSD')
        df[str(currencies[i])+str('_High')] = pd.DataFrame.from_dict(temp_df.iloc[4,i])['high']
        df[str(currencies[i])+str('_Low')] = pd.DataFrame.from_dict(temp_df.iloc[4,i])['low']
        
    df[str(currencies[i])+str('_Close')] = pd.DataFrame.from_dict(temp_df.iloc[4,i])['close']
    
    
    print(currencies[i],' =====> collected')
# Out:
# ...
# GBPJPY=X  =====> collected
# ...
# EURAUD=X  =====> collected
# ...
# AUDNZD=X  =====> collected
# ...
# AUDJPY=X  =====> collected
# ...
# USDCAD=X  =====> collected
# ...
# AUDHKD=X  =====> collected
# ...
# GBPSGD=X  =====> collected
# ...
# Extra features for GBPUSD
# GBPUSD=X  =====> collected

# %%
df.shape
# Out:
# (625, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 11 columns):
# Date              625 non-null object
# GBPJPY=X_Close    623 non-null float64
# EURAUD=X_Close    622 non-null float64
# AUDNZD=X_Close    624 non-null float64
# AUDJPY=X_Close    624 non-null float64
# USDCAD=X_Close    622 non-null float64
# AUDHKD=X_Close    624 non-null float64
# GBPSGD=X_Close    622 non-null float64
# GBPUSD=X_High     622 non-null float64
# GBPUSD=X_Low      622 non-null float64
# GBPUSD=X_Close    622 non-null float64
# dtypes: float64(10), object(1)
# memory usage: 53.8+ KB

# %%
df.tail()
# Out:
#            Date  GBPJPY=X_Close  EURAUD=X_Close  AUDNZD=X_Close  \
# 620  2019-05-19      140.235992         1.61720         1.05650
# 621  2019-05-20      140.089996         1.61370         1.05808
# 622  2019-05-21      140.492996         1.62140         1.05786
# 623  2019-05-22      139.572998         1.62190         1.05875
# 624  2019-05-23      138.722000         1.62102         1.05700
#
#      AUDJPY=X_Close  USDCAD=X_Close  AUDHKD=X_Close  GBPSGD=X_Close  \
# 620       76.029999         1.34469         5.41710         1.75222
# 621       76.169998         1.34272         5.43167         1.75056
# 622       76.094002             NaN         5.40216         1.74850
# 623       75.797997         1.34365         5.39760         1.74560
# 624       75.580002         1.34736         5.41400         1.74589
#
#      GBPUSD=X_High  GBPUSD=X_Low  GBPUSD=X_Close
# 620       1.275754      1.271682        1.273156
# 621       1.279427      1.268617        1.272912
# ...

# %%
df.isnull().sum()
# Out:
# Date              0
# GBPJPY=X_Close    2
# EURAUD=X_Close    3
# AUDNZD=X_Close    1
# AUDJPY=X_Close    1
# USDCAD=X_Close    3
# AUDHKD=X_Close    1
# GBPSGD=X_Close    3
# GBPUSD=X_High     3
# GBPUSD=X_Low      3
# GBPUSD=X_Close    3
# dtype: int64

# %%
df = df.dropna()

# %%
df.to_csv('df.csv')

# %%
df = pd.read_csv('df.csv')
df = df.iloc[:,1:]
df.shape
# Out:
# (621, 11)

# %%
dataset = df.copy()
dataset.head()
# Out:
#          Date  GBPJPY=X_Close  EURAUD=X_Close  AUDNZD=X_Close  AUDJPY=X_Close  \
# 0  2017-01-02      144.063004         1.45803         1.03783       84.081001
# 1  2017-01-03      144.259995         1.45362         1.03807       84.512001
# 2  2017-01-04      144.028000         1.44077         1.04409       85.040001
# 3  2017-01-05      144.322998         1.44087         1.04572       85.309998
# 4  2017-01-06      143.173004         1.44499         1.04516       84.574997
#
#    USDCAD=X_Close  AUDHKD=X_Close  GBPSGD=X_Close  GBPUSD=X_High  \
# 0         1.34340          5.5929         1.78720       1.235941
# 1         1.34414          5.5796         1.78150       1.231072
# 2         1.34218          5.6065         1.77300       1.229710
# 3         1.32990          5.6493         1.77277       1.241773
# 4         1.32294          5.6895         1.77370       1.242390
#
#    GBPUSD=X_Low  GBPUSD=X_Close
# 0      1.228350        1.234903
# 1      1.220405        1.228199
# ...

# %%
dataset.shape
# Out:
# (621, 11)

# %%
macd, macdsignal, macdhist = talib.MACD(dataset['GBPUSD=X_Close'], fastperiod=50, slowperiod=200, signalperiod=20)
rsi = talib.RSI(dataset['GBPUSD=X_Close'], timeperiod=5)
upperband, middleband, lowerband = talib.BBANDS(dataset['GBPUSD=X_Close'], timeperiod=20, nbdevup=2, nbdevdn=2, matype=0)
atr = talib.ATR( dataset['GBPUSD=X_High'], dataset['GBPUSD=X_Low'], dataset['GBPUSD=X_Close'], timeperiod=14)
wclprice = talib.WCLPRICE(dataset['GBPUSD=X_High'], dataset['GBPUSD=X_Low'], dataset['GBPUSD=X_Close'])
ema3 = talib.EMA(dataset['GBPUSD=X_Close'],timeperiod=3)
ema8 = talib.EMA(dataset['GBPUSD=X_Close'],timeperiod=8)
ema14 = talib.EMA(dataset['GBPUSD=X_Close'],timeperiod=14)
ema28 = talib.EMA(dataset['GBPUSD=X_Close'],timeperiod=28)


dataset['Macdsignal_GBPUSD'] = macdsignal
dataset['rsi_GBPUSD'] = rsi
dataset['BBup_GBPUSD'] = upperband
dataset['BBmid_GBPUSD'] = middleband
dataset['BBlow_GBPUSD'] = lowerband
dataset['atr_GBPUSD'] = atr
dataset['wclprince_GBPUSD'] = wclprice
dataset['ema3'] = ema3
dataset['ema8'] = ema8
dataset['ema14'] = ema14
dataset['ema28'] = ema28

dataset.shape
# Out:
# (621, 22)

# %%
dataset.tail()
# Out:
#            Date  GBPJPY=X_Close  EURAUD=X_Close  AUDNZD=X_Close  \
# 616  2019-05-16      140.600006         1.62113         1.05458
# 617  2019-05-19      140.235992         1.61720         1.05650
# 618  2019-05-20      140.089996         1.61370         1.05808
# 619  2019-05-22      139.572998         1.62190         1.05875
# 620  2019-05-23      138.722000         1.62102         1.05700
#
#      AUDJPY=X_Close  USDCAD=X_Close  AUDHKD=X_Close  GBPSGD=X_Close  \
# 616       75.690002         1.34620         5.40920         1.75669
# 617       76.029999         1.34469         5.41710         1.75222
# 618       76.169998         1.34272         5.43167         1.75056
# 619       75.797997         1.34365         5.39760         1.74560
# 620       75.580002         1.34736         5.41400         1.74589
#
#      GBPUSD=X_High  GBPUSD=X_Low  ...  rsi_GBPUSD  BBup_GBPUSD  BBmid_GBPUSD  \
# 616       1.279918      1.272135  ...   12.194850     1.314688      1.297796
# ...

# %%
dataset = dataset.dropna()
dataset.reset_index(inplace=True,drop=True)

# %%
dataset.head()
# Out:
#          Date  GBPJPY=X_Close  EURAUD=X_Close  AUDNZD=X_Close  AUDJPY=X_Close  \
# 0  2017-11-03      148.819000         1.51100         1.11587       87.944000
# 1  2017-11-06      149.300003         1.51789         1.10730       87.357002
# 2  2017-11-07      149.830002         1.51010         1.10660       87.452003
# 3  2017-11-08      149.837997         1.51561         1.10750       87.070999
# 4  2017-11-09      149.363998         1.50940         1.10383       87.472000
#
#    USDCAD=X_Close  AUDHKD=X_Close  GBPSGD=X_Close  GBPUSD=X_High  \
# 0         1.28075          6.0184         1.77290       1.312319
# 1         1.27600          5.9668         1.78370       1.315288
# 2         1.27136          5.9960         1.79407       1.317714
# 3         1.27614          5.9713         1.79510       1.317870
# 4         1.27278          5.9849         1.78520       1.315166
#
#    GBPUSD=X_Low  ...  rsi_GBPUSD  BBup_GBPUSD  BBmid_GBPUSD  BBlow_GBPUSD  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403 entries, 0 to 402
# Data columns (total 22 columns):
# Date                 403 non-null object
# GBPJPY=X_Close       403 non-null float64
# EURAUD=X_Close       403 non-null float64
# AUDNZD=X_Close       403 non-null float64
# AUDJPY=X_Close       403 non-null float64
# USDCAD=X_Close       403 non-null float64
# AUDHKD=X_Close       403 non-null float64
# GBPSGD=X_Close       403 non-null float64
# GBPUSD=X_High        403 non-null float64
# GBPUSD=X_Low         403 non-null float64
# GBPUSD=X_Close       403 non-null float64
# Macdsignal_GBPUSD    403 non-null float64
# rsi_GBPUSD           403 non-null float64
# BBup_GBPUSD          403 non-null float64
# BBmid_GBPUSD         403 non-null float64
# BBlow_GBPUSD         403 non-null float64
# atr_GBPUSD           403 non-null float64
# wclprince_GBPUSD     403 non-null float64
# ema3                 403 non-null float64
# ema8                 403 non-null float64
# ...

# %%
plt.figure(figsize=(26,16))
sns.heatmap(dataset.corr(),annot=True)
plt.show()

# %%
plt.figure(figsize=(26,6))
corr = dataset.corr()
sns.heatmap(corr[corr.index == 'GBPUSD=X_Close'], linewidths=0.1, vmax=1.0, square=True, cmap=colormap, linecolor='white', annot=True);

# %%
delta = round(X1.shape[0])
bloc1 = round(delta*0.8)
bloc2 = delta - bloc1
print("Période d'étude : ",delta)
print('Sur un découpage 80% - 20% de la période : ')
print('Bloc 1 : ',bloc1,' jours \nBloc 2 :',bloc2,' jours')
# Out:
# Période d'étude :  404
# Sur un découpage 80% - 20% de la période :
# Bloc 1 :  323  jours
# Bloc 2 : 81  jours

# %%
# convert into input/output

X1 = dataset['rsi_GBPUSD'].values.reshape(len(dataset),1)
X2 = dataset['EURAUD=X_Close'].values.reshape(len(dataset),1)
X3 = dataset['AUDNZD=X_Close'].values.reshape(len(dataset),1)
X4 = dataset['atr_GBPUSD'].values.reshape(len(dataset),1)


#X1 = dataset['GBPJPY=X_Close'].values.reshape(len(dataset),1)
#X4 = dataset['AUDJPY=X_Close'].values.reshape(len(dataset),1)
#X5 = dataset['USDCAD=X_Close'].values.reshape(len(dataset),1)
#X6 = dataset['AUDHKD=X_Close'].values.reshape(len(dataset),1)
#X7 = dataset['GBPSGD=X_Close'].values.reshape(len(dataset),1)
#X8 = dataset['NG=F_Close'].values.reshape(len(dataset),1)
y = dataset['GBPUSD=X_Close'].values.reshape(len(dataset),1)



#scaler = MinMaxScaler()
#X1 = scaler.fit_transform(X1)
#X2 = scaler.fit_transform(X2)
#X3 = scaler.fit_transform(X3)
#X4 = scaler.fit_transform(X4)
#X5 = scaler.fit_transform(X5)
#X6 = scaler.fit_transform(X6)
#X7 = scaler.fit_transform(X7)
#X8 = scaler.fit_transform(X8)

#y = scaler.fit_transform(y)

X1_train = X1[:bloc1]
X1_test = X1[bloc1:]

X2_train = X2[:bloc1]
X2_test = X2[bloc1:]

X3_train = X3[:bloc1]
X3_test = X3[bloc1:]

X4_train = X4[:bloc1]
X4_test = X4[bloc1:]

#X5_train = X5[:bloc1]
#X5_test = X5[bloc1:]

#X6_train = X6[:bloc1]
#X6_test = X6[bloc1:]

#X7_train = X7[:bloc1]
#X7_test = X7[bloc1:]

#X8_train = X8[:bloc1]
#X8_test = X8[bloc1:]


y_train = y[:bloc1]
y_test = y[bloc1:]

# %%
X_train = np.concatenate((X1_train,X2_train,X3_train,X4_train),axis=1) #,X5_train,X6_train,X7_train,X8_train,),axis=1)
X_test = np.concatenate((X1_test,X2_test,X3_test,X4_test),axis=1) #,X5_test,X6_test,X7_test,X8_test,),axis=1)

# %%
# first input model
model = Sequential()
model.add(Dense(50, activation='relu', input_dim=4))
#model.add(Dense(128, activation='relu'))
#model.add(Dense(64, activation='relu'))
#model.add(Dense(32, activation='relu'))
#model.add(Dense(16, activation='relu'))
#model.add(Dense(8, activation='relu'))
#model.add(Dense(4, activation='relu'))
#model.add(Dense(2, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
# fit model
history = model.fit(x=X_train, y=y_train, batch_size=1, epochs=200, verbose=1,shuffle=False,validation_split=.2)
# Out:
# Train on 258 samples, validate on 65 samples
# Epoch 1/200
# 258/258 [==============================] - 0s 807us/step - loss: 0.0011 - val_loss: 4.4037e-04
# Epoch 2/200
# 258/258 [==============================] - 0s 786us/step - loss: 0.0011 - val_loss: 3.9826e-04
# Epoch 3/200
# 258/258 [==============================] - 0s 786us/step - loss: 0.0011 - val_loss: 3.8803e-04
# Epoch 4/200
# 258/258 [==============================] - 0s 794us/step - loss: 0.0011 - val_loss: 3.9598e-04
# Epoch 5/200
# 258/258 [==============================] - 0s 775us/step - loss: 0.0012 - val_loss: 3.9916e-04
# Epoch 6/200
# 258/258 [==============================] - 0s 771us/step - loss: 0.0012 - val_loss: 3.8032e-04
# Epoch 7/200
# 258/258 [==============================] - 0s 798us/step - loss: 0.0012 - val_loss: 3.7945e-04
# Epoch 8/200
# 258/258 [==============================] - 0s 812us/step - loss: 0.0012 - val_loss: 4.1488e-04
# Epoch 9/200
# ...

# %%
X.shape,y.shape
# Out:
# ((404, 21), (404, 1))

# %%
import xgboost as xgb

model_xgb = xgb.XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
                           colsample_bytree=1, max_depth=7) # XGBClassifier()
X = dataset.drop('GBPUSD=X_Close',axis=1)
model_xgb.fit(X_train,y_train)
# Out:
# [15:01:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0,
#        importance_type='gain', learning_rate=0.08, max_delta_step=0,
#        max_depth=7, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=None, subsample=0.75, verbosity=1)

# %%
yhat_xgb = model_xgb.predict(X_test)

# %%
dataset.shape[0],bloc1,bloc2
# Out:
# (404, 323, 81)

# %%
pred = pd.DataFrame()
pred['Date'] = dataset.iloc[bloc1:,0]
pred['Close'] = dataset.iloc[bloc1-1:,10]
pred['Predictions'] = yhat_xgb.reshape(bloc2,)
pred.reset_index(inplace=True,drop=True)
resultats = pred
resultats = resultats.iloc[:bloc2,:]
resultats['% Error'] = ((resultats.iloc[:,1].values-resultats.iloc[:,2])/resultats.iloc[:,1])*100
# Out:
# /Users/YTsBaCh/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
resultats.tail()
# Out:
#           Date     Close  Predictions   % Error
# 76  2019-05-16  1.279771     1.306722 -2.105986
# 77  2019-05-19  1.273156     1.300377 -2.138117
# 78  2019-05-20  1.272912     1.304124 -2.452022
# 79  2019-05-22  1.266416     1.294682 -2.231993
# 80  2019-05-23  1.266464     1.298996 -2.568725

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 22 columns):
# Date                 404 non-null object
# GBPJPY=X_Close       404 non-null float64
# EURAUD=X_Close       404 non-null float64
# AUDNZD=X_Close       404 non-null float64
# AUDJPY=X_Close       404 non-null float64
# USDCAD=X_Close       404 non-null float64
# AUDHKD=X_Close       404 non-null float64
# GBPSGD=X_Close       404 non-null float64
# GBPUSD=X_High        404 non-null float64
# GBPUSD=X_Low         404 non-null float64
# GBPUSD=X_Close       404 non-null float64
# Macdsignal_GBPUSD    404 non-null float64
# rsi_GBPUSD           404 non-null float64
# BBup_GBPUSD          404 non-null float64
# BBmid_GBPUSD         404 non-null float64
# BBlow_GBPUSD         404 non-null float64
# atr_GBPUSD           404 non-null float64
# wclprince_GBPUSD     404 non-null float64
# ema3                 404 non-null float64
# ema8                 404 non-null float64
# ...

# %%
model.test_on_batch(X_test, y_test)
model.metrics_names
# Out:
# ['loss']

# %%
plt.figure(figsize=(16,6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
model.save('GBPUSD.h5')

# %%
X1_test, bloc1, bloc2, len(X1_train)
# Out:
# (array([], shape=(0, 1), dtype=float64), 497, 124, 403)

# %%
# demonstrate prediction
x_input = np.array([[X1_test[-1],X2_test[-1],X3_test[-1],X4_test[-1]]]) #,X5_test[-1],X6_test[-1],X7_test[-1],X8_test[-1],
yhat = model.predict(x_input, verbose=1)
#scaler.inverse_transform(yhat)
print(yhat,'versus', dataset.loc[-1,'GBPUSD=X_Close'])
error = ((df.iloc[-1,-1] - yhat)/df.iloc[-1,-1])*100
print('Error : ',abs(error[0][0]),'%')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-134-48379204d546> in <module>
#       1 # demonstrate prediction
# ----> 2 x_input = np.array([[X1_test[-1],X2_test[-1],X3_test[-1],X4_test[-1]]]) #,X5_test[-1],X6_test[-1],X7_test[-1],X8_test[-1],
#       3 yhat = model.predict(x_input, verbose=1)
#       4 #scaler.inverse_transform(yhat)
#       5 print(yhat,'versus', dataset.loc[-1,'GBPUSD=X_Close'])
#
# IndexError: index -1 is out of bounds for axis 0 with size 0

# %%
print('Initializing \b Processing')
yhat = model.predict(X_test, verbose=1)
yhat = scaler.inverse_transform(yhat)
print('All processed')
# Out:
# Initializing Processing
# 54/54 [==============================] - 0s 43us/step
# All processed

# %%
plt.figure(figsize=(22,10))
plt.plot(X1,label='GBPJPY=X_Close')
plt.plot(X3,label='AUDNZD=X_Close')
plt.plot(X4,label='AUDJPY=X_Close')
plt.plot(X6,label='AUDHKD=X_Close')
plt.plot(X7,label='GBPSGD=X_Close')
plt.plot(X8,label='NG=F_Close')
plt.plot(y,label='GBPUSD_Close')
plt.legend()
plt.show()

# %%
dataset.head()
# Out:
#          Date  GBPJPY=X_Close  EURAUD=X_Close  AUDNZD=X_Close  AUDJPY=X_Close  \
# 0  2018-07-01      144.063004         1.45803         1.03783       84.081001
# 1  2018-07-02      144.259995         1.45362         1.03807       84.512001
# 2  2018-07-03      144.028000         1.44077         1.04409       85.040001
# 3  2018-07-05      144.322998         1.44087         1.04572       85.309998
# 4  2018-07-06      143.173004         1.44499         1.04516       84.574997
#
#    USDCAD=X_Close  AUDHKD=X_Close  GBPSGD=X_Close  NG=F_Close  GBPUSD=X_Close
# 0         1.34340          5.5929         1.78720       2.910        1.234903
# 1         1.34414          5.5796         1.78150       2.861        1.228199
# 2         1.34218          5.6065         1.77300       2.892        1.224560
# 3         1.32990          5.6493         1.77277       2.830        1.232681
# 4         1.32294          5.6895         1.77370       2.850        1.242545

# %%
pred = pd.DataFrame()
pred['Date'] = dataset.iloc[bloc1:,0]
pred['Close'] = dataset.iloc[bloc1-1:,9]
pred['Predictions'] = yhat.reshape(bloc2,)
pred.reset_index(inplace=True,drop=True)
resultats = pred
resultats = resultats.iloc[:bloc2,:]
resultats['% Error'] = ((resultats.iloc[:,1].values-resultats.iloc[:,2])/resultats.iloc[:,1])*100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-21472ea2ff17> in <module>
#       2 pred['Date'] = dataset.iloc[bloc1:,0]
#       3 pred['Close'] = dataset.iloc[bloc1-1:,9]
# ----> 4 pred['Predictions'] = yhat.reshape(bloc2,)
#       5 pred.reset_index(inplace=True,drop=True)
#       6 resultats = pred
#
# ValueError: cannot reshape array of size 1 into shape (54,)

# %%
resultats.tail()
# Out:
#           Date     Close  Predictions   % Error
# 49  2019-05-17  1.357128     1.334736  1.649940
# 50  2019-05-19  1.353235     1.332176  1.556164
# 51  2019-05-20  1.351278     1.330015  1.573565
# 52  2019-05-21  1.354188     1.332059  1.634120
# 53  2019-05-22  1.373306     1.348102  1.835250

# %%
plt.figure(figsize=(16,6),dpi=200)
plt.suptitle('Prediction of GBPUSD with DEEP LEARNING',fontsize=16)
plt.plot(resultats['Close'],color='purple',label='Actual')
plt.plot(resultats['Predictions'],color='orange',label='Predicted')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,6),dpi=200)
plt.suptitle('Prediction of GBPUSD with DEEP LEARNING',fontsize=16)
plt.plot(resultats['% Error'],color='g',label='% Error')
plt.axhline(y=0,linestyle='--',color='r')
plt.legend()
plt.show()

# %%
resultats
# Out:
#           Date     Close  Predictions   % Error
# 0   2019-03-19  1.321248     1.305751  1.172904
# 1   2019-03-20  1.329222     1.317972  0.846308
# 2   2019-03-21  1.325539     1.315332  0.770049
# 3   2019-03-22  1.305330     1.294897  0.799259
# 4   2019-03-24  1.308044     1.297069  0.839085
# 5   2019-03-25  1.317506     1.306801  0.812511
# 6   2019-03-26  1.317211     1.304332  0.977722
# 7   2019-03-27  1.311303     1.299002  0.938099
# 8   2019-03-28  1.314440     1.300462  1.063437
# 9   2019-03-29  1.312026     1.299700  0.939427
# 10  2019-03-31  1.312336     1.297383  1.139429
# 11  2019-04-01  1.315789     1.303927  0.901524
# 12  2019-04-03  1.320045     1.304932  1.144849
# 13  2019-04-04  1.320271     1.307723  0.950453
# 14  2019-04-05  1.324503     1.309129  1.160760
# 15  2019-04-07  1.324556     1.308174  1.236772
# 16  2019-04-08  1.331682     1.317673  1.051960
# 17  2019-04-09  1.330672     1.316694  1.050465
# 18  2019-04-10  1.332445     1.321110  0.850675
# ...

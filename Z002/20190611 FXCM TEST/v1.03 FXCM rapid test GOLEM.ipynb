# %%
___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor\n°OoO_FXCM_Oo0°\nLumberJack Jyss 5779(c)')
print('Version v1.02')
print('Importing librairies...')
import fxcmpy
print('version fxcmpy :',fxcmpy.__version__)
import time
import numpy as np
import pandas as pd
from colorama import Fore, Back, Style 
import datetime as dt
import talib
from zigzag import *
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
plt.style.use('seaborn')
# %matplotlib inline
import plotly.plotly as py
import plotly.tools as tls
#import seaborn as sns
import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report
print('Librairies imported')
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
# Out:
# Global Optimized LumberJack Environment Motor
# °OoO_FXCM_Oo0°
# LumberJack Jyss 5779(c)
# Version v1.02
# Importing librairies...
# version fxcmpy : 1.2.4
# Using TensorFlow backend.
# Librairies imported

# %%
TOKEN = 'e053ac1597cef331df9429ac8151100ea9f1c411'
server = 'demo'

# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'
ticker = 'SPX500'
period = 'm1'
number = 8000
# Time Windows
# start = dt.datetime(2017, 7, 15)
# stop = dt.datetime(2017, 8, 1)
# con.get_candles('EUR/USD', period='D1',start=start, stop=stop)

# %%
pos_long = 0
pos_short = 0

# %%
# Python program to print 
# red text with green background 

print(Fore.BLUE + 'some red text') 
print(Back.WHITE + 'and with a green background') 
print(Style.DIM + 'and in dim text') 
print(Style.RESET_ALL) 
print('back to normal now')
# Out:
# some red text
# and with a green background
# and in dim text
#
# back to normal now

# %%
tmps1=time.time()
print('Connecting server...')
con = fxcmpy.fxcmpy(access_token=TOKEN, log_level='error',server= server)
if con.is_connected():
    print('Connection established for', Fore.BLUE + str(con.get_account_ids()[-1]),Style.RESET_ALL,' - Mode :',Fore.RED + server,Style.RESET_ALL)
else:
    print('Not connected')
tmps2=round(time.time()-tmps1,2)
print ("Connexion executed in = %f" %tmps2,'secondes')
# Out:
# Connecting server...
# WARNING: Logging before flag parsing goes to stderr.
# W0617 15:34:19.331824 4551935424 fxcmpy.py:222] Default account set to 1147539, to change use set_default_account().
# Connection established for 1147539   - Mode : demo
# Connexion executed in = 10.300000 secondes

# %%
tmps1=time.time()
data = con.get_candles(ticker, period=period,number=number) #start=start,stop=stop)
df = pd.DataFrame()
df['Open'] = data['askopen']
df['High'] = data['askhigh']
df['Low'] = data['asklow']
df['Close'] = data['askclose']
df['Date'] = data.index
df = df[['Date'] + df.columns[:-1].tolist()]
#df = data.copy()
tmps2=round(time.time()-tmps1,2)
print (Fore.GREEN + "Scrap (historical) executed in = %f"  %tmps2,'secondes',Style.RESET_ALL)

print('\033[33m' + 'Initializing GOLEM...')
print('\033[35m' +'Long Pos =',pos_long)
print('Short Pos =',pos_short,Style.RESET_ALL)
# SCRAP DATA

# DEEP LEARNING

tmps1=time.time()
df.reset_index(inplace=True,drop=True)
dataset_1D = df.copy()
dataset_1D = dataset_1D.dropna()
rsi = talib.RSI(dataset_1D['Close'],timeperiod=2)
upper, middle, lower =  talib.BBANDS(dataset_1D['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
sma5 = talib.SMA(dataset_1D['Close'],timeperiod=5)
sma8 = talib.SMA(dataset_1D['Close'],timeperiod=8)
sma10 = talib.SMA(dataset_1D['Close'],timeperiod=10)
sma12 = talib.SMA(dataset_1D['Close'],timeperiod=12)
sma15 = talib.SMA(dataset_1D['Close'],timeperiod=15)
sma30 = talib.SMA(dataset_1D['Close'],timeperiod=30)
sma35 = talib.SMA(dataset_1D['Close'],timeperiod=35)
sma40 = talib.SMA(dataset_1D['Close'],timeperiod=40)
sma45 = talib.SMA(dataset_1D['Close'],timeperiod=45)
sma50 = talib.SMA(dataset_1D['Close'],timeperiod=50)

delta5_8 = sma5 - sma8
delta8_10 = sma8 - sma10
delta10_12 = sma10 - sma12
delta12_15 = sma12 - sma15
delta15_30 = sma15 - sma30
delta30_35 = sma30 - sma35
delta35_40 = sma35 - sma40
delta40_45 = sma40 - sma45
delta45_50 = sma45 - sma50

X = dataset_1D['Close']
pivots = peak_valley_pivots(X.values, 0.001, -0.001)
ts_pivots = pd.Series(X, index=X.index)
ts_pivots = ts_pivots[pivots != 0]

peak = []
valley = []

for i in range(0,dataset_1D.shape[0]):
    if pivots[i] == 1:
        peak.append(pivots[i])
        valley.append(0)
    elif pivots[i] == -1:
        peak.append(0)
        valley.append(pivots[i])
    else:
        peak.append(0)
        valley.append(0)

bbdelta = upper - middle
price_bolup = dataset_1D['Close'] - lower
price_bolow = dataset_1D['Close'] - upper

rsi5_list = []
rsi95_list = []
for i in range(0,dataset_1D.shape[0]):
    try:
        rsi95_list.append(95 - rsi[i])
        rsi5_list.append(rsi[i] - 5)
    except:
        rsi95_list.append(0)
        rsi5_list.append(0)
varop_spy = dataset_1D['Open'] - dataset_1D['Close']
varhl_spy = dataset_1D['High'] - dataset_1D['Low']
dataset_1D['Varop_Spy'] = varop_spy
dataset_1D['Varhl_spy'] = varhl_spy
dataset_1D['RSI'] = rsi
dataset_1D['95 - RSI'] = np.array(rsi95_list)
dataset_1D['RSI - 5'] = np.array(rsi5_list)
dataset_1D['BBD_Delta_Up'] = bbdelta
dataset_1D['delta5_8'] = delta5_8
dataset_1D['delta8_10'] = delta8_10
dataset_1D['delta10_12'] = delta10_12
dataset_1D['delta12_15'] = delta12_15
dataset_1D['delta15_30'] = delta15_30
dataset_1D['delta30_35'] = delta30_35
dataset_1D['delta35_40'] = delta35_40
dataset_1D['delta40_45'] = delta40_45
dataset_1D['delta45_50'] = delta45_50
dataset_1D['Peaks'] = abs(np.array(peak))
dataset_1D['Valley'] = abs(np.array(valley))
tsf = talib.TSF(dataset_1D['Close'],timeperiod=14)
delta_tsf = dataset_1D['Close'] - tsf
dataset_1D['delta_tsf'] = tsf
forosc = []
forosc.append(0)
for i in range(1,dataset_1D.shape[0]):
    try:
        forosc.append((dataset_1D.iloc[i,4] - tsf[i-1])*100/dataset_1D.iloc[i,4])
    except:
        forosc.append(0)
dataset_1D['Forcast Oscillator'] = (forosc)
target_up = []
target_down = []

for i in range(0,dataset_1D.shape[0]-5):

    if (dataset_1D.iloc[i+1,5] * dataset_1D.iloc[i,5]) < 0 :
        if (dataset_1D.iloc[i+1,4] - dataset_1D.iloc[i,4]) > 0.02 : 
            target_up.append(1)
            target_down.append(0)
        elif (dataset_1D.iloc[i+1,4] - dataset_1D.iloc[i,4]) < -0.01 : 
            target_up.append(0)
            target_down.append(1)
        else:
            target_up.append(0)
            target_down.append(0)
    else :
        target_up.append(0)
        target_down.append(0) 

target_up.append(0)
target_down.append(0)
target_up.append(0)
target_down.append(0)
target_up.append(0)
target_down.append(0)
target_up.append(0)
target_down.append(0)
target_up.append(0)
target_down.append(0)
dataset_1D['target_up'] = target_up  # target_up # abs(np.array(valley))#target_up
dataset_1D['target_down'] = target_down # target_down # abs(np.array(peak))#target_down
dataset_1D['target_value'] = dataset_1D['Close']
dataset_1D = dataset_1D.drop(['Open','High','Low','Close'],axis=1)
df_1D = dataset_1D.copy()
df_1D = df_1D.iloc[:,1:]
df_1D['Date'] = df['Date']
df_1D = df_1D.dropna()
df_1D = df_1D[['Date'] + df_1D.columns[:-1].tolist()]
df_1D.reset_index(inplace=True,drop=True)

print('\033[36m'+'GOLEM begins Computing...'+Style.RESET_ALL)


X = df_1D.iloc[:,1:-3]
y_up = df_1D.iloc[:,-3].values
y_down = df_1D.iloc[:,-2].values

scaler = MinMaxScaler(feature_range=(0, 1))
X = scaler.fit_transform(X)
y_up = np.array(y_up).reshape(-1,1)
y_down = np.array(y_down).reshape(-1,1)

Xtrain = X[:-1,:]
Xtest = X[-1:,:]
ytrain_up = y_up[:-1,:]
ytest_up = y_up[-1:,:]
ytrain_down = y_down[:-1,:]
ytest_down = y_down[-1:,:]

seed = 770
np.random.seed(seed)

ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

model_up = Sequential()
    # Add an input layer 
model_up.add(Dense(23, activation='relu'))
    # Add one hidden layer 
model_up.add(Dense(50, activation='relu'))
    # Add an output layer 
model_up.add(Dense(1, activation='sigmoid'))

model_down = Sequential()
    # Add an input layer 
model_down.add(Dense(23, activation='relu'))
    # Add one hidden layer 
model_down.add(Dense(50, activation='relu'))
    # Add an output layer 
model_down.add(Dense(1, activation='sigmoid'))

print('Processing move_up')
model_up.compile(loss='binary_crossentropy',
                optimizer='adam',
                metrics=['accuracy','mse'])

history_up = model_up.fit(Xtrain, ytrain_up,epochs=50, batch_size=32, verbose=0)

print('Processing move_down')
model_down.compile(loss='binary_crossentropy',
                optimizer='adam',
                metrics=['accuracy','mse'])

history_down = model_down.fit(Xtrain, ytrain_down,epochs=50, batch_size=32, verbose=0)

print('Computing done')


yhat_up = model_up.predict_classes(Xtest)
yhat_down = model_down.predict_classes(Xtest)

predict_up = model_up.predict(Xtest)
predict_down = model_down.predict(Xtest)

resultats = pd.DataFrame()
resultats['Date'] = df_1D.iloc[-1:,0]
resultats['Move Up'] = yhat_up
resultats['Confiance up'] = (predict_up)*100
resultats['Move Down'] = yhat_down
resultats['Confiance Down'] = (predict_down)*100
resultats['Actual'] = df_1D['target_value']

tmps2=round(time.time()-tmps1,2)
print ("DL executed in = %f" %tmps2,'secondes')
print('Resultats :\n \033[31m', resultats,'\n',Style.RESET_ALL)

# TEST POSITIONS

# TEST POS

print('Long Pos =',pos_long)
print('Short Pos =',pos_short)
# Out:
# Scrap (historical) executed in = 1.990000 secondes
# Initializing GOLEM...
# Long Pos = 0
# Short Pos = 0
# GOLEM begins Computing...
# Processing move_up
# Processing move_down
# Computing done
# DL executed in = 23.480000 secondes
# Resultats :
#                       Date  Move Up  Confiance up  Move Down  Confiance Down  \
# 7950 2019-06-17 12:33:00        0     33.265747          0             0.0
#
#       Actual
# 7950  2893.1
#
# Long Pos = 0
# Short Pos = 0

# %%
last.index[-1] == df.iloc[-1,0] ,last.index[-1].hour == df.iloc[-1,0].hour,\
last.index[-1].minute == df.iloc[-1,0].minute,last.index[-1].second == df.iloc[-1,0].second,\
last.index[-1].minute == df.iloc[-1,0].minute +1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-03b259d4a6a2> in <module>
# ----> 1 last.index[-1] == df.iloc[-1,0] ,last.index[-1].hour == df.iloc[-1,0].hour,\
#       2 last.index[-1].minute == df.iloc[-1,0].minute,last.index[-1].second == df.iloc[-1,0].second,\
#       3 last.index[-1].minute == df.iloc[-1,0].minute +1
#
# NameError: name 'last' is not defined

# %%
dataset_1D.tail()
# Out:
#                     Date  Varop_Spy  Varhl_spy        RSI   95 - RSI  \
# 7995 2019-06-17 12:29:00      -0.25       0.25  81.188372  13.811628
# 7996 2019-06-17 12:30:00       0.75       1.25  17.376410  77.623590
# 7997 2019-06-17 12:31:00      -0.25       1.20  45.784433  49.215567
# 7998 2019-06-17 12:32:00       1.08       1.25  11.530731  83.469269
# 7999 2019-06-17 12:33:00      -0.58       0.78  50.947703  44.052297
#
#         RSI - 5  BBD_Delta_Up  delta5_8  delta8_10  delta10_12  ...  \
# 7995  76.188372      0.321401   -0.0535     0.0435    0.025667  ...
# 7996  12.376410      0.480093   -0.1050     0.0060    0.019833  ...
# 7997  40.784433      0.508078   -0.0325    -0.0445    0.021167  ...
# 7998   6.530731      0.915712   -0.1210    -0.0990   -0.021833  ...
# 7999  45.947703      0.933402   -0.1685    -0.0935   -0.069833  ...
#
#       delta35_40  delta40_45  delta45_50  Peaks  Valley    delta_tsf  \
# 7995    0.131429    0.102222    0.089778      0       0  2894.065275
# 7996    0.074321    0.117139    0.075711      0       0  2893.868571
# 7997    0.013464    0.129361    0.068289      0       0  2893.763187
# 7998   -0.050036    0.131528    0.070022      0       0  2893.357143
# 7999   -0.097893    0.125417    0.074733      0       1  2893.204505
#
#       Forcast Oscillator  target_up  target_down  target_value
# 7995            0.001891          0            0       2894.10
# 7996           -0.024721          0            0       2893.35
# 7997           -0.009282          0            0       2893.60
# 7998           -0.042979          0            0       2892.52
# 7999           -0.008888          0            0       2893.10
#
# [5 rows x 23 columns]

# %%
print('Initializing GOLEM on STREAMING LIVE...')
print('Long Pos =',pos_long)
print('Short Pos =',pos_short)
# SCRAP DATA
print('Instrument :', ticker)

for loop in range(0,2000):    
    tmps1=time.time()
    con.subscribe_market_data(ticker)
    last = con.get_prices(ticker)
    #while last.index[-1] == df.iloc[-1,0] and last.index[-1].hour == df.iloc[-1,0].hour and last.index[-1].minute == df.iloc[-1,0].minute \
    #and last.index[-1].second == df.iloc[-1,0].second :
    #    last = con.get_prices(ticker)
    
    df = df.iloc[1:,:]
    df = df.append({ 'Date':last.index[-1],'Open':last.iloc[-1,0], 'High':last.iloc[-1,1],'Low':last.iloc[-1,2], 'Close':last.iloc[-1,3]}, ignore_index=True)
    tmps2=round(time.time()-tmps1,2)
    print ("MAJ live in = %f" %tmps2,'secondes')

    # TESTING ONLY

    tmps1=time.time()
    df.reset_index(inplace=True,drop=True)
    dataset_1D = df.copy()
    dataset_1D = dataset_1D.dropna()
    rsi = talib.RSI(dataset_1D['Close'],timeperiod=2)
    upper, middle, lower =  talib.BBANDS(dataset_1D['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(dataset_1D['Close'],timeperiod=5)
    sma8 = talib.SMA(dataset_1D['Close'],timeperiod=8)
    sma10 = talib.SMA(dataset_1D['Close'],timeperiod=10)
    sma12 = talib.SMA(dataset_1D['Close'],timeperiod=12)
    sma15 = talib.SMA(dataset_1D['Close'],timeperiod=15)
    sma30 = talib.SMA(dataset_1D['Close'],timeperiod=30)
    sma35 = talib.SMA(dataset_1D['Close'],timeperiod=35)
    sma40 = talib.SMA(dataset_1D['Close'],timeperiod=40)
    sma45 = talib.SMA(dataset_1D['Close'],timeperiod=45)
    sma50 = talib.SMA(dataset_1D['Close'],timeperiod=50)

    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50

    X = dataset_1D['Close']
    pivots = peak_valley_pivots(X.values, 0.001, -0.001)
    ts_pivots = pd.Series(X, index=X.index)
    ts_pivots = ts_pivots[pivots != 0]

    peak = []
    valley = []

    for i in range(0,dataset_1D.shape[0]):
        if pivots[i] == 1:
            peak.append(pivots[i])
            valley.append(0)
        elif pivots[i] == -1:
            peak.append(0)
            valley.append(pivots[i])
        else:
            peak.append(0)
            valley.append(0)

    bbdelta = upper - middle
    price_bolup = dataset_1D['Close'] - lower
    price_bolow = dataset_1D['Close'] - upper

    rsi5_list = []
    rsi95_list = []
    for i in range(0,dataset_1D.shape[0]):
        try:
            rsi95_list.append(95 - rsi[i])
            rsi5_list.append(rsi[i] - 5)
        except:
            rsi95_list.append(0)
            rsi5_list.append(0)
    varop_spy = dataset_1D['Open'] - dataset_1D['Close']
    varhl_spy = dataset_1D['High'] - dataset_1D['Low']
    dataset_1D['Varop_Spy'] = varop_spy
    dataset_1D['Varhl_spy'] = varhl_spy
    dataset_1D['RSI'] = rsi
    dataset_1D['95 - RSI'] = np.array(rsi95_list)
    dataset_1D['RSI - 5'] = np.array(rsi5_list)
    dataset_1D['BBD_Delta_Up'] = bbdelta
    dataset_1D['delta5_8'] = delta5_8
    dataset_1D['delta8_10'] = delta8_10
    dataset_1D['delta10_12'] = delta10_12
    dataset_1D['delta12_15'] = delta12_15
    dataset_1D['delta15_30'] = delta15_30
    dataset_1D['delta30_35'] = delta30_35
    dataset_1D['delta35_40'] = delta35_40
    dataset_1D['delta40_45'] = delta40_45
    dataset_1D['delta45_50'] = delta45_50
    dataset_1D['Peaks'] = abs(np.array(peak))
    dataset_1D['Valley'] = abs(np.array(valley))
    tsf = talib.TSF(dataset_1D['Close'],timeperiod=14)
    delta_tsf = dataset_1D['Close'] - tsf
    dataset_1D['delta_tsf'] = tsf
    forosc = []
    forosc.append(0)
    for i in range(1,dataset_1D.shape[0]):
        try:
            forosc.append((dataset_1D.iloc[i,4] - tsf[i-1])*100/dataset_1D.iloc[i,4])
        except:
            forosc.append(0)
    dataset_1D['Forcast Oscillator'] = (forosc)
    target_up = []
    target_down = []

    for i in range(0,dataset_1D.shape[0]-5):

        if (dataset_1D.iloc[i+1,5] * dataset_1D.iloc[i,5]) < 0 :
            if (dataset_1D.iloc[i+1,4] - dataset_1D.iloc[i,4]) > 0.002 : 
                target_up.append(1)
                target_down.append(0)
            elif (dataset_1D.iloc[i+1,4] - dataset_1D.iloc[i,4]) < -0.001 : 
                target_up.append(0)
                target_down.append(1)
            else:
                target_up.append(0)
                target_down.append(0)
        else :
            target_up.append(0)
            target_down.append(0) 

    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    target_up.append(0)
    target_down.append(0)
    dataset_1D['target_up'] = target_up  # target_up # abs(np.array(valley))#target_up
    dataset_1D['target_down'] = target_down # target_down # abs(np.array(peak))#target_down
    dataset_1D['target_value'] = dataset_1D['Close']
    dataset_1D = dataset_1D.drop(['Open','High','Low','Close'],axis=1)
    df_1D = dataset_1D.copy()
    df_1D = df_1D.iloc[:,1:]
    df_1D['Date'] = df['Date']
    df_1D = df_1D.dropna()
    df_1D = df_1D[['Date'] + df_1D.columns[:-1].tolist()]
    df_1D.reset_index(inplace=True,drop=True)

    print('GOLEM begins testing...')


    X = df_1D.iloc[:,1:-3]
    #y_up = df_1D.iloc[:,-3].values
    #y_down = df_1D.iloc[:,-2].values

    #scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    #y_up = np.array(y_up).reshape(-1,1)
    #y_down = np.array(y_down).reshape(-1,1)

    #Xtrain = X[:-1,:]
    Xtest = X[-1:,:]
    #ytrain_up = y_up[:-1,:]
    #ytest_up = y_up[-1:,:]
    #ytrain_down = y_down[:-1,:]
    #ytest_down = y_down[-1:,:]

    seed = 770
    np.random.seed(seed)

    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)

    resultats = pd.DataFrame()
    resultats['Date'] = df_1D.iloc[-1:,0]
    resultats['Move Up'] = yhat_up
    resultats['Confiance up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confiance Down'] = (predict_down)*100
    resultats['Actual'] = df_1D['target_value']

    tmps2=round(time.time()-tmps1,2)
    print ("Testing executed in = %f" %tmps2,'secondes')
    print('Resultats :\n')
    print('\033[45m')
    print(resultats)
    print(Style.RESET_ALL)

    print('Long Pos =',pos_long)
    print('Short Pos =',pos_short)
# Out:
# Initializing GOLEM on STREAMING LIVE...
# Long Pos = 0
# Short Pos = 0
# Instrument : SPX500
# MAJ live in = 0.900000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:34:53.161        1     96.427902          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.750000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:34:53.161        0      5.964831          0
#
#       Confiance Down   Actual
# 7950         0.00329  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.640000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:34:53.161        0      3.291868          0
#
#       Confiance Down   Actual
# 7950        0.006948  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 1.010000 secondes
# GOLEM begins testing...
# Testing executed in = 0.700000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0      5.548029          0
#
#       Confiance Down   Actual
# 7950        0.002519  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 1.190000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0      3.258672          0
#
#       Confiance Down   Actual
# 7950        0.001893  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.680000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0      6.111199          0
#
#       Confiance Down   Actual
# 7950        0.001291  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.720000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     10.498925          0
#
#       Confiance Down   Actual
# 7950         0.00044  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.700000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     18.241768          0
#
#       Confiance Down   Actual
# 7950        0.000191  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.710000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     12.727821          0
#
#       Confiance Down   Actual
# 7950        0.000002  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.740000 secondes
# GOLEM begins testing...
# Testing executed in = 0.680000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     11.925906          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.660000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     14.609305          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.740000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     16.288343          0
#
#       Confiance Down   Actual
# 7950        0.000002  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.620000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     20.021271          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 1.250000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     22.218992          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 1.190000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0      25.44817          0
#
#       Confiance Down   Actual
# 7950        0.000002  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.690000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     25.783861          0
#
#       Confiance Down   Actual
# 7950        0.000002  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.660000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0      25.90493          0
#
#       Confiance Down   Actual
# 7950        0.000002  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.720000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     26.048841          0
#
#       Confiance Down   Actual
# 7950        0.000002  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.680000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     26.021412          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.710000 secondes
# GOLEM begins testing...
# Testing executed in = 0.680000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     26.095882          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.670000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     26.024612          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.790000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0         25.85          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.690000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     25.949547          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.630000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     26.087826          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.920000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     26.121166          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.710000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     26.555426          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.760000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     26.926214          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.670000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     27.322842          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.670000 secondes
# GOLEM begins testing...
# Testing executed in = 0.630000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     23.598787          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.780000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0      24.07539          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.780000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     24.620556          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.740000 secondes
# GOLEM begins testing...
# Testing executed in = 0.680000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     26.362053          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.690000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0      30.88023          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.710000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0      33.35965          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.760000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     36.878674          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.720000 secondes
# GOLEM begins testing...
# Testing executed in = 0.700000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     33.059807          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.720000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     29.791842          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.900000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0      26.47897          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 1.030000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     24.211462          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.680000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     21.690195          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 1.070000 secondes
# GOLEM begins testing...
# Testing executed in = 0.720000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     21.925835          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.630000 secondes
# GOLEM begins testing...
# Testing executed in = 0.700000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0      22.06649          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.750000 secondes
# GOLEM begins testing...
# Testing executed in = 0.680000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     22.209223          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.730000 secondes
# GOLEM begins testing...
# Testing executed in = 0.720000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:35:01.170        0     22.333721          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 1.090000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:00.205        0     22.470221          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.660000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:00.205        0      23.21487          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.770000 secondes
# GOLEM begins testing...
# Testing executed in = 0.720000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:03.651        0     24.376616          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.670000 secondes
# GOLEM begins testing...
# Testing executed in = 0.740000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:03.651        0     25.328503          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.740000 secondes
# GOLEM begins testing...
# Testing executed in = 0.780000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:06.553        0     25.752407          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.680000 secondes
# GOLEM begins testing...
# Testing executed in = 0.760000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:06.553        0     26.626726          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.690000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:09.646        0      26.81274          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.690000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:10.066        0     26.626726          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.830000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:10.066        0     26.626726          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.690000 secondes
# GOLEM begins testing...
# Testing executed in = 0.710000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:10.066        0     26.626726          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.700000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:15.020        0      26.71965          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.700000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:15.020        0      26.71965          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.770000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:15.020        0      26.71965          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.760000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:18.449        0     37.192856          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.950000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:20.516        0     26.759518          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.670000 secondes
# GOLEM begins testing...
# Testing executed in = 0.710000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:21.988        0     26.679806          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.750000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:21.988        0     26.679806          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.720000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:24.668        0     26.759518          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.720000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:26.626        0      26.71965          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.710000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:26.992        0     37.192856          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.760000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:28.717        0     13.197485          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.820000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.710000 secondes
# GOLEM begins testing...
# Testing executed in = 0.710000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.830000 secondes
# GOLEM begins testing...
# Testing executed in = 0.710000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.710000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.810000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.690000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.640000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.800000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.640000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.640000 secondes
# GOLEM begins testing...
# Testing executed in = 0.680000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.900000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.720000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.630000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.710000 secondes
# GOLEM begins testing...
# Testing executed in = 0.700000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.680000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.720000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.690000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.670000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.830000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.630000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:29.679        0     19.999825          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.750000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:58.670        0        5.3736          0
#
#       Confiance Down   Actual
# 7950        0.000004  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.730000 secondes
# GOLEM begins testing...
# Testing executed in = 0.720000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:36:58.912        0     14.845294          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.620000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:00.514        0     18.937387          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.640000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:00.514        0     18.937387          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.880000 secondes
# GOLEM begins testing...
# Testing executed in = 0.700000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:04.057        0     20.086308          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.900000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:05.621        0     10.787196          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.710000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:05.896        0     11.511876          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.800000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:07.605        0        5.3736          0
#
#       Confiance Down   Actual
# 7950        0.000004  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.670000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:09.698        0     13.943848          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.640000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:10.449        0      13.02744          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.700000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:10.449        0      13.02744          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.710000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:13.801        0      13.02744          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.680000 secondes
# GOLEM begins testing...
# Testing executed in = 0.700000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:13.801        0      13.02744          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.700000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:16.424        0      13.02744          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.710000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:16.424        0      13.02744          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.730000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:16.424        0      13.02744          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.820000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:21.196        0      9.411325          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.700000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:22.731        0      5.336162          0
#
#       Confiance Down   Actual
# 7950        0.000003  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.650000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:23.445        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.800000 secondes
# GOLEM begins testing...
# Testing executed in = 0.710000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:23.445        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.750000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:26.409        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.650000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:26.409        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.640000 secondes
# GOLEM begins testing...
# Testing executed in = 0.680000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:29.108        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.740000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:30.124        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.690000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:30.124        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.670000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:30.124        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.770000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:30.124        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.830000 secondes
# GOLEM begins testing...
# Testing executed in = 0.700000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:35.540        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.960000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:36.702        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.670000 secondes
# GOLEM begins testing...
# Testing executed in = 0.680000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:36.702        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.720000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:36.702        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.700000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:36.702        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.720000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:36.702        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.700000 secondes
# GOLEM begins testing...
# Testing executed in = 0.680000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:36.702        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.820000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:36.702        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.890000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:47.749        0      9.547611          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.810000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:49.203        0     12.824172          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.650000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:50.632        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.700000 secondes
# GOLEM begins testing...
# Testing executed in = 0.700000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:51.096        0      9.428272          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.690000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:53.248        0     13.193295          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.650000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:53.974        0     20.297941          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.710000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:55.132        0     20.297941          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.810000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:56.910        0     20.297941          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.660000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:57.963        0     20.297941          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.630000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:37:59.231        0     20.297941          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.630000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:38:01.135        0     20.297941          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.800000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:38:02.664        0     13.193295          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.630000 secondes
# GOLEM begins testing...
# Testing executed in = 0.700000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:38:02.994        0     13.178132          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.670000 secondes
# GOLEM begins testing...
# Testing executed in = 0.690000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:38:05.450        0     13.178132          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.760000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:38:05.450        0     13.178132          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.700000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:38:07.554        0     20.297941          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.700000 secondes
# GOLEM begins testing...
# Testing executed in = 0.720000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:38:07.554        0     20.297941          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.680000 secondes
# GOLEM begins testing...
# Testing executed in = 0.700000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:38:10.496        0     20.297941          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.830000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:38:12.092        0     20.297941          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.880000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:38:12.092        0     20.297941          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.800000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:38:12.092        0     20.297941          0
#
#       Confiance Down   Actual
# 7950             0.0  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.770000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:38:16.568        0      5.336162          0
#
#       Confiance Down   Actual
# 7950        0.000003  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.730000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:38:18.740        0      5.354441          0
#
#       Confiance Down   Actual
# 7950        0.000004  2889.16
#
# Long Pos = 0
# Short Pos = 0
# ...
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.650000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:00.931        0      5.345282          0
#
#       Confiance Down   Actual
# 7950        0.000003  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.750000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:04.251        0      3.914898          0
#
#       Confiance Down   Actual
# 7950        0.000006  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.660000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:04.642        0      5.345282          0
#
#       Confiance Down   Actual
# 7950        0.000003  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.620000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:04.642        0      5.345282          0
#
#       Confiance Down   Actual
# 7950        0.000003  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.710000 secondes
# GOLEM begins testing...
# Testing executed in = 0.710000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:08.213        0      2.436417          0
#
#       Confiance Down   Actual
# 7950        0.000013  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.700000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:09.667        0      3.613867          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.770000 secondes
# GOLEM begins testing...
# Testing executed in = 0.630000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:09.667        0      3.613867          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.650000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:09.667        0      3.613867          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.770000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:13.375        0      3.613867          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.660000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:13.836        0      3.613867          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.640000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:16.242        0      1.989305          0
#
#       Confiance Down   Actual
# 7950        0.000018  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.620000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:17.745        0      3.088414          0
#
#       Confiance Down   Actual
# 7950        0.000009  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.840000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:19.126        0       3.09392          0
#
#       Confiance Down   Actual
# 7950        0.000009  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.820000 secondes
# GOLEM begins testing...
# Testing executed in = 0.710000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:20.615        0      3.620279          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.640000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:20.615        0      3.620279          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.680000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:23.129        0      3.620279          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.900000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:24.490        0      3.620279          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.770000 secondes
# GOLEM begins testing...
# Testing executed in = 0.700000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:24.490        0      3.620279          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.710000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:24.490        0      3.620279          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.650000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:28.871        0      3.620279          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.650000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:28.871        0      3.620279          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.690000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:28.871        0      3.620279          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.660000 secondes
# GOLEM begins testing...
# Testing executed in = 0.630000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:28.871        0      3.620279          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.660000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:34.064        0      3.646011          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.660000 secondes
# GOLEM begins testing...
# Testing executed in = 0.670000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:34.064        0      3.646011          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.870000 secondes
# GOLEM begins testing...
# Testing executed in = 0.640000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:36.683        0      3.620279          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.810000 secondes
# GOLEM begins testing...
# Testing executed in = 0.650000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:37.507        0      3.646011          0
#
#       Confiance Down   Actual
# 7950        0.000007  2889.16
#
# Long Pos = 0
# Short Pos = 0
# MAJ live in = 0.660000 secondes
# GOLEM begins testing...
# Testing executed in = 0.660000 secondes
# Resultats :
#
#
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:39.013        0       2.07233          0
#
#       Confiance Down   Actual
# 7950        0.000017  2889.16
#
# Long Pos = 0
# Short Pos = 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-1f9a421915dc> in <module>
#       7 for loop in range(0,2000):
#       8     tmps1=time.time()
# ----> 9     con.subscribe_market_data(ticker)
#      10     last = con.get_prices(ticker)
#      11     #while last.index[-1] == df.iloc[-1,0] and last.index[-1].hour == df.iloc[-1,0].hour and last.index[-1].minute == df.iloc[-1,0].minute \
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/fxcmpy/fxcmpy.py in subscribe_market_data(self, symbol, add_callbacks)
#     744         params = {'pairs': symbol}
#     745         data = self.__handle_request__(method='subscribe', params=params,
# --> 746                                        protocol='post')
#     747         if symbol not in self.prices:
#     748             data = data['pairs'][0]
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/fxcmpy/fxcmpy.py in __handle_request__(self, method, params, protocol)
#    2467             req = requests.post('%s:443/%s' % (self.trading_url, method),
#    2468                                 headers=self.request_headers, data=params,
# -> 2469                                 proxies=self.proxies)
#    2470             self.logger.info('Sending POST Request:')
#    2471             self.logger.info('URL: %s' % req.url)
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/api.py in post(url, data, json, **kwargs)
#     114     """
#     115
# --> 116     return request('post', url, data=data, json=json, **kwargs)
#     117
#     118
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     292     def recv_into(self, *args, **kwargs):
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#     296             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:

# %%
resultats.tail()
# Out:
#                         Date  Move Up  Confiance up  Move Down  \
# 7950 2019-06-17 12:39:39.013        0       2.07233          0
#
#       Confiance Down   Actual
# 7950        0.000017  2889.16

# %%
df.tail()
# Out:
#                         Date     Open     High     Low    Close
# 7995 2019-06-17 12:39:34.064  2891.80  2892.18  2900.3  2889.16
# 7996 2019-06-17 12:39:34.064  2891.80  2892.18  2900.3  2889.16
# 7997 2019-06-17 12:39:36.683  2891.80  2892.10  2900.3  2889.16
# 7998 2019-06-17 12:39:37.507  2891.80  2892.18  2900.3  2889.16
# 7999 2019-06-17 12:39:39.013  2891.66  2892.02  2900.3  2889.16

# %%
last.tail()
# Out:
#                              Bid      Ask    High      Low
# 2019-06-17 12:39:34.064  2891.80  2892.18  2900.3  2889.16
# 2019-06-17 12:39:36.683  2891.80  2892.10  2900.3  2889.16
# 2019-06-17 12:39:37.507  2891.80  2892.18  2900.3  2889.16
# 2019-06-17 12:39:38.742  2891.80  2892.18  2900.3  2889.16
# 2019-06-17 12:39:39.013  2891.66  2892.02  2900.3  2889.16

# %%
dataset_1D.tail()
# Out:
#                         Date  Varop_Spy  Varhl_spy  RSI  95 - RSI  RSI - 5  \
# 7995 2019-06-17 12:39:34.064       2.64      -8.12  0.0      95.0     -5.0
# 7996 2019-06-17 12:39:34.064       2.64      -8.12  0.0      95.0     -5.0
# 7997 2019-06-17 12:39:36.683       2.64      -8.20  0.0      95.0     -5.0
# 7998 2019-06-17 12:39:37.507       2.64      -8.12  0.0      95.0     -5.0
# 7999 2019-06-17 12:39:39.013       2.50      -8.28  0.0      95.0     -5.0
#
#       BBD_Delta_Up      delta5_8     delta8_10    delta10_12  ...  delta35_40  \
# 7995      0.000376 -9.549694e-12  9.094947e-13  5.911716e-12  ...         0.0
# 7996      0.000376 -9.549694e-12  9.094947e-13  5.911716e-12  ...         0.0
# 7997      0.000376 -9.549694e-12  9.094947e-13  5.911716e-12  ...         0.0
# 7998      0.000376 -9.549694e-12  9.094947e-13  5.911716e-12  ...         0.0
# 7999      0.000376 -9.549694e-12  9.094947e-13  5.911716e-12  ...         0.0
#
#         delta40_45    delta45_50  Peaks  Valley  delta_tsf  \
# 7995 -4.547474e-13 -4.547474e-12      0       0    2889.16
# 7996 -4.547474e-13 -4.547474e-12      0       0    2889.16
# 7997 -4.547474e-13 -4.547474e-12      0       0    2889.16
# 7998 -4.547474e-13 -4.547474e-12      0       0    2889.16
# 7999 -4.547474e-13 -4.547474e-12      1       0    2889.16
#
#       Forcast Oscillator  target_up  target_down  target_value
# 7995       -6.295911e-14          0            0       2889.16
# 7996       -6.295911e-14          0            0       2889.16
# 7997       -6.295911e-14          0            0       2889.16
# 7998       -6.295911e-14          0            0       2889.16
# 7999       -6.295911e-14          0            0       2889.16
#
# [5 rows x 23 columns]

# %%
dataset_1D.tail().isnull().sum()
# Out:
# Date                  0
# Varop_Spy             0
# Varhl_spy             0
# RSI                   0
# 95 - RSI              0
# RSI - 5               0
# BBD_Delta_Up          0
# delta5_8              0
# delta8_10             0
# delta10_12            0
# delta12_15            0
# delta15_30            0
# delta30_35            0
# delta35_40            0
# delta40_45            0
# delta45_50            0
# Peaks                 0
# Valley                0
# delta_tsf             0
# Forcast Oscillator    0
# target_up             0
# target_down           0
# target_value          0
# dtype: int64

# %%
last
# Out:
#                              Bid      Ask    High      Low
# 2019-06-17 12:34:53.161  2892.16  2892.68  2900.3  2889.16
# 2019-06-17 12:35:01.170  2892.40  2892.78  2900.3  2889.16
# 2019-06-17 12:36:00.205  2892.40  2892.78  2900.3  2889.16
# 2019-06-17 12:36:02.680  2892.66  2893.02  2900.3  2889.16
# 2019-06-17 12:36:03.651  2892.40  2893.02  2900.3  2889.16
# 2019-06-17 12:36:06.553  2892.40  2892.78  2900.3  2889.16
# 2019-06-17 12:36:09.082  2892.56  2892.85  2900.3  2889.16
# 2019-06-17 12:36:09.646  2892.40  2892.92  2900.3  2889.16
# 2019-06-17 12:36:10.066  2892.40  2892.78  2900.3  2889.16
# 2019-06-17 12:36:14.666  2892.40  2892.92  2900.3  2889.16
# 2019-06-17 12:36:15.020  2892.40  2892.85  2900.3  2889.16
# 2019-06-17 12:36:18.449  2892.56  2892.85  2900.3  2889.16
# 2019-06-17 12:36:19.667  2892.40  2892.85  2900.3  2889.16
# 2019-06-17 12:36:20.516  2892.40  2892.88  2900.3  2889.16
# 2019-06-17 12:36:21.988  2892.40  2892.82  2900.3  2889.16
# 2019-06-17 12:36:23.917  2892.40  2892.78  2900.3  2889.16
# 2019-06-17 12:36:24.668  2892.40  2892.88  2900.3  2889.16
# 2019-06-17 12:36:26.626  2892.40  2892.85  2900.3  2889.16
# 2019-06-17 12:36:26.992  2892.56  2892.85  2900.3  2889.16
# 2019-06-17 12:36:28.717  2892.16  2892.90  2900.3  2889.16
# 2019-06-17 12:36:29.679  2892.30  2892.60  2900.3  2889.16
# 2019-06-17 12:36:58.670  2891.90  2892.68  2900.3  2889.16
# 2019-06-17 12:36:58.912  2892.20  2892.68  2900.3  2889.16
# 2019-06-17 12:37:00.514  2892.28  2892.68  2900.3  2889.16
# 2019-06-17 12:37:04.057  2892.30  2892.68  2900.3  2889.16
# 2019-06-17 12:37:05.621  2892.10  2892.68  2900.3  2889.16
# 2019-06-17 12:37:05.896  2892.12  2892.68  2900.3  2889.16
# 2019-06-17 12:37:07.605  2891.90  2892.68  2900.3  2889.16
# 2019-06-17 12:37:09.698  2892.18  2892.68  2900.3  2889.16
# 2019-06-17 12:37:10.449  2892.16  2892.52  2900.3  2889.16
# ...                          ...      ...     ...      ...
# 2019-06-17 12:39:04.251  2891.82  2892.28  2900.3  2889.16
# 2019-06-17 12:39:04.642  2891.90  2892.28  2900.3  2889.16
# 2019-06-17 12:39:07.200  2891.90  2892.20  2900.3  2889.16
# 2019-06-17 12:39:07.644  2891.90  2892.20  2900.3  2889.16
# 2019-06-17 12:39:08.213  2891.70  2892.10  2900.3  2889.16
# 2019-06-17 12:39:08.363  2891.70  2892.10  2900.3  2889.16
# 2019-06-17 12:39:09.667  2891.80  2892.10  2900.3  2889.16
# 2019-06-17 12:39:12.813  2891.80  2892.10  2900.3  2889.16
# 2019-06-17 12:39:13.375  2891.80  2892.10  2900.3  2889.16
# 2019-06-17 12:39:13.836  2891.80  2892.10  2900.3  2889.16
# 2019-06-17 12:39:15.667  2891.70  2892.08  2900.3  2889.16
# 2019-06-17 12:39:16.242  2891.65  2892.08  2900.3  2889.16
# 2019-06-17 12:39:16.413  2891.70  2892.08  2900.3  2889.16
# 2019-06-17 12:39:16.924  2891.80  2892.10  2900.3  2889.16
# 2019-06-17 12:39:17.745  2891.76  2892.08  2900.3  2889.16
# 2019-06-17 12:39:19.126  2891.76  2892.10  2900.3  2889.16
# 2019-06-17 12:39:19.518  2891.80  2892.10  2900.3  2889.16
# 2019-06-17 12:39:20.183  2891.65  2892.06  2900.3  2889.16
# 2019-06-17 12:39:20.615  2891.80  2892.10  2900.3  2889.16
# 2019-06-17 12:39:23.129  2891.80  2892.10  2900.3  2889.16
# 2019-06-17 12:39:23.451  2891.80  2892.10  2900.3  2889.16
# 2019-06-17 12:39:24.490  2891.80  2892.10  2900.3  2889.16
# 2019-06-17 12:39:28.174  2891.80  2892.12  2900.3  2889.16
# 2019-06-17 12:39:28.711  2891.70  2892.12  2900.3  2889.16
# 2019-06-17 12:39:28.871  2891.80  2892.10  2900.3  2889.16
# 2019-06-17 12:39:34.064  2891.80  2892.18  2900.3  2889.16
# 2019-06-17 12:39:36.683  2891.80  2892.10  2900.3  2889.16
# 2019-06-17 12:39:37.507  2891.80  2892.18  2900.3  2889.16
# 2019-06-17 12:39:38.742  2891.80  2892.18  2900.3  2889.16
# 2019-06-17 12:39:39.013  2891.66  2892.02  2900.3  2889.16
#
# [152 rows x 4 columns]

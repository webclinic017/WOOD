# %%
___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor\n°OoO_FXCM_Oo0°\nLumberJack Jyss 5779(c)')
print('Version v2.01')
print('Importing librairies...')
import forexconnect
from forexconnect import fxcorepy
from forexconnect import ForexConnect, ResponseListener, Common
import time
import sys
import numpy as np
import pandas as pd
from colorama import Fore, Back, Style 
import datetime as dt
import talib
print('Librairies imported')
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)


def session_status_changed(session: fxcorepy.O2GSession,
                           status: fxcorepy.AO2GSessionStatus.O2GSessionStatus):
    print("Trading session status: " + str(status))
    return



pos_long = 0
pos_short = 0

# TOKEN = 'e053ac1597cef331df9429ac8151100ea9f1c411'
# server = 'demo'
user_id = 'D261151986'
password = '2786'
url = 'fxcorporate.com/Hosts.jsp'
accountid='01147539'
# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'
ticker = 'GER30'
period = 'm1'
number = 30
jet_lag = -2
amount = 30
buysell = None
side = None
trade_id = None
open_rate = None
open_time = None
offerid = None
buy_price = None
sell_price = None
pnl = None

# Time Windows
# start = dt.datetime(2017, 7, 15)
# stop = dt.datetime(2017, 8, 1)
# con.get_candles('EUR/USD', period='D1',start=start, stop=stop)

# CONNEXION

fx = ForexConnect()
fx.login(user_id, password, url,"Demo", session_status_callback=session_status_changed)
table_manager = fx.table_manager
trades_table = table_manager.get_table(fx.TRADES)

# RECOVERING TEST
for row in trades_table:
    trade =None
    side = row['buy_sell']
    pnl = row['pl']
    trade_id = row['trade_id']
    open_rate = row['open_rate']
    should_close = row['close']
    amount = row['amount']
if side == 'B':
    pos_long = 1
elif side == 'S':
    pos_short = 1

# RECCUPERATION DES 30 DERNIERES DONNEES
tmps1=time.time()
history = fx.get_history(ticker, period,quotes_count=number)
data = pd.DataFrame({'Date':history['Date'],'Open':history['BidOpen'],'High':history['BidHigh'],'Low':history['BidLow'],'Close':history['BidClose']})
df = data.copy()
tmps2=round(time.time()-tmps1,2)
print('Data scraped in ',tmps2,' seconds')

print('\033[33m' + 'Initializing GOLEM...')
print('\033[35m' +'Long Pos =',pos_long)
print('Short Pos =',pos_short,Style.RESET_ALL)

# DATA PREPARATION

tmps1=time.time()
print('df.shape control : ',df.shape)
df.reset_index(inplace=True,drop=True)
dataset_1D = df.copy()
dataset_1D = dataset_1D.dropna()
rsi = talib.RSI(dataset_1D['Close'],timeperiod=2)
aroondown, aroonup = talib.AROON(dataset_1D['High'], dataset_1D['Low'], timeperiod=25)
aroondelta = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
dataset_1D['RSI'] = rsi
dataset_1D['Aroon Up'] = aroonup
dataset_1D['Aroon Down'] = aroondown
dataset_1D['Delta Aroon'] = aroondelta

dataset_1D['target_value'] = dataset_1D['Close']
dataset_1D = dataset_1D.drop(['Open','High','Low','Close'],axis=1)
df_1D = dataset_1D.copy()
df_1D = df_1D.iloc[:,1:]
df_1D['Date'] = df['Date']
df_1D = df_1D.dropna()
df_1D = df_1D[['Date'] + df_1D.columns[:-1].tolist()]
df_1D.reset_index(inplace=True,drop=True)
tmps2=round(time.time()-tmps1,2)
print('Data prepared in ',tmps2,' seconds')

print('\033[36m'+'GOLEM begins Computing...'+Style.RESET_ALL)


print('Computing done')
print('Instrument :', ticker)
print(df_1D.tail())

print('\n Initializing GOLEM on STREAMING LIVE...\n')

# UPDATING DATA
for loop in range(0,200000):
    #print(' \n INFRA LOOP ',loop,'\n')
    tmps1=time.time()

    history = fx.get_history(ticker, period,quotes_count=1)
    last = pd.DataFrame({'Date':history['Date'],'Open':history['BidOpen'],'High':history['BidHigh'],'Low':history['BidLow'],'Close':history['BidClose']})
    
    if last.iloc[-1,0].minute == df.iloc[-1,0].minute :
    
        print('\r \033[43m '+period+' \033[0m'+'\033[46m'+'...'+'\033[0m',end='')
        print ('\033[36m', dt.datetime.now().hour,'H',dt.datetime.now().minute,'min',dt.datetime.now().second,'sec',Style.RESET_ALL,end='')
        if pos_long == 1:
            try:
                if pnl > 0 :
                    print('\033[42m  - pnl : ',round(pnl,2),'\033[0m',end='', flush=True)
                elif pnl < 0:
                    print('\033[41m  - pnl : ',round(pnl,2),'\033[0m',end='', flush=True)
            except:
                pass
        elif pos_short == 1:
            try:
                if pnl > 0 :
                    print('\033[42m  - pnl : ',round(pnl,2),'\033[0m',end='', flush=True)
                elif pnl < 0:
                    print('\033[41m  - pnl : ',round(pnl,2),'\033[0m',end='', flush=True)
            except:
                pass
        else:
            print(' - No position',end='',flush=True)
        time.sleep(0.1)
    else :
        tmps1=time.time()
        df = df.iloc[1:,:]
        df = df.append({'Date':last.iloc[-1,0],'Open':last.iloc[-1,1], 'High':last.iloc[-1,2],'Low':last.iloc[-1,3], 'Close':last.iloc[-1,4]}, ignore_index=True)

        print('df.shape control : ',df.shape)
        df.reset_index(inplace=True,drop=True)
        dataset_1D = df.copy()
        dataset_1D = dataset_1D.dropna()
        rsi = talib.RSI(dataset_1D['Close'],timeperiod=2)
        aroondown, aroonup = talib.AROON(dataset_1D['High'], dataset_1D['Low'], timeperiod=25)
        atr = talib.ATR(dataset_1D['High'],dataset_1D['Low'],dataset_1D['Close'],timeperiod=14)
        aroondelta = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
        dataset_1D['RSI'] = rsi
        dataset_1D['Aroon Up'] = aroonup
        dataset_1D['Aroon Down'] = aroondown
        dataset_1D['Delta Aroon'] = aroondelta
        dataset_1D['target_value'] = dataset_1D['Close']
        dataset_1D = dataset_1D.drop(['Open','High','Low','Close'],axis=1)
        df_1D = dataset_1D.copy()
        df_1D = df_1D.iloc[:,1:]
        df_1D['Date'] = df['Date']
        df_1D = df_1D.dropna()
        df_1D = df_1D[['Date'] + df_1D.columns[:-1].tolist()]
        df_1D.reset_index(inplace=True,drop=True)
        
        
        print()
        print('\r GOLEM begins testing...',end='')
        print('   Aroon up :',aroonup.iloc[-1],end='')
        print('   Aroon down : ',aroondown.iloc[-1],end='')
        print('   RSI : ',rsi.iloc[-1],end='')
        print ('\033[36m    ', dt.datetime.now().hour,'H',dt.datetime.now().minute,'min',dt.datetime.now().second,'sec',Style.RESET_ALL,end='')
        
        if aroonup.iloc[-1] < 4 and aroondown.iloc[-1] > 97  and rsi.iloc[-1] < 10:

            if  pos_long == 0 and pos_short == 1 :
                
                buysell = 'B'
                try:
                    for row in trades_table:
                        trade =None
                        side = row['buy_sell']
                        pnl = row['pl']
                        trade_id = row['trade_id']
                        open_rate = row['open_rate']
                        should_close = row['close']
                        amount = row['amount']

                    trade_rate = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) + (4*float(atr.iloc[-1]))
                    request_close = fx.create_order_request(order_type='CM',
                                                                            ACCOUNT_ID=accountid,
                                                                            OFFER_ID = offerid,
                                                                            BUY_SELL=buysell,
                                                                            AMOUNT=amount,
                                                                            TIME_IN_FORCE='IOC',
                                                                            TRADE_ID = trade_id)
                    resp_close = fx.send_request(request_close)

                    closed_table = table_manager.get_table(fx.CLOSED_TRADES)
                    for row in closed_table:
                        trade =None
                        side = row['buy_sell']
                        pnl = row['pl']
                        trade_id = row['trade_id']
                        open_rate = row['open_rate']
                        amount = row['amount']
                        open_time = row['open_time']
                        close_rate = row['close_rate']
                        close_time = row['close_time']

                    print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')
                    print('Résumé : ')
                    print(' Open date : ', open_time)
                    print('Open Rate : ',open_rate)
                    print('Amount : ',amount)
                    print('Close date : ',close_time)
                    print('Close Rate : ',close_rate)
                    print('')
                    pos_short = 0
                    continue
                except:
                    print("WARNING! It wasn't possible to close the position" )
                    pass

            if pos_long == 0 and pos_short == 0:
                
                buysell = 'B'
                trade_rate = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) + (4*float(atr.iloc[-1]))
                print('Trying Long at :',trade_rate)
                try:
                    request_open = fx.create_order_request(\
                        SYMBOL=ticker,\
                        order_type='OM',\
                        ACCOUNT_ID=accountid,\
                        BUY_SELL=buysell,\
                        AMOUNT=amount,\
                        TIME_IN_FORCE='IOC'\
                        )
                    resp_open = fx.send_request(request_open)
                    order_id = resp_open.order_id
                    offer = Common.get_offer(fx,ticker)
                    offerid = offer.offer_id
                    table_manager = fx.table_manager
                    trades_table = table_manager.get_table(fx.TRADES)
                    for row in trades_table:
                        trade =None
                        side = row['buy_sell']
                        pnl = row['pl']
                        trade_id = row['trade_id']
                        open_rate = row['open_rate']
                        should_close = row['close']
                        amount = row['amount']
                    print('Side',side,'pnl : ',pnl,'Trade_ID : ',trade_id,'Open_Rate',open_rate,'Amount',amount)

                    print('Résumé : ')
                    print(' Open date : ', open_time)
                    print('Open Rate : ',open_rate)
                    print('Amount : ',amount)
                    print('pnl : ',pnl)
                    print('')
                    print(                                                    'Go Long!')
                    pos_long = 1
                    
                except:
                    print("It wasn't possible to long... What a good opportunity missed... Meoow yells the black cat")
                    pass

        elif aroondown.iloc[-1] < 4 and aroonup.iloc[-1] > 97  and rsi.iloc[-1] > 90:
            
            if  pos_long == 1 and pos_short == 0 :
                
                buysell = 'S'
                try:
                    for row in trades_table:
                        trade =None
                        side = row['buy_sell']
                        pnl = row['pl']
                        trade_id = row['trade_id']
                        open_rate = row['open_rate']
                        should_close = row['close']
                        amount = row['amount']
                    trade_rate = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) + (4*float(atr.iloc[-1]))
                    request_close = fx.create_order_request(order_type='CM',
                                                                            ACCOUNT_ID=accountid,
                                                                            OFFER_ID = offerid,
                                                                            BUY_SELL=buysell,
                                                                            AMOUNT=amount,
                                                                            TIME_IN_FORCE='IOC',
                                                                            TRADE_ID = trade_id)
                    resp_close = fx.send_request(request_close)

                    closed_table = table_manager.get_table(fx.CLOSED_TRADES)
                    for row in closed_table:
                        trade =None
                        side = row['buy_sell']
                        pnl = row['pl']
                        trade_id = row['trade_id']
                        open_rate = row['open_rate']
                        amount = row['amount']
                        open_time = row['open_time']
                        close_rate = row['close_rate']
                        close_time = row['close_time']

                    print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')
                    print('Résumé : ')
                    print(' Open date : ', open_time)
                    print('Open Rate : ',open_rate)
                    print('Amount : ',amount)
                    print('Close date : ',close_time)
                    print('Close Rate : ',close_rate)
                    print('')
                    pos_long = 0
                    continue
                except:
                    print("WARNING! It wasn't possible to close the position" )
                    continue

            if pos_long == 0 and pos_short == 0:
                
                buysell = 'S'
                trade_rate = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) - (4*float(atr.iloc[-1]))
                print('Trying short at : ',trade_rate)
                try:
                    request_open = fx.create_order_request(\
                        SYMBOL=ticker,\
                        order_type='OM',\
                        ACCOUNT_ID=accountid,\
                        BUY_SELL=buysell,\
                        AMOUNT=amount,\
                        TIME_IN_FORCE='IOC'\
                        )
                    resp_open = fx.send_request(request_open)
                    order_id = resp_open.order_id
                    offer = Common.get_offer(fx,ticker)
                    offerid = offer.offer_id
                    table_manager = fx.table_manager
                    trades_table = table_manager.get_table(fx.TRADES)
                    for row in trades_table:
                        trade =None
                        side = row['buy_sell']
                        pnl = row['pl']
                        trade_id = row['trade_id']
                        open_rate = row['open_rate']
                        should_close = row['close']
                        amount = row['amount']
                    print('Side',side,'pnl : ',pnl,'Trade_ID : ',trade_id,'Open_Rate',open_rate,'Amount',amount)

                    print('Résumé : ')
                    print(' Open date : ', open_time)
                    print('Open Rate : ',open_rate)
                    print('Amount : ',amount)
                    print('pnl : ',pnl)
                    print('')
                    print(                                                    'Go Short!')
                    pos_short = 1
                except:
                    print("It wasn't possible to short. You missed a great opportunity!")
                    pass
        else:
            print('No signal at the moment')
# Out:
# Global Optimized LumberJack Environment Motor
# °OoO_FXCM_Oo0°
# LumberJack Jyss 5779(c)
# Version v2.01
# Importing librairies...
# Librairies imported
# Trading session status: CONNECTING
# Trading session status: CONNECTED
# Data scraped in  0.2  seconds
# Initializing GOLEM...
# Long Pos = 0
# Short Pos = 1
# df.shape control :  (30, 5)
# Data prepared in  0.03  seconds
# GOLEM begins Computing...
# Computing done
# Instrument : GER30
#                  Date        RSI  Aroon Up  Aroon Down  Delta Aroon  \
# 0 2019-07-04 12:18:00  14.781069      80.0         0.0         80.0
# 1 2019-07-04 12:19:00  24.880180      76.0         0.0         76.0
# 2 2019-07-04 12:20:00  54.522258      72.0         8.0         64.0
# 3 2019-07-04 12:21:00  46.230283      68.0         4.0         64.0
# 4 2019-07-04 12:22:00  93.750767      64.0         0.0         64.0
#
#    target_value
# 0      12620.30
# 1      12620.46
# 2      12620.90
# 3      12620.80
# 4      12623.30
#
#  Initializing GOLEM on STREAMING LIVE...
#
#   m1 ... 5 H 23 min 1 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 60.0   Aroon down :  16.0   RSI :  58.55876740875752     5 H 23 min 1 sec No signal at the moment
#   m1 ... 5 H 24 min 1 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  12.0   RSI :  84.26680304367049     5 H 24 min 1 sec No signal at the moment
#   m1 ... 5 H 25 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 96.0   Aroon down :  8.0   RSI :  51.05444109137082     5 H 25 min 0 sec No signal at the moment
#   m1 ... 5 H 26 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  4.0   RSI :  79.23500870482484     5 H 26 min 0 sec No signal at the moment
#   m1 ... 5 H 27 min 5 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 96.0   Aroon down :  0.0   RSI :  40.458233743100585     5 H 27 min 5 sec No signal at the moment
#   m1 ... 5 H 28 min 2 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 92.0   Aroon down :  64.0   RSI :  50.26432259581548     5 H 28 min 3 sec No signal at the moment
#   m1 ... 5 H 29 min 3 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 88.0   Aroon down :  60.0   RSI :  62.587461051393646     5 H 29 min 3 sec No signal at the moment
#   m1 ... 5 H 30 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 84.0   Aroon down :  56.0   RSI :  62.587461159925     5 H 30 min 0 sec No signal at the moment
#   m1 ... 5 H 31 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 80.0   Aroon down :  52.0   RSI :  86.13843201412318     5 H 31 min 1 sec No signal at the moment
#   m1 ... 5 H 32 min 15 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 76.0   Aroon down :  48.0   RSI :  19.768755620717563     5 H 32 min 16 sec No signal at the moment
#   m1 ... 5 H 33 min 18 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 72.0   Aroon down :  44.0   RSI :  12.52871991401974     5 H 33 min 19 sec No signal at the moment
#   m1 ... 5 H 33 min 59 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 68.0   Aroon down :  40.0   RSI :  1.9616813738898855     5 H 34 min 0 sec No signal at the moment
#   m1 ... 5 H 35 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 64.0   Aroon down :  36.0   RSI :  54.737234507699405     5 H 35 min 0 sec No signal at the moment
#   m1 ... 5 H 36 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 60.0   Aroon down :  32.0   RSI :  46.70075849887614     5 H 36 min 0 sec No signal at the moment
#   m1 ... 5 H 37 min 3 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 56.0   Aroon down :  28.0   RSI :  22.087839089250817     5 H 37 min 4 sec No signal at the moment
#   m1 ... 5 H 37 min 59 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 52.0   Aroon down :  24.0   RSI :  38.337086239521156     5 H 38 min 0 sec No signal at the moment
#   m1 ... 5 H 39 min 4 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 48.0   Aroon down :  100.0   RSI :  13.457070605068482     5 H 39 min 4 sec No signal at the moment
#   m1 ... 5 H 40 min 1 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 44.0   Aroon down :  96.0   RSI :  67.87186463941123     5 H 40 min 1 sec No signal at the moment
#   m1 ... 5 H 40 min 59 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 40.0   Aroon down :  92.0   RSI :  82.92364831410661     5 H 41 min 0 sec No signal at the moment
#   m1 ... 5 H 42 min 7 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 36.0   Aroon down :  88.0   RSI :  86.987743031106     5 H 42 min 7 sec No signal at the moment
#   m1 ... 5 H 43 min 3 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 32.0   Aroon down :  84.0   RSI :  91.18405368364346     5 H 43 min 4 sec No signal at the moment
#   m1 ... 5 H 44 min 7 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 28.0   Aroon down :  80.0   RSI :  91.184053315571     5 H 44 min 8 sec No signal at the moment
#   m1 ... 5 H 45 min 1 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 24.0   Aroon down :  76.0   RSI :  39.8191235031314     5 H 45 min 2 sec No signal at the moment
#   m1 ... 5 H 46 min 4 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 20.0   Aroon down :  72.0   RSI :  7.231315969374724     5 H 46 min 5 sec No signal at the moment
#   m1 ... 5 H 47 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 16.0   Aroon down :  68.0   RSI :  3.2462452856153443     5 H 47 min 0 sec No signal at the moment
#   m1 ... 5 H 48 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 12.0   Aroon down :  64.0   RSI :  2.336380528750543     5 H 48 min 1 sec No signal at the moment
#   m1 ... 5 H 48 min 59 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 8.0   Aroon down :  100.0   RSI :  1.1532335103125317     5 H 49 min 0 sec No signal at the moment
#   m1 ... 5 H 49 min 59 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  96.0   RSI :  68.10052250314149     5 H 50 min 0 sec No signal at the moment
#   m1 ... 5 H 51 min 15 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  92.0   RSI :  38.80850031762812     5 H 51 min 15 sec No signal at the moment
#   m1 ... 5 H 52 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 16.0   Aroon down :  88.0   RSI :  50.881294240557075     5 H 52 min 1 sec No signal at the moment
#   m1 ... 5 H 52 min 59 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 12.0   Aroon down :  84.0   RSI :  39.26198694604198     5 H 53 min 0 sec No signal at the moment
#   m1 ... 5 H 54 min 2 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 8.0   Aroon down :  80.0   RSI :  39.261987935111584     5 H 54 min 3 sec No signal at the moment
#   m1 ... 5 H 55 min 6 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  76.0   RSI :  68.25723386032672     5 H 55 min 6 sec No signal at the moment
#   m1 ... 5 H 56 min 7 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  72.0   RSI :  92.11050339243413     5 H 56 min 8 sec No signal at the moment
#   m1 ... 5 H 57 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 48.0   Aroon down :  68.0   RSI :  27.30804869557967     5 H 57 min 0 sec No signal at the moment
#   m1 ... 5 H 58 min 1 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 44.0   Aroon down :  64.0   RSI :  30.564700622219487     5 H 58 min 1 sec No signal at the moment
#   m1 ... 5 H 59 min 3 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 40.0   Aroon down :  100.0   RSI :  5.465718109217353     5 H 59 min 4 sec No signal at the moment
#   m1 ... 6 H 0 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 36.0   Aroon down :  100.0   RSI :  2.8930271552590368     6 H 0 min 0 sec No signal at the moment
#   m1 ... 6 H 0 min 59 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 32.0   Aroon down :  96.0   RSI :  75.8394587232909     6 H 1 min 0 sec No signal at the moment
#   m1 ... 6 H 2 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 28.0   Aroon down :  92.0   RSI :  90.2794525628273     6 H 2 min 1 sec No signal at the moment
#   m1 ... 6 H 3 min 2 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 24.0   Aroon down :  88.0   RSI :  76.73014677852045     6 H 3 min 3 sec No signal at the moment
#   m1 ... 6 H 4 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 20.0   Aroon down :  84.0   RSI :  76.73014659207576     6 H 4 min 1 sec No signal at the moment
#   m1 ... 6 H 5 min 1 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 16.0   Aroon down :  80.0   RSI :  90.65195020074172     6 H 5 min 2 sec No signal at the moment
#   m1 ... 6 H 6 min 1 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  76.0   RSI :  81.57235717456466     6 H 6 min 1 sec No signal at the moment
#   m1 ... 6 H 7 min 3 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 96.0   Aroon down :  72.0   RSI :  50.426576608800765     6 H 7 min 3 sec No signal at the moment
#   m1 ... 6 H 8 min 2 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 92.0   Aroon down :  68.0   RSI :  66.84786560160326     6 H 8 min 2 sec No signal at the moment
#   m1 ... 6 H 9 min 12 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 88.0   Aroon down :  64.0   RSI :  40.2091529249122     6 H 9 min 13 sec No signal at the moment
#   m1 ... 6 H 9 min 59 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 84.0   Aroon down :  60.0   RSI :  14.226040165526546     6 H 10 min 0 sec No signal at the moment
#   m1 ... 6 H 10 min 59 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 80.0   Aroon down :  56.0   RSI :  55.242786317818094     6 H 11 min 0 sec No signal at the moment
#   m1 ... 6 H 12 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 76.0   Aroon down :  52.0   RSI :  8.507894337182535     6 H 12 min 0 sec No signal at the moment
#   m1 ... 6 H 13 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 72.0   Aroon down :  48.0   RSI :  63.227199606192286     6 H 13 min 0 sec No signal at the moment
#   m1 ... 6 H 14 min 3 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 68.0   Aroon down :  44.0   RSI :  42.3826070337174     6 H 14 min 4 sec No signal at the moment
#   m1 ... 6 H 15 min 4 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 64.0   Aroon down :  40.0   RSI :  71.3258329837839     6 H 15 min 4 sec No signal at the moment
#   m1 ... 6 H 16 min 1 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 60.0   Aroon down :  36.0   RSI :  79.47456591527899     6 H 16 min 2 sec No signal at the moment
#   m1 ... 6 H 17 min 1 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 56.0   Aroon down :  32.0   RSI :  55.60868255805117     6 H 17 min 2 sec No signal at the moment
#   m1 ... 6 H 18 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 52.0   Aroon down :  28.0   RSI :  27.493267159888816     6 H 18 min 0 sec No signal at the moment
#   m1 ... 6 H 19 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 48.0   Aroon down :  24.0   RSI :  63.063984967053386     6 H 19 min 0 sec No signal at the moment
#   m1 ... 6 H 20 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 100.0   Aroon down :  20.0   RSI :  79.67915579159674     6 H 20 min 1 sec No signal at the moment
#   m1 ... 6 H 21 min 10 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 96.0   Aroon down :  16.0   RSI :  67.52844907645826     6 H 21 min 10 sec No signal at the moment
#   m1 ... 6 H 22 min 0 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 92.0   Aroon down :  12.0   RSI :  18.032025287235804     6 H 22 min 1 sec No signal at the moment
#   m1 ... 6 H 23 min 2 sec   - pnl :  -3.66 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 88.0   Aroon down :  8.0   RSI :  15.506317097738497     6 H 23 min 3 sec No signal at the moment
#   m1 ... 6 H 23 min 55 sec   - pnl :  -3.66

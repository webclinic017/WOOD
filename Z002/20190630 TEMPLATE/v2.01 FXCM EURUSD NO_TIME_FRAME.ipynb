# %%
___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor\n°OoO_FXCM_Oo0°\nLumberJack Jyss 5779(c)')
print('Version v2.00')
print('Importing librairies...')
import forexconnect
from forexconnect import fxcorepy
from forexconnect import ForexConnect, ResponseListener, Common
import time
import sys
import numpy as np
import pandas as pd
from colorama import Fore, Back, Style 
import datetime as dt
import talib
print('Librairies imported')
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)


def session_status_changed(session: fxcorepy.O2GSession,
                           status: fxcorepy.AO2GSessionStatus.O2GSessionStatus):
    print("Trading session status: " + str(status))
    return



pos_long = 0
pos_short = 0

# TOKEN = 'e053ac1597cef331df9429ac8151100ea9f1c411'
# server = 'demo'
user_id = 'D261151986'
password = '2786'
url = 'fxcorporate.com/Hosts.jsp'
accountid='01147539'
# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'
ticker = 'EUR/USD'
period = 'm1'
number = 30
jet_lag = -2
amount = 30
buysell = None
side = None
trade_id = None
open_rate = None
open_time = None
offerid = None
buy_price = None
sell_price = None
pnl = None

# Time Windows
# start = dt.datetime(2017, 7, 15)
# stop = dt.datetime(2017, 8, 1)
# con.get_candles('EUR/USD', period='D1',start=start, stop=stop)

# CONNEXION

fx = ForexConnect()
fx.login(user_id, password, url,"Demo", session_status_callback=session_status_changed)
table_manager = fx.table_manager
trades_table = table_manager.get_table(fx.TRADES)

# RECOVERING TEST
for row in trades_table:
    trade =None
    side = row['buy_sell']
    pnl = row['pl']
    trade_id = row['trade_id']
    open_rate = row['open_rate']
    should_close = row['close']
    amount = row['amount']
if side == 'B':
    pos_long = 1
elif side == 'S':
    pos_short = 1

# RECCUPERATION DES 30 DERNIERES DONNEES
tmps1=time.time()
history = fx.get_history(ticker, period,quotes_count=number)
data = pd.DataFrame({'Date':history['Date'],'Open':history['BidOpen'],'High':history['BidHigh'],'Low':history['BidLow'],'Close':history['BidClose']})
df = data.copy()
tmps2=round(time.time()-tmps1,2)
print('Data scraped in ',tmps2,' seconds')

print('\033[33m' + 'Initializing GOLEM...')
print('\033[35m' +'Long Pos =',pos_long)
print('Short Pos =',pos_short,Style.RESET_ALL)

# DATA PREPARATION

tmps1=time.time()
print('df.shape control : ',df.shape)
df.reset_index(inplace=True,drop=True)
dataset_1D = df.copy()
dataset_1D = dataset_1D.dropna()
rsi = talib.RSI(dataset_1D['Close'],timeperiod=2)
aroondown, aroonup = talib.AROON(dataset_1D['High'], dataset_1D['Low'], timeperiod=25)
aroondelta = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
dataset_1D['RSI'] = rsi
dataset_1D['Aroon Up'] = aroonup
dataset_1D['Aroon Down'] = aroondown
dataset_1D['Delta Aroon'] = aroondelta

dataset_1D['target_value'] = dataset_1D['Close']
dataset_1D = dataset_1D.drop(['Open','High','Low','Close'],axis=1)
df_1D = dataset_1D.copy()
df_1D = df_1D.iloc[:,1:]
df_1D['Date'] = df['Date']
df_1D = df_1D.dropna()
df_1D = df_1D[['Date'] + df_1D.columns[:-1].tolist()]
df_1D.reset_index(inplace=True,drop=True)
tmps2=round(time.time()-tmps1,2)
print('Data prepared in ',tmps2,' seconds')

print('\033[36m'+'GOLEM begins Computing...'+Style.RESET_ALL)


print('Computing done')
print('Instrument :', ticker)
print(df_1D.tail())

print('\n Initializing GOLEM on STREAMING LIVE...\n')

# UPDATING DATA
for loop in range(0,200000):
    #print(' \n INFRA LOOP ',loop,'\n')
    tmps1=time.time()

    history = fx.get_history(ticker, period,quotes_count=1)
    last = pd.DataFrame({'Date':history['Date'],'Open':history['BidOpen'],'High':history['BidHigh'],'Low':history['BidLow'],'Close':history['BidClose']})
    
    if last.iloc[-1,0].minute == df.iloc[-1,0].minute :
    
        print('\r \033[43m '+period+' \033[0m'+'\033[46m'+'...'+'\033[0m',end='')
        print ('\033[36m', dt.datetime.now().hour,'H',dt.datetime.now().minute,'min',dt.datetime.now().second,'sec',Style.RESET_ALL,end='')
        if pos_long == 1:
            try:
                if pnl > 0 :
                    print('\033[42m  - pnl : ',round(pnl,2),'\033[0m',end='', flush=True)
                elif pnl < 0:
                    print('\033[41m  - pnl : ',round(pnl,2),'\033[0m',end='', flush=True)
            except:
                pass
        elif pos_short == 1:
            try:
                if pnl > 0 :
                    print('\033[42m  - pnl : ',round(pnl,2),'\033[0m',end='', flush=True)
                elif pnl < 0:
                    print('\033[41m  - pnl : ',round(pnl,2),'\033[0m',end='', flush=True)
            except:
                pass
        else:
            print(' - No position',end='',flush=True)
        time.sleep(0.1)
    else :
        tmps1=time.time()
        df = df.iloc[1:,:]
        df = df.append({'Date':last.iloc[-1,0],'Open':last.iloc[-1,1], 'High':last.iloc[-1,2],'Low':last.iloc[-1,3], 'Close':last.iloc[-1,4]}, ignore_index=True)

        print('df.shape control : ',df.shape)
        df.reset_index(inplace=True,drop=True)
        dataset_1D = df.copy()
        dataset_1D = dataset_1D.dropna()
        rsi = talib.RSI(dataset_1D['Close'],timeperiod=2)
        aroondown, aroonup = talib.AROON(dataset_1D['High'], dataset_1D['Low'], timeperiod=25)
        atr = talib.ATR(dataset_1D['High'],dataset_1D['Low'],dataset_1D['Close'],timeperiod=14)
        aroondelta = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
        dataset_1D['RSI'] = rsi
        dataset_1D['Aroon Up'] = aroonup
        dataset_1D['Aroon Down'] = aroondown
        dataset_1D['Delta Aroon'] = aroondelta
        dataset_1D['target_value'] = dataset_1D['Close']
        dataset_1D = dataset_1D.drop(['Open','High','Low','Close'],axis=1)
        df_1D = dataset_1D.copy()
        df_1D = df_1D.iloc[:,1:]
        df_1D['Date'] = df['Date']
        df_1D = df_1D.dropna()
        df_1D = df_1D[['Date'] + df_1D.columns[:-1].tolist()]
        df_1D.reset_index(inplace=True,drop=True)
        
        
        print()
        print('\r GOLEM begins testing...',end='')
        print('   Aroon up :',aroonup.iloc[-1],end='')
        print('   Aroon down : ',aroondown.iloc[-1],end='')
        print('   RSI : ',rsi.iloc[-1],end='')
        print ('\033[36m    ', dt.datetime.now().hour,'H',dt.datetime.now().minute,'min',dt.datetime.now().second,'sec',Style.RESET_ALL,end='')
        
        if aroonup.iloc[-1] < 4 and aroondown.iloc[-1] > 97  and rsi.iloc[-1] < 10:

            if  pos_long == 0 and pos_short == 1 :
                
                buysell = 'B'
                try:
                    for row in trades_table:
                        trade =None
                        side = row['buy_sell']
                        pnl = row['pl']
                        trade_id = row['trade_id']
                        open_rate = row['open_rate']
                        should_close = row['close']
                        amount = row['amount']

                    trade_rate = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) + (4*float(atr.iloc[-1]))
                    request_close = fx.create_order_request(order_type='CM',
                                                                            ACCOUNT_ID=accountid,
                                                                            OFFER_ID = offerid,
                                                                            BUY_SELL=buysell,
                                                                            AMOUNT=amount,
                                                                            TIME_IN_FORCE='IOC',
                                                                            TRADE_ID = trade_id)
                    resp_close = fx.send_request(request_close)

                    closed_table = table_manager.get_table(fx.CLOSED_TRADES)
                    for row in closed_table:
                        trade =None
                        side = row['buy_sell']
                        pnl = row['pl']
                        trade_id = row['trade_id']
                        open_rate = row['open_rate']
                        amount = row['amount']
                        open_time = row['open_time']
                        close_rate = row['close_rate']
                        close_time = row['close_time']

                    print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')
                    print('Résumé : ')
                    print(' Open date : ', open_time)
                    print('Open Rate : ',open_rate)
                    print('Amount : ',amount)
                    print('Close date : ',close_time)
                    print('Close Rate : ',close_rate)
                    print('')
                    pos_short = 0
                    continue
                except:
                    print("WARNING! It wasn't possible to close the position" )
                    pass

            if pos_long == 0 and pos_short == 0:
                
                buysell = 'B'
                trade_rate = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) + (4*float(atr.iloc[-1]))
                print('Trying Long at :',trade_rate)
                try:
                    request_open = fx.create_order_request(\
                        SYMBOL=ticker,\
                        order_type='OM',\
                        ACCOUNT_ID=accountid,\
                        BUY_SELL=buysell,\
                        AMOUNT=amount,\
                        TIME_IN_FORCE='IOC'\
                        )
                    resp_open = fx.send_request(request_open)
                    order_id = resp_open.order_id
                    offer = Common.get_offer(fx,ticker)
                    offerid = offer.offer_id
                    table_manager = fx.table_manager
                    trades_table = table_manager.get_table(fx.TRADES)
                    for row in trades_table:
                        trade =None
                        side = row['buy_sell']
                        pnl = row['pl']
                        trade_id = row['trade_id']
                        open_rate = row['open_rate']
                        should_close = row['close']
                        amount = row['amount']
                    print('Side',side,'pnl : ',pnl,'Trade_ID : ',trade_id,'Open_Rate',open_rate,'Amount',amount)

                    print('Résumé : ')
                    print(' Open date : ', open_time)
                    print('Open Rate : ',open_rate)
                    print('Amount : ',amount)
                    print('pnl : ',pnl)
                    print('')
                    print(                                                    'Go Long!')
                    pos_long = 1
                    
                except:
                    print("It wasn't possible to long... What a good opportunity missed... Meoow yells the black cat")
                    pass

        elif aroondown.iloc[-1] < 4 and aroonup.iloc[-1] > 97  and rsi.iloc[-1] > 90:
            
            if  pos_long == 1 and pos_short == 0 :
                
                buysell = 'S'
                try:
                    for row in trades_table:
                        trade =None
                        side = row['buy_sell']
                        pnl = row['pl']
                        trade_id = row['trade_id']
                        open_rate = row['open_rate']
                        should_close = row['close']
                        amount = row['amount']
                    trade_rate = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) + (4*float(atr.iloc[-1]))
                    request_close = fx.create_order_request(order_type='CM',
                                                                            ACCOUNT_ID=accountid,
                                                                            OFFER_ID = offerid,
                                                                            BUY_SELL=buysell,
                                                                            AMOUNT=amount,
                                                                            TIME_IN_FORCE='IOC',
                                                                            TRADE_ID = trade_id)
                    resp_close = fx.send_request(request_close)

                    closed_table = table_manager.get_table(fx.CLOSED_TRADES)
                    for row in closed_table:
                        trade =None
                        side = row['buy_sell']
                        pnl = row['pl']
                        trade_id = row['trade_id']
                        open_rate = row['open_rate']
                        amount = row['amount']
                        open_time = row['open_time']
                        close_rate = row['close_rate']
                        close_time = row['close_time']

                    print('\033[47m \033[31m Close Short avec un pnl de', pnl,'\033[0m')
                    print('Résumé : ')
                    print(' Open date : ', open_time)
                    print('Open Rate : ',open_rate)
                    print('Amount : ',amount)
                    print('Close date : ',close_time)
                    print('Close Rate : ',close_rate)
                    print('')
                    pos_long = 0
                    continue
                except:
                    print("WARNING! It wasn't possible to close the position" )
                    continue

            if pos_long == 0 and pos_short == 0:
                
                buysell = 'S'
                trade_rate = float(fx.get_history(ticker, 't1',quotes_count=1)['Bid'][0]) - (4*float(atr.iloc[-1]))
                print('Trying short at : ',trade_rate)
                try:
                    request_open = fx.create_order_request(\
                        SYMBOL=ticker,\
                        order_type='OM',\
                        ACCOUNT_ID=accountid,\
                        BUY_SELL=buysell,\
                        AMOUNT=amount,\
                        TIME_IN_FORCE='IOC'\
                        )
                    resp_open = fx.send_request(request_open)
                    order_id = resp_open.order_id
                    offer = Common.get_offer(fx,ticker)
                    offerid = offer.offer_id
                    table_manager = fx.table_manager
                    trades_table = table_manager.get_table(fx.TRADES)
                    for row in trades_table:
                        trade =None
                        side = row['buy_sell']
                        pnl = row['pl']
                        trade_id = row['trade_id']
                        open_rate = row['open_rate']
                        should_close = row['close']
                        amount = row['amount']
                    print('Side',side,'pnl : ',pnl,'Trade_ID : ',trade_id,'Open_Rate',open_rate,'Amount',amount)

                    print('Résumé : ')
                    print(' Open date : ', open_time)
                    print('Open Rate : ',open_rate)
                    print('Amount : ',amount)
                    print('pnl : ',pnl)
                    print('')
                    print(                                                    'Go Short!')
                    pos_short = 1
                except:
                    print("It wasn't possible to short. You missed a great opportunity!")
                    pass
        else:
            print('No signal at the moment')
# Out:
# Global Optimized LumberJack Environment Motor
# °OoO_FXCM_Oo0°
# LumberJack Jyss 5779(c)
# Version v2.00
# Importing librairies...
# Librairies imported
# Trading session status: CONNECTING
# Trading session status: CONNECTED
# Data scraped in  0.37  seconds
# Initializing GOLEM...
# Long Pos = 0
# Short Pos = 1
# df.shape control :  (30, 5)
# Data prepared in  0.04  seconds
# GOLEM begins Computing...
# Computing done
# Instrument : EUR/USD
#                  Date        RSI  Aroon Up  Aroon Down  Delta Aroon  \
# 0 2019-07-04 12:32:00  75.813472     100.0        64.0         36.0
# 1 2019-07-04 12:33:00  14.792851      96.0        60.0         36.0
# 2 2019-07-04 12:34:00  48.167765      92.0        56.0         36.0
# 3 2019-07-04 12:35:00  27.009210      88.0        52.0         36.0
# 4 2019-07-04 12:36:00  65.212163      84.0        48.0         36.0
#
#    target_value
# 0       1.12875
# 1       1.12865
# 2       1.12869
# 3       1.12865
# 4       1.12870
#
#  Initializing GOLEM on STREAMING LIVE...
#
#   m1 ... 5 H 37 min 0 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 80.0   Aroon down :  44.0   RSI :  65.21216349314702     5 H 37 min 0 sec No signal at the moment
#   m1 ... 5 H 38 min 2 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 76.0   Aroon down :  40.0   RSI :  45.965643435705054     5 H 38 min 3 sec No signal at the moment
#   m1 ... 5 H 39 min 0 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 72.0   Aroon down :  36.0   RSI :  66.0219823825824     5 H 39 min 0 sec No signal at the moment
#   m1 ... 5 H 40 min 0 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 68.0   Aroon down :  32.0   RSI :  80.49879631031264     5 H 40 min 0 sec No signal at the moment
#   m1 ... 5 H 41 min 1 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 64.0   Aroon down :  28.0   RSI :  18.259851513128204     5 H 41 min 1 sec No signal at the moment
#   m1 ... 5 H 42 min 5 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 60.0   Aroon down :  24.0   RSI :  3.476468515624729     5 H 42 min 5 sec No signal at the moment
#   m1 ... 5 H 43 min 0 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 56.0   Aroon down :  20.0   RSI :  3.47646840976343     5 H 43 min 0 sec No signal at the moment
#   m1 ... 5 H 44 min 2 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 52.0   Aroon down :  16.0   RSI :  55.67468772292876     5 H 44 min 3 sec No signal at the moment
#   m1 ... 5 H 45 min 0 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 48.0   Aroon down :  12.0   RSI :  26.746557227842516     5 H 45 min 1 sec No signal at the moment
#   m1 ... 5 H 45 min 59 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 44.0   Aroon down :  8.0   RSI :  64.07708559898882     5 H 46 min 0 sec No signal at the moment
#   m1 ... 5 H 47 min 4 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 40.0   Aroon down :  4.0   RSI :  51.06541727476669     5 H 47 min 4 sec No signal at the moment
#   m1 ... 5 H 48 min 0 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 36.0   Aroon down :  100.0   RSI :  12.01820938375142     5 H 48 min 1 sec No signal at the moment
#   m1 ... 5 H 49 min 0 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 32.0   Aroon down :  100.0   RSI :  6.810531560546076     5 H 49 min 0 sec No signal at the moment
#   m1 ... 5 H 50 min 0 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 28.0   Aroon down :  100.0   RSI :  5.597737914649484     5 H 50 min 0 sec No signal at the moment
#   m1 ... 5 H 51 min 0 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 24.0   Aroon down :  100.0   RSI :  4.127661753359181     5 H 51 min 0 sec No signal at the moment
#   m1 ... 5 H 52 min 0 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 20.0   Aroon down :  100.0   RSI :  0.7934886851303928     5 H 52 min 0 sec No signal at the moment
#   m1 ... 5 H 53 min 11 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 16.0   Aroon down :  96.0   RSI :  45.12195259486274     5 H 53 min 11 sec No signal at the moment
#   m1 ... 5 H 54 min 0 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 12.0   Aroon down :  92.0   RSI :  31.186764597903426     5 H 54 min 1 sec No signal at the moment
#   m1 ... 5 H 55 min 0 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 8.0   Aroon down :  100.0   RSI :  6.218894660765335     5 H 55 min 0 sec No signal at the moment
#   m1 ... 5 H 56 min 0 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  100.0   RSI :  16.50304572921106     5 H 56 min 0 sec No signal at the moment
#   m1 ... 5 H 56 min 59 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  96.0   RSI :  16.50304676599973     5 H 57 min 0 sec No signal at the moment
#   m1 ... 5 H 58 min 1 sec   - pnl :  -4.74 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  100.0   RSI :  8.79088859905102     5 H 58 min 1 sec WARNING! It wasn't possible to close the position
#   m1 ... 5 H 59 min 0 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  96.0   RSI :  37.83953982958899     5 H 59 min 0 sec No signal at the moment
#   m1 ... 6 H 0 min 4 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 20.0   Aroon down :  100.0   RSI :  9.04204953599021     6 H 0 min 4 sec No signal at the moment
#   m1 ... 6 H 0 min 59 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 16.0   Aroon down :  100.0   RSI :  0.39985004729823653     6 H 1 min 0 sec No signal at the moment
#   m1 ... 6 H 1 min 59 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 12.0   Aroon down :  96.0   RSI :  5.48895732187359     6 H 2 min 1 sec No signal at the moment
#   m1 ... 6 H 3 min 0 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 8.0   Aroon down :  92.0   RSI :  52.04462185767069     6 H 3 min 1 sec No signal at the moment
#   m1 ... 6 H 4 min 2 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  88.0   RSI :  66.1048855339963     6 H 4 min 3 sec No signal at the moment
#   m1 ... 6 H 5 min 0 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  84.0   RSI :  66.10488548771947     6 H 5 min 0 sec No signal at the moment
#   m1 ... 6 H 6 min 6 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  80.0   RSI :  70.4385203182717     6 H 6 min 6 sec No signal at the moment
#   m1 ... 6 H 7 min 2 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 20.0   Aroon down :  76.0   RSI :  25.247146441045803     6 H 7 min 2 sec No signal at the moment
#   m1 ... 6 H 8 min 0 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 16.0   Aroon down :  72.0   RSI :  14.566571770137882     6 H 8 min 0 sec No signal at the moment
#   m1 ... 6 H 8 min 59 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 12.0   Aroon down :  68.0   RSI :  4.675960277089594     6 H 9 min 0 sec No signal at the moment
#   m1 ... 6 H 9 min 59 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 8.0   Aroon down :  64.0   RSI :  16.07312521372177     6 H 10 min 0 sec No signal at the moment
#   m1 ... 6 H 11 min 0 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  60.0   RSI :  73.37448475629853     6 H 11 min 0 sec No signal at the moment
#   m1 ... 6 H 12 min 2 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  56.0   RSI :  79.57298110990334     6 H 12 min 3 sec No signal at the moment
#   m1 ... 6 H 13 min 0 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  52.0   RSI :  83.43042527785234     6 H 13 min 0 sec No signal at the moment
#   m1 ... 6 H 14 min 0 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  48.0   RSI :  17.465734336938958     6 H 14 min 0 sec No signal at the moment
#   m1 ... 6 H 15 min 8 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  44.0   RSI :  49.443768143567446     6 H 15 min 8 sec No signal at the moment
#   m1 ... 6 H 16 min 0 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  40.0   RSI :  18.021938075908917     6 H 16 min 0 sec No signal at the moment
#   m1 ... 6 H 17 min 3 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  100.0   RSI :  6.68796054639441     6 H 17 min 3 sec No signal at the moment
#   m1 ... 6 H 17 min 59 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  96.0   RSI :  34.253309420616205     6 H 18 min 0 sec No signal at the moment
#   m1 ... 6 H 19 min 3 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  92.0   RSI :  67.67515041659846     6 H 19 min 4 sec No signal at the moment
#   m1 ... 6 H 20 min 0 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 8.0   Aroon down :  88.0   RSI :  52.44178406885134     6 H 20 min 0 sec No signal at the moment
#   m1 ... 6 H 21 min 0 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  84.0   RSI :  31.30317851869003     6 H 21 min 0 sec No signal at the moment
#   m1 ... 6 H 21 min 59 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 0.0   Aroon down :  80.0   RSI :  66.89148469001228     6 H 22 min 0 sec No signal at the moment
#   m1 ... 6 H 23 min 1 sec   - pnl :  -1.55 df.shape control :  (30, 5)
#
#  GOLEM begins testing...   Aroon up : 4.0   Aroon down :  76.0   RSI :  20.08017842724084     6 H 23 min 1 sec No signal at the moment
#   m1 ... 6 H 24 min 0 sec   - pnl :  -1.55

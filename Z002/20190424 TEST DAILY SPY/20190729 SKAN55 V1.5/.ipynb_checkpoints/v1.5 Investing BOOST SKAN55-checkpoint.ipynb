# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
print('Importing Librairies...')
import talib
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import xgboost as xgb
from xgboost import XGBRegressor, plot_importance
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')
import time
import datetime as dt
import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
print('Librairies imported')
print('')

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print('BOOST SKAN 55 Version v1.33',Style.RESET_ALL)



print('')
print('Sraping tickers')
constituents = pd.read_csv('constituents_csv.csv')
print('Scrap -----> ok')
# PARAMETRES TEMPORELS INITIAUX
start = pd.to_datetime('2015-03-03')
end = pd.to_datetime('2019-07-21')

error = []
try :
    amorce = pd.read_csv('backtest.csv').index[-1] + 1
except:
    amorce = 0
    backtest = pd.DataFrame(columns = ['Symb.','Name','Sector','period','Begin.','End',\
                          'Pnl','%Pnl','Total Winners','Total Loosers','Nb Win','Nb Los',\
                          '% Winners','MaxDD','%MaxDD','Aver. Win',\
                          'Aver. Los','Aver. Duration',\
                          'Profit Factor'])

# SCRAPING DES DONNES BRUTES
def scrap_data(ticker,start,end):
    df = web.DataReader(ticker,'yahoo',start,end)
    df = df.drop(['Close'],axis=1)
    df['Close'] = df['Adj Close']
    df = df.drop(['Adj Close'],axis = 1)
    return(df)

def prepa_data(df):
    tmps1=time.time()
    print('Preparing data...')
    rsi = talib.RSI(df['Close'],timeperiod=14)
    stoc_slowk, stoc_slowd = talib.STOCH(df['High'],df['Low'],df['Close'])
    upper, middle, lower =  talib.BBANDS(df['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(df['Close'],timeperiod=5)
    sma8 = talib.SMA(df['Close'],timeperiod=8)
    sma10 = talib.SMA(df['Close'],timeperiod=10)
    sma12 = talib.SMA(df['Close'],timeperiod=12)
    sma15 = talib.SMA(df['Close'],timeperiod=15)
    sma30 = talib.SMA(df['Close'],timeperiod=30)
    sma35 = talib.SMA(df['Close'],timeperiod=35)
    sma40 = talib.SMA(df['Close'],timeperiod=40)
    sma45 = talib.SMA(df['Close'],timeperiod=45)
    sma50 = talib.SMA(df['Close'],timeperiod=50)
    atr = talib.ATR(df['High'],df['Low'],df['Close'],timeperiod=10)
    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50
    bbdelta = upper - middle
    price_bolup = df['Close'] - lower
    price_bolow = df['Close'] - upper
    Ema = talib.EMA(df['Close'],timeperiod=20)
    KC_High = Ema + 2*atr
    KC_Low = Ema - 2*atr
    aroondown, aroonup = talib.AROON(df['High'], df['Low'], timeperiod=9)
    aroon = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
    rsi30_list = []
    rsi70_list = []
    for i in range(0,df.shape[0]):
        rsi70_list.append(70 - rsi[i])
        rsi30_list.append(rsi[i] - 30)
        #except:
         #   rsi70_list.append(0)
          #  rs30_list.append(0)
    varop_spy = df['Open'] - df['Close']
    varhl_spy = df['High'] - df['Low']
    df['Varop_Spy'] = varop_spy
    df['Varhl_spy'] = varhl_spy
    df['RSI'] = rsi
    df['70 - RSI'] = np.array(rsi70_list)
    df['RSI - 30'] = np.array(rsi30_list)
    df['BBD_Delta_Up'] = bbdelta
    df['delta5_8'] = delta5_8
    df['delta8_10'] = delta8_10
    df['delta10_12'] = delta10_12
    df['delta12_15'] = delta12_15
    df['delta15_30'] = delta15_30
    df['delta30_35'] = delta30_35
    df['delta35_40'] = delta35_40
    df['delta40_45'] = delta40_45
    df['delta45_50'] = delta45_50
    df['Stoc_Slowk'] = stoc_slowk
    df['Stoc_Slowd'] = stoc_slowd
    df['KC_High'] = KC_High
    df['KC_Low'] = KC_Low
    df['upper'] = upper
    df['lower'] = lower
    df['var_bollup_kchigh'] = upper-KC_High
    df['var_bolllow_kclow'] = lower-KC_Low
    df['Aroon Up'] = aroonup
    df['Aroon Down'] = aroondown
    df['Delta Aroon'] = aroon
    up = []
    down = []
    df = df.dropna()
    df = boost(df)
    df['%Futur'] = ((df['Close.S']-df['Close']) *100) / (df['Close'])
    df['%Futur2'] = ((df['Close.S2']-df['Close']) *100) / (df['Close'])
    for i in range(0,df.shape[0]-5):
        if df.iloc[i]['%Futur'] > 0.1 :#or df.iloc[i]['%Futur2'] > 0.1:
            up.append(1)
            down.append(0)
        elif df.iloc[i]['%Futur'] < -0.1: #or df.iloc[i]['%Futur2'] < -0.1:
            up.append(0)
            down.append(1)
        else:
            up.append(0)
            down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    
    
    df['target_up'] = up  # target_up # abs(np.array(valley))#target_up
    df['target_down'] = down # target_down # abs(np.array(peak))#target_down
    #df = df.dropna()
    tmps2=round(time.time()-tmps1,2)
    print ("Data prepared in = %f" %tmps2,'seconds')
    return(df)

def boost(df):
    print('Boosting')
    X = df.copy()
    X = X.drop(['Close'],axis=1)
    X['Close'] = df['Close']
    y = X.iloc[:,-1]
    Xtrain = X.iloc[:-2,:-1]
    Xtest = X.iloc[-2:-1,:-1]
    yshift = y.shift(-1)
    ytrain = yshift.iloc[:-2]
    ytest = yshift.iloc[-2:-1]

    model = xgb.XGBRegressor(n_estimators=20000, learning_rate=1, gamma=1, subsample=1, colsample_bytree=1, max_depth=100)

    model.fit( Xtrain, ytrain, early_stopping_rounds=150, eval_set=[(Xtest, ytest)], verbose=0)

    ytrain_pred = model.predict(Xtrain)

    y_pred = model.predict(Xtest)

    pred = model.predict(X.iloc[:,:-1])

    df['Close.S'] = pred
    df['Close.S2'] = df['Close.S']
    df = df.dropna()
    print('Boost ok')
    return(df)

    
def deep_learning(df):
    tmps1=time.time()
    X = df.iloc[:,1:-4]
    y_up = df.iloc[:,-2].values
    y_down = df.iloc[:,-1].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:bloc1,:]
    Xtest = X[bloc1:,:]
    ytrain_up = y_up[:bloc1,:]
    ytest_up = y_up[bloc1:,:]
    ytrain_down = y_down[:bloc1,:]
    ytest_down = y_down[bloc1:,:]

    seed = 770
    np.random.seed(seed)

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    model_up = Sequential()
    # Add an input layer 
    model_up.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_up.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_up.add(Dense(1, activation='sigmoid'))

    model_down = Sequential()
    # Add an input layer 
    model_down.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_down.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_down.add(Dense(1, activation='sigmoid'))

    print('Processing move_up')
    model_up.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])
    
              

    history_up = model_up.fit(Xtrain, ytrain_up,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Processing move_down')
    model_down.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])

    history_down = model_down.fit(Xtrain, ytrain_down,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Computing done')
    print('\n')

    train_acc_up = model_up.evaluate(Xtrain, ytrain_up,verbose=1)
    train_acc_down = model_down.evaluate(Xtrain, ytrain_down,verbose=1)

    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    score_up = model_up.evaluate(Xtest, ytest_up,verbose=1)
    score_down = model_down.evaluate(Xtest, ytest_down,verbose=1)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)

    accuracy_up = accuracy_score(ytest_up, yhat_up)
    accuracy_down = accuracy_score(ytest_down, yhat_down)

    # La précision permet de mesurer la capacité du modèle à refuser résultats non-pertinents : vrais_positifs/(vrais_positifs+faux_positifs)
    precision_up = precision_score(ytest_up, yhat_up)  
    precision_down = precision_score(ytest_down, yhat_down) 


    # Recall : (vrai_positifs/(vrais_positifs+faux_négatifs))
    recall_up = recall_score(ytest_up, yhat_up) 
    recall_down = recall_score(ytest_down, yhat_down) 


    #roc_up=roc_auc_score(ytest_up,yhat_up)
    #roc_down=roc_auc_score(ytest_down,yhat_down)
    print('\n')
    print(Fore.GREEN,'RESULTATS UP\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_up * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_up *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_up * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_up *100))
    # get probabilities for positive class

    print(classification_report(ytest_up, yhat_up))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_up, yhat_up))

    print('\n')
    print('_______________________________________________________________________________________________________________________________________________________________\n')
    print(Fore.RED,'RESULTATS DOWN\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_down * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_down *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_down * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_down *100))
    # get probabilities for positive class

    print(classification_report(ytest_down, yhat_down))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_down, yhat_down))
    print('\n')

    resultats = pd.DataFrame()
    resultats['Date'] = df.index[bloc1:]
    resultats.index= df.index[bloc1:]
    resultats['Move Up'] = yhat_up
    resultats['Confiance up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confiance Down'] = (predict_down)*100
    resultats['Actual'] = df.iloc[bloc1:]['Close']
    resultats['Actual.S'] = df.iloc[bloc1:]['Close.S']
    open_S = df['Open'].shift(-1)
    resultats['Open.S'] = open_S.iloc[bloc1:]
    dmp_cp=[]
    dmp_cp = ((resultats['Confiance up']-resultats['Confiance Down'])/(resultats['Confiance up']+resultats['Confiance Down'])*100)
    resultats['DMP_CP'] = dmp_cp
    tmps2=round(time.time()-tmps1,2)
    print ("Deep Learning executed in = %f" %tmps2,'seconds')
    #resultats.set_index('Date',inplace=True)
    #parse_dates=resultats['Date']
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def learn(df):
    resultats,precision_up,precision_down,model_up,model_down,scaler = deep_learning(df)
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def grobeta(df,dfb):
    # create a time-series of monthly data points
    rts = df.resample('M').last()
    rbts = dfb.resample('M').last()
    dfsm = pd.DataFrame({'s_adjclose' : rts['Close'],
                            'b_adjclose' : rbts['Adj Close']},
                            index=rts.index)

    # compute returns
    dfsm[['s_returns','b_returns']] = dfsm[['s_adjclose','b_adjclose']]/\
        dfsm[['s_adjclose','b_adjclose']].shift(1) -1
    dfsm = dfsm.dropna()
    covmat = np.cov(dfsm["s_returns"],dfsm["b_returns"])

    # calculate measures now
    beta = covmat[0,1]/covmat[1,1]
    alpha= np.mean(dfsm["s_returns"])-beta*np.mean(dfsm["b_returns"])

    # r_squared     = 1. - SS_res/SS_tot
    ypred = alpha + beta * dfsm["b_returns"]
    SS_res = np.sum(np.power(ypred-dfsm["s_returns"],2))
    SS_tot = covmat[0,0]*(len(dfsm)-1) # SS_tot is sample_variance*(n-1)
    r_squared = 1. - SS_res/SS_tot
    # 5- year volatiity and 1-year momentum
    volatility = np.sqrt(covmat[0,0])
    momentum = np.prod(1+dfsm["s_returns"].tail(12).values) -1

    # annualize the numbers
    prd = 12. # used monthly returns; 12 periods to annualize
    alpha = alpha*prd
    volatility = volatility*np.sqrt(prd)

    print ('Beta : ',beta,'\n Alpha : ',alpha,'\n R_Squared : ', r_squared, '\n Volatility : ', volatility, '\n Momentum : ',momentum)
    return(beta,alpha,r_squared,volatility,momentum)

########################
#### MAIN SKAN55 #######
########################

    
for loop in range(amorce,len(constituents)):
    
    try:

        ticker = (constituents.iloc[loop]['Symbol'])
        name = constituents.iloc[loop]['Name']
        sector = constituents.iloc[loop]['Sector']

        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        global delta,bloc1,bloc2
        tmps1=time.time()
        print('Scraping data...')

        df = scrap_data(ticker,start,end)

        dfb = web.DataReader('^GSPC','yahoo',start,end)

        beta,alpha, r_squared, volatility, momentum = grobeta(df,dfb)

        tmps2=round(time.time()-tmps1,2)
        print ("executed in = %f" %tmps2,'seconds')

        print('\n')
        print('GOLEM begins Computing...')
        print('\n')
        delta = round(df.shape[0])
        bloc1 = round(delta*0.80)
        bloc2 = delta - bloc1
        print("# of periods : ",delta)
        print('On 80% - 20% slash : ')
        print('Bloc 1 : ',bloc1,'\nBloc 2 :',bloc2,' periods ')
        print('First period :',df.index[0])
        print('Split period :',df.index[bloc1-1])
        print('Last period :',df.index[df.shape[0]-1])
        print('\n')

        print('Data prep')
        df = prepa_data(df)

        print(Fore.BLUE,'Deeping in blue',Style.RESET_ALL)
        print('')
        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        resultats,precision_up,precision_down,model_up,model_down,scaler = learn(df)

        import sys
        orig_stdout = sys.stdout
        f = open('backtest de '+str(ticker)+'.txt', 'w')
        sys.stdout = f

        ####################
        #### TEST PLOT ####
        ###################

        filtre_up = 93
        filtre_down = 97
        filtre_up_close = 80
        filtre_down_close = 80


        plt.figure(figsize=(26,8),dpi=300)
        #plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
        plt.title('Deep Learning '+name+' Trade Signals')
        plt.plot(resultats['Actual'],color='purple',lw=0.9,label=ticker)

        green=[]
        red=[]
        green_close=[]
        red_close=[]

        for i in range(0,len(resultats)-1):


            if resultats.iloc[i]['Confiance Down'] > filtre_down:
                doob = -1
            elif resultats.iloc[i]['Confiance Down'] > filtre_down_close and resultats.iloc[i]['Confiance Down'] < filtre_down :
                waab = -1
                doob = 0
            elif resultats.iloc[i]['Confiance up'] > filtre_up:
                doob = 1
            elif resultats.iloc[i]['Confiance up'] > filtre_up_close and resultats.iloc[i]['Confiance up'] < filtre_up:
                waab = 1
                doob = 0
            else :
                doob = 0
                waab = 0

            if doob == 1 :#and resultats.iloc[i]['Confiance up'] > filtre_up:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='g',marker='o')
                #doob = -1
                green.append(1)
                red.append(0)
                green_close.append(0)
                red_close.append(1)

            elif doob == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(1)
                green_close.append(1)
                red_close.append(0)

            elif doob == 0 and waab == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(0)
                green_close.append(0)
                red_close.append(1)

            elif waab == 1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(0)
                green_close.append(1)
                red_close.append(0)  

            else:
                green.append(0)
                red.append(0)
                green_close.append(0)
                red_close.append(0)  

                #doob = 0


        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='g',marker='o',label='Buy Signal')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o',label='Sell Signal')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_01.pdf')
        plt.close()
        green.append(0)
        red.append(0)
        green_close.append(0)
        red_close.append(0)
        resultats['Green'] = green
        resultats['Red'] = red
        resultats['Green_Close'] = green_close
        resultats['Red_Close'] = red_close
        #resultats['Actual'] = df['Close'][bloc1:]

        ########################
        ####### BACKTEST########
        ########################
        pos_long = 0
        pos_short = 0
        pactol = 10000/beta
        price_buy = 0
        price_sell = 0
        x = 0
        winners = []
        loosers = []
        nb_win = 0
        nb_los = 0
        mini_pnl = 0
        pos_duration = []
        average_duration = resultats.iloc[0,0] - resultats.iloc[0,0]
        trades = []
        eq_curx = []
        eq_cury = []
        maxdd = []


        for i in range(0,len(resultats)-1):
            if pos_long == 0 and pos_short == 0 and resultats.iloc[i]['Green'] == 1 :
                pos_long = 1
                x = (10000/beta)/resultats.iloc[i]['Open.S']
                price_buy = resultats.iloc[i]['Open.S']
                time_enter = resultats.iloc[i]['Date']
                print('\n Le ',str(resultats.iloc[i]['Date']),', achat de ',x,' actions à',resultats.iloc[i]['Open.S'],'$')
                print('Nouveau pactol : ',pactol)
                trades.append((resultats.iloc[i]['Open.S'],resultats.iloc[i]['Date'],1))

            elif pos_long == 1 and resultats.iloc[i]['Green_Close'] == 0 :
                try:
                    maxdd.append((resultats.iloc[i]['Open.S'] - price_buy)*x)
                except:
                    print('Null val of maxdd')
                    maxdd.append(0)


            elif pos_long == 1 and resultats.iloc[i]['Green_Close'] == 1 :
                old_pactol = pactol
                eq_curx.append(resultats.iloc[i]['Date'])
                eq_cury.append(old_pactol)
                pos_long = 0
                price_sell = resultats.iloc[i]['Open.S']
                trades.append((resultats.iloc[i]['Open.S'],resultats.iloc[i]['Date'],2))
                mini_pnl = x*(price_sell-price_buy)
                pactol = pactol + mini_pnl
                print('\n Le ',str(resultats.iloc[i]['Date']),', vente pour close de ',x,' actions à',resultats.iloc[i]['Open.S'],'$')
                print('Nouveau pactol : ',pactol)
                print('pnl:', mini_pnl)
                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                pos_duration.append(resultats.iloc[i]['Date'] - time_enter)

                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1


            elif pos_short == 0 and pos_long == 0 and resultats.iloc[i]['Red']:
                pos_short = 1
                x = (10000/beta)/resultats.iloc[i]['Open.S']
                price_sell = resultats.iloc[i]['Open.S']
                time_enter = resultats.iloc[i]['Date']
                print('\n Le ',str(resultats.iloc[i]['Date']),', vente de ',x,' actions à',resultats.iloc[i]['Open.S'],'$')
                print('Nouveau pactol : ',pactol)
                trades.append((resultats.iloc[i]['Open.S'],resultats.iloc[i]['Date'],-1))


            elif pos_short == 1 and resultats.iloc[i]['Red_Close'] == 0 :
                try:
                    maxdd.append((resultats.iloc[i]['Open.S'] - price_sell)*x)
                except:
                    print('Null val of maxdd')
                    maxdd.append(0)

            elif pos_short == 1 and resultats.iloc[i]['Red_Close'] == 1 :
                old_pactol = pactol
                eq_curx.append(resultats.iloc[i]['Date'])
                eq_cury.append(old_pactol)
                pos_short = 0
                price_buy=resultats.iloc[i]['Open.S']
                trades.append((resultats.iloc[i]['Open.S'],resultats.iloc[i]['Date'],-2))
                mini_pnl = x*(price_sell-price_buy)
                pactol = pactol + mini_pnl
                print('\n Le ',str(resultats.iloc[i]['Date']),', achat pour close de ',x,' actions à',resultats.iloc[i]['Open.S'],'$')
                print('Nouveau pactol : ',pactol)

                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                print('pnl:', mini_pnl)
                pos_duration.append(resultats.iloc[i]['Date'] - time_enter)
                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1





        if pos_long == 1:
            pos_long = 0
            print('Cutting non resolved position')
            print(' Le price buy était de : ',price_buy)
            x = round((10000/beta)/resultats.iloc[i]['Open.S'])
            print('x = ',x)
            price_sell = resultats.iloc[i]['Open.S']
            print('Et le price sell : ',price_sell)
            mini_pnl = x*(price_sell-price_buy)
            pactol = pactol + mini_pnl
            print('pnl : ',mini_pnl)
            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1


        if pos_short == 1:
            pos_short = 0
            print('Cutting non resolved position')
            print(' Le price sell était de : ',price_sell)
            x = round((10000/beta)/resultats.iloc[i]['Open.S'])
            print('x = ',x)
            price_buy=resultats.iloc[i]['Open.S']
            print('Et le price_buy : ',price_buy)
            mini_pnl = x*(price_sell-price_buy)
            pactol = pactol + mini_pnl
            print('pnl : ',mini_pnl)

            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1


        pnl = round(pactol - (10000/beta),2)
        print('\n Begining of BackTest :',resultats.iloc[0]['Date'])
        print('Instrument :',ticker)
        print('Face value per trade : $',10000/beta)
        print('End of BackTest :',resultats.iloc[-1]['Date'])
        duration = resultats.iloc[-1]['Date'] - resultats.iloc[0]['Date']
        print("BackTest's period :",duration)
        print('Pnl :',pnl,'$')
        print('% Pnl : ',round(pnl/(10000/beta)*100,2))
        print('Total winners :',round(sum(winners),2),'$')
        print('Total loosers :',round(sum(loosers),2),'$')
        print('Number of winners :',nb_win)
        print('Number of loosers :',nb_los)
        print('Maximum Drawdown : ',round(min(maxdd),2))
        print('% Max Drawdown : ',round(min(maxdd)/(10000/beta)*100,2),'%')
        try:
            print('% winners :', round((nb_win/(nb_win+nb_los) * 100),2),'%')
            print('Average winners :',(round(sum(winners)/(nb_win))))
        except:
            print('% winners : null')
        try:
            print('Average losers :',(round(sum(loosers)/(nb_los))))
        except:
            print('Average losers : Inf')
        try:
            for t in range(0,len(pos_duration)):
                average_duration = average_duration + pos_duration[t]
            average_duration = average_duration/(nb_los+nb_win)
            print('Average Duration :', average_duration)
        except:
            print('No Average Duration available')
        try:
            print('Profit Factor : ',abs(round((sum(winners)/sum(loosers)),2)))
        except:
            print('Profit Factor : null')

        ########################
        ##### PLOT TRADES ######
        ########################

        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Trades')
        plt.plot(resultats['Open.S'],color='blue',lw=0.9)
        for i in range(0,len(trades)):
            if trades[i][2] == 1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='green',marker='^',lw=2.5)
            elif trades[i][2] == -1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='red',marker='^',lw=2.5)
            elif trades[i][2] == 2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='g',marker='x',lw=2.5)
            elif trades[i][2] == -2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='r',marker='x',lw=2.5)

        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='g',marker='^',label='Open Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='r',marker='^',label='Open Short')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='g',marker='x',label='Close Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='r',marker='x',label='Close Short')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_02.pdf')
        plt.close()

        #########################
        ##### PLOT E-CURVE ######
        #########################
        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Equity Curve')
        plt.plot(eq_curx,eq_cury)
        plt.scatter(x=eq_curx,y=eq_cury,c='orange',marker='o',lw=2.5)
        plt.savefig('backtest de '+str(ticker)+'_03.pdf')
        plt.close()


        f.close()
        sys.stdout = orig_stdout

        print('\r Boucle ', loop, 'terminée...',end='')
        print('Opération restantes :', len(constituents)-loop,'/',len(constituents),'\n')


        backtest = backtest.append([{'Symb.':ticker,'Name':name,'Sector':sector,'period':duration,'Begin.':resultats.iloc[0,0],'End':resultats.iloc[-1,0],\
                          'Pnl':pnl,'%Pnl':round(pnl/(10000/beta)*100,2),'Total Winners':round(sum(winners),2),'Total Loosers':round(sum(loosers),2),'Nb Win':nb_win,'Nb Los':nb_los,\
                          '% Winners':round((nb_win/(nb_win+nb_los) * 100),2),'MaxDD':round(min(maxdd),2),'%MaxDD':round(min(maxdd)/(10000/beta)*100,2),'Aver. Win':(round(sum(winners)/(nb_win))),\
                          'Aver. Los':(round(sum(loosers)/(nb_los))),'Aver. Duration':average_duration,\
                          'Profit Factor':abs(round((sum(winners)/sum(loosers)),2))}], ignore_index=True)

    # symbol / name / sector / period of backtest / debut / fin / pnl / total winners / total loosers / Nb winners / nb loosers / 
    # / % winners / Max DD / Aver Win / Aver Loos / Average duration / Profit Factor
        print(Fore.YELLOW,'Writing BACKTEST CSV',Style.RESET_ALL)
        backtest.to_csv('BackTest.csv')
        print(Fore.CYAN,'BACKTEST CSV WRITED',Style.RESET_ALL)
    except:
        print(Fore.RED,'Problème loop : ',loop,Style.RESET_ALL)
        error.append((loop,ticker))
         
        continue
# Out:
# Importing Librairies...
# Librairies imported
#
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
# BOOST SKAN 55 Version v1.33
#
# Sraping tickers
# Scrap -----> ok
#  --- Loop : 203  ---  --- Symbol :   BEN   ---  --- Name :  Franklin Resources  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  1.1529469654835418
#  Alpha :  -0.1248714466366095
#  R_Squared :  0.4029104088449582
#  Volatility :  0.22294783673456897
#  Momentum :  0.06816264215180845
# executed in = 52.600000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [18:54:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.630000 seconds
#  Deeping in blue
#
#  --- Loop : 203  ---  --- Symbol :   BEN   ---  --- Name :  Franklin Resources  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 68us/step
# 883/883 [==============================] - 0s 71us/step
# 172/172 [==============================] - 0s 19us/step
# 172/172 [==============================] - 0s 21us/step
#
#
#  RESULTATS UP
#
# Accuracy: 93.02%
#  Precision: 86.84%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 97.06%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94       104
#            1       0.87      0.97      0.92        68
#
#    micro avg       0.93      0.93      0.93       172
#    macro avg       0.92      0.94      0.93       172
# weighted avg       0.94      0.93      0.93       172
#
# [[94 10]
#  [ 2 66]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 95.93%
#  Precision: 95.83%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 96.84%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95        77
#            1       0.96      0.97      0.96        95
#
#    micro avg       0.96      0.96      0.96       172
#    macro avg       0.96      0.96      0.96       172
# weighted avg       0.96      0.96      0.96       172
#
# [[73  4]
#  [ 3 92]]
#
#
# Deep Learning executed in = 58.620000 seconds
#  Boucle  203 terminée...Opération restantes : 302 / 505
#
#  Problème loop :  203
#  --- Loop : 204  ---  --- Symbol :   FCX   ---  --- Name :  Freeport-McMoRan Inc.  ---  --- Sector :  Materials  ---
# Scraping data...
# Beta :  2.1485792882425763
#  Alpha :  -0.08887497779842717
#  R_Squared :  0.14927333311278312
#  Volatility :  0.6825876801132222
#  Momentum :  -0.29215265497878073
# executed in = 63.620000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [18:56:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.080000 seconds
#  Deeping in blue
#
#  --- Loop : 204  ---  --- Symbol :   FCX   ---  --- Name :  Freeport-McMoRan Inc.  ---  --- Sector :  Materials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 111us/step
# 883/883 [==============================] - 0s 114us/step
# 172/172 [==============================] - 0s 21us/step
# 172/172 [==============================] - 0s 23us/step
#
#
#  RESULTATS UP
#
# Accuracy: 78.49%
#  Precision: 70.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 90.91%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.68      0.78        95
#            1       0.70      0.91      0.79        77
#
#    micro avg       0.78      0.78      0.78       172
#    macro avg       0.80      0.80      0.78       172
# weighted avg       0.81      0.78      0.78       172
#
# [[65 30]
#  [ 7 70]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 86.63%
#  Precision: 95.38%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 75.61%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.81      0.97      0.88        90
#            1       0.95      0.76      0.84        82
#
#    micro avg       0.87      0.87      0.87       172
#    macro avg       0.88      0.86      0.86       172
# weighted avg       0.88      0.87      0.86       172
#
# [[87  3]
#  [20 62]]
#
#
# Deep Learning executed in = 56.290000 seconds
#  Boucle  204 terminée...Opération restantes : 301 / 505
#
#  Problème loop :  204
#  --- Loop : 205  ---  --- Symbol :   GPS   ---  --- Name :  Gap Inc.  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  0.7021540447321776
#  Alpha :  -0.14357233613429096
#  R_Squared :  0.049191441764688704
#  Volatility :  0.3885847939582023
#  Momentum :  -0.35186493057916635
# executed in = 3.000000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [18:57:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.050000 seconds
#  Deeping in blue
#
#  --- Loop : 205  ---  --- Symbol :   GPS   ---  --- Name :  Gap Inc.  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 162us/step
# 883/883 [==============================] - 0s 154us/step
# 172/172 [==============================] - 0s 24us/step
# 172/172 [==============================] - 0s 38us/step
#
#
#  RESULTATS UP
#
# Accuracy: 89.53%
#  Precision: 86.84%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 89.19%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91        98
#            1       0.87      0.89      0.88        74
#
#    micro avg       0.90      0.90      0.90       172
#    macro avg       0.89      0.89      0.89       172
# weighted avg       0.90      0.90      0.90       172
#
# [[88 10]
#  [ 8 66]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 84.30%
#  Precision: 82.95%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.88%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84        87
#            1       0.83      0.86      0.84        85
#
#    micro avg       0.84      0.84      0.84       172
#    macro avg       0.84      0.84      0.84       172
# weighted avg       0.84      0.84      0.84       172
#
# [[72 15]
#  [12 73]]
#
#
# Deep Learning executed in = 59.380000 seconds
#  Boucle  205 terminée...Opération restantes : 300 / 505
#
#  Problème loop :  205
#  --- Loop : 206  ---  --- Symbol :   GRMN   ---  --- Name :  Garmin Ltd.  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  0.9864204965543115
#  Alpha :  0.1093881974318926
#  R_Squared :  0.24712563015977596
#  Volatility :  0.2435574220607178
#  Momentum :  0.3368468278135073
# executed in = 25.440000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [18:59:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.600000 seconds
#  Deeping in blue
#
#  --- Loop : 206  ---  --- Symbol :   GRMN   ---  --- Name :  Garmin Ltd.  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 185us/step
# 883/883 [==============================] - 0s 190us/step
# 172/172 [==============================] - 0s 25us/step
# 172/172 [==============================] - 0s 24us/step
#
#
#  RESULTATS UP
#
# Accuracy: 89.53%
#  Precision: 84.78%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 78.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       122
#            1       0.85      0.78      0.81        50
#
#    micro avg       0.90      0.90      0.90       172
#    macro avg       0.88      0.86      0.87       172
# weighted avg       0.89      0.90      0.89       172
#
# [[115   7]
#  [ 11  39]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 91.28%
#  Precision: 93.16%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 93.97%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86        56
#            1       0.93      0.94      0.94       116
#
#    micro avg       0.91      0.91      0.91       172
#    macro avg       0.90      0.90      0.90       172
# weighted avg       0.91      0.91      0.91       172
#
# [[ 48   8]
#  [  7 109]]
#
#
# Deep Learning executed in = 60.380000 seconds
#  Boucle  206 terminée...Opération restantes : 299 / 505
#
#  Problème loop :  206
#  --- Loop : 207  ---  --- Symbol :   IT   ---  --- Name :  Gartner Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.3062616097082522
#  Alpha :  0.06634251635839136
#  R_Squared :  0.4547586008940877
#  Volatility :  0.2377594997142289
#  Momentum :  0.22417486710667678
# executed in = 17.270000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:00:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.900000 seconds
#  Deeping in blue
#
#  --- Loop : 207  ---  --- Symbol :   IT   ---  --- Name :  Gartner Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 236us/step
# 883/883 [==============================] - 0s 233us/step
# 172/172 [==============================] - 0s 25us/step
# 172/172 [==============================] - 0s 24us/step
#
#
#  RESULTATS UP
#
# Accuracy: 86.63%
#  Precision: 82.35%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 89.74%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.91      0.84      0.87        94
#            1       0.82      0.90      0.86        78
#
#    micro avg       0.87      0.87      0.87       172
#    macro avg       0.87      0.87      0.87       172
# weighted avg       0.87      0.87      0.87       172
#
# [[79 15]
#  [ 8 70]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 80.23%
#  Precision: 70.19%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 96.05%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.96      0.68      0.79        96
#            1       0.70      0.96      0.81        76
#
#    micro avg       0.80      0.80      0.80       172
#    macro avg       0.83      0.82      0.80       172
# weighted avg       0.84      0.80      0.80       172
#
# [[65 31]
#  [ 3 73]]
#
#
# Deep Learning executed in = 63.700000 seconds
#  Boucle  207 terminée...Opération restantes : 298 / 505
#
#  Problème loop :  207
#  --- Loop : 208  ---  --- Symbol :   GD   ---  --- Name :  General Dynamics  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.216628899078881
#  Alpha :  0.0034820726953956743
#  R_Squared :  0.500812152458233
#  Volatility :  0.21101769488961458
#  Momentum :  -0.05931984125038481
# executed in = 27.120000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:02:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.990000 seconds
#  Deeping in blue
#
#  --- Loop : 208  ---  --- Symbol :   GD   ---  --- Name :  General Dynamics  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 270us/step
# 883/883 [==============================] - 0s 295us/step
# 172/172 [==============================] - 0s 25us/step
# 172/172 [==============================] - 0s 27us/step
#
#
#  RESULTATS UP
#
# Accuracy: 80.81%
#  Precision: 75.24%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 91.86%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.70      0.78        86
#            1       0.75      0.92      0.83        86
#
#    micro avg       0.81      0.81      0.81       172
#    macro avg       0.82      0.81      0.81       172
# weighted avg       0.82      0.81      0.81       172
#
# [[60 26]
#  [ 7 79]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 86.05%
#  Precision: 88.33%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 75.71%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89       102
#            1       0.88      0.76      0.82        70
#
#    micro avg       0.86      0.86      0.86       172
#    macro avg       0.87      0.84      0.85       172
# weighted avg       0.86      0.86      0.86       172
#
# [[95  7]
#  [17 53]]
#
#
# Deep Learning executed in = 66.570000 seconds
#  Boucle  208 terminée...Opération restantes : 297 / 505
#
#  Problème loop :  208
#  --- Loop : 209  ---  --- Symbol :   GE   ---  --- Name :  General Electric  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  0.9920334752679051
#  Alpha :  -0.2171894067413737
#  R_Squared :  0.17242214947943235
#  Volatility :  0.29324321720801466
#  Momentum :  -0.22399287421378977
# executed in = 11.590000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:03:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.090000 seconds
#  Deeping in blue
#
#  --- Loop : 209  ---  --- Symbol :   GE   ---  --- Name :  General Electric  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 316us/step
# 883/883 [==============================] - 0s 301us/step
# 172/172 [==============================] - 0s 26us/step
# 172/172 [==============================] - 0s 27us/step
#
#
#  RESULTATS UP
#
# Accuracy: 57.56%
#  Precision: 81.82%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 11.25%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.56      0.98      0.71        92
#            1       0.82      0.11      0.20        80
#
#    micro avg       0.58      0.58      0.58       172
#    macro avg       0.69      0.55      0.45       172
# weighted avg       0.68      0.58      0.47       172
#
# [[90  2]
#  [71  9]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 49.42%
#  Precision: 46.48%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.71%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.63      0.20      0.30        95
#            1       0.46      0.86      0.60        77
#
#    micro avg       0.49      0.49      0.49       172
#    macro avg       0.55      0.53      0.45       172
# weighted avg       0.56      0.49      0.44       172
#
# [[19 76]
#  [11 66]]
#
#
# Deep Learning executed in = 68.160000 seconds
#  Boucle  209 terminée...Opération restantes : 296 / 505
#
#  Problème loop :  209
#  --- Loop : 210  ---  --- Symbol :   GGP   ---  --- Name :  General Growth Properties Inc.  ---  --- Sector :  Real Estate  ---
# Scraping data...
#  Problème loop :  210
#  --- Loop : 211  ---  --- Symbol :   GIS   ---  --- Name :  General Mills  ---  --- Sector :  Consumer Staples  ---
# Scraping data...
# Beta :  0.7931983038670388
#  Alpha :  -0.03287963728380007
#  R_Squared :  0.2624724993602948
#  Volatility :  0.19003694895034942
#  Momentum :  0.19458308319061635
# executed in = 2.530000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:04:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.490000 seconds
#  Deeping in blue
#
#  --- Loop : 211  ---  --- Symbol :   GIS   ---  --- Name :  General Mills  ---  --- Sector :  Consumer Staples  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 360us/step
# 883/883 [==============================] - 0s 364us/step
# 172/172 [==============================] - 0s 29us/step
# 172/172 [==============================] - 0s 33us/step
#
#
#  RESULTATS UP
#
# Accuracy: 66.28%
#  Precision: 87.50%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 39.77%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.60      0.94      0.73        84
#            1       0.88      0.40      0.55        88
#
#    micro avg       0.66      0.66      0.66       172
#    macro avg       0.74      0.67      0.64       172
# weighted avg       0.74      0.66      0.64       172
#
# [[79  5]
#  [53 35]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 78.49%
#  Precision: 69.86%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 77.27%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.85      0.79      0.82       106
#            1       0.70      0.77      0.73        66
#
#    micro avg       0.78      0.78      0.78       172
#    macro avg       0.77      0.78      0.78       172
# weighted avg       0.79      0.78      0.79       172
#
# [[84 22]
#  [15 51]]
#
#
# Deep Learning executed in = 71.440000 seconds
#  Boucle  211 terminée...Opération restantes : 294 / 505
#
#  Problème loop :  211
#  --- Loop : 212  ---  --- Symbol :   GM   ---  --- Name :  General Motors  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  1.3481972732022014
#  Alpha :  -0.03581070330758715
#  R_Squared :  0.4161864471631411
#  Volatility :  0.2565119802143291
#  Momentum :  0.08589000697839744
# executed in = 23.030000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:06:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.140000 seconds
#  Deeping in blue
#
#  --- Loop : 212  ---  --- Symbol :   GM   ---  --- Name :  General Motors  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 378us/step
# 883/883 [==============================] - 0s 392us/step
# 172/172 [==============================] - 0s 28us/step
# 172/172 [==============================] - 0s 30us/step
#
#
#  RESULTATS UP
#
# Accuracy: 82.56%
#  Precision: 91.67%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 73.33%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.76      0.93      0.84        82
#            1       0.92      0.73      0.81        90
#
#    micro avg       0.83      0.83      0.83       172
#    macro avg       0.84      0.83      0.82       172
# weighted avg       0.84      0.83      0.82       172
#
# [[76  6]
#  [24 66]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 83.72%
#  Precision: 73.81%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 91.18%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.93      0.79      0.85       104
#            1       0.74      0.91      0.82        68
#
#    micro avg       0.84      0.84      0.84       172
#    macro avg       0.83      0.85      0.83       172
# weighted avg       0.86      0.84      0.84       172
#
# [[82 22]
#  [ 6 62]]
#
#
# Deep Learning executed in = 70.290000 seconds
#  Boucle  212 terminée...Opération restantes : 293 / 505
#
#  Problème loop :  212
#  --- Loop : 213  ---  --- Symbol :   GPC   ---  --- Name :  Genuine Parts  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  0.8426058830625179
#  Alpha :  -0.02591258380138735
#  R_Squared :  0.2855220387310127
#  Volatility :  0.19355430923739772
#  Momentum :  0.006705027992287116
# executed in = 21.860000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:08:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.430000 seconds
#  Deeping in blue
#
#  --- Loop : 213  ---  --- Symbol :   GPC   ---  --- Name :  Genuine Parts  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 424us/step
# 883/883 [==============================] - 0s 420us/step
# 172/172 [==============================] - 0s 47us/step
# 172/172 [==============================] - 0s 37us/step
#
#
#  RESULTATS UP
#
# Accuracy: 86.63%
#  Precision: 80.77%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 88.73%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88       101
#            1       0.81      0.89      0.85        71
#
#    micro avg       0.87      0.87      0.87       172
#    macro avg       0.86      0.87      0.86       172
# weighted avg       0.87      0.87      0.87       172
#
# [[86 15]
#  [ 8 63]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 86.63%
#  Precision: 95.31%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 75.31%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.81      0.97      0.88        91
#            1       0.95      0.75      0.84        81
#
#    micro avg       0.87      0.87      0.87       172
#    macro avg       0.88      0.86      0.86       172
# weighted avg       0.88      0.87      0.86       172
#
# [[88  3]
#  [20 61]]
#
#
# Deep Learning executed in = 74.820000 seconds
#  Boucle  213 terminée...Opération restantes : 292 / 505
#
#  Problème loop :  213
#  --- Loop : 214  ---  --- Symbol :   GILD   ---  --- Name :  Gilead Sciences  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.2566868122950927
#  Alpha :  -0.15504168024000853
#  R_Squared :  0.405557058523502
#  Volatility :  0.24221400517256148
#  Momentum :  -0.1343562339556177
# executed in = 10.680000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:09:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.050000 seconds
#  Deeping in blue
#
#  --- Loop : 214  ---  --- Symbol :   GILD   ---  --- Name :  Gilead Sciences  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 468us/step
# 883/883 [==============================] - 0s 463us/step
# 172/172 [==============================] - 0s 29us/step
# 172/172 [==============================] - 0s 29us/step
#
#
#  RESULTATS UP
#
# Accuracy: 89.53%
#  Precision: 97.56%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 83.33%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89        76
#            1       0.98      0.83      0.90        96
#
#    micro avg       0.90      0.90      0.90       172
#    macro avg       0.90      0.90      0.90       172
# weighted avg       0.91      0.90      0.90       172
#
# [[74  2]
#  [16 80]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 84.30%
#  Precision: 71.58%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.74      0.85       104
#            1       0.72      1.00      0.83        68
#
#    micro avg       0.84      0.84      0.84       172
#    macro avg       0.86      0.87      0.84       172
# weighted avg       0.89      0.84      0.84       172
#
# [[77 27]
#  [ 0 68]]
#
#
# Deep Learning executed in = 74.580000 seconds
#  Boucle  214 terminée...Opération restantes : 291 / 505
#
#  Problème loop :  214
#  --- Loop : 215  ---  --- Symbol :   GPN   ---  --- Name :  Global Payments Inc.  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.0251942529665692
#  Alpha :  0.2280713588943319
#  R_Squared :  0.33182368232068793
#  Volatility :  0.21844929599647486
#  Momentum :  0.463813058684277
# executed in = 3.110000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:10:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.320000 seconds
#  Deeping in blue
#
#  --- Loop : 215  ---  --- Symbol :   GPN   ---  --- Name :  Global Payments Inc.  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 519us/step
# 883/883 [==============================] - 0s 494us/step
# 172/172 [==============================] - 0s 31us/step
# 172/172 [==============================] - 0s 32us/step
#
#
#  RESULTATS UP
#
# Accuracy: 75.00%
#  Precision: 84.62%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 68.04%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.67      0.84      0.75        75
#            1       0.85      0.68      0.75        97
#
#    micro avg       0.75      0.75      0.75       172
#    macro avg       0.76      0.76      0.75       172
# weighted avg       0.77      0.75      0.75       172
#
# [[63 12]
#  [31 66]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 80.23%
#  Precision: 82.93%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 55.74%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.79      0.94      0.86       111
#            1       0.83      0.56      0.67        61
#
#    micro avg       0.80      0.80      0.80       172
#    macro avg       0.81      0.75      0.76       172
# weighted avg       0.81      0.80      0.79       172
#
# [[104   7]
#  [ 27  34]]
#
#
# Deep Learning executed in = 76.950000 seconds
#  Boucle  215 terminée...Opération restantes : 290 / 505
#
#  Problème loop :  215
#  --- Loop : 216  ---  --- Symbol :   GS   ---  --- Name :  Goldman Sachs Group  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  1.2937745982340918
#  Alpha :  -0.042749535996801945
#  R_Squared :  0.3705791375030617
#  Volatility :  0.2608652994295294
#  Momentum :  -0.08631324270018426
# executed in = 7.710000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:12:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.690000 seconds
#  Deeping in blue
#
#  --- Loop : 216  ---  --- Symbol :   GS   ---  --- Name :  Goldman Sachs Group  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 548us/step
# 883/883 [==============================] - 0s 541us/step
# 172/172 [==============================] - 0s 34us/step
# 172/172 [==============================] - 0s 32us/step
#
#
#  RESULTATS UP
#
# Accuracy: 75.00%
#  Precision: 80.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 57.89%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.73      0.89      0.80        96
#            1       0.80      0.58      0.67        76
#
#    micro avg       0.75      0.75      0.75       172
#    macro avg       0.76      0.73      0.73       172
# weighted avg       0.76      0.75      0.74       172
#
# [[85 11]
#  [32 44]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 82.56%
#  Precision: 88.71%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 70.51%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.85        94
#            1       0.89      0.71      0.79        78
#
#    micro avg       0.83      0.83      0.83       172
#    macro avg       0.84      0.82      0.82       172
# weighted avg       0.83      0.83      0.82       172
#
# [[87  7]
#  [23 55]]
#
#
# Deep Learning executed in = 78.200000 seconds
#  Boucle  216 terminée...Opération restantes : 289 / 505
#
#  Problème loop :  216
#  --- Loop : 217  ---  --- Symbol :   GT   ---  --- Name :  Goodyear Tire & Rubber  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  1.623340203651103
#  Alpha :  -0.2223586262368087
#  R_Squared :  0.41446297083023986
#  Volatility :  0.3095029924765133
#  Momentum :  -0.37461972366458596
# executed in = 10.250000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:14:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.350000 seconds
#  Deeping in blue
#
#  --- Loop : 217  ---  --- Symbol :   GT   ---  --- Name :  Goodyear Tire & Rubber  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 668us/step
# 883/883 [==============================] - 1s 635us/step
# 172/172 [==============================] - 0s 34us/step
# 172/172 [==============================] - 0s 35us/step
#
#
#  RESULTATS UP
#
# Accuracy: 75.58%
#  Precision: 86.96%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 52.63%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.71      0.94      0.81        96
#            1       0.87      0.53      0.66        76
#
#    micro avg       0.76      0.76      0.76       172
#    macro avg       0.79      0.73      0.73       172
# weighted avg       0.78      0.76      0.74       172
#
# [[90  6]
#  [36 40]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 69.19%
#  Precision: 65.66%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 77.38%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.74      0.61      0.67        88
#            1       0.66      0.77      0.71        84
#
#    micro avg       0.69      0.69      0.69       172
#    macro avg       0.70      0.69      0.69       172
# weighted avg       0.70      0.69      0.69       172
#
# [[54 34]
#  [19 65]]
#
#
# Deep Learning executed in = 82.160000 seconds
#  Boucle  217 terminée...Opération restantes : 288 / 505
#
#  Problème loop :  217
#  --- Loop : 218  ---  --- Symbol :   GWW   ---  --- Name :  Grainger (W.W.) Inc.  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  0.9431374052156637
#  Alpha :  -0.0033861971583133317
#  R_Squared :  0.20181908217923084
#  Volatility :  0.2576867165896597
#  Momentum :  -0.21472877080881125
# executed in = 6.370000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:15:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.160000 seconds
#  Deeping in blue
#
#  --- Loop : 218  ---  --- Symbol :   GWW   ---  --- Name :  Grainger (W.W.) Inc.  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 627us/step
# 883/883 [==============================] - 1s 614us/step
# 172/172 [==============================] - 0s 35us/step
# 172/172 [==============================] - 0s 34us/step
#
#
#  RESULTATS UP
#
# Accuracy: 73.26%
#  Precision: 64.29%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 98.78%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.98      0.50      0.66        90
#            1       0.64      0.99      0.78        82
#
#    micro avg       0.73      0.73      0.73       172
#    macro avg       0.81      0.74      0.72       172
# weighted avg       0.82      0.73      0.72       172
#
# [[45 45]
#  [ 1 81]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 86.63%
#  Precision: 88.24%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89        97
#            1       0.88      0.80      0.84        75
#
#    micro avg       0.87      0.87      0.87       172
#    macro avg       0.87      0.86      0.86       172
# weighted avg       0.87      0.87      0.87       172
#
# [[89  8]
#  [15 60]]
#
#
# Deep Learning executed in = 84.850000 seconds
#  Boucle  218 terminée...Opération restantes : 287 / 505
#
#  Problème loop :  218
#  --- Loop : 219  ---  --- Symbol :   HAL   ---  --- Name :  Halliburton Co.  ---  --- Sector :  Energy  ---
# Scraping data...
# Beta :  1.4772155959803146
#  Alpha :  -0.22480895102914722
#  R_Squared :  0.30870637898423137
#  Volatility :  0.32633921013171185
#  Momentum :  -0.47154872724185515
# executed in = 25.140000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:17:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.020000 seconds
#  Deeping in blue
#
#  --- Loop : 219  ---  --- Symbol :   HAL   ---  --- Name :  Halliburton Co.  ---  --- Sector :  Energy  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 724us/step
# 883/883 [==============================] - 1s 668us/step
# 172/172 [==============================] - 0s 51us/step
# 172/172 [==============================] - 0s 38us/step
#
#
#  RESULTATS UP
#
# Accuracy: 70.93%
#  Precision: 48.24%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 87.23%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.93      0.65      0.76       125
#            1       0.48      0.87      0.62        47
#
#    micro avg       0.71      0.71      0.71       172
#    macro avg       0.71      0.76      0.69       172
# weighted avg       0.81      0.71      0.73       172
#
# [[81 44]
#  [ 6 41]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 79.07%
#  Precision: 96.59%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 72.03%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.61      0.94      0.74        54
#            1       0.97      0.72      0.83       118
#
#    micro avg       0.79      0.79      0.79       172
#    macro avg       0.79      0.83      0.78       172
# weighted avg       0.85      0.79      0.80       172
#
# [[51  3]
#  [33 85]]
#
#
# Deep Learning executed in = 87.320000 seconds
#  Boucle  219 terminée...Opération restantes : 286 / 505
#
#  Problème loop :  219
#  --- Loop : 220  ---  --- Symbol :   HBI   ---  --- Name :  Hanesbrands Inc  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  1.0932046172012952
#  Alpha :  -0.18717871676031062
#  R_Squared :  0.17146712603209358
#  Volatility :  0.3240478905404187
#  Momentum :  -0.23171667396994722
# executed in = 14.630000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:19:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.270000 seconds
#  Deeping in blue
#
#  --- Loop : 220  ---  --- Symbol :   HBI   ---  --- Name :  Hanesbrands Inc  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 744us/step
# 883/883 [==============================] - 1s 741us/step
# 172/172 [==============================] - 0s 50us/step
# 172/172 [==============================] - 0s 34us/step
#
#
#  RESULTATS UP
#
# Accuracy: 73.26%
#  Precision: 61.82%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 94.44%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.94      0.58      0.72       100
#            1       0.62      0.94      0.75        72
#
#    micro avg       0.73      0.73      0.73       172
#    macro avg       0.78      0.76      0.73       172
# weighted avg       0.80      0.73      0.73       172
#
# [[58 42]
#  [ 4 68]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 81.98%
#  Precision: 83.75%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 78.82%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.83        87
#            1       0.84      0.79      0.81        85
#
#    micro avg       0.82      0.82      0.82       172
#    macro avg       0.82      0.82      0.82       172
# weighted avg       0.82      0.82      0.82       172
#
# [[74 13]
#  [18 67]]
#
#
# Deep Learning executed in = 90.260000 seconds
#  Boucle  220 terminée...Opération restantes : 285 / 505
#
#  Problème loop :  220
#  --- Loop : 221  ---  --- Symbol :   HOG   ---  --- Name :  Harley-Davidson  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  1.1143285243837373
#  Alpha :  -0.16734413594273936
#  R_Squared :  0.2852725539009957
#  Volatility :  0.25608340060565
#  Momentum :  -0.154229713338346
# executed in = 7.780000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:21:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.300000 seconds
#  Deeping in blue
#
#  --- Loop : 221  ---  --- Symbol :   HOG   ---  --- Name :  Harley-Davidson  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 888us/step
# 883/883 [==============================] - 1s 770us/step
# 172/172 [==============================] - 0s 39us/step
# 172/172 [==============================] - 0s 39us/step
#
#
#  RESULTATS UP
#
# Accuracy: 92.44%
#  Precision: 94.19%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 91.01%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92        83
#            1       0.94      0.91      0.93        89
#
#    micro avg       0.92      0.92      0.92       172
#    macro avg       0.92      0.92      0.92       172
# weighted avg       0.93      0.92      0.92       172
#
# [[78  5]
#  [ 8 81]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 88.37%
#  Precision: 89.55%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 82.19%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90        99
#            1       0.90      0.82      0.86        73
#
#    micro avg       0.88      0.88      0.88       172
#    macro avg       0.89      0.88      0.88       172
# weighted avg       0.88      0.88      0.88       172
#
# [[92  7]
#  [13 60]]
#
#
# Deep Learning executed in = 93.910000 seconds
#  Boucle  221 terminée...Opération restantes : 284 / 505
#
#  Problème loop :  221
#  --- Loop : 222  ---  --- Symbol :   HRS   ---  --- Name :  Harris Corporation  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  0.8254090904986716
#  Alpha :  0.16524065971131896
#  R_Squared :  0.2342560613160849
#  Volatility :  0.20932543617671195
#  Momentum :  0.14044349716440085
# executed in = 15.460000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1094
# On 80% - 20% slash :
# Bloc 1 :  875
# Bloc 2 : 219  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-20 00:00:00
# Last period : 2019-07-05 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:22:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.880000 seconds
#  Deeping in blue
#
#  --- Loop : 222  ---  --- Symbol :   HRS   ---  --- Name :  Harris Corporation  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 875/875 [==============================] - 1s 816us/step
# 875/875 [==============================] - 1s 843us/step
# 170/170 [==============================] - 0s 36us/step
# 170/170 [==============================] - 0s 36us/step
#
#
#  RESULTATS UP
#
# Accuracy: 68.24%
#  Precision: 61.54%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 82.05%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.79      0.57      0.66        92
#            1       0.62      0.82      0.70        78
#
#    micro avg       0.68      0.68      0.68       170
#    macro avg       0.70      0.69      0.68       170
# ...
#  Alpha :  0.08447220492161633
#  R_Squared :  0.25516674552374197
#  Volatility :  0.24481557318357688
#  Momentum :  0.103238285256811
# executed in = 6.450000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:26:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.730000 seconds
#  Deeping in blue
#
#  --- Loop : 224  ---  --- Symbol :   HAS   ---  --- Name :  Hasbro Inc.  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 861us/step
# 883/883 [==============================] - 1s 888us/step
# 172/172 [==============================] - 0s 38us/step
# 172/172 [==============================] - 0s 36us/step
#
#
#  RESULTATS UP
#
# Accuracy: 81.98%
#  Precision: 87.50%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 70.89%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.79      0.91      0.85        93
#            1       0.88      0.71      0.78        79
#
#    micro avg       0.82      0.82      0.82       172
#    macro avg       0.83      0.81      0.81       172
# weighted avg       0.83      0.82      0.82       172
#
# [[85  8]
#  [23 56]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 84.30%
#  Precision: 80.49%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.71%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85        95
#            1       0.80      0.86      0.83        77
#
#    micro avg       0.84      0.84      0.84       172
#    macro avg       0.84      0.84      0.84       172
# weighted avg       0.85      0.84      0.84       172
#
# [[79 16]
#  [11 66]]
#
#
# Deep Learning executed in = 98.500000 seconds
#  Boucle  224 terminée...Opération restantes : 281 / 505
#
#  Problème loop :  224
#  --- Loop : 225  ---  --- Symbol :   HCA   ---  --- Name :  HCA Holdings  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  0.9209508942859079
#  Alpha :  0.09249427089616077
#  R_Squared :  0.20678949429179028
#  Volatility :  0.24858242140083717
#  Momentum :  0.13544588116522505
# executed in = 18.530000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:28:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.260000 seconds
#  Deeping in blue
#
#  --- Loop : 225  ---  --- Symbol :   HCA   ---  --- Name :  HCA Holdings  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 925us/step
# 883/883 [==============================] - 1s 935us/step
# 172/172 [==============================] - 0s 49us/step
# 172/172 [==============================] - 0s 46us/step
#
#
#  RESULTATS UP
#
# Accuracy: 72.67%
#  Precision: 67.27%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 87.06%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.82      0.59      0.68        87
#            1       0.67      0.87      0.76        85
#
#    micro avg       0.73      0.73      0.73       172
#    macro avg       0.75      0.73      0.72       172
# weighted avg       0.75      0.73      0.72       172
#
# [[51 36]
#  [11 74]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 75.58%
#  Precision: 82.69%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 56.58%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.72      0.91      0.81        96
#            1       0.83      0.57      0.67        76
#
#    micro avg       0.76      0.76      0.76       172
#    macro avg       0.78      0.74      0.74       172
# weighted avg       0.77      0.76      0.75       172
#
# [[87  9]
#  [33 43]]
#
#
# Deep Learning executed in = 101.200000 seconds
#  Boucle  225 terminée...Opération restantes : 280 / 505
#
#  Problème loop :  225
#  --- Loop : 226  ---  --- Symbol :   HCP   ---  --- Name :  HCP Inc.  ---  --- Sector :  Real Estate  ---
# Scraping data...
# Beta :  0.3673747839412393
#  Alpha :  -0.004845166916021271
#  R_Squared :  0.04714051449803802
#  Volatility :  0.20768750080377582
#  Momentum :  0.29059850669395804
# executed in = 18.480000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:30:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.510000 seconds
#  Deeping in blue
#
#  --- Loop : 226  ---  --- Symbol :   HCP   ---  --- Name :  HCP Inc.  ---  --- Sector :  Real Estate  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 975us/step
# 883/883 [==============================] - 1s 967us/step
# 172/172 [==============================] - 0s 47us/step
# 172/172 [==============================] - 0s 42us/step
#
#
#  RESULTATS UP
#
# Accuracy: 79.65%
#  Precision: 67.89%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.64      0.78        98
#            1       0.68      1.00      0.81        74
#
#    micro avg       0.80      0.80      0.80       172
#    macro avg       0.84      0.82      0.80       172
# weighted avg       0.86      0.80      0.79       172
#
# [[63 35]
#  [ 0 74]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 87.21%
#  Precision: 80.61%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 96.34%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.96      0.79      0.87        90
#            1       0.81      0.96      0.88        82
#
#    micro avg       0.87      0.87      0.87       172
#    macro avg       0.88      0.88      0.87       172
# weighted avg       0.89      0.87      0.87       172
#
# [[71 19]
#  [ 3 79]]
#
#
# Deep Learning executed in = 104.800000 seconds
#  Boucle  226 terminée...Opération restantes : 279 / 505
#
#  Problème loop :  226
#  --- Loop : 227  ---  --- Symbol :   HP   ---  --- Name :  Helmerich & Payne  ---  --- Sector :  Energy  ---
# Scraping data...
# Beta :  1.5276402336697914
#  Alpha :  -0.09748687141320035
#  R_Squared :  0.27669020311281467
#  Volatility :  0.3564694963829117
#  Momentum :  -0.12380671549795319
# executed in = 26.280000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:32:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.770000 seconds
#  Deeping in blue
#
#  --- Loop : 227  ---  --- Symbol :   HP   ---  --- Name :  Helmerich & Payne  ---  --- Sector :  Energy  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 996us/step
# 883/883 [==============================] - 1s 998us/step
# 172/172 [==============================] - 0s 51us/step
# 172/172 [==============================] - 0s 43us/step
#
#
#  RESULTATS UP
#
# Accuracy: 85.47%
#  Precision: 87.36%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 84.44%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85        82
#            1       0.87      0.84      0.86        90
#
#    micro avg       0.85      0.85      0.85       172
#    macro avg       0.85      0.86      0.85       172
# weighted avg       0.86      0.85      0.85       172
#
# [[71 11]
#  [14 76]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 84.88%
#  Precision: 76.09%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 94.59%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.95      0.78      0.85        98
#            1       0.76      0.95      0.84        74
#
#    micro avg       0.85      0.85      0.85       172
#    macro avg       0.86      0.86      0.85       172
# weighted avg       0.87      0.85      0.85       172
#
# [[76 22]
#  [ 4 70]]
#
#
# Deep Learning executed in = 107.610000 seconds
#  Boucle  227 terminée...Opération restantes : 278 / 505
#
#  Problème loop :  227
#  --- Loop : 228  ---  --- Symbol :   HSIC   ---  --- Name :  Henry Schein  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  0.8514244175520043
#  Alpha :  -0.007682723896229229
#  R_Squared :  0.24251321513837076
#  Volatility :  0.21221524142130588
#  Momentum :  0.08377409245881551
# executed in = 14.350000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:35:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.120000 seconds
#  Deeping in blue
#
#  --- Loop : 228  ---  --- Symbol :   HSIC   ---  --- Name :  Henry Schein  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 1ms/step
# 883/883 [==============================] - 1s 1ms/step
# 172/172 [==============================] - 0s 51us/step
# 172/172 [==============================] - 0s 49us/step
#
#
#  RESULTATS UP
#
# Accuracy: 91.86%
#  Precision: 78.79%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94       120
#            1       0.79      1.00      0.88        52
#
#    micro avg       0.92      0.92      0.92       172
#    macro avg       0.89      0.94      0.91       172
# weighted avg       0.94      0.92      0.92       172
#
# [[106  14]
#  [  0  52]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 91.86%
#  Precision: 90.52%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 97.22%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.95      0.83      0.88        64
#            1       0.91      0.97      0.94       108
#
#    micro avg       0.92      0.92      0.92       172
#    macro avg       0.93      0.90      0.91       172
# weighted avg       0.92      0.92      0.92       172
#
# [[ 53  11]
#  [  3 105]]
#
#
# Deep Learning executed in = 110.320000 seconds
#  Boucle  228 terminée...Opération restantes : 277 / 505
#
#  Problème loop :  228
#  --- Loop : 229  ---  --- Symbol :   HES   ---  --- Name :  Hess Corporation  ---  --- Sector :  Energy  ---
# Scraping data...
# Beta :  2.0299459487432086
#  Alpha :  -0.11522932266935115
#  R_Squared :  0.3842035345960576
#  Volatility :  0.40197771010066863
#  Momentum :  -0.06041253847101824
# executed in = 8.150000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:37:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.370000 seconds
#  Deeping in blue
#
#  --- Loop : 229  ---  --- Symbol :   HES   ---  --- Name :  Hess Corporation  ---  --- Sector :  Energy  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 1ms/step
# 883/883 [==============================] - 1s 1ms/step
# 172/172 [==============================] - 0s 55us/step
# 172/172 [==============================] - 0s 53us/step
#
#
#  RESULTATS UP
#
# Accuracy: 91.86%
#  Precision: 93.83%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 89.41%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92        87
#            1       0.94      0.89      0.92        85
#
#    micro avg       0.92      0.92      0.92       172
#    macro avg       0.92      0.92      0.92       172
# weighted avg       0.92      0.92      0.92       172
#
# [[82  5]
#  [ 9 76]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 88.95%
#  Precision: 91.30%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 82.89%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90        96
#            1       0.91      0.83      0.87        76
#
#    micro avg       0.89      0.89      0.89       172
#    macro avg       0.89      0.88      0.89       172
# weighted avg       0.89      0.89      0.89       172
#
# [[90  6]
#  [13 63]]
#
#
# Deep Learning executed in = 114.780000 seconds
#  Boucle  229 terminée...Opération restantes : 276 / 505
#
#  Problème loop :  229
#  --- Loop : 230  ---  --- Symbol :   HPE   ---  --- Name :  Hewlett Packard Enterprise  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.5886881719486812
#  Alpha :  0.04812466130101792
#  R_Squared :  0.3871878591068748
#  Volatility :  0.301834185276627
#  Momentum :  -0.009798565700686601
# executed in = 9.360000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  944
# On 80% - 20% slash :
# Bloc 1 :  755
# Bloc 2 : 189  periods
# First period : 2015-10-19 00:00:00
# Split period : 2018-10-16 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [19:39:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.970000 seconds
#  Deeping in blue
#
#  --- Loop : 230  ---  --- Symbol :   HPE   ---  --- Name :  Hewlett Packard Enterprise  ---  --- Sector :  Information Technology  ---
# Processing move_up

# %%
#import sys
#orig_stdout = sys.stdout
#f = open('backtestv2_4.txt', 'w')
#sys.stdout = f

# %%
#f.close()
#sys.stdout = orig_stdout

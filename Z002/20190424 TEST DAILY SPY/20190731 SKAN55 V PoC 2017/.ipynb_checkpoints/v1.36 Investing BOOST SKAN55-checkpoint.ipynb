# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
print('Importing Librairies...')
import talib
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import xgboost as xgb
from xgboost import XGBRegressor, plot_importance
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')
import time
import datetime as dt
import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
print('Librairies imported')
print('')

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print('BOOST SKAN 55 Version v1.35',Style.RESET_ALL)



print('')
print('Sraping tickers')
constituents = pd.read_csv('constituents_csv.csv')
print('Scrap -----> ok')
# PARAMETRES TEMPORELS INITIAUX
start = pd.to_datetime('2013-01-06')
end = pd.to_datetime('2017-12-31')

error = []


try :
    amorce = pd.read_csv('backTest.csv').index[-1] + 1
except:
    amorce = 0
    backtest = pd.DataFrame(columns = ['Symb.','Name','Sector','Period','Begin.','End',\
                          'Pnl $','Pnl %','Gross Profit','Gross Loss','# Winners','# Loosers',\
                          '% Winners','MaxDD $','MaxDD %','Aver. Win $',\
                          'Aver. Loos $','Aver. Duration',\
                          'Total Trades','% Long','% Short','Profit Factor'])
    
    
try:
    amorce2 = pd.read_csv('SIGNALS.csv').index[-1] + 1
except:
    amorce2 = 0
    signals = pd.DataFrame(columns = ['Date','Ticker','Open Long','Close Long','Open Short','Close Short','Buy/Sell Price','Quantity','PNL','Cumulative PNL','Latent PNL'])

    
# SCRAPING DES DONNES BRUTES
def scrap_data(ticker,start,end):
    df = web.DataReader(ticker,'yahoo',start,end)
    df = df.drop(['Close'],axis=1)
    df['Close'] = df['Adj Close']
    df = df.drop(['Adj Close'],axis = 1)    
    return(df)

def prepa_data(df):
    tmps1=time.time()
    print('Preparing data...')
    rsi = talib.RSI(df['Close'],timeperiod=14)
    stoc_slowk, stoc_slowd = talib.STOCH(df['High'],df['Low'],df['Close'])
    upper, middle, lower =  talib.BBANDS(df['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(df['Close'],timeperiod=5)
    sma8 = talib.SMA(df['Close'],timeperiod=8)
    sma10 = talib.SMA(df['Close'],timeperiod=10)
    sma12 = talib.SMA(df['Close'],timeperiod=12)
    sma15 = talib.SMA(df['Close'],timeperiod=15)
    sma30 = talib.SMA(df['Close'],timeperiod=30)
    sma35 = talib.SMA(df['Close'],timeperiod=35)
    sma40 = talib.SMA(df['Close'],timeperiod=40)
    sma45 = talib.SMA(df['Close'],timeperiod=45)
    sma50 = talib.SMA(df['Close'],timeperiod=50)
    atr = talib.ATR(df['High'],df['Low'],df['Close'],timeperiod=10)
    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50
    bbdelta = upper - middle
    price_bolup = df['Close'] - lower
    price_bolow = df['Close'] - upper
    Ema = talib.EMA(df['Close'],timeperiod=20)
    KC_High = Ema + 2*atr
    KC_Low = Ema - 2*atr
    aroondown, aroonup = talib.AROON(df['High'], df['Low'], timeperiod=9)
    aroon = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
    rsi30_list = []
    rsi70_list = []
    for i in range(0,df.shape[0]):
        rsi70_list.append(70 - rsi[i])
        rsi30_list.append(rsi[i] - 30)
        #except:
         #   rsi70_list.append(0)
          #  rs30_list.append(0)
    varop_spy = df['Open'] - df['Close']
    varhl_spy = df['High'] - df['Low']
    df['Varop_Spy'] = varop_spy
    df['Varhl_spy'] = varhl_spy
    df['RSI'] = rsi
    df['70 - RSI'] = np.array(rsi70_list)
    df['RSI - 30'] = np.array(rsi30_list)
    df['BBD_Delta_Up'] = bbdelta
    df['delta5_8'] = delta5_8
    df['delta8_10'] = delta8_10
    df['delta10_12'] = delta10_12
    df['delta12_15'] = delta12_15
    df['delta15_30'] = delta15_30
    df['delta30_35'] = delta30_35
    df['delta35_40'] = delta35_40
    df['delta40_45'] = delta40_45
    df['delta45_50'] = delta45_50
    df['Stoc_Slowk'] = stoc_slowk
    df['Stoc_Slowd'] = stoc_slowd
    df['KC_High'] = KC_High
    df['KC_Low'] = KC_Low
    df['upper'] = upper
    df['lower'] = lower
    df['var_bollup_kchigh'] = upper-KC_High
    df['var_bolllow_kclow'] = lower-KC_Low
    df['Aroon Up'] = aroonup
    df['Aroon Down'] = aroondown
    df['Delta Aroon'] = aroon
    up = []
    down = []
    df = df.dropna()
    df = boost(df)
    df['%Futur'] = ((df['Close.S']-df['Close']) *100) / (df['Close'])
    df['%Futur2'] = ((df['Close.S2']-df['Close']) *100) / (df['Close'])
    for i in range(0,df.shape[0]-5):
        if df.iloc[i]['%Futur'] > 0.1 :#or df.iloc[i]['%Futur2'] > 0.1:
            up.append(1)
            down.append(0)
        elif df.iloc[i]['%Futur'] < -0.1: #or df.iloc[i]['%Futur2'] < -0.1:
            up.append(0)
            down.append(1)
        else:
            up.append(0)
            down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    
    
    df['target_up'] = up  # target_up # abs(np.array(valley))#target_up
    df['target_down'] = down # target_down # abs(np.array(peak))#target_down
    #df = df.dropna()
    tmps2=round(time.time()-tmps1,2)
    print ("Data prepared in = %f" %tmps2,'seconds')
    return(df)

def boost(df):
    print('Boosting')
    X = df.copy()
    X = X.drop(['Close'],axis=1)
    X['Close'] = df['Close']
    y = X.iloc[:,-1]
    Xtrain = X.iloc[:-2,:-1]
    Xtest = X.iloc[-2:-1,:-1]
    yshift = y.shift(-1)
    ytrain = yshift.iloc[:-2]
    ytest = yshift.iloc[-2:-1]

    model = xgb.XGBRegressor(n_estimators=20000, learning_rate=1, gamma=1, subsample=1, colsample_bytree=1, max_depth=100)

    model.fit( Xtrain, ytrain, early_stopping_rounds=150, eval_set=[(Xtest, ytest)], verbose=0)

    ytrain_pred = model.predict(Xtrain)

    y_pred = model.predict(Xtest)

    pred = model.predict(X.iloc[:,:-1])

    df['Close.S'] = pred
    df['Close.S2'] = df['Close.S']
    df = df.dropna()
    print('Boost ok')
    return(df)

    
def deep_learning(df):
    tmps1=time.time()
    X = df.iloc[:,1:-4]
    y_up = df.iloc[:,-2].values
    y_down = df.iloc[:,-1].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:bloc1,:]
    Xtest = X[bloc1:,:]
    ytrain_up = y_up[:bloc1,:]
    ytest_up = y_up[bloc1:,:]
    ytrain_down = y_down[:bloc1,:]
    ytest_down = y_down[bloc1:,:]

    seed = 770
    np.random.seed(seed)

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    model_up = Sequential()
    # Add an input layer 
    model_up.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_up.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_up.add(Dense(1, activation='sigmoid'))

    model_down = Sequential()
    # Add an input layer 
    model_down.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_down.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_down.add(Dense(1, activation='sigmoid'))

    print('Processing move_up')
    model_up.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])
    
              

    history_up = model_up.fit(Xtrain, ytrain_up,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Processing move_down')
    model_down.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])

    history_down = model_down.fit(Xtrain, ytrain_down,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Computing done')
    print('\n')

    train_acc_up = model_up.evaluate(Xtrain, ytrain_up,verbose=1)
    train_acc_down = model_down.evaluate(Xtrain, ytrain_down,verbose=1)

    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    score_up = model_up.evaluate(Xtest, ytest_up,verbose=1)
    score_down = model_down.evaluate(Xtest, ytest_down,verbose=1)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)

    accuracy_up = accuracy_score(ytest_up, yhat_up)
    accuracy_down = accuracy_score(ytest_down, yhat_down)

    # La précision permet de mesurer la capacité du modèle à refuser résultats non-pertinents : vrais_positifs/(vrais_positifs+faux_positifs)
    precision_up = precision_score(ytest_up, yhat_up)  
    precision_down = precision_score(ytest_down, yhat_down) 


    # Recall : (vrai_positifs/(vrais_positifs+faux_négatifs))
    recall_up = recall_score(ytest_up, yhat_up) 
    recall_down = recall_score(ytest_down, yhat_down) 


    #roc_up=roc_auc_score(ytest_up,yhat_up)
    #roc_down=roc_auc_score(ytest_down,yhat_down)
    print('\n')
    print(Fore.GREEN,'RESULTATS UP\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_up * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_up *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_up * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_up *100))
    # get probabilities for positive class

    print(classification_report(ytest_up, yhat_up))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_up, yhat_up))

    print('\n')
    print('_______________________________________________________________________________________________________________________________________________________________\n')
    print(Fore.RED,'RESULTATS DOWN\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_down * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_down *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_down * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_down *100))
    # get probabilities for positive class

    print(classification_report(ytest_down, yhat_down))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_down, yhat_down))
    print('\n')

    resultats = pd.DataFrame()
    resultats['Date'] = df.index[bloc1:]
    resultats.index= df.index[bloc1:]
    resultats['Move Up'] = yhat_up
    resultats['Confiance up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confiance Down'] = (predict_down)*100
    resultats['Actual'] = df.iloc[bloc1:]['Close']
    resultats['Actual.S'] = df.iloc[bloc1:]['Close.S']
    open_S = df['Open'].shift(-1)
    resultats['Open.S'] = open_S.iloc[bloc1:]
    dmp_cp=[]
    dmp_cp = ((resultats['Confiance up']-resultats['Confiance Down'])/(resultats['Confiance up']+resultats['Confiance Down'])*100)
    resultats['DMP_CP'] = dmp_cp
    tmps2=round(time.time()-tmps1,2)
    print ("Deep Learning executed in = %f" %tmps2,'seconds')
    #resultats.set_index('Date',inplace=True)
    #parse_dates=resultats['Date']
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def learn(df):
    resultats,precision_up,precision_down,model_up,model_down,scaler = deep_learning(df)
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def grobeta(df,dfb):
    # create a time-series of monthly data points
    rts = df.resample('M').last()
    rbts = dfb.resample('M').last()
    dfsm = pd.DataFrame({'s_adjclose' : rts['Close'],
                            'b_adjclose' : rbts['Adj Close']},
                            index=rts.index)

    # compute returns
    dfsm[['s_returns','b_returns']] = dfsm[['s_adjclose','b_adjclose']]/\
        dfsm[['s_adjclose','b_adjclose']].shift(1) -1
    dfsm = dfsm.dropna()
    covmat = np.cov(dfsm["s_returns"],dfsm["b_returns"])

    # calculate measures now
    beta = covmat[0,1]/covmat[1,1]
    alpha= np.mean(dfsm["s_returns"])-beta*np.mean(dfsm["b_returns"])

    # r_squared     = 1. - SS_res/SS_tot
    ypred = alpha + beta * dfsm["b_returns"]
    SS_res = np.sum(np.power(ypred-dfsm["s_returns"],2))
    SS_tot = covmat[0,0]*(len(dfsm)-1) # SS_tot is sample_variance*(n-1)
    r_squared = 1. - SS_res/SS_tot
    # 5- year volatiity and 1-year momentum
    volatility = np.sqrt(covmat[0,0])
    momentum = np.prod(1+dfsm["s_returns"].tail(12).values) -1

    # annualize the numbers
    prd = 12. # used monthly returns; 12 periods to annualize
    alpha = alpha*prd
    volatility = volatility*np.sqrt(prd)

    print ('Beta : ',beta,'\n Alpha : ',alpha,'\n R_Squared : ', r_squared, '\n Volatility : ', volatility, '\n Momentum : ',momentum)
    return(beta,alpha,r_squared,volatility,momentum)

########################
#### MAIN SKAN55 #######
########################

for loop in range(0,49):    
#for loop in range(amorce,len(constituents)):
    print('Loop :',loop)
    print('amorce : ',amorce)
    print('amorce2 : ',amorce2)
    
    try:

        ticker = (constituents.iloc[loop]['Symbol'])
        name = constituents.iloc[loop]['Name']
        sector = constituents.iloc[loop]['Sector']

        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        global delta,bloc1,bloc2
        tmps1=time.time()
        print('Scraping data...')

        df = scrap_data(ticker,start,end)

        dfb = web.DataReader('^GSPC','yahoo',start,end)

        beta,alpha, r_squared, volatility, momentum = grobeta(df,dfb)

        tmps2=round(time.time()-tmps1,2)
        print ("executed in = %f" %tmps2,'seconds')

        print('\n')
        print('GOLEM begins Computing...')
        print('\n')
        delta = round(df.shape[0])
        bloc1 = round(delta*0.80)
        bloc2 = delta - bloc1
        print("# of periods : ",delta)
        print('On 80% - 20% slash : ')
        print('Bloc 1 : ',bloc1,'\nBloc 2 :',bloc2,' periods ')
        print('First period :',df.index[0])
        print('Split period :',df.index[bloc1-1])
        print('Last period :',df.index[df.shape[0]-1])
        print('\n')

        print('Data prep')
        df = prepa_data(df)

        print(Fore.BLUE,'Deeping in blue',Style.RESET_ALL)
        print('')
        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        resultats,precision_up,precision_down,model_up,model_down,scaler = learn(df)

        import sys
        orig_stdout = sys.stdout
        f = open('backtest de '+str(ticker)+'.txt', 'w')
        sys.stdout = f

        ####################
        #### TEST PLOT ####
        ###################

        filtre_up = 93
        filtre_down = 97
        filtre_up_close = 80
        filtre_down_close = 80


        plt.figure(figsize=(26,8),dpi=300)
        #plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
        plt.title('Deep Learning '+name+' Trade Signals')
        plt.plot(resultats['Actual'],color='purple',lw=0.9,label=ticker)

        green=[]
        red=[]
        green_close=[]
        red_close=[]

        for i in range(0,len(resultats)-1):


            if resultats.iloc[i]['Confiance Down'] > filtre_down:
                doob = -1
            elif resultats.iloc[i]['Confiance Down'] > filtre_down_close and resultats.iloc[i]['Confiance Down'] < filtre_down :
                waab = -1
                doob = 0
            elif resultats.iloc[i]['Confiance up'] > filtre_up:
                doob = 1
            elif resultats.iloc[i]['Confiance up'] > filtre_up_close and resultats.iloc[i]['Confiance up'] < filtre_up:
                waab = 1
                doob = 0
            else :
                doob = 0
                waab = 0

            if doob == 1 :#and resultats.iloc[i]['Confiance up'] > filtre_up:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='g',marker='o')
                #doob = -1
                green.append(1)
                red.append(0)
                green_close.append(0)
                red_close.append(1)

            elif doob == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(1)
                green_close.append(1)
                red_close.append(0)

            elif doob == 0 and waab == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(0)
                green_close.append(0)
                red_close.append(1)

            elif waab == 1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(0)
                green_close.append(1)
                red_close.append(0)  

            else:
                green.append(0)
                red.append(0)
                green_close.append(0)
                red_close.append(0)  

                #doob = 0


        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='g',marker='o',label='Buy Signal')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o',label='Sell Signal')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_01.pdf')
        plt.close()


        green.append(0)
        red.append(0)
        green_close.append(0)
        red_close.append(0)
        resultats['Green'] = green
        resultats['Red'] = red
        resultats['Green_Close'] = green_close
        resultats['Red_Close'] = red_close
        #resultats['Actual'] = df['Close'][bloc1:]

        ########################
        ####### BACKTEST########
        ########################
        pos_long = 0
        pos_short = 0
        pactol = 10000/beta
        price_buy = 0
        price_sell = 0
        x = 0
        winners = []
        loosers = []
        nb_win = 0
        nb_los = 0
        mini_pnl = 0
        pos_duration = []
        average_duration = resultats.iloc[0,0] - resultats.iloc[0,0]
        trades = []
        eq_curx = []
        eq_cury = []
        maxdd = []
        nbS = 0
        nbL = 0

        for i in range(0,len(resultats)-1):
            if pos_long == 0 and pos_short == 0 and resultats.iloc[i]['Green'] == 1 :
                pos_long = 1
                nbL+=1
                x = round((10000/beta)/resultats.iloc[i]['Open.S'])
                price_buy = round(resultats.iloc[i]['Open.S'],2)
                time_enter = resultats.iloc[i]['Date']

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 1,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':0}],ignore_index=True)

                print('\n Le ',str(resultats.iloc[i]['Date']),', achat de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',round(pactol,2))
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],1))

            elif pos_long == 1 and resultats.iloc[i]['Green_Close'] == 0 :

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':round((resultats.iloc[i]['Open.S'] - price_buy)*x,2)}],ignore_index=True)
                try:
                    maxdd.append(round((resultats.iloc[i]['Open.S'] - price_buy)*x,2))
                except:
                    print('Null val of maxdd')
                    maxdd.append('Null')


            elif pos_long == 1 and resultats.iloc[i]['Green_Close'] == 1 :
                old_pactol = round(pactol,2)
                eq_curx.append(resultats.iloc[i]['Date'])
                eq_cury.append(old_pactol)
                pos_long = 0
                price_sell = round(resultats.iloc[i]['Open.S'],2)
                mini_pnl = round(x*(price_sell-price_buy),2)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],2))

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 1, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : mini_pnl,\
                                           'Cumulative PNL':round(signals.iloc[:i]['PNL'].sum(),2),'Latent PNL':0}],ignore_index=True)

                pactol = round((pactol + mini_pnl),2)
                print('\n Le ',str(resultats.iloc[i]['Date']),', vente pour close de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)
                print('pnl:', mini_pnl)
                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                pos_duration.append(resultats.iloc[i]['Date'] - time_enter)

                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1


            elif pos_short == 0 and pos_long == 0 and resultats.iloc[i]['Red']:
                pos_short = 1
                nbS+=1
                x = round((10000/beta)/resultats.iloc[i]['Open.S'])
                price_sell = round(resultats.iloc[i]['Open.S'],2)
                time_enter = resultats.iloc[i]['Date']

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 1, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

                print('\n Le ',str(resultats.iloc[i]['Date']),', vente de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],-1))


            elif pos_short == 1 and resultats.iloc[i]['Red_Close'] == 0 :

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':-round((resultats.iloc[i]['Open.S'] - price_sell)*x,2)}],ignore_index=True)
                try:
                    maxdd.append(round((resultats.iloc[i]['Open.S'] - price_sell)*x,2))
                except:
                    print('Null val of maxdd')
                    maxdd.append(0)

            elif pos_short == 1 and resultats.iloc[i]['Red_Close'] == 1 :
                old_pactol = round(pactol,2)
                eq_curx.append(resultats.iloc[i]['Date'])
                eq_cury.append(old_pactol)
                pos_short = 0
                price_buy = round(resultats.iloc[i]['Open.S'],2)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],-2))
                mini_pnl = round(x*(price_sell-price_buy),2)

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 1,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : mini_pnl,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

                pactol = round((pactol + mini_pnl),2)
                print('\n Le ',str(resultats.iloc[i]['Date']),', achat pour close de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)

                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                print('pnl:', mini_pnl)
                pos_duration.append(resultats.iloc[i]['Date'] - time_enter)
                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1
            else:

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                               'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                               'Buy/Sell Price' : 0, 'Quantity' : 0, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

        if pos_long == 1:
            pos_long = 0
            print('Cutting non resolved position')
            print(' Le price buy était de : ',price_buy)
            x = round((10000/beta)/resultats.iloc[i]['Open.S'])
            print('x = ',x)
            price_sell = round(resultats.iloc[i]['Open.S'],2)
            print('Et le price sell : ',price_sell)
            mini_pnl = round(x*(price_sell-price_buy),2)

            signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 1, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : mini_pnl,\
                                       'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

            pactol = round((pactol + mini_pnl),2)
            print('pnl : ',mini_pnl)
            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1


        if pos_short == 1:
            pos_short = 0
            print('Cutting non resolved position')
            print(' Le price sell était de : ',price_sell)
            x = round((10000/beta)/resultats.iloc[i]['Open.S'])
            print('x = ',x)
            price_buy = round(resultats.iloc[i]['Open.S'],2)
            print('Et le price_buy : ',price_buy)
            mini_pnl = round(x*(price_sell-price_buy),2)

            signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 1,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : mini_pnl,\
                                       'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

            pactol = round((pactol + mini_pnl),2)
            print('pnl : ',mini_pnl)

            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1


        pnl = round(pactol - (10000/beta),2)
        print('\n Begining of BackTest :',resultats.iloc[0]['Date'])
        print('Instrument :',ticker)
        print('Face value per trade : $',10000/beta)
        print('End of BackTest :',resultats.iloc[-1]['Date'])
        duration = pd.to_timedelta((resultats.iloc[-1]['Date'] - resultats.iloc[0]['Date']),unit='d')
        print("BackTest's period :",duration)
        print('Pnl :',round(pnl,2),'$')
        print('% Pnl : ',round(pnl/(10000/beta)*100,2))
        print('Total winners :',round(sum(winners),2),'$')
        print('Total loosers :',round(sum(loosers),2),'$')
        print('Number of winners :',round(nb_win))
        print('Number of loosers :',round(nb_los))
        print('Maximum Drawdown : ',round(min(maxdd),2))
        print('% Max Drawdown : ',round(min(maxdd)/(10000/beta)*100,2),'%')
        print('Nombre toatl de trades : ',round(nbL+nbS,2))
        print('% de trades Long : ',round((nbL*100)/(nbL+nbS),2))
        print('% de trades Short : ',round((nbS*100)/(nbL+nbS),2))
        try:
            print('% winners :', round((nb_win/(nb_win+nb_los) * 100),2),'%')
            print('Average winners :',(round(sum(winners)/(nb_win))))
        except:
            print('% winners : null')
        try:
            print('Average losers :',(round(sum(loosers)/(nb_los))))
        except:
            print('Average losers : Inf')
        try:
            for t in range(0,len(pos_duration)):
                average_duration = pd.to_timedelta((average_duration + pos_duration[t]),unit='d')
            average_duration = average_duration/(nb_los+nb_win)
            print('Average Duration :', average_duration)
        except:
            print('No Average Duration available')
        try:
            print('Profit Factor : ',abs(round((sum(winners)/sum(loosers)),2)))
        except:
            print('Profit Factor : null')

        ########################
        ##### PLOT TRADES ######
        ########################

        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Trades')
        plt.plot(resultats['Open.S'],color='blue',lw=0.9)
        for i in range(0,len(trades)):
            if trades[i][2] == 1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='green',marker='^',lw=2.5)
            elif trades[i][2] == -1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='red',marker='^',lw=2.5)
            elif trades[i][2] == 2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='g',marker='x',lw=2.5)
            elif trades[i][2] == -2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='r',marker='x',lw=2.5)

        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='g',marker='^',label='Open Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='r',marker='^',label='Open Short')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='g',marker='x',label='Close Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='r',marker='x',label='Close Short')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_02.pdf')
        plt.close()

        #########################
        ##### PLOT E-CURVE ######
        #########################
        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Equity Curve')
        plt.plot(eq_curx,eq_cury)
        plt.scatter(x=eq_curx,y=eq_cury,c='orange',marker='o',lw=2.5)
        plt.savefig('backtest de '+str(ticker)+'_03.pdf')
        plt.close()


        f.close()
        sys.stdout = orig_stdout

        print('\r Boucle ', loop, 'terminée...',end='')
        print('Opération restantes :', len(constituents)-loop,'/',len(constituents),'\n')


        backtest = backtest.append([{'Symb.':ticker,'Name':name,'Sector':sector,'Period':duration,'Begin.':resultats.iloc[0,0],'End':resultats.iloc[-1,0],\
                          'Pnl $':pnl,'Pnl %':round(pnl/(10000/beta)*100,2),'Gross Profit':round(sum(winners),2),'Gross Loss':round(sum(loosers),2),'# Winners':nb_win,'# Loosers':nb_los,\
                          '% Winners':round((nb_win/(nb_win+nb_los) * 100),2),'MaxDD $':round(min(maxdd),2),'MaxDD %':round(min(maxdd)/(10000/beta)*100,2),'Aver. Win $':(round(sum(winners)/(nb_win))),\
                          'Aver. Loos $':(round(sum(loosers)/(nb_los))),'Aver. Duration':average_duration,\
                          'Total Trades':nbL+nbS,'% Long':round((nbL*100)/(nbL+nbS),2),'% Short':round((nbS*100)/(nbL+nbS),2), 'Profit Factor':abs(round((sum(winners)/sum(loosers)),2))}], ignore_index=True)


        #signals = signals.append([{ 'Date': list_signals[0], 'Ticker' : list_signals[8], 'Open Long' : list_signals[1],\
                                   #'Close Long' : list_signals[2], 'Open Short' : list_signals[3], 'Close Short' : list_signals[4],\
                                   #'Buy/Sell Price' : list_signals[5], 'Quantity' : list_signals[6], ' tPNL' : list_signals[7]}])

        #signals['Date'] = list_signals[0]
        #signals['Ticker'] = list_signals[8]
        #signals['Open Long'] = list_signals[1]
        #signals['Close Long'] = list_signals[2]
        #signals['Open Short'] = list_signals[3]
        #signals['Close Short'] = list_signals[4]
        #signals['Buy/Sell Price'] = list_signals[5]
        #signals['Quantity'] = list_signals[6]
        #signals['tPNL'] = list_signals[7]

    # symbol / name / sector / period of backtest / debut / fin / pnl / total winners / total loosers / Nb winners / nb loosers / 
    # / % winners / Max DD / Aver Win / Aver Loos / Average duration / Profit Factor
        print(Fore.YELLOW,'Writing BACKTEST CSV AND SIGNALS.CSV',Style.RESET_ALL)
        backtest.to_csv('BackTest.csv')
        signals.sort_values(by=['Date'])
        signals.to_csv('SIGNALS.csv')

        print(Fore.CYAN,'BACKTEST CSV WRITED AND SIGNALS.CSV',Style.RESET_ALL)
    except:
        print(Fore.RED,'Problème loop : ',loop,Style.RESET_ALL)
        error.append((loop,ticker))
         
        continue
# Out:
# Importing Librairies...
# Using TensorFlow backend.
# Librairies imported
#
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
# BOOST SKAN 55 Version v1.35
#
# Sraping tickers
# Scrap -----> ok
# Loop : 0
# amorce :  0
# amorce2 :  0
#  --- Loop : 0  ---  --- Symbol :   MMM   ---  --- Name :  3M Company  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.0772113491444626
#  Alpha :  0.07697177114950401
#  R_Squared :  0.5099783599499867
#  Volatility :  0.14135599351343467
#  Momentum :  0.349037445860489
# executed in = 2.560000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:31:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.500000 seconds
#  Deeping in blue
#
#  --- Loop : 0  ---  --- Symbol :   MMM   ---  --- Name :  3M Company  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 69us/step
# 1005/1005 [==============================] - 0s 68us/step
# 202/202 [==============================] - 0s 21us/step
# 202/202 [==============================] - 0s 23us/step
#
#
#  RESULTATS UP
#
# Accuracy: 68.32%
#  Precision: 65.05%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 70.53%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.72      0.66      0.69       107
#            1       0.65      0.71      0.68        95
#
#    micro avg       0.68      0.68      0.68       202
#    macro avg       0.68      0.68      0.68       202
# weighted avg       0.69      0.68      0.68       202
#
# [[71 36]
#  [28 67]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 72.77%
#  Precision: 75.86%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 31.43%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.72      0.95      0.82       132
#            1       0.76      0.31      0.44        70
#
#    micro avg       0.73      0.73      0.73       202
#    macro avg       0.74      0.63      0.63       202
# weighted avg       0.74      0.73      0.69       202
#
# [[125   7]
#  [ 48  22]]
#
#
# Deep Learning executed in = 72.120000 seconds
#  Boucle  0 terminée...Opération restantes : 505 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 1
# amorce :  0
# amorce2 :  0
#  --- Loop : 1  ---  --- Symbol :   AOS   ---  --- Name :  A.O. Smith Corp  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.5525507363017752
#  Alpha :  0.11216263163215727
#  R_Squared :  0.4747211011047955
#  Volatility :  0.2111619745409384
#  Momentum :  0.30781094612703463
# executed in = 6.340000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:32:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.530000 seconds
#  Deeping in blue
#
#  --- Loop : 1  ---  --- Symbol :   AOS   ---  --- Name :  A.O. Smith Corp  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 144us/step
# 1005/1005 [==============================] - 0s 141us/step
# 202/202 [==============================] - 0s 30us/step
# 202/202 [==============================] - 0s 34us/step
#
#
#  RESULTATS UP
#
# Accuracy: 56.93%
#  Precision: 51.90%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 88.17%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.75      0.30      0.43       109
#            1       0.52      0.88      0.65        93
#
#    micro avg       0.57      0.57      0.57       202
#    macro avg       0.63      0.59      0.54       202
# weighted avg       0.64      0.57      0.53       202
#
# [[33 76]
#  [11 82]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 63.86%
#  Precision: 51.40%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 72.37%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.78      0.59      0.67       126
#            1       0.51      0.72      0.60        76
#
#    micro avg       0.64      0.64      0.64       202
#    macro avg       0.65      0.66      0.64       202
# weighted avg       0.68      0.64      0.64       202
#
# [[74 52]
#  [21 55]]
#
#
# Deep Learning executed in = 84.310000 seconds
#  Boucle  1 terminée...Opération restantes : 504 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 2
# amorce :  0
# amorce2 :  0
#  --- Loop : 2  ---  --- Symbol :   ABT   ---  --- Name :  Abbott Laboratories  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.5561377527465479
#  Alpha :  -0.0449986194791941
#  R_Squared :  0.5786422955744501
#  Volatility :  0.19170442278751046
#  Momentum :  0.5202818107092471
# executed in = 2.180000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:34:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.020000 seconds
#  Deeping in blue
#
#  --- Loop : 2  ---  --- Symbol :   ABT   ---  --- Name :  Abbott Laboratories  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 151us/step
# 1005/1005 [==============================] - 0s 154us/step
# 202/202 [==============================] - 0s 25us/step
# 202/202 [==============================] - 0s 25us/step
#
#
#  RESULTATS UP
#
# Accuracy: 81.68%
#  Precision: 82.83%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.39%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82       100
#            1       0.83      0.80      0.82       102
#
#    micro avg       0.82      0.82      0.82       202
#    macro avg       0.82      0.82      0.82       202
# weighted avg       0.82      0.82      0.82       202
#
# [[83 17]
#  [20 82]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 68.81%
#  Precision: 100.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 16.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80       127
#            1       1.00      0.16      0.28        75
#
#    micro avg       0.69      0.69      0.69       202
#    macro avg       0.83      0.58      0.54       202
# weighted avg       0.79      0.69      0.61       202
#
# [[127   0]
#  [ 63  12]]
#
#
# Deep Learning executed in = 87.570000 seconds
#  Boucle  2 terminée...Opération restantes : 503 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 3
# amorce :  0
# amorce2 :  0
#  --- Loop : 3  ---  --- Symbol :   ABBV   ---  --- Name :  AbbVie Inc.  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.5498290871877638
#  Alpha :  0.06776749268685102
#  R_Squared :  0.4105361775017169
#  Volatility :  0.2266716841055298
#  Momentum :  0.6007488358020243
# executed in = 1.900000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:36:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.610000 seconds
#  Deeping in blue
#
#  --- Loop : 3  ---  --- Symbol :   ABBV   ---  --- Name :  AbbVie Inc.  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 303us/step
# 1005/1005 [==============================] - 0s 293us/step
# 202/202 [==============================] - 0s 39us/step
# 202/202 [==============================] - 0s 37us/step
#
#
#  RESULTATS UP
#
# Accuracy: 86.14%
#  Precision: 85.86%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.86%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       103
#            1       0.86      0.86      0.86        99
#
#    micro avg       0.86      0.86      0.86       202
#    macro avg       0.86      0.86      0.86       202
# weighted avg       0.86      0.86      0.86       202
#
# [[89 14]
#  [14 85]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 72.28%
#  Precision: 60.75%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 82.28%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.85      0.66      0.74       123
#            1       0.61      0.82      0.70        79
#
#    micro avg       0.72      0.72      0.72       202
#    macro avg       0.73      0.74      0.72       202
# weighted avg       0.76      0.72      0.73       202
#
# [[81 42]
#  [14 65]]
#
#
# Deep Learning executed in = 107.610000 seconds
#  Boucle  3 terminée...Opération restantes : 502 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 4
# amorce :  0
# amorce2 :  0
#  --- Loop : 4  ---  --- Symbol :   ACN   ---  --- Name :  Accenture plc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.0639334842295953
#  Alpha :  0.061478995654942574
#  R_Squared :  0.39780938552849177
#  Volatility :  0.1580760756253234
#  Momentum :  0.333359298105367
# executed in = 2.120000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:38:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.370000 seconds
#  Deeping in blue
#
#  --- Loop : 4  ---  --- Symbol :   ACN   ---  --- Name :  Accenture plc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 242us/step
# 1005/1005 [==============================] - 0s 229us/step
# 202/202 [==============================] - 0s 30us/step
# 202/202 [==============================] - 0s 36us/step
#
#
#  RESULTATS UP
#
# Accuracy: 80.20%
#  Precision: 79.82%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 82.86%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79        97
#            1       0.80      0.83      0.81       105
#
#    micro avg       0.80      0.80      0.80       202
#    macro avg       0.80      0.80      0.80       202
# weighted avg       0.80      0.80      0.80       202
#
# [[75 22]
#  [18 87]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 75.74%
#  Precision: 86.21%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 35.71%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.74      0.97      0.84       132
#            1       0.86      0.36      0.51        70
#
#    micro avg       0.76      0.76      0.76       202
#    macro avg       0.80      0.66      0.67       202
# weighted avg       0.78      0.76      0.72       202
#
# [[128   4]
#  [ 45  25]]
#
#
# Deep Learning executed in = 103.130000 seconds
#  Boucle  4 terminée...Opération restantes : 501 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 5
# amorce :  0
# amorce2 :  0
#  --- Loop : 5  ---  --- Symbol :   ATVI   ---  --- Name :  Activision Blizzard  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.0183148238866244
#  Alpha :  0.2739041385948301
#  R_Squared :  0.12225518326499307
#  Volatility :  0.27292141007703397
#  Momentum :  0.764266839379075
# executed in = 2.200000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:40:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.810000 seconds
#  Deeping in blue
#
#  --- Loop : 5  ---  --- Symbol :   ATVI   ---  --- Name :  Activision Blizzard  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 306us/step
# 1005/1005 [==============================] - 0s 300us/step
# 202/202 [==============================] - 0s 31us/step
# 202/202 [==============================] - 0s 31us/step
#
#
#  RESULTATS UP
#
# Accuracy: 71.78%
#  Precision: 67.41%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 87.50%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.81      0.55      0.65        98
#            1       0.67      0.88      0.76       104
#
#    micro avg       0.72      0.72      0.72       202
#    macro avg       0.74      0.71      0.71       202
# weighted avg       0.74      0.72      0.71       202
#
# [[54 44]
#  [13 91]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 83.66%
#  Precision: 86.11%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 72.94%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.82      0.91      0.87       117
#            1       0.86      0.73      0.79        85
#
#    micro avg       0.84      0.84      0.84       202
#    macro avg       0.84      0.82      0.83       202
# weighted avg       0.84      0.84      0.83       202
#
# [[107  10]
#  [ 23  62]]
#
#
# Deep Learning executed in = 89.280000 seconds
#  Boucle  5 terminée...Opération restantes : 500 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 6
# amorce :  0
# amorce2 :  0
#  --- Loop : 6  ---  --- Symbol :   AYI   ---  --- Name :  Acuity Brands Inc  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.4952054295823025
#  Alpha :  0.06318290281594649
#  R_Squared :  0.1887674297502957
#  Volatility :  0.3224976209161986
#  Momentum :  -0.23550305145180017
# executed in = 2.410000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:41:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.820000 seconds
#  Deeping in blue
#
#  --- Loop : 6  ---  --- Symbol :   AYI   ---  --- Name :  Acuity Brands Inc  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 350us/step
# 1005/1005 [==============================] - 0s 382us/step
# 202/202 [==============================] - 0s 32us/step
# 202/202 [==============================] - 0s 34us/step
#
#
#  RESULTATS UP
#
# Accuracy: 72.77%
#  Precision: 68.18%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 68.97%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76       115
#            1       0.68      0.69      0.69        87
#
#    micro avg       0.73      0.73      0.73       202
#    macro avg       0.72      0.72      0.72       202
# weighted avg       0.73      0.73      0.73       202
#
# [[87 28]
#  [27 60]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 69.80%
#  Precision: 100.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 35.11%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78       108
#            1       1.00      0.35      0.52        94
#
#    micro avg       0.70      0.70      0.70       202
#    macro avg       0.82      0.68      0.65       202
# weighted avg       0.81      0.70      0.66       202
#
# [[108   0]
#  [ 61  33]]
#
#
# Deep Learning executed in = 92.120000 seconds
#  Boucle  6 terminée...Opération restantes : 499 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 7
# amorce :  0
# amorce2 :  0
#  --- Loop : 7  ---  --- Symbol :   ADBE   ---  --- Name :  Adobe Systems Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.1181148719992475
#  Alpha :  0.19712782996643455
#  R_Squared :  0.28187736351830517
#  Volatility :  0.19735380527455068
#  Momentum :  0.7021856307704932
# executed in = 2.050000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:43:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.510000 seconds
#  Deeping in blue
#
#  --- Loop : 7  ---  --- Symbol :   ADBE   ---  --- Name :  Adobe Systems Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 382us/step
# 1005/1005 [==============================] - 0s 418us/step
# 202/202 [==============================] - 0s 35us/step
# 202/202 [==============================] - 0s 39us/step
#
#
#  RESULTATS UP
#
# Accuracy: 46.53%
#  Precision: 44.86%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 93.26%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.65      0.10      0.17       113
#            1       0.45      0.93      0.61        89
#
#    micro avg       0.47      0.47      0.47       202
#    macro avg       0.55      0.51      0.39       202
# weighted avg       0.56      0.47      0.36       202
#
# [[ 11 102]
#  [  6  83]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 65.84%
#  Precision: 63.22%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 59.78%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.68      0.71      0.69       110
#            1       0.63      0.60      0.61        92
#
#    micro avg       0.66      0.66      0.66       202
#    macro avg       0.66      0.65      0.65       202
# weighted avg       0.66      0.66      0.66       202
#
# [[78 32]
#  [37 55]]
#
#
# Deep Learning executed in = 96.290000 seconds
#  Boucle  7 terminée...Opération restantes : 498 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 8
# amorce :  0
# amorce2 :  0
#  --- Loop : 8  ---  --- Symbol :   AAP   ---  --- Name :  Advance Auto Parts  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  1.024929311281424
#  Alpha :  -0.0218338739730475
#  R_Squared :  0.11170338442995864
#  Volatility :  0.28737562482363693
#  Momentum :  -0.4092830780801753
# executed in = 2.110000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:45:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.740000 seconds
#  Deeping in blue
#
#  --- Loop : 8  ---  --- Symbol :   AAP   ---  --- Name :  Advance Auto Parts  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 453us/step
# 1005/1005 [==============================] - 0s 421us/step
# 202/202 [==============================] - 0s 32us/step
# 202/202 [==============================] - 0s 37us/step
#
#
#  RESULTATS UP
#
# Accuracy: 76.73%
#  Precision: 70.87%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 81.11%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.83      0.73      0.78       112
#            1       0.71      0.81      0.76        90
#
#    micro avg       0.77      0.77      0.77       202
#    macro avg       0.77      0.77      0.77       202
# weighted avg       0.78      0.77      0.77       202
#
# [[82 30]
#  [17 73]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 85.15%
#  Precision: 88.89%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 77.42%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87       109
#            1       0.89      0.77      0.83        93
#
#    micro avg       0.85      0.85      0.85       202
#    macro avg       0.86      0.85      0.85       202
# weighted avg       0.86      0.85      0.85       202
#
# [[100   9]
#  [ 21  72]]
#
#
# Deep Learning executed in = 98.570000 seconds
#  Boucle  8 terminée...Opération restantes : 497 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 9
# amorce :  0
# amorce2 :  0
#  --- Loop : 9  ---  --- Symbol :   AMD   ---  --- Name :  Advanced Micro Devices Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  2.4953641848261214
#  Alpha :  0.10639148082561213
#  R_Squared :  0.19273511500474083
#  Volatility :  0.5326509363848048
#  Momentum :  -0.09347446255322989
# executed in = 2.220000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:46:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.860000 seconds
#  Deeping in blue
#
#  --- Loop : 9  ---  --- Symbol :   AMD   ---  --- Name :  Advanced Micro Devices Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 466us/step
# 1005/1005 [==============================] - 0s 455us/step
# 202/202 [==============================] - 0s 34us/step
# 202/202 [==============================] - 0s 39us/step
#
#
#  RESULTATS UP
#
# Accuracy: 70.30%
#  Precision: 62.89%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 99.01%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.98      0.42      0.58       101
#            1       0.63      0.99      0.77       101
#
#    micro avg       0.70      0.70      0.70       202
#    macro avg       0.80      0.70      0.68       202
# weighted avg       0.80      0.70      0.68       202
#
# [[ 42  59]
#  [  1 100]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 78.71%
#  Precision: 80.77%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 69.23%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.82       111
#            1       0.81      0.69      0.75        91
#
#    micro avg       0.79      0.79      0.79       202
#    macro avg       0.79      0.78      0.78       202
# weighted avg       0.79      0.79      0.78       202
#
# [[96 15]
#  [28 63]]
#
#
# Deep Learning executed in = 101.950000 seconds
#  Boucle  9 terminée...Opération restantes : 496 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 10
# amorce :  0
# amorce2 :  0
#  --- Loop : 10  ---  --- Symbol :   AES   ---  --- Name :  AES Corp  ---  --- Sector :  Utilities  ---
# Scraping data...
# Beta :  1.2575060196211736
#  Alpha :  -0.10048030326578374
#  R_Squared :  0.29094247599556133
#  Volatility :  0.21847195170271916
#  Momentum :  -0.015783601425203964
# executed in = 2.560000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:48:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.930000 seconds
#  Deeping in blue
#
#  --- Loop : 10  ---  --- Symbol :   AES   ---  --- Name :  AES Corp  ---  --- Sector :  Utilities  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 498us/step
# 1005/1005 [==============================] - 0s 483us/step
# 202/202 [==============================] - 0s 37us/step
# 202/202 [==============================] - 0s 40us/step
#
#
#  RESULTATS UP
#
# Accuracy: 84.65%
#  Precision: 72.73%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 98.77%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.99      0.75      0.85       121
#            1       0.73      0.99      0.84        81
#
#    micro avg       0.85      0.85      0.85       202
#    macro avg       0.86      0.87      0.85       202
# weighted avg       0.88      0.85      0.85       202
#
# [[91 30]
#  [ 1 80]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 92.08%
#  Precision: 100.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.19%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92        94
#            1       1.00      0.85      0.92       108
#
#    micro avg       0.92      0.92      0.92       202
#    macro avg       0.93      0.93      0.92       202
# weighted avg       0.93      0.92      0.92       202
#
# [[94  0]
#  [16 92]]
#
#
# Deep Learning executed in = 105.150000 seconds
#  Boucle  10 terminée...Opération restantes : 495 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 11
# amorce :  0
# amorce2 :  0
#  --- Loop : 11  ---  --- Symbol :   AET   ---  --- Name :  Aetna Inc  ---  --- Sector :  Health Care  ---
# Scraping data...
#  Problème loop :  11
# Loop : 12
# amorce :  0
# amorce2 :  0
#  --- Loop : 12  ---  --- Symbol :   AMG   ---  --- Name :  Affiliated Managers Group Inc  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  1.6927120278868368
#  Alpha :  -0.10600752287493452
#  R_Squared :  0.4446619880220314
#  Volatility :  0.23787963229143005
#  Momentum :  0.41932751572465055
# executed in = 2.480000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:50:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.730000 seconds
#  Deeping in blue
#
#  --- Loop : 12  ---  --- Symbol :   AMG   ---  --- Name :  Affiliated Managers Group Inc  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 610us/step
# 1005/1005 [==============================] - 1s 537us/step
# 202/202 [==============================] - 0s 39us/step
# 202/202 [==============================] - 0s 42us/step
#
#
#  RESULTATS UP
#
# Accuracy: 81.68%
#  Precision: 76.27%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 90.91%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80       103
#            1       0.76      0.91      0.83        99
#
#    micro avg       0.82      0.82      0.82       202
#    macro avg       0.83      0.82      0.82       202
# weighted avg       0.83      0.82      0.82       202
#
# [[75 28]
#  [ 9 90]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 75.25%
#  Precision: 61.40%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 92.11%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.93      0.65      0.77       126
#            1       0.61      0.92      0.74        76
#
#    micro avg       0.75      0.75      0.75       202
#    macro avg       0.77      0.79      0.75       202
# weighted avg       0.81      0.75      0.76       202
#
# [[82 44]
#  [ 6 70]]
#
#
# Deep Learning executed in = 108.110000 seconds
#  Boucle  12 terminée...Opération restantes : 493 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 13
# amorce :  0
# amorce2 :  0
#  --- Loop : 13  ---  --- Symbol :   AFL   ---  --- Name :  AFLAC Inc  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  1.0860404512967565
#  Alpha :  0.0301774048026989
#  R_Squared :  0.4933141641219432
#  Volatility :  0.14490166972374313
#  Momentum :  0.32008443963387867
# executed in = 2.180000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:52:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.150000 seconds
#  Deeping in blue
#
#  --- Loop : 13  ---  --- Symbol :   AFL   ---  --- Name :  AFLAC Inc  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 581us/step
# 1005/1005 [==============================] - 1s 567us/step
# 202/202 [==============================] - 0s 38us/step
# 202/202 [==============================] - 0s 41us/step
#
#
#  RESULTATS UP
#
# Accuracy: 65.84%
#  Precision: 100.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 11.54%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78       124
#            1       1.00      0.12      0.21        78
#
#    micro avg       0.66      0.66      0.66       202
#    macro avg       0.82      0.56      0.49       202
# weighted avg       0.78      0.66      0.56       202
#
# [[124   0]
#  [ 69   9]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 72.77%
#  Precision: 66.12%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.11%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.83      0.62      0.71       108
#            1       0.66      0.85      0.74        94
#
#    micro avg       0.73      0.73      0.73       202
#    macro avg       0.74      0.74      0.73       202
# weighted avg       0.75      0.73      0.73       202
#
# [[67 41]
#  [14 80]]
#
#
# Deep Learning executed in = 111.490000 seconds
#  Boucle  13 terminée...Opération restantes : 492 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 14
# amorce :  0
# amorce2 :  0
#  --- Loop : 14  ---  --- Symbol :   A   ---  --- Name :  Agilent Technologies Inc  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.257077009933834
#  Alpha :  0.02567627750314675
#  R_Squared :  0.3628360247233715
#  Volatility :  0.19556713107105558
#  Momentum :  0.48317885669332794
# executed in = 2.120000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:54:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.500000 seconds
#  Deeping in blue
#
#  --- Loop : 14  ---  --- Symbol :   A   ---  --- Name :  Agilent Technologies Inc  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 627us/step
# 1005/1005 [==============================] - 1s 659us/step
# 202/202 [==============================] - 0s 34us/step
# 202/202 [==============================] - 0s 43us/step
#
#
#  RESULTATS UP
#
# Accuracy: 75.74%
#  Precision: 68.42%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 92.86%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.60      0.72       104
#            1       0.68      0.93      0.79        98
#
#    micro avg       0.76      0.76      0.76       202
#    macro avg       0.79      0.76      0.75       202
# weighted avg       0.79      0.76      0.75       202
#
# [[62 42]
#  [ 7 91]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 71.29%
#  Precision: 100.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 28.40%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.68      1.00      0.81       121
#            1       1.00      0.28      0.44        81
#
#    micro avg       0.71      0.71      0.71       202
#    macro avg       0.84      0.64      0.62       202
# weighted avg       0.81      0.71      0.66       202
#
# [[121   0]
#  [ 58  23]]
#
#
# Deep Learning executed in = 116.650000 seconds
#  Boucle  14 terminée...Opération restantes : 491 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 15
# amorce :  0
# amorce2 :  0
#  --- Loop : 15  ---  --- Symbol :   APD   ---  --- Name :  Air Products & Chemicals Inc  ---  --- Sector :  Materials  ---
# Scraping data...
# Beta :  1.2712696371385854
#  Alpha :  0.03290409681410712
#  R_Squared :  0.4704802109002689
#  Volatility :  0.17368254525725974
#  Momentum :  0.17769786031993506
# executed in = 1.750000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:56:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.780000 seconds
#  Deeping in blue
#
#  --- Loop : 15  ---  --- Symbol :   APD   ---  --- Name :  Air Products & Chemicals Inc  ---  --- Sector :  Materials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 631us/step
# 1005/1005 [==============================] - 1s 645us/step
# 202/202 [==============================] - 0s 40us/step
# 202/202 [==============================] - 0s 42us/step
#
#
#  RESULTATS UP
#
# Accuracy: 74.75%
#  Precision: 66.98%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 81.61%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.83      0.70      0.76       115
#            1       0.67      0.82      0.74        87
#
#    micro avg       0.75      0.75      0.75       202
#    macro avg       0.75      0.76      0.75       202
# weighted avg       0.76      0.75      0.75       202
#
# [[80 35]
#  [16 71]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 76.24%
#  Precision: 80.77%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 52.50%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.75      0.92      0.82       122
#            1       0.81      0.53      0.64        80
#
#    micro avg       0.76      0.76      0.76       202
#    macro avg       0.78      0.72      0.73       202
# weighted avg       0.77      0.76      0.75       202
#
# [[112  10]
#  [ 38  42]]
#
#
# Deep Learning executed in = 117.590000 seconds
#  Boucle  15 terminée...Opération restantes : 490 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 16
# amorce :  0
# amorce2 :  0
#  --- Loop : 16  ---  --- Symbol :   AKAM   ---  --- Name :  Akamai Technologies Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  0.7183115784185561
#  Alpha :  0.06702328879113895
#  R_Squared :  0.03575225534338278
#  Volatility :  0.3560002690081513
#  Momentum :  -0.024595071717795514
# executed in = 2.100000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:59:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.460000 seconds
#  Deeping in blue
#
#  --- Loop : 16  ---  --- Symbol :   AKAM   ---  --- Name :  Akamai Technologies Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 759us/step
# 1005/1005 [==============================] - 1s 693us/step
# 202/202 [==============================] - 0s 42us/step
# 202/202 [==============================] - 0s 45us/step
#
#
#  RESULTATS UP
#
# Accuracy: 79.70%
#  Precision: 80.17%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 83.78%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77        91
#            1       0.80      0.84      0.82       111
#
#    micro avg       0.80      0.80      0.80       202
#    macro avg       0.80      0.79      0.79       202
# weighted avg       0.80      0.80      0.80       202
#
# [[68 23]
#  [18 93]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 86.14%
#  Precision: 94.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 65.28%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.90       130
#            1       0.94      0.65      0.77        72
#
#    micro avg       0.86      0.86      0.86       202
#    macro avg       0.89      0.81      0.84       202
# weighted avg       0.87      0.86      0.85       202
#
# [[127   3]
#  [ 25  47]]
#
#
# Deep Learning executed in = 121.920000 seconds
#  Boucle  16 terminée...Opération restantes : 489 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 17
# amorce :  0
# amorce2 :  0
#  --- Loop : 17  ---  --- Symbol :   ALK   ---  --- Name :  Alaska Air Group Inc  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.0316804535926776
#  Alpha :  0.17285706096065623
#  R_Squared :  0.09430386652587475
#  Volatility :  0.314825305631645
#  Momentum :  -0.15639123043171443
# executed in = 1.920000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [10:01:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.360000 seconds
#  Deeping in blue
#
#  --- Loop : 17  ---  --- Symbol :   ALK   ---  --- Name :  Alaska Air Group Inc  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 947us/step
# 1005/1005 [==============================] - 1s 762us/step
# 202/202 [==============================] - 0s 44us/step
# 202/202 [==============================] - 0s 44us/step
#
#
#  RESULTATS UP
#
# Accuracy: 81.68%
#  Precision: 83.54%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 73.33%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       112
#            1       0.84      0.73      0.78        90
#
#    micro avg       0.82      0.82      0.82       202
#    macro avg       0.82      0.81      0.81       202
# weighted avg       0.82      0.82      0.82       202
#
# [[99 13]
#  [24 66]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 73.76%
#  Precision: 92.45%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 50.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.67      0.96      0.79       104
#            1       0.92      0.50      0.65        98
#
#    micro avg       0.74      0.74      0.74       202
#    macro avg       0.80      0.73      0.72       202
# weighted avg       0.79      0.74      0.72       202
#
# [[100   4]
#  [ 49  49]]
#
#
# Deep Learning executed in = 126.920000 seconds
#  Boucle  17 terminée...Opération restantes : 488 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 18
# amorce :  0
# amorce2 :  0
#  --- Loop : 18  ---  --- Symbol :   ALB   ---  --- Name :  Albemarle Corp  ---  --- Sector :  Materials  ---
# Scraping data...
# Beta :  1.782917068370502
#  Alpha :  -0.014719256975514947
#  R_Squared :  0.3713795640607723
#  Volatility :  0.27416456488991253
#  Momentum :  0.5021528374718012
# executed in = 2.340000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [10:03:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.010000 seconds
#  Deeping in blue
#
#  --- Loop : 18  ---  --- Symbol :   ALB   ---  --- Name :  Albemarle Corp  ---  --- Sector :  Materials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 778us/step
# 1005/1005 [==============================] - 1s 768us/step
# 202/202 [==============================] - 0s 48us/step
# 202/202 [==============================] - 0s 56us/step
#
#
#  RESULTATS UP
#
# Accuracy: 94.06%
#  Precision: 91.03%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 93.42%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       126
#            1       0.91      0.93      0.92        76
#
#    micro avg       0.94      0.94      0.94       202
#    macro avg       0.93      0.94      0.94       202
# weighted avg       0.94      0.94      0.94       202
#
# [[119   7]
#  [  5  71]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 95.05%
#  Precision: 93.02%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 99.17%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.99      0.89      0.94        81
#            1       0.93      0.99      0.96       121
#
#    micro avg       0.95      0.95      0.95       202
#    macro avg       0.96      0.94      0.95       202
# weighted avg       0.95      0.95      0.95       202
#
# [[ 72   9]
#  [  1 120]]
#
#
# Deep Learning executed in = 129.870000 seconds
#  Boucle  18 terminée...Opération restantes : 487 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# ...
# amorce :  0
# amorce2 :  0
#  --- Loop : 42  ---  --- Symbol :   APH   ---  --- Name :  Amphenol Corp  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  0.8140124527226299
#  Alpha :  0.11582880070396949
#  R_Squared :  0.37301885756686337
#  Volatility :  0.12489781360731439
#  Momentum :  0.31807456835444103
# executed in = 3.050000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:14:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.940000 seconds
#  Deeping in blue
#
#  --- Loop : 42  ---  --- Symbol :   APH   ---  --- Name :  Amphenol Corp  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 89us/step
# 202/202 [==============================] - 0s 85us/step
#
#
#  RESULTATS UP
#
# Accuracy: 75.25%
#  Precision: 66.67%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 95.83%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.94      0.57      0.71       106
#            1       0.67      0.96      0.79        96
#
#    micro avg       0.75      0.75      0.75       202
#    macro avg       0.80      0.76      0.75       202
# weighted avg       0.81      0.75      0.74       202
#
# [[60 46]
#  [ 4 92]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 70.79%
#  Precision: 100.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 23.38%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.68      1.00      0.81       125
#            1       1.00      0.23      0.38        77
#
#    micro avg       0.71      0.71      0.71       202
#    macro avg       0.84      0.62      0.59       202
# weighted avg       0.80      0.71      0.65       202
#
# [[125   0]
#  [ 59  18]]
#
#
# Deep Learning executed in = 207.010000 seconds
#  Boucle  42 terminée...Opération restantes : 463 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 43
# amorce :  0
# amorce2 :  0
#  --- Loop : 43  ---  --- Symbol :   APC   ---  --- Name :  Anadarko Petroleum Corp  ---  --- Sector :  Energy  ---
# Scraping data...
# Beta :  1.3799111005285911
#  Alpha :  -0.19136463400818174
#  R_Squared :  0.1597054351123155
#  Volatility :  0.3235790838893468
#  Momentum :  -0.22759496192861395
# executed in = 6.640000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:18:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 6.630000 seconds
#  Deeping in blue
#
#  --- Loop : 43  ---  --- Symbol :   APC   ---  --- Name :  Anadarko Petroleum Corp  ---  --- Sector :  Energy  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 78us/step
# 202/202 [==============================] - 0s 86us/step
#
#
#  RESULTATS UP
#
# Accuracy: 78.22%
#  Precision: 71.91%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 77.11%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.83      0.79      0.81       119
#            1       0.72      0.77      0.74        83
#
#    micro avg       0.78      0.78      0.78       202
#    macro avg       0.78      0.78      0.78       202
# weighted avg       0.79      0.78      0.78       202
#
# [[94 25]
#  [19 64]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 61.39%
#  Precision: 66.67%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 35.79%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.60      0.84      0.70       107
#            1       0.67      0.36      0.47        95
#
#    micro avg       0.61      0.61      0.61       202
#    macro avg       0.63      0.60      0.58       202
# weighted avg       0.63      0.61      0.59       202
#
# [[90 17]
#  [61 34]]
#
#
# Deep Learning executed in = 213.200000 seconds
#  Boucle  43 terminée...Opération restantes : 462 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 44
# amorce :  0
# amorce2 :  0
#  --- Loop : 44  ---  --- Symbol :   ADI   ---  --- Name :  Analog Devices, Inc.  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.3083631348533524
#  Alpha :  0.03543981693811798
#  R_Squared :  0.3236337010369418
#  Volatility :  0.21552150435709666
#  Momentum :  0.2530126031513198
# executed in = 2.160000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:22:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.140000 seconds
#  Deeping in blue
#
#  --- Loop : 44  ---  --- Symbol :   ADI   ---  --- Name :  Analog Devices, Inc.  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 84us/step
# 202/202 [==============================] - 0s 89us/step
#
#
#  RESULTATS UP
#
# Accuracy: 73.76%
#  Precision: 73.91%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 70.10%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.74      0.77      0.75       105
#            1       0.74      0.70      0.72        97
#
#    micro avg       0.74      0.74      0.74       202
#    macro avg       0.74      0.74      0.74       202
# weighted avg       0.74      0.74      0.74       202
#
# [[81 24]
#  [29 68]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 83.66%
#  Precision: 87.10%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 68.35%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87       123
#            1       0.87      0.68      0.77        79
#
#    micro avg       0.84      0.84      0.84       202
#    macro avg       0.85      0.81      0.82       202
# weighted avg       0.84      0.84      0.83       202
#
# [[115   8]
#  [ 25  54]]
#
#
# Deep Learning executed in = 218.430000 seconds
#  Boucle  44 terminée...Opération restantes : 461 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 45
# amorce :  0
# amorce2 :  0
#  --- Loop : 45  ---  --- Symbol :   ANDV   ---  --- Name :  Andeavor  ---  --- Sector :  Energy  ---
# Scraping data...
#  Problème loop :  45
# Loop : 46
# amorce :  0
# amorce2 :  0
#  --- Loop : 46  ---  --- Symbol :   ANSS   ---  --- Name :  ANSYS  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.0305599873484095
#  Alpha :  0.03205713917091176
#  R_Squared :  0.2782540132536011
#  Volatility :  0.18308035211791435
#  Momentum :  0.5957400772706152
# executed in = 2.400000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:26:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 6.200000 seconds
#  Deeping in blue
#
#  --- Loop : 46  ---  --- Symbol :   ANSS   ---  --- Name :  ANSYS  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 84us/step
# 202/202 [==============================] - 0s 99us/step
#
#
#  RESULTATS UP
#
# Accuracy: 67.33%
#  Precision: 65.77%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 72.28%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.69      0.62      0.66       101
#            1       0.66      0.72      0.69       101
#
#    micro avg       0.67      0.67      0.67       202
#    macro avg       0.67      0.67      0.67       202
# weighted avg       0.67      0.67      0.67       202
#
# [[63 38]
#  [28 73]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 73.76%
#  Precision: 75.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 31.34%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.74      0.95      0.83       135
#            1       0.75      0.31      0.44        67
#
#    micro avg       0.74      0.74      0.74       202
#    macro avg       0.74      0.63      0.64       202
# weighted avg       0.74      0.74      0.70       202
#
# [[128   7]
#  [ 46  21]]
#
#
# Deep Learning executed in = 214.090000 seconds
#  Boucle  46 terminée...Opération restantes : 459 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 47
# amorce :  0
# amorce2 :  0
#  --- Loop : 47  ---  --- Symbol :   ANTM   ---  --- Name :  Anthem Inc.  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  0.7838381733588401
#  Alpha :  0.19519563663852135
#  R_Squared :  0.14639727356467946
#  Volatility :  0.19197695400826545
#  Momentum :  0.5871845603530661
# executed in = 5.090000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:30:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.830000 seconds
#  Deeping in blue
#
#  --- Loop : 47  ---  --- Symbol :   ANTM   ---  --- Name :  Anthem Inc.  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 90us/step
# 202/202 [==============================] - 0s 90us/step
#
#
#  RESULTATS UP
#
# Accuracy: 69.31%
#  Precision: 62.73%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 98.06%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.95      0.39      0.56        99
#            1       0.63      0.98      0.77       103
#
#    micro avg       0.69      0.69      0.69       202
#    macro avg       0.79      0.69      0.66       202
# weighted avg       0.79      0.69      0.66       202
#
# [[ 39  60]
#  [  2 101]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 68.81%
#  Precision: 83.33%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 25.32%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.67      0.97      0.79       123
#            1       0.83      0.25      0.39        79
#
#    micro avg       0.69      0.69      0.69       202
#    macro avg       0.75      0.61      0.59       202
# weighted avg       0.73      0.69      0.63       202
#
# [[119   4]
#  [ 59  20]]
#
#
# Deep Learning executed in = 220.570000 seconds
#  Boucle  47 terminée...Opération restantes : 458 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 48
# amorce :  0
# amorce2 :  0
#  --- Loop : 48  ---  --- Symbol :   AON   ---  --- Name :  Aon plc  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  1.0452475821585938
#  Alpha :  0.06638920736046382
#  R_Squared :  0.4240165892909187
#  Volatility :  0.15042392913810984
#  Momentum :  0.21485952765767924
# executed in = 2.110000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2013-01-07 00:00:00
# Split period : 2016-12-30 00:00:00
# Last period : 2017-12-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:33:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.960000 seconds
#  Deeping in blue
#
#  --- Loop : 48  ---  --- Symbol :   AON   ---  --- Name :  Aon plc  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 85us/step
# 202/202 [==============================] - 0s 81us/step
#
#
#  RESULTATS UP
#
# Accuracy: 57.92%
#  Precision: 93.33%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 14.29%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.55      0.99      0.71       104
#            1       0.93      0.14      0.25        98
#
#    micro avg       0.58      0.58      0.58       202
#    macro avg       0.74      0.57      0.48       202
# weighted avg       0.74      0.58      0.48       202
#
# [[103   1]
#  [ 84  14]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 68.81%
#  Precision: 76.92%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 25.97%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.68      0.95      0.79       125
#            1       0.77      0.26      0.39        77
#
#    micro avg       0.69      0.69      0.69       202
#    macro avg       0.72      0.61      0.59       202
# weighted avg       0.71      0.69      0.64       202
#
# [[119   6]
#  [ 57  20]]
#
#
# Deep Learning executed in = 221.770000 seconds
#  Boucle  48 terminée...Opération restantes : 457 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV

# %%
#import sys
#orig_stdout = sys.stdout
#f = open('backtestv2_4.txt', 'w')
#sys.stdout = f

# %%
#f.close()
#sys.stdout = orig_stdout

# %% [markdown]
# import pandas as pd
#
# backtest = pd.DataFrame(columns = ['Symb.','Name','Sector','period','Begin.','End',\
#                           'Pnl','%Pnl','Total Winners','Total Loosers','Nb Win','Nb Los',\
#                           '% Winners','MaxDD','%MaxDD','Aver. Win',\
#                           'Aver. Los','Aver. Duration',\
#                           'Total Trades','% Long','% Short','Profit Factor'])
# backtest.to_csv('BackTest.csv')
#
# signals = pd.DataFrame(columns = ['Date','Ticker','Open Long','Close Long','Open Short','Close Short','Buy/Sell Price','Quantity','tPNL'])
# signals.to_csv('SIGNALS.csv')

# %%
2+2
# Out:
# 4

# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
print('Importing Librairies...')
import talib
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import xgboost as xgb
from xgboost import XGBRegressor, plot_importance
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')
import time
import datetime as dt
import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
print('Librairies imported')
print('')

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print('BOOST SKAN 55 Version v1.35',Style.RESET_ALL)



print('')
print('Sraping tickers')
constituents = pd.read_csv('constituents_csv.csv')
print('Scrap -----> ok')
# PARAMETRES TEMPORELS INITIAUX
start = pd.to_datetime('2014-01-06')
end = pd.to_datetime('2018-12-31')

error = []


try :
    amorce = pd.read_csv('backTest.csv').index[-1] + 1
except:
    amorce = 0
    backtest = pd.DataFrame(columns = ['Symb.','Name','Sector','Period','Begin.','End',\
                          'Pnl $','Pnl %','Gross Profit','Gross Loss','# Winners','# Loosers',\
                          '% Winners','MaxDD $','MaxDD %','Aver. Win $',\
                          'Aver. Loos $','Aver. Duration',\
                          'Total Trades','% Long','% Short','Profit Factor'])
    
    
try:
    amorce2 = pd.read_csv('SIGNALS.csv').index[-1] + 1
except:
    amorce2 = 0
    signals = pd.DataFrame(columns = ['Date','Ticker','Open Long','Close Long','Open Short','Close Short','Buy/Sell Price','Quantity','PNL','Cumulative PNL','Latent PNL'])

    
# SCRAPING DES DONNES BRUTES
def scrap_data(ticker,start,end):
    df = web.DataReader(ticker,'yahoo',start,end)
    df = df.drop(['Close'],axis=1)
    df['Close'] = df['Adj Close']
    df = df.drop(['Adj Close'],axis = 1)    
    return(df)

def prepa_data(df):
    tmps1=time.time()
    print('Preparing data...')
    rsi = talib.RSI(df['Close'],timeperiod=14)
    stoc_slowk, stoc_slowd = talib.STOCH(df['High'],df['Low'],df['Close'])
    upper, middle, lower =  talib.BBANDS(df['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(df['Close'],timeperiod=5)
    sma8 = talib.SMA(df['Close'],timeperiod=8)
    sma10 = talib.SMA(df['Close'],timeperiod=10)
    sma12 = talib.SMA(df['Close'],timeperiod=12)
    sma15 = talib.SMA(df['Close'],timeperiod=15)
    sma30 = talib.SMA(df['Close'],timeperiod=30)
    sma35 = talib.SMA(df['Close'],timeperiod=35)
    sma40 = talib.SMA(df['Close'],timeperiod=40)
    sma45 = talib.SMA(df['Close'],timeperiod=45)
    sma50 = talib.SMA(df['Close'],timeperiod=50)
    atr = talib.ATR(df['High'],df['Low'],df['Close'],timeperiod=10)
    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50
    bbdelta = upper - middle
    price_bolup = df['Close'] - lower
    price_bolow = df['Close'] - upper
    Ema = talib.EMA(df['Close'],timeperiod=20)
    KC_High = Ema + 2*atr
    KC_Low = Ema - 2*atr
    aroondown, aroonup = talib.AROON(df['High'], df['Low'], timeperiod=9)
    aroon = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
    rsi30_list = []
    rsi70_list = []
    for i in range(0,df.shape[0]):
        rsi70_list.append(70 - rsi[i])
        rsi30_list.append(rsi[i] - 30)
        #except:
         #   rsi70_list.append(0)
          #  rs30_list.append(0)
    varop_spy = df['Open'] - df['Close']
    varhl_spy = df['High'] - df['Low']
    df['Varop_Spy'] = varop_spy
    df['Varhl_spy'] = varhl_spy
    df['RSI'] = rsi
    df['70 - RSI'] = np.array(rsi70_list)
    df['RSI - 30'] = np.array(rsi30_list)
    df['BBD_Delta_Up'] = bbdelta
    df['delta5_8'] = delta5_8
    df['delta8_10'] = delta8_10
    df['delta10_12'] = delta10_12
    df['delta12_15'] = delta12_15
    df['delta15_30'] = delta15_30
    df['delta30_35'] = delta30_35
    df['delta35_40'] = delta35_40
    df['delta40_45'] = delta40_45
    df['delta45_50'] = delta45_50
    df['Stoc_Slowk'] = stoc_slowk
    df['Stoc_Slowd'] = stoc_slowd
    df['KC_High'] = KC_High
    df['KC_Low'] = KC_Low
    df['upper'] = upper
    df['lower'] = lower
    df['var_bollup_kchigh'] = upper-KC_High
    df['var_bolllow_kclow'] = lower-KC_Low
    df['Aroon Up'] = aroonup
    df['Aroon Down'] = aroondown
    df['Delta Aroon'] = aroon
    up = []
    down = []
    df = df.dropna()
    df = boost(df)
    df['%Futur'] = ((df['Close.S']-df['Close']) *100) / (df['Close'])
    df['%Futur2'] = ((df['Close.S2']-df['Close']) *100) / (df['Close'])
    for i in range(0,df.shape[0]-5):
        if df.iloc[i]['%Futur'] > 0.1 :#or df.iloc[i]['%Futur2'] > 0.1:
            up.append(1)
            down.append(0)
        elif df.iloc[i]['%Futur'] < -0.1: #or df.iloc[i]['%Futur2'] < -0.1:
            up.append(0)
            down.append(1)
        else:
            up.append(0)
            down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    
    
    df['target_up'] = up  # target_up # abs(np.array(valley))#target_up
    df['target_down'] = down # target_down # abs(np.array(peak))#target_down
    #df = df.dropna()
    tmps2=round(time.time()-tmps1,2)
    print ("Data prepared in = %f" %tmps2,'seconds')
    return(df)

def boost(df):
    print('Boosting')
    X = df.copy()
    X = X.drop(['Close'],axis=1)
    X['Close'] = df['Close']
    y = X.iloc[:,-1]
    Xtrain = X.iloc[:-2,:-1]
    Xtest = X.iloc[-2:-1,:-1]
    yshift = y.shift(-1)
    ytrain = yshift.iloc[:-2]
    ytest = yshift.iloc[-2:-1]

    model = xgb.XGBRegressor(n_estimators=20000, learning_rate=1, gamma=1, subsample=1, colsample_bytree=1, max_depth=100)

    model.fit( Xtrain, ytrain, early_stopping_rounds=150, eval_set=[(Xtest, ytest)], verbose=0)

    ytrain_pred = model.predict(Xtrain)

    y_pred = model.predict(Xtest)

    pred = model.predict(X.iloc[:,:-1])

    df['Close.S'] = pred
    df['Close.S2'] = df['Close.S']
    df = df.dropna()
    print('Boost ok')
    return(df)

    
def deep_learning(df):
    tmps1=time.time()
    X = df.iloc[:,1:-4]
    y_up = df.iloc[:,-2].values
    y_down = df.iloc[:,-1].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:bloc1,:]
    Xtest = X[bloc1:,:]
    ytrain_up = y_up[:bloc1,:]
    ytest_up = y_up[bloc1:,:]
    ytrain_down = y_down[:bloc1,:]
    ytest_down = y_down[bloc1:,:]

    seed = 770
    np.random.seed(seed)

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    model_up = Sequential()
    # Add an input layer 
    model_up.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_up.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_up.add(Dense(1, activation='sigmoid'))

    model_down = Sequential()
    # Add an input layer 
    model_down.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_down.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_down.add(Dense(1, activation='sigmoid'))

    print('Processing move_up')
    model_up.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])
    
              

    history_up = model_up.fit(Xtrain, ytrain_up,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Processing move_down')
    model_down.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])

    history_down = model_down.fit(Xtrain, ytrain_down,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Computing done')
    print('\n')

    train_acc_up = model_up.evaluate(Xtrain, ytrain_up,verbose=1)
    train_acc_down = model_down.evaluate(Xtrain, ytrain_down,verbose=1)

    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    score_up = model_up.evaluate(Xtest, ytest_up,verbose=1)
    score_down = model_down.evaluate(Xtest, ytest_down,verbose=1)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)

    accuracy_up = accuracy_score(ytest_up, yhat_up)
    accuracy_down = accuracy_score(ytest_down, yhat_down)

    # La précision permet de mesurer la capacité du modèle à refuser résultats non-pertinents : vrais_positifs/(vrais_positifs+faux_positifs)
    precision_up = precision_score(ytest_up, yhat_up)  
    precision_down = precision_score(ytest_down, yhat_down) 


    # Recall : (vrai_positifs/(vrais_positifs+faux_négatifs))
    recall_up = recall_score(ytest_up, yhat_up) 
    recall_down = recall_score(ytest_down, yhat_down) 


    #roc_up=roc_auc_score(ytest_up,yhat_up)
    #roc_down=roc_auc_score(ytest_down,yhat_down)
    print('\n')
    print(Fore.GREEN,'RESULTATS UP\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_up * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_up *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_up * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_up *100))
    # get probabilities for positive class

    print(classification_report(ytest_up, yhat_up))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_up, yhat_up))

    print('\n')
    print('_______________________________________________________________________________________________________________________________________________________________\n')
    print(Fore.RED,'RESULTATS DOWN\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_down * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_down *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_down * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_down *100))
    # get probabilities for positive class

    print(classification_report(ytest_down, yhat_down))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_down, yhat_down))
    print('\n')

    resultats = pd.DataFrame()
    resultats['Date'] = df.index[bloc1:]
    resultats.index= df.index[bloc1:]
    resultats['Move Up'] = yhat_up
    resultats['Confiance up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confiance Down'] = (predict_down)*100
    resultats['Actual'] = df.iloc[bloc1:]['Close']
    resultats['Actual.S'] = df.iloc[bloc1:]['Close.S']
    open_S = df['Open'].shift(-1)
    resultats['Open.S'] = open_S.iloc[bloc1:]
    dmp_cp=[]
    dmp_cp = ((resultats['Confiance up']-resultats['Confiance Down'])/(resultats['Confiance up']+resultats['Confiance Down'])*100)
    resultats['DMP_CP'] = dmp_cp
    tmps2=round(time.time()-tmps1,2)
    print ("Deep Learning executed in = %f" %tmps2,'seconds')
    #resultats.set_index('Date',inplace=True)
    #parse_dates=resultats['Date']
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def learn(df):
    resultats,precision_up,precision_down,model_up,model_down,scaler = deep_learning(df)
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def grobeta(df,dfb):
    # create a time-series of monthly data points
    rts = df.resample('M').last()
    rbts = dfb.resample('M').last()
    dfsm = pd.DataFrame({'s_adjclose' : rts['Close'],
                            'b_adjclose' : rbts['Adj Close']},
                            index=rts.index)

    # compute returns
    dfsm[['s_returns','b_returns']] = dfsm[['s_adjclose','b_adjclose']]/\
        dfsm[['s_adjclose','b_adjclose']].shift(1) -1
    dfsm = dfsm.dropna()
    covmat = np.cov(dfsm["s_returns"],dfsm["b_returns"])

    # calculate measures now
    beta = covmat[0,1]/covmat[1,1]
    alpha= np.mean(dfsm["s_returns"])-beta*np.mean(dfsm["b_returns"])

    # r_squared     = 1. - SS_res/SS_tot
    ypred = alpha + beta * dfsm["b_returns"]
    SS_res = np.sum(np.power(ypred-dfsm["s_returns"],2))
    SS_tot = covmat[0,0]*(len(dfsm)-1) # SS_tot is sample_variance*(n-1)
    r_squared = 1. - SS_res/SS_tot
    # 5- year volatiity and 1-year momentum
    volatility = np.sqrt(covmat[0,0])
    momentum = np.prod(1+dfsm["s_returns"].tail(12).values) -1

    # annualize the numbers
    prd = 12. # used monthly returns; 12 periods to annualize
    alpha = alpha*prd
    volatility = volatility*np.sqrt(prd)

    print ('Beta : ',beta,'\n Alpha : ',alpha,'\n R_Squared : ', r_squared, '\n Volatility : ', volatility, '\n Momentum : ',momentum)
    return(beta,alpha,r_squared,volatility,momentum)

########################
#### MAIN SKAN55 #######
########################

for loop in range(0,49):    
#for loop in range(amorce,len(constituents)):
    print('Loop :',loop)
    print('amorce : ',amorce)
    print('amorce2 : ',amorce2)
    
    try:

        ticker = (constituents.iloc[loop]['Symbol'])
        name = constituents.iloc[loop]['Name']
        sector = constituents.iloc[loop]['Sector']

        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        global delta,bloc1,bloc2
        tmps1=time.time()
        print('Scraping data...')

        df = scrap_data(ticker,start,end)

        dfb = web.DataReader('^GSPC','yahoo',start,end)

        beta,alpha, r_squared, volatility, momentum = grobeta(df,dfb)

        tmps2=round(time.time()-tmps1,2)
        print ("executed in = %f" %tmps2,'seconds')

        print('\n')
        print('GOLEM begins Computing...')
        print('\n')
        delta = round(df.shape[0])
        bloc1 = round(delta*0.80)
        bloc2 = delta - bloc1
        print("# of periods : ",delta)
        print('On 80% - 20% slash : ')
        print('Bloc 1 : ',bloc1,'\nBloc 2 :',bloc2,' periods ')
        print('First period :',df.index[0])
        print('Split period :',df.index[bloc1-1])
        print('Last period :',df.index[df.shape[0]-1])
        print('\n')

        print('Data prep')
        df = prepa_data(df)

        print(Fore.BLUE,'Deeping in blue',Style.RESET_ALL)
        print('')
        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        resultats,precision_up,precision_down,model_up,model_down,scaler = learn(df)

        import sys
        orig_stdout = sys.stdout
        f = open('backtest de '+str(ticker)+'.txt', 'w')
        sys.stdout = f

        ####################
        #### TEST PLOT ####
        ###################

        filtre_up = 93
        filtre_down = 97
        filtre_up_close = 80
        filtre_down_close = 80


        plt.figure(figsize=(26,8),dpi=300)
        #plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
        plt.title('Deep Learning '+name+' Trade Signals')
        plt.plot(resultats['Actual'],color='purple',lw=0.9,label=ticker)

        green=[]
        red=[]
        green_close=[]
        red_close=[]

        for i in range(0,len(resultats)-1):


            if resultats.iloc[i]['Confiance Down'] > filtre_down:
                doob = -1
            elif resultats.iloc[i]['Confiance Down'] > filtre_down_close and resultats.iloc[i]['Confiance Down'] < filtre_down :
                waab = -1
                doob = 0
            elif resultats.iloc[i]['Confiance up'] > filtre_up:
                doob = 1
            elif resultats.iloc[i]['Confiance up'] > filtre_up_close and resultats.iloc[i]['Confiance up'] < filtre_up:
                waab = 1
                doob = 0
            else :
                doob = 0
                waab = 0

            if doob == 1 :#and resultats.iloc[i]['Confiance up'] > filtre_up:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='g',marker='o')
                #doob = -1
                green.append(1)
                red.append(0)
                green_close.append(0)
                red_close.append(1)

            elif doob == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(1)
                green_close.append(1)
                red_close.append(0)

            elif doob == 0 and waab == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(0)
                green_close.append(0)
                red_close.append(1)

            elif waab == 1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(0)
                green_close.append(1)
                red_close.append(0)  

            else:
                green.append(0)
                red.append(0)
                green_close.append(0)
                red_close.append(0)  

                #doob = 0


        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='g',marker='o',label='Buy Signal')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o',label='Sell Signal')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_01.pdf')
        plt.close()


        green.append(0)
        red.append(0)
        green_close.append(0)
        red_close.append(0)
        resultats['Green'] = green
        resultats['Red'] = red
        resultats['Green_Close'] = green_close
        resultats['Red_Close'] = red_close
        #resultats['Actual'] = df['Close'][bloc1:]

        ########################
        ####### BACKTEST########
        ########################
        pos_long = 0
        pos_short = 0
        pactol = 10000/beta
        price_buy = 0
        price_sell = 0
        x = 0
        winners = []
        loosers = []
        nb_win = 0
        nb_los = 0
        mini_pnl = 0
        pos_duration = []
        average_duration = resultats.iloc[0,0] - resultats.iloc[0,0]
        trades = []
        eq_curx = []
        eq_cury = []
        maxdd = []
        nbS = 0
        nbL = 0

        for i in range(0,len(resultats)-1):
            if pos_long == 0 and pos_short == 0 and resultats.iloc[i]['Green'] == 1 :
                pos_long = 1
                nbL+=1
                x = round((10000/beta)/resultats.iloc[i]['Open.S'])
                price_buy = round(resultats.iloc[i]['Open.S'],2)
                time_enter = resultats.iloc[i]['Date']

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 1,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':0}],ignore_index=True)

                print('\n Le ',str(resultats.iloc[i]['Date']),', achat de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',round(pactol,2))
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],1))

            elif pos_long == 1 and resultats.iloc[i]['Green_Close'] == 0 :

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':round((resultats.iloc[i]['Open.S'] - price_buy)*x,2)}],ignore_index=True)
                try:
                    maxdd.append(round((resultats.iloc[i]['Open.S'] - price_buy)*x,2))
                except:
                    print('Null val of maxdd')
                    maxdd.append('Null')


            elif pos_long == 1 and resultats.iloc[i]['Green_Close'] == 1 :
                old_pactol = round(pactol,2)
                eq_curx.append(resultats.iloc[i]['Date'])
                eq_cury.append(old_pactol)
                pos_long = 0
                price_sell = round(resultats.iloc[i]['Open.S'],2)
                mini_pnl = round(x*(price_sell-price_buy),2)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],2))

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 1, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : mini_pnl,\
                                           'Cumulative PNL':round(signals.iloc[:i]['PNL'].sum(),2),'Latent PNL':0}],ignore_index=True)

                pactol = round((pactol + mini_pnl),2)
                print('\n Le ',str(resultats.iloc[i]['Date']),', vente pour close de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)
                print('pnl:', mini_pnl)
                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                pos_duration.append(resultats.iloc[i]['Date'] - time_enter)

                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1


            elif pos_short == 0 and pos_long == 0 and resultats.iloc[i]['Red']:
                pos_short = 1
                nbS+=1
                x = round((10000/beta)/resultats.iloc[i]['Open.S'])
                price_sell = round(resultats.iloc[i]['Open.S'],2)
                time_enter = resultats.iloc[i]['Date']

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 1, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

                print('\n Le ',str(resultats.iloc[i]['Date']),', vente de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],-1))


            elif pos_short == 1 and resultats.iloc[i]['Red_Close'] == 0 :

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':-round((resultats.iloc[i]['Open.S'] - price_sell)*x,2)}],ignore_index=True)
                try:
                    maxdd.append(round((resultats.iloc[i]['Open.S'] - price_sell)*x,2))
                except:
                    print('Null val of maxdd')
                    maxdd.append(0)

            elif pos_short == 1 and resultats.iloc[i]['Red_Close'] == 1 :
                old_pactol = round(pactol,2)
                eq_curx.append(resultats.iloc[i]['Date'])
                eq_cury.append(old_pactol)
                pos_short = 0
                price_buy = round(resultats.iloc[i]['Open.S'],2)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],-2))
                mini_pnl = round(x*(price_sell-price_buy),2)

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 1,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : mini_pnl,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

                pactol = round((pactol + mini_pnl),2)
                print('\n Le ',str(resultats.iloc[i]['Date']),', achat pour close de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)

                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                print('pnl:', mini_pnl)
                pos_duration.append(resultats.iloc[i]['Date'] - time_enter)
                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1
            else:

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                               'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                               'Buy/Sell Price' : 0, 'Quantity' : 0, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

        if pos_long == 1:
            pos_long = 0
            print('Cutting non resolved position')
            print(' Le price buy était de : ',price_buy)
            x = round((10000/beta)/resultats.iloc[i]['Open.S'])
            print('x = ',x)
            price_sell = round(resultats.iloc[i]['Open.S'],2)
            print('Et le price sell : ',price_sell)
            mini_pnl = round(x*(price_sell-price_buy),2)

            signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 1, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : mini_pnl,\
                                       'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

            pactol = round((pactol + mini_pnl),2)
            print('pnl : ',mini_pnl)
            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1


        if pos_short == 1:
            pos_short = 0
            print('Cutting non resolved position')
            print(' Le price sell était de : ',price_sell)
            x = round((10000/beta)/resultats.iloc[i]['Open.S'])
            print('x = ',x)
            price_buy = round(resultats.iloc[i]['Open.S'],2)
            print('Et le price_buy : ',price_buy)
            mini_pnl = round(x*(price_sell-price_buy),2)

            signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 1,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : mini_pnl,\
                                       'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

            pactol = round((pactol + mini_pnl),2)
            print('pnl : ',mini_pnl)

            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1


        pnl = round(pactol - (10000/beta),2)
        print('\n Begining of BackTest :',resultats.iloc[0]['Date'])
        print('Instrument :',ticker)
        print('Face value per trade : $',10000/beta)
        print('End of BackTest :',resultats.iloc[-1]['Date'])
        duration = pd.to_timedelta((resultats.iloc[-1]['Date'] - resultats.iloc[0]['Date']),unit='d')
        print("BackTest's period :",duration)
        print('Pnl :',round(pnl,2),'$')
        print('% Pnl : ',round(pnl/(10000/beta)*100,2))
        print('Total winners :',round(sum(winners),2),'$')
        print('Total loosers :',round(sum(loosers),2),'$')
        print('Number of winners :',round(nb_win))
        print('Number of loosers :',round(nb_los))
        print('Maximum Drawdown : ',round(min(maxdd),2))
        print('% Max Drawdown : ',round(min(maxdd)/(10000/beta)*100,2),'%')
        print('Nombre toatl de trades : ',round(nbL+nbS,2))
        print('% de trades Long : ',round((nbL*100)/(nbL+nbS),2))
        print('% de trades Short : ',round((nbS*100)/(nbL+nbS),2))
        try:
            print('% winners :', round((nb_win/(nb_win+nb_los) * 100),2),'%')
            print('Average winners :',(round(sum(winners)/(nb_win))))
        except:
            print('% winners : null')
        try:
            print('Average losers :',(round(sum(loosers)/(nb_los))))
        except:
            print('Average losers : Inf')
        try:
            for t in range(0,len(pos_duration)):
                average_duration = pd.to_timedelta((average_duration + pos_duration[t]),unit='d')
            average_duration = average_duration/(nb_los+nb_win)
            print('Average Duration :', average_duration)
        except:
            print('No Average Duration available')
        try:
            print('Profit Factor : ',abs(round((sum(winners)/sum(loosers)),2)))
        except:
            print('Profit Factor : null')

        ########################
        ##### PLOT TRADES ######
        ########################

        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Trades')
        plt.plot(resultats['Open.S'],color='blue',lw=0.9)
        for i in range(0,len(trades)):
            if trades[i][2] == 1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='green',marker='^',lw=2.5)
            elif trades[i][2] == -1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='red',marker='^',lw=2.5)
            elif trades[i][2] == 2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='g',marker='x',lw=2.5)
            elif trades[i][2] == -2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='r',marker='x',lw=2.5)

        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='g',marker='^',label='Open Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='r',marker='^',label='Open Short')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='g',marker='x',label='Close Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='r',marker='x',label='Close Short')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_02.pdf')
        plt.close()

        #########################
        ##### PLOT E-CURVE ######
        #########################
        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Equity Curve')
        plt.plot(eq_curx,eq_cury)
        plt.scatter(x=eq_curx,y=eq_cury,c='orange',marker='o',lw=2.5)
        plt.savefig('backtest de '+str(ticker)+'_03.pdf')
        plt.close()


        f.close()
        sys.stdout = orig_stdout

        print('\r Boucle ', loop, 'terminée...',end='')
        print('Opération restantes :', len(constituents)-loop,'/',len(constituents),'\n')


        backtest = backtest.append([{'Symb.':ticker,'Name':name,'Sector':sector,'Period':duration,'Begin.':resultats.iloc[0,0],'End':resultats.iloc[-1,0],\
                          'Pnl $':pnl,'Pnl %':round(pnl/(10000/beta)*100,2),'Gross Profit':round(sum(winners),2),'Gross Loss':round(sum(loosers),2),'# Winners':nb_win,'# Loosers':nb_los,\
                          '% Winners':round((nb_win/(nb_win+nb_los) * 100),2),'MaxDD $':round(min(maxdd),2),'MaxDD %':round(min(maxdd)/(10000/beta)*100,2),'Aver. Win $':(round(sum(winners)/(nb_win))),\
                          'Aver. Loos $':(round(sum(loosers)/(nb_los))),'Aver. Duration':average_duration,\
                          'Total Trades':nbL+nbS,'% Long':round((nbL*100)/(nbL+nbS),2),'% Short':round((nbS*100)/(nbL+nbS),2), 'Profit Factor':abs(round((sum(winners)/sum(loosers)),2))}], ignore_index=True)


        #signals = signals.append([{ 'Date': list_signals[0], 'Ticker' : list_signals[8], 'Open Long' : list_signals[1],\
                                   #'Close Long' : list_signals[2], 'Open Short' : list_signals[3], 'Close Short' : list_signals[4],\
                                   #'Buy/Sell Price' : list_signals[5], 'Quantity' : list_signals[6], ' tPNL' : list_signals[7]}])

        #signals['Date'] = list_signals[0]
        #signals['Ticker'] = list_signals[8]
        #signals['Open Long'] = list_signals[1]
        #signals['Close Long'] = list_signals[2]
        #signals['Open Short'] = list_signals[3]
        #signals['Close Short'] = list_signals[4]
        #signals['Buy/Sell Price'] = list_signals[5]
        #signals['Quantity'] = list_signals[6]
        #signals['tPNL'] = list_signals[7]

    # symbol / name / sector / period of backtest / debut / fin / pnl / total winners / total loosers / Nb winners / nb loosers / 
    # / % winners / Max DD / Aver Win / Aver Loos / Average duration / Profit Factor
        print(Fore.YELLOW,'Writing BACKTEST CSV AND SIGNALS.CSV',Style.RESET_ALL)
        backtest.to_csv('BackTest.csv')
        signals.sort_values(by=['Date'])
        signals.to_csv('SIGNALS.csv')

        print(Fore.CYAN,'BACKTEST CSV WRITED AND SIGNALS.CSV',Style.RESET_ALL)
    except:
        print(Fore.RED,'Problème loop : ',loop,Style.RESET_ALL)
        error.append((loop,ticker))
         
        continue
# Out:
# Importing Librairies...
# Using TensorFlow backend.
# Librairies imported
#
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
# BOOST SKAN 55 Version v1.35
#
# Sraping tickers
# Scrap -----> ok
# Loop : 0
# amorce :  0
# amorce2 :  0
#  --- Loop : 0  ---  --- Symbol :   MMM   ---  --- Name :  3M Company  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.101035079282265
#  Alpha :  0.03740893788267117
#  R_Squared :  0.510409486190262
#  Volatility :  0.16686154950961513
#  Momentum :  -0.16899133407925981
# executed in = 2.110000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:33:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 6.050000 seconds
#  Deeping in blue
#
#  --- Loop : 0  ---  --- Symbol :   MMM   ---  --- Name :  3M Company  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 75us/step
# 1005/1005 [==============================] - 0s 76us/step
# 202/202 [==============================] - 0s 24us/step
# 202/202 [==============================] - 0s 27us/step
#
#
#  RESULTATS UP
#
# Accuracy: 89.11%
#  Precision: 91.38%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 75.71%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92       132
#            1       0.91      0.76      0.83        70
#
#    micro avg       0.89      0.89      0.89       202
#    macro avg       0.90      0.86      0.87       202
# weighted avg       0.89      0.89      0.89       202
#
# [[127   5]
#  [ 17  53]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 95.54%
#  Precision: 97.56%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 95.24%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94        76
#            1       0.98      0.95      0.96       126
#
#    micro avg       0.96      0.96      0.96       202
#    macro avg       0.95      0.96      0.95       202
# weighted avg       0.96      0.96      0.96       202
#
# [[ 73   3]
#  [  6 120]]
#
#
# Deep Learning executed in = 87.250000 seconds
#  Boucle  0 terminée...Opération restantes : 505 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 1
# amorce :  0
# amorce2 :  0
#  --- Loop : 1  ---  --- Symbol :   AOS   ---  --- Name :  A.O. Smith Corp  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.3591502294945956
#  Alpha :  0.05999814984649055
#  R_Squared :  0.4765113552657704
#  Volatility :  0.2131794417406938
#  Momentum :  -0.29348726063811237
# executed in = 1.690000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:35:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 6.300000 seconds
#  Deeping in blue
#
#  --- Loop : 1  ---  --- Symbol :   AOS   ---  --- Name :  A.O. Smith Corp  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 130us/step
# 1005/1005 [==============================] - 0s 130us/step
# 202/202 [==============================] - 0s 28us/step
# 202/202 [==============================] - 0s 29us/step
#
#
#  RESULTATS UP
#
# Accuracy: 81.19%
#  Precision: 76.92%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.46%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.85      0.82      0.83       115
#            1       0.77      0.80      0.79        87
#
#    micro avg       0.81      0.81      0.81       202
#    macro avg       0.81      0.81      0.81       202
# weighted avg       0.81      0.81      0.81       202
#
# [[94 21]
#  [17 70]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 79.21%
#  Precision: 91.18%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 63.27%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.73      0.94      0.82       104
#            1       0.91      0.63      0.75        98
#
#    micro avg       0.79      0.79      0.79       202
#    macro avg       0.82      0.79      0.79       202
# weighted avg       0.82      0.79      0.79       202
#
# [[98  6]
#  [36 62]]
#
#
# Deep Learning executed in = 86.010000 seconds
#  Boucle  1 terminée...Opération restantes : 504 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 2
# amorce :  0
# amorce2 :  0
#  --- Loop : 2  ---  --- Symbol :   ABT   ---  --- Name :  Abbott Laboratories  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.2531517836064885
#  Alpha :  0.08428770352319351
#  R_Squared :  0.4944864585627803
#  Volatility :  0.19294830156061096
#  Momentum :  0.290618421148757
# executed in = 1.950000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:37:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 7.440000 seconds
#  Deeping in blue
#
#  --- Loop : 2  ---  --- Symbol :   ABT   ---  --- Name :  Abbott Laboratories  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 202us/step
# 1005/1005 [==============================] - 0s 173us/step
# 202/202 [==============================] - 0s 32us/step
# 202/202 [==============================] - 0s 30us/step
#
#
#  RESULTATS UP
#
# Accuracy: 83.66%
#  Precision: 75.68%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 93.33%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.93      0.76      0.84       112
#            1       0.76      0.93      0.84        90
#
#    micro avg       0.84      0.84      0.84       202
#    macro avg       0.85      0.85      0.84       202
# weighted avg       0.86      0.84      0.84       202
#
# [[85 27]
#  [ 6 84]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 82.67%
#  Precision: 79.05%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 86.46%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.87      0.79      0.83       106
#            1       0.79      0.86      0.83        96
#
#    micro avg       0.83      0.83      0.83       202
#    macro avg       0.83      0.83      0.83       202
# weighted avg       0.83      0.83      0.83       202
#
# [[84 22]
#  [13 83]]
#
#
# Deep Learning executed in = 105.020000 seconds
#  Boucle  2 terminée...Opération restantes : 503 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 3
# amorce :  0
# amorce2 :  0
#  --- Loop : 3  ---  --- Symbol :   ABBV   ---  --- Name :  AbbVie Inc.  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.4529500222129708
#  Alpha :  0.0867776566062107
#  R_Squared :  0.3650621013472348
#  Volatility :  0.26036451029245755
#  Momentum :  -0.009564757078164399
# executed in = 1.960000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:39:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 7.150000 seconds
#  Deeping in blue
#
#  --- Loop : 3  ---  --- Symbol :   ABBV   ---  --- Name :  AbbVie Inc.  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 207us/step
# 1005/1005 [==============================] - 0s 192us/step
# 202/202 [==============================] - 0s 28us/step
# 202/202 [==============================] - 0s 31us/step
#
#
#  RESULTATS UP
#
# Accuracy: 72.28%
#  Precision: 64.62%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 89.36%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.57      0.69       108
#            1       0.65      0.89      0.75        94
#
#    micro avg       0.72      0.72      0.72       202
#    macro avg       0.75      0.73      0.72       202
# weighted avg       0.76      0.72      0.72       202
#
# [[62 46]
#  [10 84]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 69.31%
#  Precision: 96.88%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 33.70%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.64      0.99      0.78       110
#            1       0.97      0.34      0.50        92
#
#    micro avg       0.69      0.69      0.69       202
#    macro avg       0.80      0.66      0.64       202
# weighted avg       0.79      0.69      0.65       202
#
# [[109   1]
#  [ 61  31]]
#
#
# Deep Learning executed in = 88.220000 seconds
#  Boucle  3 terminée...Opération restantes : 502 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 4
# amorce :  0
# amorce2 :  0
#  --- Loop : 4  ---  --- Symbol :   ACN   ---  --- Name :  Accenture plc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.105231443177882
#  Alpha :  0.07010733634372114
#  R_Squared :  0.5228081115384566
#  Volatility :  0.16549945128246862
#  Momentum :  -0.06228695645857307
# executed in = 2.060000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:40:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.800000 seconds
#  Deeping in blue
#
#  --- Loop : 4  ---  --- Symbol :   ACN   ---  --- Name :  Accenture plc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 276us/step
# 1005/1005 [==============================] - 0s 243us/step
# 202/202 [==============================] - 0s 32us/step
# 202/202 [==============================] - 0s 31us/step
#
#
#  RESULTATS UP
#
# Accuracy: 55.45%
#  Precision: 50.55%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.18      0.31       110
#            1       0.51      1.00      0.67        92
#
#    micro avg       0.55      0.55      0.55       202
#    macro avg       0.75      0.59      0.49       202
# weighted avg       0.77      0.55      0.47       202
#
# [[20 90]
#  [ 0 92]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 82.67%
#  Precision: 88.57%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 69.66%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86       113
#            1       0.89      0.70      0.78        89
#
#    micro avg       0.83      0.83      0.83       202
#    macro avg       0.84      0.81      0.82       202
# weighted avg       0.84      0.83      0.82       202
#
# [[105   8]
#  [ 27  62]]
#
#
# Deep Learning executed in = 87.120000 seconds
#  Boucle  4 terminée...Opération restantes : 501 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 5
# amorce :  0
# amorce2 :  0
#  --- Loop : 5  ---  --- Symbol :   ATVI   ---  --- Name :  Activision Blizzard  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.012194700117205
#  Alpha :  0.18252781833532009
#  R_Squared :  0.13493664445372766
#  Volatility :  0.29834144638668864
#  Momentum :  -0.2607377203035609
# executed in = 4.980000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:42:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.650000 seconds
#  Deeping in blue
#
#  --- Loop : 5  ---  --- Symbol :   ATVI   ---  --- Name :  Activision Blizzard  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 288us/step
# 1005/1005 [==============================] - 0s 271us/step
# 202/202 [==============================] - 0s 26us/step
# 202/202 [==============================] - 0s 29us/step
#
#
#  RESULTATS UP
#
# Accuracy: 75.74%
#  Precision: 67.24%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 87.64%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.87      0.66      0.75       113
#            1       0.67      0.88      0.76        89
#
#    micro avg       0.76      0.76      0.76       202
#    macro avg       0.77      0.77      0.76       202
# weighted avg       0.78      0.76      0.76       202
#
# [[75 38]
#  [11 78]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 84.16%
#  Precision: 85.56%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.21%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85       106
#            1       0.86      0.80      0.83        96
#
#    micro avg       0.84      0.84      0.84       202
#    macro avg       0.84      0.84      0.84       202
# weighted avg       0.84      0.84      0.84       202
#
# [[93 13]
#  [19 77]]
#
#
# Deep Learning executed in = 90.070000 seconds
#  Boucle  5 terminée...Opération restantes : 500 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 6
# amorce :  0
# amorce2 :  0
#  --- Loop : 6  ---  --- Symbol :   AYI   ---  --- Name :  Acuity Brands Inc  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.6525475518085289
#  Alpha :  -0.08090880540341198
#  R_Squared :  0.2571855361493516
#  Volatility :  0.3528134879459494
#  Momentum :  -0.34438257033112774
# executed in = 2.110000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:44:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.840000 seconds
#  Deeping in blue
#
#  --- Loop : 6  ---  --- Symbol :   AYI   ---  --- Name :  Acuity Brands Inc  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 320us/step
# 1005/1005 [==============================] - 0s 322us/step
# 202/202 [==============================] - 0s 34us/step
# 202/202 [==============================] - 0s 38us/step
#
#
#  RESULTATS UP
#
# Accuracy: 80.69%
#  Precision: 73.45%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 90.22%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.73      0.80       110
#            1       0.73      0.90      0.81        92
#
#    micro avg       0.81      0.81      0.81       202
#    macro avg       0.82      0.81      0.81       202
# weighted avg       0.82      0.81      0.81       202
#
# [[80 30]
#  [ 9 83]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 84.16%
#  Precision: 100.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 67.35%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.87       104
#            1       1.00      0.67      0.80        98
#
#    micro avg       0.84      0.84      0.84       202
#    macro avg       0.88      0.84      0.84       202
# weighted avg       0.88      0.84      0.84       202
#
# [[104   0]
#  [ 32  66]]
#
#
# Deep Learning executed in = 94.100000 seconds
#  Boucle  6 terminée...Opération restantes : 499 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 7
# amorce :  0
# amorce2 :  0
#  --- Loop : 7  ---  --- Symbol :   ADBE   ---  --- Name :  Adobe Systems Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.167955413885577
#  Alpha :  0.208856731755817
#  R_Squared :  0.3616196820950557
#  Volatility :  0.21028811063433012
#  Momentum :  0.29102943620935573
# executed in = 2.040000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:45:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.840000 seconds
#  Deeping in blue
#
#  --- Loop : 7  ---  --- Symbol :   ADBE   ---  --- Name :  Adobe Systems Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 368us/step
# 1005/1005 [==============================] - 0s 374us/step
# 202/202 [==============================] - 0s 45us/step
# 202/202 [==============================] - 0s 39us/step
#
#
#  RESULTATS UP
#
# Accuracy: 67.82%
#  Precision: 63.38%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 87.38%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.78      0.47      0.59        99
#            1       0.63      0.87      0.73       103
#
#    micro avg       0.68      0.68      0.68       202
#    macro avg       0.71      0.67      0.66       202
# weighted avg       0.71      0.68      0.66       202
#
# [[47 52]
#  [13 90]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 74.75%
#  Precision: 64.10%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 89.29%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.89      0.64      0.75       118
#            1       0.64      0.89      0.75        84
#
#    micro avg       0.75      0.75      0.75       202
#    macro avg       0.77      0.77      0.75       202
# weighted avg       0.79      0.75      0.75       202
#
# [[76 42]
#  [ 9 75]]
#
#
# Deep Learning executed in = 96.330000 seconds
#  Boucle  7 terminée...Opération restantes : 498 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 8
# amorce :  0
# amorce2 :  0
#  --- Loop : 8  ---  --- Symbol :   AAP   ---  --- Name :  Advance Auto Parts  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  1.129373330868197
#  Alpha :  0.02543983481763654
#  R_Squared :  0.162653246198034
#  Volatility :  0.30319402981977
#  Momentum :  0.5821685976104445
# executed in = 2.880000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:47:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.000000 seconds
#  Deeping in blue
#
#  --- Loop : 8  ---  --- Symbol :   AAP   ---  --- Name :  Advance Auto Parts  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 493us/step
# 1005/1005 [==============================] - 1s 516us/step
# 202/202 [==============================] - 0s 36us/step
# 202/202 [==============================] - 0s 47us/step
#
#
#  RESULTATS UP
#
# Accuracy: 88.61%
#  Precision: 88.30%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 87.37%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.89       107
#            1       0.88      0.87      0.88        95
#
#    micro avg       0.89      0.89      0.89       202
#    macro avg       0.89      0.89      0.89       202
# weighted avg       0.89      0.89      0.89       202
#
# [[96 11]
#  [12 83]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 87.62%
#  Precision: 80.19%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 95.51%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.96      0.81      0.88       113
#            1       0.80      0.96      0.87        89
#
#    micro avg       0.88      0.88      0.88       202
#    macro avg       0.88      0.88      0.88       202
# weighted avg       0.89      0.88      0.88       202
#
# [[92 21]
#  [ 4 85]]
#
#
# Deep Learning executed in = 100.180000 seconds
#  Boucle  8 terminée...Opération restantes : 497 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 9
# amorce :  0
# amorce2 :  0
#  --- Loop : 9  ---  --- Symbol :   AMD   ---  --- Name :  Advanced Micro Devices Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  3.3617920325303765
#  Alpha :  0.26792537084924806
#  R_Squared :  0.3668472546514069
#  Volatility :  0.6009560225427302
#  Momentum :  0.7957198019437328
# executed in = 2.220000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:49:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.520000 seconds
#  Deeping in blue
#
#  --- Loop : 9  ---  --- Symbol :   AMD   ---  --- Name :  Advanced Micro Devices Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 490us/step
# 1005/1005 [==============================] - 0s 444us/step
# 202/202 [==============================] - 0s 36us/step
# 202/202 [==============================] - 0s 36us/step
#
#
#  RESULTATS UP
#
# Accuracy: 73.27%
#  Precision: 77.78%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 63.64%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.70      0.83      0.76       103
#            1       0.78      0.64      0.70        99
#
#    micro avg       0.73      0.73      0.73       202
#    macro avg       0.74      0.73      0.73       202
# weighted avg       0.74      0.73      0.73       202
#
# [[85 18]
#  [36 63]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 75.74%
#  Precision: 70.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 78.65%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.81      0.73      0.77       113
#            1       0.70      0.79      0.74        89
#
#    micro avg       0.76      0.76      0.76       202
#    macro avg       0.76      0.76      0.76       202
# weighted avg       0.76      0.76      0.76       202
#
# [[83 30]
#  [19 70]]
#
#
# Deep Learning executed in = 103.130000 seconds
#  Boucle  9 terminée...Opération restantes : 496 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 10
# amorce :  0
# amorce2 :  0
#  --- Loop : 10  ---  --- Symbol :   AES   ---  --- Name :  AES Corp  ---  --- Sector :  Utilities  ---
# Scraping data...
# Beta :  0.9623473969942176
#  Alpha :  -0.008360786201702938
#  R_Squared :  0.23928826951805837
#  Volatility :  0.21300296870317265
#  Momentum :  0.3902058680197724
# executed in = 1.890000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:51:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.570000 seconds
#  Deeping in blue
#
#  --- Loop : 10  ---  --- Symbol :   AES   ---  --- Name :  AES Corp  ---  --- Sector :  Utilities  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 0s 491us/step
# 1005/1005 [==============================] - 0s 471us/step
# 202/202 [==============================] - 0s 31us/step
# 202/202 [==============================] - 0s 34us/step
#
#
#  RESULTATS UP
#
# Accuracy: 68.81%
#  Precision: 58.50%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 97.73%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.96      0.46      0.63       114
#            1       0.59      0.98      0.73        88
#
#    micro avg       0.69      0.69      0.69       202
#    macro avg       0.77      0.72      0.68       202
# weighted avg       0.80      0.69      0.67       202
#
# [[53 61]
#  [ 2 86]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 76.73%
#  Precision: 94.83%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 55.56%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.69      0.97      0.81       103
#            1       0.95      0.56      0.70        99
#
#    micro avg       0.77      0.77      0.77       202
#    macro avg       0.82      0.76      0.76       202
# weighted avg       0.82      0.77      0.76       202
#
# [[100   3]
#  [ 44  55]]
#
#
# Deep Learning executed in = 105.950000 seconds
#  Boucle  10 terminée...Opération restantes : 495 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 11
# amorce :  0
# amorce2 :  0
#  --- Loop : 11  ---  --- Symbol :   AET   ---  --- Name :  Aetna Inc  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  0.5693592548712055
#  Alpha :  0.3154327594362326
#  R_Squared :  0.27230778110663123
#  Volatility :  0.12433331752567989
#  Momentum :  0.25857986359906615
# executed in = 1.910000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  185
# On 80% - 20% slash :
# Bloc 1 :  148
# Bloc 2 : 37  periods
# First period : 2018-01-04 00:00:00
# Split period : 2018-10-08 00:00:00
# Last period : 2018-11-29 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:53:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 1.040000 seconds
#  Deeping in blue
#
#  --- Loop : 11  ---  --- Symbol :   AET   ---  --- Name :  Aetna Inc  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 136/136 [==============================] - 1s 5ms/step
# 136/136 [==============================] - 1s 4ms/step
#  Problème loop :  11
# Loop : 12
# amorce :  0
# amorce2 :  0
#  --- Loop : 12  ---  --- Symbol :   AMG   ---  --- Name :  Affiliated Managers Group Inc  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  1.4513306164704534
#  Alpha :  -0.21807954555691425
#  R_Squared :  0.37263542623854096
#  Volatility :  0.25741791694079147
#  Momentum :  -0.5214767546193884
# executed in = 1.860000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:53:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.240000 seconds
#  Deeping in blue
#
#  --- Loop : 12  ---  --- Symbol :   AMG   ---  --- Name :  Affiliated Managers Group Inc  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 568us/step
# 1005/1005 [==============================] - 1s 622us/step
# 202/202 [==============================] - 0s 41us/step
# 202/202 [==============================] - 0s 40us/step
#
#
#  RESULTATS UP
#
# Accuracy: 77.72%
#  Precision: 79.45%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 65.91%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.77      0.87      0.81       114
#            1       0.79      0.66      0.72        88
#
#    micro avg       0.78      0.78      0.78       202
#    macro avg       0.78      0.76      0.77       202
# weighted avg       0.78      0.78      0.77       202
#
# [[99 15]
#  [30 58]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 81.68%
#  Precision: 86.05%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 74.75%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.83       103
#            1       0.86      0.75      0.80        99
#
#    micro avg       0.82      0.82      0.82       202
#    macro avg       0.82      0.82      0.82       202
# weighted avg       0.82      0.82      0.82       202
#
# [[91 12]
#  [25 74]]
#
#
# Deep Learning executed in = 113.190000 seconds
#  Boucle  12 terminée...Opération restantes : 493 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 13
# amorce :  0
# amorce2 :  0
#  --- Loop : 13  ---  --- Symbol :   AFL   ---  --- Name :  AFLAC Inc  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  0.8168721073099722
#  Alpha :  0.07053079062236964
#  R_Squared :  0.37557374960036916
#  Volatility :  0.14431814464899095
#  Momentum :  0.06826093304542269
# executed in = 2.220000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:55:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.540000 seconds
#  Deeping in blue
#
#  --- Loop : 13  ---  --- Symbol :   AFL   ---  --- Name :  AFLAC Inc  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 622us/step
# 1005/1005 [==============================] - 1s 614us/step
# 202/202 [==============================] - 0s 42us/step
# 202/202 [==============================] - 0s 45us/step
#
#
#  RESULTATS UP
#
# Accuracy: 81.68%
#  Precision: 62.63%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.74      0.85       140
#            1       0.63      1.00      0.77        62
#
#    micro avg       0.82      0.82      0.82       202
#    macro avg       0.81      0.87      0.81       202
# weighted avg       0.89      0.82      0.82       202
#
# [[103  37]
#  [  0  62]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 82.18%
#  Precision: 97.94%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 73.64%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.68      0.97      0.80        73
#            1       0.98      0.74      0.84       129
#
#    micro avg       0.82      0.82      0.82       202
#    macro avg       0.83      0.85      0.82       202
# weighted avg       0.87      0.82      0.83       202
#
# [[71  2]
#  [34 95]]
#
#
# Deep Learning executed in = 119.070000 seconds
#  Boucle  13 terminée...Opération restantes : 492 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 14
# amorce :  0
# amorce2 :  0
#  --- Loop : 14  ---  --- Symbol :   A   ---  --- Name :  Agilent Technologies Inc  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.3112899936620435
#  Alpha :  0.030120601420089127
#  R_Squared :  0.4873676416503432
#  Volatility :  0.2033690624556626
#  Momentum :  0.016653838257664866
# executed in = 2.110000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:57:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.120000 seconds
#  Deeping in blue
#
#  --- Loop : 14  ---  --- Symbol :   A   ---  --- Name :  Agilent Technologies Inc  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 708us/step
# 1005/1005 [==============================] - 1s 724us/step
# 202/202 [==============================] - 0s 41us/step
# 202/202 [==============================] - 0s 42us/step
#
#
#  RESULTATS UP
#
# Accuracy: 79.21%
#  Precision: 82.14%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 71.88%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.77      0.86      0.81       106
#            1       0.82      0.72      0.77        96
#
#    micro avg       0.79      0.79      0.79       202
#    macro avg       0.80      0.79      0.79       202
# weighted avg       0.80      0.79      0.79       202
#
# [[91 15]
#  [27 69]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 86.14%
#  Precision: 78.35%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 91.57%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87       119
#            1       0.78      0.92      0.84        83
#
#    micro avg       0.86      0.86      0.86       202
#    macro avg       0.86      0.87      0.86       202
# weighted avg       0.87      0.86      0.86       202
#
# [[98 21]
#  [ 7 76]]
#
#
# Deep Learning executed in = 119.390000 seconds
#  Boucle  14 terminée...Opération restantes : 491 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 15
# amorce :  0
# amorce2 :  0
#  --- Loop : 15  ---  --- Symbol :   APD   ---  --- Name :  Air Products & Chemicals Inc  ---  --- Sector :  Materials  ---
# Scraping data...
# Beta :  0.9067658157728538
#  Alpha :  0.07371691287016335
#  R_Squared :  0.41415983665182565
#  Volatility :  0.15255471463914666
#  Momentum :  0.0026061510113601916
# executed in = 5.180000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [10:00:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.430000 seconds
#  Deeping in blue
#
#  --- Loop : 15  ---  --- Symbol :   APD   ---  --- Name :  Air Products & Chemicals Inc  ---  --- Sector :  Materials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 713us/step
# 1005/1005 [==============================] - 1s 700us/step
# 202/202 [==============================] - 0s 58us/step
# 202/202 [==============================] - 0s 47us/step
#
#
#  RESULTATS UP
#
# Accuracy: 80.69%
#  Precision: 74.26%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.23%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.87      0.77      0.82       114
#            1       0.74      0.85      0.79        88
#
#    micro avg       0.81      0.81      0.81       202
#    macro avg       0.81      0.81      0.81       202
# weighted avg       0.82      0.81      0.81       202
#
# [[88 26]
#  [13 75]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 84.16%
#  Precision: 85.71%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 75.86%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.87       115
#            1       0.86      0.76      0.80        87
#
#    micro avg       0.84      0.84      0.84       202
#    macro avg       0.84      0.83      0.84       202
# weighted avg       0.84      0.84      0.84       202
#
# [[104  11]
#  [ 21  66]]
#
#
# Deep Learning executed in = 125.290000 seconds
#  Boucle  15 terminée...Opération restantes : 490 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 16
# amorce :  0
# amorce2 :  0
#  --- Loop : 16  ---  --- Symbol :   AKAM   ---  --- Name :  Akamai Technologies Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  0.6787114137447234
#  Alpha :  0.049394336359729285
#  R_Squared :  0.05071904902324864
#  Volatility :  0.3262977556734594
#  Momentum :  -0.06088559392266635
# executed in = 2.280000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [10:02:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.350000 seconds
#  Deeping in blue
#
#  --- Loop : 16  ---  --- Symbol :   AKAM   ---  --- Name :  Akamai Technologies Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 795us/step
# 1005/1005 [==============================] - 1s 762us/step
# 202/202 [==============================] - 0s 46us/step
# 202/202 [==============================] - 0s 48us/step
#
#
#  RESULTATS UP
#
# Accuracy: 88.61%
#  Precision: 83.65%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 93.55%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.94      0.84      0.89       109
#            1       0.84      0.94      0.88        93
#
#    micro avg       0.89      0.89      0.89       202
#    macro avg       0.89      0.89      0.89       202
# weighted avg       0.89      0.89      0.89       202
#
# [[92 17]
#  [ 6 87]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 89.60%
#  Precision: 89.01%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 88.04%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.90       110
#            1       0.89      0.88      0.89        92
#
#    micro avg       0.90      0.90      0.90       202
#    macro avg       0.90      0.89      0.90       202
# weighted avg       0.90      0.90      0.90       202
#
# [[100  10]
#  [ 11  81]]
#
#
# Deep Learning executed in = 129.220000 seconds
#  Boucle  16 terminée...Opération restantes : 489 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 17
# amorce :  0
# amorce2 :  0
#  --- Loop : 17  ---  --- Symbol :   ALK   ---  --- Name :  Alaska Air Group Inc  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  0.9118550389887615
#  Alpha :  0.08059241773539429
#  R_Squared :  0.10627002782714123
#  Volatility :  0.30285509911444963
#  Momentum :  -0.1554881883484347
# executed in = 1.850000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [10:04:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.950000 seconds
#  Deeping in blue
#
#  --- Loop : 17  ---  --- Symbol :   ALK   ---  --- Name :  Alaska Air Group Inc  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 782us/step
# 1005/1005 [==============================] - 1s 782us/step
# 202/202 [==============================] - 0s 48us/step
# 202/202 [==============================] - 0s 49us/step
#
#
#  RESULTATS UP
#
# Accuracy: 83.66%
#  Precision: 78.10%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 89.13%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.79      0.84       110
#            1       0.78      0.89      0.83        92
#
#    micro avg       0.84      0.84      0.84       202
#    macro avg       0.84      0.84      0.84       202
# weighted avg       0.84      0.84      0.84       202
#
# [[87 23]
#  [10 82]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 90.59%
#  Precision: 87.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 93.55%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91       109
#            1       0.87      0.94      0.90        93
#
#    micro avg       0.91      0.91      0.91       202
#    macro avg       0.91      0.91      0.91       202
# weighted avg       0.91      0.91      0.91       202
#
# [[96 13]
#  [ 6 87]]
#
#
# Deep Learning executed in = 130.920000 seconds
#  Boucle  17 terminée...Opération restantes : 488 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 18
# amorce :  0
# amorce2 :  0
#  --- Loop : 18  ---  --- Symbol :   ALB   ---  --- Name :  Albemarle Corp  ---  --- Sector :  Materials  ---
# Scraping data...
# Beta :  1.7025258550080191
#  Alpha :  -0.03089991313431855
#  R_Squared :  0.38602888893939413
#  Volatility :  0.2966868499258486
#  Momentum :  -0.3888941337050327
# executed in = 1.990000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [10:07:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.630000 seconds
#  Deeping in blue
#
#  --- Loop : 18  ---  --- Symbol :   ALB   ---  --- Name :  Albemarle Corp  ---  --- Sector :  Materials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 1s 838us/step
# 1005/1005 [==============================] - 1s 803us/step
# 202/202 [==============================] - 0s 50us/step
# 202/202 [==============================] - 0s 46us/step
#
#
#  RESULTATS UP
#
# Accuracy: 81.68%
#  Precision: 78.35%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 82.61%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       110
#            1       0.78      0.83      0.80        92
#
#    micro avg       0.82      0.82      0.82       202
#    macro avg       0.82      0.82      0.82       202
# weighted avg       0.82      0.82      0.82       202
#
# [[89 21]
#  [16 76]]
#
#
# ...
# Loop : 42
# amorce :  0
# amorce2 :  0
#  --- Loop : 42  ---  --- Symbol :   APH   ---  --- Name :  Amphenol Corp  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  0.8584709373421556
#  Alpha :  0.08295041779027566
#  R_Squared :  0.45865950105391706
#  Volatility :  0.13724447965208697
#  Momentum :  -0.06824118841394422
# executed in = 3.010000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:26:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 6.070000 seconds
#  Deeping in blue
#
#  --- Loop : 42  ---  --- Symbol :   APH   ---  --- Name :  Amphenol Corp  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 77us/step
# 202/202 [==============================] - 0s 83us/step
#
#
#  RESULTATS UP
#
# Accuracy: 70.79%
#  Precision: 64.06%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 86.32%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.82      0.57      0.67       107
#            1       0.64      0.86      0.74        95
#
#    micro avg       0.71      0.71      0.71       202
#    macro avg       0.73      0.72      0.70       202
# weighted avg       0.74      0.71      0.70       202
#
# [[61 46]
#  [13 82]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 74.26%
#  Precision: 73.61%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 61.63%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.75      0.84      0.79       116
#            1       0.74      0.62      0.67        86
#
#    micro avg       0.74      0.74      0.74       202
#    macro avg       0.74      0.73      0.73       202
# weighted avg       0.74      0.74      0.74       202
#
# [[97 19]
#  [33 53]]
#
#
# Deep Learning executed in = 210.300000 seconds
#  Boucle  42 terminée...Opération restantes : 463 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 43
# amorce :  0
# amorce2 :  0
#  --- Loop : 43  ---  --- Symbol :   APC   ---  --- Name :  Anadarko Petroleum Corp  ---  --- Sector :  Energy  ---
# Scraping data...
# Beta :  1.6358252002550966
#  Alpha :  -0.17501644354656484
#  R_Squared :  0.2522301259421095
#  Volatility :  0.3526573184575291
#  Momentum :  -0.16818836123244996
# executed in = 2.250000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:30:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.600000 seconds
#  Deeping in blue
#
#  --- Loop : 43  ---  --- Symbol :   APC   ---  --- Name :  Anadarko Petroleum Corp  ---  --- Sector :  Energy  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 84us/step
# 202/202 [==============================] - 0s 85us/step
#
#
#  RESULTATS UP
#
# Accuracy: 83.66%
#  Precision: 93.88%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 60.53%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.98      0.88       126
#            1       0.94      0.61      0.74        76
#
#    micro avg       0.84      0.84      0.84       202
#    macro avg       0.87      0.79      0.81       202
# weighted avg       0.85      0.84      0.83       202
#
# [[123   3]
#  [ 30  46]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 83.17%
#  Precision: 79.69%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 92.73%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.89      0.72      0.80        92
#            1       0.80      0.93      0.86       110
#
#    micro avg       0.83      0.83      0.83       202
#    macro avg       0.84      0.82      0.83       202
# weighted avg       0.84      0.83      0.83       202
#
# [[ 66  26]
#  [  8 102]]
#
#
# Deep Learning executed in = 216.780000 seconds
#  Boucle  43 terminée...Opération restantes : 462 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 44
# amorce :  0
# amorce2 :  0
#  --- Loop : 44  ---  --- Symbol :   ADI   ---  --- Name :  Analog Devices, Inc.  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.1675278781361
#  Alpha :  0.0796256670534051
#  R_Squared :  0.3172260994602024
#  Volatility :  0.22443846446037377
#  Momentum :  -0.016391274011067658
# executed in = 2.080000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:34:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.740000 seconds
#  Deeping in blue
#
#  --- Loop : 44  ---  --- Symbol :   ADI   ---  --- Name :  Analog Devices, Inc.  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 79us/step
# 202/202 [==============================] - 0s 74us/step
#
#
#  RESULTATS UP
#
# Accuracy: 70.79%
#  Precision: 62.31%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 89.01%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.56      0.68       111
#            1       0.62      0.89      0.73        91
#
#    micro avg       0.71      0.71      0.71       202
#    macro avg       0.74      0.72      0.71       202
# weighted avg       0.75      0.71      0.70       202
#
# [[62 49]
#  [10 81]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 76.24%
#  Precision: 67.20%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 92.31%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.91      0.63      0.74       111
#            1       0.67      0.92      0.78        91
#
#    micro avg       0.76      0.76      0.76       202
#    macro avg       0.79      0.78      0.76       202
# weighted avg       0.80      0.76      0.76       202
#
# [[70 41]
#  [ 7 84]]
#
#
# Deep Learning executed in = 219.380000 seconds
#  Boucle  44 terminée...Opération restantes : 461 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 45
# amorce :  0
# amorce2 :  0
#  --- Loop : 45  ---  --- Symbol :   ANDV   ---  --- Name :  Andeavor  ---  --- Sector :  Energy  ---
# Scraping data...
#  Problème loop :  45
# Loop : 46
# amorce :  0
# amorce2 :  0
#  --- Loop : 46  ---  --- Symbol :   ANSS   ---  --- Name :  ANSYS  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.288210285818308
#  Alpha :  0.04747969437346083
#  R_Squared :  0.43726280554361774
#  Volatility :  0.2109259330709977
#  Momentum :  -0.031506159034239256
# executed in = 2.140000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:37:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.520000 seconds
#  Deeping in blue
#
#  --- Loop : 46  ---  --- Symbol :   ANSS   ---  --- Name :  ANSYS  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 79us/step
# 202/202 [==============================] - 0s 68us/step
#
#
#  RESULTATS UP
#
# Accuracy: 79.21%
#  Precision: 72.97%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 87.10%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.87      0.72      0.79       109
#            1       0.73      0.87      0.79        93
#
#    micro avg       0.79      0.79      0.79       202
#    macro avg       0.80      0.80      0.79       202
# weighted avg       0.80      0.79      0.79       202
#
# [[79 30]
#  [12 81]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 79.21%
#  Precision: 78.02%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 76.34%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.82      0.81       109
#            1       0.78      0.76      0.77        93
#
#    micro avg       0.79      0.79      0.79       202
#    macro avg       0.79      0.79      0.79       202
# weighted avg       0.79      0.79      0.79       202
#
# [[89 20]
#  [22 71]]
#
#
# Deep Learning executed in = 174.810000 seconds
#  Boucle  46 terminée...Opération restantes : 459 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 47
# amorce :  0
# amorce2 :  0
#  --- Loop : 47  ---  --- Symbol :   ANTM   ---  --- Name :  Anthem Inc.  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  0.8719247748121733
#  Alpha :  0.19917904151279914
#  R_Squared :  0.22171896126337753
#  Volatility :  0.20048970884800213
#  Momentum :  0.1810991294843698
# executed in = 2.350000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:41:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.140000 seconds
#  Deeping in blue
#
#  --- Loop : 47  ---  --- Symbol :   ANTM   ---  --- Name :  Anthem Inc.  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 66us/step
# 202/202 [==============================] - 0s 75us/step
#
#
#  RESULTATS UP
#
# Accuracy: 91.58%
#  Precision: 88.61%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 89.74%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       124
#            1       0.89      0.90      0.89        78
#
#    micro avg       0.92      0.92      0.92       202
#    macro avg       0.91      0.91      0.91       202
# weighted avg       0.92      0.92      0.92       202
#
# [[115   9]
#  [  8  70]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 82.67%
#  Precision: 76.87%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 99.12%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.98      0.61      0.76        88
#            1       0.77      0.99      0.87       114
#
#    micro avg       0.83      0.83      0.83       202
#    macro avg       0.88      0.80      0.81       202
# weighted avg       0.86      0.83      0.82       202
#
# [[ 54  34]
#  [  1 113]]
#
#
# Deep Learning executed in = 164.690000 seconds
#  Boucle  47 terminée...Opération restantes : 458 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 48
# amorce :  0
# amorce2 :  0
#  --- Loop : 48  ---  --- Symbol :   AON   ---  --- Name :  Aon plc  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  0.9268090272009646
#  Alpha :  0.07448010753040726
#  R_Squared :  0.42905237411538044
#  Volatility :  0.1531967617833683
#  Momentum :  0.09944404909072424
# executed in = 2.810000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1256
# On 80% - 20% slash :
# Bloc 1 :  1005
# Bloc 2 : 251  periods
# First period : 2014-01-06 00:00:00
# Split period : 2017-12-29 00:00:00
# Last period : 2018-12-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:44:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.030000 seconds
#  Deeping in blue
#
#  --- Loop : 48  ---  --- Symbol :   AON   ---  --- Name :  Aon plc  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 1005/1005 [==============================] - 2s 2ms/step
# 1005/1005 [==============================] - 2s 2ms/step
# 202/202 [==============================] - 0s 81us/step
# 202/202 [==============================] - 0s 74us/step
#
#
#  RESULTATS UP
#
# Accuracy: 83.66%
#  Precision: 85.57%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 81.37%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       100
#            1       0.86      0.81      0.83       102
#
#    micro avg       0.84      0.84      0.84       202
#    macro avg       0.84      0.84      0.84       202
# weighted avg       0.84      0.84      0.84       202
#
# [[86 14]
#  [19 83]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 81.19%
#  Precision: 72.92%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.37%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.89      0.78      0.83       120
#            1       0.73      0.85      0.79        82
#
#    micro avg       0.81      0.81      0.81       202
#    macro avg       0.81      0.82      0.81       202
# weighted avg       0.82      0.81      0.81       202
#
# [[94 26]
#  [12 70]]
#
#
# Deep Learning executed in = 166.170000 seconds
#  Boucle  48 terminée...Opération restantes : 457 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV

# %%
#import sys
#orig_stdout = sys.stdout
#f = open('backtestv2_4.txt', 'w')
#sys.stdout = f

# %%
#f.close()
#sys.stdout = orig_stdout

# %% [markdown]
# import pandas as pd
#
# backtest = pd.DataFrame(columns = ['Symb.','Name','Sector','period','Begin.','End',\
#                           'Pnl','%Pnl','Total Winners','Total Loosers','Nb Win','Nb Los',\
#                           '% Winners','MaxDD','%MaxDD','Aver. Win',\
#                           'Aver. Los','Aver. Duration',\
#                           'Total Trades','% Long','% Short','Profit Factor'])
# backtest.to_csv('BackTest.csv')
#
# signals = pd.DataFrame(columns = ['Date','Ticker','Open Long','Close Long','Open Short','Close Short','Buy/Sell Price','Quantity','tPNL'])
# signals.to_csv('SIGNALS.csv')

# %%
2+2
# Out:
# 4

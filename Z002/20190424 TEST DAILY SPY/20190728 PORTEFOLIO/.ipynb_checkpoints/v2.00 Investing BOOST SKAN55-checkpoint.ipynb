# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
print('Importing Librairies...')
import talib
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import xgboost as xgb
from xgboost import XGBRegressor, plot_importance
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')
import time
import datetime as dt
import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
print('Librairies imported')
print('')

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print('BOOST SKAN 55 Version v1.33',Style.RESET_ALL)



print('')
print('Sraping tickers')
constituents = pd.read_csv('constituents_csv.csv')
print('Scrap -----> ok')
# PARAMETRES TEMPORELS INITIAUX
start = pd.to_datetime('2015-03-03')
end = pd.to_datetime('2019-07-21')

error = []
try :
    amorce = pd.read_csv('backtest.csv').index[-1] + 1
except:
    amorce = 0
    backtest = pd.DataFrame(columns = ['Symb.','Name','Sector','period','Begin.','End',\
                          'Pnl','%Pnl','Total Winners','Total Loosers','Nb Win','Nb Los',\
                          '% Winners','MaxDD','%MaxDD','Aver. Win',\
                          'Aver. Los','Aver. Duration',\
                          'Profit Factor'])

# SCRAPING DES DONNES BRUTES
def scrap_data(ticker,start,end):
    df = web.DataReader(ticker,'yahoo',start,end)
    df = df.drop(['Close'],axis=1)
    df['Close'] = df['Adj Close']
    df = df.drop(['Adj Close'],axis = 1)
    return(df)

def prepa_data(df):
    tmps1=time.time()
    print('Preparing data...')
    rsi = talib.RSI(df['Close'],timeperiod=14)
    stoc_slowk, stoc_slowd = talib.STOCH(df['High'],df['Low'],df['Close'])
    upper, middle, lower =  talib.BBANDS(df['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(df['Close'],timeperiod=5)
    sma8 = talib.SMA(df['Close'],timeperiod=8)
    sma10 = talib.SMA(df['Close'],timeperiod=10)
    sma12 = talib.SMA(df['Close'],timeperiod=12)
    sma15 = talib.SMA(df['Close'],timeperiod=15)
    sma30 = talib.SMA(df['Close'],timeperiod=30)
    sma35 = talib.SMA(df['Close'],timeperiod=35)
    sma40 = talib.SMA(df['Close'],timeperiod=40)
    sma45 = talib.SMA(df['Close'],timeperiod=45)
    sma50 = talib.SMA(df['Close'],timeperiod=50)
    atr = talib.ATR(df['High'],df['Low'],df['Close'],timeperiod=10)
    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50
    bbdelta = upper - middle
    price_bolup = df['Close'] - lower
    price_bolow = df['Close'] - upper
    Ema = talib.EMA(df['Close'],timeperiod=20)
    KC_High = Ema + 2*atr
    KC_Low = Ema - 2*atr
    aroondown, aroonup = talib.AROON(df['High'], df['Low'], timeperiod=9)
    aroon = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
    rsi30_list = []
    rsi70_list = []
    for i in range(0,df.shape[0]):
        rsi70_list.append(70 - rsi[i])
        rsi30_list.append(rsi[i] - 30)
        #except:
         #   rsi70_list.append(0)
          #  rs30_list.append(0)
    varop_spy = df['Open'] - df['Close']
    varhl_spy = df['High'] - df['Low']
    df['Varop_Spy'] = varop_spy
    df['Varhl_spy'] = varhl_spy
    df['RSI'] = rsi
    df['70 - RSI'] = np.array(rsi70_list)
    df['RSI - 30'] = np.array(rsi30_list)
    df['BBD_Delta_Up'] = bbdelta
    df['delta5_8'] = delta5_8
    df['delta8_10'] = delta8_10
    df['delta10_12'] = delta10_12
    df['delta12_15'] = delta12_15
    df['delta15_30'] = delta15_30
    df['delta30_35'] = delta30_35
    df['delta35_40'] = delta35_40
    df['delta40_45'] = delta40_45
    df['delta45_50'] = delta45_50
    df['Stoc_Slowk'] = stoc_slowk
    df['Stoc_Slowd'] = stoc_slowd
    df['KC_High'] = KC_High
    df['KC_Low'] = KC_Low
    df['upper'] = upper
    df['lower'] = lower
    df['var_bollup_kchigh'] = upper-KC_High
    df['var_bolllow_kclow'] = lower-KC_Low
    df['Aroon Up'] = aroonup
    df['Aroon Down'] = aroondown
    df['Delta Aroon'] = aroon
    up = []
    down = []
    df = df.dropna()
    df = boost(df)
    df['%Futur'] = ((df['Close.S']-df['Close']) *100) / (df['Close'])
    df['%Futur2'] = ((df['Close.S2']-df['Close']) *100) / (df['Close'])
    for i in range(0,df.shape[0]-5):
        if df.iloc[i]['%Futur'] > 0.1 :#or df.iloc[i]['%Futur2'] > 0.1:
            up.append(1)
            down.append(0)
        elif df.iloc[i]['%Futur'] < -0.1: #or df.iloc[i]['%Futur2'] < -0.1:
            up.append(0)
            down.append(1)
        else:
            up.append(0)
            down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    
    
    df['target_up'] = up  # target_up # abs(np.array(valley))#target_up
    df['target_down'] = down # target_down # abs(np.array(peak))#target_down
    #df = df.dropna()
    tmps2=round(time.time()-tmps1,2)
    print ("Data prepared in = %f" %tmps2,'seconds')
    return(df)

def boost(df):
    print('Boosting')
    X = df.copy()
    X = X.drop(['Close'],axis=1)
    X['Close'] = df['Close']
    y = X.iloc[:,-1]
    Xtrain = X.iloc[:-2,:-1]
    Xtest = X.iloc[-2:-1,:-1]
    yshift = y.shift(-1)
    ytrain = yshift.iloc[:-2]
    ytest = yshift.iloc[-2:-1]

    model = xgb.XGBRegressor(n_estimators=20000, learning_rate=1, gamma=1, subsample=1, colsample_bytree=1, max_depth=100)

    model.fit( Xtrain, ytrain, early_stopping_rounds=150, eval_set=[(Xtest, ytest)], verbose=0)

    ytrain_pred = model.predict(Xtrain)

    y_pred = model.predict(Xtest)

    pred = model.predict(X.iloc[:,:-1])

    df['Close.S'] = pred
    df['Close.S2'] = df['Close.S']
    df = df.dropna()
    print('Boost ok')
    return(df)

    
def deep_learning(df):
    tmps1=time.time()
    X = df.iloc[:,1:-4]
    y_up = df.iloc[:,-2].values
    y_down = df.iloc[:,-1].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:bloc1,:]
    Xtest = X[bloc1:,:]
    ytrain_up = y_up[:bloc1,:]
    ytest_up = y_up[bloc1:,:]
    ytrain_down = y_down[:bloc1,:]
    ytest_down = y_down[bloc1:,:]

    seed = 770
    np.random.seed(seed)

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    model_up = Sequential()
    # Add an input layer 
    model_up.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_up.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_up.add(Dense(1, activation='sigmoid'))

    model_down = Sequential()
    # Add an input layer 
    model_down.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_down.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_down.add(Dense(1, activation='sigmoid'))

    print('Processing move_up')
    model_up.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])
    
              

    history_up = model_up.fit(Xtrain, ytrain_up,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Processing move_down')
    model_down.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])

    history_down = model_down.fit(Xtrain, ytrain_down,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Computing done')
    print('\n')

    train_acc_up = model_up.evaluate(Xtrain, ytrain_up,verbose=1)
    train_acc_down = model_down.evaluate(Xtrain, ytrain_down,verbose=1)

    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    score_up = model_up.evaluate(Xtest, ytest_up,verbose=1)
    score_down = model_down.evaluate(Xtest, ytest_down,verbose=1)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)

    accuracy_up = accuracy_score(ytest_up, yhat_up)
    accuracy_down = accuracy_score(ytest_down, yhat_down)

    # La précision permet de mesurer la capacité du modèle à refuser résultats non-pertinents : vrais_positifs/(vrais_positifs+faux_positifs)
    precision_up = precision_score(ytest_up, yhat_up)  
    precision_down = precision_score(ytest_down, yhat_down) 


    # Recall : (vrai_positifs/(vrais_positifs+faux_négatifs))
    recall_up = recall_score(ytest_up, yhat_up) 
    recall_down = recall_score(ytest_down, yhat_down) 


    #roc_up=roc_auc_score(ytest_up,yhat_up)
    #roc_down=roc_auc_score(ytest_down,yhat_down)
    print('\n')
    print(Fore.GREEN,'RESULTATS UP\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_up * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_up *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_up * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_up *100))
    # get probabilities for positive class

    print(classification_report(ytest_up, yhat_up))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_up, yhat_up))

    print('\n')
    print('_______________________________________________________________________________________________________________________________________________________________\n')
    print(Fore.RED,'RESULTATS DOWN\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_down * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_down *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_down * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_down *100))
    # get probabilities for positive class

    print(classification_report(ytest_down, yhat_down))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_down, yhat_down))
    print('\n')

    resultats = pd.DataFrame()
    resultats['Date'] = df.index[bloc1:]
    resultats.index= df.index[bloc1:]
    resultats['Move Up'] = yhat_up
    resultats['Confiance up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confiance Down'] = (predict_down)*100
    resultats['Actual'] = df.iloc[bloc1:]['Close']
    resultats['Actual.S'] = df.iloc[bloc1:]['Close.S']
    open_S = df['Open'].shift(-1)
    resultats['Open.S'] = open_S.iloc[bloc1:]
    dmp_cp=[]
    dmp_cp = ((resultats['Confiance up']-resultats['Confiance Down'])/(resultats['Confiance up']+resultats['Confiance Down'])*100)
    resultats['DMP_CP'] = dmp_cp
    tmps2=round(time.time()-tmps1,2)
    print ("Deep Learning executed in = %f" %tmps2,'seconds')
    #resultats.set_index('Date',inplace=True)
    #parse_dates=resultats['Date']
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def learn(df):
    resultats,precision_up,precision_down,model_up,model_down,scaler = deep_learning(df)
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def grobeta(df,dfb):
    # create a time-series of monthly data points
    rts = df.resample('M').last()
    rbts = dfb.resample('M').last()
    dfsm = pd.DataFrame({'s_adjclose' : rts['Close'],
                            'b_adjclose' : rbts['Adj Close']},
                            index=rts.index)

    # compute returns
    dfsm[['s_returns','b_returns']] = dfsm[['s_adjclose','b_adjclose']]/\
        dfsm[['s_adjclose','b_adjclose']].shift(1) -1
    dfsm = dfsm.dropna()
    covmat = np.cov(dfsm["s_returns"],dfsm["b_returns"])

    # calculate measures now
    beta = covmat[0,1]/covmat[1,1]
    alpha= np.mean(dfsm["s_returns"])-beta*np.mean(dfsm["b_returns"])

    # r_squared     = 1. - SS_res/SS_tot
    ypred = alpha + beta * dfsm["b_returns"]
    SS_res = np.sum(np.power(ypred-dfsm["s_returns"],2))
    SS_tot = covmat[0,0]*(len(dfsm)-1) # SS_tot is sample_variance*(n-1)
    r_squared = 1. - SS_res/SS_tot
    # 5- year volatiity and 1-year momentum
    volatility = np.sqrt(covmat[0,0])
    momentum = np.prod(1+dfsm["s_returns"].tail(12).values) -1

    # annualize the numbers
    prd = 12. # used monthly returns; 12 periods to annualize
    alpha = alpha*prd
    volatility = volatility*np.sqrt(prd)

    print ('Beta : ',beta,'\n Alpha : ',alpha,'\n R_Squared : ', r_squared, '\n Volatility : ', volatility, '\n Momentum : ',momentum)
    return(beta,alpha,r_squared,volatility,momentum)

########################
#### MAIN SKAN55 #######
########################

    
for loop in range(amorce,len(constituents)):
    
    try:

        ticker = (constituents.iloc[loop]['Symbol'])
        name = constituents.iloc[loop]['Name']
        sector = constituents.iloc[loop]['Sector']

        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        global delta,bloc1,bloc2
        tmps1=time.time()
        print('Scraping data...')

        df = scrap_data(ticker,start,end)

        dfb = web.DataReader('^GSPC','yahoo',start,end)

        beta,alpha, r_squared, volatility, momentum = grobeta(df,dfb)

        tmps2=round(time.time()-tmps1,2)
        print ("executed in = %f" %tmps2,'seconds')

        print('\n')
        print('GOLEM begins Computing...')
        print('\n')
        delta = round(df.shape[0])
        bloc1 = round(delta*0.80)
        bloc2 = delta - bloc1
        print("# of periods : ",delta)
        print('On 80% - 20% slash : ')
        print('Bloc 1 : ',bloc1,'\nBloc 2 :',bloc2,' periods ')
        print('First period :',df.index[0])
        print('Split period :',df.index[bloc1-1])
        print('Last period :',df.index[df.shape[0]-1])
        print('\n')

        print('Data prep')
        df = prepa_data(df)

        print(Fore.BLUE,'Deeping in blue',Style.RESET_ALL)
        print('')
        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        resultats,precision_up,precision_down,model_up,model_down,scaler = learn(df)

        import sys
        orig_stdout = sys.stdout
        f = open('backtest de '+str(ticker)+'.txt', 'w')
        sys.stdout = f

        ####################
        #### TEST PLOT ####
        ###################

        filtre_up = 93
        filtre_down = 97
        filtre_up_close = 80
        filtre_down_close = 80


        plt.figure(figsize=(26,8),dpi=300)
        #plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
        plt.title('Deep Learning '+name+' Trade Signals')
        plt.plot(resultats['Actual'],color='purple',lw=0.9,label=ticker)

        green=[]
        red=[]
        green_close=[]
        red_close=[]

        for i in range(0,len(resultats)-1):


            if resultats.iloc[i]['Confiance Down'] > filtre_down:
                doob = -1
            elif resultats.iloc[i]['Confiance Down'] > filtre_down_close and resultats.iloc[i]['Confiance Down'] < filtre_down :
                waab = -1
                doob = 0
            elif resultats.iloc[i]['Confiance up'] > filtre_up:
                doob = 1
            elif resultats.iloc[i]['Confiance up'] > filtre_up_close and resultats.iloc[i]['Confiance up'] < filtre_up:
                waab = 1
                doob = 0
            else :
                doob = 0
                waab = 0

            if doob == 1 :#and resultats.iloc[i]['Confiance up'] > filtre_up:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='g',marker='o')
                #doob = -1
                green.append(1)
                red.append(0)
                green_close.append(0)
                red_close.append(1)

            elif doob == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(1)
                green_close.append(1)
                red_close.append(0)

            elif doob == 0 and waab == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(0)
                green_close.append(0)
                red_close.append(1)

            elif waab == 1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(0)
                green_close.append(1)
                red_close.append(0)  

            else:
                green.append(0)
                red.append(0)
                green_close.append(0)
                red_close.append(0)  

                #doob = 0


        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='g',marker='o',label='Buy Signal')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o',label='Sell Signal')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_01.pdf')
        plt.close()
        green.append(0)
        red.append(0)
        green_close.append(0)
        red_close.append(0)
        resultats['Green'] = green
        resultats['Red'] = red
        resultats['Green_Close'] = green_close
        resultats['Red_Close'] = red_close
        #resultats['Actual'] = df['Close'][bloc1:]

        ########################
        ####### BACKTEST########
        ########################
        pos_long = 0
        pos_short = 0
        pactol = 10000/beta
        price_buy = 0
        price_sell = 0
        x = 0
        winners = []
        loosers = []
        nb_win = 0
        nb_los = 0
        mini_pnl = 0
        pos_duration = []
        average_duration = resultats.iloc[0,0] - resultats.iloc[0,0]
        trades = []
        eq_curx = []
        eq_cury = []
        maxdd = []


        for i in range(0,len(resultats)-1):
            if pos_long == 0 and pos_short == 0 and resultats.iloc[i]['Green'] == 1 :
                pos_long = 1
                x = (10000/beta)/resultats.iloc[i]['Open.S']
                price_buy = resultats.iloc[i]['Open.S']
                time_enter = resultats.iloc[i]['Date']
                print('\n Le ',str(resultats.iloc[i]['Date']),', achat de ',x,' actions à',resultats.iloc[i]['Open.S'],'$')
                print('Nouveau pactol : ',pactol)
                trades.append((resultats.iloc[i]['Open.S'],resultats.iloc[i]['Date'],1))

            elif pos_long == 1 and resultats.iloc[i]['Green_Close'] == 0 :
                try:
                    maxdd.append((resultats.iloc[i]['Open.S'] - price_buy)*x)
                except:
                    print('Null val of maxdd')
                    maxdd.append(0)


            elif pos_long == 1 and resultats.iloc[i]['Green_Close'] == 1 :
                old_pactol = pactol
                eq_curx.append(resultats.iloc[i]['Date'])
                eq_cury.append(old_pactol)
                pos_long = 0
                price_sell = resultats.iloc[i]['Open.S']
                trades.append((resultats.iloc[i]['Open.S'],resultats.iloc[i]['Date'],2))
                mini_pnl = x*(price_sell-price_buy)
                pactol = pactol + mini_pnl
                print('\n Le ',str(resultats.iloc[i]['Date']),', vente pour close de ',x,' actions à',resultats.iloc[i]['Open.S'],'$')
                print('Nouveau pactol : ',pactol)
                print('pnl:', mini_pnl)
                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                pos_duration.append(resultats.iloc[i]['Date'] - time_enter)

                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1


            elif pos_short == 0 and pos_long == 0 and resultats.iloc[i]['Red']:
                pos_short = 1
                x = (10000/beta)/resultats.iloc[i]['Open.S']
                price_sell = resultats.iloc[i]['Open.S']
                time_enter = resultats.iloc[i]['Date']
                print('\n Le ',str(resultats.iloc[i]['Date']),', vente de ',x,' actions à',resultats.iloc[i]['Open.S'],'$')
                print('Nouveau pactol : ',pactol)
                trades.append((resultats.iloc[i]['Open.S'],resultats.iloc[i]['Date'],-1))


            elif pos_short == 1 and resultats.iloc[i]['Red_Close'] == 0 :
                try:
                    maxdd.append((resultats.iloc[i]['Open.S'] - price_sell)*x)
                except:
                    print('Null val of maxdd')
                    maxdd.append(0)

            elif pos_short == 1 and resultats.iloc[i]['Red_Close'] == 1 :
                old_pactol = pactol
                eq_curx.append(resultats.iloc[i]['Date'])
                eq_cury.append(old_pactol)
                pos_short = 0
                price_buy=resultats.iloc[i]['Open.S']
                trades.append((resultats.iloc[i]['Open.S'],resultats.iloc[i]['Date'],-2))
                mini_pnl = x*(price_sell-price_buy)
                pactol = pactol + mini_pnl
                print('\n Le ',str(resultats.iloc[i]['Date']),', achat pour close de ',x,' actions à',resultats.iloc[i]['Open.S'],'$')
                print('Nouveau pactol : ',pactol)

                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                print('pnl:', mini_pnl)
                pos_duration.append(resultats.iloc[i]['Date'] - time_enter)
                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1





        if pos_long == 1:
            pos_long = 0
            print('Cutting non resolved position')
            print(' Le price buy était de : ',price_buy)
            x = round((10000/beta)/resultats.iloc[i]['Open.S'])
            print('x = ',x)
            price_sell = resultats.iloc[i]['Open.S']
            print('Et le price sell : ',price_sell)
            mini_pnl = x*(price_sell-price_buy)
            pactol = pactol + mini_pnl
            print('pnl : ',mini_pnl)
            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1


        if pos_short == 1:
            pos_short = 0
            print('Cutting non resolved position')
            print(' Le price sell était de : ',price_sell)
            x = round((10000/beta)/resultats.iloc[i]['Open.S'])
            print('x = ',x)
            price_buy=resultats.iloc[i]['Open.S']
            print('Et le price_buy : ',price_buy)
            mini_pnl = x*(price_sell-price_buy)
            pactol = pactol + mini_pnl
            print('pnl : ',mini_pnl)

            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1


        pnl = round(pactol - (10000/beta),2)
        print('\n Begining of BackTest :',resultats.iloc[0]['Date'])
        print('Instrument :',ticker)
        print('Face value per trade : $',10000/beta)
        print('End of BackTest :',resultats.iloc[-1]['Date'])
        duration = resultats.iloc[-1]['Date'] - resultats.iloc[0]['Date']
        print("BackTest's period :",duration)
        print('Pnl :',pnl,'$')
        print('% Pnl : ',round(pnl/(10000/beta)*100,2))
        print('Total winners :',round(sum(winners),2),'$')
        print('Total loosers :',round(sum(loosers),2),'$')
        print('Number of winners :',nb_win)
        print('Number of loosers :',nb_los)
        print('Maximum Drawdown : ',round(min(maxdd),2))
        print('% Max Drawdown : ',round(min(maxdd)/(10000/beta)*100,2),'%')
        try:
            print('% winners :', round((nb_win/(nb_win+nb_los) * 100),2),'%')
            print('Average winners :',(round(sum(winners)/(nb_win))))
        except:
            print('% winners : null')
        try:
            print('Average losers :',(round(sum(loosers)/(nb_los))))
        except:
            print('Average losers : Inf')
        try:
            for t in range(0,len(pos_duration)):
                average_duration = average_duration + pos_duration[t]
            average_duration = average_duration/(nb_los+nb_win)
            print('Average Duration :', average_duration)
        except:
            print('No Average Duration available')
        try:
            print('Profit Factor : ',abs(round((sum(winners)/sum(loosers)),2)))
        except:
            print('Profit Factor : null')

        ########################
        ##### PLOT TRADES ######
        ########################

        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Trades')
        plt.plot(resultats['Open.S'],color='blue',lw=0.9)
        for i in range(0,len(trades)):
            if trades[i][2] == 1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='green',marker='^',lw=2.5)
            elif trades[i][2] == -1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='red',marker='^',lw=2.5)
            elif trades[i][2] == 2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='g',marker='x',lw=2.5)
            elif trades[i][2] == -2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='r',marker='x',lw=2.5)

        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='g',marker='^',label='Open Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='r',marker='^',label='Open Short')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='g',marker='x',label='Close Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='r',marker='x',label='Close Short')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_02.pdf')
        plt.close()

        #########################
        ##### PLOT E-CURVE ######
        #########################
        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Equity Curve')
        plt.plot(eq_curx,eq_cury)
        plt.scatter(x=eq_curx,y=eq_cury,c='orange',marker='o',lw=2.5)
        plt.savefig('backtest de '+str(ticker)+'_03.pdf')
        plt.close()


        f.close()
        sys.stdout = orig_stdout

        print('\r Boucle ', loop, 'terminée...',end='')
        print('Opération restantes :', len(constituents)-loop,'/',len(constituents),'\n')


        backtest = backtest.append([{'Symb.':ticker,'Name':name,'Sector':sector,'period':duration,'Begin.':resultats.iloc[0,0],'End':resultats.iloc[-1,0],\
                          'Pnl':pnl,'%Pnl':round(pnl/(10000/beta)*100,2),'Total Winners':round(sum(winners),2),'Total Loosers':round(sum(loosers),2),'Nb Win':nb_win,'Nb Los':nb_los,\
                          '% Winners':round((nb_win/(nb_win+nb_los) * 100),2),'MaxDD':round(min(maxdd),2),'%MaxDD':round(min(maxdd)/(10000/beta)*100,2),'Aver. Win':(round(sum(winners)/(nb_win))),\
                          'Aver. Los':(round(sum(loosers)/(nb_los))),'Aver. Duration':average_duration,\
                          'Profit Factor':abs(round((sum(winners)/sum(loosers)),2))}], ignore_index=True)

    # symbol / name / sector / period of backtest / debut / fin / pnl / total winners / total loosers / Nb winners / nb loosers / 
    # / % winners / Max DD / Aver Win / Aver Loos / Average duration / Profit Factor
        print(Fore.YELLOW,'Writing BACKTEST CSV',Style.RESET_ALL)
        backtest.to_csv('BackTest.csv')
        print(Fore.CYAN,'BACKTEST CSV WRITED',Style.RESET_ALL)
    except:
        print(Fore.RED,'Problème loop : ',loop,Style.RESET_ALL)
        error.append((loop,ticker))
         
        continue
# Out:
# Importing Librairies...
# Using TensorFlow backend.
# Librairies imported
#
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
# BOOST SKAN 55 Version v1.33
#
# Sraping tickers
# Scrap -----> ok
#  --- Loop : 0  ---  --- Symbol :   MMM   ---  --- Name :  3M Company  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.1014494803372252
#  Alpha :  -0.04593210449565378
#  R_Squared :  0.4793517858695432
#  Volatility :  0.19527002561287507
#  Momentum :  -0.16319471388411
# executed in = 5.810000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:34:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 2.910000 seconds
#  Deeping in blue
#
#  --- Loop : 0  ---  --- Symbol :   MMM   ---  --- Name :  3M Company  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 69us/step
# 883/883 [==============================] - 0s 74us/step
# 172/172 [==============================] - 0s 21us/step
# 172/172 [==============================] - 0s 22us/step
#
#
#  RESULTATS UP
#
# Accuracy: 69.77%
#  Precision: 62.07%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 73.97%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.78      0.67      0.72        99
#            1       0.62      0.74      0.68        73
#
#    micro avg       0.70      0.70      0.70       172
#    macro avg       0.70      0.70      0.70       172
# weighted avg       0.71      0.70      0.70       172
#
# [[66 33]
#  [19 54]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 73.84%
#  Precision: 65.29%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 96.34%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.94      0.53      0.68        90
#            1       0.65      0.96      0.78        82
#
#    micro avg       0.74      0.74      0.74       172
#    macro avg       0.80      0.75      0.73       172
# weighted avg       0.80      0.74      0.73       172
#
# [[48 42]
#  [ 3 79]]
#
#
# Deep Learning executed in = 54.010000 seconds
#  Boucle  0 terminée...Opération restantes : 505 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 1  ---  --- Symbol :   AOS   ---  --- Name :  A.O. Smith Corp  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.6398112539102285
#  Alpha :  -0.034944149566788096
#  R_Squared :  0.6016343321109314
#  Volatility :  0.25949305125857347
#  Momentum :  -0.25778396307239637
# executed in = 5.610000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:35:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.290000 seconds
#  Deeping in blue
#
#  --- Loop : 1  ---  --- Symbol :   AOS   ---  --- Name :  A.O. Smith Corp  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 101us/step
# 883/883 [==============================] - 0s 105us/step
# 172/172 [==============================] - 0s 21us/step
# 172/172 [==============================] - 0s 22us/step
#
#
#  RESULTATS UP
#
# Accuracy: 77.91%
#  Precision: 75.95%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 75.95%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        93
#            1       0.76      0.76      0.76        79
#
#    micro avg       0.78      0.78      0.78       172
#    macro avg       0.78      0.78      0.78       172
# weighted avg       0.78      0.78      0.78       172
#
# [[74 19]
#  [19 60]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 82.56%
#  Precision: 76.92%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 88.61%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.89      0.77      0.83        93
#            1       0.77      0.89      0.82        79
#
#    micro avg       0.83      0.83      0.83       172
#    macro avg       0.83      0.83      0.83       172
# weighted avg       0.83      0.83      0.83       172
#
# [[72 21]
#  [ 9 70]]
#
#
# Deep Learning executed in = 55.420000 seconds
#  Boucle  1 terminée...Opération restantes : 504 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 2  ---  --- Symbol :   ABT   ---  --- Name :  Abbott Laboratories  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.1633898901812567
#  Alpha :  0.08380926613439209
#  R_Squared :  0.47881035725455323
#  Volatility :  0.20636768536381359
#  Momentum :  0.3571885913439983
# executed in = 2.920000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:37:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.790000 seconds
#  Deeping in blue
#
#  --- Loop : 2  ---  --- Symbol :   ABT   ---  --- Name :  Abbott Laboratories  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 148us/step
# 883/883 [==============================] - 0s 149us/step
# 172/172 [==============================] - 0s 22us/step
# 172/172 [==============================] - 0s 24us/step
#
#
#  RESULTATS UP
#
# Accuracy: 72.09%
#  Precision: 65.18%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 89.02%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.85      0.57      0.68        90
#            1       0.65      0.89      0.75        82
#
#    micro avg       0.72      0.72      0.72       172
#    macro avg       0.75      0.73      0.72       172
# weighted avg       0.76      0.72      0.71       172
#
# [[51 39]
#  [ 9 73]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 80.23%
#  Precision: 76.36%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 66.67%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85       109
#            1       0.76      0.67      0.71        63
#
#    micro avg       0.80      0.80      0.80       172
#    macro avg       0.79      0.77      0.78       172
# weighted avg       0.80      0.80      0.80       172
#
# [[96 13]
#  [21 42]]
#
#
# Deep Learning executed in = 57.920000 seconds
#  Boucle  2 terminée...Opération restantes : 503 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 3  ---  --- Symbol :   ABBV   ---  --- Name :  AbbVie Inc.  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  0.9323374152802547
#  Alpha :  0.028442372495562578
#  R_Squared :  0.17630785813514793
#  Volatility :  0.2725432648188891
#  Momentum :  -0.21786768600604633
# executed in = 4.980000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:38:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.250000 seconds
#  Deeping in blue
#
#  --- Loop : 3  ---  --- Symbol :   ABBV   ---  --- Name :  AbbVie Inc.  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 183us/step
# 883/883 [==============================] - 0s 185us/step
# 172/172 [==============================] - 0s 23us/step
# 172/172 [==============================] - 0s 22us/step
#
#
#  RESULTATS UP
#
# Accuracy: 81.40%
#  Precision: 85.19%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 65.71%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.85       102
#            1       0.85      0.66      0.74        70
#
#    micro avg       0.81      0.81      0.81       172
#    macro avg       0.82      0.79      0.80       172
# weighted avg       0.82      0.81      0.81       172
#
# [[94  8]
#  [24 46]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 81.40%
#  Precision: 90.14%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 71.91%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.75      0.92      0.83        83
#            1       0.90      0.72      0.80        89
#
#    micro avg       0.81      0.81      0.81       172
#    macro avg       0.83      0.82      0.81       172
# weighted avg       0.83      0.81      0.81       172
#
# [[76  7]
#  [25 64]]
#
#
# Deep Learning executed in = 59.980000 seconds
#  Boucle  3 terminée...Opération restantes : 502 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 4  ---  --- Symbol :   ACN   ---  --- Name :  Accenture plc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.0557886805779781
#  Alpha :  0.11032034937221834
#  R_Squared :  0.5451282478836061
#  Volatility :  0.1755196861247589
#  Momentum :  0.23845746154436087
# executed in = 2.790000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:39:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.150000 seconds
#  Deeping in blue
#
#  --- Loop : 4  ---  --- Symbol :   ACN   ---  --- Name :  Accenture plc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 224us/step
# 883/883 [==============================] - 0s 217us/step
# 172/172 [==============================] - 0s 28us/step
# 172/172 [==============================] - 0s 25us/step
#
#
#  RESULTATS UP
#
# Accuracy: 75.00%
#  Precision: 71.74%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 79.52%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.79      0.71      0.75        89
#            1       0.72      0.80      0.75        83
#
#    micro avg       0.75      0.75      0.75       172
#    macro avg       0.75      0.75      0.75       172
# weighted avg       0.75      0.75      0.75       172
#
# [[63 26]
#  [17 66]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 69.77%
#  Precision: 56.67%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 79.69%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.84      0.64      0.73       108
#            1       0.57      0.80      0.66        64
#
#    micro avg       0.70      0.70      0.70       172
#    macro avg       0.70      0.72      0.69       172
# weighted avg       0.74      0.70      0.70       172
#
# [[69 39]
#  [13 51]]
#
#
# Deep Learning executed in = 60.780000 seconds
#  Boucle  4 terminée...Opération restantes : 501 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 5  ---  --- Symbol :   ATVI   ---  --- Name :  Activision Blizzard  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  0.8351261635908952
#  Alpha :  0.13857192241832322
#  R_Squared :  0.10880987455066837
#  Volatility :  0.3107535586858852
#  Momentum :  -0.38024230151452587
# executed in = 2.980000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:40:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.190000 seconds
#  Deeping in blue
#
#  --- Loop : 5  ---  --- Symbol :   ATVI   ---  --- Name :  Activision Blizzard  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 258us/step
# 883/883 [==============================] - 0s 264us/step
# 172/172 [==============================] - 0s 26us/step
# 172/172 [==============================] - 0s 25us/step
#
#
#  RESULTATS UP
#
# Accuracy: 81.98%
#  Precision: 78.35%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 88.37%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.87      0.76      0.81        86
#            1       0.78      0.88      0.83        86
#
#    micro avg       0.82      0.82      0.82       172
#    macro avg       0.83      0.82      0.82       172
# weighted avg       0.83      0.82      0.82       172
#
# [[65 21]
#  [10 76]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 81.98%
#  Precision: 89.83%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 67.95%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85        94
#            1       0.90      0.68      0.77        78
#
#    micro avg       0.82      0.82      0.82       172
#    macro avg       0.84      0.81      0.81       172
# weighted avg       0.83      0.82      0.82       172
#
# [[88  6]
#  [25 53]]
#
#
# Deep Learning executed in = 63.120000 seconds
#  Boucle  5 terminée...Opération restantes : 500 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 6  ---  --- Symbol :   AYI   ---  --- Name :  Acuity Brands Inc  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.6556760451338133
#  Alpha :  -0.14335710903418825
#  R_Squared :  0.3177582645290259
#  Volatility :  0.3605164729715376
#  Momentum :  -0.05252576475532644
# executed in = 2.060000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:41:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.410000 seconds
#  Deeping in blue
#
#  --- Loop : 6  ---  --- Symbol :   AYI   ---  --- Name :  Acuity Brands Inc  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 310us/step
# 883/883 [==============================] - 0s 301us/step
# 172/172 [==============================] - 0s 27us/step
# 172/172 [==============================] - 0s 27us/step
#
#
#  RESULTATS UP
#
# Accuracy: 79.65%
#  Precision: 85.33%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 72.73%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.75      0.87      0.81        84
#            1       0.85      0.73      0.79        88
#
#    micro avg       0.80      0.80      0.80       172
#    macro avg       0.80      0.80      0.80       172
# weighted avg       0.80      0.80      0.80       172
#
# [[73 11]
#  [24 64]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 80.23%
#  Precision: 72.37%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.88%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83       104
#            1       0.72      0.81      0.76        68
#
#    micro avg       0.80      0.80      0.80       172
#    macro avg       0.79      0.80      0.80       172
# weighted avg       0.81      0.80      0.80       172
#
# [[83 21]
#  [13 55]]
#
#
# Deep Learning executed in = 64.570000 seconds
#  Boucle  6 terminée...Opération restantes : 499 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 7  ---  --- Symbol :   ADBE   ---  --- Name :  Adobe Systems Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.0039602302896156
#  Alpha :  0.2589815261527594
#  R_Squared :  0.3995371311634295
#  Volatility :  0.19495577830588282
#  Momentum :  0.2541687277382443
# executed in = 7.640000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:42:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.550000 seconds
#  Deeping in blue
#
#  --- Loop : 7  ---  --- Symbol :   ADBE   ---  --- Name :  Adobe Systems Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 346us/step
# 883/883 [==============================] - 0s 335us/step
# 172/172 [==============================] - 0s 38us/step
# 172/172 [==============================] - 0s 29us/step
#
#
#  RESULTATS UP
#
# Accuracy: 60.47%
#  Precision: 57.27%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 75.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.66      0.47      0.55        88
#            1       0.57      0.75      0.65        84
#
#    micro avg       0.60      0.60      0.60       172
#    macro avg       0.62      0.61      0.60       172
# weighted avg       0.62      0.60      0.60       172
#
# [[41 47]
#  [21 63]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 69.77%
#  Precision: 69.39%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 47.89%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.70      0.85      0.77       101
#            1       0.69      0.48      0.57        71
#
#    micro avg       0.70      0.70      0.70       172
#    macro avg       0.70      0.67      0.67       172
# weighted avg       0.70      0.70      0.68       172
#
# [[86 15]
#  [37 34]]
#
#
# Deep Learning executed in = 67.710000 seconds
#  Boucle  7 terminée...Opération restantes : 498 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 8  ---  --- Symbol :   AAP   ---  --- Name :  Advance Auto Parts  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  0.8716300144701278
#  Alpha :  -0.024186383846852656
#  R_Squared :  0.12741229906229246
#  Volatility :  0.2997261783540708
#  Momentum :  0.11282753385124678
# executed in = 3.520000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:44:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.390000 seconds
#  Deeping in blue
#
#  --- Loop : 8  ---  --- Symbol :   AAP   ---  --- Name :  Advance Auto Parts  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 382us/step
# 883/883 [==============================] - 0s 381us/step
# 172/172 [==============================] - 0s 27us/step
# 172/172 [==============================] - 0s 29us/step
#
#
#  RESULTATS UP
#
# Accuracy: 81.40%
#  Precision: 69.62%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 87.30%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.91      0.78      0.84       109
#            1       0.70      0.87      0.77        63
#
#    micro avg       0.81      0.81      0.81       172
#    macro avg       0.81      0.83      0.81       172
# weighted avg       0.83      0.81      0.82       172
#
# [[85 24]
#  [ 8 55]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 69.77%
#  Precision: 92.86%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 44.32%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.62      0.96      0.76        84
#            1       0.93      0.44      0.60        88
#
#    micro avg       0.70      0.70      0.70       172
#    macro avg       0.78      0.70      0.68       172
# weighted avg       0.78      0.70      0.68       172
#
# [[81  3]
#  [49 39]]
#
#
# Deep Learning executed in = 67.950000 seconds
#  Boucle  8 terminée...Opération restantes : 497 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 9  ---  --- Symbol :   AMD   ---  --- Name :  Advanced Micro Devices Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  3.072886815569906
#  Alpha :  0.49161517673030447
#  R_Squared :  0.37330676319844447
#  Volatility :  0.6173220798721164
#  Momentum :  0.7735951149398672
# executed in = 4.040000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:45:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.100000 seconds
#  Deeping in blue
#
#  --- Loop : 9  ---  --- Symbol :   AMD   ---  --- Name :  Advanced Micro Devices Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 424us/step
# 883/883 [==============================] - 0s 426us/step
# 172/172 [==============================] - 0s 29us/step
# 172/172 [==============================] - 0s 31us/step
#
#
#  RESULTATS UP
#
# Accuracy: 80.23%
#  Precision: 80.43%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 82.22%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79        82
#            1       0.80      0.82      0.81        90
#
#    micro avg       0.80      0.80      0.80       172
#    macro avg       0.80      0.80      0.80       172
# weighted avg       0.80      0.80      0.80       172
#
# [[64 18]
#  [16 74]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 70.35%
#  Precision: 58.87%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.48      0.65        99
#            1       0.59      1.00      0.74        73
#
#    micro avg       0.70      0.70      0.70       172
#    macro avg       0.79      0.74      0.70       172
# weighted avg       0.83      0.70      0.69       172
#
# [[48 51]
#  [ 0 73]]
#
#
# Deep Learning executed in = 70.840000 seconds
#  Boucle  9 terminée...Opération restantes : 496 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 10  ---  --- Symbol :   AES   ---  --- Name :  AES Corp  ---  --- Sector :  Utilities  ---
# Scraping data...
# Beta :  0.9870879174145076
#  Alpha :  0.042436585762016726
#  R_Squared :  0.29178090194833517
#  Volatility :  0.22429809259058606
#  Momentum :  0.3346752170545326
# executed in = 2.020000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:46:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.110000 seconds
#  Deeping in blue
#
#  --- Loop : 10  ---  --- Symbol :   AES   ---  --- Name :  AES Corp  ---  --- Sector :  Utilities  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 475us/step
# 883/883 [==============================] - 0s 467us/step
# 172/172 [==============================] - 0s 30us/step
# 172/172 [==============================] - 0s 31us/step
#
#
#  RESULTATS UP
#
# Accuracy: 90.12%
#  Precision: 77.46%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 98.21%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.99      0.86      0.92       116
#            1       0.77      0.98      0.87        56
#
#    micro avg       0.90      0.90      0.90       172
#    macro avg       0.88      0.92      0.89       172
# weighted avg       0.92      0.90      0.90       172
#
# [[100  16]
#  [  1  55]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 86.63%
#  Precision: 89.52%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 88.68%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.83        66
#            1       0.90      0.89      0.89       106
#
#    micro avg       0.87      0.87      0.87       172
#    macro avg       0.86      0.86      0.86       172
# weighted avg       0.87      0.87      0.87       172
#
# [[55 11]
#  [12 94]]
#
#
# Deep Learning executed in = 73.370000 seconds
#  Boucle  10 terminée...Opération restantes : 495 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 11  ---  --- Symbol :   AET   ---  --- Name :  Aetna Inc  ---  --- Sector :  Health Care  ---
# Scraping data...
#  Problème loop :  11
#  --- Loop : 12  ---  --- Symbol :   AMG   ---  --- Name :  Affiliated Managers Group Inc  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  1.6920479221863007
#  Alpha :  -0.31006637785244817
#  R_Squared :  0.5013272149605613
#  Volatility :  0.2933257528755524
#  Momentum :  -0.44158202291479964
# executed in = 17.570000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:48:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.690000 seconds
#  Deeping in blue
#
#  --- Loop : 12  ---  --- Symbol :   AMG   ---  --- Name :  Affiliated Managers Group Inc  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 502us/step
# 883/883 [==============================] - 0s 498us/step
# 172/172 [==============================] - 0s 30us/step
# 172/172 [==============================] - 0s 32us/step
#
#
#  RESULTATS UP
#
# Accuracy: 65.12%
#  Precision: 76.92%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 27.03%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.63      0.94      0.75        98
#            1       0.77      0.27      0.40        74
#
#    micro avg       0.65      0.65      0.65       172
#    macro avg       0.70      0.60      0.58       172
# weighted avg       0.69      0.65      0.60       172
#
# [[92  6]
#  [54 20]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 73.84%
#  Precision: 85.71%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 56.47%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.68      0.91      0.78        87
#            1       0.86      0.56      0.68        85
#
#    micro avg       0.74      0.74      0.74       172
#    macro avg       0.77      0.74      0.73       172
# weighted avg       0.77      0.74      0.73       172
#
# [[79  8]
#  [37 48]]
#
#
# Deep Learning executed in = 78.440000 seconds
#  Boucle  12 terminée...Opération restantes : 493 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 13  ---  --- Symbol :   AFL   ---  --- Name :  AFLAC Inc  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  0.6387322658120491
#  Alpha :  0.11652008046456068
#  R_Squared :  0.32158124520961273
#  Volatility :  0.1382520802376018
#  Momentum :  0.20807158513227453
# executed in = 16.720000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:50:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.530000 seconds
#  Deeping in blue
#
#  --- Loop : 13  ---  --- Symbol :   AFL   ---  --- Name :  AFLAC Inc  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 0s 560us/step
# 883/883 [==============================] - 1s 568us/step
# 172/172 [==============================] - 0s 35us/step
# 172/172 [==============================] - 0s 33us/step
#
#
#  RESULTATS UP
#
# Accuracy: 71.51%
#  Precision: 81.25%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 49.37%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.68      0.90      0.77        93
#            1       0.81      0.49      0.61        79
#
#    micro avg       0.72      0.72      0.72       172
#    macro avg       0.74      0.70      0.69       172
# weighted avg       0.74      0.72      0.70       172
#
# [[84  9]
#  [40 39]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 54.07%
#  Precision: 46.34%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 81.43%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.73      0.35      0.48       102
#            1       0.46      0.81      0.59        70
#
#    micro avg       0.54      0.54      0.54       172
#    macro avg       0.60      0.58      0.53       172
# weighted avg       0.62      0.54      0.52       172
#
# [[36 66]
#  [13 57]]
#
#
# Deep Learning executed in = 79.130000 seconds
#  Boucle  13 terminée...Opération restantes : 492 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 14  ---  --- Symbol :   A   ---  --- Name :  Agilent Technologies Inc  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.386426130180023
#  Alpha :  0.024716132565618186
#  R_Squared :  0.5520818501382107
#  Volatility :  0.22903042332579973
#  Momentum :  0.04950012459297537
# executed in = 30.080000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:52:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.220000 seconds
#  Deeping in blue
#
#  --- Loop : 14  ---  --- Symbol :   A   ---  --- Name :  Agilent Technologies Inc  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 602us/step
# 883/883 [==============================] - 1s 588us/step
# 172/172 [==============================] - 0s 37us/step
# 172/172 [==============================] - 0s 35us/step
#
#
#  RESULTATS UP
#
# Accuracy: 79.07%
#  Precision: 78.41%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.23%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.78      0.79        86
#            1       0.78      0.80      0.79        86
#
#    micro avg       0.79      0.79      0.79       172
#    macro avg       0.79      0.79      0.79       172
# weighted avg       0.79      0.79      0.79       172
#
# [[67 19]
#  [17 69]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 80.81%
#  Precision: 80.70%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 67.65%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       104
#            1       0.81      0.68      0.74        68
#
#    micro avg       0.81      0.81      0.81       172
#    macro avg       0.81      0.79      0.79       172
# weighted avg       0.81      0.81      0.80       172
#
# [[93 11]
#  [22 46]]
#
#
# Deep Learning executed in = 81.510000 seconds
#  Boucle  14 terminée...Opération restantes : 491 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 15  ---  --- Symbol :   APD   ---  --- Name :  Air Products & Chemicals Inc  ---  --- Sector :  Materials  ---
# Scraping data...
# Beta :  0.8374793901125693
#  Alpha :  0.07298557696476543
#  R_Squared :  0.43203001763446225
#  Volatility :  0.1563922912543523
#  Momentum :  0.4019251082564945
# executed in = 8.810000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:53:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.720000 seconds
#  Deeping in blue
#
#  --- Loop : 15  ---  --- Symbol :   APD   ---  --- Name :  Air Products & Chemicals Inc  ---  --- Sector :  Materials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 633us/step
# 883/883 [==============================] - 1s 616us/step
# 172/172 [==============================] - 0s 37us/step
# 172/172 [==============================] - 0s 46us/step
#
#
#  RESULTATS UP
#
# Accuracy: 69.19%
#  Precision: 93.55%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 36.25%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.64      0.98      0.77        92
#            1       0.94      0.36      0.52        80
#
#    micro avg       0.69      0.69      0.69       172
#    macro avg       0.79      0.67      0.65       172
# weighted avg       0.78      0.69      0.66       172
#
# [[90  2]
#  [51 29]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 68.60%
#  Precision: 81.82%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 36.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.65      0.94      0.77        97
#            1       0.82      0.36      0.50        75
#
#    micro avg       0.69      0.69      0.69       172
#    macro avg       0.74      0.65      0.64       172
# weighted avg       0.73      0.69      0.65       172
#
# [[91  6]
#  [48 27]]
#
#
# Deep Learning executed in = 84.090000 seconds
#  Boucle  15 terminée...Opération restantes : 490 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 16  ---  --- Symbol :   AKAM   ---  --- Name :  Akamai Technologies Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  0.4607224984222641
#  Alpha :  0.03918209115012812
#  R_Squared :  0.034701344030508285
#  Volatility :  0.3035739128351499
#  Momentum :  0.10882267578449967
# executed in = 4.310000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:55:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.370000 seconds
#  Deeping in blue
#
#  --- Loop : 16  ---  --- Symbol :   AKAM   ---  --- Name :  Akamai Technologies Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 680us/step
# 883/883 [==============================] - 1s 712us/step
# 172/172 [==============================] - 0s 32us/step
# 172/172 [==============================] - 0s 41us/step
#
#
#  RESULTATS UP
#
# Accuracy: 79.65%
#  Precision: 98.33%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 63.44%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.70      0.99      0.82        79
#            1       0.98      0.63      0.77        93
#
#    micro avg       0.80      0.80      0.80       172
#    macro avg       0.84      0.81      0.79       172
# weighted avg       0.85      0.80      0.79       172
#
# [[78  1]
#  [34 59]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 72.09%
#  Precision: 56.36%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.56      0.72       110
#            1       0.56      1.00      0.72        62
#
#    micro avg       0.72      0.72      0.72       172
#    macro avg       0.78      0.78      0.72       172
# weighted avg       0.84      0.72      0.72       172
#
# [[62 48]
#  [ 0 62]]
#
#
# Deep Learning executed in = 85.630000 seconds
#  Boucle  16 terminée...Opération restantes : 489 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 17  ---  --- Symbol :   ALK   ---  --- Name :  Alaska Air Group Inc  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  0.9555495757936446
#  Alpha :  -0.037913210280363034
#  R_Squared :  0.15871002017956326
#  Volatility :  0.29440774194467706
#  Momentum :  0.031485312006599875
# executed in = 6.040000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:56:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.940000 seconds
#  Deeping in blue
#
#  --- Loop : 17  ---  --- Symbol :   ALK   ---  --- Name :  Alaska Air Group Inc  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 710us/step
# 883/883 [==============================] - 1s 744us/step
# 172/172 [==============================] - 0s 34us/step
# 172/172 [==============================] - 0s 38us/step
#
#
#  RESULTATS UP
#
# Accuracy: 78.49%
#  Precision: 84.13%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 66.25%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.75      0.89      0.82        92
#            1       0.84      0.66      0.74        80
#
#    micro avg       0.78      0.78      0.78       172
#    macro avg       0.80      0.78      0.78       172
# weighted avg       0.79      0.78      0.78       172
#
# [[82 10]
#  [27 53]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 83.14%
#  Precision: 76.34%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 91.03%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.91      0.77      0.83        94
#            1       0.76      0.91      0.83        78
#
#    micro avg       0.83      0.83      0.83       172
#    macro avg       0.84      0.84      0.83       172
# weighted avg       0.84      0.83      0.83       172
#
# [[72 22]
#  [ 7 71]]
#
#
# Deep Learning executed in = 87.250000 seconds
#  Boucle  17 terminée...Opération restantes : 488 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 18  ---  --- Symbol :   ALB   ---  --- Name :  Albemarle Corp  ---  --- Sector :  Materials  ---
# Scraping data...
# Beta :  1.4449374230057295
#  Alpha :  0.008486840919475491
#  R_Squared :  0.3365716329507705
#  Volatility :  0.30570916580888907
#  Momentum :  -0.19627085523272403
# executed in = 3.690000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:58:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.090000 seconds
#  Deeping in blue
#
#  --- Loop : 18  ---  --- Symbol :   ALB   ---  --- Name :  Albemarle Corp  ---  --- Sector :  Materials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 746us/step
# 883/883 [==============================] - 1s 772us/step
# 172/172 [==============================] - 0s 36us/step
# 172/172 [==============================] - 0s 39us/step
#
#
#  RESULTATS UP
#
# Accuracy: 84.88%
#  Precision: 89.86%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 76.54%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.87        91
#            1       0.90      0.77      0.83        81
#
#    micro avg       0.85      0.85      0.85       172
#    macro avg       0.86      0.84      0.85       172
# weighted avg       0.85      0.85      0.85       172
#
# [[84  7]
#  [19 62]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 79.07%
#  Precision: 87.72%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 63.29%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.75      0.92      0.83        93
#            1       0.88      0.63      0.74        79
#
#    micro avg       0.79      0.79      0.79       172
#    macro avg       0.81      0.78      0.78       172
# weighted avg       0.81      0.79      0.78       172
#
# [[86  7]
#  [29 50]]
#
#
# Deep Learning executed in = 87.380000 seconds
#  Boucle  18 terminée...Opération restantes : 487 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 19  ---  --- Symbol :   ARE   ---  --- Name :  Alexandria Real Estate Equities Inc  ---  --- Sector :  Real Estate  ---
# Scraping data...
# Beta :  0.8435547869666479
#  Alpha :  0.052545823482821497
#  R_Squared :  0.36315315992421904
#  Volatility :  0.1718171679322183
#  Momentum :  0.14498155163690596
# executed in = 2.220000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [12:59:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.950000 seconds
#  Deeping in blue
#
#  --- Loop : 19  ---  --- Symbol :   ARE   ---  --- Name :  Alexandria Real Estate Equities Inc  ---  --- Sector :  Real Estate  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 1s 775us/step
# 883/883 [==============================] - 1s 812us/step
# 172/172 [==============================] - 0s 37us/step
# 172/172 [==============================] - 0s 41us/step
#
#
#  RESULTATS UP
#
# Accuracy: 72.09%
#  Precision: 75.95%    => Discrimnination des vrais positifs parmi les faux positifs
# ...
# 883/883 [==============================] - 5s 6ms/step
# 172/172 [==============================] - 0s 223us/step
# 172/172 [==============================] - 0s 228us/step
#
#
#  RESULTATS UP
#
# Accuracy: 65.70%
#  Precision: 54.92%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 94.37%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.92      0.46      0.61       101
#            1       0.55      0.94      0.69        71
#
#    micro avg       0.66      0.66      0.66       172
#    macro avg       0.73      0.70      0.65       172
# weighted avg       0.77      0.66      0.64       172
#
# [[46 55]
#  [ 4 67]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 64.53%
#  Precision: 82.93%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 38.64%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.59      0.92      0.72        84
#            1       0.83      0.39      0.53        88
#
#    micro avg       0.65      0.65      0.65       172
#    macro avg       0.71      0.65      0.62       172
# weighted avg       0.71      0.65      0.62       172
#
# [[77  7]
#  [54 34]]
#
#
# Deep Learning executed in = 480.660000 seconds
#  Boucle  131 terminée...Opération restantes : 374 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 132  ---  --- Symbol :   CCI   ---  --- Name :  Crown Castle International Corp.  ---  --- Sector :  Real Estate  ---
# Scraping data...
# Beta :  0.35736274414916125
#  Alpha :  0.1142449688757892
#  R_Squared :  0.08274042773046775
#  Volatility :  0.15249252979245817
#  Momentum :  0.17438194679930152
# executed in = 2.310000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [21:09:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 6.470000 seconds
#  Deeping in blue
#
#  --- Loop : 132  ---  --- Symbol :   CCI   ---  --- Name :  Crown Castle International Corp.  ---  --- Sector :  Real Estate  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 5s 6ms/step
# 883/883 [==============================] - 5s 6ms/step
# 172/172 [==============================] - 0s 238us/step
# 172/172 [==============================] - 0s 250us/step
#
#
#  RESULTATS UP
#
# Accuracy: 80.23%
#  Precision: 86.44%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 66.23%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84        95
#            1       0.86      0.66      0.75        77
#
#    micro avg       0.80      0.80      0.80       172
#    macro avg       0.82      0.79      0.79       172
# weighted avg       0.81      0.80      0.80       172
#
# [[87  8]
#  [26 51]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 67.44%
#  Precision: 57.38%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 94.59%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.92      0.47      0.62        98
#            1       0.57      0.95      0.71        74
#
#    micro avg       0.67      0.67      0.67       172
#    macro avg       0.75      0.71      0.67       172
# weighted avg       0.77      0.67      0.66       172
#
# [[46 52]
#  [ 4 70]]
#
#
# Deep Learning executed in = 471.470000 seconds
#  Boucle  132 terminée...Opération restantes : 373 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 133  ---  --- Symbol :   CSRA   ---  --- Name :  CSRA Inc.  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  nan
#  Alpha :  nan
#  R_Squared :  nan
#  Volatility :  nan
#  Momentum :  0.0
# executed in = 2.140000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  17
# On 80% - 20% slash :
# Bloc 1 :  14
# Bloc 2 : 3  periods
# First period : 2018-01-04 00:00:00
# Split period : 2018-03-28 00:00:00
# Last period : 2018-04-03 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [21:17:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#  Problème loop :  133
#  --- Loop : 134  ---  --- Symbol :   CSX   ---  --- Name :  CSX Corp.  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.204767889629987
#  Alpha :  0.1190214356509451
#  R_Squared :  0.28807011676845073
#  Volatility :  0.27551957208418226
#  Momentum :  0.007305850626615262
# executed in = 1.930000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [21:17:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 6.670000 seconds
#  Deeping in blue
#
#  --- Loop : 134  ---  --- Symbol :   CSX   ---  --- Name :  CSX Corp.  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 5s 6ms/step
# 883/883 [==============================] - 5s 6ms/step
# 172/172 [==============================] - 0s 234us/step
# 172/172 [==============================] - 0s 239us/step
#
#
#  RESULTATS UP
#
# Accuracy: 77.33%
#  Precision: 70.54%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 92.94%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.62      0.73        87
#            1       0.71      0.93      0.80        85
#
#    micro avg       0.77      0.77      0.77       172
#    macro avg       0.80      0.78      0.77       172
# weighted avg       0.80      0.77      0.77       172
#
# [[54 33]
#  [ 6 79]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 75.00%
#  Precision: 82.05%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 47.06%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.73      0.93      0.82       104
#            1       0.82      0.47      0.60        68
#
#    micro avg       0.75      0.75      0.75       172
#    macro avg       0.77      0.70      0.71       172
# weighted avg       0.77      0.75      0.73       172
#
# [[97  7]
#  [36 32]]
#
#
# Deep Learning executed in = 467.210000 seconds
#  Boucle  134 terminée...Opération restantes : 371 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 135  ---  --- Symbol :   CMI   ---  --- Name :  Cummins Inc.  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.13276214659682
#  Alpha :  0.001925099396521364
#  R_Squared :  0.3748466189631888
#  Volatility :  0.22709632409720282
#  Momentum :  0.2470397369159132
# executed in = 4.080000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [21:25:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 6.750000 seconds
#  Deeping in blue
#
#  --- Loop : 135  ---  --- Symbol :   CMI   ---  --- Name :  Cummins Inc.  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 5s 6ms/step
# 883/883 [==============================] - 5s 6ms/step
# 172/172 [==============================] - 0s 237us/step
# 172/172 [==============================] - 0s 258us/step
#
#
#  RESULTATS UP
#
# Accuracy: 83.72%
#  Precision: 86.59%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.68%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.81      0.87      0.84        84
#            1       0.87      0.81      0.84        88
#
#    micro avg       0.84      0.84      0.84       172
#    macro avg       0.84      0.84      0.84       172
# weighted avg       0.84      0.84      0.84       172
#
# [[73 11]
#  [17 71]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 76.74%
#  Precision: 86.67%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 41.94%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.75      0.96      0.84       110
#            1       0.87      0.42      0.57        62
#
#    micro avg       0.77      0.77      0.77       172
#    macro avg       0.81      0.69      0.70       172
# weighted avg       0.79      0.77      0.74       172
#
# [[106   4]
#  [ 36  26]]
#
#
# Deep Learning executed in = 486.590000 seconds
#  Boucle  135 terminée...Opération restantes : 370 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 136  ---  --- Symbol :   CVS   ---  --- Name :  CVS Health  ---  --- Sector :  Consumer Staples  ---
# Scraping data...
# Beta :  0.9131956038792356
#  Alpha :  -0.17141124636945804
#  R_Squared :  0.20646247945313811
#  Volatility :  0.24668424801323935
#  Momentum :  -0.11655454844238544
# executed in = 10.350000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [21:33:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 6.740000 seconds
#  Deeping in blue
#
#  --- Loop : 136  ---  --- Symbol :   CVS   ---  --- Name :  CVS Health  ---  --- Sector :  Consumer Staples  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 5s 6ms/step
# 883/883 [==============================] - 5s 6ms/step
# 172/172 [==============================] - 0s 232us/step
# 172/172 [==============================] - 0s 258us/step
#
#
#  RESULTATS UP
#
# Accuracy: 77.33%
#  Precision: 71.23%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 74.29%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.82      0.79      0.81       102
#            1       0.71      0.74      0.73        70
#
#    micro avg       0.77      0.77      0.77       172
#    macro avg       0.77      0.77      0.77       172
# weighted avg       0.78      0.77      0.77       172
#
# [[81 21]
#  [18 52]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 75.00%
#  Precision: 80.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 68.18%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.71      0.82      0.76        84
#            1       0.80      0.68      0.74        88
#
#    micro avg       0.75      0.75      0.75       172
#    macro avg       0.76      0.75      0.75       172
# weighted avg       0.76      0.75      0.75       172
#
# [[69 15]
#  [28 60]]
#
#
# Deep Learning executed in = 493.400000 seconds
#  Boucle  136 terminée...Opération restantes : 369 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 137  ---  --- Symbol :   DHI   ---  --- Name :  D. R. Horton  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  0.9948379127551955
#  Alpha :  0.05318540902655462
#  R_Squared :  0.2764197448629616
#  Volatility :  0.23225548141302563
#  Momentum :  0.04469604531862181
# executed in = 7.430000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [21:42:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 6.640000 seconds
#  Deeping in blue
#
#  --- Loop : 137  ---  --- Symbol :   DHI   ---  --- Name :  D. R. Horton  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 883/883 [==============================] - 5s 6ms/step
# 883/883 [==============================] - 5s 6ms/step
# 172/172 [==============================] - 0s 265us/step
# 172/172 [==============================] - 0s 232us/step
#
#
#  RESULTATS UP
#
# Accuracy: 98.26%
#  Precision: 98.72%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 97.47%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98        93
#            1       0.99      0.97      0.98        79
#
#    micro avg       0.98      0.98      0.98       172
#    macro avg       0.98      0.98      0.98       172
# weighted avg       0.98      0.98      0.98       172
#
# [[92  1]
#  [ 2 77]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 90.70%
#  Precision: 91.67%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 89.53%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91        86
#            1       0.92      0.90      0.91        86
#
#    micro avg       0.91      0.91      0.91       172
#    macro avg       0.91      0.91      0.91       172
# weighted avg       0.91      0.91      0.91       172
#
# [[79  7]
#  [ 9 77]]
#
#
# Deep Learning executed in = 503.400000 seconds
#  Boucle  137 terminée...Opération restantes : 368 / 505
#
#  Writing BACKTEST CSV
#  BACKTEST CSV WRITED
#  --- Loop : 138  ---  --- Symbol :   DHR   ---  --- Name :  Danaher Corp.  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.1445243033551942
#  Alpha :  0.2118893595224998
#  R_Squared :  0.21142583270361748
#  Volatility :  0.3055231830091315
#  Momentum :  0.3882227536943712
# executed in = 3.500000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1104
# On 80% - 20% slash :
# Bloc 1 :  883
# Bloc 2 : 221  periods
# First period : 2015-03-03 00:00:00
# Split period : 2018-08-30 00:00:00
# Last period : 2019-07-19 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [21:50:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 7.000000 seconds
#  Deeping in blue
#
#  --- Loop : 138  ---  --- Symbol :   DHR   ---  --- Name :  Danaher Corp.  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down

# %%
#import sys
#orig_stdout = sys.stdout
#f = open('backtestv2_4.txt', 'w')
#sys.stdout = f

# %%
#f.close()
#sys.stdout = orig_stdout

# %%
print('Importing Librairies...')
import numpy as np
import pandas as pd
import pandas_datareader as web
import time
import datetime as dt

print('Librairies imported')
print('')



print('')
print('Sraping tickers')
constituents = pd.read_csv('constituents_csv.csv')
print('Scrap -----> ok')
# PARAMETRES TEMPORELS INITIAUX
start = pd.to_datetime('2015-03-03')
end = pd.to_datetime('2015-06-21')
gnagna = []
base_clean = []

for loop in range(0,len(constituents)):
    try:
        ticker = constituents.iloc[loop,0]
        print('Ticker : ',ticker)
        df = web.DataReader(ticker,'yahoo',start,end)
        df = df.drop(['Close'],axis=1)
        df['Close'] = df['Adj Close']
        df = df.drop(['Adj Close'],axis = 1)
        df.to_csv('Base_'+ticker+'.csv')
        base_clean.append(ticker)
    except:
        gnagna.append(ticker)
        print('Probleme au ticker : ', ticker)
base_clean.to_csv('BaseClean.csv')
gnagna.to_csv('BasePb.csv')
# Out:
# Importing Librairies...
# Librairies imported
#
#
# Sraping tickers
# Scrap -----> ok
# Ticker :  MMM
# Ticker :  AOS
# Ticker :  ABT
# Ticker :  ABBV
# Ticker :  ACN
# Ticker :  ATVI
# Ticker :  AYI
# Ticker :  ADBE
# Ticker :  AAP
# Ticker :  AMD
# Ticker :  AES
# Ticker :  AET
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-0573813224e3> in <module>
#      23     ticker = constituents.iloc[loop,0]
#      24     print('Ticker : ',ticker)
# ---> 25     df = web.DataReader(ticker,'yahoo',start,end)
#      26     df = df.drop(['Close'],axis=1)
#      27     df['Close'] = df['Adj Close']
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     308                                 adjust_price=False, chunksize=25,
#     309                                 retry_count=retry_count, pause=pause,
# --> 310                                 session=session).read()
#     311
#     312     elif data_source == "google":
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/pandas_datareader/base.py in read(self)
#     208         if isinstance(self.symbols, (compat.string_types, int)):
#     209             df = self._read_one_data(self.url,
# --> 210                                      params=self._get_params(self.symbols))
#     211         # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     212         elif isinstance(self.symbols, DataFrame):
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/pandas_datareader/yahoo/daily.py in _read_one_data(self, url, params)
#     140         prices.columns = [col.capitalize() for col in prices.columns]
#     141         prices['Date'] = to_datetime(
# --> 142             to_datetime(prices['Date'], unit='s').dt.date)
#     143
#     144         if 'Data' in prices.columns:
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/Applications/anaconda3/envs/LumberJack/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'

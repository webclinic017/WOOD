# %%
___Author___='LumberJack Jyss'

# %%
print('LumberJack Trading AtidotCom TREND FORECAST\nLumberJack Jyss (c)')
# Out:
# LumberJack Trading AtidotCom TREND FORECAST
# LumberJack Jyss (c)

# %%
print('Importation des librairies...')
import talib
import numpy as np
import pandas as pd
import pandas_datareader as web
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
print('Librairies importées')
# Out:
# Importation des librairies...
# Librairies importées

# %%
# PARAMETRES TEMPORELS INITIAUX
start = pd.to_datetime('1997-03-03')
end = pd.to_datetime('2019-04-29')

# %%
# SCRAPING DES DONNES BRUTES
spy = web.DataReader('SPY','yahoo',start,end)

# %%
spy.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 1997-03-03  79.750000  78.687500  78.750000  79.687500  1210400.0  53.450661
# 1997-03-04  80.125000  79.093697  79.906197  79.250000  1478700.0  53.157196
# 1997-03-05  80.593697  79.453102  79.718697  80.593697  1254800.0  54.058502
# 1997-03-06  80.906197  79.875000  80.625000  80.125000  1528500.0  53.744110
# 1997-03-07  81.156197  80.250000  80.437500  80.843697  1859300.0  54.226185

# %%
spy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5576 entries, 1997-03-03 to 2019-04-29
# Data columns (total 6 columns):
# High         5576 non-null float64
# Low          5576 non-null float64
# Open         5576 non-null float64
# Close        5576 non-null float64
# Volume       5576 non-null float64
# Adj Close    5576 non-null float64
# dtypes: float64(6)
# memory usage: 304.9 KB

# %%
# DEFINITION DU DATAFRAME DES SIMANIM
simanim = pd.DataFrame(index=spy.index)

# %%
CDL2CROWS = talib.CDL2CROWS(spy['Open'], spy['High'], spy['Low'], spy['Close']) 
#enc.fit(CDL2CROWS.as_matrix()).transform(df.as_matrix()).toarray()
simanim['CDL2CROWS'] = CDL2CROWS
for i in range(0,len(CDL2CROWS)):
    if simanim['CDL2CROWS'].iloc[i] == 100:
        simanim['CDL2CROWS'].iloc[i] = 1
    elif simanim['CDL2CROWS'].iloc[i] == -100:
        simanim['CDL2CROWS'].iloc[i] = -1
simanim['CDL2CROWS'].sum()
# Out:
# -1

# %%
CDL3BLACKCROWS = talib.CDL3BLACKCROWS(spy['Open'], spy['High'], spy['Low'], spy['Close']) 
#enc.fit(CDL3BLACKCROWS.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDL3BLACKCROWS'] = CDL3BLACKCROWS
simanim['CDL3BLACKCROWS'] = CDL3BLACKCROWS
for i in range(0,len(CDL3BLACKCROWS)):
    if simanim['CDL3BLACKCROWS'].iloc[i] == 100:
        simanim['CDL3BLACKCROWS'].iloc[i] = 1
    elif simanim['CDL3BLACKCROWS'].iloc[i] == -100:
        simanim['CDL3BLACKCROWS'].iloc[i] = -1
simanim['CDL3BLACKCROWS'].sum()
# Out:
# -1

# %%
CDL3INSIDE = talib.CDL3INSIDE(spy['Open'], spy['High'], spy['Low'], spy['Close']) 
#enc.fit(CDL3INSIDE.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDL3INSIDE'] = CDL3INSIDE
for i in range(0,len(CDL3INSIDE)):
    if simanim['CDL3INSIDE'].iloc[i] == 100:
        simanim['CDL3INSIDE'].iloc[i] = 1
    elif simanim['CDL3INSIDE'].iloc[i] == -100:
        simanim['CDL3INSIDE'].iloc[i] = -1
simanim['CDL3INSIDE'].sum()
# Out:
# 27

# %%
CDL3LINESTRIKE = talib.CDL3LINESTRIKE(spy['Open'], spy['High'], spy['Low'], spy['Close']) 
#enc.fit(CDL3LINESTRIKE.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDL3LINESTRIKE'] = CDL3LINESTRIKE
for i in range(0,len(CDL3LINESTRIKE)):
    if simanim['CDL3LINESTRIKE'].iloc[i] == 100:
        simanim['CDL3LINESTRIKE'].iloc[i] = 1
    elif simanim['CDL3LINESTRIKE'].iloc[i] == -100:
        simanim['CDL3LINESTRIKE'].iloc[i] = -1
simanim['CDL3LINESTRIKE'].sum()
# Out:
# -1

# %%
CDL3OUTSIDE = talib.CDL3OUTSIDE(spy['Open'], spy['High'], spy['Low'], spy['Close']) 
#enc.fit(CDL3OUTSIDE.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDL3OUTSIDE'] = CDL3OUTSIDE
for i in range(0,len(CDL3OUTSIDE)):
    if simanim['CDL3OUTSIDE'].iloc[i] == 100:
        simanim['CDL3OUTSIDE'].iloc[i] = 1
    elif simanim['CDL3OUTSIDE'].iloc[i] == -100:
        simanim['CDL3OUTSIDE'].iloc[i] = -1
simanim['CDL3OUTSIDE'].sum()
# Out:
# -5

# %%
CDL3STARSINSOUTH = talib.CDL3STARSINSOUTH(spy['Open'], spy['High'], spy['Low'], spy['Close']) 
#enc.fit(df.as_matrix()).transform(df.as_matrix()).toarray()
simanim['CDL3STARSINSOUTH'] = CDL3STARSINSOUTH
for i in range(0,len(CDL3STARSINSOUTH)):
    if simanim['CDL3STARSINSOUTH'].iloc[i] == 100:
        simanim['CDL3STARSINSOUTH'].iloc[i] = 1
    elif simanim['CDL3STARSINSOUTH'].iloc[i] == -100:
        simanim['CDL3STARSINSOUTH'].iloc[i] = -1
simanim['CDL3STARSINSOUTH'].sum()
# Out:
# 0

# %%
CDL3WHITESOLDIERS = talib.CDL3WHITESOLDIERS(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDL3STARSINSOUTH.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDL3WHITESOLDIERS'] = CDL3WHITESOLDIERS
for i in range(0,len(CDL3STARSINSOUTH)):
    if simanim['CDL3WHITESOLDIERS'].iloc[i] == 100:
        simanim['CDL3WHITESOLDIERS'].iloc[i] = 1
    elif simanim['CDL3WHITESOLDIERS'].iloc[i] == -100:
        simanim['CDL3WHITESOLDIERS'].iloc[i] = -1
simanim['CDL3WHITESOLDIERS'].sum()
# Out:
# 1

# %%
CDLABANDONEDBABY = talib.CDLABANDONEDBABY(spy['Open'], spy['High'],spy['Low'], spy['Close'], penetration=0) 
#enc.fit(CDLABANDONEDBABY.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLABANDONEDBABY'] = CDLABANDONEDBABY
for i in range(0,len(CDLABANDONEDBABY)):
    if simanim['CDLABANDONEDBABY'].iloc[i] == 100:
        simanim['CDLABANDONEDBABY'].iloc[i] = 1
    elif simanim['CDLABANDONEDBABY'].iloc[i] == -100:
        simanim['CDLABANDONEDBABY'].iloc[i] = -1
simanim['CDLABANDONEDBABY'].sum()
# Out:
# 0

# %%
CDLADVANCEBLOCK = talib.CDLADVANCEBLOCK(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLADVANCEBLOCK.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLADVANCEBLOCK'] = CDLADVANCEBLOCK
for i in range(0,len(CDLADVANCEBLOCK)):
    if simanim['CDLADVANCEBLOCK'].iloc[i] == 100:
        simanim['CDLADVANCEBLOCK'].iloc[i] = 1
    elif simanim['CDLADVANCEBLOCK'].iloc[i] == -100:
        simanim['CDLADVANCEBLOCK'].iloc[i] = -1
simanim['CDLADVANCEBLOCK'].sum()
# Out:
# -33

# %%
CDLBELTHOLD = talib.CDLBELTHOLD(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLBELTHOLD.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLBELTHOLD'] = CDLBELTHOLD
for i in range(0,len(CDLBELTHOLD)):
    if simanim['CDLBELTHOLD'].iloc[i] == 100:
        simanim['CDLBELTHOLD'].iloc[i] = 1
    elif simanim['CDLBELTHOLD'].iloc[i] == -100:
        simanim['CDLBELTHOLD'].iloc[i] = -1
simanim['CDLBELTHOLD'].sum()
# Out:
# -13

# %%
CDLBREAKAWAY = talib.CDLBREAKAWAY(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(df.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLBREAKAWAY'] = CDLBREAKAWAY
for i in range(0,len(CDLBREAKAWAY)):
    if simanim['CDLBREAKAWAY'].iloc[i] == 100:
        simanim['CDLBREAKAWAY'].iloc[i] = 1
    elif simanim['CDLBREAKAWAY'].iloc[i] == -100:
        simanim['CDLBREAKAWAY'].iloc[i] = -1
simanim['CDLBREAKAWAY'].sum()
# Out:
# 0

# %%
CDLCLOSINGMARUBOZU = talib.CDLCLOSINGMARUBOZU(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLBREAKAWAY.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLCLOSINGMARUBOZU'] = CDLCLOSINGMARUBOZU
for i in range(0,len(CDLBREAKAWAY)):
    if simanim['CDLCLOSINGMARUBOZU'].iloc[i] == 100:
        simanim['CDLCLOSINGMARUBOZU'].iloc[i] = 1
    elif simanim['CDLCLOSINGMARUBOZU'].iloc[i] == -100:
        simanim['CDLCLOSINGMARUBOZU'].iloc[i] = -1
simanim['CDLCLOSINGMARUBOZU'].sum()
# Out:
# 132

# %%
CDLCONCEALBABYSWALL = talib.CDLCONCEALBABYSWALL(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(df.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLCONCEALBABYSWALL'] = CDLCONCEALBABYSWALL
for i in range(0,len(CDLCONCEALBABYSWALL)):
    if simanim['CDLCONCEALBABYSWALL'].iloc[i] == 100:
        simanim['CDLCONCEALBABYSWALL'].iloc[i] = 1
    elif simanim['CDLCONCEALBABYSWALL'].iloc[i] == -100:
        simanim['CDLCONCEALBABYSWALL'].iloc[i] = -1
simanim['CDLCONCEALBABYSWALL'].sum()
# Out:
# 0

# %%
CDLCOUNTERATTACK = talib.CDLCOUNTERATTACK(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLCONCEALBABYSWALL.as_matrix()).transform(df.as_matrix()).toarray()
simanim['CDLCOUNTERATTACK'] = CDLCOUNTERATTACK
for i in range(0,len(CDLCOUNTERATTACK)):
    if simanim['CDLCOUNTERATTACK'].iloc[i] == 100:
        simanim['CDLCOUNTERATTACK'].iloc[i] = 1
    elif simanim['CDLCOUNTERATTACK'].iloc[i] == -100:
        simanim['CDLCOUNTERATTACK'].iloc[i] = -1
simanim['CDLCOUNTERATTACK'].sum()
# Out:
# 3

# %%
CDLDARKCLOUDCOVER = talib.CDLDARKCLOUDCOVER(spy['Open'], spy['High'],spy['Low'], spy['Close'], penetration=0) 
#enc.fit(CDLDARKCLOUDCOVER.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLDARKCLOUDCOVER'] = CDLDARKCLOUDCOVER
for i in range(0,len(CDLDARKCLOUDCOVER)):
    if simanim['CDLDARKCLOUDCOVER'].iloc[i] == 100:
        simanim['CDLDARKCLOUDCOVER'].iloc[i] = 1
    elif simanim['CDLDARKCLOUDCOVER'].iloc[i] == -100:
        simanim['CDLDARKCLOUDCOVER'].iloc[i] = -1
simanim['CDLDARKCLOUDCOVER'].sum()
# Out:
# -73

# %%
CDLDOJI = talib.CDLDOJI(spy['Open'], spy['High'],spy['Low'], spy['Close'])
#enc.fit(CDLDOJI.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLDOJI'] = CDLDOJI
for i in range(0,len(CDLDOJI)):
    if simanim['CDLDOJI'].iloc[i] == 100:
        simanim['CDLDOJI'].iloc[i] = 1
    elif simanim['CDLDOJI'].iloc[i] == -100:
        simanim['CDLDOJI'].iloc[i] = -1
simanim['CDLDOJI'].sum()
# Out:
# 767

# %%
CDLDOJISTAR = talib.CDLDOJISTAR(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(df.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLDOJISTAR'] = CDLDOJISTAR
for i in range(0,len(CDLDOJISTAR)):
    if simanim['CDLDOJISTAR'].iloc[i] == 100:
        simanim['CDLDOJISTAR'].iloc[i] = 1
    elif simanim['CDLDOJISTAR'].iloc[i] == -100:
        simanim['CDLDOJISTAR'].iloc[i] = -1
simanim['CDLDOJISTAR'].sum()
# Out:
# -53

# %%
CDLDRAGONFLYDOJI = talib.CDLDRAGONFLYDOJI(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLDOJISTAR.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLDRAGONFLYDOJI'] = CDLDRAGONFLYDOJI
for i in range(0,len(CDLDRAGONFLYDOJI)):
    if simanim['CDLDRAGONFLYDOJI'].iloc[i] == 100:
        simanim['CDLDRAGONFLYDOJI'].iloc[i] = 1
    elif simanim['CDLDRAGONFLYDOJI'].iloc[i] == -100:
        simanim['CDLDRAGONFLYDOJI'].iloc[i] = -1
simanim['CDLDRAGONFLYDOJI'].sum()
# Out:
# 80

# %%
CDLENGULFING = talib.CDLENGULFING(spy['Open'], spy['High'],spy['Low'], spy['Close'])
#enc.fit(df.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLENGULFING'] = CDLENGULFING
for i in range(0,len(CDLENGULFING)):
    if simanim['CDLENGULFING'].iloc[i] == 100:
        simanim['CDLENGULFING'].iloc[i] = 1
    elif simanim['CDLENGULFING'].iloc[i] == -100:
        simanim['CDLENGULFING'].iloc[i] = -1
simanim['CDLENGULFING'].sum()
# Out:
# -53

# %%
CDLEVENINGDOJISTAR = talib.CDLEVENINGDOJISTAR(spy['Open'], spy['High'],spy['Low'], spy['Close'], penetration=0) 
#enc.fit(CDLENGULFING.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLEVENINGDOJISTAR'] = CDLEVENINGDOJISTAR
for i in range(0,len(CDLEVENINGDOJISTAR)):
    if simanim['CDLEVENINGDOJISTAR'].iloc[i] == 100:
        simanim['CDLEVENINGDOJISTAR'].iloc[i] = 1
    elif simanim['CDLEVENINGDOJISTAR'].iloc[i] == -100:
        simanim['CDLEVENINGDOJISTAR'].iloc[i] = -1
simanim['CDLEVENINGDOJISTAR'].sum()
# Out:
# -13

# %%
CDLEVENINGSTAR = talib.CDLEVENINGSTAR(spy['Open'], spy['High'],spy['Low'], spy['Close'], penetration=0)
#enc.fit(CDLEVENINGSTAR.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLEVENINGSTAR'] = CDLEVENINGSTAR
for i in range(0,len(CDLEVENINGSTAR)):
    if simanim['CDLEVENINGSTAR'].iloc[i] == 100:
        simanim['CDLEVENINGSTAR'].iloc[i] = 1
    elif simanim['CDLEVENINGSTAR'].iloc[i] == -100:
        simanim['CDLEVENINGSTAR'].iloc[i] = -1
simanim['CDLEVENINGSTAR'].sum()
# Out:
# -38

# %%
CDLGAPSIDESIDEWHITE = talib.CDLGAPSIDESIDEWHITE(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLGAPSIDESIDEWHITE.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLGAPSIDESIDEWHITE'] = CDLGAPSIDESIDEWHITE
for i in range(0,len(CDLGAPSIDESIDEWHITE)):
    if simanim['CDLGAPSIDESIDEWHITE'].iloc[i] == 100:
        simanim['CDLGAPSIDESIDEWHITE'].iloc[i] = 1
    elif simanim['CDLGAPSIDESIDEWHITE'].iloc[i] == -100:
        simanim['CDLGAPSIDESIDEWHITE'].iloc[i] = -1
simanim['CDLGAPSIDESIDEWHITE'].sum()
# Out:
# 13

# %%
CDLGRAVESTONEDOJI = talib.CDLGRAVESTONEDOJI(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(df.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLGRAVESTONEDOJI'] = CDLGRAVESTONEDOJI
for i in range(0,len(CDLGRAVESTONEDOJI)):
    if simanim['CDLGRAVESTONEDOJI'].iloc[i] == 100:
        simanim['CDLGRAVESTONEDOJI'].iloc[i] = 1
    elif simanim['CDLGRAVESTONEDOJI'].iloc[i] == -100:
        simanim['CDLGRAVESTONEDOJI'].iloc[i] = -1
simanim['CDLGRAVESTONEDOJI'].sum()
# Out:
# 62

# %%
CDLHAMMER = talib.CDLHAMMER(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLGRAVESTONEDOJI.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLHAMMER'] = CDLHAMMER
for i in range(0,len(CDLHAMMER)):
    if simanim['CDLHAMMER'].iloc[i] == 100:
        simanim['CDLHAMMER'].iloc[i] = 1
    elif simanim['CDLHAMMER'].iloc[i] == -100:
        simanim['CDLHAMMER'].iloc[i] = -1
simanim['CDLHAMMER'].sum()
# Out:
# 86

# %%
CDLHANGINGMAN = talib.CDLHANGINGMAN(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLHANGINGMAN.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLHANGINGMAN'] = CDLHANGINGMAN
for i in range(0,len(CDLHANGINGMAN)):
    if simanim['CDLHANGINGMAN'].iloc[i] == 100:
        simanim['CDLHANGINGMAN'].iloc[i] = 1
    elif simanim['CDLHANGINGMAN'].iloc[i] == -100:
        simanim['CDLHANGINGMAN'].iloc[i] = -1
simanim['CDLHANGINGMAN'].sum()
# Out:
# -171

# %%
CDLHARAMI = talib.CDLHARAMI(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLHARAMI.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLHARAMI'] = CDLHARAMI
for i in range(0,len(CDLHARAMI)):
    if simanim['CDLHARAMI'].iloc[i] == 100:
        simanim['CDLHARAMI'].iloc[i] = 1
    elif simanim['CDLHARAMI'].iloc[i] == -100:
        simanim['CDLHARAMI'].iloc[i] = -1
simanim['CDLHARAMI'].sum()
# Out:
# 34

# %%
CDLHARAMICROSS = talib.CDLHARAMICROSS(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLHARAMICROSS.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLHARAMICROSS'] = CDLHARAMICROSS
for i in range(0,len(CDLHARAMICROSS)):
    if simanim['CDLHARAMICROSS'].iloc[i] == 100:
        simanim['CDLHARAMICROSS'].iloc[i] = 1
    elif simanim['CDLHARAMICROSS'].iloc[i] == -100:
        simanim['CDLHARAMICROSS'].iloc[i] = -1
simanim['CDLHARAMICROSS'].sum()
# Out:
# -12

# %%
CDLHIGHWAVE = talib.CDLHIGHWAVE(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLHIGHWAVE.as_matrix()).transform(df.as_matrix()).toarray()
simanim['CDLHIGHWAVE'] = CDLHIGHWAVE
for i in range(0,len(CDLHIGHWAVE)):
    if simanim['CDLHIGHWAVE'].iloc[i] == 100:
        simanim['CDLHIGHWAVE'].iloc[i] = 1
    elif simanim['CDLHIGHWAVE'].iloc[i] == -100:
        simanim['CDLHIGHWAVE'].iloc[i] = -1
simanim['CDLHIGHWAVE'].sum()
# Out:
# 26

# %%
CDLHIKKAKE = talib.CDLHIKKAKE(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLHIKKAKE.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLHIKKAKE'] = CDLHIKKAKE
for i in range(0,len(CDLHIKKAKE)):
    if simanim['CDLHIKKAKE'].iloc[i] == 100:
        simanim['CDLHIKKAKE'].iloc[i] = 1
    elif simanim['CDLHIKKAKE'].iloc[i] == -100:
        simanim['CDLHIKKAKE'].iloc[i] = -1
simanim['CDLHIKKAKE'].sum()
# Out:
# 941

# %%
CDLHIKKAKEMOD = talib.CDLHIKKAKEMOD(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLHIKKAKEMOD.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLHIKKAKEMOD'] = CDLHIKKAKEMOD
for i in range(0,len(CDLHIKKAKEMOD)):
    if simanim['CDLHIKKAKEMOD'].iloc[i] == 100:
        simanim['CDLHIKKAKEMOD'].iloc[i] = 1
    elif simanim['CDLHIKKAKEMOD'].iloc[i] == -100:
        simanim['CDLHIKKAKEMOD'].iloc[i] = -1
simanim['CDLHIKKAKEMOD'].sum()
# Out:
# -1

# %%
CDLHOMINGPIGEON = talib.CDLHOMINGPIGEON(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLHOMINGPIGEON.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLHOMINGPIGEON'] = CDLHOMINGPIGEON
for i in range(0,len(CDLHOMINGPIGEON)):
    if simanim['CDLHOMINGPIGEON'].iloc[i] == 100:
        simanim['CDLHOMINGPIGEON'].iloc[i] = 1
    elif simanim['CDLHOMINGPIGEON'].iloc[i] == -100:
        simanim['CDLHOMINGPIGEON'].iloc[i] = -1
simanim['CDLHOMINGPIGEON'].sum()
# Out:
# 73

# %%
CDLIDENTICAL3CROWS = talib.CDLIDENTICAL3CROWS(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLIDENTICAL3CROWS.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLIDENTICAL3CROWS'] = CDLIDENTICAL3CROWS
for i in range(0,len(CDLIDENTICAL3CROWS)):
    if simanim['CDLIDENTICAL3CROWS'].iloc[i] == 100:
        simanim['CDLIDENTICAL3CROWS'].iloc[i] = 1
    elif simanim['CDLIDENTICAL3CROWS'].iloc[i] == -100:
        simanim['CDLIDENTICAL3CROWS'].iloc[i] = -1
simanim['CDLIDENTICAL3CROWS'].sum()
# Out:
# -1

# %%
CDLINNECK = talib.CDLINNECK(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLINNECK.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLINNECK'] = CDLINNECK
for i in range(0,len(CDLINNECK)):
    if simanim['CDLINNECK'].iloc[i] == 100:
        simanim['CDLINNECK'].iloc[i] = 1
    elif simanim['CDLINNECK'].iloc[i] == -100:
        simanim['CDLINNECK'].iloc[i] = -1
simanim['CDLINNECK'].sum()
# Out:
# -6

# %%
CDLINVERTEDHAMMER = talib.CDLINVERTEDHAMMER(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLINVERTEDHAMMER.as_matrix()).transform(df.as_matrix()).toarray()
simanim['CDLINVERTEDHAMMER'] = CDLINVERTEDHAMMER
for i in range(0,len(CDLINVERTEDHAMMER)):
    if simanim['CDLINVERTEDHAMMER'].iloc[i] == 100:
        simanim['CDLINVERTEDHAMMER'].iloc[i] = 1
    elif simanim['CDLINVERTEDHAMMER'].iloc[i] == -100:
        simanim['CDLINVERTEDHAMMER'].iloc[i] = -1
simanim['CDLINVERTEDHAMMER'].sum()
# Out:
# 57

# %%
CDLKICKING = talib.CDLKICKING(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLKICKING.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLKICKING'] = CDLKICKING
for i in range(0,len(CDLKICKING)):
    if simanim['CDLKICKING'].iloc[i] == 100:
        simanim['CDLKICKING'].iloc[i] = 1
    elif simanim['CDLKICKING'].iloc[i] == -100:
        simanim['CDLKICKING'].iloc[i] = -1
simanim['CDLKICKING'].sum()
# Out:
# 0

# %%
CDLKICKINGBYLENGTH = talib.CDLKICKINGBYLENGTH(spy['Open'], spy['High'],spy['Low'], spy['Close'])
#enc.fit(CDLKICKINGBYLENGTH.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLKICKINGBYLENGTH'] = CDLKICKINGBYLENGTH
for i in range(0,len(CDLKICKINGBYLENGTH)):
    if simanim['CDLKICKINGBYLENGTH'].iloc[i] == 100:
        simanim['CDLKICKINGBYLENGTH'].iloc[i] = 1
    elif simanim['CDLKICKINGBYLENGTH'].iloc[i] == -100:
        simanim['CDLKICKINGBYLENGTH'].iloc[i] = -1
simanim['CDLKICKINGBYLENGTH'].sum()
# Out:
# 0

# %%
CDLLADDERBOTTOM = talib.CDLLADDERBOTTOM(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLLADDERBOTTOM.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLLADDERBOTTOM'] = CDLLADDERBOTTOM
for i in range(0,len(CDLLADDERBOTTOM)):
    if simanim['CDLLADDERBOTTOM'].iloc[i] == 100:
        simanim['CDLLADDERBOTTOM'].iloc[i] = 1
    elif simanim['CDLLADDERBOTTOM'].iloc[i] == -100:
        simanim['CDLLADDERBOTTOM'].iloc[i] = -1
simanim['CDLLADDERBOTTOM'].sum()
# Out:
# 8

# %%
CDLLONGLEGGEDDOJI = talib.CDLLONGLEGGEDDOJI(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLLONGLEGGEDDOJI.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLLONGLEGGEDDOJI'] = CDLLONGLEGGEDDOJI
for i in range(0,len(CDLLONGLEGGEDDOJI)):
    if simanim['CDLLONGLEGGEDDOJI'].iloc[i] == 100:
        simanim['CDLLONGLEGGEDDOJI'].iloc[i] = 1
    elif simanim['CDLLONGLEGGEDDOJI'].iloc[i] == -100:
        simanim['CDLLONGLEGGEDDOJI'].iloc[i] = -1
simanim['CDLLONGLEGGEDDOJI'].sum()
# Out:
# 767

# %%
CDLLONGLINE = talib.CDLLONGLINE(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLLONGLINE.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLLONGLINE'] = CDLLONGLINE
for i in range(0,len(CDLLONGLINE)):
    if simanim['CDLLONGLINE'].iloc[i] == 100:
        simanim['CDLLONGLINE'].iloc[i] = 1
    elif simanim['CDLLONGLINE'].iloc[i] == -100:
        simanim['CDLLONGLINE'].iloc[i] = -1
simanim['CDLLONGLINE'].sum()
# Out:
# 147

# %%
CDLMARUBOZU = talib.CDLMARUBOZU(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLMARUBOZU.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLMARUBOZU'] = CDLMARUBOZU
for i in range(0,len(CDLMARUBOZU)):
    if simanim['CDLMARUBOZU'].iloc[i] == 100:
        simanim['CDLMARUBOZU'].iloc[i] = 1
    elif simanim['CDLMARUBOZU'].iloc[i] == -100:
        simanim['CDLMARUBOZU'].iloc[i] = -1
simanim['CDLMARUBOZU'].sum()
# Out:
# 52

# %%
CDLMATCHINGLOW = talib.CDLMATCHINGLOW(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLMATCHINGLOW.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLMATCHINGLOW'] = CDLMATCHINGLOW
for i in range(0,len(CDLMATCHINGLOW)):
    if simanim['CDLMATCHINGLOW'].iloc[i] == 100:
        simanim['CDLMATCHINGLOW'].iloc[i] = 1
    elif simanim['CDLMATCHINGLOW'].iloc[i] == -100:
        simanim['CDLMATCHINGLOW'].iloc[i] = -1
simanim['CDLMATCHINGLOW'].sum()
# Out:
# 71

# %%
CDLMATHOLD = talib.CDLMATHOLD(spy['Open'], spy['High'],spy['Low'], spy['Close'], penetration=0) 
#enc.fit(CDLMATHOLD.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLMATHOLD'] = CDLMATHOLD
for i in range(0,len(CDLMATHOLD)):
    if simanim['CDLMATHOLD'].iloc[i] == 100:
        simanim['CDLMATHOLD'].iloc[i] = 1
    elif simanim['CDLMATHOLD'].iloc[i] == -100:
        simanim['CDLMATHOLD'].iloc[i] = -1
simanim['CDLMATHOLD'].sum()
# Out:
# 0

# %%
CDLMORNINGDOJISTAR = talib.CDLMORNINGDOJISTAR(spy['Open'], spy['High'],spy['Low'], spy['Close'], penetration=0) 
#enc.fit(CDLMORNINGDOJISTAR.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLMORNINGDOJISTAR'] = CDLMORNINGDOJISTAR
for i in range(0,len(CDLMORNINGDOJISTAR)):
    if simanim['CDLMORNINGDOJISTAR'].iloc[i] == 100:
        simanim['CDLMORNINGDOJISTAR'].iloc[i] = 1
    elif simanim['CDLMORNINGDOJISTAR'].iloc[i] == -100:
        simanim['CDLMORNINGDOJISTAR'].iloc[i] = -1
simanim['CDLMORNINGDOJISTAR'].sum()
# Out:
# 8

# %%
CDLMORNINGSTAR = talib.CDLMORNINGSTAR(spy['Open'], spy['High'],spy['Low'], spy['Close'], penetration=0) 
#enc.fit(CDLMORNINGSTAR.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLMORNINGSTAR'] = CDLMORNINGSTAR
for i in range(0,len(CDLMORNINGSTAR)):
    if simanim['CDLMORNINGSTAR'].iloc[i] == 100:
        simanim['CDLMORNINGSTAR'].iloc[i] = 1
    elif simanim['CDLMORNINGSTAR'].iloc[i] == -100:
        simanim['CDLMORNINGSTAR'].iloc[i] = -1
simanim['CDLMORNINGSTAR'].sum()
# Out:
# 30

# %%
CDLONNECK = talib.CDLONNECK(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLONNECK.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLONNECK'] = CDLONNECK
for i in range(0,len(CDLONNECK)):
    if simanim['CDLONNECK'].iloc[i] == 100:
        simanim['CDLONNECK'].iloc[i] = 1
    elif simanim['CDLONNECK'].iloc[i] == -100:
        simanim['CDLONNECK'].iloc[i] = -1
simanim['CDLONNECK'].sum()
# Out:
# -13

# %%
CDLPIERCING = talib.CDLPIERCING(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLPIERCING.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLPIERCING'] = CDLPIERCING
for i in range(0,len(CDLPIERCING)):
    if simanim['CDLPIERCING'].iloc[i] == 100:
        simanim['CDLPIERCING'].iloc[i] = 1
    elif simanim['CDLPIERCING'].iloc[i] == -100:
        simanim['CDLPIERCING'].iloc[i] = -1
simanim['CDLPIERCING'].sum()
# Out:
# 21

# %%
CDLRICKSHAWMAN = talib.CDLRICKSHAWMAN(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLRICKSHAWMAN.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLRICKSHAWMAN'] = CDLRICKSHAWMAN
for i in range(0,len(CDLRICKSHAWMAN)):
    if simanim['CDLRICKSHAWMAN'].iloc[i] == 100:
        simanim['CDLRICKSHAWMAN'].iloc[i] = 1
    elif simanim['CDLRICKSHAWMAN'].iloc[i] == -100:
        simanim['CDLRICKSHAWMAN'].iloc[i] = -1
simanim['CDLRICKSHAWMAN'].sum()
# Out:
# 593

# %%
CDLRISEFALL3METHODS = talib.CDLRISEFALL3METHODS(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLRISEFALL3METHODS.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLRISEFALL3METHODS'] = CDLRISEFALL3METHODS
for i in range(0,len(CDLRISEFALL3METHODS)):
    if simanim['CDLRISEFALL3METHODS'].iloc[i] == 100:
        simanim['CDLRISEFALL3METHODS'].iloc[i] = 1
    elif simanim['CDLRISEFALL3METHODS'].iloc[i] == -100:
        simanim['CDLRISEFALL3METHODS'].iloc[i] = -1
simanim['CDLRISEFALL3METHODS'].sum()
# Out:
# 0

# %%
CDLSEPARATINGLINES = talib.CDLSEPARATINGLINES(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLSEPARATINGLINES.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLSEPARATINGLINES'] = CDLSEPARATINGLINES
for i in range(0,len(CDLSEPARATINGLINES)):
    if simanim['CDLSEPARATINGLINES'].iloc[i] == 100:
        simanim['CDLSEPARATINGLINES'].iloc[i] = 1
    elif simanim['CDLSEPARATINGLINES'].iloc[i] == -100:
        simanim['CDLSEPARATINGLINES'].iloc[i] = -1
simanim['CDLSEPARATINGLINES'].sum()
# Out:
# 6

# %%
CDLSHOOTINGSTAR = talib.CDLSHOOTINGSTAR(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLSHOOTINGSTAR.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLSHOOTINGSTAR'] = CDLSHOOTINGSTAR
for i in range(0,len(CDLSHOOTINGSTAR)):
    if simanim['CDLSHOOTINGSTAR'].iloc[i] == 100:
        simanim['CDLSHOOTINGSTAR'].iloc[i] = 1
    elif simanim['CDLSHOOTINGSTAR'].iloc[i] == -100:
        simanim['CDLSHOOTINGSTAR'].iloc[i] = -1
simanim['CDLSHOOTINGSTAR'].sum()
# Out:
# -57

# %%
CDLSHORTLINE = talib.CDLSHORTLINE(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLSHORTLINE.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLSHORTLINE'] = CDLSHORTLINE
for i in range(0,len(CDLSHORTLINE)):
    if simanim['CDLSHORTLINE'].iloc[i] == 100:
        simanim['CDLSHORTLINE'].iloc[i] = 1
    elif simanim['CDLSHORTLINE'].iloc[i] == -100:
        simanim['CDLSHORTLINE'].iloc[i] = -1
simanim['CDLSHORTLINE'].sum()
# Out:
# 154

# %%
CDLSPINNINGTOP = talib.CDLSPINNINGTOP(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLSPINNINGTOP.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLSPINNINGTOP'] = CDLSPINNINGTOP
for i in range(0,len(CDLSPINNINGTOP)):
    if simanim['CDLSPINNINGTOP'].iloc[i] == 100:
        simanim['CDLSPINNINGTOP'].iloc[i] = 1
    elif simanim['CDLSPINNINGTOP'].iloc[i] == -100:
        simanim['CDLSPINNINGTOP'].iloc[i] = -1
simanim['CDLSPINNINGTOP'].sum()
# Out:
# 63

# %%
CDLSTALLEDPATTERN = talib.CDLSTALLEDPATTERN(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLSTALLEDPATTERN.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLSTALLEDPATTERN'] = CDLSTALLEDPATTERN
for i in range(0,len(CDLSTALLEDPATTERN)):
    if simanim['CDLSTALLEDPATTERN'].iloc[i] == 100:
        simanim['CDLSTALLEDPATTERN'].iloc[i] = 1
    elif simanim['CDLSTALLEDPATTERN'].iloc[i] == -100:
        simanim['CDLSTALLEDPATTERN'].iloc[i] = -1
simanim['CDLSTALLEDPATTERN'].sum()
# Out:
# -17

# %%
CDLSTICKSANDWICH = talib.CDLSTICKSANDWICH(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLSTICKSANDWICH.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLSTICKSANDWICH'] = CDLSTICKSANDWICH
for i in range(0,len(CDLSTICKSANDWICH)):
    if simanim['CDLSTICKSANDWICH'].iloc[i] == 100:
        simanim['CDLSTICKSANDWICH'].iloc[i] = 1
    elif simanim['CDLSTICKSANDWICH'].iloc[i] == -100:
        simanim['CDLSTICKSANDWICH'].iloc[i] = -1
simanim['CDLSTICKSANDWICH'].sum()
# Out:
# 5

# %%
CDLTAKURI = talib.CDLTAKURI(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLTAKURI.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLTAKURI'] = CDLTAKURI
for i in range(0,len(CDLTAKURI)):
    if simanim['CDLTAKURI'].iloc[i] == 100:
        simanim['CDLTAKURI'].iloc[i] = 1
    elif simanim['CDLTAKURI'].iloc[i] == -100:
        simanim['CDLTAKURI'].iloc[i] = -1
simanim['CDLTAKURI'].sum()
# Out:
# 78

# %%
CDLTASUKIGAP = talib.CDLTASUKIGAP(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLTASUKIGAP.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLTASUKIGAP'] = CDLTASUKIGAP
for i in range(0,len(CDLTASUKIGAP)):
    if simanim['CDLTASUKIGAP'].iloc[i] == 100:
        simanim['CDLTASUKIGAP'].iloc[i] = 1
    elif simanim['CDLTASUKIGAP'].iloc[i] == -100:
        simanim['CDLTASUKIGAP'].iloc[i] = -1
simanim['CDLTASUKIGAP'].sum()
# Out:
# 1

# %%
CDLTHRUSTING = talib.CDLTHRUSTING(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLTHRUSTING.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLTHRUSTING'] = CDLTHRUSTING
for i in range(0,len(CDLTHRUSTING)):
    if simanim['CDLTHRUSTING'].iloc[i] == 100:
        simanim['CDLTHRUSTING'].iloc[i] = 1
    elif simanim['CDLTHRUSTING'].iloc[i] == -100:
        simanim['CDLTHRUSTING'].iloc[i] = -1
simanim['CDLTHRUSTING'].sum()
# Out:
# -42

# %%
CDLTRISTAR = talib.CDLTRISTAR(spy['Open'], spy['High'],spy['Low'], spy['Close'])
#enc.fit(CDLTRISTAR.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLTRISTAR'] = CDLTRISTAR
for i in range(0,len(CDLTRISTAR)):
    if simanim['CDLTRISTAR'].iloc[i] == 100:
        simanim['CDLTRISTAR'].iloc[i] = 1
    elif simanim['CDLTRISTAR'].iloc[i] == -100:
        simanim['CDLTRISTAR'].iloc[i] = -1
simanim['CDLTRISTAR'].sum()
# Out:
# -1

# %%
CDLUNIQUE3RIVER = talib.CDLUNIQUE3RIVER(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLUNIQUE3RIVER.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLUNIQUE3RIVER'] = CDLUNIQUE3RIVER
for i in range(0,len(CDLEVENINGSTAR)):
    if simanim['CDLEVENINGSTAR'].iloc[i] == 100:
        simanim['CDLEVENINGSTAR'].iloc[i] = 1
    elif simanim['CDLEVENINGSTAR'].iloc[i] == -100:
        simanim['CDLEVENINGSTAR'].iloc[i] = -1
simanim['CDLEVENINGSTAR'].sum()
# Out:
# -38

# %%
CDLUPSIDEGAP2CROWS = talib.CDLUPSIDEGAP2CROWS(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLUPSIDEGAP2CROWS.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLUPSIDEGAP2CROWS'] = CDLUPSIDEGAP2CROWS
for i in range(0,len(CDLUPSIDEGAP2CROWS)):
    if simanim['CDLUPSIDEGAP2CROWS'].iloc[i] == 100:
        simanim['CDLUPSIDEGAP2CROWS'].iloc[i] = 1
    elif simanim['CDLUPSIDEGAP2CROWS'].iloc[i] == -100:
        simanim['CDLUPSIDEGAP2CROWS'].iloc[i] = -1
simanim['CDLUPSIDEGAP2CROWS'].sum()
# Out:
# -3

# %%
CDLXSIDEGAP3METHODS = talib.CDLXSIDEGAP3METHODS(spy['Open'], spy['High'],spy['Low'], spy['Close']) 
#enc.fit(CDLXSIDEGAP3METHODS.as_matrix()).transform(df.as_matrix()).toarray() 
simanim['CDLXSIDEGAP3METHODS'] = CDLXSIDEGAP3METHODS
for i in range(0,len(CDLXSIDEGAP3METHODS)):
    if simanim['CDLXSIDEGAP3METHODS'].iloc[i] == 100:
        simanim['CDLXSIDEGAP3METHODS'].iloc[i] = 1
    elif simanim['CDLXSIDEGAP3METHODS'].iloc[i] == -100:
        simanim['CDLXSIDEGAP3METHODS'].iloc[i] = -1
simanim['CDLXSIDEGAP3METHODS'].sum()
# Out:
# -4

# %%
simanim.tail()
# Out:
#             CDL2CROWS  CDL3BLACKCROWS  CDL3INSIDE  CDL3LINESTRIKE  \
# Date
# 2019-04-23          0               0           0               0
# 2019-04-24          0               0           0               0
# 2019-04-25          0               0           0               0
# 2019-04-26          0               0           0               0
# 2019-04-29          0               0           0               0
#
#             CDL3OUTSIDE  CDL3STARSINSOUTH  CDL3WHITESOLDIERS  \
# Date
# 2019-04-23            1                 0                  0
# 2019-04-24            0                 0                  0
# 2019-04-25            0                 0                  0
# 2019-04-26            0                 0                  0
# 2019-04-29            0                 0                  0
#
#             CDLABANDONEDBABY  CDLADVANCEBLOCK  CDLBELTHOLD  ...  \
# Date                                                        ...
# 2019-04-23                 0                0            0  ...
# 2019-04-24                 0                0            0  ...
# 2019-04-25                 0                0            0  ...
# 2019-04-26                 0                0            0  ...
# 2019-04-29                 0                0            0  ...
#
#             CDLSPINNINGTOP  CDLSTALLEDPATTERN  CDLSTICKSANDWICH  CDLTAKURI  \
# Date
# 2019-04-23               0                  0                 0          0
# 2019-04-24               0                  0                 0          0
# 2019-04-25              -1                  0                 0          0
# 2019-04-26               0                  0                 0          0
# 2019-04-29               0                  0                 0          0
#
#             CDLTASUKIGAP  CDLTHRUSTING  CDLTRISTAR  CDLUNIQUE3RIVER  \
# Date
# 2019-04-23             0             0           0                0
# 2019-04-24             0             0           0                0
# 2019-04-25             0             0           0                0
# 2019-04-26             0             0           0                0
# 2019-04-29             0             0           0                0
#
#             CDLUPSIDEGAP2CROWS  CDLXSIDEGAP3METHODS
# Date
# 2019-04-23                   0                    0
# 2019-04-24                   0                    0
# 2019-04-25                   0                    0
# 2019-04-26                   0                    0
# 2019-04-29                   0                    0
#
# [5 rows x 61 columns]

# %%
simanim.shape
# Out:
# (5576, 61)

# %%
simanim.sum()
# Out:
# CDL2CROWS                -1
# CDL3BLACKCROWS           -1
# CDL3INSIDE               27
# CDL3LINESTRIKE           -1
# CDL3OUTSIDE              -5
# CDL3STARSINSOUTH          0
# CDL3WHITESOLDIERS         1
# CDLABANDONEDBABY          0
# CDLADVANCEBLOCK         -33
# CDLBELTHOLD             -13
# CDLBREAKAWAY              0
# CDLCLOSINGMARUBOZU      132
# CDLCONCEALBABYSWALL       0
# CDLCOUNTERATTACK          3
# CDLDARKCLOUDCOVER       -73
# CDLDOJI                 767
# CDLDOJISTAR             -53
# CDLDRAGONFLYDOJI         80
# CDLENGULFING            -53
# CDLEVENINGDOJISTAR      -13
# CDLEVENINGSTAR          -38
# CDLGAPSIDESIDEWHITE      13
# CDLGRAVESTONEDOJI        62
# CDLHAMMER                86
# CDLHANGINGMAN          -171
# CDLHARAMI                34
# CDLHARAMICROSS          -12
# CDLHIGHWAVE              26
# CDLHIKKAKE              941
# CDLHIKKAKEMOD            -1
#                        ...
# CDLIDENTICAL3CROWS       -1
# CDLINNECK                -6
# CDLINVERTEDHAMMER        57
# CDLKICKING                0
# CDLKICKINGBYLENGTH        0
# CDLLADDERBOTTOM           8
# CDLLONGLEGGEDDOJI       767
# CDLLONGLINE             147
# CDLMARUBOZU              52
# CDLMATCHINGLOW           71
# CDLMATHOLD                0
# CDLMORNINGDOJISTAR        8
# CDLMORNINGSTAR           30
# CDLONNECK               -13
# CDLPIERCING              21
# CDLRICKSHAWMAN          593
# CDLRISEFALL3METHODS       0
# CDLSEPARATINGLINES        6
# CDLSHOOTINGSTAR         -57
# CDLSHORTLINE            154
# CDLSPINNINGTOP           63
# CDLSTALLEDPATTERN       -17
# CDLSTICKSANDWICH          5
# CDLTAKURI                78
# CDLTASUKIGAP              1
# CDLTHRUSTING            -42
# CDLTRISTAR               -1
# CDLUNIQUE3RIVER        1100
# CDLUPSIDEGAP2CROWS       -3
# CDLXSIDEGAP3METHODS      -4
# Length: 61, dtype: int64

# %%
simanim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5576 entries, 1997-03-03 to 2019-04-29
# Data columns (total 61 columns):
# CDL2CROWS              5576 non-null int32
# CDL3BLACKCROWS         5576 non-null int32
# CDL3INSIDE             5576 non-null int32
# CDL3LINESTRIKE         5576 non-null int32
# CDL3OUTSIDE            5576 non-null int32
# CDL3STARSINSOUTH       5576 non-null int32
# CDL3WHITESOLDIERS      5576 non-null int32
# CDLABANDONEDBABY       5576 non-null int32
# CDLADVANCEBLOCK        5576 non-null int32
# CDLBELTHOLD            5576 non-null int32
# CDLBREAKAWAY           5576 non-null int32
# CDLCLOSINGMARUBOZU     5576 non-null int32
# CDLCONCEALBABYSWALL    5576 non-null int32
# CDLCOUNTERATTACK       5576 non-null int32
# CDLDARKCLOUDCOVER      5576 non-null int32
# CDLDOJI                5576 non-null int32
# CDLDOJISTAR            5576 non-null int32
# CDLDRAGONFLYDOJI       5576 non-null int32
# CDLENGULFING           5576 non-null int32
# CDLEVENINGDOJISTAR     5576 non-null int32
# CDLEVENINGSTAR         5576 non-null int32
# CDLGAPSIDESIDEWHITE    5576 non-null int32
# CDLGRAVESTONEDOJI      5576 non-null int32
# CDLHAMMER              5576 non-null int32
# CDLHANGINGMAN          5576 non-null int32
# CDLHARAMI              5576 non-null int32
# CDLHARAMICROSS         5576 non-null int32
# CDLHIGHWAVE            5576 non-null int32
# CDLHIKKAKE             5576 non-null int32
# CDLHIKKAKEMOD          5576 non-null int32
# CDLHOMINGPIGEON        5576 non-null int32
# CDLIDENTICAL3CROWS     5576 non-null int32
# CDLINNECK              5576 non-null int32
# CDLINVERTEDHAMMER      5576 non-null int32
# CDLKICKING             5576 non-null int32
# CDLKICKINGBYLENGTH     5576 non-null int32
# CDLLADDERBOTTOM        5576 non-null int32
# CDLLONGLEGGEDDOJI      5576 non-null int32
# CDLLONGLINE            5576 non-null int32
# CDLMARUBOZU            5576 non-null int32
# CDLMATCHINGLOW         5576 non-null int32
# CDLMATHOLD             5576 non-null int32
# CDLMORNINGDOJISTAR     5576 non-null int32
# CDLMORNINGSTAR         5576 non-null int32
# CDLONNECK              5576 non-null int32
# CDLPIERCING            5576 non-null int32
# CDLRICKSHAWMAN         5576 non-null int32
# CDLRISEFALL3METHODS    5576 non-null int32
# CDLSEPARATINGLINES     5576 non-null int32
# CDLSHOOTINGSTAR        5576 non-null int32
# CDLSHORTLINE           5576 non-null int32
# CDLSPINNINGTOP         5576 non-null int32
# CDLSTALLEDPATTERN      5576 non-null int32
# CDLSTICKSANDWICH       5576 non-null int32
# CDLTAKURI              5576 non-null int32
# CDLTASUKIGAP           5576 non-null int32
# CDLTHRUSTING           5576 non-null int32
# CDLTRISTAR             5576 non-null int32
# CDLUNIQUE3RIVER        5576 non-null int32
# CDLUPSIDEGAP2CROWS     5576 non-null int32
# CDLXSIDEGAP3METHODS    5576 non-null int32
# dtypes: int32(61)
# memory usage: 1.3 MB

# %%
# DEFINITIONS DES SIMANIM

ema9 = talib.EMA(spy['Close'], timeperiod=9) 
simanim['ema9'] = ema9

ema54 = talib.EMA(spy['Close'], timeperiod=54) 
simanim['ema54'] = ema54

ema100 = talib.EMA(spy['Close'], timeperiod=100) 
simanim['ema100'] = ema100

#atr8 = talib.EMA(spy['Close'], timeperiod=8)
#simanim['atr8'] = atr8

rsi = talib.RSI(spy['Close'], timeperiod=14)
simanim['rsi'] = rsi

#macd, macdsignal, macdhist = talib.MACD(spy['Close'], fastperiod=12, slowperiod=26, signalperiod=9)
#simanim['macd'] = macd
#simanim['macdsignal'] = macdsignal
#simanim['macdhist'] = macdhist

#fastk, fastd = talib.STOCHRSI(spy['Close'], timeperiod=14, fastk_period=5, fastd_period=3, fastd_matype=0)
#simanim['fastk'] = fastk
#simanim['fastd'] = fastd

# ad = talib.AD(spy['High'], spy['Low'], spy['Close'], spy['Volume']) # => Coorelation
# simanim['ad'] = ad

atr14 = talib.ATR(spy['High'], spy['Low'], spy['Close'], timeperiod=14)
simanim['atr14'] = atr14

wclprice = talib.WCLPRICE(spy['High'], spy['Low'], spy['Close'])
simanim['wclprice'] = wclprice

upper, middle, lower =  talib.BBANDS(spy['Close'], 9, 2, 2)
simanim['BBup'] = upper
simanim['BBmid'] = middle
simanim['BBlow'] = lower

#sine, leadsine = talib.HT_SINE(spy['Close'])
#simanim['sine'] = sine
#simanim['leadsine'] = leadsine

instant_trendline = talib.HT_TRENDLINE(spy['Close'])
simanim['instant_trendline'] = instant_trendline

#midprice5 = talib.MIDPRICE(spy['High'],spy['Low'], timeperiod=5) # Correlation 
#simanim['midprice5'] = midprice5

#ultosc = talib.ULTOSC(spy['High'], spy['Low'], spy['Close'], timeperiod1=5, timeperiod2=9, timeperiod3=13)
#simanim['ultosc'] = ultosc

#obv = talib.OBV(spy['Close'], spy['Volume'])
#simanim['obv'] = obv

#ht_trendmode = talib.HT_TRENDMODE(spy['Close'])
#simanim['ht_trendmode'] = ht_trendmode

# %%
simanim.tail()
# Out:
#             CDL2CROWS  CDL3BLACKCROWS  CDL3INSIDE  CDL3LINESTRIKE  \
# Date
# 2019-04-23          0               0           0               0
# 2019-04-24          0               0           0               0
# 2019-04-25          0               0           0               0
# 2019-04-26          0               0           0               0
# 2019-04-29          0               0           0               0
#
#             CDL3OUTSIDE  CDL3STARSINSOUTH  CDL3WHITESOLDIERS  \
# Date
# 2019-04-23            1                 0                  0
# 2019-04-24            0                 0                  0
# 2019-04-25            0                 0                  0
# 2019-04-26            0                 0                  0
# 2019-04-29            0                 0                  0
#
#             CDLABANDONEDBABY  CDLADVANCEBLOCK  CDLBELTHOLD  ...        ema9  \
# Date                                                        ...
# 2019-04-23                 0                0            0  ...  289.932169
# 2019-04-24                 0                0            0  ...  290.391738
# 2019-04-25                 0                0            0  ...  290.723388
# 2019-04-26                 0                0            0  ...  291.260711
# 2019-04-29                 0                0            0  ...  291.782568
#
#                  ema54      ema100        rsi     atr14    wclprice  \
# Date
# 2019-04-23  281.450595  277.605448  73.324726  2.137286  292.330009
# 2019-04-24  281.842574  277.895044  70.186689  2.062479  292.422508
# 2019-04-25  282.213753  278.175340  69.302067  2.061587  291.902496
# 2019-04-26  282.620889  278.477016  72.157138  2.075045  292.887497
# 2019-04-29  283.029947  278.781828  73.069451  2.001114  293.900002
#
#                   BBup       BBmid       BBlow  instant_trendline
# Date
# 2019-04-23  292.500188  289.934445  287.368702         287.637045
# 2019-04-24  293.009767  290.372223  287.734678         288.078220
# 2019-04-25  293.123032  290.798889  288.474746         288.418317
# 2019-04-26  293.940074  291.160000  288.379926         288.723677
# 2019-04-29  294.693713  291.593333  288.492952         288.987352
#
# [5 rows x 71 columns]

# %%
simanim = pd.concat((simanim,spy['Adj Close']),axis=1)

# %%
simanim.head()
# Out:
#             CDL2CROWS  CDL3BLACKCROWS  CDL3INSIDE  CDL3LINESTRIKE  \
# Date
# 1997-03-03          0               0           0               0
# 1997-03-04          0               0           0               0
# 1997-03-05          0               0           0               0
# 1997-03-06          0               0           0               0
# 1997-03-07          0               0           0               0
#
#             CDL3OUTSIDE  CDL3STARSINSOUTH  CDL3WHITESOLDIERS  \
# Date
# 1997-03-03            0                 0                  0
# 1997-03-04            0                 0                  0
# 1997-03-05            0                 0                  0
# 1997-03-06            0                 0                  0
# 1997-03-07            0                 0                  0
#
#             CDLABANDONEDBABY  CDLADVANCEBLOCK  CDLBELTHOLD  ...  ema54  \
# Date                                                        ...
# 1997-03-03                 0                0            0  ...    NaN
# 1997-03-04                 0                0            0  ...    NaN
# 1997-03-05                 0                0            0  ...    NaN
# 1997-03-06                 0                0            0  ...    NaN
# 1997-03-07                 0                0            0  ...    NaN
#
#             ema100  rsi  atr14   wclprice  BBup  BBmid  BBlow  \
# Date
# 1997-03-03     NaN  NaN    NaN  79.453125   NaN    NaN    NaN
# 1997-03-04     NaN  NaN    NaN  79.429674   NaN    NaN    NaN
# 1997-03-05     NaN  NaN    NaN  80.308548   NaN    NaN    NaN
# 1997-03-06     NaN  NaN    NaN  80.257799   NaN    NaN    NaN
# 1997-03-07     NaN  NaN    NaN  80.773397   NaN    NaN    NaN
#
#             instant_trendline  Adj Close
# Date
# 1997-03-03                NaN  53.450661
# 1997-03-04                NaN  53.157196
# 1997-03-05                NaN  54.058502
# 1997-03-06                NaN  53.744110
# 1997-03-07                NaN  54.226185
#
# [5 rows x 72 columns]

# %% [markdown]
# # TREND GLISSANT 5 JOURS COEF +atr14*2
# trend = []

# %% [markdown]
# for i in range(0,len(simanim)-5):
#
#     #ii = (atr14[i]*2)/spy.iloc[i,3]
#     ii = 0.019
#     jour = spy.iloc[i,3]
#     jour2 = spy.iloc[i+1,3]
#     jour3 = spy.iloc[i+2,3]
#     jour4 = spy.iloc[i+3,3]
#     jour5 = spy.iloc[i+4,3]
#     moy = (jour2+jour3+jour4+jour5)/4
#     jtest = jour+(jour*ii)
#
#     if jour*(1+ii)<jour5:
#         trend.append(1)
#
#
#     elif jour*(1-ii)>jour5:
#         trend.append(2)
#
#
#     else :
#         trend.append(0)
#
#
# nb_row= len(trend)
# #simanim.loc[:nb_row,'trend'] = trend5
#
# simanim.loc[:nb_row,'trend'] = trend
#
# #simanim.loc[:nb_row,'baisse'] = baisse
#
# #simanim.loc[:nb_row,'stagne'] = stagne
# simanim.shape

# %%
simanim = simanim.dropna()
simanim.isnull().sum().sum(),simanim.shape#,simanim['trend'].sum()
# Out:
# (0, (5477, 72))

# %%
#delta = round((date(simanim.index[simanim.shape[0]-1].year,\
 #                   simanim.index[simanim.shape[0]-1].month,simanim.index[simanim.shape[0]-1].day)\
  #             -date(simanim.index[0].year,simanim.index[0].month,simanim.index[0].day)).days)
delta = simanim.shape[0]
bloc1 = round(delta*0.8)
bloc2 = delta - bloc1
print("Période d'étude : ",delta)
print('Sur un découpage 80% - 20% de la période : ')
print('Bloc 1 : ',bloc1,' jours \nBloc 2 :',bloc2,' jours')
# Out:
# Période d'étude :  5477
# Sur un découpage 80% - 20% de la période :
# Bloc 1 :  4382  jours
# Bloc 2 : 1095  jours

# %%
simanim.to_csv('simanim.csv')

# %%
simanim.shape
# Out:
# (5477, 72)

# %%
plt.figure(figsize=(16,6))
sns.heatmap(simanim.iloc[:,:-1].corr())
plt.show()

# %%
# SPLIT TRAIN ET TEST
X = simanim.iloc[:,:-1]
y = simanim.iloc[:,-1]
#X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
X_train = X.iloc[:bloc1,:]
X_test = X.iloc[bloc1:,:]
y_train = y.iloc[:bloc1]
y_test = y.iloc[bloc1:]

# %%
import statsmodels.api as sm
logit_model=sm.MNLogit(y,X)
result=logit_model.fit(
    start_params=None,
    method='bfgs',
    maxiter=350,
    full_output=1,
    disp=1,
    callback=None,
)
print(result.summary2())

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test))
fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
classifier = LogisticRegression(
    penalty='l2',
    dual=False,
    tol=0.001,
    C=1,
    fit_intercept=True,
    intercept_scaling=1,
    class_weight=None,
    random_state=None,
    solver='newton-cg',
    max_iter=1000,
    multi_class='ovr',
    verbose=1,
    warm_start=False,
    n_jobs=-1,
)
classifier.fit(X_train, y_train)

# %%
X_test.shape

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[884   0   8]
#  [ 98   2   6]
#  [ 98   0   3]]

# %%
print('Accuracy de la regression logistique sue le test set: {:.2f}%'.format(classifier.score(X_test, y_test)*100))
# Out:
# Accuracy de la regression logistique sue le test set: 80.89%

# %%
y_pred
# Out:
# array([ 0.,  0.,  0., ...,  0.,  0.,  0.])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.99      0.90       892
#          1.0       1.00      0.02      0.04       106
#          2.0       0.18      0.03      0.05       101
#
#    micro avg       0.81      0.81      0.81      1099
#    macro avg       0.66      0.35      0.33      1099
# weighted avg       0.78      0.81      0.74      1099

# %%
print("The precision is the ratio tp / (tp + fp) where tp is the number of true positives and fp the number of false positives. The precision is intuitively the ability of the classifier to not label a sample as positive if it is negative.The recall is the ratio tp / (tp + fn) where tp is the number of true positives and fn the number of false negatives. The recall is intuitively the ability of the classifier to find all the positive samples.The F-beta score can be interpreted as a weighted harmonic mean of the precision and recall, where an F-beta score reaches its best value at 1 and worst score at 0.The F-beta score weights the recall more than the precision by a factor of beta. beta = 1.0 means recall and precision are equally important.The support is the number of occurrences of each class in y_test.")
# Out:
# The precision is the ratio tp / (tp + fp) where tp is the number of true positives and fp the number of false positives. The precision is intuitively the ability of the classifier to not label a sample as positive if it is negative.The recall is the ratio tp / (tp + fn) where tp is the number of true positives and fn the number of false negatives. The recall is intuitively the ability of the classifier to find all the positive samples.The F-beta score can be interpreted as a weighted harmonic mean of the precision and recall, where an F-beta score reaches its best value at 1 and worst score at 0.The F-beta score weights the recall more than the precision by a factor of beta. beta = 1.0 means recall and precision are equally important.The support is the number of occurrences of each class in y_test.

# %%
y_train.shape,y_train.sum(),y_test.shape,y_test.sum()
# Out:
# ((4397,), 2179.0, (1099,), 308.0)

# %%
# PHASE DEUX

# %%
Xtrain = simanim.iloc[:bloc1,:-1]
Xtest = simanim.iloc[bloc1:,:-1]
y = simanim.iloc[:bloc1,-1]

# %%
param = {}
param['booster'] = 'gbtree'
param['objective'] = 'binary:logistic'
param["eval_metric"] = "error"
param['eta'] = 0.3
param['gamma'] = 0
param['max_depth'] = 6
param['min_child_weight']=1
param['max_delta_step'] = 0
param['subsample']= 1
param['colsample_bytree']=1
param['silent'] = 1
param['seed'] = 0
param['base_score'] = 0.5

clf = xgb.XGBClassifier(param)

# %%
boost = XGBClassifier()
boost.fit(Xtrain, y)
p_boost = boost.predict(Xtrain)
print ("Score Train -->", round(boost.score(Xtrain, y) *100,2), " %")
# Out:
# Score Train --> 71.66  %

# %%
xgb.plot_importance(boost)

# %%
xgb.to_graphviz(boost, num_trees=2)

# %%
Xtrain.head()
# Out:
#                   rsi       fastk     atr14   wclprice      sine  leadsine  \
# Date
# 1997-06-02  61.016745    0.000000  1.320350  84.945272 -0.545650 -0.978398
# 1997-06-03  59.756457    0.000000  1.304168  84.695299 -0.551399 -0.979796
# 1997-06-04  59.327244    0.000000  1.259006  84.410124 -0.941049 -0.904616
# 1997-06-05  60.324107   29.233467  1.233813  84.792923 -0.940331 -0.905515
# 1997-06-06  65.086300  100.000000  1.277383  85.945299 -0.939121 -0.907011
#
#                ultosc
# Date
# 1997-06-02  59.832475
# 1997-06-03  51.133164
# 1997-06-04  49.648307
# 1997-06-05  50.880544
# 1997-06-06  53.857315

# %%
import catboost as cb

# %%
Xtrain = simanim.iloc[:bloc1,:-1]
Xtest = simanim.iloc[bloc1:,:-1]
y = simanim.iloc[:bloc1,-1]
simanim.shape
# Out:
# (5496, 8)

# %%
q=0
featlist = []
for bb in range(8,69):
    q+=1
    featlist.append(q)
#cat_features = featlist
params = {'depth': [4, 7, 10],
          'learning_rate' : [0.03, 0.1, 0.15],
          'l2_leaf_reg': [1,4,9],
          'iterations': [300]}

cbc = cb.CatBoostClassifier(
    iterations=None,
    learning_rate=None,
    depth=None,
    l2_leaf_reg=None,
    model_size_reg=None,
    rsm=None,
    loss_function='Logloss',
    border_count=None,
    feature_border_type=None,
    input_borders=None,
    output_borders=None,
    fold_permutation_block=None,
    od_pval=None,
    od_wait=None,
    od_type=None,
    nan_mode=None,
    counter_calc_method=None,
    leaf_estimation_iterations=None,
    leaf_estimation_method=None,
    thread_count=None,
    random_seed=None,
    use_best_model=None,
    best_model_min_trees=None,
    verbose=None,
    silent=None,
    logging_level=None,
    metric_period=None,
    ctr_leaf_count_limit=None,
    store_all_simple_ctr=None,
    max_ctr_complexity=None,
    has_time=None,
    allow_const_label=None,
    classes_count=None,
    class_weights=None,
    class_names=None,
    one_hot_max_size=None,
    random_strength=None,
    name=None,
    ignored_features=None,
    train_dir=None,
    custom_loss=None,
    custom_metric=None,
    eval_metric=None,
    bagging_temperature=None,
    save_snapshot=None,
    snapshot_file=None,
    snapshot_interval=None,
    fold_len_multiplier=None,
    used_ram_limit=None,
    gpu_ram_part=None,
    pinned_memory_size=None,
    allow_writing_files=None,
    final_ctr_computation_mode=None,
    approx_on_full_history=None,
    boosting_type=None,
    simple_ctr=None,
    combinations_ctr=None,
    per_feature_ctr=None,
    ctr_description=None,
    ctr_target_border_count=None,
    task_type=None,
    device_config=None,
    devices=None,
    bootstrap_type=None,
    subsample=None,
    sampling_unit=None,
    dev_score_calc_obj_block_size=None,
    dev_efb_max_buckets=None,
    efb_max_conflict_fraction=None,
    max_depth=None,
    n_estimators=None,
    num_boost_round=None,
    num_trees=None,
    colsample_bylevel=None,
    random_state=None,
    reg_lambda=None,
    objective=None,
    eta=None,
    max_bin=None,
    scale_pos_weight=None,
    gpu_cat_features_storage=None,
    data_partition=None,
    metadata=None,
    early_stopping_rounds=None,
    cat_features=None,
    grow_policy=None,
    min_data_in_leaf=None,
    max_leaves=None,
    score_function=None,
    leaf_estimation_backtracking=None,
    ctr_history_unit=None,
)
cbc.fit(Xtrain, y)#, cat_features)
p_cbc = cbc.predict(Xtrain)
print ("Score Train -->", round(cbc.score(Xtrain, y) *100,2), " %")
# Out:
# Learning rate set to 0.025476
# 0:	learn: 0.6849883	total: 40.2ms	remaining: 40.2s
# 1:	learn: 0.6780789	total: 62.6ms	remaining: 31.2s
# 2:	learn: 0.6714315	total: 83.6ms	remaining: 27.8s
# 3:	learn: 0.6644837	total: 114ms	remaining: 28.3s
# 4:	learn: 0.6591444	total: 148ms	remaining: 29.4s
# 5:	learn: 0.6528843	total: 169ms	remaining: 28s
# 6:	learn: 0.6467181	total: 188ms	remaining: 26.7s
# 7:	learn: 0.6416846	total: 212ms	remaining: 26.3s
# 8:	learn: 0.6365015	total: 239ms	remaining: 26.3s
# 9:	learn: 0.6314299	total: 259ms	remaining: 25.6s
clf = cb.CatBoostClassifier(eval_metric="AUC",

depth=10,

iterations= 500,

l2_leaf_reg= 9,

learning_rate= 0.15)

clf.fit(Xtrain, y)#, cat_features)

print ("Score Train -->", round(clf.score(Xtrain, y) *100,2), " %")
# Out:
# 0:	total: 337ms	remaining: 2m 48s
# 1:	total: 491ms	remaining: 2m 2s
# 2:	total: 642ms	remaining: 1m 46s
# 3:	total: 673ms	remaining: 1m 23s
# 4:	total: 838ms	remaining: 1m 22s
# 5:	total: 1.03s	remaining: 1m 24s
# 6:	total: 1.2s	remaining: 1m 24s
# 7:	total: 1.37s	remaining: 1m 24s
# 8:	total: 1.51s	remaining: 1m 22s
# 9:	total: 1.65s	remaining: 1m 20s
# 10:	total: 1.79s	remaining: 1m 19s
# 11:	total: 1.83s	remaining: 1m 14s
# 12:	total: 2s	remaining: 1m 14s
# 13:	total: 2.16s	remaining: 1m 15s
# 14:	total: 2.32s	remaining: 1m 15s
# 15:	total: 2.47s	remaining: 1m 14s
# 16:	total: 2.63s	remaining: 1m 14s
# 17:	total: 2.77s	remaining: 1m 14s
# 18:	total: 2.92s	remaining: 1m 13s
# 19:	total: 3.06s	remaining: 1m 13s
# 20:	total: 3.23s	remaining: 1m 13s
# 21:	total: 3.39s	remaining: 1m 13s
# 22:	total: 3.55s	remaining: 1m 13s
# 23:	total: 3.69s	remaining: 1m 13s
# 24:	total: 3.86s	remaining: 1m 13s
# 25:	total: 4.02s	remaining: 1m 13s
# 26:	total: 4.19s	remaining: 1m 13s
# 27:	total: 4.35s	remaining: 1m 13s
# 28:	total: 4.51s	remaining: 1m 13s
# 29:	total: 4.66s	remaining: 1m 13s
# 30:	total: 4.82s	remaining: 1m 12s
# 31:	total: 4.84s	remaining: 1m 10s
# 32:	total: 4.98s	remaining: 1m 10s
# 33:	total: 5s	remaining: 1m 8s
# 34:	total: 5.15s	remaining: 1m 8s
# 35:	total: 5.31s	remaining: 1m 8s
# 36:	total: 5.46s	remaining: 1m 8s
# 37:	total: 5.61s	remaining: 1m 8s
# 38:	total: 5.67s	remaining: 1m 6s
# 39:	total: 5.83s	remaining: 1m 7s
# 40:	total: 5.86s	remaining: 1m 5s
# 41:	total: 6.01s	remaining: 1m 5s
# 42:	total: 6.16s	remaining: 1m 5s
# 43:	total: 6.39s	remaining: 1m 6s
# 44:	total: 6.59s	remaining: 1m 6s
# 45:	total: 6.77s	remaining: 1m 6s
# 46:	total: 6.92s	remaining: 1m 6s
# 47:	total: 7.07s	remaining: 1m 6s
# 48:	total: 7.24s	remaining: 1m 6s
# 49:	total: 7.42s	remaining: 1m 6s
# 50:	total: 7.58s	remaining: 1m 6s
# 51:	total: 7.73s	remaining: 1m 6s
# 52:	total: 7.9s	remaining: 1m 6s
# 53:	total: 8.08s	remaining: 1m 6s
# 54:	total: 8.16s	remaining: 1m 6s
# 55:	total: 8.31s	remaining: 1m 5s
# 56:	total: 8.48s	remaining: 1m 5s
# 57:	total: 8.64s	remaining: 1m 5s
# 58:	total: 8.82s	remaining: 1m 5s
# 59:	total: 8.98s	remaining: 1m 5s
# 60:	total: 9.1s	remaining: 1m 5s
# 61:	total: 9.33s	remaining: 1m 5s
# 62:	total: 9.53s	remaining: 1m 6s
# 63:	total: 9.74s	remaining: 1m 6s
# 64:	total: 9.93s	remaining: 1m 6s
# 65:	total: 9.98s	remaining: 1m 5s
# 66:	total: 10.2s	remaining: 1m 5s
# 67:	total: 10.4s	remaining: 1m 5s
# 68:	total: 10.6s	remaining: 1m 5s
# 69:	total: 10.7s	remaining: 1m 5s
# 70:	total: 10.8s	remaining: 1m 4s
# 71:	total: 10.9s	remaining: 1m 4s
# 72:	total: 11.1s	remaining: 1m 4s
# 73:	total: 11.2s	remaining: 1m 4s
# 74:	total: 11.4s	remaining: 1m 4s
# 75:	total: 11.6s	remaining: 1m 4s
# 76:	total: 11.8s	remaining: 1m 4s
# 77:	total: 12s	remaining: 1m 4s
# 78:	total: 12.2s	remaining: 1m 4s
# 79:	total: 12.3s	remaining: 1m 4s
# 80:	total: 12.5s	remaining: 1m 4s
# 81:	total: 12.7s	remaining: 1m 4s
# 82:	total: 12.8s	remaining: 1m 4s
# 83:	total: 13s	remaining: 1m 4s
# 84:	total: 13.1s	remaining: 1m 4s
# 85:	total: 13.3s	remaining: 1m 4s
# 86:	total: 13.5s	remaining: 1m 3s
# 87:	total: 13.6s	remaining: 1m 3s
# 88:	total: 13.8s	remaining: 1m 3s
# 89:	total: 13.9s	remaining: 1m 3s
# 90:	total: 14.1s	remaining: 1m 3s
# 91:	total: 14.2s	remaining: 1m 3s
# 92:	total: 14.4s	remaining: 1m 2s
# 93:	total: 14.5s	remaining: 1m 2s
# 94:	total: 14.7s	remaining: 1m 2s
# 95:	total: 14.8s	remaining: 1m 2s
# 96:	total: 15s	remaining: 1m 2s
# 97:	total: 15.2s	remaining: 1m 2s
# 98:	total: 15.4s	remaining: 1m 2s
# 99:	total: 15.6s	remaining: 1m 2s
# 100:	total: 15.8s	remaining: 1m 2s
# 101:	total: 16s	remaining: 1m 2s
# 102:	total: 16.2s	remaining: 1m 2s
# 103:	total: 16.4s	remaining: 1m 2s
# 104:	total: 16.6s	remaining: 1m 2s
# 105:	total: 16.8s	remaining: 1m 2s
# 106:	total: 16.9s	remaining: 1m 2s
# 107:	total: 17.1s	remaining: 1m 2s
# 108:	total: 17.3s	remaining: 1m 1s
# 109:	total: 17.4s	remaining: 1m 1s
# 110:	total: 17.6s	remaining: 1m 1s
# 111:	total: 17.7s	remaining: 1m 1s
# 112:	total: 17.9s	remaining: 1m 1s
# 113:	total: 18.1s	remaining: 1m 1s
# 114:	total: 18.2s	remaining: 1m 1s
# 115:	total: 18.4s	remaining: 1m
# 116:	total: 18.5s	remaining: 1m
# 117:	total: 18.7s	remaining: 1m
# 118:	total: 18.9s	remaining: 1m
# 119:	total: 19s	remaining: 1m
# 120:	total: 19.2s	remaining: 1m
# 121:	total: 19.3s	remaining: 59.9s
# 122:	total: 19.5s	remaining: 59.8s
# 123:	total: 19.5s	remaining: 59.3s
# 124:	total: 19.7s	remaining: 59.2s
# 125:	total: 19.9s	remaining: 59s
# 126:	total: 20.1s	remaining: 58.9s
# 127:	total: 20.2s	remaining: 58.7s
# 128:	total: 20.4s	remaining: 58.6s
# 129:	total: 20.5s	remaining: 58.4s
# 130:	total: 20.7s	remaining: 58.2s
# 131:	total: 20.8s	remaining: 58.1s
# 132:	total: 21s	remaining: 57.9s
# 133:	total: 21.2s	remaining: 57.8s
# 134:	total: 21.3s	remaining: 57.6s
# 135:	total: 21.5s	remaining: 57.5s
# 136:	total: 21.7s	remaining: 57.4s
# 137:	total: 21.8s	remaining: 57.3s
# 138:	total: 22s	remaining: 57.2s
# 139:	total: 22.2s	remaining: 57s
# 140:	total: 22.3s	remaining: 56.9s
# 141:	total: 22.5s	remaining: 56.7s
# 142:	total: 22.7s	remaining: 56.6s
# 143:	total: 22.8s	remaining: 56.4s
# 144:	total: 23s	remaining: 56.3s
# 145:	total: 23.1s	remaining: 56s
# 146:	total: 23.3s	remaining: 55.9s
# 147:	total: 23.3s	remaining: 55.4s
# 148:	total: 23.5s	remaining: 55.3s
# 149:	total: 23.7s	remaining: 55.2s
# 150:	total: 23.8s	remaining: 55s
# 151:	total: 24s	remaining: 54.9s
# 152:	total: 24.1s	remaining: 54.7s
# 153:	total: 24.3s	remaining: 54.6s
# 154:	total: 24.4s	remaining: 54.4s
# 155:	total: 24.6s	remaining: 54.3s
# 156:	total: 24.8s	remaining: 54.1s
# 157:	total: 24.9s	remaining: 53.9s
# 158:	total: 25.1s	remaining: 53.8s
# 159:	total: 25.2s	remaining: 53.6s
# 160:	total: 25.4s	remaining: 53.4s
# 161:	total: 25.5s	remaining: 53.3s
# 162:	total: 25.7s	remaining: 53.1s
# 163:	total: 25.9s	remaining: 53s
# 164:	total: 26s	remaining: 52.9s
# 165:	total: 26.2s	remaining: 52.7s
# 166:	total: 26.3s	remaining: 52.5s
# 167:	total: 26.5s	remaining: 52.4s
# 168:	total: 26.7s	remaining: 52.3s
# 169:	total: 26.9s	remaining: 52.1s
# 170:	total: 27s	remaining: 52s
# 171:	total: 27.2s	remaining: 51.8s
# 172:	total: 27.3s	remaining: 51.6s
# 173:	total: 27.5s	remaining: 51.5s
# 174:	total: 27.6s	remaining: 51.3s
# 175:	total: 27.8s	remaining: 51.2s
# 176:	total: 28s	remaining: 51s
# 177:	total: 28.1s	remaining: 50.9s
# 178:	total: 28.3s	remaining: 50.7s
# 179:	total: 28.4s	remaining: 50.6s
# 180:	total: 28.6s	remaining: 50.4s
# 181:	total: 28.8s	remaining: 50.2s
# 182:	total: 29s	remaining: 50.2s
# 183:	total: 29.1s	remaining: 50.1s
# 184:	total: 29.3s	remaining: 49.9s
# 185:	total: 29.5s	remaining: 49.8s
# 186:	total: 29.7s	remaining: 49.7s
# 187:	total: 29.9s	remaining: 49.7s
# 188:	total: 30.1s	remaining: 49.6s
# 189:	total: 30.3s	remaining: 49.5s
# 190:	total: 30.5s	remaining: 49.4s
# 191:	total: 30.7s	remaining: 49.3s
# 192:	total: 30.9s	remaining: 49.1s
# 193:	total: 31.1s	remaining: 49.1s
# 194:	total: 31.3s	remaining: 49s
# 195:	total: 31.5s	remaining: 48.9s
# 196:	total: 31.7s	remaining: 48.8s
# 197:	total: 31.9s	remaining: 48.7s
# 198:	total: 32.1s	remaining: 48.6s
# 199:	total: 32.3s	remaining: 48.5s
# 200:	total: 32.5s	remaining: 48.4s
# 201:	total: 32.7s	remaining: 48.3s
# 202:	total: 32.9s	remaining: 48.2s
# 203:	total: 33.2s	remaining: 48.1s
# 204:	total: 33.3s	remaining: 48s
# 205:	total: 33.5s	remaining: 47.8s
# 206:	total: 33.6s	remaining: 47.6s
# 207:	total: 33.8s	remaining: 47.5s
# 208:	total: 33.9s	remaining: 47.3s
# 209:	total: 34.1s	remaining: 47.1s
# 210:	total: 34.2s	remaining: 46.9s
# 211:	total: 34.4s	remaining: 46.7s
# 212:	total: 34.5s	remaining: 46.6s
# 213:	total: 34.7s	remaining: 46.4s
# 214:	total: 34.9s	remaining: 46.2s
# 215:	total: 35s	remaining: 46s
# 216:	total: 35.2s	remaining: 45.8s
# 217:	total: 35.3s	remaining: 45.7s
# 218:	total: 35.5s	remaining: 45.5s
# 219:	total: 35.6s	remaining: 45.3s
# 220:	total: 35.8s	remaining: 45.2s
# 221:	total: 35.9s	remaining: 45s
# 222:	total: 36.1s	remaining: 44.8s
# 223:	total: 36.2s	remaining: 44.6s
# 224:	total: 36.4s	remaining: 44.5s
# 225:	total: 36.5s	remaining: 44.3s
# 226:	total: 36.7s	remaining: 44.1s
# 227:	total: 36.8s	remaining: 43.9s
# 228:	total: 37s	remaining: 43.8s
# 229:	total: 37.1s	remaining: 43.6s
# 230:	total: 37.3s	remaining: 43.4s
# 231:	total: 37.4s	remaining: 43.3s
# 232:	total: 37.6s	remaining: 43.1s
# 233:	total: 37.8s	remaining: 42.9s
# 234:	total: 37.9s	remaining: 42.7s
# 235:	total: 38s	remaining: 42.6s
# 236:	total: 38.2s	remaining: 42.4s
# 237:	total: 38.4s	remaining: 42.2s
# 238:	total: 38.5s	remaining: 42.1s
# 239:	total: 38.7s	remaining: 41.9s
# 240:	total: 38.8s	remaining: 41.7s
# 241:	total: 39s	remaining: 41.5s
# 242:	total: 39.1s	remaining: 41.4s
# 243:	total: 39.3s	remaining: 41.2s
# 244:	total: 39.4s	remaining: 41s
# 245:	total: 39.6s	remaining: 40.8s
# 246:	total: 39.7s	remaining: 40.7s
# 247:	total: 39.9s	remaining: 40.5s
# 248:	total: 40s	remaining: 40.3s
# 249:	total: 40.2s	remaining: 40.2s
# 250:	total: 40.3s	remaining: 40s
# 251:	total: 40.5s	remaining: 39.8s
# 252:	total: 40.6s	remaining: 39.7s
# 253:	total: 40.8s	remaining: 39.5s
# 254:	total: 41s	remaining: 39.4s
# 255:	total: 41.2s	remaining: 39.3s
# 256:	total: 41.4s	remaining: 39.1s
# 257:	total: 41.5s	remaining: 39s
# 258:	total: 41.7s	remaining: 38.8s
# 259:	total: 41.9s	remaining: 38.6s
# 260:	total: 42.1s	remaining: 38.5s
# 261:	total: 42.2s	remaining: 38.3s
# 262:	total: 42.4s	remaining: 38.2s
# 263:	total: 42.5s	remaining: 38s
# 264:	total: 42.7s	remaining: 37.8s
# 265:	total: 42.8s	remaining: 37.7s
# 266:	total: 43s	remaining: 37.5s
# 267:	total: 43.1s	remaining: 37.4s
# 268:	total: 43.3s	remaining: 37.2s
# 269:	total: 43.4s	remaining: 37s
# 270:	total: 43.5s	remaining: 36.8s
# 271:	total: 43.7s	remaining: 36.6s
# 272:	total: 43.9s	remaining: 36.5s
# 273:	total: 44.1s	remaining: 36.3s
# 274:	total: 44.3s	remaining: 36.2s
# 275:	total: 44.5s	remaining: 36.1s
# 276:	total: 44.7s	remaining: 36s
# 277:	total: 44.9s	remaining: 35.8s
# 278:	total: 45.1s	remaining: 35.7s
# 279:	total: 45.3s	remaining: 35.6s
# 280:	total: 45.5s	remaining: 35.5s
# 281:	total: 45.7s	remaining: 35.3s
# 282:	total: 45.9s	remaining: 35.2s
# 283:	total: 46s	remaining: 35s
# 284:	total: 46.2s	remaining: 34.8s
# 285:	total: 46.3s	remaining: 34.7s
# 286:	total: 46.5s	remaining: 34.5s
# 287:	total: 46.7s	remaining: 34.3s
# 288:	total: 46.8s	remaining: 34.2s
# 289:	total: 47s	remaining: 34s
# 290:	total: 47.2s	remaining: 33.9s
# 291:	total: 47.3s	remaining: 33.7s
# 292:	total: 47.5s	remaining: 33.6s
# 293:	total: 47.7s	remaining: 33.4s
# 294:	total: 47.9s	remaining: 33.3s
# 295:	total: 48.1s	remaining: 33.1s
# 296:	total: 48.3s	remaining: 33s
# 297:	total: 48.4s	remaining: 32.8s
# 298:	total: 48.6s	remaining: 32.7s
# 299:	total: 48.8s	remaining: 32.5s
# 300:	total: 49s	remaining: 32.4s
# 301:	total: 49.2s	remaining: 32.3s
# 302:	total: 49.4s	remaining: 32.1s
# 303:	total: 49.6s	remaining: 32s
# 304:	total: 49.7s	remaining: 31.8s
# 305:	total: 49.9s	remaining: 31.6s
# 306:	total: 50s	remaining: 31.5s
# 307:	total: 50.2s	remaining: 31.3s
# 308:	total: 50.4s	remaining: 31.2s
# 309:	total: 50.6s	remaining: 31s
# 310:	total: 50.9s	remaining: 30.9s
# 311:	total: 51.1s	remaining: 30.8s
# 312:	total: 51.3s	remaining: 30.7s
# 313:	total: 51.5s	remaining: 30.5s
# 314:	total: 51.7s	remaining: 30.4s
# 315:	total: 51.9s	remaining: 30.2s
# 316:	total: 52s	remaining: 30s
# 317:	total: 52.2s	remaining: 29.9s
# 318:	total: 52.4s	remaining: 29.7s
# 319:	total: 52.6s	remaining: 29.6s
# 320:	total: 52.8s	remaining: 29.5s
# 321:	total: 53.1s	remaining: 29.3s
# 322:	total: 53.3s	remaining: 29.2s
# 323:	total: 53.5s	remaining: 29.1s
# 324:	total: 53.7s	remaining: 28.9s
# 325:	total: 53.9s	remaining: 28.7s
# 326:	total: 54.1s	remaining: 28.6s
# 327:	total: 54.3s	remaining: 28.5s
# 328:	total: 54.5s	remaining: 28.3s
# 329:	total: 54.7s	remaining: 28.2s
# 330:	total: 54.9s	remaining: 28s
# 331:	total: 55.1s	remaining: 27.9s
# 332:	total: 55.3s	remaining: 27.7s
# 333:	total: 55.4s	remaining: 27.5s
# 334:	total: 55.6s	remaining: 27.4s
# 335:	total: 55.8s	remaining: 27.2s
# 336:	total: 55.9s	remaining: 27.1s
# 337:	total: 56.1s	remaining: 26.9s
# 338:	total: 56.2s	remaining: 26.7s
# 339:	total: 56.4s	remaining: 26.5s
# 340:	total: 56.6s	remaining: 26.4s
# 341:	total: 56.7s	remaining: 26.2s
# 342:	total: 56.9s	remaining: 26s
# 343:	total: 57s	remaining: 25.9s
# 344:	total: 57.2s	remaining: 25.7s
# 345:	total: 57.4s	remaining: 25.5s
# 346:	total: 57.5s	remaining: 25.4s
# 347:	total: 57.7s	remaining: 25.2s
# 348:	total: 57.9s	remaining: 25s
# 349:	total: 58s	remaining: 24.9s
# 350:	total: 58.2s	remaining: 24.7s
# 351:	total: 58.3s	remaining: 24.5s
# 352:	total: 58.5s	remaining: 24.4s
# 353:	total: 58.6s	remaining: 24.2s
# 354:	total: 58.8s	remaining: 24s
# 355:	total: 59s	remaining: 23.8s
# 356:	total: 59.1s	remaining: 23.7s
# 357:	total: 59.3s	remaining: 23.5s
# 358:	total: 59.4s	remaining: 23.3s
# 359:	total: 59.6s	remaining: 23.2s
# 360:	total: 59.7s	remaining: 23s
# 361:	total: 59.9s	remaining: 22.8s
# 362:	total: 1m	remaining: 22.7s
# 363:	total: 1m	remaining: 22.5s
# 364:	total: 1m	remaining: 22.3s
# 365:	total: 1m	remaining: 22.1s
# 366:	total: 1m	remaining: 22s
# 367:	total: 1m	remaining: 21.8s
# 368:	total: 1m	remaining: 21.6s
# 369:	total: 1m 1s	remaining: 21.5s
# 370:	total: 1m 1s	remaining: 21.3s
# 371:	total: 1m 1s	remaining: 21.1s
# 372:	total: 1m 1s	remaining: 21s
# 373:	total: 1m 1s	remaining: 20.8s
# 374:	total: 1m 1s	remaining: 20.6s
# 375:	total: 1m 2s	remaining: 20.5s
# 376:	total: 1m 2s	remaining: 20.3s
# 377:	total: 1m 2s	remaining: 20.1s
# 378:	total: 1m 2s	remaining: 20s
# 379:	total: 1m 2s	remaining: 19.8s
# 380:	total: 1m 2s	remaining: 19.6s
# 381:	total: 1m 3s	remaining: 19.5s
# 382:	total: 1m 3s	remaining: 19.3s
# 383:	total: 1m 3s	remaining: 19.2s
# 384:	total: 1m 3s	remaining: 19s
# 385:	total: 1m 3s	remaining: 18.9s
# 386:	total: 1m 4s	remaining: 18.7s
# 387:	total: 1m 4s	remaining: 18.5s
# 388:	total: 1m 4s	remaining: 18.4s
# 389:	total: 1m 4s	remaining: 18.2s
# 390:	total: 1m 4s	remaining: 18s
# 391:	total: 1m 4s	remaining: 17.9s
# 392:	total: 1m 5s	remaining: 17.7s
# 393:	total: 1m 5s	remaining: 17.5s
# 394:	total: 1m 5s	remaining: 17.4s
# 395:	total: 1m 5s	remaining: 17.2s
# 396:	total: 1m 5s	remaining: 17s
# 397:	total: 1m 5s	remaining: 16.9s
# 398:	total: 1m 6s	remaining: 16.7s
# 399:	total: 1m 6s	remaining: 16.6s
# 400:	total: 1m 6s	remaining: 16.4s
# 401:	total: 1m 6s	remaining: 16.2s
# 402:	total: 1m 6s	remaining: 16.1s
# 403:	total: 1m 6s	remaining: 15.9s
# 404:	total: 1m 7s	remaining: 15.8s
# 405:	total: 1m 7s	remaining: 15.6s
# 406:	total: 1m 7s	remaining: 15.4s
# 407:	total: 1m 7s	remaining: 15.3s
# 408:	total: 1m 7s	remaining: 15.1s
# 409:	total: 1m 8s	remaining: 14.9s
# 410:	total: 1m 8s	remaining: 14.8s
# 411:	total: 1m 8s	remaining: 14.6s
# 412:	total: 1m 8s	remaining: 14.5s
# 413:	total: 1m 8s	remaining: 14.3s
# 414:	total: 1m 8s	remaining: 14.1s
# 415:	total: 1m 9s	remaining: 14s
# 416:	total: 1m 9s	remaining: 13.8s
# 417:	total: 1m 9s	remaining: 13.6s
# 418:	total: 1m 9s	remaining: 13.5s
# 419:	total: 1m 9s	remaining: 13.3s
# 420:	total: 1m 10s	remaining: 13.1s
# 421:	total: 1m 10s	remaining: 13s
# 422:	total: 1m 10s	remaining: 12.8s
# 423:	total: 1m 10s	remaining: 12.7s
# 424:	total: 1m 10s	remaining: 12.5s
# 425:	total: 1m 10s	remaining: 12.3s
# 426:	total: 1m 11s	remaining: 12.2s
# 427:	total: 1m 11s	remaining: 12s
# 428:	total: 1m 11s	remaining: 11.8s
# 429:	total: 1m 11s	remaining: 11.7s
# 430:	total: 1m 11s	remaining: 11.5s
# 431:	total: 1m 12s	remaining: 11.3s
# 432:	total: 1m 12s	remaining: 11.2s
# 433:	total: 1m 12s	remaining: 11s
# 434:	total: 1m 12s	remaining: 10.9s
# 435:	total: 1m 12s	remaining: 10.7s
# 436:	total: 1m 13s	remaining: 10.5s
# 437:	total: 1m 13s	remaining: 10.4s
# 438:	total: 1m 13s	remaining: 10.2s
# 439:	total: 1m 13s	remaining: 10s
# 440:	total: 1m 13s	remaining: 9.88s
# 441:	total: 1m 14s	remaining: 9.72s
# 442:	total: 1m 14s	remaining: 9.56s
# 443:	total: 1m 14s	remaining: 9.4s
# 444:	total: 1m 14s	remaining: 9.23s
# 445:	total: 1m 14s	remaining: 9.06s
# 446:	total: 1m 14s	remaining: 8.89s
# 447:	total: 1m 15s	remaining: 8.72s
# 448:	total: 1m 15s	remaining: 8.55s
# 449:	total: 1m 15s	remaining: 8.38s
# 450:	total: 1m 15s	remaining: 8.22s
# 451:	total: 1m 15s	remaining: 8.05s
# 452:	total: 1m 15s	remaining: 7.88s
# 453:	total: 1m 16s	remaining: 7.71s
# 454:	total: 1m 16s	remaining: 7.54s
# 455:	total: 1m 16s	remaining: 7.38s
# 456:	total: 1m 16s	remaining: 7.21s
# 457:	total: 1m 16s	remaining: 7.04s
# 458:	total: 1m 16s	remaining: 6.88s
# 459:	total: 1m 17s	remaining: 6.71s
# 460:	total: 1m 17s	remaining: 6.54s
# 461:	total: 1m 17s	remaining: 6.37s
# 462:	total: 1m 17s	remaining: 6.2s
# 463:	total: 1m 17s	remaining: 6.04s
# 464:	total: 1m 17s	remaining: 5.87s
# 465:	total: 1m 18s	remaining: 5.7s
# 466:	total: 1m 18s	remaining: 5.54s
# 467:	total: 1m 18s	remaining: 5.37s
# 468:	total: 1m 18s	remaining: 5.2s
# 469:	total: 1m 18s	remaining: 5.03s
# 470:	total: 1m 19s	remaining: 4.87s
# 471:	total: 1m 19s	remaining: 4.7s
# 472:	total: 1m 19s	remaining: 4.54s
# 473:	total: 1m 19s	remaining: 4.37s
# 474:	total: 1m 19s	remaining: 4.2s
# 475:	total: 1m 19s	remaining: 4.03s
# 476:	total: 1m 20s	remaining: 3.86s
# 477:	total: 1m 20s	remaining: 3.69s
# 478:	total: 1m 20s	remaining: 3.53s
# 479:	total: 1m 20s	remaining: 3.36s
# 480:	total: 1m 20s	remaining: 3.19s
# 481:	total: 1m 20s	remaining: 3.02s
# 482:	total: 1m 21s	remaining: 2.85s
# 483:	total: 1m 21s	remaining: 2.69s
# 484:	total: 1m 21s	remaining: 2.52s
# 485:	total: 1m 21s	remaining: 2.35s
# 486:	total: 1m 21s	remaining: 2.18s
# 487:	total: 1m 21s	remaining: 2.01s
# 488:	total: 1m 22s	remaining: 1.85s
# 489:	total: 1m 22s	remaining: 1.68s
# 490:	total: 1m 22s	remaining: 1.51s
# 491:	total: 1m 22s	remaining: 1.34s
# 492:	total: 1m 22s	remaining: 1.17s
# 493:	total: 1m 22s	remaining: 1.01s
# 494:	total: 1m 23s	remaining: 839ms
# 495:	total: 1m 23s	remaining: 671ms
# 496:	total: 1m 23s	remaining: 503ms
# 497:	total: 1m 23s	remaining: 335ms
# 498:	total: 1m 23s	remaining: 168ms
# 499:	total: 1m 23s	remaining: 0us
# Score Train --> 80.78  %

# %%
from catboost import CatBoostRegressor,Pool
X_train = simanim.iloc[:bloc1,:-1]
X_validation = simanim.iloc[bloc1:,:-1]
y_train = simanim.iloc[:bloc1,-1]
y_validation = simanim.iloc[bloc1:,-1]

# %%
X_train.shape,X_test.shape,y_train.shape,y_validation.shape
# Out:
# ((4397, 7), (1099, 7), (4397,), (1099,))

# %%
categorical_features_indices = np.where(X.dtypes != np.float)[0]

# %%
model=CatBoostRegressor(iterations=50, depth=3, learning_rate=0.1, loss_function='RMSE')
model.fit(X_train, y_train,cat_features=categorical_features_indices,eval_set=(X_validation, y_validation),plot=True)
# Out:
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
#     padding: 0 0 0 20px;
# }
#
# .catboost-graph__tab {
#     display: inline-block;
#     padding: 5px 10px 0 0;
# }
#
# .catboost-graph__tab {
#     color: #999;
#     cursor: pointer;
#     transition: color 0.1s linear;
# }
#
# .catboost-graph__tab:hover {
#     color: #333;
# }
#
# .catboost-graph__tab_active {
#     color: #000;
#     cursor: auto;
# }
#
# .catboost-graph__charts {
#     padding-top: 20px;
# }
#
# .catboost-graph__chart {
#     display: none;
# }
#
# .catboost-graph__chart_active {
#     display: block;
# }
#
# .catboost-panel__serie {
#     padding-bottom: 5px;
#     border-bottom: 1px solid rgba(0, 0, 0, 0.3);
#     position: relative;
# }
#
# .catboost-panel__serie_bottom,
# .catboost-panel__serie_middle,
# .catboost-panel__serie_top {
#     white-space: nowrap;
#     position: relative;
# }
#
# #catboost-control-test {
#     margin-left: 11px;
# }
#
# .catboost-panel__serie_label {
#     padding: 0 0 0 8px;
#     width: 200px;
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     cursor: pointer;
#     margin-bottom: 0;
#     overflow: hidden;
#     position: relative;
#     top: 5px;
# }
#
# .catboost-panel__serie_hint {
#     position: absolute;
#     font-size: 9px;
#     left: 0;
# }
#
# .catboost-panel__serie__learn_hint {
#     top: 56px;
# }
#
# .catboost-panel__serie__test_hint {
#     top: 82px;
# }
#
# .catboost-panel__serie_bottom {
#     padding-bottom: 6px;
# }
#
# .catboost-panel__serie_time {
#     position: absolute;
#     top: 5px;
#     right: 2px;
#     height: 20px;
#     padding: 0 0 0 20px;
#     margin-bottom: 3px;
#     overflow: hidden;
#
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     text-align: left;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_test_pic {
#     width: 13px;
#     height: 1px;
#     border-top-width: 1px;
#     position: relative;
#     top: -3px;
#     margin-right: 5px;
# }
#
# .catboost-panel__serie_learn_pic {
#     border-top-style: dashed;
# }
#
# .catboost-panel__serie_test_pic {
#     border-top-style: solid;
# }
#
# .catboost-panel__serie-value {
#     display: inline-block;
#     min-width: 30px;
#     margin-right: 2px;
# }
#
# .catboost-panel__controls_label .catboost-panel__serie_learn_pic {
#     padding-left: 4px;
# }
#
# .catboost-panel__serie_names {
#     white-space: nowrap;
# }
#
# .catboost-panel__serie_scroll {
#     width: 240px;
#     overflow-x: auto;
#     margin-left: 20px;
# }
#
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_learn_value,
# .catboost-panel__serie_best_test_value {
#     width: 85px;
#     position: relative;
#     padding: 0 8px 0 0;
#     box-sizing: content-box;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     top: 5px;
# }
#
# .catboost-panel__serie_iteration,
# .catboost-panel__serie_best_iteration {
#     display: inline-block;
#     position: absolute;
#     box-sizing: content-box;
#     overflow: hidden;
#     right: 2px;
# }
#
# .catboost-panel__serie_iteration {
#     top: 55px;
# }
#
# .catboost-panel__serie_best_iteration {
#     top: 80px;
# }
#
# .catboost-panel__control_slider {
#     width: 100px !important;
#     margin-left: 0;
#     position: relative;
#     display: inline-block !important;
#     top: 3px;
# }
#
# .catboost-panel__control_slidervalue {
#     width: 50px;
#     padding: 2px 3px;
#     margin-left: 4px;
# }
#
# .catboost-panel__serie_time_spend,
# .catboost-panel__serie_time_left {
#     display: inline-block;
# }
#
# .catboost-panel__serie_time_left {
#     margin-left: 10px;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_best_learn_value {
#     display: inline-block;
# }
# .catboost-panel__serie_test_pic,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_test_value {
#     display: inline-block;
# }
#
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_pic,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_name,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_learn_value {
#     display: none;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_pic,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_name,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_test_value {
#     display: none;
# }
#
# /*
# .catboost-panel__series_learn_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_test_value {
#     width: 216px;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_learn_value {
#     width: 216px;
# }
# */
# .catboost-panel__series_test_disabled .catboost-panel__serie__test_hint,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_iteration {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled.catboost-panel__series_learn_disabled .catboost-panel__serie_middle {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled .catboost-panel__serie_bottom {
#     display: none;
# }
#
#             </style>
#             <script>
#                 window.__define = window.define;window.__require = window.require;window.define = undefined;window.require = undefined;/**
# * plotly.js (basic - minified) v1.27.1
# * Copyright 2012-2017, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# !function(t){if("object"==typeof exports&&"undefined"!=typeof module)module.exports=t();else if("function"==typeof define&&define.amd)define([],t);else{var e;e="undefined"!=typeof window?window:"undefined"!=typeof global?global:"undefined"!=typeof self?self:this,e.Plotly=t()}}(function(){var t;return function t(e,r,n){function a(i,l){if(!r[i]){if(!e[i]){var s="function"==typeof require&&require;if(!l&&s)return s(i,!0);if(o)return o(i,!0);var c=new Error("Cannot find module '"+i+"'");throw c.code="MODULE_NOT_FOUND",c}var u=r[i]={exports:{}};e[i][0].call(u.exports,function(t){var r=e[i][1][t];return a(r||t)},u,u.exports,t,e,r,n)}return r[i].exports}for(var o="function"==typeof require&&require,i=0;i<n.length;i++)a(n[i]);return a}({1:[function(t,e,r){"use strict";var n=t("../src/lib"),a={"X,X div":"font-family:'Open Sans', verdana, arial, sans-serif;margin:0;padding:0;","X input,X button":"font-family:'Open Sans', verdana, arial, sans-serif;","X input:focus,X button:focus":"outline:none;","X a":"text-decoration:none;","X a:hover":"text-decoration:none;","X .crisp":"shape-rendering:crispEdges;","X .user-select-none":"-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-o-user-select:none;user-select:none;","X svg":"overflow:hidden;","X svg a":"fill:#447adb;","X svg a:hover":"fill:#3c6dc5;","X .main-svg":"position:absolute;top:0;left:0;pointer-events:none;","X .main-svg .draglayer":"pointer-events:all;","X .cursor-default":"cursor:default;","X .cursor-pointer":"cursor:pointer;","X .cursor-crosshair":"cursor:crosshair;","X .cursor-move":"cursor:move;","X .cursor-col-resize":"cursor:col-resize;","X .cursor-row-resize":"cursor:row-resize;","X .cursor-ns-resize":"cursor:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# 0:	learn: 0.8725100	test: 0.6568791	best: 0.6568791 (0)	total: 24.1ms	remaining: 1.18s
# 1:	learn: 0.8448731	test: 0.6364351	best: 0.6364351 (1)	total: 35ms	remaining: 840ms
# 2:	learn: 0.8212601	test: 0.6201945	best: 0.6201945 (2)	total: 45.2ms	remaining: 708ms
# 3:	learn: 0.8025438	test: 0.6108367	best: 0.6108367 (3)	total: 55.4ms	remaining: 637ms
# 4:	learn: 0.7875115	test: 0.6043916	best: 0.6043916 (4)	total: 63.9ms	remaining: 575ms
# 5:	learn: 0.7739594	test: 0.5985442	best: 0.5985442 (5)	total: 68.4ms	remaining: 501ms
# 6:	learn: 0.7633528	test: 0.5971295	best: 0.5971295 (6)	total: 73.3ms	remaining: 450ms

# %%
___Author___='LumberJack Jyss'

# %%
print('LumberJack BRUTAL AtidotCom TREND RULES\nLumberJack Jyss (c)')
# Out:
# LumberJack BRUTAL AtidotCom TREND RULES
# LumberJack Jyss (c)

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df =  pd.read_csv('simanim.csv')
#df =  pd.read_csv('dataset_daily.csv')

# %%
df.set_index(df['Date'],drop=True,inplace=True)
df = df.iloc[:,1:]
df.head()
# Out:
#             CDL2CROWS  CDL3BLACKCROWS  CDL3INSIDE  CDL3LINESTRIKE  \
# Date
# 1997-07-23          0               0           0               0
# 1997-07-24          0               0           0               0
# 1997-07-25          0               0           0               0
# 1997-07-28          0               0           0               0
# 1997-07-29          0               0           0               0
#
#             CDL3OUTSIDE  CDL3STARSINSOUTH  CDL3WHITESOLDIERS  \
# Date
# 1997-07-23            0                 0                  0
# 1997-07-24            0                 0                  0
# 1997-07-25            0                 0                  0
# 1997-07-28            0                 0                  0
# 1997-07-29            0                 0                  0
#
#             CDLABANDONEDBABY  CDLADVANCEBLOCK  CDLBELTHOLD  ...      ema54  \
# Date                                                        ...
# 1997-07-23                 0                0            0  ...  87.978550
# 1997-07-24                 0                0            0  ...  88.200919
# 1997-07-25                 0                0            0  ...  88.412929
# 1997-07-28                 0                0            0  ...  88.614957
# 1997-07-29                 0                0            0  ...  88.821002
#
#                ema100        rsi     atr14   wclprice       BBup      BBmid  \
# Date
# 1997-07-23  83.389660  63.703248  1.431460  93.831972  94.545308  92.600654
# 1997-07-24  83.601621  65.108794  1.441934  93.785124  94.909401  92.857598
# 1997-07-25  83.808147  64.723205  1.423760  94.124973  95.161930  93.076342
# 1997-07-28  84.009346  64.313032  1.397956  93.999973  95.350174  93.236064
# 1997-07-29  84.212749  65.490636  1.372881  94.113222  95.491356  93.295086
#
#                 BBlow  instant_trendline  Adj Close
# Date
# 1997-07-23  90.656000          91.147376  63.306343
# 1997-07-24  90.805796          91.350157  63.602062
# 1997-07-25  90.990754          91.582293  63.559814
# 1997-07-28  91.121955          91.768264  63.517551
# 1997-07-29  91.098816          91.921526  63.728779
#
# [5 rows x 72 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5477 entries, 1997-07-23 to 2019-04-29
# Data columns (total 72 columns):
# CDL2CROWS              5477 non-null int64
# CDL3BLACKCROWS         5477 non-null int64
# CDL3INSIDE             5477 non-null int64
# CDL3LINESTRIKE         5477 non-null int64
# CDL3OUTSIDE            5477 non-null int64
# CDL3STARSINSOUTH       5477 non-null int64
# CDL3WHITESOLDIERS      5477 non-null int64
# CDLABANDONEDBABY       5477 non-null int64
# CDLADVANCEBLOCK        5477 non-null int64
# CDLBELTHOLD            5477 non-null int64
# CDLBREAKAWAY           5477 non-null int64
# CDLCLOSINGMARUBOZU     5477 non-null int64
# CDLCONCEALBABYSWALL    5477 non-null int64
# CDLCOUNTERATTACK       5477 non-null int64
# CDLDARKCLOUDCOVER      5477 non-null int64
# CDLDOJI                5477 non-null int64
# CDLDOJISTAR            5477 non-null int64
# CDLDRAGONFLYDOJI       5477 non-null int64
# CDLENGULFING           5477 non-null int64
# CDLEVENINGDOJISTAR     5477 non-null int64
# CDLEVENINGSTAR         5477 non-null int64
# CDLGAPSIDESIDEWHITE    5477 non-null int64
# CDLGRAVESTONEDOJI      5477 non-null int64
# CDLHAMMER              5477 non-null int64
# CDLHANGINGMAN          5477 non-null int64
# CDLHARAMI              5477 non-null int64
# CDLHARAMICROSS         5477 non-null int64
# CDLHIGHWAVE            5477 non-null int64
# CDLHIKKAKE             5477 non-null int64
# CDLHIKKAKEMOD          5477 non-null int64
# CDLHOMINGPIGEON        5477 non-null int64
# CDLIDENTICAL3CROWS     5477 non-null int64
# CDLINNECK              5477 non-null int64
# CDLINVERTEDHAMMER      5477 non-null int64
# CDLKICKING             5477 non-null int64
# CDLKICKINGBYLENGTH     5477 non-null int64
# CDLLADDERBOTTOM        5477 non-null int64
# CDLLONGLEGGEDDOJI      5477 non-null int64
# CDLLONGLINE            5477 non-null int64
# CDLMARUBOZU            5477 non-null int64
# CDLMATCHINGLOW         5477 non-null int64
# CDLMATHOLD             5477 non-null int64
# CDLMORNINGDOJISTAR     5477 non-null int64
# CDLMORNINGSTAR         5477 non-null int64
# CDLONNECK              5477 non-null int64
# CDLPIERCING            5477 non-null int64
# CDLRICKSHAWMAN         5477 non-null int64
# CDLRISEFALL3METHODS    5477 non-null int64
# CDLSEPARATINGLINES     5477 non-null int64
# CDLSHOOTINGSTAR        5477 non-null int64
# CDLSHORTLINE           5477 non-null int64
# CDLSPINNINGTOP         5477 non-null int64
# CDLSTALLEDPATTERN      5477 non-null int64
# CDLSTICKSANDWICH       5477 non-null int64
# CDLTAKURI              5477 non-null int64
# CDLTASUKIGAP           5477 non-null int64
# CDLTHRUSTING           5477 non-null int64
# CDLTRISTAR             5477 non-null int64
# CDLUNIQUE3RIVER        5477 non-null int64
# CDLUPSIDEGAP2CROWS     5477 non-null int64
# CDLXSIDEGAP3METHODS    5477 non-null int64
# ema9                   5477 non-null float64
# ema54                  5477 non-null float64
# ema100                 5477 non-null float64
# rsi                    5477 non-null float64
# atr14                  5477 non-null float64
# wclprice               5477 non-null float64
# BBup                   5477 non-null float64
# BBmid                  5477 non-null float64
# BBlow                  5477 non-null float64
# instant_trendline      5477 non-null float64
# Adj Close              5477 non-null float64
# dtypes: float64(11), int64(61)
# memory usage: 3.1+ MB

# %%
df.shape
# Out:
# (5477, 72)

# %%
df.shape[0]
# Out:
# 5477

# %%
df.tail()
# Out:
#             CDL2CROWS  CDL3BLACKCROWS  CDL3INSIDE  CDL3LINESTRIKE  \
# Date
# 2019-04-23          0               0           0               0
# 2019-04-24          0               0           0               0
# 2019-04-25          0               0           0               0
# 2019-04-26          0               0           0               0
# 2019-04-29          0               0           0               0
#
#             CDL3OUTSIDE  CDL3STARSINSOUTH  CDL3WHITESOLDIERS  \
# Date
# 2019-04-23            1                 0                  0
# 2019-04-24            0                 0                  0
# 2019-04-25            0                 0                  0
# 2019-04-26            0                 0                  0
# 2019-04-29            0                 0                  0
#
#             CDLABANDONEDBABY  CDLADVANCEBLOCK  CDLBELTHOLD  ...       ema54  \
# Date                                                        ...
# 2019-04-23                 0                0            0  ...  281.450595
# 2019-04-24                 0                0            0  ...  281.842574
# 2019-04-25                 0                0            0  ...  282.213753
# 2019-04-26                 0                0            0  ...  282.620889
# 2019-04-29                 0                0            0  ...  283.029947
#
#                 ema100        rsi     atr14    wclprice        BBup  \
# Date
# 2019-04-23  277.605448  73.324726  2.137286  292.330009  292.500188
# 2019-04-24  277.895044  70.186689  2.062479  292.422508  293.009767
# 2019-04-25  278.175340  69.302067  2.061587  291.902496  293.123032
# 2019-04-26  278.477016  72.157138  2.075045  292.887497  293.940074
# 2019-04-29  278.781828  73.069451  2.001114  293.900002  294.693713
#
#                  BBmid       BBlow  instant_trendline   Adj Close
# Date
# 2019-04-23  289.934445  287.368702         287.637045  292.880005
# 2019-04-24  290.372223  287.734678         288.078220  292.230011
# 2019-04-25  290.798889  288.474746         288.418317  292.049988
# 2019-04-26  291.160000  288.379926         288.723677  293.410004
# 2019-04-29  291.593333  288.492952         288.987352  293.869995
#
# [5 rows x 72 columns]

# %%
long_list = []
short_list = []
equity_list = []
var_long_list = []
var_short_list = []
candle_close = 0
candle_close_1 = 0
candle_close_2 = 0
candle_close_3 = 0
candle_close_4 = 0
candle_close_5 = 0
candle_open = 0
candle_high = 0
candle_low = 0
n=0
c = 0
cc = 0
long_target = 0.03
short_target = -0.02
ticket = 100000
equity = 100000
print('Début de la boucle')

import sys
orig_stdout = sys.stdout
f = open('OUt_rules.txt', 'w')
sys.stdout = f


for i in range(5,df.shape[0]-1):
    print('\nCompteur de ligne :',i)
    print('Date :',df.index[i])
    c+=1
    
    candle_close = float(df.iloc[i,-3])
    candle_close_1 = float(df.iloc[i-1,-3])
    print('candle_close_1',candle_close_1)
    candle_close_2 = float(df.iloc[i-2,-3])
    candle_close_3 = float(df.iloc[i-3,-3])
    candle_close_4 = float(df.iloc[i-4,-3])
    candle_close_5 = float(df.iloc[i-5,-3])
    candle_open = float(df.iloc[i,-3])
    #candle_high = float(df.iloc[i,7])
    #candle_low = float(df.iloc[i,8])
    
    var1 = candle_open - candle_close_1
    var2 = candle_open - candle_close_2
    var3 = candle_open - candle_close_3
    var4 = candle_open - candle_close_4
    var5 = candle_open - candle_close_5
    
    if var1/candle_close_1 > long_target or var2/candle_close_2 > long_target or\
    var3/candle_close_3 > long_target or var4/candle_close_4 > long_target or var5/candle_close_5 > long_target:
        var_long_list.append(var1)
        var_long_list.append(var2)
        var_long_list.append(var3)
        var_long_list.append(var4)
        var_long_list.append(var5)
        print('\nDate :',df.index[i])
        print('Long effectué, :',var1,', ',var2,', ',var3,', ',var4)
        print('close actuel',candle_open)
        n = round(ticket/candle_open)
        print('n ',n)
        print("les 4 close d'avant",\
              candle_close_1,candle_close_2,candle_close_3,\
              candle_close_4,candle_close_5)
        print('Max ',max(var_long_list))
        print('pnl :',max(var_long_list)*ticket)
        equity = equity -(n/100) + max(var_long_list)*n
        #equity = equity - 3 + max(var_long_list)*ticket
        print('Nouvel equity :',equity)
        long_list.append(1)
        short_list.append(0)
        equity_list.append(equity)
        cc+=1
        var_long_list = []
    
    elif var1/candle_close_1 < short_target or var2/candle_close_2 < short_target or \
    var3/candle_close_3 < short_target or var4/candle_close_4 < short_target or var5/candle_close_5 < short_target:
        var_short_list.append(var1)
        var_short_list.append(var2)
        var_short_list.append(var3)
        var_short_list.append(var4)
        var_short_list.append(var5)
        print('\nDate :',df.index[i])
        print('Short effectué :',var1,', ',var2,', ',var3,', ',var4)
        print('close actuel',candle_open)
        n = round(ticket/candle_open)
        print('n ',n)
        print("les 4 close d'avant",\
              candle_close_1,candle_close_2,candle_close_3,\
              candle_close_4,candle_close_5)
        print('Min ',-min(var_short_list))
        print('pnl :', - min(var_short_list)*ticket)
        equity = equity -n/100 - min(var_short_list)*n
        #equity = equity - 3 - min(var_short_list)*ticket
        print('Nouvel equity :',equity)
        short_list.append(1)
        long_list.append(0)
        equity_list.append(equity)
        cc+=1
        var_short_list = []
    
    else :
        print('\nDate :',df.index[i])
        print('Il ne se passe rien')
        short_list.append(0)
        long_list.append(0)
        equity_list.append(equity)
        cc+=1


print('Boucle terminée')
print('La long target était fixée à ',long_target)
print('La short target était fixée à ',short_target)
print('La règle était 4 périodes consécutives au dessus de long ou au dessous de short')
print('Il y a eu ',df.shape[0],' périodes testées')
print('Durant cette période,',sum(long_list),' long et ',sum(short_list),' short')
print("Les gains totaux s'élèvent à :",round(equity-100000),'$' )
    
f.close()
sys.stdout = orig_stdout


print('Boucle terminée')
print('La long target était fixée à ',long_target)
print('La short target était fixée à ',short_target)
print("La règle était qu'une des 5 periodes d'avant était inférieure ou supérieure à la target (long ou short)")
print('Il y a eu ',df.shape[0],' périodes testées')
print('Durant cette période,',sum(long_list),' long et ',sum(short_list),' short')
print("Les gains totaux s'élèvent à :",round(equity-100000),'$' )

var_dtf = pd.DataFrame()
var_dtf['Long'] = long_list
var_dtf['Short'] = short_list
var_dtf['Equity'] = equity_list
# Out:
# Début de la boucle
# Boucle terminée
# La long target était fixée à  0.03
# La short target était fixée à  -0.02
# La règle était qu'une des 5 periodes d'avant était inférieure ou supérieure à la target (long ou short)
# Il y a eu  5471  périodes testées
# Durant cette période, 748  long et  1084  short
# Les gains totaux s'élèvent à : 7508078 $

# %%
candle_close,candle_close_1,candle_close_2,candle_close_3,candle_close_4,candle_close_5,candle_open
# Out:
# (292.04998779296875,
#  292.2300109863281,
#  292.8800048828125,
#  290.2699890136719,
#  290.0199890136719,
#  289.45001220703125,
#  292.04998779296875)

# %%
sum(short_list)+sum(long_list), c, cc, len(short_list),len(long_list),len(equity_list),len(df)
# Out:
# (1832, 5465, 5465, 5465, 5465, 5465, 5471)

# %%
plt.figure(figsize=(16,6))
plt.plot(var_dtf['Long'],color='orange',label='Long')
plt.plot(var_dtf['Short'],color='purple',label='Short')
plt.axhline(y=long_target, color='cyan',linestyle='-', label='Long Target')
plt.axhline(y=0, color='red',linestyle='--', label='Zéro')
plt.axhline(y=short_target,color='cyan',label='Short Target')
plt.legend()

# %%
plt.figure(figsize=(16,6))
plt.plot(var_dtf['Equity'],color='green',label='Equity')
plt.axhline(y=100000., color='red',linestyle='-', label='mise de départ')
plt.legend()

# %%
len(short_list),len(long_list),len(df)
# Out:
# (5465, 5465, 5471)

# %%
df = df.iloc[5:(df.shape[0]-1),:]
df['short'] = short_list
df['long'] = long_list

# %%
print('Nombre de positions de long trouvées :',sum(long_list))
print('Nombre de positions short trouvées :',sum(short_list))
print('Sur un total de ',sum(short_list)+sum(long_list))
# Out:
# Nombre de positions de long trouvées : 748
# Nombre de positions short trouvées : 1084
# Sur un total de  1832

# %%
print('Sur un achat systématique, les gains représentent',\
      round((sum(short_list)+sum(long_list))/(len(short_list)+len(long_list))*100,2),'%')
# Out:
# Sur un achat systématique, les gains représentent 16.76 %

# %%
#df['short'] = df['trend'].shift(-1)

# %%
df.tail()
# Out:
#             CDL2CROWS  CDL3BLACKCROWS  CDL3INSIDE  CDL3LINESTRIKE  \
# Date
# 2019-04-18          0               0           0               0
# 2019-04-22          0               0           0               0
# 2019-04-23          0               0           0               0
# 2019-04-24          0               0           0               0
# 2019-04-25          0               0           0               0
#
#             CDL3OUTSIDE  CDL3STARSINSOUTH  CDL3WHITESOLDIERS  \
# Date
# 2019-04-18            0                 0                  0
# 2019-04-22            0                 0                  0
# 2019-04-23            1                 0                  0
# 2019-04-24            0                 0                  0
# 2019-04-25            0                 0                  0
#
#             CDLABANDONEDBABY  CDLADVANCEBLOCK  CDLBELTHOLD  ...        rsi  \
# Date                                                        ...
# 2019-04-18                 0                0            0  ...  67.408213
# 2019-04-22                 0                0            1  ...  67.988142
# 2019-04-23                 0                0            0  ...  73.324726
# 2019-04-24                 0                0            0  ...  70.186689
# 2019-04-25                 0                0            0  ...  69.302067
#
#                atr14    wclprice        BBup       BBmid       BBlow  \
# Date
# 2019-04-18  2.135607  289.754997  291.117259  289.151113  287.184966
# 2019-04-22  2.080921  290.012497  291.378564  289.315555  287.252546
# 2019-04-23  2.137286  292.330009  292.500188  289.934445  287.368702
# 2019-04-24  2.062479  292.422508  293.009767  290.372223  287.734678
# 2019-04-25  2.061587  291.902496  293.123032  290.798889  288.474746
#
#             instant_trendline   Adj Close  short  long
# Date
# 2019-04-18         286.855439  290.019989      0     0
# 2019-04-22         287.289383  290.269989      0     0
# 2019-04-23         287.637045  292.880005      0     0
# 2019-04-24         288.078220  292.230011      0     0
# 2019-04-25         288.418317  292.049988      0     0
#
# [5 rows x 74 columns]

# %%
df = df.dropna()
df.tail()
# Out:
#             CDL2CROWS  CDL3BLACKCROWS  CDL3INSIDE  CDL3LINESTRIKE  \
# Date
# 2019-04-18          0               0           0               0
# 2019-04-22          0               0           0               0
# 2019-04-23          0               0           0               0
# 2019-04-24          0               0           0               0
# 2019-04-25          0               0           0               0
#
#             CDL3OUTSIDE  CDL3STARSINSOUTH  CDL3WHITESOLDIERS  \
# Date
# 2019-04-18            0                 0                  0
# 2019-04-22            0                 0                  0
# 2019-04-23            1                 0                  0
# 2019-04-24            0                 0                  0
# 2019-04-25            0                 0                  0
#
#             CDLABANDONEDBABY  CDLADVANCEBLOCK  CDLBELTHOLD  ...        rsi  \
# Date                                                        ...
# 2019-04-18                 0                0            0  ...  67.408213
# 2019-04-22                 0                0            1  ...  67.988142
# 2019-04-23                 0                0            0  ...  73.324726
# 2019-04-24                 0                0            0  ...  70.186689
# 2019-04-25                 0                0            0  ...  69.302067
#
#                atr14    wclprice        BBup       BBmid       BBlow  \
# Date
# 2019-04-18  2.135607  289.754997  291.117259  289.151113  287.184966
# 2019-04-22  2.080921  290.012497  291.378564  289.315555  287.252546
# 2019-04-23  2.137286  292.330009  292.500188  289.934445  287.368702
# 2019-04-24  2.062479  292.422508  293.009767  290.372223  287.734678
# 2019-04-25  2.061587  291.902496  293.123032  290.798889  288.474746
#
#             instant_trendline   Adj Close  short  long
# Date
# 2019-04-18         286.855439  290.019989      0     0
# 2019-04-22         287.289383  290.269989      0     0
# 2019-04-23         287.637045  292.880005      0     0
# 2019-04-24         288.078220  292.230011      0     0
# 2019-04-25         288.418317  292.049988      0     0
#
# [5 rows x 74 columns]

# %%
df['short'].sum(),df['long'].sum()
# Out:
# (1084, 748)

# %%
df.to_csv('dataset_ready_to_use.csv')

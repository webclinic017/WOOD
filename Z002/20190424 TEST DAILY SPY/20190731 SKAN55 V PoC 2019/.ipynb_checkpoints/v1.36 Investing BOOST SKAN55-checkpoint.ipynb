# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
print('Importing Librairies...')
import talib
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import xgboost as xgb
from xgboost import XGBRegressor, plot_importance
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')
import time
import datetime as dt
import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report
import warnings
warnings.filterwarnings("ignore")
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)
print('Librairies imported')
print('')

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print('BOOST SKAN 55 Version v1.35',Style.RESET_ALL)



print('')
print('Sraping tickers')
constituents = pd.read_csv('constituents_csv.csv')
print('Scrap -----> ok')
# PARAMETRES TEMPORELS INITIAUX
start = pd.to_datetime('2015-06-01')
end = pd.to_datetime('2019-12-31')

error = []


try :
    amorce = pd.read_csv('backTest.csv').index[-1] + 1
except:
    amorce = 0
    backtest = pd.DataFrame(columns = ['Symb.','Name','Sector','Period','Begin.','End',\
                          'Pnl $','Pnl %','Gross Profit','Gross Loss','# Winners','# Loosers',\
                          '% Winners','MaxDD $','MaxDD %','Aver. Win $',\
                          'Aver. Loos $','Aver. Duration',\
                          'Total Trades','% Long','% Short','Profit Factor'])
    
    
try:
    amorce2 = pd.read_csv('SIGNALS.csv').index[-1] + 1
except:
    amorce2 = 0
    signals = pd.DataFrame(columns = ['Date','Ticker','Open Long','Close Long','Open Short','Close Short','Buy/Sell Price','Quantity','PNL','Cumulative PNL','Latent PNL'])

    
# SCRAPING DES DONNES BRUTES
def scrap_data(ticker,start,end):
    df = web.DataReader(ticker,'yahoo',start,end)
    df = df.drop(['Close'],axis=1)
    df['Close'] = df['Adj Close']
    df = df.drop(['Adj Close'],axis = 1)    
    return(df)

def prepa_data(df):
    tmps1=time.time()
    print('Preparing data...')
    rsi = talib.RSI(df['Close'],timeperiod=14)
    stoc_slowk, stoc_slowd = talib.STOCH(df['High'],df['Low'],df['Close'])
    upper, middle, lower =  talib.BBANDS(df['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(df['Close'],timeperiod=5)
    sma8 = talib.SMA(df['Close'],timeperiod=8)
    sma10 = talib.SMA(df['Close'],timeperiod=10)
    sma12 = talib.SMA(df['Close'],timeperiod=12)
    sma15 = talib.SMA(df['Close'],timeperiod=15)
    sma30 = talib.SMA(df['Close'],timeperiod=30)
    sma35 = talib.SMA(df['Close'],timeperiod=35)
    sma40 = talib.SMA(df['Close'],timeperiod=40)
    sma45 = talib.SMA(df['Close'],timeperiod=45)
    sma50 = talib.SMA(df['Close'],timeperiod=50)
    atr = talib.ATR(df['High'],df['Low'],df['Close'],timeperiod=10)
    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50
    bbdelta = upper - middle
    price_bolup = df['Close'] - lower
    price_bolow = df['Close'] - upper
    Ema = talib.EMA(df['Close'],timeperiod=20)
    KC_High = Ema + 2*atr
    KC_Low = Ema - 2*atr
    aroondown, aroonup = talib.AROON(df['High'], df['Low'], timeperiod=9)
    aroon = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
    rsi30_list = []
    rsi70_list = []
    for i in range(0,df.shape[0]):
        rsi70_list.append(70 - rsi[i])
        rsi30_list.append(rsi[i] - 30)
        #except:
         #   rsi70_list.append(0)
          #  rs30_list.append(0)
    varop_spy = df['Open'] - df['Close']
    varhl_spy = df['High'] - df['Low']
    df['Varop_Spy'] = varop_spy
    df['Varhl_spy'] = varhl_spy
    df['RSI'] = rsi
    df['70 - RSI'] = np.array(rsi70_list)
    df['RSI - 30'] = np.array(rsi30_list)
    df['BBD_Delta_Up'] = bbdelta
    df['delta5_8'] = delta5_8
    df['delta8_10'] = delta8_10
    df['delta10_12'] = delta10_12
    df['delta12_15'] = delta12_15
    df['delta15_30'] = delta15_30
    df['delta30_35'] = delta30_35
    df['delta35_40'] = delta35_40
    df['delta40_45'] = delta40_45
    df['delta45_50'] = delta45_50
    df['Stoc_Slowk'] = stoc_slowk
    df['Stoc_Slowd'] = stoc_slowd
    df['KC_High'] = KC_High
    df['KC_Low'] = KC_Low
    df['upper'] = upper
    df['lower'] = lower
    df['var_bollup_kchigh'] = upper-KC_High
    df['var_bolllow_kclow'] = lower-KC_Low
    df['Aroon Up'] = aroonup
    df['Aroon Down'] = aroondown
    df['Delta Aroon'] = aroon
    up = []
    down = []
    df = df.dropna()
    df = boost(df)
    df['%Futur'] = ((df['Close.S']-df['Close']) *100) / (df['Close'])
    df['%Futur2'] = ((df['Close.S2']-df['Close']) *100) / (df['Close'])
    for i in range(0,df.shape[0]-5):
        if df.iloc[i]['%Futur'] > 0.1 :#or df.iloc[i]['%Futur2'] > 0.1:
            up.append(1)
            down.append(0)
        elif df.iloc[i]['%Futur'] < -0.1: #or df.iloc[i]['%Futur2'] < -0.1:
            up.append(0)
            down.append(1)
        else:
            up.append(0)
            down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    up.append(0)
    down.append(0)
    
    
    df['target_up'] = up  # target_up # abs(np.array(valley))#target_up
    df['target_down'] = down # target_down # abs(np.array(peak))#target_down
    #df = df.dropna()
    tmps2=round(time.time()-tmps1,2)
    print ("Data prepared in = %f" %tmps2,'seconds')
    return(df)

def boost(df):
    print('Boosting')
    X = df.copy()
    X = X.drop(['Close'],axis=1)
    X['Close'] = df['Close']
    y = X.iloc[:,-1]
    Xtrain = X.iloc[:-2,:-1]
    Xtest = X.iloc[-2:-1,:-1]
    yshift = y.shift(-1)
    ytrain = yshift.iloc[:-2]
    ytest = yshift.iloc[-2:-1]

    model = xgb.XGBRegressor(n_estimators=20000, learning_rate=1, gamma=1, subsample=1, colsample_bytree=1, max_depth=100)

    model.fit( Xtrain, ytrain, early_stopping_rounds=150, eval_set=[(Xtest, ytest)], verbose=0)

    ytrain_pred = model.predict(Xtrain)

    y_pred = model.predict(Xtest)

    pred = model.predict(X.iloc[:,:-1])

    df['Close.S'] = pred
    df['Close.S2'] = df['Close.S']
    df = df.dropna()
    print('Boost ok')
    return(df)

    
def deep_learning(df):
    tmps1=time.time()
    X = df.iloc[:,1:-4]
    y_up = df.iloc[:,-2].values
    y_down = df.iloc[:,-1].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:bloc1,:]
    Xtest = X[bloc1:,:]
    ytrain_up = y_up[:bloc1,:]
    ytest_up = y_up[bloc1:,:]
    ytrain_down = y_down[:bloc1,:]
    ytest_down = y_down[bloc1:,:]

    seed = 770
    np.random.seed(seed)

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    model_up = Sequential()
    # Add an input layer 
    model_up.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_up.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_up.add(Dense(1, activation='sigmoid'))

    model_down = Sequential()
    # Add an input layer 
    model_down.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_down.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_down.add(Dense(1, activation='sigmoid'))

    print('Processing move_up')
    model_up.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])
    
              

    history_up = model_up.fit(Xtrain, ytrain_up,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Processing move_down')
    model_down.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])

    history_down = model_down.fit(Xtrain, ytrain_down,epochs=280, batch_size=8, verbose=0)
    print('\n')
    print('Computing done')
    print('\n')

    train_acc_up = model_up.evaluate(Xtrain, ytrain_up,verbose=1)
    train_acc_down = model_down.evaluate(Xtrain, ytrain_down,verbose=1)

    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    score_up = model_up.evaluate(Xtest, ytest_up,verbose=1)
    score_down = model_down.evaluate(Xtest, ytest_down,verbose=1)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)

    accuracy_up = accuracy_score(ytest_up, yhat_up)
    accuracy_down = accuracy_score(ytest_down, yhat_down)

    # La précision permet de mesurer la capacité du modèle à refuser résultats non-pertinents : vrais_positifs/(vrais_positifs+faux_positifs)
    precision_up = precision_score(ytest_up, yhat_up)  
    precision_down = precision_score(ytest_down, yhat_down) 


    # Recall : (vrai_positifs/(vrais_positifs+faux_négatifs))
    recall_up = recall_score(ytest_up, yhat_up) 
    recall_down = recall_score(ytest_down, yhat_down) 


    #roc_up=roc_auc_score(ytest_up,yhat_up)
    #roc_down=roc_auc_score(ytest_down,yhat_down)
    print('\n')
    print(Fore.GREEN,'RESULTATS UP\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_up * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_up *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_up * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_up *100))
    # get probabilities for positive class

    print(classification_report(ytest_up, yhat_up))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_up, yhat_up))

    print('\n')
    print('_______________________________________________________________________________________________________________________________________________________________\n')
    print(Fore.RED,'RESULTATS DOWN\n',Style.RESET_ALL)
    print('Accuracy: %.2f%%' % (accuracy_down * 100.0))
    print(Fore.BLUE,"Precision: %.2f%% " % (precision_down *100),Style.RESET_ALL,' => Discrimnination des vrais positifs parmi les faux positifs')
    print("Recall: %.2f%% " % (recall_down * 100),' => Positifs trouvés par Golem sur tous les positifs existants')
    #print("ROC: %.2f%% " % (roc_down *100))
    # get probabilities for positive class

    print(classification_report(ytest_down, yhat_down))
    conf_matrix = pd.DataFrame(index = ['vrais_réels','Faux_réels'])
    conf_matrix['Vrais_estimés'] = ['Vrais_positifs','Faux_positifs']
    conf_matrix['Faux_estimés'] = ['Faux_négatif','Vrais-négatifs']
    print(confusion_matrix(ytest_down, yhat_down))
    print('\n')

    resultats = pd.DataFrame()
    resultats['Date'] = df.index[bloc1:]
    resultats.index= df.index[bloc1:]
    resultats['Move Up'] = yhat_up
    resultats['Confiance up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confiance Down'] = (predict_down)*100
    resultats['Actual'] = df.iloc[bloc1:]['Close']
    resultats['Actual.S'] = df.iloc[bloc1:]['Close.S']
    open_S = df['Open'].shift(-1)
    resultats['Open.S'] = open_S.iloc[bloc1:]
    dmp_cp=[]
    dmp_cp = ((resultats['Confiance up']-resultats['Confiance Down'])/(resultats['Confiance up']+resultats['Confiance Down'])*100)
    resultats['DMP_CP'] = dmp_cp
    tmps2=round(time.time()-tmps1,2)
    print ("Deep Learning executed in = %f" %tmps2,'seconds')
    #resultats.set_index('Date',inplace=True)
    #parse_dates=resultats['Date']
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def learn(df):
    resultats,precision_up,precision_down,model_up,model_down,scaler = deep_learning(df)
    return(resultats,precision_up,precision_down,model_up,model_down,scaler)

def grobeta(df,dfb):
    # create a time-series of monthly data points
    rts = df.resample('M').last()
    rbts = dfb.resample('M').last()
    dfsm = pd.DataFrame({'s_adjclose' : rts['Close'],
                            'b_adjclose' : rbts['Adj Close']},
                            index=rts.index)

    # compute returns
    dfsm[['s_returns','b_returns']] = dfsm[['s_adjclose','b_adjclose']]/\
        dfsm[['s_adjclose','b_adjclose']].shift(1) -1
    dfsm = dfsm.dropna()
    covmat = np.cov(dfsm["s_returns"],dfsm["b_returns"])

    # calculate measures now
    beta = covmat[0,1]/covmat[1,1]
    alpha= np.mean(dfsm["s_returns"])-beta*np.mean(dfsm["b_returns"])

    # r_squared     = 1. - SS_res/SS_tot
    ypred = alpha + beta * dfsm["b_returns"]
    SS_res = np.sum(np.power(ypred-dfsm["s_returns"],2))
    SS_tot = covmat[0,0]*(len(dfsm)-1) # SS_tot is sample_variance*(n-1)
    r_squared = 1. - SS_res/SS_tot
    # 5- year volatiity and 1-year momentum
    volatility = np.sqrt(covmat[0,0])
    momentum = np.prod(1+dfsm["s_returns"].tail(12).values) -1

    # annualize the numbers
    prd = 12. # used monthly returns; 12 periods to annualize
    alpha = alpha*prd
    volatility = volatility*np.sqrt(prd)

    print ('Beta : ',beta,'\n Alpha : ',alpha,'\n R_Squared : ', r_squared, '\n Volatility : ', volatility, '\n Momentum : ',momentum)
    return(beta,alpha,r_squared,volatility,momentum)

########################
#### MAIN SKAN55 #######
########################

for loop in range (0,49):    
#for loop in range(amorce,len(constituents)):
    print('Loop :',loop)
    print('amorce : ',amorce)
    print('amorce2 : ',amorce2)
    
    try:

        ticker = (constituents.iloc[loop]['Symbol'])
        name = constituents.iloc[loop]['Name']
        sector = constituents.iloc[loop]['Sector']

        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        global delta,bloc1,bloc2
        tmps1=time.time()
        print('Scraping data...')

        df = scrap_data(ticker,start,end)

        dfb = web.DataReader('^GSPC','yahoo',start,end)

        beta,alpha, r_squared, volatility, momentum = grobeta(df,dfb)

        tmps2=round(time.time()-tmps1,2)
        print ("executed in = %f" %tmps2,'seconds')

        print('\n')
        print('GOLEM begins Computing...')
        print('\n')
        delta = round(df.shape[0])
        bloc1 = round(delta*0.80)
        bloc2 = delta - bloc1
        print("# of periods : ",delta)
        print('On 80% - 20% slash : ')
        print('Bloc 1 : ',bloc1,'\nBloc 2 :',bloc2,' periods ')
        print('First period :',df.index[0])
        print('Split period :',df.index[bloc1-1])
        print('Last period :',df.index[df.shape[0]-1])
        print('\n')

        print('Data prep')
        df = prepa_data(df)

        print(Fore.BLUE,'Deeping in blue',Style.RESET_ALL)
        print('')
        print(' --- Loop :',loop,' --- ',end='')
        print(' --- Symbol : ',Fore.YELLOW,ticker,Style.RESET_ALL,' --- ',end='')
        print(' --- Name : ',name,' --- ',end='')
        print(' --- Sector : ',sector,' --- ')

        resultats,precision_up,precision_down,model_up,model_down,scaler = learn(df)

        import sys
        orig_stdout = sys.stdout
        f = open('backtest de '+str(ticker)+'.txt', 'w')
        sys.stdout = f

        ####################
        #### TEST PLOT ####
        ###################

        filtre_up = 93
        filtre_down = 97
        filtre_up_close = 80
        filtre_down_close = 80


        plt.figure(figsize=(26,8),dpi=300)
        #plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
        plt.title('Deep Learning '+name+' Trade Signals')
        plt.plot(resultats['Actual'],color='purple',lw=0.9,label=ticker)

        green=[]
        red=[]
        green_close=[]
        red_close=[]

        for i in range(0,len(resultats)-1):


            if resultats.iloc[i]['Confiance Down'] > filtre_down:
                doob = -1
            elif resultats.iloc[i]['Confiance Down'] > filtre_down_close and resultats.iloc[i]['Confiance Down'] < filtre_down :
                waab = -1
                doob = 0
            elif resultats.iloc[i]['Confiance up'] > filtre_up:
                doob = 1
            elif resultats.iloc[i]['Confiance up'] > filtre_up_close and resultats.iloc[i]['Confiance up'] < filtre_up:
                waab = 1
                doob = 0
            else :
                doob = 0
                waab = 0

            if doob == 1 :#and resultats.iloc[i]['Confiance up'] > filtre_up:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='g',marker='o')
                #doob = -1
                green.append(1)
                red.append(0)
                green_close.append(0)
                red_close.append(1)

            elif doob == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(1)
                green_close.append(1)
                red_close.append(0)

            elif doob == 0 and waab == -1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(0)
                green_close.append(0)
                red_close.append(1)

            elif waab == 1 :#and resultats.iloc[i]['Confiance Down'] > filtre_down:
                plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o')
                #doob = 1
                green.append(0)
                red.append(0)
                green_close.append(1)
                red_close.append(0)  

            else:
                green.append(0)
                red.append(0)
                green_close.append(0)
                red_close.append(0)  

                #doob = 0


        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='g',marker='o',label='Buy Signal')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Actual'],c='r',marker='o',label='Sell Signal')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_01.pdf')
        plt.close()


        green.append(0)
        red.append(0)
        green_close.append(0)
        red_close.append(0)
        resultats['Green'] = green
        resultats['Red'] = red
        resultats['Green_Close'] = green_close
        resultats['Red_Close'] = red_close
        #resultats['Actual'] = df['Close'][bloc1:]

        ########################
        ####### BACKTEST########
        ########################
        pos_long = 0
        pos_short = 0
        pactol = 10000/beta
        price_buy = 0
        price_sell = 0
        x = 0
        winners = []
        loosers = []
        nb_win = 0
        nb_los = 0
        mini_pnl = 0
        pos_duration = []
        average_duration = resultats.iloc[0,0] - resultats.iloc[0,0]
        trades = []
        eq_curx = []
        eq_cury = []
        maxdd = []
        nbS = 0
        nbL = 0

        for i in range(0,len(resultats)-1):
            if pos_long == 0 and pos_short == 0 and resultats.iloc[i]['Green'] == 1 :
                pos_long = 1
                nbL+=1
                x = round((10000/beta)/resultats.iloc[i]['Open.S'])
                price_buy = round(resultats.iloc[i]['Open.S'],2)
                time_enter = resultats.iloc[i]['Date']

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 1,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':0}],ignore_index=True)

                print('\n Le ',str(resultats.iloc[i]['Date']),', achat de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',round(pactol,2))
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],1))

            elif pos_long == 1 and resultats.iloc[i]['Green_Close'] == 0 :

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':round((resultats.iloc[i]['Open.S'] - price_buy)*x,2)}],ignore_index=True)
                try:
                    maxdd.append(round((resultats.iloc[i]['Open.S'] - price_buy)*x,2))
                except:
                    print('Null val of maxdd')
                    maxdd.append('Null')


            elif pos_long == 1 and resultats.iloc[i]['Green_Close'] == 1 :
                old_pactol = round(pactol,2)
                eq_curx.append(resultats.iloc[i]['Date'])
                eq_cury.append(old_pactol)
                pos_long = 0
                price_sell = round(resultats.iloc[i]['Open.S'],2)
                mini_pnl = round(x*(price_sell-price_buy),2)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],2))

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 1, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : mini_pnl,\
                                           'Cumulative PNL':round(signals.iloc[:i]['PNL'].sum(),2),'Latent PNL':0}],ignore_index=True)

                pactol = round((pactol + mini_pnl),2)
                print('\n Le ',str(resultats.iloc[i]['Date']),', vente pour close de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)
                print('pnl:', mini_pnl)
                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                pos_duration.append(resultats.iloc[i]['Date'] - time_enter)

                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1


            elif pos_short == 0 and pos_long == 0 and resultats.iloc[i]['Red']:
                pos_short = 1
                nbS+=1
                x = round((10000/beta)/resultats.iloc[i]['Open.S'])
                price_sell = round(resultats.iloc[i]['Open.S'],2)
                time_enter = resultats.iloc[i]['Date']

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 1, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

                print('\n Le ',str(resultats.iloc[i]['Date']),', vente de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],-1))


            elif pos_short == 1 and resultats.iloc[i]['Red_Close'] == 0 :

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),\
                                           'Latent PNL':-round((resultats.iloc[i]['Open.S'] - price_sell)*x,2)}],ignore_index=True)
                try:
                    maxdd.append(round((resultats.iloc[i]['Open.S'] - price_sell)*x,2))
                except:
                    print('Null val of maxdd')
                    maxdd.append(0)

            elif pos_short == 1 and resultats.iloc[i]['Red_Close'] == 1 :
                old_pactol = round(pactol,2)
                eq_curx.append(resultats.iloc[i]['Date'])
                eq_cury.append(old_pactol)
                pos_short = 0
                price_buy = round(resultats.iloc[i]['Open.S'],2)
                trades.append((round(resultats.iloc[i]['Open.S'],2),resultats.iloc[i]['Date'],-2))
                mini_pnl = round(x*(price_sell-price_buy),2)

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 1,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : mini_pnl,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

                pactol = round((pactol + mini_pnl),2)
                print('\n Le ',str(resultats.iloc[i]['Date']),', achat pour close de ',x,' actions à',round(resultats.iloc[i]['Open.S'],2),'$')
                print('Nouveau pactol : ',pactol)

                print('prix de vente',price_sell)
                print('prix d achat',price_buy)

                print('pnl:', mini_pnl)
                pos_duration.append(resultats.iloc[i]['Date'] - time_enter)
                if mini_pnl > 0:
                    winners.append(mini_pnl)
                    mini_pnl = 0
                    nb_win +=1
                else :
                    loosers.append(mini_pnl)
                    mini_pnl = 0
                    nb_los +=1
            else:

                signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                               'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 0,\
                               'Buy/Sell Price' : 0, 'Quantity' : 0, 'PNL' : 0,\
                                           'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

        if pos_long == 1:
            pos_long = 0
            print('Cutting non resolved position')
            print(' Le price buy était de : ',price_buy)
            x = round((10000/beta)/resultats.iloc[i]['Open.S'])
            print('x = ',x)
            price_sell = round(resultats.iloc[i]['Open.S'],2)
            print('Et le price sell : ',price_sell)
            mini_pnl = round(x*(price_sell-price_buy),2)

            signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 1, 'Open Short' : 0, 'Close Short' : 0,\
                                   'Buy/Sell Price' : price_sell, 'Quantity' : x, 'PNL' : mini_pnl,\
                                       'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':0}],ignore_index=True)

            pactol = round((pactol + mini_pnl),2)
            print('pnl : ',mini_pnl)
            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1


        if pos_short == 1:
            pos_short = 0
            print('Cutting non resolved position')
            print(' Le price sell était de : ',price_sell)
            x = round((10000/beta)/resultats.iloc[i]['Open.S'])
            print('x = ',x)
            price_buy = round(resultats.iloc[i]['Open.S'],2)
            print('Et le price_buy : ',price_buy)
            mini_pnl = round(x*(price_sell-price_buy),2)

            signals = signals.append([{ 'Date': resultats.iloc[i]['Date'], 'Ticker' : ticker, 'Open Long' : 0,\
                                   'Close Long' : 0, 'Open Short' : 0, 'Close Short' : 1,\
                                   'Buy/Sell Price' : price_buy, 'Quantity' : x, 'PNL' : 0,\
                                       'Cumulative PNL':signals.iloc[:i]['PNL'].sum(),'Latent PNL':mini_pnl}],ignore_index=True)

            pactol = round((pactol + mini_pnl),2)
            print('pnl : ',mini_pnl)

            if mini_pnl > 0:
                winners.append(mini_pnl)
                mini_pnl = 0
                nb_win +=1
            else :
                loosers.append(mini_pnl)
                mini_pnl = 0
                nb_los +=1


        pnl = round(pactol - (10000/beta),2)
        print('\n Begining of BackTest :',resultats.iloc[0]['Date'])
        print('Instrument :',ticker)
        print('Face value per trade : $',10000/beta)
        print('End of BackTest :',resultats.iloc[-1]['Date'])
        duration = pd.to_timedelta((resultats.iloc[-1]['Date'] - resultats.iloc[0]['Date']),unit='d')
        print("BackTest's period :",duration)
        print('Pnl :',round(pnl,2),'$')
        print('% Pnl : ',round(pnl/(10000/beta)*100,2))
        print('Total winners :',round(sum(winners),2),'$')
        print('Total loosers :',round(sum(loosers),2),'$')
        print('Number of winners :',round(nb_win))
        print('Number of loosers :',round(nb_los))
        print('Maximum Drawdown : ',round(min(maxdd),2))
        print('% Max Drawdown : ',round(min(maxdd)/(10000/beta)*100,2),'%')
        print('Nombre toatl de trades : ',round(nbL+nbS,2))
        print('% de trades Long : ',round((nbL*100)/(nbL+nbS),2))
        print('% de trades Short : ',round((nbS*100)/(nbL+nbS),2))
        try:
            print('% winners :', round((nb_win/(nb_win+nb_los) * 100),2),'%')
            print('Average winners :',(round(sum(winners)/(nb_win))))
        except:
            print('% winners : null')
        try:
            print('Average losers :',(round(sum(loosers)/(nb_los))))
        except:
            print('Average losers : Inf')
        try:
            for t in range(0,len(pos_duration)):
                average_duration = pd.to_timedelta((average_duration + pos_duration[t]),unit='d')
            average_duration = average_duration/(nb_los+nb_win)
            print('Average Duration :', average_duration)
        except:
            print('No Average Duration available')
        try:
            print('Profit Factor : ',abs(round((sum(winners)/sum(loosers)),2)))
        except:
            print('Profit Factor : null')

        ########################
        ##### PLOT TRADES ######
        ########################

        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Trades')
        plt.plot(resultats['Open.S'],color='blue',lw=0.9)
        for i in range(0,len(trades)):
            if trades[i][2] == 1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='green',marker='^',lw=2.5)
            elif trades[i][2] == -1:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='red',marker='^',lw=2.5)
            elif trades[i][2] == 2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='g',marker='x',lw=2.5)
            elif trades[i][2] == -2:
                plt.scatter(x=trades[i][1],y=trades[i][0],c='r',marker='x',lw=2.5)

        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='g',marker='^',label='Open Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='r',marker='^',label='Open Short')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='g',marker='x',label='Close Long')
        plt.scatter(x=resultats.index[i],y=resultats.iloc[i]['Open.S'],c='r',marker='x',label='Close Short')
        plt.legend()
        plt.savefig('backtest de '+str(ticker)+'_02.pdf')
        plt.close()

        #########################
        ##### PLOT E-CURVE ######
        #########################
        plt.figure(figsize=(26,8),dpi=300)
        plt.title('Deep Learning '+ticker+' Equity Curve')
        plt.plot(eq_curx,eq_cury)
        plt.scatter(x=eq_curx,y=eq_cury,c='orange',marker='o',lw=2.5)
        plt.savefig('backtest de '+str(ticker)+'_03.pdf')
        plt.close()


        f.close()
        sys.stdout = orig_stdout

        print('\r Boucle ', loop, 'terminée...',end='')
        print('Opération restantes :', len(constituents)-loop,'/',len(constituents),'\n')


        backtest = backtest.append([{'Symb.':ticker,'Name':name,'Sector':sector,'Period':duration,'Begin.':resultats.iloc[0,0],'End':resultats.iloc[-1,0],\
                          'Pnl $':pnl,'Pnl %':round(pnl/(10000/beta)*100,2),'Gross Profit':round(sum(winners),2),'Gross Loss':round(sum(loosers),2),'# Winners':nb_win,'# Loosers':nb_los,\
                          '% Winners':round((nb_win/(nb_win+nb_los) * 100),2),'MaxDD $':round(min(maxdd),2),'MaxDD %':round(min(maxdd)/(10000/beta)*100,2),'Aver. Win $':(round(sum(winners)/(nb_win))),\
                          'Aver. Loos $':(round(sum(loosers)/(nb_los))),'Aver. Duration':average_duration,\
                          'Total Trades':nbL+nbS,'% Long':round((nbL*100)/(nbL+nbS),2),'% Short':round((nbS*100)/(nbL+nbS),2), 'Profit Factor':abs(round((sum(winners)/sum(loosers)),2))}], ignore_index=True)


        #signals = signals.append([{ 'Date': list_signals[0], 'Ticker' : list_signals[8], 'Open Long' : list_signals[1],\
                                   #'Close Long' : list_signals[2], 'Open Short' : list_signals[3], 'Close Short' : list_signals[4],\
                                   #'Buy/Sell Price' : list_signals[5], 'Quantity' : list_signals[6], ' tPNL' : list_signals[7]}])

        #signals['Date'] = list_signals[0]
        #signals['Ticker'] = list_signals[8]
        #signals['Open Long'] = list_signals[1]
        #signals['Close Long'] = list_signals[2]
        #signals['Open Short'] = list_signals[3]
        #signals['Close Short'] = list_signals[4]
        #signals['Buy/Sell Price'] = list_signals[5]
        #signals['Quantity'] = list_signals[6]
        #signals['tPNL'] = list_signals[7]

    # symbol / name / sector / period of backtest / debut / fin / pnl / total winners / total loosers / Nb winners / nb loosers / 
    # / % winners / Max DD / Aver Win / Aver Loos / Average duration / Profit Factor
        print(Fore.YELLOW,'Writing BACKTEST CSV AND SIGNALS.CSV',Style.RESET_ALL)
        backtest.to_csv('BackTest.csv')
        signals.sort_values(by=['Date'])
        signals.to_csv('SIGNALS.csv')

        print(Fore.CYAN,'BACKTEST CSV WRITED AND SIGNALS.CSV',Style.RESET_ALL)
    except:
        print(Fore.RED,'Problème loop : ',loop,Style.RESET_ALL)
        error.append((loop,ticker))
         
        continue
# Out:
# Importing Librairies...
# Using TensorFlow backend.
# Librairies imported
#
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
# BOOST SKAN 55 Version v1.35
#
# Sraping tickers
# Scrap -----> ok
# Loop : 0
# amorce :  0
# amorce2 :  0
#  --- Loop : 0  ---  --- Symbol :   MMM   ---  --- Name :  3M Company  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.10032306009194
#  Alpha :  -0.03225779849766493
#  R_Squared :  0.48708011995247336
#  Volatility :  0.19817227801870213
#  Momentum :  -0.15296552867927515
# executed in = 5.370000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:37:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.480000 seconds
#  Deeping in blue
#
#  --- Loop : 0  ---  --- Symbol :   MMM   ---  --- Name :  3M Company  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 0s 99us/step
# 840/840 [==============================] - 0s 105us/step
# 161/161 [==============================] - 0s 32us/step
# 161/161 [==============================] - 0s 31us/step
#
#
#  RESULTATS UP
#
# Accuracy: 77.02%
#  Precision: 70.65%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 86.67%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.69      0.76        86
#            1       0.71      0.87      0.78        75
#
#    micro avg       0.77      0.77      0.77       161
#    macro avg       0.78      0.78      0.77       161
# weighted avg       0.79      0.77      0.77       161
#
# [[59 27]
#  [10 65]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 78.26%
#  Precision: 75.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 73.91%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.81        92
#            1       0.75      0.74      0.74        69
#
#    micro avg       0.78      0.78      0.78       161
#    macro avg       0.78      0.78      0.78       161
# weighted avg       0.78      0.78      0.78       161
#
# [[75 17]
#  [18 51]]
#
#
# Deep Learning executed in = 82.810000 seconds
#  Boucle  0 terminée...Opération restantes : 505 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 1
# amorce :  0
# amorce2 :  0
#  --- Loop : 1  ---  --- Symbol :   AOS   ---  --- Name :  A.O. Smith Corp  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.6588219110739832
#  Alpha :  -0.05490651197318091
#  R_Squared :  0.6488018164616127
#  Volatility :  0.2588609995074918
#  Momentum :  -0.2220299389100181
# executed in = 2.290000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:38:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.170000 seconds
#  Deeping in blue
#
#  --- Loop : 1  ---  --- Symbol :   AOS   ---  --- Name :  A.O. Smith Corp  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 0s 141us/step
# 840/840 [==============================] - 0s 149us/step
# 161/161 [==============================] - 0s 30us/step
# 161/161 [==============================] - 0s 37us/step
#
#
#  RESULTATS UP
#
# Accuracy: 93.79%
#  Precision: 92.55%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 96.67%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93        71
#            1       0.93      0.97      0.95        90
#
#    micro avg       0.94      0.94      0.94       161
#    macro avg       0.94      0.93      0.94       161
# weighted avg       0.94      0.94      0.94       161
#
# [[64  7]
#  [ 3 87]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 93.17%
#  Precision: 87.32%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 96.88%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.98      0.91      0.94        97
#            1       0.87      0.97      0.92        64
#
#    micro avg       0.93      0.93      0.93       161
#    macro avg       0.93      0.94      0.93       161
# weighted avg       0.94      0.93      0.93       161
#
# [[88  9]
#  [ 2 62]]
#
#
# Deep Learning executed in = 75.500000 seconds
#  Boucle  1 terminée...Opération restantes : 504 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 2
# amorce :  0
# amorce2 :  0
#  --- Loop : 2  ---  --- Symbol :   ABT   ---  --- Name :  Abbott Laboratories  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.1750519000030677
#  Alpha :  0.07006953402468397
#  R_Squared :  0.48568218391182894
#  Volatility :  0.21193556976779826
#  Momentum :  0.35113872581438454
# executed in = 1.880000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:39:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.970000 seconds
#  Deeping in blue
#
#  --- Loop : 2  ---  --- Symbol :   ABT   ---  --- Name :  Abbott Laboratories  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 0s 186us/step
# 840/840 [==============================] - 0s 183us/step
# 161/161 [==============================] - 0s 30us/step
# 161/161 [==============================] - 0s 35us/step
#
#
#  RESULTATS UP
#
# Accuracy: 76.40%
#  Precision: 71.43%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 90.36%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.62      0.72        78
#            1       0.71      0.90      0.80        83
#
#    micro avg       0.76      0.76      0.76       161
#    macro avg       0.79      0.76      0.76       161
# weighted avg       0.78      0.76      0.76       161
#
# [[48 30]
#  [ 8 75]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 83.23%
#  Precision: 74.58%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 78.57%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       105
#            1       0.75      0.79      0.77        56
#
#    micro avg       0.83      0.83      0.83       161
#    macro avg       0.81      0.82      0.82       161
# weighted avg       0.83      0.83      0.83       161
#
# [[90 15]
#  [12 44]]
#
#
# Deep Learning executed in = 68.750000 seconds
#  Boucle  2 terminée...Opération restantes : 503 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 3
# amorce :  0
# amorce2 :  0
#  --- Loop : 3  ---  --- Symbol :   ABBV   ---  --- Name :  AbbVie Inc.  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  0.9399216508594603
#  Alpha :  -0.015237284491075781
#  R_Squared :  0.18157514305346
#  Volatility :  0.2772594421651549
#  Momentum :  -0.23977741157771837
# executed in = 5.090000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:41:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.010000 seconds
#  Deeping in blue
#
#  --- Loop : 3  ---  --- Symbol :   ABBV   ---  --- Name :  AbbVie Inc.  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 0s 279us/step
# 840/840 [==============================] - 0s 286us/step
# 161/161 [==============================] - 0s 44us/step
# 161/161 [==============================] - 0s 45us/step
#
#
#  RESULTATS UP
#
# Accuracy: 73.91%
#  Precision: 75.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 60.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.73      0.85      0.79        91
#            1       0.75      0.60      0.67        70
#
#    micro avg       0.74      0.74      0.74       161
#    macro avg       0.74      0.72      0.73       161
# weighted avg       0.74      0.74      0.73       161
#
# [[77 14]
#  [28 42]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 75.78%
#  Precision: 88.57%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 46.97%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.72      0.96      0.82        95
#            1       0.89      0.47      0.61        66
#
#    micro avg       0.76      0.76      0.76       161
#    macro avg       0.80      0.71      0.72       161
# weighted avg       0.79      0.76      0.74       161
#
# [[91  4]
#  [35 31]]
#
#
# Deep Learning executed in = 69.870000 seconds
#  Boucle  3 terminée...Opération restantes : 502 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 4
# amorce :  0
# amorce2 :  0
#  --- Loop : 4  ---  --- Symbol :   ACN   ---  --- Name :  Accenture plc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.0646825573794028
#  Alpha :  0.10014634488178312
#  R_Squared :  0.5510694248151351
#  Volatility :  0.1802768123803995
#  Momentum :  0.22983627710764876
# executed in = 3.770000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:42:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.400000 seconds
#  Deeping in blue
#
#  --- Loop : 4  ---  --- Symbol :   ACN   ---  --- Name :  Accenture plc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 0s 294us/step
# 840/840 [==============================] - 0s 291us/step
# 161/161 [==============================] - 0s 34us/step
# 161/161 [==============================] - 0s 36us/step
#
#
#  RESULTATS UP
#
# Accuracy: 77.02%
#  Precision: 78.79%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 69.33%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.76      0.84      0.80        86
#            1       0.79      0.69      0.74        75
#
#    micro avg       0.77      0.77      0.77       161
#    macro avg       0.77      0.77      0.77       161
# weighted avg       0.77      0.77      0.77       161
#
# [[72 14]
#  [23 52]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 70.19%
#  Precision: 70.73%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 44.62%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.70      0.88      0.78        96
#            1       0.71      0.45      0.55        65
#
#    micro avg       0.70      0.70      0.70       161
#    macro avg       0.70      0.66      0.66       161
# weighted avg       0.70      0.70      0.68       161
#
# [[84 12]
#  [36 29]]
#
#
# Deep Learning executed in = 74.090000 seconds
#  Boucle  4 terminée...Opération restantes : 501 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 5
# amorce :  0
# amorce2 :  0
#  --- Loop : 5  ---  --- Symbol :   ATVI   ---  --- Name :  Activision Blizzard  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  0.8201742042333927
#  Alpha :  0.14955676628459694
#  R_Squared :  0.10759787585134084
#  Volatility :  0.3142875272750082
#  Momentum :  -0.3308154259445596
# executed in = 2.080000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:44:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.650000 seconds
#  Deeping in blue
#
#  --- Loop : 5  ---  --- Symbol :   ATVI   ---  --- Name :  Activision Blizzard  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 0s 337us/step
# 840/840 [==============================] - 0s 321us/step
# 161/161 [==============================] - 0s 35us/step
# 161/161 [==============================] - 0s 40us/step
#
#
#  RESULTATS UP
#
# Accuracy: 80.75%
#  Precision: 86.30%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 75.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81        77
#            1       0.86      0.75      0.80        84
#
#    micro avg       0.81      0.81      0.81       161
#    macro avg       0.81      0.81      0.81       161
# weighted avg       0.81      0.81      0.81       161
#
# [[67 10]
#  [21 63]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 84.47%
#  Precision: 79.73%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.51%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86        92
#            1       0.80      0.86      0.83        69
#
#    micro avg       0.84      0.84      0.84       161
#    macro avg       0.84      0.85      0.84       161
# weighted avg       0.85      0.84      0.85       161
#
# [[77 15]
#  [10 59]]
#
#
# Deep Learning executed in = 75.670000 seconds
#  Boucle  5 terminée...Opération restantes : 500 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 6
# amorce :  0
# amorce2 :  0
#  --- Loop : 6  ---  --- Symbol :   AYI   ---  --- Name :  Acuity Brands Inc  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  1.6849847133709543
#  Alpha :  -0.16824012503821606
#  R_Squared :  0.3279697752129084
#  Volatility :  0.36982983448262263
#  Momentum :  -0.030716494137626893
# executed in = 2.170000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:45:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.890000 seconds
#  Deeping in blue
#
#  --- Loop : 6  ---  --- Symbol :   AYI   ---  --- Name :  Acuity Brands Inc  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 0s 388us/step
# 840/840 [==============================] - 0s 386us/step
# 161/161 [==============================] - 0s 36us/step
# 161/161 [==============================] - 0s 38us/step
#
#
#  RESULTATS UP
#
# Accuracy: 89.44%
#  Precision: 93.33%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.37%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90        79
#            1       0.93      0.85      0.89        82
#
#    micro avg       0.89      0.89      0.89       161
#    macro avg       0.90      0.90      0.89       161
# weighted avg       0.90      0.89      0.89       161
#
# [[74  5]
#  [12 70]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 90.06%
#  Precision: 88.57%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 88.57%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        91
#            1       0.89      0.89      0.89        70
#
#    micro avg       0.90      0.90      0.90       161
#    macro avg       0.90      0.90      0.90       161
# weighted avg       0.90      0.90      0.90       161
#
# [[83  8]
#  [ 8 62]]
#
#
# Deep Learning executed in = 79.050000 seconds
#  Boucle  6 terminée...Opération restantes : 499 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 7
# amorce :  0
# amorce2 :  0
#  --- Loop : 7  ---  --- Symbol :   ADBE   ---  --- Name :  Adobe Systems Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.0126109803662526
#  Alpha :  0.2438009008578259
#  R_Squared :  0.401377887885355
#  Volatility :  0.20090409998707814
#  Momentum :  0.22143205124079635
# executed in = 2.250000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:46:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.700000 seconds
#  Deeping in blue
#
#  --- Loop : 7  ---  --- Symbol :   ADBE   ---  --- Name :  Adobe Systems Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 0s 447us/step
# 840/840 [==============================] - 0s 507us/step
# 161/161 [==============================] - 0s 39us/step
# 161/161 [==============================] - 0s 38us/step
#
#
#  RESULTATS UP
#
# Accuracy: 63.35%
#  Precision: 54.55%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 55.38%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.69      0.69      0.69        96
#            1       0.55      0.55      0.55        65
#
#    micro avg       0.63      0.63      0.63       161
#    macro avg       0.62      0.62      0.62       161
# weighted avg       0.63      0.63      0.63       161
#
# [[66 30]
#  [29 36]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 67.70%
#  Precision: 64.29%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 78.75%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.73      0.57      0.64        81
#            1       0.64      0.79      0.71        80
#
#    micro avg       0.68      0.68      0.68       161
#    macro avg       0.69      0.68      0.67       161
# weighted avg       0.69      0.68      0.67       161
#
# [[46 35]
#  [17 63]]
#
#
# Deep Learning executed in = 81.760000 seconds
#  Boucle  7 terminée...Opération restantes : 498 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 8
# amorce :  0
# amorce2 :  0
#  --- Loop : 8  ---  --- Symbol :   AAP   ---  --- Name :  Advance Auto Parts  ---  --- Sector :  Consumer Discretionary  ---
# Scraping data...
# Beta :  0.8943416335838104
#  Alpha :  -0.05494705081916519
#  R_Squared :  0.13514288508101968
#  Volatility :  0.3057945525192405
#  Momentum :  0.06822371021499962
# executed in = 5.500000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:48:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.410000 seconds
#  Deeping in blue
#
#  --- Loop : 8  ---  --- Symbol :   AAP   ---  --- Name :  Advance Auto Parts  ---  --- Sector :  Consumer Discretionary  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 0s 481us/step
# 840/840 [==============================] - 0s 489us/step
# 161/161 [==============================] - 0s 37us/step
# 161/161 [==============================] - 0s 57us/step
#
#
#  RESULTATS UP
#
# Accuracy: 99.38%
#  Precision: 100.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 98.33%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       101
#            1       1.00      0.98      0.99        60
#
#    micro avg       0.99      0.99      0.99       161
#    macro avg       1.00      0.99      0.99       161
# weighted avg       0.99      0.99      0.99       161
#
# [[101   0]
#  [  1  59]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 95.03%
#  Precision: 92.93%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 98.92%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94        68
#            1       0.93      0.99      0.96        93
#
#    micro avg       0.95      0.95      0.95       161
#    macro avg       0.96      0.94      0.95       161
# weighted avg       0.95      0.95      0.95       161
#
# [[61  7]
#  [ 1 92]]
#
#
# Deep Learning executed in = 84.550000 seconds
#  Boucle  8 terminée...Opération restantes : 497 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 9
# amorce :  0
# amorce2 :  0
#  --- Loop : 9  ---  --- Symbol :   AMD   ---  --- Name :  Advanced Micro Devices Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  3.10589054739085
#  Alpha :  0.5227151955729978
#  R_Squared :  0.38824748357678474
#  Volatility :  0.626548524032186
#  Momentum :  0.6612111778330501
# executed in = 2.090000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:50:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.780000 seconds
#  Deeping in blue
#
#  --- Loop : 9  ---  --- Symbol :   AMD   ---  --- Name :  Advanced Micro Devices Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 0s 526us/step
# 840/840 [==============================] - 0s 526us/step
# 161/161 [==============================] - 0s 57us/step
# 161/161 [==============================] - 0s 51us/step
#
#
#  RESULTATS UP
#
# Accuracy: 96.27%
#  Precision: 96.34%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 96.34%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        79
#            1       0.96      0.96      0.96        82
#
#    micro avg       0.96      0.96      0.96       161
#    macro avg       0.96      0.96      0.96       161
# weighted avg       0.96      0.96      0.96       161
#
# [[76  3]
#  [ 3 79]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 93.17%
#  Precision: 90.79%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 94.52%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94        88
#            1       0.91      0.95      0.93        73
#
#    micro avg       0.93      0.93      0.93       161
#    macro avg       0.93      0.93      0.93       161
# weighted avg       0.93      0.93      0.93       161
#
# [[81  7]
#  [ 4 69]]
#
#
# Deep Learning executed in = 86.210000 seconds
#  Boucle  9 terminée...Opération restantes : 496 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 10
# amorce :  0
# amorce2 :  0
#  --- Loop : 10  ---  --- Symbol :   AES   ---  --- Name :  AES Corp  ---  --- Sector :  Utilities  ---
# Scraping data...
# Beta :  0.9814138923777858
#  Alpha :  0.03060996045543276
#  R_Squared :  0.2880810732389353
#  Volatility :  0.2298358266785659
#  Momentum :  0.3118265100157809
# executed in = 3.460000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:51:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.420000 seconds
#  Deeping in blue
#
#  --- Loop : 10  ---  --- Symbol :   AES   ---  --- Name :  AES Corp  ---  --- Sector :  Utilities  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 0s 577us/step
# 840/840 [==============================] - 0s 591us/step
# 161/161 [==============================] - 0s 47us/step
# 161/161 [==============================] - 0s 51us/step
#
#
#  RESULTATS UP
#
# Accuracy: 88.82%
#  Precision: 76.32%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.90       103
#            1       0.76      1.00      0.87        58
#
#    micro avg       0.89      0.89      0.89       161
#    macro avg       0.88      0.91      0.88       161
# weighted avg       0.91      0.89      0.89       161
#
# [[85 18]
#  [ 0 58]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 88.82%
#  Precision: 85.71%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 96.77%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.95      0.78      0.85        68
#            1       0.86      0.97      0.91        93
#
#    micro avg       0.89      0.89      0.89       161
#    macro avg       0.90      0.87      0.88       161
# weighted avg       0.89      0.89      0.89       161
#
# [[53 15]
#  [ 3 90]]
#
#
# Deep Learning executed in = 89.690000 seconds
#  Boucle  10 terminée...Opération restantes : 495 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 11
# amorce :  0
# amorce2 :  0
#  --- Loop : 11  ---  --- Symbol :   AET   ---  --- Name :  Aetna Inc  ---  --- Sector :  Health Care  ---
# Scraping data...
#  Problème loop :  11
# Loop : 12
# amorce :  0
# amorce2 :  0
#  --- Loop : 12  ---  --- Symbol :   AMG   ---  --- Name :  Affiliated Managers Group Inc  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  1.706646587748665
#  Alpha :  -0.3434267894111678
#  R_Squared :  0.506461088522371
#  Volatility :  0.3014348378390129
#  Momentum :  -0.4578852859972419
# executed in = 1.900000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:53:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.160000 seconds
#  Deeping in blue
#
#  --- Loop : 12  ---  --- Symbol :   AMG   ---  --- Name :  Affiliated Managers Group Inc  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 1s 645us/step
# 840/840 [==============================] - 1s 620us/step
# 161/161 [==============================] - 0s 49us/step
# 161/161 [==============================] - 0s 49us/step
#
#
#  RESULTATS UP
#
# Accuracy: 62.11%
#  Precision: 59.65%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 47.22%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.63      0.74      0.68        89
#            1       0.60      0.47      0.53        72
#
#    micro avg       0.62      0.62      0.62       161
#    macro avg       0.62      0.61      0.61       161
# weighted avg       0.62      0.62      0.61       161
#
# [[66 23]
#  [38 34]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 63.35%
#  Precision: 60.23%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 68.83%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.67      0.58      0.62        84
#            1       0.60      0.69      0.64        77
#
#    micro avg       0.63      0.63      0.63       161
#    macro avg       0.64      0.64      0.63       161
# weighted avg       0.64      0.63      0.63       161
#
# [[49 35]
#  [24 53]]
#
#
# Deep Learning executed in = 91.850000 seconds
#  Boucle  12 terminée...Opération restantes : 493 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 13
# amorce :  0
# amorce2 :  0
#  --- Loop : 13  ---  --- Symbol :   AFL   ---  --- Name :  AFLAC Inc  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  0.6373741466563858
#  Alpha :  0.11670693473243485
#  R_Squared :  0.310463577359664
#  Volatility :  0.14378447759571383
#  Momentum :  0.15623431825481027
# executed in = 2.170000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:54:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.250000 seconds
#  Deeping in blue
#
#  --- Loop : 13  ---  --- Symbol :   AFL   ---  --- Name :  AFLAC Inc  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 1s 687us/step
# 840/840 [==============================] - 1s 693us/step
# 161/161 [==============================] - 0s 47us/step
# 161/161 [==============================] - 0s 61us/step
#
#
#  RESULTATS UP
#
# Accuracy: 55.90%
#  Precision: 53.73%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 47.37%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.57      0.64      0.60        85
#            1       0.54      0.47      0.50        76
#
#    micro avg       0.56      0.56      0.56       161
#    macro avg       0.56      0.55      0.55       161
# weighted avg       0.56      0.56      0.56       161
#
# [[54 31]
#  [40 36]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 52.80%
#  Precision: 43.59%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 83.61%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.77      0.34      0.47       100
#            1       0.44      0.84      0.57        61
#
#    micro avg       0.53      0.53      0.53       161
#    macro avg       0.60      0.59      0.52       161
# weighted avg       0.65      0.53      0.51       161
#
# [[34 66]
#  [10 51]]
#
#
# Deep Learning executed in = 98.330000 seconds
#  Boucle  13 terminée...Opération restantes : 492 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 14
# amorce :  0
# amorce2 :  0
#  --- Loop : 14  ---  --- Symbol :   A   ---  --- Name :  Agilent Technologies Inc  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  1.3702563854992196
#  Alpha :  0.04610739011317481
#  R_Squared :  0.551889206713166
#  Volatility :  0.23184555467352813
#  Momentum :  0.06034658991708386
# executed in = 2.280000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:56:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.320000 seconds
#  Deeping in blue
#
#  --- Loop : 14  ---  --- Symbol :   A   ---  --- Name :  Agilent Technologies Inc  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 1s 812us/step
# 840/840 [==============================] - 1s 728us/step
# 161/161 [==============================] - 0s 46us/step
# 161/161 [==============================] - 0s 47us/step
#
#
#  RESULTATS UP
#
# Accuracy: 75.78%
#  Precision: 74.70%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 77.50%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.75        81
#            1       0.75      0.78      0.76        80
#
#    micro avg       0.76      0.76      0.76       161
#    macro avg       0.76      0.76      0.76       161
# weighted avg       0.76      0.76      0.76       161
#
# [[60 21]
#  [18 62]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 77.64%
#  Precision: 80.85%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 58.46%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.76      0.91      0.83        96
#            1       0.81      0.58      0.68        65
#
#    micro avg       0.78      0.78      0.78       161
#    macro avg       0.79      0.75      0.75       161
# weighted avg       0.78      0.78      0.77       161
#
# [[87  9]
#  [27 38]]
#
#
# Deep Learning executed in = 97.800000 seconds
#  Boucle  14 terminée...Opération restantes : 491 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 15
# amorce :  0
# amorce2 :  0
#  --- Loop : 15  ---  --- Symbol :   APD   ---  --- Name :  Air Products & Chemicals Inc  ---  --- Sector :  Materials  ---
# Scraping data...
# Beta :  0.8149732398573885
#  Alpha :  0.10521405424138475
#  R_Squared :  0.4497794183259288
#  Volatility :  0.15274480502369034
#  Momentum :  0.42527703287409424
# executed in = 2.130000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [09:58:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.290000 seconds
#  Deeping in blue
#
#  --- Loop : 15  ---  --- Symbol :   APD   ---  --- Name :  Air Products & Chemicals Inc  ---  --- Sector :  Materials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 1s 773us/step
# 840/840 [==============================] - 1s 798us/step
# 161/161 [==============================] - 0s 44us/step
# 161/161 [==============================] - 0s 43us/step
#
#
#  RESULTATS UP
#
# Accuracy: 77.64%
#  Precision: 68.75%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 91.67%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.91      0.66      0.77        89
#            1       0.69      0.92      0.79        72
#
#    micro avg       0.78      0.78      0.78       161
#    macro avg       0.80      0.79      0.78       161
# weighted avg       0.81      0.78      0.77       161
#
# [[59 30]
#  [ 6 66]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 85.71%
#  Precision: 84.52%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 87.65%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.85        80
#            1       0.85      0.88      0.86        81
#
#    micro avg       0.86      0.86      0.86       161
#    macro avg       0.86      0.86      0.86       161
# weighted avg       0.86      0.86      0.86       161
#
# [[67 13]
#  [10 71]]
#
#
# Deep Learning executed in = 99.980000 seconds
#  Boucle  15 terminée...Opération restantes : 490 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 16
# amorce :  0
# amorce2 :  0
#  --- Loop : 16  ---  --- Symbol :   AKAM   ---  --- Name :  Akamai Technologies Inc  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  0.4286982687361905
#  Alpha :  0.06169303122765635
#  R_Squared :  0.029868229472432062
#  Volatility :  0.31179552593121423
#  Momentum :  0.1710071053929969
# executed in = 2.060000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [10:00:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.100000 seconds
#  Deeping in blue
#
#  --- Loop : 16  ---  --- Symbol :   AKAM   ---  --- Name :  Akamai Technologies Inc  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 1s 850us/step
# 840/840 [==============================] - 1s 840us/step
# 161/161 [==============================] - 0s 51us/step
# 161/161 [==============================] - 0s 50us/step
#
#
#  RESULTATS UP
#
# Accuracy: 90.68%
#  Precision: 96.05%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.88%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91        76
#            1       0.96      0.86      0.91        85
#
#    micro avg       0.91      0.91      0.91       161
#    macro avg       0.91      0.91      0.91       161
# weighted avg       0.91      0.91      0.91       161
#
# [[73  3]
#  [12 73]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 88.20%
#  Precision: 84.21%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 82.76%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91       103
#            1       0.84      0.83      0.83        58
#
#    micro avg       0.88      0.88      0.88       161
#    macro avg       0.87      0.87      0.87       161
# weighted avg       0.88      0.88      0.88       161
#
# [[94  9]
#  [10 48]]
#
#
# Deep Learning executed in = 106.270000 seconds
#  Boucle  16 terminée...Opération restantes : 489 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 17
# amorce :  0
# amorce2 :  0
#  --- Loop : 17  ---  --- Symbol :   ALK   ---  --- Name :  Alaska Air Group Inc  ---  --- Sector :  Industrials  ---
# Scraping data...
# Beta :  0.9642378789253304
#  Alpha :  -0.03666375809508894
#  R_Squared :  0.16011887019200322
#  Volatility :  0.30289061619523877
#  Momentum :  0.029373259891919856
# executed in = 2.350000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [10:02:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 3.610000 seconds
#  Deeping in blue
#
#  --- Loop : 17  ---  --- Symbol :   ALK   ---  --- Name :  Alaska Air Group Inc  ---  --- Sector :  Industrials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 1s 902us/step
# 840/840 [==============================] - 1s 911us/step
# 161/161 [==============================] - 0s 52us/step
# 161/161 [==============================] - 0s 53us/step
#
#
#  RESULTATS UP
#
# Accuracy: 90.06%
#  Precision: 86.02%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 96.39%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.96      0.83      0.89        78
#            1       0.86      0.96      0.91        83
#
#    micro avg       0.90      0.90      0.90       161
#    macro avg       0.91      0.90      0.90       161
# weighted avg       0.91      0.90      0.90       161
#
# [[65 13]
#  [ 3 80]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 84.47%
#  Precision: 93.18%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 65.08%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.81      0.97      0.88        98
#            1       0.93      0.65      0.77        63
#
#    micro avg       0.84      0.84      0.84       161
#    macro avg       0.87      0.81      0.83       161
# weighted avg       0.86      0.84      0.84       161
#
# [[95  3]
#  [22 41]]
#
#
# Deep Learning executed in = 107.800000 seconds
#  Boucle  17 terminée...Opération restantes : 488 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 18
# amorce :  0
# amorce2 :  0
#  --- Loop : 18  ---  --- Symbol :   ALB   ---  --- Name :  Albemarle Corp  ---  --- Sector :  Materials  ---
# Scraping data...
# Beta :  1.4218360357919841
#  Alpha :  -0.009976009043662568
#  R_Squared :  0.3417512473760618
#  Volatility :  0.305715425053585
#  Momentum :  -0.2125677896446423
# executed in = 1.830000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [10:04:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.880000 seconds
#  Deeping in blue
#
#  --- Loop : 18  ---  --- Symbol :   ALB   ---  --- Name :  Albemarle Corp  ---  --- Sector :  Materials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 1s 908us/step
# 840/840 [==============================] - 1s 931us/step
# 161/161 [==============================] - 0s 51us/step
# 161/161 [==============================] - 0s 49us/step
#
#
#  RESULTATS UP
#
# Accuracy: 78.88%
#  Precision: 69.64%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 100.00%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       1.00      0.59      0.74        83
#            1       0.70      1.00      0.82        78
#
#    micro avg       0.79      0.79      0.79       161
#    macro avg       0.85      0.80      0.78       161
# weighted avg       0.85      0.79      0.78       161
#
# [[49 34]
#  [ 0 78]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 82.61%
#  Precision: 74.19%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 94.52%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.94      0.73      0.82        88
#            1       0.74      0.95      0.83        73
#
#    micro avg       0.83      0.83      0.83       161
#    macro avg       0.84      0.84      0.83       161
# weighted avg       0.85      0.83      0.83       161
#
# [[64 24]
#  [ 4 69]]
#
#
# Deep Learning executed in = 110.970000 seconds
#  Boucle  18 terminée...Opération restantes : 487 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 19
# amorce :  0
# amorce2 :  0
# ...
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 2s 2ms/step
# 840/840 [==============================] - 2s 2ms/step
# 161/161 [==============================] - 0s 94us/step
# 161/161 [==============================] - 0s 86us/step
#
#
#  RESULTATS UP
#
# Accuracy: 78.88%
#  Precision: 76.25%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 80.26%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.81      0.78      0.80        85
#            1       0.76      0.80      0.78        76
#
#    micro avg       0.79      0.79      0.79       161
#    macro avg       0.79      0.79      0.79       161
# weighted avg       0.79      0.79      0.79       161
#
# [[66 19]
#  [15 61]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 70.81%
#  Precision: 69.86%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 67.11%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.72      0.74      0.73        85
#            1       0.70      0.67      0.68        76
#
#    micro avg       0.71      0.71      0.71       161
#    macro avg       0.71      0.71      0.71       161
# weighted avg       0.71      0.71      0.71       161
#
# [[63 22]
#  [25 51]]
#
#
# Deep Learning executed in = 185.200000 seconds
#  Boucle  42 terminée...Opération restantes : 463 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 43
# amorce :  0
# amorce2 :  0
#  --- Loop : 43  ---  --- Symbol :   APC   ---  --- Name :  Anadarko Petroleum Corp  ---  --- Sector :  Energy  ---
# Scraping data...
# Beta :  1.7891239003068187
#  Alpha :  -0.0840928407482945
#  R_Squared :  0.23395922106196076
#  Volatility :  0.46493605147900624
#  Momentum :  0.028420901261723808
# executed in = 2.350000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:20:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.260000 seconds
#  Deeping in blue
#
#  --- Loop : 43  ---  --- Symbol :   APC   ---  --- Name :  Anadarko Petroleum Corp  ---  --- Sector :  Energy  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 2s 2ms/step
# 840/840 [==============================] - 2s 2ms/step
# 161/161 [==============================] - 0s 93us/step
# 161/161 [==============================] - 0s 89us/step
#
#
#  RESULTATS UP
#
# Accuracy: 78.26%
#  Precision: 78.48%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 77.50%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.79        81
#            1       0.78      0.78      0.78        80
#
#    micro avg       0.78      0.78      0.78       161
#    macro avg       0.78      0.78      0.78       161
# weighted avg       0.78      0.78      0.78       161
#
# [[64 17]
#  [18 62]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 73.29%
#  Precision: 67.24%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 61.90%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.77      0.81      0.79        98
#            1       0.67      0.62      0.64        63
#
#    micro avg       0.73      0.73      0.73       161
#    macro avg       0.72      0.71      0.72       161
# weighted avg       0.73      0.73      0.73       161
#
# [[79 19]
#  [24 39]]
#
#
# Deep Learning executed in = 186.690000 seconds
#  Boucle  43 terminée...Opération restantes : 462 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 44
# amorce :  0
# amorce2 :  0
#  --- Loop : 44  ---  --- Symbol :   ADI   ---  --- Name :  Analog Devices, Inc.  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.3726876871512004
#  Alpha :  0.07016398509345276
#  R_Squared :  0.4406374487021413
#  Volatility :  0.25992851471953976
#  Momentum :  0.24744623712544733
# executed in = 2.110000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:24:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.820000 seconds
#  Deeping in blue
#
#  --- Loop : 44  ---  --- Symbol :   ADI   ---  --- Name :  Analog Devices, Inc.  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 2s 2ms/step
# 840/840 [==============================] - 2s 3ms/step
# 161/161 [==============================] - 0s 111us/step
# 161/161 [==============================] - 0s 105us/step
#
#
#  RESULTATS UP
#
# Accuracy: 77.02%
#  Precision: 94.00%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 58.02%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.69      0.96      0.81        80
#            1       0.94      0.58      0.72        81
#
#    micro avg       0.77      0.77      0.77       161
#    macro avg       0.82      0.77      0.76       161
# weighted avg       0.82      0.77      0.76       161
#
# [[77  3]
#  [34 47]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 74.53%
#  Precision: 61.05%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 93.55%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.94      0.63      0.75        99
#            1       0.61      0.94      0.74        62
#
#    micro avg       0.75      0.75      0.75       161
#    macro avg       0.77      0.78      0.75       161
# weighted avg       0.81      0.75      0.75       161
#
# [[62 37]
#  [ 4 58]]
#
#
# Deep Learning executed in = 186.620000 seconds
#  Boucle  44 terminée...Opération restantes : 461 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 45
# amorce :  0
# amorce2 :  0
#  --- Loop : 45  ---  --- Symbol :   ANDV   ---  --- Name :  Andeavor  ---  --- Sector :  Energy  ---
# Scraping data...
# Beta :  0.6934067805828329
#  Alpha :  0.8119759858938802
#  R_Squared :  0.025933815157293427
#  Volatility :  0.524351329744113
#  Momentum :  0.5264519065899884
# executed in = 6.820000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  143
# On 80% - 20% slash :
# Bloc 1 :  114
# Bloc 2 : 29  periods
# First period : 2018-01-04 00:00:00
# Split period : 2018-08-20 00:00:00
# Last period : 2018-10-01 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:27:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 1.950000 seconds
#  Deeping in blue
#
#  --- Loop : 45  ---  --- Symbol :   ANDV   ---  --- Name :  Andeavor  ---  --- Sector :  Energy  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 94/94 [==============================] - 2s 19ms/step
# 94/94 [==============================] - 2s 20ms/step
#  Problème loop :  45
# Loop : 46
# amorce :  0
# amorce2 :  0
#  --- Loop : 46  ---  --- Symbol :   ANSS   ---  --- Name :  ANSYS  ---  --- Sector :  Information Technology  ---
# Scraping data...
# Beta :  1.4512100516096644
#  Alpha :  0.08369111789366222
#  R_Squared :  0.5707616108368325
#  Volatility :  0.2414492103267236
#  Momentum :  0.20274744933915945
# executed in = 2.160000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:28:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.960000 seconds
#  Deeping in blue
#
#  --- Loop : 46  ---  --- Symbol :   ANSS   ---  --- Name :  ANSYS  ---  --- Sector :  Information Technology  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 2s 2ms/step
# 840/840 [==============================] - 2s 3ms/step
# 161/161 [==============================] - 0s 128us/step
# 161/161 [==============================] - 0s 101us/step
#
#
#  RESULTATS UP
#
# Accuracy: 76.40%
#  Precision: 81.58%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 72.09%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.72      0.81      0.76        75
#            1       0.82      0.72      0.77        86
#
#    micro avg       0.76      0.76      0.76       161
#    macro avg       0.77      0.77      0.76       161
# weighted avg       0.77      0.76      0.76       161
#
# [[61 14]
#  [24 62]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 86.34%
#  Precision: 80.30%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 85.48%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89        99
#            1       0.80      0.85      0.83        62
#
#    micro avg       0.86      0.86      0.86       161
#    macro avg       0.85      0.86      0.86       161
# weighted avg       0.87      0.86      0.86       161
#
# [[86 13]
#  [ 9 53]]
#
#
# Deep Learning executed in = 189.270000 seconds
#  Boucle  46 terminée...Opération restantes : 459 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 47
# amorce :  0
# amorce2 :  0
#  --- Loop : 47  ---  --- Symbol :   ANTM   ---  --- Name :  Anthem Inc.  ---  --- Sector :  Health Care  ---
# Scraping data...
# Beta :  0.7414287452351402
#  Alpha :  0.10909976152012876
#  R_Squared :  0.18125423385630623
#  Volatility :  0.21890124354028098
#  Momentum :  0.17713068527357523
# executed in = 3.540000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:31:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 4.980000 seconds
#  Deeping in blue
#
#  --- Loop : 47  ---  --- Symbol :   ANTM   ---  --- Name :  Anthem Inc.  ---  --- Sector :  Health Care  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 2s 2ms/step
# 840/840 [==============================] - 2s 2ms/step
# 161/161 [==============================] - 0s 95us/step
# 161/161 [==============================] - 0s 95us/step
#
#
#  RESULTATS UP
#
# Accuracy: 81.99%
#  Precision: 87.88%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 73.42%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84        82
#            1       0.88      0.73      0.80        79
#
#    micro avg       0.82      0.82      0.82       161
#    macro avg       0.83      0.82      0.82       161
# weighted avg       0.83      0.82      0.82       161
#
# [[74  8]
#  [21 58]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 81.37%
#  Precision: 77.05%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 74.60%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85        98
#            1       0.77      0.75      0.76        63
#
#    micro avg       0.81      0.81      0.81       161
#    macro avg       0.81      0.80      0.80       161
# weighted avg       0.81      0.81      0.81       161
#
# [[84 14]
#  [16 47]]
#
#
# Deep Learning executed in = 191.950000 seconds
#  Boucle  47 terminée...Opération restantes : 458 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV
# Loop : 48
# amorce :  0
# amorce2 :  0
#  --- Loop : 48  ---  --- Symbol :   AON   ---  --- Name :  Aon plc  ---  --- Sector :  Financials  ---
# Scraping data...
# Beta :  0.7907922925609957
#  Alpha :  0.10462409266890965
#  R_Squared :  0.4136204169378572
#  Volatility :  0.15455545316074565
#  Momentum :  0.3351485983601259
# executed in = 1.620000 seconds
#
#
# GOLEM begins Computing...
#
#
# # of periods :  1050
# On 80% - 20% slash :
# Bloc 1 :  840
# Bloc 2 : 210  periods
# First period : 2015-06-01 00:00:00
# Split period : 2018-09-27 00:00:00
# Last period : 2019-07-31 00:00:00
#
#
# Data prep
# Preparing data...
# Boosting
# [11:34:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Boost ok
# Data prepared in = 5.610000 seconds
#  Deeping in blue
#
#  --- Loop : 48  ---  --- Symbol :   AON   ---  --- Name :  Aon plc  ---  --- Sector :  Financials  ---
# Processing move_up
#
#
# Processing move_down
#
#
# Computing done
#
#
# 840/840 [==============================] - 2s 2ms/step
# 840/840 [==============================] - 2s 2ms/step
# 161/161 [==============================] - 0s 116us/step
# 161/161 [==============================] - 0s 85us/step
#
#
#  RESULTATS UP
#
# Accuracy: 77.64%
#  Precision: 80.70%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 64.79%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.81        90
#            1       0.81      0.65      0.72        71
#
#    micro avg       0.78      0.78      0.78       161
#    macro avg       0.78      0.76      0.77       161
# weighted avg       0.78      0.78      0.77       161
#
# [[79 11]
#  [25 46]]
#
#
# _______________________________________________________________________________________________________________________________________________________________
#
#  RESULTATS DOWN
#
# Accuracy: 81.99%
#  Precision: 84.85%    => Discrimnination des vrais positifs parmi les faux positifs
# Recall: 74.67%   => Positifs trouvés par Golem sur tous les positifs existants
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84        86
#            1       0.85      0.75      0.79        75
#
#    micro avg       0.82      0.82      0.82       161
#    macro avg       0.82      0.82      0.82       161
# weighted avg       0.82      0.82      0.82       161
#
# [[76 10]
#  [19 56]]
#
#
# Deep Learning executed in = 195.130000 seconds
#  Boucle  48 terminée...Opération restantes : 457 / 505
#
#  Writing BACKTEST CSV AND SIGNALS.CSV
#  BACKTEST CSV WRITED AND SIGNALS.CSV

# %%
#import sys
#orig_stdout = sys.stdout
#f = open('backtestv2_4.txt', 'w')
#sys.stdout = f

# %%
#f.close()
#sys.stdout = orig_stdout

# %% [markdown]
# import pandas as pd
#
# backtest = pd.DataFrame(columns = ['Symb.','Name','Sector','period','Begin.','End',\
#                           'Pnl','%Pnl','Total Winners','Total Loosers','Nb Win','Nb Los',\
#                           '% Winners','MaxDD','%MaxDD','Aver. Win',\
#                           'Aver. Los','Aver. Duration',\
#                           'Total Trades','% Long','% Short','Profit Factor'])
# backtest.to_csv('BackTest.csv')
#
# signals = pd.DataFrame(columns = ['Date','Ticker','Open Long','Close Long','Open Short','Close Short','Buy/Sell Price','Quantity','tPNL'])
# signals.to_csv('SIGNALS.csv')

# %%
2+2
# Out:
# 4

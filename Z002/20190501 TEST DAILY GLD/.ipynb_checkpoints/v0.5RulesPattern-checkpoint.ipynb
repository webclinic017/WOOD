# %%
___Author___='LumberJack Jyss'

# %%
print('LumberJack BRUTAL AtidotCom TREND RULES\nLumberJack Jyss (c)')
# Out:
# LumberJack BRUTAL AtidotCom TREND RULES
# LumberJack Jyss (c)

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df =  pd.read_csv('simanim.csv')
#df =  pd.read_csv('dataset_daily.csv')

# %%
df.set_index(df['Date'],drop=True,inplace=True)
df = df.iloc[:,1:]
df.head()
# Out:
#             CDL2CROWS  CDL3BLACKCROWS  CDL3INSIDE  CDL3LINESTRIKE  \
# Date
# 2005-04-13          0               0           0               0
# 2005-04-14          0               0           0               0
# 2005-04-15          0               0           0               0
# 2005-04-18          0               0           1               0
# 2005-04-19          0               0           0               0
#
#             CDL3OUTSIDE  CDL3STARSINSOUTH  CDL3WHITESOLDIERS  \
# Date
# 2005-04-13            0                 0                  0
# 2005-04-14            0                 0                  0
# 2005-04-15            0                 0                  0
# 2005-04-18            0                 0                  0
# 2005-04-19            0                 0                  0
#
#             CDLABANDONEDBABY  CDLADVANCEBLOCK  CDLBELTHOLD  ...      ema54  \
# Date                                                        ...
# 2005-04-13                 0                0            0  ...  43.066868
# 2005-04-14                 0                0            0  ...  43.039346
# 2005-04-15                 0                0            0  ...  43.016097
# 2005-04-18                 0                0            0  ...  43.004239
# 2005-04-19                 0                0            0  ...  43.014266
#
#                ema100        rsi     atr14   wclprice       BBup      BBmid  \
# Date
# 2005-04-13  43.259700  50.198871  0.322311  42.857501  42.971103  42.653333
# 2005-04-14  43.240894  39.446509  0.352146  42.315001  43.003763  42.618889
# 2005-04-15  43.224243  41.504796  0.344850  42.430001  43.003763  42.618889
# 2005-04-18  43.213664  47.676419  0.347361  42.669999  43.012780  42.645556
# 2005-04-19  43.214977  57.500760  0.370407  43.160000  43.258868  42.717778
#
#                 BBlow  instant_trendline  Adj Close
# Date
# 2005-04-13  42.335564          42.842474  42.900002
# 2005-04-14  42.234016          42.769000  42.310001
# 2005-04-15  42.234016          42.692527  42.400002
# 2005-04-18  42.278331          42.647200  42.689999
# 2005-04-19  42.176687          42.628505  43.279999
#
# [5 rows x 72 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3535 entries, 2005-04-13 to 2019-04-29
# Data columns (total 72 columns):
# CDL2CROWS              3535 non-null int64
# CDL3BLACKCROWS         3535 non-null int64
# CDL3INSIDE             3535 non-null int64
# CDL3LINESTRIKE         3535 non-null int64
# CDL3OUTSIDE            3535 non-null int64
# CDL3STARSINSOUTH       3535 non-null int64
# CDL3WHITESOLDIERS      3535 non-null int64
# CDLABANDONEDBABY       3535 non-null int64
# CDLADVANCEBLOCK        3535 non-null int64
# CDLBELTHOLD            3535 non-null int64
# CDLBREAKAWAY           3535 non-null int64
# CDLCLOSINGMARUBOZU     3535 non-null int64
# CDLCONCEALBABYSWALL    3535 non-null int64
# CDLCOUNTERATTACK       3535 non-null int64
# CDLDARKCLOUDCOVER      3535 non-null int64
# CDLDOJI                3535 non-null int64
# CDLDOJISTAR            3535 non-null int64
# CDLDRAGONFLYDOJI       3535 non-null int64
# CDLENGULFING           3535 non-null int64
# CDLEVENINGDOJISTAR     3535 non-null int64
# CDLEVENINGSTAR         3535 non-null int64
# CDLGAPSIDESIDEWHITE    3535 non-null int64
# CDLGRAVESTONEDOJI      3535 non-null int64
# CDLHAMMER              3535 non-null int64
# CDLHANGINGMAN          3535 non-null int64
# CDLHARAMI              3535 non-null int64
# CDLHARAMICROSS         3535 non-null int64
# CDLHIGHWAVE            3535 non-null int64
# CDLHIKKAKE             3535 non-null int64
# CDLHIKKAKEMOD          3535 non-null int64
# CDLHOMINGPIGEON        3535 non-null int64
# CDLIDENTICAL3CROWS     3535 non-null int64
# CDLINNECK              3535 non-null int64
# CDLINVERTEDHAMMER      3535 non-null int64
# CDLKICKING             3535 non-null int64
# CDLKICKINGBYLENGTH     3535 non-null int64
# CDLLADDERBOTTOM        3535 non-null int64
# CDLLONGLEGGEDDOJI      3535 non-null int64
# CDLLONGLINE            3535 non-null int64
# CDLMARUBOZU            3535 non-null int64
# CDLMATCHINGLOW         3535 non-null int64
# CDLMATHOLD             3535 non-null int64
# CDLMORNINGDOJISTAR     3535 non-null int64
# CDLMORNINGSTAR         3535 non-null int64
# CDLONNECK              3535 non-null int64
# CDLPIERCING            3535 non-null int64
# CDLRICKSHAWMAN         3535 non-null int64
# CDLRISEFALL3METHODS    3535 non-null int64
# CDLSEPARATINGLINES     3535 non-null int64
# CDLSHOOTINGSTAR        3535 non-null int64
# CDLSHORTLINE           3535 non-null int64
# CDLSPINNINGTOP         3535 non-null int64
# CDLSTALLEDPATTERN      3535 non-null int64
# CDLSTICKSANDWICH       3535 non-null int64
# CDLTAKURI              3535 non-null int64
# CDLTASUKIGAP           3535 non-null int64
# CDLTHRUSTING           3535 non-null int64
# CDLTRISTAR             3535 non-null int64
# CDLUNIQUE3RIVER        3535 non-null int64
# CDLUPSIDEGAP2CROWS     3535 non-null int64
# CDLXSIDEGAP3METHODS    3535 non-null int64
# ema9                   3535 non-null float64
# ema54                  3535 non-null float64
# ema100                 3535 non-null float64
# rsi                    3535 non-null float64
# atr14                  3535 non-null float64
# wclprice               3535 non-null float64
# BBup                   3535 non-null float64
# BBmid                  3535 non-null float64
# BBlow                  3535 non-null float64
# instant_trendline      3535 non-null float64
# Adj Close              3535 non-null float64
# dtypes: float64(11), int64(61)
# memory usage: 2.0+ MB

# %%
df.shape
# Out:
# (3535, 72)

# %%
df.shape[0]
# Out:
# 3535

# %%
df.tail()
# Out:
#             CDL2CROWS  CDL3BLACKCROWS  CDL3INSIDE  CDL3LINESTRIKE  \
# Date
# 2019-04-23          0               0           0               0
# 2019-04-24          0               0           0               0
# 2019-04-25          0               0           0               0
# 2019-04-26          0               0           0               0
# 2019-04-29          0               0           0               0
#
#             CDL3OUTSIDE  CDL3STARSINSOUTH  CDL3WHITESOLDIERS  \
# Date
# 2019-04-23            0                 0                  0
# 2019-04-24            0                 0                  0
# 2019-04-25            0                 0                  0
# 2019-04-26            0                 0                  0
# 2019-04-29            0                 0                  0
#
#             CDLABANDONEDBABY  CDLADVANCEBLOCK  CDLBELTHOLD  ...       ema54  \
# Date                                                        ...
# 2019-04-23                 0                0            0  ...  122.151680
# 2019-04-24                 0                0            1  ...  122.090528
# 2019-04-25                 0                0            0  ...  122.035237
# 2019-04-26                 0                0            0  ...  122.011046
# 2019-04-29                 0                0            0  ...  121.968099
#
#                 ema100        rsi     atr14    wclprice        BBup  \
# Date
# 2019-04-23  121.424750  35.358774  0.821959  119.997501  123.324155
# 2019-04-24  121.405844  38.791876  0.811819  120.425001  122.217207
# 2019-04-25  121.389293  39.776020  0.798832  120.684999  121.819162
# 2019-04-26  121.388911  47.103571  0.820344  121.407501  121.583385
# 2019-04-29  121.377843  43.275994  0.811748  120.810001  121.236605
#
#                  BBmid       BBlow  instant_trendline   Adj Close
# Date
# 2019-04-23  121.173334  119.022512         121.756314  120.120003
# 2019-04-24  120.833334  119.449461         121.630545  120.470001
# 2019-04-25  120.680001  119.540841         121.531439  120.570000
# 2019-04-26  120.628890  119.674396         121.450789  121.370003
# 2019-04-29  120.543335  119.850065         121.374009  120.830002
#
# [5 rows x 72 columns]

# %%
long_list = []
short_list = []
equity_list = []
var_long_list = []
var_short_list = []
candle_close = 0
candle_close_1 = 0
candle_close_2 = 0
candle_close_3 = 0
candle_close_4 = 0
candle_close_5 = 0
candle_open = 0
candle_high = 0
candle_low = 0
n=0
c = 0
cc = 0
long_target = 0.01
short_target = -0.01
ticket = 100000
equity = 100000
print('Début de la boucle')

import sys
orig_stdout = sys.stdout
f = open('OUt_rules.txt', 'w')
sys.stdout = f


for i in range(5,df.shape[0]-1):
    print('\nCompteur de ligne :',i)
    print('Date :',df.index[i])
    c+=1
    
    candle_close = float(df.iloc[i,-3])
    candle_close_1 = float(df.iloc[i-1,-3])
    print('candle_close_1',candle_close_1)
    candle_close_2 = float(df.iloc[i-2,-3])
    candle_close_3 = float(df.iloc[i-3,-3])
    candle_close_4 = float(df.iloc[i-4,-3])
    candle_close_5 = float(df.iloc[i-5,-3])
    candle_open = float(df.iloc[i,-3])
    #candle_high = float(df.iloc[i,7])
    #candle_low = float(df.iloc[i,8])
    
    var1 = candle_open - candle_close_1
    var2 = candle_open - candle_close_2
    var3 = candle_open - candle_close_3
    var4 = candle_open - candle_close_4
    var5 = candle_open - candle_close_5
    
    if var1/candle_close_1 > long_target or var2/candle_close_2 > long_target or\
    var3/candle_close_3 > long_target or var4/candle_close_4 > long_target or var5/candle_close_5 > long_target:
        var_long_list.append(var1)
        var_long_list.append(var2)
        var_long_list.append(var3)
        var_long_list.append(var4)
        var_long_list.append(var5)
        print('\nDate :',df.index[i])
        print('Long effectué, :',var1,', ',var2,', ',var3,', ',var4)
        print('close actuel',candle_open)
        n = round(ticket/candle_open)
        print('n ',n)
        print("les 4 close d'avant",\
              candle_close_1,candle_close_2,candle_close_3,\
              candle_close_4,candle_close_5)
        print('Max ',max(var_long_list))
        print('pnl :',max(var_long_list)*ticket)
        equity = equity -(n/100) + max(var_long_list)*n
        #equity = equity - 3 + max(var_long_list)*ticket
        print('Nouvel equity :',equity)
        long_list.append(1)
        short_list.append(0)
        equity_list.append(equity)
        cc+=1
        var_long_list = []
    
    elif var1/candle_close_1 < short_target or var2/candle_close_2 < short_target or \
    var3/candle_close_3 < short_target or var4/candle_close_4 < short_target or var5/candle_close_5 < short_target:
        var_short_list.append(var1)
        var_short_list.append(var2)
        var_short_list.append(var3)
        var_short_list.append(var4)
        var_short_list.append(var5)
        print('\nDate :',df.index[i])
        print('Short effectué :',var1,', ',var2,', ',var3,', ',var4)
        print('close actuel',candle_open)
        n = round(ticket/candle_open)
        print('n ',n)
        print("les 4 close d'avant",\
              candle_close_1,candle_close_2,candle_close_3,\
              candle_close_4,candle_close_5)
        print('Min ',-min(var_short_list))
        print('pnl :', - min(var_short_list)*ticket)
        equity = equity -n/100 - min(var_short_list)*n
        #equity = equity - 3 - min(var_short_list)*ticket
        print('Nouvel equity :',equity)
        short_list.append(1)
        long_list.append(0)
        equity_list.append(equity)
        cc+=1
        var_short_list = []
    
    else :
        print('\nDate :',df.index[i])
        print('Il ne se passe rien')
        short_list.append(0)
        long_list.append(0)
        equity_list.append(equity)
        cc+=1


print('Boucle terminée')
print('La long target était fixée à ',long_target)
print('La short target était fixée à ',short_target)
print('La règle était 4 périodes consécutives au dessus de long ou au dessous de short')
print('Il y a eu ',df.shape[0],' périodes testées')
print('Durant cette période,',sum(long_list),' long et ',sum(short_list),' short')
print("Les gains totaux s'élèvent à :",round(equity-100000),'$' )
    
f.close()
sys.stdout = orig_stdout


print('Boucle terminée')
print('La long target était fixée à ',long_target)
print('La short target était fixée à ',short_target)
print("La règle était qu'une des 5 periodes d'avant était inférieure ou supérieure à la target (long ou short)")
print('Il y a eu ',df.shape[0],' périodes testées')
print('Durant cette période,',sum(long_list),' long et ',sum(short_list),' short')
print("Les gains totaux s'élèvent à :",round(equity-100000),'$' )

var_dtf = pd.DataFrame()
var_dtf['Long'] = long_list
var_dtf['Short'] = short_list
var_dtf['Equity'] = equity_list
# Out:
# Début de la boucle
# Boucle terminée
# La long target était fixée à  0.01
# La short target était fixée à  -0.01
# La règle était qu'une des 5 periodes d'avant était inférieure ou supérieure à la target (long ou short)
# Il y a eu  3529  périodes testées
# Durant cette période, 1775  long et  1201  short
# Les gains totaux s'élèvent à : 7702399 $

# %%
candle_close,candle_close_1,candle_close_2,candle_close_3,candle_close_4,candle_close_5,candle_open
# Out:
# (120.56999969482422,
#  120.47000122070312,
#  120.12000274658205,
#  120.37000274658205,
#  120.37000274658205,
#  120.27999877929688,
#  120.56999969482422)

# %%
sum(short_list)+sum(long_list), c, cc, len(short_list),len(long_list),len(equity_list),len(df)
# Out:
# (2976, 3523, 3523, 3523, 3523, 3523, 3529)

# %%
plt.figure(figsize=(16,6))
plt.plot(var_dtf['Long'],color='orange',label='Long')
plt.plot(var_dtf['Short'],color='purple',label='Short')
plt.axhline(y=long_target, color='cyan',linestyle='-', label='Long Target')
plt.axhline(y=0, color='red',linestyle='--', label='Zéro')
plt.axhline(y=short_target,color='cyan',label='Short Target')
plt.legend()

# %%
plt.figure(figsize=(16,6))
plt.plot(var_dtf['Equity'],color='green',label='Equity')
plt.axhline(y=100000., color='red',linestyle='-', label='mise de départ')
plt.legend()

# %%
len(short_list),len(long_list),len(df)
# Out:
# (3523, 3523, 3529)

# %%
df = df.iloc[5:(df.shape[0]-1),:]
df['short'] = short_list
df['long'] = long_list

# %%
print('Nombre de positions de long trouvées :',sum(long_list))
print('Nombre de positions short trouvées :',sum(short_list))
print('Sur un total de ',sum(short_list)+sum(long_list))
# Out:
# Nombre de positions de long trouvées : 1775
# Nombre de positions short trouvées : 1201
# Sur un total de  2976

# %%
print('Sur un achat systématique, les gains représentent',\
      round((sum(short_list)+sum(long_list))/(len(short_list)+len(long_list))*100,2),'%')
# Out:
# Sur un achat systématique, les gains représentent 42.24 %

# %%
#df['short'] = df['trend'].shift(-1)

# %%
df.tail()
# Out:
#             CDL2CROWS  CDL3BLACKCROWS  CDL3INSIDE  CDL3LINESTRIKE  \
# Date
# 2019-04-18          0               0           0               0
# 2019-04-22          0               0           0               0
# 2019-04-23          0               0           0               0
# 2019-04-24          0               0           0               0
# 2019-04-25          0               0           0               0
#
#             CDL3OUTSIDE  CDL3STARSINSOUTH  CDL3WHITESOLDIERS  \
# Date
# 2019-04-18            0                 0                  0
# 2019-04-22            0                 0                  0
# 2019-04-23            0                 0                  0
# 2019-04-24            0                 0                  0
# 2019-04-25            0                 0                  0
#
#             CDLABANDONEDBABY  CDLADVANCEBLOCK  CDLBELTHOLD  ...        rsi  \
# Date                                                        ...
# 2019-04-18                 0                0            0  ...  36.725020
# 2019-04-22                 0                0            0  ...  36.725020
# 2019-04-23                 0                0            0  ...  35.358774
# 2019-04-24                 0                0            1  ...  38.791876
# 2019-04-25                 0                0            0  ...  39.776020
#
#                atr14    wclprice        BBup       BBmid       BBlow  \
# Date
# 2019-04-18  0.867657  120.357502  123.996506  121.747778  119.499050
# 2019-04-22  0.822110  120.377501  123.837248  121.510000  119.182753
# 2019-04-23  0.821959  119.997501  123.324155  121.173334  119.022512
# 2019-04-24  0.811819  120.425001  122.217207  120.833334  119.449461
# 2019-04-25  0.798832  120.684999  121.819162  120.680001  119.540841
#
#             instant_trendline   Adj Close  short  long
# Date
# 2019-04-18         122.169713  120.370003      1     0
# 2019-04-22         121.938163  120.370003      1     0
# 2019-04-23         121.756314  120.120003      1     0
# 2019-04-24         121.630545  120.470001      0     0
# 2019-04-25         121.531439  120.570000      0     0
#
# [5 rows x 74 columns]

# %%
df = df.dropna()
df.tail()
# Out:
#             CDL2CROWS  CDL3BLACKCROWS  CDL3INSIDE  CDL3LINESTRIKE  \
# Date
# 2019-04-18          0               0           0               0
# 2019-04-22          0               0           0               0
# 2019-04-23          0               0           0               0
# 2019-04-24          0               0           0               0
# 2019-04-25          0               0           0               0
#
#             CDL3OUTSIDE  CDL3STARSINSOUTH  CDL3WHITESOLDIERS  \
# Date
# 2019-04-18            0                 0                  0
# 2019-04-22            0                 0                  0
# 2019-04-23            0                 0                  0
# 2019-04-24            0                 0                  0
# 2019-04-25            0                 0                  0
#
#             CDLABANDONEDBABY  CDLADVANCEBLOCK  CDLBELTHOLD  ...        rsi  \
# Date                                                        ...
# 2019-04-18                 0                0            0  ...  36.725020
# 2019-04-22                 0                0            0  ...  36.725020
# 2019-04-23                 0                0            0  ...  35.358774
# 2019-04-24                 0                0            1  ...  38.791876
# 2019-04-25                 0                0            0  ...  39.776020
#
#                atr14    wclprice        BBup       BBmid       BBlow  \
# Date
# 2019-04-18  0.867657  120.357502  123.996506  121.747778  119.499050
# 2019-04-22  0.822110  120.377501  123.837248  121.510000  119.182753
# 2019-04-23  0.821959  119.997501  123.324155  121.173334  119.022512
# 2019-04-24  0.811819  120.425001  122.217207  120.833334  119.449461
# 2019-04-25  0.798832  120.684999  121.819162  120.680001  119.540841
#
#             instant_trendline   Adj Close  short  long
# Date
# 2019-04-18         122.169713  120.370003      1     0
# 2019-04-22         121.938163  120.370003      1     0
# 2019-04-23         121.756314  120.120003      1     0
# 2019-04-24         121.630545  120.470001      0     0
# 2019-04-25         121.531439  120.570000      0     0
#
# [5 rows x 74 columns]

# %%
df['short'].sum(),df['long'].sum()
# Out:
# (1201, 1775)

# %%
df.to_csv('dataset_ready_to_use.csv')

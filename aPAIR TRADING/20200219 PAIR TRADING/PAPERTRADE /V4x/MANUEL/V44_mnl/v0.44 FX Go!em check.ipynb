# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
############################
######## LIBRAIRIES ########
############################
print('Importing Librairies...')
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import time
import os
import datetime as dt
import fxcmpy
import itertools
import shelve
#from twilio.rest import Client
import pyttsx3
engine = pyttsx3.init()
#import pygame
#pygame.init()

print('Librairies imported\n')
print('version fxcmpy :',fxcmpy.__version__)
# %matplotlib inline
plt.style.use('seaborn')
try:
    son = pygame.mixer.Sound("lib_loaded.mp3")
    son.play()
except:
    engine.say("librairie loaded")
engine.runAndWait()
#ignore by message
import warnings
warnings.filterwarnings("ignore", message="A value is trying to be set on a copy of a slice from a DataFrame.")
warnings.filterwarnings("ignore", message="Try using .loc[row_indexer,col_indexer] = value instead")
warnings.filterwarnings("ignore", message="The inverse of the variance-covariance matrix was calculated using the Moore-Penrose generalized matrix inversion, due to its determinant being at or very close to zero.")
warnings.filterwarnings("ignore", message="The inverse of the variance-covariance matrix ")
print('Prêt')
# Out:
# Importing Librairies...
# Librairies imported
#
# version fxcmpy : 1.2.6
# Prêt

# %%
try:
    son = pygame.mixer.Sound("ignition.mp3")
    son.play()
except:
    engine.say("Ignition du Lumberjack")
    engine.runAndWait() 

##############################################
######## INITIALISATION DES VARIABLES ########
##############################################



# COMPTE TEST #

TOKEN = '039add1dbe2b344ed08c518a98c7a1796f7a33c2'
server = 'demo'
user_id = 'D261219574'
compte = '01215057'
password = '3555'


'''
# COMPTE DEV #
TOKEN = '79f83cbff13d296eb6d9b6c1ed6dccd768ef925a'
server = 'demo'
user_id = 'D261219577'
compte = '01215060'
password = '3877'
'''


'''
# COMPTE POUBELLE #
TOKEN = 'a66bf5c0ec732487f4b348baf6364d3ee8784935'
server = 'demo'
user_id = 'D261219576'
compte = '01215059'
password = '8029'
'''

try:
    son = pygame.mixer.Sound("bsd.mp3")
    son.play()
except:
    engine.say("בסדר")
    engine.runAndWait()

# %%
############################
######## FONCTIONS ########
###########################


def conX():
    con = fxcmpy.fxcmpy(access_token=TOKEN, log_level='error',server=server)
    if con.is_connected() == True:
        print(Fore.GREEN+'Connexion établie'+Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
    else:
        print(Fore.RED+'Connexion non établie'+Style.RESET_ALL)
    return(con)

def deconX():
    con = con.close()
    if con.is_connected() == True:
        print(Fore.GREEN+'Connexion non intérrompue'+Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
    else:
        print(Fore.RED+'Connexion intérrompue'+Style.RESET_ALL)
    return()

engine.say("functions initiated")
engine.runAndWait()
print('Functions initiated')
# Out:
# Functions initiated

# %%
#########################
### CONNEXION A L'API ###
#########################

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor for FOR_EX\nLumberJack Jyss 5780(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print(Fore.YELLOW,Back.BLUE,'--- Go!em ForeX #v0.44 ---',Style.RESET_ALL)


print('')
try:
    son = pygame.mixer.Sound("init_forex.mp3")
    son.play()

    son = pygame.mixer.Sound("conx_api.mp3")
    son.play()

except:
    engine.say(" Initialisation du check Gaulem faurex")
    engine.say("Connexion du Gaulem hà la Péh e")
    engine.runAndWait()

try:
    con.is_connected() == True
    
    try:
        son = pygame.mixer.Sound("alr_connected.mp3")
        son.play()
    except:
        engine.say("already Connected")
        engine.runAndWait()
    print(Fore.GREEN+'Connexion rétablie'+Style.RESET_ALL)
    print('Compte utilisé : ',con.get_account_ids())
    print('')
    
except:
    try:
        con = conX()
        con.is_connected() == True
        print(Fore.GREEN+'Connexion établie'+Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
        try:
            son = pygame.mixer.Sound("connected.mp3")
            son.play()
        except:
            engine.say("Connected, check papa")
            engine.runAndWait()
    except:
        print(Fore.RED+'Connexion non établie'+Style.RESET_ALL)
        try:
            son = pygame.mixer.Sound("not_connected1.mp3")
            son.play()
            son = pygame.mixer.Sound("not_connected2.mp3")
            son.play()
        except:
            engine.say("Not Connected, sal rass de mor, pitun cé la merd")
            engine.say("vérifi ton internet, é relance le gaulèm")
            engine.runAndWait()
        print('')
        #os._exit(0)
        con = deconX()
        time.sleep(1)
        con = conX()



#########################
####### OPERATIVE #######
#########################
OPEN_POZ = []
TICKERS = []
pair0 = 0
pair1 = 0
pair2 = 0
pair3 = 0
pair4 = 0

nb_pattes = int(input('Combien de pattes?'))

for x in range(nb_pattes):
    globals()['pair%s' %str(x)] = input('Entrez la pair')
    TICKERS.append(globals()['pair%s' %x])

    for x in range (len(con.get_open_positions().currency)):
        for foo in TICKERS:
                if foo == con.get_open_positions().currency[x]:
                            OPEN_POZ.append(con.get_open_positions().tradeId[x])
# Out:
# Global Optimized LumberJack Environment Motor for FOR_EX
# LumberJack Jyss 5780(c)
#  °0Oo_D.A.G._26_oO0°
#   --- Go!em ForeX #v0.44 ---
#
# Connexion rétablie
# Compte utilisé :  [20263190]

# %%
balance = con.get_accounts().balance
balance = balance[0]
equity = con.get_accounts().equity
equity = equity[0]
resum = con.get_open_positions()
usable_margin = con.get_accounts_summary().usableMargin3Perc[0]

print('Balance : ',balance)

print('Equity : ',equity)

print('Marge disponible ;',usable_margin,'%')
print('')



if len(resum) == 0:
    print('\nPas de position actuellement en cours. Vous pouvez procéder à la suite\n')
    print(Fore.BLUE,'\nTimeframe :',period,' et nombre de pattes ',nb_pattes,'\n',Style.RESET_ALL)
    
    time.sleep(120)

else:
    for loop in range(72000):
        pnl = 0
        for x in OPEN_POZ:
            pnl += con.get_open_position(str(x)).get_grossPL()
        if pnl >=0:
            print('\r',Fore.GREEN+'Dynamic NET PNL :',round(pnl,2),'€ --- ',Style.RESET_ALL,end='',flush=True)
        elif (pnl < 0) :
            print('\r',Fore.RED+'Dynamic NET PNL :',round(pnl,2),'€ ---',Style.RESET_ALL,end='',flush=True)
        
        time.sleep(5)
# Out:
# Balance :  51987.24
# Equity :  52061.37631
# Marge disponible ; 73.33547 %
#
# Dynamic NET PNL : -121.65 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -121.77 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -122.86 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -122.9 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -121.97 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -121.97 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -122.94 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -116.49 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -110.06 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -110.06 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -110.05 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -109.88 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -110.0 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -131.2 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -135.55 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -135.82 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -138.53 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -139.04 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -139.04 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -139.04 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -138.19 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -125.31 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -126.12 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -129.33 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -129.33 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -129.33 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -129.22 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -129.22 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -129.22 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -129.1 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -129.06 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -129.06 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -128.57 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -128.57 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -129.27 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -129.32 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -129.32 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -127.43 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -102.45 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -106.83 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -113.22 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -113.11 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -113.22 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -113.27 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -113.27 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.47 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -113.0 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.42 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.42 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.42 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.44 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.44 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.44 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.37 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.37 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.18 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.18 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.18 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.18 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.36 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.36 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.36 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -112.12 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -111.42 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -111.42 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -111.42 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -111.42 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -108.2 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -108.2 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -108.2 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -108.2 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -109.48 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -109.47 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -110.03 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -110.26 € --- 2.6666666666666665 couches
# Dynamic NET PNL : -110.26 € --- 2.6666666666666665 couches
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d4f405bce8a0> in <module>
#      29             print('\r'+Fore.GREEN+'Dynamic NET PNL :',round(pnl,2),'€ --- ',len(con.get_open_positions())/nb_pattes,'couches'+Style.RESET_ALL,'\n',end='',flush=True)
#      30         elif (pnl < 0) :
# ---> 31             print('\r'+Fore.RED+'Dynamic NET PNL :',round(pnl,2),'€ ---',len(con.get_open_positions())/nb_pattes,'couches'+Style.RESET_ALL,'\n',end='',flush=True)
#      32
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/fxcmpy/fxcmpy.py in get_open_positions(self, kind)
#     370
#     371         """
# --> 372         data = self.get_model(('OpenPosition',))
#     373         open_pos = data['open_positions']
#     374         if kind == 'list':
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/fxcmpy/fxcmpy.py in get_model(self, models, summary)
#     343
#     344         data = self.__handle_request__(method='trading/get_model',
# --> 345                                        params={'models': list(models)})
#     346
#     347         total = dict()
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/fxcmpy/fxcmpy.py in __handle_request__(self, method, params, protocol)
#    2478             req = requests.get('%s:443/%s' % (self.trading_url, method),
#    2479                                headers=self.request_headers, params=params,
# -> 2480                                proxies=self.proxies)
#    2481             self.logger.info('Sending GET Request:')
#    2482             self.logger.info('URL: %s' % req.url)
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1837             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1838         else:
# -> 1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# KeyboardInterrupt:

# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# https://www.datacamp.com/community/tutorials/introduction-factor-analysis

# %%
############################
######## LIBRAIRIES ########
############################

import pandas as pd
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from sklearn import preprocessing
from statsmodels.tsa.stattools import adfuller
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import time
import numpy as np
# %matplotlib inline
plt.style.use('seaborn')

# %%
############################
######## FONCTIONS ########
###########################
def ols(model,results,residuals):
    jb = sm.stats.stattools.jarque_bera(residuals)[0]
    p_value = sm.stats.stattools.jarque_bera(residuals)[1]
    skew = round(sm.stats.stattools.robust_skewness(residuals)[0],4)
    kurtosis = round(sm.stats.stattools.robust_kurtosis(residuals)[0],4)
    print (name+' : ',results.summary())
    durbinwatson = sm.stats.stattools.durbin_watson(residuals, axis=0)
    print (name+' : ',durbinwatson)
    return(jb,p_value,skew,kurtosis,durbinwatson)

def ols_diff(diff):
    model_diff = sm.OLS(diff[1:],df.index[1:])
    results_diff = model_diff.fit()
    residuals_diff = results_diff.resid
    summary_diff = results_diff.summary()

    jb_diff = sm.stats.stattools.jarque_bera(residuals_diff)[0]
    p_value_diff = sm.stats.stattools.jarque_bera(residuals_diff)[1]
    skew_diff = round(sm.stats.stattools.robust_skewness(residuals_diff)[0],4)
    kurtosis_diff = round(sm.stats.stattools.robust_kurtosis(residuals_diff)[0],4)
    print (name+' : ',results_diff.summary())
    durbinwatson_diff = sm.stats.stattools.durbin_watson(residuals_diff, axis=0)
    print (name+' : ',durbinwatson_diff)
    return(jb_diff,p_value_diff,skew_diff,kurtosis_diff,durbinwatson_diff)

def jarque_berra(df):
    print(Fore.LIGHTBLUE_EX,'\nTEST DE NORMALITE : JARQUE-BERA '+name,Style.RESET_ALL)
    if p_value <= 0.05:
        print("Puisque la p-value (",round(p_value,4),") de la statistique de Jarque-Bera est inférieure au seuil de signification de 5%, donc on ",\
        "refuse l’hypothèse de la normalité de la série ")
        print(Fore.GREEN,'TEST JARQUE-BERRA VALIDE',Style.RESET_ALL)
    else:
        print("Puisque la p-value (",round(p_value,4),") de la statistique de Jarque-Bera est supérieure au seuil de signification de 5%",\
        " donc on refusel’hypothèse de la normalité de la série ")
        print(Fore.RED,"TEST JARQUE-BERA ECHOUE",Style.RESET_ALL)
    return()

def skewness(df):
    print(Fore.LIGHTBLUE_EX,"\nTEST D'ASSYMETRIE: SKEWNESS "+name,Style.RESET_ALL)
    if skew < -0.1 or skew > 0.1:
        print("Puisque le skewness (",round(skew,4),") de la statistiqest éloigné de 0, donc on valide en niveau 1 une distribution NON NORMALE")
        print(Fore.GREEN,'TEST SKEWNESS VALIDE',Style.RESET_ALL)
    else:
        print(Fore.RED,'/!\ ATTENTION SUPISCION DE NORMALITE /!\ ')
        print(Fore.RED,"TEST SKEWNESS ECHOUE",Style.RESET_ALL)
    return()

def kurtos(df):
    print(Fore.LIGHTBLUE_EX,"\nTEST D'ASSYMETRIE: KURTOSIS "+name,Style.RESET_ALL)
    if kurtosis > -3.1 or kurtosis < 3.1:
        print("Puisque le skewness (",round(kurtosis,4),") de la statistiqest éloigné de 3, donc on valide en niveau 2 une distribution NON NORMALE")
        print(Fore.GREEN,'TEST DE KURTOSIS VALIDE',Style.RESET_ALL)
    else:
        print(Fore.RED,'/!\ ATTENTION SUPISCION DE NORMALITE /!\ ')
        print(Fore.RED,"TEST KURTOSIS ECHOUE",Style.RESET_ALL)
    return()
def autocor(df):
    print(Fore.LIGHTBLUE_EX,"\nCORRELOGRAMME D'AUTOCORRELATION DE LA PAIRE "+name,Style.RESET_ALL)
    plot_acf(df['Close'])
    plot_pacf(df['Close'], lags=50)
    autocorell = pd.DataFrame()
    autocorell['ACF'] = sm.tsa.stattools.acf(df['Close'],qstat=True,fft=False)[0]
    autocorell['PACF'] = sm.tsa.stattools.pacf(df['Close'])
    QSTAT = list(sm.tsa.stattools.acf(df['Close'],qstat=True,fft=False)[1])
    QSTAT.append(df.iloc[-1]['Close'])
    PROB = list(sm.tsa.stattools.acf(df['Close'],qstat=True,alpha=0.05,fft=False)[3])
    PROB.append(0.5)
    autocorell['QSTAT'] = QSTAT
    autocorell['PROB'] = PROB
    print(name+' : ',autocorell.head())
    index = 0
    for i in range(len(autocorell)-1):
        if autocorell.iloc[i]['PACF']>autocorell.iloc[i]['PROB']+0.1:
            index += 1
    if index >= 1:
        print("L'index de sortie de l'intervalle de confiance à 5% est de",index,". Il apparait donc clairement que la série n'est pas un bruit blanc")
        print(Fore.GREEN,'TEST AUTOCORRELATION VALIDE',Style.RESET_ALL)
    else:
        print("L'index de sortie de l'intervalle de confiance à 5% est de",index,". Nous ne pouvons pas déterminer que la série n'est pas un bruit blanc")
    return()

def autocor_diff(diff):
    print(Fore.LIGHTBLUE_EX,"\nCORRELOGRAMME D'AUTOCORRELATION DE LA PAIRE EUR/USD EN PREMIERE DIFFERENCE",Style.RESET_ALL)
    plot_acf(diff)
    plot_pacf(diff, lags=50)
    autocorell = pd.DataFrame()
    autocorell['ACF'] = sm.tsa.stattools.acf(diff,qstat=True,fft=False)[0]
    autocorell['PACF'] = sm.tsa.stattools.pacf(diff)
    QSTAT = list(sm.tsa.stattools.acf(diff,qstat=True)[1],fft=False)
    QSTAT.append(0)
    PROB = list(sm.tsa.stattools.acf(diff,qstat=True,alpha=0.05)[3],fft=False)
    PROB.append(0.5)
    autocorell['QSTAT'] = QSTAT
    autocorell['PROB'] = PROB
    print(name+' : ',autocorell.head())
    index = 0
    for i in range(len(autocorell)-1):
        if autocorell.iloc[i]['PACF']>autocorell.iloc[i]['PROB']+0.1:
            index += 1
    if index >= 1:
        print("L'index de sortie de l'intervalle de confiance à 5% est de",index,". Il apparait donc clairement que la série n'est pas un bruit blanc")
        print(Fore.GREEN,'TEST AUTOCORRELATION VALIDE',Style.RESET_ALL)
        print("D’après le corrélogramme de la série ‘EURUSD’ en différence première, nous constatons que la première bande associée à la fonction    d’auto-corrélation partielle sort significativement de l’intervalle de confiance représenté par les pointillés, donc nous retenons p = 1 comme nombre de retards pour les régressions des tests ADF")
        p = 1
    else:
        print("L'index de sortie de l'intervalle de confiance à 5% est de",index,". Nous ne pouvons pas déterminer que la série n'est pas un bruit blanc")
    return()

def test_stationarity(timeseries,lag):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(window=12).mean()
    rolstd = timeseries.rolling(window=12).std()

    #Plot rolling statistics:
    plt.figure(figsize=(20,6))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation for '+name)
    plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test pour la paire : '+name)
    dftest = adfuller(timeseries, autolag=None,maxlag=lag )#'AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)
    return(dfoutput)

def test_adf(df):
    print(Fore.BLUE,"\nADF MODELE 3 pour la paire : "+name,Style.RESET_ALL)
    X = df['Close'].values
    result_adf = adfuller(X)
    print('ADF Statistic: %f' % result_adf[0])
    print('p-value: %f' % result_adf[1])
    print('Critical Values:')

    for key, value in result_adf[4].items():
        print('\t%s: %.3f' % (key, value))

    if result_adf[1] >= 0.05:
        print("La p_value est de ",result_adf[1],"et est bien supérieure à 0.05. On accèpte l'hypothèse nulle Ho. Il n'y a pas de trend significatif")
        print(Fore.GREEN,'TEST ADF => NON STATIONNAIRE',Style.RESET_ALL)

    else:
        print(Fore.RED,"TEST ADF => STATIONNAIRE",Style.RESET_ALL)

    print(Fore.BLUE,"\nADF MODELE 2 (LAG)",Style.RESET_ALL)
    X = diff[1:].values
    result_adf = adfuller(X)
    print('ADF Statistic: %f' % result_adf[0])
    print('p-value: %f' % result_adf[1])
    print('Critical Values:')

    for key, value in result_adf[4].items():
        print('\t%s: %.3f' % (key, value))

    if result_adf[1] >= 0.05 :
        print(Fore.GREEN,'TEST ADF => NON STATIONNAIRE',Style.RESET_ALL)

    elif result_adf[0] >= min([result_adf[4]['1%'],result_adf[4]['5%'],result_adf[4]['10%']]):
        print(Fore.GREEN,'TEST ADF => NON STATIONNAIRE',Style.RESET_ALL)

    else:
        print("La série est stationnaire en intégration d'ordre 1")
        print(Fore.RED,"TEST ADF => STATIONNAIRE",Style.RESET_ALL)
    return()

def isname(pair):
    if pair.equals(eurusd):
        name = 'EUR/USD'
    elif pair.equals(audusd):
        name = 'AUD/USD'
    elif pair.equals(chfusd):
        name = 'CHF/USD'
    elif pair.equals(gbpusd):
        name = 'GBP/USD'
    elif pair.equals(jpyusd):
        name = 'JPY/USD'
    
    return(name)

def revname(name):
    if name == 'EUR/USD':
        pair = eurusd
    elif name == 'AUD/USD':
        pair = audusd
    elif name == 'CHF/USD':
        pair = chfusd
    elif name == 'GBP/USD':
        pair = gbpusd
    elif name == 'JPY/USD':
        pair = jpyusd
        
    return(pair)

# %%
eurusd = pd.read_csv('EURUSD.csv')
#eurusd.index = eurusd['Local time']
#eurusd = eurusd.drop(['Local time'],axis=1)
eurusd = eurusd[(eurusd['Local time'] >= '01.06.2011 00:00:00.000 GMT+0200')&(eurusd['Local time'] <= '07.06.2011 13:30:00.000 GMT+0200')]
try:
    eurusd = eurusd.drop(['Unnamed: 0'],axis=1)
except:
    pass

audusd = pd.read_csv('AUDUSD.csv')
#audusd.index = audusd['Local time']
#audusd = audusd.drop(['Local time'],axis=1)
audusd = audusd[(audusd['Local time'] >= '01.06.2011 00:00:00.000 GMT+0200')&(audusd['Local time'] <= '07.06.2011 13:30:00.000 GMT+0200')]
try:
    audusd = audusd.drop(['Unnamed: 0'],axis=1)
except:
    pass

chfusd = pd.read_csv('CHFUSD.csv')
#chfusd.index = chfusd['Local time']
#chfusd = chfusd.drop(['Local time'],axis=1)
chfusd = chfusd[(chfusd['Local time'] >= '01.06.2011 00:00:00.000 GMT+0200')&(chfusd['Local time'] <= '07.06.2011 13:30:00.000 GMT+0200')]
try:
    chfusd = chfusd.drop(['Unnamed: 0'],axis=1)
except:
    pass

gbpusd = pd.read_csv('GBPUSD.csv')
#gbpusd.index = gbpusd['Local time']
#gbpusd = gbpusd.drop(['Local time'],axis=1)
gbpusd = gbpusd[(gbpusd['Local time'] >= '01.06.2011 00:00:00.000 GMT+0200')&(gbpusd['Local time'] <= '07.06.2011 13:30:00.000 GMT+0200')]
try:
    gbpusd = gbpusd.drop(['Unnamed: 0'],axis=1)
except:
    pass

jpyusd = pd.read_csv('JPYUSD.csv')
#jpyusd.index = jpyusd['Local time']
#jpyusd = jpyusd.drop(['Local time'],axis=1)
jpyusd = jpyusd[(jpyusd['Local time'] >= '01.06.2011 00:00:00.000 GMT+0200')&(jpyusd['Local time'] <= '07.06.2011 13:30:00.000 GMT+0200')]
try:
    jpyusd = jpyusd.drop(['Unnamed: 0'],axis=1)
except:
    pass

PAIR = [eurusd,audusd,chfusd,gbpusd,jpyusd]

# %%
plt.figure(figsize=(22,6))

for pair in PAIR:
    name = isname(pair)

    #plt.figure(figsize=(16,4))
    plt.ylim(-3, 3)
    plt.title(label='Comparaison des closes standardisés')
    plt.plot(preprocessing.scale(pair['Close']),label='Close de la paire '+name,)
    plt.legend()

# %%
plt.figure(figsize=(22,6))

for pair in PAIR:
    name = isname(pair)

    #plt.figure(figsize=(16,4))
    plt.ylim(-6, 6)
    plt.title(label='Comparaison des diff des closes standardisés')
    plt.plot(preprocessing.scale(pair['Close'].diff()),label='Close.diff() de la paire '+name,)
    plt.legend()

# %%
for pair in PAIR:
    
    name = isname(pair)
    
    model = sm.OLS(pair['Close'],pair.index)
    results = model.fit()
    residuals = results.resid
    summary = results.summary()

    jb,p_value,skew,kurtosis,durbinwatson = ols(model,results, residuals)
    
    print(Fore.YELLOW,'POUR LA PAIRE '+name,Style.RESET_ALL)
    jarque_berra(pair)
    skewness(pair)
    kurtos(pair)
    autocor(pair)
# Out:
# EUR/USD :                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Close   R-squared (uncentered):                   0.755
# Model:                            OLS   Adj. R-squared (uncentered):              0.755
# Method:                 Least Squares   F-statistic:                              4050.
# Date:                Fri, 28 Feb 2020   Prob (F-statistic):                        0.00
# Time:                        10:19:35   Log-Likelihood:                         -1430.4
# No. Observations:                1315   AIC:                                      2863.
# Df Residuals:                    1314   BIC:                                      2868.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0017   2.61e-05     63.637      0.000       0.002       0.002
# ==============================================================================
# Omnibus:                      882.956   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.751
# Skew:                           0.002   Prob(JB):                     2.16e-17
# Kurtosis:                       1.816   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# EUR/USD :  5.779408396569887e-06
#  POUR LA PAIRE EUR/USD
#
# TEST DE NORMALITE : JARQUE-BERA EUR/USD
# Puisque la p-value ( 0.0 ) de la statistique de Jarque-Bera est inférieure au seuil de signification de 5%, donc on  refuse l’hypothèse de la normalité de la série
#  TEST JARQUE-BERRA VALIDE
#
# TEST D'ASSYMETRIE: SKEWNESS EUR/USD
#  /!\ ATTENTION SUPISCION DE NORMALITE /!\
#  TEST SKEWNESS ECHOUE
#
# TEST D'ASSYMETRIE: KURTOSIS EUR/USD
# Puisque le skewness ( -1.1835 ) de la statistiqest éloigné de 3, donc on valide en niveau 2 une distribution NON NORMALE
#  TEST DE KURTOSIS VALIDE
#
# CORRELOGRAMME D'AUTOCORRELATION DE LA PAIRE EUR/USD
# EUR/USD :          ACF      PACF        QSTAT           PROB
# 0  1.000000  1.000000  1310.986815  4.630635e-287
# 1  0.997335  0.998094  2616.466782   0.000000e+00
# 2  0.994859  0.048067  3916.820870   0.000000e+00
# 3  0.992526  0.038424  5211.957351   0.000000e+00
# 4  0.990155 -0.007558  6502.044083   0.000000e+00
# L'index de sortie de l'intervalle de confiance à 5% est de 2 . Il apparait donc clairement que la série n'est pas un bruit blanc
#  TEST AUTOCORRELATION VALIDE
# AUD/USD :                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Close   R-squared (uncentered):                   0.751
# Model:                            OLS   Adj. R-squared (uncentered):              0.751
# Method:                 Least Squares   F-statistic:                              3962.
# Date:                Fri, 28 Feb 2020   Prob (F-statistic):                        0.00
# Time:                        10:19:36   Log-Likelihood:                         -1040.2
# No. Observations:                1315   AIC:                                      2082.
# Df Residuals:                    1314   BIC:                                      2088.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0012   1.94e-05     62.944      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                      879.501   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.700
# Skew:                           0.008   Prob(JB):                     2.21e-17
# Kurtosis:                       1.817   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# AUD/USD :  6.1305647899026105e-06
#  POUR LA PAIRE AUD/USD
#
# TEST DE NORMALITE : JARQUE-BERA AUD/USD
# Puisque la p-value ( 0.0 ) de la statistique de Jarque-Bera est inférieure au seuil de signification de 5%, donc on  refuse l’hypothèse de la normalité de la série
#  TEST JARQUE-BERRA VALIDE
#
# TEST D'ASSYMETRIE: SKEWNESS AUD/USD
#  /!\ ATTENTION SUPISCION DE NORMALITE /!\
#  TEST SKEWNESS ECHOUE
#
# TEST D'ASSYMETRIE: KURTOSIS AUD/USD
# Puisque le skewness ( -1.183 ) de la statistiqest éloigné de 3, donc on valide en niveau 2 une distribution NON NORMALE
#  TEST DE KURTOSIS VALIDE
#
# CORRELOGRAMME D'AUTOCORRELATION DE LA PAIRE AUD/USD
# AUD/USD :          ACF      PACF        QSTAT           PROB
# 0  1.000000  1.000000  1299.137366  1.740541e-284
# 1  0.992818  0.993573  2582.935549   0.000000e+00
# 2  0.986563  0.068568  3850.383438   0.000000e+00
# 3  0.979887 -0.031438  5101.777603   0.000000e+00
# 4  0.973291 -0.001860  6337.291028   0.000000e+00
# L'index de sortie de l'intervalle de confiance à 5% est de 2 . Il apparait donc clairement que la série n'est pas un bruit blanc
#  TEST AUTOCORRELATION VALIDE
# CHF/USD :                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Close   R-squared (uncentered):                   0.755
# Model:                            OLS   Adj. R-squared (uncentered):              0.754
# Method:                 Least Squares   F-statistic:                              4039.
# Date:                Fri, 28 Feb 2020   Prob (F-statistic):                        0.00
# Time:                        10:19:36   Log-Likelihood:                         -1171.0
# No. Observations:                1315   AIC:                                      2344.
# Df Residuals:                    1314   BIC:                                      2349.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0014   2.14e-05     63.552      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                     1034.373   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.334
# Skew:                          -0.007   Prob(JB):                     5.93e-18
# Kurtosis:                       1.797   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# CHF/USD :  5.9066044261411115e-06
#  POUR LA PAIRE CHF/USD
#
# TEST DE NORMALITE : JARQUE-BERA CHF/USD
# Puisque la p-value ( 0.0 ) de la statistique de Jarque-Bera est inférieure au seuil de signification de 5%, donc on  refuse l’hypothèse de la normalité de la série
#  TEST JARQUE-BERRA VALIDE
#
# TEST D'ASSYMETRIE: SKEWNESS CHF/USD
#  /!\ ATTENTION SUPISCION DE NORMALITE /!\
#  TEST SKEWNESS ECHOUE
#
# TEST D'ASSYMETRIE: KURTOSIS CHF/USD
# Puisque le skewness ( -1.2032 ) de la statistiqest éloigné de 3, donc on valide en niveau 2 une distribution NON NORMALE
#  TEST DE KURTOSIS VALIDE
#
# CORRELOGRAMME D'AUTOCORRELATION DE LA PAIRE CHF/USD
# CHF/USD :          ACF      PACF        QSTAT           PROB
# 0  1.000000  1.000000  1305.150839  8.587641e-286
# 1  0.995113  0.995870  2599.396252   0.000000e+00
# 2  0.990569  0.038965  3884.284251   0.000000e+00
# 3  0.986606  0.069697  5159.723585   0.000000e+00
# 4  0.982597 -0.001812  6426.105841   0.000000e+00
# L'index de sortie de l'intervalle de confiance à 5% est de 2 . Il apparait donc clairement que la série n'est pas un bruit blanc
#  TEST AUTOCORRELATION VALIDE
# GBP/USD :                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Close   R-squared (uncentered):                   0.749
# Model:                            OLS   Adj. R-squared (uncentered):              0.749
# Method:                 Least Squares   F-statistic:                              3928.
# Date:                Fri, 28 Feb 2020   Prob (F-statistic):                        0.00
# Time:                        10:19:36   Log-Likelihood:                         -1605.2
# No. Observations:                1315   AIC:                                      3212.
# Df Residuals:                    1314   BIC:                                      3218.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0019   2.98e-05     62.676      0.000       0.002       0.002
# ==============================================================================
# Omnibus:                      924.363   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               77.525
# Skew:                           0.008   Prob(JB):                     1.46e-17
# Kurtosis:                       1.811   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# GBP/USD :  5.575683097492083e-06
#  POUR LA PAIRE GBP/USD
#
# TEST DE NORMALITE : JARQUE-BERA GBP/USD
# Puisque la p-value ( 0.0 ) de la statistique de Jarque-Bera est inférieure au seuil de signification de 5%, donc on  refuse l’hypothèse de la normalité de la série
#  TEST JARQUE-BERRA VALIDE
#
# TEST D'ASSYMETRIE: SKEWNESS GBP/USD
#  /!\ ATTENTION SUPISCION DE NORMALITE /!\
#  TEST SKEWNESS ECHOUE
#
# TEST D'ASSYMETRIE: KURTOSIS GBP/USD
# Puisque le skewness ( -1.1894 ) de la statistiqest éloigné de 3, donc on valide en niveau 2 une distribution NON NORMALE
#  TEST DE KURTOSIS VALIDE
#
# CORRELOGRAMME D'AUTOCORRELATION DE LA PAIRE GBP/USD
# GBP/USD :          ACF      PACF        QSTAT           PROB
# 0  1.000000  1.000000  1300.456225  8.996586e-285
# 1  0.993321  0.994077  2584.326087   0.000000e+00
# 2  0.986591 -0.008134  3851.192406   0.000000e+00
# 3  0.979663 -0.020539  5100.836478   0.000000e+00
# 4  0.972610 -0.014315  6333.623645   0.000000e+00
# L'index de sortie de l'intervalle de confiance à 5% est de 2 . Il apparait donc clairement que la série n'est pas un bruit blanc
#  TEST AUTOCORRELATION VALIDE
# JPY/USD :                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:                  Close   R-squared (uncentered):                   0.754
# Model:                            OLS   Adj. R-squared (uncentered):              0.754
# Method:                 Least Squares   F-statistic:                              4024.
# Date:                Fri, 28 Feb 2020   Prob (F-statistic):                        0.00
# Time:                        10:19:36   Log-Likelihood:                          4828.6
# No. Observations:                1315   AIC:                                     -9655.
# Df Residuals:                    1314   BIC:                                     -9650.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          1.419e-05   2.24e-07     63.437      0.000    1.38e-05    1.46e-05
# ==============================================================================
# Omnibus:                      970.072   Durbin-Watson:                   0.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               78.303
# Skew:                          -0.003   Prob(JB):                     9.93e-18
# Kurtosis:                       1.805   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# JPY/USD :  5.732327808199276e-06
#  POUR LA PAIRE JPY/USD
#
# TEST DE NORMALITE : JARQUE-BERA JPY/USD
# Puisque la p-value ( 0.0 ) de la statistique de Jarque-Bera est inférieure au seuil de signification de 5%, donc on  refuse l’hypothèse de la normalité de la série
#  TEST JARQUE-BERRA VALIDE
#
# TEST D'ASSYMETRIE: SKEWNESS JPY/USD
#  /!\ ATTENTION SUPISCION DE NORMALITE /!\
#  TEST SKEWNESS ECHOUE
#
# TEST D'ASSYMETRIE: KURTOSIS JPY/USD
# Puisque le skewness ( -1.1954 ) de la statistiqest éloigné de 3, donc on valide en niveau 2 une distribution NON NORMALE
#  TEST DE KURTOSIS VALIDE
#
# CORRELOGRAMME D'AUTOCORRELATION DE LA PAIRE JPY/USD
# JPY/USD :          ACF      PACF        QSTAT           PROB
# 0  1.000000  1.000000  1306.480077  4.415836e-286
# 1  0.995619  0.996377  2602.456265   0.000000e+00
# 2  0.991232 -0.003561  3888.321297   0.000000e+00
# 3  0.986981  0.016449  5163.794632   0.000000e+00
# 4  0.982610 -0.019281  6430.046045   0.000000e+00
# L'index de sortie de l'intervalle de confiance à 5% est de 2 . Il apparait donc clairement que la série n'est pas un bruit blanc
#  TEST AUTOCORRELATION VALIDE

# %%
from pandas.plotting import lag_plot

for pair in PAIR:
    name = isname(pair)
    plt.rcParams.update({'ytick.left' : False, 'axes.titlepad':10})

    ss = pair[['Local time','Close']]
    #ss = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/sunspotarea.csv')

    # Plot
    fig, axes = plt.subplots(1, 4, figsize=(14,4), sharex=True, sharey=True, dpi=100)
    for i, ax in enumerate(axes.flatten()):
        lag_plot(ss.Close, lag=i+1, ax=ax, c='firebrick')
        ax.set_title('Lag ' + str(i+1))

    fig.suptitle('Lag Plots of '+name+' Closes \n(Points get wide and scattered with increasing lag -> lesser correlation)\n', y=1.15)    


    fig.suptitle('Lag Plots of '+name, y=1.05)    
    plt.show()

# %%
for pair in PAIR:
    name = isname(pair)
    diff = pair.Close.diff()
    plt.figure(figsize=(16,4))
    plt.plot(diff,label='First Difference Close')
    plt.title(label='First Difference Plot for '+name)
    plt.legend()

# %%
for pair in PAIR:
    name = isname(pair)
    diff = pair.Close.diff()
    plt.figure(figsize=(16,4))

    pd.plotting.autocorrelation_plot(diff[1:])
    plt.title(label='Autocorrelation Plot for '+name)

# %%
'''for pair in PAIR:
    name = isname(pair)
    timeseries = pair['Close']
    timeseries.index = pair['Local time']
    test_stationarity(timeseries)'''
# Out:
# "for pair in PAIR:\n    name = isname(pair)\n    timeseries = pair['Close']\n    timeseries.index = pair['Local time']\n    test_stationarity(timeseries)"

# %%
df = pd.DataFrame()
for pair in PAIR:
    name = isname(pair)
    df[name] = list(pair['Close'])
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow0_col1 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow0_col2 {
#             background-color:  #eb7d62;
#             color:  #000000;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow0_col3 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow0_col4 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow1_col0 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow1_col2 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow1_col3 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow1_col4 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow2_col0 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow2_col4 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow3_col1 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow4_col0 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow4_col1 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow4_col2 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow4_col3 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >EUR/USD</th>        <th class="col_heading level0 col1" >AUD/USD</th>        <th class="col_heading level0 col2" >CHF/USD</th>        <th class="col_heading level0 col3" >GBP/USD</th>        <th class="col_heading level0 col4" >JPY/USD</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375alevel0_row0" class="row_heading level0 row0" >EUR/USD</th>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow0_col1" class="data row0 col1" >0.655231</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow0_col2" class="data row0 col2" >0.786885</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow0_col3" class="data row0 col3" >0.285670</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow0_col4" class="data row0 col4" >0.863799</td>
#             </tr>
#             <tr>
#                         <th id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375alevel0_row1" class="row_heading level0 row1" >AUD/USD</th>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow1_col0" class="data row1 col0" >0.655231</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow1_col2" class="data row1 col2" >0.282680</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow1_col3" class="data row1 col3" >0.667965</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow1_col4" class="data row1 col4" >0.398295</td>
#             </tr>
#             <tr>
#                         <th id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375alevel0_row2" class="row_heading level0 row2" >CHF/USD</th>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow2_col0" class="data row2 col0" >0.786885</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow2_col1" class="data row2 col1" >0.282680</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow2_col3" class="data row2 col3" >-0.143087</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow2_col4" class="data row2 col4" >0.924979</td>
#             </tr>
#             <tr>
#                         <th id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375alevel0_row3" class="row_heading level0 row3" >GBP/USD</th>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow3_col0" class="data row3 col0" >0.285670</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow3_col1" class="data row3 col1" >0.667965</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow3_col2" class="data row3 col2" >-0.143087</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow3_col4" class="data row3 col4" >-0.105805</td>
#             </tr>
#             <tr>
#                         <th id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375alevel0_row4" class="row_heading level0 row4" >JPY/USD</th>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow4_col0" class="data row4 col0" >0.863799</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow4_col1" class="data row4 col1" >0.398295</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow4_col2" class="data row4 col2" >0.924979</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow4_col3" class="data row4 col3" >-0.105805</td>
#                         <td id="T_73f1b2a0_5a0b_11ea_9a82_6c4008a0375arow4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
INTEGRE = []
for col in range(1,len(df.corr())):
    for ind in range(col):
        if df.corr().iloc[ind,col] > 0.5 and df.corr().iloc[ind,col] != 1:
            INTEGRE.append((df.corr().index[ind],df.corr().columns[col]))
        
INTEGRE  = list(set(INTEGRE))
print('Les paires ',INTEGRE,' sont correlées et permettent un factorisation.')
# Out:
# Les paires  [('EUR/USD', 'CHF/USD'), ('EUR/USD', 'AUD/USD'), ('EUR/USD', 'JPY/USD'), ('CHF/USD', 'JPY/USD'), ('AUD/USD', 'GBP/USD')]  sont correlées et permettent un factorisation.

# %%
from factor_analyzer.factor_analyzer import calculate_kmo
kmo_all,kmo_model=calculate_kmo(df)
print('Le KMO du modèle est de :',kmo_model)
for loop,pair in enumerate(PAIR):
    name = isname(pair)
    if kmo_all[loop] >= 0.6:
        print(Fore.GREEN,name,Style.RESET_ALL,' a un kmo considéré comme ',Fore.GREEN,'adéquet',Style.RESET_ALL)
    else:
        print(Fore.RED,name,Style.RESET_ALL,' a un kmo donsidéré comme ',Fore.RED,'inadéquat',Style.RESET_ALL)
# Out:
# Le KMO du modèle est de : 0.6558412178303276
#  EUR/USD   a un kmo considéré comme   adéquet
#  AUD/USD   a un kmo considéré comme   adéquet
#  CHF/USD   a un kmo considéré comme   adéquet
#  GBP/USD   a un kmo donsidéré comme   inadéquat
#  JPY/USD   a un kmo considéré comme   adéquet
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/factor_analyzer/utils.py:248: UserWarning: The inverse of the variance-covariance matrix was calculated using the Moore-Penrose generalized matrix inversion, due to its determinant being at or very close to zero.
#   warnings.warn('The inverse of the variance-covariance matrix '

# %%
from factor_analyzer.factor_analyzer import calculate_bartlett_sphericity
chi_square_value,p_value=calculate_bartlett_sphericity(df)
print('Dans le test de Barlett, on ibserve un chi2 à ',chi_square_value,' et une p_value à', p_value)
if p_value < 0.05:
    print(Fore.GREEN,'Statistically significant',Style.RESET_ALL," ce qui signifie que la matrice de correlation observée n'est pas une identity matrix" )
else:
    print(Fore.RED,'Statistically non significant',Style.RESET_ALL," ce qui signifie que la matrice de correlation observée peut être une identity matrix" )
# Out:
# Dans le test de Barlett, on ibserve un chi2 à  7073.076831872729  et une p_value à 0.0
#  Statistically significant   ce qui signifie que la matrice de correlation observée n'est pas une identity matrix

# %%
from factor_analyzer import FactorAnalyzer
fa = FactorAnalyzer(rotation=None)
fa.fit(df)
print(fa.loadings_)
#fa.analyze(df, 25, rotation=None)
# Check Eigenvalues
ev, v = fa.get_eigenvalues()
# Out:
# [[ 0.95512888  0.0641302   0.04905414]
#  [ 0.65428512  0.62043692 -0.19331085]
#  [ 0.84552619 -0.40325229  0.10522606]
#  [ 0.23161221  0.88231781  0.16035743]
#  [ 0.93078814 -0.35517262 -0.04994127]]

# %%
ev
# Out:
# array([3.0536107 , 1.5850516 , 0.21883824, 0.0989373 , 0.04356215])

# %%
v
# Out:
# array([ 2.97528850e+00,  1.45630115e+00,  7.90577789e-02,  2.68071557e-06,
#        -8.68725974e-06])

# %%
# Create scree plot using matplotlib
plt.scatter(range(1,df.shape[1]+1),ev)
plt.plot(range(1,df.shape[1]+1),ev)
plt.title('Scree Plot')
plt.xlabel('Factors')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()

# %%
PRINCIPAL_COMPOSANT = []
for loop,pair in enumerate(PAIR):
    name = isname(pair)
    print('\r\n'+name+' : ',ev[loop]," ===> ",end='')
    if ev[loop] >= 1:
        print('On garde le facteur car >1')
        PRINCIPAL_COMPOSANT.append((name,ev[loop]))
    else:
        print('On retire le facteur car <1')

print('\nRésumé des composants principaux gardés :')        
PRINCIPAL_COMPOSANT
# Out:
# EUR/USD :  3.053610703260666  ===> On garde le facteur car >1
#
# AUD/USD :  1.5850516037989137  ===> On garde le facteur car >1
#
# CHF/USD :  0.21883823526450896  ===> On retire le facteur car <1
#
# GBP/USD :  0.09893730327155383  ===> On retire le facteur car <1
#
# JPY/USD :  0.043562154404356845  ===> On retire le facteur car <1
#
# Résumé des composants principaux gardés :
# [('EUR/USD', 3.053610703260666), ('AUD/USD', 1.5850516037989137)]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(df)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
x_pca = pca.transform(df)
x_pca.shape
# Out:
# (1315, 2)

# %%
plt.figure(figsize=(22,6))
plt.scatter( x_pca[:,0],x_pca[:,1],c=df['EUR/USD'],cmap='rainbow')
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
for loop,pair in enumerate(PAIR):
    name = isname(pair)
    print(name,' : ',pca.components_[0][loop],' - ',pca.components_[1][loop])
# Out:
# EUR/USD  :  0.8109657260359473  -  0.16373851270092876
# AUD/USD  :  0.21914922156392908  -  0.45554708818752854
# CHF/USD  :  0.5356407032953042  -  -0.5441244894737811
# GBP/USD  :  0.08588119420228035  -  0.6852624620116886
# JPY/USD  :  0.004654818859526172  -  -0.0032323389254106587

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen as johasen
jh_results = johasen(df,0,1)
print('\nTrace Statistisque \n',jh_results.lr1)                           # dim = (n,) Trace statistic
print('\n\nCritical Value \n',jh_results.cvt)                           # dim = (n,3) critical value table (90%, 95%, 99%)
print('\n\nEigein Velue ec \n',jh_results.evec)                          # dim = (n, n), columnwise eigen-vectors
v1 = jh_results.evec[:, 0]
v2 = jh_results.evec[:, 1]
print('\n\nProbabilité de Eigein \n',jh_results.eig)
if jh_results.eig[0] <= 0.05:
    print('\nTest de cointiégration de Johasen ',Fore.GREEN,'VALIDE!',Style.RESET_ALL)
else:
    print('\nTest de cointiégration de Johasen',Fore.RED,'INVALIDE!',Style.RESET_ALL)
# Out:
# Trace Statistisque
#  [70.15406075 42.28298898 22.91635913  8.2291194   1.39595009]
#
#
# Critical Value
#  [[65.8202 69.8189 77.8202]
#  [44.4929 47.8545 54.6815]
#  [27.0669 29.7961 35.4628]
#  [13.4294 15.4943 19.9349]
#  [ 2.7055  3.8415  6.6349]]
#
#
# Eigein Velue ec
#  [[ 1.90122241e+02  1.28211295e+02 -1.45601351e+02  1.10343900e+02
#    8.76296811e+01]
#  [ 1.89693090e+02 -3.44233506e+02  1.71410985e+02  2.42300283e+01
#    4.53332736e+00]
#  [ 1.98880660e+02  2.55946925e+01  1.09855659e+02 -2.74861226e+02
#   -5.69646862e+01]
#  [-2.97595427e+02  3.65551455e+01 -1.15659906e+02 -2.30182016e+02
#    2.09717934e+01]
#  [-5.76132334e+04 -7.59151879e+03  1.07434651e+04  1.24503457e+04
#    7.05709481e+03]]
#
#
# Probabilité de Eigein
#  [0.02100331 0.01464166 0.01112369 0.00519072 0.00106261]
#
# Test de cointiégration de Johasen   VALIDE!

# %%
from sklearn.linear_model import LinearRegression

X = df.iloc[:,1:]
y = df.iloc[:,0]
reg = LinearRegression().fit(X, y)
score = reg.score(X, y) *100
coef = reg.coef_
cste = reg.intercept_

if score > 70:
    print('Test ',Fore.GREEN,'VALIDE',Style.RESET_ALL,' avec un score de ',Fore.GREEN,score,Style.RESET_ALL,' %')
    print("Les poids respectifs sont de :")
    loop = -1
    for pair in PAIR:
        name = isname(pair)
        if name == 'EUR/USD':
            continue
        loop += 1
        print(name,' : ',coef[loop])
    print('Et la constante est : ',cste)

elif score > 50:
    print('Test ',Fore.YELLOW,'MITIGE',Style.RESET_ALL,' avec un score de ',Fore.YELLOW,score,Style.RESET_ALL,' %')
    print("Les poids respectifs sont de :")
    loop = 0
    for pair in PAIR:
        name = isname(pair)
        if name == 'EUR/USD':
            continue
        loop += 1
        print(name,' : ',coef[loop])
    print('Et la constante est : ',cste)

else:
    print('Test ',Fore.RED,'NON VALIDE',Style.RESET_ALL,' avec un score de ',Fore.YELLOW,score,Style.RESET_ALL,' %')
    print("Les poids respectifs sont de :")
    loop = 0
    for pair in PAIR:
        name = isname(pair)
        if name == 'EUR/USD':
            continue
        loop += 1
        print(name,' : ',coef[loop])
    print('Et la constante est : ',cste)
# Out:
# Test   VALIDE   avec un score de   89.58701753675446   %
# Les poids respectifs sont de :
# AUD/USD  :  0.3205157859635524
# CHF/USD  :  0.11628642745815691
# GBP/USD  :  0.6257766354976829
# JPY/USD  :  121.92415395711004
# Et la constante est :  -1.5674125767177267

# %%
combo = cste + coef[0] * df['AUD/USD'] + coef[1] * df['CHF/USD'] + coef[2] * df['GBP/USD'] + coef[3] * df['JPY/USD']
plt.figure(figsize=(22,5))
plt.plot(df['EUR/USD'],label = 'EUR/USD',c='dodgerblue')
plt.plot(combo,label = 'Combo',c='darkorange')
plt.title('Comparaison de la paire de Référence et du composite')
plt.legend()

# %%
########
### RESIDUS
########
residu = df['EUR/USD']-combo
S = (residu - residu.mean())/residu.std()
plt.figure(figsize=(22,5))
plt.plot(residu,label = 'Résidu')
plt.title('Plot de la différence entre la paire de Référence et le composite : Résidu')
plt.legend()

# %%
####
## ANALYSE DES RESIDUS
###

jarque_berra(residu)
skewness(residu)
kurtos(residu)
residu_autocor = pd.DataFrame()
residu_autocor['Close'] = residu.iloc[:]
autocor(residu_autocor)
print("La moyenne des résidus est de ",residu.mean(),", et leur ecart-type vaut ",residu.std())
# Out:
#
# TEST DE NORMALITE : JARQUE-BERA JPY/USD
# Puisque la p-value ( 0.0 ) de la statistique de Jarque-Bera est inférieure au seuil de signification de 5%, donc on  refuse l’hypothèse de la normalité de la série
#  TEST JARQUE-BERRA VALIDE
#
# TEST D'ASSYMETRIE: SKEWNESS JPY/USD
#  /!\ ATTENTION SUPISCION DE NORMALITE /!\
#  TEST SKEWNESS ECHOUE
#
# TEST D'ASSYMETRIE: KURTOSIS JPY/USD
# Puisque le skewness ( -1.1954 ) de la statistiqest éloigné de 3, donc on valide en niveau 2 une distribution NON NORMALE
#  TEST DE KURTOSIS VALIDE
#
# CORRELOGRAMME D'AUTOCORRELATION DE LA PAIRE JPY/USD
# JPY/USD :          ACF      PACF        QSTAT           PROB
# 0  1.000000  1.000000  1266.684994  1.963867e-277
# 1  0.980339  0.981085  2487.110884   0.000000e+00
# 2  0.961905  0.022491  3664.720433   0.000000e+00
# 3  0.944521  0.019348  4793.154136   0.000000e+00
# 4  0.924238 -0.085201  5877.391512   0.000000e+00
# L'index de sortie de l'intervalle de confiance à 5% est de 2 . Il apparait donc clairement que la série n'est pas un bruit blanc
#  TEST AUTOCORRELATION VALIDE
# La moyenne des résidus est de  1.533205332866376e-16 , et leur ecart-type vaut  0.0032948890239369376

# %%
model = sm.OLS(residu,residu.index)
results = model.fit()
residuals = results.resid
summary = results.summary()
name = 'Analyse des Résidus'
jb,p_value,skew,kurtosis,durbinwatson = ols(model,results, residuals)
# Out:
# Analyse des Résidus :                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.016
# Model:                            OLS   Adj. R-squared (uncentered):              0.016
# Method:                 Least Squares   F-statistic:                              21.87
# Date:                Fri, 28 Feb 2020   Prob (F-statistic):                    3.22e-06
# Time:                        10:19:44   Log-Likelihood:                          5661.2
# No. Observations:                1315   AIC:                                 -1.132e+04
# Df Residuals:                    1314   BIC:                                 -1.132e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          5.554e-07   1.19e-07      4.677      0.000    3.22e-07    7.88e-07
# ==============================================================================
# Omnibus:                       39.463   Durbin-Watson:                   0.038
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               38.187
# Skew:                          -0.378   Prob(JB):                     5.10e-09
# Kurtosis:                       2.644   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Analyse des Résidus :  0.03836419758468417

# %%
temp = pd.DataFrame()
temp['Close'] = residu.iloc[:]
autocor(temp)
# Out:
#
# CORRELOGRAMME D'AUTOCORRELATION DE LA PAIRE Analyse des Résidus
# Analyse des Résidus :          ACF      PACF        QSTAT           PROB
# 0  1.000000  1.000000  1266.684994  1.963867e-277
# 1  0.980339  0.981085  2487.110884   0.000000e+00
# 2  0.961905  0.022491  3664.720433   0.000000e+00
# 3  0.944521  0.019348  4793.154136   0.000000e+00
# 4  0.924238 -0.085201  5877.391512   0.000000e+00
# L'index de sortie de l'intervalle de confiance à 5% est de 2 . Il apparait donc clairement que la série n'est pas un bruit blanc
#  TEST AUTOCORRELATION VALIDE
# ()

# %%
dfoutput =  test_stationarity(residu,lag = 1)
if dfoutput[1] < 0.05 and dfoutput[0] < dfoutput[6]:
    print('Le test est ',Fore.GREEN,'VALIDE',Style.RESET_ALL,'et le résidu est : ',Fore.GREEN,'STATIONNAIRE',Style.RESET_ALL)
else:
    print('Le test est ',Fore.RED,'NON VALIDE',Style.RESET_ALL,'et le résidu  : ',Fore.RED,'NON STATIONNAIRE',Style.RESET_ALL)
# Out:
# Results of Dickey-Fuller Test pour la paire : Analyse des Résidus
# Test Statistic                   -3.394970
# p-value                           0.011132
# #Lags Used                        1.000000
# Number of Observations Used    1313.000000
# Critical Value (1%)              -3.435340
# Critical Value (5%)              -2.863744
# Critical Value (10%)             -2.567943
# dtype: float64
# Le test est   VALIDE  et le résidu est :   STATIONNAIRE

# %%
#######
### RETOUR A LA MOYENNE
#######
dfoutput =  test_stationarity(residu,lag = 0)
if dfoutput[1] < 0.05 and dfoutput[0] < dfoutput[6]:
    print('Le test est ',Fore.GREEN,'VALIDE',Style.RESET_ALL,'et il y a : ',Fore.GREEN,'RETOUR A LA MOYENNE',Style.RESET_ALL)
else:
    print('Le test est ',Fore.RED,'NON VALIDE',Style.RESET_ALL,"et il n'y a ",Fore.RED,'PAS RETOUR A LA MOYENNE',Style.RESET_ALL)
# Out:
# Results of Dickey-Fuller Test pour la paire : Analyse des Résidus
# Test Statistic                   -3.484982
# p-value                           0.008381
# #Lags Used                        0.000000
# Number of Observations Used    1314.000000
# Critical Value (1%)              -3.435336
# Critical Value (5%)              -2.863742
# Critical Value (10%)             -2.567942
# dtype: float64
# Le test est   VALIDE  et il y a :   RETOUR A LA MOYENNE

# %%
plt.figure(figsize=(22,5))
plt.plot(S,label='Score')
plt.axhline(y=0,c='crimson',alpha=0.4,linestyle='-.',label='Zéro')
plt.axhline(y=1,c='orange',alpha=0.8,linestyle='--',label='Open Short')
plt.axhline(y=0.5,c='orange',alpha=0.8,label ='Close Short')
plt.axhline(y=-1,c='darkgreen',alpha=0.8,linestyle='--', label='Open Long')
plt.axhline(y=-0.5,c='darkgreen',alpha=0.8,label='Close Long')
plt.legend()

# %%
########
### BT
#######


bt_eurusd = pd.read_csv('BT/EURUSD.csv')
#bt_eurusd.index = bt_eurusd['Local time']
#bt_eurusd = bt_eurusd.drop(['Local time'],axis=1)
bt_eurusd = bt_eurusd[(bt_eurusd['Local time'] >= '07.06.2011 13:35:00.000 GMT+0200')&(bt_eurusd['Local time'] <= '08.06.2011 11:00:00.000 GMT+0200')]
try:
    bt_eurusd = bt_eurusd.drop(['Unnamed: 0'],axis=1)
except:
    pass


bt_audusd = pd.read_csv('BT/AUDUSD.csv')
#bt_audusd.index = bt_audusd['Local time']
#bt_audusd = bt_audusd.drop(['Local time'],axis=1)
bt_audusd = bt_audusd[(bt_audusd['Local time'] >= '07.06.2011 13:35:00.000 GMT+0200')&(bt_audusd['Local time'] <= '08.06.2011 11:00:00.000 GMT+0200')]
try:
    bt_audusd = bt_audusd.drop(['Unnamed: 0'],axis=1)
except:
    pass


bt_chfusd = pd.read_csv('BT/CHFUSD.csv')
#bt_chfusd.index = bt_chfusd['Local time']
#bt_chfusd = bt_chfusd.drop(['Local time'],axis=1)
bt_chfusd = bt_chfusd[(bt_chfusd['Local time'] >= '07.06.2011 13:35:00.000 GMT+0200')&(bt_chfusd['Local time'] <= '08.06.2011 11:00:00.000 GMT+0200')]
try:
    bt_chfusd = bt_chfusd.drop(['Unnamed: 0'],axis=1)
except:
    pass


bt_gbpusd = pd.read_csv('BT/GBPUSD.csv')
#bt_gbpusd.index = bt_gbpusd['Local time']
#bt_gbpusd = bt_gbpusd.drop(['Local time'],axis=1)
bt_gbpusd = bt_gbpusd[(bt_gbpusd['Local time'] >= '07.06.2011 13:35:00.000 GMT+0200')&(bt_gbpusd['Local time'] <= '08.06.2011 11:00:00.000 GMT+0200')]
try:
    bt_gbpusd = bt_gbpusd.drop(['Unnamed: 0'],axis=1)
except:
    pass

bt_jpyusd = pd.read_csv('BT/JPYUSD.csv')
#bt_jpyusd.index = bt_jpyusd['Local time']
#bt_jpyusd = bt_jpyusd.drop(['Local time'],axis=1)
bt_jpyusd = bt_jpyusd[(bt_jpyusd['Local time'] >= '07.06.2011 13:35:00.000 GMT+0200')&(bt_jpyusd['Local time'] <= '08.06.2011 11:00:00.000 GMT+0200')]
try:
    bt_jpyusd = bt_jpyusd.drop(['Unnamed: 0'],axis=1)
except:
    pass

bt_PAIR = [bt_eurusd,bt_audusd,bt_chfusd,bt_gbpusd,bt_jpyusd]

# %%
bt_df = pd.DataFrame()
for bt_pair in bt_PAIR:
    
    if bt_pair.equals(bt_eurusd):
        name = 'EUR/USD'
    elif bt_pair.equals(bt_audusd):
        name = 'AUD/USD'
    elif bt_pair.equals(bt_chfusd):
        name = 'CHF/USD'
    elif bt_pair.equals(bt_gbpusd):
        name = 'GBP/USD'
    elif bt_pair.equals(bt_jpyusd):
        name = 'JPY/USD'
    
    
    bt_df[name] = list(bt_pair['Close'])
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow0_col1 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow0_col2 {
#             background-color:  #eb7d62;
#             color:  #000000;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow0_col3 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow0_col4 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow1_col0 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow1_col2 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow1_col3 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow1_col4 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow2_col0 {
#             background-color:  #f7ac8e;
#             color:  #000000;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow2_col4 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow3_col1 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow4_col0 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow4_col1 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow4_col2 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow4_col3 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >EUR/USD</th>        <th class="col_heading level0 col1" >AUD/USD</th>        <th class="col_heading level0 col2" >CHF/USD</th>        <th class="col_heading level0 col3" >GBP/USD</th>        <th class="col_heading level0 col4" >JPY/USD</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375alevel0_row0" class="row_heading level0 row0" >EUR/USD</th>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow0_col1" class="data row0 col1" >0.655231</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow0_col2" class="data row0 col2" >0.786885</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow0_col3" class="data row0 col3" >0.285670</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow0_col4" class="data row0 col4" >0.863799</td>
#             </tr>
#             <tr>
#                         <th id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375alevel0_row1" class="row_heading level0 row1" >AUD/USD</th>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow1_col0" class="data row1 col0" >0.655231</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow1_col2" class="data row1 col2" >0.282680</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow1_col3" class="data row1 col3" >0.667965</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow1_col4" class="data row1 col4" >0.398295</td>
#             </tr>
#             <tr>
#                         <th id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375alevel0_row2" class="row_heading level0 row2" >CHF/USD</th>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow2_col0" class="data row2 col0" >0.786885</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow2_col1" class="data row2 col1" >0.282680</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow2_col3" class="data row2 col3" >-0.143087</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow2_col4" class="data row2 col4" >0.924979</td>
#             </tr>
#             <tr>
#                         <th id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375alevel0_row3" class="row_heading level0 row3" >GBP/USD</th>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow3_col0" class="data row3 col0" >0.285670</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow3_col1" class="data row3 col1" >0.667965</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow3_col2" class="data row3 col2" >-0.143087</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow3_col4" class="data row3 col4" >-0.105805</td>
#             </tr>
#             <tr>
#                         <th id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375alevel0_row4" class="row_heading level0 row4" >JPY/USD</th>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow4_col0" class="data row4 col0" >0.863799</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow4_col1" class="data row4 col1" >0.398295</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow4_col2" class="data row4 col2" >0.924979</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow4_col3" class="data row4 col3" >-0.105805</td>
#                         <td id="T_75a785fc_5a0b_11ea_9a82_6c4008a0375arow4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
bt_combo = cste + coef[0] * bt_df['AUD/USD'] + coef[1] * bt_df['CHF/USD'] + coef[2] * bt_df['GBP/USD'] + coef[3] * bt_df['JPY/USD']
bt_residu = bt_df['EUR/USD']-bt_combo
bt_S = (bt_residu - bt_residu.mean())/bt_residu.std()
plt.figure(figsize=(22,5))
plt.plot(bt_residu,label = 'Résidu')
plt.title('Plot de la différence entre la paire de Référence et le composite : Résidu')
plt.legend()

# %%
jarque_berra(bt_residu)
skewness(bt_residu)
kurtos(bt_residu)
bt_residu_autocor = pd.DataFrame()
bt_residu_autocor['Close'] = bt_residu.iloc[:]
autocor(bt_residu_autocor)
print("La moyenne des résidus est de ",bt_residu.mean(),", et leur ecart-type vaut ",bt_residu.std())
# Out:
#
# TEST DE NORMALITE : JARQUE-BERA JPY/USD
# Puisque la p-value ( 0.0 ) de la statistique de Jarque-Bera est inférieure au seuil de signification de 5%, donc on  refuse l’hypothèse de la normalité de la série
#  TEST JARQUE-BERRA VALIDE
#
# TEST D'ASSYMETRIE: SKEWNESS JPY/USD
# Puisque le skewness ( -0.3776 ) de la statistiqest éloigné de 0, donc on valide en niveau 1 une distribution NON NORMALE
#  TEST SKEWNESS VALIDE
#
# TEST D'ASSYMETRIE: KURTOSIS JPY/USD
# Puisque le skewness ( -0.3559 ) de la statistiqest éloigné de 3, donc on valide en niveau 2 une distribution NON NORMALE
#  TEST DE KURTOSIS VALIDE
#
# CORRELOGRAMME D'AUTOCORRELATION DE LA PAIRE JPY/USD
# JPY/USD :          ACF      PACF       QSTAT           PROB
# 0  1.000000  1.000000  221.917945   3.451747e-50
# 1  0.922075  0.925663  403.643669   2.238159e-88
# 2  0.832783 -0.122691  556.717595  2.431340e-120
# 3  0.762824  0.093279  688.043404  1.352445e-147
# 4  0.705173  0.023999  806.495092  4.551472e-172
# L'index de sortie de l'intervalle de confiance à 5% est de 3 . Il apparait donc clairement que la série n'est pas un bruit blanc
#  TEST AUTOCORRELATION VALIDE
# La moyenne des résidus est de  0.0021953463646777302 , et leur ecart-type vaut  0.0015975291300672646

# %%
bt_model = sm.OLS(bt_residu,bt_residu.index)
bt_results = bt_model.fit()
bt_residuals = bt_results.resid
bt_summary = bt_results.summary()
name = 'Analyse des Résidus'
jb,p_value,skew,kurtosis,durbinwatson = ols(bt_model,bt_results, bt_residuals)
# Out:
# Analyse des Résidus :                                   OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.374
# Model:                            OLS   Adj. R-squared (uncentered):              0.372
# Method:                 Least Squares   F-statistic:                              153.7
# Date:                Fri, 28 Feb 2020   Prob (F-statistic):                    5.52e-28
# Time:                        10:19:45   Log-Likelihood:                          1219.1
# No. Observations:                 258   AIC:                                     -2436.
# Df Residuals:                     257   BIC:                                     -2433.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          1.118e-05   9.01e-07     12.399      0.000     9.4e-06     1.3e-05
# ==============================================================================
# Omnibus:                       37.838   Durbin-Watson:                   0.083
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               15.141
# Skew:                          -0.376   Prob(JB):                     0.000515
# Kurtosis:                       2.082   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Analyse des Résidus :  0.08294354638730299

# %%
temp = pd.DataFrame()
temp['Close'] = bt_residu.iloc[:]
autocor(temp)
# Out:
#
# CORRELOGRAMME D'AUTOCORRELATION DE LA PAIRE Analyse des Résidus
# Analyse des Résidus :          ACF      PACF       QSTAT           PROB
# 0  1.000000  1.000000  221.917945   3.451747e-50
# 1  0.922075  0.925663  403.643669   2.238159e-88
# 2  0.832783 -0.122691  556.717595  2.431340e-120
# 3  0.762824  0.093279  688.043404  1.352445e-147
# 4  0.705173  0.023999  806.495092  4.551472e-172
# L'index de sortie de l'intervalle de confiance à 5% est de 3 . Il apparait donc clairement que la série n'est pas un bruit blanc
#  TEST AUTOCORRELATION VALIDE
# ()

# %%
dfoutput =  test_stationarity(bt_residu,lag = 1)
if dfoutput[1] < 0.05 and dfoutput[0] < dfoutput[6]:
    print('Le test est ',Fore.GREEN,'VALIDE',Style.RESET_ALL,'et le résidu est : ',Fore.GREEN,'STATIONNAIRE',Style.RESET_ALL)
else:
    print('Le test est ',Fore.RED,'NON VALIDE',Style.RESET_ALL,'et le résidu  : ',Fore.RED,'NON STATIONNAIRE',Style.RESET_ALL)
# Out:
# Results of Dickey-Fuller Test pour la paire : Analyse des Résidus
# Test Statistic                  -3.563150
# p-value                          0.006506
# #Lags Used                       1.000000
# Number of Observations Used    256.000000
# Critical Value (1%)             -3.456155
# Critical Value (5%)             -2.872897
# Critical Value (10%)            -2.572822
# dtype: float64
# Le test est   VALIDE  et le résidu est :   STATIONNAIRE

# %%
#######
### RETOUR A LA MOYENNE
#######
dfoutput =  test_stationarity(bt_residu,lag = 0)
if dfoutput[1] < 0.05 and dfoutput[0] < dfoutput[6]:
    print('Le test est ',Fore.GREEN,'VALIDE',Style.RESET_ALL,'et il y a : ',Fore.GREEN,'RETOUR A LA MOYENNE',Style.RESET_ALL)
else:
    print('Le test est ',Fore.RED,'NON VALIDE',Style.RESET_ALL,"et il n'y a ",Fore.RED,'PAS RETOUR A LA MOYENNE',Style.RESET_ALL)
# Out:
# Results of Dickey-Fuller Test pour la paire : Analyse des Résidus
# Test Statistic                  -3.196329
# p-value                          0.020198
# #Lags Used                       0.000000
# Number of Observations Used    257.000000
# Critical Value (1%)             -3.456054
# Critical Value (5%)             -2.872853
# Critical Value (10%)            -2.572799
# dtype: float64
# Le test est   VALIDE  et il y a :   RETOUR A LA MOYENNE

# %%
plt.figure(figsize=(22,5))
plt.plot(bt_S,label='Score')
plt.axhline(y=0,c='crimson',alpha=0.4,linestyle='-.',label='Zéro')
plt.axhline(y=1,c='orange',alpha=0.8,linestyle='--',label='Open Short')
plt.axhline(y=0.5,c='orange',alpha=0.8,label ='Close Short')
plt.axhline(y=-1,c='darkgreen',alpha=0.8,linestyle='--', label='Open Long')
plt.axhline(y=-0.5,c='darkgreen',alpha=0.8,label='Close Long')
plt.legend()

# %%
backtest_df = pd.DataFrame()
backtest_df = bt_df
backtest_df.index = bt_pair['Local time']
backtest_df['Spread'] = bt_residu.to_list()
backtest_df['Signals'] = bt_S.to_list()
backtest_df.tail()
# Out:
#                                   EUR/USD  AUD/USD   CHF/USD  GBP/USD  \
# Local time
# 08.06.2011 10:40:00.000 GMT+0200  1.46451  1.06306  1.195357  1.63718
# 08.06.2011 10:45:00.000 GMT+0200  1.46521  1.06336  1.196058  1.63766
# 08.06.2011 10:50:00.000 GMT+0200  1.46528  1.06317  1.195672  1.63689
# 08.06.2011 10:55:00.000 GMT+0200  1.46571  1.06332  1.195800  1.63675
# 08.06.2011 11:00:00.000 GMT+0200  1.46621  1.06314  1.195815  1.63676
#
#                                    JPY/USD    Spread   Signals
# Local time
# 08.06.2011 10:40:00.000 GMT+0200  0.012520  0.001169 -0.642569
# 08.06.2011 10:45:00.000 GMT+0200  0.012519  0.001505 -0.431824
# 08.06.2011 10:50:00.000 GMT+0200  0.012520  0.002048 -0.091935
# 08.06.2011 10:55:00.000 GMT+0200  0.012523  0.002159 -0.022785
# 08.06.2011 11:00:00.000 GMT+0200  0.012518  0.003320  0.704210

# %%
plt.figure(figsize=(22,5))
_plot = plt.plot(bt_S,label = 'Score')
os,cs,ol,cl = 0,0,0,0

mise = 100000
pactol = 100000
profit_long = 0
profit_short = 0
profit = 0
nbre_trade = 0
nbre_trade_long = 0
nbre_trade_short = 0

for mark in range(0,len(backtest_df)):
    if backtest_df.iloc[mark]['Signals'] > 1 and os == 0:
        _os = scatter =  plt.scatter(x=mark,y=bt_S[mark],c='r',marker='o',label='Open Short')
        os = 1
        cs = 0
        #pactol = pactol + mise * backtest_df.iloc[mark]['EUR/USD']
        #pactol = pactol - mise * (coef[0] * backtest_df.iloc[mark]['AUD/USD'] + coef[1] * backtest_df.iloc[mark]['CHF/USD'] +\
                                 #coef[2] * backtest_df.iloc[mark]['GBP/USD'] + coef[3] * backtest_df.iloc[mark]['JPY/USD'])
        eos = mise * backtest_df.iloc[mark]['EUR/USD']
        auos = -  mise * coef[0] * backtest_df.iloc[mark]['AUD/USD']
        chos = - mise * coef[1] * backtest_df.iloc[mark]['CHF/USD']
        gbos = - mise * coef[2] * backtest_df.iloc[mark]['GBP/USD']
        jpos = - mise * coef[3] * backtest_df.iloc[mark]['JPY/USD']
        
        
        print('\n\nDate : ',backtest_df.index[mark])
        print(Fore.GREEN,'ACTION OPEN SHORT',Style.RESET_ALL,\
              '- \nclose EUR/USA ',backtest_df.iloc[mark]['EUR/USD'],'\nclose AUD/USD : ',backtest_df.iloc[mark]['AUD/USD'],\
              '\nClose CHF/USD : ',backtest_df.iloc[mark]['CHF/USD'],'\nClose GBP/USD : ', backtest_df.iloc[mark]['GBP/USD'],\
             '\nClose JPY/USD : ',backtest_df.iloc[mark]['JPY/USD'])  
    
    if backtest_df.iloc[mark]['Signals'] < 0.5 and os == 1:
        _cs = scatter = plt.scatter(x=mark,y=bt_S[mark],c='r',marker='x',label='Close Short : ')
        os = 0
        cs = 1
        #pactol = pactol - mise * backtest_df.iloc[mark]['EUR/USD']
        #pactol = pactol + mise * (coef[0] * backtest_df.iloc[mark]['AUD/USD'] + coef[1] * backtest_df.iloc[mark]['CHF/USD'] +\
                                 #coef[2] * backtest_df.iloc[mark]['GBP/USD'] + coef[3] * backtest_df.iloc[mark]['JPY/USD'])
        print('\n\nDate : ',backtest_df.index[mark])
        print(Fore.RED,'ACTION CLOSE SHORT',Style.RESET_ALL,\
              '- \nclose EUR/USA ',backtest_df.iloc[mark]['EUR/USD'],'\nclose AUD/USD : ',backtest_df.iloc[mark]['AUD/USD'],\
              '\nClose CHF/USD : ',backtest_df.iloc[mark]['CHF/USD'],'\nClose GBP/USD : ', backtest_df.iloc[mark]['GBP/USD'],\
             '\nClose JPY/USD : ',backtest_df.iloc[mark]['JPY/USD']) 
        
        #e = e - mise * backtest_df.iloc[mark]['EUR/USD']
        #au = au + mise * coef[0] * backtest_df.iloc[mark]['AUD/USD']
        #ch = (ch +  mise * coef[1] * backtest_df.iloc[mark]['CHF/USD']) / backtest_df.iloc[mark]['CHF/USD']
        #gb = gb + mise * coef[2] * backtest_df.iloc[mark]['GBP/USD']
        #jp = (jp + mise * coef[3] * backtest_df.iloc[mark]['JPY/USD']) / backtest_df.iloc[mark]['JPY/USD']
        
        ecs = - mise * backtest_df.iloc[mark]['EUR/USD']
        aucs = mise * coef[0] * backtest_df.iloc[mark]['AUD/USD']
        chcs = mise * coef[1] * backtest_df.iloc[mark]['CHF/USD']
        gbcs = mise * coef[2] * backtest_df.iloc[mark]['GBP/USD']
        jpcs = mise * coef[3] * backtest_df.iloc[mark]['JPY/USD']
        
        pnles = eos + ecs
        pnlaus = auos + aucs
        pnlchs = (chos + chcs) 
        pnlgbs = gbos + gbcs
        pnljps = (jpos + jpcs) 
        pnlcombos = pnlaus + pnlchs + pnlgbs + pnljps
        pnls = pnles + pnlcombos
        
        nbre_trade += 1
        nbre_trade_short +=1
        
        profit = profit + pnls
        
        print('pnl EUR/USd :',pnles,'\npnl au :',pnlaus,'\npnl ch :',pnlchs,'\npnl gp',pnlgbs,'\npnl jp :',pnljps,\
              '\ntotal combo : ',pnlcombos,'\npnl total :',pnls)
        
        
    if backtest_df.iloc[mark]['Signals'] < -1 and ol == 0:
        _ol = scatter = plt.scatter(x=mark,y=bt_S[mark],c='g',marker='o',label='Open Long')
        ol = 1
        os = 0
        #pactol = pactol - mise * backtest_df.iloc[mark]['EUR/USD']
        #pactol = pactol + mise * (coef[0] * backtest_df.iloc[mark]['AUD/USD'] + coef[1] * backtest_df.iloc[mark]['CHF/USD'] +\
        #                         coef[2] * backtest_df.iloc[mark]['GBP/USD'] + coef[3] * backtest_df.iloc[mark]['JPY/USD'])
        print('\n\nDate : ',backtest_df.index[mark])
        print(Fore.GREEN,'ACTION OPEN LONG',Style.RESET_ALL,\
              '- \nclose EUR/USA ',backtest_df.iloc[mark]['EUR/USD'],'\nclose AUD/USD : ',backtest_df.iloc[mark]['AUD/USD'],\
              '\nClose CHF/USD : ',backtest_df.iloc[mark]['CHF/USD'],'\nClose GBP/USD : ', backtest_df.iloc[mark]['GBP/USD'],\
             '\nClose JPY/USD : ',backtest_df.iloc[mark]['JPY/USD'])
        
        eol = - mise * backtest_df.iloc[mark]['EUR/USD']
        auol = mise * coef[0] * backtest_df.iloc[mark]['AUD/USD']
        chol = mise * coef[1] * backtest_df.iloc[mark]['CHF/USD']
        gbol = mise * coef[2] * backtest_df.iloc[mark]['GBP/USD']
        jpol = mise * coef[3] * backtest_df.iloc[mark]['JPY/USD']
        
        
        
    if backtest_df.iloc[mark]['Signals'] > -0.5 and ol == 1 :
        _cl = scatter = plt.scatter(x=mark,y=bt_S[mark],c='g',marker='x',label='Close Long')
        ol = 0
        cl = 1
        #pactol = pactol + mise * backtest_df.iloc[mark]['EUR/USD']
        #pactol = pactol - mise * (coef[0] * backtest_df.iloc[mark]['AUD/USD'] + coef[1] * backtest_df.iloc[mark]['CHF/USD'] +\
        #                         coef[2] * backtest_df.iloc[mark]['GBP/USD'] + coef[3] * backtest_df.iloc[mark]['JPY/USD'])
        
        print('\n\nDate : ',backtest_df.index[mark])
        print(Fore.RED,'ACTION CLOSE LONG',Style.RESET_ALL,\
              '- \nclose EUR/USA ',backtest_df.iloc[mark]['EUR/USD'],'\nclose AUD/USD : ',backtest_df.iloc[mark]['AUD/USD'],\
              '\nClose CHF/USD : ',backtest_df.iloc[mark]['CHF/USD'],' \nClose GBP/USD : ', backtest_df.iloc[mark]['GBP/USD'],\
             '\nClose JPY/USD : ',backtest_df.iloc[mark]['JPY/USD'])
        
        ecl = mise * backtest_df.iloc[mark]['EUR/USD']
        aucl = -  mise * coef[0] * backtest_df.iloc[mark]['AUD/USD']
        chcl = - mise * coef[1] * backtest_df.iloc[mark]['CHF/USD']
        gbcl = - mise * coef[2] * backtest_df.iloc[mark]['GBP/USD']
        jpcl = - mise * coef[3] * backtest_df.iloc[mark]['JPY/USD']
        
        pnlel = eol + ecl
        pnlaul = auol + aucl
        pnlchl = (chol + chcl) 
        pnlgbl = gbol + gbcl
        pnljpl = (jpol + jpcl) 
        pnlcombol = pnlaul + pnlchl + pnlgbl + pnljpl
        pnll = pnlel + pnlcombol
        
        nbre_trade += 1
        nbre_trade_long +=1
        
        profit = profit + pnll
        
        print('pnl EUR/USd :',pnlel,'\npnl au :',pnlaul,'\npnl ch :',pnlchl,'\npnl gp',pnlgbl,'\npnl jp :',pnljpl,\
              '\ntotal combo : ',pnlcombol,'\npnl total :',pnll)
        
        print('\n\nProfit en Long :',pnll)
        print('Profit en Short : ',pnls)


    
plt.title('Plot Signaux Achat / Vente sur le Score')
plt.legend((_os,_cs,_ol,_cl),('Open Short','Close Short','Open Long','Close Long'),scatterpoints=1 )

'''if ol == 1:
    pactol = pactol - qty * backtest_df.iloc[mark]['EUR/USD']
    pactol = pactol + qty * (coef[0] * backtest_df.iloc[mark]['AUD/USD'] + coef[1] * backtest_df.iloc[mark]['CHF/USD'] +\
                             coef[2] * backtest_df.iloc[mark]['GBP/USD'] + coef[3] * backtest_df.iloc[mark]['JPY/USD']) 
    
if os == 1:
    pactol = pactol + qty * backtest_df.iloc[mark]['EUR/USD']
    pactol = pactol - qty * (coef[0] * backtest_df.iloc[mark]['AUD/USD'] + coef[1] * backtest_df.iloc[mark]['CHF/USD'] +\
                             coef[2] * backtest_df.iloc[mark]['GBP/USD'] + coef[3] * backtest_df.iloc[mark]['JPY/USD'])'''
    
print(Fore.YELLOW,'------------------------------------------------------------------------')
print(' --------------------------------RESULTATS--------------------------------')
print(' ------------------------------------------------------------------------',Style.RESET_ALL)
if profit < 0:
    print('Le profit généré en $',Fore.RED,round(profit,2),Style.RESET_ALL)
    

if profit > 0:
    print('Le profit généré en $',Fore.GREEN,round(profit,2),Style.RESET_ALL)

print('Nombre de trades long : ',nbre_trade_long)
print('Nombre de trades short : ',nbre_trade_short)
# Out:
# Date :  07.06.2011 13:40:00.000 GMT+0200
#  ACTION OPEN SHORT  -
# close EUR/USA  1.46645
# close AUD/USD :  1.07006
# Close CHF/USD :  1.1988826413782354
# Close GBP/USD :  1.64192
# Close JPY/USD :  0.012467895169937413
#
#
# Date :  07.06.2011 14:00:00.000 GMT+0200
#  ACTION CLOSE SHORT  -
# close EUR/USA  1.4651299999999998
# close AUD/USD :  1.06971
# Close CHF/USD :  1.1979060602067586
# Close GBP/USD :  1.6421
# Close JPY/USD :  0.01246976082998728
# pnl EUR/USd : 132.0000000000291
# pnl au : -11.218052508724213
# pnl ch : -11.356313555394081
# pnl gp 11.263979438939714
# pnl jp : 22.746902315149782
# total combo :  11.436515689971202
# pnl total : 143.4365156900003
#
#
# Date :  07.06.2011 14:15:00.000 GMT+0200
#  ACTION OPEN SHORT  -
# close EUR/USA  1.46506
# close AUD/USD :  1.06942
# Close CHF/USD :  1.196974049602605
# Close GBP/USD :  1.64155
# Close JPY/USD :  0.01246028284842066
#
#
# Date :  07.06.2011 14:30:00.000 GMT+0200
#  ACTION CLOSE SHORT  -
# close EUR/USA  1.46589
# close AUD/USD :  1.07041
# Close CHF/USD :  1.1972176661438816
# Close GBP/USD :  1.6430799999999999
# Close JPY/USD :  0.012468672460443135
# pnl EUR/USd : -83.0
# pnl au : 31.731062810395088
# pnl ch : 2.832929725476788
# pnl gp 95.74382523114036
# pnl jp : 102.28963478686637
# total combo :  232.5974525538786
# pnl total : 149.5974525538786
#
#
# Date :  07.06.2011 15:50:00.000 GMT+0200
#  ACTION OPEN LONG  -
# close EUR/USA  1.46536
# close AUD/USD :  1.07046
# Close CHF/USD :  1.1953143676786997
# Close GBP/USD :  1.64485
# Close JPY/USD :  0.012473805009480091
#
#
# Date :  07.06.2011 16:10:00.000 GMT+0200
#  ACTION CLOSE LONG  -
# close EUR/USA  1.46698
# close AUD/USD :  1.07124
# Close CHF/USD :  1.1940868817615171
# Close GBP/USD :  1.6461400000000002
# Close JPY/USD :  0.012471627048464742
# pnl EUR/USd : 162.0
# pnl au : -25.000231305159105
# pnl ch : 14.273995206436666
# pnl gp -80.7251859792159
# pnl jp : 26.554605414828984
# total combo :  -64.89681666310935
# pnl total : 97.10318333689065
#
#
# Profit en Long : 97.10318333689065
# Profit en Short :  149.5974525538786
#
#
# Date :  07.06.2011 16:50:00.000 GMT+0200
#  ACTION OPEN SHORT  -
# close EUR/USA  1.4687700000000001
# close AUD/USD :  1.07237
# Close CHF/USD :  1.1937590278026478
# Close GBP/USD :  1.64537
# Close JPY/USD :  0.012463544133409778
#
#
# Date :  07.06.2011 19:50:00.000 GMT+0200
#  ACTION CLOSE SHORT  -
# close EUR/USA  1.46828
# close AUD/USD :  1.07244
# Close CHF/USD :  1.1932035127911418
# Close GBP/USD :  1.6442299999999999
# Close JPY/USD :  0.01247800751176052
# pnl EUR/USd : 49.0
# pnl au : 2.243610501747753
# pnl ch : -6.459885608741388
# pnl gp -71.338536446754
# pnl jp : 176.34351687759045
# total combo :  100.7887053238428
# pnl total : 149.7887053238428
#
#
# Date :  07.06.2011 21:10:00.000 GMT+0200
#  ACTION OPEN LONG  -
# close EUR/USA  1.4689299999999998
# close AUD/USD :  1.0732700000000002
# Close CHF/USD :  1.1944862514632455
# Close GBP/USD :  1.6450099999999999
# Close JPY/USD :  0.01249500199920032
#
#
# Date :  07.06.2011 21:25:00.000 GMT+0200
#  ACTION CLOSE LONG  -
# close EUR/USA  1.46849
# close AUD/USD :  1.07261
# Close CHF/USD :  1.1941724385001191
# Close GBP/USD :  1.64462
# Close JPY/USD :  0.012487980318943015
# pnl EUR/USd : -43.999999999970896
# pnl au : 21.154041873596725
# pnl ch : 3.6492188372012606
# pnl gp 24.40528878441546
# pnl jp : 85.61124247292173
# total combo :  134.81979196813518
# pnl total : 90.81979196816428
#
#
# Profit en Long : 90.81979196816428
# Profit en Short :  149.7887053238428
#
#
# Date :  07.06.2011 21:50:00.000 GMT+0200
#  ACTION OPEN LONG  -
# close EUR/USA  1.4686299999999999
# close AUD/USD :  1.0722
# Close CHF/USD :  1.1958146487294468
# Close GBP/USD :  1.64418
# Close JPY/USD :  0.0124998437519531
#
#
# Date :  07.06.2011 22:00:00.000 GMT+0200
#  ACTION CLOSE LONG  -
# close EUR/USA  1.46801
# close AUD/USD :  1.0707799999999998
# Close CHF/USD :  1.1959290574883097
# Close GBP/USD :  1.64357
# Close JPY/USD :  0.0124892280408148
# pnl EUR/USd : -62.0
# pnl au : 45.51324160682998
# pnl ch : -1.33041858380966
# pnl gp 38.172374765359564
# pnl jp : 129.4311599190405
# total combo :  211.7863577074204
# pnl total : 149.7863577074204
#
#
# Profit en Long : 149.7863577074204
# Profit en Short :  149.7887053238428
#
#
# Date :  08.06.2011 00:45:00.000 GMT+0200
#  ACTION OPEN SHORT  -
# close EUR/USA  1.4687299999999999
# close AUD/USD :  1.07192
# Close CHF/USD :  1.1950572432419513
# Close GBP/USD :  1.644
# Close JPY/USD :  0.01247224924542892
#
#
# Date :  08.06.2011 03:00:00.000 GMT+0200
#  ACTION CLOSE SHORT  -
# close EUR/USA  1.4674200000000002
# close AUD/USD :  1.0685799999999999
# Close CHF/USD :  1.1943578535000656
# Close GBP/USD :  1.6423900000000002
# Close JPY/USD :  0.012501718986360624
# pnl EUR/USd : 130.9999999999709
# pnl au : -107.05227251183533
# pnl ch : -8.132953448475746
# pnl gp -100.75003831510548
# pnl jp : 359.30732304332196
# total combo :  143.3720587679054
# pnl total : 274.3720587678763
#
#
# Date :  08.06.2011 03:05:00.000 GMT+0200
#  ACTION OPEN LONG  -
# close EUR/USA  1.46605
# close AUD/USD :  1.06752
# Close CHF/USD :  1.1943293243679012
# Close GBP/USD :  1.64192
# Close JPY/USD :  0.012519561815336464
#
#
# Date :  08.06.2011 06:55:00.000 GMT+0200
#  ACTION CLOSE LONG  -
# close EUR/USA  1.4661899999999999
# close AUD/USD :  1.06653
# Close CHF/USD :  1.1943150603129105
# Close GBP/USD :  1.6419099999999998
# Close JPY/USD :  0.01249188027781942
# pnl EUR/USd : 14.0
# pnl au : 31.731062810395088
# pnl ch : 0.16587159959453857
# pnl gp 0.625776635526563
# pnl jp : 337.5048041997361
# total combo :  370.0275152452523
# pnl total : 384.0275152452523
#
#
# Profit en Long : 384.0275152452523
# Profit en Short :  274.3720587678763
#
#
# Date :  08.06.2011 07:00:00.000 GMT+0200
#  ACTION OPEN SHORT  -
# close EUR/USA  1.46648
# close AUD/USD :  1.06693
# Close CHF/USD :  1.1941153993121896
# Close GBP/USD :  1.6421400000000002
# Close JPY/USD :  0.012479408975190934
#
#
# Date :  08.06.2011 07:15:00.000 GMT+0200
#  ACTION CLOSE SHORT  -
# close EUR/USA  1.46708
# close AUD/USD :  1.06713
# Close CHF/USD :  1.1946860365096053
# Close GBP/USD :  1.64219
# Close JPY/USD :  0.012495938819883536
# pnl EUR/USd : -60.0
# pnl au : 6.410315719265782
# pnl ch : 6.635736106220065
# pnl gp 3.128883177487296
# pnl jp : 201.53873291879427
# total combo :  217.7136679217674
# pnl total : 157.7136679217674
#
#
# Date :  08.06.2011 08:30:00.000 GMT+0200
#  ACTION OPEN LONG  -
# close EUR/USA  1.46753
# close AUD/USD :  1.06716
# Close CHF/USD :  1.195228647240217
# Close GBP/USD :  1.6429799999999999
# Close JPY/USD :  0.01250969501363557
#
#
# Date :  08.06.2011 09:00:00.000 GMT+0200
#  ACTION CLOSE LONG  -
# close EUR/USA  1.4678200000000001
# close AUD/USD :  1.06748
# Close CHF/USD :  1.1958432488669386
# Close GBP/USD :  1.6424299999999998
# Close JPY/USD :  0.012505158377830856
# pnl EUR/USd : 29.0
# pnl au : -10.256505150835437
# pnl ch : -7.146982748143273
# pnl gp 34.41771495237481
# pnl jp : 55.31254823014024
# total combo :  72.32677528353634
# pnl total : 101.32677528353634
#
#
# Profit en Long : 101.32677528353634
# Profit en Short :  157.7136679217674
#
#
# Date :  08.06.2011 09:15:00.000 GMT+0200
#  ACTION OPEN SHORT  -
# close EUR/USA  1.46733
# close AUD/USD :  1.06639
# Close CHF/USD :  1.196029183112068
# Close GBP/USD :  1.63741
# Close JPY/USD :  0.012507817385866166
#
#
# Date :  08.06.2011 09:35:00.000 GMT+0200
#  ACTION CLOSE SHORT  -
# close EUR/USA  1.4671100000000001
# close AUD/USD :  1.06489
# Close CHF/USD :  1.1970456912340344
# Close GBP/USD :  1.63822
# Close JPY/USD :  0.012522226952841293
# pnl EUR/USd : 22.0
# pnl au : -48.07736789453338
# pnl ch : 11.820609798567602
# pnl gp 50.68790747530875
# pnl jp : 175.68742623308208
# total combo :  190.11857561242505
# pnl total : 212.11857561242505
#  ------------------------------------------------------------------------
#  --------------------------------RESULTATS--------------------------------
#  ------------------------------------------------------------------------
# Le profit généré en $  1910.09
# Nombre de trades long :  5
# Nombre de trades short :  6

# %%
backtest_df.index[mark]
# Out:
# '07.06.2011 13:40:00.000 GMT+0200'

# %%
coef[0],coef[1],coef[2],coef[3]
# Out:
# (0.3205157859635524,
#  0.11628642745815691,
#  0.6257766354976829,
#  121.92415395711004)

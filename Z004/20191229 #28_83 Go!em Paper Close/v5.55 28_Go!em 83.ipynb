# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()


print('Importing Librairies...')
import warnings
warnings.filterwarnings("ignore")
import talib
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from sklearn.preprocessing import MinMaxScaler
import yaml
from keras.models import model_from_yaml
from sklearn.metrics import  precision_score,accuracy_score,recall_score
import pickle
import sys

import xgboost as xgb
from xgboost import XGBRegressor, plot_importance
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')
import time
import datetime as dt
import os
import shutil
import ib_insync
from ib_insync import *

import smtplib
import mimetypes
from email.message import EmailMessage

print('Librairies imported')
print('')

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5780(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print(Fore.YELLOW,Back.BLUE,'OneShot Go!em Stop compte #25 -- 0.5 % -- ',Style.RESET_ALL)

print('')

ib = IB()
os.system('say "Le golem pour te servir, mon maitre. Hoilleli, hoille vavhoille li, mon bon maitre, si je ne te sers pas ou si je ne remplis pas ma mission"')
compte = 'DU1507428'
LeNom = 'Test_25'
adjusted = 'oui'
LeChemin = 'DL_2019-12-16/'
choupinet_le_canard_il_est_un_vrai_cafard = LeChemin

#LaDate = input('Entrez la date')
#start = LaDate[:2]+str(int(LaDate[2:4]) - 4)+'-'+LaDate[5:]
#end = LaDate
#stamp = LaDate

print('')

print('adjusted = ',adjusted,', LeNom = ', LeNom,', LeChemin = ',LeChemin)


if adjusted == 'oui':

    LaBase = pd.read_csv('LaBase_adj.csv')
    LaBase.index = pd.to_datetime(LaBase['Date'],format='%Y-%m-%d')
    LaBase = LaBase.sort_index()
    try:
        BasePrep = pd.read_csv('BasePrep.csv')
        BasePrep.index = pd.to_datetime(BasePrep['Date'],format='%Y-%m-%d')
        BasePrep = BasePrep.sort_index()
    except:
        BasePrep = pd.DataFrame()
    
else:
    
    os.system('say "Dommage. Tu né pas sérieux. Une question. Je te pose une pauvre petite question. Et non, on prend ça à la légère... Bref"')
    print("Dommage. Tu n'es pas sérieux. Une question. Je te pose une pauvre petite question. Et non, on prend ça à la légère... Bref")
    time.spleep(3)
    os._exit(0)
    
try:
    LaBase = LaBase.drop(['Unnamed: 0'],axis=1)
except:
    pass

constituents = sorted(LaBase['Symbol'].unique())

long = len(constituents)

jour = time.strftime("%A", time.localtime())
today = str(dt.date.today())[:5]+str(dt.date.today())[5:7]+str(dt.date.today())[7:10]
heure = time.strftime("%H:%M:%S", time.localtime()) 

#startday = str(dt.date.today()-dt.timedelta(7))[:5]+str(dt.date.today()-dt.timedelta(7))[5:7]+str(dt.date.today()-dt.timedelta(7))[7:10]
#yesterday = str(dt.date.today()-dt.timedelta(1))[:5]+str(dt.date.today()-dt.timedelta(1))[5:7]+str(dt.date.today()-dt.timedelta(1))[7:10]
#stamp = input("Enter the date (YYYY-MM-DD): ")


resultats = pd.DataFrame()

signals = pd.DataFrame(columns = ['Date','Ticker','Open Long','Close Long','Open Short','Close Short','Buy/Sell Price',\
                                  'Quantity','PNL','Cumulative PNL','Latent PNL'])

backtest = pd.DataFrame(columns = ['Symb.','Name','Sector','Period','Begin.','End',\
                          'Pnl $','Pnl %','Gross Profit','Gross Loss','# Winners','# Loosers',\
                          '% Winners','MaxDD $','MaxDD %','Aver. Win $',\
                          'Aver. Loos $','Aver. Duration',\
                          'Total Trades','% Long','% Short','Profit Factor'])


if jour == 'Sunday' and heure > '08:00:00' and heure < '23:50:00':
    print('We are ',jour,' ',today,' ',heure)
    yesterday = str(dt.date.today()-dt.timedelta(2))[:5]+str(dt.date.today()-dt.timedelta(2))[5:7]+str(dt.date.today()-dt.timedelta(2))[7:10]
    print('Hier : ', yesterday)
    dd = 1

elif jour == 'Monday' and heure > '08:00:00' and heure < '21:50:00':
    print('We are ',jour,' ',today,' ',heure)
    yesterday = str(dt.date.today()-dt.timedelta(3))[:5]+str(dt.date.today()-dt.timedelta(3))[5:7]+str(dt.date.today()-dt.timedelta(3))[7:10]
    print('Hier : ', yesterday)
    dd = 2

elif jour == 'Tuesday' and heure > '08:00:00' and heure < '21:50:00':
    print('We are ',jour,' ',today,' ',heure)
    yesterday = str(dt.date.today()-dt.timedelta(1))[:5]+str(dt.date.today()-dt.timedelta(1))[5:7]+str(dt.date.today()-dt.timedelta(1))[7:10]
    print('Hier : ', yesterday)
    dd = 3


elif jour == 'Wednesday' and heure > '08:00:00' and heure < '21:50:00':
    print('We are ',jour,' ',today,' ',heure)
    yesterday = str(dt.date.today()-dt.timedelta(1))[:5]+str(dt.date.today()-dt.timedelta(1))[5:7]+str(dt.date.today()-dt.timedelta(1))[7:10]
    print('Hier : ', yesterday)
    dd = 4


elif jour == 'Thursday' and heure > '08:00:00' and heure < '21:50:00':
    print('We are ',jour,' ',today,' ',heure)
    yesterday = str(dt.date.today()-dt.timedelta(1))[:5]+str(dt.date.today()-dt.timedelta(1))[5:7]+str(dt.date.today()-dt.timedelta(1))[7:10]
    print('Hier : ', yesterday)
    dd = 5


elif jour == 'Friday' and heure > '08:00:00' and heure < '21:50:00':
    print('We are ',jour,' ',today,' ',heure)
    yesterday = str(dt.date.today()-dt.timedelta(1))[:5]+str(dt.date.today()-dt.timedelta(1))[5:7]+str(dt.date.today()-dt.timedelta(1))[7:10]
    print('Hier : ', yesterday)
    dd = 6
else:
    
    os.system('say "Nous ne sommes pas dans un créneau où il est pertient dopérer"')
    print("Nous ne sommes pas dans un créneau où il est pertient d'opérer")
    time.sleep(4)
    os._exit(0)
    
    dd = 0

stamp = yesterday
start = '2015-12-06'
end = stamp

print('Date et heure actuelle : ',time.strftime("%d/%m/%Y %H:%M:%S", time.localtime()))
print('La date scrapée est : ', stamp)
print('La dernière date de la base est :',LaBase.index[-1])

print(Fore.YELLOW,'ON GENERE LaBase',Style.RESET_ALL)
tmps55=time.time()

df = pd.DataFrame()
BADTICKER = ['AMCR']

def load_boost(df,model):
    seed = 770
    np.random.seed(seed)
    X = df.copy()
    X = X.drop(['Close'],axis=1)
    X['Close'] = df['Close']
    y = X.iloc[:,-1]
    Xtrain = X.iloc[:-2,:-1]
    Xtest = X.iloc[-2:-1,:-1]
    yshift = y.shift(-1)
    ytrain = yshift.iloc[:-2]
    ytest = yshift.iloc[-2:-1]

    y_pred = model.predict(Xtest)

    pred = model.predict(X.iloc[:,:-1])

    df['Close.S'] = pred
    df['Close.S2'] = df['Close.S']
    df = df.dropna()
    return(df)


def prepa_data(df):
    rsi = talib.RSI(df['Close'],timeperiod=14)
    stoc_slowk, stoc_slowd = talib.STOCH(df['High'],df['Low'],df['Close'])
    upper, middle, lower =  talib.BBANDS(df['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(df['Close'],timeperiod=5)
    sma8 = talib.SMA(df['Close'],timeperiod=8)
    sma10 = talib.SMA(df['Close'],timeperiod=10)
    sma12 = talib.SMA(df['Close'],timeperiod=12)
    sma15 = talib.SMA(df['Close'],timeperiod=15)
    sma30 = talib.SMA(df['Close'],timeperiod=30)
    sma35 = talib.SMA(df['Close'],timeperiod=35)
    sma40 = talib.SMA(df['Close'],timeperiod=40)
    sma45 = talib.SMA(df['Close'],timeperiod=45)
    sma50 = talib.SMA(df['Close'],timeperiod=50)
    atr = talib.ATR(df['High'],df['Low'],df['Close'],timeperiod=10)
    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50
    bbdelta = upper - middle
    price_bolup = df['Close'] - lower
    price_bolow = df['Close'] - upper
    Ema = talib.EMA(df['Close'],timeperiod=20)
    KC_High = Ema + 2*atr
    KC_Low = Ema - 2*atr
    aroondown, aroonup = talib.AROON(df['High'], df['Low'], timeperiod=9)
    aroon = aroonup - aroondown #(aroonup-aroondown)/abs((aroonup-aroondown))
    rsi30_list = []
    rsi70_list = []
    for i in range(0,df.shape[0]):
        rsi70_list.append(70 - rsi[i])
        rsi30_list.append(rsi[i] - 30)
        #except:
         #   rsi70_list.append(0)
          #  rs30_list.append(0)
    varop_spy = df['Open'] - df['Close']
    varhl_spy = df['High'] - df['Low']
    df['Varop_Spy'] = varop_spy
    df['Varhl_spy'] = varhl_spy
    df['RSI'] = rsi
    df['70 - RSI'] = np.array(rsi70_list)
    df['RSI - 30'] = np.array(rsi30_list)
    df['BBD_Delta_Up'] = bbdelta
    df['delta5_8'] = delta5_8
    df['delta8_10'] = delta8_10
    df['delta10_12'] = delta10_12
    df['delta12_15'] = delta12_15
    df['delta15_30'] = delta15_30
    df['delta30_35'] = delta30_35
    df['delta35_40'] = delta35_40
    df['delta40_45'] = delta40_45
    df['delta45_50'] = delta45_50
    df['Stoc_Slowk'] = stoc_slowk
    df['Stoc_Slowd'] = stoc_slowd
    df['KC_High'] = KC_High
    df['KC_Low'] = KC_Low
    df['upper'] = upper
    df['lower'] = lower
    df['var_bollup_kchigh'] = upper-KC_High
    df['var_bolllow_kclow'] = lower-KC_Low
    df['Aroon Up'] = aroonup
    df['Aroon Down'] = aroondown
    df['Delta Aroon'] = aroon
    up = []
    down = []
    df = df.dropna()
    
    df['%Futur'] = ((df['Close.S']-df['Close']) *100) / (df['Close'])
    df['%Futur2'] = ((df['Close.S2']-df['Close']) *100) / (df['Close'])
    for i in range(0,df.shape[0]):
        if df.iloc[i]['%Futur'] > 0.5 :#or df.iloc[i]['%Futur2'] > 0.1:
            up.append(1)
            down.append(0)
        elif df.iloc[i]['%Futur'] < -0.5: #or df.iloc[i]['%Futur2'] < -0.1:
            up.append(0)
            down.append(1)
        else:
            up.append(0)
            down.append(0)

    df['target_up'] = up  # target_up # abs(np.array(valley))#target_up
    df['target_down'] = down # target_down # abs(np.array(peak))#target_down
    df = df[['High','Low','Open','Volume','Close','Varop_Spy','Varhl_spy','RSI','70 - RSI','RSI - 30','BBD_Delta_Up','delta5_8','delta8_10','delta10_12','delta12_15','delta15_30','delta30_35','delta35_40','delta40_45','delta45_50','Stoc_Slowk','Stoc_Slowd','KC_High','KC_Low','upper','lower','var_bollup_kchigh','var_bolllow_kclow','Aroon Up','Aroon Down','Delta Aroon','Close.S','Close.S2','%Futur','%Futur2','target_up','target_down']]
    df = df.dropna()
    return(df)


def deep_learning(df):
    seed = 770
    np.random.seed(seed)
    X = df.copy()
    #####################X = X.iloc[:,1:-4]
    X = X.iloc[:,:-4]
    X.astype(np.float64)
    y_up = df.iloc[:,-2].values
    y_down = df.iloc[:,-1].values

    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:bloc1,:]
    Xtest = X[bloc1:,:]
    ytrain_up = y_up[:bloc1,:]
    ytest_up = y_up[bloc1:,:]
    ytrain_down = y_down[:bloc1,:]
    ytest_down = y_down[bloc1:,:]

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)
    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    yhat_up = model_up.predict_classes(Xtest)
    yhat_down = model_down.predict_classes(Xtest)

    predict_up = model_up.predict(Xtest)
    predict_down = model_down.predict(Xtest)

    precision_up = precision_score(ytest_up, yhat_up)  
    precision_down = precision_score(ytest_down, yhat_down) 

    resultats = pd.DataFrame()
    resultats['Date'] = df.index[bloc1:].strftime('%Y-%m-%d')
    resultats.index= df.index[bloc1:]
    resultats['Move Up'] = yhat_up
    resultats['Confiance up'] = (predict_up)*100
    resultats['Move Down'] = yhat_down
    resultats['Confiance Down'] = (predict_down)*100
    resultats['Actual'] = df.iloc[bloc1:]['Close']
    resultats['Actual.S'] = df.iloc[bloc1:]['Close.S']
    open_S = df['Open'].shift(-1)
    resultats['Open.S'] = open_S.iloc[bloc1:]
    dmp_cp=[]
    dmp_cp = ((resultats['Confiance up']-resultats['Confiance Down'])/(resultats['Confiance up']+resultats['Confiance Down'])*100)
    resultats['DMP_CP'] = dmp_cp
    
    return(resultats,precision_up,precision_down,scaler)

def conX():
    util.startLoop()  # uncomment this line when in a notebook
    ib.connect('127.0.0.1', 7497, clientId=1)
    if ib.isConnected() == True:
        print('Golem est maintenant connecté à IB')
    return

def disconX():
    ib.disconnect()
    if ib.isConnected() == False:
        print('Golem est maintenant déconnecté de IB')
    return


def relevpoz():
    CPT = []
    QT = []
    TYPE = []
    STOCK = []
    TICK = []
    AVGCOST = []
    CONID = []
    globalpoz = ib.positions(account=compte)
    
    if globalpoz == []:
        print("Il n'y a aucune position en cours actuellement.")
        poz = pd.DataFrame({'ALERTE': [101]}) 
    else:
        print('Il y a actuellement ',len(globalpoz),'positions en cours')
        for i in range(0,len(globalpoz)):
            CPT.append(globalpoz[i][0])
            TYPE.append(str(globalpoz[i][1]).split("(")[0])
            if str(globalpoz[i][1]).split("(")[0] == 'Future':
                TICK.append(str(globalpoz[i][1]).split("'")[1])
            elif str(globalpoz[i][1]).split("(")[0] == 'Forex':
                TICK.append(str(globalpoz[i][1]).split("'")[1])
            elif str(globalpoz[i][1]).split("(")[0] == 'Stock':
                TICK.append(str(globalpoz[i][1]).split("'")[1])
            else:
                TICK.append('NA')

            QT.append(globalpoz[i][2])
            AVGCOST.append(globalpoz[i][3])
            CONID.append(ib.positions(account=compte)[i][1].conId)
            poz = pd.DataFrame()
            
            poz['Compte'] = CPT
            poz['Type'] = TYPE
            poz['conId'] = CONID
            poz['Ticker'] = TICK
            poz['Quantité'] = QT
            poz['Average Cost'] = AVGCOST
            #poz.to_csv('Relev_poz/RelevPoz_'+time.strftime("%d_%m_%Y_%H_%M_%S", time.localtime())+'.csv')
    return(poz)

def price_close(LaBase,ticker):
    
    price = round(LaBase[LaBase['Symbol']==ticker].iloc[-1]['Close'],2)
        
    return(price)

def bracketOrder(action: str, quantity: float,limitPrice: float, takeProfitPrice: float,stopLossPrice: float, **kwargs) -> BracketOrder:
    """
    Create a limit order that is bracketed by a take-profit order and
    a stop-loss order. Submit the bracket like:

    .. code-block:: python

        for o in bracket:
            ib.placeOrder(contract, o)

    https://interactivebrokers.github.io/tws-api/bracket_order.html

    Args:
        action: 'BUY' or 'SELL'.
        quantity: Size of order.
        limitPrice: Limit price of entry order.
        takeProfitPrice: Limit price of profit order.
        stopLossPrice: Stop price of loss order.
    """
    assert action in ('BUY', 'SELL')
    reverseAction = 'BUY' if action == 'SELL' else 'SELL'
    parent = LimitOrder(
        action, quantity, limitPrice,
        orderId=ib.client.getReqId(),
        transmit=False,
        **kwargs)
    takeProfit = LimitOrder(
        reverseAction, quantity, takeProfitPrice,
        orderId=ib.client.getReqId(),
        transmit=False,
        parentId=parent.orderId,tif='GTC',
        **kwargs)
    stopLoss = StopOrder(
        reverseAction, quantity, stopLossPrice,
        orderId=ib.client.getReqId(),
        transmit=True,
        parentId=parent.orderId,tif='GTC',
        **kwargs)
    return BracketOrder(parent, takeProfit, stopLoss)


def CLOSE_SHORT(contract,quantity,price,ticker):    
    try:
        transact_price = poz[poz['Ticker'] == ticker].iloc[-1]['Average Cost']
    except:
        transact_price = price
    ib.qualifyContracts(contract)
    order = LimitOrder('BUY', quantity, price,account=compte)
    trade = ib.placeOrder(contract, order)
    print(trade,'\n \n')
    return()

def CLOSE_LONG(contract,quantity,price,ticker):
    try:
        transact_price = poz[poz['Ticker'] == ticker].iloc[-1]['Average Cost']
    except:
        transact_price = price
    ib.qualifyContracts(contract)
    order = LimitOrder('SELL', quantity, price,account=compte)
    trade = ib.placeOrder(contract, order)
    print(trade,'\n \n')
    return()

def OPEN_LONG(contract,quantity,price,ticker):
 
    takeProfitPrice = round(price * 1.02,2)
    stopLossPrice = round(price * 0.85,2)
    ib.qualifyContracts(contract)
    order = bracketOrder(action='BUY', quantity=quantity, limitPrice = price,takeProfitPrice=takeProfitPrice, stopLossPrice=stopLossPrice,account=compte) 
    for o in order:
        trade = ib.placeOrder(contract, o)
        print(trade,'\n \n')
    return()

def OPEN_SHORT(contract,quantity,price,ticker):

    takeProfitPrice = round(price * 0.98,2)
    stopLossPrice = round(price * 1.15,2)
    ib.qualifyContracts(contract)
    order = bracketOrder(action='SELL',quantity=quantity, limitPrice = price,takeProfitPrice=takeProfitPrice, stopLossPrice=stopLossPrice,account=compte)
    for o in order:
        trade = ib.placeOrder(contract, o)
        print(trade,'\n \n')
    return()

def MAKE_LABASE(LaBase,start,end,constituents,long):
    print('Longueur de long : ',long,' - Date de début : ',start,' - Date de fin : ',end) 
    for loop,ticker in enumerate(constituents):

        if loop == 1:
            print('\r',Fore.GREEN,' |==',Fore.BLUE,'O',Fore.RED,'==================|',end='',flush=True)
        if loop == round(long/9):
            print('\r',Fore.GREEN,' |====',Fore.BLUE,'O',Fore.RED,'================|',end='',flush=True)
        if loop == round(long/9)*2:
            print('\r',Fore.GREEN,' |======',Fore.BLUE,'O',Fore.RED,'==============|',end='',flush=True)
        if loop == round(long/9)*3:
            print('\r',Fore.GREEN,' |========',Fore.BLUE,'O',Fore.RED,'============|',end='',flush=True)
        if loop == round(long/9)*4:
            print('\r',Fore.GREEN,' |==========',Fore.BLUE,'O',Fore.RED,'==========|',end='',flush=True)
        if loop == round(long/9)*5:
            print('\r',Fore.GREEN,' |============',Fore.BLUE,'O',Fore.RED,'========|',end='',flush=True)
        if loop == round(long/9)*6:
            print('\r',Fore.GREEN,' |==============',Fore.BLUE,'O',Fore.RED,'======|',end='',flush=True)
        if loop == round(long/9)*7:
            print('\r',Fore.GREEN,' |================',Fore.BLUE,'O',Fore.RED,'====|',end='',flush=True)
        if loop == round(long/9)*8:
            print('\r',Fore.GREEN,' |==================',Fore.BLUE,'O',Fore.RED,'==|',end='',flush=True)

        try:
            df = web.DataReader(ticker,'yahoo',start,end)
            df['Date'] = df.index
            df['Date'] = df['Date'].dt.strftime('%Y-%m-%d')
        except:
            BADTICKER.append(ticker)
            continue

        if adjusted == 'oui':

            df = df.drop(['Close'],axis=1)
            df['Close'] = df['Adj Close']
            df = df.drop(['Adj Close'],axis = 1)


        df['Symbol'] = ticker
        df = df[['Date','Symbol','High','Low','Open','Volume','Close']]
        df = df.iloc[-1:,:]
        LaBase = pd.concat((LaBase,df),ignore_index=False)
        #LaBase = LaBase.drop_duplicates()
        LaBase = LaBase.drop(['Date'],axis=1)
    tmps22=round(time.time()-tmps55,2)
    print(Fore.BLUE,"\n Time for completing LaBase Generation = %f" %tmps22,'seconds \n',Style.RESET_ALL)

    print('Il y a ',len(BADTICKER),' mauvais tickers \n')
    print('Les voici : ')
    print(BADTICKER)
    LaBase = LaBase[['Symbol','High','Low','Open','Volume','Close']]
    
    
    if adjusted == 'oui':
        try:
            os.remove('LaBase_adj.csv')
        except:
            pass
        LaBase.to_csv('LaBase_adj.csv')

    return(LaBase,BADTICKER,BLACKLIST)
    
BLACKLIST = []

if LaBase.index.strftime('%Y-%m-%d')[-1] == yesterday:
    
    print('La Base est déjà à jour')

else:
    
    print('Mise à jour de la base')
    LaBase,BADTICKER,BLACKLIST = MAKE_LABASE(LaBase,start,end,constituents,long)
    BLACKLIST = set(LaBase[LaBase['Volume']==0]['Symbol'])
    print('Il y a ',len(BLACKLIST),' tickers black-listés (vol à 0) \n')
    print('Les voici : ')
    print(BLACKLIST)
    



warnings.filterwarnings("ignore",message="Precision is ill-defined and being set to 0.0 due to no predicted samples.")
tmps55=time.time()
BasePrep = BasePrep[['Symbol','High','Low','Open','Volume','Close','Varop_Spy','Varhl_spy','RSI','70 - RSI','RSI - 30','BBD_Delta_Up','delta5_8','delta8_10','delta10_12','delta12_15','delta15_30','delta30_35','delta35_40','delta40_45','delta45_50','Stoc_Slowk','Stoc_Slowd','KC_High','KC_Low','upper','lower','var_bollup_kchigh','var_bolllow_kclow','Aroon Up','Aroon Down','Delta Aroon','Close.S','Close.S2','%Futur','%Futur2','target_up','target_down']]
bloc1 = round(0.75 * LaBase[LaBase['Symbol']=='A'].shape[0])
print(Back.WHITE,Fore.BLACK,'Le bloc1 est à :',bloc1,'. ',Style.RESET_ALL)
filtre_up = 93
filtre_down = 97
filtre_up_close = 80
filtre_down_close = 80

list_dir = os.listdir('DL_2019-12-16/.')

NEW_LIST = []

for pikunichihouahoua in range(0,len(str(list_dir).split(','))):
    if str(list_dir).split(',')[pikunichihouahoua].split(',')[0].split('.')[1].split("'")[0]=='yaml':
        NEW_LIST.append(str(list_dir).split(',')[pikunichihouahoua].split(',')[0].split('.')[0].split("'")[1].split('_')[1])

NEW_LIST = set(sorted(NEW_LIST))
    
print('\n Date : ',stamp)

print('Génération de signaux')

DATE = []
TICKER = []
GREEN = []
GREEN_CLOSE = []
RED = []
RED_CLOSE = []
PRICE = []
OPEN_S = []
error = []
PB_LNG = []
PB_DATE = []


pos_long = 0
pos_short = 0
pactol = 10000
price_buy = 0
price_sell = 0
x = 0
winners = []
loosers = []
nb_win = 0
nb_los = 0
mini_pnl = 0
pos_duration = []
average_duration = ''#resultats.iloc[0,0] - resultats.iloc[0,0]
trades = []
eq_curx = []
eq_cury = []
maxdd = []
nbS = 0
nbL = 0

if BasePrep.index[-1].strftime('%Y-%m-%d') == yesterday:
    
    print('La Base est déjà à jour')

else:

    for loop,ticker in enumerate(NEW_LIST): # ON BOUCLE SUR LE TICKER

        long = len(NEW_LIST)

        if loop == 1:
            print('\r',Fore.GREEN,' |==',Fore.BLUE,'O',Fore.RED,'==================|',end='',flush=True)
        if loop == round(long/9):
            print('\r',Fore.GREEN,' |====',Fore.BLUE,'O',Fore.RED,'================|',end='',flush=True)
        if loop == round(long/9)*2:
            print('\r',Fore.GREEN,' |======',Fore.BLUE,'O',Fore.RED,'==============|',end='',flush=True)
        if loop == round(long/9)*3:
            print('\r',Fore.GREEN,' |========',Fore.BLUE,'O',Fore.RED,'============|',end='',flush=True)
        if loop == round(long/9)*4:
            print('\r',Fore.GREEN,' |==========',Fore.BLUE,'O',Fore.RED,'==========|',end='',flush=True)
        if loop == round(long/9)*5:
            print('\r',Fore.GREEN,' |============',Fore.BLUE,'O',Fore.RED,'========|',end='',flush=True)
        if loop == round(long/9)*6:
            print('\r',Fore.GREEN,' |==============',Fore.BLUE,'O',Fore.RED,'======|',end='',flush=True)
        if loop == round(long/9)*7:
            print('\r',Fore.GREEN,' |================',Fore.BLUE,'O',Fore.RED,'====|',end='',flush=True)
        if loop == round(long/9)*8:
            print('\r',Fore.GREEN,' |==================',Fore.BLUE,'O',Fore.RED,'==|',end='',flush=True)

        LeChemin = 'DL_2019-12-16/'
        yamlup = (LeChemin+'Save_'+ticker+'_up.yaml')
        yamldown = (LeChemin+'Save_'+ticker+'_down.yaml')
        modelup = (LeChemin+'Save_'+ticker+'_up.h5')
        modeldown = (LeChemin+'Save_'+ticker+'_down.h5')

        yaml_file_up = open(yamlup, 'r')
        yaml_file_down = open(yamldown, 'r')
        model_yaml_up = yaml_file_up.read()
        model_yaml_down = yaml_file_down.read()
        yaml_file_up.close()
        yaml_file_down.close()
        model_up = model_from_yaml(model_yaml_up)
        model_down = model_from_yaml(model_yaml_down)
        # load weights into new model
        model_up.load_weights(modelup)
        model_down.load_weights(modeldown)

        model = pickle.load(open('Boost/'+ticker+'_boost_09.dat', "rb"))

        try:
            LaBase = LaBase.drop(['Date'],axis=1)
        except:
            pass
        df = LaBase[LaBase['Symbol']==ticker] # ON REDUIT LaBase A df SUR CE TICKER
        if len(LaBase[LaBase['Symbol']==ticker])<820: # Si jamais il n'y a pas assez de valeurs (genre nouveau ticker dans le S&P)
            PB_LNG.append(ticker)
            continue # Alors, change donc de Ticker

        if str(LaBase[LaBase['Symbol']==ticker].index[-1])[:10] != end:
            PB_DATE.append(ticker)
            continue

        #df = df.iloc[-820:,:] # ON REDUIT df AUX 820 DERNIERES VALEURS JUSQU'A STAMP

        df = df.drop(['Symbol'],axis=1) # ON ENLEVE LA COLONNE 'Symbol'
        df = load_boost(df,model)
        df = prepa_data(df)
        df = df.iloc[-1:,:]
        df['Symbol'] = ticker
        df = df[['Symbol','High','Low','Open','Volume','Close','Varop_Spy','Varhl_spy','RSI','70 - RSI','RSI - 30','BBD_Delta_Up','delta5_8','delta8_10','delta10_12','delta12_15','delta15_30','delta30_35','delta35_40','delta40_45','delta45_50','Stoc_Slowk','Stoc_Slowd','KC_High','KC_Low','upper','lower','var_bollup_kchigh','var_bolllow_kclow','Aroon Up','Aroon Down','Delta Aroon','Close.S','Close.S2','%Futur','%Futur2','target_up','target_down']]

        BasePrep = pd.concat((BasePrep,df),ignore_index=False)
        
    BasePrep = BasePrep[['Symbol','High','Low','Open','Volume','Close','Varop_Spy','Varhl_spy','RSI','70 - RSI','RSI - 30','BBD_Delta_Up','delta5_8','delta8_10','delta10_12','delta12_15','delta15_30','delta30_35','delta35_40','delta40_45','delta45_50','Stoc_Slowk','Stoc_Slowd','KC_High','KC_Low','upper','lower','var_bollup_kchigh','var_bolllow_kclow','Aroon Up','Aroon Down','Delta Aroon','Close.S','Close.S2','%Futur','%Futur2','target_up','target_down']]

    try:
        os.remove('LaBase.csv')
    except:
        pass
    LaBase.to_csv('LaBase.csv')   

    try:
        os.remove('BasePrep.csv')
    except:
        pass
    BasePrep.to_csv('BasePrep.csv')  
    
        
print(Style.RESET_ALL,'\n Done.') 
    
df = pd.DataFrame()


for loop,ticker in enumerate(NEW_LIST): # ON BOUCLE SUR LE TICKER
    
    if loop == 1:
        print('\r',Fore.GREEN,' |==',Fore.BLUE,'O',Fore.RED,'==================|',end='',flush=True)
    if loop == round(long/9):
        print('\r',Fore.GREEN,' |====',Fore.BLUE,'O',Fore.RED,'================|',end='',flush=True)
    if loop == round(long/9)*2:
        print('\r',Fore.GREEN,' |======',Fore.BLUE,'O',Fore.RED,'==============|',end='',flush=True)
    if loop == round(long/9)*3:
        print('\r',Fore.GREEN,' |========',Fore.BLUE,'O',Fore.RED,'============|',end='',flush=True)
    if loop == round(long/9)*4:
        print('\r',Fore.GREEN,' |==========',Fore.BLUE,'O',Fore.RED,'==========|',end='',flush=True)
    if loop == round(long/9)*5:
        print('\r',Fore.GREEN,' |============',Fore.BLUE,'O',Fore.RED,'========|',end='',flush=True)
    if loop == round(long/9)*6:
        print('\r',Fore.GREEN,' |==============',Fore.BLUE,'O',Fore.RED,'======|',end='',flush=True)
    if loop == round(long/9)*7:
        print('\r',Fore.GREEN,' |================',Fore.BLUE,'O',Fore.RED,'====|',end='',flush=True)
    if loop == round(long/9)*8:
        print('\r',Fore.GREEN,' |==================',Fore.BLUE,'O',Fore.RED,'==|',end='',flush=True) 
        
        
        
    LeChemin = 'DL_2019-12-16/'
    yamlup = (LeChemin+'Save_'+ticker+'_up.yaml')
    yamldown = (LeChemin+'Save_'+ticker+'_down.yaml')
    modelup = (LeChemin+'Save_'+ticker+'_up.h5')
    modeldown = (LeChemin+'Save_'+ticker+'_down.h5')

    yaml_file_up = open(yamlup, 'r')
    yaml_file_down = open(yamldown, 'r')
    model_yaml_up = yaml_file_up.read()
    model_yaml_down = yaml_file_down.read()
    yaml_file_up.close()
    yaml_file_down.close()
    model_up = model_from_yaml(model_yaml_up)
    model_down = model_from_yaml(model_yaml_down)
    # load weights into new model
    model_up.load_weights(modelup)
    model_down.load_weights(modeldown)

    model = pickle.load(open('Boost/'+ticker+'_boost_09.dat', "rb"))

    df = BasePrep[BasePrep['Symbol']==ticker]
    
    if df.shape[0]<771:
        error.append(ticker)
        continue
    
    df = df.drop(['Symbol'],axis=1)
    
    try:
        df = df.drop(['Date'],axis=1)
    except:
        pass
    
    df = df[['High','Low','Open','Volume','Close','Varop_Spy','Varhl_spy','RSI','70 - RSI','RSI - 30','BBD_Delta_Up','delta5_8','delta8_10','delta10_12','delta12_15','delta15_30','delta30_35','delta35_40','delta40_45','delta45_50','Stoc_Slowk','Stoc_Slowd','KC_High','KC_Low','upper','lower','var_bollup_kchigh','var_bolllow_kclow','Aroon Up','Aroon Down','Delta Aroon','Close.S','Close.S2','%Futur','%Futur2','target_up','target_down']]
        
    resultats,precision_up,precision_down,scaler = deep_learning(df)
    
    i = -1 # ON DEFINIT L'INDEX DE FIN DE TEST A PARTIR DE stamp
    
    price = df.iloc[i]['Close']
    if price == '' or price == None or price == 'NaN':
        price = 9999999999
    

    if (precision_up * 100) > 83 and (precision_down * 100) > 83:

        ####################
        ##### SIGNALS #####
        ###################

        if resultats.iloc[i]['Confiance Down'] > filtre_down:
            doob = -1
        elif resultats.iloc[i]['Confiance Down'] > filtre_down_close and resultats.iloc[i]['Confiance Down'] < filtre_down :
            waab = -1
            doob = 0
        elif resultats.iloc[i]['Confiance up'] > filtre_up:
            doob = 1
        elif resultats.iloc[i]['Confiance up'] > filtre_up_close and resultats.iloc[i]['Confiance up'] < filtre_up:
            waab = 1
            doob = 0
        else :
            doob = 0
            waab = 0

        if doob == 1 :
            DATE.append(df.index[i])
            TICKER.append(ticker)
            GREEN.append(1)
            RED.append(0)
            GREEN_CLOSE.append(0)
            RED_CLOSE.append(1)
            PRICE.append(price)
            #OPEN_S.append(open_price)


        elif doob == -1 :
            DATE.append(df.index[i])
            TICKER.append(ticker)
            GREEN.append(0)
            RED.append(1)
            GREEN_CLOSE.append(1)
            RED_CLOSE.append(0)
            PRICE.append(price)
            #OPEN_S.append(open_price)


        elif doob == 0 and waab == -1 :
            DATE.append(df.index[i])
            TICKER.append(ticker)
            GREEN.append(0)
            RED.append(0)
            GREEN_CLOSE.append(1)
            RED_CLOSE.append(0)
            PRICE.append(price)
            #OPEN_S.append(open_price)


        elif doob == 0 and waab == 1 :
            DATE.append(df.index[i])
            TICKER.append(ticker)
            GREEN.append(0)
            RED.append(0)
            GREEN_CLOSE.append(0)
            RED_CLOSE.append(1)
            PRICE.append(price)
            #OPEN_S.append(open_price)


        else:
            DATE.append(df.index[i])
            TICKER.append(ticker)
            GREEN.append(0)
            RED.append(0)
            GREEN_CLOSE.append(0)
            RED_CLOSE.append(0)
            PRICE.append(price)
            #OPEN_S.append(open_price)



    else:
        DATE.append(df.index[i])
        TICKER.append(ticker)
        GREEN.append(0)
        RED.append(0)
        GREEN_CLOSE.append(0)
        RED_CLOSE.append(0)
        PRICE.append(price)
        #OPEN_S.append(open_price)
        
signals = pd.DataFrame(columns = ['Date','Ticker','Open Long','Close Long','Open Short','Close Short','Close Price'])
signals['Date'] = DATE
signals['Ticker'] = TICKER
signals['Open Long'] = GREEN
signals['Close Long'] = GREEN_CLOSE
signals['Open Short'] = RED
signals['Close Short'] = RED_CLOSE 
signals['Close Price'] = PRICE
#signals['Open.S Price'] = OPEN_S

signals = signals[(signals['Close Long']==1)|(signals['Close Short']==1)|(signals['Open Long']==1)|(signals['Open Short']==1)]

tmps22=round(time.time()-tmps55,2)
print(Fore.MAGENTA,"\n Ensemble des opérations du jour effectué en %f" %tmps22,'seconds \n',Style.RESET_ALL)  
try:
    os.remove('Results/Megasignals/SIGNALS_'+stamp+'.csv')
except:
    pass

signals.to_csv('Results/Megasignals/SIGNALS_'+stamp+'.csv')
# Out:
# Importing Librairies...
# Using TensorFlow backend.
# Librairies imported
#
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5780(c)
#  °0Oo_D.A.G._26_oO0°
#   OneShot Go!em Stop compte #25 -- 0.5 % --
#
#
# adjusted =  oui , LeNom =  Test_25 , LeChemin =  DL_2019-12-16/
# We are  Monday   2020-01-27   19:17:29
# Hier :  2020-01-24
# Date et heure actuelle :  27/01/2020 19:17:29
# La date scrapée est :  2020-01-24
# La dernière date de la base est : 2020-01-13 00:00:00
#  ON GENERE LaBase
# Mise à jour de la base
# Longueur de long :  501  - Date de début :  2015-12-06  - Date de fin :  2020-01-24
#    |==================  O  ==|
#  Time for completing LaBase Generation = 812.110000 seconds
#
# Il y a  3  mauvais tickers
#
# Les voici :
# ['AMCR', 'HCP', 'SYMC']
# Il y a  9  tickers black-listés (vol à 0)
#
# Les voici :
# {'UA', 'PFG', 'CELG', 'XEL', 'AMCR', 'SBAC', 'CBS', 'CHD', 'ARNC'}
#   Le bloc1 est à : 775 .
#
#  Date :  2020-01-24
# Génération de signaux
#    |==================  O  ==|
#  Done.
#    |==================  O  ==|
#  Ensemble des opérations du jour effectué en 443.680000 seconds

# %%
signals
# Out:
#           Date Ticker  Open Long  Close Long  Open Short  Close Short  \
# 11  2020-01-24    MCK          0           1           1            0
# 24  2020-01-24    AIG          0           1           0            0
# 32  2020-01-24   JBHT          0           1           1            0
# 42  2020-01-24    HRB          0           1           1            0
# 54  2020-01-24     GS          0           1           1            0
# 78  2020-01-24    HES          0           1           0            0
# 85  2020-01-24    STZ          0           1           1            0
# 120 2020-01-24    JEF          0           1           1            0
# 174 2020-01-24    CAG          0           1           1            0
# 198 2020-01-24    CHD          0           1           0            0
# 286 2020-01-24    SJM          0           1           1            0
# 307 2020-01-24    MPC          0           1           1            0
# 308 2020-01-24    CVX          0           1           1            0
# 329 2020-01-24   FBHS          0           1           1            0
# 336 2020-01-24    AGN          0           1           1            0
# 370 2020-01-24    HOG          0           1           0            0
# 375 2020-01-24     CE          0           1           1            0
#
#      Close Price
# 11    152.619995
# 24     51.060001
# 32    115.709999
# 42     23.940001
# 54    241.919998
# 78     64.410004
# 85    191.559998
# 120    21.889999
# 174    32.279999
# 198    71.309998
# 286   107.669998
# 307    54.490002
# 308   111.849998
# 329    69.510002
# 336   188.190002
# 370    35.230000
# 375   114.510002

# %%
try:
    disconX()
except:
    time.sleep(6)
    conX()

os.system('say "Béchème Hachème nahassé vénatsliahh"')
time.sleep(3)
conX()
time.sleep(3)
if ib.isConnected() == False:
    conX()

today = str(dt.date.today())[:5]+str(dt.date.today())[5:7]+str(dt.date.today())[7:10]
yesterday = str(dt.date.today()-dt.timedelta(1))[:5]+str(dt.date.today()-dt.timedelta(1))[5:7]+str(dt.date.today()-dt.timedelta(1))[7:10]

try:
    
    signals = pd.read_csv('Results/Megasignals/SIGNALS_'+stamp+'.csv')
    try:
        signals = signals.drop('Unnamed: 0',axis=1)
    except:
        pass
    print('Le fichier SIGNALS_'+stamp+'.csv a bien été chargé')
    
    
except:
    sys.exit("\n Golem n'a pas trouvé le fichier SIGNALS_"+stamp+".csv => Arrêt du programme")

poz = relevpoz()


foo = 0
ACTION = []
ASKED_PRICE = []
WHEN = []
OL = []
CL = []
OS = []
CS = []

try:
    signals['Tradé']
except:
    signals['Tradé'] = 'NA'
if (signals[signals['Tradé']=='NA'].shape[0] == signals.shape[0]):
    print('1er passage')
else:
    
    foo = signals[signals['Tradé']=='NA'].index[0]
    print('On reprend le passage en ligne ',foo)
    
try:
    pactol = float(str(str([v for v in ib.accountValues() if v.tag == 'NetLiquidationByCurrency' and v.currency == 'BASE']).split()[2]).split("'")[1])
except:
    print('Montant du pactol non récupéré')
    ib.isConnected()

print(Back.BLUE,Fore.YELLOW,'Les fonds disponibles sur le compte sont de : $',pactol,Style.RESET_ALL)
mise = pactol * 0.02
tmps55=time.time()
for i in range (foo,signals.shape[0]):

    horo = signals.iloc[i,0]
    ticker = signals.iloc[i,1]
    openlong = signals.iloc[i,2]
    closelong = signals.iloc[i,3]
    openshort = signals.iloc[i,4]
    closeshort = signals.iloc[i,5]
    contract = Stock(ticker,'SMART','USD')
    price = price_close(LaBase,ticker)

    en_poz = 0
    if poz.iloc[0,0] != 101:
        if len(poz[ticker == poz.iloc[:]['Ticker']]) > 1:
            exit("Il y a plus d'une position pour le ticker ",ticker)
        elif len(poz[ticker == poz.iloc[:]['Ticker']]) == 1:
            indeX = int(str(str(poz[ticker == poz.iloc[:]['Ticker']].index).split('[')[1]).split(']')[0])
            quantity = abs(poz.iloc[indeX]['Quantité'])
            if poz.iloc[indeX]['Quantité'] < 0:
                en_poz = -1
            if poz.iloc[indeX]['Quantité'] > 0:
                en_poz = 1

    if openlong == 1 and en_poz == 0:
        print('')
        price = round(price * 1.002,2)
        quantity = round(mise/price)
        print(Fore.GREEN,'Open Long',Style.RESET_ALL,' sur le ticker ',ticker,' basé sur un close limité à ', price,'\n')
        WHEN.append(time.strftime("%d-%m-%Y %H:%M:%S", time.localtime()))
        ASKED_PRICE.append(price)
        ACTION.append('Open Long')
        OL.append(1)
        OPEN_LONG(contract,quantity,price,ticker)


    elif openshort == 1 and en_poz == 0:
        print('')
        price = round(price * 0.998,2)
        quantity = round(mise/price)
        print(Fore.GREEN,'Open Short',Style.RESET_ALL,' sur le ticker ',ticker,' basé sur un close limité à ', price,'\n')
        WHEN.append(time.strftime("%d-%m-%Y %H:%M:%S", time.localtime()))
        ASKED_PRICE.append(price)
        ACTION.append('Open Short')
        OS.append(1)
        OPEN_SHORT(contract,quantity,price,ticker)


    elif closelong == 1 and en_poz == 1:
        print('')
        price = round(price * 0.998,2)
        print(Fore.RED,'Close Long',Style.RESET_ALL,' sur le ticker ',ticker,' basé sur un close limité à ', price,'\n')
        WHEN.append(time.strftime("%d-%m-%Y %H:%M:%S", time.localtime()))
        ASKED_PRICE.append(price)
        ACTION.append('Close Long')
        CL.append(1)
        CLOSE_LONG(contract,quantity,price,ticker)


    elif closeshort == 1 and en_poz == -1:
        print('')
        price = round(price * 1.002,2)
        print(Fore.RED,'Close Short',Style.RESET_ALL,' sur le ticker ',ticker,' basé sur un close limité à ', price,'\n')
        WHEN.append(time.strftime("%d-%m-%Y %H:%M:%S", time.localtime()))
        ASKED_PRICE.append(price)
        ACTION.append('Close Short')
        CS.append(1)
        CLOSE_SHORT(contract,quantity,price,ticker)


    else:
        WHEN.append('NA')
        ASKED_PRICE.append('NA')
        ACTION.append('NA')
        
    signals.iloc[i,7]='Traité'
    #except:
     #   print('souci boucle ',i,' pour le ticker ',ticker)
      #  continue

traded = signals
traded['Action'] = ACTION
traded['Quand'] = WHEN
traded['Prix limite'] = ASKED_PRICE
nownow = time.strftime("%d_%m_%Y_%H_%M_%S", time.localtime())
traded.to_csv('Ordres_passes/25_OrdresPasses_'+nownow+'.csv')
poz.to_csv('Relev_poz/RelevPoz_'+nownow+'.csv')
tmps22=round(time.time()-tmps55,2)
print("\n Ensemble des opérations du jour effectué en %f" %tmps22,'seconds \n')

log = today+': \n La NAV est de : '+str(pactol)+'$ \n Il y a eu '+str(sum(OL))+' Open Long, '+str(sum(OS))+' Open Short, '+str(sum(CL))+' Close Long, et '+\
str(sum(CS))+' Close Short. \n \n'

print(log)
fichier = open("log.txt", "a")
fichier.write(log)
fichier.close()
disconX()
# Out:
# Golem est maintenant déconnecté de IB
# Golem est maintenant connecté à IB
# Le fichier SIGNALS_2020-01-24.csv a bien été chargé
# Il y a actuellement  16 positions en cours
# 1er passage
#   Les fonds disponibles sur le compte sont de : $ 500407.905
#
#  Open Short   sur le ticker  JBHT  basé sur un close limité à  115.48
#
# Trade(contract=Stock(conId=270825, symbol='JBHT', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='JBHT', tradingClass='NMS'), order=LimitOrder(orderId=23107, clientId=1, action='SELL', totalQuantity=87.0, lmtPrice=115.48, transmit=False, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 0, 346202, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
# Trade(contract=Stock(conId=270825, symbol='JBHT', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='JBHT', tradingClass='NMS'), order=LimitOrder(orderId=23108, clientId=1, action='BUY', totalQuantity=87.0, lmtPrice=113.17, tif='GTC', transmit=False, parentId=23107, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 0, 347276, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
# Trade(contract=Stock(conId=270825, symbol='JBHT', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='JBHT', tradingClass='NMS'), order=StopOrder(orderId=23109, clientId=1, action='BUY', totalQuantity=87.0, auxPrice=132.8, tif='GTC', parentId=23107, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 0, 348151, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
#
#  Close Long   sur le ticker  HES  basé sur un close limité à  64.28
#
# Trade(contract=Stock(conId=39118796, symbol='HES', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='HES', tradingClass='HES'), order=LimitOrder(orderId=23111, clientId=1, action='SELL', totalQuantity=150.0, lmtPrice=64.28, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 1, 27128, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
#
#  Open Short   sur le ticker  STZ  basé sur un close limité à  191.18
#
# Trade(contract=Stock(conId=276066, symbol='STZ', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='STZ', tradingClass='STZ'), order=LimitOrder(orderId=23113, clientId=1, action='SELL', totalQuantity=52.0, lmtPrice=191.18, transmit=False, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 1, 443814, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
# Trade(contract=Stock(conId=276066, symbol='STZ', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='STZ', tradingClass='STZ'), order=LimitOrder(orderId=23114, clientId=1, action='BUY', totalQuantity=52.0, lmtPrice=187.36, tif='GTC', transmit=False, parentId=23113, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 1, 444568, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
# Trade(contract=Stock(conId=276066, symbol='STZ', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='STZ', tradingClass='STZ'), order=StopOrder(orderId=23115, clientId=1, action='BUY', totalQuantity=52.0, auxPrice=219.86, tif='GTC', parentId=23113, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 1, 445165, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
#
#  Close Long   sur le ticker  CHD  basé sur un close limité à  71.17
#
# Trade(contract=Stock(conId=5651, symbol='CHD', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='CHD', tradingClass='CHD'), order=LimitOrder(orderId=23117, clientId=1, action='SELL', totalQuantity=143.0, lmtPrice=71.17, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 1, 899692, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
#
#  Open Short   sur le ticker  MPC  basé sur un close limité à  54.38
#
# Trade(contract=Stock(conId=89495776, symbol='MPC', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='MPC', tradingClass='MPC'), order=LimitOrder(orderId=23119, clientId=1, action='SELL', totalQuantity=184.0, lmtPrice=54.38, transmit=False, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 2, 120241, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
# Trade(contract=Stock(conId=89495776, symbol='MPC', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='MPC', tradingClass='MPC'), order=LimitOrder(orderId=23120, clientId=1, action='BUY', totalQuantity=184.0, lmtPrice=53.29, tif='GTC', transmit=False, parentId=23119, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 2, 122471, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
# Trade(contract=Stock(conId=89495776, symbol='MPC', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='MPC', tradingClass='MPC'), order=StopOrder(orderId=23121, clientId=1, action='BUY', totalQuantity=184.0, auxPrice=62.54, tif='GTC', parentId=23119, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 2, 124656, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
#
#  Open Short   sur le ticker  CVX  basé sur un close limité à  111.63
#
# Trade(contract=Stock(conId=5684, symbol='CVX', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='CVX', tradingClass='CVX'), order=LimitOrder(orderId=23123, clientId=1, action='SELL', totalQuantity=90.0, lmtPrice=111.63, transmit=False, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 2, 584993, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
# Trade(contract=Stock(conId=5684, symbol='CVX', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='CVX', tradingClass='CVX'), order=LimitOrder(orderId=23124, clientId=1, action='BUY', totalQuantity=90.0, lmtPrice=109.4, tif='GTC', transmit=False, parentId=23123, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 2, 586137, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
# Trade(contract=Stock(conId=5684, symbol='CVX', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='CVX', tradingClass='CVX'), order=StopOrder(orderId=23125, clientId=1, action='BUY', totalQuantity=90.0, auxPrice=128.37, tif='GTC', parentId=23123, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 2, 586677, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
#
#  Open Short   sur le ticker  CE  basé sur un close limité à  114.28
#
# Trade(contract=Stock(conId=32943358, symbol='CE', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='CE', tradingClass='CE'), order=LimitOrder(orderId=23127, clientId=1, action='SELL', totalQuantity=88.0, lmtPrice=114.28, transmit=False, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 3, 94273, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
# Trade(contract=Stock(conId=32943358, symbol='CE', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='CE', tradingClass='CE'), order=LimitOrder(orderId=23128, clientId=1, action='BUY', totalQuantity=88.0, lmtPrice=111.99, tif='GTC', transmit=False, parentId=23127, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 3, 95627, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
# Trade(contract=Stock(conId=32943358, symbol='CE', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='CE', tradingClass='CE'), order=StopOrder(orderId=23129, clientId=1, action='BUY', totalQuantity=88.0, auxPrice=131.42, tif='GTC', parentId=23127, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 18, 55, 3, 96482, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#
#
#  Ensemble des opérations du jour effectué en 3.400000 seconds
#
# 2020-01-27:
#  La NAV est de : 500407.905$
#  Il y a eu 0 Open Long, 5 Open Short, 2 Close Long, et 0 Close Short.
#
#
# Golem est maintenant déconnecté de IB

# %%
poz.iloc[12]['conId']
# Out:
# 3142097

# %%
poz
# Out:
#        Compte   Type      conId Ticker  Quantité  Average Cost
# 0   DU1507428  Stock   15130038    SJM     -97.0    102.937440
# 1   DU1507428  Stock       5402    CAG    -314.0     32.024218
# 2   DU1507428  Stock    4627828     GS     -43.0    231.091842
# 3   DU1507428  Stock      11758    RTN     -46.0    219.963589
# 4   DU1507428  Stock   39118796    HES     150.0     65.356667
# 5   DU1507428  Stock       9657    MCK    -144.0    141.193069
# 6   DU1507428  Stock       8130    HRB    -429.0     23.314398
# 7   DU1507428  Stock       5651    CHD     143.0     70.146993
# 8   DU1507428  Stock    6858322   TSCO    -109.0     91.518812
# 9   DU1507428  Stock  318911976    JEF    -475.0     21.264441
# 10  DU1507428  Stock       7935    HOG    -288.0     34.874159
# 11  DU1507428  Stock  196610642    AGN    -104.0    191.284383
# 12  DU1507428  Stock    3142097    PXD     132.0    149.880152
# 13  DU1507428  Stock  308728373   BKNG       5.0   1996.700000
# 14  DU1507428  Stock       6735    EFX     -71.0    140.322892
# 15  DU1507428  Stock   94078796   FBHS    -147.0     67.981671

# %%
conX()
# Out:
# Golem est maintenant connecté à IB

# %%
try:
    transact_price = poz[poz['Ticker'] == ticker].iloc[-1]['Average Cost']
except:
    transact_price = price
ib.qualifyContracts(contract)
order = LimitOrder('SELL', quantity, price,account=compte)
trade = ib.placeOrder(contract, order)
print(trade,'\n \n')
# Out:
# Trade(contract=Stock(conId=3142097, symbol='PXD', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='PXD', tradingClass='PXD'), order=LimitOrder(orderId=23138, clientId=1, action='SELL', totalQuantity=88.0, lmtPrice=114.28, account='DU1507428', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2020, 1, 27, 23, 9, 25, 670778, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
# Error 1100, reqId -1: La connexion entre IB et Trader Workstation a été perdue.

# %%
conX()
# Out:
# Golem est maintenant connecté à IB

# %%
contract.conId = poz.iloc[12]['conId']

# %%
contract
# Out:
# Stock(conId=3142097, symbol='PXD', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='PXD', tradingClass='PXD')

# %%
poz.iloc[12]['conId']
# Out:
# 3142097

# %%
quantity
# Out:
# 88.0

# %%
conX()
# Out:
# Golem est maintenant connecté à IB

# %%
contract = Contract()
contract.secType = "NEWS"
contract.exchange = "BRFG" #Briefing Trader

# %%
ib.reqContractDetails(10004, ContractSamples.NewsFeedForQuery())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-184-293eb6eb9415> in <module>
# ----> 1 ib.reqContractDetails(10004, ContractSamples.NewsFeedForQuery())
#
# NameError: name 'ContractSamples' is not defined

# %%
 class TestWrapper(wrapper.EWrapper):
        def contractDetails(self, reqId: int, contractDetails: ContractDetails):
            super().contractDetails(reqId, contractDetails)
            printinstance(contractDetails)
            
        def contractDetailsEnd(self, reqId: int):
            super().contractDetailsEnd(reqId)
            print("ContractDetailsEnd. ReqId:", reqId)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-180-d788e2662a27> in <module>
# ----> 1 class TestWrapper(wrapper.EWrapper):
#       2        def contractDetails(self, reqId: int, contractDetails: ContractDetails):
#       3            super().contractDetails(reqId, contractDetails)
#       4            printinstance(contractDetails)
#       5
#
# NameError: name 'wrapper' is not defined

# %%
disconX()
# Out:
# Golem est maintenant déconnecté de IB

# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
        
clearall()

# %%
############################
######## LIBRAIRIES ########
############################
print('Importing Librairies...')
from sklearn.linear_model import LinearRegression
import colorama as col
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import time
import os
import datetime as dt
import numpy as np
import fxcmpy
import socketio
import shelve
import talib
import statistics
import pyttsx3

engine = pyttsx3.init()

print('Librairies imported\n')
print('version fxcmpy :',fxcmpy.__version__)
# %matplotlib inline
plt.style.use('seaborn')
engine.say("librairie loaded")
engine.runAndWait()
print('Prêt')
# Out:
# Importing Librairies...
# Librairies imported
#
# version fxcmpy : 1.2.6
# Prêt

# %%
engine.say("Ignition du Lumberjack")
engine.runAndWait() 

##############################################
######## INITIALISATION DES VARIABLES ########
##############################################

'''
# COMPTE TEST #

TOKEN = '89410007226e1ad8ffce5dbf03f1e1bf056f2451'
server = 'demo'
user_id = 'D261219574'
compte = '01215057'
password = '3555'
'''


# COMPTE DEV #
TOKEN = '4973fff4a559fa6e5a25dfd3e7c8f9367f04378b'
server = 'demo'
user_id = 'D161435731'
compte = '01425123'
password = '8889'


'''
# COMPTE POUBELLE #
TOKEN = 'a66bf5c0ec732487f4b348baf6364d3ee8784935'
server = 'demo'
user_id = 'D261219576'
compte = '01215059'
password = '8029'
'''


# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'


_number = 10000
_period = 'm5'
_period2 = 'H1'
_period3 = 'D1'
_total = 0
_cash_ini = 200000
_cash = _cash_ini
_rate = 1
_flag = 0


_size = 100
_target = 15
_sl = -30
_rsi_high = 80
_rsi_low = 20



engine.say("בסדר")
engine.runAndWait()
print('Variables initialisées')
# Out:
# Variables initialisées

# %%
############################
######## FONCTIONS ########
###########################


def conX():
    con = fxcmpy.fxcmpy(access_token=TOKEN, log_level='error',server=server)
    if con.is_connected() == True:
        print(col.Fore.GREEN+'Connexion établie'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
    else:
        print(col.Fore.RED+'Connexion non établie'+col.Style.RESET_ALL)
    return(con)

def deconX():
    con = con.close()
    if con.is_connected() == True:
        print(col.Fore.GREEN+'Connexion non intérrompue'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
    else:
        print(col.Fore.RED+'Connexion intérrompue'+col.Style.RESET_ALL)
    return()


def scrap_hist(_ticker,number,laperiod):
    print(col.Fore.BLUE,'Scraping des données OHLC pour le ticker',col.Fore.YELLOW,_ticker,col.Style.RESET_ALL)
    data = con.get_candles(instrument=_ticker,number = 10000,period=laperiod)
    df = pd.DataFrame(index=data.index)
    df['Open_Bid'] = data['bidopen']
    df['Open_Ask'] = data['askopen']
    df['Open'] = (data['bidopen']+data['askopen'])/2
    df['High_Bid'] = data['bidhigh']
    df['High_Ask'] = data['askhigh']
    df['High'] = (data['bidhigh']+data['askhigh'])/2
    df['Low_Bid'] = data['bidlow']
    df['Low_Ask'] = data['asklow']
    df['Low'] = (data['bidlow']+data['asklow'])/2
    df['Close_Bid'] = data['bidclose']
    df['Close_Ask'] = data['askclose']
    df['Close'] = (data['bidclose']+data['askclose'])/2
    return(df)

def convert(devise,_rate,_flag):
    
    prix_usd = 0
    if x[4:] == 'USD':
        prix_usd = devise
    elif x[:3] == 'USD':
        prix_usd = round(devise/_rate,2)
    elif _flag == 1:
        prix_usd = round(devise * _rate,2)
       
    elif _flag == -1 :
            prix_usd = round(devise / _rate,2)
    else:
        prix_usd = 'NA'
    return(prix_usd,_flag)

# %%
#########################
### CONNEXION A L'API ###
#########################

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor for FOR_EX\nLumberJack Jyss 5780(c)')
print(col.Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print(col.Fore.YELLOW,col.Back.BLUE,'--- Go!em MOVING AVERAGE RETRACEMENT #v0.15 ---',col.Style.RESET_ALL)

print('')
engine.say(" Initialisation du Gaulem Moving, Average, Retracement")
engine.say("Connexion du Gaulem hà la Péh e")
engine.runAndWait()

try:
    con.is_connected() == True
    
    engine.say("already Connected")
    engine.runAndWait()
    print(col.Fore.GREEN+'Connexion rétablie'+col.Style.RESET_ALL)
    print('Compte utilisé : ',con.get_account_ids())
    print('')
    
except:
    try:
        con = conX()
        con.is_connected() == True
        print(col.Fore.GREEN+'Connexion établie'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
        engine.say("Connected")
        engine.runAndWait()
    except:
        print(col.Fore.RED+'Connexion non établie'+col.Style.RESET_ALL)
        engine.say("Not Connected, sal rass de mor, pitun cé la merd")
        engine.say("vérifi ton internet, é relance le gaulèm")
        engine.runAndWait()
        print('')
        #os._exit(0)
        con = deconX()
        time.sleep(1)
        con = conX()
# Out:
# Global Optimized LumberJack Environment Motor for FOR_EX
# LumberJack Jyss 5780(c)
#  °0Oo_D.A.G._26_oO0°
#   --- Go!em MOVING AVERAGE RETRACEMENT #v0.15 ---
#
# Connexion établie
# Compte utilisé :  [1425123]
# Connexion établie
# Compte utilisé :  [1425123]

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.dates as mdates
import pandas as pd
from numpy import loadtxt
from functools import reduce
import talib
import time
from scipy.signal import argrelextrema
from ipywidgets import *

from datetime import datetime

DATE = []
CONTRACT = []
OPEN_POZ = []
CLOSE_POZ = []
RATE_OPEN_POZ = []
RATE_CLOSE_POZ = []
PNL_LAT = []
PNL_REAL = []
TOTAL_OPEN = []
TOTAL_CLOSE = []
PRICE_BUY = []
PRICE_SELL = []
DER_POZ = []
TOTAL_PNL_LAT = []
TOTAL_PNL_REAL = []
_cash = _cash_ini
WINNERS = []
LOOSERS = []

_verbose = 1

# %%
def peak_detect(price,order=10):
    max_idx = list(argrelextrema(price,np.greater,order=order)[0])
    min_idx = list(argrelextrema(price,np.less,order=order)[0])
    idx = max_idx + min_idx + [len(price)-1]
    idx.sort()
    _current_idx = idx[-3:]
    
    _start = min(_current_idx)
    _end = max(_current_idx)
    _current_pat = price[_current_idx]
    return _current_idx,_current_pat,_start,_end 
    
def is_BAAM(moves,err_allowed):  
    XA=moves[0]
    AB=moves[1]
    
    
    X=prices[0]
    A=prices[1]
    B=prices[2]
    
    AB_range = np.array([0.68 - err_allowed,0.68+ err_allowed])*abs(XA)
    AB_range2 = np.array([0.15 - err_allowed,0.15+ err_allowed])*abs(XA)
    
    
    
    if abs(A-X)/X>0.001:
        
        if XA>0 and AB<0 :

            if (AB_range[0]<abs(AB)<AB_range[1]) or (AB_range2[0]<abs(AB)<AB_range2[1]) :

                BAAM = 1
                return (BAAM)
            else:
                return (np.isnan)

        elif XA<0 and AB>0 :


            if (AB_range[0]<abs(AB)<AB_range[1]) or (AB_range2[0]<abs(AB)<AB_range2[1]):

                BAAM = -1
                return (BAAM)
            else:
                return (np.isnan)
        else:
             return (np.isnan)

# %%
# %%time
df_resultats = pd.DataFrame(index=['TimeFrame 1','TimeFrame2','Equity','Nbre Winners','Nbre Loosers','Average lenght of trade','Cumul pnl'])

#TICKERS = [ 'EUR/USD','GBP/USD','EUR/JPY','GBP/JPY','EUR/AUD','GBP/AUD','EUR/NZD']

TICKERS = [ 'EUR/USD']

engine.say("קדימה")
engine.runAndWait()

err_allowed = 2/100
plt.ion()
position = 0
equity = 100000
for x in TICKERS:

    if x[4:] == 'USD':
        _rate = 1

    elif x[:3] == 'USD':
        con.subscribe_market_data(x)
        _rate = con.get_last_price(x).Bid
        con.unsubscribe_market_data(x)
    elif x[:3] != 'USD' and x[4:] != 'USD':
        try:
            con.subscribe_market_data(x[4:]+'/USD')
            _rate = con.get_last_price(x[4:]+'/USD').Bid
            con.unsubscribe_market_data(x[4:]+'/USD')
            _flag = 1
        except:
            con.subscribe_market_data('USD/'+x[4:])
            _rate = con.get_last_price('USD/'+x[4:]).Bid
            con.unsubscribe_market_data('USD/'+x[4:])
            _flag = -1
    else:
        prix_usd = 'NA'

    print(col.Fore.MAGENTA,'Le rate du ticker',x,'est à ',_rate,col.Style.RESET_ALL)
    label = ''
    data = scrap_hist(x,_number,_period)
    data2 = scrap_hist(x,_number,_period2)
    price = data.copy()
    price2 = data2.copy()
    _position = 0
    _equity = 0
    _nbtransactions = 0
    backtest_graph = pd.DataFrame()
    EQUITY = [_cash]
    CASH = [_cash]
    _winner = 0
    _looser = 0
    _index_entry = 0
    TRADE_DURATION = []
    _average_duration = 0
    _size = 50000

    PRICE_BUY = []
    PRICE_SELL = []
   
    _total = 0

    _target = 0.006
    _sl = 0.0015
    _spread_filter = 0.00050
    _filtre_multipoz = 0.001 # En %
    _filtre_multipoz = _filtre_multipoz/100
    
    _open_buy = 0
    _open_sell = 0
    _minipoz = 0
    
    MM21 = talib.EMA(price.Close, timeperiod=21)
    MM34 = talib.EMA(price.Close, timeperiod=34)
    MM54 = talib.EMA(price.Close, timeperiod=54)
    rsi = talib.RSI(price.Close, timeperiod=14)
    rsi_high = 70
    rsi_low = 30
    
    MM542 = talib.EMA(price2.Close, timeperiod=54)
    
    for i in range(150,len(price)-1):
        
        j = len(price2[price2.index <= price.index[i]])-1
        
        current_idx,current_pat,start,end = peak_detect(price.Close.values[:i+1])
        current_rsi = [rsi.iloc[current_idx[0]],rsi.iloc[current_idx[1]],rsi.iloc[current_idx[2]]]
        current_rsi_max = max(current_rsi)
        current_rsi_min = min(current_rsi)
        delta_price = current_pat[2] - current_pat[0]
        delta_rsi = current_rsi[2] - current_rsi[0]
      
        XA = current_pat[1] - current_pat[0]     
        AB = current_pat[2] - current_pat[1]      
        
        X = current_pat[0]
        A = current_pat[1]
        B = current_pat[2]

        prices =[X,A,B]

        moves=[XA,AB]
        
        BAAM = is_BAAM(moves,err_allowed)

        harmonics = np.array([BAAM])

        if _position == 0 :
            if (np.any(harmonics==1) and np.all(harmonics!=-1 )) or  (np.any(harmonics==-1) and np.all(harmonics!=1 )):

                for h in range(0, len(harmonics)):

                    if harmonics[h]==-1 and price.iloc[i]['Close_Bid']<MM21[i] and X>MM54[current_idx[0]] and MM21[current_idx[0]]>MM54[current_idx[0]] and MM21[i]<MM34[i]<MM54[i]\
                            and price2.Close[j]<MM542[j]:
                            _pnl = 0
                            _open_sell += 1
                            _equity = _cash + _pnl
                            EQUITY.append(_equity)
                            CASH.append(_cash)
                            _index_entry = i
                            _position = -1
                            _nbtransactions += 1
                            price_sell = price.Close_Bid.iloc[i]
                            PRICE_SELL.append(price_sell)
                            _price_sell_mean = round(sum(PRICE_SELL)/len(PRICE_SELL),5)
                            if _verbose == 1:
                                print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                                print('Position 1 sold at', price_sell,'(verification liste',PRICE_SELL[-1],')')
                                print('Nouvelle moyenne du price_sell',_price_sell_mean)

                            DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                            CONTRACT.append(x)
                            OPEN_POZ.append(-1)
                            CLOSE_POZ.append(0)
                            RATE_OPEN_POZ.append(price_sell)
                            RATE_CLOSE_POZ.append(0) 
                            PNL_LAT.append(_pnl)
                            PNL_REAL.append(0)
                            TOTAL_PNL_LAT.append(_pnl)
                            TOTAL_PNL_REAL.append(0)

                            TOTAL_OPEN.append(1)
                    
                    if harmonics[h]==1 and price.iloc[i]['Close_Ask']>MM21[i] and X<MM54[current_idx[0]] and MM21[current_idx[0]]<MM54[current_idx[0]] and MM21[i]>MM34[i]>MM54[i]\
                        and price2.Close[j]>MM542[j]:
                   
                            _pnl = 0
                            _open_buy += 1
                            _equity = _cash + _pnl
                            EQUITY.append(_equity)
                            CASH.append(_cash)
                            _position = 1
                            _index_entry = i
                            _nbtransactions += 1
                            price_buy = price.Close_Ask.iloc[i]
                            PRICE_BUY.append(price_buy)
                            _price_buy_mean = round(sum(PRICE_BUY)/len(PRICE_BUY),5)
                            if _verbose == 1:
                                print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                                print('Position 1 bought at', price_buy,'(verification liste',PRICE_BUY[-1],')')
                                print('Nouvelle moyenne du price_buy',_price_buy_mean)

                            DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                            CONTRACT.append(x)
                            OPEN_POZ.append(1)
                            CLOSE_POZ.append(0)
                            RATE_OPEN_POZ.append(price_buy)
                            RATE_CLOSE_POZ.append(0)
                            PNL_LAT.append(_pnl)
                            PNL_REAL.append(0)
                            TOTAL_OPEN.append(1) 
                            TOTAL_PNL_LAT.append(_pnl)
                            TOTAL_PNL_REAL.append(0) 

                    else :
                        _pnl = 0
                        _equity = _cash + _pnl
                        EQUITY.append(_equity)
                        CASH.append(_cash)
                
        elif _position == 1:

            
            if (price_buy - price.Close_Bid[i])/price_buy>=_filtre_multipoz and  MM21[i]>MM34[i]>MM54[i]\
            and price2.Close_Bid[j]>MM542[j] and harmonics[h]==1:
            
                _pnl = (price.Close_Ask.iloc[i] - _price_buy_mean) * _size * _open_buy
                _open_buy += 1
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)
                _position = 1
                _index_entry = i
                _nbtransactions += 1
                price_buy = price.Close_Ask.iloc[i]
                PRICE_BUY.append(price_buy)
                _price_buy_mean = round(sum(PRICE_BUY)/len(PRICE_BUY),5)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print('Position',_open_buy,'bought at ', price_buy,'(verification liste',PRICE_BUY[-1],')')
                    print('Nouvelle moyenne du price_buy',_price_buy_mean)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(1)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(price_buy)
                RATE_CLOSE_POZ.append(0)
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_OPEN.append(1) 
                TOTAL_PNL_LAT.append(_pnl)
                TOTAL_PNL_REAL.append(0) 


        

            if (float(price.Low_Bid.iloc[i]) - float(_price_buy_mean))/float(_price_buy_mean) >= _target \
                or ((float(price.Low_Bid.iloc[i]) - float(_price_buy_mean) > 0) and (i - _index_entry > 48)):#slowd[i]>80:
        
                _position = 0
                _pnl = (price.Low_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _winner += _open_buy

                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print(_open_buy,'positions TP closed at',price.Low_Bid.iloc[i],col.Fore.GREEN,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Low_Bid.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_buy)
                PRICE_BUY = [] 
                _open_buy = 0

            elif ((float(price.Low_Bid.iloc[i]) - float(_price_buy_mean))/float(_price_buy_mean) <= -_sl) or \
                (PNL_LAT[-1] < -500) or ((i - _index_entry) > 30 and (float(price.Low_Bid.iloc[i]) - float(_price_buy_mean)) < 0):
                _position = 0
                _pnl = (price.High_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_buy

                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print(_open_buy,'positions SL closed at',price.High_Bid.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.High_Bid.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_buy) 
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                PRICE_BUY = []
                _open_buy = 0
            else:

                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(0) ############### 
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_PNL_LAT.append(_pnl)
                TOTAL_PNL_REAL.append(0) 


        elif _position == -1:

            
            
            if ( price.Close_Bid[i] - price_sell)/price_sell>=_filtre_multipoz and price.iloc[i]['Close_Bid']<MM21[i] and MM21[i]<MM34[i]<MM54[i]\
            and price2.Close_Bid[j]<MM542[j] and harmonics[h] == -1:
                
                _pnl = - (price.Low_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _open_sell += 1
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)
                _position = -1
                _index_entry = i
                _nbtransactions += 1
                price_sell = price.Close_Bid.iloc[i]
                PRICE_SELL.append(price_sell)
                _price_sell_mean = round(sum(PRICE_SELL)/len(PRICE_SELL),5)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print('Position 1 sold at', price_sell,'(verification liste',PRICE_SELL[-1],')')
                    print('Nouvelle moyenne du price_sell',_price_sell_mean)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(1)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(price_sell)
                RATE_CLOSE_POZ.append(0)
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_OPEN.append(1) 
                TOTAL_PNL_LAT.append(_pnl)
                TOTAL_PNL_REAL.append(0) 



            if (float(price.High_Ask.iloc[i]) - float(_price_sell_mean))/float(_price_sell_mean) <= -_target \
            or((float(price.High_Ask.iloc[i]) - float(_price_sell_mean) < 0) and(i - _index_entry > 48)):
                _position = 0
                _pnl = - (price.High_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _winner += _open_sell
                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print(_open_sell,'positions TP closed at',price.High_Ask.iloc[i],col.Fore.GREEN,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(-1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.High_Ask.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_sell)
                PRICE_SELL = [] 
                _open_sell = 0

            elif ((float(price.Low_Ask.iloc[i]) - float(_price_sell_mean))/float(_price_sell_mean) >= _sl) or \
                (PNL_LAT[-1] < -500) or ((i - _index_entry) > 30 and (float(price.Low_Ask.iloc[i]) - float(_price_sell_mean)>0)) :
                _position = 0
                _pnl = - (price.Low_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_sell
                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)    
                    print(_open_sell,'position SL closed at',price.Low_Ask.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(-1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Low_Ask.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_sell)
                PRICE_SELL = []
                _open_sell = 0

            else:

                _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _equity = _cash + _pnl

                EQUITY.append(_equity)
                CASH.append(_cash)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(0)
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_PNL_LAT.append(_pnl)

                TOTAL_PNL_REAL.append(0)
              
        elif i == (len(price)-1) and _position != 0 :

            if _position == -1:
                _position = 0
                _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_sell
                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print(col.Fore.CYAN,"Cloture des positions en l'air",col.Style.RESET_ALL)
                    print(_open_sell,'position closed at',price.Close_Ask.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(-1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Ask.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_sell)
                PRICE_SELL = []
                _open_sell = 0

            if _position == 1:

                _position = 0
                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_buy

                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print(col.Fore.CYAN,"Cloture des positions en l'air",col.Style.RESET_ALL)
                    print(_open_buy,'positions closed at',price.Close_Bid.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_buy) 
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                PRICE_BUY = []
                _open_buy = 0

    try:
        _average_duration = round(statistics.mean(TRADE_DURATION),2)
    
    except:
        print("(pas de duration)") 
        _average_duration = 'NA' 
    print(col.Fore.BLUE,'Pour le ticker',col.Fore.YELLOW,x,col.Style.RESET_ALL)              
    print(col.Fore.MAGENTA,"\nLes gains faramineux s'élèvent à : $",col.Fore.GREEN,round(_total,2),'!. En ',_nbtransactions,' transactions.',col.Style.RESET_ALL ) 
    print(col.Fore.GREEN,"\nNbre de winners :",_winner,col.Style.RESET_ALL)
    print(col.Fore.RED,"\nNbre de loosers :",_looser,col.Style.RESET_ALL)
    print("\nAverage trade duration ",_average_duration)
    backtest_graph['Equity'] = EQUITY
    
    df_resultats[x] = [_period,_period2,(round(_equity,2)),(_winner),(_looser),(_average_duration),(_total)]

    print('Total des gains faramineux :',round((EQUITY[-1] - _cash_ini) * _rate,2))
    print('Pnl latent restant',_pnl,'Open Buy',_open_buy,'Open Sell',_open_sell)
    DER_POZ.append(_pnl)

engine.say("Finito caucau")
engine.runAndWait()
# Out:
#  Le rate du ticker EUR/USD est à  1
#  Scraping des données OHLC pour le ticker  EUR/USD
#  Scraping des données OHLC pour le ticker  EUR/USD
#  2020-09-24 02:55:00
# Position 1 sold at 1.1661 (verification liste 1.1661 )
# Nouvelle moyenne du price_sell 1.1661
#  2020-09-24 07:00:00
# 1 positions TP closed at 1.16563  pnl 23.499999999998522
# nombre de candles en position : 49
# Equity : 200023.5
#  2020-09-25 09:30:00
# Position 1 sold at 1.16516 (verification liste 1.16516 )
# Nouvelle moyenne du price_sell 1.16516
#  2020-09-25 13:35:00
# 1 positions TP closed at 1.16376  pnl 70.0000000000034
# nombre de candles en position : 49
# Equity : 200093.5
#  2020-09-28 10:35:00
# Position 1 bought at 1.16589 (verification liste 1.16589 )
# Nouvelle moyenne du price_buy 1.16589
#  2020-09-28 10:45:00
# Position 2 bought at  1.16588 (verification liste 1.16588 )
# Nouvelle moyenne du price_buy 1.16588
#  2020-09-28 14:35:00
# 2 positions SL closed at 1.16623  pnl 35.00000000000725
# nombre de candles en position : 46
# Equity : 200128.5
#  2020-09-28 18:00:00
# Position 1 bought at 1.16631 (verification liste 1.16631 )
# Nouvelle moyenne du price_buy 1.16631
#  2020-09-28 20:35:00
# 1 positions SL closed at 1.16624  pnl -3.5000000000007248
# nombre de candles en position : 31
# Equity : 200125.0
#  2020-09-30 15:00:00
# Position 1 bought at 1.17267 (verification liste 1.17267 )
# Nouvelle moyenne du price_buy 1.17267
#  2020-09-30 16:05:00
# 1 positions SL closed at 1.17231  pnl -18.0000000000069
# nombre de candles en position : 13
# Equity : 200107.0
#  2020-09-30 20:30:00
# Position 1 bought at 1.17243 (verification liste 1.17243 )
# Nouvelle moyenne du price_buy 1.17243
#  2020-09-30 23:40:00
# 1 positions SL closed at 1.17255  pnl 5.999999999994898
# nombre de candles en position : 38
# Equity : 200113.0
#  2020-10-01 01:45:00
# Position 1 bought at 1.1737 (verification liste 1.1737 )
# Nouvelle moyenne du price_buy 1.1737
#  2020-10-01 02:25:00
# Position 2 bought at  1.17376 (verification liste 1.17376 )
# Nouvelle moyenne du price_buy 1.17373
#  2020-10-01 06:30:00
# 2 positions TP closed at 1.17483  pnl 110.00000000001009
# nombre de candles en position : 49
# Equity : 200223.0
#  2020-10-01 10:20:00
# Position 1 bought at 1.17455 (verification liste 1.17455 )
# Nouvelle moyenne du price_buy 1.17455
#  2020-10-01 10:25:00
# Position 2 bought at  1.17454 (verification liste 1.17454 )
# Nouvelle moyenne du price_buy 1.17454
#  2020-10-01 13:05:00
# 2 positions SL closed at 1.17567  pnl 113.00000000000753
# nombre de candles en position : 32
# Equity : 200336.0
#  2020-10-01 15:55:00
# Position 1 bought at 1.17521 (verification liste 1.17521 )
# Nouvelle moyenne du price_buy 1.17521
#  2020-10-01 18:10:00
# 1 positions SL closed at 1.17382  pnl -69.50000000000011
# nombre de candles en position : 27
# Equity : 200266.5
#  2020-10-02 01:20:00
# Position 1 sold at 1.17351 (verification liste 1.17351 )
# Nouvelle moyenne du price_sell 1.17351
#  2020-10-02 05:25:00
# 1 positions TP closed at 1.17176  pnl 87.50000000000702
# nombre de candles en position : 49
# Equity : 200354.0
#  2020-10-02 08:10:00
# Position 1 sold at 1.17211 (verification liste 1.17211 )
# Nouvelle moyenne du price_sell 1.17211
#  2020-10-02 08:40:00
# Position 1 sold at 1.17214 (verification liste 1.17214 )
# Nouvelle moyenne du price_sell 1.17212
#  2020-10-02 12:00:00
# 2 position SL closed at 1.1723  pnl -17.999999999984695
# nombre de candles en position : 40
# Equity : 200336.00000000003
#  2020-10-02 13:15:00
# Position 1 sold at 1.17062 (verification liste 1.17062 )
# Nouvelle moyenne du price_sell 1.17062
#  2020-10-02 15:50:00
# 1 position SL closed at 1.17074  pnl -5.999999999994898
# nombre de candles en position : 31
# Equity : 200330.00000000003
#  2020-10-05 08:20:00
# Position 1 bought at 1.17401 (verification liste 1.17401 )
# Nouvelle moyenne du price_buy 1.17401
#  2020-10-05 12:25:00
# 1 positions TP closed at 1.17597  pnl 97.9999999999981
# nombre de candles en position : 49
# Equity : 200428.00000000003
#  2020-10-05 20:35:00
# Position 1 bought at 1.17849 (verification liste 1.17849 )
# Nouvelle moyenne du price_buy 1.17849
#  2020-10-05 23:10:00
# 1 positions SL closed at 1.17864  pnl 7.499999999993623
# nombre de candles en position : 31
# Equity : 200435.50000000003
#  2020-10-07 08:35:00
# Position 1 bought at 1.17617 (verification liste 1.17617 )
# Nouvelle moyenne du price_buy 1.17617
#  2020-10-07 09:00:00
# Position 2 bought at  1.17621 (verification liste 1.17621 )
# Nouvelle moyenne du price_buy 1.17619
#  2020-10-07 13:05:00
# 2 positions TP closed at 1.17706  pnl 86.99999999999264
# nombre de candles en position : 49
# Equity : 200522.50000000003
#  2020-10-08 08:25:00
# Position 1 sold at 1.17612 (verification liste 1.17612 )
# Nouvelle moyenne du price_sell 1.17612
#  2020-10-08 12:15:00
# 1 position SL closed at 1.17636  pnl -12.000000000000899
# nombre de candles en position : 46
# Equity : 200510.50000000003
#  2020-10-13 01:05:00
# Position 1 sold at 1.17971 (verification liste 1.17971 )
# Nouvelle moyenne du price_sell 1.17971
#  2020-10-13 04:55:00
# 1 position SL closed at 1.17981  pnl -4.999999999999449
# nombre de candles en position : 46
# Equity : 200505.50000000003
#  2020-10-13 13:05:00
# Position 1 sold at 1.17834 (verification liste 1.17834 )
# Nouvelle moyenne du price_sell 1.17834
#  2020-10-13 17:10:00
# 1 positions TP closed at 1.17352  pnl 241.00000000000233
# nombre de candles en position : 49
# Equity : 200746.50000000003
#  2020-10-14 07:20:00
# Position 1 sold at 1.17331 (verification liste 1.17331 )
# Nouvelle moyenne du price_sell 1.17331
#  2020-10-14 10:30:00
# 1 position SL closed at 1.17334  pnl -1.4999999999987246
# nombre de candles en position : 38
# Equity : 200745.00000000003
#  2020-10-15 07:25:00
# Position 1 sold at 1.17362 (verification liste 1.17362 )
# Nouvelle moyenne du price_sell 1.17362
#  2020-10-15 11:30:00
# 1 positions TP closed at 1.17171  pnl 95.50000000000392
# nombre de candles en position : 49
# Equity : 200840.50000000003
#  2020-10-16 03:30:00
# Position 1 sold at 1.17036 (verification liste 1.17036 )
# Nouvelle moyenne du price_sell 1.17036
#  2020-10-16 06:05:00
# 1 position SL closed at 1.17061  pnl -12.499999999993072
# nombre de candles en position : 31
# Equity : 200828.00000000003
#  2020-10-16 15:25:00
# Position 1 sold at 1.17158 (verification liste 1.17158 )
# Nouvelle moyenne du price_sell 1.17158
#  2020-10-16 18:00:00
# 1 position SL closed at 1.17159  pnl -0.49999999999217337
# nombre de candles en position : 31
# Equity : 200827.50000000003
#  2020-10-18 23:25:00
# Position 1 sold at 1.17134 (verification liste 1.17134 )
# Nouvelle moyenne du price_sell 1.17134
#  2020-10-19 03:00:00
# 1 position SL closed at 1.17136  pnl -0.999999999995449
# nombre de candles en position : 43
# Equity : 200826.50000000003
#  2020-10-20 09:00:00
# Position 1 bought at 1.17873 (verification liste 1.17873 )
# Nouvelle moyenne du price_buy 1.17873
#  2020-10-20 13:05:00
# 1 positions TP closed at 1.18085  pnl 105.99999999999498
# nombre de candles en position : 49
# Equity : 200932.50000000003
#  2020-10-21 11:00:00
# Position 1 bought at 1.18575 (verification liste 1.18575 )
# Nouvelle moyenne du price_buy 1.18575
#  2020-10-21 13:15:00
# Position 2 bought at  1.18505 (verification liste 1.18505 )
# Nouvelle moyenne du price_buy 1.1854
#  2020-10-21 17:20:00
# 2 positions TP closed at 1.1867  pnl 130.0000000000079
# nombre de candles en position : 49
# Equity : 201062.50000000003
#  2020-10-23 08:20:00
# Position 1 bought at 1.18383 (verification liste 1.18383 )
# Nouvelle moyenne du price_buy 1.18383
#  2020-10-23 08:55:00
# Position 2 bought at  1.18392 (verification liste 1.18392 )
# Nouvelle moyenne du price_buy 1.18388
#  2020-10-23 13:00:00
# 2 positions TP closed at 1.18498  pnl 109.99999999998789
# nombre de candles en position : 49
# Equity : 201172.50000000003
#  2020-10-23 18:10:00
# Position 1 bought at 1.18558 (verification liste 1.18558 )
# Nouvelle moyenne du price_buy 1.18558
#  2020-10-23 20:55:00
# 1 positions SL closed at 1.18608  pnl 24.999999999997247
# nombre de candles en position : 33
# Equity : 201197.50000000003
#  2020-10-26 08:30:00
# Position 1 sold at 1.18226 (verification liste 1.18226 )
# Nouvelle moyenne du price_sell 1.18226
#  2020-10-26 11:05:00
# 1 position SL closed at 1.18253  pnl -13.499999999999623
# nombre de candles en position : 31
# Equity : 201184.00000000003
#  2020-10-26 20:05:00
# Position 1 sold at 1.18088 (verification liste 1.18088 )
# Nouvelle moyenne du price_sell 1.18088
#  2020-10-26 20:40:00
# Position 1 sold at 1.18093 (verification liste 1.18093 )
# Nouvelle moyenne du price_sell 1.18091
#  2020-10-26 23:15:00
# 2 position SL closed at 1.18092  pnl -1.0000000000065512
# nombre de candles en position : 31
# Equity : 201183.00000000003
#  2020-10-27 09:00:00
# Position 1 sold at 1.18043 (verification liste 1.18043 )
# Nouvelle moyenne du price_sell 1.18043
#  2020-10-27 09:15:00
# Position 1 sold at 1.18045 (verification liste 1.18045 )
# Nouvelle moyenne du price_sell 1.18044
#  2020-10-27 11:50:00
# 2 position SL closed at 1.1824  pnl -195.9999999999962
# nombre de candles en position : 31
# Equity : 200987.00000000003
#  2020-10-27 13:00:00
# Position 1 bought at 1.18294 (verification liste 1.18294 )
# Nouvelle moyenne du price_buy 1.18294
#  2020-10-27 15:35:00
# 1 positions SL closed at 1.18333  pnl 19.49999999999452
# nombre de candles en position : 31
# Equity : 201006.50000000003
#  2020-10-27 19:30:00
# Position 1 sold at 1.18142 (verification liste 1.18142 )
# Nouvelle moyenne du price_sell 1.18142
#  2020-10-27 23:35:00
# 1 positions TP closed at 1.17802  pnl 169.99999999999238
# nombre de candles en position : 49
# Equity : 201176.50000000003
#  2020-10-28 07:50:00
# Position 1 sold at 1.17697 (verification liste 1.17697 )
# Nouvelle moyenne du price_sell 1.17697
#  2020-10-28 11:55:00
# 1 positions TP closed at 1.1739  pnl 153.50000000000642
# nombre de candles en position : 49
# Equity : 201330.00000000003
#  2020-10-29 08:20:00
# Position 1 sold at 1.17291 (verification liste 1.17291 )
# Nouvelle moyenne du price_sell 1.17291
#  2020-10-29 12:25:00
# 1 positions TP closed at 1.17048  pnl 121.49999999999662
# nombre de candles en position : 49
# Equity : 201451.50000000003
#  2020-10-30 16:25:00
# Position 1 sold at 1.16515 (verification liste 1.16515 )
# Nouvelle moyenne du price_sell 1.16515
#  2020-10-30 16:45:00
# Position 1 sold at 1.1652 (verification liste 1.1652 )
# Nouvelle moyenne du price_sell 1.16518
#  2020-10-30 20:50:00
# 2 positions TP closed at 1.16491  pnl 27.00000000002145
# nombre de candles en position : 49
# Equity : 201478.50000000006
#  2020-11-02 14:10:00
# Position 1 sold at 1.16358 (verification liste 1.16358 )
# Nouvelle moyenne du price_sell 1.16358
#  2020-11-02 18:15:00
# 1 positions TP closed at 1.16291  pnl 33.49999999999742
# nombre de candles en position : 49
# Equity : 201512.00000000006
#  2020-11-05 03:05:00
# Position 1 bought at 1.17303 (verification liste 1.17303 )
# Nouvelle moyenne du price_buy 1.17303
#  2020-11-05 07:05:00
# 1 positions SL closed at 1.17367  pnl 31.999999999998696
# nombre de candles en position : 48
# Equity : 201544.00000000006
#  2020-11-10 10:20:00
# Position 1 sold at 1.17994 (verification liste 1.17994 )
# Nouvelle moyenne du price_sell 1.17994
#  Pour le ticker  EUR/USD
#
# Les gains faramineux s'élèvent à : $  1544.0 !. En  48  transactions.
#
# Nbre de winners : 21
#
# Nbre de loosers : 26
#
# Average trade duration  40.89
# Total des gains faramineux : 1595.0
# Pnl latent restant 51.000000000001044 Open Buy 0 Open Sell 1
# CPU times: user 17.1 s, sys: 497 ms, total: 17.6 s
# Wall time: 24.6 s

# %%
df_historical = pd.DataFrame()
df_historical = pd.DataFrame(index=DATE)
df_historical['Contract'] = CONTRACT
df_historical['Open_Poz'] = OPEN_POZ
df_historical['Close_Pos'] = CLOSE_POZ
df_historical['Rate_Open_Poz'] = RATE_OPEN_POZ 
df_historical['Rate_Close_Poze'] = RATE_CLOSE_POZ
df_historical['Pnl_Lat'] = TOTAL_PNL_LAT
df_historical['Pnl_Real'] = TOTAL_PNL_REAL
df_historical = df_historical.sort_index()
_generated_cash = round(df_historical.Pnl_Real.sum() * _rate,2)
print(col.Fore.BLUE,'Résultats pour le ticker',col.Fore.YELLOW,x,col.Style.RESET_ALL)
if _generated_cash <= 0:
     print('Cash généré :',col.Fore.RED,str(_generated_cash)+'$',col.Style.RESET_ALL)
else:
    print('Cash généré :',col.Fore.GREEN,str(_generated_cash)+'$',col.Style.RESET_ALL)
print('Pnl latent minimal :',str((df_historical.Pnl_Real.min()) * _rate)+'$')
print('Pnl latent maximal :',str((df_historical.Pnl_Real.max())* _rate)+'$')
print('Pnl latent moyen :',str(round(df_historical.Pnl_Real.mean()* _rate,2))+'$')
print('Max des durées moyennes',df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].max())
print('Min des durées moyennes',df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].min())
print('Moyenne des durées moyennes',round(df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].mean(),2))
print('Nombre total de winners',df_resultats.T['Nbre Winners'].sum())
print('Nombre total de loosers',df_resultats.T['Nbre Loosers'].sum())
print('Total des gains cumulés',round(df_historical[df_historical.Pnl_Real>0].Pnl_Real.sum() * _rate,2))
print('Total des pertes cumulées',round(df_historical[df_historical.Pnl_Real<0].Pnl_Real.sum() * _rate,2))
print(col.Fore.BLUE,'PROFIT FACTOR : ',\
    abs(round(df_historical[df_historical.Pnl_Real>0].Pnl_Real.sum()/df_historical[df_historical.Pnl_Real<0].Pnl_Real.sum(),2)),col.Style.RESET_ALL)
print(col.Fore.CYAN,'Ratio du nombre de winners :',\
    round((df_resultats.T['Nbre Winners'].sum()*100)/(df_resultats.T['Nbre Loosers'].sum()+df_resultats.T['Nbre Winners'].sum()),2),'%',col.Style.RESET_ALL)
print('Average Winners',round(sum(list(filter(lambda x:  x > 0,PNL_REAL)))/len(list(filter(lambda x:  x > 0,PNL_REAL)))) * _rate,2)
print('Average Loosers',round(sum(list(filter(lambda x:  x < 0,PNL_REAL)))/len(list(filter(lambda x:  x < 0,PNL_REAL)))) * _rate,2)
print('Average pnl',round(sum(PNL_REAL)/len(set(PNL_REAL))) * _rate,2)
print('Nombre total de trades ouverts',sum(TOTAL_OPEN))
print('Nombre total de trades fermés',sum(TOTAL_CLOSE))
print("Nombre de positions en l'air",(sum(TOTAL_OPEN) - sum(TOTAL_CLOSE)))
# Out:
#  Résultats pour le ticker  EUR/USD
# Cash généré :  1544.0$
# Pnl latent minimal : -195.9999999999962$
# Pnl latent maximal : 241.00000000000233$
# Pnl latent moyen : 0.94$
# Max des durées moyennes 40.89
# Min des durées moyennes 40.89
# Moyenne des durées moyennes 40.89
# Nombre total de winners 21
# Nombre total de loosers 26
# Total des gains cumulés 1902.0
# Total des pertes cumulées -358.0
#  PROFIT FACTOR :  5.31
#  Ratio du nombre de winners : 44.68 %
# Average Winners 83.0 2
# Average Loosers -26.0 2
# Average pnl 41.0 2
# Nombre total de trades ouverts 48
# Nombre total de trades fermés 47
# Nombre de positions en l'air 1

# %%
###################### BIG BAZ #######################

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.dates as mdates
import pandas as pd
from numpy import loadtxt
from functools import reduce
import talib
import time
from scipy.signal import argrelextrema
from ipywidgets import *

from datetime import datetime

DATE = []
CONTRACT = []
OPEN_POZ = []
CLOSE_POZ = []
RATE_OPEN_POZ = []
RATE_CLOSE_POZ = []
PNL_LAT = []
PNL_REAL = []
TOTAL_OPEN = []
TOTAL_CLOSE = []
PRICE_BUY = []
PRICE_SELL = []
DER_POZ = []
TOTAL_PNL_LAT = []
TOTAL_PNL_REAL = []
_cash = _cash_ini
WINNERS = []
LOOSERS = []

_year_top = '2010-12-31 23:59:59'
_year_bottom = '2010-01-01 00:00:01'

_verbose = 1

# %%
def peak_detect(price,order=10):
    max_idx = list(argrelextrema(price,np.greater,order=order)[0])
    min_idx = list(argrelextrema(price,np.less,order=order)[0])
    idx = max_idx + min_idx + [len(price)-1]
    idx.sort()
    _current_idx = idx[-3:]
    
    _start = min(_current_idx)
    _end = max(_current_idx)
    _current_pat = price[_current_idx]
    return _current_idx,_current_pat,_start,_end 
    
def is_BAAM(moves,err_allowed):  
    XA=moves[0]
    AB=moves[1]
    
    
    X=prices[0]
    A=prices[1]
    B=prices[2]
    
    AB_range = np.array([0.68 - err_allowed,0.68+ err_allowed])*abs(XA)
    AB_range2 = np.array([0.15 - err_allowed,0.15+ err_allowed])*abs(XA)
    
    
    
    if abs(A-X)/X>0.001:
        
        if XA>0 and AB<0 :

            if (AB_range[0]<abs(AB)<AB_range[1]) or (AB_range2[0]<abs(AB)<AB_range2[1]) :

                BAAM = 1
                return (BAAM)
            else:
                return (np.isnan)

        elif XA<0 and AB>0 :


            if (AB_range[0]<abs(AB)<AB_range[1]) or (AB_range2[0]<abs(AB)<AB_range2[1]):

                BAAM = -1
                return (BAAM)
            else:
                return (np.isnan)
        else:
             return (np.isnan)

# %%
# %%time

df_resultats = pd.DataFrame(index=['TimeFrame 1','TimeFrame2','Equity','Nbre Winners','Nbre Loosers','Max lenght of trade','Min lenght of trade',\
    'Average lenght of trade','Cumul pnl'])

TICKERS = [ 'EUR/USD']

engine.say("קדימה")
engine.runAndWait()

err_allowed = 2/100
plt.ion()
position = 0
equity = 100000
for x in TICKERS:

    if x[4:] == 'USD':
        _rate = 1

    elif x[:3] == 'USD':
        con.subscribe_market_data(x)
        _rate = con.get_last_price(x).Bid
        con.unsubscribe_market_data(x)
    elif x[:3] != 'USD' and x[4:] != 'USD':
        try:
            con.subscribe_market_data(x[4:]+'/USD')
            _rate = con.get_last_price(x[4:]+'/USD').Bid
            con.unsubscribe_market_data(x[4:]+'/USD')
            _flag = 1
        except:
            con.subscribe_market_data('USD/'+x[4:])
            _rate = con.get_last_price('USD/'+x[4:]).Bid
            con.unsubscribe_market_data('USD/'+x[4:])
            _flag = -1
    else:
        prix_usd = 'NA'

    print(col.Fore.MAGENTA,'Le rate du ticker',x,'est à ',_rate,col.Style.RESET_ALL)
    label = ''
    data = pd.read_csv('Base_Clean/EURUSDm5.csv')
    data2 = pd.read_csv('Base_Clean/EURUSDH1.csv')

    data.index = pd.to_datetime(data['Date'])
    data = data.drop(['Date','Total'],axis=1)
    data.rename(columns={'OpenBid':'Open_Bid','HighBid':'High_Bid','LowBid':'Low_Bid','CloseBid':'Close_Bid',\
        'OpenAsk':'Open_Ask','HighAsk':'High_Ask','LowAsk':'Low_Ask','CloseAsk':'Close_Ask'},inplace = True)

    data2.index = pd.to_datetime(data2['Date'])
    data2 = data2.drop(['Date','Total'],axis=1)
    data2.rename(columns={'OpenBid':'Open_Bid','HighBid':'High_Bid','LowBid':'Low_Bid','CloseBid':'Close_Bid',\
        'OpenAsk':'Open_Ask','HighAsk':'High_Ask','LowAsk':'Low_Ask','CloseAsk':'Close_Ask'},inplace = True)

    data = data[(data.index >= _year_bottom) & (data.index <= _year_top)]
    data2 = data2[(data2.index >= _year_bottom) & (data2.index <= _year_top)]

    price = data.copy()
    price2 = data2.copy()
    _position = 0
    _equity = 0
    _nbtransactions = 0
    backtest_graph = pd.DataFrame()
    EQUITY = [_cash]
    CASH = [_cash]
    _winner = 0
    _looser = 0
    _index_entry = 0
    TRADE_DURATION = []
    _average_duration = 0
    _size = 50000

    PRICE_BUY = []
    PRICE_SELL = []
   
    _total = 0

    _target = 0.003
    _sl = 0.0015
    _spread_filter = 0.00050
    _filtre_multipoz = 0.1 # En %
    _filtre_multipoz = _filtre_multipoz/100
    
    _open_buy = 0
    _open_sell = 0
    _minipoz = 0
    
    MM21 = talib.EMA(price.Close, timeperiod=21)
    MM34 = talib.EMA(price.Close, timeperiod=34)
    MM54 = talib.EMA(price.Close, timeperiod=54)
    rsi = talib.RSI(price.Close, timeperiod=14)
    rsi_high = 70
    rsi_low = 30
    
    MM542 = talib.EMA(price2.Close, timeperiod=54)
    
    for i in range(150,len(price)-1):
        
        j = len(price2[price2.index <= price.index[i]])-1
        
        current_idx,current_pat,start,end = peak_detect(price.Close.values[:i+1])
        current_rsi = [rsi.iloc[current_idx[0]],rsi.iloc[current_idx[1]],rsi.iloc[current_idx[2]]]
        current_rsi_max = max(current_rsi)
        current_rsi_min = min(current_rsi)
        delta_price = current_pat[2] - current_pat[0]
        delta_rsi = current_rsi[2] - current_rsi[0]
      
        XA = current_pat[1] - current_pat[0]     
        AB = current_pat[2] - current_pat[1]      
        
        X = current_pat[0]
        A = current_pat[1]
        B = current_pat[2]

        prices =[X,A,B]

        moves=[XA,AB]
        
        BAAM = is_BAAM(moves,err_allowed)

        harmonics = np.array([BAAM])

        if _position == 0 :
            if (np.any(harmonics==1) and np.all(harmonics!=-1 )) or  (np.any(harmonics==-1) and np.all(harmonics!=1 )):

                for h in range(0, len(harmonics)):

                    if harmonics[h]==-1 and price.iloc[i]['Close_Bid']<MM21[i] and X>MM54[current_idx[0]] and MM21[current_idx[0]]>MM54[current_idx[0]] and MM21[i]<MM34[i]<MM54[i]\
                            and price2.Close[j]<MM542[j]:
                            _pnl = 0
                            _open_sell += 1
                            _equity = _cash + _pnl
                            EQUITY.append(_equity)
                            CASH.append(_cash)
                            _index_entry = i
                            _position = -1
                            _nbtransactions += 1
                            price_sell = price.Close_Bid.iloc[i]
                            PRICE_SELL.append(price_sell)
                            _price_sell_mean = round(sum(PRICE_SELL)/len(PRICE_SELL),5)
                            if _verbose == 1:
                                print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                                print('Position 1 sold at', price_sell,'(verification liste',PRICE_SELL[-1],')')
                                print('Nouvelle moyenne du price_sell',_price_sell_mean)

                            DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                            CONTRACT.append(x)
                            OPEN_POZ.append(-1)
                            CLOSE_POZ.append(0)
                            RATE_OPEN_POZ.append(price_sell)
                            RATE_CLOSE_POZ.append(0) 
                            PNL_LAT.append(_pnl)
                            PNL_REAL.append(0)
                            TOTAL_PNL_LAT.append(_pnl)
                            TOTAL_PNL_REAL.append(0)

                            TOTAL_OPEN.append(1)
                    
                    if harmonics[h]==1 and price.iloc[i]['Close_Ask']>MM21[i] and X<MM54[current_idx[0]] and MM21[current_idx[0]]<MM54[current_idx[0]] and MM21[i]>MM34[i]>MM54[i]\
                        and price2.Close[j]>MM542[j]:
                   
                            _pnl = 0
                            _open_buy += 1
                            _equity = _cash + _pnl
                            EQUITY.append(_equity)
                            CASH.append(_cash)
                            _position = 1
                            _index_entry = i
                            _nbtransactions += 1
                            price_buy = price.Close_Ask.iloc[i]
                            PRICE_BUY.append(price_buy)
                            _price_buy_mean = round(sum(PRICE_BUY)/len(PRICE_BUY),5)
                            if _verbose == 1:
                                print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                                print('Position 1 bought at', price_buy,'(verification liste',PRICE_BUY[-1],')')
                                print('Nouvelle moyenne du price_buy',_price_buy_mean)

                            DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                            CONTRACT.append(x)
                            OPEN_POZ.append(1)
                            CLOSE_POZ.append(0)
                            RATE_OPEN_POZ.append(price_buy)
                            RATE_CLOSE_POZ.append(0)
                            PNL_LAT.append(_pnl)
                            PNL_REAL.append(0)
                            TOTAL_OPEN.append(1) 
                            TOTAL_PNL_LAT.append(_pnl)
                            TOTAL_PNL_REAL.append(0) 

                    else :
                        _pnl = 0
                        _equity = _cash + _pnl
                        EQUITY.append(_equity)
                        CASH.append(_cash)
                
        elif _position == 1:

            
            if (price_buy - price.Close_Bid[i])/price_buy>=_filtre_multipoz and  MM21[i]>MM34[i]>MM54[i]\
            and price2.Close_Bid[j]>MM542[j] :#and harmonics[h]==1:
            
                _pnl = (price.Close_Ask.iloc[i] - _price_buy_mean) * _size * _open_buy
                _open_buy += 1
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)
                _position = 1
                _index_entry = i
                _nbtransactions += 1
                price_buy = price.Close_Ask.iloc[i]
                PRICE_BUY.append(price_buy)
                _price_buy_mean = round(sum(PRICE_BUY)/len(PRICE_BUY),5)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print('Position',_open_buy,'bought at ', price_buy,'(verification liste',PRICE_BUY[-1],')')
                    print('Nouvelle moyenne du price_buy',_price_buy_mean)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(1)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(price_buy)
                RATE_CLOSE_POZ.append(0)
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_OPEN.append(1) 
                TOTAL_PNL_LAT.append(_pnl)
                TOTAL_PNL_REAL.append(0) 


        

            if (float(price.Low_Bid.iloc[i]) - float(_price_buy_mean))/float(_price_buy_mean) >= _target \
                or ((float(price.Low_Bid.iloc[i]) - float(_price_buy_mean) > 0) and (i - _index_entry > 48)):#slowd[i]>80:
        
                _position = 0
                _pnl = (price.Low_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _winner += _open_buy

                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print(_open_buy,'positions TP closed at',price.Low_Bid.iloc[i],col.Fore.GREEN,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Low_Bid.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_buy)
                PRICE_BUY = [] 
                _open_buy = 0

            elif ((float(price.Low_Bid.iloc[i]) - float(_price_buy_mean))/float(_price_buy_mean) <= -_sl) or \
                (PNL_LAT[-1] < -500) or ((i - _index_entry) > 30 and (float(price.Low_Bid.iloc[i]) - float(_price_buy_mean)) < 0):
                _position = 0
                _pnl = (price.High_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_buy

                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print(_open_buy,'positions SL closed at',price.High_Bid.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.High_Bid.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_buy) 
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                PRICE_BUY = []
                _open_buy = 0
            else:

                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(0) ############### 
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_PNL_LAT.append(_pnl)
                TOTAL_PNL_REAL.append(0) 


        elif _position == -1:

            
            
            if ( price.Close_Bid[i] - price_sell)/price_sell>=_filtre_multipoz and price.iloc[i]['Close_Bid']<MM21[i] and MM21[i]<MM34[i]<MM54[i]\
            and price2.Close_Bid[j]<MM542[j] : #and harmonics[h] == -1:
                
                _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _open_sell += 1
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)
                _position = -1
                _index_entry = i
                _nbtransactions += 1
                price_sell = price.Close_Bid.iloc[i]
                PRICE_SELL.append(price_sell)
                _price_sell_mean = round(sum(PRICE_SELL)/len(PRICE_SELL),5)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print('Position 1 sold at', price_sell,'(verification liste',PRICE_SELL[-1],')')
                    print('Nouvelle moyenne du price_sell',_price_sell_mean)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(1)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(price_sell)
                RATE_CLOSE_POZ.append(0)
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_OPEN.append(1) 
                TOTAL_PNL_LAT.append(_pnl)
                TOTAL_PNL_REAL.append(0) 



            if (float(price.High_Ask.iloc[i]) - float(_price_sell_mean))/float(_price_sell_mean) <= -_target \
                or((float(price.High_Ask.iloc[i]) - float(_price_sell_mean) < 0) and(i - _index_entry > 48)):
                _position = 0
                _pnl = - (price.High_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _winner += _open_sell
                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print(_open_sell,'positions TP closed at',price.High_Ask.iloc[i],col.Fore.GREEN,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(-1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.High_Ask.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_sell)
                PRICE_SELL = [] 
                _open_sell = 0

            elif ((float(price.Low_Ask.iloc[i]) - float(_price_sell_mean))/float(_price_sell_mean) >= _sl) or \
                (PNL_LAT[-1] < -500) or ((i - _index_entry) > 30 and (float(price.Low_Ask.iloc[i]) - float(_price_sell_mean)>0)) :
                _position = 0
                _pnl = - (price.Low_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_sell
                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)    
                    print(_open_sell,'position SL closed at',price.Low_Ask.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(-1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Low_Ask.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_sell)
                PRICE_SELL = []
                _open_sell = 0

            else:

                _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _equity = _cash + _pnl

                EQUITY.append(_equity)
                CASH.append(_cash)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(0)
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_PNL_LAT.append(_pnl)

                TOTAL_PNL_REAL.append(0)
              
        elif i == (len(price)-1) and _position != 0 :

            if _position == -1:
                _position = 0
                _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_sell
                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print(col.Fore.CYAN,"Cloture des positions en l'air",col.Style.RESET_ALL)
                    print(_open_sell,'position closed at',price.Close_Ask.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(-1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Ask.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_sell)
                PRICE_SELL = []
                _open_sell = 0

            if _position == 1:

                _position = 0
                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_buy

                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print(col.Fore.CYAN,"Cloture des positions en l'air",col.Style.RESET_ALL)
                    print(_open_buy,'positions closed at',price.Close_Bid.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_buy) 
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                PRICE_BUY = []
                _open_buy = 0

    try:
        _average_duration = round(statistics.mean(TRADE_DURATION),2)
        _max_duration = max(TRADE_DURATION)
        _min_duration = min([item for item in TRADE_DURATION if item !=0])
    
    except:
        print("(pas de duration)") 
        _average_duration = 'NA' 
    print(col.Fore.BLUE,'Pour le ticker',col.Fore.YELLOW,x,col.Style.RESET_ALL)              
    print(col.Fore.MAGENTA,"\nLes gains faramineux s'élèvent à : $",col.Fore.GREEN,round(_total,2),'!. En ',_nbtransactions,' transactions.',col.Style.RESET_ALL ) 
    print(col.Fore.GREEN,"\nNbre de winners :",_winner,col.Style.RESET_ALL)
    print(col.Fore.RED,"\nNbre de loosers :",_looser,col.Style.RESET_ALL)
    print("\nAverage trade duration ",_average_duration)
    backtest_graph['Equity'] = EQUITY
    
    df_resultats[x] = [_period,_period2,(round(_equity,2)),(_winner),(_looser),(_max_duration),(_min_duration),(_average_duration),(_total)]

    print('Total des gains faramineux :',round((EQUITY[-1] - _cash_ini) * _rate,2))
    print('Pnl latent restant',_pnl,'Open Buy',_open_buy,'Open Sell',_open_sell)
    DER_POZ.append(_pnl)

engine.say("Finito caucau")
engine.runAndWait()
# Out:
#  Le rate du ticker EUR/USD est à  1
#  2010-09-10 13:35:00
# Position 1 sold at 1.26954 (verification liste 1.26954 )
# Nouvelle moyenne du price_sell 1.26954
#  2010-09-10 14:35:00
# 1 position SL closed at 1.2715299999999998  pnl -99.49999999999682
# nombre de candles en position : 12
# Equity : 199900.5
#  2010-09-10 19:35:00
# Position 1 sold at 1.27154 (verification liste 1.27154 )
# Nouvelle moyenne du price_sell 1.27154
#  2010-09-12 23:05:00
# 1 position SL closed at 1.27167  pnl -6.500000000009276
# nombre de candles en position : 31
# Equity : 199894.0
#  2010-09-13 11:15:00
# Position 1 bought at 1.28126 (verification liste 1.28126 )
# Nouvelle moyenne du price_buy 1.28126
#  2010-09-13 14:50:00
# 1 positions TP closed at 1.28525  pnl 199.4999999999969
# nombre de candles en position : 43
# Equity : 200093.5
#  2010-09-14 03:00:00
# Position 1 bought at 1.28712 (verification liste 1.28712 )
# Nouvelle moyenne du price_buy 1.28712
#  2010-09-14 05:45:00
# 1 positions SL closed at 1.28766  pnl 26.999999999999247
# nombre de candles en position : 33
# Equity : 200120.5
#  2010-09-14 07:35:00
# Position 1 bought at 1.28938 (verification liste 1.28938 )
# Nouvelle moyenne du price_buy 1.28938
#  2010-09-14 09:00:00
# Position 2 bought at  1.2875299999999998 (verification liste 1.2875299999999998 )
# Nouvelle moyenne du price_buy 1.28845
#  2010-09-14 09:00:00
# 2 positions SL closed at 1.28831  pnl -14.000000000002899
# nombre de candles en position : 0
# Equity : 200106.5
#  2010-09-14 15:20:00
# Position 1 bought at 1.2982799999999999 (verification liste 1.2982799999999999 )
# Nouvelle moyenne du price_buy 1.29828
#  2010-09-14 19:25:00
# 1 positions TP closed at 1.30206  pnl 188.9999999999947
# nombre de candles en position : 49
# Equity : 200295.5
#  2010-09-15 00:25:00
# Position 1 bought at 1.30138 (verification liste 1.30138 )
# Nouvelle moyenne du price_buy 1.30138
#  2010-09-15 01:15:00
# Position 2 bought at  1.30018 (verification liste 1.30018 )
# Nouvelle moyenne du price_buy 1.30078
#  2010-09-15 01:35:00
# Position 3 bought at  1.29845 (verification liste 1.29845 )
# Nouvelle moyenne du price_buy 1.3
#  2010-09-15 01:40:00
# 3 positions SL closed at 1.29881  pnl -178.50000000000367
# nombre de candles en position : 1
# Equity : 200117.0
#  2010-09-16 07:40:00
# Position 1 bought at 1.30221 (verification liste 1.30221 )
# Nouvelle moyenne du price_buy 1.30221
#  2010-09-16 09:10:00
# 1 positions TP closed at 1.3067  pnl 224.49999999999415
# nombre de candles en position : 18
# Equity : 200341.5
#  2010-09-16 18:30:00
# Position 1 bought at 1.30857 (verification liste 1.30857 )
# Nouvelle moyenne du price_buy 1.30857
#  2010-09-16 21:05:00
# 1 positions SL closed at 1.30777  pnl -39.999999999995595
# nombre de candles en position : 31
# Equity : 200301.5
#  2010-09-17 02:35:00
# Position 1 bought at 1.30823 (verification liste 1.30823 )
# Nouvelle moyenne du price_buy 1.30823
#  2010-09-17 04:35:00
# 1 positions TP closed at 1.31234  pnl 205.5000000000029
# nombre de candles en position : 24
# Equity : 200507.0
#  2010-09-20 02:50:00
# Position 1 bought at 1.30738 (verification liste 1.30738 )
# Nouvelle moyenne du price_buy 1.30738
#  2010-09-20 05:25:00
# 1 positions SL closed at 1.30718  pnl -9.999999999998899
# nombre de candles en position : 31
# Equity : 200497.0
#  2010-09-20 13:25:00
# Position 1 sold at 1.3042799999999999 (verification liste 1.3042799999999999 )
# Nouvelle moyenne du price_sell 1.30428
#  2010-09-20 14:10:00
# 1 position SL closed at 1.30654  pnl -112.99999999999643
# nombre de candles en position : 9
# Equity : 200384.0
#  2010-09-20 18:05:00
# Position 1 sold at 1.30651 (verification liste 1.30651 )
# Nouvelle moyenne du price_sell 1.30651
#  2010-09-20 21:15:00
# 1 position SL closed at 1.30657  pnl -2.999999999997449
# nombre de candles en position : 38
# Equity : 200381.0
#  2010-09-21 01:30:00
# Position 1 bought at 1.30893 (verification liste 1.30893 )
# Nouvelle moyenne du price_buy 1.30893
#  2010-09-21 04:30:00
# 1 positions SL closed at 1.30912  pnl 9.500000000006725
# nombre de candles en position : 36
# Equity : 200390.5
#  2010-09-21 08:35:00
# Position 1 bought at 1.3123 (verification liste 1.3123 )
# Nouvelle moyenne du price_buy 1.3123
#  2010-09-21 11:10:00
# 1 positions SL closed at 1.31271  pnl 20.500000000001073
# nombre de candles en position : 31
# Equity : 200411.0
#  2010-09-22 19:55:00
# Position 1 bought at 1.33923 (verification liste 1.33923 )
# Nouvelle moyenne du price_buy 1.33923
#  2010-09-22 22:40:00
# 1 positions SL closed at 1.33945  pnl 11.00000000000545
# nombre de candles en position : 33
# Equity : 200422.0
#  2010-09-24 02:05:00
# Position 1 bought at 1.3325799999999999 (verification liste 1.3325799999999999 )
# Nouvelle moyenne du price_buy 1.33258
#  2010-09-24 04:55:00
# 1 positions SL closed at 1.33341  pnl 41.499999999994316
# nombre de candles en position : 34
# Equity : 200463.5
#  2010-09-24 08:40:00
# Position 1 bought at 1.33823 (verification liste 1.33823 )
# Nouvelle moyenne du price_buy 1.33823
#  2010-09-24 12:35:00
# 1 positions TP closed at 1.3425  pnl 213.4999999999998
# nombre de candles en position : 47
# Equity : 200677.0
#  2010-09-28 03:40:00
# Position 1 bought at 1.34639 (verification liste 1.34639 )
# Nouvelle moyenne du price_buy 1.34639
#  2010-09-28 05:55:00
# Position 2 bought at  1.34511 (verification liste 1.34511 )
# Nouvelle moyenne du price_buy 1.34575
#  2010-09-28 06:20:00
# 2 positions SL closed at 1.3448  pnl -95.00000000000064
# nombre de candles en position : 5
# Equity : 200582.0
#  2010-09-28 10:15:00
# Position 1 bought at 1.34762 (verification liste 1.34762 )
# Nouvelle moyenne du price_buy 1.34762
#  2010-09-28 10:35:00
# Position 2 bought at  1.34633 (verification liste 1.34633 )
# Nouvelle moyenne du price_buy 1.34698
#  2010-09-28 11:00:00
# 2 positions SL closed at 1.34599  pnl -99.00000000000463
# nombre de candles en position : 5
# Equity : 200483.0
#  2010-09-29 10:50:00
# Position 1 bought at 1.36113 (verification liste 1.36113 )
# Nouvelle moyenne du price_buy 1.36113
#  2010-09-29 13:00:00
# Position 2 bought at  1.3593899999999999 (verification liste 1.3593899999999999 )
# Nouvelle moyenne du price_buy 1.36026
#  2010-09-29 13:50:00
# 2 positions SL closed at 1.35917  pnl -109.00000000000354
# nombre de candles en position : 10
# Equity : 200374.0
#  2010-09-30 08:45:00
# Position 1 bought at 1.36245 (verification liste 1.36245 )
# Nouvelle moyenne du price_buy 1.36245
#  2010-09-30 10:25:00
# 1 positions TP closed at 1.36656  pnl 205.5000000000029
# nombre de candles en position : 20
# Equity : 200579.5
#  2010-09-30 19:25:00
# Position 1 bought at 1.3635899999999999 (verification liste 1.3635899999999999 )
# Nouvelle moyenne du price_buy 1.36359
#  2010-09-30 22:00:00
# 1 positions SL closed at 1.36297  pnl -31.000000000003247
# nombre de candles en position : 31
# Equity : 200548.5
#  2010-10-01 00:55:00
# Position 1 bought at 1.36509 (verification liste 1.36509 )
# Nouvelle moyenne du price_buy 1.36509
#  2010-10-01 05:00:00
# 1 positions TP closed at 1.36627  pnl 59.000000000009045
# nombre de candles en position : 49
# Equity : 200607.5
#  2010-10-01 07:20:00
# Position 1 bought at 1.36802 (verification liste 1.36802 )
# Nouvelle moyenne du price_buy 1.36802
#  2010-10-01 09:15:00
# 1 positions TP closed at 1.37246  pnl 221.99999999999997
# nombre de candles en position : 23
# Equity : 200829.5
#  2010-10-04 10:00:00
# Position 1 sold at 1.36848 (verification liste 1.36848 )
# Nouvelle moyenne du price_sell 1.36848
#  2010-10-04 11:15:00
# 1 position SL closed at 1.37144  pnl -148.0000000000037
# nombre de candles en position : 15
# Equity : 200681.5
#  2010-10-05 06:50:00
# Position 1 bought at 1.37055 (verification liste 1.37055 )
# Nouvelle moyenne du price_buy 1.37055
#  2010-10-05 07:20:00
# Position 2 bought at  1.36921 (verification liste 1.36921 )
# Nouvelle moyenne du price_buy 1.36988
#  2010-10-05 07:45:00
# 2 positions TP closed at 1.37457  pnl 469.0000000000083
# nombre de candles en position : 5
# Equity : 201150.5
#  2010-10-06 13:35:00
# Position 1 bought at 1.38752 (verification liste 1.38752 )
# Nouvelle moyenne du price_buy 1.38752
#  2010-10-06 15:50:00
# 1 positions TP closed at 1.39185  pnl 216.49999999999724
# nombre de candles en position : 27
# Equity : 201367.0
#  2010-10-08 03:10:00
# Position 1 bought at 1.39521 (verification liste 1.39521 )
# Nouvelle moyenne du price_buy 1.39521
#  2010-10-08 05:25:00
# Position 2 bought at  1.39391 (verification liste 1.39391 )
# Nouvelle moyenne du price_buy 1.39456
#  2010-10-08 06:25:00
# 2 positions SL closed at 1.39314  pnl -141.99999999999767
# nombre de candles en position : 12
# Equity : 201225.0
#  2010-10-08 13:45:00
# Position 1 bought at 1.39256 (verification liste 1.39256 )
# Nouvelle moyenne du price_buy 1.39256
#  2010-10-08 15:35:00
# Position 2 bought at  1.39091 (verification liste 1.39091 )
# Nouvelle moyenne du price_buy 1.39174
#  2010-10-08 18:10:00
# 2 positions SL closed at 1.39086  pnl -87.99999999999919
# nombre de candles en position : 31
# Equity : 201137.0
#  2010-10-12 04:55:00
# Position 1 sold at 1.38637 (verification liste 1.38637 )
# Nouvelle moyenne du price_sell 1.38637
#  2010-10-12 07:55:00
# 1 positions TP closed at 1.38211  pnl 213.00000000000762
# nombre de candles en position : 36
# Equity : 201350.0
#  2010-10-14 00:30:00
# Position 1 bought at 1.40333 (verification liste 1.40333 )
# Nouvelle moyenne du price_buy 1.40333
#  2010-10-14 02:00:00
# 1 positions TP closed at 1.4075799999999998  pnl 212.49999999999324
# nombre de candles en position : 18
# Equity : 201562.5
#  2010-10-14 20:05:00
# Position 1 bought at 1.4079899999999999 (verification liste 1.4079899999999999 )
# Nouvelle moyenne du price_buy 1.40799
#  2010-10-14 22:40:00
# 1 positions SL closed at 1.40751  pnl -24.000000000001798
# nombre de candles en position : 31
# Equity : 201538.5
#  2010-10-15 14:05:00
# Position 1 sold at 1.40295 (verification liste 1.40295 )
# Nouvelle moyenne du price_sell 1.40295
#  2010-10-15 17:45:00
# 1 positions TP closed at 1.3974600000000001  pnl 274.49999999998863
# nombre de candles en position : 44
# Equity : 201813.0
#  2010-10-18 21:05:00
# Position 1 sold at 1.39411 (verification liste 1.39411 )
# Nouvelle moyenne du price_sell 1.39411
#  2010-10-18 23:40:00
# 1 position SL closed at 1.39602  pnl -95.50000000000392
# nombre de candles en position : 31
# Equity : 201717.5
#  2010-10-19 00:35:00
# Position 1 bought at 1.3979 (verification liste 1.3979 )
# Nouvelle moyenne du price_buy 1.3979
#  2010-10-19 01:05:00
# 1 positions SL closed at 1.39665  pnl -62.499999999998664
# nombre de candles en position : 6
# Equity : 201655.0
#  2010-10-19 02:40:00
# Position 1 sold at 1.3935600000000001 (verification liste 1.3935600000000001 )
# Nouvelle moyenne du price_sell 1.39356
#  2010-10-19 06:45:00
# 1 positions TP closed at 1.3928200000000002  pnl 36.99999999998704
# nombre de candles en position : 49
# Equity : 201692.0
#  2010-10-21 06:35:00
# Position 1 bought at 1.39632 (verification liste 1.39632 )
# Nouvelle moyenne du price_buy 1.39632
#  2010-10-21 07:00:00
# Position 2 bought at  1.39354 (verification liste 1.39354 )
# Nouvelle moyenne du price_buy 1.39493
#  2010-10-21 08:05:00
# 2 positions TP closed at 1.39959  pnl 465.99999999998863
# nombre de candles en position : 13
# Equity : 202158.0
#  2010-10-21 14:20:00
# Position 1 bought at 1.40244 (verification liste 1.40244 )
# Nouvelle moyenne du price_buy 1.40244
#  2010-10-21 14:35:00
# Position 2 bought at  1.40113 (verification liste 1.40113 )
# Nouvelle moyenne du price_buy 1.40178
#  2010-10-21 14:50:00
# Position 3 bought at  1.39973 (verification liste 1.39973 )
# Nouvelle moyenne du price_buy 1.4011
#  2010-10-21 15:15:00
# 3 positions SL closed at 1.4  pnl -165.00000000001512
# nombre de candles en position : 5
# Equity : 201992.99999999997
#  2010-10-22 04:00:00
# Position 1 bought at 1.3928 (verification liste 1.3928 )
# Nouvelle moyenne du price_buy 1.3928
#  2010-10-22 07:15:00
# 1 positions SL closed at 1.39364  pnl 41.9999999999976
# nombre de candles en position : 39
# Equity : 202034.99999999997
#  2010-10-22 08:55:00
# Position 1 sold at 1.38822 (verification liste 1.38822 )
# Nouvelle moyenne du price_sell 1.38822
#  2010-10-22 09:15:00
# 1 position SL closed at 1.3908399999999999  pnl -130.99999999999224
# nombre de candles en position : 4
# Equity : 201903.99999999997
#  2010-10-22 11:55:00
# Position 1 bought at 1.39504 (verification liste 1.39504 )
# Nouvelle moyenne du price_buy 1.39504
#  2010-10-22 12:10:00
# Position 2 bought at  1.39336 (verification liste 1.39336 )
# Nouvelle moyenne du price_buy 1.3942
#  2010-10-22 12:45:00
# 2 positions SL closed at 1.3934600000000001  pnl -73.99999999999629
# nombre de candles en position : 7
# Equity : 201829.99999999997
#  2010-10-22 19:05:00
# Position 1 bought at 1.39339 (verification liste 1.39339 )
# Nouvelle moyenne du price_buy 1.39339
#  2010-10-24 23:05:00
# 1 positions SL closed at 1.39382  pnl 21.500000000007624
# nombre de candles en position : 37
# Equity : 201851.49999999997
#  2010-10-25 10:10:00
# Position 1 bought at 1.40503 (verification liste 1.40503 )
# Nouvelle moyenne du price_buy 1.40503
#  2010-10-25 10:30:00
# Position 2 bought at  1.40364 (verification liste 1.40364 )
# Nouvelle moyenne du price_buy 1.40434
#  2010-10-25 12:20:00
# 2 positions SL closed at 1.40319  pnl -114.99999999999844
# nombre de candles en position : 22
# Equity : 201736.49999999997
#  2010-10-27 00:10:00
# Position 1 sold at 1.3843 (verification liste 1.3843 )
# Nouvelle moyenne du price_sell 1.3843
#  2010-10-27 00:55:00
# 1 position SL closed at 1.3864299999999998  pnl -106.49999999998715
# nombre de candles en position : 9
# Equity : 201629.99999999997
#  2010-11-02 01:50:00
# Position 1 sold at 1.38871 (verification liste 1.38871 )
# Nouvelle moyenne du price_sell 1.38871
#  2010-11-02 03:35:00
# 1 position SL closed at 1.39152  pnl -140.49999999999895
# nombre de candles en position : 21
# Equity : 201489.49999999997
#  2010-11-02 03:50:00
# Position 1 bought at 1.39149 (verification liste 1.39149 )
# Nouvelle moyenne du price_buy 1.39149
#  2010-11-02 07:40:00
# 1 positions SL closed at 1.39247  pnl 49.00000000001015
# nombre de candles en position : 46
# Equity : 201538.49999999997
#  2010-11-03 07:55:00
# Position 1 bought at 1.40319 (verification liste 1.40319 )
# Nouvelle moyenne du price_buy 1.40319
#  2010-11-03 12:00:00
# 1 positions TP closed at 1.40428  pnl 54.50000000000177
# nombre de candles en position : 49
# Equity : 201592.99999999997
#  2010-11-03 17:20:00
# Position 1 bought at 1.40478 (verification liste 1.40478 )
# Nouvelle moyenne du price_buy 1.40478
#  2010-11-03 18:15:00
# 1 positions SL closed at 1.41887  pnl 704.5000000000078
# nombre de candles en position : 11
# Equity : 202297.49999999997
#  2010-11-04 02:45:00
# Position 1 bought at 1.41289 (verification liste 1.41289 )
# Nouvelle moyenne du price_buy 1.41289
#  2010-11-04 05:20:00
# 1 positions SL closed at 1.41297  pnl 4.000000000004
# nombre de candles en position : 31
# Equity : 202301.49999999997
#  2010-11-04 10:20:00
# Position 1 bought at 1.42363 (verification liste 1.42363 )
# Nouvelle moyenne du price_buy 1.42363
#  2010-11-04 11:00:00
# Position 2 bought at  1.42234 (verification liste 1.42234 )
# Nouvelle moyenne du price_buy 1.42298
#  2010-11-04 15:05:00
# 2 positions TP closed at 1.4251200000000002  pnl 214.0000000000253
# nombre de candles en position : 49
# Equity : 202515.5
#  2010-11-05 11:30:00
# Position 1 sold at 1.41115 (verification liste 1.41115 )
# Nouvelle moyenne du price_sell 1.41115
#  2010-11-05 12:35:00
# 1 positions TP closed at 1.40658  pnl 228.49999999999815
# nombre de candles en position : 13
# Equity : 202744.0
#  2010-11-08 02:50:00
# Position 1 sold at 1.39545 (verification liste 1.39545 )
# Nouvelle moyenne du price_sell 1.39545
#  2010-11-08 05:25:00
# 1 position SL closed at 1.3967399999999999  pnl -64.49999999998957
# nombre de candles en position : 31
# Equity : 202679.5
#  2010-11-08 21:00:00
# Position 1 sold at 1.3919700000000002 (verification liste 1.3919700000000002 )
# Nouvelle moyenne du price_sell 1.39197
#  2010-11-08 23:35:00
# 1 position SL closed at 1.3922700000000001  pnl -15.00000000000945
# nombre de candles en position : 31
# Equity : 202664.5
#  2010-11-09 17:10:00
# Position 1 sold at 1.38723 (verification liste 1.38723 )
# Nouvelle moyenne du price_sell 1.38723
#  2010-11-09 18:40:00
# 1 positions TP closed at 1.38299  pnl 212.00000000000108
# nombre de candles en position : 18
# Equity : 202876.5
#  2010-11-15 16:10:00
# Position 1 sold at 1.35996 (verification liste 1.35996 )
# Nouvelle moyenne du price_sell 1.35996
#  2010-11-15 18:45:00
# 1 position SL closed at 1.36155  pnl -79.49999999999902
# nombre de candles en position : 31
# Equity : 202797.0
#  2010-11-16 07:05:00
# Position 1 sold at 1.3588200000000001 (verification liste 1.3588200000000001 )
# Nouvelle moyenne du price_sell 1.35882
#  2010-11-16 08:15:00
# 1 position SL closed at 1.36116  pnl -117.00000000000044
# nombre de candles en position : 14
# Equity : 202680.0
#  2010-11-16 15:05:00
# Position 1 sold at 1.3582299999999998 (verification liste 1.3582299999999998 )
# Nouvelle moyenne du price_sell 1.35823
#  2010-11-16 16:10:00
# 1 positions TP closed at 1.35389  pnl 217.0000000000005
# nombre de candles en position : 13
# Equity : 202897.0
#  2010-11-16 16:35:00
# Position 1 sold at 1.35327 (verification liste 1.35327 )
# Nouvelle moyenne du price_sell 1.35327
#  2010-11-16 17:35:00
# 1 positions TP closed at 1.34854  pnl 236.49999999999505
# nombre de candles en position : 12
# Equity : 203133.5
#  2010-11-16 17:55:00
# Position 1 sold at 1.34848 (verification liste 1.34848 )
# Nouvelle moyenne du price_sell 1.34848
#  2010-11-16 20:30:00
# 1 position SL closed at 1.34877  pnl -14.500000000006175
# nombre de candles en position : 31
# Equity : 203119.0
#  2010-11-17 07:30:00
# Position 1 sold at 1.34917 (verification liste 1.34917 )
# Nouvelle moyenne du price_sell 1.34917
#  2010-11-17 09:50:00
# 1 position SL closed at 1.3522299999999998  pnl -152.99999999999204
# nombre de candles en position : 28
# Equity : 202966.0
#  2010-11-17 12:55:00
# Position 1 sold at 1.34725 (verification liste 1.34725 )
# Nouvelle moyenne du price_sell 1.34725
#  2010-11-17 13:30:00
# 1 position SL closed at 1.34954  pnl -114.49999999999517
# nombre de candles en position : 7
# Equity : 202851.5
#  2010-11-18 18:40:00
# Position 1 bought at 1.36299 (verification liste 1.36299 )
# Nouvelle moyenne du price_buy 1.36299
#  2010-11-18 22:45:00
# 1 positions TP closed at 1.36385  pnl 43.00000000000415
# nombre de candles en position : 49
# Equity : 202894.5
#  2010-11-19 08:25:00
# Position 1 bought at 1.36842 (verification liste 1.36842 )
# Nouvelle moyenne du price_buy 1.36842
#  2010-11-19 12:30:00
# 1 positions SL closed at 1.36945  pnl 51.50000000000432
# nombre de candles en position : 49
# Equity : 202946.0
#  2010-11-22 07:20:00
# Position 1 bought at 1.37732 (verification liste 1.37732 )
# Nouvelle moyenne du price_buy 1.37732
#  2010-11-22 07:45:00
# Position 2 bought at  1.37529 (verification liste 1.37529 )
# Nouvelle moyenne du price_buy 1.3763
#  2010-11-22 07:50:00
# Position 3 bought at  1.37384 (verification liste 1.37384 )
# Nouvelle moyenne du price_buy 1.37548
#  2010-11-22 07:50:00
# 3 positions SL closed at 1.3751799999999998  pnl -45.00000000002835
# nombre de candles en position : 0
# Equity : 202900.99999999997
#  2010-11-23 00:05:00
# Position 1 sold at 1.3594 (verification liste 1.3594 )
# Nouvelle moyenne du price_sell 1.3594
#  2010-11-23 00:15:00
# Position 1 sold at 1.36096 (verification liste 1.36096 )
# Nouvelle moyenne du price_sell 1.36018
#  2010-11-23 04:20:00
# 2 positions TP closed at 1.35884  pnl 133.99999999998968
# nombre de candles en position : 49
# Equity : 203034.99999999997
#  2010-11-23 06:30:00
# Position 1 sold at 1.35562 (verification liste 1.35562 )
# Nouvelle moyenne du price_sell 1.35562
#  2010-11-23 09:05:00
# 1 position SL closed at 1.35744  pnl -90.99999999999665
# nombre de candles en position : 31
# Equity : 202943.99999999997
#  2010-11-23 13:20:00
# Position 1 sold at 1.3506 (verification liste 1.3506 )
# Nouvelle moyenne du price_sell 1.3506
#  2010-11-23 14:50:00
# 1 positions TP closed at 1.34594  pnl 233.00000000000543
# nombre de candles en position : 18
# Equity : 203176.99999999997
#  2010-11-23 15:00:00
# Position 1 sold at 1.34546 (verification liste 1.34546 )
# Nouvelle moyenne du price_sell 1.34546
#  2010-11-23 15:30:00
# 1 positions TP closed at 1.3411600000000001  pnl 214.99999999999852
# nombre de candles en position : 6
# Equity : 203391.99999999997
#  2010-11-24 09:20:00
# Position 1 sold at 1.33187 (verification liste 1.33187 )
# Nouvelle moyenne du price_sell 1.33187
#  2010-11-24 11:15:00
# 1 position SL closed at 1.33447  pnl -129.9999999999968
# nombre de candles en position : 23
# Equity : 203261.99999999997
#  2010-11-25 01:15:00
# Position 1 sold at 1.3326200000000001 (verification liste 1.3326200000000001 )
# Nouvelle moyenne du price_sell 1.33262
#  2010-11-25 04:05:00
# 1 position SL closed at 1.3327  pnl -4.000000000004
# nombre de candles en position : 34
# Equity : 203257.99999999997
#  2010-11-25 10:35:00
# Position 1 sold at 1.33036 (verification liste 1.33036 )
# Nouvelle moyenne du price_sell 1.33036
#  2010-11-25 11:30:00
# 1 position SL closed at 1.33257  pnl -110.50000000000226
# nombre de candles en position : 11
# Equity : 203147.49999999997
#  2010-11-25 21:30:00
# Position 1 sold at 1.33543 (verification liste 1.33543 )
# Nouvelle moyenne du price_sell 1.33543
#  2010-11-26 01:35:00
# 1 positions TP closed at 1.33428  pnl 57.49999999999922
# nombre de candles en position : 49
# Equity : 203204.99999999997
#  2010-11-29 00:55:00
# Position 1 sold at 1.32114 (verification liste 1.32114 )
# Nouvelle moyenne du price_sell 1.32114
#  2010-11-29 02:35:00
# 1 position SL closed at 1.32348  pnl -117.00000000000044
# nombre de candles en position : 18
# Equity : 203087.99999999997
#  2010-11-30 04:40:00
# Position 1 sold at 1.30911 (verification liste 1.30911 )
# Nouvelle moyenne du price_sell 1.30911
#  2010-11-30 06:30:00
# 1 position SL closed at 1.3113299999999999  pnl -110.99999999999443
# nombre de candles en position : 22
# Equity : 202976.99999999997
#  2010-11-30 09:50:00
# Position 1 sold at 1.30216 (verification liste 1.30216 )
# Nouvelle moyenne du price_sell 1.30216
#  2010-11-30 11:40:00
# 1 position SL closed at 1.30413  pnl -98.50000000000136
# nombre de candles en position : 22
# Equity : 202878.49999999997
#  2010-11-30 19:25:00
# Position 1 sold at 1.30079 (verification liste 1.30079 )
# Nouvelle moyenne du price_sell 1.30079
#  2010-11-30 23:30:00
# 1 positions TP closed at 1.2996299999999998  pnl 58.000000000002494
# nombre de candles en position : 49
# Equity : 202936.49999999997
#  2010-12-01 17:10:00
# Position 1 bought at 1.31364 (verification liste 1.31364 )
# Nouvelle moyenne du price_buy 1.31364
#  2010-12-01 18:15:00
# Position 2 bought at  1.3110700000000002 (verification liste 1.3110700000000002 )
# Nouvelle moyenne du price_buy 1.31236
#  2010-12-01 18:20:00
# 2 positions SL closed at 1.31142  pnl -93.99999999999409
# nombre de candles en position : 1
# Equity : 202842.49999999997
#  2010-12-02 06:45:00
# Position 1 bought at 1.31374 (verification liste 1.31374 )
# Nouvelle moyenne du price_buy 1.31374
#  2010-12-02 08:40:00
# 1 positions SL closed at 1.31282  pnl -45.99999999999049
# nombre de candles en position : 23
# Equity : 202796.49999999997
#  2010-12-02 16:05:00
# Position 1 bought at 1.31779 (verification liste 1.31779 )
# Nouvelle moyenne du price_buy 1.31779
#  2010-12-02 16:30:00
# 1 positions TP closed at 1.3231700000000002  pnl 269.00000000000813
# nombre de candles en position : 5
# Equity : 203065.49999999997
#  2010-12-03 06:10:00
# Position 1 bought at 1.32264 (verification liste 1.32264 )
# Nouvelle moyenne du price_buy 1.32264
#  2010-12-03 07:55:00
# Position 2 bought at  1.32128 (verification liste 1.32128 )
# Nouvelle moyenne du price_buy 1.32196
#  2010-12-03 08:00:00
# 2 positions SL closed at 1.32115  pnl -80.99999999999774
# nombre de candles en position : 1
# Equity : 202984.49999999997
#  2010-12-06 19:10:00
# Position 1 bought at 1.33151 (verification liste 1.33151 )
# Nouvelle moyenne du price_buy 1.33151
#  2010-12-06 21:15:00
# Position 2 bought at  1.33036 (verification liste 1.33036 )
# Nouvelle moyenne du price_buy 1.33094
#  2010-12-06 23:45:00
# 2 positions SL closed at 1.32968  pnl -126.0000000000039
# nombre de candles en position : 30
# Equity : 202858.49999999997
#  2010-12-07 08:25:00
# Position 1 bought at 1.3362100000000001 (verification liste 1.3362100000000001 )
# Nouvelle moyenne du price_buy 1.33621
#  2010-12-07 08:50:00
# Position 2 bought at  1.33324 (verification liste 1.33324 )
# Nouvelle moyenne du price_buy 1.33473
#  2010-12-07 12:55:00
# 2 positions TP closed at 1.33588  pnl 114.99999999999844
# nombre de candles en position : 49
# Equity : 202973.49999999997
#  2010-12-07 17:20:00
# Position 1 sold at 1.33223 (verification liste 1.33223 )
# Nouvelle moyenne du price_sell 1.33223
#  2010-12-07 20:25:00
# 1 positions TP closed at 1.3274700000000001  pnl 237.99999999999378
# nombre de candles en position : 37
# Equity : 203211.49999999997
#  2010-12-08 13:05:00
# Position 1 sold at 1.3211600000000001 (verification liste 1.3211600000000001 )
# Nouvelle moyenne du price_sell 1.32116
#  2010-12-08 14:00:00
# 1 position SL closed at 1.3231600000000001  pnl -100.0000000000112
# nombre de candles en position : 11
# Equity : 203111.49999999997
#  2010-12-09 01:25:00
# Position 1 bought at 1.3295299999999999 (verification liste 1.3295299999999999 )
# Nouvelle moyenne du price_buy 1.32953
#  2010-12-09 05:30:00
# 1 positions TP closed at 1.33038  pnl 42.49999999998977
# nombre de candles en position : 49
# Equity : 203153.99999999997
#  2010-12-09 09:20:00
# Position 1 sold at 1.32659 (verification liste 1.32659 )
# Nouvelle moyenne du price_sell 1.32659
#  2010-12-09 09:50:00
# 1 positions TP closed at 1.32255  pnl 202.0000000000022
# nombre de candles en position : 6
# Equity : 203355.99999999997
#  2010-12-09 10:50:00
# Position 1 sold at 1.32189 (verification liste 1.32189 )
# Nouvelle moyenne du price_sell 1.32189
#  2010-12-09 13:35:00
# 1 position SL closed at 1.32301  pnl -56.0000000000005
# nombre de candles en position : 33
# Equity : 203299.99999999997
#  2010-12-12 22:50:00
# Position 1 sold at 1.31984 (verification liste 1.31984 )
# Nouvelle moyenne du price_sell 1.31984
#  2010-12-13 02:55:00
# 1 positions TP closed at 1.31922  pnl 30.999999999992145
# nombre de candles en position : 49
# Equity : 203330.99999999997
#  2010-12-14 08:25:00
# Position 1 bought at 1.34574 (verification liste 1.34574 )
# Nouvelle moyenne du price_buy 1.34574
#  2010-12-14 08:50:00
# Position 2 bought at  1.3444200000000002 (verification liste 1.3444200000000002 )
# Nouvelle moyenne du price_buy 1.34508
#  2010-12-14 08:55:00
# 2 positions SL closed at 1.3443100000000001  pnl -76.99999999999375
# nombre de candles en position : 1
# Equity : 203253.99999999997
#  2010-12-15 18:00:00
# Position 1 sold at 1.32704 (verification liste 1.32704 )
# Nouvelle moyenne du price_sell 1.32704
#  2010-12-15 19:40:00
# 1 positions TP closed at 1.32284  pnl 209.9999999999991
# nombre de candles en position : 20
# Equity : 203463.99999999997
#  2010-12-15 20:35:00
# Position 1 sold at 1.3233 (verification liste 1.3233 )
# Nouvelle moyenne du price_sell 1.3233
#  2010-12-16 00:40:00
# 1 positions TP closed at 1.32294  pnl 17.999999999995797
# nombre de candles en position : 49
# Equity : 203481.99999999997
#  2010-12-16 15:55:00
# Position 1 sold at 1.31935 (verification liste 1.31935 )
# Nouvelle moyenne du price_sell 1.31935
#  2010-12-16 17:35:00
# 1 position SL closed at 1.32162  pnl -113.49999999999972
# nombre de candles en position : 20
# Equity : 203368.49999999997
#  2010-12-17 12:50:00
# Position 1 sold at 1.32629 (verification liste 1.32629 )
# Nouvelle moyenne du price_sell 1.32629
#  2010-12-17 15:05:00
# 1 positions TP closed at 1.3219999999999998  pnl 214.50000000000637
# nombre de candles en position : 27
# Equity : 203582.99999999997
#  2010-12-21 08:35:00
# Position 1 sold at 1.31485 (verification liste 1.31485 )
# Nouvelle moyenne du price_sell 1.31485
#  2010-12-21 11:10:00
# 1 position SL closed at 1.31524  pnl -19.49999999999452
# nombre de candles en position : 31
# Equity : 203563.49999999997
#  2010-12-21 15:35:00
# Position 1 sold at 1.31301 (verification liste 1.31301 )
# Nouvelle moyenne du price_sell 1.31301
#  2010-12-21 18:25:00
# 1 positions TP closed at 1.3089  pnl 205.5000000000029
# nombre de candles en position : 34
# Equity : 203768.99999999997
#  2010-12-23 08:55:00
# Position 1 sold at 1.31024 (verification liste 1.31024 )
# Nouvelle moyenne du price_sell 1.31024
#  2010-12-23 13:00:00
# 1 positions TP closed at 1.30964  pnl 30.000000000007798
# nombre de candles en position : 49
# Equity : 203798.99999999997
#  2010-12-24 10:20:00
# Position 1 sold at 1.31188 (verification liste 1.31188 )
# Nouvelle moyenne du price_sell 1.31188
#  2010-12-24 12:55:00
# 1 position SL closed at 1.31244  pnl -28.000000000005798
# nombre de candles en position : 31
# Equity : 203770.99999999997
#  2010-12-27 03:05:00
# Position 1 bought at 1.31161 (verification liste 1.31161 )
# Nouvelle moyenne du price_buy 1.31161
#  2010-12-27 06:55:00
# 1 positions TP closed at 1.31555  pnl 197.00000000000273
# nombre de candles en position : 46
# Equity : 203967.99999999997
#  2010-12-27 22:35:00
# Position 1 bought at 1.31664 (verification liste 1.31664 )
# Nouvelle moyenne du price_buy 1.31664
#  2010-12-28 00:20:00
# 1 positions TP closed at 1.32186  pnl 261.0000000000001
# nombre de candles en position : 21
# Equity : 204228.99999999997
#  2010-12-28 10:40:00
# Position 1 bought at 1.3245200000000001 (verification liste 1.3245200000000001 )
# Nouvelle moyenne du price_buy 1.32452
#  2010-12-28 12:50:00
# Position 2 bought at  1.32324 (verification liste 1.32324 )
# Nouvelle moyenne du price_buy 1.32388
#  2010-12-28 12:55:00
# 2 positions SL closed at 1.32323  pnl -65.00000000000395
# nombre de candles en position : 1
# Equity : 204163.99999999997
#  2010-12-29 11:05:00
# Position 1 sold at 1.3119399999999999 (verification liste 1.3119399999999999 )
# Nouvelle moyenne du price_sell 1.31194
#  2010-12-29 13:40:00
# 1 position SL closed at 1.31332  pnl -68.99999999999685
# nombre de candles en position : 31
# Equity : 204094.99999999997
#  2010-12-30 19:30:00
# Position 1 bought at 1.32962 (verification liste 1.32962 )
# Nouvelle moyenne du price_buy 1.32962
#  2010-12-30 20:40:00
# Position 2 bought at  1.32826 (verification liste 1.32826 )
# Nouvelle moyenne du price_buy 1.32894
#  2010-12-30 23:20:00
# 2 positions SL closed at 1.32939  pnl 45.000000000006146
# nombre de candles en position : 32
# Equity : 204139.99999999997
#  2010-12-31 07:00:00
# Position 1 bought at 1.33643 (verification liste 1.33643 )
# Nouvelle moyenne du price_buy 1.33643
#  2010-12-31 07:40:00
# Position 2 bought at  1.33522 (verification liste 1.33522 )
# Nouvelle moyenne du price_buy 1.33582
#  2010-12-31 08:25:00
# 2 positions SL closed at 1.3345200000000002  pnl -129.99999999998568
# nombre de candles en position : 9
# Equity : 204009.99999999997
#  Pour le ticker  EUR/USD
#
# Les gains faramineux s'élèvent à : $  4010.0 !. En  130  transactions.
#
# Nbre de winners : 45
#
# Nbre de loosers : 85
#
# Average trade duration  25.45
# Total des gains faramineux : 4010.0
# Pnl latent restant 0 Open Buy 0 Open Sell 0
# CPU times: user 53.6 s, sys: 1.66 s, total: 55.3 s
# Wall time: 1min

# %%
df_historical = pd.DataFrame()
df_historical = pd.DataFrame(index=DATE)
df_historical['Contract'] = CONTRACT
df_historical['Open_Poz'] = OPEN_POZ
df_historical['Close_Pos'] = CLOSE_POZ
df_historical['Rate_Open_Poz'] = RATE_OPEN_POZ 
df_historical['Rate_Close_Poze'] = RATE_CLOSE_POZ
df_historical['Pnl_Lat'] = TOTAL_PNL_LAT
df_historical['Pnl_Real'] = TOTAL_PNL_REAL
df_historical = df_historical.sort_index()
_generated_cash = round(df_historical.Pnl_Real.sum() * _rate,2)
_generated_cash_perc = round((_generated_cash / _cash_ini) * 100,2)
print(col.Fore.YELLOW,x,col.Fore.BLUE,'results',col.Style.RESET_ALL)
print(col.Fore.MAGENTA,'Tested Period',_year_bottom,' à',_year_top,col.Style.RESET_ALL)
print(col.Fore.CYAN,'Total Number of trades',max([sum(TOTAL_OPEN),sum(TOTAL_CLOSE)]),col.Style.RESET_ALL)
if _generated_cash <= 0:
    print('Started Cash :',_size)
    print('P&L in current:',col.Fore.RED,str(_generated_cash)+'$',col.Style.RESET_ALL)
    print('P&L in %:',col.Fore.RED,str(_generated_cash_perc)+'%',col.Style.RESET_ALL)

else:
    print('Started Cash :',_size)
    print('P&L  in current:',col.Fore.GREEN,str(_generated_cash)+'$',col.Style.RESET_ALL)
    print('P&L in %:',col.Fore.GREEN,str(_generated_cash_perc)+'%',col.Style.RESET_ALL)

print('Pnl latent minimal :',str(round((df_historical.Pnl_Real.min()) * _rate,2))+'$')
print('Pnl latent maximal :',str(round((df_historical.Pnl_Real.max())* _rate,2))+'$')
print('Pnl latent moyen :',str(round(df_historical.Pnl_Real.mean()* _rate,2))+'$')
print('Maximal trade duration',_max_duration)
print('Minimal trade duration',_min_duration)
print('Average trade duration',_average_duration)
print('Winners nmber',df_resultats.T['Nbre Winners'].sum())
print('Loosers number',df_resultats.T['Nbre Loosers'].sum())
print('Cumulated gains',round(df_historical[df_historical.Pnl_Real>0].Pnl_Real.sum() * _rate,2))
print('Cumulated losses',round(df_historical[df_historical.Pnl_Real<0].Pnl_Real.sum() * _rate,2))
print(col.Fore.BLUE,'PROFIT FACTOR : ',\
    abs(round(df_historical[df_historical.Pnl_Real>0].Pnl_Real.sum()/df_historical[df_historical.Pnl_Real<0].Pnl_Real.sum(),2)),col.Style.RESET_ALL)
print(col.Fore.CYAN,'Winners Ratio :',\
    round((df_resultats.T['Nbre Winners'].sum()*100)/(df_resultats.T['Nbre Loosers'].sum()+df_resultats.T['Nbre Winners'].sum()),2),'%',col.Style.RESET_ALL)
print('Average Winners',round(sum(list(filter(lambda x:  x > 0,PNL_REAL)))/len(list(filter(lambda x:  x > 0,PNL_REAL))) * _rate,2))
print('Average Loosers',round(sum(list(filter(lambda x:  x < 0,PNL_REAL)))/len(list(filter(lambda x:  x < 0,PNL_REAL))) * _rate,2))
print('Average pnl',round(sum(PNL_REAL)/len(set(PNL_REAL))) * _rate,2)
print('% Average Winners',round((sum(list(filter(lambda x:  x > 0,PNL_REAL)))/len(list(filter(lambda x:  x > 0,PNL_REAL))) * _rate) / _cash_ini * 100,2))
print('% Average Loosers',round(sum(list(filter(lambda x:  x < 0,PNL_REAL)))/len(list(filter(lambda x:  x < 0,PNL_REAL)) * _rate) / _cash_ini * 100,2))
print('% Average pnl',round((sum(PNL_REAL)/len(set(PNL_REAL)) * _rate) / _cash_ini * 100,2))
print('Number of opened trades',sum(TOTAL_OPEN))
print('Number of closed trades',sum(TOTAL_CLOSE))
print("Nombre de positions en l'air",(sum(TOTAL_OPEN) - sum(TOTAL_CLOSE)))
# Out:
#  EUR/USD  results
#  Tested Period 2010-01-01 00:00:01  à 2010-12-31 23:59:59
#  Total Number of trades 130
# Started Cash : 50000
# P&L  in current:  4010.0$
# P&L in %:  2.0%
# Pnl latent minimal : -178.5$
# Pnl latent maximal : 704.5$
# Pnl latent moyen : 1.31$
# Maximal trade duration 49
# Minimal trade duration 1
# Average trade duration 25.45
# Winners nmber 45
# Loosers number 85
# Cumulated gains 8370.5
# Cumulated losses -4360.5
#  PROFIT FACTOR :  1.92
#  Winners Ratio : 34.62 %
# Average Winners 160.97
# Average Loosers -83.86
# Average pnl 39.0 2
# % Average Winners 0.08
# % Average Loosers -0.04
# % Average pnl 0.02
# Number of opened trades 130
# Number of closed trades 130
# Nombre de positions en l'air 0

# %%
# Out:
# 130

# %%
len(list(filter(lambda x:  x < 0,PNL_REAL)) * _rate) / _cash_ini * 100
# Out:
# 0.026

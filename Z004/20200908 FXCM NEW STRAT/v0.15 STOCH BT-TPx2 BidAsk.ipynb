# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
        
clearall()

# %%
# TO DO 
# 
# pour le nombre d'occurences (len !=), mettre un pnl latent pour la pos = 0
# 
# 
#

# %%
############################
######## LIBRAIRIES ########
############################
print('Importing Librairies...')
from sklearn.linear_model import LinearRegression
import colorama as col
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import time
import os
import datetime as dt
import numpy as np
import fxcmpy
import socketio
import shelve
import talib
import statistics
import pyttsx3

engine = pyttsx3.init()

print('Librairies imported\n')
print('version fxcmpy :',fxcmpy.__version__)
# %matplotlib inline
plt.style.use('seaborn')
engine.say("librairie loaded")
engine.runAndWait()
print('Prêt')
# Out:
# Importing Librairies...
# Librairies imported
#
# version fxcmpy : 1.2.6
# Prêt

# %%
engine.say("Ignition du Lumberjack")
engine.runAndWait() 

##############################################
######## INITIALISATION DES VARIABLES ########
##############################################


# COMPTE TEST #

TOKEN = 'a30285ad958d60b7e7134a195a516cf00a9967be'
server = 'demo'
user_id = 'D261219574'
compte = '01215057'
password = '3555'


'''
# COMPTE DEV #
TOKEN = '79f83cbff13d296eb6d9b6c1ed6dccd768ef925a'
server = 'demo'
user_id = 'D261219577'
compte = '01215060'
password = '3877'
'''

'''
# COMPTE POUBELLE #
TOKEN = 'a66bf5c0ec732487f4b348baf6364d3ee8784935'
server = 'demo'
user_id = 'D261219576'
compte = '01215059'
password = '8029'
'''


# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'


_number = 10000
_period = 'm5'
_period2 = 'D1'
_total = 0
_cash_ini = 200000
_cash = _cash_ini
_rate = 1
_flag = 0

engine.say("בסדר")
engine.runAndWait()
print('Variables initialisées')
# Out:
# Variables initialisées

# %%
############################
######## FONCTIONS ########
###########################


def conX():
    con = fxcmpy.fxcmpy(access_token=TOKEN, log_level='error',server=server)
    if con.is_connected() == True:
        print(col.Fore.GREEN+'Connexion établie'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
    else:
        print(col.Fore.RED+'Connexion non établie'+col.Style.RESET_ALL)
    return(con)

def deconX():
    con = con.close()
    if con.is_connected() == True:
        print(col.Fore.GREEN+'Connexion non intérrompue'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
    else:
        print(col.Fore.RED+'Connexion intérrompue'+col.Style.RESET_ALL)
    return()


def scrap_hist(_ticker,number,laperiod):
    print(col.Fore.BLUE,'Scraping des données OHLC pour le ticker',col.Fore.YELLOW,_ticker,col.Style.RESET_ALL)
    data = con.get_candles(instrument=_ticker,number = 10000,period=laperiod)
    df = pd.DataFrame(index=data.index)
    df['Open_Bid'] = data['bidopen']
    df['Open_Ask'] = data['askopen']
    df['Open'] = (data['bidopen']+data['askopen'])/2
    df['High_Bid'] = data['bidhigh']
    df['High_Ask'] = data['askhigh']
    df['High'] = (data['bidhigh']+data['askhigh'])/2
    df['Low_Bid'] = data['bidlow']
    df['Low_Ask'] = data['asklow']
    df['Low'] = (data['bidlow']+data['asklow'])/2
    df['Close_Bid'] = data['bidclose']
    df['Close_Ask'] = data['askclose']
    df['Close'] = (data['bidclose']+data['askclose'])/2
    return(df)

def convert(devise,_rate,_flag):
    
    prix_usd = 0
    if x[4:] == 'USD':
        prix_usd = devise
    elif x[:3] == 'USD':
        prix_usd = round(devise/_rate,2)
    elif _flag == 1:
        prix_usd = round(devise * _rate,2)
       
    elif _flag == -1 :
            prix_usd = round(devise / _rate,2)
    else:
        prix_usd = 'NA'
    return(prix_usd,_flag)

engine.say("functions initiated")
engine.runAndWait()
print('Functions initiated')
# Out:
# Functions initiated

# %%
#########################
### CONNEXION A L'API ###
#########################

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor for FOR_EX\nLumberJack Jyss 5780(c)')
print(col.Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print(col.Fore.YELLOW,col.Back.BLUE,'--- Go!em STOCHASTIC-RSI #v0.15 ---',col.Style.RESET_ALL)

print('')
engine.say(" Initialisation du Gaulem Stok R S E")
engine.say("Connexion du Gaulem hà la Péh e")
engine.runAndWait()

try:
    con.is_connected() == True
    
    engine.say("already Connected")
    engine.runAndWait()
    print(col.Fore.GREEN+'Connexion rétablie'+col.Style.RESET_ALL)
    print('Compte utilisé : ',con.get_account_ids())
    print('')
    
except:
    try:
        con = conX()
        con.is_connected() == True
        print(col.Fore.GREEN+'Connexion établie'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
        engine.say("Connected")
        engine.runAndWait()
    except:
        print(col.Fore.RED+'Connexion non établie'+col.Style.RESET_ALL)
        engine.say("Not Connected, sal rass de mor, pitun cé la merd")
        engine.say("vérifi ton internet, é relance le gaulèm")
        engine.runAndWait()
        print('')
        #os._exit(0)
        con = deconX()
        time.sleep(1)
        con = conX()
# Out:
# Global Optimized LumberJack Environment Motor for FOR_EX
# LumberJack Jyss 5780(c)
#  °0Oo_D.A.G._26_oO0°
#   --- Go!em STOCHASTIC-RSI #v0.15 ---
#
# Connexion établie
# Compte utilisé :  [1215057]
# Connexion établie
# Compte utilisé :  [1215057]

# %%
DATE = []
CONTRACT = []
OPEN_POZ = []
CLOSE_POZ = []
RATE_OPEN_POZ = []
RATE_CLOSE_POZ = []
PNL_LAT = []
PNL_REAL = []
TOTAL_OPEN = []
TOTAL_CLOSE = []
PRICE_BUY = []
PRICE_SELL = []
DER_POZ = []
TOTAL_PNL_LAT = []
TOTAL_PNL_REAL = []

# %%
# %%time
df_resultats = pd.DataFrame(index=['TimeFrame 1','TimeFrame2','Equity','Nbre Winners','Nbre Loosers','Average lenght of trade','Cumul pnl'])

#TICKERS = con.get_instruments()
TICKERS = [ 'EUR/USD','USD/JPY','GBP/USD','USD/CHF','EUR/CHF','AUD/USD','USD/CAD','NZD/USD','EUR/GBP','EUR/JPY','GBP/JPY','CHF/JPY','GBP/CHF','EUR/AUD','EUR/CAD','AUD/CAD','AUD/JPY','CAD/JPY','NZD/JPY','GBP/CAD','GBP/NZD','GBP/AUD','AUD/NZD','USD/SEK','EUR/SEK','EUR/NOK','USD/NOK','USD/MXN','AUD/CHF','EUR/NZD','USD/ZAR','ZAR/JPY','NZD/CHF','CAD/CHF','NZD/CAD','USD/ILS','USD/CNH']

engine.say("קדימה")
engine.runAndWait()

for x in TICKERS:

    if x[4:] == 'USD':
        _rate = 1

    elif x[:3] == 'USD':
        con.subscribe_market_data(x)
        _rate = con.get_last_price(x).Bid
        con.unsubscribe_market_data(x)
    elif x[:3] != 'USD' and x[4:] != 'USD':
        try:
            con.subscribe_market_data(x[4:]+'/USD')
            _rate = con.get_last_price(x[4:]+'/USD').Bid
            con.unsubscribe_market_data(x[4:]+'/USD')
            _flag = 1
        except:
            con.subscribe_market_data('USD/'+x[4:])
            _rate = con.get_last_price('USD/'+x[4:]).Bid
            con.unsubscribe_market_data('USD/'+x[4:])
            _flag = -1
    else:
        prix_usd = 'NA'

    print(col.Fore.MAGENTA,'Le rate du ticker',x,'est à ',_rate,col.Style.RESET_ALL)

    data = scrap_hist(x,_number,_period)
    data2 = scrap_hist(x,_number,_period2)
    price = data.copy()
    price2 = data2.copy()
    _position = 0
    _equity = 0
    _nbtransactions = 0
    backtest_graph = pd.DataFrame()
    EQUITY = [_cash]
    CASH = [_cash]
    _winner = 0
    _looser = 0
    _index_entry = 0
    TRADE_DURATION = []
    _average_duration = 0
    _size = 50000

    PRICE_BUY = []
    PRICE_SELL = []
   
    _total = 0

    _target = 0.0020
    _sl = 0.0090
    _spread_filter = 0.00050
    _filtre_multipoz = 1 # En %
    _filtre_multipoz = _filtre_multipoz/100

    _open_buy = 0
    _open_sell = 0
    
    MM21 = talib.EMA(price.Close, timeperiod=21)
    rsi = talib.RSI(price.Close, timeperiod=14)
    rsi_high = 65
    rsi_low = 35
    upperband, middleband, lowerband = talib.BBANDS(price.Close, timeperiod=5, nbdevup=2, nbdevdn=2, matype=0)
    fastk, fastd = talib.STOCHRSI(price.Close, timeperiod=14, fastk_period=5, fastd_period=3, fastd_matype=0)#STOCHASTICRSI
    slowk, slowd = talib.STOCH(price.High, price.Low, price.Close, fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)#STOCHASTIC
    
    MM82 = talib.EMA(price2.Close, timeperiod=8)
    MM212 = talib.EMA(price2.Close, timeperiod=21)
    MM342 = talib.EMA(price2.Close, timeperiod=34)
    rsi2 = talib.RSI(price2.Close, timeperiod=14)
    upperband2, middleband2, lowerband2 = talib.BBANDS(price2.Close, timeperiod=5, nbdevup=2, nbdevdn=2, matype=0)
    fastk2, fastd2 = talib.STOCHRSI(price2.Close, timeperiod=14, fastk_period=5, fastd_period=3, fastd_matype=0)#STOCHASTICRSI
    slowk2, slowd2 = talib.STOCH(price2.High, price2.Low, price2.Close, fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)

    for i in range(25,len(price)):

        if _position == 0 :

            if slowk[i-1] > 80 and slowk[i-1] > slowd[i-1] and slowk[i] < slowd[i] and price.High[i-1] > price.High[i-2] and price.High[i] < price.High[i-2]:
                
                j = len(price2[price2.index <= price.index[i]])-1 
                    
                if  price2.Close[j] < MM82[j] and MM82[j]<MM212[j] and MM212[j] < MM342[j] \
                    and (price.Close_Ask[i]-price.Close_Bid[i])/price.Close_Ask[i] < _spread_filter:

                    print("Filtre de petite time frame passé, pour i=",i,"et un index à i de",str(price.index[i]))
                    print("Filtre de grosse time frame passé, pour j=",j,"et un index à j de",str(price2.index[j]))

                    sense ='bearish' 
                    
                    print(i)
                    _pnl = 0
                    _open_sell += 1
                    _equity = _cash + _pnl
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _index_entry = i
                    _position = -1
                    _nbtransactions += 1
                    price_sell = price.Close_Bid.iloc[i]
                    PRICE_SELL.append(price_sell)
                    _price_sell_mean = round(sum(PRICE_SELL)/len(PRICE_SELL),5)
                    print('Position 1 sold at', price_sell,'(verification liste',PRICE_SELL[-1],')')
                    print('Nouvelle moyenne du price_sell',_price_sell_mean)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(-1)
                    CLOSE_POZ.append(0)
                    RATE_OPEN_POZ.append(price_sell)
                    RATE_CLOSE_POZ.append(0) 
                    PNL_LAT.append(_pnl)
                    PNL_REAL.append(0)
                    TOTAL_PNL_LAT.append(_pnl)
                    TOTAL_PNL_REAL.append(0)

                    TOTAL_OPEN.append(1)
                        
                                
            elif slowk[i-1] < 20 and slowk[i-1] < slowd[i-1] and slowk[i] > slowd[i] and price.Low[i-1] < price.Low[i-2] and price.Low[i] > price.Low[i-2]:
                
                j = len(price2[price2.index <= price.index[i]])-1
                
                if price2.Close[j] > MM82[j] and MM82[j]>MM212[j] and MM212[j] > MM342[j] \
                    and (price.Close_Ask[i]-price.Close_Bid[i])/price.Close_Ask[i] < _spread_filter:

                    print("Filtre de petite time frame passé, pour i=",i,"et un index à i de",str(price.index[i]))
                    print("Filtre de grosse time frame passé, pour j=",j,"et un index à j de",str(price2.index[j]))
                    
                    sense = 'bullish'

                    print(i)
                    _pnl = 0
                    _open_buy += 1
                    _equity = _cash + _pnl
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _position = 1
                    _index_entry = i
                    _nbtransactions += 1
                    price_buy = price.Close_Ask.iloc[i]
                    PRICE_BUY.append(price_buy)
                    _price_buy_mean = round(sum(PRICE_BUY)/len(PRICE_BUY),5)
                    print('Position 1 bought at', price_buy,'(verification liste',PRICE_BUY[-1],')')
                    print('Nouvelle moyenne du price_buy',_price_buy_mean)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(1)
                    CLOSE_POZ.append(0)
                    RATE_OPEN_POZ.append(price_buy)
                    RATE_CLOSE_POZ.append(0)
                    PNL_LAT.append(_pnl)
                    PNL_REAL.append(0)
                    TOTAL_OPEN.append(1) 
                    TOTAL_PNL_LAT.append(_pnl)
                    TOTAL_PNL_REAL.append(0) 

            else :
                _pnl = 0
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)
            
        
        elif _position == 1:

            if slowk[i-1] < 20 and slowk[i-1] < slowd[i-1] and slowk[i] > slowd[i] and price.Low[i-1] < price.Low[i-2] and price.Low[i] > price.Low[i-2]\
                and price.Close_Bid.iloc[i] <= (price_buy * (1 + _filtre_multipoz)):
                
                j = len(price2[price2.index <= price.index[i]])-1
                
                if price2.Close[j] > MM82[j] and MM82[j]>MM212[j] and MM212[j] > MM342[j] \
                    and (price.Close_Ask[i]-price.Close_Bid[i])/price.Close_Ask[i] < _spread_filter:

                    print("Filtre de petite time frame passé, pour i=",i,"et un index à i de",str(price.index[i]))
                    print("Filtre de grosse time frame passé, pour j=",j,"et un index à j de",str(price2.index[j]))
                    
                    sense = 'bullish'

                    print(i)
                    _pnl = 0
                    _open_buy += 1
                    _equity = _cash + _pnl
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _position = 1
                    _index_entry = i
                    _nbtransactions += 1
                    price_buy = price.Close_Ask.iloc[i]
                    PRICE_BUY.append(price_buy)
                    _price_buy_mean = round(sum(PRICE_BUY)/len(PRICE_BUY),5)
                    print('Position',_open_buy,'bought at', price_buy,'(verification liste',PRICE_BUY[-1],')')
                    print('Nouvelle moyenne du price_buy',_price_buy_mean)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(1)
                    CLOSE_POZ.append(0)
                    RATE_OPEN_POZ.append(price_buy)
                    RATE_CLOSE_POZ.append(0)
                    PNL_LAT.append(_pnl)
                    PNL_REAL.append(0)
                    TOTAL_OPEN.append(1) 
                    TOTAL_PNL_LAT.append(_pnl)
                    TOTAL_PNL_REAL.append(0) 

            #else :
             #   _pnl = 0
              #  _equity = _cash + _pnl
               # EQUITY.append(_equity)
                #CASH.append(_cash)

            if (float(price.Close_Bid.iloc[i]) - float(_price_buy_mean))/float(_price_buy_mean) >= _target :#slowd[i]>80:
                _position = 0
                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _winner += _open_buy
                
                TRADE_DURATION.append(i - _index_entry)
                print(i)
                print(_open_buy,'positions TP closed at',price.Close_Bid.iloc[i],col.Fore.GREEN,'pnl', _pnl,col.Style.RESET_ALL)
                print('nombre de candles en position :',i - _index_entry)
                print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_buy)
                PRICE_BUY = [] 
                _open_buy = 0
            
            elif (float(price.Close_Bid.iloc[i]) - float(_price_buy_mean))/float(_price_buy_mean) <= -_sl :
                _position = 0
                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_buy
                
                TRADE_DURATION.append(i - _index_entry)
                print(i)
                print(_open_buy,'positions SL closed at',price.Close_Bid.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                print('nombre de candles en position :',i - _index_entry)
                print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_buy) 
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                PRICE_BUY = []
                _open_buy = 0

            else:
                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_PNL_LAT.append(_pnl)
                TOTAL_PNL_REAL.append(0) 

            
        
        elif _position == -1:

                if slowk[i-1] > 80 and slowk[i-1] > slowd[i-1] and slowk[i] < slowd[i] and price.High[i-1] > price.High[i-2]\
                     and price.High[i] < price.High[i-2] and price.Close_Bid.iloc[i] >= (price_sell * (1 - _filtre_multipoz)) :
                
                    j = len(price2[price2.index <= price.index[i]])-1
                        
                    if  price2.Close[j] < MM82[j] and MM82[j]<MM212[j] and MM212[j] < MM342[j] \
                        and (price.Close_Ask[i]-price.Close_Bid[i])/price.Close_Ask[i] < _spread_filter:

                        print("Filtre de petite time frame passé, pour i=",i,"et un index à i de",str(price.index[i]))
                        print("Filtre de grosse time frame passé, pour j=",j,"et un index à j de",str(price2.index[j]))

                        sense ='bearish' 
                        
                        print(i)
                        _pnl = 0
                        _open_sell += 1
                        _equity = _cash + _pnl
                        EQUITY.append(_equity)
                        CASH.append(_cash)
                        _index_entry = i
                        _position = -1
                        _nbtransactions += 1
                        price_sell = price.Close_Bid.iloc[i]
                        PRICE_SELL.append(price_sell)
                        _price_sell_mean = round(sum(PRICE_SELL)/len(PRICE_SELL),5)
                        print('sold at', price_sell,'(verification liste',PRICE_SELL[-1],')')
                        print('Nouvelle moyenne du price_sell',_price_sell_mean)

                        DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                        CONTRACT.append(x)
                        OPEN_POZ.append(-1)
                        CLOSE_POZ.append(0)
                        RATE_OPEN_POZ.append(price_sell)
                        RATE_CLOSE_POZ.append(0) 
                        PNL_LAT.append(_pnl)
                        PNL_REAL.append(0)
                        TOTAL_PNL_LAT.append(_pnl)
                        TOTAL_PNL_REAL.append(0)

                        TOTAL_OPEN.append(1)

                #else :
                 #   _pnl = 0
                  #  _equity = _cash + _pnl
                   # EQUITY.append(_equity)
                    #CASH.append(_cash)    
            
                if (float(price.Close_Ask.iloc[i]) - float(_price_sell_mean))/float(_price_sell_mean) <= -_target :
                    _position = 0
                    _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _total += _pnl
                    _cash += _pnl
                    _equity = _cash
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _winner += _open_sell
                    TRADE_DURATION.append(i - _index_entry)
                    print(i)
                    print(_open_sell,'positions TP closed at',price.Close_Ask.iloc[i],col.Fore.GREEN,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(0)
                    CLOSE_POZ.append(-1)
                    RATE_OPEN_POZ.append(0)
                    RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                    PNL_LAT.append(0)
                    PNL_REAL.append(_pnl)
                    TOTAL_PNL_LAT.append(0)
                    TOTAL_PNL_REAL.append(_pnl)
                    TOTAL_CLOSE.append(_open_sell)
                    PRICE_SELL = [] 
                    _open_sell = 0
                
                elif (float(price.Close_Ask.iloc[i]) - float(_price_sell_mean))/float(_price_sell_mean) >= _sl :
                    _position = 0
                    _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _total += _pnl
                    _cash += _pnl
                    _equity = _cash
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _looser += _open_sell
                    TRADE_DURATION.append(i - _index_entry)
                    print(i)
                    print(_open_sell,'position SL closed at',price.Close_Bid.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(0)
                    CLOSE_POZ.append(-1)
                    RATE_OPEN_POZ.append(0)
                    RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                    PNL_LAT.append(0)
                    PNL_REAL.append(_pnl)
                    TOTAL_PNL_LAT.append(0)
                    TOTAL_PNL_REAL.append(_pnl)
                    TOTAL_CLOSE.append(_open_sell)
                    PRICE_SELL = []
                    _open_sell = 0
                
                else:
                    _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _equity = _cash + _pnl
        
                    EQUITY.append(_equity)
                    CASH.append(_cash)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(0)
                    CLOSE_POZ.append(0)
                    RATE_OPEN_POZ.append(0)
                    RATE_CLOSE_POZ.append(0)
                    PNL_LAT.append(_pnl)
                    PNL_REAL.append(0)
                    TOTAL_PNL_LAT.append(_pnl)
                    TOTAL_PNL_REAL.append(0)

    try:
        _average_duration = round(statistics.mean(TRADE_DURATION),2)
    
    except:
        print("(pas de duration)") 
        _average_duration = 'NA'               
    print(col.Fore.MAGENTA,"\nLes gains faramineux s'élèvent à : $",col.Fore.GREEN,round(_total,2),'!. En ',_nbtransactions,' transactions.',col.Style.RESET_ALL ) 
    print(col.Fore.GREEN,"\nNbre de winners :",_winner,col.Style.RESET_ALL)
    print(col.Fore.RED,"\nNbre de loosers :",_looser,col.Style.RESET_ALL)
    print("\nAverage trade duration ",_average_duration)
    backtest_graph['Equity'] = EQUITY
    
    df_resultats[x] = [_period,_period2,(round(_equity,2)),(_winner),(_looser),(_average_duration),(_total)]

    print('Total des gains faramineux :',round(EQUITY[-1] - _cash_ini,2))
    print('Pnl latent restant',_pnl,'Open Buy',_open_buy,'Open Sell',_open_sell)
    DER_POZ.append(_pnl)
    

try:
    os.mkdir('Period_'+_period+'_Period2_'+_period2+'_target_'+str(_target)+'_sl_'+str(_sl)+'_rsiHigh'+str(rsi_high)+'_rsiLow_'+str(rsi_low)+'/')
except:
    pass

df_resultats.T.to_csv('Period_'+_period+'_Period2_'+_period2+'_target_'+str(_target)+'_sl_'+str(_sl)+'_rsiHigh'+str(rsi_high)+'_rsiLow_'+str(rsi_low)+'/pnl_'+str(_total)+'.csv')
    
engine.say("The job is done. Check, we are billionaire")
engine.runAndWait()
# Out:
#  Le rate du ticker EUR/USD est à  1
#  Scraping des données OHLC pour le ticker  EUR/USD
#  Scraping des données OHLC pour le ticker  EUR/USD
# Filtre de petite time frame passé, pour i= 208 et un index à i de 2020-07-17 19:10:00
# Filtre de grosse time frame passé, pour j= 5426 et un index à j de 2020-07-16 21:00:00
# 208
# Position 1 bought at 1.144 (verification liste 1.144 )
# Nouvelle moyenne du price_buy 1.144
# Filtre de petite time frame passé, pour i= 217 et un index à i de 2020-07-17 19:55:00
# Filtre de grosse time frame passé, pour j= 5426 et un index à j de 2020-07-16 21:00:00
# 217
# Position 2 bought at 1.14405 (verification liste 1.14405 )
# Nouvelle moyenne du price_buy 1.14402
# Filtre de petite time frame passé, pour i= 262 et un index à i de 2020-07-19 22:00:00
# Filtre de grosse time frame passé, pour j= 5428 et un index à j de 2020-07-19 21:00:00
# 262
# Position 3 bought at 1.14242 (verification liste 1.14242 )
# Nouvelle moyenne du price_buy 1.14349
# 358
# 3 positions TP closed at 1.1462  pnl 406.50000000003183
# nombre de candles en position : 96
# Equity : 200406.50000000003
# Filtre de petite time frame passé, pour i= 396 et un index à i de 2020-07-20 09:10:00
# Filtre de grosse time frame passé, pour j= 5428 et un index à j de 2020-07-19 21:00:00
# 396
# Position 1 bought at 1.14593 (verification liste 1.14593 )
# Nouvelle moyenne du price_buy 1.14593
# Filtre de petite time frame passé, pour i= 432 et un index à i de 2020-07-20 12:10:00
# Filtre de grosse time frame passé, pour j= 5428 et un index à j de 2020-07-19 21:00:00
# 432
# Position 2 bought at 1.14489 (verification liste 1.14489 )
# Nouvelle moyenne du price_buy 1.14541
# Filtre de petite time frame passé, pour i= 485 et un index à i de 2020-07-20 16:35:00
# Filtre de grosse time frame passé, pour j= 5428 et un index à j de 2020-07-19 21:00:00
# 485
# Position 3 bought at 1.144 (verification liste 1.144 )
# Nouvelle moyenne du price_buy 1.14494
# Filtre de petite time frame passé, pour i= 628 et un index à i de 2020-07-21 04:30:00
# Filtre de grosse time frame passé, pour j= 5429 et un index à j de 2020-07-20 21:00:00
# 628
# Position 4 bought at 1.1434 (verification liste 1.1434 )
# Nouvelle moyenne du price_buy 1.14456
# 745
# 4 positions TP closed at 1.14741  pnl 570.0000000000039
# nombre de candles en position : 117
# Equity : 200976.50000000003
# Filtre de petite time frame passé, pour i= 820 et un index à i de 2020-07-21 20:30:00
# Filtre de grosse time frame passé, pour j= 5429 et un index à j de 2020-07-20 21:00:00
# 820
# Position 1 bought at 1.15229 (verification liste 1.15229 )
# Nouvelle moyenne du price_buy 1.15229
# Filtre de petite time frame passé, pour i= 904 et un index à i de 2020-07-22 03:30:00
# Filtre de grosse time frame passé, pour j= 5430 et un index à j de 2020-07-21 21:00:00
# 904
# Position 2 bought at 1.1543 (verification liste 1.1543 )
# Nouvelle moyenne du price_buy 1.1533
# 983
# 2 positions TP closed at 1.15625  pnl 295.0000000000008
# nombre de candles en position : 79
# Equity : 201271.50000000003
# Filtre de petite time frame passé, pour i= 1156 et un index à i de 2020-07-23 00:30:00
# Filtre de grosse time frame passé, pour j= 5431 et un index à j de 2020-07-22 21:00:00
# 1156
# Position 1 bought at 1.15681 (verification liste 1.15681 )
# Nouvelle moyenne du price_buy 1.15681
# 1234
# 1 positions TP closed at 1.15929  pnl 124.00000000000189
# nombre de candles en position : 78
# Equity : 201395.50000000003
# Filtre de petite time frame passé, pour i= 1307 et un index à i de 2020-07-23 13:05:00
# Filtre de grosse time frame passé, pour j= 5431 et un index à j de 2020-07-22 21:00:00
# 1307
# Position 1 bought at 1.15555 (verification liste 1.15555 )
# Nouvelle moyenne du price_buy 1.15555
# 1316
# 1 positions TP closed at 1.15795  pnl 119.99999999999788
# nombre de candles en position : 9
# Equity : 201515.50000000003
# Filtre de petite time frame passé, pour i= 1399 et un index à i de 2020-07-23 20:45:00
# Filtre de grosse time frame passé, pour j= 5431 et un index à j de 2020-07-22 21:00:00
# 1399
# Position 1 bought at 1.15941 (verification liste 1.15941 )
# Nouvelle moyenne du price_buy 1.15941
# Filtre de petite time frame passé, pour i= 1431 et un index à i de 2020-07-23 23:25:00
# Filtre de grosse time frame passé, pour j= 5432 et un index à j de 2020-07-23 21:00:00
# 1431
# Position 2 bought at 1.15998 (verification liste 1.15998 )
# Nouvelle moyenne du price_buy 1.1597
# 1531
# 2 positions TP closed at 1.16203  pnl 232.99999999999432
# nombre de candles en position : 100
# Equity : 201748.50000000003
# Filtre de petite time frame passé, pour i= 1545 et un index à i de 2020-07-24 08:55:00
# Filtre de grosse time frame passé, pour j= 5432 et un index à j de 2020-07-23 21:00:00
# 1545
# Position 1 bought at 1.16009 (verification liste 1.16009 )
# Nouvelle moyenne du price_buy 1.16009
# 1611
# 1 positions TP closed at 1.16269  pnl 129.9999999999968
# nombre de candles en position : 66
# Equity : 201878.50000000003
# Filtre de petite time frame passé, pour i= 1728 et un index à i de 2020-07-26 22:15:00
# Filtre de grosse time frame passé, pour j= 5434 et un index à j de 2020-07-26 21:00:00
# 1728
# Position 1 bought at 1.16453 (verification liste 1.16453 )
# Nouvelle moyenne du price_buy 1.16453
# 1754
# 1 positions TP closed at 1.16694  pnl 120.50000000000117
# nombre de candles en position : 26
# Equity : 201999.00000000003
# Filtre de petite time frame passé, pour i= 1775 et un index à i de 2020-07-27 02:10:00
# Filtre de grosse time frame passé, pour j= 5434 et un index à j de 2020-07-26 21:00:00
# 1775
# Position 1 bought at 1.16941 (verification liste 1.16941 )
# Nouvelle moyenne du price_buy 1.16941
# Filtre de petite time frame passé, pour i= 1835 et un index à i de 2020-07-27 07:10:00
# Filtre de grosse time frame passé, pour j= 5434 et un index à j de 2020-07-26 21:00:00
# 1835
# Position 2 bought at 1.17105 (verification liste 1.17105 )
# Nouvelle moyenne du price_buy 1.17023
# 1874
# 2 positions TP closed at 1.17305  pnl 281.99999999998226
# nombre de candles en position : 39
# Equity : 202281.0
# Filtre de petite time frame passé, pour i= 2045 et un index à i de 2020-07-28 00:40:00
# Filtre de grosse time frame passé, pour j= 5435 et un index à j de 2020-07-27 21:00:00
# 2045
# Position 1 bought at 1.17652 (verification liste 1.17652 )
# Nouvelle moyenne du price_buy 1.17652
# 2542
# 1 positions TP closed at 1.17942  pnl 144.99999999999514
# nombre de candles en position : 497
# Equity : 202426.0
# Filtre de petite time frame passé, pour i= 2581 et un index à i de 2020-07-29 21:20:00
# Filtre de grosse time frame passé, pour j= 5437 et un index à j de 2020-07-29 21:00:00
# 2581
# Position 1 bought at 1.1792 (verification liste 1.1792 )
# Nouvelle moyenne du price_buy 1.1792
# Filtre de petite time frame passé, pour i= 2639 et un index à i de 2020-07-30 02:10:00
# Filtre de grosse time frame passé, pour j= 5437 et un index à j de 2020-07-29 21:00:00
# 2639
# Position 2 bought at 1.17704 (verification liste 1.17704 )
# Nouvelle moyenne du price_buy 1.17812
# Filtre de petite time frame passé, pour i= 2742 et un index à i de 2020-07-30 10:45:00
# Filtre de grosse time frame passé, pour j= 5437 et un index à j de 2020-07-29 21:00:00
# 2742
# Position 3 bought at 1.17514 (verification liste 1.17514 )
# Nouvelle moyenne du price_buy 1.17713
# 2775
# 3 positions TP closed at 1.1796  pnl 370.4999999999958
# nombre de candles en position : 33
# Equity : 202796.5
# Filtre de petite time frame passé, pour i= 2939 et un index à i de 2020-07-31 03:10:00
# Filtre de grosse time frame passé, pour j= 5438 et un index à j de 2020-07-30 21:00:00
# 2939
# Position 1 bought at 1.189 (verification liste 1.189 )
# Nouvelle moyenne du price_buy 1.189
# Filtre de petite time frame passé, pour i= 2989 et un index à i de 2020-07-31 07:20:00
# Filtre de grosse time frame passé, pour j= 5438 et un index à j de 2020-07-30 21:00:00
# 2989
# Position 2 bought at 1.1892 (verification liste 1.1892 )
# Nouvelle moyenne du price_buy 1.1891
# Filtre de petite time frame passé, pour i= 3065 et un index à i de 2020-07-31 13:40:00
# Filtre de grosse time frame passé, pour j= 5438 et un index à j de 2020-07-30 21:00:00
# 3065
# Position 3 bought at 1.18199 (verification liste 1.18199 )
# Nouvelle moyenne du price_buy 1.18673
# 3212
# 3 positions SL closed at 1.1754  pnl -1699.500000000009
# nombre de candles en position : 147
# Equity : 201097.0
# Filtre de petite time frame passé, pour i= 3410 et un index à i de 2020-08-03 16:45:00
# Filtre de grosse time frame passé, pour j= 5440 et un index à j de 2020-08-02 21:00:00
# 3410
# Position 1 bought at 1.17447 (verification liste 1.17447 )
# Nouvelle moyenne du price_buy 1.17447
# Filtre de petite time frame passé, pour i= 3501 et un index à i de 2020-08-04 00:20:00
# Filtre de grosse time frame passé, pour j= 5441 et un index à j de 2020-08-03 21:00:00
# 3501
# Position 2 bought at 1.17563 (verification liste 1.17563 )
# Nouvelle moyenne du price_buy 1.17505
# 3557
# 2 positions TP closed at 1.17747  pnl 242.00000000000887
# nombre de candles en position : 56
# Equity : 201339.0
# Filtre de petite time frame passé, pour i= 3566 et un index à i de 2020-08-04 05:45:00
# Filtre de grosse time frame passé, pour j= 5441 et un index à j de 2020-08-03 21:00:00
# 3566
# Position 1 bought at 1.17683 (verification liste 1.17683 )
# Nouvelle moyenne du price_buy 1.17683
# 3586
# 1 positions TP closed at 1.17938  pnl 127.50000000000261
# nombre de candles en position : 20
# Equity : 201466.5
# Filtre de petite time frame passé, pour i= 3601 et un index à i de 2020-08-04 08:40:00
# Filtre de grosse time frame passé, pour j= 5441 et un index à j de 2020-08-03 21:00:00
# 3601
# Position 1 bought at 1.17826 (verification liste 1.17826 )
# Nouvelle moyenne du price_buy 1.17826
# 3783
# 1 positions TP closed at 1.18079  pnl 126.49999999999606
# nombre de candles en position : 182
# Equity : 201593.0
# Filtre de petite time frame passé, pour i= 3858 et un index à i de 2020-08-05 06:05:00
# Filtre de grosse time frame passé, pour j= 5442 et un index à j de 2020-08-04 21:00:00
# 3858
# Position 1 bought at 1.18069 (verification liste 1.18069 )
# Nouvelle moyenne du price_buy 1.18069
# 3891
# 1 positions TP closed at 1.18386  pnl 158.49999999999477
# nombre de candles en position : 33
# Equity : 201751.5
# Filtre de petite time frame passé, pour i= 4001 et un index à i de 2020-08-05 18:00:00
# Filtre de grosse time frame passé, pour j= 5442 et un index à j de 2020-08-04 21:00:00
# 4001
# Position 1 bought at 1.18674 (verification liste 1.18674 )
# Nouvelle moyenne du price_buy 1.18674
# 4146
# 1 positions TP closed at 1.19101  pnl 213.4999999999998
# nombre de candles en position : 145
# Equity : 201965.0
# Filtre de petite time frame passé, pour i= 4155 et un index à i de 2020-08-06 06:50:00
# Filtre de grosse time frame passé, pour j= 5443 et un index à j de 2020-08-05 21:00:00
# 4155
# Position 1 bought at 1.18784 (verification liste 1.18784 )
# Nouvelle moyenne du price_buy 1.18784
# Filtre de petite time frame passé, pour i= 4164 et un index à i de 2020-08-06 07:35:00
# Filtre de grosse time frame passé, pour j= 5443 et un index à j de 2020-08-05 21:00:00
# 4164
# Position 2 bought at 1.18632 (verification liste 1.18632 )
# Nouvelle moyenne du price_buy 1.18708
# 4529
# 2 positions SL closed at 1.17634  pnl -1073.9999999999973
# nombre de candles en position : 365
# Equity : 200891.0
# Filtre de petite time frame passé, pour i= 5293 et un index à i de 2020-08-12 04:35:00
# Filtre de grosse time frame passé, pour j= 5448 et un index à j de 2020-08-11 21:00:00
# 5293
# Position 1 bought at 1.17178 (verification liste 1.17178 )
# Nouvelle moyenne du price_buy 1.17178
# 5329
# 1 positions TP closed at 1.17446  pnl 134.0000000000008
# nombre de candles en position : 36
# Equity : 201025.0
# Filtre de petite time frame passé, pour i= 5423 et un index à i de 2020-08-12 15:25:00
# Filtre de grosse time frame passé, pour j= 5448 et un index à j de 2020-08-11 21:00:00
# 5423
# Position 1 bought at 1.17951 (verification liste 1.17951 )
# Nouvelle moyenne du price_buy 1.17951
# 5597
# 1 positions TP closed at 1.18232  pnl 140.49999999999895
# nombre de candles en position : 174
# Equity : 201165.5
# Filtre de petite time frame passé, pour i= 5637 et un index à i de 2020-08-13 09:20:00
# Filtre de grosse time frame passé, pour j= 5449 et un index à j de 2020-08-12 21:00:00
# 5637
# Position 1 bought at 1.18349 (verification liste 1.18349 )
# Nouvelle moyenne du price_buy 1.18349
# 5690
# 1 positions TP closed at 1.18592  pnl 121.50000000000772
# nombre de candles en position : 53
# Equity : 201287.0
# Filtre de petite time frame passé, pour i= 5795 et un index à i de 2020-08-13 22:30:00
# Filtre de grosse time frame passé, pour j= 5450 et un index à j de 2020-08-13 21:00:00
# 5795
# Position 1 bought at 1.18157 (verification liste 1.18157 )
# Nouvelle moyenne du price_buy 1.18157
# Filtre de petite time frame passé, pour i= 5958 et un index à i de 2020-08-14 12:05:00
# Filtre de grosse time frame passé, pour j= 5450 et un index à j de 2020-08-13 21:00:00
# 5958
# Position 2 bought at 1.18142 (verification liste 1.18142 )
# Nouvelle moyenne du price_buy 1.1815
# 6013
# 2 positions TP closed at 1.18439  pnl 289.0000000000059
# nombre de candles en position : 55
# Equity : 201576.0
# Filtre de petite time frame passé, pour i= 6026 et un index à i de 2020-08-14 17:45:00
# Filtre de grosse time frame passé, pour j= 5450 et un index à j de 2020-08-13 21:00:00
# 6026
# Position 1 bought at 1.18408 (verification liste 1.18408 )
# Nouvelle moyenne du price_buy 1.18408
# 6181
# 1 positions TP closed at 1.18667  pnl 129.49999999999352
# nombre de candles en position : 155
# Equity : 201705.5
# Filtre de petite time frame passé, pour i= 6307 et un index à i de 2020-08-17 16:30:00
# Filtre de grosse time frame passé, pour j= 5452 et un index à j de 2020-08-16 21:00:00
# 6307
# Position 1 bought at 1.1858 (verification liste 1.1858 )
# Nouvelle moyenne du price_buy 1.1858
# 6406
# 1 positions TP closed at 1.18889  pnl 154.50000000000185
# nombre de candles en position : 99
# Equity : 201860.0
# Filtre de petite time frame passé, pour i= 6605 et un index à i de 2020-08-18 17:20:00
# Filtre de grosse time frame passé, pour j= 5453 et un index à j de 2020-08-17 21:00:00
# 6605
# Position 1 bought at 1.1935 (verification liste 1.1935 )
# Nouvelle moyenne du price_buy 1.1935
# Filtre de petite time frame passé, pour i= 6615 et un index à i de 2020-08-18 18:10:00
# Filtre de grosse time frame passé, pour j= 5453 et un index à j de 2020-08-17 21:00:00
# 6615
# Position 2 bought at 1.19323 (verification liste 1.19323 )
# Nouvelle moyenne du price_buy 1.19336
# Filtre de petite time frame passé, pour i= 6968 et un index à i de 2020-08-19 23:35:00
# Filtre de grosse time frame passé, pour j= 5455 et un index à j de 2020-08-19 21:00:00
# 6968
# Position 3 bought at 1.1849 (verification liste 1.1849 )
# Nouvelle moyenne du price_buy 1.19054
# Filtre de petite time frame passé, pour i= 7007 et un index à i de 2020-08-20 02:50:00
# Filtre de grosse time frame passé, pour j= 5455 et un index à j de 2020-08-19 21:00:00
# 7007
# Position 4 bought at 1.18424 (verification liste 1.18424 )
# Nouvelle moyenne du price_buy 1.18897
# Filtre de petite time frame passé, pour i= 7174 et un index à i de 2020-08-20 16:45:00
# Filtre de grosse time frame passé, pour j= 5455 et un index à j de 2020-08-19 21:00:00
# 7174
# Position 5 bought at 1.1854 (verification liste 1.1854 )
# Nouvelle moyenne du price_buy 1.18825
# 7404
# 5 positions SL closed at 1.17739  pnl -2715.0000000000227
# nombre de candles en position : 230
# Equity : 199144.99999999997
# Filtre de petite time frame passé, pour i= 8103 et un index à i de 2020-08-25 21:55:00
# Filtre de grosse time frame passé, pour j= 5460 et un index à j de 2020-08-25 21:00:00
# 8103
# Position 1 bought at 1.18361 (verification liste 1.18361 )
# Nouvelle moyenne du price_buy 1.18361
# Filtre de petite time frame passé, pour i= 8192 et un index à i de 2020-08-26 05:20:00
# Filtre de grosse time frame passé, pour j= 5460 et un index à j de 2020-08-25 21:00:00
# 8192
# Position 2 bought at 1.18117 (verification liste 1.18117 )
# Nouvelle moyenne du price_buy 1.18239
# Filtre de petite time frame passé, pour i= 8226 et un index à i de 2020-08-26 08:10:00
# Filtre de grosse time frame passé, pour j= 5460 et un index à j de 2020-08-25 21:00:00
# 8226
# Position 3 bought at 1.18129 (verification liste 1.18129 )
# Nouvelle moyenne du price_buy 1.18202
# Filtre de petite time frame passé, pour i= 8256 et un index à i de 2020-08-26 10:40:00
# Filtre de grosse time frame passé, pour j= 5460 et un index à j de 2020-08-25 21:00:00
# 8256
# Position 4 bought at 1.18129 (verification liste 1.18129 )
# Nouvelle moyenne du price_buy 1.18184
# Filtre de petite time frame passé, pour i= 8348 et un index à i de 2020-08-26 18:20:00
# Filtre de grosse time frame passé, pour j= 5460 et un index à j de 2020-08-25 21:00:00
# 8348
# Position 5 bought at 1.18239 (verification liste 1.18239 )
# Nouvelle moyenne du price_buy 1.18195
# 8428
# 5 positions TP closed at 1.18462  pnl 667.4999999999875
# nombre de candles en position : 80
# Equity : 199812.49999999997
# Filtre de petite time frame passé, pour i= 8707 et un index à i de 2020-08-28 00:15:00
# Filtre de grosse time frame passé, pour j= 5462 et un index à j de 2020-08-27 21:00:00
# 8707
# Position 1 bought at 1.18178 (verification liste 1.18178 )
# Nouvelle moyenne du price_buy 1.18178
# 8743
# 1 positions TP closed at 1.18424  pnl 122.99999999999534
# nombre de candles en position : 36
# Equity : 199935.49999999997
# Filtre de petite time frame passé, pour i= 9207 et un index à i de 2020-08-31 17:45:00
# Filtre de grosse time frame passé, pour j= 5464 et un index à j de 2020-08-30 21:00:00
# 9207
# Position 1 bought at 1.1944 (verification liste 1.1944 )
# Nouvelle moyenne du price_buy 1.1944
# Filtre de petite time frame passé, pour i= 9264 et un index à i de 2020-08-31 22:35:00
# Filtre de grosse time frame passé, pour j= 5465 et un index à j de 2020-08-31 21:00:00
# 9264
# Position 2 bought at 1.19391 (verification liste 1.19391 )
# Nouvelle moyenne du price_buy 1.19415
# Filtre de petite time frame passé, pour i= 9281 et un index à i de 2020-09-01 00:00:00
# Filtre de grosse time frame passé, pour j= 5465 et un index à j de 2020-08-31 21:00:00
# 9281
# Position 3 bought at 1.1944 (verification liste 1.1944 )
# Nouvelle moyenne du price_buy 1.19424
# 9304
# 3 positions TP closed at 1.19701  pnl 415.4999999999909
# nombre de candles en position : 23
# Equity : 200350.99999999997
# Filtre de petite time frame passé, pour i= 9360 et un index à i de 2020-09-01 06:35:00
# Filtre de grosse time frame passé, pour j= 5465 et un index à j de 2020-08-31 21:00:00
# 9360
# Position 1 bought at 1.19858 (verification liste 1.19858 )
# Nouvelle moyenne du price_buy 1.19858
# Filtre de petite time frame passé, pour i= 9369 et un index à i de 2020-09-01 07:20:00
# Filtre de grosse time frame passé, pour j= 5465 et un index à j de 2020-08-31 21:00:00
# 9369
# Position 2 bought at 1.19714 (verification liste 1.19714 )
# Nouvelle moyenne du price_buy 1.19786
# 9659
# 2 positions SL closed at 1.18653  pnl -1132.999999999984
# nombre de candles en position : 290
# Equity : 199218.0
#
# Les gains faramineux s'élèvent à : $  -782.0 !. En  55  transactions.
#
# Nbre de winners : 43
#
# Nbre de loosers : 12
#
# Average trade duration  114.45
# Total des gains faramineux : -782.0
# Pnl latent restant 0 Open Buy 0 Open Sell 0
#  Le rate du ticker USD/JPY est à  106.481
#  Scraping des données OHLC pour le ticker  USD/JPY
#  Scraping des données OHLC pour le ticker  USD/JPY
# Filtre de petite time frame passé, pour i= 239 et un index à i de 2020-07-17 12:55:00
# Filtre de grosse time frame passé, pour j= 5412 et un index à j de 2020-07-16 21:00:00
# 239
# Position 1 sold at 107.234 (verification liste 107.234 )
# Nouvelle moyenne du price_sell 107.234
# 286
# 1 positions TP closed at 107.019  pnl 100.96
# nombre de candles en position : 47
# Equity : 199318.96
# Filtre de petite time frame passé, pour i= 767 et un index à i de 2020-07-21 09:05:00
# Filtre de grosse time frame passé, pour j= 5414 et un index à j de 2020-07-20 21:00:00
# 767
# Position 1 sold at 107.273 (verification liste 107.273 )
# Nouvelle moyenne du price_sell 107.273
# Filtre de petite time frame passé, pour i= 794 et un index à i de 2020-07-21 11:20:00
# Filtre de grosse time frame passé, pour j= 5414 et un index à j de 2020-07-20 21:00:00
# 794
# sold at 107.282 (verification liste 107.282 )
# Nouvelle moyenne du price_sell 107.2775
# 823
# 2 positions TP closed at 107.049  pnl 214.59
# nombre de candles en position : 29
# Equity : 199533.55
# Filtre de petite time frame passé, pour i= 1227 et un index à i de 2020-07-22 23:25:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-07-22 21:00:00
# 1227
# Position 1 sold at 107.172 (verification liste 107.172 )
# Nouvelle moyenne du price_sell 107.172
# Filtre de petite time frame passé, pour i= 1254 et un index à i de 2020-07-23 01:40:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-07-22 21:00:00
# 1254
# sold at 107.115 (verification liste 107.115 )
# Nouvelle moyenne du price_sell 107.1435
# Filtre de petite time frame passé, pour i= 1403 et un index à i de 2020-07-23 14:25:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-07-22 21:00:00
# 1403
# sold at 107.101 (verification liste 107.101 )
# Nouvelle moyenne du price_sell 107.12933
# 1416
# 3 positions TP closed at 106.902  pnl 320.24
# nombre de candles en position : 13
# Equity : 199853.78999999998
# Filtre de petite time frame passé, pour i= 2108 et un index à i de 2020-07-27 23:30:00
# Filtre de grosse time frame passé, pour j= 5420 et un index à j de 2020-07-27 21:00:00
# 2108
# Position 1 sold at 105.348 (verification liste 105.348 )
# Nouvelle moyenne du price_sell 105.348
# Filtre de petite time frame passé, pour i= 2125 et un index à i de 2020-07-28 00:55:00
# Filtre de grosse time frame passé, pour j= 5420 et un index à j de 2020-07-27 21:00:00
# 2125
# sold at 105.322 (verification liste 105.322 )
# Nouvelle moyenne du price_sell 105.335
# Filtre de petite time frame passé, pour i= 2162 et un index à i de 2020-07-28 04:00:00
# Filtre de grosse time frame passé, pour j= 5420 et un index à j de 2020-07-27 21:00:00
# 2162
# sold at 105.543 (verification liste 105.543 )
# Nouvelle moyenne du price_sell 105.40433
# 2235
# 3 positions TP closed at 105.176  pnl 321.65
# nombre de candles en position : 73
# Equity : 200175.43999999997
# Filtre de petite time frame passé, pour i= 2325 et un index à i de 2020-07-28 17:40:00
# Filtre de grosse time frame passé, pour j= 5420 et un index à j de 2020-07-27 21:00:00
# 2325
# Position 1 sold at 105.052 (verification liste 105.052 )
# Nouvelle moyenne du price_sell 105.052
# 2489
# 1 positions TP closed at 104.827  pnl 105.65
# nombre de candles en position : 164
# Equity : 200281.08999999997
# Filtre de petite time frame passé, pour i= 2541 et un index à i de 2020-07-29 12:10:00
# Filtre de grosse time frame passé, pour j= 5421 et un index à j de 2020-07-28 21:00:00
# 2541
# Position 1 sold at 105.132 (verification liste 105.132 )
# Nouvelle moyenne du price_sell 105.132
# 2612
# 1 positions TP closed at 104.874  pnl 121.15
# nombre de candles en position : 71
# Equity : 200402.23999999996
# Filtre de petite time frame passé, pour i= 2732 et un index à i de 2020-07-30 04:05:00
# Filtre de grosse time frame passé, pour j= 5422 et un index à j de 2020-07-29 21:00:00
# 2732
# Position 1 sold at 105.023 (verification liste 105.023 )
# Nouvelle moyenne du price_sell 105.023
# Filtre de petite time frame passé, pour i= 2902 et un index à i de 2020-07-30 18:15:00
# Filtre de grosse time frame passé, pour j= 5422 et un index à j de 2020-07-29 21:00:00
# 2902
# sold at 104.877 (verification liste 104.877 )
# Nouvelle moyenne du price_sell 104.95
# 2923
# 2 positions TP closed at 104.726  pnl 210.37
# nombre de candles en position : 21
# Equity : 200612.60999999996
# Filtre de petite time frame passé, pour i= 3557 et un index à i de 2020-08-04 00:25:00
# Filtre de grosse time frame passé, pour j= 5426 et un index à j de 2020-08-03 21:00:00
# 3557
# Position 1 sold at 106.073 (verification liste 106.073 )
# Nouvelle moyenne du price_sell 106.073
# Filtre de petite time frame passé, pour i= 3565 et un index à i de 2020-08-04 01:05:00
# Filtre de grosse time frame passé, pour j= 5426 et un index à j de 2020-08-03 21:00:00
# 3565
# sold at 106.099 (verification liste 106.099 )
# Nouvelle moyenne du price_sell 106.086
# 3640
# 2 positions TP closed at 105.868  pnl 204.73
# nombre de candles en position : 75
# Equity : 200817.33999999997
# Filtre de petite time frame passé, pour i= 4016 et un index à i de 2020-08-05 15:00:00
# Filtre de grosse time frame passé, pour j= 5427 et un index à j de 2020-08-04 21:00:00
# 4016
# Position 1 sold at 105.517 (verification liste 105.517 )
# Nouvelle moyenne du price_sell 105.517
# Filtre de petite time frame passé, pour i= 4074 et un index à i de 2020-08-05 19:50:00
# Filtre de grosse time frame passé, pour j= 5427 et un index à j de 2020-08-04 21:00:00
# 4074
# sold at 105.592 (verification liste 105.592 )
# Nouvelle moyenne du price_sell 105.5545
# Filtre de petite time frame passé, pour i= 4078 et un index à i de 2020-08-05 20:10:00
# Filtre de grosse time frame passé, pour j= 5427 et un index à j de 2020-08-04 21:00:00
# 4078
# sold at 105.613 (verification liste 105.613 )
# Nouvelle moyenne du price_sell 105.574
# Filtre de petite time frame passé, pour i= 4206 et un index à i de 2020-08-06 06:50:00
# Filtre de grosse time frame passé, pour j= 5428 et un index à j de 2020-08-05 21:00:00
# 4206
# sold at 105.485 (verification liste 105.485 )
# Nouvelle moyenne du price_sell 105.55175
# Filtre de petite time frame passé, pour i= 4221 et un index à i de 2020-08-06 08:05:00
# Filtre de grosse time frame passé, pour j= 5428 et un index à j de 2020-08-05 21:00:00
# 4221
# sold at 105.593 (verification liste 105.593 )
# Nouvelle moyenne du price_sell 105.56
# Filtre de petite time frame passé, pour i= 4280 et un index à i de 2020-08-06 13:00:00
# Filtre de grosse time frame passé, pour j= 5428 et un index à j de 2020-08-05 21:00:00
# 4280
# sold at 105.509 (verification liste 105.509 )
# Nouvelle moyenne du price_sell 105.5515
# 5175
# 6 position SL closed at 106.536  pnl -2807.54
# nombre de candles en position : 895
# Equity : 198009.79999999996
# Filtre de petite time frame passé, pour i= 7153 et un index à i de 2020-08-20 16:30:00
# Filtre de grosse time frame passé, pour j= 5439 et un index à j de 2020-08-19 21:00:00
# 7153
# Position 1 sold at 105.811 (verification liste 105.811 )
# Nouvelle moyenne du price_sell 105.811
# Filtre de petite time frame passé, pour i= 7205 et un index à i de 2020-08-20 20:50:00
# Filtre de grosse time frame passé, pour j= 5439 et un index à j de 2020-08-19 21:00:00
# 7205
# sold at 105.783 (verification liste 105.783 )
# Nouvelle moyenne du price_sell 105.797
# Filtre de petite time frame passé, pour i= 7257 et un index à i de 2020-08-21 01:10:00
# Filtre de grosse time frame passé, pour j= 5440 et un index à j de 2020-08-20 21:00:00
# 7257
# sold at 105.703 (verification liste 105.703 )
# Nouvelle moyenne du price_sell 105.76567
# 7329
# 3 positions TP closed at 105.554  pnl 298.18
# nombre de candles en position : 72
# Equity : 198307.97999999995
# Filtre de petite time frame passé, pour i= 8116 et un index à i de 2020-08-26 00:20:00
# Filtre de grosse time frame passé, pour j= 5444 et un index à j de 2020-08-25 21:00:00
# 8116
# Position 1 sold at 106.522 (verification liste 106.522 )
# Nouvelle moyenne du price_sell 106.522
# 8201
# 1 positions TP closed at 106.28  pnl 113.64
# nombre de candles en position : 85
# Equity : 198421.61999999997
# Filtre de petite time frame passé, pour i= 8209 et un index à i de 2020-08-26 08:05:00
# Filtre de grosse time frame passé, pour j= 5444 et un index à j de 2020-08-25 21:00:00
# 8209
# Position 1 sold at 106.257 (verification liste 106.257 )
# Nouvelle moyenne du price_sell 106.257
# Filtre de petite time frame passé, pour i= 8226 et un index à i de 2020-08-26 09:30:00
# Filtre de grosse time frame passé, pour j= 5444 et un index à j de 2020-08-25 21:00:00
# 8226
# sold at 106.293 (verification liste 106.293 )
# Nouvelle moyenne du price_sell 106.275
# Filtre de petite time frame passé, pour i= 8243 et un index à i de 2020-08-26 10:55:00
# Filtre de grosse time frame passé, pour j= 5444 et un index à j de 2020-08-25 21:00:00
# 8243
# sold at 106.256 (verification liste 106.256 )
# Nouvelle moyenne du price_sell 106.26867
# 8308
# 3 positions TP closed at 106.03  pnl 336.21
# nombre de candles en position : 65
# Equity : 198757.82999999996
# Filtre de petite time frame passé, pour i= 8323 et un index à i de 2020-08-26 17:35:00
# Filtre de grosse time frame passé, pour j= 5444 et un index à j de 2020-08-25 21:00:00
# 8323
# Position 1 sold at 105.983 (verification liste 105.983 )
# Nouvelle moyenne du price_sell 105.983
# Filtre de petite time frame passé, pour i= 8339 et un index à i de 2020-08-26 18:55:00
# Filtre de grosse time frame passé, pour j= 5444 et un index à j de 2020-08-25 21:00:00
# 8339
# sold at 106.012 (verification liste 106.012 )
# Nouvelle moyenne du price_sell 105.9975
# 8558
# 2 positions TP closed at 105.782  pnl 202.38
# nombre de candles en position : 219
# Equity : 198960.20999999996
# Filtre de petite time frame passé, pour i= 8676 et un index à i de 2020-08-27 23:00:00
# Filtre de grosse time frame passé, pour j= 5446 et un index à j de 2020-08-27 21:00:00
# 8676
# Position 1 sold at 106.576 (verification liste 106.576 )
# Nouvelle moyenne du price_sell 106.576
# Filtre de petite time frame passé, pour i= 8691 et un index à i de 2020-08-28 00:15:00
# Filtre de grosse time frame passé, pour j= 5446 et un index à j de 2020-08-27 21:00:00
# 8691
# sold at 106.729 (verification liste 106.729 )
# Nouvelle moyenne du price_sell 106.6525
# 8749
# 2 positions TP closed at 106.267  pnl 362.04
# nombre de candles en position : 58
# Equity : 199322.24999999997
# Filtre de petite time frame passé, pour i= 8913 et un index à i de 2020-08-28 18:55:00
# Filtre de grosse time frame passé, pour j= 5446 et un index à j de 2020-08-27 21:00:00
# 8913
# Position 1 sold at 105.403 (verification liste 105.403 )
# Nouvelle moyenne du price_sell 105.403
# 9973
# 1 position SL closed at 106.346  pnl -448.91
# nombre de candles en position : 1060
# Equity : 198873.33999999997
#
# Les gains faramineux s'élèvent à : $  -344.66 !. En  33  transactions.
#
# Nbre de winners : 26
#
# Nbre de loosers : 7
#
# Average trade duration  196.47
# Total des gains faramineux : -1126.66
# Pnl latent restant 0 Open Buy 0 Open Sell 0
#  Le rate du ticker GBP/USD est à  1
#  Scraping des données OHLC pour le ticker  GBP/USD
#  Scraping des données OHLC pour le ticker  GBP/USD
# Filtre de petite time frame passé, pour i= 192 et un index à i de 2020-07-17 12:50:00
# Filtre de grosse time frame passé, pour j= 5406 et un index à j de 2020-07-16 21:00:00
# 192
# Position 1 bought at 1.25182 (verification liste 1.25182 )
# Nouvelle moyenne du price_buy 1.25182
# 228
# 1 positions TP closed at 1.25458  pnl 138.00000000000477
# nombre de candles en position : 36
# Equity : 199011.33999999997
# Filtre de petite time frame passé, pour i= 284 et un index à i de 2020-07-17 20:30:00
# Filtre de grosse time frame passé, pour j= 5406 et un index à j de 2020-07-16 21:00:00
# 284
# Position 1 bought at 1.25715 (verification liste 1.25715 )
# Nouvelle moyenne du price_buy 1.25715
# 465
# 1 positions TP closed at 1.25993  pnl 139.00000000000023
# nombre de candles en position : 181
# Equity : 199150.33999999997
# Filtre de petite time frame passé, pour i= 494 et un index à i de 2020-07-20 12:55:00
# Filtre de grosse time frame passé, pour j= 5408 et un index à j de 2020-07-19 21:00:00
# 494
# Position 1 bought at 1.2626 (verification liste 1.2626 )
# Nouvelle moyenne du price_buy 1.2626
# 528
# 1 positions TP closed at 1.26545  pnl 142.50000000000097
# nombre de candles en position : 34
# Equity : 199292.83999999997
# Filtre de petite time frame passé, pour i= 539 et un index à i de 2020-07-20 16:40:00
# Filtre de grosse time frame passé, pour j= 5408 et un index à j de 2020-07-19 21:00:00
# 539
# Position 1 bought at 1.26487 (verification liste 1.26487 )
# Nouvelle moyenne du price_buy 1.26487
# 628
# 1 positions TP closed at 1.26741  pnl 126.99999999999933
# nombre de candles en position : 89
# Equity : 199419.83999999997
# Filtre de petite time frame passé, pour i= 833 et un index à i de 2020-07-21 17:20:00
# Filtre de grosse time frame passé, pour j= 5409 et un index à j de 2020-07-20 21:00:00
# 833
# Position 1 bought at 1.27414 (verification liste 1.27414 )
# Nouvelle moyenne du price_buy 1.27414
# Filtre de petite time frame passé, pour i= 857 et un index à i de 2020-07-21 19:30:00
# Filtre de grosse time frame passé, pour j= 5409 et un index à j de 2020-07-20 21:00:00
# 857
# Position 2 bought at 1.27478 (verification liste 1.27478 )
# Nouvelle moyenne du price_buy 1.27446
# Filtre de petite time frame passé, pour i= 880 et un index à i de 2020-07-21 21:35:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-21 21:00:00
# 880
# Position 3 bought at 1.27236 (verification liste 1.27236 )
# Nouvelle moyenne du price_buy 1.27376
# Filtre de petite time frame passé, pour i= 982 et un index à i de 2020-07-22 06:30:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-21 21:00:00
# 982
# Position 4 bought at 1.27199 (verification liste 1.27199 )
# Nouvelle moyenne du price_buy 1.27332
# Filtre de petite time frame passé, pour i= 996 et un index à i de 2020-07-22 07:40:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-21 21:00:00
# 996
# Position 5 bought at 1.26773 (verification liste 1.26773 )
# Nouvelle moyenne du price_buy 1.2722
# Filtre de petite time frame passé, pour i=1139 et un index à i de 2020-07-22 19:35:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-21 21:00:00
# 1139
# Position 6 bought at 1.27384 (verification liste 1.27384 )
# Nouvelle moyenne du price_buy 1.27247
# 1265
# 6 positions TP closed at 1.27506  pnl 777.0000000000276
# nombre de candles en position : 126
# Equity : 200196.84
# Filtre de petite time frame passé, pour i= 1335 et un index à i de 2020-07-23 11:55:00
# Filtre de grosse time frame passé, pour j= 5411 et un index à j de 2020-07-22 21:00:00
# 1335
# Position 1 bought at 1.26911 (verification liste 1.26911 )
# Nouvelle moyenne du price_buy 1.26911
# 1359
# 1 positions TP closed at 1.2722  pnl 154.50000000000185
# nombre de candles en position : 24
# Equity : 200351.34
# Filtre de petite time frame passé, pour i= 1688 et un index à i de 2020-07-24 17:20:00
# Filtre de grosse time frame passé, pour j= 5412 et un index à j de 2020-07-23 21:00:00
# 1688
# Position 1 bought at 1.27854 (verification liste 1.27854 )
# Nouvelle moyenne du price_buy 1.27854
# Filtre de petite time frame passé, pour i= 1766 et un index à i de 2020-07-26 22:15:00
# Filtre de grosse time frame passé, pour j= 5414 et un index à j de 2020-07-26 21:00:00
# 1766
# Position 2 bought at 1.27877 (verification liste 1.27877 )
# Nouvelle moyenne du price_buy 1.27866
# 1794
# 2 positions TP closed at 1.28171  pnl 304.9999999999997
# nombre de candles en position : 28
# Equity : 200656.34
# Filtre de petite time frame passé, pour i= 2119 et un index à i de 2020-07-28 04:00:00
# Filtre de grosse time frame passé, pour j= 5415 et un index à j de 2020-07-27 21:00:00
# 2119
# Position 1 bought at 1.28546 (verification liste 1.28546 )
# Nouvelle moyenne du price_buy 1.28546
# Filtre de petite time frame passé, pour i= 2138 et un index à i de 2020-07-28 05:35:00
# Filtre de grosse time frame passé, pour j= 5415 et un index à j de 2020-07-27 21:00:00
# 2138
# Position 2 bought at 1.28554 (verification liste 1.28554 )
# Nouvelle moyenne du price_buy 1.2855
# 2182
# 2 positions TP closed at 1.28808  pnl 257.99999999998045
# nombre de candles en position : 44
# Equity : 200914.33999999997
# Filtre de petite time frame passé, pour i= 2247 et un index à i de 2020-07-28 14:40:00
# Filtre de grosse time frame passé, pour j= 5415 et un index à j de 2020-07-27 21:00:00
# 2247
# Position 1 bought at 1.29195 (verification liste 1.29195 )
# Nouvelle moyenne du price_buy 1.29195
# Filtre de petite time frame passé, pour i= 2257 et un index à i de 2020-07-28 15:30:00
# Filtre de grosse time frame passé, pour j= 5415 et un index à j de 2020-07-27 21:00:00
# 2257
# Position 2 bought at 1.29389 (verification liste 1.29389 )
# Nouvelle moyenne du price_buy 1.29292
# Filtre de petite time frame passé, pour i= 2344 et un index à i de 2020-07-28 22:45:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-07-28 21:00:00
# 2344
# Position 3 bought at 1.29299 (verification liste 1.29299 )
# Nouvelle moyenne du price_buy 1.29294
# Filtre de petite time frame passé, pour i= 2349 et un index à i de 2020-07-28 23:10:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-07-28 21:00:00
# 2349
# Position 4 bought at 1.29297 (verification liste 1.29297 )
# Nouvelle moyenne du price_buy 1.29295
# 2451
# 4 positions TP closed at 1.29685  pnl 780.000000000003
# nombre de candles en position : 102
# Equity : 201694.33999999997
# Filtre de petite time frame passé, pour i= 2488 et un index à i de 2020-07-29 10:45:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-07-28 21:00:00
# 2488
# Position 1 bought at 1.29702 (verification liste 1.29702 )
# Nouvelle moyenne du price_buy 1.29702
# Filtre de petite time frame passé, pour i= 2526 et un index à i de 2020-07-29 13:55:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-07-28 21:00:00
# 2526
# Position 2 bought at 1.29862 (verification liste 1.29862 )
# Nouvelle moyenne du price_buy 1.29782
# 2581
# 2 positions TP closed at 1.30049  pnl 266.999999999995
# nombre de candles en position : 55
# Equity : 201961.33999999997
# Filtre de petite time frame passé, pour i= 2599 et un index à i de 2020-07-29 20:00:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-07-28 21:00:00
# 2599
# Position 1 bought at 1.29883 (verification liste 1.29883 )
# Nouvelle moyenne du price_buy 1.29883
# 2778
# 1 positions TP closed at 1.30159  pnl 138.00000000000477
# nombre de candles en position : 179
# Equity : 202099.33999999997
# Filtre de petite time frame passé, pour i= 3173 et un index à i de 2020-07-31 19:55:00
# Filtre de grosse time frame passé, pour j= 5418 et un index à j de 2020-07-30 21:00:00
# 3173
# Position 1 bought at 1.30916 (verification liste 1.30916 )
# Nouvelle moyenne du price_buy 1.30916
# Filtre de petite time frame passé, pour i= 3192 et un index à i de 2020-08-02 21:20:00
# Filtre de grosse time frame passé, pour j= 5420 et un index à j de 2020-08-02 21:00:00
# 3192
# Position 2 bought at 1.30816 (verification liste 1.30816 )
# Nouvelle moyenne du price_buy 1.30866
# Filtre de petite time frame passé, pour i= 3399 et un index à i de 2020-08-03 14:45:00
# Filtre de grosse time frame passé, pour j= 5420 et un index à j de 2020-08-02 21:00:00
# 3399
# Position 3 bought at 1.30192 (verification liste 1.30192 )
# Nouvelle moyenne du price_buy 1.30641
# 3596
# 3 positions TP closed at 1.30948  pnl 460.4999999999859
# nombre de candles en position : 197
# Equity : 202559.83999999997
# Filtre de petite time frame passé, pour i= 3666 et un index à i de 2020-08-04 13:00:00
# Filtre de grosse time frame passé, pour j= 5421 et un index à j de 2020-08-03 21:00:00
# 3666
# Position 1 bought at 1.29966 (verification liste 1.29966 )
# Nouvelle moyenne du price_buy 1.29966
# 3679
# 1 positions TP closed at 1.30295  pnl 164.50000000000077
# nombre de candles en position : 13
# Equity : 202724.33999999997
# Filtre de petite time frame passé, pour i= 3871 et un index à i de 2020-08-05 06:05:00
# Filtre de grosse time frame passé, pour j= 5422 et un index à j de 2020-08-04 21:00:00
# 3871
# Position 1 bought at 1.30866 (verification liste 1.30866 )
# Nouvelle moyenne du price_buy 1.30866
# 3889
# 1 positions TP closed at 1.31196  pnl 165.00000000000404
# nombre de candles en position : 18
# Equity : 202889.33999999997
# Filtre de petite time frame passé, pour i= 3910 et un index à i de 2020-08-05 09:30:00
# Filtre de grosse time frame passé, pour j= 5422 et un index à j de 2020-08-04 21:00:00
# 3910
# Position 1 bought at 1.30979 (verification liste 1.30979 )
# Nouvelle moyenne du price_buy 1.30979
# 3915
# 1 positions TP closed at 1.31294  pnl 157.49999999999932
# nombre de candles en position : 5
# Equity : 203046.83999999997
# Filtre de petite time frame passé, pour i= 4695 et un index à i de 2020-08-10 03:15:00
# Filtre de grosse time frame passé, pour j= 5426 et un index à j de 2020-08-09 21:00:00
# 4695
# Position 1 bought at 1.30739 (verification liste 1.30739 )
# Nouvelle moyenne du price_buy 1.30739
# 4826
# 1 positions TP closed at 1.31014  pnl 137.5000000000015
# nombre de candles en position : 131
# Equity : 203184.33999999997
# Filtre de petite time frame passé, pour i= 5552 et un index à i de 2020-08-13 02:55:00
# Filtre de grosse time frame passé, pour j= 5429 et un index à j de 2020-08-12 21:00:00
# 5552
# Position 1 bought at 1.30637 (verification liste 1.30637 )
# Nouvelle moyenne du price_buy 1.30637
# Filtre de petite time frame passé, pour i= 5599 et un index à i de 2020-08-13 06:50:00
# Filtre de grosse time frame passé, pour j= 5429 et un index à j de 2020-08-12 21:00:00
# 5599
# Position 2 bought at 1.30742 (verification liste 1.30742 )
# Nouvelle moyenne du price_buy 1.30689
# 5640
# 2 positions TP closed at 1.30964  pnl 274.9999999999808
# nombre de candles en position : 41
# Equity : 203459.33999999994
# Filtre de petite time frame passé, pour i= 5695 et un index à i de 2020-08-13 14:50:00
# Filtre de grosse time frame passé, pour j= 5429 et un index à j de 2020-08-12 21:00:00
# 5695
# Position 1 bought at 1.31023 (verification liste 1.31023 )
# Nouvelle moyenne du price_buy 1.31023
# Filtre de petite time frame passé, pour i= 5823 et un index à i de 2020-08-14 01:30:00
# Filtre de grosse time frame passé, pour j= 5430 et un index à j de 2020-08-13 21:00:00
# 5823
# Position 2 bought at 1.30582 (verification liste 1.30582 )
# Nouvelle moyenne du price_buy 1.30802
# Filtre de petite time frame passé, pour i= 5897 et un index à i de 2020-08-14 07:40:00
# Filtre de grosse time frame passé, pour j= 5430 et un index à j de 2020-08-13 21:00:00
# 5897
# Position 3 bought at 1.30621 (verification liste 1.30621 )
# Nouvelle moyenne du price_buy 1.30742
# 5936
# 3 positions TP closed at 1.3104  pnl 446.99999999999744
# nombre de candles en position : 39
# Equity : 203906.33999999994
# Filtre de petite time frame passé, pour i= 6143 et un index à i de 2020-08-17 03:45:00
# Filtre de grosse time frame passé, pour j= 5432 et un index à j de 2020-08-16 21:00:00
# 6143
# Position 1 bought at 1.30992 (verification liste 1.30992 )
# Nouvelle moyenne du price_buy 1.30992
# Filtre de petite time frame passé, pour i= 6193 et un index à i de 2020-08-17 07:55:00
# Filtre de grosse time frame passé, pour j= 5432 et un index à j de 2020-08-16 21:00:00
# 6193
# Position 2 bought at 1.30973 (verification liste 1.30973 )
# Nouvelle moyenne du price_buy 1.30982
# Filtre de petite time frame passé, pour i= 6198 et un index à i de 2020-08-17 08:20:00
# Filtre de grosse time frame passé, pour j= 5432 et un index à j de 2020-08-16 21:00:00
# 6198
# Position 3 bought at 1.30905 (verification liste 1.30905 )
# Nouvelle moyenne du price_buy 1.30957
# Filtre de petite time frame passé, pour i= 6245 et un index à i de 2020-08-17 12:15:00
# Filtre de grosse time frame passé, pour j= 5432 et un index à j de 2020-08-16 21:00:00
# 6245
# Position 4 bought at 1.30831 (verification liste 1.30831 )
# Nouvelle moyenne du price_buy 1.30925
# 6395
# 4 positions TP closed at 1.31243  pnl 635.9999999999922
# nombre de candles en position : 150
# Equity : 204542.33999999994
# Filtre de petite time frame passé, pour i= 6407 et un index à i de 2020-08-18 01:45:00
# Filtre de grosse time frame passé, pour j= 5433 et un index à j de 2020-08-17 21:00:00
# 6407
# Position 1 bought at 1.31289 (verification liste 1.31289 )
# Nouvelle moyenne du price_buy 1.31289
# 6464
# 1 positions TP closed at 1.31633  pnl 172.00000000000549
# nombre de candles en position : 57
# Equity : 204714.33999999994
# Filtre de petite time frame passé, pour i= 6561 et un index à i de 2020-08-18 14:35:00
# Filtre de grosse time frame passé, pour j= 5433 et un index à j de 2020-08-17 21:00:00
# 6561
# Position 1 bought at 1.3225 (verification liste 1.3225 )
# Nouvelle moyenne du price_buy 1.3225
# 6673
# 1 positions TP closed at 1.3252  pnl 134.99999999999625
# nombre de candles en position : 112
# Equity : 204849.33999999994
# Filtre de petite time frame passé, pour i= 6991 et un index à i de 2020-08-20 02:50:00
# Filtre de grosse time frame passé, pour j= 5435 et un index à j de 2020-08-19 21:00:00
# 6991
# Position 1 bought at 1.30934 (verification liste 1.30934 )
# Nouvelle moyenne du price_buy 1.30934
# 7081
# 1 positions TP closed at 1.31249  pnl 157.49999999999932
# nombre de candles en position : 90
# Equity : 205006.83999999994
# Filtre de petite time frame passé, pour i= 7192 et un index à i de 2020-08-20 19:35:00
# Filtre de grosse time frame passé, pour j= 5435 et un index à j de 2020-08-19 21:00:00
# 7192
# Position 1 bought at 1.32128 (verification liste 1.32128 )
# Nouvelle moyenne du price_buy 1.32128
# 7302
# 1 positions TP closed at 1.32396  pnl 134.0000000000008
# nombre de candles en position : 110
# Equity : 205140.83999999994
# Filtre de petite time frame passé, pour i= 8333 et un index à i de 2020-08-26 18:05:00
# Filtre de grosse time frame passé, pour j= 5440 et un index à j de 2020-08-25 21:00:00
# 8333
# Position 1 bought at 1.32065 (verification liste 1.32065 )
# Nouvelle moyenne du price_buy 1.32065
# Filtre de petite time frame passé, pour i= 8435 et un index à i de 2020-08-27 02:35:00
# Filtre de grosse time frame passé, pour j= 5441 et un index à j de 2020-08-26 21:00:00
# 8435
# Position 2 bought at 1.31995 (verification liste 1.31995 )
# Nouvelle moyenne du price_buy 1.3203
# 8561
# 2 positions TP closed at 1.3233  pnl 299.99999999998914
# nombre de candles en position : 126
# Equity : 205440.83999999994
# Filtre de petite time frame passé, pour i= 8636 et un index à i de 2020-08-27 19:20:00
# Filtre de grosse time frame passé, pour j= 5441 et un index à j de 2020-08-26 21:00:00
# 8636
# Position 1 bought at 1.32072 (verification liste 1.32072 )
# Nouvelle moyenne du price_buy 1.32072
# Filtre de petite time frame passé, pour i= 8695 et un index à i de 2020-08-28 00:15:00
# Filtre de grosse time frame passé, pour j= 5442 et un index à j de 2020-08-27 21:00:00
# 8695
# Position 2 bought at 1.31965 (verification liste 1.31965 )
# Nouvelle moyenne du price_buy 1.32018
# 8727
# 2 positions TP closed at 1.32312  pnl 294.0000000000165
# nombre de candles en position : 32
# Equity : 205734.83999999997
# Filtre de petite time frame passé, pour i= 9145 et un index à i de 2020-08-31 12:35:00
# Filtre de grosse time frame passé, pour j= 5444 et un index à j de 2020-08-30 21:00:00
# 9145
# Position 1 bought at 1.33181 (verification liste 1.33181 )
# Nouvelle moyenne du price_buy 1.33181
# 9164
# 1 positions TP closed at 1.33456  pnl 137.5000000000015
# nombre de candles en position : 19
# Equity : 205872.33999999997
# Filtre de petite time frame passé, pour i= 9206 et un index à i de 2020-08-31 17:40:00
# Filtre de grosse time frame passé, pour j= 5444 et un index à j de 2020-08-30 21:00:00
# 9206
# Position 1 bought at 1.33772 (verification liste 1.33772 )
# Nouvelle moyenne du price_buy 1.33772
# Filtre de petite time frame passé, pour i= 9228 et un index à i de 2020-08-31 19:30:00
# Filtre de grosse time frame passé, pour j= 5444 et un index à j de 2020-08-30 21:00:00
# 9228
# Position 2 bought at 1.33654 (verification liste 1.33654 )
# Nouvelle moyenne du price_buy 1.33713
# 9313
# 2 positions TP closed at 1.34067  pnl 354.0000000000099
# nombre de candles en position : 85
# Equity : 206226.33999999997
# Filtre de petite time frame passé, pour i= 9361 et un index à i de 2020-09-01 06:35:00
# Filtre de grosse time frame passé, pour j= 5445 et un index à j de 2020-08-31 21:00:00
# 9361
# Position 1 bought at 1.34093 (verification liste 1.34093 )
# Nouvelle moyenne du price_buy 1.34093
# 9397
# 1 positions TP closed at 1.34403  pnl 155.00000000000514
# nombre de candles en position : 36
# Equity : 206381.33999999997
# Filtre de petite time frame passé, pour i= 9433 et un index à i de 2020-09-01 12:35:00
# Filtre de grosse time frame passé, pour j= 5445 et un index à j de 2020-08-31 21:00:00
# 9433
# Position 1 bought at 1.34621 (verification liste 1.34621 )
# Nouvelle moyenne du price_buy 1.34621
# 9657
# 1 positions SL closed at 1.33382  pnl -619.499999999995
# nombre de candles en position : 224
# Equity : 205761.83999999997
#
# Les gains faramineux s'élèvent à : $  6888.5 !. En  51  transactions.
#
# Nbre de winners : 50
#
# Nbre de loosers : 1
#
# Average trade duration  82.17
# Total des gains faramineux : 5761.84
# Pnl latent restant 0 Open Buy 0 Open Sell 0
# ...
# Nouvelle moyenne du price_sell 6.99559
# Filtre de petite time frame passé, pour i= 2511 et un index à i de 2020-07-29 12:35:00
# Filtre de grosse time frame passé, pour j= 2517 et un index à j de 2020-07-28 21:00:00
# 2511
# sold at 7.00591 (verification liste 7.00591 )
# Nouvelle moyenne du price_sell 6.99706
# Filtre de petite time frame passé, pour i= 2589 et un index à i de 2020-07-29 19:05:00
# Filtre de grosse time frame passé, pour j= 2517 et un index à j de 2020-07-28 21:00:00
# 2589
# sold at 6.99813 (verification liste 6.99813 )
# Nouvelle moyenne du price_sell 6.9972
# Filtre de petite time frame passé, pour i= 2753 et un index à i de 2020-07-30 08:45:00
# Filtre de grosse time frame passé, pour j= 2518 et un index à j de 2020-07-29 21:00:00
# 2753
# sold at 7.00781 (verification liste 7.00781 )
# Nouvelle moyenne du price_sell 6.99838
# Filtre de petite time frame passé, pour i= 2992 et un index à i de 2020-07-31 04:40:00
# Filtre de grosse time frame passé, pour j= 2519 et un index à j de 2020-07-30 21:00:00
# 2992
# sold at 6.99204 (verification liste 6.99204 )
# Nouvelle moyenne du price_sell 6.99774
# Filtre de petite time frame passé, pour i= 3024 et un index à i de 2020-07-31 07:20:00
# Filtre de grosse time frame passé, pour j= 2519 et un index à j de 2020-07-30 21:00:00
# 3024
# sold at 6.99384 (verification liste 6.99384 )
# Nouvelle moyenne du price_sell 6.99739
# 3034
# 11 positions TP closed at 6.98252  pnl 1195.25
# nombre de candles en position : 10
# Equity : 228463.83999999997
# Filtre de petite time frame passé, pour i= 3462 et un index à i de 2020-08-03 19:20:00
# Filtre de grosse time frame passé, pour j= 2521 et un index à j de 2020-08-02 21:00:00
# 3462
# Position 1 sold at 6.98395 (verification liste 6.98395 )
# Nouvelle moyenne du price_sell 6.98395
# Filtre de petite time frame passé, pour i= 3583 et un index à i de 2020-08-04 05:25:00
# Filtre de grosse time frame passé, pour j= 2522 et un index à j de 2020-08-03 21:00:00
# 3583
# sold at 6.98277 (verification liste 6.98277 )
# Nouvelle moyenne du price_sell 6.98336
# Filtre de petite time frame passé, pour i= 3614 et un index à i de 2020-08-04 08:00:00
# Filtre de grosse time frame passé, pour j= 2522 et un index à j de 2020-08-03 21:00:00
# 3614
# sold at 6.98775 (verification liste 6.98775 )
# Nouvelle moyenne du price_sell 6.98482
# 3822
# 3 positions TP closed at 6.96991  pnl 326.85
# nombre de candles en position : 208
# Equity : 228790.68999999997
# Filtre de petite time frame passé, pour i= 4036 et un index à i de 2020-08-05 19:10:00
# Filtre de grosse time frame passé, pour j= 2523 et un index à j de 2020-08-04 21:00:00
# 4036
# Position 1 sold at 6.94119 (verification liste 6.94119 )
# Nouvelle moyenne du price_sell 6.94119
# Filtre de petite time frame passé, pour i= 4121 et un index à i de 2020-08-06 02:15:00
# Filtre de grosse time frame passé, pour j= 2524 et un index à j de 2020-08-05 21:00:00
# 4121
# sold at 6.945 (verification liste 6.945 )
# Nouvelle moyenne du price_sell 6.9431
# Filtre de petite time frame passé, pour i= 4269 et un index à i de 2020-08-06 14:35:00
# Filtre de grosse time frame passé, pour j= 2524 et un index à j de 2020-08-05 21:00:00
# 4269
# sold at 6.94918 (verification liste 6.94918 )
# Nouvelle moyenne du price_sell 6.94512
# Filtre de petite time frame passé, pour i= 4520 et un index à i de 2020-08-07 11:30:00
# Filtre de grosse time frame passé, pour j= 2525 et un index à j de 2020-08-06 21:00:00
# 4520
# sold at 6.95708 (verification liste 6.95708 )
# Nouvelle moyenne du price_sell 6.94811
# Filtre de petite time frame passé, pour i= 4790 et un index à i de 2020-08-10 09:55:00
# Filtre de grosse time frame passé, pour j= 2527 et un index à j de 2020-08-09 21:00:00
# 4790
# sold at 6.96898 (verification liste 6.96898 )
# Nouvelle moyenne du price_sell 6.95229
# Filtre de petite time frame passé, pour i= 4811 et un index à i de 2020-08-10 11:40:00
# Filtre de grosse time frame passé, pour j= 2527 et un index à j de 2020-08-09 21:00:00
# 4811
# sold at 6.97204 (verification liste 6.97204 )
# Nouvelle moyenne du price_sell 6.95558
# Filtre de petite time frame passé, pour i= 4934 et un index à i de 2020-08-10 21:55:00
# Filtre de grosse time frame passé, pour j= 2528 et un index à j de 2020-08-10 21:00:00
# 4934
# sold at 6.96009 (verification liste 6.96009 )
# Nouvelle moyenne du price_sell 6.95622
# 5072
# 7 positions TP closed at 6.94091  pnl 783.12
# nombre de candles en position : 138
# Equity : 229573.80999999997
# Filtre de petite time frame passé, pour i= 5120 et un index à i de 2020-08-11 13:25:00
# Filtre de grosse time frame passé, pour j= 2528 et un index à j de 2020-08-10 21:00:00
# 5120
# Position 1 sold at 6.94117 (verification liste 6.94117 )
# Nouvelle moyenne du price_sell 6.94117
# Filtre de petite time frame passé, pour i= 5166 et un index à i de 2020-08-11 17:15:00
# Filtre de grosse time frame passé, pour j= 2528 et un index à j de 2020-08-10 21:00:00
# 5166
# sold at 6.94063 (verification liste 6.94063 )
# Nouvelle moyenne du price_sell 6.9409
# Filtre de petite time frame passé, pour i= 5374 et un index à i de 2020-08-12 10:35:00
# Filtre de grosse time frame passé, pour j= 2529 et un index à j de 2020-08-11 21:00:00
# 5374
# sold at 6.94423 (verification liste 6.94423 )
# Nouvelle moyenne du price_sell 6.94201
# Filtre de petite time frame passé, pour i= 5536 et un index à i de 2020-08-13 00:05:00
# Filtre de grosse time frame passé, pour j= 2530 et un index à j de 2020-08-12 21:00:00
# 5536
# sold at 6.93163 (verification liste 6.93163 )
# Nouvelle moyenne du price_sell 6.93942
# Filtre de petite time frame passé, pour i= 5579 et un index à i de 2020-08-13 03:40:00
# Filtre de grosse time frame passé, pour j= 2530 et un index à j de 2020-08-12 21:00:00
# 5579
# sold at 6.9372 (verification liste 6.9372 )
# Nouvelle moyenne du price_sell 6.93897
# Filtre de petite time frame passé, pour i= 5713 et un index à i de 2020-08-13 14:50:00
# Filtre de grosse time frame passé, pour j= 2530 et un index à j de 2020-08-12 21:00:00
# 5713
# sold at 6.94382 (verification liste 6.94382 )
# Nouvelle moyenne du price_sell 6.93978
# Filtre de petite time frame passé, pour i= 5716 et un index à i de 2020-08-13 15:05:00
# Filtre de grosse time frame passé, pour j= 2530 et un index à j de 2020-08-12 21:00:00
# 5716
# sold at 6.94296 (verification liste 6.94296 )
# Nouvelle moyenne du price_sell 6.94023
# Filtre de petite time frame passé, pour i= 5904 et un index à i de 2020-08-14 06:50:00
# Filtre de grosse time frame passé, pour j= 2531 et un index à j de 2020-08-13 21:00:00
# 5904
# sold at 6.94099 (verification liste 6.94099 )
# Nouvelle moyenne du price_sell 6.94033
# Filtre de petite time frame passé, pour i= 6231 et un index à i de 2020-08-17 10:20:00
# Filtre de grosse time frame passé, pour j= 2533 et un index à j de 2020-08-16 21:00:00
# 6231
# sold at 6.93737 (verification liste 6.93737 )
# Nouvelle moyenne du price_sell 6.94
# Filtre de petite time frame passé, pour i= 6352 et un index à i de 2020-08-17 20:25:00
# Filtre de grosse time frame passé, pour j= 2533 et un index à j de 2020-08-16 21:00:00
# 6352
# sold at 6.93291 (verification liste 6.93291 )
# Nouvelle moyenne du price_sell 6.93929
# 6415
# 10 positions TP closed at 6.92314  pnl 1180.12
# nombre de candles en position : 63
# Equity : 230753.92999999996
# Filtre de petite time frame passé, pour i= 6737 et un index à i de 2020-08-19 04:35:00
# Filtre de grosse time frame passé, pour j= 2535 et un index à j de 2020-08-18 21:00:00
# 6737
# Position 1 sold at 6.91614 (verification liste 6.91614 )
# Nouvelle moyenne du price_sell 6.91614
# 6784
# 1 positions TP closed at 6.90219  pnl 101.94
# nombre de candles en position : 47
# Equity : 230855.86999999997
# Filtre de petite time frame passé, pour i= 6802 et un index à i de 2020-08-19 10:00:00
# Filtre de grosse time frame passé, pour j= 2535 et un index à j de 2020-08-18 21:00:00
# 6802
# Position 1 sold at 6.89978 (verification liste 6.89978 )
# Nouvelle moyenne du price_sell 6.89978
# Filtre de petite time frame passé, pour i= 6836 et un index à i de 2020-08-19 12:50:00
# Filtre de grosse time frame passé, pour j= 2535 et un index à j de 2020-08-18 21:00:00
# 6836
# sold at 6.90562 (verification liste 6.90562 )
# Nouvelle moyenne du price_sell 6.9027
# Filtre de petite time frame passé, pour i= 6966 et un index à i de 2020-08-19 23:40:00
# Filtre de grosse time frame passé, pour j= 2536 et un index à j de 2020-08-19 21:00:00
# 6966
# sold at 6.92193 (verification liste 6.92193 )
# Nouvelle moyenne du price_sell 6.90911
# Filtre de petite time frame passé, pour i= 7065 et un index à i de 2020-08-20 07:55:00
# Filtre de grosse time frame passé, pour j= 2536 et un index à j de 2020-08-19 21:00:00
# 7065
# sold at 6.91287 (verification liste 6.91287 )
# Nouvelle moyenne du price_sell 6.91005
# Filtre de petite time frame passé, pour i= 7130 et un index à i de 2020-08-20 13:20:00
# Filtre de grosse time frame passé, pour j= 2536 et un index à j de 2020-08-19 21:00:00
# 7130
# sold at 6.91996 (verification liste 6.91996 )
# Nouvelle moyenne du price_sell 6.91203
# 7273
# 5 positions TP closed at 6.89539  pnl 607.96
# nombre de candles en position : 143
# Equity : 231463.82999999996
# Filtre de petite time frame passé, pour i= 7361 et un index à i de 2020-08-21 08:55:00
# Filtre de grosse time frame passé, pour j= 2537 et un index à j de 2020-08-20 21:00:00
# 7361
# Position 1 sold at 6.9087 (verification liste 6.9087 )
# Nouvelle moyenne du price_sell 6.9087
# Filtre de petite time frame passé, pour i= 7443 et un index à i de 2020-08-21 15:45:00
# Filtre de grosse time frame passé, pour j= 2537 et un index à j de 2020-08-20 21:00:00
# 7443
# sold at 6.92058 (verification liste 6.92058 )
# Nouvelle moyenne du price_sell 6.91464
# Filtre de petite time frame passé, pour i= 7591 et un index à i de 2020-08-24 03:05:00
# Filtre de grosse time frame passé, pour j= 2539 et un index à j de 2020-08-23 21:00:00
# 7591
# sold at 6.91568 (verification liste 6.91568 )
# Nouvelle moyenne du price_sell 6.91499
# Filtre de petite time frame passé, pour i= 7706 et un index à i de 2020-08-24 12:40:00
# Filtre de grosse time frame passé, pour j= 2539 et un index à j de 2020-08-23 21:00:00
# 7706
# sold at 6.90681 (verification liste 6.90681 )
# Nouvelle moyenne du price_sell 6.91294
# Filtre de petite time frame passé, pour i= 7723 et un index à i de 2020-08-24 14:05:00
# Filtre de grosse time frame passé, pour j= 2539 et un index à j de 2020-08-23 21:00:00
# 7723
# sold at 6.90838 (verification liste 6.90838 )
# Nouvelle moyenne du price_sell 6.91203
# Filtre de petite time frame passé, pour i= 7793 et un index à i de 2020-08-24 19:55:00
# Filtre de grosse time frame passé, pour j= 2539 et un index à j de 2020-08-23 21:00:00
# 7793
# sold at 6.91398 (verification liste 6.91398 )
# Nouvelle moyenne du price_sell 6.91236
# Filtre de petite time frame passé, pour i= 7905 et un index à i de 2020-08-25 05:15:00
# Filtre de grosse time frame passé, pour j= 2540 et un index à j de 2020-08-24 21:00:00
# 7905
# sold at 6.90746 (verification liste 6.90746 )
# Nouvelle moyenne du price_sell 6.91166
# Filtre de petite time frame passé, pour i= 8122 et un index à i de 2020-08-25 23:20:00
# Filtre de grosse time frame passé, pour j= 2541 et un index à j de 2020-08-25 21:00:00
# 8122
# sold at 6.90383 (verification liste 6.90383 )
# Nouvelle moyenne du price_sell 6.91068
# 8210
# 8 positions TP closed at 6.89476  pnl 930.65
# nombre de candles en position : 88
# Equity : 232394.47999999995
# Filtre de petite time frame passé, pour i= 8252 et un index à i de 2020-08-26 10:10:00
# Filtre de grosse time frame passé, pour j= 2541 et un index à j de 2020-08-25 21:00:00
# 8252
# Position 1 sold at 6.88556 (verification liste 6.88556 )
# Nouvelle moyenne du price_sell 6.88556
# 8506
# 1 positions TP closed at 6.87064  pnl 109.02
# nombre de candles en position : 254
# Equity : 232503.49999999994
# Filtre de petite time frame passé, pour i= 8541 et un index à i de 2020-08-27 10:45:00
# Filtre de grosse time frame passé, pour j= 2542 et un index à j de 2020-08-26 21:00:00
# 8541
# Position 1 sold at 6.88202 (verification liste 6.88202 )
# Nouvelle moyenne du price_sell 6.88202
# Filtre de petite time frame passé, pour i= 8578 et un index à i de 2020-08-27 13:50:00
# Filtre de grosse time frame passé, pour j= 2542 et un index à j de 2020-08-26 21:00:00
# 8578
# sold at 6.88208 (verification liste 6.88208 )
# Nouvelle moyenne du price_sell 6.88205
# Filtre de petite time frame passé, pour i= 8709 et un index à i de 2020-08-28 00:55:00
# Filtre de grosse time frame passé, pour j= 2543 et un index à j de 2020-08-27 21:00:00
# 8709
# sold at 6.88389 (verification liste 6.88389 )
# Nouvelle moyenne du price_sell 6.88266
# Filtre de petite time frame passé, pour i= 8743 et un index à i de 2020-08-28 03:45:00
# Filtre de grosse time frame passé, pour j= 2543 et un index à j de 2020-08-27 21:00:00
# 8743
# sold at 6.87241 (verification liste 6.87241 )
# Nouvelle moyenne du price_sell 6.8801
# 8774
# 4 positions TP closed at 6.86532  pnl 432.0
# nombre de candles en position : 31
# Equity : 232935.49999999994
# Filtre de petite time frame passé, pour i= 8913 et un index à i de 2020-08-28 18:05:00
# Filtre de grosse time frame passé, pour j= 2543 et un index à j de 2020-08-27 21:00:00
# 8913
# Position 1 sold at 6.8625 (verification liste 6.8625 )
# Nouvelle moyenne du price_sell 6.8625
# 9030
# 1 positions TP closed at 6.84784  pnl 107.12
# nombre de candles en position : 117
# Equity : 233042.61999999994
# Filtre de petite time frame passé, pour i= 9115 et un index à i de 2020-08-31 09:50:00
# Filtre de grosse time frame passé, pour j= 2545 et un index à j de 2020-08-30 21:00:00
# 9115
# Position 1 sold at 6.8485 (verification liste 6.8485 )
# Nouvelle moyenne du price_sell 6.8485
# Filtre de petite time frame passé, pour i= 9208 et un index à i de 2020-08-31 17:35:00
# Filtre de grosse time frame passé, pour j= 2545 et un index à j de 2020-08-30 21:00:00
# 9208
# sold at 6.84995 (verification liste 6.84995 )
# Nouvelle moyenne du price_sell 6.84922
# Filtre de petite time frame passé, pour i= 9231 et un index à i de 2020-08-31 19:30:00
# Filtre de grosse time frame passé, pour j= 2545 et un index à j de 2020-08-30 21:00:00
# 9231
# sold at 6.85095 (verification liste 6.85095 )
# Nouvelle moyenne du price_sell 6.8498
# 9301
# 3 positions TP closed at 6.83589  pnl 304.93
# nombre de candles en position : 70
# Equity : 233347.54999999993
# Filtre de petite time frame passé, pour i= 9460 et un index à i de 2020-09-01 14:50:00
# Filtre de grosse time frame passé, pour j= 2546 et un index à j de 2020-08-31 21:00:00
# 9460
# Position 1 sold at 6.83007 (verification liste 6.83007 )
# Nouvelle moyenne du price_sell 6.83007
# Filtre de petite time frame passé, pour i= 9592 et un index à i de 2020-09-02 01:55:00
# Filtre de grosse time frame passé, pour j= 2547 et un index à j de 2020-09-01 21:00:00
# 9592
# sold at 6.83439 (verification liste 6.83439 )
# Nouvelle moyenne du price_sell 6.83223
# Filtre de petite time frame passé, pour i= 9657 et un index à i de 2020-09-02 07:20:00
# Filtre de grosse time frame passé, pour j= 2547 et un index à j de 2020-09-01 21:00:00
# 9657
# sold at 6.8278 (verification liste 6.8278 )
# Nouvelle moyenne du price_sell 6.83075
# Filtre de petite time frame passé, pour i= 9713 et un index à i de 2020-09-02 12:00:00
# Filtre de grosse time frame passé, pour j= 2547 et un index à j de 2020-09-01 21:00:00
# 9713
# sold at 6.8266 (verification liste 6.8266 )
# Nouvelle moyenne du price_sell 6.82972
# Filtre de petite time frame passé, pour i= 9871 et un index à i de 2020-09-03 01:15:00
# Filtre de grosse time frame passé, pour j= 2548 et un index à j de 2020-09-02 21:00:00
# 9871
# sold at 6.83255 (verification liste 6.83255 )
# Nouvelle moyenne du price_sell 6.83028
# Filtre de petite time frame passé, pour i= 9898 et un index à i de 2020-09-03 03:30:00
# Filtre de grosse time frame passé, pour j= 2548 et un index à j de 2020-09-02 21:00:00
# 9898
# sold at 6.83004 (verification liste 6.83004 )
# Nouvelle moyenne du price_sell 6.83024
#
# Les gains faramineux s'élèvent à : $  6395.29 !. En  63  transactions.
#
# Nbre de winners : 57
#
# Nbre de loosers : 0
#
# Average trade duration  108.92
# Total des gains faramineux : 32760.05
# Pnl latent restant -587.5 Open Buy 0 Open Sell 6
# CPU times: user 1min 7s, sys: 3.68 s, total: 1min 11s
# Wall time: 2min 23s

# %%
print(col.Fore.BLUE,'Total des gains faramineux :',round(EQUITY[-1] - _cash_ini,2),col.Style.RESET_ALL)
print(col.Fore.YELLOW,'Total du cash titanesque :',round(EQUITY[-1],2),col.Style.RESET_ALL)

df_resultats.T
# Out:
#  Total des gains faramineux : 32760.05
#  Total du cash titanesque : 232760.05
#         TimeFrame 1 TimeFrame2  Equity Nbre Winners Nbre Loosers  \
# EUR/USD          m5         D1  199218           43           12
# USD/JPY          m5         D1  198873           26            7
# GBP/USD          m5         D1  205762           50            1
# USD/CHF          m5         D1  208370           46            5
# EUR/CHF          m5         D1  211648           38            2
# AUD/USD          m5         D1  213145           56           11
# USD/CAD          m5         D1  220025           73            0
# NZD/USD          m5         D1  223271           34            0
# EUR/GBP          m5         D1  225093           29            4
# EUR/JPY          m5         D1  224368           49           10
# GBP/JPY          m5         D1  231477           46            1
# CHF/JPY          m5         D1  231635           42           10
# GBP/CHF          m5         D1  232498           15            0
# EUR/AUD          m5         D1  233277           27            6
# EUR/CAD          m5         D1  233951           29            7
# AUD/CAD          m5         D1  234624           19            2
# AUD/JPY          m5         D1  234917           30            6
# CAD/JPY          m5         D1  236451           35            5
# NZD/JPY          m5         D1  234343           12            9
# GBP/CAD          m5         D1  229818           29           14
# GBP/NZD          m5         D1  231955           36            6
# GBP/AUD          m5         D1  231642           22            6
# AUD/NZD          m5         D1  234259           42            2
# USD/SEK          m5         D1  236958           37            2
# EUR/SEK          m5         D1  238713           27            3
# EUR/NOK          m5         D1  238406           15            5
# USD/NOK          m5         D1  237757           40           12
# USD/MXN          m5         D1  238895           46            9
# AUD/CHF          m5         D1  236366            9            9
# EUR/NZD          m5         D1  230523           21           17
# USD/ZAR          m5         D1  229527           20            7
# ZAR/JPY          m5         D1  229527            0            0
# NZD/CHF          m5         D1  229527            0            0
# CAD/CHF          m5         D1  229049           24            6
# NZD/CAD          m5         D1  226952           13           12
# USD/ILS          m5         D1  226952            0            0
# USD/CNH          m5         D1  232760           57            0
#
#         Average lenght of trade Cumul pnl
# EUR/USD                  114.45      -782
# USD/JPY                  196.47   -344.66
# GBP/USD                   82.17    6888.5
# USD/CHF                   90.17   2608.41
# EUR/CHF                  201.27   3986.49
# AUD/USD                   52.69       788
# USD/CAD                   67.73   7986.53
# NZD/USD                   54.07    2688.5
# EUR/GBP                  205.45   1557.88
# EUR/JPY                   88.83    731.15
# GBP/JPY                  128.83   5760.83
# CHF/JPY                   142.1    -234.3
# GBP/CHF                  160.25   2013.56
# EUR/AUD                  219.08    169.76
# EUR/CAD                     144    262.77
# AUD/CAD                   91.07    828.68
# AUD/JPY                  144.12    459.25
# CAD/JPY                  217.38   1152.36
# NZD/JPY                   132.1  -1924.35
# GBP/CAD                  180.92  -4332.58
# GBP/NZD                  109.45   1690.57
# GBP/AUD                  192.55   -313.66
# AUD/NZD                  178.53   2617.37
# USD/SEK                   89.92   3542.51
# EUR/SEK                  624.33   1620.43
# EUR/NOK                  126.36    -739.8
# USD/NOK                   76.61   -925.29
# USD/MXN                   74.23   1481.22
# AUD/CHF                  192.67  -2294.97
# EUR/NZD                  121.31  -6420.47
# USD/ZAR                    55.8   -995.56
# ZAR/JPY                      NA         0
# NZD/CHF                      NA         0
# CAD/CHF                  127.75     -30.7
# NZD/CAD                  277.67  -2544.17
# USD/ILS                      NA         0
# USD/CNH                  108.92   6395.29

# %%
len(DATE),len(CONTRACT),len(OPEN_POZ),len(CLOSE_POZ),len(RATE_OPEN_POZ),len(RATE_CLOSE_POZ),len(PNL_LAT),len(PNL_REAL),len(TOTAL_PNL_LAT),len(TOTAL_PNL_REAL)
# Out:
# (152146,
#  152146,
#  152146,
#  152146,
#  152146,
#  152146,
#  152146,
#  152146,
#  152146,
#  152146)

# %%
df_historical = pd.DataFrame()
df_historical = pd.DataFrame(index=DATE)
df_historical['Contract'] = CONTRACT
df_historical['Open_Poz'] = OPEN_POZ
df_historical['Close_Pos'] = CLOSE_POZ
df_historical['Rate_Open_Poz'] = RATE_OPEN_POZ 
df_historical['Rate_Close_Poze'] = RATE_CLOSE_POZ
df_historical['Pnl_Lat'] = TOTAL_PNL_LAT
df_historical['Pnl_Real'] = TOTAL_PNL_REAL
df_historical.sort_index()
df_historical
# Out:
#                     Contract  Open_Poz  Close_Pos  Rate_Open_Poz  \
# 2020-07-17 19:10:00  EUR/USD         1          0          1.144
# 2020-07-17 19:15:00  EUR/USD         0          0          0.000
# 2020-07-17 19:20:00  EUR/USD         0          0          0.000
# 2020-07-17 19:25:00  EUR/USD         0          0          0.000
# 2020-07-17 19:30:00  EUR/USD         0          0          0.000
# ...                      ...       ...        ...            ...
# 2020-09-03 11:35:00  USD/CNH         0          0          0.000
# 2020-09-03 11:40:00  USD/CNH         0          0          0.000
# 2020-09-03 11:45:00  USD/CNH         0          0          0.000
# 2020-09-03 11:50:00  USD/CNH         0          0          0.000
# 2020-09-03 11:55:00  USD/CNH         0          0          0.000
#
#                      Rate_Close_Poze  Pnl_Lat  Pnl_Real
# 2020-07-17 19:10:00          0.00000     0.00       0.0
# 2020-07-17 19:15:00          1.14387    -6.50       0.0
# 2020-07-17 19:20:00          1.14384    -8.00       0.0
# 2020-07-17 19:25:00          1.14367   -16.50       0.0
# 2020-07-17 19:30:00          1.14386    -7.00       0.0
# ...                              ...      ...       ...
# 2020-09-03 11:35:00          0.00000  -475.70       0.0
# 2020-09-03 11:40:00          0.00000  -532.26       0.0
# 2020-09-03 11:45:00          0.00000  -535.33       0.0
# 2020-09-03 11:50:00          0.00000  -583.12       0.0
# 2020-09-03 11:55:00          0.00000  -587.50       0.0
#
# [152146 rows x 7 columns]

# %%
print('Cash généré :',str(round(df_historical.Pnl_Real.sum(),2))+'$')
print('Pnl latent minimal :',str(df_historical.Pnl_Real.min())+'$')
print('Pnl latent maximal :',str(df_historical.Pnl_Real.max())+'$')
print('Pnl latent moyen :',str(round(df_historical.Pnl_Real.mean(),2))+'$')
print('Max des durées moyennes',df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].max())
print('Min des durées moyennes',df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].min())
print('Moyenne des durées moyennes',round(df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].mean(),2))
print('Nombre total de winners',df_resultats.T['Nbre Winners'].sum())
print('Nombre total de loosers',df_resultats.T['Nbre Loosers'].sum())
print('Total des gains cumulés',round(df_historical[df_historical.Pnl_Real>0].Pnl_Real.sum(),2))
print('Total des pertes cumulées',round(df_historical[df_historical.Pnl_Real<0].Pnl_Real.sum(),2))
print(col.Fore.BLUE,'PROFIT FACTOR : ',\
    abs(round(df_historical[df_historical.Pnl_Real>0].Pnl_Real.sum()/df_historical[df_historical.Pnl_Real<0].Pnl_Real.sum(),2)),col.Style.RESET_ALL)
print(col.Fore.CYAN,'Ratio du nombre de winners :',\
    round((df_resultats.T['Nbre Winners'].sum()*100)/(df_resultats.T['Nbre Loosers'].sum()+df_resultats.T['Nbre Winners'].sum()),2),'%',col.Style.RESET_ALL)
print('Nombre total de trades ouverts',sum(TOTAL_OPEN))
print('Nombre total de trades fermés',sum(TOTAL_CLOSE))
print("Nombre de positions en l'air",(sum(TOTAL_OPEN) - sum(TOTAL_CLOSE)))
# Out:
# Cash généré : 33347.55$
# Pnl latent minimal : -8462.3$
# Pnl latent maximal : 2973.3$
# Pnl latent moyen : 0.22$
# Max des durées moyennes 624.33
# Min des durées moyennes 52.69
# Moyenne des durées moyennes 149.1
# Nombre total de winners 1137
# Nombre total de loosers 208
# Total des gains cumulés 132069.84
# Total des pertes cumulées -98722.29
#  PROFIT FACTOR :  1.34
#  Ratio du nombre de winners : 84.54 %
# Nombre total de trades ouverts 1405
# Nombre total de trades fermés 1345
# Nombre de positions en l'air 60

# %%
df_historical[df_historical.Contract=='EUR/USD'].head(60)

# %%
df_historical.to_csv('historical.csv')

# %%
_number = 10000
_period = 'm5'
_period2 = 'D1'
_total = 0
_cash_ini = 200000
_cash = _cash_ini
_rate = 1
_flag = 0
data = scrap_hist(x,_number,_period)
data2 = scrap_hist(x,_number,_period2)
price = data.copy()
price2 = data2.copy()
_position = 0
_equity = 0
_nbtransactions = 0
backtest_graph = pd.DataFrame()
EQUITY = [_cash]
CASH = [_cash]
OPEN_POZ = [0]
_winner = 0
_looser = 0
_index_entry = 0
TRADE_DURATION = []
_average_duration = 0
_size = 50000

_total = 0

_target = 0.0010
_sl = 0.0050
_spread_filter = 0.002
# Out:
#  Scraping des données OHLC pour le ticker  USD/CNH
#  Scraping des données OHLC pour le ticker  USD/CNH

# %%
plt.figure(figsize=(20,5))
plt.plot(df_historical.Pnl_Lat,label='Pnl Latent')
plt.plot(df_historical.Pnl_Real,label='Pnl Réalisé')
plt.legend()

# %%
TICKERS = ['EUR/USD','USD/JPY','GBP/USD','USD/CHF','EUR/CHF','AUD/USD','USD/CAD','NZD/USD','EUR/GBP','EUR/JPY','GBP/JPY','CHF/JPY','GBP/CHF','EUR/AUD','EUR/CAD','AUD/CAD','AUD/JPY','CAD/JPY','NZD/JPY','GBP/CAD','GBP/NZD','GBP/AUD','AUD/NZD','USD/SEK','EUR/SEK','EUR/NOK','USD/NOK','USD/MXN','AUD/CHF','EUR/NZD','USD/ZAR','ZAR/JPY','NZD/CHF','CAD/CHF','NZD/CAD','USD/ILS','USD/CNH']

# %%
len(TICKERS)
# Out:
# 37

# %%
37 * 50000
# Out:
# 1850000

# %%
90 * 50000
# Out:
# 4500000

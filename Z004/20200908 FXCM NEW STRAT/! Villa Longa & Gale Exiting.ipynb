# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
        
clearall()

# %%
############################
######## LIBRAIRIES ########
############################
print('Importing Librairies...')
from sklearn.linear_model import LinearRegression
import colorama as col
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import time
import os
import datetime as dt
import numpy as np
import fxcmpy
import socketio
import shelve
import talib
import statistics
import pyttsx3

engine = pyttsx3.init()

print('Librairies imported\n')
print('version fxcmpy :',fxcmpy.__version__)
# %matplotlib inline
plt.style.use('seaborn')
engine.say("librairie loaded")
engine.runAndWait()
print('Prêt')
# Out:
# Importing Librairies...
# Librairies imported
#
# version fxcmpy : 1.2.6
# Prêt

# %%
engine.say("Ignition du Lumberjack")
engine.runAndWait() 

##############################################
######## INITIALISATION DES VARIABLES ########
##############################################

'''
# COMPTE TEST #

TOKEN = '89410007226e1ad8ffce5dbf03f1e1bf056f2451'
server = 'demo'
user_id = 'D261219574'
compte = '01215057'
password = '3555'
'''


# COMPTE DEV #
TOKEN = '4973fff4a559fa6e5a25dfd3e7c8f9367f04378b'
server = 'demo'
user_id = 'D161435731'
compte = '01425123'
password = '8889'


'''
# COMPTE POUBELLE #
TOKEN = 'a66bf5c0ec732487f4b348baf6364d3ee8784935'
server = 'demo'
user_id = 'D261219576'
compte = '01215059'
password = '8029'
'''


# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'


_number = 10000
_period = 'm5'
_period2 = 'H1'
_period3 = 'D1'
_total = 0
_cash_ini = 200000
_cash = _cash_ini
_rate = 1
_flag = 0


_size = 100
_target = 15
_sl = -30
_rsi_high = 80
_rsi_low = 20



engine.say("בסדר")
engine.runAndWait()
print('Variables initialisées')
# Out:
# Variables initialisées

# %%
############################
######## FONCTIONS ########
###########################


def conX():
    con = fxcmpy.fxcmpy(access_token=TOKEN, log_level='error',server=server)
    if con.is_connected() == True:
        print(col.Fore.GREEN+'Connexion établie'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
    else:
        print(col.Fore.RED+'Connexion non établie'+col.Style.RESET_ALL)
    return(con)

def deconX():
    con = con.close()
    if con.is_connected() == True:
        print(col.Fore.GREEN+'Connexion non intérrompue'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
    else:
        print(col.Fore.RED+'Connexion intérrompue'+col.Style.RESET_ALL)
    return()


def scrap_hist(_ticker,number,laperiod):
    print(col.Fore.BLUE,'Scraping des données OHLC pour le ticker',col.Fore.YELLOW,_ticker,col.Style.RESET_ALL)
    data = con.get_candles(instrument=_ticker,number = 10000,period=laperiod)
    df = pd.DataFrame(index=data.index)
    df['Open_Bid'] = data['bidopen']
    df['Open_Ask'] = data['askopen']
    df['Open'] = (data['bidopen']+data['askopen'])/2
    df['High_Bid'] = data['bidhigh']
    df['High_Ask'] = data['askhigh']
    df['High'] = (data['bidhigh']+data['askhigh'])/2
    df['Low_Bid'] = data['bidlow']
    df['Low_Ask'] = data['asklow']
    df['Low'] = (data['bidlow']+data['asklow'])/2
    df['Close_Bid'] = data['bidclose']
    df['Close_Ask'] = data['askclose']
    df['Close'] = (data['bidclose']+data['askclose'])/2
    return(df)

def convert(devise,_rate,_flag):
    
    prix_usd = 0
    if x[4:] == 'USD':
        prix_usd = devise
    elif x[:3] == 'USD':
        prix_usd = round(devise/_rate,2)
    elif _flag == 1:
        prix_usd = round(devise * _rate,2)
       
    elif _flag == -1 :
            prix_usd = round(devise / _rate,2)
    else:
        prix_usd = 'NA'
    return(prix_usd,_flag)

# %%
#########################
### CONNEXION A L'API ###
#########################

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor for FOR_EX\nLumberJack Jyss 5780(c)')
print(col.Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print(col.Fore.YELLOW,col.Back.BLUE,'--- Go!em MOVING AVERAGE RETRACEMENT #v0.15 ---',col.Style.RESET_ALL)

print('')
engine.say(" Initialisation du Gaulem Moving, Average, Retracement")
engine.say("Connexion du Gaulem hà la Péh e")
engine.runAndWait()

try:
    con.is_connected() == True
    
    engine.say("already Connected")
    engine.runAndWait()
    print(col.Fore.GREEN+'Connexion rétablie'+col.Style.RESET_ALL)
    print('Compte utilisé : ',con.get_account_ids())
    print('')
    
except:
    try:
        con = conX()
        con.is_connected() == True
        print(col.Fore.GREEN+'Connexion établie'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
        engine.say("Connected")
        engine.runAndWait()
    except:
        print(col.Fore.RED+'Connexion non établie'+col.Style.RESET_ALL)
        engine.say("Not Connected, sal rass de mor, pitun cé la merd")
        engine.say("vérifi ton internet, é relance le gaulèm")
        engine.runAndWait()
        print('')
        #os._exit(0)
        con = deconX()
        time.sleep(1)
        con = conX()
# Out:
# Global Optimized LumberJack Environment Motor for FOR_EX
# LumberJack Jyss 5780(c)
#  °0Oo_D.A.G._26_oO0°
#   --- Go!em MOVING AVERAGE RETRACEMENT #v0.15 ---
#
# Connexion établie
# Compte utilisé :  [1425123]
# Connexion établie
# Compte utilisé :  [1425123]

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.dates as mdates
import pandas as pd
from numpy import loadtxt
from functools import reduce
import talib
import time
from scipy.signal import argrelextrema
from ipywidgets import *

from datetime import datetime

DATE = []
CONTRACT = []
OPEN_POZ = []
CLOSE_POZ = []
RATE_OPEN_POZ = []
RATE_CLOSE_POZ = []
PNL_LAT = []
PNL_REAL = []
TOTAL_OPEN = []
TOTAL_CLOSE = []
PRICE_BUY = []
PRICE_SELL = []
DER_POZ = []
TOTAL_PNL_LAT = []
TOTAL_PNL_REAL = []
_cash = _cash_ini
WINNERS = []
LOOSERS = []

# %%
def peak_detect(price,order=10):
    max_idx = list(argrelextrema(price,np.greater,order=order)[0])
    min_idx = list(argrelextrema(price,np.less,order=order)[0])
    idx = max_idx + min_idx + [len(price)-1]
    idx.sort()
    _current_idx = idx[-3:]
    
    _start = min(_current_idx)
    _end = max(_current_idx)
    _current_pat = price[_current_idx]
    return _current_idx,_current_pat,_start,_end 
    
def is_BAAM(moves,err_allowed):  
    XA=moves[0]
    AB=moves[1]
    
    
    X=prices[0]
    A=prices[1]
    B=prices[2]
    
    AB_range = np.array([0.15 - err_allowed,0.15+ err_allowed])*abs(XA)
    AB_range2 = np.array([0.38 - err_allowed,0.38+ err_allowed])*abs(XA)
    
    
    
    if abs(A-X)/X>0.001:
        
        if XA>0 and AB<0 :

            if (AB_range[0]<abs(AB)<AB_range[1]) or (AB_range2[0]<abs(AB)<AB_range2[1]) :

                BAAM = 1
                return (BAAM)
            else:
                return (np.isnan)

        elif XA<0 and AB>0 :


            if (AB_range[0]<abs(AB)<AB_range[1]) or (AB_range2[0]<abs(AB)<AB_range2[1]):

                BAAM = -1
                return (BAAM)
            else:
                return (np.isnan)
        else:
             return (np.isnan)

# %%
# %%time
df_resultats = pd.DataFrame(index=['TimeFrame 1','TimeFrame2','Equity','Nbre Winners','Nbre Loosers','Average lenght of trade','Cumul pnl'])

#TICKERS = [ 'EUR/USD','GBP/USD','EUR/JPY','GBP/JPY','EUR/AUD','GBP/AUD','EUR/NZD']

TICKERS = [ 'EUR/USD']

engine.say("קדימה")
engine.runAndWait()

err_allowed = 2/100
plt.ion()
position = 0
equity = 100000
for x in TICKERS:

    if x[4:] == 'USD':
        _rate = 1

    elif x[:3] == 'USD':
        con.subscribe_market_data(x)
        _rate = con.get_last_price(x).Bid
        con.unsubscribe_market_data(x)
    elif x[:3] != 'USD' and x[4:] != 'USD':
        try:
            con.subscribe_market_data(x[4:]+'/USD')
            _rate = con.get_last_price(x[4:]+'/USD').Bid
            con.unsubscribe_market_data(x[4:]+'/USD')
            _flag = 1
        except:
            con.subscribe_market_data('USD/'+x[4:])
            _rate = con.get_last_price('USD/'+x[4:]).Bid
            con.unsubscribe_market_data('USD/'+x[4:])
            _flag = -1
    else:
        prix_usd = 'NA'

    print(col.Fore.MAGENTA,'Le rate du ticker',x,'est à ',_rate,col.Style.RESET_ALL)
    label = ''
    data = scrap_hist(x,_number,_period)
    data2 = scrap_hist(x,_number,_period2)
    price = data.copy()
    price2 = data2.copy()
    _position = 0
    _equity = 0
    _nbtransactions = 0
    backtest_graph = pd.DataFrame()
    EQUITY = [_cash]
    CASH = [_cash]
    _winner = 0
    _looser = 0
    _index_entry = 0
    TRADE_DURATION = []
    _average_duration = 0
    _size = 50000

    PRICE_BUY = []
    PRICE_SELL = []
   
    _total = 0

    _target = 0.0015
    _sl = 0.0015
    _spread_filter = 0.00050
    _filtre_multipoz = 0.01 # En %
    _filtre_multipoz = _filtre_multipoz/100
    
    _open_buy = 0
    _open_sell = 0
    _minipoz = 0
    
    MM21 = talib.EMA(price.Close, timeperiod=21)
    MM34 = talib.EMA(price.Close, timeperiod=34)
    MM54 = talib.EMA(price.Close, timeperiod=54)
    rsi = talib.RSI(price.Close, timeperiod=14)
    rsi_high = 70
    rsi_low = 30
    
    MM542 = talib.EMA(price2.Close, timeperiod=54)
    
    for i in range(150,len(price)-1):
        
        j = len(price2[price2.index <= price.index[i]])-1
        
        current_idx,current_pat,start,end = peak_detect(price.Close.values[:i+1])
        current_rsi = [rsi.iloc[current_idx[0]],rsi.iloc[current_idx[1]],rsi.iloc[current_idx[2]]]
        current_rsi_max = max(current_rsi)
        current_rsi_min = min(current_rsi)
        delta_price = current_pat[2] - current_pat[0]
        delta_rsi = current_rsi[2] - current_rsi[0]
      
        XA = current_pat[1] - current_pat[0]     
        AB = current_pat[2] - current_pat[1]      
        
        X = current_pat[0]
        A = current_pat[1]
        B = current_pat[2]

        prices =[X,A,B]

        moves=[XA,AB]
        
        BAAM = is_BAAM(moves,err_allowed)

        harmonics = np.array([BAAM])

        if _position == 0 :
            if (np.any(harmonics==1) and np.all(harmonics!=-1 )) or  (np.any(harmonics==-1) and np.all(harmonics!=1 )):

                for h in range(0, len(harmonics)):

                    if harmonics[h]==-1 and price.iloc[i]['Close']<MM21[i] and X>MM54[current_idx[0]] and MM21[current_idx[0]]>MM54[current_idx[0]] and MM21[i]<MM34[i]<MM54[i]\
                            and price2.Close[j]<MM542[j]:
                            _pnl = 0
                            _open_sell += 1
                            _equity = _cash + _pnl
                            EQUITY.append(_equity)
                            CASH.append(_cash)
                            _index_entry = i
                            _position = -1
                            _nbtransactions += 1
                            price_sell = price.Close_Bid.iloc[i]
                            PRICE_SELL.append(price_sell)
                            _price_sell_mean = round(sum(PRICE_SELL)/len(PRICE_SELL),5)
                            print('Position 1 sold at', price_sell,'(verification liste',PRICE_SELL[-1],')')
                            print('Nouvelle moyenne du price_sell',_price_sell_mean)

                            DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                            CONTRACT.append(x)
                            OPEN_POZ.append(-1)
                            CLOSE_POZ.append(0)
                            RATE_OPEN_POZ.append(price_sell)
                            RATE_CLOSE_POZ.append(0) 
                            PNL_LAT.append(_pnl)
                            PNL_REAL.append(0)
                            TOTAL_PNL_LAT.append(_pnl)
                            TOTAL_PNL_REAL.append(0)

                            TOTAL_OPEN.append(1)
                    
                    if harmonics[h]==1 and price.iloc[i]['Close']>MM21[i] and X<MM54[current_idx[0]] and MM21[current_idx[0]]<MM54[current_idx[0]] and MM21[i]>MM34[i]>MM54[i]\
                        and price2.Close[j]>MM542[j]:
                   
                            _pnl = 0
                            _open_buy += 1
                            _equity = _cash + _pnl
                            EQUITY.append(_equity)
                            CASH.append(_cash)
                            _position = 1
                            _index_entry = i
                            _nbtransactions += 1
                            price_buy = price.Close_Ask.iloc[i]
                            PRICE_BUY.append(price_buy)
                            _price_buy_mean = round(sum(PRICE_BUY)/len(PRICE_BUY),5)
                            print('Position 1 bought at', price_buy,'(verification liste',PRICE_BUY[-1],')')
                            print('Nouvelle moyenne du price_buy',_price_buy_mean)

                            DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                            CONTRACT.append(x)
                            OPEN_POZ.append(1)
                            CLOSE_POZ.append(0)
                            RATE_OPEN_POZ.append(price_buy)
                            RATE_CLOSE_POZ.append(0)
                            PNL_LAT.append(_pnl)
                            PNL_REAL.append(0)
                            TOTAL_OPEN.append(1) 
                            TOTAL_PNL_LAT.append(_pnl)
                            TOTAL_PNL_REAL.append(0) 

                    else :
                        _pnl = 0
                        _equity = _cash + _pnl
                        EQUITY.append(_equity)
                        CASH.append(_cash)
                
        elif _position == 1:

            
            if (price_buy - price.Close[i])/price_buy>=_filtre_multipoz and  MM21[i]>MM34[i]>MM54[i]\
            and price2.Close[j]>MM542[j] :
             
                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _open_buy += 1
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)
                _position = 1
                _index_entry = i
                _nbtransactions += 1
                price_buy = price.Close_Ask.iloc[i]
                PRICE_BUY.append(price_buy)
                _price_buy_mean = round(sum(PRICE_BUY)/len(PRICE_BUY),5)
                print('Position',_open_buy,'bought at ', price_buy,'(verification liste',PRICE_BUY[-1],')')
                print('Nouvelle moyenne du price_buy',_price_buy_mean)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(1)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(price_buy)
                RATE_CLOSE_POZ.append(0)
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_OPEN.append(1) 
                TOTAL_PNL_LAT.append(_pnl)
                TOTAL_PNL_REAL.append(0) 


            else:

                if (float(price.Close_Bid.iloc[i]) - float(_price_buy_mean))/float(_price_buy_mean) >= _target :#slowd[i]>80:
               
                    _position = 0
                    _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _total += _pnl
                    _cash += _pnl
                    _equity = _cash
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _winner += _open_buy

                    TRADE_DURATION.append(i - _index_entry)
                    print(_open_buy,'positions TP closed at',price.Close_Bid.iloc[i],col.Fore.GREEN,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(0)
                    CLOSE_POZ.append(1)
                    RATE_OPEN_POZ.append(0)
                    RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                    PNL_LAT.append(0)
                    PNL_REAL.append(_pnl)
                    TOTAL_PNL_LAT.append(0)
                    TOTAL_PNL_REAL.append(_pnl)
                    TOTAL_CLOSE.append(_open_buy)
                    PRICE_BUY = [] 
                    _open_buy = 0

                elif ((float(price.Close_Bid.iloc[i]) - float(_price_buy_mean))/float(_price_buy_mean) <= -_sl) or \
                    (PNL_LAT[-1] < -180):
                    _position = 0
                    _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _total += _pnl
                    _cash += _pnl
                    _equity = _cash
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _looser += _open_buy

                    TRADE_DURATION.append(i - _index_entry)
                    print(_open_buy,'positions SL closed at',price.Close_Bid.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(0)
                    CLOSE_POZ.append(1)
                    RATE_OPEN_POZ.append(0)
                    RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                    PNL_LAT.append(0)
                    PNL_REAL.append(_pnl)
                    TOTAL_CLOSE.append(_open_buy) 
                    TOTAL_PNL_LAT.append(0)
                    TOTAL_PNL_REAL.append(_pnl)
                    PRICE_BUY = []
                    _open_buy = 0
                else:

                    _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _equity = _cash + _pnl
                    EQUITY.append(_equity)
                    CASH.append(_cash)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(0)
                    CLOSE_POZ.append(0)
                    RATE_OPEN_POZ.append(0)
                    RATE_CLOSE_POZ.append(0) ############### 
                    PNL_LAT.append(_pnl)
                    PNL_REAL.append(0)
                    TOTAL_PNL_LAT.append(_pnl)
                    TOTAL_PNL_REAL.append(0) 


        elif _position == -1:

            
            if ( price.Close[i] - price_sell)/price_sell>=_filtre_multipoz and price.iloc[i]['Close']<MM21[i] and MM21[i]<MM34[i]<MM54[i]\
            and price2.Close[j]<MM542[j]:
                
                _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _open_sell += 1
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)
                _position = -1
                _index_entry = i
                _nbtransactions += 1
                price_sell = price.Close_Bid.iloc[i]
                PRICE_SELL.append(price_sell)
                _price_sell_mean = round(sum(PRICE_SELL)/len(PRICE_SELL),5)
                print('Position 1 sold at', price_sell,'(verification liste',PRICE_SELL[-1],')')
                print('Nouvelle moyenne du price_sell',_price_sell_mean)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(1)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(price_sell)
                RATE_CLOSE_POZ.append(0)
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_OPEN.append(1) 
                TOTAL_PNL_LAT.append(_pnl)
                TOTAL_PNL_REAL.append(0) 


            else:

                if (float(price.Close_Ask.iloc[i]) - float(_price_sell_mean))/float(_price_sell_mean) <= -_target :
                    _position = 0
                    _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _total += _pnl
                    _cash += _pnl
                    _equity = _cash
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _winner += _open_sell
                    TRADE_DURATION.append(i - _index_entry)
                    print(_open_sell,'positions TP closed at',price.Close_Ask.iloc[i],col.Fore.GREEN,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(0)
                    CLOSE_POZ.append(-1)
                    RATE_OPEN_POZ.append(0)
                    RATE_CLOSE_POZ.append(price.Close_Ask.iloc[i])
                    PNL_LAT.append(0)
                    PNL_REAL.append(_pnl)
                    TOTAL_PNL_LAT.append(0)
                    TOTAL_PNL_REAL.append(_pnl)
                    TOTAL_CLOSE.append(_open_sell)
                    PRICE_SELL = [] 
                    _open_sell = 0

                elif ((float(price.Close_Ask.iloc[i]) - float(_price_sell_mean))/float(_price_sell_mean) >= _sl) or \
                    (PNL_LAT[-1] < -180):
                    _position = 0
                    _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _total += _pnl
                    _cash += _pnl
                    _equity = _cash
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _looser += _open_sell
                    TRADE_DURATION.append(i - _index_entry)
                    print(_open_sell,'position SL closed at',price.Close_Ask.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(0)
                    CLOSE_POZ.append(-1)
                    RATE_OPEN_POZ.append(0)
                    RATE_CLOSE_POZ.append(price.Close_Ask.iloc[i])
                    PNL_LAT.append(0)
                    PNL_REAL.append(_pnl)
                    TOTAL_PNL_LAT.append(0)
                    TOTAL_PNL_REAL.append(_pnl)
                    TOTAL_CLOSE.append(_open_sell)
                    PRICE_SELL = []
                    _open_sell = 0

                else:

                    _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _equity = _cash + _pnl

                    EQUITY.append(_equity)
                    CASH.append(_cash)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(0)
                    CLOSE_POZ.append(0)
                    RATE_OPEN_POZ.append(0)
                    RATE_CLOSE_POZ.append(0)
                    PNL_LAT.append(_pnl)
                    PNL_REAL.append(0)
                    TOTAL_PNL_LAT.append(_pnl)

                    TOTAL_PNL_REAL.append(0)
              
        elif i == (len(price)-1) and _position != 0 :

            if _position == -1:
                _position = 0
                _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_sell
                TRADE_DURATION.append(i - _index_entry)
                print(col.Fore.CYAN,"Cloture des positions en l'air",col.Style.RESET_ALL)
                print(_open_sell,'position closed at',price.Close_Ask.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                print('nombre de candles en position :',i - _index_entry)
                print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(-1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Ask.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_sell)
                PRICE_SELL = []
                _open_sell = 0

            if _position == 1:

                _position = 0
                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_buy

                TRADE_DURATION.append(i - _index_entry)
                print(col.Fore.CYAN,"Cloture des positions en l'air",col.Style.RESET_ALL)
                print(_open_buy,'positions closed at',price.Close_Bid.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                print('nombre de candles en position :',i - _index_entry)
                print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_buy) 
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                PRICE_BUY = []
                _open_buy = 0

    try:
        _average_duration = round(statistics.mean(TRADE_DURATION),2)
    
    except:
        print("(pas de duration)") 
        _average_duration = 'NA' 
    print(col.Fore.BLUE,'Pour le ticker',col.Fore.YELLOW,x,col.Style.RESET_ALL)              
    print(col.Fore.MAGENTA,"\nLes gains faramineux s'élèvent à : $",col.Fore.GREEN,round(_total,2),'!. En ',_nbtransactions,' transactions.',col.Style.RESET_ALL ) 
    print(col.Fore.GREEN,"\nNbre de winners :",_winner,col.Style.RESET_ALL)
    print(col.Fore.RED,"\nNbre de loosers :",_looser,col.Style.RESET_ALL)
    print("\nAverage trade duration ",_average_duration)
    backtest_graph['Equity'] = EQUITY
    
    df_resultats[x] = [_period,_period2,(round(_equity,2)),(_winner),(_looser),(_average_duration),(_total)]

    print('Total des gains faramineux :',round(EQUITY[-1] - _cash_ini,2))
    print('Pnl latent restant',_pnl,'Open Buy',_open_buy,'Open Sell',_open_sell)
    DER_POZ.append(_pnl)
# Out:
#  Le rate du ticker EUR/USD est à  1
#  Scraping des données OHLC pour le ticker  EUR/USD
#  Scraping des données OHLC pour le ticker  EUR/USD
# Position 1 sold at 1.16915 (verification liste 1.16915 )
# Nouvelle moyenne du price_sell 1.16915
# 1 positions TP closed at 1.16694  pnl 110.49999999999116
# nombre de candles en position : 18
# Equity : 200110.5
# Position 1 sold at 1.1661 (verification liste 1.1661 )
# Nouvelle moyenne du price_sell 1.1661
# Position 1 sold at 1.16632 (verification liste 1.16632 )
# Nouvelle moyenne du price_sell 1.16621
# 2 positions TP closed at 1.16393  pnl 228.00000000000597
# nombre de candles en position : 77
# Equity : 200338.5
# Position 1 sold at 1.16516 (verification liste 1.16516 )
# Nouvelle moyenne du price_sell 1.16516
# 1 positions TP closed at 1.16336  pnl 90.0000000000012
# nombre de candles en position : 18
# Equity : 200428.5
# Position 1 sold at 1.16228 (verification liste 1.16228 )
# Nouvelle moyenne du price_sell 1.16228
# Position 1 sold at 1.16248 (verification liste 1.16248 )
# Nouvelle moyenne du price_sell 1.16238
# Position 1 sold at 1.16272 (verification liste 1.16272 )
# Nouvelle moyenne du price_sell 1.16249
# Position 1 sold at 1.16296 (verification liste 1.16296 )
# Nouvelle moyenne du price_sell 1.16261
# Position 1 sold at 1.16307 (verification liste 1.16307 )
# Nouvelle moyenne du price_sell 1.1627
# 5 position SL closed at 1.16329  pnl -147.4999999999671
# nombre de candles en position : 2
# Equity : 200281.00000000003
# Position 1 bought at 1.16589 (verification liste 1.16589 )
# Nouvelle moyenne du price_buy 1.16589
# Position 2 bought at  1.16551 (verification liste 1.16551 )
# Nouvelle moyenne du price_buy 1.1657
# 2 positions TP closed at 1.16745  pnl 175.00000000001404
# nombre de candles en position : 8
# Equity : 200456.00000000003
# Position 1 bought at 1.16631 (verification liste 1.16631 )
# Nouvelle moyenne du price_buy 1.16631
# Position 2 bought at  1.16624 (verification liste 1.16624 )
# Nouvelle moyenne du price_buy 1.16628
# 2 positions TP closed at 1.16814  pnl 185.99999999999727
# nombre de candles en position : 56
# Equity : 200642.00000000003
# Position 1 bought at 1.17267 (verification liste 1.17267 )
# Nouvelle moyenne du price_buy 1.17267
# 1 positions TP closed at 1.17466  pnl 99.49999999999682
# nombre de candles en position : 2
# Equity : 200741.50000000003
# Position 1 bought at 1.17398 (verification liste 1.17398 )
# Nouvelle moyenne du price_buy 1.17398
# Position 2 bought at  1.17358 (verification liste 1.17358 )
# Nouvelle moyenne du price_buy 1.17378
# Position 3 bought at  1.17284 (verification liste 1.17284 )
# Nouvelle moyenne du price_buy 1.17347
# Position 4 bought at  1.17227 (verification liste 1.17227 )
# Nouvelle moyenne du price_buy 1.17317
# Position 5 bought at  1.17201 (verification liste 1.17201 )
# Nouvelle moyenne du price_buy 1.17294
# Position 6 bought at  1.1712 (verification liste 1.1712 )
# Nouvelle moyenne du price_buy 1.17265
# 6 positions SL closed at 1.17152  pnl -339.0000000000226
# nombre de candles en position : 1
# Equity : 200402.5
# Position 1 bought at 1.17219 (verification liste 1.17219 )
# Nouvelle moyenne du price_buy 1.17219
# Position 2 bought at  1.17173 (verification liste 1.17173 )
# Nouvelle moyenne du price_buy 1.17196
# 2 positions TP closed at 1.17392  pnl 196.0000000000184
# nombre de candles en position : 85
# Equity : 200598.50000000003
# Position 1 bought at 1.1737 (verification liste 1.1737 )
# Nouvelle moyenne du price_buy 1.1737
# Position 2 bought at  1.17361 (verification liste 1.17361 )
# Nouvelle moyenne du price_buy 1.17366
# Position 3 bought at  1.17356 (verification liste 1.17356 )
# Nouvelle moyenne du price_buy 1.17362
# Position 4 bought at  1.17345 (verification liste 1.17345 )
# Nouvelle moyenne du price_buy 1.17358
# 4 positions SL closed at 1.17315  pnl -86.0000000000305
# nombre de candles en position : 66
# Equity : 200512.5
# Position 1 bought at 1.17455 (verification liste 1.17455 )
# Nouvelle moyenne du price_buy 1.17455
# Position 2 bought at  1.17421 (verification liste 1.17421 )
# Nouvelle moyenne du price_buy 1.17438
# Position 3 bought at  1.1741 (verification liste 1.1741 )
# Nouvelle moyenne du price_buy 1.17429
# Position 4 bought at  1.17387 (verification liste 1.17387 )
# Nouvelle moyenne du price_buy 1.17418
# 4 positions TP closed at 1.17609  pnl 382.0000000000157
# nombre de candles en position : 9
# Equity : 200894.50000000003
# Position 1 bought at 1.17521 (verification liste 1.17521 )
# Nouvelle moyenne du price_buy 1.17521
# Position 2 bought at  1.17411 (verification liste 1.17411 )
# Nouvelle moyenne du price_buy 1.17466
# 2 positions SL closed at 1.17277  pnl -188.9999999999947
# nombre de candles en position : 120
# Equity : 200705.50000000003
# Position 1 sold at 1.17307 (verification liste 1.17307 )
# Nouvelle moyenne du price_sell 1.17307
# 1 positions TP closed at 1.17129  pnl 89.00000000000574
# nombre de candles en position : 29
# Equity : 200794.50000000003
# Position 1 sold at 1.17211 (verification liste 1.17211 )
# Nouvelle moyenne du price_sell 1.17211
# Position 1 sold at 1.17236 (verification liste 1.17236 )
# Nouvelle moyenne du price_sell 1.17224
# 2 positions TP closed at 1.17035  pnl 188.9999999999947
# nombre de candles en position : 57
# Equity : 200983.50000000003
# Position 1 sold at 1.17062 (verification liste 1.17062 )
# Nouvelle moyenne du price_sell 1.17062
# Position 1 sold at 1.17095 (verification liste 1.17095 )
# Nouvelle moyenne du price_sell 1.17078
# Position 1 sold at 1.17119 (verification liste 1.17119 )
# Nouvelle moyenne du price_sell 1.17092
# 3 position SL closed at 1.17188  pnl -144.0000000000108
# nombre de candles en position : 3
# Equity : 200839.50000000003
# Position 1 bought at 1.17401 (verification liste 1.17401 )
# Nouvelle moyenne du price_buy 1.17401
# Position 2 bought at  1.17382 (verification liste 1.17382 )
# Nouvelle moyenne du price_buy 1.17392
# 2 positions TP closed at 1.17574  pnl 181.9999999999933
# nombre de candles en position : 15
# Equity : 201021.50000000003
# Position 1 bought at 1.17849 (verification liste 1.17849 )
# Nouvelle moyenne du price_buy 1.17849
# Position 2 bought at  1.17844 (verification liste 1.17844 )
# Nouvelle moyenne du price_buy 1.17847
# Position 3 bought at  1.17854 (verification liste 1.17854 )
# Nouvelle moyenne du price_buy 1.17849
# Position 4 bought at  1.17808 (verification liste 1.17808 )
# Nouvelle moyenne du price_buy 1.17839
# 4 positions SL closed at 1.17709  pnl -260.0000000000158
# nombre de candles en position : 131
# Equity : 200761.5
# Position 1 bought at 1.17617 (verification liste 1.17617 )
# Nouvelle moyenne du price_buy 1.17617
# Position 2 bought at  1.17583 (verification liste 1.17583 )
# Nouvelle moyenne du price_buy 1.176
# Position 3 bought at  1.17577 (verification liste 1.17577 )
# Nouvelle moyenne du price_buy 1.17592
# Position 4 bought at  1.17533 (verification liste 1.17533 )
# Nouvelle moyenne du price_buy 1.17578
# Position 5 bought at  1.1751 (verification liste 1.1751 )
# Nouvelle moyenne du price_buy 1.17564
# 5 positions TP closed at 1.17777  pnl 532.4999999999914
# nombre de candles en position : 25
# Equity : 201294.0
# Position 1 sold at 1.17612 (verification liste 1.17612 )
# Nouvelle moyenne du price_sell 1.17612
# Position 1 sold at 1.17627 (verification liste 1.17627 )
# Nouvelle moyenne du price_sell 1.17619
# 2 positions TP closed at 1.17396  pnl 223.00000000001762
# nombre de candles en position : 55
# Equity : 201517.00000000003
# Position 1 sold at 1.17971 (verification liste 1.17971 )
# Nouvelle moyenne du price_sell 1.17971
# Position 1 sold at 1.17988 (verification liste 1.17988 )
# Nouvelle moyenne du price_sell 1.17979
# Position 1 sold at 1.1801 (verification liste 1.1801 )
# Nouvelle moyenne du price_sell 1.1799
# 3 positions TP closed at 1.17811  pnl 268.49999999999375
# nombre de candles en position : 80
# Equity : 201785.50000000003
# Position 1 sold at 1.17834 (verification liste 1.17834 )
# Nouvelle moyenne du price_sell 1.17834
# 1 positions TP closed at 1.17531  pnl 151.4999999999933
# nombre de candles en position : 6
# Equity : 201937.00000000003
# Position 1 sold at 1.17467 (verification liste 1.17467 )
# Nouvelle moyenne du price_sell 1.17467
# 1 positions TP closed at 1.17289  pnl 89.00000000000574
# nombre de candles en position : 211
# Equity : 202026.00000000003
# Position 1 sold at 1.17362 (verification liste 1.17362 )
# Nouvelle moyenne du price_sell 1.17362
# Position 1 sold at 1.17389 (verification liste 1.17389 )
# Nouvelle moyenne du price_sell 1.17376
# 2 positions TP closed at 1.17167  pnl 208.99999999999253
# nombre de candles en position : 9
# Equity : 202235.00000000003
# Position 1 sold at 1.1711 (verification liste 1.1711 )
# Nouvelle moyenne du price_sell 1.1711
# Position 1 sold at 1.17116 (verification liste 1.17116 )
# Nouvelle moyenne du price_sell 1.17113
# Position 1 sold at 1.17144 (verification liste 1.17144 )
# Nouvelle moyenne du price_sell 1.17123
# 3 positions TP closed at 1.16927  pnl 293.9999999999943
# nombre de candles en position : 25
# Equity : 202529.00000000003
# Position 1 sold at 1.17036 (verification liste 1.17036 )
# Nouvelle moyenne du price_sell 1.17036
# Position 1 sold at 1.17043 (verification liste 1.17043 )
# Nouvelle moyenne du price_sell 1.1704
# 2 position SL closed at 1.17221  pnl -180.99999999998673
# nombre de candles en position : 82
# Equity : 202348.00000000003
# Position 1 sold at 1.17158 (verification liste 1.17158 )
# Nouvelle moyenne du price_sell 1.17158
# Position 1 sold at 1.17166 (verification liste 1.17166 )
# Nouvelle moyenne du price_sell 1.17162
# Position 1 sold at 1.17186 (verification liste 1.17186 )
# Nouvelle moyenne du price_sell 1.1717
# Position 1 sold at 1.17195 (verification liste 1.17195 )
# Nouvelle moyenne du price_sell 1.17176
# 4 position SL closed at 1.17266  pnl -180.00000000002458
# nombre de candles en position : 56
# Equity : 202168.0
# Position 1 sold at 1.17134 (verification liste 1.17134 )
# Nouvelle moyenne du price_sell 1.17134
# Position 1 sold at 1.1714 (verification liste 1.1714 )
# Nouvelle moyenne du price_sell 1.17137
# 2 position SL closed at 1.1735  pnl -212.99999999999653
# nombre de candles en position : 106
# Equity : 201955.0
# Position 1 bought at 1.1778 (verification liste 1.1778 )
# Nouvelle moyenne du price_buy 1.1778
# 1 positions TP closed at 1.17964  pnl 92.00000000000318
# nombre de candles en position : 11
# Equity : 202047.0
# Position 1 bought at 1.18575 (verification liste 1.18575 )
# Nouvelle moyenne du price_buy 1.18575
# Position 2 bought at  1.1853 (verification liste 1.1853 )
# Nouvelle moyenne du price_buy 1.18553
# Position 3 bought at  1.18517 (verification liste 1.18517 )
# Nouvelle moyenne du price_buy 1.18541
# Position 4 bought at  1.1844 (verification liste 1.1844 )
# Nouvelle moyenne du price_buy 1.18516
# 4 positions TP closed at 1.18709  pnl 385.99999999999744
# nombre de candles en position : 30
# Equity : 202433.0
# Position 1 bought at 1.18383 (verification liste 1.18383 )
# Nouvelle moyenne du price_buy 1.18383
# Position 2 bought at  1.18364 (verification liste 1.18364 )
# Nouvelle moyenne du price_buy 1.18374
# 2 positions TP closed at 1.1856  pnl 185.99999999999727
# nombre de candles en position : 37
# Equity : 202619.0
# Position 1 bought at 1.18558 (verification liste 1.18558 )
# Nouvelle moyenne du price_buy 1.18558
# Position 2 bought at  1.18556 (verification liste 1.18556 )
# Nouvelle moyenne du price_buy 1.18557
# Position 3 bought at  1.1849 (verification liste 1.1849 )
# Nouvelle moyenne du price_buy 1.18535
# Position 4 bought at  1.18507 (verification liste 1.18507 )
# Nouvelle moyenne du price_buy 1.18528
# 4 positions SL closed at 1.1844  pnl -175.99999999999838
# nombre de candles en position : 2
# Equity : 202443.0
# Position 1 sold at 1.18226 (verification liste 1.18226 )
# Nouvelle moyenne du price_sell 1.18226
# 1 positions TP closed at 1.18043  pnl 91.49999999999991
# nombre de candles en position : 19
# Equity : 202534.5
# Position 1 sold at 1.18088 (verification liste 1.18088 )
# Nouvelle moyenne du price_sell 1.18088
# Position 1 sold at 1.18074 (verification liste 1.18074 )
# Nouvelle moyenne du price_sell 1.18081
# Position 1 sold at 1.18076 (verification liste 1.18076 )
# Nouvelle moyenne du price_sell 1.18079
# Position 1 sold at 1.18087 (verification liste 1.18087 )
# Nouvelle moyenne du price_sell 1.18081
# Position 1 sold at 1.18087 (verification liste 1.18087 )
# Nouvelle moyenne du price_sell 1.18082
# 5 position SL closed at 1.18163  pnl -202.49999999999434
# nombre de candles en position : 33
# Equity : 202332.0
# Position 1 sold at 1.18125 (verification liste 1.18125 )
# Nouvelle moyenne du price_sell 1.18125
# 1 position SL closed at 1.18313  pnl -94.00000000000519
# nombre de candles en position : 43
# Equity : 202238.0
# Position 1 bought at 1.18294 (verification liste 1.18294 )
# Nouvelle moyenne du price_buy 1.18294
# Position 2 bought at  1.1826 (verification liste 1.1826 )
# Nouvelle moyenne du price_buy 1.18277
# Position 3 bought at  1.18243 (verification liste 1.18243 )
# Nouvelle moyenne du price_buy 1.18266
# 3 positions SL closed at 1.18126  pnl -210.00000000001017
# nombre de candles en position : 48
# Equity : 202028.0
# Position 1 sold at 1.18142 (verification liste 1.18142 )
# Nouvelle moyenne du price_sell 1.18142
# Position 1 sold at 1.18151 (verification liste 1.18151 )
# Nouvelle moyenne du price_sell 1.18146
# 2 positions TP closed at 1.17968  pnl 177.99999999998929
# nombre de candles en position : 16
# Equity : 202206.0
# Position 1 sold at 1.17739 (verification liste 1.17739 )
# Nouvelle moyenne du price_sell 1.17739
# 1 positions TP closed at 1.17518  pnl 110.50000000000226
# nombre de candles en position : 13
# Equity : 202316.5
# Position 1 sold at 1.17291 (verification liste 1.17291 )
# Nouvelle moyenne du price_sell 1.17291
# Position 1 sold at 1.17317 (verification liste 1.17317 )
# Nouvelle moyenne du price_sell 1.17304
# Position 1 sold at 1.17331 (verification liste 1.17331 )
# Nouvelle moyenne du price_sell 1.17313
# Position 1 sold at 1.17354 (verification liste 1.17354 )
# Nouvelle moyenne du price_sell 1.17323
# 4 positions TP closed at 1.17118  pnl 409.99999999997704
# nombre de candles en position : 28
# Equity : 202726.49999999997
# Position 1 sold at 1.16515 (verification liste 1.16515 )
# Nouvelle moyenne du price_sell 1.16515
# 1 positions TP closed at 1.16338  pnl 88.49999999999136
# nombre de candles en position : 154
# Equity : 202814.99999999997
# Position 1 sold at 1.16358 (verification liste 1.16358 )
# Nouvelle moyenne du price_sell 1.16358
# 1 position SL closed at 1.16538  pnl -90.0000000000012
# nombre de candles en position : 161
# Equity : 202724.99999999997
# Position 1 bought at 1.17303 (verification liste 1.17303 )
# Nouvelle moyenne du price_buy 1.17303
# Position 2 bought at  1.17296 (verification liste 1.17296 )
# Nouvelle moyenne du price_buy 1.173
# 2 positions TP closed at 1.17491  pnl 190.99999999998562
# nombre de candles en position : 60
# Equity : 202915.99999999997
#  Pour le ticker  EUR/USD
#
# Les gains faramineux s'élèvent à : $  2916.0 !. En  101  transactions.
#
# Nbre de winners : 55
#
# Nbre de loosers : 46
#
# Average trade duration  48.95
# Total des gains faramineux : 2916.0
# Pnl latent restant 0 Open Buy 0 Open Sell 0
# CPU times: user 16.1 s, sys: 450 ms, total: 16.6 s
# Wall time: 20.9 s

# %%
df_historical = pd.DataFrame()
df_historical = pd.DataFrame(index=DATE)
df_historical['Contract'] = CONTRACT
df_historical['Open_Poz'] = OPEN_POZ
df_historical['Close_Pos'] = CLOSE_POZ
df_historical['Rate_Open_Poz'] = RATE_OPEN_POZ 
df_historical['Rate_Close_Poze'] = RATE_CLOSE_POZ
df_historical['Pnl_Lat'] = TOTAL_PNL_LAT
df_historical['Pnl_Real'] = TOTAL_PNL_REAL
df_historical = df_historical.sort_index()
_generated_cash = round(df_historical.Pnl_Real.sum(),2)
if _generated_cash <= 0:
     print('Cash généré :',col.Fore.RED,str(_generated_cash)+'$',col.Style.RESET_ALL)
else:
    print('Cash généré :',col.Fore.GREEN,str(_generated_cash)+'$',col.Style.RESET_ALL)
print('Pnl latent minimal :',str(df_historical.Pnl_Real.min())+'$')
print('Pnl latent maximal :',str(df_historical.Pnl_Real.max())+'$')
print('Pnl latent moyen :',str(round(df_historical.Pnl_Real.mean(),2))+'$')
print('Max des durées moyennes',df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].max())
print('Min des durées moyennes',df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].min())
print('Moyenne des durées moyennes',round(df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].mean(),2))
print('Nombre total de winners',df_resultats.T['Nbre Winners'].sum())
print('Nombre total de loosers',df_resultats.T['Nbre Loosers'].sum())
print('Total des gains cumulés',round(df_historical[df_historical.Pnl_Real>0].Pnl_Real.sum(),2))
print('Total des pertes cumulées',round(df_historical[df_historical.Pnl_Real<0].Pnl_Real.sum(),2))
print(col.Fore.BLUE,'PROFIT FACTOR : ',\
    abs(round(df_historical[df_historical.Pnl_Real>0].Pnl_Real.sum()/df_historical[df_historical.Pnl_Real<0].Pnl_Real.sum(),2)),col.Style.RESET_ALL)
print(col.Fore.CYAN,'Ratio du nombre de winners :',\
    round((df_resultats.T['Nbre Winners'].sum()*100)/(df_resultats.T['Nbre Loosers'].sum()+df_resultats.T['Nbre Winners'].sum()),2),'%',col.Style.RESET_ALL)
print('Average Winners',round(sum(list(filter(lambda x:  x > 0,PNL_REAL)))/len(list(filter(lambda x:  x > 0,PNL_REAL)))),2)
print('Average Loosers',round(sum(list(filter(lambda x:  x < 0,PNL_REAL)))/len(list(filter(lambda x:  x < 0,PNL_REAL)))),2)
print('Average pnl',round(sum(PNL_REAL)/len(set(PNL_REAL))),2)
print('Nombre total de trades ouverts',sum(TOTAL_OPEN))
print('Nombre total de trades fermés',sum(TOTAL_CLOSE))
print("Nombre de positions en l'air",(sum(TOTAL_OPEN) - sum(TOTAL_CLOSE)))
# Out:
# Cash généré :  2916.0$
# Pnl latent minimal : -339.0000000000226$
# Pnl latent maximal : 532.4999999999914$
# Pnl latent moyen : 1.23$
# Max des durées moyennes 48.95
# Min des durées moyennes 48.95
# Moyenne des durées moyennes 48.95
# Nombre total de winners 55
# Nombre total de loosers 46
# Total des gains cumulés 5428.0
# Total des pertes cumulées -2512.0
#  PROFIT FACTOR :  2.16
#  Ratio du nombre de winners : 54.46 %
# Average Winners 201.0 2
# Average Loosers -179.0 2
# Average pnl 73.0 2
# Nombre total de trades ouverts 101
# Nombre total de trades fermés 101
# Nombre de positions en l'air 0

# %%
###################### BIG BAZ #######################

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.dates as mdates
import pandas as pd
from numpy import loadtxt
from functools import reduce
import talib
import time
from scipy.signal import argrelextrema
from ipywidgets import *

from datetime import datetime

DATE = []
CONTRACT = []
OPEN_POZ = []
CLOSE_POZ = []
RATE_OPEN_POZ = []
RATE_CLOSE_POZ = []
PNL_LAT = []
PNL_REAL = []
TOTAL_OPEN = []
TOTAL_CLOSE = []
PRICE_BUY = []
PRICE_SELL = []
DER_POZ = []
TOTAL_PNL_LAT = []
TOTAL_PNL_REAL = []
_cash = _cash_ini
WINNERS = []
LOOSERS = []

_year_top = '2012-12-31 23:59:59'
_year_bottom = '2012-01-01 00:00:01'

# %%
def peak_detect(price,order=10):
    max_idx = list(argrelextrema(price,np.greater,order=order)[0])
    min_idx = list(argrelextrema(price,np.less,order=order)[0])
    idx = max_idx + min_idx + [len(price)-1]
    idx.sort()
    _current_idx = idx[-3:]
    
    _start = min(_current_idx)
    _end = max(_current_idx)
    _current_pat = price[_current_idx]
    return _current_idx,_current_pat,_start,_end 
    
def is_BAAM(moves,err_allowed):  
    XA=moves[0]
    AB=moves[1]
    
    
    X=prices[0]
    A=prices[1]
    B=prices[2]
    
    AB_range = np.array([0.50 - err_allowed,0.50+ err_allowed])*abs(XA)
    AB_range2 = np.array([0.68 - err_allowed,0.68+ err_allowed])*abs(XA)
    
    
    
    if abs(A-X)/X>0.001:
        
        if XA>0 and AB<0 :

            if (AB_range[0]<abs(AB)<AB_range[1]) or (AB_range2[0]<abs(AB)<AB_range2[1]) :

                BAAM = 1
                return (BAAM)
            else:
                return (np.isnan)

        elif XA<0 and AB>0 :


            if (AB_range[0]<abs(AB)<AB_range[1]) or (AB_range2[0]<abs(AB)<AB_range2[1]):

                BAAM = -1
                return (BAAM)
            else:
                return (np.isnan)
        else:
             return (np.isnan)

# %%
# %%time


TICKERS = [ 'EUR/USD']

engine.say("קדימה")
engine.runAndWait()

err_allowed = 2/100
plt.ion()
position = 0
equity = 100000
for x in TICKERS:

    if x[4:] == 'USD':
        _rate = 1

    elif x[:3] == 'USD':
        con.subscribe_market_data(x)
        _rate = con.get_last_price(x).Bid
        con.unsubscribe_market_data(x)
    elif x[:3] != 'USD' and x[4:] != 'USD':
        try:
            con.subscribe_market_data(x[4:]+'/USD')
            _rate = con.get_last_price(x[4:]+'/USD').Bid
            con.unsubscribe_market_data(x[4:]+'/USD')
            _flag = 1
        except:
            con.subscribe_market_data('USD/'+x[4:])
            _rate = con.get_last_price('USD/'+x[4:]).Bid
            con.unsubscribe_market_data('USD/'+x[4:])
            _flag = -1
    else:
        prix_usd = 'NA'

    print(col.Fore.MAGENTA,'Le rate du ticker',x,'est à ',_rate,col.Style.RESET_ALL)
    label = ''
    data = pd.read_csv('Base_Clean/EURUSDm5.csv')
    data2 = pd.read_csv('Base_Clean/EURUSDH1.csv')

    data.index = pd.to_datetime(data['Date'])
    data = data.drop(['Date','Total'],axis=1)
    data.rename(columns={'OpenBid':'Open_Bid','HighBid':'High_Bid','LowBid':'Low_Bid','CloseBid':'Close_Bid',\
        'OpenAsk':'Open_Ask','HighAsk':'High_Ask','LowAsk':'Low_Ask','CloseAsk':'Close_Ask'},inplace = True)

    data2.index = pd.to_datetime(data2['Date'])
    data2 = data2.drop(['Date','Total'],axis=1)
    data2.rename(columns={'OpenBid':'Open_Bid','HighBid':'High_Bid','LowBid':'Low_Bid','CloseBid':'Close_Bid',\
        'OpenAsk':'Open_Ask','HighAsk':'High_Ask','LowAsk':'Low_Ask','CloseAsk':'Close_Ask'},inplace = True)

    data = data[(data.index >= _year_bottom) & (data.index <= _year_top)]
    data2 = data2[(data2.index >= _year_bottom) & (data2.index <= _year_top)]

    price = data.copy()
    price2 = data2.copy()
    _position = 0
    _equity = 0
    _nbtransactions = 0
    backtest_graph = pd.DataFrame()
    EQUITY = [_cash]
    CASH = [_cash]
    _winner = 0
    _looser = 0
    _index_entry = 0
    TRADE_DURATION = []
    _average_duration = 0
    _size = 50000

    PRICE_BUY = []
    PRICE_SELL = []
   
    _total = 0

    _target = 0.0015
    _sl = 0.0015
    _spread_filter = 0.00050
    _filtre_multipoz = 0.01 # En %
    _filtre_multipoz = _filtre_multipoz/100
    
    _open_buy = 0
    _open_sell = 0
    _minipoz = 0
    
    MM21 = talib.EMA(price.Close, timeperiod=21)
    MM34 = talib.EMA(price.Close, timeperiod=34)
    MM54 = talib.EMA(price.Close, timeperiod=54)
    rsi = talib.RSI(price.Close, timeperiod=14)
    rsi_high = 70
    rsi_low = 30
    
    MM542 = talib.EMA(price2.Close, timeperiod=54)
    
    for i in range(150,len(price)-1):
        
        j = len(price2[price2.index <= price.index[i]])-1
        
        current_idx,current_pat,start,end = peak_detect(price.Close.values[:i+1])
        current_rsi = [rsi.iloc[current_idx[0]],rsi.iloc[current_idx[1]],rsi.iloc[current_idx[2]]]
        current_rsi_max = max(current_rsi)
        current_rsi_min = min(current_rsi)
        delta_price = current_pat[2] - current_pat[0]
        delta_rsi = current_rsi[2] - current_rsi[0]
      
        XA = current_pat[1] - current_pat[0]     
        AB = current_pat[2] - current_pat[1]      
        
        X = current_pat[0]
        A = current_pat[1]
        B = current_pat[2]

        prices =[X,A,B]

        moves=[XA,AB]
        
        BAAM = is_BAAM(moves,err_allowed)

        harmonics = np.array([BAAM])

        if _position == 0 :
            if (np.any(harmonics==1) and np.all(harmonics!=-1 )) or  (np.any(harmonics==-1) and np.all(harmonics!=1 )):

                for h in range(0, len(harmonics)):

                    if harmonics[h]==-1 and price.iloc[i]['Close']<MM21[i] and X>MM54[current_idx[0]] and MM21[current_idx[0]]>MM54[current_idx[0]] and MM21[i]<MM34[i]<MM54[i]\
                            and price2.Close[j]<MM542[j]:
                            _pnl = 0
                            _open_sell += 1
                            _equity = _cash + _pnl
                            EQUITY.append(_equity)
                            CASH.append(_cash)
                            _index_entry = i
                            _position = -1
                            _nbtransactions += 1
                            price_sell = price.Close_Bid.iloc[i]
                            PRICE_SELL.append(price_sell)
                            _price_sell_mean = round(sum(PRICE_SELL)/len(PRICE_SELL),5)
                            print('Position 1 sold at', price_sell,'(verification liste',PRICE_SELL[-1],')')
                            print('Nouvelle moyenne du price_sell',_price_sell_mean)

                            DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                            CONTRACT.append(x)
                            OPEN_POZ.append(-1)
                            CLOSE_POZ.append(0)
                            RATE_OPEN_POZ.append(price_sell)
                            RATE_CLOSE_POZ.append(0) 
                            PNL_LAT.append(_pnl)
                            PNL_REAL.append(0)
                            TOTAL_PNL_LAT.append(_pnl)
                            TOTAL_PNL_REAL.append(0)

                            TOTAL_OPEN.append(1)
                    
                    if harmonics[h]==1 and price.iloc[i]['Close']>MM21[i] and X<MM54[current_idx[0]] and MM21[current_idx[0]]<MM54[current_idx[0]] and MM21[i]>MM34[i]>MM54[i]\
                        and price2.Close[j]>MM542[j]:
                   
                            _pnl = 0
                            _open_buy += 1
                            _equity = _cash + _pnl
                            EQUITY.append(_equity)
                            CASH.append(_cash)
                            _position = 1
                            _index_entry = i
                            _nbtransactions += 1
                            price_buy = price.Close_Ask.iloc[i]
                            PRICE_BUY.append(price_buy)
                            _price_buy_mean = round(sum(PRICE_BUY)/len(PRICE_BUY),5)
                            print('Position 1 bought at', price_buy,'(verification liste',PRICE_BUY[-1],')')
                            print('Nouvelle moyenne du price_buy',_price_buy_mean)

                            DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                            CONTRACT.append(x)
                            OPEN_POZ.append(1)
                            CLOSE_POZ.append(0)
                            RATE_OPEN_POZ.append(price_buy)
                            RATE_CLOSE_POZ.append(0)
                            PNL_LAT.append(_pnl)
                            PNL_REAL.append(0)
                            TOTAL_OPEN.append(1) 
                            TOTAL_PNL_LAT.append(_pnl)
                            TOTAL_PNL_REAL.append(0) 

                    else :
                        _pnl = 0
                        _equity = _cash + _pnl
                        EQUITY.append(_equity)
                        CASH.append(_cash)
                
        elif _position == 1:

            
            if (price_buy - price.Close[i])/price_buy>=_filtre_multipoz and  MM21[i]>MM34[i]>MM54[i]\
            and price2.Close[j]>MM542[j] :
             
                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _open_buy += 1
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)
                _position = 1
                _index_entry = i
                _nbtransactions += 1
                price_buy = price.Close_Ask.iloc[i]
                PRICE_BUY.append(price_buy)
                _price_buy_mean = round(sum(PRICE_BUY)/len(PRICE_BUY),5)
                print('Position',_open_buy,'bought at ', price_buy,'(verification liste',PRICE_BUY[-1],')')
                print('Nouvelle moyenne du price_buy',_price_buy_mean)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(1)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(price_buy)
                RATE_CLOSE_POZ.append(0)
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_OPEN.append(1) 
                TOTAL_PNL_LAT.append(_pnl)
                TOTAL_PNL_REAL.append(0) 


            else:

                if (float(price.Close_Bid.iloc[i]) - float(_price_buy_mean))/float(_price_buy_mean) >= _target :#slowd[i]>80:
               
                    _position = 0
                    _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _total += _pnl
                    _cash += _pnl
                    _equity = _cash
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _winner += _open_buy

                    TRADE_DURATION.append(i - _index_entry)
                    print(_open_buy,'positions TP closed at',price.Close_Bid.iloc[i],col.Fore.GREEN,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(0)
                    CLOSE_POZ.append(1)
                    RATE_OPEN_POZ.append(0)
                    RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                    PNL_LAT.append(0)
                    PNL_REAL.append(_pnl)
                    TOTAL_PNL_LAT.append(0)
                    TOTAL_PNL_REAL.append(_pnl)
                    TOTAL_CLOSE.append(_open_buy)
                    PRICE_BUY = [] 
                    _open_buy = 0

                elif ((float(price.Close_Bid.iloc[i]) - float(_price_buy_mean))/float(_price_buy_mean) <= -_sl) or \
                    (PNL_LAT[-1] < -180):
                    _position = 0
                    _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _total += _pnl
                    _cash += _pnl
                    _equity = _cash
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _looser += _open_buy

                    TRADE_DURATION.append(i - _index_entry)
                    print(_open_buy,'positions SL closed at',price.Close_Bid.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(0)
                    CLOSE_POZ.append(1)
                    RATE_OPEN_POZ.append(0)
                    RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                    PNL_LAT.append(0)
                    PNL_REAL.append(_pnl)
                    TOTAL_CLOSE.append(_open_buy) 
                    TOTAL_PNL_LAT.append(0)
                    TOTAL_PNL_REAL.append(_pnl)
                    PRICE_BUY = []
                    _open_buy = 0
                else:

                    _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _equity = _cash + _pnl
                    EQUITY.append(_equity)
                    CASH.append(_cash)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(0)
                    CLOSE_POZ.append(0)
                    RATE_OPEN_POZ.append(0)
                    RATE_CLOSE_POZ.append(0) ############### 
                    PNL_LAT.append(_pnl)
                    PNL_REAL.append(0)
                    TOTAL_PNL_LAT.append(_pnl)
                    TOTAL_PNL_REAL.append(0) 


        elif _position == -1:

            
            if ( price.Close[i] - price_sell)/price_sell>=_filtre_multipoz and price.iloc[i]['Close']<MM21[i] and MM21[i]<MM34[i]<MM54[i]\
            and price2.Close[j]<MM542[j]:
                
                _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _open_sell += 1
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)
                _position = -1
                _index_entry = i
                _nbtransactions += 1
                price_sell = price.Close_Bid.iloc[i]
                PRICE_SELL.append(price_sell)
                _price_sell_mean = round(sum(PRICE_SELL)/len(PRICE_SELL),5)
                print('Position 1 sold at', price_sell,'(verification liste',PRICE_SELL[-1],')')
                print('Nouvelle moyenne du price_sell',_price_sell_mean)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(1)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(price_sell)
                RATE_CLOSE_POZ.append(0)
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_OPEN.append(1) 
                TOTAL_PNL_LAT.append(_pnl)
                TOTAL_PNL_REAL.append(0) 


            else:

                if (float(price.Close_Ask.iloc[i]) - float(_price_sell_mean))/float(_price_sell_mean) <= -_target :
                    _position = 0
                    _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _total += _pnl
                    _cash += _pnl
                    _equity = _cash
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _winner += _open_sell
                    TRADE_DURATION.append(i - _index_entry)
                    print(_open_sell,'positions TP closed at',price.Close_Ask.iloc[i],col.Fore.GREEN,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(0)
                    CLOSE_POZ.append(-1)
                    RATE_OPEN_POZ.append(0)
                    RATE_CLOSE_POZ.append(price.Close_Ask.iloc[i])
                    PNL_LAT.append(0)
                    PNL_REAL.append(_pnl)
                    TOTAL_PNL_LAT.append(0)
                    TOTAL_PNL_REAL.append(_pnl)
                    TOTAL_CLOSE.append(_open_sell)
                    PRICE_SELL = [] 
                    _open_sell = 0

                elif ((float(price.Close_Ask.iloc[i]) - float(_price_sell_mean))/float(_price_sell_mean) >= _sl) or \
                    (PNL_LAT[-1] < -180):
                    _position = 0
                    _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _total += _pnl
                    _cash += _pnl
                    _equity = _cash
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _looser += _open_sell
                    TRADE_DURATION.append(i - _index_entry)
                    print(_open_sell,'position SL closed at',price.Close_Ask.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(0)
                    CLOSE_POZ.append(-1)
                    RATE_OPEN_POZ.append(0)
                    RATE_CLOSE_POZ.append(price.Close_Ask.iloc[i])
                    PNL_LAT.append(0)
                    PNL_REAL.append(_pnl)
                    TOTAL_PNL_LAT.append(0)
                    TOTAL_PNL_REAL.append(_pnl)
                    TOTAL_CLOSE.append(_open_sell)
                    PRICE_SELL = []
                    _open_sell = 0

                else:

                    _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _equity = _cash + _pnl

                    EQUITY.append(_equity)
                    CASH.append(_cash)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(0)
                    CLOSE_POZ.append(0)
                    RATE_OPEN_POZ.append(0)
                    RATE_CLOSE_POZ.append(0)
                    PNL_LAT.append(_pnl)
                    PNL_REAL.append(0)
                    TOTAL_PNL_LAT.append(_pnl)

                    TOTAL_PNL_REAL.append(0)
              
        elif i == (len(price)-1) and _position != 0 :

            if _position == -1:
                _position = 0
                _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_sell
                TRADE_DURATION.append(i - _index_entry)
                print(col.Fore.CYAN,"Cloture des positions en l'air",col.Style.RESET_ALL)
                print(_open_sell,'position closed at',price.Close_Ask.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                print('nombre de candles en position :',i - _index_entry)
                print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(-1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Ask.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_sell)
                PRICE_SELL = []
                _open_sell = 0

            if _position == 1:

                _position = 0
                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_buy

                TRADE_DURATION.append(i - _index_entry)
                print(col.Fore.CYAN,"Cloture des positions en l'air",col.Style.RESET_ALL)
                print(_open_buy,'positions closed at',price.Close_Bid.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                print('nombre de candles en position :',i - _index_entry)
                print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_buy) 
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                PRICE_BUY = []
                _open_buy = 0

    try:
        _average_duration = round(statistics.mean(TRADE_DURATION),2)
    
    except:
        print("(pas de duration)") 
        _average_duration = 'NA' 
    print(col.Fore.BLUE,'Pour le ticker',col.Fore.YELLOW,x,col.Style.RESET_ALL)              
    print(col.Fore.MAGENTA,"\nLes gains faramineux s'élèvent à : $",col.Fore.GREEN,round(_total,2),'!. En ',_nbtransactions,' transactions.',col.Style.RESET_ALL ) 
    print(col.Fore.GREEN,"\nNbre de winners :",_winner,col.Style.RESET_ALL)
    print(col.Fore.RED,"\nNbre de loosers :",_looser,col.Style.RESET_ALL)
    print("\nAverage trade duration ",_average_duration)
    backtest_graph['Equity'] = EQUITY
    
    df_resultats[x] = [_period,_period2,(round(_equity,2)),(_winner),(_looser),(_average_duration),(_total)]

    print('Total des gains faramineux :',round(EQUITY[-1] - _cash_ini,2))
    print('Pnl latent restant',_pnl,'Open Buy',_open_buy,'Open Sell',_open_sell)
    DER_POZ.append(_pnl)

engine.say("Finito, coco")
engine.runAndWait()
# Out:
#  Le rate du ticker EUR/USD est à  1
# Position 1 bought at 1.3029700000000002 (verification liste 1.3029700000000002 )
# Nouvelle moyenne du price_buy 1.30297
# Position 2 bought at  1.30281 (verification liste 1.30281 )
# Nouvelle moyenne du price_buy 1.30289
# 2 positions SL closed at 1.30056  pnl -233.00000000001654
# nombre de candles en position : 14
# Equity : 199766.99999999997
# Position 1 bought at 1.31568 (verification liste 1.31568 )
# Nouvelle moyenne du price_buy 1.31568
# Position 2 bought at  1.31561 (verification liste 1.31561 )
# Nouvelle moyenne du price_buy 1.31564
# 2 positions TP closed at 1.31805  pnl 241.00000000000233
# nombre de candles en position : 15
# Equity : 200007.99999999997
# Position 1 bought at 1.32368 (verification liste 1.32368 )
# Nouvelle moyenne du price_buy 1.32368
# Position 2 bought at  1.32335 (verification liste 1.32335 )
# Nouvelle moyenne du price_buy 1.32352
# Position 3 bought at  1.3231700000000002 (verification liste 1.3231700000000002 )
# Nouvelle moyenne du price_buy 1.3234
# 3 positions SL closed at 1.32233  pnl -160.49999999998565
# nombre de candles en position : 2
# Equity : 199847.49999999997
# Position 1 sold at 1.31904 (verification liste 1.31904 )
# Nouvelle moyenne du price_sell 1.31904
# 1 positions TP closed at 1.3170600000000001  pnl 98.99999999999353
# nombre de candles en position : 15
# Equity : 199946.49999999997
# Position 1 bought at 1.33486 (verification liste 1.33486 )
# Nouvelle moyenne du price_buy 1.33486
# Position 2 bought at  1.3345200000000002 (verification liste 1.3345200000000002 )
# Nouvelle moyenne du price_buy 1.33469
# Position 3 bought at  1.33435 (verification liste 1.33435 )
# Nouvelle moyenne du price_buy 1.33458
# Position 4 bought at  1.33419 (verification liste 1.33419 )
# Nouvelle moyenne du price_buy 1.33448
# Position 5 bought at  1.3341 (verification liste 1.3341 )
# Nouvelle moyenne du price_buy 1.3344
# Position 6 bought at  1.33361 (verification liste 1.33361 )
# Nouvelle moyenne du price_buy 1.33427
# 6 positions SL closed at 1.33389  pnl -114.0000000000141
# nombre de candles en position : 1
# Equity : 199832.49999999997
# Position 1 sold at 1.23987 (verification liste 1.23987 )
# Nouvelle moyenne du price_sell 1.23987
# Position 1 sold at 1.24009 (verification liste 1.24009 )
# Nouvelle moyenne du price_sell 1.23998
# 2 positions TP closed at 1.23807  pnl 191.00000000000784
# nombre de candles en position : 8
# Equity : 200023.49999999997
# Position 1 sold at 1.2483899999999999 (verification liste 1.2483899999999999 )
# Nouvelle moyenne du price_sell 1.24839
# 1 positions TP closed at 1.24641  pnl 99.00000000000463
# nombre de candles en position : 6
# Equity : 200122.49999999997
# Position 1 sold at 1.23759 (verification liste 1.23759 )
# Nouvelle moyenne du price_sell 1.23759
# 1 position SL closed at 1.23971  pnl -106.00000000000608
# nombre de candles en position : 11
# Equity : 200016.49999999997
# Position 1 sold at 1.2234399999999999 (verification liste 1.2234399999999999 )
# Nouvelle moyenne du price_sell 1.22344
# 1 positions TP closed at 1.22147  pnl 98.50000000000136
# nombre de candles en position : 14
# Equity : 200114.99999999997
# Position 1 sold at 1.21741 (verification liste 1.21741 )
# Nouvelle moyenne du price_sell 1.21741
# 1 position SL closed at 1.2193200000000002  pnl -95.50000000000392
# nombre de candles en position : 63
# Equity : 200019.49999999997
# Position 1 bought at 1.29344 (verification liste 1.29344 )
# Nouvelle moyenne du price_buy 1.29344
# Position 2 bought at  1.29334 (verification liste 1.29334 )
# Nouvelle moyenne du price_buy 1.29339
# Position 3 bought at  1.29322 (verification liste 1.29322 )
# Nouvelle moyenne du price_buy 1.29333
# 3 positions TP closed at 1.29644  pnl 466.4999999999919
# nombre de candles en position : 52
# Equity : 200485.99999999997
# Position 1 sold at 1.27843 (verification liste 1.27843 )
# Nouvelle moyenne du price_sell 1.27843
# 1 position SL closed at 1.28039  pnl -97.9999999999981
# nombre de candles en position : 28
# Equity : 200387.99999999997
# Position 1 bought at 1.31031 (verification liste 1.31031 )
# Nouvelle moyenne du price_buy 1.31031
# Position 2 bought at  1.31016 (verification liste 1.31016 )
# Nouvelle moyenne du price_buy 1.31024
# Position 3 bought at  1.3099399999999999 (verification liste 1.3099399999999999 )
# Nouvelle moyenne du price_buy 1.31014
# 3 positions TP closed at 1.31216  pnl 302.9999999999866
# nombre de candles en position : 82
# Equity : 200690.99999999997
#  Pour le ticker  EUR/USD
#
# Les gains faramineux s'élèvent à : $  691.0 !. En  27  transactions.
#
# Nbre de winners : 13
#
# Nbre de loosers : 14
#
# Average trade duration  23.92
# Total des gains faramineux : 691.0
# Pnl latent restant 0 Open Buy 0 Open Sell 0
# CPU times: user 5min 54s, sys: 6.97 s, total: 6min 1s
# Wall time: 6min 3s

# %%
df_historical = pd.DataFrame()
df_historical = pd.DataFrame(index=DATE)
df_historical['Contract'] = CONTRACT
df_historical['Open_Poz'] = OPEN_POZ
df_historical['Close_Pos'] = CLOSE_POZ
df_historical['Rate_Open_Poz'] = RATE_OPEN_POZ 
df_historical['Rate_Close_Poze'] = RATE_CLOSE_POZ
df_historical['Pnl_Lat'] = TOTAL_PNL_LAT
df_historical['Pnl_Real'] = TOTAL_PNL_REAL
df_historical = df_historical.sort_index()
_generated_cash = round(df_historical.Pnl_Real.sum(),2)
if _generated_cash <= 0:
     print('Cash généré :',col.Fore.RED,str(_generated_cash)+'$',col.Style.RESET_ALL)
else:
    print('Cash généré :',col.Fore.GREEN,str(_generated_cash)+'$',col.Style.RESET_ALL)
print('Pnl latent minimal :',str(df_historical.Pnl_Real.min())+'$')
print('Pnl latent maximal :',str(df_historical.Pnl_Real.max())+'$')
print('Pnl latent moyen :',str(round(df_historical.Pnl_Real.mean(),2))+'$')
print('Max des durées moyennes',df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].max())
print('Min des durées moyennes',df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].min())
print('Moyenne des durées moyennes',round(df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].mean(),2))
print('Nombre total de winners',df_resultats.T['Nbre Winners'].sum())
print('Nombre total de loosers',df_resultats.T['Nbre Loosers'].sum())
print('Total des gains cumulés',round(df_historical[df_historical.Pnl_Real>0].Pnl_Real.sum(),2))
print('Total des pertes cumulées',round(df_historical[df_historical.Pnl_Real<0].Pnl_Real.sum(),2))
print(col.Fore.BLUE,'PROFIT FACTOR : ',\
    abs(round(df_historical[df_historical.Pnl_Real>0].Pnl_Real.sum()/df_historical[df_historical.Pnl_Real<0].Pnl_Real.sum(),2)),col.Style.RESET_ALL)
print(col.Fore.CYAN,'Ratio du nombre de winners :',\
    round((df_resultats.T['Nbre Winners'].sum()*100)/(df_resultats.T['Nbre Loosers'].sum()+df_resultats.T['Nbre Winners'].sum()),2),'%',col.Style.RESET_ALL)
print('Average Winners',round(sum(list(filter(lambda x:  x > 0,PNL_REAL)))/len(list(filter(lambda x:  x > 0,PNL_REAL)))),2)
print('Average Loosers',round(sum(list(filter(lambda x:  x < 0,PNL_REAL)))/len(list(filter(lambda x:  x < 0,PNL_REAL)))),2)
print('Average pnl',round(sum(PNL_REAL)/len(set(PNL_REAL))),2)
print('Nombre total de trades ouverts',sum(TOTAL_OPEN))
print('Nombre total de trades fermés',sum(TOTAL_CLOSE))
print("Nombre de positions en l'air",(sum(TOTAL_OPEN) - sum(TOTAL_CLOSE)))
# Out:
# Cash généré :  691.0$
# Pnl latent minimal : -233.00000000001654$
# Pnl latent maximal : 466.4999999999919$
# Pnl latent moyen : 1.79$
# Max des durées moyennes 23.92
# Min des durées moyennes 23.92
# Moyenne des durées moyennes 23.92
# Nombre total de winners 13
# Nombre total de loosers 14
# Total des gains cumulés 1498.0
# Total des pertes cumulées -807.0
#  PROFIT FACTOR :  1.86
#  Ratio du nombre de winners : 48.15 %
# Average Winners 214.0 2
# Average Loosers -135.0 2
# Average pnl 49.0 2
# Nombre total de trades ouverts 27
# Nombre total de trades fermés 27
# Nombre de positions en l'air 0

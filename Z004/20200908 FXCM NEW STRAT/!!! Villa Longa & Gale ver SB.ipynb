# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
        
clearall()

# %%
############################
######## LIBRAIRIES ########
############################
print('Importing Librairies...')
from sklearn.linear_model import LinearRegression
import colorama as col
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import time
import os
import datetime as dt
import numpy as np
import fxcmpy
import socketio
import shelve
import talib
import statistics
import pyttsx3

engine = pyttsx3.init()

print('Librairies imported\n')
print('version fxcmpy :',fxcmpy.__version__)
# %matplotlib inline
plt.style.use('seaborn')
engine.say("librairie loaded")
engine.runAndWait()
print('Prêt')
# Out:
# Importing Librairies...
# Librairies imported
#
# version fxcmpy : 1.2.6
# Prêt

# %%
engine.say("Ignition du Lumberjack")
engine.runAndWait() 

##############################################
######## INITIALISATION DES VARIABLES ########
##############################################

'''
# COMPTE TEST #

TOKEN = '89410007226e1ad8ffce5dbf03f1e1bf056f2451'
server = 'demo'
user_id = 'D261219574'
compte = '01215057'
password = '3555'
'''


# COMPTE DEV #
TOKEN = '4973fff4a559fa6e5a25dfd3e7c8f9367f04378b'
server = 'demo'
user_id = 'D161435731'
compte = '01425123'
password = '8889'


'''
# COMPTE POUBELLE #
TOKEN = 'a66bf5c0ec732487f4b348baf6364d3ee8784935'
server = 'demo'
user_id = 'D261219576'
compte = '01215059'
password = '8029'
'''


# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'


_number = 10000
_period = 'm5'
_period2 = 'H1'
_period3 = 'D1'
_total = 0
_cash_ini = 200000
_cash = _cash_ini
_rate = 1
_flag = 0


_size = 100
_target = 15
_sl = -30
_rsi_high = 80
_rsi_low = 20



engine.say("בסדר")
engine.runAndWait()
print('Variables initialisées')
# Out:
# Variables initialisées

# %%
############################
######## FONCTIONS ########
###########################


def conX():
    con = fxcmpy.fxcmpy(access_token=TOKEN, log_level='error',server=server)
    if con.is_connected() == True:
        print(col.Fore.GREEN+'Connexion établie'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
    else:
        print(col.Fore.RED+'Connexion non établie'+col.Style.RESET_ALL)
    return(con)

def deconX():
    con = con.close()
    if con.is_connected() == True:
        print(col.Fore.GREEN+'Connexion non intérrompue'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
    else:
        print(col.Fore.RED+'Connexion intérrompue'+col.Style.RESET_ALL)
    return()


def scrap_hist(_ticker,number,laperiod):
    print(col.Fore.BLUE,'Scraping des données OHLC pour le ticker',col.Fore.YELLOW,_ticker,col.Style.RESET_ALL)
    data = con.get_candles(instrument=_ticker,number = 10000,period=laperiod)
    df = pd.DataFrame(index=data.index)
    df['Open_Bid'] = data['bidopen']
    df['Open_Ask'] = data['askopen']
    df['Open'] = (data['bidopen']+data['askopen'])/2
    df['High_Bid'] = data['bidhigh']
    df['High_Ask'] = data['askhigh']
    df['High'] = (data['bidhigh']+data['askhigh'])/2
    df['Low_Bid'] = data['bidlow']
    df['Low_Ask'] = data['asklow']
    df['Low'] = (data['bidlow']+data['asklow'])/2
    df['Close_Bid'] = data['bidclose']
    df['Close_Ask'] = data['askclose']
    df['Close'] = (data['bidclose']+data['askclose'])/2
    return(df)

def convert(devise,_rate,_flag):
    
    prix_usd = 0
    if x[4:] == 'USD':
        prix_usd = devise
    elif x[:3] == 'USD':
        prix_usd = round(devise/_rate,2)
    elif _flag == 1:
        prix_usd = round(devise * _rate,2)
       
    elif _flag == -1 :
            prix_usd = round(devise / _rate,2)
    else:
        prix_usd = 'NA'
    return(prix_usd,_flag)

# %%
#########################
### CONNEXION A L'API ###
#########################

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor for FOR_EX\nLumberJack Jyss 5780(c)')
print(col.Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print(col.Fore.YELLOW,col.Back.BLUE,'--- Go!em MOVING AVERAGE RETRACEMENT #v0.15 ---',col.Style.RESET_ALL)

print('')
engine.say(" Initialisation du Gaulem Moving, Average, Retracement")
engine.say("Connexion du Gaulem hà la Péh e")
engine.runAndWait()

try:
    con.is_connected() == True
    
    engine.say("already Connected")
    engine.runAndWait()
    print(col.Fore.GREEN+'Connexion rétablie'+col.Style.RESET_ALL)
    print('Compte utilisé : ',con.get_account_ids())
    print('')
    
except:
    try:
        con = conX()
        con.is_connected() == True
        print(col.Fore.GREEN+'Connexion établie'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
        engine.say("Connected")
        engine.runAndWait()
    except:
        print(col.Fore.RED+'Connexion non établie'+col.Style.RESET_ALL)
        engine.say("Not Connected, sal rass de mor, pitun cé la merd")
        engine.say("vérifi ton internet, é relance le gaulèm")
        engine.runAndWait()
        print('')
        #os._exit(0)
        con = deconX()
        time.sleep(1)
        con = conX()
# Out:
# Global Optimized LumberJack Environment Motor for FOR_EX
# LumberJack Jyss 5780(c)
#  °0Oo_D.A.G._26_oO0°
#   --- Go!em MOVING AVERAGE RETRACEMENT #v0.15 ---
#
# Connexion établie
# Compte utilisé :  [1425123]
# Connexion établie
# Compte utilisé :  [1425123]

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.dates as mdates
import pandas as pd
from numpy import loadtxt
from functools import reduce
import talib
import time
from scipy.signal import argrelextrema
from ipywidgets import *

from datetime import datetime

DATE = []
CONTRACT = []
OPEN_POZ = []
CLOSE_POZ = []
RATE_OPEN_POZ = []
RATE_CLOSE_POZ = []
PNL_LAT = []
PNL_REAL = []
TOTAL_OPEN = []
TOTAL_CLOSE = []
PRICE_BUY = []
PRICE_SELL = []
DER_POZ = []
TOTAL_PNL_LAT = []
TOTAL_PNL_REAL = []
_cash = _cash_ini
WINNERS = []
LOOSERS = []

# %%
def peak_detect(price,order=10):
    max_idx = list(argrelextrema(price,np.greater,order=order)[0])
    min_idx = list(argrelextrema(price,np.less,order=order)[0])
    idx = max_idx + min_idx + [len(price)-1]
    idx.sort()
    _current_idx = idx[-3:]
    
    _start = min(_current_idx)
    _end = max(_current_idx)
    _current_pat = price[_current_idx]
    return _current_idx,_current_pat,_start,_end 
    
def is_BAAM(moves,err_allowed):  
    XA=moves[0]
    AB=moves[1]
    
    
    X=prices[0]
    A=prices[1]
    B=prices[2]
    
    AB_range = np.array([0.68 - err_allowed,0.68+ err_allowed])*abs(XA)
    AB_range2 = np.array([0.15 - err_allowed,0.15+ err_allowed])*abs(XA)
    
    
    
    if abs(A-X)/X>0.001:
        
        if XA>0 and AB<0 :

            if (AB_range[0]<abs(AB)<AB_range[1]) or (AB_range2[0]<abs(AB)<AB_range2[1]) :

                BAAM = 1
                return (BAAM)
            else:
                return (np.isnan)

        elif XA<0 and AB>0 :


            if (AB_range[0]<abs(AB)<AB_range[1]) or (AB_range2[0]<abs(AB)<AB_range2[1]):

                BAAM = -1
                return (BAAM)
            else:
                return (np.isnan)
        else:
             return (np.isnan)

# %%
# %%time
df_resultats = pd.DataFrame(index=['TimeFrame 1','TimeFrame2','Equity','Nbre Winners','Nbre Loosers','Average lenght of trade','Cumul pnl'])

#TICKERS = [ 'EUR/USD','GBP/USD','EUR/JPY','GBP/JPY','EUR/AUD','GBP/AUD','EUR/NZD']

TICKERS = [ 'EUR/USD']

engine.say("קדימה")
engine.runAndWait()

err_allowed = 2/100
plt.ion()
position = 0
equity = 100000
for x in TICKERS:

    if x[4:] == 'USD':
        _rate = 1

    elif x[:3] == 'USD':
        con.subscribe_market_data(x)
        _rate = con.get_last_price(x).Bid
        con.unsubscribe_market_data(x)
    elif x[:3] != 'USD' and x[4:] != 'USD':
        try:
            con.subscribe_market_data(x[4:]+'/USD')
            _rate = con.get_last_price(x[4:]+'/USD').Bid
            con.unsubscribe_market_data(x[4:]+'/USD')
            _flag = 1
        except:
            con.subscribe_market_data('USD/'+x[4:])
            _rate = con.get_last_price('USD/'+x[4:]).Bid
            con.unsubscribe_market_data('USD/'+x[4:])
            _flag = -1
    else:
        prix_usd = 'NA'

    print(col.Fore.MAGENTA,'Le rate du ticker',x,'est à ',_rate,col.Style.RESET_ALL)
    label = ''
    data = scrap_hist(x,_number,_period)
    data2 = scrap_hist(x,_number,_period2)
    price = data.copy()
    price2 = data2.copy()
    _position = 0
    _equity = 0
    _nbtransactions = 0
    backtest_graph = pd.DataFrame()
    EQUITY = [_cash]
    CASH = [_cash]
    _winner = 0
    _looser = 0
    _index_entry = 0
    TRADE_DURATION = []
    _average_duration = 0
    _size = 50000

    PRICE_BUY = []
    PRICE_SELL = []
   
    _total = 0

    _target = 0.003
    _sl = 0.0015
    _spread_filter = 0.00050
    _filtre_multipoz = 0.1 # En %
    _filtre_multipoz = _filtre_multipoz/100
    
    _open_buy = 0
    _open_sell = 0
    _minipoz = 0
    
    MM21 = talib.EMA(price.Close, timeperiod=21)
    MM34 = talib.EMA(price.Close, timeperiod=34)
    MM54 = talib.EMA(price.Close, timeperiod=54)
    rsi = talib.RSI(price.Close, timeperiod=14)
    rsi_high = 70
    rsi_low = 30
    
    MM542 = talib.EMA(price2.Close, timeperiod=54)
    
    for i in range(150,len(price)-1):
        
        j = len(price2[price2.index <= price.index[i]])-1
        
        current_idx,current_pat,start,end = peak_detect(price.Close.values[:i+1])
        current_rsi = [rsi.iloc[current_idx[0]],rsi.iloc[current_idx[1]],rsi.iloc[current_idx[2]]]
        current_rsi_max = max(current_rsi)
        current_rsi_min = min(current_rsi)
        delta_price = current_pat[2] - current_pat[0]
        delta_rsi = current_rsi[2] - current_rsi[0]
      
        XA = current_pat[1] - current_pat[0]     
        AB = current_pat[2] - current_pat[1]      
        
        X = current_pat[0]
        A = current_pat[1]
        B = current_pat[2]

        prices =[X,A,B]

        moves=[XA,AB]
        
        BAAM = is_BAAM(moves,err_allowed)

        harmonics = np.array([BAAM])

        if _position == 0 :
            if (np.any(harmonics==1) and np.all(harmonics!=-1 )) or  (np.any(harmonics==-1) and np.all(harmonics!=1 )):

                for h in range(0, len(harmonics)):

                    if harmonics[h]==-1 and price.iloc[i]['Close']<MM21[i] and X>MM54[current_idx[0]] and MM21[current_idx[0]]>MM54[current_idx[0]] and MM21[i]<MM34[i]<MM54[i]\
                            and price2.Close[j]<MM542[j]:
                            _pnl = 0
                            _open_sell += 1
                            _equity = _cash + _pnl
                            EQUITY.append(_equity)
                            CASH.append(_cash)
                            _index_entry = i
                            _position = -1
                            _nbtransactions += 1
                            price_sell = price.Close_Bid.iloc[i]
                            PRICE_SELL.append(price_sell)
                            _price_sell_mean = round(sum(PRICE_SELL)/len(PRICE_SELL),5)
                            print('Position 1 sold at', price_sell,'(verification liste',PRICE_SELL[-1],')')
                            print('Nouvelle moyenne du price_sell',_price_sell_mean)

                            DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                            CONTRACT.append(x)
                            OPEN_POZ.append(-1)
                            CLOSE_POZ.append(0)
                            RATE_OPEN_POZ.append(price_sell)
                            RATE_CLOSE_POZ.append(0) 
                            PNL_LAT.append(_pnl)
                            PNL_REAL.append(0)
                            TOTAL_PNL_LAT.append(_pnl)
                            TOTAL_PNL_REAL.append(0)

                            TOTAL_OPEN.append(1)
                    
                    if harmonics[h]==1 and price.iloc[i]['Close']>MM21[i] and X<MM54[current_idx[0]] and MM21[current_idx[0]]<MM54[current_idx[0]] and MM21[i]>MM34[i]>MM54[i]\
                        and price2.Close[j]>MM542[j]:
                   
                            _pnl = 0
                            _open_buy += 1
                            _equity = _cash + _pnl
                            EQUITY.append(_equity)
                            CASH.append(_cash)
                            _position = 1
                            _index_entry = i
                            _nbtransactions += 1
                            price_buy = price.Close_Ask.iloc[i]
                            PRICE_BUY.append(price_buy)
                            _price_buy_mean = round(sum(PRICE_BUY)/len(PRICE_BUY),5)
                            print('Position 1 bought at', price_buy,'(verification liste',PRICE_BUY[-1],')')
                            print('Nouvelle moyenne du price_buy',_price_buy_mean)

                            DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                            CONTRACT.append(x)
                            OPEN_POZ.append(1)
                            CLOSE_POZ.append(0)
                            RATE_OPEN_POZ.append(price_buy)
                            RATE_CLOSE_POZ.append(0)
                            PNL_LAT.append(_pnl)
                            PNL_REAL.append(0)
                            TOTAL_OPEN.append(1) 
                            TOTAL_PNL_LAT.append(_pnl)
                            TOTAL_PNL_REAL.append(0) 

                    else :
                        _pnl = 0
                        _equity = _cash + _pnl
                        EQUITY.append(_equity)
                        CASH.append(_cash)
                
        elif _position == 1:

            for h in range(0, len(harmonics)):

            
                if (price_buy - price.Close[i])/price_buy>=_filtre_multipoz and  MM21[i]>MM34[i]>MM54[i]\
                and price2.Close[j]>MM542[j] and harmonics[h]==1:
                
                    _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                    _open_buy += 1
                    _equity = _cash + _pnl
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _position = 1
                    _index_entry = i
                    _nbtransactions += 1
                    price_buy = price.Close_Ask.iloc[i]
                    PRICE_BUY.append(price_buy)
                    _price_buy_mean = round(sum(PRICE_BUY)/len(PRICE_BUY),5)
                    print('Position',_open_buy,'bought at ', price_buy,'(verification liste',PRICE_BUY[-1],')')
                    print('Nouvelle moyenne du price_buy',_price_buy_mean)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(1)
                    CLOSE_POZ.append(0)
                    RATE_OPEN_POZ.append(price_buy)
                    RATE_CLOSE_POZ.append(0)
                    PNL_LAT.append(_pnl)
                    PNL_REAL.append(0)
                    TOTAL_OPEN.append(1) 
                    TOTAL_PNL_LAT.append(_pnl)
                    TOTAL_PNL_REAL.append(0) 


        

            if (float(price.Close_Bid.iloc[i]) - float(_price_buy_mean))/float(_price_buy_mean) >= _target :#slowd[i]>80:
        
                _position = 0
                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _winner += _open_buy

                TRADE_DURATION.append(i - _index_entry)
                print(_open_buy,'positions TP closed at',price.Close_Bid.iloc[i],col.Fore.GREEN,'pnl', _pnl,col.Style.RESET_ALL)
                print('nombre de candles en position :',i - _index_entry)
                print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_buy)
                PRICE_BUY = [] 
                _open_buy = 0

            elif ((float(price.Close_Bid.iloc[i]) - float(_price_buy_mean))/float(_price_buy_mean) <= -_sl) or \
                (PNL_LAT[-1] < -100) or ((i - _index_entry) > 30 and (float(price.Close_Bid.iloc[i]) - float(_price_buy_mean)) < 0):
                _position = 0
                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_buy

                TRADE_DURATION.append(i - _index_entry)
                print(_open_buy,'positions SL closed at',price.Close_Bid.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                print('nombre de candles en position :',i - _index_entry)
                print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_buy) 
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                PRICE_BUY = []
                _open_buy = 0
            else:

                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(0) ############### 
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_PNL_LAT.append(_pnl)
                TOTAL_PNL_REAL.append(0) 


        elif _position == -1:

            for h in range(0, len(harmonics)):
            
                if ( price.Close[i] - price_sell)/price_sell>=_filtre_multipoz and price.iloc[i]['Close']<MM21[i] and MM21[i]<MM34[i]<MM54[i]\
                and price2.Close[j]<MM542[j] and harmonics[h] == -1:
                    
                    _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                    _open_sell += 1
                    _equity = _cash + _pnl
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _position = -1
                    _index_entry = i
                    _nbtransactions += 1
                    price_sell = price.Close_Bid.iloc[i]
                    PRICE_SELL.append(price_sell)
                    _price_sell_mean = round(sum(PRICE_SELL)/len(PRICE_SELL),5)
                    print('Position 1 sold at', price_sell,'(verification liste',PRICE_SELL[-1],')')
                    print('Nouvelle moyenne du price_sell',_price_sell_mean)

                    DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                    CONTRACT.append(x)
                    OPEN_POZ.append(1)
                    CLOSE_POZ.append(0)
                    RATE_OPEN_POZ.append(price_sell)
                    RATE_CLOSE_POZ.append(0)
                    PNL_LAT.append(_pnl)
                    PNL_REAL.append(0)
                    TOTAL_OPEN.append(1) 
                    TOTAL_PNL_LAT.append(_pnl)
                    TOTAL_PNL_REAL.append(0) 



            if (float(price.Close_Ask.iloc[i]) - float(_price_sell_mean))/float(_price_sell_mean) <= -_target :
                _position = 0
                _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _winner += _open_sell
                TRADE_DURATION.append(i - _index_entry)
                print(_open_sell,'positions TP closed at',price.Close_Ask.iloc[i],col.Fore.GREEN,'pnl', _pnl,col.Style.RESET_ALL)
                print('nombre de candles en position :',i - _index_entry)
                print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(-1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Ask.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_sell)
                PRICE_SELL = [] 
                _open_sell = 0

            elif ((float(price.Close_Ask.iloc[i]) - float(_price_sell_mean))/float(_price_sell_mean) >= _sl) or \
                (PNL_LAT[-1] < -100) or ((i - _index_entry) > 30 and (float(price.Close_Ask.iloc[i]) - float(_price_sell_mean)>0)) :
                _position = 0
                _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_sell
                TRADE_DURATION.append(i - _index_entry)
                print(_open_sell,'position SL closed at',price.Close_Ask.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                print('nombre de candles en position :',i - _index_entry)
                print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(-1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Ask.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_sell)
                PRICE_SELL = []
                _open_sell = 0

            else:

                _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _equity = _cash + _pnl

                EQUITY.append(_equity)
                CASH.append(_cash)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(0)
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_PNL_LAT.append(_pnl)

                TOTAL_PNL_REAL.append(0)
              
        elif i == (len(price)-1) and _position != 0 :

            if _position == -1:
                _position = 0
                _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_sell
                TRADE_DURATION.append(i - _index_entry)
                print(col.Fore.CYAN,"Cloture des positions en l'air",col.Style.RESET_ALL)
                print(_open_sell,'position closed at',price.Close_Ask.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                print('nombre de candles en position :',i - _index_entry)
                print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(-1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Ask.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_sell)
                PRICE_SELL = []
                _open_sell = 0

            if _position == 1:

                _position = 0
                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_buy

                TRADE_DURATION.append(i - _index_entry)
                print(col.Fore.CYAN,"Cloture des positions en l'air",col.Style.RESET_ALL)
                print(_open_buy,'positions closed at',price.Close_Bid.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                print('nombre de candles en position :',i - _index_entry)
                print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_buy) 
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                PRICE_BUY = []
                _open_buy = 0

    try:
        _average_duration = round(statistics.mean(TRADE_DURATION),2)
    
    except:
        print("(pas de duration)") 
        _average_duration = 'NA' 
    print(col.Fore.BLUE,'Pour le ticker',col.Fore.YELLOW,x,col.Style.RESET_ALL)              
    print(col.Fore.MAGENTA,"\nLes gains faramineux s'élèvent à : $",col.Fore.GREEN,round(_total,2),'!. En ',_nbtransactions,' transactions.',col.Style.RESET_ALL ) 
    print(col.Fore.GREEN,"\nNbre de winners :",_winner,col.Style.RESET_ALL)
    print(col.Fore.RED,"\nNbre de loosers :",_looser,col.Style.RESET_ALL)
    print("\nAverage trade duration ",_average_duration)
    backtest_graph['Equity'] = EQUITY
    
    df_resultats[x] = [_period,_period2,(round(_equity,2)),(_winner),(_looser),(_average_duration),(_total)]

    print('Total des gains faramineux :',round(EQUITY[-1] - _cash_ini,2))
    print('Pnl latent restant',_pnl,'Open Buy',_open_buy,'Open Sell',_open_sell)
    DER_POZ.append(_pnl)

engine.say("Finito caucau")
engine.runAndWait()
# Out:
#  Le rate du ticker EUR/USD est à  1
#  Scraping des données OHLC pour le ticker  EUR/USD
#  Scraping des données OHLC pour le ticker  EUR/USD
# Position 1 sold at 1.16915 (verification liste 1.16915 )
# Nouvelle moyenne du price_sell 1.16915
# 1 positions TP closed at 1.16527  pnl 193.99999999999417
# nombre de candles en position : 74
# Equity : 200194.0
# Position 1 sold at 1.1661 (verification liste 1.1661 )
# Nouvelle moyenne du price_sell 1.1661
# 1 position SL closed at 1.16639  pnl -14.500000000006175
# nombre de candles en position : 50
# Equity : 200179.5
# Position 1 sold at 1.16516 (verification liste 1.16516 )
# Nouvelle moyenne du price_sell 1.16516
# 1 positions TP closed at 1.16156  pnl 180.0000000000024
# nombre de candles en position : 67
# Equity : 200359.5
# Position 1 bought at 1.16589 (verification liste 1.16589 )
# Nouvelle moyenne du price_buy 1.16589
# 1 positions SL closed at 1.16548  pnl -20.500000000001073
# nombre de candles en position : 48
# Equity : 200339.0
# Position 1 bought at 1.16631 (verification liste 1.16631 )
# Nouvelle moyenne du price_buy 1.16631
# 1 positions SL closed at 1.16615  pnl -7.9999999999968985
# nombre de candles en position : 31
# Equity : 200331.0
# Position 1 bought at 1.17267 (verification liste 1.17267 )
# Nouvelle moyenne du price_buy 1.17267
# 1 positions SL closed at 1.17166  pnl -50.50000000000887
# nombre de candles en position : 31
# Equity : 200280.5
# Position 1 bought at 1.17243 (verification liste 1.17243 )
# Nouvelle moyenne du price_buy 1.17243
# 1 positions SL closed at 1.17236  pnl -3.5000000000007248
# nombre de candles en position : 38
# Equity : 200277.0
# Position 1 bought at 1.1737 (verification liste 1.1737 )
# Nouvelle moyenne du price_buy 1.1737
# 1 positions SL closed at 1.17331  pnl -19.49999999999452
# nombre de candles en position : 69
# Equity : 200257.5
# Position 1 bought at 1.17455 (verification liste 1.17455 )
# Nouvelle moyenne du price_buy 1.17455
# 1 positions SL closed at 1.17426  pnl -14.499999999995072
# nombre de candles en position : 35
# Equity : 200243.0
# Position 1 bought at 1.17521 (verification liste 1.17521 )
# Nouvelle moyenne du price_buy 1.17521
# 1 positions SL closed at 1.17407  pnl -57.00000000000705
# nombre de candles en position : 31
# Equity : 200186.0
# Position 1 sold at 1.17351 (verification liste 1.17351 )
# Nouvelle moyenne du price_sell 1.17351
# 1 position SL closed at 1.17361  pnl -4.999999999999449
# nombre de candles en position : 61
# Equity : 200181.0
# Position 1 sold at 1.17211 (verification liste 1.17211 )
# Nouvelle moyenne du price_sell 1.17211
# 1 position SL closed at 1.17216  pnl -2.500000000005276
# nombre de candles en position : 32
# Equity : 200178.5
# Position 1 sold at 1.17062 (verification liste 1.17062 )
# Nouvelle moyenne du price_sell 1.17062
# 1 position SL closed at 1.17084  pnl -11.00000000000545
# nombre de candles en position : 31
# Equity : 200167.5
# Position 1 bought at 1.17401 (verification liste 1.17401 )
# Nouvelle moyenne du price_buy 1.17401
# 1 positions TP closed at 1.17828  pnl 213.4999999999998
# nombre de candles en position : 62
# Equity : 200381.0
# Position 1 bought at 1.17849 (verification liste 1.17849 )
# Nouvelle moyenne du price_buy 1.17849
# 1 positions SL closed at 1.1782  pnl -14.500000000006175
# nombre de candles en position : 114
# Equity : 200366.5
# Position 1 bought at 1.17617 (verification liste 1.17617 )
# Nouvelle moyenne du price_buy 1.17617
# 1 positions SL closed at 1.17603  pnl -7.0000000000014495
# nombre de candles en position : 31
# Equity : 200359.5
# Position 1 sold at 1.17612 (verification liste 1.17612 )
# Nouvelle moyenne du price_sell 1.17612
# 1 position SL closed at 1.17655  pnl -21.499999999996522
# nombre de candles en position : 45
# Equity : 200338.0
# Position 1 sold at 1.17971 (verification liste 1.17971 )
# Nouvelle moyenne du price_sell 1.17971
# 1 position SL closed at 1.17988  pnl -8.500000000000174
# nombre de candles en position : 45
# Equity : 200329.5
# Position 1 sold at 1.17834 (verification liste 1.17834 )
# Nouvelle moyenne du price_sell 1.17834
# 1 positions TP closed at 1.17442  pnl 195.9999999999962
# nombre de candles en position : 13
# Equity : 200525.5
# Position 1 sold at 1.17467 (verification liste 1.17467 )
# Nouvelle moyenne du price_sell 1.17467
# 1 position SL closed at 1.17474  pnl -3.4999999999896225
# nombre de candles en position : 41
# Equity : 200522.0
# Position 1 sold at 1.17331 (verification liste 1.17331 )
# Nouvelle moyenne du price_sell 1.17331
# 1 position SL closed at 1.17349  pnl -8.999999999992347
# nombre de candles en position : 32
# Equity : 200513.0
# Position 1 sold at 1.17362 (verification liste 1.17362 )
# Nouvelle moyenne du price_sell 1.17362
# 1 positions TP closed at 1.16958  pnl 202.0000000000022
# nombre de candles en position : 56
# Equity : 200715.0
# Position 1 sold at 1.17036 (verification liste 1.17036 )
# Nouvelle moyenne du price_sell 1.17036
# 1 position SL closed at 1.17066  pnl -14.999999999998348
# nombre de candles en position : 31
# Equity : 200700.0
# Position 1 sold at 1.17158 (verification liste 1.17158 )
# Nouvelle moyenne du price_sell 1.17158
# 1 position SL closed at 1.17169  pnl -5.499999999991623
# nombre de candles en position : 31
# Equity : 200694.5
# Position 1 sold at 1.17134 (verification liste 1.17134 )
# Nouvelle moyenne du price_sell 1.17134
# 1 position SL closed at 1.17148  pnl -7.0000000000014495
# nombre de candles en position : 33
# Equity : 200687.5
# Position 1 sold at 1.17126 (verification liste 1.17126 )
# Nouvelle moyenne du price_sell 1.17126
# 1 position SL closed at 1.17133  pnl -3.5000000000007248
# nombre de candles en position : 43
# Equity : 200684.0
# Position 1 bought at 1.17873 (verification liste 1.17873 )
# Nouvelle moyenne du price_buy 1.17873
# 1 positions TP closed at 1.18247  pnl 186.99999999999272
# nombre de candles en position : 61
# Equity : 200871.0
# Position 1 bought at 1.18575 (verification liste 1.18575 )
# Nouvelle moyenne du price_buy 1.18575
# 1 positions SL closed at 1.18521  pnl -26.999999999999247
# nombre de candles en position : 31
# Equity : 200844.0
# Position 1 bought at 1.18383 (verification liste 1.18383 )
# Nouvelle moyenne du price_buy 1.18383
# 1 positions SL closed at 1.18322  pnl -30.49999999999997
# nombre de candles en position : 68
# Equity : 200813.5
# Position 1 bought at 1.18558 (verification liste 1.18558 )
# Nouvelle moyenne du price_buy 1.18558
# 1 positions SL closed at 1.18531  pnl -13.499999999999623
# nombre de candles en position : 34
# Equity : 200800.0
# Position 1 sold at 1.18226 (verification liste 1.18226 )
# Nouvelle moyenne du price_sell 1.18226
# 1 position SL closed at 1.18255  pnl -14.499999999995072
# nombre de candles en position : 31
# Equity : 200785.5
# Position 1 sold at 1.18088 (verification liste 1.18088 )
# Nouvelle moyenne du price_sell 1.18088
# 1 position SL closed at 1.18109  pnl -10.500000000002174
# nombre de candles en position : 31
# Equity : 200775.0
# Position 1 sold at 1.18043 (verification liste 1.18043 )
# Nouvelle moyenne du price_sell 1.18043
# 1 position SL closed at 1.18221  pnl -88.99999999999464
# nombre de candles en position : 31
# Equity : 200686.0
# Position 1 bought at 1.18294 (verification liste 1.18294 )
# Nouvelle moyenne du price_buy 1.18294
# 1 positions SL closed at 1.18274  pnl -10.000000000010001
# nombre de candles en position : 33
# Equity : 200676.0
# Position 1 sold at 1.18142 (verification liste 1.18142 )
# Nouvelle moyenne du price_sell 1.18142
# 1 positions TP closed at 1.17739  pnl 201.4999999999989
# nombre de candles en position : 33
# Equity : 200877.5
# Position 1 sold at 1.17697 (verification liste 1.17697 )
# Nouvelle moyenne du price_sell 1.17697
# 1 positions TP closed at 1.17333  pnl 182.00000000000438
# nombre de candles en position : 46
# Equity : 201059.5
# Position 1 sold at 1.17291 (verification liste 1.17291 )
# Nouvelle moyenne du price_sell 1.17291
# 1 positions TP closed at 1.16921  pnl 184.99999999999073
# nombre de candles en position : 65
# Equity : 201244.5
# Position 1 sold at 1.16515 (verification liste 1.16515 )
# Nouvelle moyenne du price_sell 1.16515
# 1 position SL closed at 1.16532  pnl -8.500000000000174
# nombre de candles en position : 55
# Equity : 201236.0
# Position 1 sold at 1.16358 (verification liste 1.16358 )
# Nouvelle moyenne du price_sell 1.16358
# 1 position SL closed at 1.16362  pnl -2.000000000002
# nombre de candles en position : 74
# Equity : 201234.0
# Position 1 bought at 1.17303 (verification liste 1.17303 )
# Nouvelle moyenne du price_buy 1.17303
# 1 positions SL closed at 1.17279  pnl -12.000000000000899
# nombre de candles en position : 48
# Equity : 201222.0
#  Pour le ticker  EUR/USD
#
# Les gains faramineux s'élèvent à : $  1222.0 !. En  40  transactions.
#
# Nbre de winners : 9
#
# Nbre de loosers : 31
#
# Average trade duration  45.4
# Total des gains faramineux : 1222.0
# Pnl latent restant 0 Open Buy 0 Open Sell 0
# CPU times: user 16.4 s, sys: 454 ms, total: 16.9 s
# Wall time: 23.7 s

# %%
df_historical = pd.DataFrame()
df_historical = pd.DataFrame(index=DATE)
df_historical['Contract'] = CONTRACT
df_historical['Open_Poz'] = OPEN_POZ
df_historical['Close_Pos'] = CLOSE_POZ
df_historical['Rate_Open_Poz'] = RATE_OPEN_POZ 
df_historical['Rate_Close_Poze'] = RATE_CLOSE_POZ
df_historical['Pnl_Lat'] = TOTAL_PNL_LAT
df_historical['Pnl_Real'] = TOTAL_PNL_REAL
df_historical = df_historical.sort_index()
_generated_cash = round(df_historical.Pnl_Real.sum(),2)
if _generated_cash <= 0:
     print('Cash généré :',col.Fore.RED,str(_generated_cash)+'$',col.Style.RESET_ALL)
else:
    print('Cash généré :',col.Fore.GREEN,str(_generated_cash)+'$',col.Style.RESET_ALL)
print('Pnl latent minimal :',str(df_historical.Pnl_Real.min())+'$')
print('Pnl latent maximal :',str(df_historical.Pnl_Real.max())+'$')
print('Pnl latent moyen :',str(round(df_historical.Pnl_Real.mean(),2))+'$')
print('Max des durées moyennes',df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].max())
print('Min des durées moyennes',df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].min())
print('Moyenne des durées moyennes',round(df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].mean(),2))
print('Nombre total de winners',df_resultats.T['Nbre Winners'].sum())
print('Nombre total de loosers',df_resultats.T['Nbre Loosers'].sum())
print('Total des gains cumulés',round(df_historical[df_historical.Pnl_Real>0].Pnl_Real.sum(),2))
print('Total des pertes cumulées',round(df_historical[df_historical.Pnl_Real<0].Pnl_Real.sum(),2))
print(col.Fore.BLUE,'PROFIT FACTOR : ',\
    abs(round(df_historical[df_historical.Pnl_Real>0].Pnl_Real.sum()/df_historical[df_historical.Pnl_Real<0].Pnl_Real.sum(),2)),col.Style.RESET_ALL)
print(col.Fore.CYAN,'Ratio du nombre de winners :',\
    round((df_resultats.T['Nbre Winners'].sum()*100)/(df_resultats.T['Nbre Loosers'].sum()+df_resultats.T['Nbre Winners'].sum()),2),'%',col.Style.RESET_ALL)
print('Average Winners',round(sum(list(filter(lambda x:  x > 0,PNL_REAL)))/len(list(filter(lambda x:  x > 0,PNL_REAL)))),2)
print('Average Loosers',round(sum(list(filter(lambda x:  x < 0,PNL_REAL)))/len(list(filter(lambda x:  x < 0,PNL_REAL)))),2)
print('Average pnl',round(sum(PNL_REAL)/len(set(PNL_REAL))),2)
print('Nombre total de trades ouverts',sum(TOTAL_OPEN))
print('Nombre total de trades fermés',sum(TOTAL_CLOSE))
print("Nombre de positions en l'air",(sum(TOTAL_OPEN) - sum(TOTAL_CLOSE)))
# Out:
# Cash généré :  1222.0$
# Pnl latent minimal : -88.99999999999464$
# Pnl latent maximal : 213.4999999999998$
# Pnl latent moyen : 0.66$
# Max des durées moyennes 45.4
# Min des durées moyennes 45.4
# Moyenne des durées moyennes 45.4
# Nombre total de winners 9
# Nombre total de loosers 31
# Total des gains cumulés 1741.0
# Total des pertes cumulées -519.0
#  PROFIT FACTOR :  3.35
#  Ratio du nombre de winners : 22.5 %
# Average Winners 193.0 2
# Average Loosers -17.0 2
# Average pnl 34.0 2
# Nombre total de trades ouverts 40
# Nombre total de trades fermés 40
# Nombre de positions en l'air 0

# %%
###################### BIG BAZ #######################

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.dates as mdates
import pandas as pd
from numpy import loadtxt
from functools import reduce
import talib
import time
from scipy.signal import argrelextrema
from ipywidgets import *

from datetime import datetime

DATE = []
CONTRACT = []
OPEN_POZ = []
CLOSE_POZ = []
RATE_OPEN_POZ = []
RATE_CLOSE_POZ = []
PNL_LAT = []
PNL_REAL = []
TOTAL_OPEN = []
TOTAL_CLOSE = []
PRICE_BUY = []
PRICE_SELL = []
DER_POZ = []
TOTAL_PNL_LAT = []
TOTAL_PNL_REAL = []
_cash = _cash_ini
WINNERS = []
LOOSERS = []

_year_top = '2015-12-31 23:59:59'
_year_bottom = '2015-01-01 00:00:01'

_verbose = 1

# %%
def peak_detect(price,order=10):
    max_idx = list(argrelextrema(price,np.greater,order=order)[0])
    min_idx = list(argrelextrema(price,np.less,order=order)[0])
    idx = max_idx + min_idx + [len(price)-1]
    idx.sort()
    _current_idx = idx[-3:]
    
    _start = min(_current_idx)
    _end = max(_current_idx)
    _current_pat = price[_current_idx]
    return _current_idx,_current_pat,_start,_end 
    
def is_BAAM(moves,err_allowed):  
    XA=moves[0]
    AB=moves[1]
    
    
    X=prices[0]
    A=prices[1]
    B=prices[2]
    
    AB_range = np.array([0.68 - err_allowed,0.68+ err_allowed])*abs(XA)
    AB_range2 = np.array([0.15 - err_allowed,0.15+ err_allowed])*abs(XA)
    
    
    
    if abs(A-X)/X>0.001:
        
        if XA>0 and AB<0 :

            if (AB_range[0]<abs(AB)<AB_range[1]) or (AB_range2[0]<abs(AB)<AB_range2[1]) :

                BAAM = 1
                return (BAAM)
            else:
                return (np.isnan)

        elif XA<0 and AB>0 :


            if (AB_range[0]<abs(AB)<AB_range[1]) or (AB_range2[0]<abs(AB)<AB_range2[1]):

                BAAM = -1
                return (BAAM)
            else:
                return (np.isnan)
        else:
             return (np.isnan)

# %%
# %%time


TICKERS = [ 'EUR/USD']

engine.say("קדימה")
engine.runAndWait()

err_allowed = 2/100
plt.ion()
position = 0
equity = 100000
for x in TICKERS:

    if x[4:] == 'USD':
        _rate = 1

    elif x[:3] == 'USD':
        con.subscribe_market_data(x)
        _rate = con.get_last_price(x).Bid
        con.unsubscribe_market_data(x)
    elif x[:3] != 'USD' and x[4:] != 'USD':
        try:
            con.subscribe_market_data(x[4:]+'/USD')
            _rate = con.get_last_price(x[4:]+'/USD').Bid
            con.unsubscribe_market_data(x[4:]+'/USD')
            _flag = 1
        except:
            con.subscribe_market_data('USD/'+x[4:])
            _rate = con.get_last_price('USD/'+x[4:]).Bid
            con.unsubscribe_market_data('USD/'+x[4:])
            _flag = -1
    else:
        prix_usd = 'NA'

    print(col.Fore.MAGENTA,'Le rate du ticker',x,'est à ',_rate,col.Style.RESET_ALL)
    label = ''
    data = pd.read_csv('Base_Clean/EURUSDm5.csv')
    data2 = pd.read_csv('Base_Clean/EURUSDH1.csv')

    data.index = pd.to_datetime(data['Date'])
    data = data.drop(['Date','Total'],axis=1)
    data.rename(columns={'OpenBid':'Open_Bid','HighBid':'High_Bid','LowBid':'Low_Bid','CloseBid':'Close_Bid',\
        'OpenAsk':'Open_Ask','HighAsk':'High_Ask','LowAsk':'Low_Ask','CloseAsk':'Close_Ask'},inplace = True)

    data2.index = pd.to_datetime(data2['Date'])
    data2 = data2.drop(['Date','Total'],axis=1)
    data2.rename(columns={'OpenBid':'Open_Bid','HighBid':'High_Bid','LowBid':'Low_Bid','CloseBid':'Close_Bid',\
        'OpenAsk':'Open_Ask','HighAsk':'High_Ask','LowAsk':'Low_Ask','CloseAsk':'Close_Ask'},inplace = True)

    data = data[(data.index >= _year_bottom) & (data.index <= _year_top)]
    data2 = data2[(data2.index >= _year_bottom) & (data2.index <= _year_top)]

    price = data.copy()
    price2 = data2.copy()
    _position = 0
    _equity = 0
    _nbtransactions = 0
    backtest_graph = pd.DataFrame()
    EQUITY = [_cash]
    CASH = [_cash]
    _winner = 0
    _looser = 0
    _index_entry = 0
    TRADE_DURATION = []
    _average_duration = 0
    _size = 50000

    PRICE_BUY = []
    PRICE_SELL = []
   
    _total = 0

    _target = 0.003
    _sl = 0.0015
    _spread_filter = 0.00050
    _filtre_multipoz = 0.1 # En %
    _filtre_multipoz = _filtre_multipoz/100
    
    _open_buy = 0
    _open_sell = 0
    _minipoz = 0
    
    MM21 = talib.EMA(price.Close, timeperiod=21)
    MM34 = talib.EMA(price.Close, timeperiod=34)
    MM54 = talib.EMA(price.Close, timeperiod=54)
    rsi = talib.RSI(price.Close, timeperiod=14)
    rsi_high = 70
    rsi_low = 30
    
    MM542 = talib.EMA(price2.Close, timeperiod=54)
    
    for i in range(150,len(price)-1):
        
        j = len(price2[price2.index <= price.index[i]])-1
        
        current_idx,current_pat,start,end = peak_detect(price.Close.values[:i+1])
        current_rsi = [rsi.iloc[current_idx[0]],rsi.iloc[current_idx[1]],rsi.iloc[current_idx[2]]]
        current_rsi_max = max(current_rsi)
        current_rsi_min = min(current_rsi)
        delta_price = current_pat[2] - current_pat[0]
        delta_rsi = current_rsi[2] - current_rsi[0]
      
        XA = current_pat[1] - current_pat[0]     
        AB = current_pat[2] - current_pat[1]      
        
        X = current_pat[0]
        A = current_pat[1]
        B = current_pat[2]

        prices =[X,A,B]

        moves=[XA,AB]
        
        BAAM = is_BAAM(moves,err_allowed)

        harmonics = np.array([BAAM])

        if _position == 0 :
            if (np.any(harmonics==1) and np.all(harmonics!=-1 )) or  (np.any(harmonics==-1) and np.all(harmonics!=1 )):

                for h in range(0, len(harmonics)):

                    if harmonics[h]==-1 and price.iloc[i]['Close']<MM21[i] and X>MM54[current_idx[0]] and MM21[current_idx[0]]>MM54[current_idx[0]] and MM21[i]<MM34[i]<MM54[i]\
                            and price2.Close[j]<MM542[j]:
                            _pnl = 0
                            _open_sell += 1
                            _equity = _cash + _pnl
                            EQUITY.append(_equity)
                            CASH.append(_cash)
                            _index_entry = i
                            _position = -1
                            _nbtransactions += 1
                            price_sell = price.Close_Bid.iloc[i]
                            PRICE_SELL.append(price_sell)
                            _price_sell_mean = round(sum(PRICE_SELL)/len(PRICE_SELL),5)
                            if _verbose == 1:
                                print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                                print('Position 1 sold at', price_sell,'(verification liste',PRICE_SELL[-1],')')
                                print('Nouvelle moyenne du price_sell',_price_sell_mean)

                            DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                            CONTRACT.append(x)
                            OPEN_POZ.append(-1)
                            CLOSE_POZ.append(0)
                            RATE_OPEN_POZ.append(price_sell)
                            RATE_CLOSE_POZ.append(0) 
                            PNL_LAT.append(_pnl)
                            PNL_REAL.append(0)
                            TOTAL_PNL_LAT.append(_pnl)
                            TOTAL_PNL_REAL.append(0)

                            TOTAL_OPEN.append(1)
                    
                    if harmonics[h]==1 and price.iloc[i]['Close']>MM21[i] and X<MM54[current_idx[0]] and MM21[current_idx[0]]<MM54[current_idx[0]] and MM21[i]>MM34[i]>MM54[i]\
                        and price2.Close[j]>MM542[j]:
                   
                            _pnl = 0
                            _open_buy += 1
                            _equity = _cash + _pnl
                            EQUITY.append(_equity)
                            CASH.append(_cash)
                            _position = 1
                            _index_entry = i
                            _nbtransactions += 1
                            price_buy = price.Close_Ask.iloc[i]
                            PRICE_BUY.append(price_buy)
                            _price_buy_mean = round(sum(PRICE_BUY)/len(PRICE_BUY),5)
                            if _verbose == 1:
                                print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                                print('Position 1 bought at', price_buy,'(verification liste',PRICE_BUY[-1],')')
                                print('Nouvelle moyenne du price_buy',_price_buy_mean)

                            DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                            CONTRACT.append(x)
                            OPEN_POZ.append(1)
                            CLOSE_POZ.append(0)
                            RATE_OPEN_POZ.append(price_buy)
                            RATE_CLOSE_POZ.append(0)
                            PNL_LAT.append(_pnl)
                            PNL_REAL.append(0)
                            TOTAL_OPEN.append(1) 
                            TOTAL_PNL_LAT.append(_pnl)
                            TOTAL_PNL_REAL.append(0) 

                    else :
                        _pnl = 0
                        _equity = _cash + _pnl
                        EQUITY.append(_equity)
                        CASH.append(_cash)
                
        elif _position == 1:

            
            if (price_buy - price.Close_Bid[i])/price_buy>=_filtre_multipoz and  MM21[i]>MM34[i]>MM54[i]\
            and price2.High_Bid[j]>MM542[j] and harmonics[h]==1:
            
                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _open_buy += 1
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)
                _position = 1
                _index_entry = i
                _nbtransactions += 1
                price_buy = price.Close_Ask.iloc[i]
                PRICE_BUY.append(price_buy)
                _price_buy_mean = round(sum(PRICE_BUY)/len(PRICE_BUY),5)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print('Position',_open_buy,'bought at ', price_buy,'(verification liste',PRICE_BUY[-1],')')
                    print('Nouvelle moyenne du price_buy',_price_buy_mean)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(1)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(price_buy)
                RATE_CLOSE_POZ.append(0)
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_OPEN.append(1) 
                TOTAL_PNL_LAT.append(_pnl)
                TOTAL_PNL_REAL.append(0) 


        

            if (float(price.Low_Bid.iloc[i]) - float(_price_buy_mean))/float(_price_buy_mean) >= _target :#slowd[i]>80:
        
                _position = 0
                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _winner += _open_buy

                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print(_open_buy,'positions TP closed at',price.Low_Bid.iloc[i],col.Fore.GREEN,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Low_Bid.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_buy)
                PRICE_BUY = [] 
                _open_buy = 0

            elif ((float(price.Low_Bid.iloc[i]) - float(_price_buy_mean))/float(_price_buy_mean) <= -_sl) or \
                (PNL_LAT[-1] < -500) or ((i - _index_entry) > 30 and (float(price.High_Bid.iloc[i]) - float(_price_buy_mean)) < 0):
                _position = 0
                _pnl = (price.Low_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_buy

                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print(_open_buy,'positions SL closed at',price.Low_Bid.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.High_Bid.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_buy) 
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                PRICE_BUY = []
                _open_buy = 0
            else:

                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(0) ############### 
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_PNL_LAT.append(_pnl)
                TOTAL_PNL_REAL.append(0) 


        elif _position == -1:

            
            
            if ( price.Close_Bid[i] - price_sell)/price_sell>=_filtre_multipoz and price.iloc[i]['Low_Ask']<MM21[i] and MM21[i]<MM34[i]<MM54[i]\
            and price2.Close_Bid[j]<MM542[j] and harmonics[h] == -1:
                
                _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _open_sell += 1
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)
                _position = -1
                _index_entry = i
                _nbtransactions += 1
                price_sell = price.Close_Bid.iloc[i]
                PRICE_SELL.append(price_sell)
                _price_sell_mean = round(sum(PRICE_SELL)/len(PRICE_SELL),5)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print('Position 1 sold at', price_sell,'(verification liste',PRICE_SELL[-1],')')
                    print('Nouvelle moyenne du price_sell',_price_sell_mean)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(1)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(price_sell)
                RATE_CLOSE_POZ.append(0)
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_OPEN.append(1) 
                TOTAL_PNL_LAT.append(_pnl)
                TOTAL_PNL_REAL.append(0) 



            if (float(price.High_Ask.iloc[i]) - float(_price_sell_mean))/float(_price_sell_mean) <= -_target :
                _position = 0
                _pnl = - (price.High_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _winner += _open_sell
                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print(_open_sell,'positions TP closed at',price.High_Ask.iloc[i],col.Fore.GREEN,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(-1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.High_Ask.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_sell)
                PRICE_SELL = [] 
                _open_sell = 0

            elif ((float(price.Low_Ask.iloc[i]) - float(_price_sell_mean))/float(_price_sell_mean) >= _sl) or \
                (PNL_LAT[-1] < -500) or ((i - _index_entry) > 30 and (float(price.Low_Ask.iloc[i]) - float(_price_sell_mean)>0)) :
                _position = 0
                _pnl = - (price.Low_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_sell
                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)    
                    print(_open_sell,'position SL closed at',price.Low_Ask.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(-1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Low_Ask.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_sell)
                PRICE_SELL = []
                _open_sell = 0

            else:

                _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _equity = _cash + _pnl

                EQUITY.append(_equity)
                CASH.append(_cash)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(0)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(0)
                PNL_LAT.append(_pnl)
                PNL_REAL.append(0)
                TOTAL_PNL_LAT.append(_pnl)

                TOTAL_PNL_REAL.append(0)
              
        elif i == (len(price)-1) and _position != 0 :

            if _position == -1:
                _position = 0
                _pnl = - (price.Close_Ask.iloc[i] - _price_sell_mean) * _size * _open_sell
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_sell
                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print(col.Fore.CYAN,"Cloture des positions en l'air",col.Style.RESET_ALL)
                    print(_open_sell,'position closed at',price.Close_Ask.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(-1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Ask.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_sell)
                PRICE_SELL = []
                _open_sell = 0

            if _position == 1:

                _position = 0
                _pnl = (price.Close_Bid.iloc[i] - _price_buy_mean) * _size * _open_buy
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += _open_buy

                TRADE_DURATION.append(i - _index_entry)
                if _verbose == 1:
                    print(col.Fore.MAGENTA,price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'),col.Style.RESET_ALL)
                    print(col.Fore.CYAN,"Cloture des positions en l'air",col.Style.RESET_ALL)
                    print(_open_buy,'positions closed at',price.Close_Bid.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)

                DATE.append(price.index[i].strftime(format='%Y-%m-%d %H:%M:%S'))
                CONTRACT.append(x)
                OPEN_POZ.append(0)
                CLOSE_POZ.append(1)
                RATE_OPEN_POZ.append(0)
                RATE_CLOSE_POZ.append(price.Close_Bid.iloc[i])
                PNL_LAT.append(0)
                PNL_REAL.append(_pnl)
                TOTAL_CLOSE.append(_open_buy) 
                TOTAL_PNL_LAT.append(0)
                TOTAL_PNL_REAL.append(_pnl)
                PRICE_BUY = []
                _open_buy = 0

    try:
        _average_duration = round(statistics.mean(TRADE_DURATION),2)
    
    except:
        print("(pas de duration)") 
        _average_duration = 'NA' 
    print(col.Fore.BLUE,'Pour le ticker',col.Fore.YELLOW,x,col.Style.RESET_ALL)              
    print(col.Fore.MAGENTA,"\nLes gains faramineux s'élèvent à : $",col.Fore.GREEN,round(_total,2),'!. En ',_nbtransactions,' transactions.',col.Style.RESET_ALL ) 
    print(col.Fore.GREEN,"\nNbre de winners :",_winner,col.Style.RESET_ALL)
    print(col.Fore.RED,"\nNbre de loosers :",_looser,col.Style.RESET_ALL)
    print("\nAverage trade duration ",_average_duration)
    backtest_graph['Equity'] = EQUITY
    
    df_resultats[x] = [_period,_period2,(round(_equity,2)),(_winner),(_looser),(_average_duration),(_total)]

    print('Total des gains faramineux :',round((EQUITY[-1] - _cash_ini) * _rate,2))
    print('Pnl latent restant',_pnl,'Open Buy',_open_buy,'Open Sell',_open_sell)
    DER_POZ.append(_pnl)

engine.say("Finito caucau")
engine.runAndWait()
# Out:
# |ERROR|2020-11-09 23:01:30,172|Server reports an error: {'executed': False, 'error': 'Cannot subscribe to symbol: JPY/USD'}.
# |ERROR|2020-11-09 23:01:30,172|URL: https://api-demo.fxcm.com:443/subscribe
# |ERROR|2020-11-09 23:01:30,173|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer 8UgAAjVTZQqbUzswAMNu4973fff4a559fa6e5a25dfd3e7c8f9367f04378b', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '15'}
# |ERROR|2020-11-09 23:01:30,174|Params: {'pairs': 'JPY/USD'}
# |ERROR|2020-11-09 23:01:30,175|Bearer token: Bearer 8UgAAjVTZQqbUzswAMNu4973fff4a559fa6e5a25dfd3e7c8f9367f04378b
# |ERROR|2020-11-09 23:01:30,176|Connection status: established
# |ERROR|2020-11-09 23:01:30,176|Socket session id: 8UgAAjVTZQqbUzswAMNu
# |ERROR|2020-11-09 23:01:30,177|Can not parse server answer to json object: {"response":{"executed":false,"error":"Cannot subscribe to symbol: JPY/USD"},"pairs":[]}.
#  Le rate du ticker GBP/JPY est à  105.32000000000002
#  Pour le ticker  GBP/JPY
#
# Les gains faramineux s'élèvent à : $  27.73 !. En  247  transactions.
#
# Nbre de winners : 45
#
# Nbre de loosers : 202
#
# Average trade duration  56.51
# Total des gains faramineux : 2920.52
# Pnl latent restant 0 Open Buy 0 Open Sell 0
# CPU times: user 6min 6s, sys: 6.18 s, total: 6min 12s
# Wall time: 6min 19s

# %%
df_historical = pd.DataFrame()
df_historical = pd.DataFrame(index=DATE)
df_historical['Contract'] = CONTRACT
df_historical['Open_Poz'] = OPEN_POZ
df_historical['Close_Pos'] = CLOSE_POZ
df_historical['Rate_Open_Poz'] = RATE_OPEN_POZ 
df_historical['Rate_Close_Poze'] = RATE_CLOSE_POZ
df_historical['Pnl_Lat'] = TOTAL_PNL_LAT
df_historical['Pnl_Real'] = TOTAL_PNL_REAL
df_historical = df_historical.sort_index()
_generated_cash = round(df_historical.Pnl_Real.sum() * _rate,2)
if _generated_cash <= 0:
     print('Cash généré :',col.Fore.RED,str(_generated_cash)+'$',col.Style.RESET_ALL)
else:
    print('Cash généré :',col.Fore.GREEN,str(_generated_cash)+'$',col.Style.RESET_ALL)
print('Pnl latent minimal :',str((df_historical.Pnl_Real.min()) * _rate)+'$')
print('Pnl latent maximal :',str((df_historical.Pnl_Real.max())* _rate)+'$')
print('Pnl latent moyen :',str(round(df_historical.Pnl_Real.mean()* _rate,2))+'$')
print('Max des durées moyennes',df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].max())
print('Min des durées moyennes',df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].min())
print('Moyenne des durées moyennes',round(df_resultats.T['Average lenght of trade'][df_resultats.T['Average lenght of trade'] != 'NA'].mean(),2))
print('Nombre total de winners',df_resultats.T['Nbre Winners'].sum())
print('Nombre total de loosers',df_resultats.T['Nbre Loosers'].sum())
print('Total des gains cumulés',round(df_historical[df_historical.Pnl_Real>0].Pnl_Real.sum() * _rate,2))
print('Total des pertes cumulées',round(df_historical[df_historical.Pnl_Real<0].Pnl_Real.sum() * _rate,2))
print(col.Fore.BLUE,'PROFIT FACTOR : ',\
    abs(round(df_historical[df_historical.Pnl_Real>0].Pnl_Real.sum()/df_historical[df_historical.Pnl_Real<0].Pnl_Real.sum(),2)),col.Style.RESET_ALL)
print(col.Fore.CYAN,'Ratio du nombre de winners :',\
    round((df_resultats.T['Nbre Winners'].sum()*100)/(df_resultats.T['Nbre Loosers'].sum()+df_resultats.T['Nbre Winners'].sum()),2),'%',col.Style.RESET_ALL)
print('Average Winners',round(sum(list(filter(lambda x:  x > 0,PNL_REAL)))/len(list(filter(lambda x:  x > 0,PNL_REAL)))) * _rate,2)
print('Average Loosers',round(sum(list(filter(lambda x:  x < 0,PNL_REAL)))/len(list(filter(lambda x:  x < 0,PNL_REAL)))) * _rate,2)
print('Average pnl',round(sum(PNL_REAL)/len(set(PNL_REAL))) * _rate,2)
print('Nombre total de trades ouverts',sum(TOTAL_OPEN))
print('Nombre total de trades fermés',sum(TOTAL_CLOSE))
print("Nombre de positions en l'air",(sum(TOTAL_OPEN) - sum(TOTAL_CLOSE)))
# Out:
# Cash généré :  2920.52$
# Pnl latent minimal : -206.42720000000003$
# Pnl latent maximal : 506.58920000000006$
# Pnl latent moyen : 0.21$
# Max des durées moyennes 56.51
# Min des durées moyennes 41.9
# Moyenne des durées moyennes 46.77
# Nombre total de winners 163
# Nombre total de loosers 502
# Total des gains cumulés 10468.81
# Total des pertes cumulées -7548.28
#  PROFIT FACTOR :  1.39
#  Ratio du nombre de winners : 24.51 %
# Average Winners 210.64000000000004 2
# Average Loosers -0.0 2
# Average pnl 0.0 2
# Nombre total de trades ouverts 247
# Nombre total de trades fermés 247
# Nombre de positions en l'air 0

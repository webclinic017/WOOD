# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
res = pd.DataFrame(index=['20','36','48','60','72','84','96','280']) #

# %%
_period = 'Tested period : From 2019-11-21 19:35:00 to 2020-11-23 23:50:00'

# %%
PF = [1.99,3.29,4.36,4.75,4.61,6.52,7.97,3.39]
RATIO = [57.92,58.86,63.58,68.89,65.12,72.41,74.56,73.91]
WIN = [0.02,0.03,0.04,0.05,0.05,0.06,0.06,0.1]
LOSS = [-0.01,-0.01,-0.01,-0.01,-0.01,-0.01,-0.01,-0.03]
PFTG = [1.99,3.29,3.67,4.17,4.06,5.67,6.35,5.35]
RATIOTG = [58.91,61.49,66.23,71.01,71.97,75.61,77.05,86.24]
WINTG = [0.02,0.03,0.03,0.03,0.04,0.04,0.04,0.05]
LOSSTG = [-0.01,-0.01,-0.01,-0.01,-0.01,-0.01,-0.01,-0.01]
PFTGREG = [2.9,4.89,5.38,6.57,6.55,6.98,7.16,3.63]
RATIOTGREG = [60.61,64.75,74.25,74.96,75.09,74.26,76.2,84.41]
WINTGREG = [0.02,0.03,0.03,0.04,0.04,0.04,0.04,0.05]
LOSSTGREG = [-0.01,-0.01,-0.01,-0.01,-0.01,-0.01,-0.01,-0.01]

# %%
len(PF),len(WIN),len(LOSS),len(PFTG),len(WINTG),len(LOSSTG),len(PFTGREG),len(WINTGREG),len(LOSSTGREG)
# Out:
# (8, 8, 8, 8, 8, 8, 8, 8, 8)

# %%
res['PF'] = PF
res['RATIO'] = RATIO
res['WIN'] = WIN
res['LOSS'] = LOSS
res['PFTG'] = PFTG
res['RATIOTG'] = RATIOTG
res['WINTG'] = WINTG
res['LOSSTG'] = LOSSTG
res['PFTGREG'] = PFTGREG
res['RATIOTGREG'] = RATIOTGREG
res['WINTGREG'] = WINTGREG
res['LOSSTGREG'] = LOSSTGREG

# %%
res
# Out:
#        PF  RATIO   WIN  LOSS  PFTG  RATIOTG  WINTG  LOSSTG  PFTGREG  \
# 20   1.99  57.92  0.02 -0.01  1.99    58.91   0.02   -0.01     2.90
# 36   3.29  58.86  0.03 -0.01  3.29    61.49   0.03   -0.01     4.89
# 48   4.36  63.58  0.04 -0.01  3.67    66.23   0.03   -0.01     5.38
# 60   4.75  68.89  0.05 -0.01  4.17    71.01   0.03   -0.01     6.57
# 72   4.61  65.12  0.05 -0.01  4.06    71.97   0.04   -0.01     6.55
# 84   6.52  72.41  0.06 -0.01  5.67    75.61   0.04   -0.01     6.98
# 96   7.97  74.56  0.06 -0.01  6.35    77.05   0.04   -0.01     7.16
# 280  3.39  73.91  0.10 -0.03  5.35    86.24   0.05   -0.01     3.63
#
#      RATIOTGREG  WINTGREG  LOSSTGREG
# 20        60.61      0.02      -0.01
# 36        64.75      0.03      -0.01
# 48        74.25      0.03      -0.01
# 60        74.96      0.04      -0.01
# 72        75.09      0.04      -0.01
# 84        74.26      0.04      -0.01
# 96        76.20      0.04      -0.01
# 280       84.41      0.05      -0.01

# %%
res[['PF','PFTG','PFTGREG']].plot(figsize=(22,4))
plt.suptitle(_period)
# Out:
# Text(0.5, 0.98, 'Tested period : From 2019-11-21 19:35:00 to 2020-11-23 23:50:00')

# %%
res[['WIN','WINTG','WINTGREG']].plot(figsize=(22,4))
plt.suptitle(_period)
# Out:
# Text(0.5, 0.98, 'Tested period : From 2019-11-21 19:35:00 to 2020-11-23 23:50:00')

# %%
plt.figure(figsize=(22,4))
plt.plot(res['PF']-res['PFTG'])
plt.hlines(xmin=0,xmax=7,y=0,colors='red',linestyles='--',alpha=0.5)
plt.suptitle(_period)
# Out:
# Text(0.5, 0.98, 'Tested period : From 2019-11-21 19:35:00 to 2020-11-23 23:50:00')

# %%
plt.figure(figsize=(22,4))
plt.plot(res['PF']-res['PFTGREG'])
plt.hlines(xmin=0,xmax=7,y=0,colors='red',linestyles='--',alpha=0.5)
plt.suptitle(_period)
# Out:
# Text(0.5, 0.98, 'Tested period : From 2019-11-21 19:35:00 to 2020-11-23 23:50:00')

# %%
plt.figure(figsize=(22,4))
plt.plot(res['PFTG']-res['PFTGREG'])
plt.hlines(xmin=0,xmax=7,y=0,colors='red',linestyles='--',alpha=0.5)
plt.suptitle(_period)
# Out:
# Text(0.5, 0.98, 'Tested period : From 2019-11-21 19:35:00 to 2020-11-23 23:50:00')

# %%
res[['RATIO','RATIOTG','RATIOTGREG']].plot(figsize=(22,4))
plt.suptitle(_period)
# Out:
# Text(0.5, 0.98, 'Tested period : From 2019-11-21 19:35:00 to 2020-11-23 23:50:00')

# %%
plt.figure(figsize=(22,4))
plt.plot(res['RATIO']-res['RATIOTG'])
plt.hlines(xmin=0,xmax=7,y=0,colors='red',linestyles='--',alpha=0.5)
plt.suptitle(_period)
# Out:
# Text(0.5, 0.98, 'Tested period : From 2019-11-21 19:35:00 to 2020-11-23 23:50:00')

# %%
plt.figure(figsize=(22,4))
plt.plot(res['RATIO']-res['RATIOTGREG'])
plt.hlines(xmin=0,xmax=7,y=0,colors='red',linestyles='--',alpha=0.5)
plt.suptitle(_period)
# Out:
# Text(0.5, 0.98, 'Tested period : From 2019-11-21 19:35:00 to 2020-11-23 23:50:00')

# %%
plt.figure(figsize=(22,4))
plt.plot(res['RATIOTG']-res['RATIOTGREG'])
plt.hlines(xmin=0,xmax=7,y=0,colors='red',linestyles='--',alpha=0.5)
plt.suptitle(_period)
# Out:
# Text(0.5, 0.98, 'Tested period : From 2019-11-21 19:35:00 to 2020-11-23 23:50:00')

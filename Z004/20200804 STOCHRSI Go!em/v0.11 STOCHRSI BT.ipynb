# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
        
clearall()

# %%
############################
######## LIBRAIRIES ########
############################
print('Importing Librairies...')
from sklearn.linear_model import LinearRegression
import colorama as col
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import time
import os
import datetime as dt
import numpy as np
import fxcmpy
import socketio
import shelve
import talib
import statistics
import pyttsx3

engine = pyttsx3.init()

print('Librairies imported\n')
print('version fxcmpy :',fxcmpy.__version__)
# %matplotlib inline
plt.style.use('seaborn')
engine.say("librairie loaded")
engine.runAndWait()
print('Prêt')
# Out:
# Importing Librairies...
# Librairies imported
#
# version fxcmpy : 1.2.6
# Prêt

# %%
engine.say("Ignition du Lumberjack")
engine.runAndWait() 

##############################################
######## INITIALISATION DES VARIABLES ########
##############################################


# COMPTE TEST #
'''
TOKEN = '039add1dbe2b344ed08c518a98c7a1796f7a33c2'
server = 'demo'
user_id = 'D261219574'
compte = '01215057'
password = '3555'
'''

'''
# COMPTE DEV #
TOKEN = '79f83cbff13d296eb6d9b6c1ed6dccd768ef925a'
server = 'demo'
user_id = 'D261219577'
compte = '01215060'
password = '3877'
'''


# COMPTE POUBELLE #
TOKEN = 'a66bf5c0ec732487f4b348baf6364d3ee8784935'
server = 'demo'
user_id = 'D261219576'
compte = '01215059'
password = '8029'



# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'


_number = 10000
_period = 'm5'
_period2 = 'H1'

engine.say("בסדר")
engine.runAndWait()
print('Variables initialisées')
# Out:
# Variables initialisées

# %%
############################
######## FONCTIONS ########
###########################


def conX():
    con = fxcmpy.fxcmpy(access_token=TOKEN, log_level='error',server=server)
    if con.is_connected() == True:
        print(col.Fore.GREEN+'Connexion établie'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
    else:
        print(col.Fore.RED+'Connexion non établie'+col.Style.RESET_ALL)
    return(con)

def deconX():
    con = con.close()
    if con.is_connected() == True:
        print(col.Fore.GREEN+'Connexion non intérrompue'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
    else:
        print(col.Fore.RED+'Connexion intérrompue'+col.Style.RESET_ALL)
    return()


def scrap_hist(_ticker,number,laperiod):
    print(col.Fore.BLUE,'Scraping des données OHLC pour le ticker',col.Fore.YELLOW,_ticker,col.Style.RESET_ALL)
    data = con.get_candles(instrument=_ticker,number = 10000,period=laperiod)
    df = pd.DataFrame(index=data.index)
    df['Open'] = (data['bidopen']+data['askopen'])/2
    df['High'] = (data['bidhigh']+data['askhigh'])/2
    df['Low'] = (data['bidlow']+data['asklow'])/2
    df['Close'] = (data['bidclose']+data['askclose'])/2
    return(df)

engine.say("functions initiated")
engine.runAndWait()
print('Functions initiated')
# Out:
# Functions initiated

# %%
#########################
### CONNEXION A L'API ###
#########################

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor for FOR_EX\nLumberJack Jyss 5780(c)')
print(col.Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print(col.Fore.YELLOW,col.Back.BLUE,'--- Go!em STOCHASTIC-RSI #v0.11 ---',col.Style.RESET_ALL)

print('')
engine.say(" Initialisation du Gaulem Stok R S E")
engine.say("Connexion du Gaulem hà la Péh e")
engine.runAndWait()

try:
    con.is_connected() == True
    
    engine.say("already Connected")
    engine.runAndWait()
    print(col.Fore.GREEN+'Connexion rétablie'+col.Style.RESET_ALL)
    print('Compte utilisé : ',con.get_account_ids())
    print('')
    
except:
    try:
        con = conX()
        con.is_connected() == True
        print(col.Fore.GREEN+'Connexion établie'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
        engine.say("Connected")
        engine.runAndWait()
    except:
        print(col.Fore.RED+'Connexion non établie'+col.Style.RESET_ALL)
        engine.say("Not Connected, sal rass de mor, pitun cé la merd")
        engine.say("vérifi ton internet, é relance le gaulèm")
        engine.runAndWait()
        print('')
        #os._exit(0)
        con = deconX()
        time.sleep(1)
        con = conX()
# Out:
# Global Optimized LumberJack Environment Motor for FOR_EX
# LumberJack Jyss 5780(c)
#  °0Oo_D.A.G._26_oO0°
#   --- Go!em STOCHASTIC-RSI #v0.11 ---
#
# Connexion établie
# Compte utilisé :  [1215059]
# Connexion établie
# Compte utilisé :  [1215059]

# %%
# %%time
TICKERS = con.get_instruments()
for x in TICKERS:
    data = scrap_hist(x,_number,_period)
    data2 = scrap_hist(x,_number,_period2)
    price = data.copy()
    price2 = data2.copy()
    position = 0
    equity = 1000000
    nbtransactions = 0
    backtest_graph = pd.DataFrame()
    col_equity = [1000000]
    col_open_pos = [0]
    col_close_pos = [0]
    col_is_win = [0]
    col_profit = [0]
    col_cours = [0]
    max_gross = (0,0)
    max_loss = (0,0)
    Stop_Loss_Short =[]
    Stop_Loss_Long = []
    winner = 0
    looser = 0
    entry_index = []
    trade_duration = []
    average_duration = 0
    size = 100000
   
    target = 0.0015
    sl = 0.003
    
    MM21 = talib.EMA(price.Close, timeperiod=21)
    rsi = talib.RSI(price.Close, timeperiod=14)
    rsi_high = 65
    rsi_low = 35
    upperband, middleband, lowerband = talib.BBANDS(price.Close, timeperiod=5, nbdevup=2, nbdevdn=2, matype=0)
    fastk, fastd = talib.STOCHRSI(price.Close, timeperiod=14, fastk_period=5, fastd_period=3, fastd_matype=0)#STOCHASTICRSI
    slowk, slowd = talib.STOCH(price.High, price.Low, price.Close, fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)#STOCHASTIC

    MM212 = talib.EMA(price2.Close, timeperiod=21)
    rsi2 = talib.RSI(price2.Close, timeperiod=14)
    upperband2, middleband2, lowerband2 = talib.BBANDS(price2.Close, timeperiod=5, nbdevup=2, nbdevdn=2, matype=0)
    fastk2, fastd2 = talib.STOCHRSI(price2.Close, timeperiod=14, fastk_period=5, fastd_period=3, fastd_matype=0)#STOCHASTICRSI
    slowk2, slowd2 = talib.STOCH(price2.High, price2.Low, price2.Close, fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)#STOCHASTIC

    #try:
    for i in range(25,len(price)):
        
        if position == 0:
                        
            if fastk[i-1] > 99 and fastk[i-1] > fastd[i-1] and fastk[i] < fastd[i] and price.High[i-1] > price.High[i-2] and price.High[i] < price.High[i-2]\
                    and price.Close[i] < MM21[i]:
                
                j = len(price2[price2.index<=str(price.index[i])[:14]+'00:00'])-1
                    
                if fastk2[j-1] > 99 and fastk2[j-1] > fastd2[j-1] and fastk2[j] < fastd2[j] and \
                        price2.High[j-1] > price2.High[j-2] and price2.High[j] < price2.High[j-2] and price2.Close[j] < MM212[j] and\
                            '08:00:00' < str(price.index[j])[11:] < '23:30:00':

                    print("Filtre de petite time frame passé, pour i=",i,"et un index à i de",str(price.index[i]))
                    print("Filtre de groose time frame passé, pour j=",j,"et un index à j de",str(price2.index[j]))

                    sense ='bearish' 
                    #label =  sense + labels[j] +'found'
                    #print(label)
                    print(i)
                    entry_index = i
                    position = -1
                    col_open_pos.append(1)
                    nbtransactions+=1
                    price_sell = price.Close.iloc[i]
                    Stop_Loss_Sell = price.High.iloc[i-1]
                    print('sold at', price_sell)  
                    print('SL at', Stop_Loss_Sell)
                        
                                
            elif fastk[i-1] < 1 and fastk[i-1] < fastd[i-1] and fastk[i] > fastd[i] and price.Low[i-1] < price.Low[i-2] and price.Low[i] > price.Low[i-2] and\
                    price.Close[i] > MM21[i]:
                
                j = len(price2[price2.index<=str(price.index[i])[:14]+'00:00'])-1
                
                if fastk2[j-1] < 1 and fastk2[j-1] < fastd2[j-1] and fastk2[j] > fastd2[j] and price2.Low[j-1] < price2.Low[j-2] and\
                        price2.Low[j] > price2.Low[j-2] and price2.Close[j] > MM212[j] and '08:00:00' < str(price.index[j])[11:] < '23:30:00':

                    print("Filtre de petite time frame passé, pour i=",i,"et un index à i de",str(price.index[i]))
                    print("Filtre de groose time frame passé, pour j=",j,"et un index à j de",str(price2.index[j]))

                    position = 1
                    entry_index = i
                    col_open_pos.append(1)
                    nbtransactions+=1
                    price_buy = price.Close.iloc[i]
                    Stop_Loss_Buy = price.Low.iloc[i-1]
                    print('bought at', price_buy)
                    print('SL at', Stop_Loss_Buy)
            else :
                pass
        
        elif position == 1:
            
            if (float(price.Close.iloc[i]) - float(price_buy))/float(price_buy) >= target :#slowd[i]>80:
                    position = 0
                    equity = equity + (price.Close.iloc[i] - price_buy)*size
                    col_equity.append(equity)
                    winner+=1
                    trade_duration.append(i - entry_index)
                    print(i)
                    print('TP position closed at',price.Close.iloc[i],'pnl', (price.Close.iloc[i] - price_buy)*size)
                    print('nombre de candles en position :',i- entry_index)
                    print(equity)
            elif (float(price.Close.iloc[i]) - float(price_buy))/float(price_buy) <= -sl :#price.Close.iloc[i]<Stop_Loss_Buy
                    position = 0
                    #equity = equity + (Stop_Loss_Buy - price_buy)*size
                    equity = equity + (price.Close.iloc[i] - price_buy)*size
                    col_equity.append(equity)
                    looser+=1
                    trade_duration.append(i - entry_index)
                    print(i)
                    print('SL position closed at',price.Close.iloc[i],'pnl',(price.Close.iloc[i] - price_buy)*size)
                    print('nombre de candles en position :',i- entry_index)
                    print(equity)
        elif position == -1:
            
                if (float(price.Close.iloc[i]) - float(price_sell))/float(price_sell) <= -target :#slowd[i]<20:
                    position = 0
                    equity = equity - (price.Close.iloc[i] - price_sell)*size
                    col_equity.append(equity)
                    winner+=1
                    trade_duration.append(i - entry_index)
                    print(i)
                    print('TP position closed at',price.Close.iloc[i],'pnl',-(price.Close.iloc[i] - price_sell)*size)
                    print('nombre de candles en position :',i- entry_index)
                    print(equity)
                elif (float(price.Close.iloc[i]) - float(price_sell))/float(price_sell) >= sl :#price.Close.iloc[i]>Stop_Loss_Sell:
                    position = 0
                    #equity = equity - (Stop_Loss_Sell - price_sell)*size
                    equity = equity - (price.Close.iloc[i] - price_sell)*size
                    col_equity.append(equity)
                    looser+=1
                    trade_duration.append(i - entry_index)
                    print(i)
                    print('SL position closed at',price.Close.iloc[i],'pnl', -(price.Close.iloc[i] - price_sell)*size)
                    print('nombre de candles en position :',i- entry_index)
                    print(equity)
    try:
        average_duration=statistics.mean(trade_duration)
    except:
        print("(pas de duration)")                
    print(col.Fore.MAGENTA,"\nLes gains faramineux s'élèvent à : $",col.Fore.GREEN,equity-1000000,'!. En ',nbtransactions,' transactions.',col.Style.RESET_ALL ) 
    print(col.Fore.GREEN,"\nNbre de winners :",winner,col.Style.RESET_ALL)
    print(col.Fore.RED,"\nNbre de loosers :",looser,col.Style.RESET_ALL)
    print("\nAverage trade duration ",average_duration)
    backtest_graph['equity'] = col_equity
        
    #except :
     #   print(col.Fore.RED,'\n\nProbleme avec le ticker\n\n',col.Fore.YELLOW,x,col.Style.RESET_ALL)
      #  continue
# Out:
#  Scraping des données OHLC pour le ticker  EUR/USD
#  Scraping des données OHLC pour le ticker  EUR/USD
# Filtre de petite time frame passé, pour i= 73 et un index à i de 2020-06-17 20:20:00
# Filtre de petite time frame passé, pour i= 595 et un index à i de 2020-06-19 15:50:00
# Filtre de petite time frame passé, pour i= 615 et un index à i de 2020-06-19 17:30:00
# Filtre de petite time frame passé, pour i= 973 et un index à i de 2020-06-22 21:40:00
# Filtre de petite time frame passé, pour i= 1046 et un index à i de 2020-06-23 03:45:00
# Filtre de petite time frame passé, pour i= 1133 et un index à i de 2020-06-23 11:00:00
# Filtre de petite time frame passé, pour i= 1225 et un index à i de 2020-06-23 18:40:00
# Filtre de petite time frame passé, pour i= 1303 et un index à i de 2020-06-24 01:10:00
# Filtre de petite time frame passé, pour i= 1489 et un index à i de 2020-06-24 16:40:00
# Filtre de petite time frame passé, pour i= 1512 et un index à i de 2020-06-24 18:35:00
# Filtre de petite time frame passé, pour i= 1525 et un index à i de 2020-06-24 19:40:00
# Filtre de petite time frame passé, pour i= 7418 et un index à i de 2020-07-22 16:10:00
# Filtre de petite time frame passé, pour i= 7473 et un index à i de 2020-07-22 20:45:00
# Filtre de petite time frame passé, pour i= 7549 et un index à i de 2020-07-23 03:10:00
# Filtre de petite time frame passé, pour i= 7971 et un index à i de 2020-07-24 14:40:00
# Filtre de petite time frame passé, pour i= 7982 et un index à i de 2020-07-24 15:40:00
# Filtre de petite time frame passé, pour i= 8033 et un index à i de 2020-07-24 20:30:00
# Filtre de petite time frame passé, pour i= 8203 et un index à i de 2020-07-27 11:50:00
# Filtre de petite time frame passé, pour i= 8726 et un index à i de 2020-07-29 09:50:00
# Filtre de petite time frame passé, pour i= 8969 et un index à i de 2020-07-30 06:50:00
# Filtre de petite time frame passé, pour i= 9009 et un index à i de 2020-07-30 10:10:00
# Filtre de petite time frame passé, pour i= 9191 et un index à i de 2020-07-31 01:25:00
# Filtre de petite time frame passé, pour i= 9253 et un index à i de 2020-07-31 06:35:00
# Filtre de petite time frame passé, pour i= 9415 et un index à i de 2020-07-31 20:05:00
# Filtre de petite time frame passé, pour i= 9422 et un index à i de 2020-07-31 20:40:00
# Filtre de petite time frame passé, pour i= 9426 et un index à i de 2020-08-02 21:20:00
#
# Les gains faramineux s'élèvent à : $  -1867.5 !. En  2  transactions.
#
# Nbre de winners : 1
#
# Nbre de loosers : 1
#
# Average trade duration  85
#  Scraping des données OHLC pour le ticker  USD/MXN
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-25-acf1590e802c> in scrap_hist(_ticker, number, laperiod)
#      25 def scrap_hist(_ticker,number,laperiod):
#      26     print(col.Fore.BLUE,'Scraping des données OHLC pour le ticker',col.Fore.YELLOW,_ticker,col.Style.RESET_ALL)
# ---> 27     data = con.get_candles(instrument=_ticker,number = 10000,period=laperiod)
#      28     df = pd.DataFrame(index=data.index)
#      29     df['Open'] = (data['bidopen']+data['askopen'])/2
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/fxcmpy/fxcmpy.py in get_candles(self, instrument, offer_id, period, number, start, end, with_index, columns, stop)
#    2183
#    2184         data = self.__handle_request__(method='candles/%s/%s'
# -> 2185                                        % (offer_id, period), params=params)
#    2186
#    2187         if len(columns) == 0:
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/fxcmpy/fxcmpy.py in __handle_request__(self, method, params, protocol)
#    2478             req = requests.get('%s:443/%s' % (self.trading_url, method),
#    2479                                headers=self.request_headers, params=params,
# -> 2480                                proxies=self.proxies)
#    2481             self.logger.info('Sending GET Request:')
#    2482             self.logger.info('URL: %s' % req.url)
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/requests/models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/requests/models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     558         """
#     559         if self.chunked and self.supports_chunked_reads():
# --> 560             for line in self.read_chunked(amt, decode_content=decode_content):
#     561                 yield line
#     562         else:
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     753                 if self.chunk_left == 0:
#     754                     break
# --> 755                 chunk = self._handle_chunk(amt)
#     756                 decoded = self._decode(
#     757                     chunk, decode_content=decode_content, flush_decoder=False
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/urllib3/response.py in _handle_chunk(self, amt)
#     697             self.chunk_left = None
#     698         elif amt < self.chunk_left:
# --> 699             value = self._fp._safe_read(amt)
#     700             self.chunk_left = self.chunk_left - amt
#     701             returned_chunk = value
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/http/client.py in _safe_read(self, amt)
#     618         s = []
#     619         while amt > 0:
# --> 620             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     621             if not chunk:
#     622                 raise IncompleteRead(b''.join(s), amt)
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1837             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1838         else:
# -> 1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# KeyboardInterrupt:

# %%
average_duration
# Out:
# 0

# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
        
clearall()

# %%
# TO DO 
# 
# pour le nombre d'occurences (len !=), mettre un pnl latent pour la pos = 0
# 
# 
#

# %%
############################
######## LIBRAIRIES ########
############################
print('Importing Librairies...')
from sklearn.linear_model import LinearRegression
import colorama as col
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import time
import os
import datetime as dt
import numpy as np
import fxcmpy
import socketio
import shelve
import talib
import statistics
import pyttsx3

engine = pyttsx3.init()

print('Librairies imported\n')
print('version fxcmpy :',fxcmpy.__version__)
# %matplotlib inline
plt.style.use('seaborn')
engine.say("librairie loaded")
engine.runAndWait()
print('Prêt')
# Out:
# Importing Librairies...
# Librairies imported
#
# version fxcmpy : 1.2.6
# Prêt

# %%
engine.say("Ignition du Lumberjack")
engine.runAndWait() 

##############################################
######## INITIALISATION DES VARIABLES ########
##############################################


# COMPTE TEST #

TOKEN = '89410007226e1ad8ffce5dbf03f1e1bf056f2451'
server = 'demo'
user_id = 'D261219574'
compte = '01215057'
password = '3555'


'''
# COMPTE DEV #
TOKEN = '79f83cbff13d296eb6d9b6c1ed6dccd768ef925a'
server = 'demo'
user_id = 'D261219577'
compte = '01215060'
password = '3877'
'''

'''
# COMPTE POUBELLE #
TOKEN = 'a66bf5c0ec732487f4b348baf6364d3ee8784935'
server = 'demo'
user_id = 'D261219576'
compte = '01215059'
password = '8029'
'''


# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'


_number = 10000
_period = 'm5'
_period2 = 'D1'
_total = 0
_cash_ini = 200000
_cash = _cash_ini
_rate = 1
_flag = 0

engine.say("בסדר")
engine.runAndWait()
print('Variables initialisées')
# Out:
# Variables initialisées

# %%
############################
######## FONCTIONS ########
###########################


def conX():
    con = fxcmpy.fxcmpy(access_token=TOKEN, log_level='error',server=server)
    if con.is_connected() == True:
        print(col.Fore.GREEN+'Connexion établie'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
    else:
        print(col.Fore.RED+'Connexion non établie'+col.Style.RESET_ALL)
    return(con)

def deconX():
    con = con.close()
    if con.is_connected() == True:
        print(col.Fore.GREEN+'Connexion non intérrompue'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
    else:
        print(col.Fore.RED+'Connexion intérrompue'+col.Style.RESET_ALL)
    return()


def scrap_hist(_ticker,number,laperiod):
    print(col.Fore.BLUE,'Scraping des données OHLC pour le ticker',col.Fore.YELLOW,_ticker,col.Style.RESET_ALL)
    data = con.get_candles(instrument=_ticker,number = 10000,period=laperiod)
    df = pd.DataFrame(index=data.index)
    df['Open_Bid'] = data['bidopen']
    df['Open_Ask'] = data['askopen']
    df['Open'] = (data['bidopen']+data['askopen'])/2
    df['High_Bid'] = data['bidhigh']
    df['High_Ask'] = data['askhigh']
    df['High'] = (data['bidhigh']+data['askhigh'])/2
    df['Low_Bid'] = data['bidlow']
    df['Low_Ask'] = data['asklow']
    df['Low'] = (data['bidlow']+data['asklow'])/2
    df['Close_Bid'] = data['bidclose']
    df['Close_Ask'] = data['askclose']
    df['Close'] = (data['bidclose']+data['askclose'])/2
    return(df)

def convert(devise,_rate,_flag):
    
    prix_usd = 0
    if x[4:] == 'USD':
        prix_usd = devise
    elif x[:3] == 'USD':
        prix_usd = round(devise/_rate,2)
    elif _flag == 1:
        prix_usd = round(devise * _rate,2)
       
    elif _flag == -1 :
            prix_usd = round(devise / _rate,2)
    else:
        prix_usd = 'NA'
    return(prix_usd,_flag)

engine.say("functions initiated")
engine.runAndWait()
print('Functions initiated')
# Out:
# Functions initiated

# %%
#########################
### CONNEXION A L'API ###
#########################

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor for FOR_EX\nLumberJack Jyss 5780(c)')
print(col.Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print(col.Fore.YELLOW,col.Back.BLUE,'--- Go!em STOCHASTIC-RSI #v0.14 ---',col.Style.RESET_ALL)

print('')
engine.say(" Initialisation du Gaulem Stok R S E")
engine.say("Connexion du Gaulem hà la Péh e")
engine.runAndWait()

try:
    con.is_connected() == True
    
    engine.say("already Connected")
    engine.runAndWait()
    print(col.Fore.GREEN+'Connexion rétablie'+col.Style.RESET_ALL)
    print('Compte utilisé : ',con.get_account_ids())
    print('')
    
except:
    try:
        con = conX()
        con.is_connected() == True
        print(col.Fore.GREEN+'Connexion établie'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
        engine.say("Connected")
        engine.runAndWait()
    except:
        print(col.Fore.RED+'Connexion non établie'+col.Style.RESET_ALL)
        engine.say("Not Connected, sal rass de mor, pitun cé la merd")
        engine.say("vérifi ton internet, é relance le gaulèm")
        engine.runAndWait()
        print('')
        #os._exit(0)
        con = deconX()
        time.sleep(1)
        con = conX()
# Out:
# Global Optimized LumberJack Environment Motor for FOR_EX
# LumberJack Jyss 5780(c)
#  °0Oo_D.A.G._26_oO0°
#   --- Go!em STOCHASTIC-RSI #v0.14 ---
#
# Connexion établie
# Compte utilisé :  [1215057]
# Connexion établie
# Compte utilisé :  [1215057]

# %%
# %%time
df_resultats = pd.DataFrame(index=['TimeFrame 1','TimeFrame2','Equity','Nbre Winners','Nbre Loosers','Average lenght of trade','Cumul pnl'])

#TICKERS = con.get_instruments()
TICKERS = [ 'EUR/USD','USD/JPY','GBP/USD','USD/CHF','EUR/CHF','AUD/USD','USD/CAD','NZD/USD','EUR/GBP','EUR/JPY','GBP/JPY','CHF/JPY','GBP/CHF','EUR/AUD','EUR/CAD','AUD/CAD','AUD/JPY','CAD/JPY','NZD/JPY','GBP/CAD','GBP/NZD','GBP/AUD','AUD/NZD','USD/SEK','EUR/SEK','EUR/NOK','USD/NOK','USD/MXN','AUD/CHF','EUR/NZD','USD/ZAR','ZAR/JPY','NZD/CHF','CAD/CHF','NZD/CAD','USD/ILS','USD/CNH']

engine.say("קדימה")
engine.runAndWait()

for x in TICKERS:

    if x[4:] == 'USD':
        _rate = 1

    elif x[:3] == 'USD':
        con.subscribe_market_data(x)
        _rate = con.get_last_price(x).Bid
        con.unsubscribe_market_data(x)
    elif x[:3] != 'USD' and x[4:] != 'USD':
        try:
            con.subscribe_market_data(x[4:]+'/USD')
            _rate = con.get_last_price(x[4:]+'/USD').Bid
            con.unsubscribe_market_data(x[4:]+'/USD')
            _flag = 1
        except:
            con.subscribe_market_data('USD/'+x[4:])
            _rate = con.get_last_price('USD/'+x[4:]).Bid
            con.unsubscribe_market_data('USD/'+x[4:])
            _flag = -1
    else:
        prix_usd = 'NA'

    print(col.Fore.MAGENTA,'Le rate du ticker',x,'est à ',_rate,col.Style.RESET_ALL)

    data = scrap_hist(x,_number,_period)
    data2 = scrap_hist(x,_number,_period2)
    price = data.copy()
    price2 = data2.copy()
    _position = 0
    _equity = 0
    _nbtransactions = 0
    backtest_graph = pd.DataFrame()
    EQUITY = [_cash]
    CASH = [_cash]
    OPEN_POZ = [0]
    _winner = 0
    _looser = 0
    _index_entry = 0
    TRADE_DURATION = []
    _average_duration = 0
    _size = 50000
   
    _total = 0

    _target = 0.0010
    _sl = 0.0090
    _spread_filter = 0.0010
    
    MM21 = talib.EMA(price.Close, timeperiod=21)
    rsi = talib.RSI(price.Close, timeperiod=14)
    rsi_high = 65
    rsi_low = 35
    upperband, middleband, lowerband = talib.BBANDS(price.Close, timeperiod=5, nbdevup=2, nbdevdn=2, matype=0)
    fastk, fastd = talib.STOCHRSI(price.Close, timeperiod=14, fastk_period=5, fastd_period=3, fastd_matype=0)#STOCHASTICRSI
    slowk, slowd = talib.STOCH(price.High, price.Low, price.Close, fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)#STOCHASTIC
    
    MM82 = talib.EMA(price2.Close, timeperiod=8)
    MM212 = talib.EMA(price2.Close, timeperiod=21)
    MM342 = talib.EMA(price2.Close, timeperiod=34)
    rsi2 = talib.RSI(price2.Close, timeperiod=14)
    upperband2, middleband2, lowerband2 = talib.BBANDS(price2.Close, timeperiod=5, nbdevup=2, nbdevdn=2, matype=0)
    fastk2, fastd2 = talib.STOCHRSI(price2.Close, timeperiod=14, fastk_period=5, fastd_period=3, fastd_matype=0)#STOCHASTICRSI
    slowk2, slowd2 = talib.STOCH(price2.High, price2.Low, price2.Close, fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)

    for i in range(25,len(price)):
        _pnl = 0
        if _position <= 1: 
            
            if slowk[i-1] > 80 and slowk[i-1] > slowd[i-1] and slowk[i] < slowd[i] and price.High[i-1] > price.High[i-2] and price.High[i] < price.High[i-2] :
                j = len(price2[price2.index <= price.index[i]])-1
                    
                if  price2.Close[j] < MM82[j] and MM82[j]<MM212[j] and MM212[j] < MM342[j] \
                    and (price.Close_Ask[i]-price.Close_Bid[i])/price.Close_Ask[i] < _spread_filter:

                    print("Filtre de petite time frame passé, pour i=",i,"et un index à i de",str(price.index[i]))
                    print("Filtre de grosse time frame passé, pour j=",j,"et un index à j de",str(price2.index[j]))

                    sense ='bearish' 
                    
                    print(i)
                    _pnl = 0
                    _equity = _cash + _pnl
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _index_entry = i
                    _position = -1
                    OPEN_POZ.append(1)
                    _nbtransactions += 1
                    price_sell = price.Close_Bid.iloc[i]
                    print('sold at', price_sell)  
                        
                                
            elif slowk[i-1] < 20 and slowk[i-1] < slowd[i-1] and slowk[i] > slowd[i] and price.Low[i-1] < price.Low[i-2] and price.Low[i] > price.Low[i-2]:
                j = len(price2[price2.index <= price.index[i]])-1
                
                if price2.Close[j] > MM82[j] and MM82[j]>MM212[j] and MM212[j] > MM342[j] \
                    and (price.Close_Ask[i]-price.Close_Bid[i])/price.Close_Ask[i] < _spread_filter:

                    print("Filtre de petite time frame passé, pour i=",i,"et un index à i de",str(price.index[i]))
                    print("Filtre de grosse time frame passé, pour j=",j,"et un index à j de",str(price2.index[j]))
                    
                    sense = 'bullish'

                    print(i)
                    _pnl = 0
                    _equity = _cash + _pnl
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _position = 1
                    _index_entry = i
                    OPEN_POZ.append(1)
                    _nbtransactions += 1
                    price_buy = price.Close_Ask.iloc[i]
                    print('bought at', price_buy)

            else :
                _pnl = 2
                _equity = _cash + _pnl
                EQUITY.append(_equity)
                CASH.append(_cash)
        
        if _position == 1:
            if (float(price.Close_Bid.iloc[i]) - float(price_buy))/float(price_buy) >= _target :#slowd[i]>80:
                _position = 0
                _pnl = (price.Close_Bid.iloc[i] - price_buy) * _size
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _winner += 1
                TRADE_DURATION.append(i - _index_entry)
                print(i)
                print('TP position closed at',price.Close_Bid.iloc[i],col.Fore.GREEN,'pnl', _pnl,col.Style.RESET_ALL)
                print('nombre de candles en position :',i - _index_entry)
                print('Equity :', _equity)
            
            elif (float(price.Close_Bid.iloc[i]) - float(price_buy))/float(price_buy) <= -_sl :
                _position = 0
                _pnl = (price.Close_Bid.iloc[i] - price_buy) * _size
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _total += _pnl
                _cash += _pnl
                _equity = _cash
                EQUITY.append(_equity)
                CASH.append(_cash)
                _looser += 1
                TRADE_DURATION.append(i - _index_entry)
                print(i)
                print('SL position closed at',price.Close_Bid.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                print('nombre de candles en position :',i - _index_entry)
                print('Equity :', _equity)

            else:
                _pnl = (price.Close_Bid.iloc[i] - price_buy) * _size
                _pnl,_flag = convert(_pnl,_rate,_flag)
                _equity = _cash + _pnl
                _pnl = 0
                EQUITY.append(_equity)
                CASH.append(_cash)

            
        
        elif _position == -1:
            
                if (float(price.Close_Ask.iloc[i]) - float(price_sell))/float(price_sell) <= -_target :
                    _position = 0
                    _pnl = - (price.Close_Ask.iloc[i] - price_sell) * _size
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _total += _pnl
                    _cash += _pnl
                    _equity = _cash
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _winner += 1
                    TRADE_DURATION.append(i - _index_entry)
                    print(i)
                    print('TP position closed at',price.Close_Ask.iloc[i],col.Fore.GREEN,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)
                
                elif (float(price.Close_Ask.iloc[i]) - float(price_sell))/float(price_sell) >= _sl :
                    _position = 0
                    _pnl = - (price.Close_Ask.iloc[i] - price_sell) * _size
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _total += _pnl
                    _cash += _pnl
                    _equity = _cash
                    EQUITY.append(_equity)
                    CASH.append(_cash)
                    _looser += 1
                    TRADE_DURATION.append(i - _index_entry)
                    print(i)
                    print('SL position closed at',price.Close_Bid.iloc[i],col.Fore.RED,'pnl', _pnl,col.Style.RESET_ALL)
                    print('nombre de candles en position :',i - _index_entry)
                    print('Equity :', _equity)
                
                else:
                    _pnl = - (price.Close_Ask.iloc[i] - price_sell) * _size
                    _pnl,_flag = convert(_pnl,_rate,_flag)
                    _equity = _cash + _pnl
                    _pnl = 0
                    EQUITY.append(_equity)
                    CASH.append(_cash)
    try:
        _average_duration = round(statistics.mean(TRADE_DURATION),2)
    
    except:
        print("(pas de duration)") 
        _average_duration = 'NA'               
    print(col.Fore.MAGENTA,"\nLes gains faramineux s'élèvent à : $",col.Fore.GREEN,round(_total,2),'!. En ',_nbtransactions,' transactions.',col.Style.RESET_ALL ) 
    print(col.Fore.GREEN,"\nNbre de winners :",_winner,col.Style.RESET_ALL)
    print(col.Fore.RED,"\nNbre de loosers :",_looser,col.Style.RESET_ALL)
    print("\nAverage trade duration ",_average_duration)
    backtest_graph['Equity'] = EQUITY
    
    df_resultats[x] = [_period,_period2,str(round(_equity,2)),str(_winner),str(_looser),str(_average_duration),str(_total)]

    print('Total des gains faramineux :',round(EQUITY[-1] - _cash_ini,2))

try:
    os.mkdir('Period_'+_period+'_Period2_'+_period2+'_target_'+str(_target)+'_sl_'+str(_sl)+'_rsiHigh'+str(rsi_high)+'_rsiLow_'+str(rsi_low)+'/')
except:
    pass

df_resultats.T.to_csv('Period_'+_period+'_Period2_'+_period2+'_target_'+str(_target)+'_sl_'+str(_sl)+'_rsiHigh'+str(rsi_high)+'_rsiLow_'+str(rsi_low)+'/pnl_'+str(_total)+'.csv')
    
engine.say("The job is done. Check, we are billionaire")
engine.runAndWait()
# Out:
#  Le rate du ticker EUR/USD est à  1
#  Scraping des données OHLC pour le ticker  EUR/USD
#  Scraping des données OHLC pour le ticker  EUR/USD
# Filtre de petite time frame passé, pour i= 307 et un index à i de 2020-07-13 11:45:00
# Filtre de grosse time frame passé, pour j= 5422 et un index à j de 2020-07
00
# Filtre de grosse time frame passé, pour j= 5429 et un index à j de 2020-07-20 21:00:00
# 1968
# bought at 1.1434
# 1986
# TP position closed at 1.14494  pnl 77.00000000000485
# nombre de candles en position : 18
# Equity : 200523.5
# Filtre de petite time frame passé, pour i= 2160 et un index à i de 2020-07-21 20:30:00
# Filtre de grosse time frame passé, pour j= 5429 et un index à j de 2020-07-20 21:00:00
# 2160
# bought at 1.15229
# 2198
# TP position closed at 1.15363  pnl 66.99999999999484
# nombre de candles en position : 38
# Equity : 200590.5
# Filtre de petite time frame passé, pour i= 2244 et un index à i de 2020-07-22 03:30:00
# Filtre de grosse time frame passé, pour j= 5430 et un index à j de 2020-07-21 21:00:00
# 2244
# bought at 1.1543
# 2323
# TP position closed at 1.15625  pnl 97.49999999999481
# nombre de candles en position : 79
# Equity : 200688.0
# Filtre de petite time frame passé, pour i= 2496 et un index à i de 2020-07-23 00:30:00
# Filtre de grosse time frame passé, pour j= 5431 et un index à j de 2020-07-22 21:00:00
# 2496
# bought at 1.15681
# 2543
# TP position closed at 1.15805  pnl 62.000000000006494
# nombre de candles en position : 47
# Equity : 200750.0
# Filtre de petite time frame passé, pour i= 2647 et un index à i de 2020-07-23 13:05:00
# Filtre de grosse time frame passé, pour j= 5431 et un index à j de 2020-07-22 21:00:00
# 2647
# bought at 1.15555
# 2653
# TP position closed at 1.15671  pnl 57.99999999999139
# nombre de candles en position : 6
# Equity : 200808.0
# Filtre de petite time frame passé, pour i= 2739 et un index à i de 2020-07-23 20:45:00
# Filtre de grosse time frame passé, pour j= 5431 et un index à j de 2020-07-22 21:00:00
# 2739
# bought at 1.15941
# Filtre de petite time frame passé, pour i= 2771 et un index à i de 2020-07-23 23:25:00
# Filtre de grosse time frame passé, pour j= 5432 et un index à j de 2020-07-23 21:00:00
# 2771
# bought at 1.15998
# 2788
# TP position closed at 1.16121  pnl 61.50000000000322
# nombre de candles en position : 17
# Equity : 200869.5
# Filtre de petite time frame passé, pour i= 2885 et un index à i de 2020-07-24 08:55:00
# Filtre de grosse time frame passé, pour j= 5432 et un index à j de 2020-07-23 21:00:00
# 2885
# bought at 1.16009
# 2933
# TP position closed at 1.16142  pnl 66.49999999999156
# nombre de candles en position : 48
# Equity : 200936.0
# Filtre de petite time frame passé, pour i= 3068 et un index à i de 2020-07-26 22:15:00
# Filtre de grosse time frame passé, pour j= 5434 et un index à j de 2020-07-26 21:00:00
# 3068
# bought at 1.16453
# 3089
# TP position closed at 1.16576  pnl 61.49999999999211
# nombre de candles en position : 21
# Equity : 200997.5
# Filtre de petite time frame passé, pour i= 3115 et un index à i de 2020-07-27 02:10:00
# Filtre de grosse time frame passé, pour j= 5434 et un index à j de 2020-07-26 21:00:00
# 3115
# bought at 1.16941
# 3122
# TP position closed at 1.17087  pnl 73.00000000000084
# nombre de candles en position : 7
# Equity : 201070.5
# Filtre de petite time frame passé, pour i= 3175 et un index à i de 2020-07-27 07:10:00
# Filtre de grosse time frame passé, pour j= 5434 et un index à j de 2020-07-26 21:00:00
# 3175
# bought at 1.17105
# 3213
# TP position closed at 1.17243  pnl 69.00000000000794
# nombre de candles en position : 38
# Equity : 201139.5
# Filtre de petite time frame passé, pour i= 3385 et un index à i de 2020-07-28 00:40:00
# Filtre de grosse time frame passé, pour j= 5435 et un index à j de 2020-07-27 21:00:00
# 3385
# bought at 1.17652
# 3874
# TP position closed at 1.17772  pnl 60.00000000000449
# nombre de candles en position : 489
# Equity : 201199.5
# Filtre de petite time frame passé, pour i= 3921 et un index à i de 2020-07-29 21:20:00
# Filtre de grosse time frame passé, pour j= 5437 et un index à j de 2020-07-29 21:00:00
# 3921
# bought at 1.1792
# Filtre de petite time frame passé, pour i= 3979 et un index à i de 2020-07-30 02:10:00
# Filtre de grosse time frame passé, pour j= 5437 et un index à j de 2020-07-29 21:00:00
# 3979
# bought at 1.17704
# 3993
# TP position closed at 1.17829  pnl 62.499999999998664
# nombre de candles en position : 14
# Equity : 201262.0
# Filtre de petite time frame passé, pour i= 4082 et un index à i de 2020-07-30 10:45:00
# Filtre de grosse time frame passé, pour j= 5437 et un index à j de 2020-07-29 21:00:00
# 4082
# bought at 1.17514
# 4108
# TP position closed at 1.17765  pnl 125.50000000000061
# nombre de candles en position : 26
# Equity : 201387.5
# Filtre de petite time frame passé, pour i= 4279 et un index à i de 2020-07-31 03:10:00
# Filtre de grosse time frame passé, pour j= 5438 et un index à j de 2020-07-30 21:00:00
# 4279
# bought at 1.189
# 4322
# TP position closed at 1.19047  pnl 73.49999999999301
# nombre de candles en position : 43
# Equity : 201461.0
# Filtre de petite time frame passé, pour i= 4329 et un index à i de 2020-07-31 07:20:00
# Filtre de grosse time frame passé, pour j= 5438 et un index à j de 2020-07-30 21:00:00
# 4329
# bought at 1.1892
# Filtre de petite time frame passé, pour i= 4405 et un index à i de 2020-07-31 13:40:00
# Filtre de grosse time frame passé, pour j= 5438 et un index à j de 2020-07-30 21:00:00
# 4405
# bought at 1.18199
# 4410
# TP position closed at 1.18349  pnl 74.99999999999174
# nombre de candles en position : 5
# Equity : 201536.0
# Filtre de petite time frame passé, pour i= 4510 et un index à i de 2020-08-02 20:45:00
# Filtre de grosse time frame passé, pour j= 5439 et un index à j de 2020-08-01 21:00:00
# 4510
# bought at 1.17777
# 4533
# TP position closed at 1.17912  pnl 67.49999999999812
# nombre de candles en position : 23
# Equity : 201603.5
# Filtre de petite time frame passé, pour i= 4750 et un index à i de 2020-08-03 16:45:00
# Filtre de grosse time frame passé, pour j= 5440 et un index à j de 2020-08-02 21:00:00
# 4750
# bought at 1.17447
# 4772
# TP position closed at 1.17613  pnl 82.99999999999974
# nombre de candles en position : 22
# Equity : 201686.5
# Filtre de petite time frame passé, pour i= 4841 et un index à i de 2020-08-04 00:20:00
# Filtre de grosse time frame passé, pour j= 5441 et un index à j de 2020-08-03 21:00:00
# 4841
# bought at 1.17563
# 4868
# TP position closed at 1.17703  pnl 70.0000000000034
# nombre de candles en position : 27
# Equity : 201756.5
# Filtre de petite time frame passé, pour i= 4906 et un index à i de 2020-08-04 05:45:00
# Filtre de grosse time frame passé, pour j= 5441 et un index à j de 2020-08-03 21:00:00
# 4906
# bought at 1.17683
# 4921
# TP position closed at 1.17815  pnl 65.99999999999939
# nombre de candles en position : 15
# Equity : 201822.5
# Filtre de petite time frame passé, pour i= 4941 et un index à i de 2020-08-04 08:40:00
# Filtre de grosse time frame passé, pour j= 5441 et un index à j de 2020-08-03 21:00:00
# 4941
# bought at 1.17826
# 4947
# TP position closed at 1.1795  pnl 61.999999999995396
# nombre de candles en position : 6
# Equity : 201884.5
# Filtre de petite time frame passé, pour i= 5198 et un index à i de 2020-08-05 06:05:00
# Filtre de grosse time frame passé, pour j= 5442 et un index à j de 2020-08-04 21:00:00
# 5198
# bought at 1.18069
# 5207
# TP position closed at 1.18249  pnl 90.0000000000012
# nombre de candles en position : 9
# Equity : 201974.5
# Filtre de petite time frame passé, pour i= 5341 et un index à i de 2020-08-05 18:00:00
# Filtre de grosse time frame passé, pour j= 5442 et un index à j de 2020-08-04 21:00:00
# 5341
# bought at 1.18674
# 5415
# TP position closed at 1.18826  pnl 76.0000000000094
# nombre de candles en position : 74
# Equity : 202050.5
# Filtre de petite time frame passé, pour i= 5495 et un index à i de 2020-08-06 06:50:00
# Filtre de grosse time frame passé, pour j= 5443 et un index à j de 2020-08-05 21:00:00
# 5495
# bought at 1.18784
# Filtre de petite time frame passé, pour i= 5504 et un index à i de 2020-08-06 07:35:00
# Filtre de grosse time frame passé, pour j= 5443 et un index à j de 2020-08-05 21:00:00
# 5504
# bought at 1.18632
# 5606
# TP position closed at 1.18851  pnl 109.49999999999571
# nombre de candles en position : 102
# Equity : 202160.0
# Filtre de petite time frame passé, pour i= 6633 et un index à i de 2020-08-12 04:35:00
# Filtre de grosse time frame passé, pour j= 5448 et un index à j de 2020-08-11 21:00:00
# 6633
# bought at 1.17178
# 6651
# TP position closed at 1.17317  pnl 69.50000000000011
# nombre de candles en position : 18
# Equity : 202229.5
# Filtre de petite time frame passé, pour i= 6763 et un index à i de 2020-08-12 15:25:00
00
# Filtre de grosse time frame passé, pour j= 5460 et un index à j de 2020-08-25 21:00:00
# 9688
# bought at 1.18239
# 9740
# TP position closed at 1.18362  pnl 61.49999999999211
# nombre de candles en position : 52
# Equity : 202940.0
#
# Les gains faramineux s'élèvent à : $  2940.0 !. En  58  transactions.
#
# Nbre de winners : 42
#
# Nbre de loosers : 0
#
# Average trade duration  48.6
# Total des gains faramineux : 2942.0
#  Le rate du ticker USD/JPY est à  106.562
#  Scraping des données OHLC pour le ticker  USD/JPY
#  Scraping des données OHLC pour le ticker  USD/JPY
# Filtre de petite time frame passé, pour i= 45 et un index à i de 2020-07-10 04:20:00
# Filtre de grosse time frame passé, pour j= 5406 et un index à j de 2020-07-09 21:00:00
# 45
# sold at 106.999
# 71
# TP position closed at 106.882  pnl 54.9
# nombre de candles en position : 26
# Equity : 202994.9
# Filtre de petite time frame passé, pour i= 111 et un index à i de 2020-07-10 09:50:00
# Filtre de grosse time frame passé, pour j= 5406 et un index à j de 2020-07-09 21:00:00
# 111
# sold at 106.793
# Filtre de petite time frame passé, pour i= 878 et un index à i de 2020-07-15 01:00:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-14 21:00:00
# 878
# sold at 107.274
# Filtre de petite time frame passé, pour i= 903 et un index à i de 2020-07-15 03:05:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-14 21:00:00
# 903
# sold at 107.256
# Filtre de petite time frame passé, pour i= 929 et un index à i de 2020-07-15 05:15:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-14 21:00:00
# 929
# sold at 107.262
# 953
# TP position closed at 107.127  pnl 63.34
# nombre de candles en position : 24
# Equity : 203058.24
# Filtre de petite time frame passé, pour i= 1003 et un index à i de 2020-07-15 11:25:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-14 21:00:00
# 1003
# sold at 106.947
# 1011
# TP position closed at 106.833  pnl 53.49
# nombre de candles en position : 8
# Equity : 203111.72999999998
# Filtre de petite time frame passé, pour i= 1062 et un index à i de 2020-07-15 16:20:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-14 21:00:00
# 1062
# sold at 106.942
# Filtre de petite time frame passé, pour i= 1083 et un index à i de 2020-07-15 18:05:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-14 21:00:00
# 1083
# sold at 106.932
# Filtre de petite time frame passé, pour i= 1412 et un index à i de 2020-07-16 21:40:00
# Filtre de grosse time frame passé, pour j= 5412 et un index à j de 2020-07-16 21:00:00
# 1412
# sold at 107.241
# 1528
# TP position closed at 107.127  pnl 53.49
# nombre de candles en position : 116
# Equity : 203165.21999999997
# Filtre de petite time frame passé, pour i= 1595 et un index à i de 2020-07-17 12:55:00
# Filtre de grosse time frame passé, pour j= 5412 et un index à j de 2020-07-16 21:00:00
# 1595
# sold at 107.234
# 1616
# TP position closed at 107.125  pnl 51.14
# nombre de candles en position : 21
# Equity : 203216.36
# Filtre de petite time frame passé, pour i= 2123 et un index à i de 2020-07-21 09:05:00
# Filtre de grosse time frame passé, pour j= 5414 et un index à j de 2020-07-20 21:00:00
# 2123
# sold at 107.273
# Filtre de petite time frame passé, pour i= 2150 et un index à i de 2020-07-21 11:20:00
# Filtre de grosse time frame passé, pour j= 5414 et un index à j de 2020-07-20 21:00:00
# 2150
# sold at 107.282
# 2162
# TP position closed at 107.16  pnl 57.24
# nombre de candles en position : 12
# Equity : 203273.59999999998
# Filtre de petite time frame passé, pour i= 2583 et un index à i de 2020-07-22 23:25:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-07-22 21:00:00
# 2583
# sold at 107.172
# Filtre de petite time frame passé, pour i= 2610 et un index à i de 2020-07-23 01:40:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-07-22 21:00:00
# 2610
# sold at 107.115
# Filtre de petite time frame passé, pour i= 2759 et un index à i de 2020-07-23 14:25:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-07-22 21:00:00
# 2759
# sold at 107.101
# 2765
# TP position closed at 106.99  pnl 52.08
# nombre de candles en position : 6
# Equity : 203325.67999999996
# Filtre de petite time frame passé, pour i= 3464 et un index à i de 2020-07-27 23:30:00
# Filtre de grosse time frame passé, pour j= 5420 et un index à j de 2020-07-27 21:00:00
# 3464
# sold at 105.348
# 3473
# TP position closed at 105.235  pnl 53.02
# nombre de candles en position : 9
# Equity : 203378.69999999995
# Filtre de petite time frame passé, pour i= 3481 et un index à i de 2020-07-28 00:55:00
# Filtre de grosse time frame passé, pour j= 5420 et un index à j de 2020-07-27 21:00:00
# 3481
# sold at 105.322
# Filtre de petite time frame passé, pour i= 3518 et un index à i de 2020-07-28 04:00:00
# Filtre de grosse time frame passé, pour j= 5420 et un index à j de 2020-07-27 21:00:00
# 3518
# sold at 105.543
# 3577
# TP position closed at 105.41  pnl 62.4
# nombre de candles en position : 59
# Equity : 203441.09999999995
# Filtre de petite time frame passé, pour i= 3681 et un index à i de 2020-07-28 17:40:00
# Filtre de grosse time frame passé, pour j= 5420 et un index à j de 2020-07-27 21:00:00
# 3681
# sold at 105.052
# 3843
# TP position closed at 104.843  pnl 98.06
# nombre de candles en position : 162
# Equity : 203539.15999999995
# Filtre de petite time frame passé, pour i= 3897 et un index à i de 2020-07-29 12:10:00
# Filtre de grosse time frame passé, pour j= 5421 et un index à j de 2020-07-28 21:00:00
# 3897
# sold at 105.132
# 3908
# TP position closed at 105.003  pnl 60.53
# nombre de candles en position : 11
# Equity : 203599.68999999994
# Filtre de petite time frame passé, pour i= 4088 et un index à i de 2020-07-30 04:05:00
# Filtre de grosse time frame passé, pour j= 5422 et un index à j de 2020-07-29 21:00:00
# 4088
# sold at 105.023
# 4245
# TP position closed at 104.876  pnl 68.97
# nombre de candles en position : 157
# Equity : 203668.65999999995
# Filtre de petite time frame passé, pour i= 4258 et un index à i de 2020-07-30 18:15:00
# Filtre de grosse time frame passé, pour j= 5422 et un index à j de 2020-07-29 21:00:00
# 4258
# sold at 104.877
# 4278
# TP position closed at 104.76  pnl 54.9
# nombre de candles en position : 20
# Equity : 203723.55999999994
# Filtre de petite time frame passé, pour i= 4913 et un index à i de 2020-08-04 00:25:00
# Filtre de grosse time frame passé, pour j= 5426 et un index à j de 2020-08-03 21:00:00
# 4913
# sold at 106.073
# Filtre de petite time frame passé, pour i= 4921 et un index à i de 2020-08-04 01:05:00
# Filtre de grosse time frame passé, pour j= 5426 et un index à j de 2020-08-03 21:00:00
# 4921
# sold at 106.099
# 4992
# TP position closed at 105.982  pnl 54.9
# nombre de candles en position : 71
# Equity : 203778.45999999993
# Filtre de petite time frame passé, pour i= 5372 et un index à i de 2020-08-05 15:00:00
# Filtre de grosse time frame passé, pour j= 5427 et un index à j de 2020-08-04 21:00:00
# 5372
# sold at 105.517
# Filtre de petite time frame passé, pour i= 5430 et un index à i de 2020-08-05 19:50:00
# Filtre de grosse time frame passé, pour j= 5427 et un index à j de 2020-08-04 21:00:00
# 5430
# sold at 105.592
# Filtre de petite time frame passé, pour i= 5434 et un index à i de 2020-08-05 20:10:00
# Filtre de grosse time frame passé, pour j= 5427 et un index à j de 2020-08-04 21:00:00
# 5434
# sold at 105.613
# 5482
# TP position closed at 105.467  pnl 68.5
# nombre de candles en position : 48
# Equity : 203846.95999999993
# Filtre de petite time frame passé, pour i= 5562 et un index à i de 2020-08-06 06:50:00
# Filtre de grosse time frame passé, pour j= 5428 et un index à j de 2020-08-05 21:00:00
# 5562
# sold at 105.485
# Filtre de petite time frame passé, pour i= 5577 et un index à i de 2020-08-06 08:05:00
# Filtre de grosse time frame passé, pour j= 5428 et un index à j de 2020-08-05 21:00:00
# 5577
# sold at 105.593
# 5613
# TP position closed at 105.482  pnl 52.08
# nombre de candles en position : 36
# Equity : 203899.03999999992
# Filtre de petite time frame passé, pour i= 5636 et un index à i de 2020-08-06 13:00:00
# Filtre de grosse time frame passé, pour j= 5428 et un index à j de 2020-08-05 21:00:00
# 5636
# sold at 105.509
# 5644
# TP position closed at 105.381  pnl 60.06
# nombre de candles en position : 8
# Equity : 203959.09999999992
# Filtre de petite time frame passé, pour i= 8509 et un index à i de 2020-08-20 16:30:00
# Filtre de grosse time frame passé, pour j= 5439 et un index à j de 2020-08-19 21:00:00
# 8509
# sold at 105.811
# Filtre de petite time frame passé, pour i= 8561 et un index à i de 2020-08-20 20:50:00
# Filtre de grosse time frame passé, pour j= 5439 et un index à j de 2020-08-19 21:00:00
# 8561
# sold at 105.783
# 8602
# TP position closed at 105.676  pnl 50.21
# nombre de candles en position : 41
# Equity : 204009.3099999999
# Filtre de petite time frame passé, pour i= 8613 et un index à i de 2020-08-21 01:10:00
# Filtre de grosse time frame passé, pour j= 5440 et un index à j de 2020-08-20 21:00:00
# 8613
# sold at 105.703
# 8662
# TP position closed at 105.572  pnl 61.47
# nombre de candles en position : 49
# Equity : 204070.7799999999
# Filtre de petite time frame passé, pour i= 9472 et un index à i de 2020-08-26 00:20:00
# Filtre de grosse time frame passé, pour j= 5444 et un index à j de 2020-08-25 21:00:00
# 9472
# sold at 106.522
# 9522
# TP position closed at 106.402  pnl 56.31
# nombre de candles en position : 50
# Equity : 204127.0899999999
# Filtre de petite time frame passé, pour i= 9565 et un index à i de 2020-08-26 08:05:00
# Filtre de grosse time frame passé, pour j= 5444 et un index à j de 2020-08-25 21:00:00
# 9565
# sold at 106.257
# Filtre de petite time frame passé, pour i= 9582 et un index à i de 2020-08-26 09:30:00
# Filtre de grosse time frame passé, pour j= 5444 et un index à j de 2020-08-25 21:00:00
# 9582
# sold at 106.293
# Filtre de petite time frame passé, pour i= 9599 et un index à i de 2020-08-26 10:55:00
# Filtre de grosse time frame passé, pour j= 5444 et un index à j de 2020-08-25 21:00:00
# 9599
# sold at 106.256
# 9644
# TP position closed at 106.14  pnl 54.43
# nombre de candles en position : 45
# Equity : 204181.5199999999
# Filtre de petite time frame passé, pour i= 9679 et un index à i de 2020-08-26 17:35:00
# Filtre de grosse time frame passé, pour j= 5444 et un index à j de 2020-08-25 21:00:00
# 9679
# sold at 105.983
# Filtre de petite time frame passé, pour i= 9695 et un index à i de 2020-08-26 18:55:00
# Filtre de grosse time frame passé, pour j= 5444 et un index à j de 2020-08-25 21:00:00
# 9695
# sold at 106.012
# 9740
# TP position closed at 105.847  pnl 77.42
# nombre de candles en position : 45
# Equity : 204258.93999999992
#
# Les gains faramineux s'élèvent à : $  1318.94 !. En  39  transactions.
#
# Nbre de winners : 22
#
# Nbre de loosers : 0
#
# Average trade duration  46.55
# Total des gains faramineux : 4260.94
#  Le rate du ticker GBP/USD est à  1
#  Scraping des données OHLC pour le ticker  GBP/USD
#  Scraping des données OHLC pour le ticker  GBP/USD
# Filtre de petite time frame passé, pour i= 189 et un index à i de 2020-07-10 19:15:00
# Filtre de grosse time frame passé, pour j= 5400 et un index à j de 2020-07-09 21:00:00
# 189
# bought at 1.26263
# 250
# TP position closed at 1.26477  pnl 107.00000000000153
# nombre de candles en position : 61
# Equity : 204365.93999999992
# Filtre de petite time frame passé, pour i= 903 et un index à i de 2020-07-15 07:25:00
# Filtre de grosse time frame passé, pour j= 5404 et un index à j de 2020-07-14 21:00:00
# 903
# bought at 1.25933
# 908
# TP position closed at 1.26068  pnl 67.49999999999812
# nombre de candles en position : 5
# Equity : 204433.43999999992
# Filtre de petite time frame passé, pour i= 922 et un index à i de 2020-07-15 09:00:00
# Filtre de grosse time frame passé, pour j= 5404 et un index à j de 2020-07-14 21:00:00
# 922
# bought at 1.26035
# 936
# TP position closed at 1.26229  pnl 96.99999999999153
# nombre de candles en position : 14
# Equity : 204530.43999999992
# Filtre de petite time frame passé, pour i= 1016 et un index à i de 2020-07-15 16:50:00
# Filtre de grosse time frame passé, pour j= 5404 et un index à j de 2020-07-14 21:00:00
# 1016
# bought at 1.2588
# Filtre de petite time frame passé, pour i= 1031 et un index à i de 2020-07-15 18:05:00
# Filtre de grosse time frame passé, pour j= 5404 et un index à j de 2020-07-14 21:00:00
# 1031
# bought at 1.25854
# 1281
# TP position closed at 1.25991  pnl 68.50000000000466
# nombre de candles en position : 250
# Equity : 204598.93999999992
# Filtre de petite time frame passé, pour i= 1367 et un index à i de 2020-07-16 22:05:00
# Filtre de grosse time frame passé, pour j= 5406 et un index à j de 2020-07-16 21:00:00
# 1367
# bought at 1.25552
# 1433
# TP position closed at 1.25689  pnl 68.50000000000466
# nombre de candles en position : 66
# Equity : 204667.43999999992
# Filtre de petite time frame passé, pour i= 1544 et un index à i de 2020-07-17 12:50:00
# Filtre de grosse time frame passé, pour j= 5406 et un index à j de 2020-07-16 21:00:00
# 1544
# bought at 1.25182
# 1549
# TP position closed at 1.25312  pnl 65.00000000000395
# nombre de candles en position : 5
# Equity : 204732.43999999992
# Filtre de petite time frame passé, pour i= 1636 et un index à i de 2020-07-17 20:30:00
# Filtre de grosse time frame passé, pour j= 5406 et un index à j de 2020-07-16 21:00:00
00
# Filtre de grosse time frame passé, pour j= 5441 et un index à j de 2020-08-26 21:00:00
# 9787
# bought at 1.31995
# 9847
# TP position closed at 1.3217  pnl 87.50000000000702
# nombre de candles en position : 60
# Equity : 207452.43999999992
# Filtre de petite time frame passé, pour i= 9988 et un index à i de 2020-08-27 19:20:00
# Filtre de grosse time frame passé, pour j= 5441 et un index à j de 2020-08-26 21:00:00
# 9988
# bought at 1.32072
#
# Les gains faramineux s'élèvent à : $  3193.5 !. En  52  transactions.
#
# Nbre de winners : 40
#
# Nbre de loosers : 0
#
# Average trade duration  42.95
# Total des gains faramineux : 7429.94
#  Le rate du ticker USD/CHF est à  0.90887
#  Scraping des données OHLC pour le ticker  USD/CHF
#  Scraping des données OHLC pour le ticker  USD/CHF
# Filtre de petite time frame passé, pour i= 228 et un index à i de 2020-07-12 23:25:00
# Filtre de grosse time frame passé, pour j= 5396 et un index à j de 2020-07-12 21:00:00
# 228
# sold at 0.94025
# Filtre de petite time frame passé, pour i= 322 et un index à i de 2020-07-13 07:15:00
# Filtre de grosse time frame passé, pour j= 5396 et un index à j de 2020-07-12 21:00:00
# 322
# sold at 0.93967
# Filtre de petite time frame passé, pour i= 376 et un index à i de 2020-07-13 11:45:00
# Filtre de grosse time frame passé, pour j= 5396 et un index à j de 2020-07-12 21:00:00
# 376
# sold at 0.94215
# 402
# TP position closed at 0.9411  pnl 57.76
# nombre de candles en position : 26
# Equity : 207510.19999999992
# Filtre de petite time frame passé, pour i= 448 et un index à i de 2020-07-13 17:45:00
# Filtre de grosse time frame passé, pour j= 5396 et un index à j de 2020-07-12 21:00:00
# 448
# sold at 0.94054
# Filtre de petite time frame passé, pour i= 529 et un index à i de 2020-07-14 00:30:00
# Filtre de grosse time frame passé, pour j= 5397 et un index à j de 2020-07-13 21:00:00
# 529
# sold at 0.9423
# 601
# TP position closed at 0.9412  pnl 60.51
# nombre de candles en position : 72
# Equity : 207570.70999999993
# Filtre de petite time frame passé, pour i= 624 et un index à i de 2020-07-14 08:25:00
# Filtre de grosse time frame passé, pour j= 5397 et un index à j de 2020-07-13 21:00:00
# 624
# sold at 0.94035
# 631
# TP position closed at 0.93936  pnl 54.46
# nombre de candles en position : 7
# Equity : 207625.16999999993
# Filtre de petite time frame passé, pour i= 729 et un index à i de 2020-07-14 17:10:00
# Filtre de grosse time frame passé, pour j= 5397 et un index à j de 2020-07-13 21:00:00
# 729
# sold at 0.93845
# 904
# TP position closed at 0.93731  pnl 62.72
# nombre de candles en position : 175
# Equity : 207687.88999999993
# Filtre de petite time frame passé, pour i= 1543 et un index à i de 2020-07-17 13:00:00
# Filtre de grosse time frame passé, pour j= 5400 et un index à j de 2020-07-16 21:00:00
# 1543
# sold at 0.94064
# 1556
# TP position closed at 0.93958  pnl 58.31
# nombre de candles en position : 13
# Equity : 207746.19999999992
# Filtre de petite time frame passé, pour i= 1633 et un index à i de 2020-07-17 20:30:00
# Filtre de grosse time frame passé, pour j= 5400 et un index à j de 2020-07-16 21:00:00
# 1633
# sold at 0.93828
# Filtre de petite time frame passé, pour i= 1997 et un index à i de 2020-07-21 02:55:00
# Filtre de grosse time frame passé, pour j= 5402 et un index à j de 2020-07-20 21:00:00
# 1997
# sold at 0.9382
# 2084
# TP position closed at 0.93725  pnl 52.26
# nombre de candles en position : 87
# Equity : 207798.45999999993
# Filtre de petite time frame passé, pour i= 2306 et un index à i de 2020-07-22 04:40:00
# Filtre de grosse time frame passé, pour j= 5403 et un index à j de 2020-07-21 21:00:00
# 2306
# sold at 0.93236
# 2398
# TP position closed at 0.93103  pnl 73.17
# nombre de candles en position : 92
# Equity : 207871.62999999995
# Filtre de petite time frame passé, pour i= 2408 et un index à i de 2020-07-22 13:10:00
# Filtre de grosse time frame passé, pour j= 5403 et un index à j de 2020-07-21 21:00:00
# 2408
# sold at 0.93065
# 2429
# TP position closed at 0.9291  pnl 85.27
# nombre de candles en position : 21
# Equity : 207956.89999999994
# Filtre de petite time frame passé, pour i= 3055 et un index à i de 2020-07-24 19:05:00
# Filtre de grosse time frame passé, pour j= 5405 et un index à j de 2020-07-23 21:00:00
# 3055
# sold at 0.92198
# Filtre de petite time frame passé, pour i= 3067 et un index à i de 2020-07-24 20:05:00
# Filtre de grosse time frame passé, pour j= 5405 et un index à j de 2020-07-23 21:00:00
# 3067
# sold at 0.92238
# 3074
# TP position closed at 0.92105  pnl 73.17
# nombre de candles en position : 7
# Equity : 208030.06999999995
# Filtre de petite time frame passé, pour i= 3218 et un index à i de 2020-07-27 07:45:00
# Filtre de grosse time frame passé, pour j= 5407 et un index à j de 2020-07-26 21:00:00
# 3218
# sold at 0.91834
# Filtre de petite time frame passé, pour i= 3374 et un index à i de 2020-07-27 20:45:00
# Filtre de grosse time frame passé, pour j= 5407 et un index à j de 2020-07-26 21:00:00
# 3374
# sold at 0.92002
# Filtre de petite time frame passé, pour i= 3421 et un index à i de 2020-07-28 00:40:00
# Filtre de grosse time frame passé, pour j= 5408 et un index à j de 2020-07-27 21:00:00
# 3421
# sold at 0.91988
# Filtre de petite time frame passé, pour i= 3480 et un index à i de 2020-07-28 05:35:00
# Filtre de grosse time frame passé, pour j= 5408 et un index à j de 2020-07-27 21:00:00
# 3480
# sold at 0.92205
# 3491
# TP position closed at 0.92089  pnl 63.82
# nombre de candles en position : 11
# Equity : 208093.88999999996
# Filtre de petite time frame passé, pour i= 3598 et un index à i de 2020-07-28 15:25:00
# Filtre de grosse time frame passé, pour j= 5408 et un index à j de 2020-07-27 21:00:00
# 3598
# sold at 0.91804
# 3604
# TP position closed at 0.91702  pnl 56.11
# nombre de candles en position : 6
# Equity : 208149.99999999994
# Filtre de petite time frame passé, pour i= 3654 et un index à i de 2020-07-28 20:05:00
# Filtre de grosse time frame passé, pour j= 5408 et un index à j de 2020-07-27 21:00:00
# 3654
# sold at 0.91775
# Filtre de petite time frame passé, pour i= 3704 et un index à i de 2020-07-29 00:15:00
# Filtre de grosse time frame passé, pour j= 5409 et un index à j de 2020-07-28 21:00:00
# 3704
# sold at 0.91761
# 3775
# TP position closed at 0.91664  pnl 53.36
# nombre de candles en position : 71
# Equity : 208203.35999999993
# Filtre de petite time frame passé, pour i= 3812 et un index à i de 2020-07-29 09:15:00
# Filtre de grosse time frame passé, pour j= 5409 et un index à j de 2020-07-28 21:00:00
# 3812
# sold at 0.91539
# Filtre de petite time frame passé, pour i= 3837 et un index à i de 2020-07-29 11:20:00
# ...
# 7190
# sold at 3.4018
# Filtre de petite time frame passé, pour i= 8225 et un index à i de 2020-08-19 10:25:00
# Filtre de grosse time frame passé, pour j= 2455 et un index à j de 2020-08-18 21:00:00
# 8225
# sold at 3.3997
# Filtre de petite time frame passé, pour i= 8347 et un index à i de 2020-08-19 20:35:00
# Filtre de grosse time frame passé, pour j= 2455 et un index à j de 2020-08-18 21:00:00
# 8347
# sold at 3.4027
# Filtre de petite time frame passé, pour i= 9870 et un index à i de 2020-08-27 09:25:00
# Filtre de grosse time frame passé, pour j= 2462 et un index à j de 2020-08-26 21:00:00
# 9870
# sold at 3.39892
# 9880
# TP position closed at 3.39061  pnl 123.29
# nombre de candles en position : 10
# Equity : 239079.2200000001
#
# Les gains faramineux s'élèvent à : $  350.29 !. En  14  transactions.
#
# Nbre de winners : 5
#
# Nbre de loosers : 0
#
# Average trade duration  160.6
# Total des gains faramineux : 39081.22
#  Le rate du ticker USD/CNH est à  6.88786
#  Scraping des données OHLC pour le ticker  USD/CNH
#  Scraping des données OHLC pour le ticker  USD/CNH
# Filtre de petite time frame passé, pour i= 67 et un index à i de 2020-07-10 08:55:00
# Filtre de grosse time frame passé, pour j= 2501 et un index à j de 2020-07-09 21:00:00
# 67
# sold at 7.01075
# 79
# TP position closed at 7.00363  pnl 51.69
# nombre de candles en position : 12
# Equity : 239130.9100000001
# Filtre de petite time frame passé, pour i= 108 et un index à i de 2020-07-10 12:20:00
# Filtre de grosse time frame passé, pour j= 2501 et un index à j de 2020-07-09 21:00:00
# 108
# sold at 7.00623
# Filtre de petite time frame passé, pour i= 148 et un index à i de 2020-07-10 15:40:00
# Filtre de grosse time frame passé, pour j= 2501 et un index à j de 2020-07-09 21:00:00
# 148
# sold at 7.00466
# 299
# TP position closed at 6.99723  pnl 53.94
# nombre de candles en position : 151
# Equity : 239184.8500000001
# Filtre de petite time frame passé, pour i= 360 et un index à i de 2020-07-13 08:30:00
# Filtre de grosse time frame passé, pour j= 2503 et un index à j de 2020-07-12 21:00:00
# 360
# sold at 7.00531
# 400
# TP position closed at 6.99791  pnl 53.72
# nombre de candles en position : 40
# Equity : 239238.5700000001
# Filtre de petite time frame passé, pour i= 482 et un index à i de 2020-07-13 18:40:00
# Filtre de grosse time frame passé, pour j= 2503 et un index à j de 2020-07-12 21:00:00
# 482
# sold at 7.00129
# 851
# TP position closed at 6.99248  pnl 63.95
# nombre de candles en position : 369
# Equity : 239302.5200000001
# Filtre de petite time frame passé, pour i= 1352 et un index à i de 2020-07-16 19:15:00
# Filtre de grosse time frame passé, pour j= 2506 et un index à j de 2020-07-15 21:00:00
# 1352
# sold at 6.9971
# Filtre de petite time frame passé, pour i= 1518 et un index à i de 2020-07-17 09:20:00
# Filtre de grosse time frame passé, pour j= 2507 et un index à j de 2020-07-16 21:00:00
# 1518
# sold at 6.9968
# 1621
# TP position closed at 6.98978  pnl 50.96
# nombre de candles en position : 103
# Equity : 239353.4800000001
# Filtre de petite time frame passé, pour i= 1783 et un index à i de 2020-07-20 07:10:00
# Filtre de grosse time frame passé, pour j= 2509 et un index à j de 2020-07-19 21:00:00
# 1783
# sold at 6.98688
# Filtre de petite time frame passé, pour i= 2036 et un index à i de 2020-07-21 04:30:00
# Filtre de grosse time frame passé, pour j= 2510 et un index à j de 2020-07-20 21:00:00
# 2036
# sold at 6.99082
# 2133
# TP position closed at 6.98347  pnl 53.35
# nombre de candles en position : 97
# Equity : 239406.8300000001
# Filtre de petite time frame passé, pour i= 2219 et un index à i de 2020-07-21 19:45:00
# Filtre de grosse time frame passé, pour j= 2510 et un index à j de 2020-07-20 21:00:00
# 2219
# sold at 6.97267
# Filtre de petite time frame passé, pour i= 2281 et un index à i de 2020-07-22 00:55:00
# Filtre de grosse time frame passé, pour j= 2511 et un index à j de 2020-07-21 21:00:00
# 2281
# sold at 6.97282
# 2292
# TP position closed at 6.96542  pnl 53.72
# nombre de candles en position : 11
# Equity : 239460.5500000001
# Filtre de petite time frame passé, pour i= 2512 et un index à i de 2020-07-22 20:10:00
# Filtre de grosse time frame passé, pour j= 2511 et un index à j de 2020-07-21 21:00:00
# 2512
# sold at 7.01623
# 2570
# TP position closed at 7.00641  pnl 71.28
# nombre de candles en position : 58
# Equity : 239531.8300000001
# Filtre de petite time frame passé, pour i= 3389 et un index à i de 2020-07-27 21:45:00
# Filtre de grosse time frame passé, pour j= 2516 et un index à j de 2020-07-27 21:00:00
# 3389
# sold at 6.99788
# 3430
# TP position closed at 6.9906  pnl 52.85
# nombre de candles en position : 41
# Equity : 239584.6800000001
# Filtre de petite time frame passé, pour i= 3464 et un index à i de 2020-07-28 04:00:00
# Filtre de grosse time frame passé, pour j= 2516 et un index à j de 2020-07-27 21:00:00
# 3464
# sold at 7.00297
# Filtre de petite time frame passé, pour i= 3494 et un index à i de 2020-07-28 06:30:00
# Filtre de grosse time frame passé, pour j= 2516 et un index à j de 2020-07-27 21:00:00
# 3494
# sold at 7.00227
# Filtre de petite time frame passé, pour i= 3690 et un index à i de 2020-07-28 22:50:00
# Filtre de grosse time frame passé, pour j= 2517 et un index à j de 2020-07-28 21:00:00
# 3690
# sold at 7.00657
# 3796
# TP position closed at 6.99745  pnl 66.2
# nombre de candles en position : 106
# Equity : 239650.88000000012
# Filtre de petite time frame passé, pour i= 3855 et un index à i de 2020-07-29 12:35:00
# Filtre de grosse time frame passé, pour j= 2517 et un index à j de 2020-07-28 21:00:00
# 3855
# sold at 7.00591
# 3922
# TP position closed at 6.99736  pnl 62.07
# nombre de candles en position : 67
# Equity : 239712.95000000013
# Filtre de petite time frame passé, pour i= 3933 et un index à i de 2020-07-29 19:05:00
# Filtre de grosse time frame passé, pour j= 2517 et un index à j de 2020-07-28 21:00:00
# 3933
# sold at 6.99813
# Filtre de petite time frame passé, pour i= 4097 et un index à i de 2020-07-30 08:45:00
# Filtre de grosse time frame passé, pour j= 2518 et un index à j de 2020-07-29 21:00:00
# 4097
# sold at 7.00781
# 4260
# TP position closed at 7.0002  pnl 55.24
# nombre de candles en position : 163
# Equity : 239768.19000000012
# Filtre de petite time frame passé, pour i= 4336 et un index à i de 2020-07-31 04:40:00
# Filtre de grosse time frame passé, pour j= 2519 et un index à j de 2020-07-30 21:00:00
# 4336
# sold at 6.99204
# Filtre de petite time frame passé, pour i= 4368 et un index à i de 2020-07-31 07:20:00
# Filtre de grosse time frame passé, pour j= 2519 et un index à j de 2020-07-30 21:00:00
# 4368
# sold at 6.99384
# 4376
# TP position closed at 6.98464  pnl 66.78
# nombre de candles en position : 8
# Equity : 239834.97000000012
# Filtre de petite time frame passé, pour i= 4806 et un index à i de 2020-08-03 19:20:00
# Filtre de grosse time frame passé, pour j= 2521 et un index à j de 2020-08-02 21:00:00
# 4806
# sold at 6.98395
# Filtre de petite time frame passé, pour i= 4927 et un index à i de 2020-08-04 05:25:00
# Filtre de grosse time frame passé, pour j= 2522 et un index à j de 2020-08-03 21:00:00
# 4927
# sold at 6.98277
# Filtre de petite time frame passé, pour i= 4958 et un index à i de 2020-08-04 08:00:00
# Filtre de grosse time frame passé, pour j= 2522 et un index à j de 2020-08-03 21:00:00
# 4958
# sold at 6.98775
# 5045
# TP position closed at 6.9807  pnl 51.18
# nombre de candles en position : 87
# Equity : 239886.1500000001
00
# Filtre de grosse time frame passé, pour j= 2530 et un index à j de 2020-08-12 21:00:00
# 7060
# sold at 6.94296
# Filtre de petite time frame passé, pour i= 7248 et un index à i de 2020-08-14 06:50:00
# Filtre de grosse time frame passé, pour j= 2531 et un index à j de 2020-08-13 21:00:00
# 7248
# sold at 6.94099
# 7522
# TP position closed at 6.93389  pnl 51.54
# nombre de candles en position : 274
# Equity : 240173.9800000001
# Filtre de petite time frame passé, pour i= 7575 et un index à i de 2020-08-17 10:20:00
# Filtre de grosse time frame passé, pour j= 2533 et un index à j de 2020-08-16 21:00:00
# 7575
# sold at 6.93737
# Filtre de petite time frame passé, pour i= 7696 et un index à i de 2020-08-17 20:25:00
# Filtre de grosse time frame passé, pour j= 2533 et un index à j de 2020-08-16 21:00:00
# 7696
# sold at 6.93291
# 7759
# TP position closed at 6.92314  pnl 70.92
# nombre de candles en position : 63
# Equity : 240244.9000000001
# Filtre de petite time frame passé, pour i= 8081 et un index à i de 2020-08-19 04:35:00
# Filtre de grosse time frame passé, pour j= 2535 et un index à j de 2020-08-18 21:00:00
# 8081
# sold at 6.91614
# 8125
# TP position closed at 6.90835  pnl 56.55
# nombre de candles en position : 44
# Equity : 240301.4500000001
# Filtre de petite time frame passé, pour i= 8146 et un index à i de 2020-08-19 10:00:00
# Filtre de grosse time frame passé, pour j= 2535 et un index à j de 2020-08-18 21:00:00
# 8146
# sold at 6.89978
# Filtre de petite time frame passé, pour i= 8180 et un index à i de 2020-08-19 12:50:00
# Filtre de grosse time frame passé, pour j= 2535 et un index à j de 2020-08-18 21:00:00
# 8180
# sold at 6.90562
# Filtre de petite time frame passé, pour i= 8310 et un index à i de 2020-08-19 23:40:00
# Filtre de grosse time frame passé, pour j= 2536 et un index à j de 2020-08-19 21:00:00
# 8310
# sold at 6.92193
# 8401
# TP position closed at 6.91322  pnl 63.23
# nombre de candles en position : 91
# Equity : 240364.6800000001
# Filtre de petite time frame passé, pour i= 8409 et un index à i de 2020-08-20 07:55:00
# Filtre de grosse time frame passé, pour j= 2536 et un index à j de 2020-08-19 21:00:00
# 8409
# sold at 6.91287
# Filtre de petite time frame passé, pour i= 8474 et un index à i de 2020-08-20 13:20:00
# Filtre de grosse time frame passé, pour j= 2536 et un index à j de 2020-08-19 21:00:00
# 8474
# sold at 6.91996
# 8485
# TP position closed at 6.91188  pnl 58.65
# nombre de candles en position : 11
# Equity : 240423.3300000001
# Filtre de petite time frame passé, pour i= 8705 et un index à i de 2020-08-21 08:55:00
# Filtre de grosse time frame passé, pour j= 2537 et un index à j de 2020-08-20 21:00:00
# 8705
# sold at 6.9087
# Filtre de petite time frame passé, pour i= 8787 et un index à i de 2020-08-21 15:45:00
# Filtre de grosse time frame passé, pour j= 2537 et un index à j de 2020-08-20 21:00:00
# 8787
# sold at 6.92058
# 8913
# TP position closed at 6.91338  pnl 52.27
# nombre de candles en position : 126
# Equity : 240475.6000000001
# Filtre de petite time frame passé, pour i= 8935 et un index à i de 2020-08-24 03:05:00
# Filtre de grosse time frame passé, pour j= 2539 et un index à j de 2020-08-23 21:00:00
# 8935
# sold at 6.91568
# 8992
# TP position closed at 6.90829  pnl 53.65
# nombre de candles en position : 57
# Equity : 240529.2500000001
# Filtre de petite time frame passé, pour i= 9050 et un index à i de 2020-08-24 12:40:00
# Filtre de grosse time frame passé, pour j= 2539 et un index à j de 2020-08-23 21:00:00
# 9050
# sold at 6.90681
# Filtre de petite time frame passé, pour i= 9067 et un index à i de 2020-08-24 14:05:00
# Filtre de grosse time frame passé, pour j= 2539 et un index à j de 2020-08-23 21:00:00
# 9067
# sold at 6.90838
# Filtre de petite time frame passé, pour i= 9137 et un index à i de 2020-08-24 19:55:00
# Filtre de grosse time frame passé, pour j= 2539 et un index à j de 2020-08-23 21:00:00
# 9137
# sold at 6.91398
# 9192
# TP position closed at 6.90624  pnl 56.19
# nombre de candles en position : 55
# Equity : 240585.4400000001
# Filtre de petite time frame passé, pour i= 9249 et un index à i de 2020-08-25 05:15:00
# Filtre de grosse time frame passé, pour j= 2540 et un index à j de 2020-08-24 21:00:00
# 9249
# sold at 6.90746
# Filtre de petite time frame passé, pour i= 9466 et un index à i de 2020-08-25 23:20:00
# Filtre de grosse time frame passé, pour j= 2541 et un index à j de 2020-08-25 21:00:00
# 9466
# sold at 6.90383
# 9554
# TP position closed at 6.89476  pnl 65.84
# nombre de candles en position : 88
# Equity : 240651.2800000001
# Filtre de petite time frame passé, pour i= 9596 et un index à i de 2020-08-26 10:10:00
# Filtre de grosse time frame passé, pour j= 2541 et un index à j de 2020-08-25 21:00:00
# 9596
# sold at 6.88556
# 9751
# TP position closed at 6.87803  pnl 54.66
# nombre de candles en position : 155
# Equity : 240705.9400000001
# Filtre de petite time frame passé, pour i= 9885 et un index à i de 2020-08-27 10:45:00
# Filtre de grosse time frame passé, pour j= 2542 et un index à j de 2020-08-26 21:00:00
# 9885
# sold at 6.88202
# 9915
# TP position closed at 6.87144  pnl 76.8
# nombre de candles en position : 30
# Equity : 240782.74000000008
# Filtre de petite time frame passé, pour i= 9922 et un index à i de 2020-08-27 13:50:00
# Filtre de grosse time frame passé, pour j= 2542 et un index à j de 2020-08-26 21:00:00
# 9922
# sold at 6.88208
#
# Les gains faramineux s'élèvent à : $  1703.52 !. En  59  transactions.
#
# Nbre de winners : 29
#
# Nbre de loosers : 0
#
# Average trade duration  85.28
# Total des gains faramineux : 40735.77
# CPU times: user 53.3 s, sys: 2 s, total: 55.3 s
# Wall time: 1min 46s

# %%
print(col.Fore.BLUE,'Total des gains faramineux :',round(EQUITY[-1] - _cash_ini,2),col.Style.RESET_ALL)
print(col.Fore.YELLOW,'Total du cash titanesque :',round(EQUITY[-1],2),col.Style.RESET_ALL)

df_resultats.T
# Out:
#  Total des gains faramineux : 40735.77
#  Total du cash titanesque : 240735.77
#         TimeFrame 1 TimeFrame2     Equity Nbre Winners Nbre Loosers  \
# EUR/USD          m5         D1   202942.0           42            0
# USD/JPY          m5         D1  204260.94           22            0
# GBP/USD          m5         D1  207429.94           40            0
# USD/CHF          m5         D1  209638.42           35            0
# EUR/CHF          m5         D1  210762.91           16            0
# AUD/USD          m5         D1  213015.91           48            0
# USD/CAD          m5         D1  215369.94           39            0
# NZD/USD          m5         D1  216408.94           23            0
# EUR/GBP          m5         D1  217721.23           19            0
# EUR/JPY          m5         D1  219575.16           35            1
# GBP/JPY          m5         D1  221824.04           27            0
# CHF/JPY          m5         D1  223127.02           29            1
# GBP/CHF          m5         D1  223327.83           10            1
# EUR/AUD          m5         D1  224389.77           15            0
# EUR/CAD          m5         D1  224704.35           28            3
# AUD/CAD          m5         D1  225164.42           20            1
# AUD/JPY          m5         D1   225696.5           21            1
# CAD/JPY          m5         D1  226154.92           19            1
# NZD/JPY          m5         D1  226383.88           13            1
# GBP/CAD          m5         D1  228175.85           23            0
# GBP/NZD          m5         D1  229846.38           29            1
# GBP/AUD          m5         D1  231406.47           19            0
# AUD/NZD          m5         D1  232135.39           21            1
# USD/SEK          m5         D1  233896.25           33            1
# EUR/SEK          m5         D1  234509.12           16            1
# EUR/NOK          m5         D1  234608.85           17            2
# USD/NOK          m5         D1  236185.76           39            2
# USD/MXN          m5         D1   235843.3           34            5
# AUD/CHF          m5         D1  236094.91           10            0
# EUR/NZD          m5         D1  236265.44           23            3
# USD/ZAR          m5         D1  237127.26           26            2
# ZAR/JPY          m5         D1  237127.26            0            0
# NZD/CHF          m5         D1  237200.65           21            2
# CAD/CHF          m5         D1  238191.22           19            0
# NZD/CAD          m5         D1  238605.91           15            0
# USD/ILS          m5         D1  239081.22            5            0
# USD/CNH          m5         D1  240735.77           29            0
#
#         Average lenght of trade           Cumul pnl
# EUR/USD                    48.6   2940.000000000009
# USD/JPY                   46.55             1318.94
# GBP/USD                   42.95   3193.500000000015
# USD/CHF                   49.06   2183.980000000001
# EUR/CHF                   56.25  1124.4899999999998
# AUD/USD                   23.67  2252.9999999999945
# USD/CAD                   34.51             2354.03
# NZD/USD                   30.57    1038.99999999999
# EUR/GBP                   82.63  1320.8899999999999
# EUR/JPY                   54.31  1845.3299999999997
# GBP/JPY                   56.07             2248.88
# CHF/JPY                   75.43  1302.9800000000002
# GBP/CHF                   67.36              200.81
# EUR/AUD                   93.53  1061.9399999999998
# EUR/CAD                   84.32  314.58000000000004
# AUD/CAD                   64.76  460.07000000000016
# AUD/JPY                      64              532.08
# CAD/JPY                   89.95   458.4200000000001
# NZD/JPY                   82.71  228.95999999999992
# GBP/CAD                   106.7  1791.9700000000005
# GBP/NZD                   44.27  1917.4799999999996
# GBP/AUD                  109.47  1564.7499999999998
# AUD/NZD                  126.95   582.5400000000001
# USD/SEK                   38.74  1655.6300000000003
# EUR/SEK                  202.47   612.8700000000001
# EUR/NOK                   82.68   99.73000000000008
# USD/NOK                   37.05  1576.9100000000003
# USD/MXN                   37.72  -342.4599999999999
# AUD/CHF                   108.5               408.2
# EUR/NZD                   73.38  228.36000000000013
# USD/ZAR                   38.04   647.4000000000002
# ZAR/JPY                      NA                   0
# NZD/CHF                   98.43  210.16999999999996
# CAD/CHF                   77.89   853.7899999999998
# NZD/CAD                    83.4              539.71
# USD/ILS                   160.6              350.29
# USD/CNH                   85.28  1703.5200000000002

# %%
_number = 10000
_period = 'm5'
_period2 = 'D1'
_total = 0
_cash_ini = 200000
_cash = _cash_ini
_rate = 1
_flag = 0
data = scrap_hist(x,_number,_period)
data2 = scrap_hist(x,_number,_period2)
price = data.copy()
price2 = data2.copy()
_position = 0
_equity = 0
_nbtransactions = 0
backtest_graph = pd.DataFrame()
EQUITY = [_cash]
CASH = [_cash]
OPEN_POZ = [0]
_winner = 0
_looser = 0
_index_entry = 0
TRADE_DURATION = []
_average_duration = 0
_size = 50000

_total = 0

_target = 0.0010
_sl = 0.0050
_spread_filter = 0.002
# Out:
#  Scraping des données OHLC pour le ticker  USD/CNH
#  Scraping des données OHLC pour le ticker  USD/CNH

# %%
cash, _total, _pnl, equity, EQUITY ,CASH

# %%
TICKERS = ['EUR/USD','USD/JPY','GBP/USD','USD/CHF','EUR/CHF','AUD/USD','USD/CAD','NZD/USD','EUR/GBP','EUR/JPY','GBP/JPY','CHF/JPY','GBP/CHF','EUR/AUD','EUR/CAD','AUD/CAD','AUD/JPY','CAD/JPY','NZD/JPY','GBP/CAD','GBP/NZD','GBP/AUD','AUD/NZD','USD/SEK','EUR/SEK','EUR/NOK','USD/NOK','USD/MXN','AUD/CHF','EUR/NZD','USD/ZAR','ZAR/JPY','NZD/CHF','CAD/CHF','NZD/CAD','USD/ILS','USD/CNH']

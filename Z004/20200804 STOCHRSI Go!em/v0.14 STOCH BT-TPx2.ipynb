# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
        
clearall()

# %%
############################
######## LIBRAIRIES ########
############################
print('Importing Librairies...')
from sklearn.linear_model import LinearRegression
import colorama as col
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import time
import os
import datetime as dt
import numpy as np
import fxcmpy
import socketio
import shelve
import talib
import statistics
import pyttsx3

engine = pyttsx3.init()

print('Librairies imported\n')
print('version fxcmpy :',fxcmpy.__version__)
# %matplotlib inline
plt.style.use('seaborn')
engine.say("librairie loaded")
engine.runAndWait()
print('Prêt')
# Out:
# Importing Librairies...
# Librairies imported
#
# version fxcmpy : 1.2.6
# Prêt

# %%
engine.say("Ignition du Lumberjack")
engine.runAndWait() 

##############################################
######## INITIALISATION DES VARIABLES ########
##############################################


# COMPTE TEST #
'''
TOKEN = '039add1dbe2b344ed08c518a98c7a1796f7a33c2'
server = 'demo'
user_id = 'D261219574'
compte = '01215057'
password = '3555'
'''

'''
# COMPTE DEV #
TOKEN = '79f83cbff13d296eb6d9b6c1ed6dccd768ef925a'
server = 'demo'
user_id = 'D261219577'
compte = '01215060'
password = '3877'
'''


# COMPTE POUBELLE #
TOKEN = 'a66bf5c0ec732487f4b348baf6364d3ee8784935'
server = 'demo'
user_id = 'D261219576'
compte = '01215059'
password = '8029'



# minutes: 'm1' , 'm5' , 'm15' , 'm30' 
# hours: 'H1' , 'H2', 'H3', 'H4', 'H6' 'H8'
# one day: 'D1'
# one week: 'W1'
# one month: 'M1'


_number = 10000
_period = 'm5'
_period2 = 'D1'
_total = 0

engine.say("בסדר")
engine.runAndWait()
print('Variables initialisées')
# Out:
# Variables initialisées

# %%
############################
######## FONCTIONS ########
###########################


def conX():
    con = fxcmpy.fxcmpy(access_token=TOKEN, log_level='error',server=server)
    if con.is_connected() == True:
        print(col.Fore.GREEN+'Connexion établie'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
    else:
        print(col.Fore.RED+'Connexion non établie'+col.Style.RESET_ALL)
    return(con)

def deconX():
    con = con.close()
    if con.is_connected() == True:
        print(col.Fore.GREEN+'Connexion non intérrompue'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
    else:
        print(col.Fore.RED+'Connexion intérrompue'+col.Style.RESET_ALL)
    return()


def scrap_hist(_ticker,number,laperiod):
    print(col.Fore.BLUE,'Scraping des données OHLC pour le ticker',col.Fore.YELLOW,_ticker,col.Style.RESET_ALL)
    data = con.get_candles(instrument=_ticker,number = 10000,period=laperiod)
    df = pd.DataFrame(index=data.index)
    df['Open'] = (data['bidopen']+data['askopen'])/2
    df['High'] = (data['bidhigh']+data['askhigh'])/2
    df['Low'] = (data['bidlow']+data['asklow'])/2
    df['Close'] = (data['bidclose']+data['askclose'])/2
    return(df)

engine.say("functions initiated")
engine.runAndWait()
print('Functions initiated')
# Out:
# Functions initiated

# %%
#########################
### CONNEXION A L'API ###
#########################

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor for FOR_EX\nLumberJack Jyss 5780(c)')
print(col.Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print(col.Fore.YELLOW,col.Back.BLUE,'--- Go!em STOCHASTIC-RSI #v0.14 ---',col.Style.RESET_ALL)

print('')
engine.say(" Initialisation du Gaulem Stok R S E")
engine.say("Connexion du Gaulem hà la Péh e")
engine.runAndWait()

try:
    con.is_connected() == True
    
    engine.say("already Connected")
    engine.runAndWait()
    print(col.Fore.GREEN+'Connexion rétablie'+col.Style.RESET_ALL)
    print('Compte utilisé : ',con.get_account_ids())
    print('')
    
except:
    try:
        con = conX()
        con.is_connected() == True
        print(col.Fore.GREEN+'Connexion établie'+col.Style.RESET_ALL)
        print('Compte utilisé : ',con.get_account_ids())
        engine.say("Connected")
        engine.runAndWait()
    except:
        print(col.Fore.RED+'Connexion non établie'+col.Style.RESET_ALL)
        engine.say("Not Connected, sal rass de mor, pitun cé la merd")
        engine.say("vérifi ton internet, é relance le gaulèm")
        engine.runAndWait()
        print('')
        #os._exit(0)
        con = deconX()
        time.sleep(1)
        con = conX()
# Out:
# Global Optimized LumberJack Environment Motor for FOR_EX
# LumberJack Jyss 5780(c)
#  °0Oo_D.A.G._26_oO0°
#   --- Go!em STOCHASTIC-RSI #v0.14 ---
#
# Connexion établie
# Compte utilisé :  [1215059]
# Connexion établie
# Compte utilisé :  [1215059]

# %%
# %%time
df_resultats = pd.DataFrame(index=['TimeFrame 1','TimeFrame2','Total Pnl','Nbre Winners','Nbre Loosers','Average lenght of trade','currency of the pnl','Pnl in USD'])

#TICKERS = con.get_instruments()
TICKERS = [ 'EUR/USD','USD/JPY','GBP/USD','USD/CHF','EUR/CHF','AUD/USD','USD/CAD','NZD/USD','EUR/GBP','EUR/JPY','GBP/JPY','CHF/JPY','GBP/CHF','EUR/AUD','EUR/CAD','AUD/CAD','AUD/JPY','CAD/JPY','NZD/JPY','GBP/CAD','GBP/NZD','GBP/AUD','AUD/NZD','USD/SEK','EUR/SEK','EUR/NOK','USD/NOK','USD/MXN','AUD/CHF','EUR/NZD','USD/ZAR','ZAR/JPY','NZD/CHF','CAD/CHF','NZD/CAD','USD/ILS','USD/CNH']

_total = 0

for x in TICKERS:
    data = scrap_hist(x,_number,_period)
    data2 = scrap_hist(x,_number,_period2)
    price = data.copy()
    price2 = data2.copy()
    position = 0
    equity = 1000000
    nbtransactions = 0
    backtest_graph = pd.DataFrame()
    col_equity = [1000000]
    col_open_pos = [0]
    col_close_pos = [0]
    col_is_win = [0]
    col_profit = [0]
    col_cours = [0]
    max_gross = (0,0)
    max_loss = (0,0)
    Stop_Loss_Short =[]
    Stop_Loss_Long = []
    winner = 0
    looser = 0
    entry_index = []
    trade_duration = []
    average_duration = 0
    size = 100000
   
    target = 0.0020
    sl = 0.0010
    
    MM21 = talib.EMA(price.Close, timeperiod=21)
    rsi = talib.RSI(price.Close, timeperiod=14)
    rsi_high = 65
    rsi_low = 35
    upperband, middleband, lowerband = talib.BBANDS(price.Close, timeperiod=5, nbdevup=2, nbdevdn=2, matype=0)
    fastk, fastd = talib.STOCHRSI(price.Close, timeperiod=14, fastk_period=5, fastd_period=3, fastd_matype=0)#STOCHASTICRSI
    slowk, slowd = talib.STOCH(price.High, price.Low, price.Close, fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)#STOCHASTIC
    
    MM82 = talib.EMA(price2.Close, timeperiod=8)
    MM212 = talib.EMA(price2.Close, timeperiod=21)
    MM342 = talib.EMA(price2.Close, timeperiod=34)
    rsi2 = talib.RSI(price2.Close, timeperiod=14)
    upperband2, middleband2, lowerband2 = talib.BBANDS(price2.Close, timeperiod=5, nbdevup=2, nbdevdn=2, matype=0)
    fastk2, fastd2 = talib.STOCHRSI(price2.Close, timeperiod=14, fastk_period=5, fastd_period=3, fastd_matype=0)#STOCHASTICRSI
    slowk2, slowd2 = talib.STOCH(price2.High, price2.Low, price2.Close, fastk_period=5, slowk_period=3, slowk_matype=0, slowd_period=3, slowd_matype=0)#STOCHASTIC

    #try:
    for i in range(25,len(price)):
        
        if position == 0:
                        
            if slowk[i-1] > 80 and slowk[i-1] > slowd[i-1] and slowk[i] < slowd[i] and price.High[i-1] > price.High[i-2] and price.High[i] < price.High[i-2] :
                
                j = len(price2[price2.index <= price.index[i]])-1
                    
                if  price2.Close[j] < MM82[j] and MM82[j]<MM212[j] and MM212[j] < MM342[j]  and\
                    '08:00:00' < str(price.index[j])[11:] < '23:30:00':#fastk2[j-1] > 99 and fastk2[j-1] > fastd2[j-1] and fastk2[j] < fastd2[j] and \price2.High[j-1] > price2.High[j-2] and price2.High[j] < price2.High[j-2] and

                    print("Filtre de petite time frame passé, pour i=",i,"et un index à i de",str(price.index[i]))
                    print("Filtre de grosse time frame passé, pour j=",j,"et un index à j de",str(price2.index[j]))

                    sense ='bearish' 
                    #label =  sense + labels[j] +'found'
                    #print(label)
                    print(i)
                    entry_index = i
                    position = -1
                    col_open_pos.append(1)
                    nbtransactions+=1
                    price_sell = price.Close.iloc[i]
                    Stop_Loss_Sell = price.High.iloc[i-1]
                    print('sold at', price_sell)  
                    print('SL at', Stop_Loss_Sell)
                        
                                
            elif slowk[i-1] < 20 and slowk[i-1] < slowd[i-1] and slowk[i] > slowd[i] and price.Low[i-1] < price.Low[i-2] and price.Low[i] > price.Low[i-2]:
                
                j = len(price2[price2.index <= price.index[i]])-1
                
                if price2.Close[j] > MM82[j] and MM82[j]>MM212[j] and MM212[j] > MM342[j] and '08:00:00' < str(price.index[j])[11:] < '23:30:00':#fastk2[j-1] < 1 and fastk2[j-1] < fastd2[j-1] and fastk2[j] > fastd2[j] and price2.Low[j-1] < price2.Low[j-2] and\price2.Low[j] > price2.Low[j-2] and 

                    print("Filtre de petite time frame passé, pour i=",i,"et un index à i de",str(price.index[i]))
                    print("Filtre de grosse time frame passé, pour j=",j,"et un index à j de",str(price2.index[j]))

                    position = 1
                    entry_index = i
                    col_open_pos.append(1)
                    nbtransactions+=1
                    price_buy = price.Close.iloc[i]
                    Stop_Loss_Buy = price.Low.iloc[i-1]
                    print('bought at', price_buy)
                    print('SL at', Stop_Loss_Buy)
            else :
                pass
        
        elif position == 1:
            
            if (float(price.Close.iloc[i]) - float(price_buy))/float(price_buy) >= target :#slowd[i]>80:
                    position = 0
                    equity = equity + (price.Close.iloc[i] - price_buy)*size
                    col_equity.append(equity)
                    winner+=1
                    trade_duration.append(i - entry_index)
                    print(i)
                    print('TP position closed at',price.Close.iloc[i],'pnl', (price.Close.iloc[i] - price_buy)*size)
                    print('nombre de candles en position :',i- entry_index)
                    print(equity)
            elif (float(price.Close.iloc[i]) - float(price_buy))/float(price_buy) <= -sl :#price.Close.iloc[i]<Stop_Loss_Buy
                    position = 0
                    #equity = equity + (Stop_Loss_Buy - price_buy)*size
                    equity = equity + (price.Close.iloc[i] - price_buy)*size
                    col_equity.append(equity)
                    looser+=1
                    trade_duration.append(i - entry_index)
                    print(i)
                    print('SL position closed at',price.Close.iloc[i],'pnl',(price.Close.iloc[i] - price_buy)*size)
                    print('nombre de candles en position :',i- entry_index)
                    print(equity)
        elif position == -1:
            
                if (float(price.Close.iloc[i]) - float(price_sell))/float(price_sell) <= -target :#slowd[i]<20:
                    position = 0
                    equity = equity - (price.Close.iloc[i] - price_sell)*size
                    col_equity.append(equity)
                    winner+=1
                    trade_duration.append(i - entry_index)
                    print(i)
                    print('TP position closed at',price.Close.iloc[i],'pnl',-(price.Close.iloc[i] - price_sell)*size)
                    print('nombre de candles en position :',i- entry_index)
                    print(equity)
                elif (float(price.Close.iloc[i]) - float(price_sell))/float(price_sell) >= sl :#price.Close.iloc[i]>Stop_Loss_Sell:
                    position = 0
                    #equity = equity - (Stop_Loss_Sell - price_sell)*size
                    equity = equity - (price.Close.iloc[i] - price_sell)*size
                    col_equity.append(equity)
                    looser+=1
                    trade_duration.append(i - entry_index)
                    print(i)
                    print('SL position closed at',price.Close.iloc[i],'pnl', -(price.Close.iloc[i] - price_sell)*size)
                    print('nombre de candles en position :',i- entry_index)
                    print(equity)
    try:
        average_duration=round(statistics.mean(trade_duration),2)
    except:
        print("(pas de duration)") 
        average_duration='NA'               
    print(col.Fore.MAGENTA,"\nLes gains faramineux s'élèvent à : $",col.Fore.GREEN,round(equity-1000000,2),'!. En ',nbtransactions,' transactions.',col.Style.RESET_ALL ) 
    print(col.Fore.GREEN,"\nNbre de winners :",winner,col.Style.RESET_ALL)
    print(col.Fore.RED,"\nNbre de loosers :",looser,col.Style.RESET_ALL)
    print("\nAverage trade duration ",average_duration)
    backtest_graph['equity'] = col_equity
    
    if x[4:] == 'USD':
        _pnl_USD = round(equity-1000000,2)
        _total += _pnl_USD
        _pnl_USD = str(_pnl_USD)
    elif x[:3] == 'USD':
        con.subscribe_market_data(x)
        _rate = con.get_last_price(x).Bid
        _pnl_USD = round((round(equity-1000000,2))/_rate,2)
        _total += _pnl_USD
        _pnl_USD = str(_pnl_USD)
        con.unsubscribe_market_data(x)
    elif x[:3] != 'USD' and x[4:] != 'USD':
        try:
            con.subscribe_market_data(x[4:]+'/USD')
            _rate = con.get_last_price(x[4:]+'/USD').Bid
            _pnl_USD = round((round(equity-1000000,2))*_rate,2)
            _total += _pnl_USD
            _pnl_USD = str(_pnl_USD)
            con.unsubscribe_market_data(x[4:]+'/USD')
        except:
            con.subscribe_market_data('USD/'+x[4:])
            _rate = con.get_last_price('USD/'+x[4:]).Bid
            _pnl_USD = round((round(equity-1000000,2))/_rate,2)
            _total += _pnl_USD
            _pnl_USD = str(_pnl_USD)
            con.unsubscribe_market_data('USD/'+x[4:])
    else:
        _pnl_USD = 'NA'

    
    df_resultats[x] = [_period,_period2,str(round(equity-1000000,2)),str(winner),str(looser),str(average_duration),x[4:],_pnl_USD]

try:
    os.mkdir('Period_'+_period+'_Period2_'+_period2+'_target_'+str(target)+'_sl_'+str(sl)+'_rsiHigh'+str(rsi_high)+'_rsiLow_'+str(rsi_low)+'/')
except:
    pass

df_resultats.T.to_csv('Period_'+_period+'_Period2_'+_period2+'_target_'+str(target)+'_sl_'+str(sl)+'_rsiHigh'+str(rsi_high)+'_rsiLow_'+str(rsi_low)+'/pnl_'+str(_total)+'.csv')
    
    
        
    #except :
     #   print(col.Fore.RED,'\n\nProbleme avec le ticker\n\n',col.Fore.YELLOW,x,col.Style.RESET_ALL)
      #  continue
# Out:
#  Scraping des données OHLC pour le ticker  EUR/USD
#  Scraping des données OHLC pour le ticker  EUR/USD
# Filtre de petite time frame passé, pour i= 825 et un index à i de 2020-07-10 00:15:00
# Filtre de grosse time frame passé, pour j= 5420 et un index à j de 2020-07-09 21:00:00
# bought at 1.1283400000000001
# SL at 1.12806
# 851
# SL position closed at 1.1271200000000001 pnl -121.99999999999989
# nombre de candles en position : 26
# 999878.0
# Filtre de petite time frame passé, pour i= 1272 et un index à i de 2020-07-13 11:45:00
# Filtre de grosse time frame passé, pour j= 5422 et un index à j de 2020-07-12 21:00:00
# bought at 1.13317
# SL at 1.132615
# 1294
# TP position closed at 1.1356199999999999 pnl 244.9999999999841
# nombre de candles en position : 22
# 1000123.0
# Filtre de petite time frame passé, pour i= 1355 et un index à i de 2020-07-13 18:40:00
# Filtre de grosse time frame passé, pour j= 5422 et un index à j de 2020-07-12 21:00:00
# bought at 1.1357149999999998
# SL at 1.135125
# 1365
# SL position closed at 1.1345399999999999 pnl -117.49999999999261
# nombre de candles en position : 10
# 1000005.5
# Filtre de petite time frame passé, pour i= 1438 et un index à i de 2020-07-14 01:35:00
# Filtre de grosse time frame passé, pour j= 5423 et un index à j de 2020-07-13 21:00:00
# bought at 1.13429
# SL at 1.133735
# 1509
# SL position closed at 1.13308 pnl -120.99999999999334
# nombre de candles en position : 71
# 999884.5
# Filtre de petite time frame passé, pour i= 1795 et un index à i de 2020-07-15 07:20:00
# Filtre de grosse time frame passé, pour j= 5424 et un index à j de 2020-07-14 21:00:00
# bought at 1.140375
# SL at 1.139865
# 1799
# TP position closed at 1.14334 pnl 296.50000000001063
# nombre de candles en position : 4
# 1000181.0
# Filtre de petite time frame passé, pour i= 1844 et un index à i de 2020-07-15 11:25:00
# Filtre de grosse time frame passé, pour j= 5424 et un index à j de 2020-07-14 21:00:00
# bought at 1.1440299999999999
# SL at 1.1433399999999998
# 1874
# SL position closed at 1.1427649999999998 pnl -126.50000000000716
# nombre de candles en position : 30
# 1000054.5
# Filtre de petite time frame passé, pour i= 2073 et un index à i de 2020-07-16 06:30:00
# Filtre de grosse time frame passé, pour j= 5425 et un index à j de 2020-07-15 21:00:00
# bought at 1.13952
# SL at 1.1392799999999998
# 2114
# SL position closed at 1.1381000000000001 pnl -141.99999999999767
# nombre de candles en position : 41
# 999912.5
# Filtre de petite time frame passé, pour i= 2178 et un index à i de 2020-07-16 15:15:00
# Filtre de grosse time frame passé, pour j= 5425 et un index à j de 2020-07-15 21:00:00
# bought at 1.1427800000000001
# SL at 1.14214
# 2194
# SL position closed at 1.14147 pnl -131.00000000001444
# nombre de candles en position : 16
# 999781.5
# Filtre de petite time frame passé, pour i= 2226 et un index à i de 2020-07-16 19:15:00
# Filtre de grosse time frame passé, pour j= 5425 et un index à j de 2020-07-15 21:00:00
# bought at 1.137785
# SL at 1.13705
# 2385
# TP position closed at 1.14039 pnl 260.4999999999968
# nombre de candles en position : 159
# 1000042.0
# Filtre de petite time frame passé, pour i= 2513 et un index à i de 2020-07-17 19:10:00
# Filtre de grosse time frame passé, pour j= 5426 et un index à j de 2020-07-16 21:00:00
# bought at 1.14394
# SL at 1.1434250000000001
# 2533
# SL position closed at 1.1426349999999998 pnl -130.50000000001117
# nombre de candles en position : 20
# 999911.5
# Filtre de petite time frame passé, pour i= 2567 et un index à i de 2020-07-19 22:00:00
# Filtre de grosse time frame passé, pour j= 5428 et un index à j de 2020-07-19 21:00:00
# bought at 1.142355
# SL at 1.1417950000000001
# 2657
# TP position closed at 1.14497 pnl 261.5000000000034
# nombre de candles en position : 90
# 1000173.0
# Filtre de petite time frame passé, pour i= 2701 et un index à i de 2020-07-20 09:10:00
# Filtre de grosse time frame passé, pour j= 5428 et un index à j de 2020-07-19 21:00:00
# bought at 1.14587
# SL at 1.145115
# 2734
# SL position closed at 1.1446049999999999 pnl -126.50000000000716
# nombre de candles en position : 33
# 1000046.5
# Filtre de petite time frame passé, pour i= 2737 et un index à i de 2020-07-20 12:10:00
# Filtre de grosse time frame passé, pour j= 5428 et un index à j de 2020-07-19 21:00:00
# bought at 1.14483
# SL at 1.1442350000000001
# 2744
# SL position closed at 1.143405 pnl -142.50000000000097
# nombre de candles en position : 7
# 999904.0
# Filtre de petite time frame passé, pour i= 2790 et un index à i de 2020-07-20 16:35:00
# Filtre de grosse time frame passé, pour j= 5428 et un index à j de 2020-07-19 21:00:00
# bought at 1.143945
# SL at 1.1433200000000001
# 2885
# TP position closed at 1.1463 pnl 235.5000000000107
# nombre de candles en position : 95
# 1000139.5
# Filtre de petite time frame passé, pour i= 2933 et un index à i de 2020-07-21 04:30:00
# Filtre de grosse time frame passé, pour j= 5429 et un index à j de 2020-07-20 21:00:00
# bought at 1.143345
# SL at 1.142805
# 2963
# TP position closed at 1.1458300000000001 pnl 248.50000000000705
# nombre de candles en position : 30
# 1000388.0
# Filtre de petite time frame passé, pour i= 3125 et un index à i de 2020-07-21 20:30:00
# Filtre de grosse time frame passé, pour j= 5429 et un index à j de 2020-07-20 21:00:00
# bought at 1.15224
# SL at 1.1520350000000001
# 3203
# TP position closed at 1.154625 pnl 238.50000000000816
# nombre de candles en position : 78
# 1000626.5
# Filtre de petite time frame passé, pour i= 3209 et un index à i de 2020-07-22 03:30:00
# Filtre de grosse time frame passé, pour j= 5430 et un index à j de 2020-07-21 21:00:00
# bought at 1.154245
# SL at 1.15397
# 3240
# SL position closed at 1.1529500000000001 pnl -129.4999999999824
# nombre de candles en position : 31
# 1000497.0
# Filtre de petite time frame passé, pour i= 3461 et un index à i de 2020-07-23 00:30:00
# Filtre de grosse time frame passé, pour j= 5431 et un index à j de 2020-07-22 21:00:00
# bought at 1.15675
# SL at 1.156425
# 3529
# TP position closed at 1.15907 pnl 232.00000000000998
# nombre de candles en position : 68
# 1000729.0
# Filtre de petite time frame passé, pour i= 3612 et un index à i de 2020-07-23 13:05:00
# Filtre de grosse time frame passé, pour j= 5431 et un index à j de 2020-07-22 21:00:00
# bought at 1.15549
# SL at 1.1540300000000001
# 3621
# TP position closed at 1.158015 pnl 252.50000000001106
# nombre de candles en position : 9
# 1000981.5
# Filtre de petite time frame passé, pour i= 3704 et un index à i de 2020-07-23 20:45:00
# Filtre de grosse time frame passé, pour j= 5431 et un index à j de 2020-07-22 21:00:00
# bought at 1.1593550000000001
# SL at 1.159005
# 3758
# TP position closed at 1.1618249999999999 pnl 246.99999999997502
# nombre de candles en position : 54
# 1001228.5
# Filtre de petite time frame passé, pour i= 3850 et un index à i de 2020-07-24 08:55:00
# Filtre de grosse time frame passé, pour j= 5432 et un index à j de 2020-07-23 21:00:00
# bought at 1.16003
# SL at 1.1592500000000001
# 3872
# SL position closed at 1.158285 pnl -174.49999999998855
# nombre de candles en position : 22
# 1001054.0
# Filtre de petite time frame passé, pour i= 4033 et un index à i de 2020-07-26 22:15:00
# Filtre de grosse time frame passé, pour j= 5434 et un index à j de 2020-07-26 21:00:00
# bought at 1.164475
# SL at 1.1643050000000001
# 4059
# TP position closed at 1.1670099999999999 pnl 253.4999999999954
# nombre de candles en position : 26
# 1001307.5
# Filtre de petite time frame passé, pour i= 4080 et un index à i de 2020-07-27 02:10:00
# Filtre de grosse time frame passé, pour j= 5434 et un index à j de 2020-07-26 21:00:00
# bought at 1.1693500000000001
# SL at 1.168955
# 4177
# TP position closed at 1.172015 pnl 266.49999999999176
# nombre de candles en position : 97
# 1001574.0
# Filtre de petite time frame passé, pour i= 4350 et un index à i de 2020-07-28 00:40:00
# Filtre de grosse time frame passé, pour j= 5435 et un index à j de 2020-07-27 21:00:00
# bought at 1.176455
# SL at 1.17603
# 4375
# SL position closed at 1.1752099999999999 pnl -124.50000000001626
# nombre de candles en position : 25
# 1001449.5
# Filtre de petite time frame passé, pour i= 4886 et un index à i de 2020-07-29 21:20:00
# Filtre de grosse time frame passé, pour j= 5437 et un index à j de 2020-07-29 21:00:00
# bought at 1.17897
# SL at 1.17841
# 4921
# SL position closed at 1.177635 pnl -133.5000000000086
# nombre de candles en position : 35
# 1001316.0
# Filtre de petite time frame passé, pour i= 4944 et un index à i de 2020-07-30 02:10:00
# Filtre de grosse time frame passé, pour j= 5437 et un index à j de 2020-07-29 21:00:00
# bought at 1.17699
# SL at 1.17658
# 4992
# SL position closed at 1.17567 pnl -131.99999999999878
# nombre de candles en position : 48
# 1001184.0
# Filtre de petite time frame passé, pour i= 5047 et un index à i de 2020-07-30 10:45:00
# Filtre de grosse time frame passé, pour j= 5437 et un index à j de 2020-07-29 21:00:00
# bought at 1.175075
# SL at 1.17424
# 5073
# TP position closed at 1.177715 pnl 263.99999999999756
# nombre de candles en position : 26
# 1001448.0
# Filtre de petite time frame passé, pour i= 5244 et un index à i de 2020-07-31 03:10:00
# Filtre de grosse time frame passé, pour j= 5438 et un index à j de 2020-07-30 21:00:00
# bought at 1.18894
# SL at 1.188415
# 5301
# SL position closed at 1.18756 pnl -138.0000000000159
# nombre de candles en position : 57
# 1001310.0
# Filtre de petite time frame passé, pour i= 5370 et un index à i de 2020-07-31 13:40:00
# Filtre de grosse time frame passé, pour j= 5438 et un index à j de 2020-07-30 21:00:00
# bought at 1.18193
# SL at 1.18018
# 5377
# TP position closed at 1.1850049999999999 pnl 307.49999999999386
# nombre de candles en position : 7
# 1001617.5
# Filtre de petite time frame passé, pour i= 5475 et un index à i de 2020-08-02 20:45:00
# Filtre de grosse time frame passé, pour j= 5439 et un index à j de 2020-08-01 21:00:00
# bought at 1.17741
# SL at 1.17685
# 5517
# SL position closed at 1.17545 pnl -195.9999999999962
# nombre de candles en position : 42
# 1001421.5
# Filtre de petite time frame passé, pour i= 5715 et un index à i de 2020-08-03 16:45:00
# Filtre de grosse time frame passé, pour j= 5440 et un index à j de 2020-08-02 21:00:00
# bought at 1.17441
# SL at 1.173825
# 5833
# TP position closed at 1.17709 pnl 268.0000000000016
# nombre de candles en position : 118
# 1001689.5
# Filtre de petite time frame passé, pour i= 5871 et un index à i de 2020-08-04 05:45:00
# Filtre de grosse time frame passé, pour j= 5441 et un index à j de 2020-08-03 21:00:00
# bought at 1.1767750000000001
# SL at 1.17641
# 5891
# TP position closed at 1.179435 pnl 265.99999999998846
# nombre de candles en position : 20
# 1001955.5
# Filtre de petite time frame passé, pour i= 5906 et un index à i de 2020-08-04 08:40:00
# Filtre de grosse time frame passé, pour j= 5441 et un index à j de 2020-08-03 21:00:00
# bought at 1.178195
# SL at 1.1772749999999998
# 5933
# SL position closed at 1.177015 pnl -118.00000000001809
# nombre de candles en position : 27
# 1001837.5
# Filtre de petite time frame passé, pour i= 6163 et un index à i de 2020-08-05 06:05:00
# Filtre de grosse time frame passé, pour j= 5442 et un index à j de 2020-08-04 21:00:00
# bought at 1.18062
# SL at 1.18021
# 6196
# TP position closed at 1.1839149999999998 pnl 329.4999999999826
# nombre de candles en position : 33
# 1002167.0
# Filtre de petite time frame passé, pour i= 6306 et un index à i de 2020-08-05 18:00:00
# Filtre de grosse time frame passé, pour j= 5442 et un index à j de 2020-08-04 21:00:00
# bought at 1.18668
# SL at 1.186245
# 6451
# TP position closed at 1.19108 pnl 439.99999999999596
# nombre de candles en position : 145
# 1002607.0
# Filtre de petite time frame passé, pour i= 6460 et un index à i de 2020-08-06 06:50:00
# Filtre de grosse time frame passé, pour j= 5443 et un index à j de 2020-08-05 21:00:00
# bought at 1.18778
# SL at 1.187225
# 6467
# SL position closed at 1.185745 pnl -203.5000000000009
# nombre de candles en position : 7
# 1002403.5
# Filtre de petite time frame passé, pour i= 6469 et un index à i de 2020-08-06 07:35:00
# Filtre de grosse time frame passé, pour j= 5443 et un index à j de 2020-08-05 21:00:00
# bought at 1.186255
# SL at 1.1855250000000002
# 6472
# SL position closed at 1.183885 pnl -236.99999999999832
# nombre de candles en position : 3
# 1002166.5
# Filtre de petite time frame passé, pour i= 7598 et un index à i de 2020-08-12 04:35:00
# Filtre de grosse time frame passé, pour j= 5448 et un index à j de 2020-08-11 21:00:00
# bought at 1.17172
# SL at 1.17111
# 7634
# TP position closed at 1.1745100000000002 pnl 279.00000000000705
# nombre de candles en position : 36
# 1002445.5
# Filtre de petite time frame passé, pour i= 7728 et un index à i de 2020-08-12 15:25:00
# Filtre de grosse time frame passé, pour j= 5448 et un index à j de 2020-08-11 21:00:00
# bought at 1.17945
# SL at 1.17902
# 7800
# SL position closed at 1.17827 pnl -118.00000000001809
# nombre de candles en position : 72
# 1002327.5
# Filtre de petite time frame passé, pour i= 7942 et un index à i de 2020-08-13 09:20:00
# Filtre de grosse time frame passé, pour j= 5449 et un index à j de 2020-08-12 21:00:00
# bought at 1.183435
# SL at 1.18281
# 7995
# TP position closed at 1.185985 pnl 255.00000000000523
# nombre de candles en position : 53
# 1002582.5
# Filtre de petite time frame passé, pour i= 8100 et un index à i de 2020-08-13 22:30:00
# Filtre de grosse time frame passé, pour j= 5450 et un index à j de 2020-08-13 21:00:00
# bought at 1.1815099999999998
# SL at 1.181135
# 8134
# SL position closed at 1.18028 pnl -122.99999999998423
# nombre de candles en position : 34
# 1002459.5
# Filtre de petite time frame passé, pour i= 8263 et un index à i de 2020-08-14 12:05:00
# Filtre de grosse time frame passé, pour j= 5450 et un index à j de 2020-08-13 21:00:00
# bought at 1.181355
# SL at 1.18065
# 8318
# TP position closed at 1.184455 pnl 310.0000000000103
# nombre de candles en position : 55
# 1002769.5
# Filtre de petite time frame passé, pour i= 8331 et un index à i de 2020-08-14 17:45:00
# Filtre de grosse time frame passé, pour j= 5450 et un index à j de 2020-08-13 21:00:00
# bought at 1.184025
# SL at 1.183715
# 8444
# TP position closed at 1.1865 pnl 247.5000000000005
# nombre de candles en position : 113
# 1003017.0
# Filtre de petite time frame passé, pour i= 8612 et un index à i de 2020-08-17 16:30:00
# Filtre de grosse time frame passé, pour j= 5452 et un index à j de 2020-08-16 21:00:00
# bought at 1.18574
# SL at 1.18568
# 8710
# TP position closed at 1.1882000000000001 pnl 246.00000000001288
# nombre de candles en position : 98
# 1003263.0
# Filtre de petite time frame passé, pour i= 8910 et un index à i de 2020-08-18 17:20:00
# Filtre de grosse time frame passé, pour j= 5453 et un index à j de 2020-08-17 21:00:00
# bought at 1.19344
# SL at 1.19299
# 9165
# SL position closed at 1.1915 pnl -194.0000000000053
# nombre de candles en position : 255
# 1003069.0
# Filtre de petite time frame passé, pour i= 9273 et un index à i de 2020-08-19 23:35:00
# Filtre de grosse time frame passé, pour j= 5455 et un index à j de 2020-08-19 21:00:00
# bought at 1.1848450000000001
# SL at 1.184525
# 9293
# SL position closed at 1.183645 pnl -120.00000000000898
# nombre de candles en position : 20
# 1002949.0
# Filtre de petite time frame passé, pour i= 9312 et un index à i de 2020-08-20 02:50:00
# Filtre de grosse time frame passé, pour j= 5455 et un index à j de 2020-08-19 21:00:00
# bought at 1.18418
# SL at 1.18354
# 9367
# TP position closed at 1.18661 pnl 242.99999999999324
# nombre de candles en position : 55
# 1003192.0
# Filtre de petite time frame passé, pour i= 9479 et un index à i de 2020-08-20 16:45:00
# Filtre de grosse time frame passé, pour j= 5455 et un index à j de 2020-08-19 21:00:00
# bought at 1.185335
# SL at 1.1852800000000001
# 9626
# TP position closed at 1.187745 pnl 241.00000000000233
# nombre de candles en position : 147
# 1003433.0
#
# Les gains faramineux s'élèvent à : $  3433.0 !. En  48  transactions.
#
# Nbre de winners : 25
#
# Nbre de loosers : 23
#
# Average trade duration  53.54
#  Scraping des données OHLC pour le ticker  USD/JPY
#  Scraping des données OHLC pour le ticker  USD/JPY
# Filtre de petite time frame passé, pour i= 738 et un index à i de 2020-07-09 05:40:00
# Filtre de grosse time frame passé, pour j= 5405 et un index à j de 2020-07-08 21:00:00
# 738
# sold at 107.2945
# SL at 107.31200000000001
# 969
# TP position closed at 107.074 pnl 22050.000000000124
# nombre de candles en position : 231
# 1022050.0000000001
# Filtre de petite time frame passé, pour i= 1010 et un index à i de 2020-07-10 04:20:00
# Filtre de grosse time frame passé, pour j= 5406 et un index à j de 2020-07-09 21:00:00
# 1010
# sold at 107.005
# SL at 107.0445
# 1061
# TP position closed at 106.789 pnl 21599.999999999396
# nombre de candles en position : 51
# 1043649.9999999995
# Filtre de petite time frame passé, pour i= 1076 et un index à i de 2020-07-10 09:50:00
# Filtre de grosse time frame passé, pour j= 5406 et un index à j de 2020-07-09 21:00:00
# 1076
# sold at 106.799
# SL at 106.8035
# 1160
# SL position closed at 106.936 pnl -13700.000000000045
# nombre de candles en position : 84
# 1029949.9999999995
# Filtre de petite time frame passé, pour i= 1843 et un index à i de 2020-07-15 01:00:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-14 21:00:00
# 1843
# sold at 107.28
# SL at 107.3055
# 1923
# TP position closed at 107.0215 pnl 25849.999999999796
# nombre de candles en position : 80
# 1055799.9999999993
# Filtre de petite time frame passé, pour i= 1968 et un index à i de 2020-07-15 11:25:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-14 21:00:00
# 1968
# sold at 106.9525
# SL at 106.99199999999999
# 1992
# TP position closed at 106.7175 pnl 23499.99999999994
# nombre de candles en position : 24
# 1079299.9999999993
# Filtre de petite time frame passé, pour i= 2027 et un index à i de 2020-07-15 16:20:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-14 21:00:00
# 2027
# sold at 106.948
# SL at 106.961
# 2222
# SL position closed at 107.05799999999999 pnl -10999.999999999944
# nombre de candles en position : 195
# 1068299.9999999993
# Filtre de petite time frame passé, pour i= 2377 et un index à i de 2020-07-16 21:40:00
# Filtre de grosse time frame passé, pour j= 5412 et un index à j de 2020-07-16 21:00:00
# 2377
# sold at 107.273
# SL at 107.34100000000001
# 2597
# TP position closed at 107.0565 pnl 21649.999999999636
# nombre de candles en position : 220
# 1089949.9999999988
# Filtre de petite time frame passé, pour i= 3088 et un index à i de 2020-07-21 09:05:00
# Filtre de grosse time frame passé, pour j= 5414 et un index à j de 2020-07-20 21:00:00
# 3088
# sold at 107.279
# SL at 107.3125
# 3144
# TP position closed at 107.0435 pnl 23550.000000000182
# nombre de candles en position : 56
# 1113499.999999999
# Filtre de petite time frame passé, pour i= 3548 et un index à i de 2020-07-22 23:25:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-07-22 21:00:00
# 3548
# sold at 107.1785
# SL at 107.1955
# 3737
# TP position closed at 106.896 pnl 28249.999999999887
# nombre de candles en position : 189
# 1141749.999999999
# Filtre de petite time frame passé, pour i= 4429 et un index à i de 2020-07-27 23:30:00
# Filtre de grosse time frame passé, pour j= 5420 et un index à j de 2020-07-27 21:00:00
# 4429
# sold at 105.354
# SL at 105.3865
# 4469
# SL position closed at 105.4625 pnl -10850.000000000648
# nombre de candles en position : 40
# 1130899.9999999984
# Filtre de petite time frame passé, pour i= 4483 et un index à i de 2020-07-28 04:00:00
# Filtre de grosse time frame passé, pour j= 5420 et un index à j de 2020-07-27 21:00:00
# 4483
# sold at 105.549
# SL at 105.6125
# 4487
# SL position closed at 105.6735 pnl -12449.999999999762
# nombre de candles en position : 4
# 1118449.9999999986
# Filtre de petite time frame passé, pour i= 4646 et un index à i de 2020-07-28 17:40:00
# Filtre de grosse time frame passé, pour j= 5420 et un index à j de 2020-07-27 21:00:00
# 4646
# sold at 105.05799999999999
# SL at 105.081
# 4652
# SL position closed at 105.18299999999999 pnl -12500.0
# nombre de candles en position : 6
# 1105949.9999999986
# Filtre de petite time frame passé, pour i= 4862 et un index à i de 2020-07-29 12:10:00
# Filtre de grosse time frame passé, pour j= 5421 et un index à j de 2020-07-28 21:00:00
# 4862
# sold at 105.1375
# SL at 105.1945
# 4933
# TP position closed at 104.8685 pnl 26900.000000000546
# nombre de candles en position : 71
# 1132849.999999999
# Filtre de petite time frame passé, pour i= 5053 et un index à i de 2020-07-30 04:05:00
# Filtre de grosse time frame passé, pour j= 5422 et un index à j de 2020-07-29 21:00:00
# 5053
# sold at 105.0295
# SL at 105.0455
# 5064
# SL position closed at 105.139 pnl -10949.999999999705
# nombre de candles en position : 11
# 1121899.9999999993
# Filtre de petite time frame passé, pour i= 5223 et un index à i de 2020-07-30 18:15:00
# Filtre de grosse time frame passé, pour j= 5422 et un index à j de 2020-07-29 21:00:00
# 5223
# sold at 104.883
# SL at 104.9165
# 5283
# TP position closed at 104.664 pnl 21899.99999999941
# nombre de candles en position : 60
# 1143799.9999999986
# Filtre de petite time frame passé, pour i= 5878 et un index à i de 2020-08-04 00:25:00
# Filtre de grosse time frame passé, pour j= 5426 et un index à j de 2020-08-03 21:00:00
# 5878
# sold at 106.0795
# SL at 106.144
# 5892
# SL position closed at 106.188 pnl -10850.000000000648
# nombre de candles en position : 14
# 1132949.999999998
# Filtre de petite time frame passé, pour i= 6337 et un index à i de 2020-08-05 15:00:00
# Filtre de grosse time frame passé, pour j= 5427 et un index à j de 2020-08-04 21:00:00
# 6337
# sold at 105.523
# SL at 105.598
# 6379
# SL position closed at 105.644 pnl -12100.000000000931
# nombre de candles en position : 42
# 1120849.999999997
# Filtre de petite time frame passé, pour i= 6395 et un index à i de 2020-08-05 19:50:00
# Filtre de grosse time frame passé, pour j= 5427 et un index à j de 2020-08-04 21:00:00
# 6395
# sold at 105.5985
# SL at 105.6265
# 6609
# TP position closed at 105.3735 pnl 22499.999999999432
# nombre de candles en position : 214
# 1143349.9999999965
# Filtre de petite time frame passé, pour i= 9474 et un index à i de 2020-08-20 16:30:00
# Filtre de grosse time frame passé, pour j= 5439 et un index à j de 2020-08-19 21:00:00
# 9474
# sold at 105.81700000000001
# SL at 105.839
# 9627
# TP position closed at 105.566 pnl 25100.000000000477
# nombre de candles en position : 153
# 1168449.999999997
# Filtre de petite time frame passé, pour i= 9879 et un index à i de 2020-08-24 01:50:00
# Filtre de grosse time frame passé, pour j= 5442 et un index à j de 2020-08-23 21:00:00
# 9879
# sold at 105.741
# SL at 105.78
# 9908
# SL position closed at 105.847 pnl -10599.999999999454
# nombre de candles en position : 29
# 1157849.9999999974
#
# Les gains faramineux s'élèvent à : $  157850.0 !. En  20  transactions.
#
# Nbre de winners : 11
#
# Nbre de loosers : 9
#
# Average trade duration  88.7
#  Scraping des données OHLC pour le ticker  GBP/USD
#  Scraping des données OHLC pour le ticker  GBP/USD
# Filtre de petite time frame passé, pour i= 260 et un index à i de 2020-07-07 15:50:00
# Filtre de grosse time frame passé, pour j= 5397 et un index à j de 2020-07-06 21:00:00
# bought at 1.2579799999999999
# SL at 1.257155
# 269
# SL position closed at 1.25651 pnl -146.99999999998602
# nombre de candles en position : 9
# 999853.0
# Filtre de petite time frame passé, pour i= 424 et un index à i de 2020-07-08 05:35:00
# Filtre de grosse time frame passé, pour j= 5398 et un index à j de 2020-07-07 21:00:00
# bought at 1.25583
# SL at 1.2551999999999999
# 430
# SL position closed at 1.254235 pnl -159.5000000000013
# nombre de candles en position : 6
# 999693.5
# Filtre de petite time frame passé, pour i= 634 et un index à i de 2020-07-08 23:05:00
# Filtre de grosse time frame passé, pour j= 5399 et un index à j de 2020-07-08 21:00:00
# bought at 1.2611599999999998
# SL at 1.2607650000000001
# 717
# TP position closed at 1.264065 pnl 290.50000000001575
# nombre de candles en position : 83
# 999984.0
# Filtre de petite time frame passé, pour i= 824 et un index à i de 2020-07-09 14:55:00
# Filtre de grosse time frame passé, pour j= 5399 et un index à j de 2020-07-08 21:00:00
# bought at 1.26176
# SL at 1.2606549999999999
# 828
# SL position closed at 1.2602099999999998 pnl -155.00000000001623
# nombre de candles en position : 4
# 999829.0
# Filtre de petite time frame passé, pour i= 944 et un index à i de 2020-07-10 00:55:00
# Filtre de grosse time frame passé, pour j= 5400 et un index à j de 2020-07-09 21:00:00
# bought at 1.25915
# SL at 1.25817
# 1008
# SL position closed at 1.257295 pnl -185.499999999994
# nombre de candles en position : 64
# 999643.5
# Filtre de petite time frame passé, pour i= 1154 et un index à i de 2020-07-10 19:15:00
# Filtre de grosse time frame passé, pour j= 5400 et un index à j de 2020-07-09 21:00:00
# bought at 1.2625549999999999
# SL at 1.262065
# 1175
# SL position closed at 1.26125 pnl -130.49999999998897
# nombre de candles en position : 21
# 999513.0
# Filtre de petite time frame passé, pour i= 1868 et un index à i de 2020-07-15 07:25:00
# Filtre de grosse time frame passé, pour j= 5404 et un index à j de 2020-07-14 21:00:00
# bought at 1.259255
# SL at 1.258655
# 1880
# TP position closed at 1.262035 pnl 278.00000000000045
# nombre de candles en position : 12
# 999791.0
# Filtre de petite time frame passé, pour i= 1887 et un index à i de 2020-07-15 09:00:00
# Filtre de grosse time frame passé, pour j= 5404 et un index à j de 2020-07-14 21:00:00
# bought at 1.260275
# SL at 1.26001
# 1908
# TP position closed at 1.26324 pnl 296.49999999998846
# nombre de candles en position : 21
# 1000087.5
# Filtre de petite time frame passé, pour i= 1981 et un index à i de 2020-07-15 16:50:00
# Filtre de grosse time frame passé, pour j= 5404 et un index à j de 2020-07-14 21:00:00
# bought at 1.258735
# SL at 1.25752
# 2077
# SL position closed at 1.2572649999999999 pnl -147.00000000000824
# nombre de candles en position : 96
# 999940.5
# Filtre de petite time frame passé, pour i= 2332 et un index à i de 2020-07-16 22:05:00
# Filtre de grosse time frame passé, pour j= 5406 et un index à j de 2020-07-16 21:00:00
# bought at 1.25542
# SL at 1.25521
# 2453
# SL position closed at 1.254155 pnl -126.50000000000716
# nombre de candles en position : 121
# 999814.0
# Filtre de petite time frame passé, pour i= 2509 et un index à i de 2020-07-17 12:50:00
# Filtre de grosse time frame passé, pour j= 5406 et un index à j de 2020-07-16 21:00:00
# bought at 1.251765
# SL at 1.251225
# 2545
# TP position closed at 1.25464 pnl 287.4999999999961
# nombre de candles en position : 36
# 1000101.5
# Filtre de petite time frame passé, pour i= 2601 et un index à i de 2020-07-17 20:30:00
# Filtre de grosse time frame passé, pour j= 5406 et un index à j de 2020-07-16 21:00:00
# bought at 1.2570700000000001
# SL at 1.2565650000000002
# 2613
# SL position closed at 1.2545600000000001 pnl -251.00000000000122
# nombre de candles en position : 12
# 999850.5
# Filtre de petite time frame passé, pour i= 2615 et un index à i de 2020-07-19 20:15:00
# Filtre de grosse time frame passé, pour j= 5407 et un index à j de 2020-07-18 21:00:00
# bought at 1.2565
# SL at 1.25453
# 2666
# SL position closed at 1.2545000000000002 pnl -199.99999999997797
# nombre de candles en position : 51
# 999650.5
# Filtre de petite time frame passé, pour i= 2811 et un index à i de 2020-07-20 12:55:00
# Filtre de grosse time frame passé, pour j= 5408 et un index à j de 2020-07-19 21:00:00
# bought at 1.262535
# SL at 1.2615349999999999
# 2845
# TP position closed at 1.26552 pnl 298.50000000000153
# nombre de candles en position : 34
# 999949.0
# Filtre de petite time frame passé, pour i= 2856 et un index à i de 2020-07-20 16:40:00
# Filtre de grosse time frame passé, pour j= 5408 et un index à j de 2020-07-19 21:00:00
# bought at 1.264805
# SL at 1.2647249999999999
# 2945
# TP position closed at 1.2674599999999998 pnl 265.4999999999852
# nombre de candles en position : 89
# 1000214.5
# Filtre de petite time frame passé, pour i= 3150 et un index à i de 2020-07-21 17:20:00
# Filtre de grosse time frame passé, pour j= 5409 et un index à j de 2020-07-20 21:00:00
# bought at 1.274065
# SL at 1.273655
# 3158
# TP position closed at 1.276645 pnl 258.0000000000027
# nombre de candles en position : 8
# 1000472.5
# Filtre de petite time frame passé, pour i= 3174 et un index à i de 2020-07-21 19:30:00
# Filtre de grosse time frame passé, pour j= 5409 et un index à j de 2020-07-20 21:00:00
# bought at 1.27471
# SL at 1.274425
# 3178
# SL position closed at 1.273315 pnl -139.50000000000352
# nombre de candles en position : 4
# 1000333.0
# Filtre de petite time frame passé, pour i= 3197 et un index à i de 2020-07-21 21:35:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-21 21:00:00
# bought at 1.27219
# SL at 1.27148
# 3308
# SL position closed at 1.27073 pnl -146.00000000000168
# nombre de candles en position : 111
# 1000187.0
# Filtre de petite time frame passé, pour i= 3313 et un index à i de 2020-07-22 07:40:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-21 21:00:00
# bought at 1.2676699999999999
# SL at 1.266135
# 3321
# SL position closed at 1.2662399999999998 pnl -143.00000000000423
# nombre de candles en position : 8
# 1000044.0
# Filtre de petite time frame passé, pour i= 3456 et un index à i de 2020-07-22 19:35:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-21 21:00:00
# bought at 1.273775
# SL at 1.27331
# 3474
# SL position closed at 1.272465 pnl -131.00000000001444
# nombre de candles en position : 18
# 999913.0
# Filtre de petite time frame passé, pour i= 3652 et un index à i de 2020-07-23 11:55:00
# Filtre de grosse time frame passé, pour j= 5411 et un index à j de 2020-07-22 21:00:00
# bought at 1.26904
# SL at 1.268405
# 3664
# SL position closed at 1.2675 pnl -153.9999999999875
# nombre de candles en position : 12
# 999759.0
# Filtre de petite time frame passé, pour i= 4005 et un index à i de 2020-07-24 17:20:00
# Filtre de grosse time frame passé, pour j= 5412 et un index à j de 2020-07-23 21:00:00
# bought at 1.27846
# SL at 1.2778100000000001
# 4111
# TP position closed at 1.2817699999999999 pnl 330.9999999999924
# nombre de candles en position : 106
# 1000090.0
# Filtre de petite time frame passé, pour i= 4436 et un index à i de 2020-07-28 04:00:00
# Filtre de grosse time frame passé, pour j= 5415 et un index à j de 2020-07-27 21:00:00
# bought at 1.285395
# SL at 1.28454
# 4499
# TP position closed at 1.288145 pnl 275.000000000003
# nombre de candles en position : 63
# 1000365.0
# Filtre de petite time frame passé, pour i= 4564 et un index à i de 2020-07-28 14:40:00
# Filtre de grosse time frame passé, pour j= 5415 et un index à j de 2020-07-27 21:00:00
# bought at 1.29189
# SL at 1.29112
# 4567
# TP position closed at 1.2946 pnl 270.99999999999903
# nombre de candles en position : 3
# 1000636.0
# Filtre de petite time frame passé, pour i= 4574 et un index à i de 2020-07-28 15:30:00
# Filtre de grosse time frame passé, pour j= 5415 et un index à j de 2020-07-27 21:00:00
# bought at 1.293825
# SL at 1.2928
# 4635
# SL position closed at 1.292455 pnl -137.00000000000932
# nombre de candles en position : 61
# 1000499.0
# Filtre de petite time frame passé, pour i= 4661 et un index à i de 2020-07-28 22:45:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-07-28 21:00:00
# bought at 1.29291
# SL at 1.292775
# 4694
# SL position closed at 1.2914750000000002 pnl -143.4999999999853
# nombre de candles en position : 33
# 1000355.5
# Filtre de petite time frame passé, pour i= 4805 et un index à i de 2020-07-29 10:45:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-07-28 21:00:00
# bought at 1.29695
# SL at 1.296255
# 4893
# TP position closed at 1.299965 pnl 301.499999999999
# nombre de candles en position : 88
# 1000657.0
# Filtre de petite time frame passé, pour i= 4916 et un index à i de 2020-07-29 20:00:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-07-28 21:00:00
# bought at 1.2987549999999999
# SL at 1.2978
# 4989
# SL position closed at 1.29737 pnl -138.49999999999696
# nombre de candles en position : 73
# 1000518.5
# Filtre de petite time frame passé, pour i= 5490 et un index à i de 2020-07-31 19:55:00
# Filtre de grosse time frame passé, pour j= 5418 et un index à j de 2020-07-30 21:00:00
# bought at 1.309085
# SL at 1.3087149999999999
# 5493
# SL position closed at 1.30714 pnl -194.50000000000855
# nombre de candles en position : 3
# 1000324.0
# Filtre de petite time frame passé, pour i= 5509 et un index à i de 2020-08-02 21:20:00
# Filtre de grosse time frame passé, pour j= 5420 et un index à j de 2020-08-02 21:00:00
# bought at 1.3079800000000001
# SL at 1.3079100000000001
# 5543
# SL position closed at 1.3061950000000002 pnl -178.49999999999255
# nombre de candles en position : 34
# 1000145.5
# Filtre de petite time frame passé, pour i= 5716 et un index à i de 2020-08-03 14:45:00
# Filtre de grosse time frame passé, pour j= 5420 et un index à j de 2020-08-02 21:00:00
# bought at 1.3018450000000001
# SL at 1.30095
# 5729
# TP position closed at 1.30512 pnl 327.4999999999917
# nombre de candles en position : 13
# 1000473.0
# Filtre de petite time frame passé, pour i= 5983 et un index à i de 2020-08-04 13:00:00
# Filtre de grosse time frame passé, pour j= 5421 et un index à j de 2020-08-03 21:00:00
# bought at 1.2996050000000001
# SL at 1.2981349999999998
# 5996
# TP position closed at 1.30302 pnl 341.4999999999946
# nombre de candles en position : 13
# 1000814.5
# Filtre de petite time frame passé, pour i= 6188 et un index à i de 2020-08-05 06:05:00
# Filtre de grosse time frame passé, pour j= 5422 et un index à j de 2020-08-04 21:00:00
# bought at 1.308595
# SL at 1.307655
# 6190
# SL position closed at 1.30694 pnl -165.4999999999962
# nombre de candles en position : 2
# 1000649.0
# Filtre de petite time frame passé, pour i= 6227 et un index à i de 2020-08-05 09:30:00
# Filtre de grosse time frame passé, pour j= 5422 et un index à j de 2020-08-04 21:00:00
# bought at 1.30972
# SL at 1.30864
# 6232
# TP position closed at 1.313 pnl 327.99999999999494
# nombre de candles en position : 5
# 1000977.0
# Filtre de petite time frame passé, pour i= 7012 et un index à i de 2020-08-10 03:15:00
# Filtre de grosse time frame passé, pour j= 5426 et un index à j de 2020-08-09 21:00:00
# bought at 1.30732
# SL at 1.306605
# 7051
# SL position closed at 1.305715 pnl -160.50000000000784
# nombre de candles en position : 39
# 1000816.5
# Filtre de petite time frame passé, pour i= 7869 et un index à i de 2020-08-13 02:55:00
# Filtre de grosse time frame passé, pour j= 5429 et un index à j de 2020-08-12 21:00:00
# bought at 1.3062900000000002
# SL at 1.305675
# 7938
# TP position closed at 1.308985 pnl 269.4999999999892
# nombre de candles en position : 69
# 1001086.0
# Filtre de petite time frame passé, pour i= 8012 et un index à i de 2020-08-13 14:50:00
# Filtre de grosse time frame passé, pour j= 5429 et un index à j de 2020-08-12 21:00:00
# bought at 1.310165
# SL at 1.30883
# 8014
# SL position closed at 1.30824 pnl -192.49999999999545
# nombre de candles en position : 2
# 1000893.5
# Filtre de petite time frame passé, pour i= 8140 et un index à i de 2020-08-14 01:30:00
# Filtre de grosse time frame passé, pour j= 5430 et un index à j de 2020-08-13 21:00:00
# bought at 1.30576
# SL at 1.304995
# 8242
# TP position closed at 1.30862 pnl 285.99999999998624
# nombre de candles en position : 102
# 1001179.5
# Filtre de petite time frame passé, pour i= 8460 et un index à i de 2020-08-17 03:45:00
# Filtre de grosse time frame passé, pour j= 5432 et un index à j de 2020-08-16 21:00:00
# bought at 1.309875
# SL at 1.30966
# 8512
# SL position closed at 1.3080850000000002 pnl -178.99999999997362
# nombre de candles en position : 52
# 1001000.5
# Filtre de petite time frame passé, pour i= 8515 et un index à i de 2020-08-17 08:20:00
# Filtre de grosse time frame passé, pour j= 5432 et un index à j de 2020-08-16 21:00:00
# bought at 1.308985
# SL at 1.307865
# 8540
# TP position closed at 1.311665 pnl 268.0000000000016
# nombre de candles en position : 25
# 1001268.5
# Filtre de petite time frame passé, pour i= 8562 et un index à i de 2020-08-17 12:15:00
# Filtre de grosse time frame passé, pour j= 5432 et un index à j de 2020-08-16 21:00:00
# bought at 1.308255
# SL at 1.30763
# 8577
# TP position closed at 1.310895 pnl 263.99999999999756
# nombre de candles en position : 15
# 1001532.5
# Filtre de petite time frame passé, pour i= 8724 et un index à i de 2020-08-18 01:45:00
# Filtre de grosse time frame passé, pour j= 5433 et un index à j de 2020-08-17 21:00:00
# bought at 1.3128199999999999
# SL at 1.31226
# 8781
# TP position closed at 1.316395 pnl 357.5000000000106
# nombre de candles en position : 57
# 1001890.0
# Filtre de petite time frame passé, pour i= 8878 et un index à i de 2020-08-18 14:35:00
# Filtre de grosse time frame passé, pour j= 5433 et un index à j de 2020-08-17 21:00:00
# bought at 1.32243
# SL at 1.3205200000000001
# 8989
# TP position closed at 1.32521 pnl 278.00000000000045
# nombre de candles en position : 111
# 1002168.0
# Filtre de petite time frame passé, pour i= 9308 et un index à i de 2020-08-20 02:50:00
# Filtre de grosse time frame passé, pour j= 5435 et un index à j de 2020-08-19 21:00:00
# bought at 1.309265
# SL at 1.3087499999999999
# 9342
# SL position closed at 1.307585 pnl -167.9999999999904
# nombre de candles en position : 34
# 1002000.0
# Filtre de petite time frame passé, pour i= 9509 et un index à i de 2020-08-20 19:35:00
# Filtre de grosse time frame passé, pour j= 5435 et un index à j de 2020-08-19 21:00:00
# bought at 1.321215
# SL at 1.32078
# 9619
# TP position closed at 1.3240150000000002 pnl 280.0000000000136
# nombre de candles en position : 110
# 1002280.0
# Filtre de petite time frame passé, pour i= 9833 et un index à i de 2020-08-23 21:55:00
# Filtre de grosse time frame passé, pour j= 5438 et un index à j de 2020-08-23 21:00:00
# bought at 1.308915
# SL at 1.3088
# 9970
# TP position closed at 1.311745 pnl 282.9999999999888
# nombre de candles en position : 137
# 1002563.0
#
# Les gains faramineux s'élèvent à : $  2563.0 !. En  46  transactions.
#
# Nbre de winners : 22
#
# Nbre de loosers : 24
#
# Average trade duration  45
#  Scraping des données OHLC pour le ticker  USD/CHF
#  Scraping des données OHLC pour le ticker  USD/CHF
# Filtre de petite time frame passé, pour i= 27 et un index à i de 2020-07-06 22:05:00
# Filtre de grosse time frame passé, pour j= 5392 et un index à j de 2020-07-06 21:00:00
# 27
# sold at 0.9420949999999999
# SL at 0.94224
# 119
# SL position closed at 0.943105 pnl -101.00000000000664
# nombre de candles en position : 92
# 999899.0
# Filtre de petite time frame passé, pour i= 142 et un index à i de 2020-07-07 07:40:00
# Filtre de grosse time frame passé, pour j= 5392 et un index à j de 2020-07-06 21:00:00
# 142
# sold at 0.942725
# SL at 0.942975
# 151
# SL position closed at 0.9437800000000001 pnl -105.50000000000281
# nombre de candles en position : 9
# 999793.5
# Filtre de petite time frame passé, pour i= 283 et un index à i de 2020-07-07 19:25:00
# Filtre de grosse time frame passé, pour j= 5392 et un index à j de 2020-07-06 21:00:00
# 283
# sold at 0.942215
# SL at 0.942245
# 499
# TP position closed at 0.94011 pnl 210.50000000000236
# nombre de candles en position : 216
# 1000004.0
# Filtre de petite time frame passé, pour i= 758 et un index à i de 2020-07-09 11:00:00
# Filtre de grosse time frame passé, pour j= 5394 et un index à j de 2020-07-08 21:00:00
# 758
# sold at 0.93878
# SL at 0.9393400000000001
# 804
# SL position closed at 0.9397249999999999 pnl -94.49999999999736
# nombre de candles en position : 46
# 999909.5
# Filtre de petite time frame passé, pour i= 925 et un index à i de 2020-07-10 00:55:00
# Filtre de grosse time frame passé, pour j= 5395 et un index à j de 2020-07-09 21:00:00
# 925
# sold at 0.940955
# SL at 0.941335
# 956
# SL position closed at 0.94194 pnl -98.50000000000136
# nombre de candles en position : 31
# 999811.0
# Filtre de petite time frame passé, pour i= 1193 et un index à i de 2020-07-12 23:25:00
# Filtre de grosse time frame passé, pour j= 5396 et un index à j de 2020-07-12 21:00:00
# 1193
# sold at 0.94032
# SL at 0.9405349999999999
# 1299
# SL position closed at 0.94127 pnl -95.00000000000064
# nombre de candles en position : 106
# 999716.0
# Filtre de petite time frame passé, pour i= 1341 et un index à i de 2020-07-13 11:45:00
# Filtre de grosse time frame passé, pour j= 5396 et un index à j de 2020-07-12 21:00:00
# 1341
# sold at 0.94221
# SL at 0.942375
# 1346
# SL position closed at 0.9431700000000001 pnl -96.00000000000719
# nombre de candles en position : 5
# 999620.0
# Filtre de petite time frame passé, pour i= 1413 et un index à i de 2020-07-13 17:45:00
# Filtre de grosse time frame passé, pour j= 5396 et un index à j de 2020-07-12 21:00:00
# 1413
# sold at 0.940605
# SL at 0.9407300000000001
# 1422
# SL position closed at 0.941745 pnl -114.00000000000298
# nombre de candles en position : 9
# 999506.0
# Filtre de petite time frame passé, pour i= 1494 et un index à i de 2020-07-14 00:30:00
# Filtre de grosse time frame passé, pour j= 5397 et un index à j de 2020-07-13 21:00:00
# 1494
# sold at 0.942365
# SL at 0.94243
# 1582
# TP position closed at 0.9402349999999999 pnl 213.00000000000762
# nombre de candles en position : 88
# 999719.0
# Filtre de petite time frame passé, pour i= 1589 et un index à i de 2020-07-14 08:25:00
# Filtre de grosse time frame passé, pour j= 5397 et un index à j de 2020-07-13 21:00:00
# 1589
# sold at 0.9404250000000001
# SL at 0.94087
# 1660
# TP position closed at 0.9384300000000001 pnl 199.4999999999969
# nombre de candles en position : 71
# 999918.5
# Filtre de petite time frame passé, pour i= 1694 et un index à i de 2020-07-14 17:10:00
# Filtre de grosse time frame passé, pour j= 5397 et un index à j de 2020-07-13 21:00:00
# 1694
# sold at 0.938515
# SL at 0.9387449999999999
# 1716
# SL position closed at 0.93947 pnl -95.50000000000392
# nombre de candles en position : 22
# 999823.0
# Filtre de petite time frame passé, pour i= 2508 et un index à i de 2020-07-17 13:00:00
# Filtre de grosse time frame passé, pour j= 5400 et un index à j de 2020-07-16 21:00:00
# 2508
# sold at 0.9407099999999999
# SL at 0.941175
# 2544
# TP position closed at 0.93878 pnl 192.99999999999872
# nombre de candles en position : 36
# 1000016.0
# Filtre de petite time frame passé, pour i= 2598 et un index à i de 2020-07-17 20:30:00
# Filtre de grosse time frame passé, pour j= 5400 et un index à j de 2020-07-16 21:00:00
# 2598
# sold at 0.9383600000000001
# SL at 0.93848
# 2605
# SL position closed at 0.9401550000000001 pnl -179.4999999999991
# nombre de candles en position : 7
# 999836.5
# Filtre de petite time frame passé, pour i= 2962 et un index à i de 2020-07-21 02:55:00
# Filtre de grosse time frame passé, pour j= 5402 et un index à j de 2020-07-20 21:00:00
# 2962
# sold at 0.938265
# SL at 0.93834
# 2979
# SL position closed at 0.93921 pnl -94.49999999999736
# nombre de candles en position : 17
# 999742.0
# Filtre de petite time frame passé, pour i= 3271 et un index à i de 2020-07-22 04:40:00
# Filtre de grosse time frame passé, pour j= 5403 et un index à j de 2020-07-21 21:00:00
# 3271
# sold at 0.9324250000000001
# SL at 0.93263
# 3306
# SL position closed at 0.933405 pnl -97.9999999999981
# nombre de candles en position : 35
# 999644.0
# Filtre de petite time frame passé, pour i= 3373 et un index à i de 2020-07-22 13:10:00
# Filtre de grosse time frame passé, pour j= 5403 et un index à j de 2020-07-21 21:00:00
# 3373
# sold at 0.93072
# SL at 0.9312450000000001
# 3407
# TP position closed at 0.92883 pnl 188.9999999999947
# nombre de candles en position : 34
# 999833.0
# Filtre de petite time frame passé, pour i= 4020 et un index à i de 2020-07-24 19:05:00
# Filtre de grosse time frame passé, pour j= 5405 et un index à j de 2020-07-23 21:00:00
# 4020
# sold at 0.9220550000000001
# SL at 0.92243
# 4097
# TP position closed at 0.918955 pnl 310.0000000000103
# nombre de candles en position : 77
# 1000143.0
# Filtre de petite time frame passé, pour i= 4183 et un index à i de 2020-07-27 07:45:00
# Filtre de grosse time frame passé, pour j= 5407 et un index à j de 2020-07-26 21:00:00
# 4183
# sold at 0.9184000000000001
# SL at 0.91892
# 4194
# SL position closed at 0.919845 pnl -144.49999999999187
# nombre de candles en position : 11
# 999998.5
# Filtre de petite time frame passé, pour i= 4339 et un index à i de 2020-07-27 20:45:00
# Filtre de grosse time frame passé, pour j= 5407 et un index à j de 2020-07-26 21:00:00
# 4339
# sold at 0.9200699999999999
# SL at 0.92039
# 4414
# SL position closed at 0.92161 pnl -154.0000000000097
# nombre de candles en position : 75
# 999844.5
# Filtre de petite time frame passé, pour i= 4445 et un index à i de 2020-07-28 05:35:00
# Filtre de grosse time frame passé, pour j= 5408 et un index à j de 2020-07-27 21:00:00
# 4445
# sold at 0.92213
# SL at 0.9224749999999999
# 4459
# TP position closed at 0.92027 pnl 185.99999999999727
# nombre de candles en position : 14
# 1000030.5
# Filtre de petite time frame passé, pour i= 4563 et un index à i de 2020-07-28 15:25:00
# Filtre de grosse time frame passé, pour j= 5408 et un index à j de 2020-07-27 21:00:00
# 4563
# sold at 0.91811
# SL at 0.91841
# 4752
# TP position closed at 0.9162250000000001 pnl 188.49999999999145
# nombre de candles en position : 189
# 1000219.0
# Filtre de petite time frame passé, pour i= 4777 et un index à i de 2020-07-29 09:15:00
# Filtre de grosse time frame passé, pour j= 5409 et un index à j de 2020-07-28 21:00:00
# 4777
# sold at 0.915465
# SL at 0.9158599999999999
# 4794
# SL position closed at 0.91691 pnl -144.50000000000296
# nombre de candles en position : 17
# 1000074.5
# Filtre de petite time frame passé, pour i= 4802 et un index à i de 2020-07-29 11:20:00
# Filtre de grosse time frame passé, pour j= 5409 et un index à j de 2020-07-28 21:00:00
# 4802
# sold at 0.91795
# SL at 0.9187350000000001
# 4833
# TP position closed at 0.9160600000000001 pnl 188.9999999999947
# nombre de candles en position : 31
# 1000263.5
# Filtre de petite time frame passé, pour i= 4952 et un index à i de 2020-07-29 23:50:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-29 21:00:00
# 4952
# sold at 0.9123749999999999
# SL at 0.9124950000000001
# 4968
# SL position closed at 0.913295 pnl -92.00000000000318
# nombre de candles en position : 16
# 1000171.5
# Filtre de petite time frame passé, pour i= 4972 et un index à i de 2020-07-30 01:30:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-29 21:00:00
# 4972
# sold at 0.91309
# SL at 0.913385
# 5031
# SL position closed at 0.91408 pnl -99.00000000000463
# nombre de candles en position : 59
# 1000072.5
# Filtre de petite time frame passé, pour i= 5140 et un index à i de 2020-07-30 15:30:00
# Filtre de grosse time frame passé, pour j= 5410 et un index à j de 2020-07-29 21:00:00
# 5140
# sold at 0.9126449999999999
# SL at 0.913135
# 5159
# TP position closed at 0.910685 pnl 195.9999999999962
# nombre de candles en position : 19
# 1000268.5
# Filtre de petite time frame passé, pour i= 5395 et un index à i de 2020-07-31 12:45:00
# Filtre de grosse time frame passé, pour j= 5411 et un index à j de 2020-07-30 21:00:00
# 5395
# sold at 0.909335
# SL at 0.910245
# 5401
# SL position closed at 0.910405 pnl -107.00000000000153
# nombre de candles en position : 6
# 1000161.5
# Filtre de petite time frame passé, pour i= 5482 et un index à i de 2020-07-31 20:00:00
# Filtre de grosse time frame passé, pour j= 5411 et un index à j de 2020-07-30 21:00:00
# 5482
# sold at 0.9142
# SL at 0.914845
# 5537
# SL position closed at 0.9154249999999999 pnl -122.49999999999206
# nombre de candles en position : 55
# 1000039.0
# Filtre de petite time frame passé, pour i= 5807 et un index à i de 2020-08-03 23:20:00
# Filtre de grosse time frame passé, pour j= 5414 et un index à j de 2020-08-03 21:00:00
# 5807
# sold at 0.9178900000000001
# SL at 0.918025
# 5905
# TP position closed at 0.915795 pnl 209.5000000000069
# nombre de candles en position : 98
# 1000248.5
# Filtre de petite time frame passé, pour i= 5978 et un index à i de 2020-08-04 13:35:00
# Filtre de grosse time frame passé, pour j= 5414 et un index à j de 2020-08-03 21:00:00
# 5978
# sold at 0.91688
# SL at 0.917015
# 5998
# TP position closed at 0.914855 pnl 202.50000000000546
# nombre de candles en position : 20
# 1000451.0
# Filtre de petite time frame passé, pour i= 6111 et un index à i de 2020-08-05 00:40:00
# Filtre de grosse time frame passé, pour j= 5415 et un index à j de 2020-08-04 21:00:00
# 6111
# sold at 0.913215
# SL at 0.913505
# 6186
# TP position closed at 0.9113249999999999 pnl 189.00000000000583
# nombre de candles en position : 75
# 1000640.0
# Filtre de petite time frame passé, pour i= 6527 et un index à i de 2020-08-06 11:20:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-08-05 21:00:00
# 6527
# sold at 0.90869
# SL at 0.90922
# 6546
# SL position closed at 0.909975 pnl -128.49999999999807
# nombre de candles en position : 19
# 1000511.5
# Filtre de petite time frame passé, pour i= 6548 et un index à i de 2020-08-06 13:05:00
# Filtre de grosse time frame passé, pour j= 5416 et un index à j de 2020-08-05 21:00:00
# 6548
# sold at 0.909675
# SL at 0.910075
# 6560
# SL position closed at 0.91118 pnl -150.49999999999787
# nombre de candles en position : 12
# 1000361.0
# Filtre de petite time frame passé, pour i= 6629 et un index à i de 2020-08-06 19:50:00
# ...
# 4427
# SL position closed at 0.892215 pnl -92.00000000000318
# nombre de candles en position : 8
# 999410.0
# Filtre de petite time frame passé, pour i= 4552 et un index à i de 2020-07-28 13:25:00
# Filtre de grosse time frame passé, pour j= 3442 et un index à j de 2020-07-27 21:00:00
# bought at 0.890565
# SL at 0.8898699999999999
# 4585
# SL position closed at 0.889625 pnl -94.00000000000519
# nombre de candles en position : 33
# 999316.0
# Filtre de petite time frame passé, pour i= 8112 et un index à i de 2020-08-13 22:45:00
# Filtre de grosse time frame passé, pour j= 3457 et un index à j de 2020-08-13 21:00:00
# 8112
# sold at 0.865675
# SL at 0.866005
# 8170
# TP position closed at 0.863925 pnl 174.99999999999181
# nombre de candles en position : 58
# 999491.0
# Filtre de petite time frame passé, pour i= 8215 et un index à i de 2020-08-14 07:20:00
# Filtre de grosse time frame passé, pour j= 3457 et un index à j de 2020-08-13 21:00:00
# 8215
# sold at 0.86509
# SL at 0.86546
# 8274
# SL position closed at 0.8663799999999999 pnl -128.99999999999022
# nombre de candles en position : 59
# 999362.0
# Filtre de petite time frame passé, pour i= 8524 et un index à i de 2020-08-17 09:10:00
# Filtre de grosse time frame passé, pour j= 3459 et un index à j de 2020-08-16 21:00:00
# 8524
# sold at 0.86441
# SL at 0.864825
# 8652
# SL position closed at 0.86581 pnl -139.99999999999568
# nombre de candles en position : 128
# 999222.0
# Filtre de petite time frame passé, pour i= 9505 et un index à i de 2020-08-20 19:00:00
# Filtre de grosse time frame passé, pour j= 3462 et un index à j de 2020-08-19 21:00:00
# 9505
# sold at 0.860105
# SL at 0.8606
# 9514
# SL position closed at 0.860985 pnl -87.99999999999919
# nombre de candles en position : 9
# 999134.0
# Filtre de petite time frame passé, pour i= 9538 et un index à i de 2020-08-20 21:45:00
# Filtre de grosse time frame passé, pour j= 3463 et un index à j de 2020-08-20 21:00:00
# 9538
# sold at 0.86136
# SL at 0.861625
# 9673
# SL position closed at 0.8626450000000001 pnl -128.50000000000915
# nombre de candles en position : 135
# 999005.5
# Filtre de petite time frame passé, pour i= 9770 et un index à i de 2020-08-21 17:05:00
# Filtre de grosse time frame passé, pour j= 3463 et un index à j de 2020-08-20 21:00:00
# 9770
# sold at 0.8618
# SL at 0.862215
# 9796
# SL position closed at 0.862725 pnl -92.49999999999537
# nombre de candles en position : 26
# 998913.0
# Filtre de petite time frame passé, pour i= 9913 et un index à i de 2020-08-24 04:40:00
# Filtre de grosse time frame passé, pour j= 3465 et un index à j de 2020-08-23 21:00:00
# 9913
# sold at 0.8604499999999999
# SL at 0.8605499999999999
# 9981
# SL position closed at 0.861345 pnl -89.50000000000901
# nombre de candles en position : 68
# 998823.5
# Filtre de petite time frame passé, pour i= 9987 et un index à i de 2020-08-24 10:50:00
# Filtre de grosse time frame passé, pour j= 3465 et un index à j de 2020-08-23 21:00:00
# 9987
# sold at 0.8626199999999999
# SL at 0.86294
#
# Les gains faramineux s'élèvent à : $  -1176.5 !. En  23  transactions.
#
# Nbre de winners : 4
#
# Nbre de loosers : 18
#
# Average trade duration  73.95
# |ERROR|2020-08-24 13:54:01,135|Server reports an error: {'executed': False, 'error': 'Cannot subscribe to symbol: CAD/USD'}.
# |ERROR|2020-08-24 13:54:01,136|URL: https://api-demo.fxcm.com:443/subscribe
# |ERROR|2020-08-24 13:54:01,136|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer Jl8erkMWS7CVnMOHAAhla66bf5c0ec732487f4b348baf6364d3ee8784935', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '15'}
# |ERROR|2020-08-24 13:54:01,137|Params: {'pairs': 'CAD/USD'}
# |ERROR|2020-08-24 13:54:01,139|Bearer token: Bearer Jl8erkMWS7CVnMOHAAhla66bf5c0ec732487f4b348baf6364d3ee8784935
# |ERROR|2020-08-24 13:54:01,139|Connection status: established
# |ERROR|2020-08-24 13:54:01,140|Socket session id: Jl8erkMWS7CVnMOHAAhl
# |ERROR|2020-08-24 13:54:01,140|Can not parse server answer to json object: {"response":{"executed":false,"error":"Cannot subscribe to symbol: CAD/USD"},"pairs":[]}.
#  Scraping des données OHLC pour le ticker  USD/ILS
#  Scraping des données OHLC pour le ticker  USD/ILS
# (pas de duration)
#
# Les gains faramineux s'élèvent à : $  0 !. En  0  transactions.
#
# Nbre de winners : 0
#
# Nbre de loosers : 0
#
# Average trade duration  NA
#  Scraping des données OHLC pour le ticker  USD/CNH
#  Scraping des données OHLC pour le ticker  USD/CNH
# Filtre de petite time frame passé, pour i= 78 et un index à i de 2020-07-07 01:35:00
# Filtre de grosse time frame passé, pour j= 2498 et un index à j de 2020-07-06 21:00:00
# 78
# sold at 7.004435
# SL at 7.0084
# 91
# SL position closed at 7.0144649999999995 pnl -1002.999999999954
# nombre de candles en position : 13
# 998997.0
# Filtre de petite time frame passé, pour i= 95 et un index à i de 2020-07-07 03:00:00
# Filtre de grosse time frame passé, pour j= 2498 et un index à j de 2020-07-06 21:00:00
# 95
# sold at 7.01466
# SL at 7.017575
# 147
# SL position closed at 7.025320000000001 pnl -1066.0000000000557
# nombre de candles en position : 52
# 997931.0
# Filtre de petite time frame passé, pour i= 253 et un index à i de 2020-07-07 16:10:00
# Filtre de grosse time frame passé, pour j= 2498 et un index à j de 2020-07-06 21:00:00
# 253
# sold at 7.014125
# SL at 7.01488
# 289
# SL position closed at 7.02122 pnl -709.4999999999629
# nombre de candles en position : 36
# 997221.5
# Filtre de petite time frame passé, pour i= 291 et un index à i de 2020-07-07 19:20:00
# Filtre de grosse time frame passé, pour j= 2498 et un index à j de 2020-07-06 21:00:00
# 291
# sold at 7.02078
# SL at 7.0212900000000005
# 357
# SL position closed at 7.028865 pnl -808.4999999999454
# nombre de candles en position : 66
# 996413.0
# Filtre de petite time frame passé, pour i= 533 et un index à i de 2020-07-08 15:30:00
# Filtre de grosse time frame passé, pour j= 2499 et un index à j de 2020-07-07 21:00:00
# 533
# sold at 7.00589
# SL at 7.009455
# 634
# TP position closed at 6.9913 pnl 1459.0000000000102
# nombre de candles en position : 101
# 997872.0
# Filtre de petite time frame passé, pour i= 769 et un index à i de 2020-07-09 11:25:00
# Filtre de grosse time frame passé, pour j= 2500 et un index à j de 2020-07-08 21:00:00
# 769
# sold at 6.985835
# SL at 6.987635
# 808
# SL position closed at 6.99289 pnl -705.5000000000256
# nombre de candles en position : 39
# 997166.5
# Filtre de petite time frame passé, pour i= 868 et un index à i de 2020-07-09 19:40:00
# Filtre de grosse time frame passé, pour j= 2500 et un index à j de 2020-07-08 21:00:00
# 868
# sold at 6.99745
# SL at 6.998715000000001
# 929
# SL position closed at 7.00448 pnl -703.0000000000314
# nombre de candles en position : 61
# 996463.5
# Filtre de petite time frame passé, pour i= 930 et un index à i de 2020-07-10 00:55:00
# Filtre de grosse time frame passé, pour j= 2501 et un index à j de 2020-07-09 21:00:00
# 930
# sold at 7.003165
# SL at 7.00788
# 985
# SL position closed at 7.01049 pnl -732.4999999999804
# nombre de candles en position : 55
# 995731.0
# Filtre de petite time frame passé, pour i= 1026 et un index à i de 2020-07-10 08:55:00
# Filtre de grosse time frame passé, pour j= 2501 et un index à j de 2020-07-09 21:00:00
# 1026
# sold at 7.011015
# SL at 7.01197
# 1278
# TP position closed at 6.996840000000001 pnl 1417.4999999999827
# nombre de candles en position : 252
# 997148.5
# Filtre de petite time frame passé, pour i= 1319 et un index à i de 2020-07-13 08:30:00
# Filtre de grosse time frame passé, pour j= 2503 et un index à j de 2020-07-12 21:00:00
# 1319
# sold at 7.005595
# SL at 7.00687
# 1531
# SL position closed at 7.013525 pnl -792.9999999999993
# nombre de candles en position : 212
# 996355.5
# Filtre de petite time frame passé, pour i= 2311 et un index à i de 2020-07-16 19:15:00
# Filtre de grosse time frame passé, pour j= 2506 et un index à j de 2020-07-15 21:00:00
# 2311
# sold at 6.997375
# SL at 6.9983900000000006
# 2723
# TP position closed at 6.982965 pnl 1440.9999999999811
# nombre de candles en position : 412
# 997796.5
# Filtre de petite time frame passé, pour i= 2742 et un index à i de 2020-07-20 07:10:00
# Filtre de grosse time frame passé, pour j= 2509 et un index à j de 2020-07-19 21:00:00
# 2742
# sold at 6.98717
# SL at 6.98874
# 3153
# TP position closed at 6.97224 pnl 1492.9999999999666
# nombre de candles en position : 411
# 999289.5
# Filtre de petite time frame passé, pour i= 3178 et un index à i de 2020-07-21 19:45:00
# Filtre de grosse time frame passé, pour j= 2510 et un index à j de 2020-07-20 21:00:00
# 3178
# sold at 6.97297
# SL at 6.9742750000000004
# 3318
# SL position closed at 6.983695 pnl -1072.4999999999873
# nombre de candles en position : 140
# 998217.0
# Filtre de petite time frame passé, pour i= 3471 et un index à i de 2020-07-22 20:10:00
# Filtre de grosse time frame passé, pour j= 2511 et un index à j de 2020-07-21 21:00:00
# 3471
# sold at 7.0165500000000005
# SL at 7.0175149999999995
# 3574
# TP position closed at 7.00188 pnl 1467.0000000000628
# nombre de candles en position : 103
# 999684.0000000001
# Filtre de petite time frame passé, pour i= 4348 et un index à i de 2020-07-27 21:45:00
# Filtre de grosse time frame passé, pour j= 2516 et un index à j de 2020-07-27 21:00:00
# 4348
# sold at 7.000135
# SL at 7.00023
# 4440
# SL position closed at 7.007715 pnl -757.999999999992
# nombre de candles en position : 92
# 998926.0000000001
# Filtre de petite time frame passé, pour i= 4453 et un index à i de 2020-07-28 06:30:00
# Filtre de grosse time frame passé, pour j= 2516 et un index à j de 2020-07-27 21:00:00
# 4453
# sold at 7.002535
# SL at 7.00431
# 4469
# SL position closed at 7.009824999999999 pnl -728.9999999999352
# nombre de candles en position : 16
# 998197.0000000002
# Filtre de petite time frame passé, pour i= 4649 et un index à i de 2020-07-28 22:50:00
# Filtre de grosse time frame passé, pour j= 2517 et un index à j de 2020-07-28 21:00:00
# 4649
# sold at 7.00819
# SL at 7.008725
# 4969
# TP position closed at 6.99339 pnl 1480.0000000000146
# nombre de candles en position : 320
# 999677.0000000002
# Filtre de petite time frame passé, pour i= 5056 et un index à i de 2020-07-30 08:45:00
# Filtre de grosse time frame passé, pour j= 2518 et un index à j de 2020-07-29 21:00:00
# 5056
# sold at 7.00804
# SL at 7.010495
# 5127
# SL position closed at 7.016970000000001 pnl -893.0000000000326
# nombre de candles en position : 71
# 998784.0000000002
# Filtre de petite time frame passé, pour i= 5295 et un index à i de 2020-07-31 04:40:00
# Filtre de grosse time frame passé, pour j= 2519 et un index à j de 2020-07-30 21:00:00
# 5295
# sold at 6.992305
# SL at 6.9931149999999995
# 5357
# TP position closed at 6.976535 pnl 1576.999999999984
# nombre de candles en position : 62
# 1000361.0000000002
# Filtre de petite time frame passé, pour i= 5765 et un index à i de 2020-08-03 19:20:00
# Filtre de grosse time frame passé, pour j= 2521 et un index à j de 2020-08-02 21:00:00
# 5765
# sold at 6.984215
# SL at 6.9845500000000005
# 6125
# TP position closed at 6.9696549999999995 pnl 1456.000000000035
# nombre de candles en position : 360
# 1001817.0000000002
# Filtre de petite time frame passé, pour i= 6339 et un index à i de 2020-08-05 19:10:00
# Filtre de grosse time frame passé, pour j= 2523 et un index à j de 2020-08-04 21:00:00
# 6339
# sold at 6.94148
# SL at 6.942215
# 6432
# SL position closed at 6.948845 pnl -736.5000000000066
# nombre de candles en position : 93
# 1001080.5000000002
# Filtre de petite time frame passé, pour i= 6572 et un index à i de 2020-08-06 14:35:00
# Filtre de grosse time frame passé, pour j= 2524 et un index à j de 2020-08-05 21:00:00
# 6572
# sold at 6.9494299999999996
# SL at 6.950875
# 6702
# SL position closed at 6.956765000000001 pnl -733.5000000001202
# nombre de candles en position : 130
# 1000347.0000000001
# Filtre de petite time frame passé, pour i= 6823 et un index à i de 2020-08-07 11:30:00
# Filtre de grosse time frame passé, pour j= 2525 et un index à j de 2020-08-06 21:00:00
# 6823
# sold at 6.957375000000001
# SL at 6.95916
# 6844
# SL position closed at 6.969519999999999 pnl -1214.4999999998518
# nombre de candles en position : 21
# 999132.5000000002
# Filtre de petite time frame passé, pour i= 7093 et un index à i de 2020-08-10 09:55:00
# Filtre de grosse time frame passé, pour j= 2527 et un index à j de 2020-08-09 21:00:00
# 7093
# sold at 6.969235
# SL at 6.97012
# 7280
# TP position closed at 6.954345 pnl 1489.000000000029
# nombre de candles en position : 187
# 1000621.5000000002
# Filtre de petite time frame passé, pour i= 7423 et un index à i de 2020-08-11 13:25:00
# Filtre de grosse time frame passé, pour j= 2528 et un index à j de 2020-08-10 21:00:00
# 7423
# sold at 6.94145
# SL at 6.94425
# 7557
# SL position closed at 6.95312 pnl -1167.0000000000514
# nombre de candles en position : 134
# 999454.5000000002
# Filtre de petite time frame passé, pour i= 7677 et un index à i de 2020-08-12 10:35:00
# Filtre de grosse time frame passé, pour j= 2529 et un index à j de 2020-08-11 21:00:00
# 7677
# sold at 6.94449
# SL at 6.94578
# 7841
# TP position closed at 6.9304749999999995 pnl 1401.5000000000555
# nombre de candles en position : 164
# 1000856.0000000002
# Filtre de petite time frame passé, pour i= 7882 et un index à i de 2020-08-13 03:40:00
# Filtre de grosse time frame passé, pour j= 2530 et un index à j de 2020-08-12 21:00:00
# 7882
# sold at 6.937445
# SL at 6.938245
# 7983
# SL position closed at 6.94456 pnl -711.499999999976
# nombre de candles en position : 101
# 1000144.5000000002
# Filtre de petite time frame passé, pour i= 8016 et un index à i de 2020-08-13 14:50:00
# Filtre de grosse time frame passé, pour j= 2530 et un index à j de 2020-08-12 21:00:00
# 8016
# sold at 6.9440100000000005
# SL at 6.944775
# 8048
# SL position closed at 6.951475 pnl -746.4999999999833
# nombre de candles en position : 32
# 999398.0000000002
# Filtre de petite time frame passé, pour i= 8207 et un index à i de 2020-08-14 06:50:00
# Filtre de grosse time frame passé, pour j= 2531 et un index à j de 2020-08-13 21:00:00
# 8207
# sold at 6.9412400000000005
# SL at 6.942315
# 8225
# SL position closed at 6.9488900000000005 pnl -764.9999999999934
# nombre de candles en position : 18
# 998633.0000000002
# Filtre de petite time frame passé, pour i= 8534 et un index à i de 2020-08-17 10:20:00
# Filtre de grosse time frame passé, pour j= 2533 et un index à j de 2020-08-16 21:00:00
# 8534
# sold at 6.937605
# SL at 6.939515
# 8718
# TP position closed at 6.92291 pnl 1469.4999999999682
# nombre de candles en position : 184
# 1000102.5000000002
# Filtre de petite time frame passé, pour i= 9040 et un index à i de 2020-08-19 04:35:00
# Filtre de grosse time frame passé, pour j= 2535 et un index à j de 2020-08-18 21:00:00
# 9040
# sold at 6.91638
# SL at 6.917574999999999
# 9087
# TP position closed at 6.901905 pnl 1447.5000000000016
# nombre de candles en position : 47
# 1001550.0000000002
# Filtre de petite time frame passé, pour i= 9105 et un index à i de 2020-08-19 10:00:00
# Filtre de grosse time frame passé, pour j= 2535 et un index à j de 2020-08-18 21:00:00
# 9105
# sold at 6.90005
# SL at 6.90278
# 9141
# SL position closed at 6.90773 pnl -767.9999999999687
# nombre de candles en position : 36
# 1000782.0000000002
# Filtre de petite time frame passé, pour i= 9269 et un index à i de 2020-08-19 23:40:00
# Filtre de grosse time frame passé, pour j= 2536 et un index à j de 2020-08-19 21:00:00
# 9269
# sold at 6.922525
# SL at 6.923385
# 9451
# TP position closed at 6.908475 pnl 1405.0000000000118
# nombre de candles en position : 182
# 1002187.0000000002
# Filtre de petite time frame passé, pour i= 9664 et un index à i de 2020-08-21 08:55:00
# Filtre de grosse time frame passé, pour j= 2537 et un index à j de 2020-08-20 21:00:00
# 9664
# sold at 6.908965
# SL at 6.911295
# 9682
# SL position closed at 6.916600000000001 pnl -763.5000000000502
# nombre de candles en position : 18
# 1001423.5000000002
# Filtre de petite time frame passé, pour i= 9746 et un index à i de 2020-08-21 15:45:00
# Filtre de grosse time frame passé, pour j= 2537 et un index à j de 2020-08-20 21:00:00
# 9746
# sold at 6.920825000000001
# SL at 6.921455
# 9953
# TP position closed at 6.906445 pnl 1438.0000000000948
# nombre de candles en position : 207
# 1002861.5000000003
#
# Les gains faramineux s'élèvent à : $  2861.5 !. En  35  transactions.
#
# Nbre de winners : 14
#
# Nbre de loosers : 21
#
# Average trade duration  126.51
# CPU times: user 38 s, sys: 1.55 s, total: 39.5 s
# Wall time: 2min 2s

# %%
df_resultats.T
# Out:
#         TimeFrame 1 TimeFrame2 Total Pnl Nbre Winners Nbre Loosers  \
# EUR/USD          m5         D1    3433.0           25           23
# USD/JPY          m5         D1  157850.0           11            9
# GBP/USD          m5         D1    2563.0           22           24
# USD/CHF          m5         D1    1538.0           22           25
# EUR/CHF          m5         D1    -161.0           10           20
# AUD/USD          m5         D1    1842.5           27           27
# USD/CAD          m5         D1    1193.5           17           24
# NZD/USD          m5         D1     111.0           13           23
# EUR/GBP          m5         D1     515.5            9           11
# EUR/JPY          m5         D1   47100.0           13           21
# GBP/JPY          m5         D1  -72550.0           12           29
# CHF/JPY          m5         D1  100500.0           15           22
# GBP/CHF          m5         D1    -877.0            2            9
# EUR/AUD          m5         D1   -1616.0            6           20
# EUR/CAD          m5         D1    5671.0           24           15
# AUD/CAD          m5         D1    2771.5           20           12
# AUD/JPY          m5         D1  -30250.0           13           25
# CAD/JPY          m5         D1  -48850.0            7           18
# NZD/JPY          m5         D1  -14150.0            1            3
# GBP/CAD          m5         D1     531.5            9           14
# GBP/NZD          m5         D1    2870.5           17           21
# GBP/AUD          m5         D1    -395.0            8           17
# AUD/NZD          m5         D1    1216.0           17           22
# USD/SEK          m5         D1   14399.5           21           25
# EUR/SEK          m5         D1  -12573.5            9           26
# EUR/NOK          m5         D1   -1408.0           10           18
# USD/NOK          m5         D1     877.5            3            4
# USD/MXN          m5         D1   12719.5           19           26
# AUD/CHF          m5         D1     187.5            6            8
# EUR/NZD          m5         D1    1334.0           12           15
# USD/ZAR          m5         D1  -12895.0            1            7
# ZAR/JPY          m5         D1   -3100.0            0            4
# NZD/CHF          m5         D1     200.5           13           21
# CAD/CHF          m5         D1    -726.5            9           23
# NZD/CAD          m5         D1   -1176.5            4           18
# USD/ILS          m5         D1         0            0            0
# USD/CNH          m5         D1    2861.5           14           21
#
#         Average lenght of trade currency of the pnl Pnl in USD
# EUR/USD                   53.54                 USD     3433.0
# USD/JPY                    88.7                 JPY    1492.88
# GBP/USD                      45                 USD     2563.0
# USD/CHF                   52.19                 CHF    1693.53
# EUR/CHF                      83                 CHF    -177.28
# AUD/USD                   23.28                 USD     1842.5
# USD/CAD                   58.32                 CAD      908.3
# NZD/USD                   22.06                 USD      111.0
# EUR/GBP                    62.8                 GBP     676.77
# EUR/JPY                   43.85                 JPY     445.48
# GBP/JPY                    49.9                 JPY    -686.18
# CHF/JPY                   62.97                 JPY     950.48
# GBP/CHF                   44.18                 CHF    -965.61
# EUR/AUD                   62.92                 AUD   -1162.71
# EUR/CAD                   74.59                 CAD    4315.63
# AUD/CAD                   45.19                 CAD    2109.11
# AUD/JPY                      30                 JPY    -286.09
# CAD/JPY                   63.36                 JPY     -462.0
# NZD/JPY                   53.75                 JPY    -133.82
# GBP/CAD                    50.3                 CAD     404.49
# GBP/NZD                   48.37                 NZD    1882.22
# GBP/AUD                   47.64                 AUD    -284.21
# AUD/NZD                   64.97                 NZD     797.38
# USD/SEK                   26.43                 SEK    1644.81
# EUR/SEK                   70.26                 SEK   -1436.23
# EUR/NOK                   37.36                 NOK     -157.0
# USD/NOK                   22.86                 NOK      97.85
# USD/MXN                    18.2                 MXN     580.71
# AUD/CHF                    44.5                 CHF     206.32
# EUR/NZD                   49.96                 NZD     874.84
# USD/ZAR                    17.5                 ZAR    -760.52
# ZAR/JPY                   17.75                 JPY     -29.32
# NZD/CHF                   33.32                 CHF     220.64
# CAD/CHF                   59.94                 CHF    -799.49
# NZD/CAD                   73.95                 CAD     -895.4
# USD/ILS                      NA                 ILS        0.0
# USD/CNH                  126.51                 CNH     414.43

# %%
_total
# Out:
# 19429.51

# %%
TICKERS = ['EUR/USD','USD/JPY','GBP/USD','USD/CHF','EUR/CHF','AUD/USD','USD/CAD','NZD/USD','EUR/GBP','EUR/JPY','GBP/JPY','CHF/JPY','GBP/CHF','EUR/AUD','EUR/CAD','AUD/CAD','AUD/JPY','CAD/JPY','NZD/JPY','GBP/CAD','GBP/NZD','GBP/AUD','AUD/NZD','USD/SEK','EUR/SEK','EUR/NOK','USD/NOK','USD/MXN','AUD/CHF','EUR/NZD','USD/ZAR','ZAR/JPY','NZD/CHF','CAD/CHF','NZD/CAD','USD/ILS','USD/CNH']

# %%
data

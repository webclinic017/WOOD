# %%
import fxcmpy
import socketio
import datetime as dt
import time
print('fxcmpy version',fxcmpy.__version__)
print('socketio version',socketio.__version__)
# Out:
# fxcmpy version 1.2.6
# socketio version 4.4.0

# %%
TOKEN = '79f83cbff13d296eb6d9b6c1ed6dccd768ef925a'
server = 'demo'

# %%
con = fxcmpy.fxcmpy(access_token=TOKEN, log_level='debug',server=server)
# Out:
# |INFO|2020-08-21 15:32:23,672|Connecting FXCM Server
# |DEBUG|2020-08-21 15:32:23,675|Access token: 79f83cbff13d296eb6d9b6c1ed6dccd768ef925a.
# |DEBUG|2020-08-21 15:32:23,693|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:23,840|https://api-demo.fxcm.com:443 "GET /socket.io/?access_token=79f83cbff13d296eb6d9b6c1ed6dccd768ef925a&agent=pythonquants&wait_for_connection=False&transport=polling&EIO=3&t=1598016743.6774468 HTTP/1.1" 200 None
# |INFO|2020-08-21 15:32:24,327|Socket established: <socketio.client.Client object at 0x105764d50>.
# |INFO|2020-08-21 15:32:30,433|Connection established.
# |INFO|2020-08-21 15:32:30,695|In handle_request with method trading/get_model
# |INFO|2020-08-21 15:32:30,696|Connection status: True
# |INFO|2020-08-21 15:32:30,697|2. connection status: established
# |INFO|2020-08-21 15:32:30,698|Socket state: True
# |INFO|2020-08-21 15:32:30,700|Thread state: True
# |INFO|2020-08-21 15:32:30,702|Thread name: Thread-4
# |INFO|2020-08-21 15:32:30,703|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:30,703|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:30,704|Sending request to https://api-demo.fxcm.com/trading/get_model, parameter: {'models': ['Account']}.
# |DEBUG|2020-08-21 15:32:30,709|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:30,856|https://api-demo.fxcm.com:443 "GET /trading/get_model?models=Account HTTP/1.1" 200 471
# |INFO|2020-08-21 15:32:30,862|Sending GET Request:
# |INFO|2020-08-21 15:32:30,862|URL: https://api-demo.fxcm.com:443/trading/get_model?models=Account
# |INFO|2020-08-21 15:32:30,863|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded'}
# |INFO|2020-08-21 15:32:30,864|Params: {'models': ['Account']}
# |INFO|2020-08-21 15:32:30,865|Proxies: {}
# |DEBUG|2020-08-21 15:32:30,866|Server answer: {'response': {'executed': True}, 'accounts': [{'t': 6, 'ratePrecision': 0, 'accountId': '1215060', 'balance': 44469.55, 'usdMr': 7193.7, 'mc': 'N', 'mcDate': '', 'accountName': '01215060', 'usdMr3': 14387.4, 'hedging': 'Y', 'usableMargin3': 23845.40465, 'usableMarginPerc': 81.18448, 'usableMargin3Perc': 62.36897, 'equity': 38232.80465, 'usableMargin': 31039.10465, 'bus': '1000', 'dayPL': 2726.18465, 'grossPL': -6236.74535}, {'t': 6, 'ratePrecision': 0, 'accountId': '', 'balance': 44469.55, 'usdMr': 7193.7, 'mc': '', 'mcDate': None, 'accountName': '', 'usdMr3': 14387.4, 'hedging': '', 'usableMargin3': 23845.40465, 'usableMarginPerc': 81.18448, 'usableMargin3Perc': 62.36897, 'equity': 38232.80465, 'usableMargin': 31039.10465, 'bus': None, 'dayPL': 2726.18465, 'grossPL': -6236.74535, 'isTotal': True}]}.
# |WARNING|2020-08-21 15:32:30,867|Default account set to 1215060, to change use set_default_account().
# |INFO|2020-08-21 15:32:30,868|In handle_request with method trading/get_model
# |INFO|2020-08-21 15:32:30,868|Connection status: True
# |INFO|2020-08-21 15:32:30,869|2. connection status: established
# |INFO|2020-08-21 15:32:30,869|Socket state: True
# |INFO|2020-08-21 15:32:30,870|Thread state: True
# |INFO|2020-08-21 15:32:30,870|Thread name: Thread-4
# |INFO|2020-08-21 15:32:30,871|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:30,871|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:30,872|Sending request to https://api-demo.fxcm.com/trading/get_model, parameter: {'models': ['Order']}.
# |DEBUG|2020-08-21 15:32:30,875|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:31,352|https://api-demo.fxcm.com:443 "GET /trading/get_model?models=Order HTTP/1.1" 200 42
# |INFO|2020-08-21 15:32:31,359|Sending GET Request:
# |INFO|2020-08-21 15:32:31,360|URL: https://api-demo.fxcm.com:443/trading/get_model?models=Order
# |INFO|2020-08-21 15:32:31,360|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded'}
# |INFO|2020-08-21 15:32:31,363|Params: {'models': ['Order']}
# |INFO|2020-08-21 15:32:31,364|Proxies: {}
# |DEBUG|2020-08-21 15:32:31,365|Server answer: {'response': {'executed': True}, 'orders': []}.
# |DEBUG|2020-08-21 15:32:31,365|Fetching instruments table.
# |INFO|2020-08-21 15:32:31,366|In handle_request with method trading/get_instruments
# |INFO|2020-08-21 15:32:31,367|Connection status: True
# |INFO|2020-08-21 15:32:31,367|2. connection status: established
# |INFO|2020-08-21 15:32:31,368|Socket state: True
# |INFO|2020-08-21 15:32:31,369|Thread state: True
# |INFO|2020-08-21 15:32:31,369|Thread name: Thread-4
# |INFO|2020-08-21 15:32:31,370|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:31,370|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:31,371|Sending request to https://api-demo.fxcm.com/trading/get_instruments, parameter: {}.
# |DEBUG|2020-08-21 15:32:31,374|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:31,805|https://api-demo.fxcm.com:443 "GET /trading/get_instruments HTTP/1.1" 200 731
# |INFO|2020-08-21 15:32:31,810|Sending GET Request:
# |INFO|2020-08-21 15:32:31,810|URL: https://api-demo.fxcm.com:443/trading/get_instruments
# |INFO|2020-08-21 15:32:31,812|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded'}
# |INFO|2020-08-21 15:32:31,813|Params: {}
# |INFO|2020-08-21 15:32:31,814|Proxies: {}
# |DEBUG|2020-08-21 15:32:31,816|Server answer: {'response': {'executed': True}, 'data': {'instrument': [{'symbol': 'EUR/USD', 'visible': True, 'order': 100}, {'symbol': 'USD/JPY', 'visible': True, 'order': 950}, {'symbol': 'GBP/USD', 'visible': True, 'order': 250}, {'symbol': 'USD/CHF', 'visible': True, 'order': 1250}, {'symbol': 'EUR/CHF', 'visible': False, 'order': 1450}, {'symbol': 'AUD/USD', 'visible': True, 'order': 1350}, {'symbol': 'USD/CAD', 'visible': True, 'order': 1750}, {'symbol': 'NZD/USD', 'visible': True, 'order': 1650}, {'symbol': 'EUR/GBP', 'visible': False, 'order': 1550}, {'symbol': 'EUR/JPY', 'visible': False, 'order': 850}, {'symbol': 'GBP/JPY', 'visible': False, 'order': 1050}, {'symbol': 'CHF/JPY', 'visible': False, 'order': 1200}, {'symbol': 'GBP/CHF', 'visible': False, 'order': 1300}, {'symbol': 'EUR/AUD', 'visible': False, 'order': 1400}, {'symbol': 'EUR/CAD', 'visible': False, 'order': 1500}, {'symbol': 'AUD/CAD', 'visible': False, 'order': 1600}, {'symbol': 'AUD/JPY', 'visible': False, 'order': 1150}, {'symbol': 'CAD/JPY', 'visible': False, 'order': 1800}, {'symbol': 'NZD/JPY', 'visible': False, 'order': 1900}, {'symbol': 'GBP/CAD', 'visible': False, 'order': 2000}, {'symbol': 'GBP/NZD', 'visible': False, 'order': 2100}, {'symbol': 'GBP/AUD', 'visible': False, 'order': 1850}, {'symbol': 'AUD/NZD', 'visible': False, 'order': 2800}, {'symbol': 'USD/SEK', 'visible': True, 'order': 3000}, {'symbol': 'EUR/SEK', 'visible': False, 'order': 3200}, {'symbol': 'EUR/NOK', 'visible': False, 'order': 3600}, {'symbol': 'USD/NOK', 'visible': True, 'order': 3700}, {'symbol': 'USD/MXN', 'visible': True, 'order': 3800}, {'symbol': 'AUD/CHF', 'visible': False, 'order': 3900}, {'symbol': 'EUR/NZD', 'visible': False, 'order': 4000}, {'symbol': 'USD/ZAR', 'visible': True, 'order': 4700}, {'symbol': 'USD/HKD', 'visible': False, 'order': 5000}, {'symbol': 'ZAR/JPY', 'visible': False, 'order': 7100}, {'symbol': 'USD/TRY', 'visible': False, 'order': 8300}, {'symbol': 'EUR/TRY', 'visible': False, 'order': 8700}, {'symbol': 'NZD/CHF', 'visible': False, 'order': 8900}, {'symbol': 'CAD/CHF', 'visible': False, 'order': 9000}, {'symbol': 'NZD/CAD', 'visible': False, 'order': 9100}, {'symbol': 'TRY/JPY', 'visible': False, 'order': 9800}, {'symbol': 'USD/ILS', 'visible': True, 'order': 10000}, {'symbol': 'USD/CNH', 'visible': True, 'order': 799}, {'symbol': 'AUS200', 'visible': False, 'order': 100100}, {'symbol': 'ESP35', 'visible': False, 'order': 100200}, {'symbol': 'FRA40', 'visible': False, 'order': 750}, {'symbol': 'GER30', 'visible': False, 'order': 650}, {'symbol': 'HKG33', 'visible': False, 'order': 100500}, {'symbol': 'JPN225', 'visible': False, 'order': 100700}, {'symbol': 'NAS100', 'visible': False, 'order': 100800}, {'symbol': 'SPX500', 'visible': True, 'order': 101000}, {'symbol': 'UK100', 'visible': False, 'order': 350}, {'symbol': 'US30', 'visible': False, 'order': 1950}, {'symbol': 'Copper', 'visible': False, 'order': 101600}, {'symbol': 'CHN50', 'visible': False, 'order': 1020}, {'symbol': 'EUSTX50', 'visible': False, 'order': 103500}, {'symbol': 'USDOLLAR', 'visible': False, 'order': 450}, {'symbol': 'US2000', 'visible': True, 'order': 1060}, {'symbol': 'USOil', 'visible': False, 'order': 200100}, {'symbol': 'UKOil', 'visible': False, 'order': 200200}, {'symbol': 'SOYF', 'visible': False, 'order': 2003}, {'symbol': 'NGAS', 'visible': False, 'order': 201500}, {'symbol': 'USOilSpot', 'visible': True, 'order': 2018}, {'symbol': 'UKOilSpot', 'visible': True, 'order': 2019}, {'symbol': 'WHEATF', 'visible': True, 'order': 2020}, {'symbol': 'CORNF', 'visible': True, 'order': 2021}, {'symbol': 'Bund', 'visible': False, 'order': 300100}, {'symbol': 'XAU/USD', 'visible': False, 'order': 150}, {'symbol': 'XAG/USD', 'visible': False, 'order': 550}, {'symbol': 'EMBasket', 'visible': True, 'order': 6001}, {'symbol': 'JPYBasket', 'visible': True, 'order': 6002}, {'symbol': 'BTC/USD', 'visible': True, 'order': 8001}, {'symbol': 'BC ...
# |INFO|2020-08-21 15:32:31,818|In handle_request with method trading/update_subscriptions
# |INFO|2020-08-21 15:32:31,818|Connection status: True
# |INFO|2020-08-21 15:32:31,819|2. connection status: established
# |INFO|2020-08-21 15:32:31,821|Socket state: True
# |INFO|2020-08-21 15:32:31,822|Thread state: True
# |INFO|2020-08-21 15:32:31,824|Thread name: Thread-4
# |INFO|2020-08-21 15:32:31,824|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:31,825|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:31,826|Sending request to https://api-demo.fxcm.com/trading/update_subscriptions, parameter: {'symbol': 'CANNABIS', 'visible': 'true'}.
# |DEBUG|2020-08-21 15:32:31,832|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:34,874|https://api-demo.fxcm.com:443 "POST /trading/update_subscriptions HTTP/1.1" 200 30
# |INFO|2020-08-21 15:32:34,879|Sending POST Request:
# |INFO|2020-08-21 15:32:34,879|URL: https://api-demo.fxcm.com:443/trading/update_subscriptions
# |INFO|2020-08-21 15:32:34,884|Payload: symbol=CANNABIS&visible=true
# |INFO|2020-08-21 15:32:34,886|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '28'}
# |INFO|2020-08-21 15:32:34,889|Params: {'symbol': 'CANNABIS', 'visible': 'true'}
# |INFO|2020-08-21 15:32:34,899|Proxies: {}
# |DEBUG|2020-08-21 15:32:34,902|Server answer: {'response': {'executed': True}}.
# |INFO|2020-08-21 15:32:34,906|In handle_request with method trading/update_subscriptions
# |INFO|2020-08-21 15:32:34,908|Connection status: True
# |INFO|2020-08-21 15:32:34,910|2. connection status: established
# |INFO|2020-08-21 15:32:34,913|Socket state: True
# |INFO|2020-08-21 15:32:34,916|Thread state: True
# |INFO|2020-08-21 15:32:34,917|Thread name: Thread-4
# |INFO|2020-08-21 15:32:34,918|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:34,920|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:34,921|Sending request to https://api-demo.fxcm.com/trading/update_subscriptions, parameter: {'symbol': 'FAANG', 'visible': 'true'}.
# |DEBUG|2020-08-21 15:32:34,928|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:36,415|https://api-demo.fxcm.com:443 "POST /trading/update_subscriptions HTTP/1.1" 200 30
# |INFO|2020-08-21 15:32:36,419|Sending POST Request:
# |INFO|2020-08-21 15:32:36,420|URL: https://api-demo.fxcm.com:443/trading/update_subscriptions
# |INFO|2020-08-21 15:32:36,421|Payload: symbol=FAANG&visible=true
# |INFO|2020-08-21 15:32:36,422|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '25'}
# |INFO|2020-08-21 15:32:36,423|Params: {'symbol': 'FAANG', 'visible': 'true'}
# |INFO|2020-08-21 15:32:36,423|Proxies: {}
# |DEBUG|2020-08-21 15:32:36,424|Server answer: {'response': {'executed': True}}.
# |INFO|2020-08-21 15:32:36,426|In handle_request with method trading/update_subscriptions
# |INFO|2020-08-21 15:32:36,427|Connection status: True
# |INFO|2020-08-21 15:32:36,429|2. connection status: established
# |INFO|2020-08-21 15:32:36,429|Socket state: True
# |INFO|2020-08-21 15:32:36,430|Thread state: True
# |INFO|2020-08-21 15:32:36,430|Thread name: Thread-4
# |INFO|2020-08-21 15:32:36,431|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:36,431|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:36,432|Sending request to https://api-demo.fxcm.com/trading/update_subscriptions, parameter: {'symbol': 'CHN.TECH', 'visible': 'true'}.
# |DEBUG|2020-08-21 15:32:36,435|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:38,338|https://api-demo.fxcm.com:443 "POST /trading/update_subscriptions HTTP/1.1" 200 30
# |INFO|2020-08-21 15:32:38,343|Sending POST Request:
# |INFO|2020-08-21 15:32:38,345|URL: https://api-demo.fxcm.com:443/trading/update_subscriptions
# |INFO|2020-08-21 15:32:38,345|Payload: symbol=CHN.TECH&visible=true
# |INFO|2020-08-21 15:32:38,346|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '28'}
# |INFO|2020-08-21 15:32:38,348|Params: {'symbol': 'CHN.TECH', 'visible': 'true'}
# |INFO|2020-08-21 15:32:38,349|Proxies: {}
# |DEBUG|2020-08-21 15:32:38,350|Server answer: {'response': {'executed': True}}.
# |INFO|2020-08-21 15:32:38,350|In handle_request with method trading/update_subscriptions
# |INFO|2020-08-21 15:32:38,352|Connection status: True
# |INFO|2020-08-21 15:32:38,353|2. connection status: established
# |INFO|2020-08-21 15:32:38,353|Socket state: True
# |INFO|2020-08-21 15:32:38,355|Thread state: True
# |INFO|2020-08-21 15:32:38,355|Thread name: Thread-4
# |INFO|2020-08-21 15:32:38,356|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:38,357|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:38,358|Sending request to https://api-demo.fxcm.com/trading/update_subscriptions, parameter: {'symbol': 'CHN.ECOMM', 'visible': 'true'}.
# |DEBUG|2020-08-21 15:32:38,362|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:39,337|https://api-demo.fxcm.com:443 "POST /trading/update_subscriptions HTTP/1.1" 200 30
# |INFO|2020-08-21 15:32:39,342|Sending POST Request:
# |INFO|2020-08-21 15:32:39,343|URL: https://api-demo.fxcm.com:443/trading/update_subscriptions
# |INFO|2020-08-21 15:32:39,343|Payload: symbol=CHN.ECOMM&visible=true
# |INFO|2020-08-21 15:32:39,345|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '29'}
# |INFO|2020-08-21 15:32:39,347|Params: {'symbol': 'CHN.ECOMM', 'visible': 'true'}
# |INFO|2020-08-21 15:32:39,348|Proxies: {}
# |DEBUG|2020-08-21 15:32:39,350|Server answer: {'response': {'executed': True}}.
# |INFO|2020-08-21 15:32:39,351|In handle_request with method trading/update_subscriptions
# |INFO|2020-08-21 15:32:39,352|Connection status: True
# |INFO|2020-08-21 15:32:39,353|2. connection status: established
# |INFO|2020-08-21 15:32:39,353|Socket state: True
# |INFO|2020-08-21 15:32:39,354|Thread state: True
# |INFO|2020-08-21 15:32:39,355|Thread name: Thread-4
# |INFO|2020-08-21 15:32:39,355|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:39,356|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:39,357|Sending request to https://api-demo.fxcm.com/trading/update_subscriptions, parameter: {'symbol': 'USEquities', 'visible': 'true'}.
# |DEBUG|2020-08-21 15:32:39,361|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:41,300|https://api-demo.fxcm.com:443 "POST /trading/update_subscriptions HTTP/1.1" 200 30
# |INFO|2020-08-21 15:32:41,305|Sending POST Request:
# |INFO|2020-08-21 15:32:41,306|URL: https://api-demo.fxcm.com:443/trading/update_subscriptions
# |INFO|2020-08-21 15:32:41,308|Payload: symbol=USEquities&visible=true
# |INFO|2020-08-21 15:32:41,310|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '30'}
# |INFO|2020-08-21 15:32:41,312|Params: {'symbol': 'USEquities', 'visible': 'true'}
# |INFO|2020-08-21 15:32:41,314|Proxies: {}
# |DEBUG|2020-08-21 15:32:41,315|Server answer: {'response': {'executed': True}}.
# |INFO|2020-08-21 15:32:41,317|In handle_request with method trading/get_model
# |INFO|2020-08-21 15:32:41,318|Connection status: True
# |INFO|2020-08-21 15:32:41,320|2. connection status: established
# |INFO|2020-08-21 15:32:41,322|Socket state: True
# |INFO|2020-08-21 15:32:41,324|Thread state: True
# |INFO|2020-08-21 15:32:41,325|Thread name: Thread-4
# |INFO|2020-08-21 15:32:41,327|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:41,328|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:41,330|Sending request to https://api-demo.fxcm.com/trading/get_model, parameter: {'models': ['Offer']}.
# |DEBUG|2020-08-21 15:32:41,336|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:41,860|https://api-demo.fxcm.com:443 "GET /trading/get_model?models=Offer HTTP/1.1" 200 2609
# |INFO|2020-08-21 15:32:41,865|Sending GET Request:
# |INFO|2020-08-21 15:32:41,867|URL: https://api-demo.fxcm.com:443/trading/get_model?models=Offer
# |INFO|2020-08-21 15:32:41,869|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded'}
# |INFO|2020-08-21 15:32:41,871|Params: {'models': ['Offer']}
# |INFO|2020-08-21 15:32:41,872|Proxies: {}
# |DEBUG|2020-08-21 15:32:41,875|Server answer: {'response': {'executed': True}, 'offers': [{'t': 0, 'ratePrecision': 5, 'offerId': 1, 'rollB': -0.2577, 'rollS': 0.1132, 'fractionDigits': 5, 'pip': 0.0001, 'defaultSortOrder': 100, 'currency': 'EUR/USD', 'instrumentType': 1, 'valueDate': '08252020', 'time': '2020-08-21T13:32:41.149Z', 'sell': 1.17795, 'buy': 1.17809, 'sellTradable': True, 'buyTradable': True, 'high': 1.18835, 'low': 1.17598, 'volume': 1, 'pipFraction': 0.1, 'spread': 1.4, 'mmr': 33.3, 'emr': 33.3, 'lmr': 16.65, 'minQuantity': 1, 'maxQuantity': 50000000, 'instrBaseUnitSize': 1, 'pipCost': 0.08489}, {'t': 0, 'ratePrecision': 3, 'offerId': 2, 'rollB': 0.0338, 'rollS': -0.0862, 'fractionDigits': 3, 'pip': 0.01, 'defaultSortOrder': 950, 'currency': 'USD/JPY', 'instrumentType': 1, 'valueDate': '08252020', 'time': '2020-08-21T13:32:41.466Z', 'sell': 105.714, 'buy': 105.726, 'sellTradable': True, 'buyTradable': True, 'high': 105.878, 'low': 105.436, 'volume': 0.00803, 'pipFraction': 0.1, 'spread': 1.2, 'mmr': 33.3, 'emr': 33.3, 'lmr': 16.65, 'minQuantity': 1, 'maxQuantity': 50000000, 'instrBaseUnitSize': 1, 'pipCost': 0.08029}, {'t': 0, 'ratePrecision': 5, 'offerId': 3, 'rollB': -0.0448, 'rollS': 0.011, 'fractionDigits': 5, 'pip': 0.0001, 'defaultSortOrder': 250, 'currency': 'GBP/USD', 'instrumentType': 1, 'valueDate': '08252020', 'time': '2020-08-21T13:32:41.210Z', 'sell': 1.30981, 'buy': 1.30997, 'sellTradable': True, 'buyTradable': True, 'high': 1.32559, 'low': 1.30776, 'volume': 0.84886, 'pipFraction': 0.1, 'spread': 1.6, 'mmr': 43.29, 'emr': 43.29, 'lmr': 21.645, 'minQuantity': 1, 'maxQuantity': 50000000, 'instrBaseUnitSize': 1, 'pipCost': 0.08489}, {'t': 0, 'ratePrecision': 5, 'offerId': 4, 'rollB': 0.1259, 'rollS': -0.2923, 'fractionDigits': 5, 'pip': 0.0001, 'defaultSortOrder': 1250, 'currency': 'USD/CHF', 'instrumentType': 1, 'valueDate': '08252020', 'time': '2020-08-21T13:32:41.138Z', 'sell': 0.91208, 'buy': 0.9122, 'sellTradable': True, 'buyTradable': True, 'high': 0.91381, 'low': 0.90604, 'volume': 0.93056, 'pipFraction': 0.1, 'spread': 1.2, 'mmr': 33.3, 'emr': 33.3, 'lmr': 16.65, 'minQuantity': 1, 'maxQuantity': 50000000, 'instrBaseUnitSize': 1, 'pipCost': 0.09306}, {'t': 0, 'ratePrecision': 5, 'offerId': 6, 'rollB': -0.0118, 'rollS': -0.011, 'fractionDigits': 5, 'pip': 0.0001, 'defaultSortOrder': 1350, 'currency': 'AUD/USD', 'instrumentType': 1, 'valueDate': '08252020', 'time': '2020-08-21T13:32:41.431Z', 'sell': 0.71669, 'buy': 0.71686, 'sellTradable': True, 'buyTradable': True, 'high': 0.72167, 'low': 0.71539, 'volume': 0.84886, 'pipFraction': 0.1, 'spread': 1.7, 'mmr': 35, 'emr': 35, 'lmr': 17.5, 'minQuantity': 1, 'maxQuantity': 50000000, 'instrBaseUnitSize': 1, 'pipCost': 0.08489}, {'t': 0, 'ratePrecision': 5, 'offerId': 7, 'rollB': -0.0059, 'rollS': -0.0262, 'fractionDigits': 5, 'pip': 0.0001, 'defaultSortOrder': 1750, 'currency': 'USD/CAD', 'instrumentType': 1, 'valueDate': '08252020', 'time': '2020-08-21T13:32:40.646Z', 'sell': 1.32164, 'buy': 1.32184, 'sellTradable': True, 'buyTradable': True, 'high': 1.32295, 'low': 1.31581, 'volume': 0.64226, 'pipFraction': 0.1, 'spread': 2, 'mmr': 33.3, 'emr': 33.3, 'lmr': 16.65, 'minQuantity': 1, 'maxQuantity': 50000000, 'instrBaseUnitSize': 1, 'pipCost': 0.06422}, {'t': 0, 'ratePrecision': 5, 'offerId': 8, 'rollB': 0.0186, 'rollS': -0.0473, 'fractionDigits': 5, 'pip': 0.0001, 'defaultSortOrder': 1650, 'currency': 'NZD/USD', 'instrumentType': 1, 'valueDate': '08252020', 'time': '2020-08-21T13:32:41.372Z', 'sell': 0.65348, 'buy': 0.65366, 'sellTradable': True, 'buyTradable': True, 'high': 0.65502, 'low': 0.6516, 'volume': 0.84886, 'pipFraction': 0.1, 'spread': 1.8, 'mmr': 35, 'emr': 35, 'lmr': 17.5, 'minQuantity': 1, 'maxQuantity': 50000000, 'instrBaseUnitSize': 1, 'pipCost': 0.08489}, {'t': 0, 'ratePrecision': 5, 'offerId': 30, 'rollB': 0.0262, 'rollS': -0.1124, 'fractionDigits': 5, 'pip': 0.0001, 'defaultSortOrder': 3000, 'currency': 'USD/SEK', 'instrumentType' ...
# |INFO|2020-08-21 15:32:41,877|In handle_request with method trading/update_subscriptions
# |INFO|2020-08-21 15:32:41,878|Connection status: True
# |INFO|2020-08-21 15:32:41,880|2. connection status: established
# |INFO|2020-08-21 15:32:41,881|Socket state: True
# |INFO|2020-08-21 15:32:41,883|Thread state: True
# |INFO|2020-08-21 15:32:41,884|Thread name: Thread-4
# |INFO|2020-08-21 15:32:41,886|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:41,886|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:41,887|Sending request to https://api-demo.fxcm.com/trading/update_subscriptions, parameter: {'symbol': 'CANNABIS', 'visible': 'false'}.
# |DEBUG|2020-08-21 15:32:41,891|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:42,882|https://api-demo.fxcm.com:443 "POST /trading/update_subscriptions HTTP/1.1" 200 30
# |INFO|2020-08-21 15:32:42,885|Sending POST Request:
# |INFO|2020-08-21 15:32:42,887|URL: https://api-demo.fxcm.com:443/trading/update_subscriptions
# |INFO|2020-08-21 15:32:42,888|Payload: symbol=CANNABIS&visible=false
# |INFO|2020-08-21 15:32:42,889|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '29'}
# |INFO|2020-08-21 15:32:42,890|Params: {'symbol': 'CANNABIS', 'visible': 'false'}
# |INFO|2020-08-21 15:32:42,891|Proxies: {}
# |DEBUG|2020-08-21 15:32:42,892|Server answer: {'response': {'executed': True}}.
# |INFO|2020-08-21 15:32:42,894|In handle_request with method trading/update_subscriptions
# |INFO|2020-08-21 15:32:42,895|Connection status: True
# |INFO|2020-08-21 15:32:42,898|2. connection status: established
# |INFO|2020-08-21 15:32:42,899|Socket state: True
# |INFO|2020-08-21 15:32:42,900|Thread state: True
# |INFO|2020-08-21 15:32:42,901|Thread name: Thread-4
# |INFO|2020-08-21 15:32:42,902|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:42,903|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:42,904|Sending request to https://api-demo.fxcm.com/trading/update_subscriptions, parameter: {'symbol': 'FAANG', 'visible': 'false'}.
# |DEBUG|2020-08-21 15:32:42,909|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:43,335|https://api-demo.fxcm.com:443 "POST /trading/update_subscriptions HTTP/1.1" 200 30
# |INFO|2020-08-21 15:32:43,339|Sending POST Request:
# |INFO|2020-08-21 15:32:43,340|URL: https://api-demo.fxcm.com:443/trading/update_subscriptions
# |INFO|2020-08-21 15:32:43,341|Payload: symbol=FAANG&visible=false
# |INFO|2020-08-21 15:32:43,342|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '26'}
# |INFO|2020-08-21 15:32:43,343|Params: {'symbol': 'FAANG', 'visible': 'false'}
# |INFO|2020-08-21 15:32:43,343|Proxies: {}
# |DEBUG|2020-08-21 15:32:43,344|Server answer: {'response': {'executed': True}}.
# |INFO|2020-08-21 15:32:43,344|In handle_request with method trading/update_subscriptions
# |INFO|2020-08-21 15:32:43,345|Connection status: True
# |INFO|2020-08-21 15:32:43,346|2. connection status: established
# |INFO|2020-08-21 15:32:43,347|Socket state: True
# |INFO|2020-08-21 15:32:43,348|Thread state: True
# |INFO|2020-08-21 15:32:43,348|Thread name: Thread-4
# |INFO|2020-08-21 15:32:43,349|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:43,350|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:43,350|Sending request to https://api-demo.fxcm.com/trading/update_subscriptions, parameter: {'symbol': 'CHN.TECH', 'visible': 'false'}.
# |DEBUG|2020-08-21 15:32:43,353|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:43,732|https://api-demo.fxcm.com:443 "POST /trading/update_subscriptions HTTP/1.1" 200 30
# |INFO|2020-08-21 15:32:43,735|Sending POST Request:
# |INFO|2020-08-21 15:32:43,736|URL: https://api-demo.fxcm.com:443/trading/update_subscriptions
# |INFO|2020-08-21 15:32:43,737|Payload: symbol=CHN.TECH&visible=false
# |INFO|2020-08-21 15:32:43,738|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '29'}
# |INFO|2020-08-21 15:32:43,739|Params: {'symbol': 'CHN.TECH', 'visible': 'false'}
# |INFO|2020-08-21 15:32:43,740|Proxies: {}
# |DEBUG|2020-08-21 15:32:43,741|Server answer: {'response': {'executed': True}}.
# |INFO|2020-08-21 15:32:43,741|In handle_request with method trading/update_subscriptions
# |INFO|2020-08-21 15:32:43,742|Connection status: True
# |INFO|2020-08-21 15:32:43,743|2. connection status: established
# |INFO|2020-08-21 15:32:43,743|Socket state: True
# |INFO|2020-08-21 15:32:43,744|Thread state: True
# |INFO|2020-08-21 15:32:43,745|Thread name: Thread-4
# |INFO|2020-08-21 15:32:43,745|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:43,746|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:43,746|Sending request to https://api-demo.fxcm.com/trading/update_subscriptions, parameter: {'symbol': 'CHN.ECOMM', 'visible': 'false'}.
# |DEBUG|2020-08-21 15:32:43,750|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:44,171|https://api-demo.fxcm.com:443 "POST /trading/update_subscriptions HTTP/1.1" 200 30
# |INFO|2020-08-21 15:32:44,174|Sending POST Request:
# |INFO|2020-08-21 15:32:44,176|URL: https://api-demo.fxcm.com:443/trading/update_subscriptions
# |INFO|2020-08-21 15:32:44,177|Payload: symbol=CHN.ECOMM&visible=false
# |INFO|2020-08-21 15:32:44,178|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '30'}
# |INFO|2020-08-21 15:32:44,179|Params: {'symbol': 'CHN.ECOMM', 'visible': 'false'}
# |INFO|2020-08-21 15:32:44,180|Proxies: {}
# |DEBUG|2020-08-21 15:32:44,180|Server answer: {'response': {'executed': True}}.
# |INFO|2020-08-21 15:32:44,181|In handle_request with method trading/update_subscriptions
# |INFO|2020-08-21 15:32:44,182|Connection status: True
# |INFO|2020-08-21 15:32:44,183|2. connection status: established
# |INFO|2020-08-21 15:32:44,183|Socket state: True
# |INFO|2020-08-21 15:32:44,183|Thread state: True
# |INFO|2020-08-21 15:32:44,184|Thread name: Thread-4
# |INFO|2020-08-21 15:32:44,185|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:44,186|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:44,186|Sending request to https://api-demo.fxcm.com/trading/update_subscriptions, parameter: {'symbol': 'USEquities', 'visible': 'false'}.
# |DEBUG|2020-08-21 15:32:44,189|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:44,504|https://api-demo.fxcm.com:443 "POST /trading/update_subscriptions HTTP/1.1" 200 30
# |INFO|2020-08-21 15:32:44,509|Sending POST Request:
# |INFO|2020-08-21 15:32:44,510|URL: https://api-demo.fxcm.com:443/trading/update_subscriptions
# |INFO|2020-08-21 15:32:44,512|Payload: symbol=USEquities&visible=false
# |INFO|2020-08-21 15:32:44,512|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '31'}
# |INFO|2020-08-21 15:32:44,513|Params: {'symbol': 'USEquities', 'visible': 'false'}
# |INFO|2020-08-21 15:32:44,514|Proxies: {}
# |DEBUG|2020-08-21 15:32:44,515|Server answer: {'response': {'executed': True}}.
# |INFO|2020-08-21 15:32:44,515|In handle_request with method trading/get_model
# |INFO|2020-08-21 15:32:44,516|Connection status: True
# |INFO|2020-08-21 15:32:44,518|2. connection status: established
# |INFO|2020-08-21 15:32:44,520|Socket state: True
# |INFO|2020-08-21 15:32:44,522|Thread state: True
# |INFO|2020-08-21 15:32:44,523|Thread name: Thread-4
# |INFO|2020-08-21 15:32:44,524|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:44,525|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:44,526|Sending request to https://api-demo.fxcm.com/trading/get_model, parameter: {'models': ['OpenPosition']}.
# |DEBUG|2020-08-21 15:32:44,530|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:44,687|https://api-demo.fxcm.com:443 "GET /trading/get_model?models=OpenPosition HTTP/1.1" 200 1962
# |INFO|2020-08-21 15:32:44,692|Sending GET Request:
# |INFO|2020-08-21 15:32:44,693|URL: https://api-demo.fxcm.com:443/trading/get_model?models=OpenPosition
# |INFO|2020-08-21 15:32:44,695|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded'}
# |INFO|2020-08-21 15:32:44,696|Params: {'models': ['OpenPosition']}
# |INFO|2020-08-21 15:32:44,697|Proxies: {}
# |DEBUG|2020-08-21 15:32:44,698|Server answer: {'response': {'executed': True}, 'open_positions': [{'t': 1, 'ratePrecision': 5, 'tradeId': '168799372', 'accountName': '01215060', 'accountId': '1215060', 'roll': 2.99, 'com': 0, 'open': 1.16091, 'valueDate': '', 'grossPL': -131.17106, 'close': 1.17808, 'visiblePL': -171.7, 'isDisabled': False, 'currency': 'EUR/USD', 'isBuy': False, 'amountK': 9, 'currencyPoint': 0.764, 'time': '07242020121045', 'usedMargin': 149.85, 'OpenOrderRequestTXT': None, 'stop': 0, 'stopMove': 0, 'limit': 1.15802}, {'t': 1, 'ratePrecision': 5, 'tradeId': '168798474', 'accountName': '01215060', 'accountId': '1215060', 'roll': 2.99, 'com': 0, 'open': 1.15858, 'valueDate': '', 'grossPL': -148.97121, 'close': 1.17808, 'visiblePL': -195, 'isDisabled': False, 'currency': 'EUR/USD', 'isBuy': False, 'amountK': 9, 'currencyPoint': 0.764, 'time': '07242020110536', 'usedMargin': 149.85, 'OpenOrderRequestTXT': None, 'stop': 0, 'stopMove': 0, 'limit': 1.15802}, {'t': 1, 'ratePrecision': 5, 'tradeId': '168787611', 'accountName': '01215060', 'accountId': '1215060', 'roll': 3.1, 'com': 0, 'open': 1.15885, 'valueDate': '', 'grossPL': -146.90853, 'close': 1.17808, 'visiblePL': -192.3, 'isDisabled': False, 'currency': 'EUR/USD', 'isBuy': False, 'amountK': 9, 'currencyPoint': 0.764, 'time': '07232020151306', 'usedMargin': 149.85, 'OpenOrderRequestTXT': None, 'stop': 0, 'stopMove': 0, 'limit': 1.15765}, {'t': 1, 'ratePrecision': 5, 'tradeId': '168799387', 'accountName': '01215060', 'accountId': '1215060', 'roll': 0.33, 'com': 0, 'open': 8.8466, 'valueDate': '', 'grossPL': -20.51307, 'close': 8.79347, 'visiblePL': -531.3, 'isDisabled': False, 'currency': 'USD/SEK', 'isBuy': True, 'amountK': 4, 'currencyPoint': 0.03861, 'time': '07242020121139', 'usedMargin': 100, 'OpenOrderRequestTXT': None, 'stop': 0, 'stopMove': 0, 'limit': 8.86911}, {'t': 1, 'ratePrecision': 5, 'tradeId': '168799383', 'accountName': '01215060', 'accountId': '1215060', 'roll': 0.29, 'com': 0, 'open': 9.21447, 'valueDate': '', 'grossPL': -73.05297, 'close': 9.02037, 'visiblePL': -1941, 'isDisabled': False, 'currency': 'USD/NOK', 'isBuy': True, 'amountK': 4, 'currencyPoint': 0.03764, 'time': '07242020121128', 'usedMargin': 100, 'OpenOrderRequestTXT': None, 'stop': 0, 'stopMove': 0, 'limit': 9.23473}, {'t': 1, 'ratePrecision': 5, 'tradeId': '168798483', 'accountName': '01215060', 'accountId': '1215060', 'roll': 2.99, 'com': 0, 'open': 1.1586, 'valueDate': '', 'grossPL': -148.81842, 'close': 1.17808, 'visiblePL': -194.8, 'isDisabled': False, 'currency': 'EUR/USD', 'isBuy': False, 'amountK': 9, 'currencyPoint': 0.764, 'time': '07242020110618', 'usedMargin': 149.85, 'OpenOrderRequestTXT': None, 'stop': 0, 'stopMove': 0, 'limit': 1.15802}, {'t': 1, 'ratePrecision': 5, 'tradeId': '168799377', 'accountName': '01215060', 'accountId': '1215060', 'roll': 2.99, 'com': 0, 'open': 1.16091, 'valueDate': '', 'grossPL': -131.17106, 'close': 1.17808, 'visiblePL': -171.7, 'isDisabled': False, 'currency': 'EUR/USD', 'isBuy': False, 'amountK': 9, 'currencyPoint': 0.764, 'time': '07242020121106', 'usedMargin': 149.85, 'OpenOrderRequestTXT': None, 'stop': 0, 'stopMove': 0, 'limit': 1.15802}, {'t': 1, 'ratePrecision': 5, 'tradeId': '168799405', 'accountName': '01215060', 'accountId': '1215060', 'roll': 2.99, 'com': 0, 'open': 1.16104, 'valueDate': '', 'grossPL': -130.17792, 'close': 1.17808, 'visiblePL': -170.4, 'isDisabled': False, 'currency': 'EUR/USD', 'isBuy': False, 'amountK': 9, 'currencyPoint': 0.764, 'time': '07242020121240', 'usedMargin': 149.85, 'OpenOrderRequestTXT': None, 'stop': 0, 'stopMove': 0, 'limit': 1.15802}, {'t': 1, 'ratePrecision': 5, 'tradeId': '168777898', 'accountName': '01215060', 'accountId': '1215060', 'roll': 4.27, 'com': 0, 'open': 0.92978, 'valueDate': '', 'grossPL': -181.19381, 'close': 0.91208, 'visiblePL': -177, 'isDisabled': False, 'currency': 'USD/CHF', 'isBuy': True, 'amountK': 11, 'currencyPoint': 1.02369, 'time': '07222020233633', 'usedMargin':  ...
# |INFO|2020-08-21 15:32:44,702|In handle_request with method trading/get_model
# |INFO|2020-08-21 15:32:44,703|Connection status: True
# |INFO|2020-08-21 15:32:44,704|2. connection status: established
# |INFO|2020-08-21 15:32:44,704|Socket state: True
# |INFO|2020-08-21 15:32:44,705|Thread state: True
# |INFO|2020-08-21 15:32:44,705|Thread name: Thread-4
# |INFO|2020-08-21 15:32:44,706|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:44,707|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:44,707|Sending request to https://api-demo.fxcm.com/trading/get_model, parameter: {'models': ['ClosedPosition']}.
# |DEBUG|2020-08-21 15:32:44,711|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:45,239|https://api-demo.fxcm.com:443 "GET /trading/get_model?models=ClosedPosition HTTP/1.1" 200 None
# |INFO|2020-08-21 15:32:45,243|Sending GET Request:
# |INFO|2020-08-21 15:32:45,244|URL: https://api-demo.fxcm.com:443/trading/get_model?models=ClosedPosition
# |INFO|2020-08-21 15:32:45,245|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded'}
# |INFO|2020-08-21 15:32:45,246|Params: {'models': ['ClosedPosition']}
# |INFO|2020-08-21 15:32:45,247|Proxies: {}
# |DEBUG|2020-08-21 15:32:45,247|Server answer: {'response': {'executed': True}, 'closed_positions': [{'t': 2, 'ratePrecision': 0, 'tradeId': '', 'accountName': '', 'roll': 0, 'com': 0, 'open': 0, 'valueDate': '', 'grossPL': 0, 'close': 0, 'visiblePL': 0, 'currency': '', 'isBuy': False, 'amountK': 0, 'currencyPoint': 0, 'openTime': None, 'closeTime': None, 'isTotal': True}]}.
# |DEBUG|2020-08-21 15:32:45,248|Fetching available instruments
# |DEBUG|2020-08-21 15:32:45,248|Fetching instruments table.
# |INFO|2020-08-21 15:32:45,248|In handle_request with method trading/get_instruments
# |INFO|2020-08-21 15:32:45,249|Connection status: True
# |INFO|2020-08-21 15:32:45,249|2. connection status: established
# |INFO|2020-08-21 15:32:45,250|Socket state: True
# |INFO|2020-08-21 15:32:45,250|Thread state: True
# |INFO|2020-08-21 15:32:45,252|Thread name: Thread-4
# |INFO|2020-08-21 15:32:45,253|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:45,253|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:45,254|Sending request to https://api-demo.fxcm.com/trading/get_instruments, parameter: {}.
# |DEBUG|2020-08-21 15:32:45,257|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:45,678|https://api-demo.fxcm.com:443 "GET /trading/get_instruments HTTP/1.1" 200 725
# |INFO|2020-08-21 15:32:45,682|Sending GET Request:
# |INFO|2020-08-21 15:32:45,683|URL: https://api-demo.fxcm.com:443/trading/get_instruments
# |INFO|2020-08-21 15:32:45,684|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded'}
# |INFO|2020-08-21 15:32:45,684|Params: {}
# |INFO|2020-08-21 15:32:45,685|Proxies: {}
# |DEBUG|2020-08-21 15:32:45,686|Server answer: {'response': {'executed': True}, 'data': {'instrument': [{'symbol': 'EUR/USD', 'visible': True, 'order': 100}, {'symbol': 'USD/JPY', 'visible': True, 'order': 950}, {'symbol': 'GBP/USD', 'visible': True, 'order': 250}, {'symbol': 'USD/CHF', 'visible': True, 'order': 1250}, {'symbol': 'EUR/CHF', 'visible': False, 'order': 1450}, {'symbol': 'AUD/USD', 'visible': True, 'order': 1350}, {'symbol': 'USD/CAD', 'visible': True, 'order': 1750}, {'symbol': 'NZD/USD', 'visible': True, 'order': 1650}, {'symbol': 'EUR/GBP', 'visible': False, 'order': 1550}, {'symbol': 'EUR/JPY', 'visible': False, 'order': 850}, {'symbol': 'GBP/JPY', 'visible': False, 'order': 1050}, {'symbol': 'CHF/JPY', 'visible': False, 'order': 1200}, {'symbol': 'GBP/CHF', 'visible': False, 'order': 1300}, {'symbol': 'EUR/AUD', 'visible': False, 'order': 1400}, {'symbol': 'EUR/CAD', 'visible': False, 'order': 1500}, {'symbol': 'AUD/CAD', 'visible': False, 'order': 1600}, {'symbol': 'AUD/JPY', 'visible': False, 'order': 1150}, {'symbol': 'CAD/JPY', 'visible': False, 'order': 1800}, {'symbol': 'NZD/JPY', 'visible': False, 'order': 1900}, {'symbol': 'GBP/CAD', 'visible': False, 'order': 2000}, {'symbol': 'GBP/NZD', 'visible': False, 'order': 2100}, {'symbol': 'GBP/AUD', 'visible': False, 'order': 1850}, {'symbol': 'AUD/NZD', 'visible': False, 'order': 2800}, {'symbol': 'USD/SEK', 'visible': True, 'order': 3000}, {'symbol': 'EUR/SEK', 'visible': False, 'order': 3200}, {'symbol': 'EUR/NOK', 'visible': False, 'order': 3600}, {'symbol': 'USD/NOK', 'visible': True, 'order': 3700}, {'symbol': 'USD/MXN', 'visible': True, 'order': 3800}, {'symbol': 'AUD/CHF', 'visible': False, 'order': 3900}, {'symbol': 'EUR/NZD', 'visible': False, 'order': 4000}, {'symbol': 'USD/ZAR', 'visible': True, 'order': 4700}, {'symbol': 'USD/HKD', 'visible': False, 'order': 5000}, {'symbol': 'ZAR/JPY', 'visible': False, 'order': 7100}, {'symbol': 'USD/TRY', 'visible': False, 'order': 8300}, {'symbol': 'EUR/TRY', 'visible': False, 'order': 8700}, {'symbol': 'NZD/CHF', 'visible': False, 'order': 8900}, {'symbol': 'CAD/CHF', 'visible': False, 'order': 9000}, {'symbol': 'NZD/CAD', 'visible': False, 'order': 9100}, {'symbol': 'TRY/JPY', 'visible': False, 'order': 9800}, {'symbol': 'USD/ILS', 'visible': True, 'order': 10000}, {'symbol': 'USD/CNH', 'visible': True, 'order': 799}, {'symbol': 'AUS200', 'visible': False, 'order': 100100}, {'symbol': 'ESP35', 'visible': False, 'order': 100200}, {'symbol': 'FRA40', 'visible': False, 'order': 750}, {'symbol': 'GER30', 'visible': False, 'order': 650}, {'symbol': 'HKG33', 'visible': False, 'order': 100500}, {'symbol': 'JPN225', 'visible': False, 'order': 100700}, {'symbol': 'NAS100', 'visible': False, 'order': 100800}, {'symbol': 'SPX500', 'visible': True, 'order': 101000}, {'symbol': 'UK100', 'visible': False, 'order': 350}, {'symbol': 'US30', 'visible': False, 'order': 1950}, {'symbol': 'Copper', 'visible': False, 'order': 101600}, {'symbol': 'CHN50', 'visible': False, 'order': 1020}, {'symbol': 'EUSTX50', 'visible': False, 'order': 103500}, {'symbol': 'USDOLLAR', 'visible': False, 'order': 450}, {'symbol': 'US2000', 'visible': True, 'order': 1060}, {'symbol': 'USOil', 'visible': False, 'order': 200100}, {'symbol': 'UKOil', 'visible': False, 'order': 200200}, {'symbol': 'SOYF', 'visible': False, 'order': 2003}, {'symbol': 'NGAS', 'visible': False, 'order': 201500}, {'symbol': 'USOilSpot', 'visible': True, 'order': 2018}, {'symbol': 'UKOilSpot', 'visible': True, 'order': 2019}, {'symbol': 'WHEATF', 'visible': True, 'order': 2020}, {'symbol': 'CORNF', 'visible': True, 'order': 2021}, {'symbol': 'Bund', 'visible': False, 'order': 300100}, {'symbol': 'XAU/USD', 'visible': False, 'order': 150}, {'symbol': 'XAG/USD', 'visible': False, 'order': 550}, {'symbol': 'EMBasket', 'visible': True, 'order': 6001}, {'symbol': 'JPYBasket', 'visible': True, 'order': 6002}, {'symbol': 'BTC/USD', 'visible': True, 'order': 8001}, {'symbol': 'BC ...
# |INFO|2020-08-21 15:32:45,686|Try to subscribe for Order.
# |INFO|2020-08-21 15:32:45,687|In handle_request with method trading/subscribe
# |INFO|2020-08-21 15:32:45,687|Connection status: True
# |INFO|2020-08-21 15:32:45,688|2. connection status: established
# |INFO|2020-08-21 15:32:45,688|Socket state: True
# |INFO|2020-08-21 15:32:45,689|Thread state: True
# |INFO|2020-08-21 15:32:45,689|Thread name: Thread-4
# |INFO|2020-08-21 15:32:45,690|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:45,690|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:45,690|Sending request to https://api-demo.fxcm.com/trading/subscribe, parameter: {'models': 'Order'}.
# |DEBUG|2020-08-21 15:32:45,695|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:45,899|https://api-demo.fxcm.com:443 "POST /trading/subscribe HTTP/1.1" 200 30
# |INFO|2020-08-21 15:32:45,904|Sending POST Request:
# |INFO|2020-08-21 15:32:45,904|URL: https://api-demo.fxcm.com:443/trading/subscribe
# |INFO|2020-08-21 15:32:45,906|Payload: models=Order
# |INFO|2020-08-21 15:32:45,907|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '12'}
# |INFO|2020-08-21 15:32:45,907|Params: {'models': 'Order'}
# |INFO|2020-08-21 15:32:45,908|Proxies: {}
# |DEBUG|2020-08-21 15:32:45,909|Server answer: {'response': {'executed': True}}.
# |INFO|2020-08-21 15:32:45,910|Try to subscribe for OpenPosition.
# |INFO|2020-08-21 15:32:45,910|In handle_request with method trading/subscribe
# |INFO|2020-08-21 15:32:45,911|Connection status: True
# |INFO|2020-08-21 15:32:45,911|2. connection status: established
# |INFO|2020-08-21 15:32:45,912|Socket state: True
# |INFO|2020-08-21 15:32:45,913|Thread state: True
# |INFO|2020-08-21 15:32:45,913|Thread name: Thread-4
# |INFO|2020-08-21 15:32:45,914|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:45,914|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:45,915|Sending request to https://api-demo.fxcm.com/trading/subscribe, parameter: {'models': 'OpenPosition'}.
# |DEBUG|2020-08-21 15:32:45,918|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:46,320|https://api-demo.fxcm.com:443 "POST /trading/subscribe HTTP/1.1" 200 30
# |INFO|2020-08-21 15:32:46,323|Sending POST Request:
# |INFO|2020-08-21 15:32:46,324|URL: https://api-demo.fxcm.com:443/trading/subscribe
# |INFO|2020-08-21 15:32:46,326|Payload: models=OpenPosition
# |INFO|2020-08-21 15:32:46,326|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '19'}
# |INFO|2020-08-21 15:32:46,327|Params: {'models': 'OpenPosition'}
# |INFO|2020-08-21 15:32:46,328|Proxies: {}
# |DEBUG|2020-08-21 15:32:46,329|Server answer: {'response': {'executed': True}}.
# |INFO|2020-08-21 15:32:46,329|Try to subscribe for ClosedPosition.
# |INFO|2020-08-21 15:32:46,330|In handle_request with method trading/subscribe
# |INFO|2020-08-21 15:32:46,331|Connection status: True
# |INFO|2020-08-21 15:32:46,332|2. connection status: established
# |INFO|2020-08-21 15:32:46,332|Socket state: True
# |INFO|2020-08-21 15:32:46,333|Thread state: True
# |INFO|2020-08-21 15:32:46,333|Thread name: Thread-4
# |INFO|2020-08-21 15:32:46,334|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:46,334|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:46,335|Sending request to https://api-demo.fxcm.com/trading/subscribe, parameter: {'models': 'ClosedPosition'}.
# |DEBUG|2020-08-21 15:32:46,338|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:46,364|Update data without action:
# |DEBUG|2020-08-21 15:32:46,365|{'t': 1, 'grossPL': -13.6798, 'close': 1.32167, 'visiblePL': -21.3, 'stop': 0, 'limit': 1.3369, 'tradeId': '169136852'}
# |DEBUG|2020-08-21 15:32:46,366|Update data without action:
# |DEBUG|2020-08-21 15:32:46,367|Update data without action:
# |DEBUG|2020-08-21 15:32:46,369|Update data without action:
# |DEBUG|2020-08-21 15:32:46,369|{'t': 1, 'grossPL': -180.98992, 'close': 0.9121, 'visiblePL': -176.8, 'stop': 0, 'limit': 0.93071, 'tradeId': '168777898'}
# |DEBUG|2020-08-21 15:32:46,370|Update data without action:
# |DEBUG|2020-08-21 15:32:46,371|{'t': 1, 'grossPL': -178.84015, 'close': 0.9121, 'visiblePL': -174.7, 'stop': 0, 'limit': 0.9305, 'tradeId': '168777799'}
# |DEBUG|2020-08-21 15:32:46,372|Update data without action:
# |DEBUG|2020-08-21 15:32:46,373|{'t': 1, 'grossPL': -175.97379, 'close': 0.9121, 'visiblePL': -171.9, 'stop': 0, 'limit': 0.93023, 'tradeId': '168777695'}
# |DEBUG|2020-08-21 15:32:46,375|Update data without action:
# |DEBUG|2020-08-21 15:32:46,375|{'t': 1, 'grossPL': -179.65911, 'close': 0.9121, 'visiblePL': -175.5, 'stop': 0, 'limit': 0.93058, 'tradeId': '168777836'}
# |DEBUG|2020-08-21 15:32:46,376|Update data without action:
# |DEBUG|2020-08-21 15:32:46,377|Update data without action:
# |DEBUG|2020-08-21 15:32:46,377|Update data without action:
# |DEBUG|2020-08-21 15:32:46,378|{'t': 1, 'grossPL': -13.80825, 'close': 1.32165, 'visiblePL': -21.5, 'stop': 0, 'limit': 1.3369, 'tradeId': '169136852'}
# |DEBUG|2020-08-21 15:32:46,379|Update data without action:
# |DEBUG|2020-08-21 15:32:46,380|Update data without action:
# |DEBUG|2020-08-21 15:32:46,381|Update data without action:
# |DEBUG|2020-08-21 15:32:46,382|{'t': 1, 'grossPL': -72.98899, 'close': 9.02054, 'visiblePL': -1939.3, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799383'}
# |DEBUG|2020-08-21 15:32:46,382|Update data without action:
# |DEBUG|2020-08-21 15:32:46,383|Update data without action:
# |DEBUG|2020-08-21 15:32:46,384|Update data without action:
# |DEBUG|2020-08-21 15:32:46,386|Update data without action:
# |DEBUG|2020-08-21 15:32:46,386|Update data without action:
# |DEBUG|2020-08-21 15:32:46,386|{'t': 1, 'grossPL': -78.34846, 'close': 9.02054, 'visiblePL': -2081.7, 'stop': 0, 'limit': 9.23473, 'tradeId': '168798796'}
# |DEBUG|2020-08-21 15:32:46,387|Update data without action:
# |DEBUG|2020-08-21 15:32:46,388|{'t': 1, 'grossPL': -73.87721, 'close': 9.02054, 'visiblePL': -1962.9, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799709'}
# |DEBUG|2020-08-21 15:32:46,388|{'t': 1, 'grossPL': -79.62435, 'close': 9.02054, 'visiblePL': -2115.6, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799066'}
# |DEBUG|2020-08-21 15:32:46,391|{'t': 1, 'grossPL': -20.49737, 'close': 8.79351, 'visiblePL': -530.9, 'stop': 0, 'limit': 8.86911, 'tradeId': '168799387'}
# |DEBUG|2020-08-21 15:32:46,392|{'t': 1, 'grossPL': -27.98746, 'close': 8.79351, 'visiblePL': -724.9, 'stop': 0, 'limit': 8.86911, 'tradeId': '168798512'}
# |DEBUG|2020-08-21 15:32:46,392|{'t': 1, 'grossPL': -26.86781, 'close': 8.79351, 'visiblePL': -695.9, 'stop': 0, 'limit': 8.86911, 'tradeId': '168798799'}
# |DEBUG|2020-08-21 15:32:46,394|{'t': 1, 'grossPL': -21.88728, 'close': 8.79351, 'visiblePL': -566.9, 'stop': 0, 'limit': 8.86911, 'tradeId': '168799711'}
# |DEBUG|2020-08-21 15:32:46,394|{'t': 1, 'grossPL': -26.25007, 'close': 8.79351, 'visiblePL': -679.9, 'stop': 0, 'limit': 8.86911, 'tradeId': '168799070'}
# |DEBUG|2020-08-21 15:32:46,395|{'t': 1, 'grossPL': -180.98655, 'close': 0.9121, 'visiblePL': -176.8, 'stop': 0, 'limit': 0.93071, 'tradeId': '168777898'}
# |DEBUG|2020-08-21 15:32:46,396|{'t': 1, 'grossPL': -178.83682, 'close': 0.9121, 'visiblePL': -174.7, 'stop': 0, 'limit': 0.9305, 'tradeId': '168777799'}
# |DEBUG|2020-08-21 15:32:46,396|{'t': 1, 'grossPL': -175.97052, 'close': 0.9121, 'visiblePL': -171.9, 'stop': 0, 'limit': 0.93023, 'tradeId': '168777695'}
# |DEBUG|2020-08-21 15:32:46,398|{'t': 1, 'grossPL': -179.65576, 'close': 0.9121, 'visiblePL': -175.5, 'stop': 0, 'limit': 0.93058, 'tradeId': '168777836'}
# |DEBUG|2020-08-21 15:32:46,606|https://api-demo.fxcm.com:443 "POST /trading/subscribe HTTP/1.1" 200 30
# |INFO|2020-08-21 15:32:46,610|Sending POST Request:
# |INFO|2020-08-21 15:32:46,611|URL: https://api-demo.fxcm.com:443/trading/subscribe
# |INFO|2020-08-21 15:32:46,611|Payload: models=ClosedPosition
# |INFO|2020-08-21 15:32:46,612|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '21'}
# |INFO|2020-08-21 15:32:46,612|Params: {'models': 'ClosedPosition'}
# |INFO|2020-08-21 15:32:46,613|Proxies: {}
# |DEBUG|2020-08-21 15:32:46,614|Server answer: {'response': {'executed': True}}.

# %%
ticker = 'GBP/CAD'
_mise = 1
_target = 0.003
_sl = 0.0015

for i in range(50):
    print('\nLoop:',i,'\n')
    con.subscribe_market_data(ticker)
    p0os = con.create_entry_order(symbol=ticker,\
                    is_buy=True,\
                        amount=_mise,\
                        time_in_force='GTD',\
                            order_type='Entry',\
                            rate=round(float(con.get_last_price(ticker).Ask * 1.0001),4),\
                                is_in_pips=False,\
                                    limit=round(float(con.get_last_price(ticker).Ask * (1 + _target)),4) ,\
                                        stop=round(float(con.get_last_price(ticker).Ask * (1 - _sl)),4),\
                                            trailing_step=None,\
                                                expiration = (dt.datetime.now() + dt.timedelta(minutes=10)).strftime(format='%Y-%m-%d %H:%M'))

    time.sleep(5)
    con.unsubscribe_market_data(ticker)
# Out:
# |INFO|2020-08-21 15:32:46,626|Try to subscribe for GBP/CAD.
# |INFO|2020-08-21 15:32:46,627|In handle_request with method subscribe
# |INFO|2020-08-21 15:32:46,628|Connection status: True
# |INFO|2020-08-21 15:32:46,629|2. connection status: established
# |INFO|2020-08-21 15:32:46,631|Socket state: True
# |INFO|2020-08-21 15:32:46,632|Thread state: True
# |INFO|2020-08-21 15:32:46,632|Thread name: Thread-4
# |INFO|2020-08-21 15:32:46,633|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:46,634|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:46,634|Sending request to https://api-demo.fxcm.com/subscribe, parameter: {'pairs': 'GBP/CAD'}.
# |DEBUG|2020-08-21 15:32:46,639|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:46,731|Update data without action:
# |DEBUG|2020-08-21 15:32:46,733|Update data without action:
# |DEBUG|2020-08-21 15:32:46,746|{'t': 1, 'grossPL': -148.82094, 'close': 1.17806, 'visiblePL': -194.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798474'}
# |DEBUG|2020-08-21 15:32:46,734|Update data without action:
# |DEBUG|2020-08-21 15:32:46,735|Update data without action:
# |DEBUG|2020-08-21 15:32:46,740|Update data without action:
# |DEBUG|2020-08-21 15:32:46,744|Update data without action:
# |DEBUG|2020-08-21 15:32:46,746|Update data without action:
# |DEBUG|2020-08-21 15:32:46,734|{'t': 1, 'grossPL': -131.02049, 'close': 1.17806, 'visiblePL': -171.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799372'}
# |DEBUG|2020-08-21 15:32:46,749|Update data without action:
# |DEBUG|2020-08-21 15:32:46,751|Update data without action:
# |DEBUG|2020-08-21 15:32:46,752|Update data without action:
# |DEBUG|2020-08-21 15:32:46,752|{'t': 1, 'grossPL': -146.75823, 'close': 1.17806, 'visiblePL': -192.1, 'stop': 0, 'limit': 1.15765, 'tradeId': '168787611'}
# |DEBUG|2020-08-21 15:32:46,753|Update data without action:
# |DEBUG|2020-08-21 15:32:46,753|Update data without action:
# |DEBUG|2020-08-21 15:32:46,754|Update data without action:
# |DEBUG|2020-08-21 15:32:46,754|{'t': 1, 'grossPL': -148.66815, 'close': 1.17806, 'visiblePL': -194.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798483'}
# |DEBUG|2020-08-21 15:32:46,755|Update data without action:
# |DEBUG|2020-08-21 15:32:46,756|{'t': 1, 'grossPL': -131.02049, 'close': 1.17806, 'visiblePL': -171.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799377'}
# |DEBUG|2020-08-21 15:32:46,756|Update data without action:
# |DEBUG|2020-08-21 15:32:46,757|Update data without action:
# |DEBUG|2020-08-21 15:32:46,757|{'t': 1, 'grossPL': -130.02733, 'close': 1.17806, 'visiblePL': -170.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799405'}
# |DEBUG|2020-08-21 15:32:46,758|Update data without action:
# |DEBUG|2020-08-21 15:32:46,759|{'t': 1, 'grossPL': -130.94409, 'close': 1.17806, 'visiblePL': -171.4, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799399'}
# |DEBUG|2020-08-21 15:32:46,759|Update data without action:
# |DEBUG|2020-08-21 15:32:46,760|Update data without action:
# |DEBUG|2020-08-21 15:32:46,761|Update data without action:
# |DEBUG|2020-08-21 15:32:46,762|{'t': 1, 'grossPL': -130.63851, 'close': 1.17806, 'visiblePL': -171, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799393'}
# |DEBUG|2020-08-21 15:32:46,762|Update data without action:
# |DEBUG|2020-08-21 15:32:46,763|Update data without action:
# |DEBUG|2020-08-21 15:32:46,763|{'t': 1, 'grossPL': -147.4458, 'close': 1.17806, 'visiblePL': -193, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798781'}
# |DEBUG|2020-08-21 15:32:46,764|Update data without action:
# |DEBUG|2020-08-21 15:32:46,765|{'t': 1, 'grossPL': -148.97374, 'close': 1.17806, 'visiblePL': -195, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798521'}
# |DEBUG|2020-08-21 15:32:46,765|Update data without action:
# |DEBUG|2020-08-21 15:32:46,766|Update data without action:
# |DEBUG|2020-08-21 15:32:46,768|Update data without action:
# |DEBUG|2020-08-21 15:32:46,769|{'t': 1, 'grossPL': -131.09689, 'close': 1.17806, 'visiblePL': -171.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799417'}
# |DEBUG|2020-08-21 15:32:46,770|Update data without action:
# |DEBUG|2020-08-21 15:32:46,816|{'t': 1, 'grossPL': -133.54159, 'close': 1.17806, 'visiblePL': -174.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799725'}
# |DEBUG|2020-08-21 15:32:46,772|Update data without action:
# |DEBUG|2020-08-21 15:32:46,772|{'t': 1, 'grossPL': -147.75139, 'close': 1.17806, 'visiblePL': -193.4, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798261'}
# |DEBUG|2020-08-21 15:32:46,773|Update data without action:
# |DEBUG|2020-08-21 15:32:46,774|Update data without action:
# |DEBUG|2020-08-21 15:32:46,774|{'t': 1, 'grossPL': -130.48571, 'close': 1.17806, 'visiblePL': -170.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799410'}
#
# Loop: 0
#
# |DEBUG|2020-08-21 15:32:46,774|Update data without action:
# |DEBUG|2020-08-21 15:32:46,828|{'t': 1, 'grossPL': -142.55641, 'close': 1.17806, 'visiblePL': -186.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799073'}
# |DEBUG|2020-08-21 15:32:46,777|Update data without action:
# |DEBUG|2020-08-21 15:32:46,831|{'t': 1, 'grossPL': -133.1596, 'close': 1.17806, 'visiblePL': -174.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799735'}
# |DEBUG|2020-08-21 15:32:46,778|Update data without action:
# |DEBUG|2020-08-21 15:32:46,780|Update data without action:
# |DEBUG|2020-08-21 15:32:46,782|{'t': 1, 'grossPL': -142.7856, 'close': 1.17806, 'visiblePL': -186.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799049'}
# |DEBUG|2020-08-21 15:32:46,783|Update data without action:
# |DEBUG|2020-08-21 15:32:46,839|{'t': 1, 'grossPL': -13.80816, 'close': 1.32165, 'visiblePL': -21.5, 'stop': 0, 'limit': 1.3369, 'tradeId': '169136852'}
# |DEBUG|2020-08-21 15:32:46,785|Update data without action:
# |DEBUG|2020-08-21 15:32:46,787|Update data without action:
# |DEBUG|2020-08-21 15:32:46,787|Update data without action:
# |DEBUG|2020-08-21 15:32:46,788|{'t': 1, 'grossPL': -152.79358, 'close': 1.17806, 'visiblePL': -200, 'stop': 0, 'limit': 1.1569, 'tradeId': '168786497'}
# |DEBUG|2020-08-21 15:32:46,788|Update data without action:
# |DEBUG|2020-08-21 15:32:46,789|Update data without action:
# |DEBUG|2020-08-21 15:32:46,791|Update data without action:
# |DEBUG|2020-08-21 15:32:46,791|{'t': 1, 'grossPL': -147.21661, 'close': 1.17806, 'visiblePL': -192.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798272'}
# |DEBUG|2020-08-21 15:32:46,791|Update data without action:
# |DEBUG|2020-08-21 15:32:46,854|{'t': 1, 'grossPL': -27.98731, 'close': 8.79351, 'visiblePL': -724.9, 'stop': 0, 'limit': 8.86911, 'tradeId': '168798512'}
# |DEBUG|2020-08-21 15:32:46,793|Update data without action:
# |DEBUG|2020-08-21 15:32:46,793|{'t': 1, 'grossPL': -142.48001, 'close': 1.17806, 'visiblePL': -186.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799040'}
# |DEBUG|2020-08-21 15:32:46,794|Update data without action:
# |DEBUG|2020-08-21 15:32:46,796|{'t': 1, 'grossPL': -147.21661, 'close': 1.17806, 'visiblePL': -192.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798812'}
# |DEBUG|2020-08-21 15:32:46,796|Update data without action:
# |DEBUG|2020-08-21 15:32:46,797|Update data without action:
# |DEBUG|2020-08-21 15:32:46,799|Update data without action:
# |DEBUG|2020-08-21 15:32:46,801|Update data without action:
# |DEBUG|2020-08-21 15:32:46,802|{'t': 1, 'grossPL': -145.91786, 'close': 1.17806, 'visiblePL': -191, 'stop': 0, 'limit': 1.15781, 'tradeId': '168787029'}
# |DEBUG|2020-08-21 15:32:46,804|{'t': 1, 'grossPL': -132.01365, 'close': 1.17806, 'visiblePL': -172.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799700'}
# |DEBUG|2020-08-21 15:32:46,807|{'t': 1, 'grossPL': -146.07066, 'close': 1.17806, 'visiblePL': -191.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798291'}
# |DEBUG|2020-08-21 15:32:46,811|{'t': 1, 'grossPL': -146.22345, 'close': 1.17806, 'visiblePL': -191.4, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798803'}
# |DEBUG|2020-08-21 15:32:46,812|{'t': 1, 'grossPL': -131.32608, 'close': 1.17806, 'visiblePL': -171.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799696'}
# |DEBUG|2020-08-21 15:32:46,814|{'t': 1, 'grossPL': -142.86199, 'close': 1.17806, 'visiblePL': -187, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799085'}
# |DEBUG|2020-08-21 15:32:46,771|Update data without action:
# |DEBUG|2020-08-21 15:32:46,820|{'t': 1, 'grossPL': -132.31924, 'close': 1.17806, 'visiblePL': -173.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799715'}
# |DEBUG|2020-08-21 15:32:46,823|{'t': 1, 'grossPL': -175.9418, 'close': 1.17806, 'visiblePL': -230.3, 'stop': 0, 'limit': 1.15388, 'tradeId': '168785506'}
# |DEBUG|2020-08-21 15:32:46,824|{'t': 1, 'grossPL': -147.06382, 'close': 1.17806, 'visiblePL': -192.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798817'}
# |DEBUG|2020-08-21 15:32:46,775|Update data without action:
# |DEBUG|2020-08-21 15:32:46,874|{'t': 1, 'grossPL': -141.33406, 'close': 1.17806, 'visiblePL': -185, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799099'}
# |DEBUG|2020-08-21 15:32:46,834|{'t': 1, 'grossPL': -142.6328, 'close': 1.17806, 'visiblePL': -186.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799090'}
# |DEBUG|2020-08-21 15:32:46,835|{'t': 1, 'grossPL': -132.85401, 'close': 1.17806, 'visiblePL': -173.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799730'}
# |DEBUG|2020-08-21 15:32:46,784|{'t': 1, 'grossPL': -147.5222, 'close': 1.17806, 'visiblePL': -193.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798788'}
# |DEBUG|2020-08-21 15:32:46,842|{'t': 1, 'grossPL': -13.80816, 'close': 1.32165, 'visiblePL': -21.5, 'stop': 0, 'limit': 1.3369, 'tradeId': '169136852'}
# |DEBUG|2020-08-21 15:32:46,843|{'t': 1, 'grossPL': -72.93253, 'close': 9.02069, 'visiblePL': -1937.8, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799383'}
# |DEBUG|2020-08-21 15:32:46,845|https://api-demo.fxcm.com:443 "POST /subscribe HTTP/1.1" 200 None
# |DEBUG|2020-08-21 15:32:46,846|{'t': 1, 'grossPL': -78.29201, 'close': 9.02069, 'visiblePL': -2080.2, 'stop': 0, 'limit': 9.23473, 'tradeId': '168798796'}
# |DEBUG|2020-08-21 15:32:46,848|{'t': 1, 'grossPL': -73.82076, 'close': 9.02069, 'visiblePL': -1961.4, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799709'}
# |DEBUG|2020-08-21 15:32:46,850|{'t': 1, 'grossPL': -79.56789, 'close': 9.02069, 'visiblePL': -2114.1, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799066'}
# |DEBUG|2020-08-21 15:32:46,851|{'t': 1, 'grossPL': -20.49726, 'close': 8.79351, 'visiblePL': -530.9, 'stop': 0, 'limit': 8.86911, 'tradeId': '168799387'}
# |DEBUG|2020-08-21 15:32:46,792|Update data without action:
# |DEBUG|2020-08-21 15:32:46,857|{'t': 1, 'grossPL': -21.88716, 'close': 8.79351, 'visiblePL': -566.9, 'stop': 0, 'limit': 8.86911, 'tradeId': '168799711'}
# |DEBUG|2020-08-21 15:32:46,860|{'t': 1, 'grossPL': -26.24993, 'close': 8.79351, 'visiblePL': -679.9, 'stop': 0, 'limit': 8.86911, 'tradeId': '168799070'}
# |DEBUG|2020-08-21 15:32:46,861|{'t': 1, 'grossPL': -180.98739, 'close': 0.9121, 'visiblePL': -176.8, 'stop': 0, 'limit': 0.93071, 'tradeId': '168777898'}
# |DEBUG|2020-08-21 15:32:46,862|{'t': 1, 'grossPL': -178.83765, 'close': 0.9121, 'visiblePL': -174.7, 'stop': 0, 'limit': 0.9305, 'tradeId': '168777799'}
# |DEBUG|2020-08-21 15:32:46,863|{'t': 1, 'grossPL': -175.97134, 'close': 0.9121, 'visiblePL': -171.9, 'stop': 0, 'limit': 0.93023, 'tradeId': '168777695'}
# |DEBUG|2020-08-21 15:32:46,864|{'t': 1, 'grossPL': -179.6566, 'close': 0.9121, 'visiblePL': -175.5, 'stop': 0, 'limit': 0.93058, 'tradeId': '168777836'}
# |DEBUG|2020-08-21 15:32:46,870|{'t': 1, 'grossPL': -132.24284, 'close': 1.17806, 'visiblePL': -173.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799721'}
# |DEBUG|2020-08-21 15:32:46,778|{'t': 1, 'grossPL': -149.12653, 'close': 1.17806, 'visiblePL': -195.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798539'}
# |INFO|2020-08-21 15:32:46,886|Sending POST Request:
# |INFO|2020-08-21 15:32:46,903|URL: https://api-demo.fxcm.com:443/subscribe
# |DEBUG|2020-08-21 15:32:46,891|{'t': 1, 'grossPL': -26.86766, 'close': 8.79351, 'visiblePL': -695.9, 'stop': 0, 'limit': 8.86911, 'tradeId': '168798799'}
# |INFO|2020-08-21 15:32:46,905|Payload: pairs=GBP%2FCAD
# |INFO|2020-08-21 15:32:46,908|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '15'}
# |INFO|2020-08-21 15:32:46,909|Params: {'pairs': 'GBP/CAD'}
# |INFO|2020-08-21 15:32:46,911|Proxies: {}
# |DEBUG|2020-08-21 15:32:46,912|Server answer: {'response': {'executed': True, 'error': ''}, 'pairs': [{'Updated': 1598016766161, 'Rates': [1.73117, 1.73149, 1.74509, 1.72887, 1.73117, 1.73149], 'Symbol': 'GBP/CAD'}]}.
# |INFO|2020-08-21 15:32:46,917|In handle_request with method trading/create_entry_order
# |INFO|2020-08-21 15:32:46,918|Connection status: True
# |INFO|2020-08-21 15:32:46,919|2. connection status: established
# |INFO|2020-08-21 15:32:46,920|Socket state: True
# |INFO|2020-08-21 15:32:46,920|Thread state: True
# |INFO|2020-08-21 15:32:46,921|Thread name: Thread-4
# |INFO|2020-08-21 15:32:46,922|Socket id: KzFiBwuTKcTxQuoPDTb7
# |INFO|2020-08-21 15:32:46,923|Created bearer token: Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a
# |INFO|2020-08-21 15:32:46,924|Sending request to https://api-demo.fxcm.com/trading/create_entry_order, parameter: {'account_id': 1215060, 'symbol': 'GBP/CAD', 'is_buy': 'true', 'rate': 1.7317, 'amount': 1, 'limit': 1.7367, 'order_type': 'Entry', 'is_in_pips': 'false', 'time_in_force': 'GTD', 'stop': 1.7289, 'expiration': '2020-08-21 15:42'}.
# |DEBUG|2020-08-21 15:32:46,929|Starting new HTTPS connection (1): api-demo.fxcm.com:443
# |DEBUG|2020-08-21 15:32:47,231|Update data without action:
# |DEBUG|2020-08-21 15:32:47,232|Update data without action:
# |DEBUG|2020-08-21 15:32:47,233|{'t': 1, 'grossPL': -131.09578, 'close': 1.17807, 'visiblePL': -171.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799372'}
# |DEBUG|2020-08-21 15:32:47,233|Update data without action:
# |DEBUG|2020-08-21 15:32:47,235|{'t': 1, 'grossPL': -148.89608, 'close': 1.17807, 'visiblePL': -194.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798474'}
# |DEBUG|2020-08-21 15:32:47,235|Update data without action:
# |DEBUG|2020-08-21 15:32:47,237|Update data without action:
# |DEBUG|2020-08-21 15:32:47,245|{'t': 1, 'grossPL': -131.09578, 'close': 1.17807, 'visiblePL': -171.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799377'}
# |DEBUG|2020-08-21 15:32:47,240|{'t': 1, 'grossPL': -146.83338, 'close': 1.17807, 'visiblePL': -192.2, 'stop': 0, 'limit': 1.15765, 'tradeId': '168787611'}
# |DEBUG|2020-08-21 15:32:47,240|Update data without action:
# |DEBUG|2020-08-21 15:32:47,241|Update data without action:
# |DEBUG|2020-08-21 15:32:47,242|Update data without action:
# |DEBUG|2020-08-21 15:32:47,243|{'t': 1, 'grossPL': -148.74328, 'close': 1.17807, 'visiblePL': -194.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798483'}
# |DEBUG|2020-08-21 15:32:47,244|Update data without action:
# |DEBUG|2020-08-21 15:32:47,259|{'t': 1, 'grossPL': -149.04887, 'close': 1.17807, 'visiblePL': -195.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798521'}
# |DEBUG|2020-08-21 15:32:47,238|Update data without action:
# |DEBUG|2020-08-21 15:32:47,265|{'t': 1, 'grossPL': -130.10263, 'close': 1.17807, 'visiblePL': -170.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799405'}
# |DEBUG|2020-08-21 15:32:47,248|Update data without action:
# |DEBUG|2020-08-21 15:32:47,250|Update data without action:
# |DEBUG|2020-08-21 15:32:47,250|https://api-demo.fxcm.com:443 "POST /trading/create_entry_order HTTP/1.1" 200 None
# |DEBUG|2020-08-21 15:32:47,251|{'t': 1, 'grossPL': -131.01938, 'close': 1.17807, 'visiblePL': -171.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799399'}
# |DEBUG|2020-08-21 15:32:47,251|Update data without action:
# |DEBUG|2020-08-21 15:32:47,283|{'t': 1, 'grossPL': -142.86078, 'close': 1.17807, 'visiblePL': -187, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799049'}
# |DEBUG|2020-08-21 15:32:47,253|Update data without action:
# |DEBUG|2020-08-21 15:32:47,254|Update data without action:
# |DEBUG|2020-08-21 15:32:47,254|{'t': 1, 'grossPL': -147.52095, 'close': 1.17807, 'visiblePL': -193.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798781'}
# |DEBUG|2020-08-21 15:32:47,256|Update data without action:
# |DEBUG|2020-08-21 15:32:47,257|Update data without action:
# |DEBUG|2020-08-21 15:32:47,258|Update data without action:
# |DEBUG|2020-08-21 15:32:47,245|Update data without action:
# |DEBUG|2020-08-21 15:32:47,301|{'t': 1, 'grossPL': -131.17217, 'close': 1.17807, 'visiblePL': -171.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799417'}
# |DEBUG|2020-08-21 15:32:47,261|Update data without action:
# |DEBUG|2020-08-21 15:32:47,263|Update data without action:
# |DEBUG|2020-08-21 15:32:47,311|{'t': 1, 'grossPL': -146.14581, 'close': 1.17807, 'visiblePL': -191.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798291'}
# |DEBUG|2020-08-21 15:32:47,266|Update data without action:
# |DEBUG|2020-08-21 15:32:47,267|Update data without action:
# |DEBUG|2020-08-21 15:32:47,267|{'t': 1, 'grossPL': -130.561, 'close': 1.17807, 'visiblePL': -170.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799410'}
# |DEBUG|2020-08-21 15:32:47,268|Update data without action:
# |DEBUG|2020-08-21 15:32:47,269|{'t': 1, 'grossPL': -149.20166, 'close': 1.17807, 'visiblePL': -195.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798539'}
# |DEBUG|2020-08-21 15:32:47,269|Update data without action:
# |DEBUG|2020-08-21 15:32:47,270|Update data without action:
# |DEBUG|2020-08-21 15:32:47,271|Update data without action:
# |DEBUG|2020-08-21 15:32:47,333|{'t': 1, 'grossPL': -132.39451, 'close': 1.17807, 'visiblePL': -173.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799715'}
# |INFO|2020-08-21 15:32:47,277|Sending POST Request:
# |DEBUG|2020-08-21 15:32:47,279|Update data without action:
# |DEBUG|2020-08-21 15:32:47,336|{'t': 1, 'grossPL': -147.13896, 'close': 1.17807, 'visiblePL': -192.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798817'}
# |DEBUG|2020-08-21 15:32:47,285|Update data without action:
# |DEBUG|2020-08-21 15:32:47,253|{'t': 1, 'grossPL': -130.71379, 'close': 1.17807, 'visiblePL': -171.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799393'}
# |DEBUG|2020-08-21 15:32:47,287|Update data without action:
# |DEBUG|2020-08-21 15:32:47,287|{'t': 1, 'grossPL': -147.59734, 'close': 1.17807, 'visiblePL': -193.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798788'}
# |DEBUG|2020-08-21 15:32:47,288|Update data without action:
# |DEBUG|2020-08-21 15:32:47,288|{'t': 1, 'grossPL': -152.86868, 'close': 1.17807, 'visiblePL': -200.1, 'stop': 0, 'limit': 1.1569, 'tradeId': '168786497'}
# |DEBUG|2020-08-21 15:32:47,290|Update data without action:
# |DEBUG|2020-08-21 15:32:47,293|{'t': 1, 'grossPL': -147.29176, 'close': 1.17807, 'visiblePL': -192.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798272'}
# |DEBUG|2020-08-21 15:32:47,294|Update data without action:
# |DEBUG|2020-08-21 15:32:47,296|Update data without action:
# |DEBUG|2020-08-21 15:32:47,296|{'t': 1, 'grossPL': -142.5552, 'close': 1.17807, 'visiblePL': -186.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799040'}
# |DEBUG|2020-08-21 15:32:47,298|Update data without action:
# |DEBUG|2020-08-21 15:32:47,299|{'t': 1, 'grossPL': -147.29176, 'close': 1.17807, 'visiblePL': -192.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798812'}
# |DEBUG|2020-08-21 15:32:47,299|Update data without action:
# |DEBUG|2020-08-21 15:32:47,259|Update data without action:
# |DEBUG|2020-08-21 15:32:47,304|Update data without action:
# |DEBUG|2020-08-21 15:32:47,307|Update data without action:
# |DEBUG|2020-08-21 15:32:47,308|{'t': 1, 'grossPL': -132.08893, 'close': 1.17807, 'visiblePL': -172.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799700'}
# |DEBUG|2020-08-21 15:32:47,310|Update data without action:
# |DEBUG|2020-08-21 15:32:47,248|Update data without action:
# |DEBUG|2020-08-21 15:32:47,314|Update data without action:
# |DEBUG|2020-08-21 15:32:47,315|{'t': 1, 'grossPL': -146.29861, 'close': 1.17807, 'visiblePL': -191.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798803'}
# |DEBUG|2020-08-21 15:32:47,316|Update data without action:
# |DEBUG|2020-08-21 15:32:47,361|{'t': 1, 'grossPL': -78.37104, 'close': 9.02048, 'visiblePL': -2082.3, 'stop': 0, 'limit': 9.23473, 'tradeId': '168798796'}
# |DEBUG|2020-08-21 15:32:47,317|Update data without action:
# |DEBUG|2020-08-21 15:32:47,320|Update data without action:
# |DEBUG|2020-08-21 15:32:47,364|{'t': 1, 'grossPL': -79.64693, 'close': 9.02048, 'visiblePL': -2116.2, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799066'}
# |DEBUG|2020-08-21 15:32:47,324|{'t': 1, 'grossPL': -142.93718, 'close': 1.17807, 'visiblePL': -187.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799085'}
# |DEBUG|2020-08-21 15:32:47,325|Update data without action:
# |DEBUG|2020-08-21 15:32:47,327|Update data without action:
# |DEBUG|2020-08-21 15:32:47,370|{'t': 1, 'grossPL': -175.97052, 'close': 0.9121, 'visiblePL': -171.9, 'stop': 0, 'limit': 0.93023, 'tradeId': '168777695'}
# |DEBUG|2020-08-21 15:32:47,329|Update data without action:
# |DEBUG|2020-08-21 15:32:47,330|{'t': 1, 'grossPL': -132.31811, 'close': 1.17807, 'visiblePL': -173.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799721'}
# |DEBUG|2020-08-21 15:32:47,277|Update data without action:
# |INFO|2020-08-21 15:32:47,334|Got a insert event for orders: {'t': 3, 'ratePrecision': 5, 'orderId': '363409281', 'tradeId': '169150478', 'time': '08212020133247209', 'accountName': '01215060', 'accountId': '1215060', 'timeInForce': 'GTD', 'expireDate': '08212020154200', 'currency': 'GBP/CAD', 'isBuy': True, 'buy': 1.7317, 'sell': 0, 'type': 'SE', 'status': 1, 'amountK': 1, 'currencyPoint': 0.06422, 'stopMove': 0, 'stop': 0, 'stopRate': 0, 'limit': 0, 'limitRate': 0, 'isEntryOrder': True, 'ocoBulkId': 0, 'isNetQuantity': False, 'isLimitOrder': False, 'isStopOrder': True, 'isELSOrder': False, 'stopPegBaseType': -1, 'limitPegBaseType': -1, 'range': 0, 'action': 'I'}.
# |INFO|2020-08-21 15:32:47,335|URL: https://api-demo.fxcm.com:443/trading/create_entry_order
# |DEBUG|2020-08-21 15:32:47,281|Update data without action:
# |DEBUG|2020-08-21 15:32:47,377|{'t': 1, 'grossPL': -142.63159, 'close': 1.17807, 'visiblePL': -186.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799073'}
# |DEBUG|2020-08-21 15:32:47,340|{'t': 1, 'grossPL': -133.23487, 'close': 1.17807, 'visiblePL': -174.4, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799735'}
# |DEBUG|2020-08-21 15:32:47,342|{'t': 1, 'grossPL': -142.70799, 'close': 1.17807, 'visiblePL': -186.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799090'}
# |DEBUG|2020-08-21 15:32:47,345|{'t': 1, 'grossPL': -132.92928, 'close': 1.17807, 'visiblePL': -174, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799730'}
# |DEBUG|2020-08-21 15:32:47,348|{'t': 1, 'grossPL': -20.50884, 'close': 8.79348, 'visiblePL': -531.2, 'stop': 0, 'limit': 8.86911, 'tradeId': '168799387'}
# |DEBUG|2020-08-21 15:32:47,349|{'t': 1, 'grossPL': -27.99889, 'close': 8.79348, 'visiblePL': -725.2, 'stop': 0, 'limit': 8.86911, 'tradeId': '168798512'}
# |DEBUG|2020-08-21 15:32:47,350|{'t': 1, 'grossPL': -26.87925, 'close': 8.79348, 'visiblePL': -696.2, 'stop': 0, 'limit': 8.86911, 'tradeId': '168798799'}
# |DEBUG|2020-08-21 15:32:47,352|{'t': 1, 'grossPL': -21.89875, 'close': 8.79348, 'visiblePL': -567.2, 'stop': 0, 'limit': 8.86911, 'tradeId': '168799711'}
# |DEBUG|2020-08-21 15:32:47,353|{'t': 1, 'grossPL': -145.99302, 'close': 1.17807, 'visiblePL': -191.1, 'stop': 0, 'limit': 1.15781, 'tradeId': '168787029'}
# |DEBUG|2020-08-21 15:32:47,354|{'t': 1, 'grossPL': -26.26151, 'close': 8.79348, 'visiblePL': -680.2, 'stop': 0, 'limit': 8.86911, 'tradeId': '168799070'}
# |DEBUG|2020-08-21 15:32:47,355|{'t': 1, 'grossPL': -13.80816, 'close': 1.32165, 'visiblePL': -21.5, 'stop': 0, 'limit': 1.3369, 'tradeId': '169136852'}
# |DEBUG|2020-08-21 15:32:47,357|{'t': 1, 'grossPL': -13.74394, 'close': 1.32166, 'visiblePL': -21.4, 'stop': 0, 'limit': 1.3369, 'tradeId': '169136852'}
# |DEBUG|2020-08-21 15:32:47,358|{'t': 1, 'grossPL': -147.82653, 'close': 1.17807, 'visiblePL': -193.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798261'}
# |DEBUG|2020-08-21 15:32:47,359|{'t': 1, 'grossPL': -73.01157, 'close': 9.02048, 'visiblePL': -1939.9, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799383'}
# |DEBUG|2020-08-21 15:32:47,318|{'t': 1, 'grossPL': -131.40136, 'close': 1.17807, 'visiblePL': -172, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799696'}
# |DEBUG|2020-08-21 15:32:47,363|{'t': 1, 'grossPL': -73.89979, 'close': 9.02048, 'visiblePL': -1963.5, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799709'}
# |DEBUG|2020-08-21 15:32:47,324|Update data without action:
# |DEBUG|2020-08-21 15:32:47,368|{'t': 1, 'grossPL': -178.83682, 'close': 0.9121, 'visiblePL': -174.7, 'stop': 0, 'limit': 0.9305, 'tradeId': '168777799'}
# |DEBUG|2020-08-21 15:32:47,329|{'t': 1, 'grossPL': -133.61685, 'close': 1.17807, 'visiblePL': -174.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799725'}
# |DEBUG|2020-08-21 15:32:47,371|{'t': 1, 'grossPL': -179.65576, 'close': 0.9121, 'visiblePL': -175.5, 'stop': 0, 'limit': 0.93058, 'tradeId': '168777836'}
# |DEBUG|2020-08-21 15:32:47,373|{'t': 1, 'grossPL': -176.01671, 'close': 1.17807, 'visiblePL': -230.4, 'stop': 0, 'limit': 1.15388, 'tradeId': '168785506'}
# |INFO|2020-08-21 15:32:47,375|Payload: account_id=1215060&symbol=GBP%2FCAD&is_buy=true&rate=1.7317&amount=1&limit=1.7367&order_type=Entry&is_in_pips=false&time_in_force=GTD&stop=1.7289&expiration=2020-08-21+15%3A42
# |DEBUG|2020-08-21 15:32:47,338|{'t': 1, 'grossPL': -141.40925, 'close': 1.17807, 'visiblePL': -185.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799099'}
# |DEBUG|2020-08-21 15:32:47,393|{'t': 1, 'grossPL': -180.98655, 'close': 0.9121, 'visiblePL': -176.8, 'stop': 0, 'limit': 0.93071, 'tradeId': '168777898'}
# |INFO|2020-08-21 15:32:47,396|Headers: {'User-Agent': 'request', 'Accept-Encoding': 'gzip, deflate', 'Accept': 'application/json', 'Connection': 'keep-alive', 'Authorization': 'Bearer KzFiBwuTKcTxQuoPDTb779f83cbff13d296eb6d9b6c1ed6dccd768ef925a', 'Content-Type': 'application/x-www-form-urlencoded', 'Content-Length': '175'}
# |INFO|2020-08-21 15:32:47,398|Params: {'account_id': 1215060, 'symbol': 'GBP/CAD', 'is_buy': 'true', 'rate': 1.7317, 'amount': 1, 'limit': 1.7367, 'order_type': 'Entry', 'is_in_pips': 'false', 'time_in_force': 'GTD', 'stop': 1.7289, 'expiration': '2020-08-21 15:42'}
# |INFO|2020-08-21 15:32:47,398|Proxies: {}
# |DEBUG|2020-08-21 15:32:47,399|Server answer: {'response': {'executed': True}, 'data': {'type': 0, 'orderId': 363409281}}.
# |DEBUG|2020-08-21 15:32:47,530|Update data without action:
# |DEBUG|2020-08-21 15:32:47,531|{'t': 3, 'stop': 1.7289, 'stopRate': 1.7289, 'limit': 0, 'limitRate': 0, 'stopPegBaseType': -1, 'limitPegBaseType': -1, 'orderId': '363409281'}
# |DEBUG|2020-08-21 15:32:47,836|Update data without action:
# |DEBUG|2020-08-21 15:32:47,837|{'t': 3, 'stop': 1.7289, 'stopRate': 1.7289, 'limit': 1.7367, 'limitRate': 1.7367, 'stopPegBaseType': -1, 'limitPegBaseType': -1, 'orderId': '363409281'}
# |DEBUG|2020-08-21 15:32:47,837|Update data without action:
# |DEBUG|2020-08-21 15:32:47,839|Update data without action:
# |DEBUG|2020-08-21 15:32:47,840|Update data without action:
# |DEBUG|2020-08-21 15:32:47,842|Update data without action:
# |DEBUG|2020-08-21 15:32:47,842|{'t': 1, 'grossPL': -130.79463, 'close': 1.17803, 'visiblePL': -171.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799372'}
# |DEBUG|2020-08-21 15:32:47,843|Update data without action:
# |DEBUG|2020-08-21 15:32:47,844|{'t': 1, 'grossPL': -148.59554, 'close': 1.17803, 'visiblePL': -194.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798474'}
# |DEBUG|2020-08-21 15:32:47,844|Update data without action:
# |DEBUG|2020-08-21 15:32:47,845|Update data without action:
# |DEBUG|2020-08-21 15:32:47,846|{'t': 1, 'grossPL': -146.53277, 'close': 1.17803, 'visiblePL': -191.8, 'stop': 0, 'limit': 1.15765, 'tradeId': '168787611'}
# |DEBUG|2020-08-21 15:32:47,846|Update data without action:
# |DEBUG|2020-08-21 15:32:47,847|Update data without action:
# |DEBUG|2020-08-21 15:32:47,848|{'t': 1, 'grossPL': -148.44274, 'close': 1.17803, 'visiblePL': -194.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798483'}
# |DEBUG|2020-08-21 15:32:47,851|Update data without action:
# |DEBUG|2020-08-21 15:32:47,851|{'t': 1, 'grossPL': -130.79463, 'close': 1.17803, 'visiblePL': -171.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799377'}
# |DEBUG|2020-08-21 15:32:47,852|Update data without action:
# |DEBUG|2020-08-21 15:32:47,879|{'t': 1, 'grossPL': -130.87103, 'close': 1.17803, 'visiblePL': -171.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799417'}
# |DEBUG|2020-08-21 15:32:47,856|{'t': 1, 'grossPL': -129.80145, 'close': 1.17803, 'visiblePL': -169.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799405'}
# |DEBUG|2020-08-21 15:32:47,856|Update data without action:
# |DEBUG|2020-08-21 15:32:47,895|{'t': 1, 'grossPL': -130.25984, 'close': 1.17803, 'visiblePL': -170.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799410'}
# |DEBUG|2020-08-21 15:32:47,858|Update data without action:
# |DEBUG|2020-08-21 15:32:47,902|{'t': 1, 'grossPL': -142.56004, 'close': 1.17803, 'visiblePL': -186.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799049'}
# |DEBUG|2020-08-21 15:32:47,860|Update data without action:
# |DEBUG|2020-08-21 15:32:47,860|Update data without action:
# |DEBUG|2020-08-21 15:32:47,861|Update data without action:
# |DEBUG|2020-08-21 15:32:47,861|Update data without action:
# |DEBUG|2020-08-21 15:32:47,861|{'t': 1, 'grossPL': -130.41264, 'close': 1.17803, 'visiblePL': -170.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799393'}
# |DEBUG|2020-08-21 15:32:47,863|Update data without action:
# |DEBUG|2020-08-21 15:32:47,863|{'t': 1, 'grossPL': -147.22036, 'close': 1.17803, 'visiblePL': -192.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798781'}
# |DEBUG|2020-08-21 15:32:47,863|Update data without action:
# |DEBUG|2020-08-21 15:32:47,865|Update data without action:
# |DEBUG|2020-08-21 15:32:47,867|Update data without action:
# |DEBUG|2020-08-21 15:32:47,868|Update data without action:
# |DEBUG|2020-08-21 15:32:47,868|Update data without action:
# |DEBUG|2020-08-21 15:32:47,869|Update data without action:
# |DEBUG|2020-08-21 15:32:47,869|{'t': 1, 'grossPL': -148.74833, 'close': 1.17803, 'visiblePL': -194.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798521'}
# |DEBUG|2020-08-21 15:32:47,869|Update data without action:
# |DEBUG|2020-08-21 15:32:47,870|Update data without action:
# |DEBUG|2020-08-21 15:32:47,871|Update data without action:
# |DEBUG|2020-08-21 15:32:47,871|Update data without action:
# |DEBUG|2020-08-21 15:32:47,872|Update data without action:
# |DEBUG|2020-08-21 15:32:47,875|Update data without action:
# |DEBUG|2020-08-21 15:32:47,880|Update data without action:
# |DEBUG|2020-08-21 15:32:47,883|Update data without action:
# |DEBUG|2020-08-21 15:32:47,854|Update data without action:
# |DEBUG|2020-08-21 15:32:47,889|Update data without action:
# |DEBUG|2020-08-21 15:32:47,892|Update data without action:
# |DEBUG|2020-08-21 15:32:47,857|Update data without action:
# |DEBUG|2020-08-21 15:32:47,899|Update data without action:
# |DEBUG|2020-08-21 15:32:47,901|Update data without action:
# |DEBUG|2020-08-21 15:32:47,902|Update data without action:
# |DEBUG|2020-08-21 15:32:47,903|Update data without action:
# |DEBUG|2020-08-21 15:32:47,858|{'t': 1, 'grossPL': -130.71823, 'close': 1.17803, 'visiblePL': -171.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799399'}
# |DEBUG|2020-08-21 15:32:47,903|Update data without action:
# |DEBUG|2020-08-21 15:32:47,908|Update data without action:
# |DEBUG|2020-08-21 15:32:47,911|Update data without action:
# |DEBUG|2020-08-21 15:32:47,911|{'t': 1, 'grossPL': -147.29676, 'close': 1.17803, 'visiblePL': -192.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798788'}
# |DEBUG|2020-08-21 15:32:47,911|Update data without action:
# |DEBUG|2020-08-21 15:32:47,912|Update data without action:
# |DEBUG|2020-08-21 15:32:47,913|{'t': 1, 'grossPL': -152.56827, 'close': 1.17803, 'visiblePL': -199.7, 'stop': 0, 'limit': 1.1569, 'tradeId': '168786497'}
# |DEBUG|2020-08-21 15:32:47,913|Update data without action:
# |DEBUG|2020-08-21 15:32:47,914|Update data without action:
# |DEBUG|2020-08-21 15:32:47,915|{'t': 1, 'grossPL': -146.99116, 'close': 1.17803, 'visiblePL': -192.4, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798272'}
# |DEBUG|2020-08-21 15:32:47,917|Update data without action:
# |DEBUG|2020-08-21 15:32:47,917|{'t': 1, 'grossPL': -142.25444, 'close': 1.17803, 'visiblePL': -186.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799040'}
# |DEBUG|2020-08-21 15:32:47,917|Update data without action:
# |DEBUG|2020-08-21 15:32:47,919|Update data without action:
# |DEBUG|2020-08-21 15:32:47,921|Update data without action:
# |DEBUG|2020-08-21 15:32:47,924|{'t': 1, 'grossPL': -146.99116, 'close': 1.17803, 'visiblePL': -192.4, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798812'}
# |DEBUG|2020-08-21 15:32:47,926|Update data without action:
# |DEBUG|2020-08-21 15:32:47,928|Update data without action:
# |DEBUG|2020-08-21 15:32:47,930|Update data without action:
# |DEBUG|2020-08-21 15:32:47,931|Update data without action:
# |DEBUG|2020-08-21 15:32:47,932|{'t': 1, 'grossPL': -145.69238, 'close': 1.17803, 'visiblePL': -190.7, 'stop': 0, 'limit': 1.15781, 'tradeId': '168787029'}
# |DEBUG|2020-08-21 15:32:47,933|Update data without action:
# |DEBUG|2020-08-21 15:32:47,934|{'t': 1, 'grossPL': -131.78782, 'close': 1.17803, 'visiblePL': -172.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799700'}
# |DEBUG|2020-08-21 15:32:47,934|Update data without action:
# |DEBUG|2020-08-21 15:32:47,935|{'t': 1, 'grossPL': -145.84518, 'close': 1.17803, 'visiblePL': -190.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798291'}
# |DEBUG|2020-08-21 15:32:47,935|Update data without action:
# |DEBUG|2020-08-21 15:32:47,936|Update data without action:
# |DEBUG|2020-08-21 15:32:47,937|Update data without action:
# |DEBUG|2020-08-21 15:32:47,937|{'t': 1, 'grossPL': -145.99798, 'close': 1.17803, 'visiblePL': -191.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798803'}
# |DEBUG|2020-08-21 15:32:47,938|{'t': 1, 'grossPL': -131.10023, 'close': 1.17803, 'visiblePL': -171.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799696'}
# |DEBUG|2020-08-21 15:32:47,939|{'t': 1, 'grossPL': -142.63644, 'close': 1.17803, 'visiblePL': -186.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799085'}
# |DEBUG|2020-08-21 15:32:47,940|{'t': 1, 'grossPL': -133.31579, 'close': 1.17803, 'visiblePL': -174.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799725'}
# |DEBUG|2020-08-21 15:32:47,941|{'t': 1, 'grossPL': -132.01701, 'close': 1.17803, 'visiblePL': -172.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799721'}
# |DEBUG|2020-08-21 15:32:47,942|{'t': 1, 'grossPL': -132.09341, 'close': 1.17803, 'visiblePL': -172.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799715'}
# |DEBUG|2020-08-21 15:32:47,942|{'t': 1, 'grossPL': -175.71709, 'close': 1.17803, 'visiblePL': -230, 'stop': 0, 'limit': 1.15388, 'tradeId': '168785506'}
# |DEBUG|2020-08-21 15:32:47,943|{'t': 1, 'grossPL': -146.83837, 'close': 1.17803, 'visiblePL': -192.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798817'}
# |DEBUG|2020-08-21 15:32:47,944|{'t': 1, 'grossPL': -142.33084, 'close': 1.17803, 'visiblePL': -186.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799073'}
# |DEBUG|2020-08-21 15:32:47,944|{'t': 1, 'grossPL': -141.10846, 'close': 1.17803, 'visiblePL': -184.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799099'}
# |DEBUG|2020-08-21 15:32:47,945|{'t': 1, 'grossPL': -132.9338, 'close': 1.17803, 'visiblePL': -174, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799735'}
# |DEBUG|2020-08-21 15:32:47,946|{'t': 1, 'grossPL': -147.52595, 'close': 1.17803, 'visiblePL': -193.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798261'}
# |DEBUG|2020-08-21 15:32:47,946|{'t': 1, 'grossPL': -142.40724, 'close': 1.17803, 'visiblePL': -186.4, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799090'}
# |DEBUG|2020-08-21 15:32:47,947|{'t': 1, 'grossPL': -132.6282, 'close': 1.17803, 'visiblePL': -173.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799730'}
# |DEBUG|2020-08-21 15:32:47,948|{'t': 1, 'grossPL': -148.90113, 'close': 1.17803, 'visiblePL': -194.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798539'}
# |DEBUG|2020-08-21 15:32:47,948|{'t': 1, 'grossPL': -20.38915, 'close': 8.79379, 'visiblePL': -528.1, 'stop': 0, 'limit': 8.86911, 'tradeId': '168799387'}
# |DEBUG|2020-08-21 15:32:47,949|{'t': 1, 'grossPL': -27.87921, 'close': 8.79379, 'visiblePL': -722.1, 'stop': 0, 'limit': 8.86911, 'tradeId': '168798512'}
# |DEBUG|2020-08-21 15:32:47,950|{'t': 1, 'grossPL': -26.75956, 'close': 8.79379, 'visiblePL': -693.1, 'stop': 0, 'limit': 8.86911, 'tradeId': '168798799'}
# |DEBUG|2020-08-21 15:32:47,950|{'t': 1, 'grossPL': -21.77906, 'close': 8.79379, 'visiblePL': -564.1, 'stop': 0, 'limit': 8.86911, 'tradeId': '168799711'}
# |DEBUG|2020-08-21 15:32:47,951|{'t': 1, 'grossPL': -26.14182, 'close': 8.79379, 'visiblePL': -677.1, 'stop': 0, 'limit': 8.86911, 'tradeId': '168799070'}
# |DEBUG|2020-08-21 15:32:47,952|{'t': 1, 'grossPL': -13.74429, 'close': 1.32166, 'visiblePL': -21.4, 'stop': 0, 'limit': 1.3369, 'tradeId': '169136852'}
# |DEBUG|2020-08-21 15:32:47,953|{'t': 1, 'grossPL': -180.88418, 'close': 0.91211, 'visiblePL': -176.7, 'stop': 0, 'limit': 0.93071, 'tradeId': '168777898'}
# |DEBUG|2020-08-21 15:32:47,954|{'t': 1, 'grossPL': -178.73445, 'close': 0.91211, 'visiblePL': -174.6, 'stop': 0, 'limit': 0.9305, 'tradeId': '168777799'}
# |DEBUG|2020-08-21 15:32:47,955|{'t': 1, 'grossPL': -175.86815, 'close': 0.91211, 'visiblePL': -171.8, 'stop': 0, 'limit': 0.93023, 'tradeId': '168777695'}
# |DEBUG|2020-08-21 15:32:47,956|{'t': 1, 'grossPL': -179.5534, 'close': 0.91211, 'visiblePL': -175.4, 'stop': 0, 'limit': 0.93058, 'tradeId': '168777836'}
# |DEBUG|2020-08-21 15:32:47,956|{'t': 1, 'grossPL': -13.74429, 'close': 1.32166, 'visiblePL': -21.4, 'stop': 0, 'limit': 1.3369, 'tradeId': '169136852'}
# |DEBUG|2020-08-21 15:32:47,958|{'t': 1, 'grossPL': -72.92877, 'close': 9.0207, 'visiblePL': -1937.7, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799383'}
# |DEBUG|2020-08-21 15:32:47,959|{'t': 1, 'grossPL': -78.28824, 'close': 9.0207, 'visiblePL': -2080.1, 'stop': 0, 'limit': 9.23473, 'tradeId': '168798796'}
# |DEBUG|2020-08-21 15:32:47,960|{'t': 1, 'grossPL': -73.81699, 'close': 9.0207, 'visiblePL': -1961.3, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799709'}
# |DEBUG|2020-08-21 15:32:47,961|{'t': 1, 'grossPL': -79.56413, 'close': 9.0207, 'visiblePL': -2114, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799066'}
# |DEBUG|2020-08-21 15:32:47,962|{'t': 1, 'grossPL': -20.38911, 'close': 8.79379, 'visiblePL': -528.1, 'stop': 0, 'limit': 8.86911, 'tradeId': '168799387'}
# |DEBUG|2020-08-21 15:32:47,963|{'t': 1, 'grossPL': -27.87914, 'close': 8.79379, 'visiblePL': -722.1, 'stop': 0, 'limit': 8.86911, 'tradeId': '168798512'}
# |DEBUG|2020-08-21 15:32:47,963|{'t': 1, 'grossPL': -26.75949, 'close': 8.79379, 'visiblePL': -693.1, 'stop': 0, 'limit': 8.86911, 'tradeId': '168798799'}
# |DEBUG|2020-08-21 15:32:47,964|{'t': 1, 'grossPL': -21.77901, 'close': 8.79379, 'visiblePL': -564.1, 'stop': 0, 'limit': 8.86911, 'tradeId': '168799711'}
# |DEBUG|2020-08-21 15:32:47,965|{'t': 1, 'grossPL': -26.14176, 'close': 8.79379, 'visiblePL': -677.1, 'stop': 0, 'limit': 8.86911, 'tradeId': '168799070'}
# |DEBUG|2020-08-21 15:32:47,967|{'t': 1, 'grossPL': -180.88755, 'close': 0.91211, 'visiblePL': -176.7, 'stop': 0, 'limit': 0.93071, 'tradeId': '168777898'}
# |DEBUG|2020-08-21 15:32:47,968|{'t': 1, 'grossPL': -178.73778, 'close': 0.91211, 'visiblePL': -174.6, 'stop': 0, 'limit': 0.9305, 'tradeId': '168777799'}
# |DEBUG|2020-08-21 15:32:47,969|{'t': 1, 'grossPL': -175.87142, 'close': 0.91211, 'visiblePL': -171.8, 'stop': 0, 'limit': 0.93023, 'tradeId': '168777695'}
# |DEBUG|2020-08-21 15:32:47,969|{'t': 1, 'grossPL': -179.55674, 'close': 0.91211, 'visiblePL': -175.4, 'stop': 0, 'limit': 0.93058, 'tradeId': '168777836'}
# |DEBUG|2020-08-21 15:32:48,202|Update data without action:
# |DEBUG|2020-08-21 15:32:48,204|{'t': 1, 'grossPL': -130.79463, 'close': 1.17803, 'visiblePL': -171.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799372'}
# |DEBUG|2020-08-21 15:32:48,204|Update data without action:
# |DEBUG|2020-08-21 15:32:48,210|{'t': 1, 'grossPL': -146.53277, 'close': 1.17803, 'visiblePL': -191.8, 'stop': 0, 'limit': 1.15765, 'tradeId': '168787611'}
# |DEBUG|2020-08-21 15:32:48,206|Update data without action:
# |DEBUG|2020-08-21 15:32:48,214|{'t': 1, 'grossPL': -148.44274, 'close': 1.17803, 'visiblePL': -194.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798483'}
# |DEBUG|2020-08-21 15:32:48,208|Update data without action:
# |DEBUG|2020-08-21 15:32:48,203|Update data without action:
# |DEBUG|2020-08-21 15:32:48,210|Update data without action:
# |DEBUG|2020-08-21 15:32:48,213|Update data without action:
# |DEBUG|2020-08-21 15:32:48,213|Update data without action:
# |DEBUG|2020-08-21 15:32:48,214|Update data without action:
# |DEBUG|2020-08-21 15:32:48,228|{'t': 1, 'grossPL': -148.74833, 'close': 1.17803, 'visiblePL': -194.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798521'}
# |DEBUG|2020-08-21 15:32:48,207|Update data without action:
# |DEBUG|2020-08-21 15:32:48,216|Update data without action:
# |DEBUG|2020-08-21 15:32:48,218|Update data without action:
# |DEBUG|2020-08-21 15:32:48,218|{'t': 1, 'grossPL': -148.59554, 'close': 1.17803, 'visiblePL': -194.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798474'}
# |DEBUG|2020-08-21 15:32:48,220|Update data without action:
# |DEBUG|2020-08-21 15:32:48,221|Update data without action:
# |DEBUG|2020-08-21 15:32:48,221|{'t': 1, 'grossPL': -130.71823, 'close': 1.17803, 'visiblePL': -171.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799399'}
# |DEBUG|2020-08-21 15:32:48,222|Update data without action:
# |DEBUG|2020-08-21 15:32:48,223|Update data without action:
# |DEBUG|2020-08-21 15:32:48,223|{'t': 1, 'grossPL': -130.41264, 'close': 1.17803, 'visiblePL': -170.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799393'}
# |DEBUG|2020-08-21 15:32:48,224|Update data without action:
# |DEBUG|2020-08-21 15:32:48,251|{'t': 1, 'grossPL': -152.56827, 'close': 1.17803, 'visiblePL': -199.7, 'stop': 0, 'limit': 1.1569, 'tradeId': '168786497'}
# |DEBUG|2020-08-21 15:32:48,225|Update data without action:
# |DEBUG|2020-08-21 15:32:48,226|Update data without action:
# |DEBUG|2020-08-21 15:32:48,227|Update data without action:
# |DEBUG|2020-08-21 15:32:48,229|Update data without action:
# |DEBUG|2020-08-21 15:32:48,216|{'t': 1, 'grossPL': -129.80145, 'close': 1.17803, 'visiblePL': -169.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799405'}
# |DEBUG|2020-08-21 15:32:48,230|Update data without action:
# |DEBUG|2020-08-21 15:32:48,233|Update data without action:
# |DEBUG|2020-08-21 15:32:48,233|{'t': 1, 'grossPL': -130.79463, 'close': 1.17803, 'visiblePL': -171.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799377'}
# |DEBUG|2020-08-21 15:32:48,233|Update data without action:
# |DEBUG|2020-08-21 15:32:48,234|{'t': 1, 'grossPL': -130.87103, 'close': 1.17803, 'visiblePL': -171.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799417'}
# |DEBUG|2020-08-21 15:32:48,235|Update data without action:
# |DEBUG|2020-08-21 15:32:48,236|Update data without action:
# |DEBUG|2020-08-21 15:32:48,237|Update data without action:
# |DEBUG|2020-08-21 15:32:48,237|{'t': 1, 'grossPL': -147.52595, 'close': 1.17803, 'visiblePL': -193.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798261'}
# |DEBUG|2020-08-21 15:32:48,238|Update data without action:
# |DEBUG|2020-08-21 15:32:48,239|Update data without action:
# |DEBUG|2020-08-21 15:32:48,240|Update data without action:
# |DEBUG|2020-08-21 15:32:48,240|{'t': 1, 'grossPL': -130.25984, 'close': 1.17803, 'visiblePL': -170.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799410'}
# |DEBUG|2020-08-21 15:32:48,241|Update data without action:
# |DEBUG|2020-08-21 15:32:48,277|{'t': 1, 'grossPL': -146.83837, 'close': 1.17803, 'visiblePL': -192.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798817'}
# |DEBUG|2020-08-21 15:32:48,242|Update data without action:
# |DEBUG|2020-08-21 15:32:48,242|Update data without action:
# |DEBUG|2020-08-21 15:32:48,243|Update data without action:
# |DEBUG|2020-08-21 15:32:48,245|Update data without action:
# |DEBUG|2020-08-21 15:32:48,246|Update data without action:
# |DEBUG|2020-08-21 15:32:48,283|{'t': 1, 'grossPL': -132.6282, 'close': 1.17803, 'visiblePL': -173.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799730'}
# |DEBUG|2020-08-21 15:32:48,248|{'t': 1, 'grossPL': -147.29676, 'close': 1.17803, 'visiblePL': -192.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798788'}
# |DEBUG|2020-08-21 15:32:48,248|Update data without action:
# |DEBUG|2020-08-21 15:32:48,250|Update data without action:
# |DEBUG|2020-08-21 15:32:48,225|{'t': 1, 'grossPL': -147.22036, 'close': 1.17803, 'visiblePL': -192.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798781'}
# |DEBUG|2020-08-21 15:32:48,253|Update data without action:
# |DEBUG|2020-08-21 15:32:48,292|{'t': 1, 'grossPL': -72.925, 'close': 9.02071, 'visiblePL': -1937.6, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799383'}
# |DEBUG|2020-08-21 15:32:48,254|Update data without action:
# |DEBUG|2020-08-21 15:32:48,255|Update data without action:
# |DEBUG|2020-08-21 15:32:48,295|{'t': 1, 'grossPL': -73.81323, 'close': 9.02071, 'visiblePL': -1961.2, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799709'}
# |DEBUG|2020-08-21 15:32:48,256|Update data without action:
# |DEBUG|2020-08-21 15:32:48,299|{'t': 1, 'grossPL': -79.56036, 'close': 9.02071, 'visiblePL': -2113.9, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799066'}
# |DEBUG|2020-08-21 15:32:48,258|Update data without action:
# |DEBUG|2020-08-21 15:32:48,260|Update data without action:
# |DEBUG|2020-08-21 15:32:48,304|{'t': 1, 'grossPL': -27.87902, 'close': 8.79379, 'visiblePL': -722.1, 'stop': 0, 'limit': 8.86911, 'tradeId': '168798512'}
# |DEBUG|2020-08-21 15:32:48,261|Update data without action:
# |DEBUG|2020-08-21 15:32:48,262|Update data without action:
# |DEBUG|2020-08-21 15:32:48,262|Update data without action:
# |DEBUG|2020-08-21 15:32:48,265|{'t': 1, 'grossPL': -131.78782, 'close': 1.17803, 'visiblePL': -172.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799700'}
# |DEBUG|2020-08-21 15:32:48,266|{'t': 1, 'grossPL': -145.84518, 'close': 1.17803, 'visiblePL': -190.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798291'}
# |DEBUG|2020-08-21 15:32:48,268|{'t': 1, 'grossPL': -145.99798, 'close': 1.17803, 'visiblePL': -191.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798803'}
# |DEBUG|2020-08-21 15:32:48,270|{'t': 1, 'grossPL': -131.10023, 'close': 1.17803, 'visiblePL': -171.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799696'}
# |DEBUG|2020-08-21 15:32:48,270|{'t': 1, 'grossPL': -142.63644, 'close': 1.17803, 'visiblePL': -186.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799085'}
# |DEBUG|2020-08-21 15:32:48,271|{'t': 1, 'grossPL': -133.31579, 'close': 1.17803, 'visiblePL': -174.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799725'}
# |DEBUG|2020-08-21 15:32:48,273|{'t': 1, 'grossPL': -132.01701, 'close': 1.17803, 'visiblePL': -172.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799721'}
# |DEBUG|2020-08-21 15:32:48,274|{'t': 1, 'grossPL': -132.09341, 'close': 1.17803, 'visiblePL': -172.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799715'}
# |DEBUG|2020-08-21 15:32:48,275|{'t': 1, 'grossPL': -175.71709, 'close': 1.17803, 'visiblePL': -230, 'stop': 0, 'limit': 1.15388, 'tradeId': '168785506'}
# |DEBUG|2020-08-21 15:32:48,242|{'t': 1, 'grossPL': -148.90113, 'close': 1.17803, 'visiblePL': -194.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798539'}
# |DEBUG|2020-08-21 15:32:48,279|{'t': 1, 'grossPL': -142.33084, 'close': 1.17803, 'visiblePL': -186.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799073'}
# |DEBUG|2020-08-21 15:32:48,280|{'t': 1, 'grossPL': -141.10846, 'close': 1.17803, 'visiblePL': -184.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799099'}
# |DEBUG|2020-08-21 15:32:48,281|{'t': 1, 'grossPL': -132.9338, 'close': 1.17803, 'visiblePL': -174, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799735'}
# |DEBUG|2020-08-21 15:32:48,282|{'t': 1, 'grossPL': -142.40724, 'close': 1.17803, 'visiblePL': -186.4, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799090'}
# |DEBUG|2020-08-21 15:32:48,246|{'t': 1, 'grossPL': -142.56004, 'close': 1.17803, 'visiblePL': -186.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799049'}
# ...
# |DEBUG|2020-08-21 15:33:01,684|{'t': 1, 'grossPL': -131.4666, 'close': 1.17817, 'visiblePL': -172.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799393'}
# |DEBUG|2020-08-21 15:33:01,685|{'t': 1, 'grossPL': -148.27232, 'close': 1.17817, 'visiblePL': -194.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798781'}
# |DEBUG|2020-08-21 15:33:01,685|{'t': 1, 'grossPL': -149.80011, 'close': 1.17817, 'visiblePL': -196.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798521'}
# |DEBUG|2020-08-21 15:33:01,686|{'t': 1, 'grossPL': -131.92493, 'close': 1.17817, 'visiblePL': -172.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799417'}
# |DEBUG|2020-08-21 15:33:01,687|{'t': 1, 'grossPL': -148.57788, 'close': 1.17817, 'visiblePL': -194.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798261'}
# |DEBUG|2020-08-21 15:33:01,688|{'t': 1, 'grossPL': -131.31382, 'close': 1.17817, 'visiblePL': -171.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799410'}
# |DEBUG|2020-08-21 15:33:01,689|{'t': 1, 'grossPL': -149.95289, 'close': 1.17817, 'visiblePL': -196.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798539'}
# |DEBUG|2020-08-21 15:33:01,690|{'t': 1, 'grossPL': -143.61255, 'close': 1.17817, 'visiblePL': -188, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799049'}
# |DEBUG|2020-08-21 15:33:01,690|{'t': 1, 'grossPL': -148.34871, 'close': 1.17817, 'visiblePL': -194.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798788'}
# |DEBUG|2020-08-21 15:33:01,691|{'t': 1, 'grossPL': -153.6196, 'close': 1.17817, 'visiblePL': -201.1, 'stop': 0, 'limit': 1.1569, 'tradeId': '168786497'}
# |DEBUG|2020-08-21 15:33:01,692|{'t': 1, 'grossPL': -148.04315, 'close': 1.17817, 'visiblePL': -193.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798272'}
# |DEBUG|2020-08-21 15:33:01,692|{'t': 1, 'grossPL': -143.30699, 'close': 1.17817, 'visiblePL': -187.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799040'}
# |DEBUG|2020-08-21 15:33:01,693|{'t': 1, 'grossPL': -148.04315, 'close': 1.17817, 'visiblePL': -193.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798812'}
# |DEBUG|2020-08-21 15:33:01,694|{'t': 1, 'grossPL': -146.74453, 'close': 1.17817, 'visiblePL': -192.1, 'stop': 0, 'limit': 1.15781, 'tradeId': '168787029'}
# |DEBUG|2020-08-21 15:33:01,695|{'t': 1, 'grossPL': -132.84161, 'close': 1.17817, 'visiblePL': -173.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799700'}
# |DEBUG|2020-08-21 15:33:01,696|{'t': 1, 'grossPL': -146.89731, 'close': 1.17817, 'visiblePL': -192.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798291'}
# |DEBUG|2020-08-21 15:33:01,697|{'t': 1, 'grossPL': -147.05009, 'close': 1.17817, 'visiblePL': -192.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798803'}
# |DEBUG|2020-08-21 15:33:01,698|{'t': 1, 'grossPL': -132.1541, 'close': 1.17817, 'visiblePL': -173, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799696'}
# |DEBUG|2020-08-21 15:33:01,699|{'t': 1, 'grossPL': -143.68894, 'close': 1.17817, 'visiblePL': -188.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799085'}
# |DEBUG|2020-08-21 15:33:01,700|{'t': 1, 'grossPL': -134.3694, 'close': 1.17817, 'visiblePL': -175.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799725'}
# |DEBUG|2020-08-21 15:33:01,700|{'t': 1, 'grossPL': -133.07078, 'close': 1.17817, 'visiblePL': -174.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799721'}
# |DEBUG|2020-08-21 15:33:01,701|{'t': 1, 'grossPL': -133.14717, 'close': 1.17817, 'visiblePL': -174.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799715'}
# |DEBUG|2020-08-21 15:33:01,702|{'t': 1, 'grossPL': -176.76566, 'close': 1.17817, 'visiblePL': -231.4, 'stop': 0, 'limit': 1.15388, 'tradeId': '168785506'}
# |DEBUG|2020-08-21 15:33:01,703|{'t': 1, 'grossPL': -147.89037, 'close': 1.17817, 'visiblePL': -193.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798817'}
# |DEBUG|2020-08-21 15:33:01,704|{'t': 1, 'grossPL': -143.38338, 'close': 1.17817, 'visiblePL': -187.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799073'}
# |DEBUG|2020-08-21 15:33:01,705|{'t': 1, 'grossPL': -142.16115, 'close': 1.17817, 'visiblePL': -186.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799099'}
# |DEBUG|2020-08-21 15:33:01,706|{'t': 1, 'grossPL': -133.98746, 'close': 1.17817, 'visiblePL': -175.4, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799735'}
# |DEBUG|2020-08-21 15:33:01,707|{'t': 1, 'grossPL': -143.45977, 'close': 1.17817, 'visiblePL': -187.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799090'}
# |DEBUG|2020-08-21 15:33:01,708|{'t': 1, 'grossPL': -133.6819, 'close': 1.17817, 'visiblePL': -175, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799730'}
# |DEBUG|2020-08-21 15:33:01,750|Update data without action:
# |DEBUG|2020-08-21 15:33:01,750|Update data without action:
# |DEBUG|2020-08-21 15:33:01,751|Update data without action:
# |DEBUG|2020-08-21 15:33:01,751|{'t': 1, 'grossPL': -131.84854, 'close': 1.17817, 'visiblePL': -172.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799372'}
# |DEBUG|2020-08-21 15:33:01,752|{'t': 1, 'grossPL': -149.64733, 'close': 1.17817, 'visiblePL': -195.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798474'}
# |DEBUG|2020-08-21 15:33:01,753|Update data without action:
# |DEBUG|2020-08-21 15:33:01,753|Update data without action:
# |DEBUG|2020-08-21 15:33:01,753|{'t': 1, 'grossPL': -147.58481, 'close': 1.17817, 'visiblePL': -193.2, 'stop': 0, 'limit': 1.15765, 'tradeId': '168787611'}
# |DEBUG|2020-08-21 15:33:01,754|Update data without action:
# |DEBUG|2020-08-21 15:33:01,754|Update data without action:
# |DEBUG|2020-08-21 15:33:01,755|Update data without action:
# |DEBUG|2020-08-21 15:33:01,755|Update data without action:
# |DEBUG|2020-08-21 15:33:01,756|Update data without action:
# |DEBUG|2020-08-21 15:33:01,756|Update data without action:
# |DEBUG|2020-08-21 15:33:01,757|Update data without action:
# |DEBUG|2020-08-21 15:33:01,757|Update data without action:
# |DEBUG|2020-08-21 15:33:01,758|Update data without action:
# |DEBUG|2020-08-21 15:33:01,758|Update data without action:
# |DEBUG|2020-08-21 15:33:01,758|{'t': 1, 'grossPL': -149.49456, 'close': 1.17817, 'visiblePL': -195.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798483'}
# |DEBUG|2020-08-21 15:33:01,759|Update data without action:
# |DEBUG|2020-08-21 15:33:01,759|Update data without action:
# |DEBUG|2020-08-21 15:33:01,759|Update data without action:
# |DEBUG|2020-08-21 15:33:01,760|{'t': 1, 'grossPL': -131.84854, 'close': 1.17817, 'visiblePL': -172.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799377'}
# |DEBUG|2020-08-21 15:33:01,760|Update data without action:
# |DEBUG|2020-08-21 15:33:01,761|Update data without action:
# |DEBUG|2020-08-21 15:33:01,761|Update data without action:
# |DEBUG|2020-08-21 15:33:01,761|Update data without action:
# |DEBUG|2020-08-21 15:33:01,762|Update data without action:
# |DEBUG|2020-08-21 15:33:01,763|Update data without action:
# |DEBUG|2020-08-21 15:33:01,763|Update data without action:
# |DEBUG|2020-08-21 15:33:01,764|Update data without action:
# |DEBUG|2020-08-21 15:33:01,764|Update data without action:
# |DEBUG|2020-08-21 15:33:01,764|{'t': 1, 'grossPL': -130.85548, 'close': 1.17817, 'visiblePL': -171.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799405'}
# |DEBUG|2020-08-21 15:33:01,765|Update data without action:
# |DEBUG|2020-08-21 15:33:01,765|Update data without action:
# |DEBUG|2020-08-21 15:33:01,766|{'t': 1, 'grossPL': -131.77216, 'close': 1.17817, 'visiblePL': -172.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799399'}
# |DEBUG|2020-08-21 15:33:01,766|Update data without action:
# |DEBUG|2020-08-21 15:33:01,766|Update data without action:
# |DEBUG|2020-08-21 15:33:01,767|Update data without action:
# |DEBUG|2020-08-21 15:33:01,767|{'t': 1, 'grossPL': -131.4666, 'close': 1.17817, 'visiblePL': -172.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799393'}
# |DEBUG|2020-08-21 15:33:01,767|Update data without action:
# |DEBUG|2020-08-21 15:33:01,768|Update data without action:
# |DEBUG|2020-08-21 15:33:01,768|Update data without action:
# |DEBUG|2020-08-21 15:33:01,768|{'t': 1, 'grossPL': -148.27232, 'close': 1.17817, 'visiblePL': -194.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798781'}
# |DEBUG|2020-08-21 15:33:01,769|Update data without action:
# |DEBUG|2020-08-21 15:33:01,769|{'t': 1, 'grossPL': -149.80011, 'close': 1.17817, 'visiblePL': -196.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798521'}
# |DEBUG|2020-08-21 15:33:01,770|Update data without action:
# |DEBUG|2020-08-21 15:33:01,770|{'t': 1, 'grossPL': -131.92493, 'close': 1.17817, 'visiblePL': -172.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799417'}
# |DEBUG|2020-08-21 15:33:01,771|Update data without action:
# |DEBUG|2020-08-21 15:33:01,772|{'t': 1, 'grossPL': -148.57788, 'close': 1.17817, 'visiblePL': -194.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798261'}
# |DEBUG|2020-08-21 15:33:01,772|Update data without action:
# |DEBUG|2020-08-21 15:33:01,773|Update data without action:
# |DEBUG|2020-08-21 15:33:01,774|Update data without action:
# |DEBUG|2020-08-21 15:33:01,775|Update data without action:
# |DEBUG|2020-08-21 15:33:01,775|{'t': 1, 'grossPL': -131.31382, 'close': 1.17817, 'visiblePL': -171.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799410'}
# |DEBUG|2020-08-21 15:33:01,775|Update data without action:
# |DEBUG|2020-08-21 15:33:01,776|{'t': 1, 'grossPL': -149.95289, 'close': 1.17817, 'visiblePL': -196.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798539'}
# |DEBUG|2020-08-21 15:33:01,776|Update data without action:
# |DEBUG|2020-08-21 15:33:01,777|{'t': 1, 'grossPL': -143.61255, 'close': 1.17817, 'visiblePL': -188, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799049'}
# |DEBUG|2020-08-21 15:33:01,779|{'t': 1, 'grossPL': -148.34871, 'close': 1.17817, 'visiblePL': -194.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798788'}
# |DEBUG|2020-08-21 15:33:01,779|{'t': 1, 'grossPL': -153.6196, 'close': 1.17817, 'visiblePL': -201.1, 'stop': 0, 'limit': 1.1569, 'tradeId': '168786497'}
# |DEBUG|2020-08-21 15:33:01,780|{'t': 1, 'grossPL': -148.04315, 'close': 1.17817, 'visiblePL': -193.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798272'}
# |DEBUG|2020-08-21 15:33:01,781|{'t': 1, 'grossPL': -143.30699, 'close': 1.17817, 'visiblePL': -187.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799040'}
# |DEBUG|2020-08-21 15:33:01,782|{'t': 1, 'grossPL': -148.04315, 'close': 1.17817, 'visiblePL': -193.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798812'}
# |DEBUG|2020-08-21 15:33:01,783|{'t': 1, 'grossPL': -146.74453, 'close': 1.17817, 'visiblePL': -192.1, 'stop': 0, 'limit': 1.15781, 'tradeId': '168787029'}
# |DEBUG|2020-08-21 15:33:01,783|{'t': 1, 'grossPL': -132.84161, 'close': 1.17817, 'visiblePL': -173.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799700'}
# |DEBUG|2020-08-21 15:33:01,784|{'t': 1, 'grossPL': -146.89731, 'close': 1.17817, 'visiblePL': -192.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798291'}
# |DEBUG|2020-08-21 15:33:01,785|{'t': 1, 'grossPL': -147.05009, 'close': 1.17817, 'visiblePL': -192.5, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798803'}
# |DEBUG|2020-08-21 15:33:01,785|{'t': 1, 'grossPL': -132.1541, 'close': 1.17817, 'visiblePL': -173, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799696'}
# |DEBUG|2020-08-21 15:33:01,786|{'t': 1, 'grossPL': -143.68894, 'close': 1.17817, 'visiblePL': -188.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799085'}
# |DEBUG|2020-08-21 15:33:01,787|{'t': 1, 'grossPL': -134.3694, 'close': 1.17817, 'visiblePL': -175.9, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799725'}
# |DEBUG|2020-08-21 15:33:01,788|{'t': 1, 'grossPL': -133.07078, 'close': 1.17817, 'visiblePL': -174.2, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799721'}
# |DEBUG|2020-08-21 15:33:01,789|{'t': 1, 'grossPL': -133.14717, 'close': 1.17817, 'visiblePL': -174.3, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799715'}
# |DEBUG|2020-08-21 15:33:01,790|{'t': 1, 'grossPL': -176.76566, 'close': 1.17817, 'visiblePL': -231.4, 'stop': 0, 'limit': 1.15388, 'tradeId': '168785506'}
# |DEBUG|2020-08-21 15:33:01,791|{'t': 1, 'grossPL': -147.89037, 'close': 1.17817, 'visiblePL': -193.6, 'stop': 0, 'limit': 1.15802, 'tradeId': '168798817'}
# |DEBUG|2020-08-21 15:33:01,791|{'t': 1, 'grossPL': -143.38338, 'close': 1.17817, 'visiblePL': -187.7, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799073'}
# |DEBUG|2020-08-21 15:33:01,793|{'t': 1, 'grossPL': -142.16115, 'close': 1.17817, 'visiblePL': -186.1, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799099'}
# |DEBUG|2020-08-21 15:33:01,793|{'t': 1, 'grossPL': -133.98746, 'close': 1.17817, 'visiblePL': -175.4, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799735'}
# |DEBUG|2020-08-21 15:33:01,794|{'t': 1, 'grossPL': -143.45977, 'close': 1.17817, 'visiblePL': -187.8, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799090'}
# |DEBUG|2020-08-21 15:33:01,796|{'t': 1, 'grossPL': -133.6819, 'close': 1.17817, 'visiblePL': -175, 'stop': 0, 'limit': 1.15802, 'tradeId': '168799730'}
# |DEBUG|2020-08-21 15:33:01,797|{'t': 1, 'grossPL': -13.74297, 'close': 1.32166, 'visiblePL': -21.4, 'stop': 0, 'limit': 1.3369, 'tradeId': '169136852'}
# |DEBUG|2020-08-21 15:33:01,799|{'t': 1, 'grossPL': -72.29088, 'close': 9.02234, 'visiblePL': -1921.3, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799383'}
# |DEBUG|2020-08-21 15:33:01,800|{'t': 1, 'grossPL': -77.64883, 'close': 9.02234, 'visiblePL': -2063.7, 'stop': 0, 'limit': 9.23473, 'tradeId': '168798796'}
# |DEBUG|2020-08-21 15:33:01,800|{'t': 1, 'grossPL': -73.17885, 'close': 9.02234, 'visiblePL': -1944.9, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799709'}
# |DEBUG|2020-08-21 15:33:01,801|{'t': 1, 'grossPL': -78.92435, 'close': 9.02234, 'visiblePL': -2097.6, 'stop': 0, 'limit': 9.23473, 'tradeId': '168799066'}
# |DEBUG|2020-08-21 15:33:01,802|{'t': 1, 'grossPL': -13.74288, 'close': 1.32166, 'visiblePL': -21.4, 'stop': 0, 'limit': 1.3369, 'tradeId': '169136852'}
# |DEBUG|2020-08-21 15:33:01,803|{'t': 1, 'grossPL': -0.42385, 'close': 1.73105, 'visiblePL': -6.6, 'stop': 1.7289, 'limit': 1.7367, 'tradeId': '169150478'}
# |DEBUG|2020-08-21 15:33:01,805|{'t': 1, 'grossPL': -0.42385, 'close': 1.73105, 'visiblePL': -6.6, 'stop': 1.7289, 'limit': 1.7367, 'tradeId': '169150479'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/fxcmpy/fxcmpy.py in create_entry_order(self, symbol, is_buy, amount, time_in_force, order_type, limit, is_in_pips, rate, stop, trailing_step, trailing_stop_step, order_range, expiration, account_id)
#    1647         try:
# -> 1648             order = self.get_order(order_id)
#    1649         except:
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/fxcmpy/fxcmpy.py in get_order(self, order_id)
#     636         else:
# --> 637             raise ValueError('No order with id %s' % order_id)
#     638
#
# ValueError: No order with id 363409284
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-7bd62d605a7c> in <module>
#      17                                         stop=round(float(con.get_last_price(ticker).Ask * (1 - _sl)),4),\
#      18                                             trailing_step=None,\
# ---> 19                                                 expiration = (dt.datetime.now() + dt.timedelta(minutes=10)).strftime(format='%Y-%m-%d %H:%M'))
#      20
#      21     time.sleep(5)
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/fxcmpy/fxcmpy.py in create_entry_order(self, symbol, is_buy, amount, time_in_force, order_type, limit, is_in_pips, rate, stop, trailing_step, trailing_stop_step, order_range, expiration, account_id)
#    1649         except:
#    1650             time.sleep(1)
# -> 1651             order = self.get_order(order_id)
#    1652
#    1653         return order
#
# /opt/anaconda3/envs/FinTech/lib/python3.7/site-packages/fxcmpy/fxcmpy.py in get_order(self, order_id)
#     635             return self.old_orders[order_id]
#     636         else:
# --> 637             raise ValueError('No order with id %s' % order_id)
#     638
#     639     def get_oco_order_ids(self):
#
# ValueError: No order with id 363409284

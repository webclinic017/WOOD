# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
print('Importing Librairies...')
import talib
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import xgboost as xgb
from xgboost import XGBRegressor, plot_importance
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')
import time
import datetime as dt
import os
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score,roc_curve,confusion_matrix,classification_report,r2_score
import warnings
import pickle
warnings.filterwarnings("ignore")
#import tensorflow as tf
#tf.logging.set_verbosity(tf.logging.ERROR)
print('Librairies imported')
print('')

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print('DEEP LEARNING FOREX V1',Style.RESET_ALL)

#LaDate = input('Date de DL - YYYY-MM-DD ')
LaDate = '2020-01-15'
ticker = 'USDJPY_1D'
indice = 0.3
try:
    os.mkdir('DL_'+ticker+'-'+LaDate)
except:
    pass
try:
    os.mkdir('Boost_'+ticker+'-'+LaDate)
except:
    pass
# Out:
# Importing Librairies...
# Librairies imported
#
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
# DEEP LEARNING FOREX V1

# %%
def prepa_data(df):
    rsi = talib.RSI(df['Close'],timeperiod=14)
    stoc_slowk, stoc_slowd = talib.STOCH(df['High'],df['Low'],df['Close'])
    upper, middle, lower =  talib.BBANDS(df['Close'], timeperiod=9, nbdevup=2, nbdevdn=2,matype=0)
    sma5 = talib.SMA(df['Close'],timeperiod=5)
    sma8 = talib.SMA(df['Close'],timeperiod=8)
    sma10 = talib.SMA(df['Close'],timeperiod=10)
    sma12 = talib.SMA(df['Close'],timeperiod=12)
    sma15 = talib.SMA(df['Close'],timeperiod=15)
    sma30 = talib.SMA(df['Close'],timeperiod=30)
    sma35 = talib.SMA(df['Close'],timeperiod=35)
    sma40 = talib.SMA(df['Close'],timeperiod=40)
    sma45 = talib.SMA(df['Close'],timeperiod=45)
    sma50 = talib.SMA(df['Close'],timeperiod=50)
    atr = talib.ATR(df['High'],df['Low'],df['Close'],timeperiod=10)
    delta5_8 = sma5 - sma8
    delta8_10 = sma8 - sma10
    delta10_12 = sma10 - sma12
    delta12_15 = sma12 - sma15
    delta15_30 = sma15 - sma30
    delta30_35 = sma30 - sma35
    delta35_40 = sma35 - sma40
    delta40_45 = sma40 - sma45
    delta45_50 = sma45 - sma50
    bbdelta = upper - middle
    price_bolup = df['Close'] - lower
    price_bolow = df['Close'] - upper
    Ema = talib.EMA(df['Close'],timeperiod=20)
    KC_High = Ema + 2*atr
    KC_Low = Ema - 2*atr
    aroondown, aroonup = talib.AROON(df['High'], df['Low'], timeperiod=9)
    aroon = aroonup - aroondown 
    rsi30_list = []
    rsi70_list = []
    for i in range(0,df.shape[0]):
        #try:
        rsi70_list.append(70 - rsi[i])
        rsi30_list.append(rsi[i] - 30)
        #except:
         #   rsi70_list.append(0)
          #  rsi30_list.append(0)
        
    varop_spy = df['Open'] - df['Close']
    varhl_spy = df['High'] - df['Low']
    df['Varop_Spy'] = varop_spy
    df['Varhl_spy'] = varhl_spy
    df['RSI'] = rsi
    df['70 - RSI'] = np.array(rsi70_list)
    df['RSI - 30'] = np.array(rsi30_list)
    df['BBD_Delta_Up'] = bbdelta
    df['delta5_8'] = delta5_8
    df['delta8_10'] = delta8_10
    df['delta10_12'] = delta10_12
    df['delta12_15'] = delta12_15
    df['delta15_30'] = delta15_30
    df['delta30_35'] = delta30_35
    df['delta35_40'] = delta35_40
    df['delta40_45'] = delta40_45
    df['delta45_50'] = delta45_50
    df['Stoc_Slowk'] = stoc_slowk
    df['Stoc_Slowd'] = stoc_slowd
    df['KC_High'] = KC_High
    df['KC_Low'] = KC_Low
    df['upper'] = upper
    df['lower'] = lower
    df['var_bollup_kchigh'] = upper-KC_High
    df['var_bolllow_kclow'] = lower-KC_Low
    df['Aroon Up'] = aroonup
    df['Aroon Down'] = aroondown
    df['Delta Aroon'] = aroon
    up = []
    down = []
    df = df.dropna()
    df['%Futur1'] = ((df['Close'].shift(-1)-df['Close']) *100) / (df['Close'])
    df['%Futur2'] = ((df['Close'].shift(-2)-df['Close']) *100) / (df['Close'])
    df['%Futur3'] = ((df['Close'].shift(-3)-df['Close']) *100) / (df['Close'])
    df['%Futur4'] = ((df['Close'].shift(-4)-df['Close']) *100) / (df['Close'])
    df['%Futur5'] = ((df['Close'].shift(-5)-df['Close']) *100) / (df['Close'])
    for i in range(0,df.shape[0]):
        if df.iloc[i]['%Futur1'] > indice or df.iloc[i]['%Futur2'] > indice or df.iloc[i]['%Futur3'] > indice or df.iloc[i]['%Futur4'] > indice or df.iloc[i]['%Futur5'] > indice:
            up.append(1)
            down.append(0)
        elif df.iloc[i]['%Futur1'] < -indice or df.iloc[i]['%Futur2'] < -indice or df.iloc[i]['%Futur3'] < -indice or df.iloc[i]['%Futur4'] < -indice or df.iloc[i]['%Futur5'] < -indice:
            up.append(0)
            down.append(1)
        else:
            up.append(0)
            down.append(0)
        
    df['target_up'] = up  
    df['target_down'] = down 
    #df = df.dropna()
    
    df = df[['High','Low','Open','Volume','DeltaVol','Close','Varop_Spy','Varhl_spy','RSI',\
             '70 - RSI','RSI - 30','BBD_Delta_Up','delta5_8','delta8_10','delta10_12',\
             'delta12_15','delta15_30','delta30_35','delta35_40','delta40_45','delta45_50',\
             'Stoc_Slowk','Stoc_Slowd','KC_High','KC_Low','upper','lower','var_bollup_kchigh',\
             'var_bolllow_kclow','Aroon Up','Aroon Down','Delta Aroon',\
             '%Futur1','%Futur2','%Futur3','%Futur4','%Futur5','target_up','target_down']]
        
    return(df)
    



def save_model(model_up,model_down):
    savename = 'DL_'+ticker+'-'+LaDate+'/Save_'+ticker
    # serialize model to YAML
    model_up_yaml = model_up.to_yaml()
    model_down_yaml = model_down.to_yaml()
    with open(savename+"_up.yaml", "w") as yaml_file:
        yaml_file.write(model_up_yaml)
    with open(savename+"_down.yaml", "w") as yaml_file:
        yaml_file.write(model_down_yaml)
    # serialize weights to HDF5
    model_up.save_weights(savename+"_up.h5")
    model_down.save_weights(savename+"_down.h5")

# %%
# PARAMETRES TEMPORELS INITIAUX
start = '2016-08-01'
end = LaDate
print('DATE ORIGINELLE DU DEBUT DE TOUT... :',start)
error = []

        
########################
#### MAIN SKAN55 #######
########################

print(' - Date de début : ',start,' - Date de fin : ',end)
print(Fore.YELLOW,'GENERATION DE LaBase :',Fore.MAGENTA,time.strftime("%H:%M:%S", time.localtime()))
tmps55=time.time()
LaBase = pd.read_csv('USDJPY_1D.csv')
df = LaBase

INDEX = []
for i in range(0,len(df)):
    INDEX.append((str(df.iloc[i,0])[6:10]+'-'+str(df.iloc[i,0])[3:5]+'-'+str(df.iloc[i,0])[:2]))
df.index = INDEX
df = df.drop(['Local time'],axis=1)
df = df[df.index>=start]
delta = round(df.shape[0])
bloc1 = round(delta*0.75)
bloc2 = delta - bloc1

tmps22=round(time.time()-tmps55,2)
print(Fore.BLUE,"Time for complete Base Preparation = %f" %tmps22,'seconds \n',Style.RESET_ALL)
#LaBasePrep.to_csv('LaBasePrep.csv')
df.head()
# Out:
# DATE ORIGINELLE DU DEBUT DE TOUT... : 2016-08-01
#  - Date de début :  2016-08-01  - Date de fin :  2020-01-15
#  GENERATION DE LaBase :  17:36:39
#  Time for complete Base Preparation = 0.170000 seconds
#                Open     High      Low    Close       Volume
# 2016-08-01  102.384  102.830  100.679  100.889  700202.3037
# 2016-08-02  100.889  101.569  100.748  101.240  613891.8053
# 2016-08-03  101.237  101.667  100.861  101.202  560742.0905
# 2016-08-04  101.202  102.061  100.872  101.785  530031.4499
# 2016-08-07  101.984  102.655  101.861  102.446  445920.5372

# %%
###### PREPARATION #########


print('The computing has begun at ',dt.datetime.now().hour,':',dt.datetime.now().minute,':',dt.datetime.now().second)

BasePrep = pd.DataFrame()
tmps55=time.time()

df['DeltaVol'] = df['Volume'] - df['Volume'].shift(1)
df = df.dropna()
df = prepa_data(df)
    
BasePrep = df
tmps22=round(time.time()-tmps55,2)
print(Fore.BLUE,"\nTime for complete Preparation = %f" %tmps22,'seconds \n',Style.RESET_ALL)
BasePrep.to_csv('BasePrep.csv')
df.head()
# Out:
# The computing has begun at  17 : 36 : 41
#
# Time for complete Preparation = 0.790000 seconds
#                High      Low     Open       Volume     DeltaVol    Close  \
# 2016-10-09  103.787  102.808  103.247  457897.1212 -217213.9517  103.606
# 2016-10-10  104.071  103.174  103.608  605088.1880  147191.0668  103.490
# 2016-10-11  104.482  103.278  103.499  540128.8581  -64959.3299  104.205
# 2016-10-12  104.635  103.333  104.205  556401.2204   16272.3623  103.691
# 2016-10-13  104.475  103.609  103.694  626564.1875   70162.9671  104.082
#
#             Varop_Spy  Varhl_spy        RSI   70 - RSI  ...    Aroon Up  \
# 2016-10-09     -0.359      0.979  61.267455   8.732545  ...   77.777778
# 2016-10-10      0.118      0.897  60.255378   9.744622  ...   66.666667
# 2016-10-11     -0.706      1.204  64.182804   5.817196  ...  100.000000
# 2016-10-12      0.514      1.302  59.621643  10.378357  ...  100.000000
# 2016-10-13     -0.388      0.866  61.843053   8.156947  ...   88.888889
#
#             Aroon Down  Delta Aroon   %Futur1   %Futur2   %Futur3   %Futur4  \
# 2016-10-09    0.000000    77.777778 -0.111963  0.578152  0.082042  0.459433
# 2016-10-10    0.000000    66.666667  0.690888  0.194222  0.572036  0.379747
# 2016-10-11    0.000000   100.000000 -0.493258 -0.118037 -0.309006 -0.325320
# 2016-10-12   11.111111    88.888889  0.377082  0.185166  0.168771 -0.247852
# 2016-10-13    0.000000    88.888889 -0.191195 -0.207529 -0.622586 -0.130666
#
#              %Futur5  target_up  target_down
# 2016-10-09  0.267359          1            0
# 2016-10-10  0.363320          1            0
# 2016-10-11 -0.739888          0            1
# 2016-10-12  0.245923          1            0
# 2016-10-13 -0.268058          0            1
#
# [5 rows x 39 columns]

# %%
def boost(df,period):
    print(Fore.YELLOW,'\nGENERATION DU BOOST :',Fore.MAGENTA,time.strftime("%H:%M:%S", time.localtime()))
    tmps55=time.time()
    
    seed = 770
    np.random.seed(seed)
    X = df.copy()
    X = X.drop(['Close'],axis=1)
    X['Close'] = df['Close']
    y = X.iloc[:,-1]
    Xtrain = X.iloc[:bloc1,:-1]
    Xtest = X.iloc[bloc1:-period,:-1]
    yshift = y.shift(-period)
    ytrain = yshift.iloc[:bloc1]
    ytest = yshift.iloc[bloc1:-period]

    model = xgb.XGBRegressor(n_estimators=200000, learning_rate=1, gamma=1, subsample=1, colsample_bytree=1, max_depth=5,objective='reg:squarederror')

    model.fit( Xtrain, ytrain, early_stopping_rounds=10, eval_metric=['mae'],eval_set=[(Xtest, ytest)], verbose=0)

    ytrain_pred = model.predict(Xtrain)

    y_pred = model.predict(Xtest)

    pred = model.predict(X.iloc[:,:-1])
    r2 = r2_score(ytest,y_pred)*100
    df['Boost'+str(period)] = pred
    return(df,model,r2)

for period in range(0,10):
    period = period + 1
    df,model,r2 = boost(df,period)

    print(Fore.GREEN,'\nPeriod = ',period,'   ----   r2_score = ',r2,'%')

    print('% error : ',abs(((df['Boost'+str(period)].shift(+period)-df['Close'])/df['Close']*100)).mean(),'%')

    print('\nEcart min : ',abs(((df['Boost'+str(period)].shift(+period)-df['Close'])/df['Close']*100)).min(),'%')

    print('\nEcart max : ',abs(((df['Boost'+str(period)].shift(+period)-df['Close'])/df['Close']*100)).max(),'%')

    print('\n',model.evals_result())

    pickle.dump(model, open('Boost_'+ticker+'-'+LaDate+'/'+ticker+'_boost'+str(period)+'.dat', "wb"))

tmps22=round(time.time()-tmps55,2)
print(Fore.BLUE,"\nTime for complete BOOST GENERATION = %f" %tmps22,'seconds \n',Style.RESET_ALL)

#df['Boost1'] = df['Boost1'] - df ['Close']
#df['Boost2'] = df['Boost2'] - df ['Close']
#df['Boost3'] = df['Boost3'] - df ['Close']
#df['Boost4'] = df['Boost4'] - df ['Close']
#df['Boost4'] = df['Boost5'] - df ['Close']

df = df[['High','Low','Open','Volume','DeltaVol','Close','Varop_Spy','Varhl_spy','RSI',\
             '70 - RSI','RSI - 30','BBD_Delta_Up','delta5_8','delta8_10','delta10_12',\
             'delta12_15','delta15_30','delta30_35','delta35_40','delta40_45','delta45_50',\
             'Stoc_Slowk','Stoc_Slowd','KC_High','KC_Low','upper','lower','var_bollup_kchigh',\
             'var_bolllow_kclow','Aroon Up','Aroon Down','Delta Aroon',\
             'Boost1','Boost2','Boost3','Boost4','Boost5','%Futur1','%Futur2','%Futur3','%Futur4','%Futur5','target_up','target_down']]

df = df.dropna()
# Out:
#
# GENERATION DU BOOST :  17:36:42
#
# Period =  1    ----   r2_score =  62.388942323284844 %
# % error :  0.2647346472051738 %
#
# Ecart min :  0.0006958462224399813 %
#
# Ecart max :  2.239248222437414 %
#
#  {'validation_0': {'mae': [2.745538, 0.662499, 0.632127, 0.49169, 0.487255, 0.492567, 0.492929, 0.492929, 0.492929, 0.492929, 0.492929, 0.492929, 0.492929, 0.492929]}}
#
# GENERATION DU BOOST :  17:36:42
#
# Period =  2    ----   r2_score =  34.80873743376222 %
# % error :  0.28970419584563073 %
#
# Ecart min :  0.0012477779763677957 %
#
# Ecart max :  2.004415282909738 %
#
#  {'validation_0': {'mae': [2.762731, 0.721271, 0.697632, 0.689801, 0.690849, 0.685559, 0.690533, 0.690696, 0.690698, 0.690698, 0.690698, 0.690698, 0.690698, 0.690698, 0.690698]}}
#
# GENERATION DU BOOST :  17:36:43
#
# Period =  3    ----   r2_score =  16.999942115470756 %
# % error :  0.31316380538269445 %
#
# Ecart min :  0.00035876672564331947 %
#
# Ecart max :  2.5245286360262167 %
#
#  {'validation_0': {'mae': [2.778871, 0.861419, 0.849043, 0.811358, 0.815097, 0.805047, 0.79784, 0.797135, 0.837554, 0.820639, 0.827051, 0.831219, 0.831549, 0.831549, 0.831549, 0.831549, 0.831549]}}
#
# GENERATION DU BOOST :  17:36:43
#
# Period =  4    ----   r2_score =  6.737972662603109 %
# % error :  0.3094736788462496 %
#
# Ecart min :  0.00022334942150280056 %
#
# Ecart max :  3.1691051442348446 %
#
#  {'validation_0': {'mae': [2.797737, 0.982139, 0.916903, 0.900289, 0.918905, 0.923825, 0.832217, 0.831947, 0.831947, 0.831947, 0.831947, 0.831947, 0.831947, 0.831947, 0.831947, 0.831947, 0.831947]}}
#
# GENERATION DU BOOST :  17:36:43
#
# Period =  5    ----   r2_score =  -20.74351347771095 %
# % error :  0.4128097928576151 %
#
# Ecart min :  0.0008492398606465572 %
#
# Ecart max :  3.0224956597423565 %
#
#  {'validation_0': {'mae': [2.817695, 0.997358, 0.975389, 0.981015, 0.990905, 0.985097, 0.982813, 0.981153, 0.982435, 0.982498, 0.982498, 0.982498]}}
#
# GENERATION DU BOOST :  17:36:43
#
# Period =  6    ----   r2_score =  -54.324862439764466 %
# % error :  0.5203918901160272 %
#
# Ecart min :  0.002550368045759766 %
#
# Ecart max :  3.9769518196872897 %
#
#  {'validation_0': {'mae': [2.838139, 1.074216, 1.147235, 1.140214, 1.171974, 1.185816, 1.17511, 1.184881, 1.174062, 1.178529, 1.186071]}}
#
# GENERATION DU BOOST :  17:36:43
#
# Period =  7    ----   r2_score =  -77.03381566855401 %
# % error :  0.3772980147072521 %
#
# Ecart min :  0.00044643490642698154 %
#
# Ecart max :  3.8249027056692224 %
#
#  {'validation_0': {'mae': [2.861922, 1.147119, 1.153118, 1.183202, 1.169985, 1.157963, 1.171206, 1.131016, 1.137959, 1.116217, 1.139338, 1.139221, 1.139221, 1.139221, 1.139221, 1.139221, 1.139221, 1.139221, 1.139221]}}
#
# GENERATION DU BOOST :  17:36:43
#
# Period =  8    ----   r2_score =  -119.40863672776341 %
# % error :  0.5201996231215066 %
#
# Ecart min :  6.0079152216633394e-05 %
#
# Ecart max :  5.201666486122321 %
#
#  {'validation_0': {'mae': [2.885465, 1.208114, 1.233855, 1.235452, 1.253717, 1.259236, 1.266664, 1.267339, 1.254647, 1.264857, 1.2644]}}
#
# GENERATION DU BOOST :  17:36:43
#
# Period =  9    ----   r2_score =  -141.17372599689818 %
# % error :  0.4327691966819057 %
#
# Ecart min :  0.0003530510990366569 %
#
# Ecart max :  3.9847665300731783 %
#
#  {'validation_0': {'mae': [2.902791, 1.327858, 1.318704, 1.298069, 1.278849, 1.2741, 1.349435, 1.337407, 1.348544, 1.348619, 1.348619, 1.348619, 1.348619, 1.348619, 1.348619]}}
#
# GENERATION DU BOOST :  17:36:43
#
# Period =  10    ----   r2_score =  -142.81916481589238 %
# % error :  0.5327250029412656 %
#
# Ecart min :  0.0015134288723508043 %
#
# Ecart max :  4.696357702565281 %
#
#  {'validation_0': {'mae': [2.918063, 1.255802, 1.262289, 1.300257, 1.331121, 1.345623, 1.339297, 1.338626, 1.349085, 1.348778, 1.348773]}}
#
# Time for complete BOOST GENERATION = 2.750000 seconds

# %%
df.shape,df['target_up'].sum(),df['target_down'].sum(),'Futur%',df['%Futur1'].mean(),df['%Futur2'].mean(),df['%Futur3'].mean(),df['%Futur4'].mean(),df['%Futur5'].mean(),\
'Boost',df['Boost1'].mean(),df['Boost2'].mean(),df['Boost3'].mean(),df['Boost4'].mean(),df['Boost5'].mean(),
# Out:
# ((845, 44),
#  480,
#  318,
#  'Futur%',
#  0.006322755230706353,
#  0.012815202659473142,
#  0.019229811031069036,
#  0.02667325871140339,
#  0.03371569137329003,
#  'Boost',
#  110.52912902832031,
#  110.56481170654297,
#  110.58967590332031,
#  110.60077667236328,
#  110.62287139892578)

# %%
df.tail()
# Out:
#                High      Low     Open       Volume     DeltaVol    Close  \
# 2019-12-29  109.472  108.768  109.408   88699.0393   -6088.9991  108.874
# 2019-12-30  108.882  108.470  108.874   71656.2104  -17042.8289  108.631
# 2019-12-31  108.631  108.631  108.631       0.0000  -71656.2104  108.631
# 2020-01-01  108.864  108.211  108.730  215080.7890  215080.7890  108.567
# 2020-01-02  108.630  107.839  108.556  184360.8900  -30719.8990  108.047
#
#             Varop_Spy  Varhl_spy        RSI   70 - RSI  ...      Boost3  \
# 2019-12-29      0.534      0.704  45.029823  24.970177  ...  108.630234
# 2019-12-30      0.243      0.412  41.164839  28.835161  ...  108.794891
# 2019-12-31      0.000      0.000  41.164839  28.835161  ...  108.666145
# 2020-01-01      0.163      0.653  40.113174  29.886826  ...  109.239639
# 2020-01-02      0.509      0.791  32.784467  37.215533  ...  109.876617
#
#                 Boost4      Boost5   %Futur1   %Futur2   %Futur3   %Futur4  \
# 2019-12-29  108.249565  108.909515 -0.223194 -0.223194 -0.281977 -0.759594
# 2019-12-30  109.158478  108.909515  0.000000 -0.058915 -0.537600 -0.246707
# 2019-12-31  109.062027  110.184906 -0.058915 -0.537600 -0.246707 -0.175825
# 2020-01-01  109.127869  109.418701 -0.478967 -0.187902 -0.116978  0.494625
# 2020-01-02  109.966019  109.456757  0.292465  0.363731  0.978278  1.357742
#
#              %Futur5  target_up  target_down
# 2019-12-29 -0.469350          0            1
# 2019-12-30 -0.175825          0            1
# 2019-12-31  0.435419          1            0
# 2020-01-01  0.872272          1            0
# 2020-01-02  1.299435          1            0
#
# [5 rows x 44 columns]

# %%
def deep_learning_down(df):
    
    seed = 770
    np.random.seed(seed)
    X = df.iloc[:,:-7]
    y_down = df.iloc[:,-1].values
    X.astype(np.float64)
    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_down = np.array(y_down).reshape(-1,1)

    Xtrain = X[:bloc1,:]
    Xtest = X[bloc1:,:]

    ytrain_down = y_down[:bloc1,:]
    ytest_down = y_down[bloc1:,:]

    ytrain_down = ytrain_down.reshape(ytrain_down.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])
        
    model_down = Sequential()
    # Add an input layer 
    model_down.add(Dense(50, activation='relu'))
    # Add an input layer 
    model_down.add(Dense(50, activation='relu'))
    # Add an input layer 
    model_down.add(Dense(50, activation='relu'))
    # Add an input layer 
    model_down.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_down.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_down.add(Dense(1, activation='sigmoid'))
    
    model_down.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])

    history_down = model_down.fit(Xtrain, ytrain_down,epochs=600, batch_size=300, verbose=0)
    

    train_acc_down = model_down.evaluate(Xtrain, ytrain_down,verbose=1)

    yhat_down = model_down.predict_classes(Xtest)

    score_down = model_down.evaluate(Xtest, ytest_down,verbose=1)

    predict_down = model_down.predict(Xtest)

    accuracy_down = accuracy_score(ytest_down, yhat_down)

    # La précision permet de mesurer la capacité du modèle à refuser résultats non-pertinents : vrais_positifs/(vrais_positifs+faux_positifs)
    precision_down = precision_score(ytest_down, yhat_down) 


    # Recall : (vrai_positifs/(vrais_positifs+faux_négatifs))
    recall_down = recall_score(ytest_down, yhat_down) 


    resultats = pd.DataFrame()
    resultats['Date'] = df.index[bloc1:]
    resultats.index= df.index[bloc1:]
   
    resultats['Move Down'] = yhat_down
    resultats['Confiance Down'] = (predict_down)*100
    resultats['Actual'] = df.iloc[bloc1:]['Close']
    resultats['Actual.S'] = df.iloc[bloc1:]['Close'].shift(-1)
    open_S = df['Open'].shift(-1)
    resultats['Open.S'] = open_S.iloc[bloc1:]
    
    
    return(resultats,precision_down,model_down,scaler)

def deep_learning_up(df):
    
    seed = 770
    np.random.seed(seed)
    X = df.iloc[:,:-7]
    y_up = df.iloc[:,-2].values
    X.astype(np.float64)
    scaler = MinMaxScaler(feature_range=(0, 1))
    X = scaler.fit_transform(X)
    y_up = np.array(y_up).reshape(-1,1)

    Xtrain = X[:bloc1,:]
    Xtest = X[bloc1:,:]
    ytrain_up = y_up[:bloc1,:]
    ytest_up = y_up[bloc1:,:]
    

    ytrain_up = ytrain_up.reshape(ytrain_up.shape[0],)

    Xtrain = Xtrain.reshape(Xtrain.shape[0],Xtrain.shape[1])

    model_up = Sequential()
    
    # Add an input layer 
    model_up.add(Dense(50, activation='relu'))
    # Add an input layer 
    model_up.add(Dense(50, activation='relu'))
    # Add an input layer 
    model_up.add(Dense(50, activation='relu'))
    # Add an input layer 
    model_up.add(Dense(50, activation='relu'))
    # Add one hidden layer 
    model_up.add(Dense(23, activation='relu'))
    # Add an output layer 
    model_up.add(Dense(1, activation='sigmoid'))


    model_up.compile(loss='binary_crossentropy',
                  optimizer='adam', #rmsprop
                  metrics=['accuracy','mse'])
    
              

    history_up = model_up.fit(Xtrain, ytrain_up,epochs=600, batch_size=300, verbose=0)
            
    
    

    train_acc_up = model_up.evaluate(Xtrain, ytrain_up,verbose=1)

    yhat_up = model_up.predict_classes(Xtest)

    score_up = model_up.evaluate(Xtest, ytest_up,verbose=1)

    predict_up = model_up.predict(Xtest)

    accuracy_up = accuracy_score(ytest_up, yhat_up)

    # La précision permet de mesurer la capacité du modèle à refuser résultats non-pertinents : vrais_positifs/(vrais_positifs+faux_positifs)
    precision_up = precision_score(ytest_up, yhat_up)  


    # Recall : (vrai_positifs/(vrais_positifs+faux_négatifs))
    recall_up = recall_score(ytest_up, yhat_up) 


    resultats['Move Up'] = yhat_up
    resultats['Confiance up'] = (predict_up)*100

    dmp_cp=[]
    dmp_cp = ((resultats['Confiance up']-resultats['Confiance Down'])/(resultats['Confiance up']+resultats['Confiance Down'])*100)
    resultats['DMP_CP'] = dmp_cp
    return(resultats,precision_up,model_up,scaler)




tmps55=time.time()
print(Fore.BLUE,'\nDeeping in blue for ',ticker,Style.RESET_ALL)

resultats,precision_down,model_down,scaler = deep_learning_down(df)

resultats,precision_up,model_up,scaler = deep_learning_up(df)

n = 0    
while (precision_down*100) < 69:
    n+=1
    print('\nTicker : ',ticker,' Precision Down',precision_down*100,'\n')
    print('Test Raté ',n,' fois. On remet cela. \n')
    tmps5=time.time()
    resultats,precision_down,model_down,scaler = deep_learning_down(df)
    print(round(time.time()-tmps5,2),' secondes')
    
# serialize model to YAML
model_down_yaml = model_down.to_yaml()
savename = 'DL_'+ticker+'-'+LaDate+'/Save_'+ticker
with open(savename+"_down.yaml", "w") as yaml_file:
    yaml_file.write(model_down_yaml)
# serialize weights to HDF5
model_down.save_weights(savename+"_down.h5")

print('Le ',Fore.BLUE,'Deep Learning',Style.RESET_ALL ,'de ',Fore.YELLOW,ticker,Style.RESET_ALL,' pour le DOWN a été effecué avec succès. Les modèles ont été sauvegardés')

n = 0
while (precision_up*100) < 69:
    n+=1
    print('\nTicker : ',ticker,'Precision Up :',precision_up*100,'\n')
    print('Test Raté ',n,' fois. On remet cela. \n')
    tmps5=time.time()
    resultats,precision_up,model_up,scaler = deep_learning_up(df)
    print(round(time.time()-tmps5,2),' secondes')


savename = 'DL_'+ticker+'-'+LaDate+'/Save_'+ticker
# serialize model to YAML
model_up_yaml = model_up.to_yaml()
with open(savename+"_up.yaml", "w") as yaml_file:
    yaml_file.write(model_up_yaml)
# serialize weights to HDF5
model_up.save_weights(savename+"_up.h5")

print('Le ',Fore.BLUE,'Deep Learning',Style.RESET_ALL ,'de ',Fore.YELLOW,ticker,Style.RESET_ALL,' pour le UP a été effecué avec succès. Les modèles ont été sauvegardés')


    
print(Fore.YELLOW,Back.MAGENTA,Style.DIM,'PASSAGE FINI!!!!!!',Style.RESET_ALL)
tmps2=round(time.time()-tmps55,2)
print ("Job done in = %f" %tmps2,'seconds')
# Out:
#
# Deeping in blue for  USDJPY_1D
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 33us/step
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 32us/step
#
# Ticker :  USDJPY_1D  Precision Down 55.26315789473685
#
# Test Raté  1  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 28us/step
# 5.37  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.61290322580645
#
# Test Raté  2  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 28us/step
# 5.29  secondes
#
# Ticker :  USDJPY_1D  Precision Down 57.49999999999999
#
# Test Raté  3  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 30us/step
# 4.98  secondes
#
# Ticker :  USDJPY_1D  Precision Down 62.06896551724138
#
# Test Raté  4  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 28us/step
# 5.21  secondes
#
# Ticker :  USDJPY_1D  Precision Down 57.89473684210527
#
# Test Raté  5  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 35us/step
# 5.48  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  6  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 43us/step
# 5.1  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.38095238095239
#
# Test Raté  7  fois. On remet cela.
#
# 675/675 [==============================] - 0s 76us/step
# 170/170 [==============================] - 0s 30us/step
# 5.03  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.35135135135135
#
# Test Raté  8  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 28us/step
# 7.75  secondes
#
# Ticker :  USDJPY_1D  Precision Down 44.44444444444444
#
# Test Raté  9  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 35us/step
# 4.98  secondes
#
# Ticker :  USDJPY_1D  Precision Down 58.139534883720934
#
# Test Raté  10  fois. On remet cela.
#
# 675/675 [==============================] - 0s 67us/step
# 170/170 [==============================] - 0s 31us/step
# 4.97  secondes
#
# Ticker :  USDJPY_1D  Precision Down 55.81395348837209
#
# Test Raté  11  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 49us/step
# 5.14  secondes
#
# Ticker :  USDJPY_1D  Precision Down 55.319148936170215
#
# Test Raté  12  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 28us/step
# 4.96  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.347826086956516
#
# Test Raté  13  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 42us/step
# 5.02  secondes
#
# Ticker :  USDJPY_1D  Precision Down 56.41025641025641
#
# Test Raté  14  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 38us/step
# 5.0  secondes
#
# Ticker :  USDJPY_1D  Precision Down 46.666666666666664
#
# Test Raté  15  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 29us/step
# 5.35  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.166666666666664
#
# Test Raté  16  fois. On remet cela.
#
# 675/675 [==============================] - 0s 76us/step
# 170/170 [==============================] - 0s 33us/step
# 5.06  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.77777777777778
#
# Test Raté  17  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 55us/step
# 5.11  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  18  fois. On remet cela.
#
# 675/675 [==============================] - 0s 66us/step
# 170/170 [==============================] - 0s 26us/step
# 5.14  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.65853658536586
#
# Test Raté  19  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 36us/step
# 5.19  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.761904761904766
#
# Test Raté  20  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 30us/step
# 5.1  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.333333333333336
#
# Test Raté  21  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 30us/step
# 5.05  secondes
#
# Ticker :  USDJPY_1D  Precision Down 48.484848484848484
#
# Test Raté  22  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 31us/step
# 6.92  secondes
#
# Ticker :  USDJPY_1D  Precision Down 47.27272727272727
#
# Test Raté  23  fois. On remet cela.
#
# 675/675 [==============================] - 0s 79us/step
# 170/170 [==============================] - 0s 34us/step
# 5.26  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.125
#
# Test Raté  24  fois. On remet cela.
#
# 675/675 [==============================] - 0s 79us/step
# 170/170 [==============================] - 0s 43us/step
# 5.12  secondes
#
# Ticker :  USDJPY_1D  Precision Down 55.00000000000001
#
# Test Raté  25  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 28us/step
# 5.26  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.84615384615385
#
# Test Raté  26  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 30us/step
# 5.21  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  27  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 27us/step
# 5.04  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  28  fois. On remet cela.
#
# 675/675 [==============================] - 0s 79us/step
# 170/170 [==============================] - 0s 29us/step
# 5.12  secondes
#
# Ticker :  USDJPY_1D  Precision Down 58.333333333333336
#
# Test Raté  29  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 29us/step
# 5.21  secondes
#
# Ticker :  USDJPY_1D  Precision Down 48.57142857142857
#
# Test Raté  30  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 27us/step
# 5.09  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.38095238095239
#
# Test Raté  31  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 30us/step
# 5.09  secondes
#
# Ticker :  USDJPY_1D  Precision Down 43.58974358974359
#
# Test Raté  32  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 36us/step
# 5.04  secondes
#
# Ticker :  USDJPY_1D  Precision Down 46.808510638297875
#
# Test Raté  33  fois. On remet cela.
#
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 28us/step
# 5.3  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.28205128205128
#
# Test Raté  34  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 27us/step
# 5.18  secondes
#
# Ticker :  USDJPY_1D  Precision Down 58.06451612903226
#
# Test Raté  35  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 28us/step
# 4.92  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.125
#
# Test Raté  36  fois. On remet cela.
#
# 675/675 [==============================] - 0s 67us/step
# 170/170 [==============================] - 0s 26us/step
# 5.11  secondes
#
# Ticker :  USDJPY_1D  Precision Down 55.26315789473685
#
# Test Raté  37  fois. On remet cela.
#
# 675/675 [==============================] - 0s 82us/step
# 170/170 [==============================] - 0s 59us/step
# 7.27  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.083333333333336
#
# Test Raté  38  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 27us/step
# 5.28  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  39  fois. On remet cela.
#
# 675/675 [==============================] - 0s 77us/step
# 170/170 [==============================] - 0s 33us/step
# 5.23  secondes
#
# Ticker :  USDJPY_1D  Precision Down 56.41025641025641
#
# Test Raté  40  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 64us/step
# 5.6  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.38095238095239
#
# Test Raté  41  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 31us/step
# 5.24  secondes
#
# Ticker :  USDJPY_1D  Precision Down 55.55555555555556
#
# Test Raté  42  fois. On remet cela.
#
# 675/675 [==============================] - 0s 67us/step
# 170/170 [==============================] - 0s 40us/step
# 5.23  secondes
#
# Ticker :  USDJPY_1D  Precision Down 56.41025641025641
#
# Test Raté  43  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 28us/step
# 5.2  secondes
#
# Ticker :  USDJPY_1D  Precision Down 57.57575757575758
#
# Test Raté  44  fois. On remet cela.
#
# 675/675 [==============================] - 0s 83us/step
# 170/170 [==============================] - 0s 35us/step
# 5.73  secondes
#
# Ticker :  USDJPY_1D  Precision Down 64.1025641025641
#
# Test Raté  45  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 28us/step
# 5.25  secondes
#
# Ticker :  USDJPY_1D  Precision Down 56.41025641025641
#
# Test Raté  46  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 26us/step
# 5.23  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.285714285714285
#
# Test Raté  47  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 57us/step
# 5.23  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.761904761904766
#
# Test Raté  48  fois. On remet cela.
#
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 28us/step
# 5.13  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  49  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 28us/step
# 5.14  secondes
#
# Ticker :  USDJPY_1D  Precision Down 48.57142857142857
#
# Test Raté  50  fois. On remet cela.
#
# 675/675 [==============================] - 0s 78us/step
# 170/170 [==============================] - 0s 45us/step
# 5.06  secondes
#
# Ticker :  USDJPY_1D  Precision Down 56.75675675675676
#
# Test Raté  51  fois. On remet cela.
#
# 675/675 [==============================] - 0s 67us/step
# 170/170 [==============================] - 0s 31us/step
# 5.21  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.5
#
# Test Raté  52  fois. On remet cela.
#
# 675/675 [==============================] - 0s 78us/step
# 170/170 [==============================] - 0s 37us/step
# 7.76  secondes
#
# Ticker :  USDJPY_1D  Precision Down 62.16216216216216
#
# Test Raté  53  fois. On remet cela.
#
# 675/675 [==============================] - 0s 83us/step
# 170/170 [==============================] - 0s 39us/step
# 5.32  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.285714285714285
#
# Test Raté  54  fois. On remet cela.
#
# 675/675 [==============================] - 0s 80us/step
# 170/170 [==============================] - 0s 28us/step
# 5.35  secondes
#
# Ticker :  USDJPY_1D  Precision Down 66.66666666666666
#
# Test Raté  55  fois. On remet cela.
#
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 28us/step
# 5.51  secondes
#
# Ticker :  USDJPY_1D  Precision Down 45.23809523809524
#
# Test Raté  56  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 27us/step
# 5.5  secondes
#
# Ticker :  USDJPY_1D  Precision Down 60.0
#
# Test Raté  57  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 40us/step
# 5.76  secondes
#
# Ticker :  USDJPY_1D  Precision Down 56.666666666666664
#
# Test Raté  58  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 29us/step
# 5.18  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.94117647058824
#
# Test Raté  59  fois. On remet cela.
#
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 28us/step
# 5.3  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  60  fois. On remet cela.
#
# 675/675 [==============================] - 0s 76us/step
# 170/170 [==============================] - 0s 28us/step
# 5.27  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  61  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 27us/step
# 5.21  secondes
#
# Ticker :  USDJPY_1D  Precision Down 48.717948717948715
#
# Test Raté  62  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 28us/step
# 5.17  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.02040816326531
#
# Test Raté  63  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 37us/step
# 5.43  secondes
#
# Ticker :  USDJPY_1D  Precision Down 58.333333333333336
#
# Test Raté  64  fois. On remet cela.
#
# 675/675 [==============================] - 0s 66us/step
# 170/170 [==============================] - 0s 26us/step
# 5.11  secondes
#
# Ticker :  USDJPY_1D  Precision Down 49.09090909090909
#
# Test Raté  65  fois. On remet cela.
#
# 675/675 [==============================] - 0s 77us/step
# 170/170 [==============================] - 0s 30us/step
# 5.29  secondes
#
# Ticker :  USDJPY_1D  Precision Down 55.26315789473685
#
# Test Raté  66  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 31us/step
# 5.45  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.285714285714285
#
# Test Raté  67  fois. On remet cela.
#
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 27us/step
# 5.24  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.65853658536586
#
# Test Raté  68  fois. On remet cela.
#
# 675/675 [==============================] - 0s 84us/step
# 170/170 [==============================] - 0s 33us/step
# 7.69  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.35135135135135
#
# Test Raté  69  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 32us/step
# 5.43  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.761904761904766
#
# Test Raté  70  fois. On remet cela.
#
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 27us/step
# 5.26  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.94117647058824
#
# Test Raté  71  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 33us/step
# 5.36  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.77777777777778
#
# Test Raté  72  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 31us/step
# 5.28  secondes
#
# Ticker :  USDJPY_1D  Precision Down 61.111111111111114
#
# Test Raté  73  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 29us/step
# 5.38  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.17391304347826
#
# Test Raté  74  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 28us/step
# 5.52  secondes
#
# Ticker :  USDJPY_1D  Precision Down 55.55555555555556
#
# Test Raté  75  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 38us/step
# 5.41  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  76  fois. On remet cela.
#
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 28us/step
# 5.2  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  77  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 27us/step
# 5.3  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.63157894736842
#
# Test Raté  78  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 27us/step
# 5.63  secondes
#
# Ticker :  USDJPY_1D  Precision Down 61.111111111111114
#
# Test Raté  79  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 33us/step
# 5.3  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.38095238095239
#
# Test Raté  80  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 31us/step
# 5.27  secondes
#
# Ticker :  USDJPY_1D  Precision Down 55.00000000000001
#
# Test Raté  81  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 28us/step
# 5.25  secondes
#
# Ticker :  USDJPY_1D  Precision Down 48.484848484848484
#
# Test Raté  82  fois. On remet cela.
#
# 675/675 [==============================] - 0s 66us/step
# 170/170 [==============================] - 0s 27us/step
# 5.32  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.54545454545454
#
# Test Raté  83  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 32us/step
# 5.69  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.77777777777778
#
# Test Raté  84  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 30us/step
# 7.96  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.11111111111111
#
# Test Raté  85  fois. On remet cela.
#
# 675/675 [==============================] - 0s 80us/step
# 170/170 [==============================] - 0s 31us/step
# 5.61  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.5
#
# Test Raté  86  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 31us/step
# 5.56  secondes
#
# Ticker :  USDJPY_1D  Precision Down 57.14285714285714
#
# Test Raté  87  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 29us/step
# 5.35  secondes
#
# Ticker :  USDJPY_1D  Precision Down 55.81395348837209
#
# Test Raté  88  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 28us/step
# 5.56  secondes
#
# Ticker :  USDJPY_1D  Precision Down 57.49999999999999
#
# Test Raté  89  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 27us/step
# 5.54  secondes
#
# Ticker :  USDJPY_1D  Precision Down 60.0
#
# Test Raté  90  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 32us/step
# 5.47  secondes
#
# Ticker :  USDJPY_1D  Precision Down 60.0
#
# Test Raté  91  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 30us/step
# 5.22  secondes
#
# Ticker :  USDJPY_1D  Precision Down 56.09756097560976
#
# Test Raté  92  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 30us/step
# 5.41  secondes
#
# Ticker :  USDJPY_1D  Precision Down 58.82352941176471
#
# Test Raté  93  fois. On remet cela.
#
# 675/675 [==============================] - 0s 76us/step
# 170/170 [==============================] - 0s 30us/step
# 5.59  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.84615384615385
#
# Test Raté  94  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 29us/step
# 5.41  secondes
#
# Ticker :  USDJPY_1D  Precision Down 56.09756097560976
#
# Test Raté  95  fois. On remet cela.
#
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 26us/step
# 5.27  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.35135135135135
#
# Test Raté  96  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 34us/step
# 5.31  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.77777777777778
#
# Test Raté  97  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 27us/step
# 5.36  secondes
#
# Ticker :  USDJPY_1D  Precision Down 57.14285714285714
#
# Test Raté  98  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 34us/step
# 5.39  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  99  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 34us/step
# 5.51  secondes
#
# Ticker :  USDJPY_1D  Precision Down 47.05882352941176
#
# Test Raté  100  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 32us/step
# 5.27  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.61290322580645
#
# Test Raté  101  fois. On remet cela.
#
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 29us/step
# 7.82  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.94117647058824
#
# Test Raté  102  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 26us/step
# 5.33  secondes
#
# Ticker :  USDJPY_1D  Precision Down 47.5
#
# Test Raté  103  fois. On remet cela.
#
# 675/675 [==============================] - 0s 78us/step
# 170/170 [==============================] - 0s 35us/step
# 5.44  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.85185185185185
#
# Test Raté  104  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 27us/step
# 5.25  secondes
#
# Ticker :  USDJPY_1D  Precision Down 43.24324324324324
#
# Test Raté  105  fois. On remet cela.
#
# 675/675 [==============================] - 0s 77us/step
# 170/170 [==============================] - 0s 28us/step
# 5.24  secondes
#
# Ticker :  USDJPY_1D  Precision Down 58.536585365853654
#
# Test Raté  106  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 30us/step
# 5.35  secondes
#
# Ticker :  USDJPY_1D  Precision Down 46.51162790697674
#
# Test Raté  107  fois. On remet cela.
#
# 675/675 [==============================] - 0s 65us/step
# 170/170 [==============================] - 0s 36us/step
# 5.27  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.77777777777778
#
# Test Raté  108  fois. On remet cela.
#
# 675/675 [==============================] - 0s 81us/step
# 170/170 [==============================] - 0s 26us/step
# 5.38  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  109  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 29us/step
# 5.19  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.285714285714285
#
# Test Raté  110  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 29us/step
# 5.3  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  111  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 31us/step
# 5.35  secondes
#
# Ticker :  USDJPY_1D  Precision Down 46.34146341463415
#
# Test Raté  112  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 37us/step
# 5.31  secondes
#
# Ticker :  USDJPY_1D  Precision Down 47.368421052631575
#
# Test Raté  113  fois. On remet cela.
#
# 675/675 [==============================] - 0s 66us/step
# 170/170 [==============================] - 0s 27us/step
# 5.25  secondes
#
# Ticker :  USDJPY_1D  Precision Down 56.81818181818182
#
# Test Raté  114  fois. On remet cela.
#
# 675/675 [==============================] - 0s 67us/step
# 170/170 [==============================] - 0s 28us/step
# 5.42  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.63157894736842
#
# Test Raté  115  fois. On remet cela.
#
# 675/675 [==============================] - 0s 66us/step
# 170/170 [==============================] - 0s 27us/step
# 5.29  secondes
#
# Ticker :  USDJPY_1D  Precision Down 57.89473684210527
#
# Test Raté  116  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 29us/step
# 5.37  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.17391304347826
#
# Test Raté  117  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 31us/step
# 5.38  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  118  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 33us/step
# 5.32  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.347826086956516
#
# Test Raté  119  fois. On remet cela.
#
# 675/675 [==============================] - 0s 85us/step
# 170/170 [==============================] - 0s 33us/step
# 8.53  secondes
#
# Ticker :  USDJPY_1D  Precision Down 48.484848484848484
#
# Test Raté  120  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 38us/step
# 5.56  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.77777777777778
#
# Test Raté  121  fois. On remet cela.
#
# 675/675 [==============================] - 0s 82us/step
# 170/170 [==============================] - 0s 29us/step
# 5.61  secondes
#
# Ticker :  USDJPY_1D  Precision Down 55.319148936170215
#
# Test Raté  122  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 27us/step
# 5.41  secondes
#
# Ticker :  USDJPY_1D  Precision Down 47.82608695652174
#
# Test Raté  123  fois. On remet cela.
#
# 675/675 [==============================] - 0s 79us/step
# 170/170 [==============================] - 0s 38us/step
# 5.51  secondes
#
# Ticker :  USDJPY_1D  Precision Down 56.86274509803921
#
# Test Raté  124  fois. On remet cela.
#
# 675/675 [==============================] - 0s 84us/step
# 170/170 [==============================] - 0s 33us/step
# 5.26  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.054054054054056
#
# Test Raté  125  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 28us/step
# 5.52  secondes
#
# Ticker :  USDJPY_1D  Precision Down 47.5
#
# Test Raté  126  fois. On remet cela.
#
# 675/675 [==============================] - 0s 81us/step
# 170/170 [==============================] - 0s 32us/step
# 5.67  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  127  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 28us/step
# 5.5  secondes
#
# Ticker :  USDJPY_1D  Precision Down 44.44444444444444
#
# Test Raté  128  fois. On remet cela.
#
# 675/675 [==============================] - 0s 76us/step
# 170/170 [==============================] - 0s 29us/step
# 5.29  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.191489361702125
#
# Test Raté  129  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 28us/step
# 5.38  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.06122448979592
#
# Test Raté  130  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 27us/step
# 5.44  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.347826086956516
#
# Test Raté  131  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 30us/step
# 5.7  secondes
#
# Ticker :  USDJPY_1D  Precision Down 43.333333333333336
#
# Test Raté  132  fois. On remet cela.
#
# 675/675 [==============================] - 0s 80us/step
# 170/170 [==============================] - 0s 43us/step
# 5.91  secondes
#
# Ticker :  USDJPY_1D  Precision Down 48.78048780487805
#
# Test Raté  133  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 28us/step
# 5.72  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.77777777777778
#
# Test Raté  134  fois. On remet cela.
#
# 675/675 [==============================] - 0s 67us/step
# 170/170 [==============================] - 0s 29us/step
# 5.37  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.28205128205128
#
# Test Raté  135  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 26us/step
# 5.3  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.02040816326531
#
# Test Raté  136  fois. On remet cela.
#
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 29us/step
# 5.31  secondes
#
# Ticker :  USDJPY_1D  Precision Down 60.0
#
# Test Raté  137  fois. On remet cela.
#
# 675/675 [==============================] - 0s 87us/step
# 170/170 [==============================] - 0s 38us/step
# 8.08  secondes
#
# Ticker :  USDJPY_1D  Precision Down 56.52173913043478
#
# Test Raté  138  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 28us/step
# 5.55  secondes
#
# Ticker :  USDJPY_1D  Precision Down 57.89473684210527
#
# Test Raté  139  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 35us/step
# 5.39  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.333333333333336
#
# Test Raté  140  fois. On remet cela.
#
# 675/675 [==============================] - 0s 84us/step
# 170/170 [==============================] - 0s 30us/step
# 5.59  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.0
#
# Test Raté  141  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 39us/step
# 5.39  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.54545454545454
#
# Test Raté  142  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 29us/step
# 5.48  secondes
#
# Ticker :  USDJPY_1D  Precision Down 56.75675675675676
#
# Test Raté  143  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 30us/step
# 5.38  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.06382978723404
#
# Test Raté  144  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 29us/step
# 5.58  secondes
#
# Ticker :  USDJPY_1D  Precision Down 47.22222222222222
#
# Test Raté  145  fois. On remet cela.
#
# 675/675 [==============================] - 0s 83us/step
# 170/170 [==============================] - 0s 30us/step
# 5.46  secondes
#
# Ticker :  USDJPY_1D  Precision Down 60.0
#
# Test Raté  146  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 28us/step
# 5.38  secondes
#
# Ticker :  USDJPY_1D  Precision Down 48.837209302325576
#
# Test Raté  147  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 28us/step
# 5.39  secondes
#
# Ticker :  USDJPY_1D  Precision Down 46.808510638297875
#
# Test Raté  148  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 30us/step
# 5.51  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.054054054054056
#
# Test Raté  149  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 35us/step
# 5.41  secondes
#
# Ticker :  USDJPY_1D  Precision Down 44.44444444444444
#
# Test Raté  150  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 28us/step
# 5.48  secondes
#
# Ticker :  USDJPY_1D  Precision Down 59.09090909090909
#
# Test Raté  151  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 29us/step
# 5.54  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.347826086956516
#
# Test Raté  152  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 29us/step
# 5.46  secondes
#
# Ticker :  USDJPY_1D  Precision Down 55.55555555555556
#
# Test Raté  153  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 39us/step
# 5.45  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.61290322580645
#
# Test Raté  154  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 40us/step
# 5.36  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.285714285714285
#
# Test Raté  155  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 30us/step
# 5.44  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  156  fois. On remet cela.
#
# 675/675 [==============================] - 0s 90us/step
# 170/170 [==============================] - 0s 33us/step
# 8.6  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.21951219512195
#
# Test Raté  157  fois. On remet cela.
#
# 675/675 [==============================] - 0s 81us/step
# 170/170 [==============================] - 0s 29us/step
# 5.72  secondes
#
# Ticker :  USDJPY_1D  Precision Down 59.523809523809526
#
# Test Raté  158  fois. On remet cela.
#
# 675/675 [==============================] - 0s 76us/step
# 170/170 [==============================] - 0s 27us/step
# 5.4  secondes
#
# Ticker :  USDJPY_1D  Precision Down 59.523809523809526
#
# Test Raté  159  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 38us/step
# 5.44  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.28205128205128
#
# Test Raté  160  fois. On remet cela.
#
# 675/675 [==============================] - 0s 78us/step
# 170/170 [==============================] - 0s 31us/step
# 5.51  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.5
#
# Test Raté  161  fois. On remet cela.
#
# 675/675 [==============================] - 0s 79us/step
# 170/170 [==============================] - 0s 36us/step
# 5.68  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.0
#
# Test Raté  162  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 30us/step
# 5.5  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.48837209302325
#
# Test Raté  163  fois. On remet cela.
#
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 30us/step
# 5.4  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.42857142857142
#
# Test Raté  164  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 30us/step
# 5.53  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.65853658536586
#
# Test Raté  165  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 31us/step
# 5.62  secondes
#
# Ticker :  USDJPY_1D  Precision Down 59.09090909090909
#
# Test Raté  166  fois. On remet cela.
#
# 675/675 [==============================] - 0s 80us/step
# 170/170 [==============================] - 0s 26us/step
# 5.51  secondes
#
# Ticker :  USDJPY_1D  Precision Down 48.717948717948715
#
# Test Raté  167  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 28us/step
# 5.51  secondes
#
# Ticker :  USDJPY_1D  Precision Down 55.319148936170215
#
# Test Raté  168  fois. On remet cela.
#
# 675/675 [==============================] - 0s 67us/step
# 170/170 [==============================] - 0s 26us/step
# 5.55  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  169  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 44us/step
# 5.5  secondes
#
# Ticker :  USDJPY_1D  Precision Down 59.45945945945946
#
# Test Raté  170  fois. On remet cela.
#
# 675/675 [==============================] - 0s 79us/step
# 170/170 [==============================] - 0s 36us/step
# 5.51  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.28205128205128
#
# Test Raté  171  fois. On remet cela.
#
# 675/675 [==============================] - 0s 76us/step
# 170/170 [==============================] - 0s 30us/step
# 5.47  secondes
#
# Ticker :  USDJPY_1D  Precision Down 55.81395348837209
#
# Test Raté  172  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 26us/step
# 5.48  secondes
#
# Ticker :  USDJPY_1D  Precision Down 56.81818181818182
#
# Test Raté  173  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 27us/step
# 5.51  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  174  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 33us/step
# 5.43  secondes
#
# Ticker :  USDJPY_1D  Precision Down 60.0
#
# Test Raté  175  fois. On remet cela.
#
# 675/675 [==============================] - 0s 85us/step
# 170/170 [==============================] - 0s 50us/step
# 8.53  secondes
#
# Ticker :  USDJPY_1D  Precision Down 57.14285714285714
#
# Test Raté  176  fois. On remet cela.
#
# 675/675 [==============================] - 0s 77us/step
# 170/170 [==============================] - 0s 28us/step
# 5.71  secondes
#
# Ticker :  USDJPY_1D  Precision Down 46.0
#
# Test Raté  177  fois. On remet cela.
#
# 675/675 [==============================] - 0s 87us/step
# 170/170 [==============================] - 0s 27us/step
# 5.61  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.83870967741935
#
# Test Raté  178  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 33us/step
# 5.64  secondes
#
# Ticker :  USDJPY_1D  Precision Down 55.00000000000001
#
# Test Raté  179  fois. On remet cela.
#
# 675/675 [==============================] - 0s 76us/step
# 170/170 [==============================] - 0s 28us/step
# 5.52  secondes
#
# Ticker :  USDJPY_1D  Precision Down 57.89473684210527
#
# Test Raté  180  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 32us/step
# 5.58  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.84615384615385
#
# Test Raté  181  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 32us/step
# 5.69  secondes
#
# Ticker :  USDJPY_1D  Precision Down 43.58974358974359
#
# Test Raté  182  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 31us/step
# 5.51  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.65853658536586
#
# Test Raté  183  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 30us/step
# 5.61  secondes
#
# Ticker :  USDJPY_1D  Precision Down 47.5
#
# Test Raté  184  fois. On remet cela.
#
# 675/675 [==============================] - 0s 83us/step
# 170/170 [==============================] - 0s 27us/step
# 5.93  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.17391304347826
#
# Test Raté  185  fois. On remet cela.
#
# 675/675 [==============================] - 0s 64us/step
# 170/170 [==============================] - 0s 27us/step
# 5.56  secondes
#
# Ticker :  USDJPY_1D  Precision Down 58.333333333333336
#
# Test Raté  186  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 31us/step
# 5.65  secondes
#
# Ticker :  USDJPY_1D  Precision Down 58.82352941176471
#
# Test Raté  187  fois. On remet cela.
#
# 675/675 [==============================] - 0s 77us/step
# 170/170 [==============================] - 0s 31us/step
# 5.65  secondes
#
# Ticker :  USDJPY_1D  Precision Down 48.148148148148145
#
# Test Raté  188  fois. On remet cela.
#
# 675/675 [==============================] - 0s 78us/step
# 170/170 [==============================] - 0s 55us/step
# 5.66  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.84615384615385
#
# Test Raté  189  fois. On remet cela.
#
# 675/675 [==============================] - 0s 91us/step
# 170/170 [==============================] - 0s 29us/step
# 5.88  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.48837209302325
#
# Test Raté  190  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 29us/step
# 5.53  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.761904761904766
#
# Test Raté  191  fois. On remet cela.
#
# 675/675 [==============================] - 0s 77us/step
# 170/170 [==============================] - 0s 29us/step
# 5.55  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  192  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 28us/step
# 5.69  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.63157894736842
#
# Test Raté  193  fois. On remet cela.
#
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 40us/step
# 5.48  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.17391304347826
#
# Test Raté  194  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 32us/step
# 5.49  secondes
#
# Ticker :  USDJPY_1D  Precision Down 53.333333333333336
#
# Test Raté  195  fois. On remet cela.
#
# 675/675 [==============================] - 0s 86us/step
# 170/170 [==============================] - 0s 28us/step
# 8.71  secondes
#
# Ticker :  USDJPY_1D  Precision Down 57.89473684210527
#
# Test Raté  196  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 32us/step
# 5.78  secondes
#
# Ticker :  USDJPY_1D  Precision Down 48.837209302325576
#
# Test Raté  197  fois. On remet cela.
#
# 675/675 [==============================] - 0s 84us/step
# 170/170 [==============================] - 0s 28us/step
# 5.77  secondes
#
# Ticker :  USDJPY_1D  Precision Down 57.14285714285714
#
# Test Raté  198  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 34us/step
# 5.61  secondes
#
# Ticker :  USDJPY_1D  Precision Down 46.666666666666664
#
# Test Raté  199  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 27us/step
# 5.67  secondes
#
# Ticker :  USDJPY_1D  Precision Down 56.52173913043478
#
# Test Raté  200  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 28us/step
# 5.49  secondes
#
# Ticker :  USDJPY_1D  Precision Down 57.49999999999999
#
# Test Raté  201  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 27us/step
# 5.38  secondes
#
# Ticker :  USDJPY_1D  Precision Down 44.11764705882353
#
# Test Raté  202  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 30us/step
# 5.54  secondes
#
# Ticker :  USDJPY_1D  Precision Down 58.97435897435898
#
# Test Raté  203  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 28us/step
# 5.44  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.27272727272727
#
# Test Raté  204  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 28us/step
# 5.44  secondes
#
# Ticker :  USDJPY_1D  Precision Down 46.15384615384615
#
# Test Raté  205  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 29us/step
# 5.48  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.94117647058824
#
# Test Raté  206  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 34us/step
# 5.55  secondes
#
# Ticker :  USDJPY_1D  Precision Down 56.36363636363636
#
# Test Raté  207  fois. On remet cela.
#
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 32us/step
# 5.49  secondes
#
# Ticker :  USDJPY_1D  Precision Down 51.92307692307693
#
# Test Raté  208  fois. On remet cela.
#
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 28us/step
# 5.54  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.77777777777778
#
# Test Raté  209  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 30us/step
# 5.49  secondes
#
# Ticker :  USDJPY_1D  Precision Down 55.55555555555556
#
# Test Raté  210  fois. On remet cela.
#
# 675/675 [==============================] - 0s 66us/step
# 170/170 [==============================] - 0s 28us/step
# 5.41  secondes
#
# Ticker :  USDJPY_1D  Precision Down 58.333333333333336
#
# Test Raté  211  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 29us/step
# 5.41  secondes
#
# Ticker :  USDJPY_1D  Precision Down 48.38709677419355
#
# Test Raté  212  fois. On remet cela.
#
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 28us/step
# 5.34  secondes
#
# Ticker :  USDJPY_1D  Precision Down 55.55555555555556
#
# Test Raté  213  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 28us/step
# 5.44  secondes
#
# Ticker :  USDJPY_1D  Precision Down 52.27272727272727
#
# Test Raté  214  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 28us/step
# 5.43  secondes
#
# Ticker :  USDJPY_1D  Precision Down 50.0
#
# Test Raté  215  fois. On remet cela.
#
# 675/675 [==============================] - 0s 66us/step
# 170/170 [==============================] - 0s 31us/step
# 8.37  secondes
#
# Ticker :  USDJPY_1D  Precision Down 54.0
#
# Test Raté  216  fois. On remet cela.
#
# 675/675 [==============================] - 0s 78us/step
# 170/170 [==============================] - 0s 26us/step
# 5.68  secondes
#
# Ticker :  USDJPY_1D  Precision Down 47.91666666666667
#
# Test Raté  217  fois. On remet cela.
#
# ...
#
# Ticker :  USDJPY_1D Precision Up : 57.72357723577236
#
# Test Raté  3510  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 29us/step
# 16.53  secondes
#
# Ticker :  USDJPY_1D Precision Up : 59.130434782608695
#
# Test Raté  3511  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 26us/step
# 17.14  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.599999999999994
#
# Test Raté  3512  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 26us/step
# 17.04  secondes
#
# Ticker :  USDJPY_1D Precision Up : 58.06451612903226
#
# Test Raté  3513  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 28us/step
# 17.03  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.36434108527132
#
# Test Raté  3514  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 26us/step
# 17.04  secondes
#
# Ticker :  USDJPY_1D Precision Up : 55.72519083969466
#
# Test Raté  3515  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 51us/step
# 17.65  secondes
#
# Ticker :  USDJPY_1D Precision Up : 59.523809523809526
#
# Test Raté  3516  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 28us/step
# 16.93  secondes
#
# Ticker :  USDJPY_1D Precision Up : 55.3030303030303
#
# Test Raté  3517  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 27us/step
# 17.65  secondes
#
# Ticker :  USDJPY_1D Precision Up : 59.01639344262295
#
# Test Raté  3518  fois. On remet cela.
#
# 675/675 [==============================] - 0s 118us/step
# 170/170 [==============================] - 0s 37us/step
# 395.16  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.49999999999999
#
# Test Raté  3519  fois. On remet cela.
#
# 675/675 [==============================] - 0s 81us/step
# 170/170 [==============================] - 0s 37us/step
# 22.05  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.72357723577236
#
# Test Raté  3520  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 29us/step
# 20.24  secondes
#
# Ticker :  USDJPY_1D Precision Up : 56.34920634920635
#
# Test Raté  3521  fois. On remet cela.
#
# 675/675 [==============================] - 0s 68us/step
# 170/170 [==============================] - 0s 28us/step
# 19.92  secondes
#
# Ticker :  USDJPY_1D Precision Up : 54.41176470588235
#
# Test Raté  3522  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 29us/step
# 20.55  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.758620689655174
#
# Test Raté  3523  fois. On remet cela.
#
# 675/675 [==============================] - 0s 88us/step
# 170/170 [==============================] - 0s 36us/step
# 20.78  secondes
#
# Ticker :  USDJPY_1D Precision Up : 55.46875
#
# Test Raté  3524  fois. On remet cela.
#
# 675/675 [==============================] - 0s 78us/step
# 170/170 [==============================] - 0s 28us/step
# 20.37  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.6271186440678
#
# Test Raté  3525  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 36us/step
# 21.31  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.25806451612904
#
# Test Raté  3526  fois. On remet cela.
#
# 675/675 [==============================] - 0s 89us/step
# 170/170 [==============================] - 0s 37us/step
# 21.27  secondes
#
# Ticker :  USDJPY_1D Precision Up : 56.52173913043478
#
# Test Raté  3527  fois. On remet cela.
#
# 675/675 [==============================] - 0s 81us/step
# 170/170 [==============================] - 0s 31us/step
# 21.95  secondes
#
# Ticker :  USDJPY_1D Precision Up : 54.54545454545454
#
# Test Raté  3528  fois. On remet cela.
#
# 675/675 [==============================] - 0s 88us/step
# 170/170 [==============================] - 0s 28us/step
# 21.16  secondes
#
# Ticker :  USDJPY_1D Precision Up : 61.86440677966102
#
# Test Raté  3529  fois. On remet cela.
#
# 675/675 [==============================] - 0s 83us/step
# 170/170 [==============================] - 0s 29us/step
# 20.78  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.8125
#
# Test Raté  3530  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 29us/step
# 20.93  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.8125
#
# Test Raté  3531  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 30us/step
# 22.71  secondes
#
# Ticker :  USDJPY_1D Precision Up : 58.82352941176471
#
# Test Raté  3532  fois. On remet cela.
#
# 675/675 [==============================] - 0s 88us/step
# 170/170 [==============================] - 0s 30us/step
# 19.94  secondes
#
# Ticker :  USDJPY_1D Precision Up : 55.55555555555556
#
# Test Raté  3533  fois. On remet cela.
#
# 675/675 [==============================] - 0s 101us/step
# 170/170 [==============================] - 0s 29us/step
# 18.21  secondes
#
# Ticker :  USDJPY_1D Precision Up : 58.97435897435898
#
# Test Raté  3534  fois. On remet cela.
#
# 675/675 [==============================] - 0s 77us/step
# 170/170 [==============================] - 0s 29us/step
# 17.75  secondes
#
# Ticker :  USDJPY_1D Precision Up : 53.2258064516129
#
# Test Raté  3535  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 27us/step
# 17.89  secondes
#
# Ticker :  USDJPY_1D Precision Up : 59.130434782608695
#
# Test Raté  3536  fois. On remet cela.
#
# 675/675 [==============================] - 0s 67us/step
# 170/170 [==============================] - 0s 29us/step
# 17.41  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.98319327731093
#
# Test Raté  3537  fois. On remet cela.
#
# 675/675 [==============================] - 0s 100us/step
# 170/170 [==============================] - 0s 37us/step
# 17.37  secondes
#
# Ticker :  USDJPY_1D Precision Up : 59.29203539823009
#
# Test Raté  3538  fois. On remet cela.
#
# 675/675 [==============================] - 0s 98us/step
# 170/170 [==============================] - 0s 30us/step
# 17.8  secondes
#
# Ticker :  USDJPY_1D Precision Up : 58.71559633027523
#
# Test Raté  3539  fois. On remet cela.
#
# 675/675 [==============================] - 0s 70us/step
# 170/170 [==============================] - 0s 27us/step
# 17.86  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.89473684210527
#
# Test Raté  3540  fois. On remet cela.
#
# 675/675 [==============================] - 0s 134us/step
# 170/170 [==============================] - 0s 31us/step
# 21.04  secondes
#
# Ticker :  USDJPY_1D Precision Up : 56.390977443609025
#
# Test Raté  3541  fois. On remet cela.
#
# 675/675 [==============================] - 0s 164us/step
# 170/170 [==============================] - 0s 33us/step
# 21.35  secondes
#
# Ticker :  USDJPY_1D Precision Up : 56.41025641025641
#
# Test Raté  3542  fois. On remet cela.
#
# 675/675 [==============================] - 0s 90us/step
# 170/170 [==============================] - 0s 28us/step
# 20.58  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.377049180327866
#
# Test Raté  3543  fois. On remet cela.
#
# 675/675 [==============================] - 0s 78us/step
# 170/170 [==============================] - 0s 43us/step
# 19.74  secondes
#
# Ticker :  USDJPY_1D Precision Up : 59.48275862068966
#
# Test Raté  3544  fois. On remet cela.
#
# 675/675 [==============================] - 0s 86us/step
# 170/170 [==============================] - 0s 26us/step
# 21.49  secondes
#
# Ticker :  USDJPY_1D Precision Up : 60.747663551401864
#
# Test Raté  3545  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 29us/step
# 18.37  secondes
#
# Ticker :  USDJPY_1D Precision Up : 61.06194690265486
#
# Test Raté  3546  fois. On remet cela.
#
# 675/675 [==============================] - 0s 75us/step
# 170/170 [==============================] - 0s 30us/step
# 18.35  secondes
#
# Ticker :  USDJPY_1D Precision Up : 61.40350877192983
#
# Test Raté  3547  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 29us/step
# 18.12  secondes
#
# Ticker :  USDJPY_1D Precision Up : 58.536585365853654
#
# Test Raté  3548  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 30us/step
# 17.83  secondes
#
# Ticker :  USDJPY_1D Precision Up : 56.88073394495413
#
# Test Raté  3549  fois. On remet cela.
#
# 675/675 [==============================] - 0s 66us/step
# 170/170 [==============================] - 0s 26us/step
# 17.34  secondes
#
# Ticker :  USDJPY_1D Precision Up : 58.26771653543307
#
# Test Raté  3550  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 26us/step
# 17.38  secondes
#
# Ticker :  USDJPY_1D Precision Up : 55.64516129032258
#
# Test Raté  3551  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 26us/step
# 17.42  secondes
#
# Ticker :  USDJPY_1D Precision Up : 56.34920634920635
#
# Test Raté  3552  fois. On remet cela.
#
# 675/675 [==============================] - 0s 224us/step
# 170/170 [==============================] - 0s 36us/step
# 468.92  secondes
#
# Ticker :  USDJPY_1D Precision Up : 59.83606557377049
#
# Test Raté  3553  fois. On remet cela.
#
# 675/675 [==============================] - 0s 79us/step
# 170/170 [==============================] - 0s 27us/step
# 21.24  secondes
#
# Ticker :  USDJPY_1D Precision Up : 60.83333333333333
#
# Test Raté  3554  fois. On remet cela.
#
# 675/675 [==============================] - 0s 89us/step
# 170/170 [==============================] - 0s 30us/step
# 26.34  secondes
#
# Ticker :  USDJPY_1D Precision Up : 55.223880597014926
#
# Test Raté  3555  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 27us/step
# 22.64  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.89473684210527
#
# Test Raté  3556  fois. On remet cela.
#
# 675/675 [==============================] - 0s 83us/step
# 170/170 [==============================] - 0s 28us/step
# 21.99  secondes
#
# Ticker :  USDJPY_1D Precision Up : 58.730158730158735
#
# Test Raté  3557  fois. On remet cela.
#
# 675/675 [==============================] - 0s 79us/step
# 170/170 [==============================] - 0s 33us/step
# 23.83  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.6271186440678
#
# Test Raté  3558  fois. On remet cela.
#
# 675/675 [==============================] - 0s 67us/step
# 170/170 [==============================] - 0s 28us/step
# 21.3  secondes
#
# Ticker :  USDJPY_1D Precision Up : 62.03703703703704
#
# Test Raté  3559  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 26us/step
# 21.85  secondes
#
# Ticker :  USDJPY_1D Precision Up : 59.66386554621849
#
# Test Raté  3560  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 26us/step
# 22.01  secondes
#
# Ticker :  USDJPY_1D Precision Up : 53.48837209302325
#
# Test Raté  3561  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 26us/step
# 21.72  secondes
#
# Ticker :  USDJPY_1D Precision Up : 56.19834710743802
#
# Test Raté  3562  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 29us/step
# 22.03  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.8125
#
# Test Raté  3563  fois. On remet cela.
#
# 675/675 [==============================] - 0s 66us/step
# 170/170 [==============================] - 0s 28us/step
# 19.83  secondes
#
# Ticker :  USDJPY_1D Precision Up : 60.37735849056604
#
# Test Raté  3564  fois. On remet cela.
#
# 675/675 [==============================] - 0s 87us/step
# 170/170 [==============================] - 0s 26us/step
# 20.22  secondes
#
# Ticker :  USDJPY_1D Precision Up : 58.59375
#
# Test Raté  3565  fois. On remet cela.
#
# 675/675 [==============================] - 0s 72us/step
# 170/170 [==============================] - 0s 28us/step
# 18.23  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.14285714285714
#
# Test Raté  3566  fois. On remet cela.
#
# 675/675 [==============================] - 0s 81us/step
# 170/170 [==============================] - 0s 27us/step
# 18.17  secondes
#
# Ticker :  USDJPY_1D Precision Up : 58.87096774193549
#
# Test Raté  3567  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 27us/step
# 17.94  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.98319327731093
#
# Test Raté  3568  fois. On remet cela.
#
# 675/675 [==============================] - 0s 67us/step
# 170/170 [==============================] - 0s 30us/step
# 18.11  secondes
#
# Ticker :  USDJPY_1D Precision Up : 59.66386554621849
#
# Test Raté  3569  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 26us/step
# 17.03  secondes
#
# Ticker :  USDJPY_1D Precision Up : 56.92307692307692
#
# Test Raté  3570  fois. On remet cela.
#
# 675/675 [==============================] - 0s 77us/step
# 170/170 [==============================] - 0s 33us/step
# 17.1  secondes
#
# Ticker :  USDJPY_1D Precision Up : 60.0
#
# Test Raté  3571  fois. On remet cela.
#
# 675/675 [==============================] - 0s 73us/step
# 170/170 [==============================] - 0s 27us/step
# 16.99  secondes
#
# Ticker :  USDJPY_1D Precision Up : 62.264150943396224
#
# Test Raté  3572  fois. On remet cela.
#
# 675/675 [==============================] - 0s 67us/step
# 170/170 [==============================] - 0s 29us/step
# 17.02  secondes
#
# Ticker :  USDJPY_1D Precision Up : 58.4070796460177
#
# Test Raté  3573  fois. On remet cela.
#
# 675/675 [==============================] - 0s 82us/step
# 170/170 [==============================] - 0s 27us/step
# 16.8  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.03125
#
# Test Raté  3574  fois. On remet cela.
#
# 675/675 [==============================] - 0s 79us/step
# 170/170 [==============================] - 0s 27us/step
# 17.4  secondes
#
# Ticker :  USDJPY_1D Precision Up : 53.43511450381679
#
# Test Raté  3575  fois. On remet cela.
#
# 675/675 [==============================] - 0s 71us/step
# 170/170 [==============================] - 0s 27us/step
# 17.07  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.25190839694656
#
# Test Raté  3576  fois. On remet cela.
#
# 675/675 [==============================] - 0s 105us/step
# 170/170 [==============================] - 0s 29us/step
# 16.67  secondes
#
# Ticker :  USDJPY_1D Precision Up : 59.64912280701754
#
# Test Raté  3577  fois. On remet cela.
#
# 675/675 [==============================] - 0s 80us/step
# 170/170 [==============================] - 0s 28us/step
# 16.66  secondes
#
# Ticker :  USDJPY_1D Precision Up : 60.0
#
# Test Raté  3578  fois. On remet cela.
#
# 675/675 [==============================] - 0s 74us/step
# 170/170 [==============================] - 0s 27us/step
# 16.69  secondes
#
# Ticker :  USDJPY_1D Precision Up : 54.81481481481482
#
# Test Raté  3579  fois. On remet cela.
#
# 675/675 [==============================] - 0s 69us/step
# 170/170 [==============================] - 0s 28us/step
# 16.3  secondes
#
# Ticker :  USDJPY_1D Precision Up : 57.377049180327866
#
# Test Raté  3580  fois. On remet cela.
#
# 675/675 [==============================] - 0s 66us/step
# 170/170 [==============================] - 0s 27us/step
# 16.65  secondes
# Le   Deep Learning  de   USDJPY_1D   pour le UP a été effecué avec succès. Les modèles ont été sauvegardés
#    PASSAGE FINI!!!!!!
# Job done in = 64369.030000 seconds

# %%
precision_down,precision_up
# Out:
# (0.7037037037037037, 0.7586206896551724)

# %%
from sklearn import  metrics, model_selection
from xgboost.sklearn import XGBClassifier

# %%
# %%time
seed = 770
np.random.seed(seed)
X = df.iloc[:,:-7]
y_up = df.iloc[:,-2].values
y_down = df.iloc[:,-1].values
X.astype(np.float64)
scaler = MinMaxScaler(feature_range=(0, 1))
X = scaler.fit_transform(X)
'''y_up = np.array(y_up).reshape(-1,1)
y_down = np.array(y_down).reshape(-1,1)'''

Xtrain = X[:bloc1,:]
Xtest = X[bloc1:,:]
ytrain_up = y_up[:bloc1]
ytest_up = y_up[bloc1:]
ytrain_down = y_down[:bloc1]
ytest_down = y_down[bloc1:]


model_up = XGBClassifier(
                            max_depth=80,
                            learning_rate=1,
                            n_estimators=1000000,
                            verbosity=1,
                            silent=None,
                            objective='binary:logistic',
                            booster='gbtree',
                            n_jobs=1,
                            nthread=None,
                            gamma=1,
                            min_child_weight=1,
                            max_delta_step=1,
                            subsample=1,
                            colsample_bytree=1,
                            colsample_bylevel=1,
                            colsample_bynode=1,
                            reg_alpha=1,
                            reg_lambda=1,
                            scale_pos_weight=1,
                            base_score=0.99,
                            random_state=1,
                            seed=None,
                            missing=None,).fit(Xtrain, ytrain_up)

model_down = XGBClassifier(
                            max_depth=80,
                            learning_rate=1,
                            n_estimators=100,
                            verbosity=1,
                            silent=None,
                            objective='binary:logistic',
                            booster='gbtree',
                            n_jobs=1,
                            nthread=None,
                            gamma=1,
                            min_child_weight=1,
                            max_delta_step=1,
                            subsample=1,
                            colsample_bytree=1,
                            colsample_bylevel=1,
                            colsample_bynode=1,
                            reg_alpha=1,
                            reg_lambda=1,
                            scale_pos_weight=1,
                            base_score=0.99,
                            random_state=1,
                            seed=None,
                            missing=None,).fit(Xtrain, ytrain_up)

# use the model to make predictions with the test data

y_pred_up = model_up.predict(Xtest)
y_pred_down = model_down.predict(Xtest)
# how did our model perform?

count_misclassified = (ytest_up != y_pred_up).sum()

print('Misclassified samples: {}'.format(count_misclassified))


#yhat_up = model_up.predict_classes(Xtest)
#yhat_down = model_down.predict_classes(Xtest)

#score_up = model_up.evaluate(Xtest, ytest_up,verbose=1)
#score_down = model_down.evaluate(Xtest, ytest_down,verbose=1)

predict_up = model_up.predict(Xtest)
predict_down = model_down.predict(Xtest)

accuracy_up = accuracy_score(ytest_up, y_pred_up)
accuracy_down = accuracy_score(ytest_down, y_pred_down)

# La précision permet de mesurer la capacité du modèle à refuser résultats non-pertinents : vrais_positifs/(vrais_positifs+faux_positifs)
precision_up = precision_score(ytest_up, y_pred_up)  
precision_down = precision_score(ytest_down, y_pred_down) 


# Recall : (vrai_positifs/(vrais_positifs+faux_négatifs))
recall_up = recall_score(ytest_up, y_pred_up) 
recall_down = recall_score(ytest_down, y_pred_down)  



print('Accuracy UP: {:.2f}'.format(accuracy_up*100))
print('Accuracy DOWN: {:.2f}'.format(accuracy_down*100))
#print('SCORE UP: {:.2f}'.format(score_up*100))
#print('SCORE DOWN: {:.2f}'.format(score_down*100))
print('Precision  UP: {:.2f}'.format(precision_up*100))
print('Precision DOWN: {:.2f}'.format(precision_down*100))
print('Recall UP: {:.2f}'.format(recall_up*100))
print('Recall DOWN: {:.2f}'.format(recall_down*100))

# %%
if (precision_up*100) < 69 or (precision_down*100) < 69:
    print('\nTicker : ',ticker,'Precision Up :',precision_up*100,' ---- Precision Down',precision_down*100,'\n')
    print('Test Raté 1 fois. On remet cela. \n')
    tmps5=time.time()
    resultats,precision_up,precision_down,model_up,model_down,scaler = deep_learning(df)
    print(round(time.time()-tmps5,2),' secondes')
    
if (precision_up*100) < 69 or (precision_down*100) < 69:
    print('\nTicker : ',ticker,'Precision Up :',precision_up*100,' ---- Precision Down',precision_down*100,'\n')
    print('Test Raté 2 fois. On remet cela. \n')
    tmps5=time.time()
    resultats,precision_up,precision_down,model_up,model_down,scaler = deep_learning(df)
    print(round(time.time()-tmps5,2),' secondes')
    
if (precision_up*100) < 69 or (precision_down*100) < 69:
    print('\nTicker : ',ticker,'Precision Up :',precision_up*100,' ---- Precision Down',precision_down*100,'\n')
    print('Test Raté 3 fois. \n')
    print('Le ',Fore.BLUE,'Deep Learning',Style.RESET_ALL ,'de ',Fore.YELLOW,ticker,Style.RESET_ALL,' a échoué. Les modèles ne sont pas sauvegardés')
    print(Fore.YELLOW,Back.MAGENTA,Style.DIM,'PASSAGE FINI!!!!!!',Style.RESET_ALL)
    tmps2=round(time.time()-tmps55,2)
    print ("Job done in = %f" %tmps2,'seconds')

if (precision_up*100) >= 69 and (precision_down*100) >= 69:
    save_model(model_up, model_down)

    print('Le ',Fore.BLUE,'Deep Learning',Style.RESET_ALL ,'de ',Fore.YELLOW,ticker,Style.RESET_ALL,' a été effecué avec succès. Les modèles ont été sauvegardés')
    print(Fore.YELLOW,Back.MAGENTA,Style.DIM,'PASSAGE FINI!!!!!!',Style.RESET_ALL)
    tmps2=round(time.time()-tmps55,2)
    print ("Job done in = %f" %tmps2,'seconds')

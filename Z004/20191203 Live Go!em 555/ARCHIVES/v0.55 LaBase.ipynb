# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
print('Importing Librairies...')
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import time
import datetime as dt
import os
print('Librairies imported')
print('')

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print(Fore.YELLOW,Back.BLUE,'LaBase Version v0.55',Style.RESET_ALL)

print('')

print('Sraping tickers')
constituents = pd.read_csv('New.csv')
print('shape : ',constituents.shape)
constituents = constituents.drop_duplicates(['Symbol'])
try:
    constituents = constituents.drop(['Unnamed: 0'],axis=1)
except:
    pass
print('shape : ',constituents.shape)    
print('Scrap -----> ok')

today = str(dt.date.today())[:5]+str(dt.date.today())[5:7]+str(dt.date.today())[7:10]
startday = str(dt.date.today()-dt.timedelta(1190))[:5]+str(dt.date.today()-dt.timedelta(1190))[5:7]+str(dt.date.today()-dt.timedelta(1190))[7:10]
yesterday = str(dt.date.today()-dt.timedelta(1))[:5]+str(dt.date.today()-dt.timedelta(1))[5:7]+str(dt.date.today()-dt.timedelta(1))[7:10]
stamp = input("Enter the date (YYYY-MM-DD): ")

start = startday
end = stamp
print('Date et heure actuelle : ',time.strftime("%d/%m/%Y %H:%M:%S", time.localtime()))
print('La date scrapée est : ', stamp)

try:
    os.remove('LaBase.csv')
except:
    pass

try:
    LaBase = pd.read_csv('LaBase.csv')
    LaBase.index = pd.to_datetime(LaBase['Date'],format='%Y-%m-%d')
    LaBase = LaBase.drop_duplicates()
    try:
        LaBase = LaBase.drop(['Unnamed: 0'],axis=1)
    except:
        pass
    LaBase['Date'] = LaBase.Date.apply(lambda x: pd.to_datetime(x).strftime('%Y-%m-%d'))
    
    print('\n Le dernier ticker de LaBase est :',LaBase.iloc[-1,0],'\n')
    if LaBase.iloc[-1,0] == stamp:
        print(Back.RED,Fore.BLACK,'\n ATTENTION! LA DATE EST DEJA DANS LA BASE!!! \n',Style.RESET_ALL)
        print('Nous procédons au nettoyage pour remplacement')
        LaBase = LaBase[LaBase.Date != stamp]
    
    LaBase=LaBase.drop_duplicates()
    print(Fore.YELLOW,'ON AJOUTE UNE LIGNE A LaBase',Style.RESET_ALL)

    tmps55=time.time()
    df = pd.DataFrame()
    BADTICKER = []
    for loop in range(0, len(constituents)):
    #for loop in range(0, 2):
        if loop == 1:
            print('\r',Fore.GREEN,' |==',Fore.BLUE,'O',Fore.RED,'==================|',end='',flush=True)
        if loop == 50:
            print('\r',Fore.GREEN,' |====',Fore.BLUE,'O',Fore.RED,'================|',end='',flush=True)
        if loop == 100:
            print('\r',Fore.GREEN,' |======',Fore.BLUE,'O',Fore.RED,'==============|',end='',flush=True)
        if loop == 150:
            print('\r',Fore.GREEN,' |========',Fore.BLUE,'O',Fore.RED,'============|',end='',flush=True)
        if loop == 200:
            print('\r',Fore.GREEN,' |==========',Fore.BLUE,'O',Fore.RED,'==========|',end='',flush=True)
        if loop == 250:
            print('\r',Fore.GREEN,' |============',Fore.BLUE,'O',Fore.RED,'========|',end='',flush=True)
        if loop == 300:
            print('\r',Fore.GREEN,' |==============',Fore.BLUE,'O',Fore.RED,'======|',end='',flush=True)
        if loop == 350:
            print('\r',Fore.GREEN,' |================',Fore.BLUE,'O',Fore.RED,'====|',end='',flush=True)
        if loop == 400:
            print('\r',Fore.GREEN,' |==================',Fore.BLUE,'O',Fore.RED,'==|',end='',flush=True)


        #try:
        ticker = (constituents.iloc[loop]['Symbol'])
        try:
            df = web.DataReader(ticker,'yahoo',end,end)
            df['Date'] = df.index
            df['Date'] = df['Date'].dt.strftime('%Y-%m-%d')
        except:
            BADTICKER.append(ticker)
            pass
        df['Symbol'] = ticker
        df = df[['Date','Symbol','High','Low','Open','Close','Volume','Adj Close']]
        LaBase = pd.concat((LaBase,df),ignore_index=False)
        LaBase = LaBase.drop(['Date'],axis=1)
    tmps22=round(time.time()-tmps55,2)
    print(Fore.BLUE,"Time for completing LaBase Generation = %f" %tmps22,'seconds \n',Style.RESET_ALL)
    print(LaBase.tail())

    print('Il y a ',len(BADTICKER),' mauvais tickers')
    print('Les voici')
    print(BADTICKER)

    #LaBase[LaBase.duplicated()].shape

    print('Base générée : ',LaBase.shape)
    print('Il y a ',LaBase[LaBase.duplicated()].shape,' Duplicats')
    LaBase=LaBase.drop_duplicates(subset=(['Date','Symbol']),keep='last')
    print('Base déclonée : ',LaBase.shape)
    print('Dernière date relevée : ',LaBase.index[-1])
    LaBase.to_csv('LaBase.csv')   

except:
    print(Fore.YELLOW,'ON GENERE LaBase',Style.RESET_ALL)
    tmps55=time.time()
    LaBase = pd.DataFrame()
    df = pd.DataFrame()
    BADTICKER = []
    for loop in range(0, len(constituents)):
    #for loop in range(0, 2):
        if loop == 1:
            print('\r',Fore.GREEN,' |==',Fore.BLUE,'O',Fore.RED,'==================|',end='',flush=True)
        if loop == 50:
            print('\r',Fore.GREEN,' |====',Fore.BLUE,'O',Fore.RED,'================|',end='',flush=True)
        if loop == 100:
            print('\r',Fore.GREEN,' |======',Fore.BLUE,'O',Fore.RED,'==============|',end='',flush=True)
        if loop == 150:
            print('\r',Fore.GREEN,' |========',Fore.BLUE,'O',Fore.RED,'============|',end='',flush=True)
        if loop == 200:
            print('\r',Fore.GREEN,' |==========',Fore.BLUE,'O',Fore.RED,'==========|',end='',flush=True)
        if loop == 250:
            print('\r',Fore.GREEN,' |============',Fore.BLUE,'O',Fore.RED,'========|',end='',flush=True)
        if loop == 300:
            print('\r',Fore.GREEN,' |==============',Fore.BLUE,'O',Fore.RED,'======|',end='',flush=True)
        if loop == 350:
            print('\r',Fore.GREEN,' |================',Fore.BLUE,'O',Fore.RED,'====|',end='',flush=True)
        if loop == 400:
            print('\r',Fore.GREEN,' |==================',Fore.BLUE,'O',Fore.RED,'==|',end='',flush=True)


        #try:
        ticker = (constituents.iloc[loop]['Symbol'])
        try:
            df = web.DataReader(ticker,'yahoo',startday,end)
            df['Date'] = str(df.index[0])[:10]
        except:
            BADTICKER.append(ticker)
            continue
        df['Symbol'] = ticker
        df = df[['Symbol','High','Low','Open','Close','Volume','Adj Close']]
        LaBase = pd.concat((LaBase,df),ignore_index=False)
    tmps22=round(time.time()-tmps55,2)
    print(Fore.BLUE,"Time for completing LaBase Generation = %f" %tmps22,'seconds \n',Style.RESET_ALL)
    print(LaBase.tail())

    print('Il y a ',len(BADTICKER),' mauvais tickers')
    print('Les voici')
    print(BADTICKER)

    #LaBase[LaBase.duplicated()].shape

    print('Base générée : ',LaBase.shape)
    print('Il y a ',LaBase[LaBase.duplicated()].shape,' Duplicats')
    LaBase = LaBase.drop_duplicates()
    print('Base déclonée : ',LaBase.shape)
    ###########################################################
    ############## SI BESOIN DE RETIRER LA DATE DU JOUR #######
    ##
    #  LaBase = LaBase[LaBase.index != '2019-09-18 00:00:00'] #
    ##
    ###########################################################
    LaBase = LaBase.drop_duplicates()
    LaBase.to_csv('LaBase.csv')
# Out:
# Importing Librairies...
# Librairies imported
#
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
#   LaBase Version v0.55
#
# Sraping tickers
# shape :  (505, 4)
# shape :  (505, 3)
# Scrap -----> ok
# Enter the date (YYYY-MM-DD):  2019-12-02
# Date et heure actuelle :  03/12/2019 12:08:18
# La date scrapée est :  2019-12-02
#  ON GENERE LaBase
#    |==================  O  ==| Time for completing LaBase Generation = 685.300000 seconds
#
#            Symbol        High         Low        Open       Close     Volume  \
# Date
# 2019-11-25    ZTS  121.970001  120.000000  120.739998  120.610001  1774400.0
# 2019-11-26    ZTS  122.000000  120.250000  120.910004  121.889999  3688700.0
# 2019-11-27    ZTS  122.919998  120.940002  122.139999  121.629997  1443300.0
# 2019-11-29    ZTS  121.820000  120.099998  121.290001  120.519997  1064400.0
# 2019-12-02    ZTS  121.500000  118.809998  120.870003  119.910004  2050400.0
#
#              Adj Close
# Date
# 2019-11-25  120.610001
# 2019-11-26  121.889999
# 2019-11-27  121.629997
# 2019-11-29  120.519997
# 2019-12-02  119.910004
# Il y a  3  mauvais tickers
# Les voici
# ['BF.B', 'BRK.B', 'TSS']
# Base générée :  (408898, 7)
# Il y a  (455, 7)  Duplicats
# Base déclonée :  (408443, 7)

# %%
len(LaBase.duplicated()),LaBase.shape

# %%
LaBase.shape
# Out:
# (408443, 7)

# %%
toto = LaBase[(LaBase.index != '2019-12-02')&(LaBase.index != '2019-11-29')]

# %%
toto.tail()
# Out:
#            Symbol        High         Low        Open       Close     Volume  \
# Date
# 2019-11-21    ZTS  121.070000  119.389999  119.860001  120.220001  1654500.0
# 2019-11-22    ZTS  121.059998  119.180000  120.410004  119.809998  1627700.0
# 2019-11-25    ZTS  121.970001  120.000000  120.739998  120.610001  1774400.0
# 2019-11-26    ZTS  122.000000  120.250000  120.910004  121.889999  3688700.0
# 2019-11-27    ZTS  122.919998  120.940002  122.139999  121.629997  1443300.0
#
#              Adj Close
# Date
# 2019-11-21  120.220001
# 2019-11-22  119.809998
# 2019-11-25  120.610001
# 2019-11-26  121.889999
# 2019-11-27  121.629997

# %%
def clearall():
    all = [var for var in globals() if var[0] != "_"]
    for var in all:
        del globals()[var]
clearall()

# %%
import warnings
warnings.filterwarnings("ignore")

print('Importing Librairies...')
import warnings
warnings.filterwarnings("ignore")
import ib_insync
from ib_insync import *
import numpy as np
import pandas as pd
import pandas_datareader as web
from colorama import Fore, Back, Style
import time
import datetime as dt
import os
import sys
print('Librairies imported')
print('')

___Author___='LumberJack Jyss'
print('Global Optimized LumberJack Environment Motor 55\nLumberJack Jyss 5779(c)')
print(Fore.BLUE,'°0Oo_D.A.G._26_oO0°')
print(Fore.YELLOW,Back.BLUE,'PlaySignal IB Version v1.55',Style.RESET_ALL)

print('')
ib = IB()


try:
    LaBase = pd.read_csv('LaBase.csv')
    print('LaBase est chargée :\n',LaBase.tail(2))
    try:
        LaBase = LaBase.drop(['Unnamed: 0'],axis=1)
    except:
        pass
    try:
        LaBase = LaBase.drop(['Date.1'],axis=1)
    except:
        pass
except:
    print("Il n'y a pas de fichier LaBase")
    kill()
stamp = input("Enter the date (YYYY-MM-DD): ")
compte = 'DU1507426'

def conX():
    util.startLoop()  # uncomment this line when in a notebook
    ib.connect('127.0.0.1', 7497, clientId=1)
    if ib.isConnected() == True:
        print('Golem est maintenant connecté à IB')
    return

def disconX():
    ib.disconnect()
    if ib.isConnected() == False:
        print('Golem est maintenant déconnecté de IB')
    return



def relevpoz():
    CPT = []
    QT = []
    TYPE = []
    STOCK = []
    TICK = []
    AVGCOST = []
    globalpoz = ib.positions(account=compte)
    
    if globalpoz == []:
        print("Il n'y a aucune position en cours actuellement.")
        poz = pd.DataFrame({'ALERTE': [101]}) 
    else:
        print('Il y a actuellement ',len(globalpoz),'positions en cours')
        for i in range(0,len(globalpoz)):
            CPT.append(globalpoz[i][0])
            TYPE.append(str(globalpoz[i][1]).split("(")[0])
            if str(globalpoz[i][1]).split("(")[0] == 'Future':
                TICK.append(str(globalpoz[i][1]).split("'")[1])
            elif str(globalpoz[i][1]).split("(")[0] == 'Forex':
                TICK.append(str(globalpoz[i][1]).split("'")[1])
            elif str(globalpoz[i][1]).split("(")[0] == 'Stock':
                TICK.append(str(globalpoz[i][1]).split("'")[1])
            else:
                TICK.append('NA')

            QT.append(globalpoz[i][2])
            AVGCOST.append(globalpoz[i][3])
            poz = pd.DataFrame()
            
            poz['Compte'] = CPT
            poz['Type'] = TYPE
            poz['Ticker'] = TICK
            poz['Quantité'] = QT
            poz['Average Cost'] = AVGCOST
            poz.to_csv('RelevPoz_'+time.strftime("%d_%m_%Y_%H_%M_%S", time.localtime())+'.csv')
    return(poz)

def price_close(LaBase,ticker):
    
    #today = str(dt.date.today())[:5]+str(dt.date.today())[5:7]+str(dt.date.today())[7:10]
    #yesterday = str(dt.date.today()-dt.timedelta(1))[:5]+str(dt.date.today()-dt.timedelta(1))[5:7]+str(dt.date.today()-dt.timedelta(1))[7:10]
    
    #if str(web.DataReader(ticker,'yahoo',yesterday,today).index[-1])[:10] == today:
    #    price = web.DataReader(ticker,'yahoo',yesterday,today).iloc[-2,3]

    #elif str(web.DataReader(ticker,'yahoo',yesterday,today).index[-1])[:10] == yesterday:
    #    price = web.DataReader(ticker,'yahoo',yesterday,today).iloc[-1,3]
    #else:
    #    price = web.DataReader(ticker,'yahoo',yesterday,today).iloc[-1,3]
    
    price = round(LaBase[LaBase['Symbol']==ticker].iloc[-1]['Close'],2)
    
    return(price)

def BUY(contract,quantity,pot):
    #Contract(conId=270639)
    ib.qualifyContracts(contract)
    order = LimitOrder('BUY', quantity, pot,account=compte,outsideRth=True)
    trade = ib.placeOrder(contract, order)
    print(trade)
    return()

def SELL(contract,quantity,pot):
    #Contract(conId=270639)
    ib.qualifyContracts(contract)
    order = LimitOrder('SELL', quantity, pot,account=compte,outsideRth=True)
    trade = ib.placeOrder(contract, order)
    print(trade)
    return()

try:
    disconX()
except:
    pass

try:
    conX()
except:
    pass

today = str(dt.date.today())[:5]+str(dt.date.today())[5:7]+str(dt.date.today())[7:10]
yesterday = str(dt.date.today()-dt.timedelta(1))[:5]+str(dt.date.today()-dt.timedelta(1))[5:7]+str(dt.date.today()-dt.timedelta(1))[7:10]

try:
    
    signals = pd.read_csv('SIGNALS/SIGNALS_'+stamp+'.csv')
    try:
        signals = signals.drop('Unnamed: 0',axis=1)
    except:
        pass
    print('Le fichier SIGNALS_'+stamp+'.csv a bien été chargé')
    
    
except:
    sys.exit("\n Golem n'a pas trouvé le fichier SIGNALS_"+stamp+".csv => Arrêt du programme")

poz = relevpoz()


foo = 0
ACTION = []
ASKED_PRICE = []
WHEN = []
OL = []
CL = []
OS = []
CS = []

try:
    signals['Tradé']
except:
    signals['Tradé'] = 'NA'
if (signals[signals['Tradé']=='NA'].shape[0] == signals.shape[0]):
    print('Passage')
else:
    
    foo = signals[signals['Tradé']=='NA'].index[0]
    print('On reprend le passage en ligne ',foo)
    
try:
    pactol = float(str(str([v for v in ib.accountValues() if v.tag == 'NetLiquidationByCurrency' and v.currency == 'BASE']).split()[2]).split("'")[1])
except:
    print('Montant du pactol non récupéré')
    ib.isConnected()
print(Back.BLUE,Fore.YELLOW,'Les fonds disponibles sur le compte sont de : $',pactol,Style.RESET_ALL)
mise = pactol * 0.02
tmps55=time.time()
for i in range (foo,signals.shape[0]):
    #try:
    #Contract(conId=270639)
    horo = signals.iloc[i,0]
    ticker = signals.iloc[i,1]
    openlong = signals.iloc[i,2]
    closelong = signals.iloc[i,3]
    openshort = signals.iloc[i,4]
    closeshort = signals.iloc[i,5]
    contract = Stock(ticker,'SMART','USD')
    price = price_close(LaBase,ticker)

    en_poz = 0
    if poz.iloc[0,0] != 101:
        if len(poz[ticker == poz.iloc[:,2]]) > 1:
            exit("Il y a plus d'une position pour le ticker ",ticker)
        elif len(poz[ticker == poz.iloc[:,2]]) == 1:
            indeX = int(str(str(poz[ticker == poz.iloc[:,2]].index).split('[')[1]).split(']')[0])
            quantity = abs(poz.iloc[indeX,3])
            if poz.iloc[indeX,3] < 0:
                en_poz = -1
            if poz.iloc[indeX,3] > 0:
                en_poz = 1

    if openlong == 1 and en_poz == 0:
        print('')
        pot = round(price * 1.002,2)
        quantity = round(mise/pot)
        print(Fore.GREEN,'Open Long',Style.RESET_ALL,' sur le ticker ',ticker,' basé sur un close limité à ', price,'\n')
        WHEN.append(time.strftime("%d-%m-%Y %H:%M:%S", time.localtime()))
        ASKED_PRICE.append(pot)
        ACTION.append('Open Long')
        OL.append(1)
        BUY(contract,quantity,pot)


    elif openshort == 1 and en_poz == 0:
        print('')
        pot = round(price * 0.998,2)
        quantity = round(mise/pot)
        print(Fore.GREEN,'Open Short',Style.RESET_ALL,' sur le ticker ',ticker,' basé sur un close limité à ', price,'\n')
        WHEN.append(time.strftime("%d-%m-%Y %H:%M:%S", time.localtime()))
        ASKED_PRICE.append(pot)
        ACTION.append('Open Short')
        OS.append(1)
        SELL(contract,quantity,pot)


    elif closelong == 1 and en_poz == 1:
        print('')
        pot = float(round(poz[poz['Ticker']==ticker]['Average Cost'],2))
        print(Fore.RED,'Close Long',Style.RESET_ALL,' sur le ticker ',ticker,' basé sur un close limité à ', price,'\n')
        WHEN.append(time.strftime("%d-%m-%Y %H:%M:%S", time.localtime()))
        ASKED_PRICE.append(pot)
        ACTION.append('Close Long')
        CL.append(1)
        SELL(contract,quantity,pot)


    elif closeshort == 1 and en_poz == -1:
        print('')
        pot = pot = float(round(poz[poz['Ticker']==ticker]['Average Cost'],2))
        print(Fore.RED,'Close Short',Style.RESET_ALL,' sur le ticker ',ticker,' basé sur un close limité à ', price,'\n')
        WHEN.append(time.strftime("%d-%m-%Y %H:%M:%S", time.localtime()))
        ASKED_PRICE.append(pot)
        ACTION.append('Close Short')
        CS.append(1)
        BUY(contract,quantity,pot)


    else:
        WHEN.append('NA')
        ASKED_PRICE.append('NA')
        ACTION.append('NA')
        
    signals.iloc[foo,7]='Traité'
    #except:
     #   print('souci boucle ',i,' pour le ticker ',ticker)
      #  continue

traded = signals
traded['Action'] = ACTION
traded['Quand'] = WHEN
traded['Prix limite'] = ASKED_PRICE

traded.to_csv('ORDRES/26_OrdresPasses_'+time.strftime("%d_%m_%Y_%H_%M_%S", time.localtime())+'.csv')

tmps22=round(time.time()-tmps55,2)
print("\n Ensemble des opérations du jour effectué en %f" %tmps22,'seconds \n')

print('Il y a eu ',sum(OL),' Open Long, ',sum(OS),' Open Short, ',sum(CL),' Close Long, et ',sum(CS),' Close Short.')
disconX()
# Out:
# Importing Librairies...
# Librairies imported
#
# Global Optimized LumberJack Environment Motor 55
# LumberJack Jyss 5779(c)
#  °0Oo_D.A.G._26_oO0°
#   PlaySignal IB Version v1.55
#
# LaBase est chargée :
#                Date Symbol    High         Low        Open       Close  \
# 408441  2019-11-29    ZTS  121.82  120.099998  121.290001  120.519997
# 408442  2019-12-02    ZTS  121.50  118.809998  120.870003  119.910004
#
#            Volume   Adj Close
# 408441  1064400.0  120.519997
# 408442  2050400.0  119.910004
# Enter the date (YYYY-MM-DD):  2019-12-02
# Golem est maintenant déconnecté de IB
# Golem est maintenant connecté à IB
# Le fichier SIGNALS_2019-12-02.csv a bien été chargé
# Il y a actuellement  48 positions en cours
# Passage
#   Les fonds disponibles sur le compte sont de : $ 490573.824
#
#  Open Long   sur le ticker  WYNN  basé sur un close limité à  119.39
#
# Trade(contract=Stock(conId=16454492, symbol='WYNN', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='WYNN', tradingClass='NMS'), order=LimitOrder(orderId=17652, clientId=1, action='BUY', totalQuantity=82.0, lmtPrice=119.63, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 55, 56, 333025, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Close Short   sur le ticker  NFLX  basé sur un close limité à  309.99
#
# Trade(contract=Stock(conId=15124833, symbol='NFLX', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='NFLX', tradingClass='NMS'), order=LimitOrder(orderId=17654, clientId=1, action='BUY', totalQuantity=47.0, lmtPrice=315.27, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 55, 56, 773866, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Open Short   sur le ticker  LH  basé sur un close limité à  172.6
#
# Trade(contract=Stock(conId=661507, symbol='LH', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='LH', tradingClass='LH'), order=LimitOrder(orderId=17656, clientId=1, action='SELL', totalQuantity=57.0, lmtPrice=172.25, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 55, 57, 294834, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Open Short   sur le ticker  BWA  basé sur un close limité à  42.47
#
# Trade(contract=Stock(conId=5336, symbol='BWA', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='BWA', tradingClass='BWA'), order=LimitOrder(orderId=17658, clientId=1, action='SELL', totalQuantity=231.0, lmtPrice=42.39, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 55, 57, 828266, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Open Short   sur le ticker  VRSK  basé sur un close limité à  146.11
#
# Trade(contract=Stock(conId=69293559, symbol='VRSK', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='VRSK', tradingClass='NMS'), order=LimitOrder(orderId=17660, clientId=1, action='SELL', totalQuantity=67.0, lmtPrice=145.82, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 55, 58, 360513, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Open Short   sur le ticker  HES  basé sur un close limité à  61.19
#
# Trade(contract=Stock(conId=39118796, symbol='HES', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='HES', tradingClass='HES'), order=LimitOrder(orderId=17662, clientId=1, action='SELL', totalQuantity=161.0, lmtPrice=61.07, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 55, 58, 786783, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Open Long   sur le ticker  PBCT  basé sur un close limité à  16.31
#
# Trade(contract=Stock(conId=43670008, symbol='PBCT', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='PBCT', tradingClass='NMS'), order=LimitOrder(orderId=17664, clientId=1, action='BUY', totalQuantity=600.0, lmtPrice=16.34, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 55, 59, 256760, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Open Short   sur le ticker  WDC  basé sur un close limité à  48.5
#
# Trade(contract=Stock(conId=13681, symbol='WDC', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='WDC', tradingClass='NMS'), order=LimitOrder(orderId=17666, clientId=1, action='SELL', totalQuantity=203.0, lmtPrice=48.4, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 55, 59, 769887, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Open Long   sur le ticker  KR  basé sur un close limité à  27.74
#
# Trade(contract=Stock(conId=8908, symbol='KR', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='KR', tradingClass='KR'), order=LimitOrder(orderId=17668, clientId=1, action='BUY', totalQuantity=353.0, lmtPrice=27.8, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 56, 0, 250625, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Open Short   sur le ticker  HRL  basé sur un close limité à  45.43
#
# Trade(contract=Stock(conId=8153, symbol='HRL', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='HRL', tradingClass='HRL'), order=LimitOrder(orderId=17670, clientId=1, action='SELL', totalQuantity=216.0, lmtPrice=45.34, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 56, 0, 748391, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Open Long   sur le ticker  UAL  basé sur un close limité à  91.63
#
# Trade(contract=Stock(conId=79498203, symbol='UAL', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='UAL', tradingClass='NMS'), order=LimitOrder(orderId=17672, clientId=1, action='BUY', totalQuantity=107.0, lmtPrice=91.81, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 56, 1, 30413, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Open Long   sur le ticker  LRCX  basé sur un close limité à  262.94
#
# Trade(contract=Stock(conId=271308, symbol='LRCX', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='LRCX', tradingClass='NMS'), order=LimitOrder(orderId=17674, clientId=1, action='BUY', totalQuantity=37.0, lmtPrice=263.47, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 56, 1, 555312, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Close Long   sur le ticker  NWSA  basé sur un close limité à  12.88
#
# Trade(contract=Stock(conId=129348126, symbol='NWSA', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='NWSA', tradingClass='NMS'), order=LimitOrder(orderId=17676, clientId=1, action='SELL', totalQuantity=1150.0, lmtPrice=12.9, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 56, 2, 85227, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Close Short   sur le ticker  EFX  basé sur un close limité à  138.23
#
# Trade(contract=Stock(conId=6735, symbol='EFX', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='EFX', tradingClass='EFX'), order=LimitOrder(orderId=17678, clientId=1, action='BUY', totalQuantity=105.0, lmtPrice=141.07, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 56, 2, 315713, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Open Short   sur le ticker  CAH  basé sur un close limité à  54.64
#
# Trade(contract=Stock(conId=5407, symbol='CAH', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='CAH', tradingClass='CAH'), order=LimitOrder(orderId=17680, clientId=1, action='SELL', totalQuantity=180.0, lmtPrice=54.53, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 56, 2, 824091, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Open Long   sur le ticker  JWN  basé sur un close limité à  37.54
#
# Trade(contract=Stock(conId=272428, symbol='JWN', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='JWN', tradingClass='JWN'), order=LimitOrder(orderId=17682, clientId=1, action='BUY', totalQuantity=261.0, lmtPrice=37.62, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 56, 3, 311362, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Open Long   sur le ticker  ANTM  basé sur un close limité à  287.43
#
# Trade(contract=Stock(conId=173962302, symbol='ANTM', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='ANTM', tradingClass='ANTM'), order=LimitOrder(orderId=17684, clientId=1, action='BUY', totalQuantity=34.0, lmtPrice=288.0, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 56, 3, 489885, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Open Long   sur le ticker  DE  basé sur un close limité à  165.29
#
# Trade(contract=Stock(conId=6393, symbol='DE', exchange='SMART', primaryExchange='NYSE', currency='USD', localSymbol='DE', tradingClass='DE'), order=LimitOrder(orderId=17686, clientId=1, action='BUY', totalQuantity=59.0, lmtPrice=165.62, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 56, 3, 943619, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Open Long   sur le ticker  TMUS  basé sur un close limité à  77.64
#
# Trade(contract=Stock(conId=125980227, symbol='TMUS', exchange='SMART', primaryExchange='NASDAQ', currency='USD', localSymbol='TMUS', tradingClass='NMS'), order=LimitOrder(orderId=17688, clientId=1, action='BUY', totalQuantity=126.0, lmtPrice=77.8, outsideRth=True, account='DU1507426', conditions=[], softDollarTier=SoftDollarTier()), orderStatus=OrderStatus(status='PendingSubmit'), fills=[], log=[TradeLogEntry(time=datetime.datetime(2019, 12, 3, 13, 56, 4, 304415, tzinfo=datetime.timezone.utc), status='PendingSubmit', message='')])
#
#  Ensemble des opérations du jour effectué en 8.410000 seconds
#
# Il y a eu  9  Open Long,  7  Open Short,  1  Close Long, et  2  Close Short.
# Golem est maintenant déconnecté de IB

# %%
conX()

# %%
ib.trades()

# %%
disconX()

# %%
conX()

# %%
# MANOUAL

#ticker = 'TROW'
#contract = Stock(ticker,'SMART','USD')
#indeX = int(str(str(poz[ticker == poz.iloc[:,2]].index).split('[')[1]).split(']')[0])
#quantity = abs(poz.iloc[indeX,3])
#price = 117.34
#indeX, quantity, price

# %%
#BUY(contract,quantity,price)
#SELL(contract,quantity,price)

# %%
len(ib.positions(compte))

# %%
ib.positions(compte)

# %%
relevpoz()

# %%
signals.iloc[foo,7]='Traité'

# %%
signals.head()

# %%
util.df(ib.accountSummary(account=compte))

# %%
ib_insync.objects.PnLSingle(compte).dailyPnL

# %%
ib_insync.objects.PnLSingle(compte).unrealizedPnL

# %%
ib_insync.objects.PnLSingle(compte).realizedPnL

# %%
ib_insync.objects.PnLSingle(compte).value

# %%
ib_insync.objects.PnL(compte,'dailyPnL')

# %%
ib_insync.client.Client()#.reqCompletedOrders()

# %%
ib.qualifyContracts(contract)
order = LimitOrder('SELL', quantity, pot,account=compte,conditionsIgnoreRth=True)
trade = ib.placeOrder(contract, order)
print(trade)

# %%
disconX()
